# %%
# Stores only the required config & build files and metrics. it does not save any repo

import pandas as pd
import os
import requests
import base64

# === CONFIGURATION ===
csv_path = r"C:\GitHub\Android-Mobile-Apps\8.1-Project_GitHub_URLs.csv"
output_dir = r"C:\GitHub\AndroidProjects"
os.makedirs(output_dir, exist_ok=True)

# Subfolders
yml_output_dir = os.path.join(output_dir, "Config Files")
commits_dir = os.path.join(output_dir, "Commits")
build_info_dir = os.path.join(output_dir, "BuildInfo")
meta_output = os.path.join(output_dir, "Repo_Metadata.csv")

for d in [yml_output_dir, commits_dir, build_info_dir]:
    if os.path.exists(d):
        for file in os.listdir(d):
            os.remove(os.path.join(d, file))
    else:
        os.makedirs(d)

# === LOAD AND CLEAN CSV ===
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip().str.lower()
df = df[df['github_url'].notna()]
df['github_url'] = df['github_url'].astype(str).str.strip()
df = df[df['github_url'].str.startswith("https://")]

def extract_repo_info(url):
    parts = url.replace("https://github.com/", "").split("/")
    return parts[0], parts[1] if len(parts) > 1 else None

def github_api(url):
    headers = {'Accept': 'application/vnd.github.v3+json'}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    return None

def save_text(content_b64, path):
    try:
        decoded = base64.b64decode(content_b64).decode('utf-8')
        with open(path, 'w', encoding='utf-8') as f:
            f.write(decoded)
        return decoded
    except Exception:
        return ""

metadata = []

for url in df['github_url']:
    user, repo = extract_repo_info(url)
    print(f"\n📦 Processing {user}/{repo}...")

    # === Metadata
    repo_info = github_api(f"https://api.github.com/repos/{user}/{repo}")
    commits_info = github_api(f"https://api.github.com/repos/{user}/{repo}/commits")
    contributors_info = github_api(f"https://api.github.com/repos/{user}/{repo}/contributors")

    metadata.append({
        'repo': f"{user}/{repo}",
        'stars': repo_info.get('stargazers_count') if repo_info else None,
        'forks': repo_info.get('forks_count') if repo_info else None,
        'size_kb': repo_info.get('size') if repo_info else None,
        'commit_count': len(commits_info) if commits_info else None,
        'last_commit_date': commits_info[0]['commit']['author']['date'] if commits_info else None,
        'contributors': len(contributors_info) if contributors_info else None
    })

    # === Search and download .yml/.yaml in common CI folders
    ci_folders = ['.github/workflows', '.circleci', '.travis', '.gitlab']
    for folder in ci_folders:
        files = github_api(f"https://api.github.com/repos/{user}/{repo}/contents/{folder}")
        if not isinstance(files, list):
            continue
        for file in files:
            if file['name'].endswith(('.yml', '.yaml')):
                raw = github_api(file['url'])
                if raw and raw.get('content'):
                    save_text(raw['content'], os.path.join(yml_output_dir, f"{repo}.{file['name']}"))

    # === Search build.gradle(.kts) in root
    root_files = github_api(f"https://api.github.com/repos/{user}/{repo}/contents/")
    if isinstance(root_files, list):
        for file in root_files:
            if file['name'].startswith("build.gradle"):
                raw = github_api(file['url'])
                if raw and raw.get('content'):
                    decoded = save_text(raw['content'], os.path.join(build_info_dir, f"{repo}.{file['name']}"))
                    if 'test' in decoded.lower():
                        with open(os.path.join(build_info_dir, f"{repo}_test_lines.txt"), 'w', encoding='utf-8') as out:
                            for line in decoded.splitlines():
                                if 'test' in line.lower():
                                    out.write(line + "\n")

# === Export metadata
pd.DataFrame(metadata).to_csv(meta_output, index=False)
print("\n✅ All tasks completed without cloning.")
# Out:
# 📦 Processing AChep/15puzzle...
#
# 📦 Processing hapramp/1Rramp-Android...
#
# 📦 Processing CSID-DGU/2021-1-OSSP2-Barcode-8...
#
# 📦 Processing pknu-wap/2022_2_WAP_APP_TEAM1...
#
# 📦 Processing uberspot/2048-android...
#
# 📦 Processing TylerCarberry/2048-Battles...
#
# 📦 Processing slartus/4pdaClient-plus...
#
# 📦 Processing mansoura-cis/4th_Grade_IS-Master-...
#
# 📦 Processing felipecsl/6502Android...
#
# 📦 Processing mash-up-kr/9tique-android...
#
# 📦 Processing patri9ck/a2ln-app...
#
# 📦 Processing divVerent/aaaaxy...
#
# 📦 Processing atsushieno/aap-juce-frequalizer...
#
# 📦 Processing AsyncAlgoTrading/aat...
#
# 📦 Processing greenaddress/abcore...
#
# 📦 Processing springload/react-accessible-accordion...
#
# 📦 Processing accrescent/accrescent...
#
# 📦 Processing AChep/AcDisplay...
#
# 📦 Processing acestream/acestream-engine-android...
#
# 📦 Processing student-hub/acs-upb-mobile...
#
# 📦 Processing Stigmatoz/web-activity-time-tracker...
#
# 📦 Processing ramack/ActivityDiary...
#
# 📦 Processing butzist/ActivityLauncher...
#
# 📦 Processing coreui/coreui-free-bootstrap-admin-template...
#
# 📦 Processing aghontpi/ad-silence...
#
# 📦 Processing microsoft/AdaptiveCards...
#
# 📦 Processing AdAway/AdAway...
#
# 📦 Processing pr4bh4sh/adb-wifi-setting-manager...
#
# 📦 Processing PRosenb/AdbClipboard...
#
# 📦 Processing invoiceninja/admin-portal...
#
# 📦 Processing riggaroo/adopt-me-compose...
#
# 📦 Processing sssemil/Advanced-Settings-for-Android-Wear...
#
# 📦 Processing yuyu0127/AdventCalenderSlime...
#
# 📦 Processing beemdevelopment/Aegis...
#
# 📦 Processing nathanael-h/aelf-flutter...
#
# 📦 Processing Jamling/af-pay...
#
# 📦 Processing alexandr7035/AffinidiID...
#
# 📦 Processing daktak/afh_downloader...
#
# 📦 Processing feiyin0719/AFreeSvg...
#
# 📦 Processing dxsdyhm/AlarmAndJob...
#
# 📦 Processing yuriykulikov/AlarmClock...
#
# 📦 Processing fennifith/Alarmio...
#
# 📦 Processing gzu-liyujiang/AliyunGradleConfig...
#
# 📦 Processing nextcloud/all-in-one...
#
# 📦 Processing vlacour97/alldebrid-watcher...
#
# 📦 Processing RunaCapital/awesome-oss-alternatives...
#
# 📦 Processing deltazefiro/Amarok-Hider...
#
# 📦 Processing TeamAmaze/AmazeFileManager...
#
# 📦 Processing braniii/Ameixa...
#
# 📦 Processing Jblew/amerykahospital-personalized-advice-client-android...
#
# 📦 Processing ianyh/Amethyst...
#
# 📦 Processing oscarg798/AmiiboWiki...
#
# 📦 Processing zdavatz/AmiKo-Android...
#
# 📦 Processing amirisback/frogo-admob...
#
# 📦 Processing dokar3/amlv...
#
# 📦 Processing amos-flyinn/amos-tub-ws18-proj1...
#
# 📦 Processing aws-amplify/amplify-js...
#
# 📦 Processing plausible/analytics...
#
# 📦 Processing anbox/anbox...
#
# 📦 Processing prolificinteractive/anchored-behavior...
#
# 📦 Processing DSAppTeam/Anchors...
#
# 📦 Processing AndBible/and-bible...
#
# 📦 Processing klassm/andFHEM...
#
# 📦 Processing AndProx/AndProx...
#
# 📦 Processing rosterloh/AndrIoT...
#
# 📦 Processing fr3ts0n/AndrOBD...
#
# 📦 Processing wasabeef/awesome-android-ui...
#
# 📦 Processing sunnyswag/android-2048-compose-material3...
#
# 📦 Processing ctywzy/Android-Accounting...
#
# 📦 Processing hzitoun/android-camera2-secret-picture-taker...
#
# 📦 Processing lincanbin/Android-Carbon-Forum...
#
# 📦 Processing gonzaloguzzardi/android-clean-arquitecture...
#
# 📦 Processing HotBitmapGG/bilibili-android-client...
#
# 📦 Processing irfanirawansukirman/android-codebase-modularity...
#
# 📦 Processing commons-app/apps-android-commons...
#
# 📦 Processing Cotel/Android-Comonadic-UI...
#
# 📦 Processing jitinsharma/android-conferences...
#
# 📦 Processing odiapratama/Android-CovidBedRest...
#
# 📦 Processing saschpe/android-customtabs...
#
# 📦 Processing andremion/AndroidDevChallenge-Compose-CountdownTimer...
#
# 📦 Processing Shady-Selim/android-dev-challenge-compose-week1...
#
# 📦 Processing DroidsOnRoids/android-font-binder...
#
# 📦 Processing jaredsburrows/android-gif-search...
#
# 📦 Processing wuhenzhizao/android-gitlab-ci-build...
#
# 📦 Processing gfx/Android-Helium...
#
# 📦 Processing piotrpolak/android-http-server...
#
# 📦 Processing RichardLuo0/global-icon-pack-android...
#
# 📦 Processing mikepenz/Android-Iconics...
#
# 📦 Processing esafirm/android-image-picker...
#
# 📦 Processing CellularPrivacy/Android-IMSI-Catcher-Detector...
#
# 📦 Processing fidisys/android-invoice-generator...
#
# 📦 Processing ZoserLock/android-ir-remote...
#
# 📦 Processing jpaulynice/android-jigsaw-puzzle...
#
# 📦 Processing Infomaniak/android-kDrive...
#
# 📦 Processing Infomaniak/android-kMail...
#
# 📦 Processing odiapratama/Android-Kotlin-COVID19...
#
# 📦 Processing gayanvoice/android-layout-transitions-kotlin...
#
# 📦 Processing JonForShort/android-local-vpn...
#
# 📦 Processing TakWolf/Android-Lock9View...
#
# 📦 Processing bmaupin/android-pitchpipe...
#
# 📦 Processing hossain-khan/android-police-brutality-incidents...
#
# 📦 Processing ponewheel/android-ponewheel...
#
# 📦 Processing yongjhih/android-proguards...
#
# 📦 Processing remote-android/redroid-doc...
#
# 📦 Processing zugaldia/android-robocar...
#
# 📦 Processing matshofman/Android-RSS-Reader-Library...
#
# 📦 Processing ezhome/Android-RxFirebase...
#
# 📦 Processing trinnguyen/Android-SegmentView...
#
# 📦 Processing Razeeman/Android-SimpleTimeTracker...
#
# 📦 Processing elsewhat/com.elsewhat.android.slideshow...
#
# 📦 Processing capcom6/android-sms-gateway...
#
# 📦 Processing marinantonio/android-splitbus...
#
# 📦 Processing google-developer-training/android-kotlin-fundamentals-starter-apps...
#
# 📦 Processing krzdabrowski/android-starter-2022...
#
# 📦 Processing bensonokiora/android-supermarket-price-comparison-app-...
#
# 📦 Processing theruslanusmanov/android-taxi-client...
#
# 📦 Processing 75py/Android-TemporaryBrightness...
#
# 📦 Processing kb-1000/android-torchlight...
#
# 📦 Processing zfdang/Android-Touch-Helper...
#
# 📦 Processing revoltchat/android-twa...
#
# 📦 Processing Netdex/android-usb-script...
#
# 📦 Processing gayanvoice/android-vpn-client-ics-openvpn...
#
# 📦 Processing mcnaveen/Android-Webview-Darkmode-with-JavaScript...
#
# 📦 Processing isuPatches/android-wisefy...
#
# 📦 Processing boostcampwm-2021/android03-Contact...
#
# 📦 Processing boostcampwm-2021/android04-God-Fisherman...
#
# 📦 Processing boostcampwm-2022/android05-MoGakRun...
#
# 📦 Processing boostcampwm-2022/android06-mogle...
#
# 📦 Processing boostcampwm-2021/android07-notto...
#
# 📦 Processing tomgersic/AndroidKeyLogger...
#
# 📦 Processing junixapp/AndroidKTX...
#
# 📦 Processing paug/AndroidMakersApp...
#
# 📦 Processing GcsSloop/AndroidNote...
#
# 📦 Processing ptkNktq/AndroidNotificationNotifier...
#
# 📦 Processing kobakei/AndroidNotificationShowcase...
#
# 📦 Processing daktak/androidpn-client...
#
# 📦 Processing getActivity/AndroidProject...
#
# 📦 Processing getActivity/AndroidProject-Kotlin...
#
# 📦 Processing kibotu/AndroidResourceExtensions...
#
# 📦 Processing BruceWind/AndroidScreenShot_SysApi...
#
# 📦 Processing jonghough/AndroidSSH...
#
# 📦 Processing Fare9/AndroidSwissKnife...
#
# 📦 Processing ToxicBakery/AndroidThings-Mirror...
#
# 📦 Processing weidongjian/androidWheelView...
#
# 📦 Processing androidx/androidx...
#
# 📦 Processing andstatus/andstatus...
#
# 📦 Processing airnativeextensions/ANE-BranchIO...
#
# 📦 Processing HugoGresse/Anecdote...
#
# 📦 Processing marunjar/anewjkuapp...
#
# 📦 Processing NathanWalker/angular-seed-advanced...
#
# 📦 Processing AniList/ApiV2-GraphQL-Docs...
#
# 📦 Processing statho/animals3d...
#
# 📦 Processing anthonycr/AnimatedProgressBar...
#
# 📦 Processing luiskcs89/AnimationsGarden...
#
# 📦 Processing meta-boy/Anime-Twist...
#
# 📦 Processing brunodles/anime-watcher...
#
# 📦 Processing halilozcan/AnimeArch...
#
# 📦 Processing miao1007/AnimeWallpaper...
#
# 📦 Processing qkdxorjs1002/AniSched-Android...
#
# 📦 Processing goweii/AnyLayer...
#
# 📦 Processing AnySoftKeyboard/AnySoftKeyboard...
#
# 📦 Processing norkator/apcupsd-monitor...
#
# 📦 Processing Calsign/APDE...
#
# 📦 Processing fordfrog/apgdiff...
#
# 📦 Processing k3b/APhotoManager...
#
# 📦 Processing Rooyca/obsidian-api-request...
#
# 📦 Processing luoqii/ApkLauncher_legacy...
#
# 📦 Processing lgarin211/Laravel-BACKEND-Aplikasi-Absensi-Karyawan...
#
# 📦 Processing Dimas263/aplikasi_pendaftaran_pasien...
#
# 📦 Processing penfeizhou/APNG4Android...
#
# 📦 Processing machineinteractive/APODKTM...
#
# 📦 Processing jp1017/ApolloModMusic...
#
# 📦 Processing facebook/create-react-app...
#
# 📦 Processing mimuc/app-ins-gruene...
#
# 📦 Processing jsakamoto/WHOISClientWebApp...
#
# 📦 Processing osamhack2020/APP_KookMoBanUser_PonJohmNaimann...
#
# 📦 Processing mptwaktusolat/app_waktu_solat_malaysia...
#
# 📦 Processing yahoojapan/AppFeedback-android...
#
# 📦 Processing gjoshevski/aca-appgtw-custom-domain...
#
# 📦 Processing ar-/apple-flinger...
#
# 📦 Processing microg/AppleWifiNlpBackend...
#
# 📦 Processing astaxie/build-web-application-with-golang...
#
# 📦 Processing MuntashirAkon/AppManager...
#
# 📦 Processing 8enet/AppOpsX...
#
# 📦 Processing WikiEducationFoundation/apps-android-wikiedudashboard...
#
# 📦 Processing wikimedia/apps-android-wikipedia...
#
# 📦 Processing MengTo/AppStoreSketch...
#
# 📦 Processing solkin/appteka-android...
#
# 📦 Processing anod/AppWatcher...
#
# 📦 Processing Alberto97/ArpavBTS...
#
# 📦 Processing wzslr321/artiver...
#
# 📦 Processing santalu/aspect-ratio-imageview...
#
# 📦 Processing assume-breach/Home-Grown-Red-Team...
#
# 📦 Processing withastro/astro...
#
# 📦 Processing james-woo/athelite...
#
# 📦 Processing netmackan/ATimeTracker...
#
# 📦 Processing atticuscornett/AtmosWeather...
#
# 📦 Processing irrationalistic/atom-tasks...
#
# 📦 Processing AtomicGameEngine/AtomicGameEngine...
#
# 📦 Processing evilcorpltd/aTox...
#
# 📦 Processing rainerblind/aTrainingTracker...
#
# 📦 Processing kyawhtut-cu/atsy-cast...
#
# 📦 Processing cketti/AttachContact...
#
# 📦 Processing adrielcafe/AndroidAudioRecorder...
#
# 📦 Processing florent37/Flutter-AssetsAudioPlayer...
#
# 📦 Processing Unity-Technologies/ProjectAuditor...
#
# 📦 Processing Governikus/AusweisApp2-SDK-iOS...
#
# 📦 Processing authpass/authpass...
#
# 📦 Processing IrisRainbowNeko/genshin_auto_fish...
#
# 📦 Processing amirisback/automated-build-android-app-with-github-action...
#
# 📦 Processing valory-xyz/open-autonomy-client...
#
# 📦 Processing carousell/AutoNotifyList...
#
# 📦 Processing lopspower/AutoScrollTextView...
#
# 📦 Processing OxygenCobalt/Auxio...
#
# 📦 Processing apps4av/avare...
#
# 📦 Processing vitorhugods/AvatarView...
#
# 📦 Processing deckerst/aves...
#
# 📦 Processing gujjwal00/avnc...
#
# 📦 Processing wasabeef/awesome-android-ui...
#
# 📦 Processing UriahShaulMandel/BaldPhone...
#
# 📦 Processing robperc/BananaPeels...
#
# 📦 Processing MakinGiants/banjen...
#
# 📦 Processing suno-ai/bark...
#
# 📦 Processing dougkeen/BartRunnerAndroid...
#
# 📦 Processing pratamawijaya/BaseKotlinAndroid...
#
# 📦 Processing pelya/BasiliskII-android...
#
# 📦 Processing daktak/basketbuild_downloader...
#
# 📦 Processing CominAtYou/BatteryTile...
#
# 📦 Processing AyeshaShaukat/Project-Battle-Ships-Game...
#
# 📦 Processing battle-buddy/battlebuddy-android...
#
# 📦 Processing BaseballCardTracker/bbct-android...
#
# 📦 Processing bcgov/BCVAX-Android...
#
# 📦 Processing beat-feet/beat-feet...
#
# 📦 Processing Meituan-Dianping/beeshell...
#
# 📦 Processing VladThodo/behe-explorer...
#
# 📦 Processing VladThodo/behe-keyboard...
#
# 📦 Processing berty/berty...
#
# 📦 Processing ichsanulalifwan/best-seller-book-app...
#
# 📦 Processing CasperVerswijvelt/Better-Internet-Tiles...
#
# 📦 Processing SapuSeven/BetterUntis...
#
# 📦 Processing dylanaraps/pure-bash-bible...
#
# 📦 Processing KAYOKG/BibliotecaDev...
#
# 📦 Processing patou/biblionantes...
#
# 📦 Processing openclimatefix/bigsolarhunt...
#
# 📦 Processing joreilly/BikeShare...
#
# 📦 Processing francoisfds/BikeSharingHub...
#
# 📦 Processing silmood/Bindapter...
#
# 📦 Processing tminions/binocularss...
#
# 📦 Processing m-i-n-a-r/birday...
#
# 📦 Processing shengxinjing/programmer-job-blacklist...
#
# 📦 Processing vhaudiquet/BladePlayer...
#
# 📦 Processing rootphantomer/Blasting_dictionary...
#
# 📦 Processing PunchThrough/ble-starter-android...
#
# 📦 Processing proninyaroslav/blink-comparison...
#
# 📦 Processing kilimchoi/engineering-blogs...
#
# 📦 Processing scoutant/blokish...
#
# 📦 Processing efguydan/Blood-Donor-Blood-Bank-Finder...
#
# 📦 Processing nhirokinet/bluelineconsole...
#
# 📦 Processing geertj/bluepass...
#
# 📦 Processing bertrandmartel/bluetooth-le-analyzer...
#
# 📦 Processing Nurgak/Android-Bluetooth-Remote-Control...
#
# 📦 Processing manishkummar21/bluetoothscanning...
#
# 📦 Processing MatsuriDayo/NekoBoxForAndroid...
#
# 📦 Processing ccomeaux/boardgamegeek4android...
#
# 📦 Processing Octav14n/BoFiLo...
#
# 📦 Processing LukeHackett12/BOI-Balance-Checker...
#
# 📦 Processing h5bp/html5-boilerplate...
#
# 📦 Processing BOINC/boinc...
#
# 📦 Processing BombusMod/BombusMod...
#
# 📦 Processing bookdash/bookdash-android-app...
#
# 📦 Processing LuiSauter/bookend-android-ios...
#
# 📦 Processing Norbert515/BookSearch...
#
# 📦 Processing mejdi14/BooksSwipe...
#
# 📦 Processing babluboy/bookworm...
#
# 📦 Processing nullxception/boorusphere...
#
# 📦 Processing toolness/boromir...
#
# 📦 Processing riddhimanadib/BottomNavBar...
#
# 📦 Processing RoyWallace/BottomNavigationBar...
#
# 📦 Processing Benjamin-Code-YouTube/boumboum-back...
#
# 📦 Processing TokTok/bTox...
#
# 📦 Processing BanDev/BuddhaQuotes...
#
# 📦 Processing brarcher/budget-watch...
#
# 📦 Processing BuildAPKs/buildAPKs...
#
# 📦 Processing code-with-the-italians/bundel...
#
# 📦 Processing DatL4g/Burning-Series...
#
# 📦 Processing sweetiepiggy/Bus-When-Twin-Cities...
#
# 📦 Processing jerryc127/hexo-theme-butterfly...
#
# 📦 Processing ACM-VIT/c2c-android-2021...
#
# 📦 Processing c3nav/c3nav-android...
#
# 📦 Processing azavea/cac-tripplanner-android...
#
# 📦 Processing MichaCo/CacheManager...
#
# 📦 Processing memfis19/Cadar...
#
# 📦 Processing arop/cafe-payment-system...
#
# 📦 Processing otaconix/caffeinetile...
#
# 📦 Processing tiefz/calculadhora...
#
# 📦 Processing microsoft/calculator...
#
# 📦 Processing prathameshmm02/Calculator-inator...
#
# 📦 Processing plum-tech/CalcuPiano...
#
# 📦 Processing k3b/calef...
#
# 📦 Processing nhn/tui.calendar...
#
# 📦 Processing SufficientlySecure/calendar-import-export...
#
# 📦 Processing citiususc/calendula...
#
# 📦 Processing 75py/CallConfirm...
#
# 📦 Processing aykuttasil/CallRecorder...
#
# 📦 Processing TUM-Dev/Campus-Android...
#
# 📦 Processing tube42/candymem...
#
# 📦 Processing VincentAudibert/CanIDrive...
#
# 📦 Processing aditmodhvadia/Canteen_App...
#
# 📦 Processing CYB3R-G0D/Canvass-app...
#
# 📦 Processing fredboy/cavedroid...
#
# 📦 Processing mgerhardy/caveexpress...
#
# 📦 Processing wiringbits/cazadescuentos...
#
# 📦 Processing jkbenaim/cboy...
#
# 📦 Processing vincent-paing/CCDroidX...
#
# 📦 Processing cculife/CCULife...
#
# 📦 Processing tilk/cdlc_player...
#
# 📦 Processing MeoMunDep/Cell-Wallet...
#
# 📦 Processing nulltea/chainmetric-app...
#
# 📦 Processing LeonardoTeixeira/cinq-android-challenge...
#
# 📦 Processing dgtlmoon/changedetection.io...
#
# 📦 Processing NiciDieNase/chaosflix...
#
# 📦 Processing adrianhajdin/project_chat_application...
#
# 📦 Processing anse-app/chatgpt-demo...
#
# 📦 Processing edilsonmatola/ChatifyApp-flutter...
#
# 📦 Processing ChatSecure/ChatSecure-iOS...
#
# 📦 Processing chatwoot/chatwoot-mobile-app...
#
# 📦 Processing LeCoupa/awesome-cheatsheets...
#
# 📦 Processing soffes/cheddar-ios...
#
# 📦 Processing cheers-li/cheers-li-app...
#
# 📦 Processing mlmed/chester-xray...
#
# 📦 Processing benjaminwan/ChineseTtsTflite...
#
# 📦 Processing Pradyuman7/ChocoBar...
#
# 📦 Processing medic/cht-android...
#
# 📦 Processing karoltaka/churrascometro...
#
# 📦 Processing vgaidarji/ci-matters...
#
# 📦 Processing Haleydu/Cimoc...
#
# 📦 Processing spacepandas/cineaste-android...
#
# 📦 Processing hitanshu-dhawan/CircularProgressBar-Compose...
#
# 📦 Processing crowd-studio/circulartimer...
#
# 📦 Processing DeweyReed/ClipboardCleaner...
#
# 📦 Processing veler/clipboardzanager...
#
# 📦 Processing x13a/Clipeus...
#
# 📦 Processing mbrukman/cloud-launcher...
#
# 📦 Processing cloudinary/cloudinary_android...
#
# 📦 Processing skydoves/Cloudy...
#
# 📦 Processing CRED-CLUB/synth-android...
#
# 📦 Processing MexsonFernandes/ClusTMPay-SIH2019...
#
# 📦 Processing CMPUT301F22T06/CMPUT301F22T06_team_project...
#
# 📦 Processing crux-bphc/CMS-Android...
#
# 📦 Processing amfoss/cms-mobile...
#
# 📦 Processing TakWolf/CNode-Material-Design...
#
# 📦 Processing wendreof/cnpj_company...
#
# 📦 Processing mikayelgr/cobadge...
#
# 📦 Processing rcmstark/cocoatouch-for-android...
#
# 📦 Processing kavindyasinthasilva/Cocwallpaper-android-...
#
# 📦 Processing yuriy-budiyev/code-scanner...
#
# 📦 Processing ice1000/code_wars_android...
#
# 📦 Processing skas-labs/CodeBlitzApp...
#
# 📦 Processing CodeEditApp/CodeEditTextView...
#
# 📦 Processing jashkenas/coffeescript...
#
# 📦 Processing kerusey/CoffeeBreaker...
#
# 📦 Processing hbirchtree/coffeecutie...
#
# 📦 Processing AlexZhukovich/CoffeeDrinksWithJetpackCompose...
#
# 📦 Processing rozPierog/Cofi...
#
# 📦 Processing Commit451/coil-imagegetter...
#
# 📦 Processing CoinCapDev/CoinCap.io...
#
# 📦 Processing shrikanth7698/Collapsible-Calendar-View-Android...
#
# 📦 Processing Konyaco/CollinsDictionary...
#
# 📦 Processing PandaNocturne/Obsidian-colorful-sticky-notes...
#
# 📦 Processing matiascalvo/compose-kotlin-repositories...
#
# 📦 Processing msfjarvis/compose-lobsters...
#
# 📦 Processing PranavMaganti/compose-material-dialogs...
#
# 📦 Processing nschnettler/Compose-Scrobbler...
#
# 📦 Processing philipplackner/ComposeTimer...
#
# 📦 Processing esafirm/compose-ui-book...
#
# 📦 Processing tminet/ComposeThemeSwitch...
#
# 📦 Processing zetbaitsu/Compressor...
#
# 📦 Processing Maximus5/ConEmu...
#
# 📦 Processing DroidKaigi/conference-app-2021...
#
# 📦 Processing connectbot/connectbot...
#
# 📦 Processing andychucs/conning_tower...
#
# 📦 Processing razinj/context_launcher...
#
# 📦 Processing MedusaLeee/ContinuousSpeechRecognition...
#
# 📦 Processing ferraridamiano/ConverterNOW...
#
# 📦 Processing remind101/conveyor...
#
# 📦 Processing guolindev/coolweatherjetpack...
#
# 📦 Processing siggel/coordinatejoker...
#
# 📦 Processing mh-/corona-warn-companion-android...
#
# 📦 Processing ladrahul25/CoroutineAsyncTask...
#
# 📦 Processing i5ting/How-to-learn-node-correctly...
#
# 📦 Processing AMOS-Project-TU-Berlin-Team-2/Corridor-Navigation-Android...
#
# 📦 Processing Cosmic-Ide/Cosmic-IDE...
#
# 📦 Processing muffix/couleurbummel...
#
# 📦 Processing hidetas/AndroidCountdowns...
#
# 📦 Processing Lyken17/pytorch-OpCounter...
#
# 📦 Processing CSSEGISandData/COVID-19...
#
# 📦 Processing CSSEGISandData/COVID-19...
#
# 📦 Processing TheEconomist/covid-19-excess-deaths-tracker...
#
# 📦 Processing cds-snc/covid-alert-app...
#
# 📦 Processing jorio/CroMagRally...
#
# 📦 Processing niusounds/cronet-engine...
#
# 📦 Processing RinoReyns/CrossPlatformVstHost...
#
# 📦 Processing Jimbly/regex-crossword...
#
# 📦 Processing eastmountyxz/CSDNBlog-Security-Based...
#
# 📦 Processing sal0max/currencies...
#
# 📦 Processing scurker/currency.js...
#
# 📦 Processing vexelon-dot-net/currencybg.app...
#
# 📦 Processing Omico/CurrentActivity...
#
# 📦 Processing LiangJunrong/CurriculumVitae...
#
# 📦 Processing miguelhincapie/CustomBottomSheetBehavior...
#
# 📦 Processing Riontech/CustomCalendar...
#
# 📦 Processing posquit0/Awesome-CV...
#
# 📦 Processing onuralpszr/CvCamera-Mobile...
#
# 📦 Processing Shillos/cyirc-mobile...
#
# 📦 Processing gstraube/cythara...
#
# 📦 Processing kennyvoo/SmartLib-Cz3002-...
#
# 📦 Processing iTXTech/Daedalus...
#
# 📦 Processing STAR-ZERO/DagashiApp...
#
# 📦 Processing NUmeroAndDev/DagashiApp-android...
#
# 📦 Processing Dagda-Social/dagda-app...
#
# 📦 Processing dagger/dagger...
#
# 📦 Processing sharshi/daily-learning-app...
#
# 📦 Processing mayojava/DailyFootball...
#
# 📦 Processing NAGARAJ08/Dairy-Management-System...
#
# 📦 Processing saadeghi/daisyui...
#
# 📦 Processing scttnlsn/dandelion...
#
# 📦 Processing flex3r/DankChat...
#
# 📦 Processing DanXi-Dev/DanXi...
#
# 📦 Processing tknopp/RedPitayaDAQServer...
#
# 📦 Processing kamranahmedse/developer-roadmap...
#
# 📦 Processing sunilpaulmathew/De-Bloater...
#
# 📦 Processing code4romania/de-urgenta-android...
#
# 📦 Processing ethanmdavidson/DeathProgress...
#
# 📦 Processing Marmo/debitum...
#
# 📦 Processing chikecodes/Debt-Manager...
#
# 📦 Processing evankale/debtris...
#
# 📦 Processing fabirt/debty-v2...
#
# 📦 Processing ianramzy/decentralized-video-chat...
#
# 📦 Processing r0adkll/DeckBox...
#
# 📦 Processing snoe/deedum...
#
# 📦 Processing wispborne/deep-link-launcher...
#
# 📦 Processing sakusaku3939/DeepLAndroid...
#
# 📦 Processing fevziomurtekin/DeezerClone...
#
# 📦 Processing PhongHuynh93/DeezerKMP...
#
# 📦 Processing DeFiCh/defiscan.live...
#
# 📦 Processing melbehiry/Delish...
#
# 📦 Processing remynln/pc_delock...
#
# 📦 Processing upost/DeltaCamera...
#
# 📦 Processing demixr/demixr-app...
#
# 📦 Processing Manabu-GT/DesignOverlay-Android...
#
# 📦 Processing user1342/DroidDetective...
#
# 📦 Processing 01sadra/Detoxiom...
#
# 📦 Processing simevidas/web-dev-feeds...
#
# 📦 Processing mustafa01ali/Dev-Tiles...
#
# 📦 Processing Madonahs/Developers-Portfolio...
#
# 📦 Processing y123456yz/middleware_development_learning...
#
# 📦 Processing devhubapp/devhub...
#
# 📦 Processing kent-lee/deviantart-scraper...
#
# 📦 Processing cncf/devstats.archive...
#
# 📦 Processing rootphantomer/Blasting_dictionary...
#
# 📦 Processing yamin8000/freeDictionaryApp...
#
# 📦 Processing ralonsobeas/Didaktikapp...
#
# 📦 Processing fpvout/DigiView-Android...
#
# 📦 Processing feizc/Dimba...
#
# 📦 Processing binaryage/dirac...
#
# 📦 Processing shinil7/direct-net-share...
#
# 📦 Processing oianmol/DiscordJetpackCompose...
#
# 📦 Processing falzonv/discreet-launcher...
#
# 📦 Processing akhbulatov/discusim...
#
# 📦 Processing kidozh/DiscuzHub...
#
# 📦 Processing skydoves/DisneyMotions...
#
# 📦 Processing cmargonis/DistantWorlds-Muzei...
#
# 📦 Processing radensaleh/Ditonton-App...
#
# 📦 Processing hongbeomi/DividerSeekBar...
#
# 📦 Processing abarisain/dmix...
#
# 📦 Processing team-aliens/DMS-Android...
#
# 📦 Processing dwnste/dndplayer...
#
# 📦 Processing julian-klode/dns66...
#
# 📦 Processing devgianlu/DNSHero...
#
# 📦 Processing Tardo/DocumentOCR...
#
# 📦 Processing mgolokhov/dodroid...
#
# 📦 Processing fabienli/DokuwikiAndroid...
#
# 📦 Processing lschaeffer313/domaine-nc-mobile...
#
# 📦 Processing domogik/domodroid...
#
# 📦 Processing jamiesanson/donezo...
#
# 📦 Processing muwoo/doubanMovie-SSR...
#
# 📦 Processing zhanghai/Douya...
#
# 📦 Processing dgngulcan/droid-feed...
#
# 📦 Processing cappee/droidinfo...
#
# 📦 Processing westny/dronalize...
#
# 📦 Processing drone-plugins/sonarqube-scanner...
#
# 📦 Processing hakobast/DropdownTextView...
#
# 📦 Processing nadraliev/DsrWeatherApp...
#
# 📦 Processing Petroula/Android-Car-duino...
#
# 📦 Processing iglaweb/DuoCamera...
#
# 📦 Processing nuvious/pam-duress...
#
# 📦 Processing sasfmlzr/DvachMovie...
#
# 📦 Processing blindchimp/dwyco...
#
# 📦 Processing MaramHarsha/Dynamic-Island-Android-Full-Application...
#
# 📦 Processing quaddy-services/DynamicNightLight...
#
# 📦 Processing StAResComp/DYNAMICOPERU...
#
# 📦 Processing dzikirqu/dzikirqu-android...
#
# 📦 Processing EmaSuriano/e2e-react-native-detox...
#
# 📦 Processing e-Luminous/e_luminous_mobile...
#
# 📦 Processing CreateJS/EaselJS...
#
# 📦 Processing renyuneyun/Easer...
#
# 📦 Processing kulasekara02/eastFoods...
#
# 📦 Processing tom-anders/Easy_xkcd...
#
# 📦 Processing MaksTuev/EasyAdapter...
#
# 📦 Processing easybangumiorg/EasyBangumi...
#
# 📦 Processing anirudhmpai/EasyLocationFetch...
#
# 📦 Processing Appaxer/EasyRecipe...
#
# 📦 Processing sschueller/easyrepost...
#
# 📦 Processing mkrupal09/EasyShapeView...
#
# 📦 Processing bobrofon/easysshfs...
#
# 📦 Processing yjfnypeu/EasyThread...
#
# 📦 Processing rosuH/EasyWatermark...
#
# 📦 Processing itsarjunsinh/elder_launcher...
#
# 📦 Processing geetnsh2k1/Electricity-Frontend...
#
# 📦 Processing electrode-io/electrode-native...
#
# 📦 Processing muigukenneth/ElegantDialog...
#
# 📦 Processing element-hq/element-android...
#
# 📦 Processing areina/elfeed-cljsrn...
#
# 📦 Processing mideind/EmblaFlutterApp...
#
# 📦 Processing withplum/EmojiBottomSheetDialog...
#
# 📦 Processing santalu/empty-view...
#
# 📦 Processing framgia/android-emulator-detector...
#
# 📦 Processing subchannel13/EnchantedFortress...
#
# 📦 Processing pedroSG94/RootEncoder...
#
# 📦 Processing osipxd/encrypted-datastore...
#
# 📦 Processing akaita/encryptedsharedpreferences-example...
#
# 📦 Processing mykola-dev/energy-meter-scanner...
#
# 📦 Processing dair-ai/Prompt-Engineering-Guide...
#
# 📦 Processing techie66/EngineDataLogger---Dashboard...
#
# 📦 Processing JMRI/EngineDriver...
#
# 📦 Processing codingchili/enigmatic-mouse...
#
# 📦 Processing tj/react-enroute...
#
# 📦 Processing aliernfrog/ensicord...
#
# 📦 Processing envelop-app/envelop-android...
#
# 📦 Processing PaulMonnery/Epicture...
#
# 📦 Processing roylines/node-epimetheus...
#
# 📦 Processing hydrargyrum/epistolaire...
#
# 📦 Processing epochjs/epoch...
#
# 📦 Processing EvanRespaut/Equate...
#
# 📦 Processing taoyimin/eshop-game-android...
#
# 📦 Processing espeak-ng/espeak-ng...
#
# 📦 Processing josh0xA/Espionage...
#
# 📦 Processing exokitxr/exokit...
#
# 📦 Processing st235/ExpandableBottomBar...
#
# 📦 Processing bradtraversy/expense-tracker-react...
#
# 📦 Processing nkuppan/expensemanager...
#
# 📦 Processing mitchkoko/expensetracker...
#
# 📦 Processing KothamireNarendra/ComposeExperiment...
#
# 📦 Processing offensive-security/exploitdb...
#
# 📦 Processing supervons/ExploreRN...
#
# 📦 Processing JBirdVegas/external_jbirdvegas_mGerrit...
#
# 📦 Processing Abhiek187/ez-recipes-android...
#
# 📦 Processing ArtiomL/f5networks...
#
# 📦 Processing Masquerade0097/Face_Animate...
#
# 📦 Processing Lauszus/FaceRecognitionApp...
#
# 📦 Processing indywidualny/FaceSlim...
#
# 📦 Processing facted-net/facted-camera...
#
# 📦 Processing fzaninotto/Faker...
#
# 📦 Processing JonasBernard/FakeStandby...
#
# 📦 Processing mcastillof/FakeTraveler...
#
# 📦 Processing moritzgloeckl/FallASleep...
#
# 📦 Processing ayelrod/Social-Media-to-Inform-Family-Caregiving-Research...
#
# 📦 Processing zVolt/familyfinance-android...
#
# 📦 Processing gabm/FancyPlaces...
#
# 📦 Processing faruktoptas/FancyShowCaseView...
#
# 📦 Processing FantLab/FantLab-Android...
#
# 📦 Processing codebutler/farebot...
#
# 📦 Processing gicheonkang/fast-face-android...
#
# 📦 Processing mikepenz/FastAdapter...
#
# 📦 Processing kibotu/FastExoPlayerSeeker...
#
# 📦 Processing PatilShreyas/AndroidFastlaneCICD...
#
# 📦 Processing Albert221/FastShopping...
#
# 📦 Processing zouroboros/filmchecker...
#
# 📦 Processing SecUSo/privacy-friendly-finance-manager...
#
# 📦 Processing kpauly2/findapet...
#
# 📦 Processing symfony/finder...
#
# 📦 Processing apache/fineract-cn-mobile...
#
# 📦 Processing odaridavid/FirebaseChatApp...
#
# 📦 Processing Commit451/FirestoreAdapter...
#
# 📦 Processing MarcellHarmaci/Fitary...
#
# 📦 Processing mepox/fitbuddy...
#
# 📦 Processing saumya1singh/Fitofy-India...
#
# 📦 Processing Commit451/FitterNumberPicker...
#
# 📦 Processing alisonthemonster/FiveThingsKotlin...
#
# 📦 Processing tiquasar/FLAITER...
#
# 📦 Processing newlinedotco/FlappySwift...
#
# 📦 Processing VadimBoev/FlappyBird...
#
# 📦 Processing sarthakpranesh/FlappyFace...
#
# 📦 Processing flareteam/flare-engine...
#
# 📦 Processing SummerFalls/UDS_S32K144_FlashDriver...
#
# 📦 Processing cyb3rko/flashdim...
#
# 📦 Processing Cuberto/flashy-tabbar...
#
# 📦 Processing yahyatinani/flashy-alarm...
#
# 📦 Processing flexbooru/flexbooru...
#
# 📦 Processing FlingOS/FlingOS...
#
# 📦 Processing FLinspirer/FLinspirer...
#
# 📦 Processing flipperdevices/Flipper-Android-App...
#
# 📦 Processing spsaswat/APPF_FLIR...
#
# 📦 Processing ajay-dewari/FloatingActionButton-Menu...
#
# 📦 Processing floccusaddon/floccus...
#
# 📦 Processing fewlaps/flone-android...
#
# 📦 Processing Flowit-Game/Flowit...
#
# 📦 Processing djangoflow/flutter-odoo-timesheets...
#
# 📦 Processing livelivecoding/flutter-weather-app...
#
# 📦 Processing CarGuo/gsy_flutter_book...
#
# 📦 Processing hiennguyen92/flutter_callkit_incoming...
#
# 📦 Processing IsaiasCuvula/Flutter-Developer-Portfolio...
#
# 📦 Processing RivaanRanawat/instagram-flutter-clone...
#
# 📦 Processing SinaSys/flutter_japanese_restaurant_app...
#
# 📦 Processing NaagAlgates/flutter_permission_using_bloc...
#
# 📦 Processing lollipopkit/flutter_server_box...
#
# 📦 Processing foxsofter/flutter_thrio...
#
# 📦 Processing Natoto/flutterWechat...
#
# 📦 Processing ItsPriyesh/fontster...
#
# 📦 Processing phunehehe/foocam...
#
# 📦 Processing Tarikul711/flutter-food-delivery-app-ui...
#
# 📦 Processing localForage/localForage...
#
# 📦 Processing sktime/pytorch-forecasting...
#
# 📦 Processing martykan/forecastie...
#
# 📦 Processing cbeyls/fosdem-companion-android...
#
# 📦 Processing nucleus-ffm/foss_warn...
#
# 📦 Processing source-foundry/Hack...
#
# 📦 Processing d4rken-org/fpv-dvca...
#
# 📦 Processing comodoro/FractalZoo...
#
# 📦 Processing jfilter/frag-den-staat-app...
#
# 📦 Processing koenbok/Framer...
#
# 📦 Processing JuliaData/DataFrames.jl...
#
# 📦 Processing EarlOfEgo/FrameView...
#
# 📦 Processing seemoo-lab/frankenstein...
#
# 📦 Processing freeotp/freeotp-android...
#
# 📦 Processing futurice/freesound-android...
#
# 📦 Processing jskcse4/FreeTamilEBooks...
#
# 📦 Processing Slion/Fulguris...
#
# 📦 Processing pakoito/FunctionalAndroidReference...
#
# 📦 Processing elixsr/FwdPortForwardingApp...
#
# 📦 Processing bossly/gallerywall...
#
# 📦 Processing R4md4c/GameDealz...
#
# 📦 Processing sagiadinos/garlic-launcher...
#
# 📦 Processing ucsb-cs48-w20/gauchoshare...
#
# 📦 Processing kkla320/GaugeProgressViewStyle...
#
# 📦 Processing GelaniNijraj/gbooks-scrapper...
#
# 📦 Processing lukaspieper/Gcam-Services-Provider...
#
# 📦 Processing PatilShreyas/GDGPune-DevFest19-Android...
#
# 📦 Processing qimiko/gdps-android-public...
#
# 📦 Processing gearoenix/gearoenix...
#
# 📦 Processing grimm-co/GEARSHIFT...
#
# 📦 Processing dkanada/gelli...
#
# 📦 Processing gabrieldernbach/general-feedback-delay-network...
#
# 📦 Processing oobabooga/text-generation-webui...
#
# 📦 Processing zdavatz/generika_android...
#
# 📦 Processing WangDaYeeeeee/GeometricWeather...
#
# 📦 Processing SoorajModi/GeoNotesPlus...
#
# 📦 Processing sinawangnan7/GestureLockView...
#
# 📦 Processing ruleant/getback_gps...
#
# 📦 Processing Tommy-Geenexus/gh-release-monitor...
#
# 📦 Processing Ultra-Techies/ghala-android...
#
# 📦 Processing Ghini/ghini.desktop...
#
# 📦 Processing ogtega/ghostotp...
#
# 📦 Processing gidgethub/gidgethub...
#
# 📦 Processing elapse-d/foo-Wallpaper-Feh-Gif...
#
# 📦 Processing felipecsl/GifImageView...
#
# 📦 Processing takempf/GIFit...
#
# 📦 Processing MateriiApps/Gloom...
#
# 📦 Processing SanojPunchihewa/GlowButton...
#
# 📦 Processing uncommonhacks/glowing-potato...
#
# 📦 Processing Glucosio/glucosio-android...
#
# 📦 Processing rust-windowing/glutin...
#
# 📦 Processing codinguser/gnucash-android...
#
# 📦 Processing sitatec/Go4Lunch...
#
# 📦 Processing ligi/gobandroid...
#
# 📦 Processing bobpoekert/gobi-player...
#
# 📦 Processing ayoisaiah/gocorona...
#
# 📦 Processing godotengine/godot...
#
# 📦 Processing AkshayChordiya/gofun-android...
#
# 📦 Processing llaosgekc/golearning...
#
# 📦 Processing ipfs-shipyard/gomobile-ipfs...
#
# 📦 Processing lilongweidev/GoodWeather...
#
# 📦 Processing DeepSourceCorp/good-first-issue...
#
# 📦 Processing DiegoVictor/gorestaurant-app...
#
# 📦 Processing AdoraNwodo/got-trivia...
#
# 📦 Processing mendhak/gpslogger...
#
# 📦 Processing woheller69/gptAssist...
#
# 📦 Processing xbdcc/GrabRedEnvelope...
#
# 📦 Processing boldtrn/graphhopper-maps-capacitor...
#
# 📦 Processing zeevy/grblcontroller...
#
# 📦 Processing Blockstream/green_android...
#
# 📦 Processing kenji-tojo/greencloud-paper...
#
# 📦 Processing JulieGibbs/greenpass-android...
#
# 📦 Processing Pool-Of-Tears/GreenStash...
#
# 📦 Processing devlint/gridlex...
#
# 📦 Processing patzly/grocy-android...
#
# 📦 Processing Mariia-Ostapets/project-group-05-backend...
#
# 📦 Processing impronunciable/hackdash...
#
# 📦 Processing mitchellkrogza/The-Big-List-of-Hacked-Malware-Web-Sites...
#
# 📦 Processing iSimar/HackerNews-React-Native...
#
# 📦 Processing Hack-with-Github/Awesome-Hacking...
#
# 📦 Processing hadithmv/hadithmv.github.io...
#
# 📦 Processing Haifa3D/haifa3d-hand-app...
#
# 📦 Processing aistra0528/Hail...
#
# 📦 Processing YBIGTA/pytorch-hair-segmentation...
#
# 📦 Processing hajkmap/Hajk...
#
# 📦 Processing davquar/halfdot...
#
# 📦 Processing kaievns/halmak...
#
# 📦 Processing HandyOrg/HandyControl...
#
# 📦 Processing Foundy-LLC/Hanstargram...
#
# 📦 Processing xujiaji/HappyBubble...
#
# 📦 Processing micuintus/harbour-Berlin-Vegan...
#
# 📦 Processing Awesome-HarmonyOS/HarmonyOS...
#
# 📦 Processing hash-checker/hash-checker...
#
# 📦 Processing jefvel/hashlink-launcher...
#
# 📦 Processing serialx/hashring...
#
# 📦 Processing HathorNetwork/hathor-wallet-mobile...
#
# 📦 Processing verticalphotoplacer/HeadingCalculator...
#
# 📦 Processing yashovardhan99/HealersDiary...
#
# 📦 Processing PoojaB26/HearMeNow-DepressionChatbot-Dialogflow...
#
# 📦 Processing zimv/websocket-heartbeat-js...
#
# 📦 Processing meilisearch/heed...
#
# 📦 Processing flathub/fm.helio.Workstation...
#
# 📦 Processing compscidr/hello-java-android...
#
# 📦 Processing kauffecup/react-native-web-hello-world...
#
# 📦 Processing sdresselmann/Herculade...
#
# 📦 Processing WerWolv/ImHex...
#
# 📦 Processing ClickHouse/ClickHouse...
#
# 📦 Processing tijmenb/houseparty...
#
# 📦 Processing HuRuWo/HowToReserveFlutter...
#
# 📦 Processing HRVBand/hrv-band...
#
# 📦 Processing Waboodoo/HTTP-Shortcuts...
#
# 📦 Processing springcomp/HttpTrackingMiddleware...
#
# 📦 Processing Banana-Boat/huaxiaoyu-fe...
#
# 📦 Processing Humanizr/Humanizer...
#
# 📦 Processing VelbazhdSoftwareLLC/HungarianRingsForAndroid...
#
# 📦 Processing nahamsec/Resources-for-Beginner-Bug-Bounty-Hunters...
#
# 📦 Processing AnchorFreePartner/hydrasdk-demo-android...
#
# 📦 Processing gazpachu/hypatia...
#
# 📦 Processing zenorogue/hyperrogue...
#
# 📦 Processing varbhat/hyperupnp...
#
# 📦 Processing PurpleI2P/i2pd-android...
#
# 📦 Processing microg/IchnaeaNlpBackend...
#
# 📦 Processing bigscreen/iconic-tab-bar...
#
# 📦 Processing iconify/iconify...
#
# 📦 Processing cernekee/ics-openconnect...
#
# 📦 Processing schwabe/ics-openvpn...
#
# 📦 Processing bitfireAT/icsx5...
#
# 📦 Processing mclintprojects/ideabag2...
#
# 📦 Processing IdeaTrackerPlus/IdeaTrackerPlus...
#
# 📦 Processing TheMindhouse/idee-android...
#
# 📦 Processing Jinjinov/Ididit...
#
# 📦 Processing MohitGupta121/IES-IPS-Android...
#
# 📦 Processing Calinou/if26-projet-android...
#
# 📦 Processing codefest-iit-bhu/codefest-app...
#
# 📦 Processing Njack-IITP/IITP-Connect...
#
# 📦 Processing zjutjh/IJH-Android...
#
# 📦 Processing NVlabs/instant-ngp...
#
# 📦 Processing DevCom-IITB/instiapp-android...
#
# 📦 Processing shubhanshu02/InstiComplaints-App...
#
# 📦 Processing sonusourav/InstiGo...
#
# 📦 Processing erdewit/ib_insync...
#
# 📦 Processing the-cult-of-integral/discord-raidkit...
#
# 📦 Processing intrications/intent-intercept...
#
# 📦 Processing Interconnected-project/interconnected_mobile_client...
#
# 📦 Processing Husseinfo/interfast...
#
# 📦 Processing Commit451/InternalLinkMovementMethod...
#
# 📦 Processing Hamza417/Inure...
#
# 📦 Processing alfianlosari/FirestoreInventoryTracker...
#
# 📦 Processing iptv-org/iptv...
#
# 📦 Processing ireader/media-server...
#
# 📦 Processing LezdCS/irl-link...
#
# 📦 Processing privacybydesign/irmamobile...
#
# 📦 Processing Arduino-IRremote/Arduino-IRremote...
#
# 📦 Processing martapanc/ItalianFiscalCodeCalculatorApp...
#
# 📦 Processing kyori19/itc-lms-unofficial...
#
# 📦 Processing VelbazhdSoftwareLLC/IthakaBoardGame...
#
# 📦 Processing vgrec/ITMoldova...
#
# 📦 Processing sylvek/itracing2...
#
# 📦 Processing garg3133/JagratiWebApp...
#
# 📦 Processing EmenstaNougat/ESP32-BlueJammer...
#
# 📦 Processing phramusca/JaMuz-Remote...
#
# 📦 Processing deathkiller/jazz2-native...
#
# 📦 Processing jellyfin/jellyfin-androidtv...
#
# 📦 Processing jellyfin/jellyfin-androidtv...
#
# 📦 Processing leinelissen/jellyfin-audio-player...
#
# 📦 Processing Focfa/Jreader...
#
# 📦 Processing NPP-JSONViewer/JSON-Viewer...
#
# 📦 Processing aragaer/jtt_android...
#
# 📦 Processing TechbeeAT/jtxBoard...
#
# 📦 Processing aaronlinv/JuiceTimetable...
#
# 📦 Processing konnovdev/jukuu...
#
# 📦 Processing danirod/jumpdontdie...
#
# 📦 Processing jojoldu/junior-recruit-scheduler...
#
# 📦 Processing outadoc/just-chatting...
#
# 📦 Processing blockbasti/just_another_workout_timer...
#
# 📦 Processing JingZhuanDuoYing/JZAndroidChart...
#
# 📦 Processing derailed/k9s...
#
# 📦 Processing Kaljurand/K6nele...
#
# 📦 Processing fgl27/KA27...
#
# 📦 Processing StefanOltmann/Kaesekaestchen...
#
# 📦 Processing KaidanIM/Kaidan...
#
# 📦 Processing kaltura/kaltura-device-info-android...
#
# 📦 Processing alexcmgit/kanade...
#
# 📦 Processing skywind3000/KanaQuiz...
#
# 📦 Processing pawegio/KAndroid...
#
# 📦 Processing ichisadashioko/kanji-recognition-android...
#
# 📦 Processing kaptaind/kaptaind...
#
# 📦 Processing karma-runner/karma...
#
# 📦 Processing PhilippC/keepass2android...
#
# 📦 Processing kee-org/keevault2...
#
# 📦 Processing keibai/keibai-android...
#
# 📦 Processing LivingWithHippos/Keter-Escape...
#
# 📦 Processing peng-zhihui/HelloWord-Keyboard...
#
# 📦 Processing keymapperorg/KeyMapper...
#
# 📦 Processing yogeshpaliyal/KeyPass...
#
# 📦 Processing rnixik/knigopis.com...
#
# 📦 Processing Lojii/Knot...
#
# 📦 Processing pradeeshmp/kNOw-Corona...
#
# 📦 Processing CodemateLtd/Koffeemate...
#
# 📦 Processing KotatsuApp/Kotatsu...
#
# 📦 Processing google-developer-training/android-kotlin-fundamentals-starter-apps...
#
# 📦 Processing wupdigital/kotlin-native-superhero-app...
#
# 📦 Processing muratozturk5/Kotlin-Order-Food-App...
#
# 📦 Processing QuickPermissions/QuickPermissions-Kotlin...
#
# 📦 Processing mrcsxsiq/Kotlin-Pokedex...
#
# 📦 Processing evroon/kotlin-soundboard...
#
# 📦 Processing tscholze/kotlin-surfaceduo-duobahn...
#
# 📦 Processing HaneetGH/KotlinAndroidBase...
#
# 📦 Processing Qase/KotlinLogger...
#
# 📦 Processing felipecsl/ktnes...
#
# 📦 Processing KDE/ktrip...
#
# 📦 Processing android/android-ktx...
#
# 📦 Processing kubenav/kubenav...
#
# 📦 Processing kungfoo/geohash-java...
#
# 📦 Processing brookmg/Kuwas...
#
# 📦 Processing MM2-0/Kvaesitso...
#
# 📦 Processing noboru-i/kyouen-android...
#
# 📦 Processing Commit451/LabCoat...
#
# 📦 Processing a-frank/labeled-range-slider...
#
# 📦 Processing edgar-zigis/LabeledSeekSlider...
#
# 📦 Processing egorikftp/Lady-happy-Android...
#
# 📦 Processing Moheeeetgupta/LadyBuddy-A-woman-safety-app...
#
# 📦 Processing lapce/lapdev...
#
# 📦 Processing SubhamTyagi/Last-Launcher...
#
# 📦 Processing Leaflet/Leaflet...
#
# 📦 Processing nivisi/LeafyLauncher...
#
# 📦 Processing FlyingRadish/Leamonax...
#
# 📦 Processing leaonline/leaonline-app...
#
# 📦 Processing androiddevnotes/awesome-android-learning-resources...
#
# 📦 Processing braille-systems/learn-braille...
#
# 📦 Processing foxtrotdev/learn-digits...
#
# 📦 Processing shesheer/leavesheet...
#
# 📦 Processing gruessung/leihen...
#
# 📦 Processing Swordfish90/Lemuroid...
#
# 📦 Processing leon-ai/leon...
#
# 📦 Processing openproject/LessCode...
#
# 📦 Processing lesspass/lesspass...
#
# 📦 Processing rezaiyan/LevelProgressBar...
#
# 📦 Processing facebook/lexical...
#
# 📦 Processing XilinJia/Life-Dots...
#
# 📦 Processing JessYanCoding/LifecycleModel...
#
# 📦 Processing liftbridge-io/liftbridge...
#
# 📦 Processing objcio/issue-1-lighter-view-controllers...
#
# 📦 Processing unblinking/lilaoftheday_android...
#
# 📦 Processing lucasew/limpazap...
#
# 📦 Processing AdamLBS/LineFlag...
#
# 📦 Processing yaxarat/lingvaandroid...
#
# 📦 Processing AmrDeveloper/LinkHub...
#
# 📦 Processing BelledonneCommunications/linphone-android...
#
# 📦 Processing microsoft/ProcMon-for-Linux...
#
# 📦 Processing b3dgs/lionheart-remake...
#
# 📦 Processing listen1/listen1_mobile...
#
# 📦 Processing FishHawk/lisu-android...
#
# 📦 Processing shivarajp/LivePokemonFinder...
#
# 📦 Processing mfikricom/Login-Multi-Role-Backend...
#
# 📦 Processing DevelopFreedom/logmein-android...
#
# 📦 Processing otem/Raspberry-Pi-Looper-synth-drum-thing...
#
# 📦 Processing why168/LoopViewPagerLayout...
#
# 📦 Processing ncase/loopy...
#
# 📦 Processing wizos/loread...
#
# 📦 Processing k3b/LosslessJpgCrop...
#
# 📦 Processing VictorHVS/lotonaticos...
#
# 📦 Processing brarcher/loyalty-card-locker...
#
# 📦 Processing lfuelling/lrkFM...
#
# 📦 Processing mendezand/LTECleanerFOSS...
#
# 📦 Processing jie-meng/LuaDroid...
#
# 📦 Processing tytydraco/Ludere...
#
# 📦 Processing ludoscity/ludOScity...
#
# 📦 Processing cuongpm/ludwig-android...
#
# 📦 Processing opentelecoms-org/lumicall...
#
# 📦 Processing iamrasel/lunar-launcher...
#
# 📦 Processing wardellbagby/lyricistant...
#
# 📦 Processing LyricLy/ASCII...
#
# 📦 Processing machbarschaft/machbarschaft-android-kotlin...
#
# 📦 Processing supersu-man/macronium-android...
#
# 📦 Processing bewee/macrozilla...
#
# 📦 Processing yeSpud/MACSTransitApp...
#
# 📦 Processing Adithya-13/MadeSubmsission...
#
# 📦 Processing MafQud/MafQud-Android...
#
# 📦 Processing magicphotos/magicphotos-android...
#
# 📦 Processing topjohnwu/Magisk...
#
# 📦 Processing mosra/magnum-extras...
#
# 📦 Processing MiSTer-devel/Main_MiSTer...
#
# 📦 Processing solkin/mandarin-android...
#
# 📦 Processing gsantner/markor...
#
# 📦 Processing markyun/markyun...
#
# 📦 Processing skydoves/MarvelHeroes...
#
# 📦 Processing cinder92/react-native-marvel-app...
#
# 📦 Processing Karumi/MarvelApiClientAndroid...
#
# 📦 Processing marvelapp/devices.css...
#
# 📦 Processing TeamMascota/Mascota-Android...
#
# 📦 Processing santalu/maskara...
#
# 📦 Processing Lyndir/MasterPassword...
#
# 📦 Processing gomatcha/matcha...
#
# 📦 Processing romannurik/MaterialColorsApp...
#
# 📦 Processing TangoAgency/material-intro-screen...
#
# 📦 Processing jdamcd/material-sudoku...
#
# 📦 Processing nbsp-team/MaterialFilePicker...
#
# 📦 Processing zhanghai/MaterialFiles...
#
# 📦 Processing florent37/MaterialTextField...
#
# 📦 Processing zhenghaoz/MaterialWeCenter...
#
# 📦 Processing zzllrr/mather...
#
# 📦 Processing jianzhongli/MathView...
#
# 📦 Processing MatsuriDayo/Matsuri...
#
# 📦 Processing mattermost/mattermost-mobile...
#
# 📦 Processing Abhitiwari001/Mausam-The-Weather-App...
#
# 📦 Processing X1nto/Mauth...
#
# 📦 Processing musicbeeremote/mbrc...
#
# 📦 Processing MD2Korg/mCerebrum-AutoSense...
#
# 📦 Processing MD2Korg/mCerebrum-EMAScheduler...
#
# 📦 Processing MD2Korg/mCerebrum-MicrosoftBand...
#
# 📦 Processing MD2Korg/mCerebrum-MoodSurfing...
#
# 📦 Processing MD2Korg/mCerebrum-Omron...
#
# 📦 Processing MD2Korg/mCerebrum-PhoneSensor...
#
# 📦 Processing wajahatkarim3/MediumClap-Android...
#
# 📦 Processing medusajs/medusa...
#
# 📦 Processing synyx/MeeRoo...
#
# 📦 Processing Hussienfahmy/MeFab...
#
# 📦 Processing billthefarmer/melodeon...
#
# 📦 Processing melonjs/melonJS...
#
# 📦 Processing jasonycw/MemeCreator...
#
# 📦 Processing SuhasDissa/MemerizeApp...
#
# 📦 Processing gsantner/memetastic...
#
# 📦 Processing JuandaGarcia/MemoryGame...
#
# 📦 Processing jakobwenzel/MensaGuthaben...
#
# 📦 Processing csicar/MensaPlan...
#
# 📦 Processing anitab-org/mentorship-android...
#
# 📦 Processing juan-goncalves/mentra-app...
#
# 📦 Processing sindresorhus/meow...
#
# 📦 Processing mercy-project/Mercy-Emotion-SNS...
#
# 📦 Processing mesibo/messenger-app-android...
#
# 📦 Processing hackslash-nitp/messsy...
#
# 📦 Processing aditmodhvadia/MET-CS622-ChatBot-Project...
#
# 📦 Processing Crazy-Marvin/MetadataRemover...
#
# 📦 Processing oortcloud/meteorite...
#
# 📦 Processing meteroid-oss/meteroid...
#
# 📦 Processing louis993546/Metro-Compose...
#
# 📦 Processing metrodroid/metrodroid...
#
# 📦 Processing cwilso/metronome...
#
# 📦 Processing MyEtherWallet/MEWconnect-Android...
#
# 📦 Processing maks/MGit...
#
# 📦 Processing FriesI23/mhabit...
#
# 📦 Processing gatheringhallstudios/MHWorldDatabase...
#
# 📦 Processing dotWee/MicroPinner...
#
# 📦 Processing lanrat/minimalin-watchface...
#
# 📦 Processing wiomoc/MioCheck...
#
# 📦 Processing MirakelX/mirakel-android...
#
# 📦 Processing elijahverdoorn/MirrorDisplay...
#
# 📦 Processing mirru-app/mirru-android...
#
# 📦 Processing kirimin/mitsumine...
#
# 📦 Processing FirePing32/MityURL...
#
# 📦 Processing fankes/MIUINativeNotifyIcon...
#
# 📦 Processing sagarchoudhary96/Miwok-App...
#
# 📦 Processing mixpanel/mixpanel-android...
#
# 📦 Processing MkDocsEditor/MkDocsEditor-Android...
#
# 📦 Processing jamesnguyenhub/mkloader...
#
# 📦 Processing javiersantos/MLManager...
#
# 📦 Processing P3TERX/GeoLite.mmdb...
#
# 📦 Processing MobSF/Mobile-Security-Framework-MobSF...
#
# 📦 Processing OpenVK/mobile-android-legacy...
#
# 📦 Processing bagisto/opensource-ecommerce-mobile-app...
#
# 📦 Processing invercity/mobile-cardio...
#
# 📦 Processing surajsau/Mobile-Jisho...
#
# 📦 Processing DefinedNet/mobile_nebula...
#
# 📦 Processing bleibdirtroy/MobilePrism...
#
# 📦 Processing TiagoMSSantos/MobileRT...
#
# 📦 Processing invissvenska/ModalBottomSheetDialog...
#
# 📦 Processing MayconCardoso/Modularized-Flicker-Showcase...
#
# 📦 Processing MayconCardoso/Modularized-Marvel-Showcase...
#
# 📦 Processing DCDmllm/Momentor...
#
# 📦 Processing Next-Flip/Momentum-Firmware...
#
# 📦 Processing guger/MoneyBook...
#
# 📦 Processing AkiMosi/moneycontrolPy...
#
# 📦 Processing carousell/MonoAdapter...
#
# 📦 Processing noln/motorsport-circuits...
#
# 📦 Processing m7mdra/move-tickets-seats...
#
# 📦 Processing Fbada006/Moveery...
#
# 📦 Processing vpaliy/android-movies-app...
#
# 📦 Processing razaghimahdi/Movie-List-By-Jetpack-Compose-01...
#
# 📦 Processing junedomingo/movieapp...
#
# 📦 Processing atilsamancioglu/IA33-MovieDatabaseCompose...
#
# 📦 Processing impronunciable/moviedb...
#
# 📦 Processing Haid-Faiz/MovieLand...
#
# 📦 Processing k4m4/movies-for-hackers...
#
# 📦 Processing fnk0/MoviesTMDB...
#
# 📦 Processing KaustubhPatange/Moviesy...
#
# 📦 Processing AlphaCentaury/MovistarTV...
#
# 📦 Processing bezzad/MP3Player...
#
# 📦 Processing mpdf/mpdf...
#
# 📦 Processing novemberfiveco/kotlin-mpp-standard...
#
# 📦 Processing mpv-android/mpv-android...
#
# 📦 Processing tediousjs/node-mssql...
#
# 📦 Processing EhsanMsz/MszProgressIndicator...
#
# 📦 Processing AEFeinstein/mtg-familiar...
#
# 📦 Processing rubenwardy/mtmods4android...
#
# 📦 Processing codebude/MtuOptimizer...
#
# 📦 Processing moritz-weber/mucke...
#
# 📦 Processing mullvad/mullvadvpn-app...
#
# 📦 Processing getActivity/MultiLanguages...
#
# 📦 Processing mikepenz/multiplatform-markdown-renderer...
#
# 📦 Processing jakepurple13/MultiplatformGithubTopics...
#
# 📦 Processing kumaleap/MultipleStatusLayout...
#
# 📦 Processing datarockets/munchkin-counter-android...
#
# 📦 Processing niccokunzmann/mundraub-android...
#
# 📦 Processing kiyui/MVEZ...
#
# 📦 Processing KunMinX/MVI-Dispatcher-KTX...
#
# 📦 Processing PopStackHack/mVoterAndroid...
#
# 📦 Processing hendisantika/Online-banking-angular-springboot-mysql...
#
# 📦 Processing a-creative/AiMyCareer...
#
# 📦 Processing GeorgiGradev/MyFitnessApp...
#
# 📦 Processing alopes2/Medium-MyMusic...
#
# 📦 Processing danielesegato/my-soothe-dev-challenge...
#
# 📦 Processing myspecialway/my-special-way-android...
#
# 📦 Processing developermypos/myPOS-SDK-Android...
#
# 📦 Processing SalmanTKhan/MyAnimeViewer...
#
# 📦 Processing hujinmeng/MyApplication...
#
# 📦 Processing fitriadyaa/MyGithubUser...
#
# 📦 Processing fixme-lausanne/MyHackerspace...
#
# 📦 Processing mirfatif/MyLocation...
#
# 📦 Processing dingyi222666/MyLuaApp...
#
# 📦 Processing syllogismos/MyntraTinder...
#
# 📦 Processing Davidemanoel7/mypass-app-fl...
#
# 📦 Processing Jchegenye/mypesapal...
#
# 📦 Processing peternijssen/mypetsage...
#
# 📦 Processing alabeduarte/mypodcasts-android...
#
# 📦 Processing mysteriumnetwork/mysterium-vpn-mobile...
#
# 📦 Processing orogersilva/myweatherforecast...
#
# 📦 Processing fiqryq/Nabung...
#
# 📦 Processing TaQuangKhoi/Napkin-Collect-Android...
#
# 📦 Processing bogerchan/National-Geography...
#
# 📦 Processing facebook/react-native...
#
# 📦 Processing expo/create-react-native-app...
#
# 📦 Processing proyecto26/nativescript-inappbrowser...
#
# 📦 Processing cinit/NCIHost...
#
# 📦 Processing Netflix/Hystrix...
#
# 📦 Processing kost/NetworkMapper...
#
# 📦 Processing fossasia/neurolab-android...
#
# 📦 Processing albertolalanda/new-ultrasonic-fork-for-MyMusicQoE...
#
# 📦 Processing TeamNewPipe/NewPipe...
#
# 📦 Processing codelucas/newspaper...
#
# 📦 Processing nextcloud/news-android...
#
# 📦 Processing AlexeyVoronov96/NewsApp-With-SwiftUI-And-Combine...
#
# 📦 Processing KadirKuruca/NewsApp-MVVM-Hilt-Room-Retrofit...
#
# 📦 Processing NexdApp/nexd-android...
#
# 📦 Processing nextcloud/deck...
#
# 📦 Processing matiasdelellis/nextcloud-quicknotes-android...
#
# 📦 Processing nextcloud/tables...
#
# 📦 Processing hegocre/NextcloudPasswords...
#
# 📦 Processing 0xf104a/NextcloudServices...
#
# 📦 Processing AnaelMobilia/NextINpact-Unofficial...
#
# 📦 Processing Nexters/Nextrot_Android...
#
# 📦 Processing infertux/nfc-explorer...
#
# 📦 Processing nfcgate/nfcgate...
#
# 📦 Processing treastrain/TRETJapanNFCReader...
#
# 📦 Processing nfcim/nfsee...
#
# 📦 Processing Grohden/nice-animals...
#
# 📦 Processing jianjunxiao/NiceVieoPlayer...
#
# 📦 Processing oakes/Nightlight...
#
# 📦 Processing Zhou-Li-Bin/Tvbox-QingNing...
#
# 📦 Processing deskbtm/nitmgpt...
#
# 📦 Processing nitroshare/nitroshare-android...
#
# 📦 Processing nkitsaini/nkit-launcher...
#
# 📦 Processing CNugteren/NLWeer...
#
# 📦 Processing ppXD/NMediator...
#
# 📦 Processing notepad-plus-plus/notepad-plus-plus...
#
# 📦 Processing CyC2018/CS-Notes...
#
# 📦 Processing android-notes/Cockroach...
#
# 📦 Processing streetwriters/notesnook...
#
# 📦 Processing Vaibhav2002/NotesX...
#
# 📦 Processing gautamkrishnar/nothing-private...
#
# 📦 Processing SapuSeven/NotiCap...
#
# 📦 Processing sri-rang/notifer.js...
#
# 📦 Processing khuttun/NotificationNotes...
#
# 📦 Processing julienXX/terminal-notifier...
#
# 📦 Processing rajkumaar23/notify-abroad...
#
# 📦 Processing Yanndroid/NotiNotes...
#
# 📦 Processing timonback/notipush...
#
# 📦 Processing ApplETS/Notre-Dame...
#
# 📦 Processing ApplETS/Notre-Dame-v3...
#
# 📦 Processing PatilShreyas/NotyKT...
#
# 📦 Processing now-u/now-u-app...
#
# 📦 Processing developersu/ns-usbloader-mobile...
#
# 📦 Processing williamniemiec/ntravel-app...
#
# 📦 Processing daimajia/NumberProgressBar...
#
# 📦 Processing sephiroth74/NumberSlidingPicker...
#
# 📦 Processing holylobster/nuntius-android...
#
# 📦 Processing schnatterer/nusic...
#
# 📦 Processing anamansari062/Nutrifit...
#
# 📦 Processing dooptha/nuwm-frontend...
#
# 📦 Processing louib/nwipe-android...
#
# 📦 Processing ahmedmshaker/NY-Times-Most-Popular-articles-Flutter...
#
# 📦 Processing NyaaPantsu/NyaaPantsu-android-app...
#
# 📦 Processing powerje/NyanDroid...
#
# 📦 Processing WildAid/o-fish-android...
#
# 📦 Processing OdyseeTeam/odysee-android...
#
# 📦 Processing tabasavr/oeis-android...
#
# 📦 Processing insiderdev/office-assistant-legacy...
#
# 📦 Processing benarmstead/OfflineCookBook...
#
# 📦 Processing 2439905184/oiapp...
#
# 📦 Processing federicoiosue/Omni-Notes...
#
# ...
#
# 📦 Processing mikecao/shorty...
#
# 📦 Processing kebernet/shortyz...
#
# 📦 Processing ivaniskandar/shouko...
#
# 📦 Processing niranjan94/show-java...
#
# 📦 Processing kriticalflare/SIESGSTarena-android-app...
#
# 📦 Processing vdeschwb/esp32-signal-generator...
#
# 📦 Processing obfusk/sigblock-code-poc...
#
# 📦 Processing Sajjad3223/Chatroom-SignalR...
#
# 📦 Processing esofar/cnblogs-theme-silence...
#
# 📦 Processing bertrandmartel/sim-password-wallet...
#
# 📦 Processing grammatek/simacorrect...
#
# 📦 Processing grammatek/simaromur...
#
# 📦 Processing simlar/simlar-android...
#
# 📦 Processing simple-icons/simple-icons...
#
# 📦 Processing lg2de/SimpleAccounting...
#
# 📦 Processing fossasia/Ember_Simple_Calculator...
#
# 📦 Processing fySpring/SimpleStepCounter...
#
# 📦 Processing smarek/Simple-Dilbert...
#
# 📦 Processing l3ger0j/Simple-Dimple-Draw...
#
# 📦 Processing simple-login/Simple-Login-Android...
#
# 📦 Processing hieuwu/simple-note-application...
#
# 📦 Processing SimpleMobileTools/Simple-Notes...
#
# 📦 Processing alpacasking/SimpleVertexPainter...
#
# 📦 Processing CASL0/simple_app_blocker...
#
# 📦 Processing jbttn/SimpleDocumentScanner-Android...
#
# 📦 Processing lg2de/SimpleAccounting...
#
# 📦 Processing ArisGuimera/SimpleAndroidMVVM...
#
# 📦 Processing mithun17/SimpleBible...
#
# 📦 Processing Takahana/SkyWayClient...
#
# 📦 Processing letelete/sleep-cycle-alarm...
#
# 📦 Processing yydcdut/SlideAndDragListView...
#
# 📦 Processing leongersen/noUiSlider...
#
# 📦 Processing nanwangjkl/sliding_puzzle...
#
# 📦 Processing sduduzog/slim-launcher...
#
# 📦 Processing annybudong/SlipView...
#
# 📦 Processing ouchadam/small-talk...
#
# 📦 Processing Nain57/Smart-AutoClicker...
#
# 📦 Processing CookieJarApps/SmartCookieWeb-Preview...
#
# 📦 Processing axel358/smartdock...
#
# 📦 Processing Kunalapk/SmartExoPlayer...
#
# 📦 Processing BzCoder/SmartMediaPicker...
#
# 📦 Processing salarcode/SmartProxy...
#
# 📦 Processing DevChatter/Smilodon...
#
# 📦 Processing henrytao-me/smooth-app-bar-layout...
#
# 📦 Processing jberkel/sms-backup-plus...
#
# 📦 Processing bertrandmartel/sms-group-sender...
#
# 📦 Processing anevero/sms_my_gps...
#
# 📦 Processing pppscn/SmsForwarder...
#
# 📦 Processing pwnslinger/sn4ke...
#
# 📦 Processing badaix/snapdroid...
#
# 📦 Processing fm-sys/snapdrop-android...
#
# 📦 Processing fei0316/snapstreak-alarm...
#
# 📦 Processing akexorcist/SnapTimePicker...
#
# 📦 Processing snikket-im/snikket-android...
#
# 📦 Processing emschu/snmp-cockpit...
#
# 📦 Processing nithinmanne/SnoreDetector...
#
# 📦 Processing sunilpaulmathew/sNotz...
#
# 📦 Processing FredKSchott/snowpack...
#
# 📦 Processing SefkanTas/Sonofy...
#
# 📦 Processing W-sharp-TCU/sosaku...
#
# 📦 Processing teamulster2/soTired...
#
# 📦 Processing 2ec0b4/kaamelott-soundboard...
#
# 📦 Processing minikin/soundcloud_audio_player...
#
# 📦 Processing soundcrowd/soundcrowd...
#
# 📦 Processing rnehra01/SoundProfile...
#
# 📦 Processing zorgluf/souvenirs-android...
#
# 📦 Processing shagalalab/sozlik-android...
#
# 📦 Processing TheFakeMontyOnTheRun/space-trashman-blues...
#
# 📦 Processing ItsCalebJones/SpaceLaunchNow-Android...
#
# 📦 Processing spaceship-prompt/spaceship-prompt...
#
# 📦 Processing palfrey/spaceteam-timer...
#
# 📦 Processing Jonathan357611/SpaceX-Launch-Tracker...
#
# 📦 Processing OMIsie11/SpaceXFollower...
#
# 📦 Processing joshuadeguzman/Spanly...
#
# 📦 Processing TxcA/SpannableX...
#
# 📦 Processing PanosK92/SpartanEngine...
#
# 📦 Processing koha13/spasic-app...
#
# 📦 Processing dl00/speedrun-browser-android...
#
# 📦 Processing yogeshpaliyal/Speld...
#
# 📦 Processing peters-josh/spending-tracker...
#
# 📦 Processing koenidv/sph-planner...
#
# 📦 Processing NaiboWang/EasySpider...
#
# 📦 Processing ThatCakeID/Splum...
#
# 📦 Processing muthuraj57/SpoilerBlocker...
#
# 📦 Processing KRTirtho/spotube...
#
# 📦 Processing cvillaseca/SpotifyKt...
#
# 📦 Processing Knight-ZXW/SpWaitKiller...
#
# 📦 Processing massivemadness/Squircle-CE...
#
# 📦 Processing Sw24Softwares/StarkeVerben...
#
# 📦 Processing AlpetGexha/Starlords...
#
# 📦 Processing liaokongVFX/LangChain-Chinese-Getting-Started-Guide...
#
# 📦 Processing rintoj/statex...
#
# 📦 Processing SimoneTinella/Stato_COVID19_Italia_Android...
#
# 📦 Processing laobie/StatusBarUtil...
#
# 📦 Processing laobie/StatusBarUtil...
#
# 📦 Processing staxrip/staxrip...
#
# 📦 Processing arnav-deep/StaySafe...
#
# 📦 Processing dfrood/SteamRouteTool...
#
# 📦 Processing steedos/steedos-notification-center...
#
# 📦 Processing DanielMartinus/Stepper-Touch...
#
# 📦 Processing supertuxkart/stk-code...
#
# 📦 Processing jurajkusnier/stock-browser...
#
# 📦 Processing cvbutani/StockControl...
#
# 📦 Processing stopstalk/stopstalk-android...
#
# 📦 Processing 2729StormRobotics/StormAppMaster2020...
#
# 📦 Processing 2729StormRobotics/StormAppUser2020...
#
# 📦 Processing GetStream/stream-draw-android...
#
# 📦 Processing kibotu/StreamingAndroidLogger...
#
# 📦 Processing kofemann/streetguide...
#
# 📦 Processing stroke-input/stroke-input-android...
#
# 📦 Processing obsproject/obs-studio...
#
# 📦 Processing Gnuhry/student-alarm...
#
# 📦 Processing polito/students-app...
#
# 📦 Processing hoangsonww/StudySync-Study-Buddy-App...
#
# 📦 Processing peterpeterparker/stylo...
#
# 📦 Processing unknwon/sublite...
#
# 📦 Processing RafayGhafoor/Subscene-Subtitle-Grabber...
#
# 📦 Processing teamOSC/SubtleNews_Android_App...
#
# 📦 Processing sustcast/sustcast-android-app-v1...
#
# 📦 Processing Muhammed-Rahif/swadeeq...
#
# 📦 Processing aykuttasil/sweetloc...
#
# 📦 Processing nt4f04uNd/sweyer...
#
# 📦 Processing necatievrenyasar/SwiftUI-WeatherApp...
#
# 📦 Processing kevinhinterlong/SwishTicker...
#
# 📦 Processing SwissCovid/swisscovid-app-android...
#
# 📦 Processing kyleduo/SwitchButton...
#
# 📦 Processing JackCho/SwitchLanguageDemo...
#
# 📦 Processing simrat39/symbols-outline.nvim...
#
# 📦 Processing 88250/symphony...
#
# 📦 Processing mo3rfan/syncplayer...
#
# 📦 Processing timmo001/system-bridge-android-companion...
#
# 📦 Processing j4velin/SystemAppMover...
#
# 📦 Processing szkolny-eu/szkolny-android...
#
# 📦 Processing tasks/tasks...
#
# 📦 Processing rsteube/t4-launcher...
#
# 📦 Processing ciasaboark/Tacere...
#
# 📦 Processing jogboms/tailor_made...
#
# 📦 Processing tailscale/tailscale-android...
#
# 📦 Processing Droidui/TajMahalApp-Android...
#
# 📦 Processing trikita/talalarmo...
#
# 📦 Processing PalisadoesFoundation/talawa...
#
# 📦 Processing nextcloud/talk-android...
#
# 📦 Processing ltsopensource/light-task-scheduler...
#
# 📦 Processing ChrisAnd1998/TaskbarX...
#
# 📦 Processing JobinBiju/Taskly...
#
# 📦 Processing tasks/tasks...
#
# 📦 Processing yadav-rahul/TastyToast...
#
# 📦 Processing Helsinki-NLP/Tatoeba-Challenge...
#
# 📦 Processing termux/termux-boot...
#
# 📦 Processing termux/termux-float...
#
# 📦 Processing termux/termux-styling...
#
# 📦 Processing terabyte25/tes3mp-android...
#
# 📦 Processing DimensionDev/TesserPG-Android...
#
# 📦 Processing chvin/react-tetris...
#
# 📦 Processing renard314/textfairy...
#
# 📦 Processing santalu/textmatcher...
#
# 📦 Processing swipefintech/textmatic...
#
# 📦 Processing maxistar/TextPad...
#
# 📦 Processing zhanghai/TextSelectionWebSearch...
#
# 📦 Processing iglaweb/TFProfiler...
#
# 📦 Processing the-blue-alliance/the-blue-alliance-android...
#
# 📦 Processing the-channels/channels...
#
# 📦 Processing dangquanuet/The-Movie-DB-Kotlin...
#
# 📦 Processing chriskiehl/home-theater-calculator...
#
# 📦 Processing cavestri/themoviedb-javascript-library...
#
# 📦 Processing yuliansyahibr/TheMovieDB_Android_App...
#
# 📦 Processing TheNounProject/CollectionView...
#
# 📦 Processing FaceInCake/ThePrincipleApp...
#
# 📦 Processing depromeet12th/three-days-android...
#
# 📦 Processing thu-info-community/thu-info-app...
#
# 📦 Processing thunderbird/thunderbird-android...
#
# 📦 Processing nesbox/TIC-80...
#
# 📦 Processing asweigart/my_first_tic_tac_toe...
#
# 📦 Processing annypatel/tickmarks...
#
# 📦 Processing lordi/tickmate...
#
# 📦 Processing ericmaxwell2003/ticTacToe...
#
# 📦 Processing andersevenrud/TileGame...
#
# 📦 Processing simonpham/Tiles-For-Developers...
#
# 📦 Processing joaomneto/TitanCompanion...
#
# 📦 Processing getActivity/TitleBar...
#
# 📦 Processing hidroh/tldroid...
#
# 📦 Processing n0lik/TMDB-Android-Client...
#
# 📦 Processing MakeItEasyDev/Jetpack-Compose-ToDo-Notes...
#
# 📦 Processing getActivity/Toaster...
#
# 📦 Processing MakinGiants/todayhistory...
#
# 📦 Processing tastejs/todomvc...
#
# 📦 Processing davidfowl/TodoApp...
#
# 📦 Processing wisnukurniawan/Compose-ToDo...
#
# 📦 Processing davidfowl/TodoApp...
#
# 📦 Processing Mustafa-Hassan2001/TodoList-with-ReactNative...
#
# 📦 Processing agustiyann/ToDoList-Room-MVVM...
#
# 📦 Processing tiffon/vscode-todone...
#
# 📦 Processing Crazy-Marvin/ToDont...
#
# 📦 Processing brayan/todozy...
#
# 📦 Processing savvyapps/ToggleButtonLayout...
#
# 📦 Processing k3b/ToGoZip...
#
# 📦 Processing TOMB5/TOMB5...
#
# 📦 Processing Fortyseven/ToneDef...
#
# 📦 Processing tookit/vue-material-admin...
#
# 📦 Processing gsora/TootApp...
#
# 📦 Processing guowenfh/geek-time-topdf...
#
# 📦 Processing praslnx8/Topsed-Speedometer...
#
# 📦 Processing sofwerx/TORGI...
#
# 📦 Processing YouROK/TorrServer...
#
# 📦 Processing guardianproject/torservices...
#
# 📦 Processing neonbjb/tortoise-tts...
#
# 📦 Processing imbushuo/mac-precision-touchpad...
#
# 📦 Processing kartchnb/AutoTowersGenerator...
#
# 📦 Processing transtone/hackintosh...
#
# 📦 Processing GOVINDDIXIT/Travel-Wise...
#
# 📦 Processing sahan/Travis-Jr...
#
# 📦 Processing Greenstand/treetracker-android...
#
# 📦 Processing andreynovikov/trekarta...
#
# 📦 Processing equeim/tremotesf-android...
#
# 📦 Processing koelleChristian/trickytripper...
#
# 📦 Processing osfans/trime...
#
# 📦 Processing frengels/trinkster...
#
# 📦 Processing midhunhk/trip-o-meter...
#
# 📦 Processing Puriii/tripmobile...
#
# 📦 Processing nuhkoca/Trippo-The_Travel_Guide...
#
# 📦 Processing tomoya0x00/Troutoss...
#
# 📦 Processing forceporquillo/truck-me-android...
#
# 📦 Processing ygohko/tsukimisou...
#
# 📦 Processing jing332/tts-server-android...
#
# 📦 Processing Tyde/TuCanMobile...
#
# 📦 Processing blackbbc/Tucao...
#
# 📦 Processing keras-team/keras-tuner...
#
# 📦 Processing JamesClonk/turbojira...
#
# 📦 Processing tutao/tutanota...
#
# 📦 Processing nielsvanvelzen/tv-launcher...
#
# 📦 Processing rsiebert/TVHClient...
#
# 📦 Processing dodohua/TVRemotePlay...
#
# 📦 Processing TwidereProject/Twidere-Android...
#
# 📦 Processing TwidereProject/TwidereX-Android...
#
# 📦 Processing twilio/twilio-video-app-android...
#
# 📦 Processing twireapp/Twire...
#
# 📦 Processing AnimeTwist/twist-mobile...
#
# 📦 Processing mtlthorrr/TwitchApp...
#
# 📦 Processing grspy/ulev1plus...
#
# 📦 Processing CCninja86/UltimateWordFinder...
#
# 📦 Processing mareksabo/umimecesky...
#
# 📦 Processing payu-intrepos/PayUMoney-Android-SDK...
#
# 📦 Processing nining377/UnblockMusicPro_Xposed...
#
# 📦 Processing LivingWithHippos/unchained-android...
#
# 📦 Processing yairm210/Unciv...
#
# 📦 Processing husaynhakeem/Unconnectify-Re...
#
# 📦 Processing Julow/Unexpected-Keyboard...
#
# 📦 Processing unicode-org/icu...
#
# 📦 Processing Ryosuke839/UnicodePad...
#
# 📦 Processing microg/UnifiedNlp...
#
# 📦 Processing kudoabhijeet/UniSHARE-Legacy...
#
# 📦 Processing Unity-Technologies/ml-agents...
#
# 📦 Processing xausky/UnityModManager...
#
# 📦 Processing c-h-/universal-native-boilerplate...
#
# 📦 Processing horizontalsystems/unstoppable-wallet-android...
#
# 📦 Processing DeluxeAlonso/UpcomingMovies...
#
# 📦 Processing DUpdateSystem/UpgradeAll...
#
# 📦 Processing ptgamr/upnext...
#
# 📦 Processing r-lib/urlchecker...
#
# 📦 Processing 452/USBHIDTerminal...
#
# 📦 Processing felHR85/UsbSerial...
#
# 📦 Processing eriknellessen/user-controlled-decryption-operations...
#
# 📦 Processing electron-userland/electron-builder...
#
# 📦 Processing uTox/uTox...
#
# 📦 Processing fan123199/v2ex-simple...
#
# 📦 Processing Crazy-Marvin/VacationDays...
#
# 📦 Processing TheRakeshPurohit/VaccinfoApp...
#
# 📦 Processing systemallica/ValenBisi...
#
# 📦 Processing eriknellessen/Virtual-Keycard...
#
# 📦 Processing mzdm/virtual_traveller_flutter...
#
# 📦 Processing android-hacker/VirtualXposed...
#
# 📦 Processing jwilber/roughViz...
#
# 📦 Processing vkgeo/vkgeo-android...
#
# 📦 Processing ojacquemart/vlilleChecker...
#
# 📦 Processing srbrettle/VLSM-Subnet-Mask-Calculator...
#
# 📦 Processing tzfun/VmConsole-Api...
#
# 📦 Processing vuvdv3101/VNavigator...
#
# 📦 Processing 0xpr03/VocableTrainer-Android...
#
# 📦 Processing rahulworld/voice-calci...
#
# 📦 Processing volta-cli/volta...
#
# 📦 Processing hammmmy/VolumeKeys...
#
# 📦 Processing QEDK/volunteery...
#
# 📦 Processing frankmorgner/vsmartcard...
#
# 📦 Processing code-gambit/VT-AndroidClient...
#
# 📦 Processing praharshjain/Vudit...
#
# 📦 Processing maxroehrl/Vueddit...
#
# 📦 Processing VueTubeApp/VueTube...
#
# 📦 Processing ARM-software/vulkan_best_practice_for_mobile_developers...
#
# 📦 Processing rnd-ash/W203-canbus...
#
# 📦 Processing nagadomi/waifu2x...
#
# 📦 Processing d4rken-org/wakelock-revamp...
#
# 📦 Processing ahmed-tasaly/WallMe-Wallpaper...
#
# 📦 Processing niumoo/bing-wallpaper...
#
# 📦 Processing cvzi/WallpaperExport...
#
# 📦 Processing Sky24n/flutter_wanandroid...
#
# 📦 Processing RicardoJiang/wanandroid-compose...
#
# 📦 Processing TechCafeFreedom/Wantum-android...
#
# 📦 Processing taitberlette/wasp-os-companion...
#
# 📦 Processing probablycorey/wax...
#
# 📦 Processing narrate-co/waylan_android...
#
# 📦 Processing shadowfacts/WaypointCompass...
#
# 📦 Processing hamza94max/Wazaker...
#
# 📦 Processing microsoft/TailwindTraders-Website...
#
# 📦 Processing florent37/WearKit...
#
# 📦 Processing whether-jacket/weather-app-2020-android...
#
# 📦 Processing guerrerorodrigo/compose-multiplatform-weather-app...
#
# 📦 Processing aydbtiko24/weather-forecast-ID...
#
# 📦 Processing furkanaskin/Weatherapp...
#
# 📦 Processing Shashank02051997/WeatherApp-Android...
#
# 📦 Processing Andrious/weathercast...
#
# 📦 Processing dh4/WeatherRadar...
#
# 📦 Processing dead-beef/webaudio-spectrum-analyser...
#
# 📦 Processing Taritsyn/WebMarkupMin...
#
# 📦 Processing VictorTaelin/WebMonkeys...
#
# 📦 Processing damiengo/WebsiteRSS...
#
# 📦 Processing webtoon/psd...
#
# 📦 Processing kibotu/WebViewAdapter...
#
# 📦 Processing ubergeek42/weechat-android...
#
# 📦 Processing Peng-YM/WeiJu-AndroidClient...
#
# 📦 Processing ChainSafe/WeiPay...
#
# 📦 Processing skmodi649/Wellness_meter...
#
# 📦 Processing kulloveth/WellnessCity...
#
# 📦 Processing GreyWolfDev/Werewolf...
#
# 📦 Processing ohyooo/Wessager...
#
# 📦 Processing LaGrangeMtl/WhatsNearby...
#
# 📦 Processing AkramChauhan/WhatsApp-Status-Downloader-using-Flutter...
#
# 📦 Processing GauthamAsir/WhatsApp_Status_Saver...
#
# 📦 Processing javiersantos/WhatsAppBetaUpdater...
#
# 📦 Processing jwd-ali/WifiView...
#
# 📦 Processing marcowindt/WiiMoteDSU...
#
# 📦 Processing JonasKress/WikiExplorer...
#
# 📦 Processing oliveroneill/wilt-android...
#
# 📦 Processing wszqkzqk/deepin-wine-ubuntu...
#
# 📦 Processing Divested-Mobile/WLANBackend...
#
# 📦 Processing uqbar-project/wollok-mobile...
#
# 📦 Processing Wolox/wolmo-cookbook-android...
#
# 📦 Processing wonkey-coders/wonkey...
#
# 📦 Processing outadoc/woolly-app...
#
# 📦 Processing LDNOOBW/List-of-Dirty-Naughty-Obscene-and-Otherwise-Bad-Words...
#
# 📦 Processing opatry/wordle-kt...
#
# 📦 Processing supertechninja/WordleCompose...
#
# 📦 Processing zulkarnine/WordleSolver...
#
# 📦 Processing hanxiaomax/WordPowerMadeEasy...
#
# 📦 Processing atiqsamtia/WordPress-App-with-Flutter...
#
# 📦 Processing psanford/wormhole-william-mobile...
#
# 📦 Processing MRwangqi/WQthrottle...
#
# 📦 Processing plafue/writeily-pro...
#
# 📦 Processing fh-erfurt/ws2022_pme_flipsen...
#
# 📦 Processing infinitepower18/WSA-InstalledApps...
#
# 📦 Processing warmshowers/wsandroid...
#
# 📦 Processing wtcounter/wtcounter...
#
# 📦 Processing nelenkov/wwwjdic...
#
# 📦 Processing redsolution/xabber-android...
#
# 📦 Processing xbmc/xbmc...
#
# 📦 Processing XCSoar/XCSoar...
#
# 📦 Processing gbarre/xiaExpressAndroid...
#
# 📦 Processing quantum-shift/XiaomiOde2Code2022...
#
# 📦 Processing LiushuiXiaoxia/XiaoxiaZhihu_AAC...
#
# 📦 Processing youkai-app/Youkai...
#
# 📦 Processing thuryn/your-local-weather...
#
# 📦 Processing PierfrancescoSoffritti/android-youtube-player...
#
# 📦 Processing turtton/YtAlarm...
#
# 📦 Processing Yubico/yubioath-flutter...
#
# 📦 Processing DONGChuan/Yummy-Jekyll...
#
# 📦 Processing itning/yunshu_music...
#
# 📦 Processing avram/zandy...
#
# 📦 Processing Miserlou/Zappa...
#
# 📦 Processing betterclever/ZapTap...
#
# 📦 Processing SallaApp/ZATCA...
#
# 📦 Processing zazencodes/zazencodes-season-1...
#
# 📦 Processing zephyrproject-rtos/zephyr...
#
# 📦 Processing proydakov/zeptobird...
#
# 📦 Processing zeromicro/go-zero...
#
# 📦 Processing gdg-berlin-android/ZeThree...
#
# 📦 Processing mwydmuch/ZoomVideoComposer...
#
# 📦 Processing natario1/ZoomLayout...
#
# 📦 Processing zfdang/zSMTH-Android...
#
# 📦 Processing zulip/zulip-mobile...
#
# 📦 Processing institutotim/zup-android-tecnico...
#
# ✅ All tasks completed without cloning.
