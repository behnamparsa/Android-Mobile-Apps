# %%
import os
import pandas as pd

# === CONFIGURATION ===
GRADLE_DIR = r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_ 21\BuildInfo"
OUTPUT_CSV = r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\3.2_Gradle_List_ShallowC.csv"

# === TEST DETECTION LOGIC ===
def detect_tests(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        content = f.read().lower()
        has_unit_test = any(keyword in content for keyword in ['junit', 'testimplementation'])
        has_instrumentation_test = any(keyword in content for keyword in ['androidtestimplementation', 'espresso', 'uiautomator'])
        return has_unit_test, has_instrumentation_test

# === ANALYZE FILES ===
rows = []
for filename in os.listdir(GRADLE_DIR):
    if filename.endswith('++build.gradle') or filename.endswith('++build.gradle.kts'):
        full_path = os.path.join(GRADLE_DIR, filename)
    try:
        # Split into base and filename (e.g., username.project__CI++build.gradle)
        base, file_part = filename.split("++", 1)
        repo_info, ci_platform = base.split("__", 1)

        full_name = repo_info  # e.g., username.project

        has_unit, has_instrument = detect_tests(full_path)

        print(f"✅ {filename} | Full Name: {full_name} | CI Platform: {ci_platform} | Unit: {has_unit} | Instr: {has_instrument}")

        rows.append({
            'full_name': full_name,
            'ci_platform_build': ci_platform,
            'gradle_file': filename,
            'has_local_unit_test': has_unit,
            'has_local_instrumentation_test': has_instrument
        })
    except Exception as e:
        print(f"❌ Error processing {filename}: {e}")

# === SAVE TO CSV ===
df = pd.DataFrame(rows)
df.to_csv(OUTPUT_CSV, index=False)
print(f"✅ Saved results to: {OUTPUT_CSV}")
# Out:
# ✅ 0niel.university-app__Other++build.gradle | Full Name: 0niel.university-app | CI Platform: Other | Unit: True | Instr: True
# ✅ 0xf104a.NextcloudServices__Other++build.gradle | Full Name: 0xf104a.NextcloudServices | CI Platform: Other | Unit: True | Instr: True
# ✅ 100mslive.100ms-android__Other++build.gradle | Full Name: 100mslive.100ms-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 10miaomiao.bili-down-out__Other++build.gradle | Full Name: 10miaomiao.bili-down-out | CI Platform: Other | Unit: True | Instr: True
# ✅ 10miaomiao.bilimiao2__Other++build.gradle | Full Name: 10miaomiao.bilimiao2 | CI Platform: Other | Unit: True | Instr: True
# ✅ 1596941391qq.pokerogue-android__Other++build.gradle | Full Name: 1596941391qq.pokerogue-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 2d-inc.developer_quest__Other++build.gradle | Full Name: 2d-inc.developer_quest | CI Platform: Other | Unit: True | Instr: True
# ✅ 360Conferences.chicago-roboto__Other++build.gradle | Full Name: 360Conferences.chicago-roboto | CI Platform: Other | Unit: True | Instr: False
# ✅ 452.USBHIDTerminal__Other++build.gradle | Full Name: 452.USBHIDTerminal | CI Platform: Other | Unit: True | Instr: True
# ✅ 4eRTuk.audioview__Other++build.gradle | Full Name: 4eRTuk.audioview | CI Platform: Other | Unit: True | Instr: True
# ✅ 4seer.openflutterecommerceapp__Other++build.gradle | Full Name: 4seer.openflutterecommerceapp | CI Platform: Other | Unit: True | Instr: True
# ✅ 5GSD.AIMSICDL__Other++build.gradle | Full Name: 5GSD.AIMSICDL | CI Platform: Other | Unit: False | Instr: False
# ✅ 6c65726f79.Transmissionic__Other++build.gradle | Full Name: 6c65726f79.Transmissionic | CI Platform: Other | Unit: True | Instr: True
# ✅ 6thsolution.ApexNLP__Other++build.gradle | Full Name: 6thsolution.ApexNLP | CI Platform: Other | Unit: True | Instr: True
# ✅ 709924470.FanboxViewer__Other++build.gradle | Full Name: 709924470.FanboxViewer | CI Platform: Other | Unit: True | Instr: True
# ✅ 8tory.json2notification__Other++build.gradle | Full Name: 8tory.json2notification | CI Platform: Other | Unit: True | Instr: False
# ✅ 99Taxis.RxPlaces__Other++build.gradle | Full Name: 99Taxis.RxPlaces | CI Platform: Other | Unit: True | Instr: True
# ✅ a914-gowtham.compose-ratingbar__Other++build.gradle | Full Name: a914-gowtham.compose-ratingbar | CI Platform: Other | Unit: True | Instr: True
# ✅ aabhasr1.OtpView__Other++build.gradle | Full Name: aabhasr1.OtpView | CI Platform: Other | Unit: True | Instr: True
# ✅ aarcangeli.Serious-Sam-Android__Other++build.gradle | Full Name: aarcangeli.Serious-Sam-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ aashrai.Skittles__Other++build.gradle | Full Name: aashrai.Skittles | CI Platform: Other | Unit: True | Instr: True
# ✅ abdelaziz-mahdy.pytorch_lite__Other++build.gradle | Full Name: abdelaziz-mahdy.pytorch_lite | CI Platform: Other | Unit: True | Instr: False
# ✅ abertschi.ad-free__Other++build.gradle | Full Name: abertschi.ad-free | CI Platform: Other | Unit: True | Instr: True
# ✅ Abonaventure.ORB_SLAM3_AR-for-Android__Other++build.gradle | Full Name: Abonaventure.ORB_SLAM3_AR-for-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ abrensch.brouter__Other++build.gradle | Full Name: abrensch.brouter | CI Platform: Other | Unit: True | Instr: False
# ✅ abuanwar072.Welcome-Login-Signup-Page-Flutter__Other++build.gradle | Full Name: abuanwar072.Welcome-Login-Signup-Page-Flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ AChep.15puzzle__Other++build.gradle | Full Name: AChep.15puzzle | CI Platform: Other | Unit: True | Instr: True
# ✅ AChep.AcDisplay__Other++build.gradle | Full Name: AChep.AcDisplay | CI Platform: Other | Unit: True | Instr: True
# ✅ AChep.HeadsUp__Other++build.gradle | Full Name: AChep.HeadsUp | CI Platform: Other | Unit: True | Instr: False
# ✅ AChep.PocketMode__Other++build.gradle | Full Name: AChep.PocketMode | CI Platform: Other | Unit: True | Instr: True
# ✅ acterglobal.a3__Other++build.gradle | Full Name: acterglobal.a3 | CI Platform: Other | Unit: False | Instr: False
# ✅ ActivityWatch.aw-android__Other++build.gradle | Full Name: ActivityWatch.aw-android | CI Platform: Other | Unit: True | Instr: True
# ✅ adafruit.Bluefruit_LE_Connect_Android_V2__Other++build.gradle | Full Name: adafruit.Bluefruit_LE_Connect_Android_V2 | CI Platform: Other | Unit: True | Instr: True
# ✅ Adamant-im.adamant-im__Other++build.gradle | Full Name: Adamant-im.adamant-im | CI Platform: Other | Unit: True | Instr: True
# ✅ AdamMc331.AndroidStudyGuide__Other++build.gradle | Full Name: AdamMc331.AndroidStudyGuide | CI Platform: Other | Unit: True | Instr: False
# ✅ AdAway.AdAway__Other++build.gradle | Full Name: AdAway.AdAway | CI Platform: Other | Unit: True | Instr: True
# ✅ adibfara.WatchTower__Other++build.gradle | Full Name: adibfara.WatchTower | CI Platform: Other | Unit: True | Instr: False
# ✅ Aditprayogo.GithubUsers__Other++build.gradle | Full Name: Aditprayogo.GithubUsers | CI Platform: Other | Unit: True | Instr: False
# ✅ AdityaMulgundkar.flutter_opencv__Other++build.gradle | Full Name: AdityaMulgundkar.flutter_opencv | CI Platform: Other | Unit: True | Instr: True
# ✅ adonespitogo.AdoBot__Other++build.gradle | Full Name: adonespitogo.AdoBot | CI Platform: Other | Unit: True | Instr: True
# ✅ adorsys.secure-storage-android__Other++build.gradle | Full Name: adorsys.secure-storage-android | CI Platform: Other | Unit: True | Instr: True
# ✅ adriangl.pict2cam__Other++build.gradle | Full Name: adriangl.pict2cam | CI Platform: Other | Unit: True | Instr: True
# ✅ adrielcafe.satchel__Other++build.gradle | Full Name: adrielcafe.satchel | CI Platform: Other | Unit: True | Instr: False
# ✅ advplyr.audiobookshelf-app__Other++build.gradle | Full Name: advplyr.audiobookshelf-app | CI Platform: Other | Unit: True | Instr: False
# ✅ AEFeinstein.mtg-familiar__Other++build.gradle | Full Name: AEFeinstein.mtg-familiar | CI Platform: Other | Unit: True | Instr: True
# ✅ aelassas.wexflow__Other++build.gradle | Full Name: aelassas.wexflow | CI Platform: Other | Unit: True | Instr: True
# ✅ ag2s20150909.TTS__Other++build.gradle | Full Name: ag2s20150909.TTS | CI Platform: Other | Unit: True | Instr: True
# ✅ agateau.pixelwheels__Other++build.gradle | Full Name: agateau.pixelwheels | CI Platform: Other | Unit: True | Instr: False
# ✅ AgoraIO-Usecase.agora-ent-scenarios__Other++build.gradle | Full Name: AgoraIO-Usecase.agora-ent-scenarios | CI Platform: Other | Unit: True | Instr: True
# ✅ AgoraIO-Usecase.Chatroom__Other++build.gradle | Full Name: AgoraIO-Usecase.Chatroom | CI Platform: Other | Unit: True | Instr: True
# ✅ Ahmadre.FlutterIconPicker__Other++build.gradle | Full Name: Ahmadre.FlutterIconPicker | CI Platform: Other | Unit: True | Instr: True
# ✅ ailabstw.social-distancing-android__Other++build.gradle | Full Name: ailabstw.social-distancing-android | CI Platform: Other | Unit: True | Instr: False
# ✅ ailiwean.NBZxing__Other++build.gradle | Full Name: ailiwean.NBZxing | CI Platform: Other | Unit: True | Instr: False
# ✅ aint.laverna-android__Other++build.gradle | Full Name: aint.laverna-android | CI Platform: Other | Unit: True | Instr: True
# ✅ airbnb.AirMapView__Other++build.gradle | Full Name: airbnb.AirMapView | CI Platform: Other | Unit: True | Instr: False
# ✅ airbnb.mavericks__Other++build.gradle | Full Name: airbnb.mavericks | CI Platform: Other | Unit: True | Instr: False
# ✅ airbnb.okreplay__Other++build.gradle | Full Name: airbnb.okreplay | CI Platform: Other | Unit: True | Instr: False
# ✅ airbnb.paris__Other++build.gradle | Full Name: airbnb.paris | CI Platform: Other | Unit: False | Instr: False
# ✅ airbnb.RxGroups__Other++build.gradle | Full Name: airbnb.RxGroups | CI Platform: Other | Unit: True | Instr: False
# ✅ airgap-it.airgap-vault__Other++build.gradle | Full Name: airgap-it.airgap-vault | CI Platform: Other | Unit: True | Instr: True
# ✅ airgap-it.airgap-wallet__Other++build.gradle | Full Name: airgap-it.airgap-wallet | CI Platform: Other | Unit: True | Instr: True
# ✅ aissat.easy_localization__Other++build.gradle | Full Name: aissat.easy_localization | CI Platform: Other | Unit: True | Instr: True
# ✅ aivanovski.keepassvault__Other++build.gradle | Full Name: aivanovski.keepassvault | CI Platform: Other | Unit: True | Instr: True
# ✅ aizuzi.FastAdapter__Other++build.gradle | Full Name: aizuzi.FastAdapter | CI Platform: Other | Unit: False | Instr: False
# ✅ ajay-dewari.FloatingActionButton-Menu__Other++build.gradle | Full Name: ajay-dewari.FloatingActionButton-Menu | CI Platform: Other | Unit: True | Instr: True
# ✅ ajitsing.ExpenseManager__Other++build.gradle | Full Name: ajitsing.ExpenseManager | CI Platform: Other | Unit: True | Instr: True
# ✅ ajitsing.Sherlock__Other++build.gradle | Full Name: ajitsing.Sherlock | CI Platform: Other | Unit: True | Instr: True
# ✅ akexorcist.SnapTimePicker__Other++build.gradle | Full Name: akexorcist.SnapTimePicker | CI Platform: Other | Unit: True | Instr: False
# ✅ akitikkx.upnext__Other++build.gradle | Full Name: akitikkx.upnext | CI Platform: Other | Unit: True | Instr: True
# ✅ akshay2211.Oblique__Other++build.gradle | Full Name: akshay2211.Oblique | CI Platform: Other | Unit: True | Instr: False
# ✅ akshay2211.PixImagePicker__Other++build.gradle | Full Name: akshay2211.PixImagePicker | CI Platform: Other | Unit: True | Instr: True
# ✅ Akylas.oss-weather__Other++build.gradle | Full Name: Akylas.oss-weather | CI Platform: Other | Unit: True | Instr: True
# ✅ AlanCheen.Flap__Other++build.gradle | Full Name: AlanCheen.Flap | CI Platform: Other | Unit: True | Instr: True
# ✅ alariej.quadrix__Other++build.gradle | Full Name: alariej.quadrix | CI Platform: Other | Unit: False | Instr: False
# ✅ alashow.datmusic-android__Other++build.gradle | Full Name: alashow.datmusic-android | CI Platform: Other | Unit: True | Instr: True
# ✅ albertogeniola.Custom-Meross-Pairer__Other++build.gradle | Full Name: albertogeniola.Custom-Meross-Pairer | CI Platform: Other | Unit: True | Instr: True
# ✅ alescdb.LauncherTV__Other++build.gradle | Full Name: alescdb.LauncherTV | CI Platform: Other | Unit: False | Instr: False
# ✅ alexch33.super-video-downloader__Other++build.gradle | Full Name: alexch33.super-video-downloader | CI Platform: Other | Unit: True | Instr: True
# ✅ AlfaazPlus.QuranApp__Other++build.gradle | Full Name: AlfaazPlus.QuranApp | CI Platform: Other | Unit: True | Instr: True
# ✅ ali322.v2x__Other++build.gradle | Full Name: ali322.v2x | CI Platform: Other | Unit: True | Instr: True
# ✅ alisonthemonster.Presently__Other++build.gradle | Full Name: alisonthemonster.Presently | CI Platform: Other | Unit: True | Instr: False
# ✅ aloisdeniel.vsts-flutter-tasks__Other++build.gradle | Full Name: aloisdeniel.vsts-flutter-tasks | CI Platform: Other | Unit: True | Instr: True
# ✅ alphamu.PinEntryEditText__Other++build.gradle | Full Name: alphamu.PinEntryEditText | CI Platform: Other | Unit: True | Instr: False
# ✅ AlphaWallet.alpha-wallet-android__Other++build.gradle | Full Name: AlphaWallet.alpha-wallet-android | CI Platform: Other | Unit: True | Instr: False
# ✅ amahi.android__Other++build.gradle | Full Name: amahi.android | CI Platform: Other | Unit: True | Instr: True
# ✅ amalChandran.trail-android__Other++build.gradle | Full Name: amalChandran.trail-android | CI Platform: Other | Unit: True | Instr: True
# ✅ americanexpress.busybee__Other++build.gradle | Full Name: americanexpress.busybee | CI Platform: Other | Unit: True | Instr: True
# ✅ Ammar64.Sharing__Other++build.gradle | Full Name: Ammar64.Sharing | CI Platform: Other | Unit: True | Instr: False
# ✅ AmrDeveloper.TreeView__Other++build.gradle | Full Name: AmrDeveloper.TreeView | CI Platform: Other | Unit: True | Instr: True
# ✅ amugofjava.anytime_podcast_player__Other++build.gradle | Full Name: amugofjava.anytime_podcast_player | CI Platform: Other | Unit: True | Instr: True
# ✅ AndProx.AndProx__Other++build.gradle | Full Name: AndProx.AndProx | CI Platform: Other | Unit: True | Instr: True
# ✅ andremion.CounterFab__Other++build.gradle | Full Name: andremion.CounterFab | CI Platform: Other | Unit: True | Instr: True
# ✅ andresth.Kandroid__Other++build.gradle | Full Name: andresth.Kandroid | CI Platform: Other | Unit: True | Instr: True
# ✅ andreynovikov.trekarta__Other++build.gradle | Full Name: andreynovikov.trekarta | CI Platform: Other | Unit: True | Instr: True
# ✅ android.codelab-android-datastore__Other++build.gradle | Full Name: android.codelab-android-datastore | CI Platform: Other | Unit: True | Instr: True
# ✅ android.codelab-android-workmanager__Other++build.gradle | Full Name: android.codelab-android-workmanager | CI Platform: Other | Unit: True | Instr: False
# ✅ android.codelab-exoplayer-intro__Other++build.gradle | Full Name: android.codelab-exoplayer-intro | CI Platform: Other | Unit: True | Instr: False
# ✅ android.codelab-mlkit-android__Other++build.gradle | Full Name: android.codelab-mlkit-android | CI Platform: Other | Unit: True | Instr: True
# ✅ AndroidBBQ.android10__Other++build.gradle | Full Name: AndroidBBQ.android10 | CI Platform: Other | Unit: True | Instr: False
# ✅ AndroidDevFr.AndroidForm__Other++build.gradle | Full Name: AndroidDevFr.AndroidForm | CI Platform: Other | Unit: True | Instr: True
# ✅ androidstarters.kotlin-android-starter__Other++build.gradle | Full Name: androidstarters.kotlin-android-starter | CI Platform: Other | Unit: True | Instr: True
# ✅ AndyJennifer.SimpleEyes__Other++build.gradle | Full Name: AndyJennifer.SimpleEyes | CI Platform: Other | Unit: True | Instr: True
# ✅ anhnnt1.Android-UtilCode__Other++build.gradle | Full Name: anhnnt1.Android-UtilCode | CI Platform: Other | Unit: True | Instr: False
# ✅ AniFOSS.CloudStream-3__Other++build.gradle | Full Name: AniFOSS.CloudStream-3 | CI Platform: Other | Unit: True | Instr: True
# ✅ anime-vsub.app__Other++build.gradle | Full Name: anime-vsub.app | CI Platform: Other | Unit: True | Instr: True
# ✅ ansh94.KotlinMessenger__Other++build.gradle | Full Name: ansh94.KotlinMessenger | CI Platform: Other | Unit: True | Instr: True
# ✅ ANSSI-FR.ultrablue__Other++build.gradle | Full Name: ANSSI-FR.ultrablue | CI Platform: Other | Unit: True | Instr: True
# ✅ AntennaPod.AntennaPod__Other++build.gradle | Full Name: AntennaPod.AntennaPod | CI Platform: Other | Unit: True | Instr: False
# ✅ Antox.Antox__Other++build.gradle | Full Name: Antox.Antox | CI Platform: Other | Unit: False | Instr: True
# ✅ Anuken.animdustry__Other++build.gradle | Full Name: Anuken.animdustry | CI Platform: Other | Unit: False | Instr: False
# ✅ Anuken.Mindustry__Other++build.gradle | Full Name: Anuken.Mindustry | CI Platform: Other | Unit: False | Instr: False
# ✅ AnyPortal.AnyPortal__Other++build.gradle | Full Name: AnyPortal.AnyPortal | CI Platform: Other | Unit: False | Instr: False
# ✅ anyproto.anytype-kotlin__Other++build.gradle | Full Name: anyproto.anytype-kotlin | CI Platform: Other | Unit: False | Instr: False
# ✅ AnySoftKeyboard.AnySoftKeyboard__Other++build.gradle | Full Name: AnySoftKeyboard.AnySoftKeyboard | CI Platform: Other | Unit: True | Instr: False
# ✅ AoEiuV020.IAmNotDisabled__Other++build.gradle | Full Name: AoEiuV020.IAmNotDisabled | CI Platform: Other | Unit: True | Instr: True
# ✅ AoEiuV020.PaNovel__Other++build.gradle | Full Name: AoEiuV020.PaNovel | CI Platform: Other | Unit: True | Instr: True
# ✅ ApmeM.android-flowlayout__Other++build.gradle | Full Name: ApmeM.android-flowlayout | CI Platform: Other | Unit: True | Instr: False
# ✅ appditto.blaise_wallet_flutter__Other++build.gradle | Full Name: appditto.blaise_wallet_flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ appditto.natrium_wallet_flutter__Other++build.gradle | Full Name: appditto.natrium_wallet_flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ appleshaman.CarPlayBLE__Other++build.gradle | Full Name: appleshaman.CarPlayBLE | CI Platform: Other | Unit: True | Instr: True
# ✅ apps4av.avare__Other++build.gradle | Full Name: apps4av.avare | CI Platform: Other | Unit: True | Instr: False
# ✅ AppSci.SleepTimePicker__Other++build.gradle | Full Name: AppSci.SleepTimePicker | CI Platform: Other | Unit: True | Instr: False
# ✅ apptik.MultiSlider__Other++build.gradle | Full Name: apptik.MultiSlider | CI Platform: Other | Unit: True | Instr: True
# ✅ arbelkilani.Clock-view__Other++build.gradle | Full Name: arbelkilani.Clock-view | CI Platform: Other | Unit: True | Instr: True
# ✅ ArcaneChat.android__Other++build.gradle | Full Name: ArcaneChat.android | CI Platform: Other | Unit: True | Instr: True
# ✅ ardovic.Open-Source-Android-Weather-App__Other++build.gradle | Full Name: ardovic.Open-Source-Android-Weather-App | CI Platform: Other | Unit: True | Instr: True
# ✅ arduia.ProExpense__Other++build.gradle | Full Name: arduia.ProExpense | CI Platform: Other | Unit: True | Instr: True
# ✅ area9innovation.flow9__Other++build.gradle | Full Name: area9innovation.flow9 | CI Platform: Other | Unit: False | Instr: False
# ✅ ArisGuimera.FilterRecyclerview__Other++build.gradle | Full Name: ArisGuimera.FilterRecyclerview | CI Platform: Other | Unit: True | Instr: True
# ✅ ArisGuimera.SimpleAndroidMVVM__Other++build.gradle | Full Name: ArisGuimera.SimpleAndroidMVVM | CI Platform: Other | Unit: True | Instr: True
# ✅ arkivanov.android-dev-challenge-compose-2__Other++build.gradle | Full Name: arkivanov.android-dev-challenge-compose-2 | CI Platform: Other | Unit: True | Instr: True
# ✅ artem-zinnatullin.android-wail-app__Other++build.gradle | Full Name: artem-zinnatullin.android-wail-app | CI Platform: Other | Unit: False | Instr: False
# ✅ artem-zinnatullin.qualitymatters__Other++build.gradle | Full Name: artem-zinnatullin.qualitymatters | CI Platform: Other | Unit: True | Instr: True
# ✅ artem-zinnatullin.RxUi__Other++build.gradle | Full Name: artem-zinnatullin.RxUi | CI Platform: Other | Unit: True | Instr: False
# ✅ ArthurBrussee.brush__Other++build.gradle | Full Name: ArthurBrussee.brush | CI Platform: Other | Unit: True | Instr: False
# ✅ artsmvch.Frolomuse__Other++build.gradle | Full Name: artsmvch.Frolomuse | CI Platform: Other | Unit: True | Instr: False
# ✅ artur-ios-dev.watermaniac__Other++build.gradle | Full Name: artur-ios-dev.watermaniac | CI Platform: Other | Unit: True | Instr: True
# ✅ arturogutierrez.Openticator__Other++build.gradle | Full Name: arturogutierrez.Openticator | CI Platform: Other | Unit: True | Instr: False
# ✅ arunk140.nth-kbd__Other++build.gradle | Full Name: arunk140.nth-kbd | CI Platform: Other | Unit: True | Instr: False
# ✅ arunkumar9t2.transition-x__Other++build.gradle | Full Name: arunkumar9t2.transition-x | CI Platform: Other | Unit: True | Instr: False
# ✅ astubenbord.paperless-mobile__Other++build.gradle | Full Name: astubenbord.paperless-mobile | CI Platform: Other | Unit: True | Instr: True
# ✅ AsyJAIZ.Notification-Shade-Transparency__Other++build.gradle | Full Name: AsyJAIZ.Notification-Shade-Transparency | CI Platform: Other | Unit: True | Instr: True
# ✅ atiqsamtia.WordPress-App-with-Flutter__Other++build.gradle | Full Name: atiqsamtia.WordPress-App-with-Flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ atn832.fake_cloud_firestore__Other++build.gradle | Full Name: atn832.fake_cloud_firestore | CI Platform: Other | Unit: True | Instr: True
# ✅ AU-COVIDSafe.mobile-android__Other++build.gradle | Full Name: AU-COVIDSafe.mobile-android | CI Platform: Other | Unit: True | Instr: False
# ✅ austrianredcross.stopp-corona-android__Other++build.gradle | Full Name: austrianredcross.stopp-corona-android | CI Platform: Other | Unit: True | Instr: False
# ✅ Auto-Accounting.AutoAccounting__Other++build.gradle | Full Name: Auto-Accounting.AutoAccounting | CI Platform: Other | Unit: True | Instr: True
# ✅ AutoAccountingOrg.AutoAccounting__Other++build.gradle | Full Name: AutoAccountingOrg.AutoAccounting | CI Platform: Other | Unit: True | Instr: True
# ✅ Automattic.simplenote-android__Other++build.gradle | Full Name: Automattic.simplenote-android | CI Platform: Other | Unit: True | Instr: True
# ✅ autosquid.Clean-SmS-Forwarding__Other++build.gradle | Full Name: autosquid.Clean-SmS-Forwarding | CI Platform: Other | Unit: True | Instr: True
# ✅ avram.zandy__Other++build.gradle | Full Name: avram.zandy | CI Platform: Other | Unit: True | Instr: True
# ✅ Axixi2233.chiaki-android__Other++build.gradle | Full Name: Axixi2233.chiaki-android | CI Platform: Other | Unit: False | Instr: False
# ✅ axmolengine.axmol__Other++build.gradle | Full Name: axmolengine.axmol | CI Platform: Other | Unit: False | Instr: False
# ✅ aykuttasil.CallRecorder__Other++build.gradle | Full Name: aykuttasil.CallRecorder | CI Platform: Other | Unit: True | Instr: True
# ✅ Backbase.DeferredResources__Other++build.gradle | Full Name: Backbase.DeferredResources | CI Platform: Other | Unit: True | Instr: False
# ✅ badaix.snapdroid__Other++build.gradle | Full Name: badaix.snapdroid | CI Platform: Other | Unit: True | Instr: False
# ✅ badoo.Reaktive__Other++build.gradle | Full Name: badoo.Reaktive | CI Platform: Other | Unit: False | Instr: False
# ✅ BananoCoin.kalium_wallet_flutter__Other++build.gradle | Full Name: BananoCoin.kalium_wallet_flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ bawaviki.youtube-dl-android__Other++build.gradle | Full Name: bawaviki.youtube-dl-android | CI Platform: Other | Unit: True | Instr: True
# ✅ bazelbuild.rules_kotlin__Other++build.gradle | Full Name: bazelbuild.rules_kotlin | CI Platform: Other | Unit: True | Instr: True
# ✅ BearWare.TeamTalk5__Other++build.gradle | Full Name: BearWare.TeamTalk5 | CI Platform: Other | Unit: True | Instr: True
# ✅ beat-feet.beat-feet__Other++build.gradle | Full Name: beat-feet.beat-feet | CI Platform: Other | Unit: False | Instr: False
# ✅ Beaver-Notes.Beaver-pocket__Other++build.gradle | Full Name: Beaver-Notes.Beaver-pocket | CI Platform: Other | Unit: True | Instr: True
# ✅ beemdevelopment.Aegis__Other++build.gradle | Full Name: beemdevelopment.Aegis | CI Platform: Other | Unit: True | Instr: True
# ✅ BeksOmega.looping-layout__Other++build.gradle | Full Name: BeksOmega.looping-layout | CI Platform: Other | Unit: True | Instr: True
# ✅ benceszasz.xDripCareLinkFollower__Other++build.gradle | Full Name: benceszasz.xDripCareLinkFollower | CI Platform: Other | Unit: True | Instr: False
# ✅ BenderBlog.traintime_pda__Other++build.gradle | Full Name: BenderBlog.traintime_pda | CI Platform: Other | Unit: False | Instr: False
# ✅ benjamindean.flutter_vibration__Other++build.gradle | Full Name: benjamindean.flutter_vibration | CI Platform: Other | Unit: True | Instr: False
# ✅ benjaminwan.ChineseTtsTflite__Other++build.gradle | Full Name: benjaminwan.ChineseTtsTflite | CI Platform: Other | Unit: True | Instr: True
# ✅ benjaminwan.OcrLiteAndroidNcnn__Other++build.gradle | Full Name: benjaminwan.OcrLiteAndroidNcnn | CI Platform: Other | Unit: True | Instr: True
# ✅ benjaminwan.OcrLiteAndroidOnnx__Other++build.gradle | Full Name: benjaminwan.OcrLiteAndroidOnnx | CI Platform: Other | Unit: True | Instr: True
# ✅ bepass-org.oblivion__Other++build.gradle | Full Name: bepass-org.oblivion | CI Platform: Other | Unit: True | Instr: False
# ✅ berdosi.HeartBeat__Other++build.gradle | Full Name: berdosi.HeartBeat | CI Platform: Other | Unit: True | Instr: True
# ✅ bernaferrari.hsluv-dart__Other++build.gradle | Full Name: bernaferrari.hsluv-dart | CI Platform: Other | Unit: True | Instr: True
# ✅ best-flutter.transformer_page_view__Other++build.gradle | Full Name: best-flutter.transformer_page_view | CI Platform: Other | Unit: True | Instr: True
# ✅ betroy.xifan__Other++build.gradle | Full Name: betroy.xifan | CI Platform: Other | Unit: True | Instr: True
# ✅ beyondeye.Reduks__Other++build.gradle | Full Name: beyondeye.Reduks | CI Platform: Other | Unit: True | Instr: False
# ✅ bgregos.foreground__Other++build.gradle | Full Name: bgregos.foreground | CI Platform: Other | Unit: True | Instr: True
# ✅ bhavya-arora.SocketIO_Chat_APP__Other++build.gradle | Full Name: bhavya-arora.SocketIO_Chat_APP | CI Platform: Other | Unit: True | Instr: True
# ✅ bilde2910.Hauk__Other++build.gradle | Full Name: bilde2910.Hauk | CI Platform: Other | Unit: True | Instr: True
# ✅ billthefarmer.mididriver__Other++build.gradle | Full Name: billthefarmer.mididriver | CI Platform: Other | Unit: False | Instr: False
# ✅ BimmerGestalt.IDriveConnectAddons__Other++build.gradle | Full Name: BimmerGestalt.IDriveConnectAddons | CI Platform: Other | Unit: True | Instr: True
# ✅ BitBoxSwiss.bitbox-wallet-app__Other++build.gradle | Full Name: BitBoxSwiss.bitbox-wallet-app | CI Platform: Other | Unit: True | Instr: True
# ✅ bitcoin-wallet.bitcoin-wallet__Other++build.gradle | Full Name: bitcoin-wallet.bitcoin-wallet | CI Platform: Other | Unit: True | Instr: False
# ✅ Bithack.principia__Other++build.gradle | Full Name: Bithack.principia | CI Platform: Other | Unit: True | Instr: False
# ✅ bkhezry.earthquake__Other++build.gradle | Full Name: bkhezry.earthquake | CI Platform: Other | Unit: True | Instr: True
# ✅ bkhezry.weather__Other++build.gradle | Full Name: bkhezry.weather | CI Platform: Other | Unit: True | Instr: True
# ✅ blackbbc.Tucao__Other++build.gradle | Full Name: blackbbc.Tucao | CI Platform: Other | Unit: True | Instr: True
# ✅ Blankj.RxBus__Other++build.gradle | Full Name: Blankj.RxBus | CI Platform: Other | Unit: True | Instr: False
# ✅ blazsolar.android-collapse-calendar-view__Other++build.gradle | Full Name: blazsolar.android-collapse-calendar-view | CI Platform: Other | Unit: True | Instr: False
# ✅ blocktrail.blocktrail-wallet__Other++build.gradle | Full Name: blocktrail.blocktrail-wallet | CI Platform: Other | Unit: False | Instr: False
# ✅ blokadaorg.five-android__Other++build.gradle | Full Name: blokadaorg.five-android | CI Platform: Other | Unit: True | Instr: True
# ✅ bluefireteam.audioplayers__Other++build.gradle | Full Name: bluefireteam.audioplayers | CI Platform: Other | Unit: True | Instr: False
# ✅ BlueWallet.BlueWallet__Other++build.gradle | Full Name: BlueWallet.BlueWallet | CI Platform: Other | Unit: True | Instr: True
# ✅ bmw-tech.lumberdash__Other++build.gradle | Full Name: bmw-tech.lumberdash | CI Platform: Other | Unit: True | Instr: True
# ✅ bmw-tech.ozzie.flutter__Other++build.gradle | Full Name: bmw-tech.ozzie.flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ BOINC.boinc__Other++build.gradle | Full Name: BOINC.boinc | CI Platform: Other | Unit: True | Instr: False
# ✅ bookdash.bookdash-android-app__Other++build.gradle | Full Name: bookdash.bookdash-android-app | CI Platform: Other | Unit: True | Instr: True
# ✅ boyan01.flutter-music-player__Other++build.gradle | Full Name: boyan01.flutter-music-player | CI Platform: Other | Unit: True | Instr: True
# ✅ braintree.android-card-form__Other++build.gradle | Full Name: braintree.android-card-form | CI Platform: Other | Unit: True | Instr: True
# ✅ brarcher.budget-watch__Other++build.gradle | Full Name: brarcher.budget-watch | CI Platform: Other | Unit: True | Instr: False
# ✅ brarcher.loyalty-card-locker__Other++build.gradle | Full Name: brarcher.loyalty-card-locker | CI Platform: Other | Unit: True | Instr: False
# ✅ brarcher.video-transcoder__Other++build.gradle | Full Name: brarcher.video-transcoder | CI Platform: Other | Unit: True | Instr: False
# ✅ bravoborja.ReadMoreTextView__Other++build.gradle | Full Name: bravoborja.ReadMoreTextView | CI Platform: Other | Unit: True | Instr: False
# ✅ BreadKid.SearchItem__Other++build.gradle | Full Name: BreadKid.SearchItem | CI Platform: Other | Unit: True | Instr: True
# ✅ breez.breezmobile__Other++build.gradle | Full Name: breez.breezmobile | CI Platform: Other | Unit: False | Instr: False
# ✅ briar.briar__Other++build.gradle | Full Name: briar.briar | CI Platform: Other | Unit: True | Instr: False
# ✅ bright.slf4android__Other++build.gradle | Full Name: bright.slf4android | CI Platform: Other | Unit: True | Instr: True
# ✅ BrightDV.BoxBox__Other++build.gradle | Full Name: BrightDV.BoxBox | CI Platform: Other | Unit: True | Instr: True
# ✅ brltty.brltty__Other++build.gradle | Full Name: brltty.brltty | CI Platform: Other | Unit: False | Instr: False
# ✅ brumeproject.wallet__Other++build.gradle | Full Name: brumeproject.wallet | CI Platform: Other | Unit: True | Instr: True
# ✅ Bruno125.Compose-Challenges__Other++build.gradle | Full Name: Bruno125.Compose-Challenges | CI Platform: Other | Unit: True | Instr: True
# ✅ BryanGIG.PADumper__Other++build.gradle | Full Name: BryanGIG.PADumper | CI Platform: Other | Unit: True | Instr: True
# ✅ bttv-android.bttv__Other++build.gradle | Full Name: bttv-android.bttv | CI Platform: Other | Unit: True | Instr: True
# ✅ buggins.dlangui__Other++build.gradle | Full Name: buggins.dlangui | CI Platform: Other | Unit: True | Instr: True
# ✅ buildwiththeta.buildwiththeta__Other++build.gradle | Full Name: buildwiththeta.buildwiththeta | CI Platform: Other | Unit: False | Instr: False
# ✅ burgessjp.GanHuoIO__Other++build.gradle | Full Name: burgessjp.GanHuoIO | CI Platform: Other | Unit: True | Instr: False
# ✅ butterproject.butter-android__Other++build.gradle | Full Name: butterproject.butter-android | CI Platform: Other | Unit: True | Instr: True
# ✅ cachapa.AerialDream__Other++build.gradle | Full Name: cachapa.AerialDream | CI Platform: Other | Unit: True | Instr: False
# ✅ cagnulein.QZCompanionNordictrackTreadmill__Other++build.gradle | Full Name: cagnulein.QZCompanionNordictrackTreadmill | CI Platform: Other | Unit: True | Instr: True
# ✅ caiyonglong.MusicLake__Other++build.gradle | Full Name: caiyonglong.MusicLake | CI Platform: Other | Unit: True | Instr: False
# ✅ calcitem.Sanmill__Other++build.gradle | Full Name: calcitem.Sanmill | CI Platform: Other | Unit: False | Instr: False
# ✅ callstack.react-native-material-palette__Other++build.gradle | Full Name: callstack.react-native-material-palette | CI Platform: Other | Unit: False | Instr: False
# ✅ Calsign.APDE__Other++build.gradle | Full Name: Calsign.APDE | CI Platform: Other | Unit: True | Instr: True
# ✅ canopas.compose-country-picker__Other++build.gradle | Full Name: canopas.compose-country-picker | CI Platform: Other | Unit: True | Instr: True
# ✅ canopas.compose-intro-showcase__Other++build.gradle | Full Name: canopas.compose-intro-showcase | CI Platform: Other | Unit: True | Instr: True
# ✅ canopas.rich-editor-compose__Other++build.gradle | Full Name: canopas.rich-editor-compose | CI Platform: Other | Unit: True | Instr: True
# ✅ cantrowitz.RxBroadcast__Other++build.gradle | Full Name: cantrowitz.RxBroadcast | CI Platform: Other | Unit: True | Instr: False
# ✅ Cap-go.capgo__Other++build.gradle | Full Name: Cap-go.capgo | CI Platform: Other | Unit: True | Instr: True
# ✅ capcom6.android-sms-gateway__Other++build.gradle | Full Name: capcom6.android-sms-gateway | CI Platform: Other | Unit: True | Instr: True
# ✅ CappielloAntonio.tempo__Other++build.gradle | Full Name: CappielloAntonio.tempo | CI Platform: Other | Unit: True | Instr: False
# ✅ captainepoch.husky__Other++build.gradle | Full Name: captainepoch.husky | CI Platform: Other | Unit: True | Instr: True
# ✅ cardano-foundation.veridian-wallet__Other++build.gradle | Full Name: cardano-foundation.veridian-wallet | CI Platform: Other | Unit: True | Instr: True
# ✅ CarGuo.GSYRickText__Other++build.gradle | Full Name: CarGuo.GSYRickText | CI Platform: Other | Unit: False | Instr: False
# ✅ CarGuo.gsy_github_app_flutter__Other++build.gradle | Full Name: CarGuo.gsy_github_app_flutter | CI Platform: Other | Unit: True | Instr: False
# ✅ CarGuo.LazyRecyclerAdapter__Other++build.gradle | Full Name: CarGuo.LazyRecyclerAdapter | CI Platform: Other | Unit: False | Instr: False
# ✅ CarlosMChica.easyrecycleradapters__Other++build.gradle | Full Name: CarlosMChica.easyrecycleradapters | CI Platform: Other | Unit: True | Instr: False
# ✅ cashubtc.cashu.me__Other++build.gradle | Full Name: cashubtc.cashu.me | CI Platform: Other | Unit: True | Instr: True
# ✅ casimir.frigoligo__Other++build.gradle | Full Name: casimir.frigoligo | CI Platform: Other | Unit: False | Instr: False
# ✅ CasperVerswijvelt.Better-Internet-Tiles__Other++build.gradle | Full Name: CasperVerswijvelt.Better-Internet-Tiles | CI Platform: Other | Unit: True | Instr: False
# ✅ Catrobat.Catroid__Other++build.gradle | Full Name: Catrobat.Catroid | CI Platform: Other | Unit: True | Instr: True
# ✅ Catrobat.Paintroid__Other++build.gradle | Full Name: Catrobat.Paintroid | CI Platform: Other | Unit: True | Instr: True
# ✅ cats-oss.android-tab-animation__Other++build.gradle | Full Name: cats-oss.android-tab-animation | CI Platform: Other | Unit: True | Instr: True
# ✅ cbeuw.Cloak-android__Other++build.gradle | Full Name: cbeuw.Cloak-android | CI Platform: Other | Unit: True | Instr: True
# ✅ cbl-dart.cbl-dart__Other++build.gradle | Full Name: cbl-dart.cbl-dart | CI Platform: Other | Unit: False | Instr: False
# ✅ CellularPrivacy.Android-IMSI-Catcher-Detector__Other++build.gradle | Full Name: CellularPrivacy.Android-IMSI-Catcher-Detector | CI Platform: Other | Unit: True | Instr: False
# ✅ celzero.rethink-app__Other++build.gradle | Full Name: celzero.rethink-app | CI Platform: Other | Unit: True | Instr: True
# ✅ cernekee.ics-openconnect__Other++build.gradle | Full Name: cernekee.ics-openconnect | CI Platform: Other | Unit: True | Instr: True
# ✅ CeuiLiSA.Pixiv-Shaft__Other++build.gradle | Full Name: CeuiLiSA.Pixiv-Shaft | CI Platform: Other | Unit: True | Instr: False
# ✅ cgeo.cgeo__Other++build.gradle | Full Name: cgeo.cgeo | CI Platform: Other | Unit: False | Instr: False
# ✅ ch4rl3x.HtmlText__Other++build.gradle | Full Name: ch4rl3x.HtmlText | CI Platform: Other | Unit: True | Instr: False
# ✅ ch4rl3x.RevealSwipe__Other++build.gradle | Full Name: ch4rl3x.RevealSwipe | CI Platform: Other | Unit: True | Instr: True
# ✅ Ch4t4r.Nebulo__Other++build.gradle | Full Name: Ch4t4r.Nebulo | CI Platform: Other | Unit: True | Instr: False
# ✅ chahine.pageindicator__Other++build.gradle | Full Name: chahine.pageindicator | CI Platform: Other | Unit: True | Instr: False
# ✅ chaosbastler.opentraining__Other++build.gradle | Full Name: chaosbastler.opentraining | CI Platform: Other | Unit: False | Instr: False
# ✅ charpeni.react-native-url-polyfill__Other++build.gradle | Full Name: charpeni.react-native-url-polyfill | CI Platform: Other | Unit: True | Instr: True
# ✅ chennaione.sugar__Other++build.gradle | Full Name: chennaione.sugar | CI Platform: Other | Unit: True | Instr: False
# ✅ ChenSiLiang.RotatePhotoView__Other++build.gradle | Full Name: ChenSiLiang.RotatePhotoView | CI Platform: Other | Unit: True | Instr: False
# ✅ chesterbr.minitruco-android__Other++build.gradle | Full Name: chesterbr.minitruco-android | CI Platform: Other | Unit: True | Instr: False
# ✅ cho45.NanoVNA-Web-Client__Other++build.gradle | Full Name: cho45.NanoVNA-Web-Client | CI Platform: Other | Unit: True | Instr: True
# ✅ Chouten-App.Chouten-Android__Other++build.gradle | Full Name: Chouten-App.Chouten-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ chr15m.PdDroidParty__Other++build.gradle | Full Name: chr15m.PdDroidParty | CI Platform: Other | Unit: False | Instr: False
# ✅ chris-horner.SocketWeather__Other++build.gradle | Full Name: chris-horner.SocketWeather | CI Platform: Other | Unit: True | Instr: True
# ✅ christianrowlands.android-network-survey__Other++build.gradle | Full Name: christianrowlands.android-network-survey | CI Platform: Other | Unit: True | Instr: True
# ✅ CircuitVerse.mobile-app__Other++build.gradle | Full Name: CircuitVerse.mobile-app | CI Platform: Other | Unit: True | Instr: True
# ✅ citiususc.calendula__Other++build.gradle | Full Name: citiususc.calendula | CI Platform: Other | Unit: True | Instr: True
# ✅ clementine-player.Android-Remote__Other++build.gradle | Full Name: clementine-player.Android-Remote | CI Platform: Other | Unit: False | Instr: False
# ✅ cliqz-oss.browser-android__Other++build.gradle | Full Name: cliqz-oss.browser-android | CI Platform: Other | Unit: True | Instr: False
# ✅ cloudinary.cloudinary_android__Other++build.gradle | Full Name: cloudinary.cloudinary_android | CI Platform: Other | Unit: True | Instr: True
# ✅ cocos.cocos-engine__Other++build.gradle | Full Name: cocos.cocos-engine | CI Platform: Other | Unit: True | Instr: False
# ✅ codeforpublic.SQUID__Other++build.gradle | Full Name: codeforpublic.SQUID | CI Platform: Other | Unit: False | Instr: False
# ✅ CodeGather.flutter_ali_auth__Other++build.gradle | Full Name: CodeGather.flutter_ali_auth | CI Platform: Other | Unit: True | Instr: False
# ✅ coderGtm.yantra-app-launcher__Other++build.gradle | Full Name: coderGtm.yantra-app-launcher | CI Platform: Other | Unit: True | Instr: True
# ✅ coderyi.hello-weex__Other++build.gradle | Full Name: coderyi.hello-weex | CI Platform: Other | Unit: True | Instr: False
# ✅ coding-blocks.CBOnlineApp__Other++build.gradle | Full Name: coding-blocks.CBOnlineApp | CI Platform: Other | Unit: True | Instr: False
# ✅ coding.Coding-Android__Other++build.gradle | Full Name: coding.Coding-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ codinguser.gnucash-android__Other++build.gradle | Full Name: codinguser.gnucash-android | CI Platform: Other | Unit: True | Instr: True
# ✅ CofbroTeam.Doraemon__Other++build.gradle | Full Name: CofbroTeam.Doraemon | CI Platform: Other | Unit: True | Instr: True
# ✅ CominAtYou.BatteryTile__Other++build.gradle | Full Name: CominAtYou.BatteryTile | CI Platform: Other | Unit: True | Instr: True
# ✅ Commit451.ModalBottomSheetDialogFragment__Other++build.gradle | Full Name: Commit451.ModalBottomSheetDialogFragment | CI Platform: Other | Unit: True | Instr: False
# ✅ Commit451.Reptar__Other++build.gradle | Full Name: Commit451.Reptar | CI Platform: Other | Unit: True | Instr: False
# ✅ CommitteeOfZero.impacto__Other++build.gradle | Full Name: CommitteeOfZero.impacto | CI Platform: Other | Unit: True | Instr: False
# ✅ concretesolutions.canarinho__Other++build.gradle | Full Name: concretesolutions.canarinho | CI Platform: Other | Unit: True | Instr: True
# ✅ connectbot.connectbot__Other++build.gradle | Full Name: connectbot.connectbot | CI Platform: Other | Unit: True | Instr: True
# ✅ CookieJarApps.SmartCookieWeb-Preview__Other++build.gradle | Full Name: CookieJarApps.SmartCookieWeb-Preview | CI Platform: Other | Unit: True | Instr: True
# ✅ CookieJarApps.SmartCookieWeb__Other++build.gradle | Full Name: CookieJarApps.SmartCookieWeb | CI Platform: Other | Unit: True | Instr: True
# ✅ coolerfall.Android-HttpDownloadManager__Other++build.gradle | Full Name: coolerfall.Android-HttpDownloadManager | CI Platform: Other | Unit: True | Instr: False
# ✅ coracle-social.coracle__Other++build.gradle | Full Name: coracle-social.coracle | CI Platform: Other | Unit: True | Instr: True
# ✅ corbado.flutter-passkeys__Other++build.gradle | Full Name: corbado.flutter-passkeys | CI Platform: Other | Unit: True | Instr: False
# ✅ corphish.NightLight__Other++build.gradle | Full Name: corphish.NightLight | CI Platform: Other | Unit: True | Instr: False
# ✅ cosmostation.cosmostation-android__Other++build.gradle | Full Name: cosmostation.cosmostation-android | CI Platform: Other | Unit: True | Instr: False
# ✅ covid-be-app.cwa-app-android__Other++build.gradle | Full Name: covid-be-app.cwa-app-android | CI Platform: Other | Unit: True | Instr: True
# ✅ cpiz.BubbleView__Other++build.gradle | Full Name: cpiz.BubbleView | CI Platform: Other | Unit: True | Instr: False
# ✅ Crazy-Marvin.Flashy__Other++build.gradle | Full Name: Crazy-Marvin.Flashy | CI Platform: Other | Unit: True | Instr: True
# ✅ Crazy-Marvin.ToDont__Other++build.gradle | Full Name: Crazy-Marvin.ToDont | CI Platform: Other | Unit: True | Instr: True
# ✅ Criptext.Android-Email-Client__Other++build.gradle | Full Name: Criptext.Android-Email-Client | CI Platform: Other | Unit: True | Instr: True
# ✅ criticalmaps.criticalmaps-android__Other++build.gradle | Full Name: criticalmaps.criticalmaps-android | CI Platform: Other | Unit: True | Instr: True
# ✅ CryptoGuardOSS.cryptoguard__Other++build.gradle | Full Name: CryptoGuardOSS.cryptoguard | CI Platform: Other | Unit: False | Instr: False
# ✅ csicar.Ning__Other++build.gradle | Full Name: csicar.Ning | CI Platform: Other | Unit: True | Instr: True
# ✅ cucumber.cucumber-android__Other++build.gradle | Full Name: cucumber.cucumber-android | CI Platform: Other | Unit: True | Instr: True
# ✅ cuongpm.youtube-dl-android__Other++build.gradle | Full Name: cuongpm.youtube-dl-android | CI Platform: Other | Unit: True | Instr: True
# ✅ cyberbuddy-io.open-source-contribution-for-beginners__Other++build.gradle | Full Name: cyberbuddy-io.open-source-contribution-for-beginners | CI Platform: Other | Unit: True | Instr: True
# ✅ cyclejs-community.cycle-android__Other++build.gradle | Full Name: cyclejs-community.cycle-android | CI Platform: Other | Unit: True | Instr: False
# ✅ CycloneAxe.phphub-android__Other++build.gradle | Full Name: CycloneAxe.phphub-android | CI Platform: Other | Unit: True | Instr: False
# ✅ cygnusx-1-org.Slide__Other++build.gradle | Full Name: cygnusx-1-org.Slide | CI Platform: Other | Unit: True | Instr: False
# ✅ CypherpunkArmory.UserLAnd__Other++build.gradle | Full Name: CypherpunkArmory.UserLAnd | CI Platform: Other | Unit: True | Instr: False
# ✅ czlucius.code-scanner__Other++build.gradle | Full Name: czlucius.code-scanner | CI Platform: Other | Unit: True | Instr: True
# ✅ d4rken-org.bluemusic__Other++build.gradle | Full Name: d4rken-org.bluemusic | CI Platform: Other | Unit: True | Instr: True
# ✅ d4rken.RxShell__Other++build.gradle | Full Name: d4rken.RxShell | CI Platform: Other | Unit: True | Instr: False
# ✅ daimajia.EverMemo__Other++build.gradle | Full Name: daimajia.EverMemo | CI Platform: Other | Unit: False | Instr: False
# ✅ danikula.AndroidVideoCache__Other++build.gradle | Full Name: danikula.AndroidVideoCache | CI Platform: Other | Unit: True | Instr: False
# ✅ danirod.jumpdontdie__Other++build.gradle | Full Name: danirod.jumpdontdie | CI Platform: Other | Unit: False | Instr: False
# ✅ DanXi-Dev.DanXi__Other++build.gradle | Full Name: DanXi-Dev.DanXi | CI Platform: Other | Unit: False | Instr: False
# ✅ darshanparajuli.LogcatReader__Other++build.gradle | Full Name: darshanparajuli.LogcatReader | CI Platform: Other | Unit: True | Instr: True
# ✅ dart-flitter.flitter__Other++build.gradle | Full Name: dart-flitter.flitter | CI Platform: Other | Unit: True | Instr: True
# ✅ dart-lang.native__Other++build.gradle | Full Name: dart-lang.native | CI Platform: Other | Unit: False | Instr: False
# ✅ dart-native.dart_native__Other++build.gradle | Full Name: dart-native.dart_native | CI Platform: Other | Unit: True | Instr: True
# ✅ DataDropp.OllamaDroid__Other++build.gradle | Full Name: DataDropp.OllamaDroid | CI Platform: Other | Unit: True | Instr: True
# ✅ davidanaya.flutter-circular-slider__Other++build.gradle | Full Name: davidanaya.flutter-circular-slider | CI Platform: Other | Unit: True | Instr: True
# ✅ dazza5000.austin-feeds-me-flutter__Other++build.gradle | Full Name: dazza5000.austin-feeds-me-flutter | CI Platform: Other | Unit: True | Instr: True
# ✅ dbrodie.AdBuster__Other++build.gradle | Full Name: dbrodie.AdBuster | CI Platform: Other | Unit: True | Instr: True
# ✅ deckerst.aves__Other++build.gradle | Full Name: deckerst.aves | CI Platform: Other | Unit: True | Instr: False
# ✅ deep-gaurav.MusicPiped__Other++build.gradle | Full Name: deep-gaurav.MusicPiped | CI Platform: Other | Unit: True | Instr: True
# ✅ defold.defold__Other++build.gradle | Full Name: defold.defold | CI Platform: Other | Unit: True | Instr: False
# ✅ dekusms.DekuSMS-Android__Other++build.gradle | Full Name: dekusms.DekuSMS-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ deltazefiro.Amarok-Hider__Other++build.gradle | Full Name: deltazefiro.Amarok-Hider | CI Platform: Other | Unit: True | Instr: False
# ✅ DerTyp7214.MixplorerThemeCreator__Other++build.gradle | Full Name: DerTyp7214.MixplorerThemeCreator | CI Platform: Other | Unit: True | Instr: True
# ✅ desertkun.brainout__Other++build.gradle | Full Name: desertkun.brainout | CI Platform: Other | Unit: False | Instr: False
# ✅ dev-aniketj.WeatherApp-Android__Other++build.gradle | Full Name: dev-aniketj.WeatherApp-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ devclub-iitd.ShareACab__Other++build.gradle | Full Name: devclub-iitd.ShareACab | CI Platform: Other | Unit: True | Instr: True
# ✅ developersu.ns-usbloader-mobile__Other++build.gradle | Full Name: developersu.ns-usbloader-mobile | CI Platform: Other | Unit: True | Instr: True
# ✅ devtodollars.mvp-boilerplate__Other++build.gradle | Full Name: devtodollars.mvp-boilerplate | CI Platform: Other | Unit: False | Instr: False
# ✅ devzld.ExpandableTextView__Other++build.gradle | Full Name: devzld.ExpandableTextView | CI Platform: Other | Unit: True | Instr: True
# ✅ dgngulcan.droid-feed__Other++build.gradle | Full Name: dgngulcan.droid-feed | CI Platform: Other | Unit: True | Instr: True
# ✅ Dhaval2404.ImagePicker__Other++build.gradle | Full Name: Dhaval2404.ImagePicker | CI Platform: Other | Unit: True | Instr: True
# ✅ dheerajkotwani.GithubVisualizer__Other++build.gradle | Full Name: dheerajkotwani.GithubVisualizer | CI Platform: Other | Unit: True | Instr: True
# ✅ dhhAndroid.RxWebSocket__Other++build.gradle | Full Name: dhhAndroid.RxWebSocket | CI Platform: Other | Unit: True | Instr: True
# ✅ dic1911.Momogram__Other++build.gradle | Full Name: dic1911.Momogram | CI Platform: Other | Unit: True | Instr: False
# ✅ didi.AoE__Other++build.gradle | Full Name: didi.AoE | CI Platform: Other | Unit: True | Instr: False
# ✅ digidem.mapeo-mobile__Other++build.gradle | Full Name: digidem.mapeo-mobile | CI Platform: Other | Unit: True | Instr: True
# ✅ digitalgust.miniJVM__Other++build.gradle | Full Name: digitalgust.miniJVM | CI Platform: Other | Unit: True | Instr: True
# ✅ DiligentGraphics.DiligentCore__Other++build.gradle | Full Name: DiligentGraphics.DiligentCore | CI Platform: Other | Unit: False | Instr: False
# ✅ DimensionDev.TesserPG-Android__Other++build.gradle | Full Name: DimensionDev.TesserPG-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ Dimezis.BottomNavigationBar__Other++build.gradle | Full Name: Dimezis.BottomNavigationBar | CI Platform: Other | Unit: False | Instr: False
# ✅ dingjibang.GDX-RPG__Other++build.gradle | Full Name: dingjibang.GDX-RPG | CI Platform: Other | Unit: False | Instr: False
# ✅ dint-dev.cryptography__Other++build.gradle | Full Name: dint-dev.cryptography | CI Platform: Other | Unit: False | Instr: False
# ✅ discospiff.MyPlantDiaryQ__Other++build.gradle | Full Name: discospiff.MyPlantDiaryQ | CI Platform: Other | Unit: True | Instr: True
# ✅ divVerent.aaaaxy__Other++build.gradle | Full Name: divVerent.aaaaxy | CI Platform: Other | Unit: True | Instr: True
# ✅ dlazaro66.QRCodeReaderView__Other++build.gradle | Full Name: dlazaro66.QRCodeReaderView | CI Platform: Other | Unit: True | Instr: False
# ✅ dlazaro66.WheelIndicatorView__Other++build.gradle | Full Name: dlazaro66.WheelIndicatorView | CI Platform: Other | Unit: True | Instr: False
# ✅ dmfs.opentasks__Other++build.gradle | Full Name: dmfs.opentasks | CI Platform: Other | Unit: True | Instr: False
# ✅ dmitrymalk.gito-github-client__Other++build.gradle | Full Name: dmitrymalk.gito-github-client | CI Platform: Other | Unit: True | Instr: True
# ✅ dmitrymalk.material-design-dimens__Other++build.gradle | Full Name: dmitrymalk.material-design-dimens | CI Platform: Other | Unit: True | Instr: False
# ✅ Docile-Alligator.Infinity-For-Reddit__Other++build.gradle | Full Name: Docile-Alligator.Infinity-For-Reddit | CI Platform: Other | Unit: True | Instr: False
# ✅ dokar3.amlv__Other++build.gradle | Full Name: dokar3.amlv | CI Platform: Other | Unit: True | Instr: True
# ✅ dokar3.ChipTextField__Other++build.gradle | Full Name: dokar3.ChipTextField | CI Platform: Other | Unit: True | Instr: True
# ✅ dokar3.draggable-menu__Other++build.gradle | Full Name: dokar3.draggable-menu | CI Platform: Other | Unit: True | Instr: True
# ✅ dongweiq.study__Other++build.gradle | Full Name: dongweiq.study | CI Platform: Other | Unit: False | Instr: False
# ✅ dotnet.java-interop__Other++build.gradle | Full Name: dotnet.java-interop | CI Platform: Other | Unit: True | Instr: False
# ✅ Doubi88.SlideshowWallpaper__Other++build.gradle | Full Name: Doubi88.SlideshowWallpaper | CI Platform: Other | Unit: True | Instr: True
# ✅ doukutsu-rs.doukutsu-rs__Other++build.gradle | Full Name: doukutsu-rs.doukutsu-rs | CI Platform: Other | Unit: True | Instr: False
# ...
# ✅ WasimMemon.Myapplications__Other++build.gradle | Full Name: WasimMemon.Myapplications | CI Platform: Other | Unit: True | Instr: True
# ✅ Waterdish.Shipwright-Android__Other++build.gradle | Full Name: Waterdish.Shipwright-Android | CI Platform: Other | Unit: False | Instr: False
# ✅ wavesplatform.WavesWallet-android__Other++build.gradle | Full Name: wavesplatform.WavesWallet-android | CI Platform: Other | Unit: True | Instr: True
# ✅ weexext.weex-toutiao__Other++build.gradle | Full Name: weexext.weex-toutiao | CI Platform: Other | Unit: True | Instr: False
# ✅ weixiansen574.HybridFileXfer__Other++build.gradle | Full Name: weixiansen574.HybridFileXfer | CI Platform: Other | Unit: True | Instr: True
# ✅ wendux.DSBridge-Android__Other++build.gradle | Full Name: wendux.DSBridge-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ wendux.WebViewJavascriptBridge__Other++build.gradle | Full Name: wendux.WebViewJavascriptBridge | CI Platform: Other | Unit: True | Instr: True
# ✅ wenet-e2e.wetts__Other++build.gradle | Full Name: wenet-e2e.wetts | CI Platform: Other | Unit: True | Instr: True
# ✅ werbhelius.MoreType__Other++build.gradle | Full Name: werbhelius.MoreType | CI Platform: Other | Unit: True | Instr: False
# ✅ wger-project.flutter__Other++build.gradle | Full Name: wger-project.flutter | CI Platform: Other | Unit: False | Instr: False
# ✅ Wheellog.Wheellog.Android__Other++build.gradle | Full Name: Wheellog.Wheellog.Android | CI Platform: Other | Unit: True | Instr: False
# ✅ why168.LoopViewPagerLayout__Other++build.gradle | Full Name: why168.LoopViewPagerLayout | CI Platform: Other | Unit: True | Instr: True
# ✅ wikimedia.apps-android-wikipedia__Other++build.gradle | Full Name: wikimedia.apps-android-wikipedia | CI Platform: Other | Unit: True | Instr: True
# ✅ wilinz.easy_write__Other++build.gradle | Full Name: wilinz.easy_write | CI Platform: Other | Unit: True | Instr: True
# ✅ willbsp.habits__Other++build.gradle | Full Name: willbsp.habits | CI Platform: Other | Unit: True | Instr: True
# ✅ willowtreeapps.vocable-android__Other++build.gradle | Full Name: willowtreeapps.vocable-android | CI Platform: Other | Unit: True | Instr: True
# ✅ Wilm0r.giggity__Other++build.gradle | Full Name: Wilm0r.giggity | CI Platform: Other | Unit: True | Instr: True
# ✅ Windscribe.Android-App__Other++build.gradle | Full Name: Windscribe.Android-App | CI Platform: Other | Unit: True | Instr: False
# ✅ winkstu.ABPlayer__Other++build.gradle | Full Name: winkstu.ABPlayer | CI Platform: Other | Unit: False | Instr: False
# ✅ wintonBy.BottomNavigationView__Other++build.gradle | Full Name: wintonBy.BottomNavigationView | CI Platform: Other | Unit: True | Instr: True
# ✅ WirelessAlien.BhagavadGitaApp__Other++build.gradle | Full Name: WirelessAlien.BhagavadGitaApp | CI Platform: Other | Unit: True | Instr: True
# ✅ WirelessAlien.ZipXtract__Other++build.gradle | Full Name: WirelessAlien.ZipXtract | CI Platform: Other | Unit: True | Instr: True
# ✅ wisnukurniawan.Compose-Expense__Other++build.gradle | Full Name: wisnukurniawan.Compose-Expense | CI Platform: Other | Unit: True | Instr: True
# ✅ wisnukurniawan.Compose-ToDo__Other++build.gradle | Full Name: wisnukurniawan.Compose-ToDo | CI Platform: Other | Unit: True | Instr: True
# ✅ wix.react-native-notifications__Other++build.gradle | Full Name: wix.react-native-notifications | CI Platform: Other | Unit: True | Instr: False
# ✅ wiyarmir.keynotedex__Other++build.gradle | Full Name: wiyarmir.keynotedex | CI Platform: Other | Unit: True | Instr: False
# ✅ wizos.loread__Other++build.gradle | Full Name: wizos.loread | CI Platform: Other | Unit: True | Instr: False
# ✅ wolfSSL.wolfssljni__Other++build.gradle | Full Name: wolfSSL.wolfssljni | CI Platform: Other | Unit: True | Instr: True
# ✅ wolpi.prim-ftpd__Other++build.gradle | Full Name: wolpi.prim-ftpd | CI Platform: Other | Unit: False | Instr: False
# ✅ woocommerce.woocommerce-android__Other++build.gradle | Full Name: woocommerce.woocommerce-android | CI Platform: Other | Unit: True | Instr: False
# ✅ wordpress-mobile.AztecEditor-Android__Other++build.gradle | Full Name: wordpress-mobile.AztecEditor-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ wordpress-mobile.WordPress-Android__Other++build.gradle | Full Name: wordpress-mobile.WordPress-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ WrBug.DeveloperHelper__Other++build.gradle | Full Name: WrBug.DeveloperHelper | CI Platform: Other | Unit: True | Instr: False
# ✅ wshunli.arcgis-android-tianditu__Other++build.gradle | Full Name: wshunli.arcgis-android-tianditu | CI Platform: Other | Unit: True | Instr: False
# ✅ wu9007.qrcode_scanner__Other++build.gradle | Full Name: wu9007.qrcode_scanner | CI Platform: Other | Unit: True | Instr: True
# ✅ wuan.bo-android__Other++build.gradle | Full Name: wuan.bo-android | CI Platform: Other | Unit: True | Instr: True
# ✅ wuba.magpie__Other++build.gradle | Full Name: wuba.magpie | CI Platform: Other | Unit: True | Instr: False
# ✅ WuDi-ZhanShen.AccessibilityManager__Other++build.gradle | Full Name: WuDi-ZhanShen.AccessibilityManager | CI Platform: Other | Unit: True | Instr: False
# ✅ wustor.GangedRecyclerview__Other++build.gradle | Full Name: wustor.GangedRecyclerview | CI Platform: Other | Unit: True | Instr: True
# ✅ wuyexiong.transparent-over-animtabsview__Other++build.gradle | Full Name: wuyexiong.transparent-over-animtabsview | CI Platform: Other | Unit: False | Instr: False
# ✅ x13a.Clipeus__Other++build.gradle | Full Name: x13a.Clipeus | CI Platform: Other | Unit: True | Instr: True
# ✅ x13a.Duress__Other++build.gradle | Full Name: x13a.Duress | CI Platform: Other | Unit: True | Instr: True
# ✅ x13a.Sentry__Other++build.gradle | Full Name: x13a.Sentry | CI Platform: Other | Unit: True | Instr: True
# ✅ x13a.Wasted__Other++build.gradle | Full Name: x13a.Wasted | CI Platform: Other | Unit: True | Instr: True
# ✅ xbdcc.GrabRedEnvelope__Other++build.gradle | Full Name: xbdcc.GrabRedEnvelope | CI Platform: Other | Unit: True | Instr: True
# ✅ Xcreen.RestSMS__Other++build.gradle | Full Name: Xcreen.RestSMS | CI Platform: Other | Unit: True | Instr: True
# ✅ xdevs23.Cornowser__Other++build.gradle | Full Name: xdevs23.Cornowser | CI Platform: Other | Unit: True | Instr: False
# ✅ xdtianyu.CallerInfo__Other++build.gradle | Full Name: xdtianyu.CallerInfo | CI Platform: Other | Unit: True | Instr: False
# ✅ Xed-Editor.Xed-Editor__Other++build.gradle | Full Name: Xed-Editor.Xed-Editor | CI Platform: Other | Unit: True | Instr: True
# ✅ xEdenx.Isolate__Other++build.gradle | Full Name: xEdenx.Isolate | CI Platform: Other | Unit: True | Instr: False
# ✅ XiangRongLin.NewPipe-preuinified__Other++build.gradle | Full Name: XiangRongLin.NewPipe-preuinified | CI Platform: Other | Unit: True | Instr: True
# ✅ xiaojieonly.Ehviewer_CN_SXJ__Other++build.gradle | Full Name: xiaojieonly.Ehviewer_CN_SXJ | CI Platform: Other | Unit: True | Instr: False
# ✅ XilinJia.Podcini__Other++build.gradle | Full Name: XilinJia.Podcini | CI Platform: Other | Unit: False | Instr: False
# ✅ xinpengfei520.iMoney__Other++build.gradle | Full Name: xinpengfei520.iMoney | CI Platform: Other | Unit: True | Instr: True
# ✅ xinthink.flutter-keep__Other++build.gradle | Full Name: xinthink.flutter-keep | CI Platform: Other | Unit: True | Instr: True
# ✅ xjunz.AutoSkip__Other++build.gradle | Full Name: xjunz.AutoSkip | CI Platform: Other | Unit: True | Instr: True
# ✅ xlrpa.WorkBot__Other++oldbuild.gradle | Full Name: xlrpa.WorkBot | CI Platform: Other | Unit: True | Instr: True
# ✅ xmagicj.LazyFragment__Other++build.gradle | Full Name: xmagicj.LazyFragment | CI Platform: Other | Unit: True | Instr: False
# ✅ xoureldeen.Vectras-VM-Android__Other++build.gradle | Full Name: xoureldeen.Vectras-VM-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ XRPL-Labs.Xaman-App__Other++build.gradle | Full Name: XRPL-Labs.Xaman-App | CI Platform: Other | Unit: True | Instr: True
# ✅ xsahil03x.Flutter-News-Reader__Other++build.gradle | Full Name: xsahil03x.Flutter-News-Reader | CI Platform: Other | Unit: True | Instr: True
# ✅ Xtr126.XtMapper__Other++build.gradle | Full Name: Xtr126.XtMapper | CI Platform: Other | Unit: True | Instr: False
# ✅ XuDaojie.MultiStateView__Other++build.gradle | Full Name: XuDaojie.MultiStateView | CI Platform: Other | Unit: True | Instr: False
# ✅ xujiaji.HappyBubble__Other++build.gradle | Full Name: xujiaji.HappyBubble | CI Platform: Other | Unit: True | Instr: False
# ✅ XWC95.ShapeView__Other++build.gradle | Full Name: XWC95.ShapeView | CI Platform: Other | Unit: True | Instr: False
# ✅ y-polek.TransmissionRemote__Other++build.gradle | Full Name: y-polek.TransmissionRemote | CI Platform: Other | Unit: True | Instr: True
# ✅ yadav-rahul.TastyToast__Other++build.gradle | Full Name: yadav-rahul.TastyToast | CI Platform: Other | Unit: True | Instr: False
# ✅ yaming116.UpdateApp__Other++build.gradle | Full Name: yaming116.UpdateApp | CI Platform: Other | Unit: True | Instr: False
# ✅ yangwencan2002.MediaLoader__Other++build.gradle | Full Name: yangwencan2002.MediaLoader | CI Platform: Other | Unit: True | Instr: False
# ✅ Yanndroid.DualWallpaper__Other++build.gradle | Full Name: Yanndroid.DualWallpaper | CI Platform: Other | Unit: True | Instr: False
# ✅ yatatsu.AutoBundle__Other++build.gradle | Full Name: yatatsu.AutoBundle | CI Platform: Other | Unit: True | Instr: False
# ✅ yetel.EasyChatAndroidClient__Other++build.gradle | Full Name: yetel.EasyChatAndroidClient | CI Platform: Other | Unit: True | Instr: True
# ✅ yeungeek.monkey-android__Other++build.gradle | Full Name: yeungeek.monkey-android | CI Platform: Other | Unit: True | Instr: False
# ✅ YeungKC.Gank.io-for-Kotlin-Android__Other++build.gradle | Full Name: YeungKC.Gank.io-for-Kotlin-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ yeyueduxing.YeLearns__Other++build.gradle | Full Name: yeyueduxing.YeLearns | CI Platform: Other | Unit: True | Instr: False
# ✅ yggdrasil-network.yggdrasil-android__Other++build.gradle | Full Name: yggdrasil-network.yggdrasil-android | CI Platform: Other | Unit: True | Instr: True
# ✅ yhs0602.Android-Disassembler__Other++build.gradle | Full Name: yhs0602.Android-Disassembler | CI Platform: Other | Unit: False | Instr: False
# ✅ yigit.android-priority-jobqueue__Other++build.gradle | Full Name: yigit.android-priority-jobqueue | CI Platform: Other | Unit: True | Instr: False
# ✅ yjfnypeu.EasyThread__Other++build.gradle | Full Name: yjfnypeu.EasyThread | CI Platform: Other | Unit: True | Instr: True
# ✅ yohom.amap_search_fluttify__Other++build.gradle | Full Name: yohom.amap_search_fluttify | CI Platform: Other | Unit: False | Instr: False
# ✅ yongjhih.android-proguards__Other++build.gradle | Full Name: yongjhih.android-proguards | CI Platform: Other | Unit: False | Instr: False
# ✅ yongjhih.kotlin-extensions__Other++build.gradle | Full Name: yongjhih.kotlin-extensions | CI Platform: Other | Unit: True | Instr: False
# ✅ yongjhih.RxParse__Other++build.gradle | Full Name: yongjhih.RxParse | CI Platform: Other | Unit: False | Instr: False
# ✅ YouROK.TorrServe__Other++build.gradle | Full Name: YouROK.TorrServe | CI Platform: Other | Unit: False | Instr: False
# ✅ youwallet.wallet__Other++build.gradle | Full Name: youwallet.wallet | CI Platform: Other | Unit: True | Instr: True
# ✅ youzan.TitanRecyclerView__Other++build.gradle | Full Name: youzan.TitanRecyclerView | CI Platform: Other | Unit: True | Instr: False
# ✅ ytai.ioio__Other++build.gradle | Full Name: ytai.ioio | CI Platform: Other | Unit: False | Instr: False
# ✅ Yu2002s.SplitLanzou__Other++build.gradle | Full Name: Yu2002s.SplitLanzou | CI Platform: Other | Unit: True | Instr: True
# ✅ Yubico.yubioath-flutter__Other++build.gradle | Full Name: Yubico.yubioath-flutter | CI Platform: Other | Unit: True | Instr: False
# ✅ yueeng.moebooru__Other++build.gradle | Full Name: yueeng.moebooru | CI Platform: Other | Unit: True | Instr: True
# ✅ yukuku.androidbible__Other++build.gradle | Full Name: yukuku.androidbible | CI Platform: Other | Unit: True | Instr: False
# ✅ yumemi-inc.android-engineer-codecheck__Other++build.gradle | Full Name: yumemi-inc.android-engineer-codecheck | CI Platform: Other | Unit: True | Instr: True
# ✅ yunusefendi52.quran_app__Other++build.gradle | Full Name: yunusefendi52.quran_app | CI Platform: Other | Unit: True | Instr: True
# ✅ YuriSizuku.OnscripterYuri__Other++build.gradle | Full Name: YuriSizuku.OnscripterYuri | CI Platform: Other | Unit: True | Instr: True
# ✅ yusufonderd.Weightly__Other++build.gradle | Full Name: yusufonderd.Weightly | CI Platform: Other | Unit: True | Instr: True
# ✅ zacharee.ShizukuHack__Other++build.gradle | Full Name: zacharee.ShizukuHack | CI Platform: Other | Unit: True | Instr: True
# ✅ ZahraHeydari.MusicPlayer__Other++build.gradle | Full Name: ZahraHeydari.MusicPlayer | CI Platform: Other | Unit: True | Instr: True
# ✅ ZaneYork.SMAPI-Android-Installer__Other++build.gradle | Full Name: ZaneYork.SMAPI-Android-Installer | CI Platform: Other | Unit: True | Instr: True
# ✅ ZaraclaJ.audio_recorder__Other++build.gradle | Full Name: ZaraclaJ.audio_recorder | CI Platform: Other | Unit: True | Instr: True
# ✅ ZCShou.GoGoGo__Other++build.gradle | Full Name: ZCShou.GoGoGo | CI Platform: Other | Unit: True | Instr: True
# ✅ zeevy.grblcontroller__Other++build.gradle | Full Name: zeevy.grblcontroller | CI Platform: Other | Unit: True | Instr: True
# ✅ zerochl.FFMPEG-AAC-264-Android-32-64__Other++build.gradle | Full Name: zerochl.FFMPEG-AAC-264-Android-32-64 | CI Platform: Other | Unit: True | Instr: False
# ✅ zetbaitsu.Compressor__Other++build.gradle | Full Name: zetbaitsu.Compressor | CI Platform: Other | Unit: True | Instr: False
# ✅ zfdang.Android-Touch-Helper__Other++build.gradle | Full Name: zfdang.Android-Touch-Helper | CI Platform: Other | Unit: True | Instr: True
# ✅ zfdang.zSMTH-Android__Other++build.gradle | Full Name: zfdang.zSMTH-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ zhkrb.Iwara-android-client__Other++build.gradle | Full Name: zhkrb.Iwara-android-client | CI Platform: Other | Unit: True | Instr: True
# ✅ zhongfq.cocos-lua__Other++build.gradle | Full Name: zhongfq.cocos-lua | CI Platform: Other | Unit: False | Instr: False
# ✅ zhouchaoyuan.excelPanel__Other++build.gradle | Full Name: zhouchaoyuan.excelPanel | CI Platform: Other | Unit: True | Instr: True
# ✅ zhpanvip.LockView__Other++build.gradle | Full Name: zhpanvip.LockView | CI Platform: Other | Unit: True | Instr: True
# ✅ Zhuinden.live-event__Other++build.gradle | Full Name: Zhuinden.live-event | CI Platform: Other | Unit: True | Instr: True
# ✅ zilianliuxue.AndroidStudy__Other++build.gradle | Full Name: zilianliuxue.AndroidStudy | CI Platform: Other | Unit: True | Instr: True
# ✅ zlgopen.awtk__Other++build.gradle | Full Name: zlgopen.awtk | CI Platform: Other | Unit: True | Instr: True
# ✅ zoff99.ToxAndroidRefImpl__Other++build.gradle | Full Name: zoff99.ToxAndroidRefImpl | CI Platform: Other | Unit: True | Instr: True
# ✅ Zomato.sushi-ui-android__Other++build.gradle | Full Name: Zomato.sushi-ui-android | CI Platform: Other | Unit: True | Instr: True
# ✅ Zoxc.crusader__Other++build.gradle | Full Name: Zoxc.crusader | CI Platform: Other | Unit: True | Instr: False
# ✅ zserge.log__Other++build.gradle | Full Name: zserge.log | CI Platform: Other | Unit: True | Instr: False
# ✅ zsoltk.compose-router__Other++build.gradle | Full Name: zsoltk.compose-router | CI Platform: Other | Unit: True | Instr: False
# ✅ zsoltk.GameOfLife__Other++build.gradle | Full Name: zsoltk.GameOfLife | CI Platform: Other | Unit: True | Instr: True
# ✅ zsoltk.overpasser__Other++build.gradle | Full Name: zsoltk.overpasser | CI Platform: Other | Unit: True | Instr: False
# ✅ zugaldia.android-robocar__Other++build.gradle | Full Name: zugaldia.android-robocar | CI Platform: Other | Unit: True | Instr: True
# ✅ Zweihui.Aurora__Other++build.gradle | Full Name: Zweihui.Aurora | CI Platform: Other | Unit: True | Instr: False
# ✅ Saved results to: C:\Android Mobile App\Step3_Instr_Testing_Analysis\3.2_Gradle_List_ShallowC.csv
