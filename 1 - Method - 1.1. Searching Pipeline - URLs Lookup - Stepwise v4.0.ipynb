# %% [markdown]
# - This code runs 5 independent base queries for seaching 3 languages and the keyword android once in the topic and once in the name, desc and readme
# - All 5 queries includes three common qualifier: stars:>50, fork:false and archived:false
# - Layer 1: Live Search - GitHub API
# - Layer 2: there is no layer two in this version
# - This is the final version used to create the list for step 2: AndroidManifest.xml check

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv, set_key, dotenv_values
from base64 import b64decode
from datetime import datetime, timedelta
from time import sleep

# === Load environment variables ===
env_path = "All_Tokens.env"
load_dotenv(env_path)
env_vars = dotenv_values(env_path)

# === Load GitHub tokens ===
tokens = [os.getenv(f"GITHUB_TOKEN_{i}") for i in range(1, 7) if os.getenv(f"GITHUB_TOKEN_{i}")]
if not tokens:
    raise ValueError("❌ No GitHub tokens found in All_Tokens.env")

# === Token rotation ===
current_token_index = 0
last_used_token_index = -1
RATE_LIMIT_THRESHOLD = 1

def get_headers():
    global current_token_index, last_used_token_index
    if last_used_token_index != current_token_index:
        print(f"🔄 Switching to token #{current_token_index + 1} / {len(tokens)}")
        last_used_token_index = current_token_index
    return {
        "Authorization": f"token {tokens[current_token_index]}",
        "Accept": "application/vnd.github.mercy-preview+json"
    }

def rotate_token():
    global current_token_index
    current_token_index = (current_token_index + 1) % len(tokens)
    print(f"🔁 Rotating to next token: #{current_token_index + 1}")
    if current_token_index == 0:
        print("⏳ All tokens used. Sleeping for 60 seconds to reset rate limits...")
        sleep(60)
        print("🔄 Resuming after sleep...")

def check_rate_limit():
    url = "https://api.github.com/rate_limit"
    res = requests.get(url, headers=get_headers())
    if res.status_code == 200:
        remaining = res.json()['rate']['remaining']
        if remaining <= RATE_LIMIT_THRESHOLD:
            print("⚠️ Nearing rate limit. Rotating token...")
            rotate_token()
            return check_rate_limit()
    elif res.status_code == 403:
        print("🚫 Forbidden: Possibly rate-limited. Rotating token...")
        rotate_token()
        return check_rate_limit()

# === Constants ===
DEFAULT_START_DATE = "2008-01-01T00:00:00Z"
END_DATE = "2024-12-31T23:59:59Z"
INITIAL_WINDOW_HOURS = float(os.getenv("SEARCH_WINDOW_HOURS", 24))
MIN_WINDOW_HOURS = 1
MAX_WINDOW_HOURS = 90 * 24
MAX_RESULTS_PER_QUERY = 1000
TARGET_FILL_RATIO = 0.25

# === Output path ===
OUTPUT_DIR = r"C:\Android Mobile App\Step1_URL_Search\Type_1_Searching_Pipeline"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_FILE = os.path.join(OUTPUT_DIR, "step1_url_lookup_output.csv")

# === Base queries ===
BASE_QUERIES = {
    "language:Kotlin": "stars:>50 language:Kotlin fork:false archived:false",
    "language:Java": "stars:>50 language:Java fork:false archived:false",
    "language:Dart": "stars:>50 language:Dart fork:false archived:false",
    "topic:android": "stars:>50 topic:android fork:false archived:false",
    "android:keyword": "stars:>50 android in:name,description,readme fork:false archived:false"
}

# === Load checkpoints from .env ===
checkpoints = {
    label: env_vars.get(f"SEARCH_CHECKPOINT_{label.replace(':', '_').upper()}", DEFAULT_START_DATE)
    for label in BASE_QUERIES
}

# === GitHub enrichment ===
def get_readme(repo_full_name):
    url = f"https://api.github.com/repos/{repo_full_name}/readme"
    check_rate_limit()
    res = requests.get(url, headers=get_headers())
    if res.status_code == 200:
        content = res.json().get("content", "")
        return b64decode(content).decode("utf-8", errors="ignore")
    return ""

def get_topics(repo_full_name):
    url = f"https://api.github.com/repos/{repo_full_name}/topics"
    check_rate_limit()
    res = requests.get(url, headers=get_headers())
    if res.status_code == 200:
        return res.json().get("names", [])
    return []

def search_android_keyword(name, desc, topics, readme):
    fields = [name or "", desc or "", " ".join(topics), readme or ""]
    return "yes" if any("android" in f.lower() for f in fields) else "no"

def fetch_metadata(repo):
    full_name = repo.get("full_name")
    print(f"🔎 Fetching metadata for {full_name}")
    url = f"https://api.github.com/repos/{full_name}"
    check_rate_limit()
    res = requests.get(url, headers=get_headers())
    if res.status_code == 200:
        repo_data = res.json()
        lang = repo_data.get("language", "")
        readme = get_readme(full_name)
        topics = get_topics(full_name)
        ak = search_android_keyword(repo_data.get("name"), repo_data.get("description"), topics, readme)
        valid = "yes" if lang in ["Java", "Kotlin", "Dart"] or ak == "yes" else "no"
        return {
            "html_url": repo_data.get("html_url"),
            "name": repo_data.get("name"),
            "language": lang,
            "stars": repo_data.get("stargazers_count", 0),
            "created_at": repo_data.get("created_at", ""),
            "Android_keyword": ak,
            "Valid_Repo_Step1": valid
        }
    return None

# === Main search ===
def search():
    if os.path.exists(OUTPUT_FILE):
        df_all = pd.read_csv(OUTPUT_FILE)
    else:
        df_all = pd.DataFrame()

    for label, q in BASE_QUERIES.items():
        key = f"SEARCH_CHECKPOINT_{label.replace(':', '_').upper()}"
        start_str = checkpoints.get(label, DEFAULT_START_DATE)
        start = datetime.strptime(start_str, "%Y-%m-%dT%H:%M:%SZ")
        end = datetime.strptime(END_DATE, "%Y-%m-%dT%H:%M:%SZ")

        if start >= end:
            print(f"⏩ Skipping completed query: {label}")
            continue

        print(f"\n🔁 Starting sweep for query [{label}] from {start_str}")
        window = timedelta(hours=INITIAL_WINDOW_HOURS)

        while start < end:
            since = start.strftime("%Y-%m-%dT%H:%M:%SZ")
            until_dt = min(start + window, end)
            until = until_dt.strftime("%Y-%m-%dT%H:%M:%SZ")
            print(f"\n🔍 Window for [{label}]: {since} → {until} (window = {window})")

            q_base = f"{q} created:{since}..{until}"
            count_url = f"https://api.github.com/search/repositories?q={q_base}&per_page=1"
            check_rate_limit()
            count_res = requests.get(count_url, headers=get_headers())
            total_count = count_res.json().get("total_count", 0) if count_res.status_code == 200 else -1
            print(f"🔢 Estimated total: {total_count}")

            current_hours = window.total_seconds() / 3600
            if total_count >= MAX_RESULTS_PER_QUERY and current_hours > MIN_WINDOW_HOURS:
                window = timedelta(hours=max(current_hours // 2, MIN_WINDOW_HOURS))
                print(f"⚠️ Too many results. Shrinking window to {window}.")
                continue
            elif 0 <= total_count < MAX_RESULTS_PER_QUERY * TARGET_FILL_RATIO and current_hours * 2 <= MAX_WINDOW_HOURS:
                window = timedelta(hours=min(current_hours * 2, MAX_WINDOW_HOURS))
                print(f"📈 Too few results. Expanding window to {window}.")

            batch = []
            for page in range(1, 11):
                paged_url = f"https://api.github.com/search/repositories?q={q_base}&per_page=100&page={page}&sort=stars&order=desc"
                print(f"📄 Fetching page {page} for [{label}]...")
                check_rate_limit()
                res = requests.get(paged_url, headers=get_headers())
                if res.status_code == 200:
                    items = res.json().get("items", [])
                    if not items:
                        print("📭 No more items.")
                        break
                    print(f"✅ Page {page}: Retrieved {len(items)} repos")
                    for repo in items:
                        meta = fetch_metadata(repo)
                        if meta:
                            batch.append(meta)
                        sleep(1)
                elif res.status_code == 403:
                    print("⏳ Rate limited. Rotating token...")
                    rotate_token()
                    continue
                else:
                    print(f"❌ Error on page {page}: {res.status_code} - {res.text}")
                    break

            if len(batch) >= MAX_RESULTS_PER_QUERY:
                print(f"⚠️ Hit GitHub's 1,000 result cap. Shrinking window from {window}.")
                current_hours = window.total_seconds() / 3600
                window = timedelta(hours=max(current_hours // 2, MIN_WINDOW_HOURS))
                continue

            if batch:
                df_batch = pd.DataFrame(batch)
                df_all = pd.concat([df_all, df_batch], ignore_index=True)
                df_all.drop_duplicates(subset="html_url", inplace=True)
                df_all.to_csv(OUTPUT_FILE, index=False)
                print(f"💾 Saved {len(batch)} new repos to CSV")

            # ✅ Update checkpoint in .env
            start = until_dt + timedelta(seconds=1)
            new_start_str = start.strftime("%Y-%m-%dT%H:%M:%SZ")
            set_key(env_path, key, new_start_str)
            checkpoints[label] = new_start_str

        print(f"✅ Finished full time sweep for query: {label}")

    print("\n🎉 All queries processed. Final results saved.")

# === Run it ===
if __name__ == "__main__":
    search()
# Out:
# 🔁 Starting sweep for query [language:Kotlin] from 2019-04-01T00:00:00Z
#
# 🔍 Window for [language:Kotlin]: 2019-04-01T00:00:00Z → 2019-04-02T00:00:00Z (window = 1 day, 0:00:00)
# 🔄 Switching to token #1 / 6
# 🔢 Estimated total: 2
# 📈 Too few results. Expanding window to 2 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 2 repos
# 🔎 Fetching metadata for tadfisher/gradle2nix
# 🔎 Fetching metadata for tfcporciuncula/dagger-journey
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 2 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-04-02T00:00:01Z → 2019-04-04T00:00:01Z (window = 2 days, 0:00:00)
# 🔢 Estimated total: 9
# 📈 Too few results. Expanding window to 4 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 9 repos
# 🔎 Fetching metadata for home-assistant/android
# 🔎 Fetching metadata for ITGungnir/KotlinWanAndroid
# 🔎 Fetching metadata for sergivonavi/MaterialBanner
# 🔎 Fetching metadata for kenneycode/OpenGLESPro
# 🔎 Fetching metadata for binaryshao/WanAndroid-MVVM
# 🔎 Fetching metadata for instructure/canvas-android
# 🔎 Fetching metadata for adrielcafe/pufferdb
# 🔎 Fetching metadata for joaomgcd/TaskerPluginSample
# 🔎 Fetching metadata for yishuinanfeng/jigsawMaker
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 9 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-04-04T00:00:02Z → 2019-04-08T00:00:02Z (window = 4 days, 0:00:00)
# 🔢 Estimated total: 5
# 📈 Too few results. Expanding window to 8 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 5 repos
# 🔎 Fetching metadata for rnmapbox/maps
# 🔎 Fetching metadata for iammert/MultiSearchView
# 🔎 Fetching metadata for wuyr/LitePager
# 🔎 Fetching metadata for msasikanth/ColorSheet
# 🔎 Fetching metadata for kanawish/upvote
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 5 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-04-08T00:00:03Z → 2019-04-16T00:00:03Z (window = 8 days, 0:00:00)
# 🔢 Estimated total: 18
# 📈 Too few results. Expanding window to 16 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 18 repos
# 🔎 Fetching metadata for eprendre/tingshu
# 🔎 Fetching metadata for uniflow-kt/uniflow-kt
# 🔎 Fetching metadata for massoudss/waveformSeekBar
# 🔎 Fetching metadata for androidmalin/AndroidComponentPlugin
# 🔎 Fetching metadata for YvesCheung/SlidableLayout
# 🔎 Fetching metadata for SapuSeven/BetterUntis
# 🔎 Fetching metadata for soundcrowd/soundcrowd
# 🔎 Fetching metadata for volga-volga/react-native-yamap
# 🔎 Fetching metadata for sshpark/LeetCode-Kotlin
# 🔎 Fetching metadata for hoanganhtuan95ptit/DraggablePanel
# 🔎 Fetching metadata for agoda-com/ninjato
# 🔎 Fetching metadata for AdamMc331/PokeDex
# 🔎 Fetching metadata for PacktPublishing/Android-Programming-with-Kotlin-for-Beginners
# 🔎 Fetching metadata for pranayairan/CoinBit
# 🔎 Fetching metadata for savepopulation/beaver
# 🔎 Fetching metadata for D10NGYANG/DL10RoundMenuView
# 🔎 Fetching metadata for keciciler/OnViewTouchHoldListener
# 🔎 Fetching metadata for hantsy/spring-kotlin-coroutines-sample
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 18 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-04-16T00:00:04Z → 2019-05-02T00:00:04Z (window = 16 days, 0:00:00)
# 🔢 Estimated total: 51
# 📈 Too few results. Expanding window to 32 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 51 repos
# 🔎 Fetching metadata for kizitonwose/Calendar
# 🔎 Fetching metadata for didi/booster
# 🔎 Fetching metadata for nekomangaorg/Neko
# 🔎 Fetching metadata for android/storage-samples
# 🔎 Fetching metadata for DUpdateSystem/UpgradeAll
# 🔎 Fetching metadata for Leifzhang/AndroidAutoTrack
# 🔎 Fetching metadata for Tobi823/ffupdater
# 🔎 Fetching metadata for razir/ProgressButton
# 🔎 Fetching metadata for dracula/jetbrains
# 🔎 Fetching metadata for haroldadmin/NetworkResponseAdapter
# 🔎 Fetching metadata for emedinaa/kotlin-mvvm
# 🔎 Fetching metadata for Kr0oked/Compass
# 🔎 Fetching metadata for giandifra/arcore_flutter_plugin
# 🔎 Fetching metadata for anugotta/FlipTimerView
# 🔎 Fetching metadata for Yelp/bento
# 🔎 Fetching metadata for soulqw/CoCo
# 🔎 Fetching metadata for juancresc/SMSHub
# 🔎 Fetching metadata for zhujiang521/AndroidAOP
# 🔎 Fetching metadata for raghavk92/Kontroller
# 🔎 Fetching metadata for tizisdeepan/VideoEditor
# 🔎 Fetching metadata for yellowbluesky/PixivforMuzei3
# 🔎 Fetching metadata for Syex/MoviesMPP
# 🔎 Fetching metadata for PhilippeBoisney/Material
# 🔎 Fetching metadata for drawf/SourceSet
# 🔎 Fetching metadata for AhmedAshrafG/ExpandableSelectionView
# 🔎 Fetching metadata for grivos/Spanomatic
# 🔎 Fetching metadata for dennisschroeder/khome
# 🔎 Fetching metadata for rahuldange09/Splashy
# 🔎 Fetching metadata for furkanaskin/podpocket
# 🔎 Fetching metadata for OpenSooq/Pluto
# 🔎 Fetching metadata for Freeport-Metrics/android-kotlin-starter
# 🔎 Fetching metadata for RamiJ3mli/Easings
# 🔎 Fetching metadata for javadevelopuser/DouyinHooker
# 🔎 Fetching metadata for bowserf/android-cmake-sample
# 🔎 Fetching metadata for wuyr/HexagramDecoder
# 🔎 Fetching metadata for cats-oss/android-license-sample
# 🔎 Fetching metadata for KirkBushman/ARAW
# 🔎 Fetching metadata for antoniolg/architect-coders
# 🔎 Fetching metadata for willowtreeapps/fuzzywuzzy-kotlin
# 🔎 Fetching metadata for ArisGuimera/RetrofitKotlinExample
# 🔎 Fetching metadata for uber/lint-checks
# 🔎 Fetching metadata for ReplayMod/preprocessor
# 🔎 Fetching metadata for Quillraven/SimpleKtxGame
# 🔎 Fetching metadata for damian-burke/android-dynamic-feature
# 🔎 Fetching metadata for SimonMarquis/QrCode
# 🔎 Fetching metadata for alexsocha/luckyblock
# 🔎 Fetching metadata for InkApplications/Shade
# 🔎 Fetching metadata for phase/MinecraftMappings
# 🔎 Fetching metadata for EspoirX/ImageUploadManager
# 🔎 Fetching metadata for DevNatan/kuken
# 🔎 Fetching metadata for AChep/PocketMode
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 51 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-05-02T00:00:05Z → 2019-06-03T00:00:05Z (window = 32 days, 0:00:00)
# 🔢 Estimated total: 95
# 📈 Too few results. Expanding window to 64 days, 0:00:00.
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 95 repos
# 🔎 Fetching metadata for 2dust/v2rayNG
# 🔎 Fetching metadata for gedoor/legado
# 🔎 Fetching metadata for android/camera-samples
# 🔎 Fetching metadata for Foso/Jetpack-Compose-Playground
# 🔎 Fetching metadata for TencentBlueKing/bk-ci
# 🔎 Fetching metadata for mCyp/Hoo
# 🔎 Fetching metadata for sksamuel/hoplite
# 🔎 Fetching metadata for trynoice/android-app
# 🔎 Fetching metadata for ismaeldivita/chip-navigation-bar
# 🔎 Fetching metadata for meshenger-app/meshenger-android
# 🔎 Fetching metadata for jarroyoesp/KotlinMultiPlatform
# 🔎 Fetching metadata for freeletics/FlowRedux
# 🔎 Fetching metadata for libgdx/gdx-liftoff
# 🔎 Fetching metadata for mickstar/Zoo-For-Zotero
# 🔎 Fetching metadata for partiql/partiql-lang-kotlin
# 🔎 Fetching metadata for tom5079/Pupil
# 🔎 Fetching metadata for aminography/PrimeDatePicker
# 🔎 Fetching metadata for reduxkotlin/redux-kotlin
# 🔎 Fetching metadata for tangcent/easy-yapi
# 🔎 Fetching metadata for HeyAlex/BottomDrawer
# 🔎 Fetching metadata for evilcorpltd/aTox
# 🔎 Fetching metadata for tema6120/ForgetMeNot
# 🔎 Fetching metadata for lulululbj/AndroidUtilCodeKTX
# 🔎 Fetching metadata for libp2p/jvm-libp2p
# 🔎 Fetching metadata for flex3r/DankChat
# 🔎 Fetching metadata for georgeherby/flutter-snippets
# 🔎 Fetching metadata for kotlin-hands-on/intro-coroutines
# 🔎 Fetching metadata for papsign/Ktor-OpenAPI-Generator
# 🔎 Fetching metadata for theapache64/remove-bg
# 🔎 Fetching metadata for Hankkin/JetPack_Note
# 🔎 Fetching metadata for getbouncer/cardscan-android
# 🔎 Fetching metadata for ChenLittlePing/FillTextView
# 🔎 Fetching metadata for lopspower/CircleView
# 🔎 Fetching metadata for haroldadmin/MoonShot
# 🔎 Fetching metadata for SimonSchubert/Braincup
# 🔎 Fetching metadata for SciProgCentre/plotly.kt
# 🔎 Fetching metadata for endyrubbin/AAStream
# 🔎 Fetching metadata for andrasferenczi/dart-data-plugin
# 🔎 Fetching metadata for amrfarid140/webrtc-android-codelab
# 🔎 Fetching metadata for jimmod/ShareToComputer
# 🔎 Fetching metadata for reactor/reactor-kotlin-extensions
# 🔎 Fetching metadata for priettt/kotlin-mvvm-clean-sample
# 🔎 Fetching metadata for iFr0z/WorkManagerNotification
# 🔎 Fetching metadata for arindamxd/android-camerax
# 🔎 Fetching metadata for aafanasev/sekret
# 🔎 Fetching metadata for willowtreeapps/vocable-android
# 🔎 Fetching metadata for battlecatsultimate/BCU_Android
# 🔎 Fetching metadata for evanrupert/ExcelKt
# 🔎 Fetching metadata for PRNDcompany/StepProgressBar
# 🔎 Fetching metadata for ToDou/nestrefresh
# 🔎 Fetching metadata for z3r0c00l-2k/AquaDroid
# 🔎 Fetching metadata for bitvale/FitnessChallenge
# 🔎 Fetching metadata for lcdsmao/SpringX
# 🔎 Fetching metadata for namjug-kim/reactive-crypto
# 🔎 Fetching metadata for pearxteam/kasechange
# 🔎 Fetching metadata for Giphy/giphy-android-sdk
# 🔎 Fetching metadata for char/Koffee
# 🔎 Fetching metadata for yeswehack/YesWeBurp
# 🔎 Fetching metadata for TayfunCesur/Stepper
# 🔎 Fetching metadata for ebi-igweze/ViewPagerNavigation
# 🔎 Fetching metadata for imurluck/HeaderLayout
# 🔎 Fetching metadata for dropbox/hypershard-android
# 🔎 Fetching metadata for yunshuipiao/Potato
# 🔎 Fetching metadata for captain82/Zomato
# 🔎 Fetching metadata for hyzhan43/KtArmor
# 🔎 Fetching metadata for DuartBreedt/Android-Navigation-in-a-Single-Activity-Multi-Module-App
# 🔎 Fetching metadata for patou/gitmoji-intellij-plugin
# 🔎 Fetching metadata for adityam49/Updoot
# 🔎 Fetching metadata for fs0c131y/SamsungLocker
# 🔎 Fetching metadata for jeffshee/NextGenVisualizer
# 🔎 Fetching metadata for razir/MoviesInsetsDemo
# 🔎 Fetching metadata for Pixelnetica/android-pdf-ocr-document-scanner
# 🔎 Fetching metadata for kenneycode/GLKit
# 🔎 Fetching metadata for aminography/PrimeCalendar
# 🔎 Fetching metadata for TayfunCesur/GithubProjectBrowser
# 🔎 Fetching metadata for astrit-veliu/Boom
# 🔎 Fetching metadata for KingsMentor/RVcompose
# 🔎 Fetching metadata for indritbashkimi/ScreenKap
# 🔎 Fetching metadata for ricknout/android-mdc-custom-views
# 🔎 Fetching metadata for bobymicroby/elmo
# 🔎 Fetching metadata for packwiz/packwiz-installer
# 🔎 Fetching metadata for Angry-Potato/prettier-plugin-kotlin
# 🔎 Fetching metadata for gastsail/CleanFirestoreLogin
# 🔎 Fetching metadata for PhilJay/JWT
# 🔎 Fetching metadata for CoinbaseWallet/CBCrypto
# 🔎 Fetching metadata for thomasnield/kotlin-machine-learning-demos
# 🔎 Fetching metadata for aminography/ChoosePhotoHelper
# 🔎 Fetching metadata for uchitel/eventex
# 🔎 Fetching metadata for feng0403/ConstraintLayoutSamples
# 🔎 Fetching metadata for WindySha/RemoveVideoAdsPlugin
# 🔎 Fetching metadata for magneticflux-/fabric-mumblelink-mod
# 🔎 Fetching metadata for HitenDev/android-dependencies-completion
# 🔎 Fetching metadata for jxj2118/JCamera
# 🔎 Fetching metadata for Trojan295/android-webauthn-token
# 🔎 Fetching metadata for Naveentp/Clean-MVVM-NewsApp
# 📄 Fetching page 2 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 95 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-06-03T00:00:06Z → 2019-08-06T00:00:06Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 176
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 100 repos
# 🔎 Fetching metadata for skydoves/Balloon
# 🔎 Fetching metadata for vmadalin/android-modular-architecture
# 🔎 Fetching metadata for evant/kotlin-inject
# 🔎 Fetching metadata for KieronQuinn/DarQ
# 🔎 Fetching metadata for android/wear-os-samples
# 🔎 Fetching metadata for JetBrains/kotless
# 🔎 Fetching metadata for android/tv-samples
# 🔎 Fetching metadata for JunioJsv/mtk-easy-su
# 🔎 Fetching metadata for Stypox/dicio-android
# 🔎 Fetching metadata for fabricezhang/lcg
# 🔎 Fetching metadata for runningcode/gradle-doctor
# 🔎 Fetching metadata for Eli-Fox/LEGO-Catalog
# 🔎 Fetching metadata for ACINQ/phoenix
# 🔎 Fetching metadata for mitchtabian/Open-API-Android-App
# 🔎 Fetching metadata for feelschaotic/SDKHotFix
# 🔎 Fetching metadata for GoSecure/dtd-finder
# 🔎 Fetching metadata for JetBrains/lincheck
# 🔎 Fetching metadata for lopspower/RxAnimation
# 🔎 Fetching metadata for ParkSangGwon/TedImagePicker
# 🔎 Fetching metadata for codota/tabnine-intellij
# 🔎 Fetching metadata for nanchen2251/ScreenRecordHelper
# 🔎 Fetching metadata for nuhkoca/kotlin-modular-tdd-coroutines-mvvm
# 🔎 Fetching metadata for akarnokd/kotlin-flow-extensions
# 🔎 Fetching metadata for koxudaxi/pydantic-pycharm-plugin
# 🔎 Fetching metadata for Malinskiy/adam
# 🔎 Fetching metadata for skydoves/Only
# 🔎 Fetching metadata for dotanuki-labs/norris
# 🔎 Fetching metadata for skydoves/Submarine
# 🔎 Fetching metadata for hashlin/rally
# 🔎 Fetching metadata for TayfunCesur/CurvedBottomSheet
# 🔎 Fetching metadata for callstack/react-native-brownfield
# 🔎 Fetching metadata for Armen101/AudioRecordView
# 🔎 Fetching metadata for mroczis/netmonster-core
# 🔎 Fetching metadata for splendo/kaluga
# 🔎 Fetching metadata for robertlevonyan/camerax-demo
# 🔎 Fetching metadata for melihaksoy/Android-Kotlin-Modulerized-CleanArchitecture
# 🔎 Fetching metadata for HamidrezaAmz/MagicalExoPlayer
# 🔎 Fetching metadata for ansnail/SuperFamily
# 🔎 Fetching metadata for VladimirWrites/BLTaxi
# 🔎 Fetching metadata for emeraldpay/dshackle
# 🔎 Fetching metadata for kukyxs/CoroutinesWanAndroid
# 🔎 Fetching metadata for majorkik/SparkLineLayout
# 🔎 Fetching metadata for SimonMarquis/AR-Toolbox
# 🔎 Fetching metadata for PandoraMedia/BottomNavigator
# 🔎 Fetching metadata for cbeust/kash
# 🔎 Fetching metadata for marius-h/flutter_enhancement_suite
# 🔎 Fetching metadata for willowtreeapps/sign-in-with-apple-button-android
# 🔎 Fetching metadata for ZahraHeydari/Android-Clean-Arch-Coroutines-Koin
# 🔎 Fetching metadata for rogro82/PiPup
# 🔎 Fetching metadata for lukelorusso/VerticalSeekBar
# 🔎 Fetching metadata for alirezat775/carousel-view
# 🔎 Fetching metadata for just-ai/aimybox-android-assistant
# 🔎 Fetching metadata for wmpf/wmpf_demo_external
# 🔎 Fetching metadata for Gekkio/GhidraBoy
# 🔎 Fetching metadata for joffrey-bion/krossbow
# 🔎 Fetching metadata for manuelvicnt/MathCoroutinesFlow
# 🔎 Fetching metadata for eopeter/flutter_mapbox_navigation
# 🔎 Fetching metadata for Mindinventory/Lassi-Android
# 🔎 Fetching metadata for robertohuertasm/endless-service
# 🔎 Fetching metadata for kotlin-inquirer/kotlin-inquirer
# 🔎 Fetching metadata for Shouheng88/arch-android
# 🔎 Fetching metadata for robotemi/sdk
# 🔎 Fetching metadata for specialprojects-experiments/paperphone
# 🔎 Fetching metadata for Liloupar/novel-server
# 🔎 Fetching metadata for markaren/three.kt
# 🔎 Fetching metadata for lzan13/VMTemplateAndroid
# 🔎 Fetching metadata for mitchtabian/Navigation-Components-Example
# 🔎 Fetching metadata for avro-kotlin/avro4k
# 🔎 Fetching metadata for muratcanbur/ProjectX
# 🔎 Fetching metadata for hasankucuk/SocialTextView
# 🔎 Fetching metadata for DDoSolitary/OkcAgent
# 🔎 Fetching metadata for TanJiaJunBeyond/AndroidGenericFramework
# 🔎 Fetching metadata for p-lr/MapView
# 🔎 Fetching metadata for line/lich
# 🔎 Fetching metadata for dragneelfps/realworld-kotlin-ktor
# 🔎 Fetching metadata for fpinkotlin/fpinkotlin
# 🔎 Fetching metadata for donfuxx/Mockinizer
# 🔎 Fetching metadata for haroldadmin/Vector
# 🔎 Fetching metadata for skydoves/Chamber
# 🔎 Fetching metadata for ParkSangGwon/TedNaverMapClustering
# 🔎 Fetching metadata for gs666/XimalayaKotlin
# 🔎 Fetching metadata for probelalkhan/android-mvvm-architecture
# 🔎 Fetching metadata for speekha/httpmocker
# 🔎 Fetching metadata for cashapp/barber
# 🔎 Fetching metadata for CarnegieTechnologies/gallery_saver
# 🔎 Fetching metadata for suchoX/PlacePicker
# 🔎 Fetching metadata for droid-girl/arfaces
# 🔎 Fetching metadata for imgly/vesdk-android-demo
# 🔎 Fetching metadata for dipien/releases-hub-gradle-plugin
# 🔎 Fetching metadata for iftechio/iftech-android-slide-layout
# 🔎 Fetching metadata for HedvigInsurance/android
# 🔎 Fetching metadata for QArtur99/ChatApp
# 🔎 Fetching metadata for kernel0x/finch
# 🔎 Fetching metadata for CottaCush/CurrencyEditText
# 🔎 Fetching metadata for dev-claw/vripper-project
# 🔎 Fetching metadata for SimpleAppProjects/SimpleWear
# 🔎 Fetching metadata for hotstu/QRCodeCameraX
# 🔎 Fetching metadata for kroegerama/barcode-kaiteki
# 🔎 Fetching metadata for cdnbye/android-p2p-engine
# 🔎 Fetching metadata for crowdin/mobile-sdk-android
# 📄 Fetching page 2 for [language:Kotlin]...
# ✅ Page 2: Retrieved 76 repos
# 🔎 Fetching metadata for romellfudi/FudiNFC
# 🔎 Fetching metadata for JDevZone/CheckableTextView
# 🔎 Fetching metadata for wuyr/ArrowDrawable
# 🔎 Fetching metadata for Reginer/MVVMHub
# 🔎 Fetching metadata for ismaeldivita/change-tracker-plugin
# 🔎 Fetching metadata for st235/SwipeToActionLayout
# 🔎 Fetching metadata for Kotlin/kotlin-koans-edu
# 🔎 Fetching metadata for lolo-io/OneList
# 🔎 Fetching metadata for cobeisfresh/CleanArchitecture-Android-Showcase
# 🔎 Fetching metadata for YvesCheung/EmojiReader
# 🔎 Fetching metadata for kuuuurt/rick-and-morty-app
# 🔎 Fetching metadata for ozh-dev/recycler-decorator-library-sample
# 🔎 Fetching metadata for minminaya/GenaralRoundLayout
# 🔎 Fetching metadata for MrNouri/DynamicSizes
# 🔎 Fetching metadata for MissMyDearBear/ScreenShotTools
# 🔎 Fetching metadata for open-jumpco/kfsm
# 🔎 Fetching metadata for qingtian521/MVVMDemo
# 🔎 Fetching metadata for trustwallet/wallet-connect-kotlin
# 🔎 Fetching metadata for bcgit/bc-kotlin
# 🔎 Fetching metadata for saeed-younus/motion-layout-examples
# 🔎 Fetching metadata for michaelbull/kotlin-inline-logger
# 🔎 Fetching metadata for sihaixuan/BoosterDemo
# 🔎 Fetching metadata for Dimezis/ShadowView
# 🔎 Fetching metadata for just-ai/aimybox-android-sdk
# 🔎 Fetching metadata for Krosxx/BottomDialog
# 🔎 Fetching metadata for svtk/AtomicKotlinCourse
# 🔎 Fetching metadata for webaddicted/KotlinProject
# 🔎 Fetching metadata for tuuzed/LightTunnel
# 🔎 Fetching metadata for hotstu/AutoSkeleton
# 🔎 Fetching metadata for fevziomurtekin/PayView
# 🔎 Fetching metadata for adrielcafe/hal
# 🔎 Fetching metadata for mtdhllf/RingProgressView
# 🔎 Fetching metadata for harmittaa/KoinExample
# 🔎 Fetching metadata for openrndr/openrndr-template
# 🔎 Fetching metadata for hsicen/HencoderPlus
# 🔎 Fetching metadata for mitchtabian/Kotlin-Coroutine-Examples
# 🔎 Fetching metadata for nlgtuankiet/mvrxpaged
# 🔎 Fetching metadata for OpenFlutter/rammus
# 🔎 Fetching metadata for sip3io/sip3-captain-ce
# 🔎 Fetching metadata for Bettehem/ts3-musicbot
# 🔎 Fetching metadata for karacca/beetle
# 🔎 Fetching metadata for TracyEminem/TikTokComment
# 🔎 Fetching metadata for gs-ts/TrackMyPath
# 🔎 Fetching metadata for Horizontal-org/Tella-Android
# 🔎 Fetching metadata for ellykits/neat-form
# 🔎 Fetching metadata for gdgistanbul/MeetupAttendee
# 🔎 Fetching metadata for JetBrains/jsitter
# 🔎 Fetching metadata for MindorksOpenSource/screenshot
# 🔎 Fetching metadata for SgtSilvio/android-retrofix
# 🔎 Fetching metadata for ssseasonnn/MobidMask
# 🔎 Fetching metadata for muramrr/roove
# 🔎 Fetching metadata for thellmund/droidcon-Berlin-2019-unofficial
# 🔎 Fetching metadata for bjornvester/xjc-gradle-plugin
# 🔎 Fetching metadata for luksoral/ExpandedMenuView
# 🔎 Fetching metadata for Yinzeyu/YMvRxAndroid
# 🔎 Fetching metadata for freddyfang/android-video-trimmer
# 🔎 Fetching metadata for javadev/LeetCode-in-Kotlin
# 🔎 Fetching metadata for ferPrieto/SoundLine
# 🔎 Fetching metadata for wealthfront/blend
# 🔎 Fetching metadata for rehmanmuradali/android-security-guides
# 🔎 Fetching metadata for mars-amn/Social-Note
# 🔎 Fetching metadata for ReactiveCircus/blueprint
# 🔎 Fetching metadata for michaldrabik/classicmaterialtimepicker
# 🔎 Fetching metadata for ddnosh/ARabbit
# 🔎 Fetching metadata for amrro/travelmantics
# 🔎 Fetching metadata for AntonPopoff/android-color-wheel
# 🔎 Fetching metadata for drewhamilton/InlineDimens
# 🔎 Fetching metadata for ConnectyCube/android-messenger-app
# 🔎 Fetching metadata for ionspin/kotlin-multiplatform-crypto
# 🔎 Fetching metadata for isfaaghyth/jetpack-movie
# 🔎 Fetching metadata for majorkik/MovieBox
# 🔎 Fetching metadata for Cleveroad/ARFaceDetection
# 🔎 Fetching metadata for fi3te/NotificationCron
# 🔎 Fetching metadata for timtbdev/Android-Portfolio-App-2
# 🔎 Fetching metadata for mouxuefei/MvvmModulePatternSample
# 🔎 Fetching metadata for natiginfo/QRScannerCameraX
# 📄 Fetching page 3 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 176 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-08-06T00:00:07Z → 2019-10-09T00:00:07Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 185
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 100 repos
# 🔎 Fetching metadata for android/compose-samples
# 🔎 Fetching metadata for mamoe/mirai
# 🔎 Fetching metadata for coil-kt/coil
# 🔎 Fetching metadata for gotson/komga
# 🔎 Fetching metadata for princekin-f/EasyFloat
# 🔎 Fetching metadata for liangjingkanji/BRV
# 🔎 Fetching metadata for liangjingkanji/Net
# 🔎 Fetching metadata for KasperskyLab/Kaspresso
# 🔎 Fetching metadata for Foso/Ktorfit
# 🔎 Fetching metadata for zhengcx/MethodTraceMan
# 🔎 Fetching metadata for gyf-dev/Cactus
# 🔎 Fetching metadata for icerockdev/moko-resources
# 🔎 Fetching metadata for michaldrabik/showly
# 🔎 Fetching metadata for icerockdev/moko-mvvm
# 🔎 Fetching metadata for SusionSuc/rabbit-client
# 🔎 Fetching metadata for kordlib/kord
# 🔎 Fetching metadata for skydoves/WhatIf
# 🔎 Fetching metadata for ReactiveCircus/FlowBinding
# 🔎 Fetching metadata for valentjn/ltex-ls
# 🔎 Fetching metadata for skydoves/ExpandableLayout
# 🔎 Fetching metadata for skydoves/ProgressView
# 🔎 Fetching metadata for DroidKaigi/conference-app-2020
# 🔎 Fetching metadata for akshay2211/BubbleTabBar
# 🔎 Fetching metadata for hegaojian/WanAndroid
# 🔎 Fetching metadata for angcyo/DslAdapter
# 🔎 Fetching metadata for liangjingkanji/StateLayout
# 🔎 Fetching metadata for jsoizo/kotlin-csv
# 🔎 Fetching metadata for ldlywt/FastJetpack
# 🔎 Fetching metadata for Chrisvin/RubberPicker
# 🔎 Fetching metadata for ZacSweers/MoshiX
# 🔎 Fetching metadata for LDRAlighieri/Corbind
# 🔎 Fetching metadata for SamAmco/track-and-graph
# 🔎 Fetching metadata for icerockdev/moko-permissions
# 🔎 Fetching metadata for OmneyaOsman/OnBoardingScreen
# 🔎 Fetching metadata for pandulapeter/beagle
# 🔎 Fetching metadata for jaiobs/OptiVideoEditor-for-android
# 🔎 Fetching metadata for skydoves/TheMovies2
# 🔎 Fetching metadata for android/identity-samples
# 🔎 Fetching metadata for skydoves/Rainbow
# 🔎 Fetching metadata for gradle-nexus/publish-plugin
# 🔎 Fetching metadata for android/enterprise-samples
# 🔎 Fetching metadata for Reedyuk/blue-falcon
# 🔎 Fetching metadata for SmartToolFactory/NavigationComponents-Tutorials
# 🔎 Fetching metadata for EssentialGG/Elementa
# 🔎 Fetching metadata for zedlabs/WallPortal
# 🔎 Fetching metadata for QuickBirdEng/SurveyKit
# 🔎 Fetching metadata for misosvec/SingleRowCalendar
# 🔎 Fetching metadata for AlexPl292/IdeaVim-EasyMotion
# 🔎 Fetching metadata for michaelbull/kotlin-retry
# 🔎 Fetching metadata for googlecreativelab/digital-wellbeing-experiments-toolkit
# 🔎 Fetching metadata for lppedd/idea-conventional-commit
# 🔎 Fetching metadata for 390057892/reader
# 🔎 Fetching metadata for waifu-motivator/waifu-motivator-plugin
# 🔎 Fetching metadata for B3nedikt/restring
# 🔎 Fetching metadata for rekabhq/background_locator
# 🔎 Fetching metadata for liangjingkanji/StatusBar
# 🔎 Fetching metadata for VlSomers/native-opencv-android-template
# 🔎 Fetching metadata for K1rakishou/Fuck-Storage-Access-Framework
# 🔎 Fetching metadata for streem/pbandk
# 🔎 Fetching metadata for appmattus/kotlinfixture
# 🔎 Fetching metadata for SusionSuc/DraggableImageViewer
# 🔎 Fetching metadata for JeroenMols/FeatureFlagExample
# 🔎 Fetching metadata for bolteu/screenshotty
# 🔎 Fetching metadata for pantasystem/Milktea
# 🔎 Fetching metadata for armcha/AutoLinkTextViewV2
# 🔎 Fetching metadata for yigit/ArtifactFinder
# 🔎 Fetching metadata for lordcodes/turtle
# 🔎 Fetching metadata for satishpatnayak/AndroGoat
# 🔎 Fetching metadata for exyte/replicating
# 🔎 Fetching metadata for BillyWei01/Udid
# 🔎 Fetching metadata for Almoullim/background_location
# 🔎 Fetching metadata for Koducation/AndroidCourse101
# 🔎 Fetching metadata for iamyours/Wandroid
# 🔎 Fetching metadata for apognu/otter
# 🔎 Fetching metadata for hitanshu-dhawan/SpannableStringParser
# 🔎 Fetching metadata for Trendyol/kediatR
# 🔎 Fetching metadata for ataulm/material-design-components-showcase
# 🔎 Fetching metadata for lopspower/GradientView
# 🔎 Fetching metadata for theodo-fintech/spring-search
# 🔎 Fetching metadata for americanexpress/busybee
# 🔎 Fetching metadata for nedimf/maildroid
# 🔎 Fetching metadata for maoqitian/Nice-Knowledge-System
# 🔎 Fetching metadata for ChatAir/ChatAir-android
# 🔎 Fetching metadata for leshchenko/CircularLayoutManager
# 🔎 Fetching metadata for zeshaoaaa/AppStarter
# 🔎 Fetching metadata for egeniq/android-tv-program-guide
# 🔎 Fetching metadata for FarshadTahmasbi/Vita
# 🔎 Fetching metadata for xfans/VoiceWaveView
# 🔎 Fetching metadata for Moosphan/MotionLayoutSamples
# 🔎 Fetching metadata for Isvisoft/flutter_screen_recording
# 🔎 Fetching metadata for gayanvoice/android-animations-kotlin
# 🔎 Fetching metadata for rubensousa/RecyclerViewNestedExample
# 🔎 Fetching metadata for sivze/SnapUI
# 🔎 Fetching metadata for Commit451/coil-transformations
# 🔎 Fetching metadata for bkhezry/earthquake
# 🔎 Fetching metadata for Cleveroad/BlurTutorial
# 🔎 Fetching metadata for alexjlockwood/android-lint-checks-demo
# 🔎 Fetching metadata for icerockdev/moko-network
# 🔎 Fetching metadata for mitchtabian/MVIExample
# 🔎 Fetching metadata for exigow/intellij-gdscript
# 📄 Fetching page 2 for [language:Kotlin]...
# ✅ Page 2: Retrieved 85 repos
# 🔎 Fetching metadata for jakubriegel/kotlin-shell
# 🔎 Fetching metadata for firofame/react-native-compass-heading
# 🔎 Fetching metadata for dengzii/WiFiADB
# 🔎 Fetching metadata for icerockdev/moko-media
# 🔎 Fetching metadata for RBusarow/Dispatch
# 🔎 Fetching metadata for mucahidkambur/tdk-sozluk
# 🔎 Fetching metadata for kibotu/geofencer
# 🔎 Fetching metadata for HeartPattern/MC-Remapper
# 🔎 Fetching metadata for theapache64/source-pilot
# 🔎 Fetching metadata for mertceyhan/Postman
# 🔎 Fetching metadata for plaid/plaid-link-android
# 🔎 Fetching metadata for KasperskyLab/AdbServer
# 🔎 Fetching metadata for dzirbel/kotify
# 🔎 Fetching metadata for ThibaultBee/srtdroid
# 🔎 Fetching metadata for alpheratzteam/obfuscator
# 🔎 Fetching metadata for kuuuurt/jokes-app-multiplatform
# 🔎 Fetching metadata for flutter-moum/flutter_screenshot_callback
# 🔎 Fetching metadata for allegro/envoy-control
# 🔎 Fetching metadata for vkay94/DoubleTapPlayerView
# 🔎 Fetching metadata for russhwolf/multiplatform-hello
# 🔎 Fetching metadata for cats-oss/android-tab-animation
# 🔎 Fetching metadata for hbb20/AndroidCountryPicker
# 🔎 Fetching metadata for kibotu/ParallaxScrollingView
# 🔎 Fetching metadata for Quillraven/Quilly-s-Adventure
# 🔎 Fetching metadata for icerockdev/mobile-multiplatform-gradle-plugin
# 🔎 Fetching metadata for wuyr/CoffeeDrawable
# 🔎 Fetching metadata for BilalSiddiqui/AddressPicker
# 🔎 Fetching metadata for zladnrms/RoundableLayout
# 🔎 Fetching metadata for developersancho/CleanArchitectureMVVM
# 🔎 Fetching metadata for JDevZone/FillProgressLayout
# 🔎 Fetching metadata for WangJie0822/SampleProject
# 🔎 Fetching metadata for joyceHong0524/socket.io_android
# 🔎 Fetching metadata for Tan-yi-xiong/Bangumi_Jetpack
# 🔎 Fetching metadata for pzienowicz/androidx-auto-scroll-view-pager
# 🔎 Fetching metadata for iammert/EasyMap
# 🔎 Fetching metadata for 979451341/WanIm
# 🔎 Fetching metadata for 0ranko0P/AutoDark
# 🔎 Fetching metadata for Khaos116/ABase
# 🔎 Fetching metadata for Lennoard/SysctlGUI
# 🔎 Fetching metadata for boyan01/flutter-music-player
# 🔎 Fetching metadata for nyavro/i18nPlugin
# 🔎 Fetching metadata for MediaModMC/MediaMod
# 🔎 Fetching metadata for erikc5000/island-time
# 🔎 Fetching metadata for mohamedebrahim96/ToDoListZIRO
# 🔎 Fetching metadata for sip3io/sip3-salto-ce
# 🔎 Fetching metadata for cafebazaar/Poolakey
# 🔎 Fetching metadata for camunda-community-hub/camunda-platform-7-rest-client-spring-boot
# 🔎 Fetching metadata for organization/KotlinInside
# 🔎 Fetching metadata for ekmett/cadenza
# 🔎 Fetching metadata for wwy863399246/WanAndroid
# 🔎 Fetching metadata for xing16/WanAndroid-Kotlin
# 🔎 Fetching metadata for swallowsonny/ConvertExt
# 🔎 Fetching metadata for dima74/intellij-indent-rainbow
# 🔎 Fetching metadata for rezaiyan/LevelProgressBar
# 🔎 Fetching metadata for tari-project/wallet-android
# 🔎 Fetching metadata for santalu/textmatcher
# 🔎 Fetching metadata for Jolanrensen/PermanentProxy-for-WearOS
# 🔎 Fetching metadata for gergelydaniel/kgl
# 🔎 Fetching metadata for fengzhizi715/Netty4Android
# 🔎 Fetching metadata for kerero/airdots-double-tap
# 🔎 Fetching metadata for GateOfTruth/OkSimple
# 🔎 Fetching metadata for Kieaer/Essentials
# 🔎 Fetching metadata for Ifxcyr/ActivityMessenger
# 🔎 Fetching metadata for IceCream-QAQ/Rain
# 🔎 Fetching metadata for Mishkun/Puerh
# 🔎 Fetching metadata for EssentialGG/Vigilance
# 🔎 Fetching metadata for iammert/Frames
# 🔎 Fetching metadata for anvilpowered/anvil
# 🔎 Fetching metadata for floschu/control
# 🔎 Fetching metadata for sip3io/sip3-commons
# 🔎 Fetching metadata for hamzaahmedkhan/SpinnerDialog
# 🔎 Fetching metadata for astrit-veliu/Smoolider
# 🔎 Fetching metadata for Techvisionbest/Weather
# 🔎 Fetching metadata for utsmannn/Recycling
# 🔎 Fetching metadata for wuyr/ActivityMessenger
# 🔎 Fetching metadata for waicool20/mr2tachiyomi
# 🔎 Fetching metadata for nicusX/kotlin-event-sourcing-example
# 🔎 Fetching metadata for hashlin/ConstraintFlowPlayground
# 🔎 Fetching metadata for Krosxx/retrofit-rest-client
# 🔎 Fetching metadata for mazenrashed/DotsIndicatorWithoutViewpager
# 🔎 Fetching metadata for revolut-mobile/RxData
# 🔎 Fetching metadata for mitchtabian/Kotlin-RecyclerView-Example
# 🔎 Fetching metadata for oxiadenine/kotlin-js-wrappers
# 🔎 Fetching metadata for FarshidRoohi/LineGraph
# 🔎 Fetching metadata for trieulh-ict/SimpleGenericAdapter
# 📄 Fetching page 3 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 185 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-10-09T00:00:08Z → 2019-12-12T00:00:08Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 167
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 100 repos
# 🔎 Fetching metadata for guolindev/PermissionX
# 🔎 Fetching metadata for vinaygaba/Learn-Jetpack-Compose-By-Example
# 🔎 Fetching metadata for MobileNativeFoundation/Store
# 🔎 Fetching metadata for Swordfish90/Lemuroid
# 🔎 Fetching metadata for Kotlin/kotlinx-datetime
# 🔎 Fetching metadata for ibrahimsn98/SmoothBottomBar
# 🔎 Fetching metadata for autonomousapps/dependency-analysis-gradle-plugin
# 🔎 Fetching metadata for kylecorry31/Trail-Sense
# 🔎 Fetching metadata for nikhilpanju/FabFilter
# 🔎 Fetching metadata for angcyo/DslTabLayout
# 🔎 Fetching metadata for xuhaoyang/ClashForAndroid
# 🔎 Fetching metadata for GitLiveApp/firebase-kotlin-sdk
# 🔎 Fetching metadata for zacharee/Tweaker
# 🔎 Fetching metadata for facebook/ktfmt
# 🔎 Fetching metadata for Kotlin-Android-Open-Source/MVI-Coroutines-Flow
# 🔎 Fetching metadata for JakeWharton/picnic
# 🔎 Fetching metadata for Chrisvin/LiquidSwipe
# 🔎 Fetching metadata for rt-bishop/Look4Sat
# 🔎 Fetching metadata for ZieIony/GuideToCustomViews
# 🔎 Fetching metadata for ferPrieto/SpaceX-prepare-for-Clean-Architecture-liftoff
# 🔎 Fetching metadata for aleyn97/MVVMLin
# 🔎 Fetching metadata for gabriel-TheCode/AestheticDialogs
# 🔎 Fetching metadata for vestrel00/contacts-android
# 🔎 Fetching metadata for ZahraHeydari/MusicPlayer
# 🔎 Fetching metadata for OJZen/QMD_Android
# 🔎 Fetching metadata for furkanaskin/Weatherapp
# 🔎 Fetching metadata for futuredapp/donut
# 🔎 Fetching metadata for ahinchman1/Kotlin-Compiler-Crash-Course
# 🔎 Fetching metadata for YarikSOffice/lingver
# 🔎 Fetching metadata for Chesire/Nekome
# 🔎 Fetching metadata for iammert/AppLocker
# 🔎 Fetching metadata for yasinkacmaz/jetflix
# 🔎 Fetching metadata for skydoves/IndicatorScrollView
# 🔎 Fetching metadata for ChiliLabs/ChiliPhotoPicker
# 🔎 Fetching metadata for arrow-kt/arrow-meta
# 🔎 Fetching metadata for icerockdev/moko-widgets
# 🔎 Fetching metadata for mutualmobile/Praxis
# 🔎 Fetching metadata for skydoves/DoubleLift
# 🔎 Fetching metadata for sanyuankexie/Flexml
# 🔎 Fetching metadata for Chrisvin/EasyReveal
# 🔎 Fetching metadata for skydoves/GoldMovies
# 🔎 Fetching metadata for Fraunhofer-AISEC/cpg
# 🔎 Fetching metadata for WaheedNazir/Kotlin-MVVM-Architecture
# 🔎 Fetching metadata for imknown/AndroidLowLevelDetector
# 🔎 Fetching metadata for Kotlin/kotlin-numpy
# 🔎 Fetching metadata for JorgeCastilloPrz/AndroidColorX
# 🔎 Fetching metadata for wasabeef/transformers
# 🔎 Fetching metadata for PunchThrough/ble-starter-android
# 🔎 Fetching metadata for amitshekhariitbhu/RxJava3-Android-Examples
# 🔎 Fetching metadata for BeksOmega/looping-layout
# 🔎 Fetching metadata for JetBrains/kotlin-compiler-server
# 🔎 Fetching metadata for idisfkj/AwesomeGithub
# 🔎 Fetching metadata for thetwom/Tuner
# 🔎 Fetching metadata for squti/Android-Wave-Recorder
# 🔎 Fetching metadata for jianjunxiao/wanandroid
# 🔎 Fetching metadata for mitchtabian/EspressoUITest-Examples
# 🔎 Fetching metadata for adriangl/pict2cam
# 🔎 Fetching metadata for tfcporciuncula/flow-preferences
# 🔎 Fetching metadata for twilio/twilio-video-app-android
# 🔎 Fetching metadata for iammert/TabScrollAttacher
# 🔎 Fetching metadata for Artraxon/unexBot
# 🔎 Fetching metadata for jarroyoesp/KotlinMultiplatform_MVVM
# 🔎 Fetching metadata for cgisca/PGSGP
# 🔎 Fetching metadata for google/prefab
# 🔎 Fetching metadata for fmeum/WearAuthn
# 🔎 Fetching metadata for muigukenneth/ElegantDialog
# 🔎 Fetching metadata for Trendyol/android-ui-components
# 🔎 Fetching metadata for LSafer/edgeseek
# 🔎 Fetching metadata for utsmannn/Kemana
# 🔎 Fetching metadata for capacitor-community/stripe
# 🔎 Fetching metadata for OPN48/M3U8Downloader
# 🔎 Fetching metadata for thedarkcolour/KotlinForForge
# 🔎 Fetching metadata for ImaginativeShohag/Oops-No-Internet
# 🔎 Fetching metadata for wuyr/SecondFloorBehavior
# 🔎 Fetching metadata for LikeTheSalad/android-stem
# 🔎 Fetching metadata for DataDog/dd-sdk-android
# 🔎 Fetching metadata for alpas/alpas
# 🔎 Fetching metadata for nhat-phan/merge-request-integration
# 🔎 Fetching metadata for skydoves/Flourish
# 🔎 Fetching metadata for bennyhuo/CoroutineLite
# 🔎 Fetching metadata for guolindev/SunnyWeather
# 🔎 Fetching metadata for Banno/Gordon
# 🔎 Fetching metadata for hyzhan43/KtArmor-MVVM
# 🔎 Fetching metadata for yetel/EasyChatAndroidClient
# 🔎 Fetching metadata for Chrisvin/FlipTabs
# 🔎 Fetching metadata for ichenhe/QQ-Notify-Evolution
# 🔎 Fetching metadata for OpenSooq/Gligar
# 🔎 Fetching metadata for dtmilano/CulebraTester2-public
# 🔎 Fetching metadata for corbella83/PopKorn
# 🔎 Fetching metadata for drmfinlay/tts-util-app
# 🔎 Fetching metadata for jeziellago/FlowNav
# 🔎 Fetching metadata for droidknights/DroidKnights2020_App
# 🔎 Fetching metadata for enginebai/AndroidBase
# 🔎 Fetching metadata for gemgao/redenvelopes
# 🔎 Fetching metadata for TheCosmoNomad/WhatsDeleted
# 🔎 Fetching metadata for CottaCush/HiddenCam
# 🔎 Fetching metadata for qonversion/android-sdk
# 🔎 Fetching metadata for OpenTracksApp/OSMDashboard
# 🔎 Fetching metadata for droidconKE/droidconKE2020App
# 🔎 Fetching metadata for WalrusSoup/Tailwind-Formatter
# 📄 Fetching page 2 for [language:Kotlin]...
# ✅ Page 2: Retrieved 67 repos
# 🔎 Fetching metadata for liangjingkanji/Tooltip
# 🔎 Fetching metadata for InsanusMokrassar/krontab
# 🔎 Fetching metadata for dzolnai/ExoVisualizer
# 🔎 Fetching metadata for madreain/AACHulk
# 🔎 Fetching metadata for n8ebel/GitHubActionsAutomationSandbox
# 🔎 Fetching metadata for kanch231004/News-Feed
# 🔎 Fetching metadata for 7hens/android-x2j
# 🔎 Fetching metadata for line/feature-flag-android
# 🔎 Fetching metadata for cv-project-app/common-voice-app
# 🔎 Fetching metadata for MyEtherWallet/mew-wallet-android-kit
# 🔎 Fetching metadata for sjjeong/SimpleRecyclerView
# 🔎 Fetching metadata for savepopulation/oyster
# 🔎 Fetching metadata for ppicas/flutter-android-background
# 🔎 Fetching metadata for Akilesh-T/ACC
# 🔎 Fetching metadata for amirisback/frogo-admob
# 🔎 Fetching metadata for israel-fl/bitmap2video
# 🔎 Fetching metadata for sourcegraph/scip-java
# 🔎 Fetching metadata for songlongGithub/scoped_storage_sample
# 🔎 Fetching metadata for liangjingkanji/LogCat
# 🔎 Fetching metadata for line/gradle-multi-project-support
# 🔎 Fetching metadata for tangem/tangem-sdk-android
# 🔎 Fetching metadata for arifnadeem7/mvvmcoroutinesandflow
# 🔎 Fetching metadata for rakutentech/android-miniapp
# 🔎 Fetching metadata for ErickSumargo/Drivety
# 🔎 Fetching metadata for pankaj89/MasterExoPlayer
# 🔎 Fetching metadata for iTaysonLab/HomeFeeder
# 🔎 Fetching metadata for kenneycode/fusion
# 🔎 Fetching metadata for icerockdev/moko-graphics
# 🔎 Fetching metadata for MalekKamel/AppHead
# 🔎 Fetching metadata for RedMadRobot/flipper
# 🔎 Fetching metadata for enefce/AndroidLibraryForGitHubPackagesDemo
# 🔎 Fetching metadata for instamobile/kotlin-firebase
# 🔎 Fetching metadata for shuguoli68/LiSeetaFace2
# 🔎 Fetching metadata for ImaginativeShohag/Simple-MVVM
# 🔎 Fetching metadata for mnayef95/Android-Weekly
# 🔎 Fetching metadata for icerockdev/moko-parcelize
# 🔎 Fetching metadata for sdeleuze/spring-messenger
# 🔎 Fetching metadata for LFDT-web3j/web3j-evm
# 🔎 Fetching metadata for StefMa/KotlinMultiplatformTemplate
# 🔎 Fetching metadata for TypeError/Bookmarks
# 🔎 Fetching metadata for jenly1314/ImageViewer
# 🔎 Fetching metadata for ShowMeThe/WanAndroid
# 🔎 Fetching metadata for ErikHellman/InstantSearchDemo
# 🔎 Fetching metadata for coder-pig/StealInterestingCode
# 🔎 Fetching metadata for JetBrains/Rplugin
# 🔎 Fetching metadata for philipplackner/MVVMShoppingList
# 🔎 Fetching metadata for doneservices/flutter_callkeep
# 🔎 Fetching metadata for Brain-up/brn
# 🔎 Fetching metadata for Atr07/drawer-with-bottom-navigation-architecture
# 🔎 Fetching metadata for code42/pipelinekt
# 🔎 Fetching metadata for MalekKamel/RxRequester
# 🔎 Fetching metadata for nickyrabit/StarbucksCoffeeJetpackComposeUI
# 🔎 Fetching metadata for utsmannn/SmartMarker
# 🔎 Fetching metadata for rumboalla/coolrs
# 🔎 Fetching metadata for fahadnasrullah109/Android-MVVM-with-Retrofit
# 🔎 Fetching metadata for MohammadSianaki/Retrofit2-Flow-Call-Adapter
# 🔎 Fetching metadata for paramsen/Keigen
# 🔎 Fetching metadata for devendroid/MapDrawingManager
# 🔎 Fetching metadata for faob-dev/MotionLayoutExamples
# 🔎 Fetching metadata for DevSrSouza/EventKt
# 🔎 Fetching metadata for PsHegger/recycleradapter-generator
# 🔎 Fetching metadata for BharathVishal/Message-communication-using-Wearable-Data-Layer-for-Android-Wear-OS
# 🔎 Fetching metadata for popovbodya/Garbage-collector
# 🔎 Fetching metadata for sabujak-sabujak/ShyShark
# 🔎 Fetching metadata for AgnaldoNP/PreviewImageCollection
# 🔎 Fetching metadata for natura-cosmeticos/natds-android
# 🔎 Fetching metadata for enzoftware/android_iptv
# 📄 Fetching page 3 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 167 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2019-12-12T00:00:09Z → 2020-02-14T00:00:09Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 166
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 100 repos
# 🔎 Fetching metadata for yujincheng08/BiliRoaming
# 🔎 Fetching metadata for simplex-chat/simplex-chat
# 🔎 Fetching metadata for KotatsuApp/Kotatsu
# 🔎 Fetching metadata for z-huang/InnerTune
# 🔎 Fetching metadata for JetBrains/intellij-platform-plugin-template
# 🔎 Fetching metadata for hegaojian/JetpackMvvm
# 🔎 Fetching metadata for joreilly/PeopleInSpace
# 🔎 Fetching metadata for touchlab/KaMPKit
# 🔎 Fetching metadata for mollyim/mollyim-android
# 🔎 Fetching metadata for CCBlueX/LiquidBounce
# 🔎 Fetching metadata for feelfreelinux/octo4a
# 🔎 Fetching metadata for mrcsxsiq/Kotlin-Pokedex
# 🔎 Fetching metadata for LuckyPray/XAutoDaily
# 🔎 Fetching metadata for skydoves/PowerSpinner
# 🔎 Fetching metadata for realm/realm-kotlin
# 🔎 Fetching metadata for meshtastic/Meshtastic-Android
# 🔎 Fetching metadata for MindorksOpenSource/Kotlin-Flow-Android-Examples
# 🔎 Fetching metadata for Kotlin/binary-compatibility-validator
# 🔎 Fetching metadata for AndroidCoderPeng/DailyTask
# 🔎 Fetching metadata for Spikeysanju/ZoomRecylerLayout
# 🔎 Fetching metadata for square/cycler
# 🔎 Fetching metadata for zsoltk/compose-pokedex
# 🔎 Fetching metadata for mayokunadeniyi/Instant-Weather
# 🔎 Fetching metadata for zhpanvip/viewpagerindicator
# 🔎 Fetching metadata for lucasnlm/antimine-android
# 🔎 Fetching metadata for jwstegemann/fritz2
# 🔎 Fetching metadata for odaridavid/Clean-MVVM-ArchComponents
# 🔎 Fetching metadata for zsoltk/compose-router
# 🔎 Fetching metadata for jraska/modules-graph-assert
# 🔎 Fetching metadata for ImaginativeShohag/Why-Not-Image-Carousel
# 🔎 Fetching metadata for bannedbook/v2ray.vpn
# 🔎 Fetching metadata for hitherejoe/minimise
# 🔎 Fetching metadata for noxone/regex-generator
# 🔎 Fetching metadata for avito-tech/avito-android
# 🔎 Fetching metadata for vipulasri/JetDelivery
# 🔎 Fetching metadata for Cuberto/liquid-swipe-android
# 🔎 Fetching metadata for liangjingkanji/Channel
# 🔎 Fetching metadata for 5A59/SketchyComponent
# 🔎 Fetching metadata for FunnySaltyFish/FunnyTranslation
# 🔎 Fetching metadata for skydoves/lazybones
# 🔎 Fetching metadata for tonybaloney/pycharm-security
# 🔎 Fetching metadata for Kotlin/kotlin-script-examples
# 🔎 Fetching metadata for marcellogalhardo/retained
# 🔎 Fetching metadata for anyascii/anyascii
# 🔎 Fetching metadata for Kotlin/kotlinx-knit
# 🔎 Fetching metadata for lopspower/RateBottomSheet
# 🔎 Fetching metadata for Dhaval2404/ColorPicker
# 🔎 Fetching metadata for phodal/chapi
# 🔎 Fetching metadata for igreenwood/loupe
# 🔎 Fetching metadata for HeyAlex/CornerSheet
# 🔎 Fetching metadata for utopia-rise/godot-kotlin-native
# 🔎 Fetching metadata for navikt/mock-oauth2-server
# 🔎 Fetching metadata for zend10/AL-chan
# 🔎 Fetching metadata for sokomishalov/skraper
# 🔎 Fetching metadata for slackhq/keeper
# 🔎 Fetching metadata for AndyJennifer/AndroidxLazyLoad
# 🔎 Fetching metadata for TouK/krush
# 🔎 Fetching metadata for davidepianca98/KMQTT
# 🔎 Fetching metadata for haroldadmin/WhatTheStack
# 🔎 Fetching metadata for ArcanePlugins/LevelledMobs
# 🔎 Fetching metadata for csicar/Ning
# 🔎 Fetching metadata for yoobi/exoplayer-kotlin
# 🔎 Fetching metadata for cliuff/boundo
# 🔎 Fetching metadata for GetStream/WhatsApp-Clone-Android
# 🔎 Fetching metadata for funnywolfdadada/HollowKit
# 🔎 Fetching metadata for transferwise/banks-reference-android
# 🔎 Fetching metadata for xmuSistone/PersistentCoordinatorLayout
# 🔎 Fetching metadata for gaelmarhic/Quadrant
# 🔎 Fetching metadata for icerockdev/moko-geo
# 🔎 Fetching metadata for SimformSolutionsPvtLtd/SSCustomEditTextOutLineBorder
# 🔎 Fetching metadata for vinnypessoni/api-clientes-exemplo-microservico
# 🔎 Fetching metadata for cjbooms/fabrikt
# 🔎 Fetching metadata for vmiklos/plees-tracker
# 🔎 Fetching metadata for gotev/android-cookie-store
# 🔎 Fetching metadata for YZune/CourseAdapter
# 🔎 Fetching metadata for AlexZhukovich/CoffeeDrinksWithJetpackCompose
# 🔎 Fetching metadata for bardss/PaintableVectorView
# 🔎 Fetching metadata for sergpetrov/telegraph-android
# 🔎 Fetching metadata for dkter/aaaaa
# 🔎 Fetching metadata for amirisback/frogo-recycler-view
# 🔎 Fetching metadata for JLindemann42/Atomic-Periodic-Table.Android
# 🔎 Fetching metadata for jhbxyz/WanAndroidJetpack
# 🔎 Fetching metadata for open-toast/protokt
# 🔎 Fetching metadata for Benjamin-Dobell/IntelliJ-Luanalysis
# 🔎 Fetching metadata for springdoc/springdoc-openapi-gradle-plugin
# 🔎 Fetching metadata for Kotlin/kotlinx-browser
# 🔎 Fetching metadata for specialprojects-experiments/envelope
# 🔎 Fetching metadata for TobseF/Candy-Crush-Clone
# 🔎 Fetching metadata for PHELAT/Tedu
# 🔎 Fetching metadata for kotlin-hands-on/web-app-react-kotlin-js-gradle
# 🔎 Fetching metadata for Urdzik/MovieApp
# 🔎 Fetching metadata for B3nedikt/AppLocale
# 🔎 Fetching metadata for Slava0135/reVision
# 🔎 Fetching metadata for lopspower/Biometric
# 🔎 Fetching metadata for fgiris/LiveDataWithFlowSample
# 🔎 Fetching metadata for jtouzy/Kompose
# 🔎 Fetching metadata for andrewjapar/rangedatepicker
# 🔎 Fetching metadata for PatilShreyas/FCM-OnDeviceNotificationScheduler
# 🔎 Fetching metadata for oneHamidreza/Meow-Framework-MVVM
# 🔎 Fetching metadata for jiangyuanyuan/Multi
# 📄 Fetching page 2 for [language:Kotlin]...
# ✅ Page 2: Retrieved 66 repos
# 🔎 Fetching metadata for tejpratap46/RecyclerCalendarAndroid
# 🔎 Fetching metadata for spigradle/spigradle
# 🔎 Fetching metadata for cianru/huawei-appgallery-publish-gradle-plugin
# 🔎 Fetching metadata for zacharee/OneUITunerRedesign
# 🔎 Fetching metadata for xyoye/ComicTools
# 🔎 Fetching metadata for mattprecious/protogram
# 🔎 Fetching metadata for kidozh/DiscuzHub
# 🔎 Fetching metadata for Mustafashahoud/MoviesApp
# 🔎 Fetching metadata for wix-incubator/codio
# 🔎 Fetching metadata for sreeharikv112/CleanCodeMVVMTesting
# 🔎 Fetching metadata for tuProlog/2p-kt
# 🔎 Fetching metadata for stars-one/M3u8Downloader
# 🔎 Fetching metadata for chris-horner/SocketWeather
# 🔎 Fetching metadata for RohitSurwase/AAC-MVI-Architecture
# 🔎 Fetching metadata for Drjacky/TMDbMultiplatform
# 🔎 Fetching metadata for pqpo/AIPoet
# 🔎 Fetching metadata for icerockdev/moko-maps
# 🔎 Fetching metadata for adaptyteam/AdaptySDK-Android
# 🔎 Fetching metadata for realpacific/algorithms
# 🔎 Fetching metadata for mike5v/viewmore-textview
# 🔎 Fetching metadata for OpenMined/KotlinSyft
# 🔎 Fetching metadata for ibrahimsn98/CirclesLoadingView
# 🔎 Fetching metadata for uzzu/dotenv-gradle
# 🔎 Fetching metadata for egorovandreyrm/pcap-remote
# 🔎 Fetching metadata for gardenappl/mitch
# 🔎 Fetching metadata for AmosKorir/AvatarImageGenerator
# 🔎 Fetching metadata for noonmaru/psychics
# 🔎 Fetching metadata for iambaljeet/VideoPreLoading
# 🔎 Fetching metadata for anoop44/AwesomeTextInputLayout
# 🔎 Fetching metadata for discospiff/MyPlantDiaryQ
# 🔎 Fetching metadata for ThanosFisherman/BlueFlow
# 🔎 Fetching metadata for mitchtabian/DaggerMultiFeature
# 🔎 Fetching metadata for 14v/svg-non-stop
# 🔎 Fetching metadata for ReactiveCircus/streamlined
# 🔎 Fetching metadata for flipkart-incubator/madman-android
# 🔎 Fetching metadata for newbiechen1024/NBReader
# 🔎 Fetching metadata for LGD2009/LivePermissions
# 🔎 Fetching metadata for polygon-io/client-jvm
# 🔎 Fetching metadata for ssseasonnn/Bracer
# 🔎 Fetching metadata for Tribler/kotlin-ipv8
# 🔎 Fetching metadata for wisdomtl/FloatWindow
# 🔎 Fetching metadata for mejdi14/BooksSwipe
# 🔎 Fetching metadata for debop/kotlin-design-patterns
# 🔎 Fetching metadata for Mania-Visualization-Project/Mania-Replay-Master
# 🔎 Fetching metadata for qdsfdhvh/DanDanPlayForTVPersonal
# 🔎 Fetching metadata for camunda-community-hub/zeeqs
# 🔎 Fetching metadata for yaraki/AnimateIt
# 🔎 Fetching metadata for LiteKite/Android-SystemUI
# 🔎 Fetching metadata for hashlin/ComposeDataTable
# 🔎 Fetching metadata for sip3io/sip3-twig-ce
# 🔎 Fetching metadata for anvilpowered/catalyst
# 🔎 Fetching metadata for onecode369/WYSIWYG
# 🔎 Fetching metadata for farmerbb/AppNotifier
# 🔎 Fetching metadata for Stvad/FuzzyDate
# 🔎 Fetching metadata for gilgoldzweig/MotionLayoutExample
# 🔎 Fetching metadata for microsoft/VerifiableCredential-SDK-Android
# 🔎 Fetching metadata for char/noverify-hackery
# 🔎 Fetching metadata for happysingh23828/HappyTimer
# 🔎 Fetching metadata for wajahatkarim3/BottomNavArchDemo
# 🔎 Fetching metadata for pg598595/ScopedStorageDemo
# 🔎 Fetching metadata for turansky/kfc-plugins
# 🔎 Fetching metadata for hasancse91/weather-app-android-mvvm
# 🔎 Fetching metadata for xmlking/micro-apps
# 🔎 Fetching metadata for Tc2r1/Dev_Interview_Prep_App
# 🔎 Fetching metadata for Semper-Viventem/RoundedBackgroundSpan
# 🔎 Fetching metadata for mobilepicpay/desafio-android
# 📄 Fetching page 3 for [language:Kotlin]...
# 📭 No more items.
# 💾 Saved 166 new repos to CSV
#
# 🔍 Window for [language:Kotlin]: 2020-02-14T00:00:10Z → 2020-04-18T00:00:10Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 229
# 📄 Fetching page 1 for [language:Kotlin]...
# ✅ Page 1: Retrieved 100 repos
# 🔎 Fetching metadata for florisboard/florisboard
# 🔎 Fetching metadata for androidx/androidx
# 🔎 Fetching metadata for LibChecker/LibChecker
# 🔎 Fetching metadata for LukasLechnerDev/Kotlin-Coroutines-and-Flow-UseCases-on-Android
# 🔎 Fetching metadata for skydoves/TransformationLayout
# 🔎 Fetching metadata for PatilShreyas/Foodium
# 🔎 Fetching metadata for cortinico/kotlin-android-template
# 🔎 Fetching metadata for Fate-Grand-Automata/FGA
# 🔎 Fetching metadata for project-mirai/mirai-api-http
# 🔎 Fetching metadata for amitshekhariitbhu/ridesharing-uber-lyft-app
# 🔎 Fetching metadata for Kotlin/kotlindl
# 🔎 Fetching metadata for plateaukao/einkbro
# 🔎 Fetching metadata for Spikeysanju/MotionToast
# 🔎 Fetching metadata for skydoves/DisneyMotions
# 🔎 Fetching metadata for Droppers/AnimatedBottomBar
# 🔎 Fetching metadata for tailscale/tailscale-android
# 🔎 Fetching metadata for grpc/grpc-kotlin
# 🔎 Fetching metadata for skydoves/MarvelHeroes
# 🔎 Fetching metadata for loper7/DateTimePicker
# 🔎 Fetching metadata for fornewid/neumorphism
# 🔎 Fetching metadata for m-i-n-a-r/birday
# 🔎 Fetching metadata for halilozercan/compose-richtext
# ...
# 🔎 Fetching metadata for skydoves/kmp-developer-roadmap
# 🔎 Fetching metadata for aws-samples/swift-chat
# 🔎 Fetching metadata for DevLARLEY/WidevineProxy2
# 🔎 Fetching metadata for risin42/NagramX
# 🔎 Fetching metadata for InputShare/InputShare
# 🔎 Fetching metadata for OSU-NLP-Group/GUI-Agents-Paper-List
# 🔎 Fetching metadata for shubham0204/SmolChat-Android
# 🔎 Fetching metadata for ranpox/awesome-computer-use
# 🔎 Fetching metadata for connet-dev/connet
# 🔎 Fetching metadata for nini22P/iris
# 🔎 Fetching metadata for lscambo13/ElegantFin
# 🔎 Fetching metadata for stevendborrelli/bluesky-tech-starter-packs
# 🔎 Fetching metadata for djylb/nps
# 🔎 Fetching metadata for catpuppyapp/PuppyGit
# 🔎 Fetching metadata for open-vela/docs
# 🔎 Fetching metadata for saulamsal/apple-music-sheet-ui
# 🔎 Fetching metadata for aniruddha-adhikary/mrt-buddy
# 🔎 Fetching metadata for android/xr-samples
# 🔎 Fetching metadata for saulamsal/apple-news-ui
# 🔎 Fetching metadata for TJYSunset/Phocid
# 🔎 Fetching metadata for zwc456baby/ScrcpyForAndroid
# 🔎 Fetching metadata for askui/vision-agent
# 🔎 Fetching metadata for xlang-ai/aguvis
# 🔎 Fetching metadata for xmexg/xyks
# 🔎 Fetching metadata for join-the-flock/flock
# 🔎 Fetching metadata for PhilKes/NotallyX
# 🔎 Fetching metadata for maxwai/NClientV3
# 🔎 Fetching metadata for zanjie1999/meDisplay
# 🔎 Fetching metadata for supershadoe/delta
# 🔎 Fetching metadata for session-foundation/session-android
# 🔎 Fetching metadata for tunjid/heron
# 🔎 Fetching metadata for wxxsfxyzm/InstallerX-Revived
# 🔎 Fetching metadata for dn0ne/lotus
# 🔎 Fetching metadata for igatha/flare-gun
# 🔎 Fetching metadata for reveny/Android-VBMeta-Fixer
# 🔎 Fetching metadata for winebox64/winlator
# 🔎 Fetching metadata for maplibre/maplibre-compose
# 🔎 Fetching metadata for ProtocolScience/AstralGocq
# 🔎 Fetching metadata for liuzq2002/Adguard-Home-For-Magisk-Mod
# 🔎 Fetching metadata for tosinonikute/NotelyVoice
# 🔎 Fetching metadata for Freedom-Guard/Freedom-Guard
# 🔎 Fetching metadata for secureworks/pytune
# 🔎 Fetching metadata for philipplackner/CMP-Bookpedia
# 🔎 Fetching metadata for sinspired/cnNetTool
# 🔎 Fetching metadata for namanh11611/flutter_mvvm_riverpod
# 🔎 Fetching metadata for RichardLuo0/global-icon-pack-android
# 🔎 Fetching metadata for dedsec1121fk/DedSec
# 🔎 Fetching metadata for MakersFunDuck/humidity-temperature-sensor-TH05F
# 🔎 Fetching metadata for SohelIslamImran/expo-in-app-updates
# 🔎 Fetching metadata for khaled-0/Syncara
# 🔎 Fetching metadata for ente0/hashCrack
# 🔎 Fetching metadata for kagg886/Pixiv-MultiPlatform
# 🔎 Fetching metadata for Alan-Rock-GS/GpuScript
# 🔎 Fetching metadata for cnwikee/CheckTMDB
# 🔎 Fetching metadata for hsa00000/Urocissa
# 🔎 Fetching metadata for Tweener/alarmee
# 🔎 Fetching metadata for danmindru/rare-big-deal
# 🔎 Fetching metadata for ifokeev/awesome-copilots
# 🔎 Fetching metadata for Sgyling/Free-proxy-pool
# 📄 Fetching page 2 for [android:keyword]...
# ✅ Page 2: Retrieved 100 repos
# 🔎 Fetching metadata for Luboy23/foundry_advanced_turtorial
# 🔎 Fetching metadata for icylian/MDPings
# 🔎 Fetching metadata for Rezivure/Grid-Mobile
# 🔎 Fetching metadata for nianticlabs/mvsanywhere
# 🔎 Fetching metadata for NRTnarathip/SMAPILoader
# 🔎 Fetching metadata for ismai117/KScan
# 🔎 Fetching metadata for LightQuanta/BiliResourceDownloader
# 🔎 Fetching metadata for sergeylappo/boox-rapid-draw
# 🔎 Fetching metadata for RockinChaos/Shiru
# 🔎 Fetching metadata for cinit/LibcoreSyscall
# 🔎 Fetching metadata for shahriarsajeeb/Becodemy-Mobile-App
# 🔎 Fetching metadata for vyokky/LLM-Brained-GUI-Agents-Survey
# 🔎 Fetching metadata for andrew-levy/jetpack-compose-react-native
# 🔎 Fetching metadata for ugurkocde/IntuneBrew
# 🔎 Fetching metadata for travisvn/obsidian-edge-tts
# 🔎 Fetching metadata for zebangeth/ai-closet
# 🔎 Fetching metadata for sakarie9/BiliRoamingM
# 🔎 Fetching metadata for Fredolx/open-tv-mobile
# 🔎 Fetching metadata for takushun-wu/WenYuanFonts
# 🔎 Fetching metadata for jtun-coder/JtunRouter
# 🔎 Fetching metadata for dev-Ali2008/xanite
# 🔎 Fetching metadata for EasyDarwin/EasyPlayer.js
# 🔎 Fetching metadata for Pixel-Props/sensitive-props
# 🔎 Fetching metadata for ibrahimcetin/reins
# 🔎 Fetching metadata for bipark/my_ollama_app
# 🔎 Fetching metadata for AumGupta/KWGT-Widgets
# 🔎 Fetching metadata for ArisGuimera/Windows95KMP
# 🔎 Fetching metadata for rajmani7584/Payload-Dumper-Android
# 🔎 Fetching metadata for navaismo/Ender-3V3-SE
# 🔎 Fetching metadata for zouyee/zig-learning
# 🔎 Fetching metadata for bytedance/BlockFramework
# 🔎 Fetching metadata for chinavpns/router-vpn
# 🔎 Fetching metadata for In3tinct/Androidmeda
# 🔎 Fetching metadata for AvenCores/goida-vpn-configs
# 🔎 Fetching metadata for liuk7071/ChonkyStation3
# 🔎 Fetching metadata for prathameshkhade/SysAdmin
# 🔎 Fetching metadata for galaxy-s10/billd-desk-server
# 🔎 Fetching metadata for WildKernels/OnePlus_KernelSU_SUSFS
# 🔎 Fetching metadata for jfversluis/built-with-maui
# 🔎 Fetching metadata for TouchController/TouchController
# 🔎 Fetching metadata for zach-klippenstein/constraints-explorer
# 🔎 Fetching metadata for AnyPortal/AnyPortal
# 🔎 Fetching metadata for vipulasri/aspecto
# 🔎 Fetching metadata for jakubvalenta/geoshare
# 🔎 Fetching metadata for osamaqarem/drag-select
# 🔎 Fetching metadata for pandulapeter/kubriko
# 🔎 Fetching metadata for xtfjt1988/learn-tech
# 🔎 Fetching metadata for meta-quest/webxr-first-steps-react
# 🔎 Fetching metadata for boybeak/skb-global
# 🔎 Fetching metadata for FFTAI/teleoperation
# 🔎 Fetching metadata for RustNSparks/sockudo
# 🔎 Fetching metadata for Katana-O/MobileGamePenetrationTestingFramework
# 🔎 Fetching metadata for Ivy-Apps/android-guidebook
# 🔎 Fetching metadata for ImMALWARE/zapret-magisk
# 🔎 Fetching metadata for animate-react-native/accordion
# 🔎 Fetching metadata for yshmarov/hotwire_native_rails
# 🔎 Fetching metadata for GoodyOG/Iceraven-OLED
# 🔎 Fetching metadata for Hunterdii/TryHackMe-Roadmap
# 🔎 Fetching metadata for Galaxies-dev/todoist-clone-react-native
# 🔎 Fetching metadata for List-KR/tinyShield
# 🔎 Fetching metadata for V2hiddify/HiddifyWithPanels
# 🔎 Fetching metadata for Darkx-dev/ShonenX
# 🔎 Fetching metadata for schott12521/compose-cupertino
# 🔎 Fetching metadata for typeconf/typeconf
# 🔎 Fetching metadata for trend-ui/trendui-react-native
# 🔎 Fetching metadata for abshare3/abshare3.github.io
# 🔎 Fetching metadata for GetStream/ai-chat-android
# 🔎 Fetching metadata for peditx/EZpasswall
# 🔎 Fetching metadata for paufau/react-native-multiple-modals
# 🔎 Fetching metadata for cygnusx-1-org/Slide
# 🔎 Fetching metadata for christianbaroni/react-native-turbo-haptics
# 🔎 Fetching metadata for Dev0ke/angr-java
# 🔎 Fetching metadata for chinavpns/chatgpt-plus
# 🔎 Fetching metadata for manio/aa-proxy-rs
# 🔎 Fetching metadata for donkuri/japanese-resources
# 🔎 Fetching metadata for drbarzaga/React-Toolkit
# 🔎 Fetching metadata for trakt/trakt-lite
# 🔎 Fetching metadata for xvnpw/ai-security-analyzer
# 🔎 Fetching metadata for nyeinkokoaung404/V2ray-Configs
# 🔎 Fetching metadata for JingMatrix/Demo
# 🔎 Fetching metadata for Tweener/passage
# 🔎 Fetching metadata for hangga/delvelin
# 🔎 Fetching metadata for erosman/firemonkey
# 🔎 Fetching metadata for VentralDigital/InterProfileSharing
# 🔎 Fetching metadata for hardenedlinux/userland-exec
# 🔎 Fetching metadata for nieheyong/logcat-in-devtools
# 🔎 Fetching metadata for qamarelsafadi/JetpackComposeTracker
# 🔎 Fetching metadata for denglongfei/activityGuard
# 🔎 Fetching metadata for erfanmola/TMA-Studio
# 🔎 Fetching metadata for dermv/marzbanify-template
# 🔎 Fetching metadata for Staacks/alpharemote
# 🔎 Fetching metadata for MeoMunDep/Automatic-Ultimate-Create-Wallets-for-Airdrop
# 🔎 Fetching metadata for umutcamliyurt/MockTraffic
# 🔎 Fetching metadata for avoylenko/wwebjs-api
# 🔎 Fetching metadata for Raphael-Boichot/The-TinyGB-Printer
# 🔎 Fetching metadata for ericclemmons/awesome-starter-packs
# 🔎 Fetching metadata for shubhamsinghshubham777/KHealth
# 🔎 Fetching metadata for MnlPhlp/tauri-plugin-blec
# 🔎 Fetching metadata for ikoyhn/clean-cast
# 🔎 Fetching metadata for kukuqi666/TVBoxOS-Mobile
# 📄 Fetching page 3 for [android:keyword]...
# ✅ Page 3: Retrieved 68 repos
# 🔎 Fetching metadata for yynag/edge-tts-android
# 🔎 Fetching metadata for Ericcsr/ARCap
# 🔎 Fetching metadata for xiaotujinbnb/QBDI_trace_demo
# 🔎 Fetching metadata for MLSZHU/LLMSafetyBenchmark
# 🔎 Fetching metadata for fleeksoft/fleeksoft-io
# 🔎 Fetching metadata for OpenMined/30DaysOfFLCode
# 🔎 Fetching metadata for KAppMaker/KMPDevicePreview
# 🔎 Fetching metadata for vfdeclnc/panda-vpn-pro
# 🔎 Fetching metadata for DonBraulio/tuneo
# 🔎 Fetching metadata for RaffaDNDM/HacknDroid
# 🔎 Fetching metadata for AxellNetwork/NekoBot
# 🔎 Fetching metadata for nativeapptemplate/NativeAppTemplate-Free-iOS
# 🔎 Fetching metadata for VidraProject/Vidra-Project
# 🔎 Fetching metadata for Preloading/TwitterAPIBridge
# 🔎 Fetching metadata for morrownr/rtl8852bu-20240418
# 🔎 Fetching metadata for gmankab/waydroid
# 🔎 Fetching metadata for RuriOSS/asl
# 🔎 Fetching metadata for Aurora-Nasa-1/ARMIAS
# 🔎 Fetching metadata for Bhuvaneshw/PdfViewer
# 🔎 Fetching metadata for mrwm/QRshare
# 🔎 Fetching metadata for ChunhThanhDe/cinema-booking
# 🔎 Fetching metadata for Magisk-Modules-Alt-Repo/Xtreme-Battery-Saver
# 🔎 Fetching metadata for westonganger/rails_local_analytics
# 🔎 Fetching metadata for greatfrontend/black-friday-cyber-monday-deals
# 🔎 Fetching metadata for StayRealHQ/Universal
# 🔎 Fetching metadata for vin3110/facecheck.id-results-extractor
# 🔎 Fetching metadata for Magisk-Modules-Alt-Repo/video-to-bootanimation
# 🔎 Fetching metadata for wyp010428/xiaoyuankousuan
# 🔎 Fetching metadata for kernel0x/bundlesaver
# 🔎 Fetching metadata for Pilfer/heresy
# 🔎 Fetching metadata for utkabobr/SliceBeam
# 🔎 Fetching metadata for vanhbakaa/Blum
# 🔎 Fetching metadata for ThriveEngineer/nothing.notes
# 🔎 Fetching metadata for bohonghuang/org-srs
# 🔎 Fetching metadata for s1ntoneli/Awesome-Black-Friday-Cyber-Monday-for-Mac-Apps
# 🔎 Fetching metadata for AdriaGual/pokemon-pocket-bot
# 🔎 Fetching metadata for Aunali321/ReVancedExperiments
# 🔎 Fetching metadata for eimg/spata
# 🔎 Fetching metadata for hardalgorithm/ParanoidsPal-PrivacyLock
# 🔎 Fetching metadata for PhiZone/player
# 🔎 Fetching metadata for EvanBacon/expo-stock-widget-example
# 🔎 Fetching metadata for xiaou61/XiaoYuanKousuan
# 🔎 Fetching metadata for ViewTurbo/ViewTurbo
# 🔎 Fetching metadata for browserbase/sdk-python
# 🔎 Fetching metadata for AndreyDAraya/smart_tasks
# 🔎 Fetching metadata for UbiquitousLearning/PhoneLM
# 🔎 Fetching metadata for purrseus/react-native-xenon
# 🔎 Fetching metadata for skiniks/react-native-shiki-engine
# 🔎 Fetching metadata for aw-junaid/Computer-Science
# 🔎 Fetching metadata for KoalaSat/samiz
# 🔎 Fetching metadata for DGuerrero/compose-multiplatform-template
# 🔎 Fetching metadata for jyotidwi/AntiSplit-M
# 🔎 Fetching metadata for TheByteArray/Convertit
# 🔎 Fetching metadata for jeffc/hassmic
# 🔎 Fetching metadata for abdlhay/AbyssVideoDownloader
# 🔎 Fetching metadata for hokkar/vpntochina
# 🔎 Fetching metadata for shobhakartiwari/iOS_Junior_Level_Interview_Questions
# 🔎 Fetching metadata for Numbersf/MakeFontsGreatAgain
# 🔎 Fetching metadata for bitcoin-flashing-software/Flash-BTC-apk
# 🔎 Fetching metadata for HubertRyanOfficial/google-gemini-app-clone
# 🔎 Fetching metadata for maksimowiczm/find-my-ip
# 🔎 Fetching metadata for hackcatml/frida-watchpoint-tutorial
# 🔎 Fetching metadata for HappyHackingSpace/awesome-hackathon
# 🔎 Fetching metadata for wendell0218/GVA-Survey
# 🔎 Fetching metadata for OnePlusOSS/android_kernel_oneplus_sm8750
# 🔎 Fetching metadata for PIPIKAI/android-ncnn-yolo11
# 🔎 Fetching metadata for vanhbakaa/Paws
# 🔎 Fetching metadata for maduwatas/Vin-HkE
# 📄 Fetching page 4 for [android:keyword]...
# 📭 No more items.
# 💾 Saved 268 new repos to CSV
#
# 🔍 Window for [android:keyword]: 2024-12-09T00:00:52Z → 2024-12-31T23:59:59Z (window = 64 days, 0:00:00)
# 🔢 Estimated total: 81
# 📄 Fetching page 1 for [android:keyword]...
# ✅ Page 1: Retrieved 81 repos
# 🔎 Fetching metadata for VonChange/utao
# 🔎 Fetching metadata for 5mdld/anki-jlpt-decks
# 🔎 Fetching metadata for JetBrains/mcp-jetbrains
# 🔎 Fetching metadata for WildKernels/GKI_KernelSU_SUSFS
# 🔎 Fetching metadata for KieronQuinn/uTag
# 🔎 Fetching metadata for adrianhajdin/react_native-restate
# 🔎 Fetching metadata for futo-org/Grayjay.Desktop
# 🔎 Fetching metadata for rcmiku/Payload-Dumper-Compose
# 🔎 Fetching metadata for BandarLabs/clickclickclick
# 🔎 Fetching metadata for kmod-midori/CatShare
# 🔎 Fetching metadata for woheller69/whisperIME
# 🔎 Fetching metadata for takahirom/arbigent
# 🔎 Fetching metadata for imjyotiraditya/EchoirX
# 🔎 Fetching metadata for ironfox-oss/IronFox
# 🔎 Fetching metadata for OS-Agent-Survey/OS-Agent-Survey
# 🔎 Fetching metadata for FoxSensei001/LoveIwara
# 🔎 Fetching metadata for LYiHub/privacy-radar-public
# 🔎 Fetching metadata for RohitKushvaha01/ReTerminal
# 🔎 Fetching metadata for apappascs/mcp-servers-hub
# 🔎 Fetching metadata for OOM-WG/SUU-Nyanya
# 🔎 Fetching metadata for akaMrNagar/Mindful
# 🔎 Fetching metadata for pipecat-ai/gemini-webrtc-web-simple
# 🔎 Fetching metadata for meticha/jetpack-compose-design-patterns
# 🔎 Fetching metadata for LLeavesG/eBPFDexDumper
# 🔎 Fetching metadata for umer0586/DroidPad
# 🔎 Fetching metadata for vincentnussbaum303/youtube-download
# 🔎 Fetching metadata for MaintainTeam/Hypatia
# 🔎 Fetching metadata for joinloops/loops-app
# 🔎 Fetching metadata for imxiaoc996/DeviceWarLock
# 🔎 Fetching metadata for guohub8080/mtkit
# 🔎 Fetching metadata for OS-Copilot/OS-Genesis
# 🔎 Fetching metadata for Chrisimx/ScanBridge
# 🔎 Fetching metadata for oblador/react-native-nitro-haptics
# 🔎 Fetching metadata for avitsa/aviator-predictor
# 🔎 Fetching metadata for Ucekay/nitro-palette
# 🔎 Fetching metadata for a-chacon/chaski-app
# 🔎 Fetching metadata for betomoedano/groceries-shopping-list-app
# 🔎 Fetching metadata for MyShiLingStar/PCCE
# 🔎 Fetching metadata for timklge/awesome-karoo
# 🔎 Fetching metadata for xob0t/google_photos_mobile_client
# 🔎 Fetching metadata for localdesktop/localdesktop
# 🔎 Fetching metadata for yogeshpaliyal/awesome-mobile-system-design
# 🔎 Fetching metadata for Oval-Tutu/bootstrap-love2d-project
# 🔎 Fetching metadata for joshuacant/ProjectTitle
# 🔎 Fetching metadata for MisterZtr/LineageOS_gsi
# 🔎 Fetching metadata for dessalines/habit-maker
# 🔎 Fetching metadata for nihui/ncnn-android-yolov8
# 🔎 Fetching metadata for WilliamKarolDiCioccio/fl_nodes
# 🔎 Fetching metadata for taisuii/rusda
# 🔎 Fetching metadata for 2468785842/krkr2
# 🔎 Fetching metadata for mendsalbert/medicine-reminder-app
# 🔎 Fetching metadata for abishekmuthian/apple-watch-with-android
# 🔎 Fetching metadata for PhoneLLM/Awesome-LLM-Powered-Phone-GUI-Agents
# 🔎 Fetching metadata for eindpunt/awesome-TRMNL
# 🔎 Fetching metadata for timo-drick/Multiplatform-Preview
# 🔎 Fetching metadata for alexcao194/grammar_polisher
# 🔎 Fetching metadata for marcomq/tauri-plugin-python
# 🔎 Fetching metadata for drndos/openspoolman
# 🔎 Fetching metadata for TMLP-Team/keyboxGenerator
# 🔎 Fetching metadata for FourTwooo/JumpReplay
# 🔎 Fetching metadata for XiaomingX/awesome-docker
# 🔎 Fetching metadata for JSREI/awesome-protobuf-reverse-engineering
# 🔎 Fetching metadata for gucooing/BaPs
# 🔎 Fetching metadata for Tealseed-Lab/simple_chat
# 🔎 Fetching metadata for cnrture/Quizzy-Compose-Multi-Module
# 🔎 Fetching metadata for FilipiRafael/react-native-motion-tabs
# 🔎 Fetching metadata for Touch-N-Stars/Touch-N-Stars
# 🔎 Fetching metadata for nginetechnologies/sceneri-common
# 🔎 Fetching metadata for ong19th/Torzu
# 🔎 Fetching metadata for Ethran/notable
# 🔎 Fetching metadata for shubhamsinghshubham777/YouTubeRedesigned
# 🔎 Fetching metadata for letmeNo1/Cathin
# 🔎 Fetching metadata for h0tak88r/apkX
# 🔎 Fetching metadata for brilliantlabsAR/frame_realtime_gemini_voicevision
# 🔎 Fetching metadata for TMLP-Team/TMLP-Detectors-and-Bypassers
# 🔎 Fetching metadata for galaxy-s10/billd-desk-admin
# 🔎 Fetching metadata for yuvarajan-s-16/simple-gpa-calculator-androidstudio
# 🔎 Fetching metadata for tjac/tsto_server
# 🔎 Fetching metadata for XiaomingX/1000-startup-idea-from-yc
# 🔎 Fetching metadata for aylhex/hegui_rom
# 🔎 Fetching metadata for suiyuanlixin/fas-rs-usage-clamping
# 📄 Fetching page 2 for [android:keyword]...
# 📭 No more items.
# 💾 Saved 81 new repos to CSV
# ✅ Finished full time sweep for query: android:keyword
#
# 🎉 All queries processed. Final results saved.
