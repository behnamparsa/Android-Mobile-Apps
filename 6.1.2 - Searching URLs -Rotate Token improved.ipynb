# %%
import os
import requests
import pandas as pd
import logging
from dotenv import load_dotenv
from datetime import datetime, timedelta
from time import sleep, time as now


# === LOGGING ===
logging.basicConfig(level=logging.INFO, format="[%(levelname)s] %(message)s")
logger = logging.getLogger(__name__)

# === CONFIG ===
output_dir = r"C:\Android Mobile App\Step1_URL_Search"
output_csv_all = os.path.join(output_dir, "github_android_search_results_all.csv")
output_csv_filtered = os.path.join(output_dir, "github_android_search_results_filtered.csv")

os.makedirs(output_dir, exist_ok=True)

# === AUTH ===
load_dotenv("All_Tokens.env")
tokens = [v for k, v in os.environ.items() if k.startswith("GITHUB_TOKEN_") and v]
if not tokens:
    raise ValueError("❌ No GitHub tokens found in All_Tokens.env")

token_index = 0
HEADERS = {
    "Authorization": f"token {tokens[token_index]}",
    "Accept": "application/vnd.github+json"
}

# === DATE RANGE ===
start_date = datetime.strptime("2008-01-01", "%Y-%m-%d")
end_date = datetime.strptime("2024-12-31", "%Y-%m-%d")

# === WINDOW SETTINGS ===
initial_window_hours = 15 * 24  # 10 days
min_window_hours = 1
max_window_hours = 90 * 24
MAX_RESULTS_PER_QUERY = 1000
TARGET_FILL_RATIO = 0.25

# === BASE QUERIES ===
base_queries = [
    "stars:>50 language:Kotlin fork:false archived:false",
    "stars:>50 language:Java fork:false archived:false",
    "stars:>50 language:Dart fork:false archived:false",
    "stars:>50 topic:android fork:false archived:false",
    "stars:>50 android in:name,description,readme fork:false archived:false",
]

# === Filter ===
def filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
    # Basic checks — same as before
    min_stars = 50
    if item.get('stargazers_count', 0) <= min_stars:
        return False
    if item.get('fork', False) != expected_fork:
        return False
    if item.get('archived', False) != expected_archived:
        return False

    # Lowercased comparisons
    language = (item.get('language') or '').lower()
    topics = [t.lower() for t in item.get('topics', [])]
    description = (item.get('description') or '').lower()
    name = (item.get('name') or '').lower()

    if expected_language:
        if language != expected_language:
            return False
    if expected_topic:
        if expected_topic not in topics:
            return False
    if expected_keyword:
        if expected_keyword not in description and expected_keyword not in name:
            return False

    return True


# === Token Rotate ===
def rotate_token():
    global token_index, HEADERS
    token_index = (token_index + 1) % len(tokens)
    HEADERS = {
        "Authorization": f"token {tokens[token_index]}",
        "Accept": "application/vnd.github+json"
    }
    logger.warning(f"🔑 Rotated → Token #{token_index + 1} / {len(tokens)}")

# === Rate Limit ===
def check_rate_limit():
    r = requests.get("https://api.github.com/rate_limit", headers=HEADERS)
    if r.status_code != 200:
        logger.warning("⚠️  Could not check rate limit.")
        return
    data = r.json()
    remaining = data['resources']['search']['remaining']
    reset_epoch = data['resources']['search']['reset']
    reset_in = max(0, reset_epoch - now())
    logger.info(f"🔎 Remaining: {remaining} | Resets in {reset_in/60:.1f} min")
    if remaining < 5:
        if len(tokens) > 1:
            rotate_token()
            check_rate_limit()
        else:
            logger.warning(f"⏳ No extra tokens → sleeping {reset_in/60:.1f} min")
            sleep(reset_in + 5)

# === Count ===
def check_count(query):
    while True:
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 1})
        if r.status_code == 200:
            return r.json().get("total_count", 0)
        elif r.status_code == 403:
            rotate_token()
        else:
            logger.error(f"❌ Count error: {r.status_code} — {r.text}")
            return -1

# === Fetch ===
def fetch_items(query):
    all_items = []
    for page in range(1, 11):
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 100, "page": page})
        if r.status_code == 200:
            items = r.json().get("items", [])
            if not items:
                break
            all_items.extend(items)
            sleep(1)
        elif r.status_code == 403:
            rotate_token()
            return fetch_items(query)
        else:
            logger.error(f"❌ Fetch error: {r.status_code} — {r.text}")
            break
    return all_items

# === MAIN ===
final_results = []
for base_query_prefix in base_queries:
    current_start = start_date
    window_hours = initial_window_hours

    while current_start < end_date:
        current_end = min(current_start + timedelta(hours=window_hours), end_date)
        date_range = f"created:{current_start.isoformat()}..{current_end.isoformat()}"
        base_query = f"{base_query_prefix} {date_range}"

        total_count = check_count(base_query)
        logger.info(f"⏳ {base_query} → {total_count} repos")

        if total_count >= MAX_RESULTS_PER_QUERY and window_hours > min_window_hours:
            window_hours = max(window_hours // 2, min_window_hours)
            continue
        elif total_count < MAX_RESULTS_PER_QUERY * TARGET_FILL_RATIO and window_hours * 2 <= max_window_hours:
            window_hours = min(window_hours * 2, max_window_hours)

        items = fetch_items(base_query)
        expected_fork = 'fork:true' in base_query_prefix
        expected_archived = 'archived:true' in base_query_prefix
        expected_language = ''
        expected_topic = ''
        expected_keyword = ''

        if 'language:Kotlin' in base_query_prefix:
            expected_language = 'kotlin'
        elif 'language:Java' in base_query_prefix:
            expected_language = 'java'
        elif 'language:Dart' in base_query_prefix:
            expected_language = 'dart'
        elif 'topic:android' in base_query_prefix:
            expected_topic = 'android'
        elif 'android' in base_query_prefix:
            expected_keyword = 'android'


        count_passed = 0  # ✅ NEW counter for this window
        for item in items:
            # if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
            #     # === Check for valid clone_url ===
            #     clone_url = item.get("clone_url", "").strip()
            #     if not clone_url:
            #         logger.warning(f"⚠️ Skipped: missing or blank clone_url for {item.get('full_name')}")
            #         continue  # skip this one!
            
            if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
                clean_item = {
                    "name": item.get("name"),
                    "full_name": item.get("full_name"),
                    "language": item.get("language"),
                    "stargazers_count": item.get("stargazers_count"),
                    "forks": item.get("forks"),
                    "topics": item.get("topics"),
                    #"description": item.get("description"),
                    "fork": item.get("fork"),
                    "archived": item.get("archived"),
                    "owner.login": item.get("owner", {}).get("login"),
                    "html_url": item.get("html_url"),
                    "clone_url": item.get("clone_url"),
                    "visibility": item.get("visibility"),
                    "size": item.get("size"),
                    "open_issues_count": item.get("open_issues_count"),
                    "base_qualifier": base_query_prefix,
                    "search_qualifier": base_query,
                    "repo_stars": item.get("stargazers_count", 0),
                    "match_type": expected_language.capitalize() or expected_topic.capitalize() or expected_keyword.capitalize()
                }
                final_results.append(clean_item)
                count_passed += 1  # ✅ increment

        logger.info(f"✅ Window done: {count_passed} items")


        current_start = current_end + timedelta(seconds=1)


# ✅ === SAVE CLEAN CSV/XLSX ===

# ✅ === FINAL BULLETPROOF SAVE ===



# Optional: create unique timestamp to prevent overwriting
ts = datetime.now().strftime("%Y%m%d_%H%M%S")

# 1️⃣ One final DataFrame: from CLEAN all_results
df_clean = pd.DataFrame(final_results)

# 2️⃣ Quick check: show a preview to be sure it's clean
print("📌 Columns:", list(df_clean.columns))
print(df_clean.head(5))

# 3️⃣ Choose output file names — timestamped for safety
output_csv = os.path.join(output_dir, f"search_results_{ts}.csv")
output_xlsx = os.path.join(output_dir, f"search_results_{ts}.xlsx")


# 4️⃣ Save to CSV and Excel
df_clean.to_csv(output_csv, index=False)
df_clean.to_excel(output_xlsx, index=False)

logger.info(f"✅ All done! Clean results saved to: {output_csv} and {output_xlsx}")

# 5️⃣ Optional: show final row count
print(f"✅ Final rows saved: {len(df_clean)}")
# Out:
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-01-01T00:00:00..2008-01-16T00:00:00 → 0 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-01-16T00:00:01..2008-02-15T00:00:01 → 0 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-02-15T00:00:02..2008-04-15T00:00:02 → 0 repos
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-04-15T00:00:03..2008-06-14T00:00:03 → 0 repos
# [INFO] 🔎 Remaining: 23 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 22 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-06-14T00:00:04..2008-08-13T00:00:04 → 0 repos
# [INFO] 🔎 Remaining: 21 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-08-13T00:00:05..2008-10-12T00:00:05 → 0 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-10-12T00:00:06..2008-12-11T00:00:06 → 0 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 16 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2008-12-11T00:00:07..2009-02-09T00:00:07 → 0 repos
# [INFO] 🔎 Remaining: 15 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-02-09T00:00:08..2009-04-10T00:00:08 → 0 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-04-10T00:00:09..2009-06-09T00:00:09 → 0 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-06-09T00:00:10..2009-08-08T00:00:10 → 0 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-08-08T00:00:11..2009-10-07T00:00:11 → 2 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 6 | Resets in 0.8 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 5 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-10-07T00:00:12..2009-12-06T00:00:12 → 1 repos
# [INFO] 🔎 Remaining: 4 | Resets in 0.8 min
# [WARNING] 🔑 Rotated → Token #2 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2009-12-06T00:00:13..2010-02-04T00:00:13 → 3 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-02-04T00:00:14..2010-04-05T00:00:14 → 0 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-04-05T00:00:15..2010-06-04T00:00:15 → 4 repos
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-06-04T00:00:16..2010-08-03T00:00:16 → 1 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-08-03T00:00:17..2010-10-02T00:00:17 → 1 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.8 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-10-02T00:00:18..2010-12-01T00:00:18 → 4 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.8 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 11 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2010-12-01T00:00:19..2011-01-30T00:00:19 → 5 repos
# [INFO] 🔎 Remaining: 10 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.7 min
# [INFO] ✅ Window done: 5 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-01-30T00:00:20..2011-03-31T00:00:20 → 5 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 6 | Resets in 0.7 min
# [INFO] ✅ Window done: 5 items
# [INFO] 🔎 Remaining: 5 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-03-31T00:00:21..2011-05-30T00:00:21 → 2 repos
# [INFO] 🔎 Remaining: 4 | Resets in 0.7 min
# [WARNING] 🔑 Rotated → Token #3 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-05-30T00:00:22..2011-07-29T00:00:22 → 6 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ✅ Window done: 6 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-07-29T00:00:23..2011-09-27T00:00:23 → 9 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ✅ Window done: 9 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-09-27T00:00:24..2011-11-26T00:00:24 → 6 repos
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ✅ Window done: 6 items
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2011-11-26T00:00:25..2012-01-25T00:00:25 → 8 repos
# [INFO] 🔎 Remaining: 18 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.8 min
# [INFO] ✅ Window done: 8 items
# [INFO] 🔎 Remaining: 16 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2012-01-25T00:00:26..2012-03-25T00:00:26 → 17 repos
# [INFO] 🔎 Remaining: 15 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.8 min
# [INFO] ✅ Window done: 17 items
# [INFO] 🔎 Remaining: 13 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2012-03-25T00:00:27..2012-05-24T00:00:27 → 16 repos
# [INFO] 🔎 Remaining: 12 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.7 min
# [INFO] ✅ Window done: 16 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2012-05-24T00:00:28..2012-07-23T00:00:28 → 20 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.7 min
# [INFO] ✅ Window done: 20 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2012-07-23T00:00:29..2012-09-21T00:00:29 → 17 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.6 min
# [INFO] ✅ Window done: 17 items
# [INFO] 🔎 Remaining: 4 | Resets in 0.6 min
# [WARNING] 🔑 Rotated → Token #4 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2012-09-21T00:00:30..2012-11-20T00:00:30 → 9 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ✅ Window done: 9 items
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:
repos
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] ✅ Window done: 781 items
# [INFO] 🔎 Remaining: 24 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-07-17T00:01:43..2019-08-01T00:01:43 → 804 repos
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] ✅ Window done: 804 items
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-08-01T00:01:44..2019-08-16T00:01:44 → 834 repos
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.5 min
# [INFO] ✅ Window done: 834 items
# [INFO] 🔎 Remaining: 21 | Resets in 0.5 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-08-16T00:01:45..2019-08-31T00:01:45 → 800 repos
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 800 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-08-31T00:01:46..2019-09-15T00:01:46 → 874 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.3 min
# [INFO] ✅ Window done: 871 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-09-15T00:01:47..2019-09-30T00:01:47 → 899 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] ✅ Window done: 896 items
# [INFO] 🔎 Remaining: 24 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-09-30T00:01:48..2019-10-15T00:01:48 → 843 repos
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] ✅ Window done: 839 items
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-10-15T00:01:49..2019-10-30T00:01:49 → 1004 repos
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-10-15T00:01:49..2019-10-22T12:01:49 → 557 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] ✅ Window done: 554 items
# [INFO] 🔎 Remaining: 24 | Resets in 0.7 min
# [INFO] ⏳ stars:>0 language:Kotlin fork:false archived:false created:2019-10-22T12:01:50..2019-10-30T00:01:50 → 447 repos
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] ✅ Window done: 444 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.4 min
# ...
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-13T18:13:32..2017-09-15T15:13:32 → 833 repos
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ✅ Window done: 833 items
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-15T15:13:33..2017-09-17T12:13:33 → 546 repos
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.6 min
# [INFO] ✅ Window done: 546 items
# [INFO] 🔎 Remaining: 19 | Resets in 0.6 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-17T12:13:34..2017-09-19T09:13:34 → 729 repos
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 729 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-19T09:13:35..2017-09-21T06:13:35 → 799 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] ✅ Window done: 799 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-21T06:13:36..2017-09-23T03:13:36 → 736 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] ✅ Window done: 736 items
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-23T03:13:37..2017-09-25T00:13:37 → 517 repos
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] ✅ Window done: 517 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-25T00:13:38..2017-09-26T21:13:38 → 800 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] ✅ Window done: 800 items
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-26T21:13:39..2017-09-28T18:13:39 → 793 repos
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.3 min
# [INFO] ✅ Window done: 793 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-28T18:13:40..2017-09-30T15:13:40 → 648 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] ✅ Window done: 648 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-09-30T15:13:41..2017-10-02T12:13:41 → 481 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] ✅ Window done: 481 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-02T12:13:42..2017-10-04T09:13:42 → 633 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ✅ Window done: 633 items
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-04T09:13:43..2017-10-06T06:13:43 → 624 repos
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] ✅ Window done: 624 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-06T06:13:44..2017-10-08T03:13:44 → 552 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.1 min
# [INFO] ✅ Window done: 552 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.1 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-08T03:13:45..2017-10-10T00:13:45 → 642 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.6 min
# [INFO] ✅ Window done: 642 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-10T00:13:46..2017-10-11T21:13:46 → 831 repos
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 831 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-11T21:13:47..2017-10-13T18:13:47 → 857 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] ✅ Window done: 857 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] ⏳ stars:>0 language:Java fork:false archived:false created:2017-10-13T18:13:48..2017-10-15T15:13:48 → 566 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] ✅ Window done: 566 items
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 158
#     155 date_range = f"created:{current_start.isoformat()}..{current_end.isoformat()}"
#     156 base_query = f"{base_query_prefix} {date_range}"
# --> 158 total_count = check_count(base_query)
#     159 logger.info(f"⏳ {base_query} → {total_count} repos")
#     161 if total_count >= MAX_RESULTS_PER_QUERY and window_hours > min_window_hours:
#
# Cell In[5], line 116, in check_count(query)
#     114 while True:
#     115     check_rate_limit()
# --> 116     r = requests.get("https://api.github.com/search/repositories",
#     117                      headers=HEADERS, params={"q": query, "per_page": 1})
#     118     if r.status_code == 200:
#     119         return r.json().get("total_count", 0)
#
# File c:\GitHub\.PCvenv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\GitHub\.PCvenv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\GitHub\.PCvenv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\GitHub\.PCvenv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\GitHub\.PCvenv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\GitHub\.PCvenv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\GitHub\.PCvenv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\GitHub\.PCvenv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
