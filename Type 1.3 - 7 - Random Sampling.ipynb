# %%
import pandas as pd
import numpy as np
import os

# === CONFIGURATION ===
# Input file path
input_file = r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\Intru_Test_Check\URL_List_1169.csv"
output_file = r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\Intru_Test_Check\URL_List_Rand.csv"

# Set random seed for reproducibility
np.random.seed(42)

# Load repo list
df = pd.read_csv(input_file)

# Take a random sample of 65 records (reproducible)
sample_df = df.sample(n=65, random_state=42)

# Save to CSV
sample_df.to_csv(output_file, index=False)

print(f"Random sample of 65 repos saved to:\n{output_file}")
# Out:
# Random sample of 65 repos saved to:
# C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\Intru_Test_Check\URL_List_Rand.csv
