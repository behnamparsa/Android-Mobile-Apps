# %% [markdown]
# upgradeing the miner to pull the number of the changes to each style in dwelling period

# %% [markdown]
# # Step 1: Clone
# ## Part 1 - Repo's Full Clone only

# %%
from __future__ import annotations
import csv, os, re, subprocess, time
from pathlib import Path
from typing import Optional, List

# -----------------------------
# Config (edit as needed)
# -----------------------------
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
URL_LIST_CSV = WORK_ROOT / "URL_List.csv"
CLONE_ROOT   = WORK_ROOT / "clonesV1.0"
MANIFEST_CSV = WORK_ROOT / "clones_manifestV1.0.csv"

WITH_SUBMODULES = False     # set True if you want submodules initialized/updated
WITH_LFS        = False     # set True if you need Git LFS objects
FETCH_PR_REFS   = True      # set False to skip GitHub PR heads

# Create dirs
WORK_ROOT.mkdir(parents=True, exist_ok=True)
CLONE_ROOT.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Helpers
# -----------------------------
DEFAULT_TIMEOUT = 1800  # 30 minutes for huge repos
GIT_ENV = {"GIT_TERMINAL_PROMPT": "0", "GIT_ASKPASS": ""}

def sh(cmd: List[str], cwd: Optional[Path] = None, check: bool = True,
       capture: bool = True, timeout: Optional[int] = DEFAULT_TIMEOUT) -> subprocess.CompletedProcess:
    env = os.environ.copy()
    env.update(GIT_ENV)
    return subprocess.run(cmd, cwd=cwd, check=check,
                          capture_output=capture, text=True,
                          timeout=timeout, env=env)

def sh_ok(cmd: List[str], cwd: Optional[Path] = None, timeout: Optional[int] = DEFAULT_TIMEOUT) -> str:
    cp = sh(cmd, cwd=cwd, check=True, capture=True, timeout=timeout)
    return cp.stdout

def repo_dir_name_from_url(url: str) -> str:
    u = url.strip()
    # SSH form: git@host:owner/repo(.git)
    m = re.match(r"^[^@]+@([^:]+):([^/]+)/(.+?)(?:\.git)?$", u)
    if m:
        owner, name = m.group(2), m.group(3)
        return f"{owner}__{name}"
    # https://host/owner/repo(.git)
    if "://" in u:
        base = u.split("://", 1)[1]
    else:
        base = u
    parts = [p for p in base.split("/") if p]
    if len(parts) >= 2:
        owner, name = parts[-2], parts[-1].removesuffix(".git")
        return f"{owner}__{name}"
    return base.replace("/", "__").removesuffix(".git")

def ensure_full_clone(url: str, dest_root: Path,
                      with_submodules: bool = False,
                      with_lfs: bool = False,
                      fetch_pr_refs: bool = True) -> Path:
    """
    Ensures a non-shallow clone with full history of all branches & tags.
    Optionally fetches GitHub PR heads to refs/remotes/origin/pr/*,
    initializes submodules, and fetches LFS objects.
    """
    dest_root.mkdir(parents=True, exist_ok=True)
    d = dest_root / repo_dir_name_from_url(url)

    if not (d.exists() and (d / ".git").exists()):
        # no-recurse-submodules avoids submodule cost unless requested later
        sh(["git", "clone", "--no-recurse-submodules", "--tags", url, str(d)],
           capture=False)
    else:
        # If repo exists, ensure origin URL is correct
        sh(["git", "remote", "set-url", "origin", url], cwd=d, check=False)

    # If shallow, unshallow
    cp = sh(["git", "rev-parse", "--is-shallow-repository"], cwd=d, check=False)
    if cp.returncode == 0 and cp.stdout.strip() == "true":
        sh(["git", "fetch", "--unshallow", "--tags"], cwd=d, capture=False)
    else:
        # Make sure we have tags even if already full
        sh(["git", "fetch", "--tags"], cwd=d, check=False, capture=False)

    # Fetch all branches under refs/heads/* and prune deleted ones
    sh(["git", "fetch", "origin", "--prune", "--tags",
        "+refs/heads/*:refs/remotes/origin/*", "--quiet"], cwd=d, check=False, capture=False)

    # Best-effort PR refs (GitHub); harmless if not present
    if fetch_pr_refs:
        sh(["git", "fetch", "origin",
            "+refs/pull/*/head:refs/remotes/origin/pr/*", "--quiet"], cwd=d, check=False, capture=False)

    # Optional: submodules
    if with_submodules:
        sh(["git", "submodule", "update", "--init", "--recursive"], cwd=d, capture=False)

    # Optional: LFS
    if with_lfs:
        # If git-lfs isn't installed, these will fail harmlessly due to check=False
        sh(["git", "lfs", "install"], cwd=d, check=False, capture=False)
        sh(["git", "lfs", "fetch", "--all"], cwd=d, check=False, capture=False)
        sh(["git", "lfs", "checkout"], cwd=d, check=False, capture=False)

    return d

def get_total_commits(repo_dir: Path) -> int:
    # Count across all refs reachable in the repository
    cp = sh(["git", "rev-list", "--all", "--count"], cwd=repo_dir, check=False)
    try:
        return int((cp.stdout or "0").strip() or "0")
    except Exception:
        return 0

# -----------------------------
# Main: FULL CLONE ONLY
# -----------------------------
assert URL_LIST_CSV.exists(), f"CSV not found: {URL_LIST_CSV}"

rows, ok, fail = [], 0, 0
with URL_LIST_CSV.open(newline="", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        url = (row.get("repo_url") or "").strip()
        if not url:
            continue
        t0 = time.time()
        rec = {
            "repo_url": url,
            "dir": None,
            "status": "unknown",
            "seconds": None,
            "total_commits": None,
            "error": ""
        }
        try:
            d = ensure_full_clone(url, CLONE_ROOT,
                                  with_submodules=WITH_SUBMODULES,
                                  with_lfs=WITH_LFS,
                                  fetch_pr_refs=FETCH_PR_REFS)
            rec["dir"] = str(d)
            rec["total_commits"] = get_total_commits(d)
            rec["status"] = "ok"
            ok += 1
        except subprocess.CalledProcessError as e:
            rec["status"] = "error"
            rec["error"]  = (e.stderr or e.stdout or str(e)).strip()[:2000]
            fail += 1
        except Exception as e:
            rec["status"] = "error"
            rec["error"]  = str(e)[:2000]
            fail += 1

        rec["seconds"] = round(time.time() - t0, 2)
        rows.append(rec)
        print(f"[{rec['status']}] {url} -> {rec['dir']} ({rec['seconds']}s)  commits={rec['total_commits']}")

# Write manifest
MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
fieldnames = ["repo_url","dir","status","seconds","total_commits","error"]
with MANIFEST_CSV.open("w", newline="", encoding="utf-8") as f:
    w = csv.DictWriter(f, fieldnames=fieldnames)
    w.writeheader()
    w.writerows(rows)

print(f"\nDone. OK={ok}, FAIL={fail}. Manifest: {MANIFEST_CSV}")
# Out:
# [ok] https://github.com/connectbot/connectbot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\connectbot__connectbot (2.27s)  commits=3884
# [ok] https://github.com/robolectric/robolectric -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\robolectric__robolectric (17.82s)  commits=21584
# [ok] https://github.com/opendocument-app/OpenDocument.droid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\opendocument-app__OpenDocument.droid (1.04s)  commits=6093
# [ok] https://github.com/maxpower47/PinDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\maxpower47__PinDroid (0.79s)  commits=1057
# [ok] https://github.com/Rajawali/Rajawali -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\Rajawali__Rajawali (1.53s)  commits=3065
# [ok] https://github.com/cgeo/cgeo -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\cgeo__cgeo (10.1s)  commits=74326
# [ok] https://github.com/OneBusAway/onebusaway-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\OneBusAway__onebusaway-android (9.53s)  commits=4380
# [ok] https://github.com/MikeOrtiz/TouchImageView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\MikeOrtiz__TouchImageView (7.47s)  commits=1146
# [ok] https://github.com/labexp/osmtracker-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\clonesV1.0\labexp__osmtracker-android (4.27s)  commits=1902

# %% [markdown]
# # Step 2: Clone
# Part 2 Extract PRs and Issues - runns after Step 3 to get only the relevant commits' PRs and Issues

# %%
from __future__ import annotations
import csv, os, re, time, json
from pathlib import Path
from typing import Optional, List, Dict, Set
from collections import defaultdict

import requests          # pip install requests
from dotenv import load_dotenv  # pip install python-dotenv

# -----------------------------
# Config (edit as needed)
# -----------------------------
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
URL_LIST_CSV = WORK_ROOT / "URL_List.csv"
MANIFEST_CSV = WORK_ROOT / "metadata_manifestV1.0.csv"

# Where to store GitHub metadata (PRs + issues)
META_ROOT = WORK_ROOT / "metadataV1.0"

# NEW: path to the commit list produced by your episode analysis
TARGET_COMMITS_CSV = WORK_ROOT / "Observations" / "obs3_1_change_episodes_commits.csv"

FETCH_GH_METADATA = True  # set False to dry-run the URL list

# Path to your env file
ENV_FILE = r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env"

# === LOAD .env ===
load_dotenv(ENV_FILE)

# Load GitHub tokens: GITHUB_TOKEN_1 ... GITHUB_TOKEN_6
TOKENS = [os.getenv(f"GITHUB_TOKEN_{i}") for i in range(1, 7)]
TOKENS = [t for t in TOKENS if t]

if not TOKENS:
    print("⚠️ Warning: No GitHub tokens found in All_Tokens.env (API metadata might be rate limited).")
else:
    print(f"ℹ️ Loaded {len(TOKENS)} GitHub token(s) from All_Tokens.env")
    print("Token lengths:", [len(t) for t in TOKENS])

# index of the current token (0-based)
token_index = 0

GITHUB_API_BASE = "https://api.github.com"

# Create dirs
WORK_ROOT.mkdir(parents=True, exist_ok=True)
META_ROOT.mkdir(parents=True, exist_ok=True)

# Regex for issue references like "#123"
ISSUE_REF_RE = re.compile(r"#(\d+)")

# -----------------------------
# Load target commits per repo
# -----------------------------
def load_target_commits(path: Path) -> Dict[str, Set[str]]:
    """
    Load target commit SHAs per repo from obs3_1_change_episodes_commits.csv.

    Uses the 'repo_name' column (e.g., 'connectbot__connectbot') and 'commit'.
    """
    mapping: Dict[str, Set[str]] = defaultdict(set)
    if not path.exists():
        print(f"⚠️ Warning: target commit CSV not found: {path}")
        return mapping

    with path.open(newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            repo_name = (row.get("repo_name") or "").strip()  # e.g., "connectbot__connectbot"
            sha = (row.get("commit") or "").strip()
            if repo_name and sha:
                mapping[repo_name].add(sha)

    print(f"ℹ️ Loaded target commits for {len(mapping)} repos from {path}")
    return mapping


TARGET_COMMITS_BY_REPO: Dict[str, Set[str]] = load_target_commits(TARGET_COMMITS_CSV)

# -----------------------------
# Helpers (no git here)
# -----------------------------

def parse_github_owner_repo(url: str) -> Optional[tuple[str, str]]:
    """
    Return (owner, repo) for GitHub URLs, or None if not GitHub.
    Supports https://github.com/owner/repo(.git) and git@github.com:owner/repo(.git).
    """
    u = url.strip()
    # SSH form
    m = re.match(r"^git@github\.com:([^/]+)/(.+?)(?:\.git)?$", u)
    if m:
        return m.group(1), m.group(2)

    # HTTPS form
    if "github.com" not in u.lower():
        return None

    # Drop protocol
    if "://" in u:
        base = u.split("://", 1)[1]
    else:
        base = u

    # Remove possible query/fragments
    base = base.split("?", 1)[0].split("#", 1)[0]

    parts = [p for p in base.split("/") if p]
    # parts like ["github.com", "owner", "repo(.git)"]
    if len(parts) >= 3 and parts[0].lower().startswith("github.com"):
        owner = parts[1]
        repo = parts[2].removesuffix(".git")
        return owner, repo

    return None


def github_get(path: str, params: Optional[dict] = None) -> list:
    """
    Basic GitHub API GET with pagination.
    Uses round-robin token rotation when hitting rate limits.
    Returns a list of items.
    """
    global token_index

    url = f"{GITHUB_API_BASE}{path}"
    items: list = []
    page = 1

    while True:
        # Build headers with the current token
        headers = {
            # include preview for /commits/{sha}/pulls endpoint as well
            "Accept": "application/vnd.github+json, application/vnd.github.groot-preview+json"
        }
        current_token = TOKENS[token_index] if TOKENS else None
        if current_token:
            headers["Authorization"] = f"Bearer {current_token}"

        q = dict(params or {})
        q.setdefault("per_page", 100)
        q["page"] = page

        resp = requests.get(url, headers=headers, params=q)

        # Detect rate limit
        remaining = resp.headers.get("X-RateLimit-Remaining")
        is_rate_limited = (
            resp.status_code == 403
            and ("rate limit" in resp.text.lower() or remaining == "0")
        )

        if is_rate_limited:
            print(
                f"[rate limit] {path} page={page} with token index {token_index}. "
                f"Remaining={remaining}"
            )
            if TOKENS and len(TOKENS) > 1:
                old_index = token_index
                token_index = (token_index + 1) % len(TOKENS)
                print(f"  -> switching token {old_index} -> {token_index} and retrying...")
                continue
            else:
                print("  -> no alternative tokens; stopping.")
                break

        # If we reach here, it's not a rate-limit error
        resp.raise_for_status()
        data = resp.json()
        if not data:
            break

        if isinstance(data, list):
            items.extend(data)
        else:
            # some endpoints return an object, not a list
            items.append(data)
            break

        if len(data) < q["per_page"]:
            # last page
            break

        page += 1

    return items


# --- Targeted helpers: commit -> PRs, PR -> issues ----

def get_prs_for_commit(owner: str, repo: str, sha: str) -> List[dict]:
    """
    Return list of PRs that include this commit.
    Uses /repos/{owner}/{repo}/commits/{sha}/pulls.
    """
    path = f"/repos/{owner}/{repo}/commits/{sha}/pulls"
    try:
        return github_get(path, params=None)
    except Exception as e:
        print(f"    [warn] commit {sha}: error fetching associated PRs: {e}")
        return []


def fetch_issue_with_comments(owner: str, repo: str, number: int) -> Optional[dict]:
    """
    Fetch a single issue + its comments.
    """
    try:
        issue_list = github_get(f"/repos/{owner}/{repo}/issues/{number}")
        if not issue_list:
            return None
        issue = issue_list[0]
    except Exception as e:
        print(f"    [warn] issue #{number}: error fetching issue: {e}")
        return None

    try:
        comments = github_get(f"/repos/{owner}/{repo}/issues/{number}/comments")
    except Exception as e:
        print(f"    [warn] issue #{number}: error fetching comments: {e}")
        comments = []
    issue["comments"] = comments
    return issue


def extract_issue_numbers_from_pr(pr: dict) -> Set[int]:
    """
    Extract referenced issue numbers from PR body/title/comments/reviews using #123 pattern.
    """
    texts: List[str] = []

    for key in ("title", "body"):
        v = pr.get(key)
        if isinstance(v, str):
            texts.append(v)

    for c in pr.get("issue_comments", []):
        v = c.get("body")
        if isinstance(v, str):
            texts.append(v)

    for c in pr.get("review_comments", []):
        v = c.get("body")
        if isinstance(v, str):
            texts.append(v)

    for r in pr.get("reviews", []):
        v = r.get("body")
        if isinstance(v, str):
            texts.append(v)

    nums: Set[int] = set()
    for t in texts:
        for m in ISSUE_REF_RE.findall(t):
            try:
                nums.add(int(m))
            except ValueError:
                pass
    return nums


def fetch_github_prs_and_issues(owner: str, repo: str, out_dir: Path) -> tuple[int, int]:
    """
    TARGETED VERSION:

    For this (owner, repo), we only fetch metadata for the commits listed
    in obs3_1_change_episodes_commits.csv (per repo).

    For those commits:
      - find associated PRs
      - fetch full PR (details + issue_comments + review_comments + reviews)
      - parse PR text/comments to find #issue references
      - fetch only those issues (+ comments)

    Returns:
        (num_targeted_prs, num_targeted_issues)
    """
    out_dir.mkdir(parents=True, exist_ok=True)
    base_name = f"{owner}__{repo}"

    repo_key = base_name  # matches 'repo_name' in the commits CSV
    commit_shas = TARGET_COMMITS_BY_REPO.get(repo_key, set())

    if not commit_shas:
        print(f"  [meta] No target commits for {owner}/{repo} (repo_name={repo_key}); skipping.")
        # still write empty JSON files for consistency
        with (out_dir / f"{base_name}_PRs.json").open("w", encoding="utf-8") as f:
            json.dump([], f, ensure_ascii=False, indent=2)
        with (out_dir / f"{base_name}_Issues.json").open("w", encoding="utf-8") as f:
            json.dump([], f, ensure_ascii=False, indent=2)
        return 0, 0

    print(f"  [meta] Target commits for {owner}/{repo}: {len(commit_shas)}")

    targeted_prs: List[dict] = []
    targeted_issues: List[dict] = []

    seen_pr_numbers: Set[int] = set()
    seen_issue_numbers: Set[int] = set()

    # ---- 1) For each commit, get its PRs and fetch full PR discussion ----
    for sha in sorted(commit_shas):
        prs_for_commit = get_prs_for_commit(owner, repo, sha)
        if not prs_for_commit:
            continue

        for pr_stub in prs_for_commit:
            number = pr_stub.get("number")
            if number is None:
                continue
            if number in seen_pr_numbers:
                # Optionally attach this commit to an existing PR record
                for existing in targeted_prs:
                    if existing.get("number") == number:
                        existing.setdefault("target_commits", [])
                        if sha not in existing["target_commits"]:
                            existing["target_commits"].append(sha)
                continue

            seen_pr_numbers.add(number)

            # PR core details
            try:
                pr_full_list = github_get(f"/repos/{owner}/{repo}/pulls/{number}")
                pr_full = pr_full_list[0] if pr_full_list else pr_stub
            except Exception as e:
                print(f"    [warn] PR #{number}: error fetching details: {e}")
                pr_full = pr_stub

            # issue-style comments on the PR
            try:
                issue_comments = github_get(
                    f"/repos/{owner}/{repo}/issues/{number}/comments"
                )
            except Exception as e:
                print(f"    [warn] PR #{number}: error fetching issue comments: {e}")
                issue_comments = []

            # review comments on specific lines
            try:
                review_comments = github_get(
                    f"/repos/{owner}/{repo}/pulls/{number}/comments"
                )
            except Exception as e:
                print(f"    [warn] PR #{number}: error fetching review comments: {e}")
                review_comments = []

            # review events (approve/request-changes etc.)
            try:
                reviews = github_get(
                    f"/repos/{owner}/{repo}/pulls/{number}/reviews"
                )
            except Exception as e:
                print(f"    [warn] PR #{number}: error fetching reviews: {e}")
                reviews = []

            pr_full["issue_comments"] = issue_comments
            pr_full["review_comments"] = review_comments
            pr_full["reviews"] = reviews
            pr_full["target_commits"] = [sha]

            targeted_prs.append(pr_full)

    # ---- 2) From those PRs, find referenced issues and fetch them ----
    for pr in targeted_prs:
        issue_numbers = extract_issue_numbers_from_pr(pr)
        for num in issue_numbers:
            if num in seen_issue_numbers:
                continue
            seen_issue_numbers.add(num)
            issue = fetch_issue_with_comments(owner, repo, num)
            if issue is not None:
                targeted_issues.append(issue)

    # ---- 3) Save as JSON (same filenames as before) ----
    with (out_dir / f"{base_name}_PRs.json").open("w", encoding="utf-8") as f:
        json.dump(targeted_prs, f, ensure_ascii=False, indent=2)

    with (out_dir / f"{base_name}_Issues.json").open("w", encoding="utf-8") as f:
        json.dump(targeted_issues, f, ensure_ascii=False, indent=2)

    return len(targeted_prs), len(targeted_issues)


# -----------------------------
# Main: GH METADATA ONLY (no clone)
# -----------------------------
def main() -> None:
    assert URL_LIST_CSV.exists(), f"CSV not found: {URL_LIST_CSV}"

    rows, ok, fail = [], 0, 0
    with URL_LIST_CSV.open(newline="", encoding="utf-8") as f:
        for row in csv.DictReader(f):
            url = (row.get("repo_url") or "").strip()
            if not url:
                continue
            t0 = time.time()
            rec = {
                "repo_url": url,
                "status": "unknown",
                "seconds": None,
                "num_prs": None,
                "num_issues": None,
                "error": "",
            }
            try:
                if not FETCH_GH_METADATA:
                    rec["status"] = "skipped"
                    ok += 1
                else:
                    gh = parse_github_owner_repo(url)
                    if gh is None:
                        rec["status"] = "non_github"
                        rec["error"] = "Not a GitHub URL"
                        fail += 1
                    else:
                        owner, repo_name = gh
                        try:
                            num_prs, num_issues = fetch_github_prs_and_issues(
                                owner, repo_name, META_ROOT
                            )
                            rec["status"] = "ok"
                            rec["num_prs"] = num_prs
                            rec["num_issues"] = num_issues
                            ok += 1
                        except Exception as e:
                            msg = f"metadata error: {e}"
                            print(f"  [meta-error] {url}: {msg}")
                            rec["status"] = "error"
                            rec["error"] = msg
                            fail += 1

            except Exception as e:
                rec["status"] = "error"
                rec["error"] = str(e)[:2000]
                fail += 1

            rec["seconds"] = round(time.time() - t0, 2)
            rows.append(rec)
            print(
                f"[{rec['status']}] {url} "
                f"({rec['seconds']}s)  PRs={rec['num_prs']}  Issues={rec['num_issues']}"
            )

    # Write manifest for metadata
    MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
    fieldnames = ["repo_url", "status", "seconds", "num_prs", "num_issues", "error"]
    with MANIFEST_CSV.open("w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=fieldnames)
        w.writeheader()
        w.writerows(rows)

    print(f"\nDone. OK={ok}, FAIL={fail}. Manifest: {MANIFEST_CSV}")


if __name__ == "__main__":
    main()
# Out:
# ℹ️ Loaded 6 GitHub token(s) from All_Tokens.env
# Token lengths: [40, 40, 40, 40, 40, 40]
# ℹ️ Loaded target commits for 350 repos from C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\obs3_1_change_episodes_commits.csv
#   [meta] Target commits for connectbot/connectbot: 2
# [ok] https://github.com/connectbot/connectbot (3.15s)  PRs=2  Issues=0
#   [meta] Target commits for robolectric/robolectric: 2
# [ok] https://github.com/robolectric/robolectric (4.5s)  PRs=2  Issues=0
#   [meta] Target commits for opendocument-app/OpenDocument.droid: 1
# [ok] https://github.com/opendocument-app/OpenDocument.droid (1.48s)  PRs=1  Issues=0
#   [meta] Target commits for maxpower47/PinDroid: 1
# [ok] https://github.com/maxpower47/PinDroid (1.59s)  PRs=1  Issues=0
#   [meta] Target commits for Rajawali/Rajawali: 5
# [ok] https://github.com/Rajawali/Rajawali (7.84s)  PRs=4  Issues=3
#   [meta] Target commits for cgeo/cgeo: 1
# [ok] https://github.com/cgeo/cgeo (1.69s)  PRs=1  Issues=0
#   [meta] Target commits for OneBusAway/onebusaway-android: 2
# [ok] https://github.com/OneBusAway/onebusaway-android (4.35s)  PRs=2  Issues=2
#   [meta] Target commits for MikeOrtiz/TouchImageView: 2
# [ok] https://github.com/MikeOrtiz/TouchImageView (2.86s)  PRs=2  Issues=0
#   [meta] Target commits for labexp/osmtracker-android: 3
# [ok] https://github.com/labexp/osmtracker-android (2.71s)  PRs=1  Issues=0
#   [meta] Target commits for AndBible/and-bible: 1
# [ok] https://github.com/AndBible/and-bible (2.61s)  PRs=1  Issues=1
#   [meta] No target commits for maxistar/TextPad (repo_name=maxistar__TextPad); skipping.
# [ok] https://github.com/maxistar/TextPad (0.0s)  PRs=0  Issues=0
#   [meta] Target commits for spacecowboy/NotePad: 2
# [ok] https://github.com/spacecowboy/NotePad (0.54s)  PRs=0  Issues=0
#   [meta] Target commits for persian-calendar/persian-calendar: 1
# [ok] https://github.com/persian-calendar/persian-calendar (1.68s)  PRs=1  Issues=0
#   [meta] Target commits for inaturalist/iNaturalistAndroid: 1
# [ok] https://github.com/inaturalist/iNaturalistAndroid (1.67s)  PRs=1  Issues=0
#   [meta] Target commits for yuriykulikov/AlarmClock: 2
# [ok] https://github.com/yuriykulikov/AlarmClock (2.3s)  PRs=1  Issues=1
#   [meta] Target commits for openintents/shoppinglist: 1
# [ok] https://github.com/openintents/shoppinglist (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for square/okhttp: 1
# [ok] https://github.com/square/okhttp (1.91s)  PRs=1  Issues=0
#   [meta] Target commits for AntennaPod/AntennaPod: 2
# [ok] https://github.com/AntennaPod/AntennaPod (1.78s)  PRs=1  Issues=0
#   [meta] Target commits for ragunathjawahar/android-saripaar: 1
# [ok] https://github.com/ragunathjawahar/android-saripaar (0.21s)  PRs=0  Issues=0
#   [meta] Target commits for fossasia/phimpme-android: 1
# [ok] https://github.com/fossasia/phimpme-android (0.36s)  PRs=0  Issues=0
#   [meta] Target commits for xebia-functional/appsly-android-rest: 1
# [ok] https://github.com/xebia-functional/appsly-android-rest (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for ankidroid/Anki-Android: 2
# [ok] https://github.com/ankidroid/Anki-Android (4.26s)  PRs=2  Issues=2
#   [meta] Target commits for ligi/PassAndroid: 2
# [ok] https://github.com/ligi/PassAndroid (1.76s)  PRs=1  Issues=0
#   [meta] Target commits for segler-alex/RadioDroid: 2
# [ok] https://github.com/segler-alex/RadioDroid (3.08s)  PRs=2  Issues=0
#   [meta] Target commits for ksoichiro/AndroidFormEnhancer: 1
# [ok] https://github.com/ksoichiro/AndroidFormEnhancer (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for cloudinary/cloudinary_android: 1
# [ok] https://github.com/cloudinary/cloudinary_android (1.53s)  PRs=1  Issues=0
#   [meta] Target commits for dmfs/opentasks: 1
# [ok] https://github.com/dmfs/opentasks (1.72s)  PRs=1  Issues=1
#   [meta] Target commits for square/wire: 1
# [ok] https://github.com/square/wire (2.38s)  PRs=1  Issues=1
#   [meta] Target commits for tasks/tasks: 6
# [ok] https://github.com/tasks/tasks (2.86s)  PRs=1  Issues=0
#   [meta] Target commits for simonnorberg/dmach: 2
# [ok] https://github.com/simonnorberg/dmach (0.63s)  PRs=0  Issues=0
#   [meta] Target commits for wikimedia/apps-android-wikipedia: 1
# [ok] https://github.com/wikimedia/apps-android-wikipedia (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for splitwise/TokenAutoComplete: 2
# [ok] https://github.com/splitwise/TokenAutoComplete (3.72s)  PRs=2  Issues=2
#   [meta] Target commits for grote/Transportr: 2
# [ok] https://github.com/grote/Transportr (2.01s)  PRs=1  Issues=1
#   [meta] Target commits for anjlab/android-inapp-billing-v3: 2
# [ok] https://github.com/anjlab/android-inapp-billing-v3 (0.61s)  PRs=0  Issues=0
#   [meta] Target commits for federicoiosue/Omni-Notes: 2
# [ok] https://github.com/federicoiosue/Omni-Notes (2.01s)  PRs=1  Issues=0
#   [meta] Target commits for rejasupotaro/Rebuild: 1
# [ok] https://github.com/rejasupotaro/Rebuild (0.53s)  PRs=0  Issues=0
#   [meta] Target commits for owntracks/android: 2
# [ok] https://github.com/owntracks/android (0.72s)  PRs=0  Issues=0
#   [meta] Target commits for dlew/joda-time-android: 2
# [ok] https://github.com/dlew/joda-time-android (2.84s)  PRs=2  Issues=0
#   [meta] Target commits for TomRoush/PdfBox-Android: 2
# [ok] https://github.com/TomRoush/PdfBox-Android (1.74s)  PRs=1  Issues=0
#   [meta] Target commits for AChep/AcDisplay: 1
# [ok] https://github.com/AChep/AcDisplay (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for mathisdt/trackworktime: 1
# [ok] https://github.com/mathisdt/trackworktime (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for ksoichiro/SimpleAlertDialog-for-Android: 1
# [ok] https://github.com/ksoichiro/SimpleAlertDialog-for-Android (0.22s)  PRs=0  Issues=0
#   [meta] Target commits for openhab/openhab-android: 2
# [ok] https://github.com/openhab/openhab-android (2.89s)  PRs=1  Issues=1
#   [meta] Target commits for amahi/android: 1
# [ok] https://github.com/amahi/android (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for EvanRespaut/Equate: 1
# [ok] https://github.com/EvanRespaut/Equate (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for OpnTec/bodyapps-android: 1
# [ok] https://github.com/OpnTec/bodyapps-android (0.21s)  PRs=0  Issues=0
#   [meta] Target commits for blazsolar/android-collapse-calendar-view: 1
# [ok] https://github.com/blazsolar/android-collapse-calendar-view (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for spacecowboy/Feeder: 4
# [ok] https://github.com/spacecowboy/Feeder (2.61s)  PRs=1  Issues=0
#   [meta] Target commits for TeamAmaze/AmazeFileManager: 1
# [ok] https://github.com/TeamAmaze/AmazeFileManager (1.8s)  PRs=1  Issues=0
#   [meta] Target commits for tripadvisor/android-clockseekbar: 1
# [ok] https://github.com/tripadvisor/android-clockseekbar (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for ksoichiro/Android-ObservableScrollView: 1
# [ok] https://github.com/ksoichiro/Android-ObservableScrollView (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for smartdevicelink/sdl_java_suite: 2
# [ok] https://github.com/smartdevicelink/sdl_java_suite (5.01s)  PRs=2  Issues=3
#   [meta] Target commits for thyrlian/AwesomeValidation: 2
# [ok] https://github.com/thyrlian/AwesomeValidation (0.44s)  PRs=0  Issues=0
#   [meta] Target commits for MostafaGazar/soas: 1
# [ok] https://github.com/MostafaGazar/soas (0.4s)  PRs=0  Issues=0
#   [meta] Target commits for Stuart-campbell/RushOrm: 1
# [ok] https://github.com/Stuart-campbell/RushOrm (1.45s)  PRs=1  Issues=0
#   [meta] Target commits for posm/OpenMapKitAndroid: 1
# [ok] https://github.com/posm/OpenMapKitAndroid (2.1s)  PRs=1  Issues=1
#   [meta] Target commits for CarlosMChica/easyrecycleradapters: 1
# [ok] https://github.com/CarlosMChica/easyrecycleradapters (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for kost/NetworkMapper: 1
# [ok] https://github.com/kost/NetworkMapper (0.22s)  PRs=0  Issues=0
#   [meta] Target commits for dart-lang/http: 1
# [ok] https://github.com/dart-lang/http (2.11s)  PRs=1  Issues=0
#   [meta] Target commits for JakeWharton/RxBinding: 2
# [ok] https://github.com/JakeWharton/RxBinding (3.46s)  PRs=2  Issues=1
#   [meta] Target commits for moezbhatti/qksms: 1
# [ok] https://github.com/moezbhatti/qksms (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for takahirom/PreLollipopTransition: 1
# [ok] https://github.com/takahirom/PreLollipopTransition (1.36s)  PRs=1  Issues=0
#   [meta] Target commits for ooni/probe-android: 2
# [ok] https://github.com/ooni/probe-android (3.52s)  PRs=2  Issues=0
#   [meta] Target commits for hitherejoe/HackerNewsReader: 1
# [ok] https://github.com/hitherejoe/HackerNewsReader (1.48s)  PRs=1  Issues=0
#   [meta] Target commits for zsoltk/GameOfLife: 1
# [ok] https://github.com/zsoltk/GameOfLife (0.52s)  PRs=0  Issues=0
#   [meta] Target commits for talenguyen/PrettyBundle: 1
# [ok] https://github.com/talenguyen/PrettyBundle (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for fewlaps/flone-android: 1
# [ok] https://github.com/fewlaps/flone-android (0.35s)  PRs=0  Issues=0
#   [meta] Target commits for square/leakcanary: 1
# [ok] https://github.com/square/leakcanary (2.64s)  PRs=1  Issues=1
#   [meta] Target commits for rtoshiro/FullscreenVideoView: 1
# [ok] https://github.com/rtoshiro/FullscreenVideoView (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for kebernet/shortyz: 1
# [ok] https://github.com/kebernet/shortyz (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for Redgram/redgram-for-reddit: 1
# [ok] https://github.com/Redgram/redgram-for-reddit (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for servo/surfman: 1
# [ok] https://github.com/servo/surfman (1.45s)  PRs=1  Issues=0
#   [meta] Target commits for pilgr/Paper: 1
# [ok] https://github.com/pilgr/Paper (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for sky-map-team/stardroid: 2
# [ok] https://github.com/sky-map-team/stardroid (3.13s)  PRs=2  Issues=0
#   [meta] Target commits for MichaelEvans/Aftermath: 1
# [ok] https://github.com/MichaelEvans/Aftermath (1.52s)  PRs=1  Issues=0
#   [meta] Target commits for thiagokimo/Faker: 1
# [ok] https://github.com/thiagokimo/Faker (2.17s)  PRs=1  Issues=0
#   [meta] Target commits for concretesolutions/canarinho: 2
# [ok] https://github.com/concretesolutions/canarinho (1.81s)  PRs=1  Issues=0
#   [meta] Target commits for commons-app/apps-android-commons: 2
# [ok] https://github.com/commons-app/apps-android-commons (4.91s)  PRs=2  Issues=3
#   [meta] Target commits for TeamNewPipe/NewPipe: 2
# [ok] https://github.com/TeamNewPipe/NewPipe (2.91s)  PRs=1  Issues=2
#   [meta] Target commits for promeG/TinyPinyin: 1
# [ok] https://github.com/promeG/TinyPinyin (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for AAkira/ExpandableLayout: 1
# [ok] https://github.com/AAkira/ExpandableLayout (1.52s)  PRs=1  Issues=0
#   [meta] Target commits for hitherejoe/MVVM_Hacker_News: 1
# [ok] https://github.com/hitherejoe/MVVM_Hacker_News (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for kakajika/SwipeAwayDialog: 1
# [ok] https://github.com/kakajika/SwipeAwayDialog (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for getodk/collect: 2
# [ok] https://github.com/getodk/collect (2.78s)  PRs=1  Issues=1
#   [meta] Target commits for hannesa2/panoramaGL: 1
# [ok] https://github.com/hannesa2/panoramaGL (1.69s)  PRs=1  Issues=0
#   [meta] Target commits for ajitsing/ExpenseManager: 1
# [ok] https://github.com/ajitsing/ExpenseManager (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for 4eRTuk/audioview: 1
# [ok] https://github.com/4eRTuk/audioview (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for sqldelight/sqldelight: 3
# [ok] https://github.com/sqldelight/sqldelight (6.59s)  PRs=3  Issues=0
#   [meta] Target commits for sangcomz/FishBun: 2
# [ok] https://github.com/sangcomz/FishBun (3.21s)  PRs=2  Issues=1
#   [meta] Target commits for requery/requery: 1
# [ok] https://github.com/requery/requery (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for fossasia/loklak_wok_android: 1
# [ok] https://github.com/fossasia/loklak_wok_android (2.56s)  PRs=1  Issues=2
#   [meta] Target commits for andreynovikov/trekarta: 1
# [ok] https://github.com/andreynovikov/trekarta (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for liangpengfei/LoadingPopPoint: 1
# [ok] https://github.com/liangpengfei/LoadingPopPoint (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for douzifly/clear-todolist: 1
# [ok] https://github.com/douzifly/clear-todolist (0.3s)  PRs=0  Issues=0
#   [meta] No target commits for VREMSoftwareDevelopment/WiFiAnalyzer (repo_name=VREMSoftwareDevelopment__WiFiAnalyzer); skipping.
# [ok] https://github.com/VREMSoftwareDevelopment/WiFiAnalyzer (0.0s)  PRs=0  Issues=0
#   [meta] Target commits for XuDaojie/MultiStateView: 1
# [ok] https://github.com/XuDaojie/MultiStateView (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for TUBB/CalendarSelector: 1
# [ok] https://github.com/TUBB/CalendarSelector (0.21s)  PRs=0  Issues=0
#   [meta] Target commits for greenaddress/abcore: 1
# [ok] https://github.com/greenaddress/abcore (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for woxingxiao/FillBlankView: 1
# [ok] https://github.com/woxingxiao/FillBlankView (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for FabianTerhorst/Iron: 1
# [ok] https://github.com/FabianTerhorst/Iron (0.37s)  PRs=0  Issues=0
#   [meta] Target commits for riggaroo/AndroidDatabaseUpgrades: 1
# [ok] https://github.com/riggaroo/AndroidDatabaseUpgrades (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for amitshekhariitbhu/Fast-Android-Networking: 1
# [ok] https://github.com/amitshekhariitbhu/Fast-Android-Networking (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for voghDev/PdfViewPager: 1
# [ok] https://github.com/voghDev/PdfViewPager (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for renyuneyun/Easer: 2
# [ok] https://github.com/renyuneyun/Easer (0.71s)  PRs=0  Issues=0
#   [meta] Target commits for nukc/StateView: 1
# [ok] https://github.com/nukc/StateView (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for yeungeek/monkey-android: 1
# [ok] https://github.com/yeungeek/monkey-android (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for maksim-m/Popular-Movies-App: 1
# [ok] https://github.com/maksim-m/Popular-Movies-App (1.44s)  PRs=1  Issues=0
#   [meta] Target commits for RoRoche/AndroidStarter: 1
# [ok] https://github.com/RoRoche/AndroidStarter (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for ValentinFunk/BrainPhaser: 1
# [ok] https://github.com/ValentinFunk/BrainPhaser (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for tonilopezmr/Game-of-Thrones: 1
# [ok] https://github.com/tonilopezmr/Game-of-Thrones (0.4s)  PRs=0  Issues=0
#   [meta] Target commits for SecUSo/privacy-friendly-notes: 1
# [ok] https://github.com/SecUSo/privacy-friendly-notes (1.63s)  PRs=1  Issues=0
#   [meta] Target commits for SecUSo/privacy-friendly-todo-list: 1
# [ok] https://github.com/SecUSo/privacy-friendly-todo-list (1.51s)  PRs=1  Issues=0
#   [meta] Target commits for dbrodie/AdBuster: 1
# [ok] https://github.com/dbrodie/AdBuster (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for nextcloud/android: 5
# [ok] https://github.com/nextcloud/android (4.3s)  PRs=2  Issues=0
#   [meta] Target commits for javiersantos/PiracyChecker: 1
# [ok] https://github.com/javiersantos/PiracyChecker (1.38s)  PRs=1  Issues=0
#   [meta] Target commits for karonl/InDoorSurfaceView: 1
# [ok] https://github.com/karonl/InDoorSurfaceView (0.4s)  PRs=0  Issues=0
#   [meta] Target commits for miguelhincapie/CustomBottomSheetBehavior: 1
# [ok] https://github.com/miguelhincapie/CustomBottomSheetBehavior (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for SecUSo/privacy-friendly-pedometer: 1
# [ok] https://github.com/SecUSo/privacy-friendly-pedometer (1.85s)  PRs=1  Issues=0
#   [meta] Target commits for y-polek/TransmissionRemote: 2
# [ok] https://github.com/y-polek/TransmissionRemote (2.93s)  PRs=2  Issues=0
#   [meta] Target commits for medic/cht-gateway: 2
# [ok] https://github.com/medic/cht-gateway (2.84s)  PRs=1  Issues=1
#   [meta] Target commits for cliqz-oss/browser-android: 1
# [ok] https://github.com/cliqz-oss/browser-android (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for andremion/Villains-and-Heroes: 1
# [ok] https://github.com/andremion/Villains-and-Heroes (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for leandroBorgesFerreira/LoadingButtonAndroid: 1
# [ok] https://github.com/leandroBorgesFerreira/LoadingButtonAndroid (3.57s)  PRs=1  Issues=2
#   [meta] Target commits for jaredsburrows/android-gif-search: 2
# [ok] https://github.com/jaredsburrows/android-gif-search (1.76s)  PRs=1  Issues=0
#   [meta] Target commits for beemdevelopment/Aegis: 2
# [ok] https://github.com/beemdevelopment/Aegis (2.06s)  PRs=1  Issues=0
#   [meta] Target commits for nukc/LoadMoreWrapper: 1
# [ok] https://github.com/nukc/LoadMoreWrapper (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for ligi/SurvivalManual: 1
# [ok] https://github.com/ligi/SurvivalManual (3.48s)  PRs=1  Issues=4
#   [meta] Target commits for gotev/android-speech: 1
# [ok] https://github.com/gotev/android-speech (0.35s)  PRs=0  Issues=0
#   [meta] Target commits for Piasy/YaMvp: 1
# [ok] https://github.com/Piasy/YaMvp (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for FabianTerhorst/Floppy: 1
# [ok] https://github.com/FabianTerhorst/Floppy (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for guardianproject/proofmode-android: 1
# [ok] https://github.com/guardianproject/proofmode-android (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for vgaidarji/ci-matters: 2
# [ok] https://github.com/vgaidarji/ci-matters (1.63s)  PRs=1  Issues=0
#   [meta] Target commits for freeotp/freeotp-android: 1
# [ok] https://github.com/freeotp/freeotp-android (1.76s)  PRs=1  Issues=0
#   [meta] Target commits for VictorAlbertos/BreadcrumbsView: 1
# [ok] https://github.com/VictorAlbertos/BreadcrumbsView (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for ronaldsmartin/Material-ViewPagerIndicator: 1
# [ok] https://github.com/ronaldsmartin/Material-ViewPagerIndicator (1.57s)  PRs=1  Issues=0
#   [meta] Target commits for VictorAlbertos/SwipeCoordinator: 1
# [ok] https://github.com/VictorAlbertos/SwipeCoordinator (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for kickstarter/android-oss: 1
# [ok] https://github.com/kickstarter/android-oss (2.14s)  PRs=1  Issues=1
#   [meta] Target commits for michelelacorte/AndroidAppShortcuts: 1
# [ok] https://github.com/michelelacorte/AndroidAppShortcuts (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for massivedisaster/ADAL: 1
# [ok] https://github.com/massivedisaster/ADAL (0.21s)  PRs=0  Issues=0
#   [meta] Target commits for getsentry/sentry-react-native: 1
# [ok] https://github.com/getsentry/sentry-react-native (2.43s)  PRs=1  Issues=0
#   [meta] Target commits for AdevintaSpain/Barista: 2
# [ok] https://github.com/AdevintaSpain/Barista (2.55s)  PRs=1  Issues=1
#   [meta] Target commits for bilibili/boxing: 1
# [ok] https://github.com/bilibili/boxing (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for jungilhan/awesome-blogs-android: 1
# [ok] https://github.com/jungilhan/awesome-blogs-android (1.88s)  PRs=1  Issues=1
#   [meta] Target commits for MarcinMoskala/PreferenceHolder: 1
# [ok] https://github.com/MarcinMoskala/PreferenceHolder (0.32s)  PRs=0  Issues=0
#   [meta] Target commits for NiciDieNase/chaosflix: 1
# [ok] https://github.com/NiciDieNase/chaosflix (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for adorsys/secure-storage-android: 2
# [ok] https://github.com/adorsys/secure-storage-android (3.24s)  PRs=2  Issues=0
#   [meta] Target commits for JimmyDaddy/react-native-image-marker: 1
# [ok] https://github.com/JimmyDaddy/react-native-image-marker (2.1s)  PRs=1  Issues=1
#   [meta] Target commits for xurxodev/Movies-Kotlin-Kata: 1
# [ok] https://github.com/xurxodev/Movies-Kotlin-Kata (0.19s)  PRs=0  Issues=0
#   [meta] Target commits for HYY-yu/TableRecyclerView: 1
# [ok] https://github.com/HYY-yu/TableRecyclerView (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for zoff99/ToxAndroidRefImpl: 2
# [ok] https://github.com/zoff99/ToxAndroidRefImpl (0.55s)  PRs=0  Issues=0
#   [meta] Target commits for gdky005/AndroidBadge: 1
# [ok] https://github.com/gdky005/AndroidBadge (0.37s)  PRs=0  Issues=0
#   [meta] Target commits for EventFahrplan/EventFahrplan: 1
# [ok] https://github.com/EventFahrplan/EventFahrplan (2.12s)  PRs=1  Issues=1
#   [meta] Target commits for jianjunxiao/NiceVieoPlayer: 1
# [ok] https://github.com/jianjunxiao/NiceVieoPlayer (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for livefront/bridge: 2
# [ok] https://github.com/livefront/bridge (3.49s)  PRs=2  Issues=0
#   [meta] Target commits for glpi-project/android-inventory-agent: 2
# [ok] https://github.com/glpi-project/android-inventory-agent (3.21s)  PRs=2  Issues=0
#   [meta] Target commits for invertase/notifee: 2
# [ok] https://github.com/invertase/notifee (3.37s)  PRs=2  Issues=1
#   [meta] Target commits for mapbox/store-locator-android: 1
# [ok] https://github.com/mapbox/store-locator-android (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for syrjs/core: 1
# [ok] https://github.com/syrjs/core (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for seedvault-app/seedvault: 3
# [ok] https://github.com/seedvault-app/seedvault (6.02s)  PRs=3  Issues=2
#   [meta] Target commits for jerryOkafor/TimeLineView: 1
# [ok] https://github.com/jerryOkafor/TimeLineView (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for dgngulcan/droid-feed: 1
# [ok] https://github.com/dgngulcan/droid-feed (1.37s)  PRs=1  Issues=0
#   [meta] Target commits for appmattus/layercache: 2
# [ok] https://github.com/appmattus/layercache (4.07s)  PRs=2  Issues=1
#   [meta] Target commits for airbnb/paris: 2
# [ok] https://github.com/airbnb/paris (4.2s)  PRs=2  Issues=0
#   [meta] Target commits for sellmair/kompass: 1
# [ok] https://github.com/sellmair/kompass (1.41s)  PRs=1  Issues=0
#   [meta] Target commits for Crazy-Marvin/MetadataRemover: 2
# [ok] https://github.com/Crazy-Marvin/MetadataRemover (2.41s)  PRs=1  Issues=1
#   [meta] Target commits for PureWriter/ToastCompat: 1
# [ok] https://github.com/PureWriter/ToastCompat (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for brarcher/video-transcoder: 1
# [ok] https://github.com/brarcher/video-transcoder (1.49s)  PRs=1  Issues=0
#   [meta] Target commits for AndProx/AndProx: 1
# [ok] https://github.com/AndProx/AndProx (1.85s)  PRs=1  Issues=0
#   [meta] Target commits for BlueWallet/BlueWallet: 5
# [ok] https://github.com/BlueWallet/BlueWallet (5.56s)  PRs=3  Issues=0
#   [meta] Target commits for Criptext/Android-Email-Client: 1
# [ok] https://github.com/Criptext/Android-Email-Client (2.99s)  PRs=1  Issues=0
#   [meta] Target commits for PRosenb/AdbClipboard: 1
# [ok] https://github.com/PRosenb/AdbClipboard (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for izderadicka/audioserve-android: 1
# [ok] https://github.com/izderadicka/audioserve-android (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for CypherpunkArmory/UserLAnd: 1
# [ok] https://github.com/CypherpunkArmory/UserLAnd (1.65s)  PRs=1  Issues=0
#   [meta] Target commits for simpledotorg/simple-android: 1
# [ok] https://github.com/simpledotorg/simple-android (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for nhirokinet/bluelineconsole: 1
# [ok] https://github.com/nhirokinet/bluelineconsole (1.48s)  PRs=1  Issues=0
#   [meta] Target commits for NUmeroAndDev/MaterialGallery-android: 2
# [ok] https://github.com/NUmeroAndDev/MaterialGallery-android (2.95s)  PRs=2  Issues=0
#   [meta] Target commits for letelete/sleep-cycle-alarm: 1
# [ok] https://github.com/letelete/sleep-cycle-alarm (0.25s)  PRs=0  Issues=0
#   [meta] No target commits for MetaMask/metamask-mobile (repo_name=MetaMask__metamask-mobile); skipping.
# [ok] https://github.com/MetaMask/metamask-mobile (0.0s)  PRs=0  Issues=0
#   [meta] Target commits for admob-plus/admob-plus: 2
# [ok] https://github.com/admob-plus/admob-plus (1.28s)  PRs=0  Issues=0
#   [meta] Target commits for software-mansion/react-native-screens: 1
# [ok] https://github.com/software-mansion/react-native-screens (1.7s)  PRs=1  Issues=0
#   [meta] Target commits for Samsung/escargot: 1
# [ok] https://github.com/Samsung/escargot (1.68s)  PRs=1  Issues=0
#   [meta] Target commits for oxygen-updater/oxygen-updater: 1
# [ok] https://github.com/oxygen-updater/oxygen-updater (1.67s)  PRs=1  Issues=0
#   [meta] Target commits for uber/simple-store: 1
# [ok] https://github.com/uber/simple-store (1.92s)  PRs=1  Issues=0
#   [meta] Target commits for cuongpm/youtube-dl-android: 1
# [ok] https://github.com/cuongpm/youtube-dl-android (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for ActivityWatch/aw-android: 1
# [ok] https://github.com/ActivityWatch/aw-android (2.13s)  PRs=1  Issues=1
#   [meta] Target commits for liihuu/KLineChartAndroid: 1
# [ok] https://github.com/liihuu/KLineChartAndroid (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for UriahShaulMandel/BaldPhone: 7
# [ok] https://github.com/UriahShaulMandel/BaldPhone (3.26s)  PRs=1  Issues=0
#   [meta] Target commits for GabrielBB/Android-CutOut: 1
# [ok] https://github.com/GabrielBB/Android-CutOut (0.32s)  PRs=0  Issues=0
#   [meta] Target commits for Albert221/FastShopping: 1
# [ok] https://github.com/Albert221/FastShopping (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for readrops/Readrops: 1
# [ok] https://github.com/readrops/Readrops (7.4s)  PRs=0  Issues=0
#   [meta] Target commits for hannesstruss/unearthed: 1
# [ok] https://github.com/hannesstruss/unearthed (0.38s)  PRs=0  Issues=0
#   [meta] Target commits for twireapp/Twire: 1
# [ok] https://github.com/twireapp/Twire (1.66s)  PRs=1  Issues=0
#   [meta] No target commits for rainbow-me/rainbow (repo_name=rainbow-me__rainbow); skipping.
# [ok] https://github.com/rainbow-me/rainbow (0.0s)  PRs=0  Issues=0
#   [meta] Target commits for trynoice/android-app: 2
# [ok] https://github.com/trynoice/android-app (3.88s)  PRs=1  Issues=3
#   [meta] Target commits for evilcorpltd/aTox: 1
# [ok] https://github.com/evilcorpltd/aTox (2.04s)  PRs=1  Issues=1
#   [meta] Target commits for haroldadmin/MoonShot: 2
# [ok] https://github.com/haroldadmin/MoonShot (0.52s)  PRs=0  Issues=0
#   [meta] Target commits for jimmod/ShareToComputer: 1
# [ok] https://github.com/jimmod/ShareToComputer (1.95s)  PRs=1  Issues=1
#   [meta] Target commits for willowtreeapps/vocable-android: 6
# [ok] https://github.com/willowtreeapps/vocable-android (10.08s)  PRs=4  Issues=2
#   [meta] Target commits for agoda-com/ninjato: 1
# [ok] https://github.com/agoda-com/ninjato (0.34s)  PRs=0  Issues=0
#   [meta] Target commits for ipfs-shipyard/gomobile-ipfs: 1
#     [warn] issue #1337: error fetching issue: 404 Client Error: Not Found for url: https://api.github.com/repos/ipfs-shipyard/gomobile-ipfs/issues/1337?per_page=100&page=1
# [ok] https://github.com/ipfs-shipyard/gomobile-ipfs (5.89s)  PRs=1  Issues=7
#   [meta] Target commits for coil-kt/coil: 2
# [ok] https://github.com/coil-kt/coil (2.76s)  PRs=1  Issues=0
#   [meta] Target commits for DroidKaigi/conference-app-2020: 1
# [ok] https://github.com/DroidKaigi/conference-app-2020 (2.13s)  PRs=1  Issues=1
#   [meta] Target commits for lolo-io/OneList: 1
# [ok] https://github.com/lolo-io/OneList (2.22s)  PRs=1  Issues=2
#   [meta] Target commits for OpenTracksApp/OpenTracks: 2
# [ok] https://github.com/OpenTracksApp/OpenTracks (2.59s)  PRs=1  Issues=1
#   [meta] Target commits for natario1/GIFCompressor: 1
# [ok] https://github.com/natario1/GIFCompressor (0.39s)  PRs=0  Issues=0
#   [meta] Target commits for fluttercommunity/flutter_workmanager: 1
# [ok] https://github.com/fluttercommunity/flutter_workmanager (1.38s)  PRs=1  Issues=0
#   [meta] Target commits for ivnsch/rust_android_ios: 1
# [ok] https://github.com/ivnsch/rust_android_ios (1.28s)  PRs=1  Issues=0
#   [meta] Target commits for ThibaultBee/srtdroid: 1
# [ok] https://github.com/ThibaultBee/srtdroid (1.42s)  PRs=1  Issues=0
#   [meta] Target commits for kylecorry31/Trail-Sense: 1
# [ok] https://github.com/kylecorry31/Trail-Sense (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for tfcporciuncula/flow-preferences: 1
# [ok] https://github.com/tfcporciuncula/flow-preferences (0.2s)  PRs=0  Issues=0
#   [meta] Target commits for n8ebel/GitHubActionsAutomationSandbox: 1
# [ok] https://github.com/n8ebel/GitHubActionsAutomationSandbox (0.32s)  PRs=0  Issues=0
#   [meta] Target commits for joreilly/PeopleInSpace: 4
# [ok] https://github.com/joreilly/PeopleInSpace (3.38s)  PRs=2  Issues=0
#   [meta] Target commits for realm/realm-kotlin: 2
# [ok] https://github.com/realm/realm-kotlin (4.93s)  PRs=2  Issues=1
#   [meta] Target commits for square/cycler: 1
# [ok] https://github.com/square/cycler (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for hitherejoe/minimise: 1
# [ok] https://github.com/hitherejoe/minimise (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for vmiklos/plees-tracker: 2
# [ok] https://github.com/vmiklos/plees-tracker (1.77s)  PRs=1  Issues=0
#   [meta] Target commits for gotev/android-cookie-store: 1
# [ok] https://github.com/gotev/android-cookie-store (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for ReactiveCircus/streamlined: 1
# [ok] https://github.com/ReactiveCircus/streamlined (1.4s)  PRs=1  Issues=0
#   [meta] Target commits for ValterKasper/space-app: 1
# [ok] https://github.com/ValterKasper/space-app (0.18s)  PRs=0  Issues=0
#   [meta] Target commits for H-PixelDroid/PixelDroid: 2
# [ok] https://github.com/H-PixelDroid/PixelDroid (0.57s)  PRs=0  Issues=0
#   [meta] Target commits for Tommy-Geenexus/exif-eraser: 1
# [ok] https://github.com/Tommy-Geenexus/exif-eraser (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for RedMadRobot/PINkman: 1
# [ok] https://github.com/RedMadRobot/PINkman (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for MiSikora/laboratory: 1
# [ok] https://github.com/MiSikora/laboratory (1.74s)  PRs=1  Issues=1
#   [meta] Target commits for nschnettler/Compose-Scrobbler: 1
# [ok] https://github.com/nschnettler/Compose-Scrobbler (0.18s)  PRs=0  Issues=0
#   [meta] Target commits for rosuH/EasyWatermark: 1
# [ok] https://github.com/rosuH/EasyWatermark (1.5s)  PRs=1  Issues=0
#   [meta] Target commits for sakusaku3939/DeepLAndroid: 1
# [ok] https://github.com/sakusaku3939/DeepLAndroid (1.82s)  PRs=1  Issues=0
#   [meta] Target commits for softartdev/NoteDelight: 1
# [ok] https://github.com/softartdev/NoteDelight (0.36s)  PRs=0  Issues=0
#   [meta] Target commits for AdamMc331/AndroidStudyGuide: 1
# [ok] https://github.com/AdamMc331/AndroidStudyGuide (0.2s)  PRs=0  Issues=0
#   [meta] Target commits for hoc081098/ViewBindingDelegate: 1
# [ok] https://github.com/hoc081098/ViewBindingDelegate (0.37s)  PRs=0  Issues=0
#   [meta] Target commits for tfcporciuncula/phonemoji: 1
# [ok] https://github.com/tfcporciuncula/phonemoji (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for PatilShreyas/NotyKT: 1
# [ok] https://github.com/PatilShreyas/NotyKT (1.79s)  PRs=1  Issues=1
#   [meta] Target commits for android/codelab-android-compose: 1
# [ok] https://github.com/android/codelab-android-compose (1.61s)  PRs=1  Issues=0
#   [meta] Target commits for TwidereProject/TwidereX-Android: 1
# [ok] https://github.com/TwidereProject/TwidereX-Android (1.38s)  PRs=1  Issues=0
#   [meta] Target commits for nightscout/AndroidAPS: 4
# [ok] https://github.com/nightscout/AndroidAPS (6.1s)  PRs=3  Issues=2
#   [meta] Target commits for MackHartley/RoundedProgressBar: 1
# [ok] https://github.com/MackHartley/RoundedProgressBar (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for rozPierog/Cofi: 1
# [ok] https://github.com/rozPierog/Cofi (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for ErickSumargo/Dads: 1
# [ok] https://github.com/ErickSumargo/Dads (1.41s)  PRs=1  Issues=0
#   [meta] Target commits for alexbakker/webdav-provider: 1
# [ok] https://github.com/alexbakker/webdav-provider (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for thunderbiscuit/padawan-wallet: 1
# [ok] https://github.com/thunderbiscuit/padawan-wallet (1.99s)  PRs=1  Issues=1
#   [meta] Target commits for lcdsmao/JetTheme: 1
# [ok] https://github.com/lcdsmao/JetTheme (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for yogeshpaliyal/KeyPass: 1
# [ok] https://github.com/yogeshpaliyal/KeyPass (1.72s)  PRs=1  Issues=0
#   [meta] Target commits for square/curtains: 1
# [ok] https://github.com/square/curtains (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for Spikeysanju/Wiggles: 1
# [ok] https://github.com/Spikeysanju/Wiggles (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for wajahatkarim3/Imagine: 1
# [ok] https://github.com/wajahatkarim3/Imagine (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for jeziellago/Linkt: 1
# [ok] https://github.com/jeziellago/Linkt (0.21s)  PRs=0  Issues=0
#   [meta] Target commits for riggaroo/adopt-me-compose: 1
# [ok] https://github.com/riggaroo/adopt-me-compose (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for guolindev/android-dev-challenge-compose: 1
# [ok] https://github.com/guolindev/android-dev-challenge-compose (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for GerardPaligot/android-countdown: 1
# [ok] https://github.com/GerardPaligot/android-countdown (0.37s)  PRs=0  Issues=0
#   [meta] Target commits for okanaydin/Android-Compose-Challenge: 1
# [ok] https://github.com/okanaydin/Android-Compose-Challenge (0.33s)  PRs=0  Issues=0
#   [meta] Target commits for a914-gowtham/compose-ratingbar: 1
# [ok] https://github.com/a914-gowtham/compose-ratingbar (0.35s)  PRs=0  Issues=0
#   [meta] Target commits for joreilly/StarWars: 1
# [ok] https://github.com/joreilly/StarWars (1.38s)  PRs=1  Issues=0
#   [meta] Target commits for pauloaapereira/AndroidDevChallenge_Week4_JetWeatherfy: 1
# [ok] https://github.com/pauloaapereira/AndroidDevChallenge_Week4_JetWeatherfy (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for vitaviva/compose-weather: 1
# [ok] https://github.com/vitaviva/compose-weather (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for KaustubhPatange/navigator: 1
# [ok] https://github.com/KaustubhPatange/navigator (0.18s)  PRs=0  Issues=0
#   [meta] Target commits for arkivanov/android-dev-challenge-compose-2: 1
# [ok] https://github.com/arkivanov/android-dev-challenge-compose-2 (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for vitaviva/CountdownTimer: 1
# [ok] https://github.com/vitaviva/CountdownTimer (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for WangJie0822/Cashbook: 1
# [ok] https://github.com/WangJie0822/Cashbook (1.28s)  PRs=1  Issues=0
#   [meta] Target commits for RBusarow/Tangle: 1
# [ok] https://github.com/RBusarow/Tangle (2.54s)  PRs=1  Issues=2
#   [meta] Target commits for michaeltroger/pdfwallet-android: 1
# [ok] https://github.com/michaeltroger/pdfwallet-android (1.5s)  PRs=1  Issues=0
#   [meta] Target commits for nanihadesuka/NovelDokusha: 1
# [ok] https://github.com/nanihadesuka/NovelDokusha (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for OlauncherCF/OlauncherCF: 1
# [ok] https://github.com/OlauncherCF/OlauncherCF (1.65s)  PRs=1  Issues=0
#   [meta] Target commits for doublesymmetry/KotlinAudio: 1
# [ok] https://github.com/doublesymmetry/KotlinAudio (2.18s)  PRs=1  Issues=0
#   [meta] Target commits for bitfireAT/davx5-ose: 3
# [ok] https://github.com/bitfireAT/davx5-ose (3.71s)  PRs=2  Issues=0
#   [meta] Target commits for alexstyl/contactstore: 1
# [ok] https://github.com/alexstyl/contactstore (2.07s)  PRs=1  Issues=1
#   [meta] Target commits for square/papa: 1
# [ok] https://github.com/square/papa (0.32s)  PRs=0  Issues=0
#   [meta] Target commits for bitfireAT/icsx5: 2
# [ok] https://github.com/bitfireAT/icsx5 (3.36s)  PRs=2  Issues=0
#   [meta] Target commits for burnoo/cokoin: 1
# [ok] https://github.com/burnoo/cokoin (0.33s)  PRs=0  Issues=0
#   [meta] Target commits for scribe-org/Scribe-Android: 1
# [ok] https://github.com/scribe-org/Scribe-Android (2.45s)  PRs=1  Issues=1
#   [meta] Target commits for StefanIlchev/ElementumService: 1
# [ok] https://github.com/StefanIlchev/ElementumService (0.34s)  PRs=0  Issues=0
#   [meta] Target commits for rafsanjani/datepickertimeline: 1
# [ok] https://github.com/rafsanjani/datepickertimeline (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for Nailik/rhasspy_mobile: 1
# [ok] https://github.com/Nailik/rhasspy_mobile (1.71s)  PRs=1  Issues=0
#   [meta] Target commits for android/nowinandroid: 4
# [ok] https://github.com/android/nowinandroid (6.63s)  PRs=3  Issues=1
#   [meta] Target commits for krzdabrowski/android-starter-2022: 1
# [ok] https://github.com/krzdabrowski/android-starter-2022 (1.54s)  PRs=1  Issues=0
#   [meta] Target commits for ruffle-rs/ruffle-android: 1
# [ok] https://github.com/ruffle-rs/ruffle-android (1.68s)  PRs=1  Issues=0
#   [meta] Target commits for fornewid/naver-map-compose: 1
# [ok] https://github.com/fornewid/naver-map-compose (1.46s)  PRs=1  Issues=0
#   [meta] Target commits for DroidKaigi/conference-app-2022: 2
# [ok] https://github.com/DroidKaigi/conference-app-2022 (2.29s)  PRs=1  Issues=0
#   [meta] Target commits for slackhq/circuit: 2
# [ok] https://github.com/slackhq/circuit (5.0s)  PRs=2  Issues=1
#   [meta] Target commits for maxkeppeler/sheets-compose-dialogs: 1
# [ok] https://github.com/maxkeppeler/sheets-compose-dialogs (0.67s)  PRs=0  Issues=0
#   [meta] Target commits for nkuppan/expensemanager: 1
# [ok] https://github.com/nkuppan/expensemanager (0.39s)  PRs=0  Issues=0
#   [meta] Target commits for lopspower/PokeCardCompose: 1
# [ok] https://github.com/lopspower/PokeCardCompose (1.43s)  PRs=1  Issues=0
#   [meta] Target commits for sopt-makers/sopt-android: 1
# [ok] https://github.com/sopt-makers/sopt-android (2.75s)  PRs=1  Issues=2
#   [meta] Target commits for zimly/zimly-backup: 1
# [ok] https://github.com/zimly/zimly-backup (0.35s)  PRs=0  Issues=0
#   [meta] Target commits for TechbeeAT/jtxBoard: 6
# [ok] https://github.com/TechbeeAT/jtxBoard (7.84s)  PRs=4  Issues=1
#   [meta] Target commits for cashapp/paraphrase: 1
# [ok] https://github.com/cashapp/paraphrase (1.84s)  PRs=1  Issues=0
#   [meta] Target commits for google/jetpack-camera-app: 1
# [ok] https://github.com/google/jetpack-camera-app (2.03s)  PRs=1  Issues=0
#   [meta] Target commits for DesarrolloAntonio/Shiori-Android-Client: 1
# [ok] https://github.com/DesarrolloAntonio/Shiori-Android-Client (1.78s)  PRs=1  Issues=0
#   [meta] Target commits for mshdabiola/NotePad: 1
# [ok] https://github.com/mshdabiola/NotePad (0.38s)  PRs=0  Issues=0
#   [meta] Target commits for anilbeesetti/nextplayer: 1
# [ok] https://github.com/anilbeesetti/nextplayer (1.48s)  PRs=1  Issues=0
#   [meta] Target commits for chenxiaolong/RSAF: 1
# [ok] https://github.com/chenxiaolong/RSAF (1.45s)  PRs=1  Issues=0
#   [meta] Target commits for irgaly/kfswatch: 1
# [ok] https://github.com/irgaly/kfswatch (1.62s)  PRs=1  Issues=0
#   [meta] Target commits for droidconKE/droidconKeKotlin: 1
# [ok] https://github.com/droidconKE/droidconKeKotlin (3.4s)  PRs=1  Issues=2
#   [meta] Target commits for TharunBalaji2004/android-ci-cd: 1
# [ok] https://github.com/TharunBalaji2004/android-ci-cd (0.3s)  PRs=0  Issues=0
#   [meta] Target commits for orgzly-revived/orgzly-android-revived: 1
# [ok] https://github.com/orgzly-revived/orgzly-android-revived (1.82s)  PRs=1  Issues=0
#   [meta] Target commits for mjaakko/NeoStumbler: 1
# [ok] https://github.com/mjaakko/NeoStumbler (2.01s)  PRs=1  Issues=1
#   [meta] Target commits for pachli/pachli-android: 1
# [ok] https://github.com/pachli/pachli-android (2.09s)  PRs=1  Issues=0
#   [meta] Target commits for JackEblan/Geto: 1
# [ok] https://github.com/JackEblan/Geto (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for f-arslan/GptMap: 1
# [ok] https://github.com/f-arslan/GptMap (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for FliegendeWurst/TriliumDroid: 1
# [ok] https://github.com/FliegendeWurst/TriliumDroid (0.25s)  PRs=0  Issues=0
#   [meta] Target commits for t895/DNSNet: 1
# [ok] https://github.com/t895/DNSNet (0.32s)  PRs=0  Issues=0
#   [meta] Target commits for linroid/Pexels: 1
# [ok] https://github.com/linroid/Pexels (0.37s)  PRs=0  Issues=0
#   [meta] Target commits for gemwalletcom/gem-android: 1
# [ok] https://github.com/gemwalletcom/gem-android (1.81s)  PRs=1  Issues=0
#   [meta] Target commits for CatimaLoyalty/Android: 2
# [ok] https://github.com/CatimaLoyalty/Android (2.5s)  PRs=1  Issues=1
#   [meta] Target commits for flauschtrud/broccoli: 2
# [ok] https://github.com/flauschtrud/broccoli (0.87s)  PRs=0  Issues=0
#   [meta] Target commits for SwissCovid/swisscovid-app-android: 1
# [ok] https://github.com/SwissCovid/swisscovid-app-android (1.81s)  PRs=1  Issues=0
#   [meta] Target commits for Faltenreich/Diaguard: 1
# [ok] https://github.com/Faltenreich/Diaguard (0.24s)  PRs=0  Issues=0
#   [meta] Target commits for Five-Prayers/five-prayers-android: 1
# [ok] https://github.com/Five-Prayers/five-prayers-android (0.34s)  PRs=0  Issues=0
#   [meta] Target commits for v2er-app/Android: 1
# [ok] https://github.com/v2er-app/Android (1.68s)  PRs=1  Issues=0
#   [meta] Target commits for thevindu-w/clip_share_client: 1
# [ok] https://github.com/thevindu-w/clip_share_client (0.35s)  PRs=0  Issues=0
#   [meta] Target commits for Hny0305Lin/NLChat: 1
# [ok] https://github.com/Hny0305Lin/NLChat (1.65s)  PRs=1  Issues=0
#   [meta] Target commits for ably/ably-flutter: 1
# [ok] https://github.com/ably/ably-flutter (1.93s)  PRs=1  Issues=0
#   [meta] Target commits for jerson/flutter-rsa: 1
# [ok] https://github.com/jerson/flutter-rsa (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for jerson/flutter-openpgp: 1
# [ok] https://github.com/jerson/flutter-openpgp (0.26s)  PRs=0  Issues=0
#   [meta] Target commits for isar/isar: 4
# [ok] https://github.com/isar/isar (4.88s)  PRs=2  Issues=2
#   [meta] Target commits for am15h/tflite_flutter_helper: 1
# [ok] https://github.com/am15h/tflite_flutter_helper (1.56s)  PRs=1  Issues=0
#   [meta] Target commits for privacybydesign/irmamobile: 1
# [ok] https://github.com/privacybydesign/irmamobile (0.5s)  PRs=0  Issues=0
#   [meta] Target commits for salvadordeveloper/flutter-crypto-app: 1
# [ok] https://github.com/salvadordeveloper/flutter-crypto-app (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for SharezoneApp/sharezone-app: 3
#     [warn] issue #0: error fetching issue: 404 Client Error: Not Found for url: https://api.github.com/repos/SharezoneApp/sharezone-app/issues/0?per_page=100&page=1
# [ok] https://github.com/SharezoneApp/sharezone-app (13.41s)  PRs=3  Issues=13
#   [meta] Target commits for alphacep/vosk-flutter: 1
# [ok] https://github.com/alphacep/vosk-flutter (2.31s)  PRs=1  Issues=1
#   [meta] Target commits for abdelaziz-mahdy/pytorch_lite: 1
# [ok] https://github.com/abdelaziz-mahdy/pytorch_lite (1.79s)  PRs=1  Issues=0
#   [meta] Target commits for passsy/spot: 1
# [ok] https://github.com/passsy/spot (2.07s)  PRs=1  Issues=1
#   [meta] Target commits for zeref278/flutter_boilerplate: 1
# [ok] https://github.com/zeref278/flutter_boilerplate (1.48s)  PRs=1  Issues=0
#   [meta] Target commits for dart-lang/native: 1
# [ok] https://github.com/dart-lang/native (2.54s)  PRs=1  Issues=1
#   [meta] Target commits for flet-dev/serious-python: 1
# [ok] https://github.com/flet-dev/serious-python (1.58s)  PRs=1  Issues=0
#   [meta] Target commits for natsuk4ze/gal: 3
# [ok] https://github.com/natsuk4ze/gal (2.23s)  PRs=1  Issues=0
#   [meta] Target commits for a-mabe/OpenHIIT: 5
# [ok] https://github.com/a-mabe/OpenHIIT (4.53s)  PRs=3  Issues=0
#   [meta] Target commits for firebase/FirebaseUI-Flutter: 2
# [ok] https://github.com/firebase/FirebaseUI-Flutter (3.53s)  PRs=2  Issues=1
#   [meta] Target commits for microservicer/flutter-pipelines: 1
# [ok] https://github.com/microservicer/flutter-pipelines (0.31s)  PRs=0  Issues=0
#   [meta] Target commits for Bdaya-Dev/oidc: 1
# [ok] https://github.com/Bdaya-Dev/oidc (0.28s)  PRs=0  Issues=0
#   [meta] Target commits for brandonp2412/FitBook: 2
# [ok] https://github.com/brandonp2412/FitBook (0.76s)  PRs=0  Issues=0
#   [meta] Target commits for andriydruk/swift-weather-app: 1
# [ok] https://github.com/andriydruk/swift-weather-app (1.39s)  PRs=1  Issues=0
#   [meta] Target commits for invertase/react-native-google-mobile-ads: 2
# [ok] https://github.com/invertase/react-native-google-mobile-ads (2.51s)  PRs=1  Issues=1
#   [meta] Target commits for jameshnsears/QuoteUnquote: 1
# [ok] https://github.com/jameshnsears/QuoteUnquote (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for erkkah/naett: 1
# [ok] https://github.com/erkkah/naett (0.27s)  PRs=0  Issues=0
#   [meta] Target commits for haiyangwu/mediasoup-client-android: 1
# [ok] https://github.com/haiyangwu/mediasoup-client-android (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for openthread/ot-commissioner: 1
# [ok] https://github.com/openthread/ot-commissioner (3.27s)  PRs=1  Issues=1
#   [meta] Target commits for XRPL-Labs/Xaman-App: 1
# [ok] https://github.com/XRPL-Labs/Xaman-App (2.13s)  PRs=1  Issues=0
#   [meta] Target commits for synonymdev/bitkit: 1
# [ok] https://github.com/synonymdev/bitkit (1.85s)  PRs=1  Issues=0
#   [meta] Target commits for streetwriters/notesnook: 2
# [ok] https://github.com/streetwriters/notesnook (0.77s)  PRs=0  Issues=0
#   [meta] Target commits for twilio/twilio-voice-react-native: 1
# [ok] https://github.com/twilio/twilio-voice-react-native (1.65s)  PRs=1  Issues=0
#   [meta] Target commits for mlcommons/mobile_app_open: 1
# [ok] https://github.com/mlcommons/mobile_app_open (2.21s)  PRs=1  Issues=0
#   [meta] Target commits for aws/amazon-ivs-react-native-player: 1
# [ok] https://github.com/aws/amazon-ivs-react-native-player (1.6s)  PRs=1  Issues=0
#   [meta] Target commits for inaturalist/iNaturalistReactNative: 3
# [ok] https://github.com/inaturalist/iNaturalistReactNative (4.78s)  PRs=2  Issues=1
#   [meta] Target commits for LedgerHQ/ledger-live: 2
# [ok] https://github.com/LedgerHQ/ledger-live (4.9s)  PRs=1  Issues=2
#   [meta] No target commits for pytorch/executorch (repo_name=pytorch__executorch); skipping.
# [ok] https://github.com/pytorch/executorch (0.0s)  PRs=0  Issues=0
#   [meta] Target commits for EnsembleUI/ensemble: 1
# [ok] https://github.com/EnsembleUI/ensemble (0.29s)  PRs=0  Issues=0
#   [meta] Target commits for elftausend/custos: 1
# [ok] https://github.com/elftausend/custos (1.87s)  PRs=1  Issues=0
#   [meta] Target commits for haqq-network/haqq-wallet: 1
# [ok] https://github.com/haqq-network/haqq-wallet (2.12s)  PRs=1  Issues=0
#   [meta] Target commits for juancastillo0/wasm_run: 1
# [ok] https://github.com/juancastillo0/wasm_run (0.22s)  PRs=0  Issues=0
#   [meta] Target commits for ice-blockchain/mobile-app: 1
# [ok] https://github.com/ice-blockchain/mobile-app (0.53s)  PRs=0  Issues=0
#   [meta] Target commits for zkmopro/mopro: 1
# [ok] https://github.com/zkmopro/mopro (3.2s)  PRs=1  Issues=3
#   [meta] Target commits for prisma/react-native-prisma: 1
# [ok] https://github.com/prisma/react-native-prisma (1.88s)  PRs=1  Issues=0
#   [meta] Target commits for ianthetechie/uniffi-starter: 1
# [ok] https://github.com/ianthetechie/uniffi-starter (0.23s)  PRs=0  Issues=0
#   [meta] Target commits for ICBNetwork/web3-Wallet: 1
# [ok] https://github.com/ICBNetwork/web3-Wallet (0.22s)  PRs=0  Issues=0
#   [meta] Target commits for RocketChat/Rocket.Chat.ReactNative: 3
# [ok] https://github.com/RocketChat/Rocket.Chat.ReactNative (6.9s)  PRs=2  Issues=5
#   [meta] Target commits for charpeni/react-native-url-polyfill: 1
# [ok] https://github.com/charpeni/react-native-url-polyfill (1.34s)  PRs=1  Issues=0
#
# Done. OK=355, FAIL=0. Manifest: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\metadata_manifestV1.0.csv

# %% [markdown]
# ## Step 2: Mining
# add a baseline to read the repos from the begining not from the first change

# %%
from __future__ import annotations

import csv
import json
import os
import random
import re
import shutil
import subprocess
import sys
import time
from concurrent.futures import ThreadPoolExecutor as PoolExecutor, as_completed
from datetime import datetime
from functools import lru_cache
from pathlib import Path
from typing import Dict, Iterable, List, Optional, Set, Tuple

# ===========================
# Config (EDIT THESE PATHS)
# ===========================
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
INPUT_CLONES = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0")  ## Read from the same as RQ3 clones
OUTPUT_MINE  = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\mineV1.0")
# Where PR / issues JSON files live (owner__repo_PRs.json, owner__repo_Issues.json)
META_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\metadataV1.0")



# Study end date (UTC)
CUTOFF_ISO = "2025-08-10 23:59:59 +0000"

# Timeline scope for evolution analysis:
#   "repo_wide" -> walk all origin/* heads (recommended for RQ3)
#   "default"   -> only default branch history
TIMELINE_SCOPE = "repo_wide"

# Performance / behavior toggles
MAX_REPOS = 0  # 0 = all
MAX_WORKERS = min(32, (os.cpu_count() or 8) * 2)
RESUME_IF_EXISTS = True
SUPPRESS_EMPTY_ROWS = True
CAPTURE_EMPTY_GAPS = True
EMIT_NONE_STATE = False

# Blob size guards
BLOB_MAX_SIZE = 2_000_000
HARD_MAX_SIZE = 5_000_000

# High-priority CI paths never skipped (even if large)
HIGH_PRIORITY_CI_PATHS = {
    ".github/workflows",
    ".gitlab-ci.yml",
    "azure-pipelines.yml",
    ".circleci/config.yml",
    ".bitrise.yml",
    ".travis.yml",
}

# ===========================
# Quick startup checks
# ===========================
def _failfast_checks() -> None:
    if shutil.which("git") is None:
        print("[fatal] Git not found in PATH. Install Git and/or add it to PATH.", file=sys.stderr)
        raise SystemExit(1)
    if not WORK_ROOT.exists():
        print(f"[fatal] WORK_ROOT does not exist: {WORK_ROOT}", file=sys.stderr)
        raise SystemExit(1)
    if not INPUT_CLONES.exists():
        print(f"[warn] INPUT_CLONES does not exist yet: {INPUT_CLONES}")
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

# ===========================
# File classifiers
# ===========================
YAML_EXTS = (".yml", ".yaml")
GRADLE_NAMES = {"build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts"}
GRADLE_EXTS = (".gradle", ".gradle.kts")
SCRIPT_EXTS = (".sh", ".bat", ".cmd", ".ps1")
CI_BUILD_SPECIAL = {"Jenkinsfile", ".travis.yml", "azure-pipelines.yml", ".gitlab-ci.yml", "circle.yml"}
XML_BUILD_FILES = {"pom.xml", "build.xml", "config.xml"}

def is_yaml(path: str) -> bool:
    return os.path.splitext(path)[1].lower() in YAML_EXTS or os.path.basename(path) in CI_BUILD_SPECIAL

def is_gradle(path: str) -> bool:
    name = os.path.basename(path)
    ext = os.path.splitext(path)[1].lower()
    return name in GRADLE_NAMES or ext in GRADLE_EXTS

def is_script(path: str) -> bool:
    ext = os.path.splitext(path)[1].lower()
    return ext in SCRIPT_EXTS or os.path.basename(path) in ("Jenkinsfile",)

def is_ci_xml_or_build_xml(path: str) -> bool:
    return os.path.basename(path).lower() in {n.lower() for n in XML_BUILD_FILES}

def is_relevant_file(path: str) -> bool:
    return is_yaml(path) or is_gradle(path) or is_script(path) or is_ci_xml_or_build_xml(path)

def is_high_priority_ci_path(path: str) -> bool:
    norm = path.replace("\\", "/")
    base = os.path.basename(norm)
    if base in HIGH_PRIORITY_CI_PATHS:
        return True
    for root in HIGH_PRIORITY_CI_PATHS:
        if norm.startswith(root.rstrip("/") + "/"):
            return True
    return False

# ===========================
# Regex helpers & normalizers
# ===========================
COMMENT_LINE_RE = re.compile(r"(?m)^\s*(#|//|REM\b|::).*?$")

def strip_comments(raw: str) -> str:
    return COMMENT_LINE_RE.sub("", raw or "")

# --- Gradle comment stripper (preserves http(s)://) ---
def strip_comments_gradle(text: str) -> str:
    if not text:
        return ""
    s = re.sub(r"/\*.*?\*/", "", text, flags=re.S)                 # /* ... */
    s = re.sub(r"(?<!:)//.*?$", "", s, flags=re.M)                  # // ...
    return s

def normalize_block_keys(text: str) -> str:
    # expose content of run/script/command keys and drop YAML dashes before likely shell lines
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(?!\||>|\|\-)\s*(.+)$", r"\2", text)
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(\||>|\|\-)\s*$", "", text)
    text = re.sub(
        r"(?m)^(\s*)-\s*(?=(?:\./|\.\\|bash|sh|pwsh|powershell|gradle(?:w)?|adb|flutter|gcloud|saucectl|appcenter)\b)",
        r"\1",
        text,
    )
    return text

IGNORE_GHA_ACTIONS_RE = re.compile(
    r"(?mi)^\s*uses\s*:\s*(docker/(?:setup-qemu-action|setup-buildx-action|build-push-action|login-action)|actions/checkout|docker/setup-qemu-action|docker/setup-buildx-action)@.*$"
)

def strip_irrelevant_ci_lines(text: str) -> str:
    return IGNORE_GHA_ACTIONS_RE.sub("", text or "")

GHA_EXPR_RE = re.compile(r"\${{\s*[^}]+}}")

def pre_sanitize(text: str) -> str:
    return GHA_EXPR_RE.sub("", text or "")

# Gradle command shapes (for CI scripts/YAML)
GRADLE_PREFIX = (
    r"^\s*"
    r"(?:\S+=\S+\s+)*"
    r"(?:sudo\s+)?"
    r"(?:(?:bash|sh)\s+-c[l]?\s+[\'\"]?)?"
    r"(?:[^#\n;]*?&&\s+)?"
    r"(?:cd\s+\S+\s+&&\s+)?"
    r"(?:\./|\.\\)?gradle(?:w)?(?:\.bat)?"
)
GRADLE_ANYWHERE = r"(?i)[^\n]*\bgradle(?:w)?(?:\.bat)?[^\n]*"
GRADLE_ANYWHERE_RE = re.compile(GRADLE_ANYWHERE)
GRADLE_BUILD_ACTION_RE = re.compile(r"(?mi)\buses\s*:\s*(gradle/gradle-build-action|gradle/actions/setup-gradle)@")
NON_TEST_PREFIX = r"(?:assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)"
SHELL_PREFIX = r"(?:\S+=\S+\s+)*(?:sudo\s+)?(?:(?:bash|sh|pwsh|powershell)\s+-c\s+[\'\"]?)?(?:[^#\n;]*?&&\s+)?"

# Device / env patterns (CI side)
EMULATOR_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}(?:\s|^)(?:(?:\./|\.\\)?(?:emulator)(?:\.exe)?)\b[^\n]*-avd\s+\S+"
ADB_WAIT_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+wait[- ]?for[- ]?device\b"
ADB_SERIAL_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+-s\s+(?:emulator-\d+|localhost:\d+|127\.0\.0\.1:\d+)"
REAL_DEVICE_LINE = rf"(?mi)^\s*adb\s+-s\s+(?!emulator-\d+\b)(?!localhost:\d+\b)(?!127\.0\.0\.1:\d+\b)\S+\b"

def compile_any(patterns: List[str], flags: int = re.I | re.M) -> List[re.Pattern]:
    return [re.compile(p, flags) for p in patterns]

def any_match(patterns: Iterable, text: str) -> bool:
    for p in patterns:
        if isinstance(p, str):
            p = re.compile(p, re.I | re.M)
        if p.search(text):
            return True
    return False

def unique_preserve(seq: Iterable[str]) -> List[str]:
    seen: Set[str] = set()
    out: List[str] = []
    for x in seq:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

# -------- DEVICE SOURCES --------
DEVICE_SOURCES = [
    ("Real_Device", "adb -s <serial> (physical)", [REAL_DEVICE_LINE]),
    ("Emulator", "adb -s emulator-serial", [ADB_SERIAL_LINE]),
    ("Emulator", "adb wait-for-device", [ADB_WAIT_LINE]),
    ("Emulator", "emulator -avd/@", [EMULATOR_LINE]),
    ("Emulator", "android-wait-for-emulator", [r"(?mi)^\s*(?:\./)?android-wait-for-emulator\b"]),
    ("Emulator", "start-emulator.sh", [r"(?mi)^\s*start-emulator\.sh\b"]),
    ("Emulator", "android create avd", [r"\bandroid\b[^\n]*\bcreate\s+avd\b"]),
    # ("Emulator", "circleci android orb", [
    #     r"(?mi)^\s*(?:-\s*)?android/start-emulator-and-run-tests\s*:",
    #     r"(?mi)^\s*system-image\s*:\s*system-images;android-\d+;google_apis;"
    # ]),
    ("Emulator", "circleci android orb", [
    r"(?mi)^\s*(?:-\s*)?android/(?:start-emulator-and-run-tests|create-avd|launch-emulator)\s*:",
    r"(?mi)^\s*system-image\s*:\s*system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*);(?:default|google_apis)[^\s]*"
    ]),
    ("Emulator", "reactivecircus runner", [r"(?mi)\buses\s*:\s*reactivecircus/android-emulator-runner@[\w\.\-]+"]),
    ("Emulator", "malinskiy runner", [r"(?mi)\buses\s*:\s*malinskiy/action-android/emulator-run-cmd@[\w\.\-]+"]),
    ("Emulator", "sys-img component", [
        r"(?m)^\s*-\s*sys-img-[^\s]*-android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b",
        r"(?m)^\s*-\s*sys-img-[^\s]*-google_apis-[^\s]*(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "avdmanager", [r"(?m)^\s*\S*avdmanager\b"]),
    ("Emulator", "sdkmanager system-images/emulator", [
        r'^\s*\S*sdkmanager\b[^\n"]*"system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)[^"\n]*"',
        r"^\s*\S*sdkmanager\b[^\n]*\bsystem-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "other gha emulator", [
        r"(?mi)^\s*uses\s*:\s*vgaidarji/android-github-actions-emulator@[\w\.\-]+",
        r"(?mi)^\s*uses\s*:\s*(?!reactivecircus/android-emulator-runner@)(?!malinskiy/action-android/emulator-run-cmd@)(?!emulator-wtf/run-tests@)[\w\.-]+/[\w\./-]*android[\w\./-]*(?:\bemulator\b|\bavd\b)[\w\./-]*@[\w\.\-]+"
    ]),
    ("Third_Party_Lab", "gcloud firebase", [r"(?mi)^[^\n]*\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "browserstack/bstack", [r"(?i)\b(browserstack|bstack)\b"]),
    ("Third_Party_Lab", "appcenter test", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "maestro cloud", [r"(?mi)^[^\n]*\bmaestro\s+cloud\b"]),
    ("Third_Party_Lab", "emulator.wtf action", [
        r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+",
        r"(?i)\bemulator\.wtf\b"
    ]),
]
DEVICE_PATTERNS = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in DEVICE_SOURCES]

# -------- Triggers (CI/YAML side) --------
TRIGGER_SOURCES_PRIMARY = [
    ("Gradle", "connectedAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedandroidtest\b[^\n\r]*"]),
    ("Gradle", "connected.*Android.*", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b(?![^\n\r]*\b(?:{NON_TEST_PREFIX})[\w-]*androidtest\b)[^\n\r]*"]),
    ("Gradle", "connectedCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedcheck\b[^\n\r]*"]),
    ("Gradle", "cAT shorthand", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*cAT\b[^\n\r]*"]),
    ("Gradle", "deviceCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b[^\n\r]*"]),
    ("Gradle", "managedDevice AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?!{NON_TEST_PREFIX})(?:manageddevice|device)[\w:-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "variant/device AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "Spoon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bmarathon(?:\w*androidtest)?\b"]),
    ("ADB", "am instrument", [r"(?mi)^[^\n]*\bam\s+instrument\b"]),
    ("Third_Party_Lab", "gcloud firebase (instr)", [r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run[^\n]*\b(--test\b|--type\s+instrumentation\b)"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "appcenter", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "emulator.wtf run", [r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+", r"(?i)\bemulator\.wtf\b"]),
]
TRIGGER_SOURCES_PRIMARY += [
    ("Gradle", "generateBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*generate(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "collectBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*collect(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "connectedBenchmarkAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedbenchmarkandroidtest\b[^\n\r]*"]),
]

TRIGGER_SOURCES_ANYWHERE = [
    ("Gradle", "connected (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b"]),
    ("Gradle", "connectedAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedandroidtest\b"]),
    ("Gradle", "connectedCheck (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connectedcheck\b"]),
    ("Gradle", "managedDevice AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b"]),
    ("Gradle", "variant/device AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})[\w-]*androidtest\b"]),
    ("Gradle", "Spoon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bmarathon(?:\w*androidtest)?\b"]),
]
TRIGGER_SOURCES_ANYWHERE += [
    ("Gradle", "generateBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bgenerate(?:\w*?)baselineprofile\b"]),
    ("Gradle", "collectBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bcollect(?:\w*?)baselineprofile\b"]),
    ("Gradle", "connectedBenchmarkAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedbenchmarkandroidtest\b"]),
]

TRIGGER_PATTERNS_PRIMARY  = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_PRIMARY]
TRIGGER_PATTERNS_ANYWHERE = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_ANYWHERE]

def collect_hits_with_groups(patterns, text: str):
    labels = []
    groups = []
    for grp, lbl, pats in patterns:
        if any_match(pats, text):
            labels.append(lbl)
            groups.append(grp)
    return unique_preserve(labels), unique_preserve(groups)

# GHA gradle inputs guard
GHA_GRADLE_INPUTS = compile_any([
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connectedcheck\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:(?:[:\w-]+:)*) (?!assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)[\w-]*androidtest\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*cAT\b",
])

PROVIDER_PATTERNS = [
    ("emulator-wtf", compile_any([r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@", r"(?i)\bemulator\.wtf\b"])),
    ("firebase-test-lab", compile_any([r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b", r"(?mi)\bflank\s+android\s+run\b"])),
    ("browserstack", compile_any([r"(?i)\bbrowserstack\b", r"(?i)\bbstack\b"])),
    ("sauce-labs", compile_any([r"(?mi)\bsaucectl(?:\s+run)?\b", r"(?mi)\bsauce\s+ctl\b"])),
    ("appcenter", compile_any([r"(?mi)\bappcenter\s+test\s+run\s+android\b"])),
    ("maestro-cloud", compile_any([r"(?mi)\bmaestro\s+cloud\b"])),
]

INLINE_DEVICE_HINTS = compile_any([
    r"(?mi)^\s*devices\s*:\s*\|",
    r"(?mi)\b--device\b",
    r"(?mi)\bmodel\s*=\s*[^,\s]+",
    r"(?mi)\bversion\s*=\s*\d+",
    r"(?mi)\blocale\s*=\s*[-\w]+",
    r"(?mi)\borientation\s*=\s*(portrait|landscape)",
    r"(?mi)^\s*with-orchestrator\s*:\s*true\b",
    r"(?mi)\b--use-orchestrator\b",
    r"(?mi)\bnum-flaky-test-attempts\s*:\s*\d+\b",
    r"(?mi)\b--num-flaky-test-attempts(?:=|\s+)\d+\b",
])

CONFIG_FILE_HINTS = compile_any([
    r"(?mi)\.ewtf\.ya?ml\b",
    r"(?mi)\b(flank\.ya?ml|flank\.android\.ya?ml)\b",
    r"(?mi)\b--config(?:=|\s+)\S+",
    r"(?mi)\b(browserstack\.ya?ml)\b",
    r"(?mi)\b(bs(?:config)?\.ya?ml)\b",
])

ANDROID_CONTEXT_RE = re.compile(
    r"(?i)\b(adb|avd|emulator|android\s+sdk|system-images;android-|androidtest|connected(?:check|androidtest)|gcloud\s+firebase\s+test\s+android\s+run)\b"
)

EMULATOR_COMMUNITY_LABELS = {"reactivecircus runner", "malinskiy runner", "other gha emulator", "circleci android orb"}
EMULATOR_CUSTOM_LABELS = {
    "adb -s emulator-serial",
    "adb wait-for-device",
    "emulator -avd/@",
    "android-wait-for-emulator",
    "start-emulator.sh",
    "android create avd",
    "avdmanager",
    "sdkmanager system-images/emulator",
    "sys-img component",
}
THIRD_PARTY_STRONG_LABELS = {"gcloud firebase", "emulator.wtf run", "saucectl", "appcenter", "browserstack/bstack", "maestro cloud"}
REAL_DEVICE_STRONG_LABELS = {"adb -s <serial> (physical)"}
STRONG_DEVICE_LABELS = EMULATOR_COMMUNITY_LABELS | EMULATOR_CUSTOM_LABELS | THIRD_PARTY_STRONG_LABELS | REAL_DEVICE_STRONG_LABELS

def detect_provider(text: str) -> str:
    for name, pats in PROVIDER_PATTERNS:
        if any_match(pats, text):
            return name
    return "other"

def has_inline_env(text: str) -> bool:
    return any_match(INLINE_DEVICE_HINTS, text)

def has_config_env(text: str) -> bool:
    return any_match(CONFIG_FILE_HINTS, text)

# ===========================
# Gradle GMD config detector (aligned with V6.0)
# ===========================
TESTOPTIONS_HEAD = re.compile(r"\btestOptions\s*\{", re.I)
MANAGED_HEAD     = re.compile(r"\bmanagedDevices\s*\{", re.I)
GMD_INNER_TOKENS_RX = re.compile(r"\b(managedDevices|managedVirtualDevice|devices|groups|deviceGroups)\b", re.I)

def _find_block_span_from_head(text: str, head_start: int) -> Optional[Tuple[int, int]]:
    i = text.find("{", head_start)
    if i == -1:
        return None
    depth = 0
    for j in range(i, len(text)):
        ch = text[j]
        if ch == "{":
            depth += 1
        elif ch == "}":
            depth -= 1
            if depth == 0:
                return (i, j)
    return None

def find_gmd_block(text_gradle_no_comments: str) -> bool:
    """Return True if we see testOptions{ managedDevices{ … } } or a direct managedDevices{ … } block."""
    t = text_gradle_no_comments
    # Direct managedDevices { ... }
    for m in MANAGED_HEAD.finditer(t):
        if _find_block_span_from_head(t, m.start()):
            return True
    # testOptions { ... } containing GMD tokens
    for m in TESTOPTIONS_HEAD.finditer(t):
        ci = _find_block_span_from_head(t, m.start())
        if not ci:
            continue
        a, b = ci
        sub = t[a:b+1]
        if GMD_INNER_TOKENS_RX.search(sub):
            return True
    return False

# ===========================
# Git helpers
# ===========================
def run_git(repo: Path, args: List[str], text: bool = True, check: bool = True, retries: int = 2) -> subprocess.CompletedProcess:
    last_exc: Optional[BaseException] = None
    for attempt in range(retries + 1):
        try:
            return subprocess.run(
                ["git", "-C", str(repo)] + args,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=text,
                check=check,
                encoding="utf-8" if text else None,
                errors="replace" if text else None,
            )
        except subprocess.CalledProcessError as e:
            last_exc = e
            time.sleep(0.1 * (attempt + 1) + random.random() * 0.1)
        except Exception as e:
            last_exc = e
            time.sleep(0.05)
    if isinstance(last_exc, subprocess.CalledProcessError) and not check:
        return last_exc  # type: ignore[return-value]
    raise last_exc  # type: ignore[misc]

def list_repos(root: Path) -> List[Path]:
    out: List[Path] = []
    for p, dirs, _files in os.walk(root):
        pth = Path(p)
        if (pth / ".git").exists():
            out.append(pth)
            dirs[:] = []
    return out

def default_branch_ref(repo: Path) -> Optional[str]:
    try:
        ref = run_git(repo, ["symbolic-ref", "refs/remotes/origin/HEAD"]).stdout.strip()
        if ref.startswith("refs/remotes/"):
            parts = ref.split("/")
            return "/".join(parts[2:])
    except Exception:
        pass
    for cand in ("origin/main", "origin/master"):
        cp = run_git(repo, ["rev-parse", "--verify", cand], check=False)
        if cp.returncode == 0:
            return cand
    return None

def cutoff_head_default(repo: Path, cutoff_iso: str) -> List[str]:
    ref = default_branch_ref(repo)
    if not ref:
        return []
    cp = run_git(repo, ["rev-list", "-n1", "--first-parent", f"--before={cutoff_iso}", ref], check=False)
    sha = (cp.stdout or "").strip()
    return [sha] if sha else []

def cutoff_heads_all(repo: Path, cutoff_iso: str) -> List[str]:
    refs_raw = run_git(repo, ["for-each-ref", "--format=%(refname:short)", "refs/remotes/origin"]).stdout
    refs = [r for r in refs_raw.splitlines() if r and r != "origin/HEAD" and not r.startswith("origin/pr/")]
    shas: List[str] = []
    for r in refs:
        cp = run_git(repo, ["rev-list", "-n1", "--first-parent", f"--before={cutoff_iso}", r], check=False)
        sha = (cp.stdout or "").strip()
        if sha:
            shas.append(sha)
    if not shas:
        cp = run_git(repo, ["rev-list", "-n1", "--before", cutoff_iso, "--all"], check=False)
        sha = (cp.stdout or "").strip()
        if sha:
            shas.append(sha)
    return shas

def _pathspecs_yaml() -> List[str]:
    return [":(glob)**/*.yml", ":(glob)**/*.yaml", ".travis.yml", "azure-pipelines.yml", ".gitlab-ci.yml", "circle.yml", ".bitrise.yml"]

def _pathspecs_gradle() -> List[str]:
    return ["build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts", ":(glob)**/*.gradle", ":(glob)**/*.gradle.kts"]

def _pathspecs_scripts_and_xml() -> List[str]:
    return ["Jenkinsfile", ":(glob)**/*.sh", ":(glob)**/*.bat", ":(glob)**/*.cmd", ":(glob)**/*.ps1", ":(glob)**/pom.xml", ":(glob)**/build.xml", ":(glob)**/config.xml"]

def commits_touching_relevant(repo: Path, heads: List[str]) -> List[str]:
    pathspecs = _pathspecs_yaml() + _pathspecs_gradle() + _pathspecs_scripts_and_xml()
    if not heads:
        return []
    s = run_git(repo, ["rev-list", "--reverse"] + heads + ["--"] + pathspecs).stdout
    return [c for c in s.splitlines() if c.strip()]

def list_tree_entries(repo: Path, treeish: str) -> List[Tuple[str, str]]:
    try:
        raw = run_git(repo, ["ls-tree", "-r", "-z", treeish]).stdout
    except Exception:
        raw = ""
    out: List[Tuple[str, str]] = []
    for entry in raw.split("\x00"):
        if not entry or "\t" not in entry:
            continue
        meta, path = entry.split("\t", 1)
        parts = meta.split()
        if len(parts) < 3:
            continue
        sha = parts[2]
        out.append((sha, path))
    return out

def blob_size(repo: Path, sha: str) -> int:
    try:
        return int(run_git(repo, ["cat-file", "-s", sha]).stdout.strip())
    except Exception:
        return 0

@lru_cache(maxsize=250_000)
def read_blob_cached(repo_path: str, sha: str) -> Optional[str]:
    repo = Path(repo_path)
    try:
        return run_git(repo, ["cat-file", "-p", sha]).stdout
    except Exception:
        return None

# ===========================
# PR / Issues metadata helpers
# ===========================

def _split_owner_repo_from_folder(folder_name: str) -> Tuple[Optional[str], str]:
    """
    Our clone dirs are owner__repo. Return (owner, repo).
    If it doesn't match that pattern, owner is None and repo is folder_name.
    """
    if "__" in folder_name:
        owner, repo = folder_name.split("__", 1)
        return owner, repo
    return None, folder_name


def _load_json_if_exists(path: Path):
    if not path.exists():
        return None
    try:
        with path.open("r", encoding="utf-8") as f:
            return json.load(f)
    except Exception:
        return None


def _load_repo_metadata(repo: Path) -> Tuple[List[dict], List[dict]]:
    """
    Given a cloned repo path, load PRs and Issues JSON from META_ROOT using
    the owner__repo_PRs.json and owner__repo_Issues.json naming convention.
    Returns (prs, issues) lists. If files are missing, returns empty lists.
    """
    owner, short_repo = _split_owner_repo_from_folder(repo.name)
    base_name = f"{owner}__{short_repo}" if owner else short_repo

    prs_path    = META_ROOT / f"{base_name}_PRs.json"
    issues_path = META_ROOT / f"{base_name}_Issues.json"

    prs    = _load_json_if_exists(prs_path) or []
    issues = _load_json_if_exists(issues_path) or []

    # Ensure they are lists (GitHub API returns list for those endpoints)
    if not isinstance(prs, list):
        prs = []
    if not isinstance(issues, list):
        issues = []

    return prs, issues


def _get_commit_subject_body(repo: Path, commit: str,
                             _cache: Dict[str, Tuple[str, str]]) -> Tuple[str, str]:
    """
    Return (subject, body) for a commit, with a small per-repo cache.
    """
    if commit in _cache:
        return _cache[commit]

    try:
        cp = run_git(
            repo,
            ["show", "-s", "--format=%s%n%b", commit],
            text=True,
            check=True,
        )
        out = cp.stdout or ""
    except Exception:
        _cache[commit] = ("", "")
        return ("", "")

    lines = out.splitlines()
    subject = lines[0] if lines else ""
    body = "\n".join(lines[1:]).strip()
    _cache[commit] = (subject, body)
    return subject, body


_CLOSING_ISSUE_RX = re.compile(
    r"(?i)\b(?:close[sd]?|fixe?[sd]?|resolve[sd]?)\s+#(\d+)\b"
)


def _build_env_event_rows_for_repo(repo: Path, rec: Dict) -> List[Dict]:
    """
    For a given repo and its timeline JSON record (rec),
    build a flat list of rows for env-related events,
    enriched with commit + PR + Issues data when available.
    """
    rows: List[Dict] = []

    prs, issues = _load_repo_metadata(repo)

    # Build quick lookup tables ------------------------------------
    pr_by_merge_sha: Dict[str, dict] = {}
    pr_by_head_sha: Dict[str, dict] = {}
    pr_to_issue_nums: Dict[int, List[int]] = {}

    issues_by_number: Dict[int, dict] = {}
    for iss in issues:
        try:
            num = iss.get("number")
            if isinstance(num, int):
                issues_by_number[num] = iss
        except Exception:
            continue

    for pr in prs:
        # map merge_commit_sha -> PR
        msha = pr.get("merge_commit_sha")
        if msha:
            pr_by_merge_sha[msha] = pr

        # map head.sha -> PR (useful for fast-forward merges or if merge_commit_sha missing)
        head = pr.get("head")
        if isinstance(head, dict):
            hsha = head.get("sha")
            if hsha:
                pr_by_head_sha[hsha] = pr

        # find 'closes #123' style references in PR body
        body = pr.get("body") or ""
        try:
            nums = {int(n) for n in _CLOSING_ISSUE_RX.findall(body) if n.isdigit()}
        except Exception:
            nums = set()
        if nums and isinstance(pr.get("number"), int):
            pr_to_issue_nums[int(pr["number"])] = sorted(nums)

    owner, short_repo = _split_owner_repo_from_folder(repo.name)
    full_name = f"{owner}/{short_repo}" if owner else short_repo

    # We'll reuse commit text across rows
    commit_cache: Dict[str, Tuple[str, str]] = {}

    events = rec.get("events", {}) or {}

    for style, elist in events.items():
        for e in elist:
            commit = e.get("commit")
            if not commit:
                continue
            date        = e.get("date") or ""
            change_type = e.get("event") or ""
            on_default  = e.get("on_default", 0)

            subject, body = _get_commit_subject_body(repo, commit, commit_cache)

            # Try to associate this commit with a PR
            pr = pr_by_merge_sha.get(commit) or pr_by_head_sha.get(commit)

            pr_number = ""
            pr_state = ""
            pr_title = ""
            pr_body = ""
            pr_created_at = ""
            pr_merged_at = ""
            pr_closed_at = ""
            pr_user_login = ""
            pr_labels = ""
            pr_html_url = ""
            issues_summary = ""

            if pr:
                pr_number = str(pr.get("number", ""))
                pr_state = pr.get("state", "") or ""
                pr_title = (pr.get("title") or "").replace("\n", " ").strip()
                pr_body = (pr.get("body") or "").strip()
                pr_created_at = pr.get("created_at", "") or ""
                pr_merged_at = pr.get("merged_at", "") or ""
                pr_closed_at = pr.get("closed_at", "") or ""
                user = pr.get("user") or {}
                if isinstance(user, dict):
                    pr_user_login = user.get("login", "") or ""
                labels = pr.get("labels") or []
                if isinstance(labels, list):
                    label_names = []
                    for lab in labels:
                        if isinstance(lab, dict) and "name" in lab:
                            label_names.append(str(lab["name"]))
                    pr_labels = ";".join(label_names)
                pr_html_url = pr.get("html_url", "") or ""

                # Attach closing issues summary, if any
                try:
                    n_int = int(pr.get("number"))
                except Exception:
                    n_int = None

                if n_int is not None:
                    nums = pr_to_issue_nums.get(n_int, [])
                    issue_texts: List[str] = []
                    for num in nums:
                        iss = issues_by_number.get(num)
                        if not iss:
                            continue
                        ttl = (iss.get("title") or "").replace("\n", " ").strip()
                        st = iss.get("state", "") or ""
                        issue_texts.append(f"#{num} [{st}] {ttl}")
                    if issue_texts:
                        issues_summary = " || ".join(issue_texts)

            rows.append(
                {
                    "full_name": full_name,            # owner/repo
                    "repo_folder": repo.name,          # owner__repo
                    "env_style": style,                # Emu_Community, GMD, ThirdParty...
                    "change_type": change_type,        # added / removed / maintenance
                    "change_date": date,
                    "on_default": on_default,

                    "commit": commit,
                    "commit_short": commit[:12],
                    "commit_subject": subject,
                    "commit_body": body,

                    "pr_number": pr_number,
                    "pr_state": pr_state,
                    "pr_title": pr_title,
                    "pr_body": pr_body,
                    "pr_created_at": pr_created_at,
                    "pr_merged_at": pr_merged_at,
                    "pr_closed_at": pr_closed_at,
                    "pr_user_login": pr_user_login,
                    "pr_labels": pr_labels,
                    "pr_html_url": pr_html_url,

                    "issues_summary": issues_summary,
                }
            )

    return rows



# ===========================
# Detection at snapshot level
# ===========================
def scan_snapshot_for_styles(repo: Path, treeish: str) -> Tuple[Set[str], Dict]:
    entries = list_tree_entries(repo, treeish)

    # Aggregate features
    features = {
        "yaml_loc": 0,
        "gradle_loc": 0,
        "runs_on": set(),
        "matrix_width_hint": 0,
        "api_levels": set(),
        "reliability_flags": set(),
        "gmd_config_present": False,
        "gmd_identifiers": set(),  # optional, we only store names when we parse them from block heads
    }
    all_text_blocks: List[Tuple[str, str]] = []
    raw_blocks_for_guard: List[str] = []
    has_gradle_anywhere_repo = False

    RX_RUNS_ON = re.compile(r"(?mi)^\s*runs-on\s*:\s*(.+)$")
    RX_LIST_ITEM = re.compile(r"(?mi)^\s*-\s")
    RX_API_LEVEL = re.compile(r"(?i)\bandroid[-_ ]?(\d{2})\b|system-images;android-(\d{2})\b")
    RX_RETRY = re.compile(r"(?i)\bretry\b|\bmax-attempts\b|\bflaky\b")
    RX_TIMEOUT = re.compile(r"(?i)\btimeout[- ]?minutes\b|\btimeout\b")
    RX_HEADLESS = re.compile(r"(?i)\bheadless\b|\b-no-window\b|\b-no-boot-anim\b")
    RX_WAIT_FOR_DEVICE = re.compile(r"(?i)\badb\s+wait[- ]?for[- ]?device\b")

    # Optional identifier capture in GMD blocks (names before "(ManagedVirtualDevice)")
    GMD_BLOCK_NAME_RX = re.compile(
        r'(\w+)\s*\(\s*(?:com\.android\.build\.api\.dsl\.)?ManagedVirtualDevice(?:\s*::\s*class)?\s*\)',
        re.I
    )

    for sha, path in entries:
        if not is_relevant_file(path):
            continue
        size = blob_size(repo, sha)
        if not is_high_priority_ci_path(path) and BLOB_MAX_SIZE and size > BLOB_MAX_SIZE:
            continue
        text = read_blob_cached(str(repo), sha)
        if not text or len(text) > HARD_MAX_SIZE:
            continue

        lines = text.splitlines()
        norm = text  # default

        if is_yaml(path):
            features["yaml_loc"] += len(lines)
            for m in RX_RUNS_ON.finditer(text):
                features["runs_on"].add(m.group(1).strip())
            features["matrix_width_hint"] = max(features["matrix_width_hint"], len(RX_LIST_ITEM.findall(text)))
            # sanitize
            norm = strip_comments(norm)
            norm = normalize_block_keys(norm)
            norm = strip_irrelevant_ci_lines(norm)
            norm = pre_sanitize(norm)

        elif is_script(path) or is_ci_xml_or_build_xml(path):
            norm = strip_comments(norm)
            norm = normalize_block_keys(norm)
            norm = strip_irrelevant_ci_lines(norm)
            norm = pre_sanitize(norm)

        elif is_gradle(path):
            features["gradle_loc"] += len(lines)
            # For Gradle, use Gradle-aware comment stripping then look for GMD config blocks
            gradle_clean = strip_comments_gradle(text)
            # Detect managedDevices presence (aligned with your V6.0)
            if not features["gmd_config_present"] and find_gmd_block(gradle_clean):
                features["gmd_config_present"] = True
                # best-effort: capture identifiers (optional, for diagnostics only)
                for m in GMD_BLOCK_NAME_RX.finditer(gradle_clean):
                    ident = (m.group(1) or "").strip()
                    if ident:
                        features["gmd_identifiers"].add(ident)
            # Keep norm as lowercased “clean” text for any incidental signals
            norm = gradle_clean

        # Common feature mining from the (possibly sanitized) text
        for m in RX_API_LEVEL.finditer(text):
            for g in m.groups():
                if g and g.isdigit():
                    features["api_levels"].add(int(g))
        if RX_RETRY.search(text):
            features["reliability_flags"].add("retry")
        if RX_TIMEOUT.search(text):
            features["reliability_flags"].add("timeout")
        if RX_HEADLESS.search(text):
            features["reliability_flags"].add("headless")
        if RX_WAIT_FOR_DEVICE.search(text):
            features["reliability_flags"].add("wait_for_device")

        all_text_blocks.append((path, norm))
        raw_blocks_for_guard.append(norm)

        if GRADLE_ANYWHERE_RE.search(norm) or GRADLE_BUILD_ACTION_RE.search(norm):
            has_gradle_anywhere_repo = True

    # Collect triggers & devices repo-wide (mostly from YAML/scripts)
    trigger_labels: List[str] = []
    trigger_groups: List[str] = []
    device_labels: List[str] = []
    device_groups: List[str] = []

    for _path, norm in all_text_blocks:
        nlow = norm.lower()

        t_labels, t_groups = collect_hits_with_groups(TRIGGER_PATTERNS_PRIMARY, nlow)
        fb_labels, fb_groups = collect_hits_with_groups(TRIGGER_PATTERNS_ANYWHERE, nlow)
        if fb_labels:
            t_labels = unique_preserve(t_labels + fb_labels)
            t_groups = unique_preserve(t_groups + fb_groups)

        # GHA gradle input guard
        if any_match(GHA_GRADLE_INPUTS, nlow):
            gha_tied = re.search(
                r"(?mi)^\s*uses\s*:\s*(reactivecircus/android-emulator-runner|malinskiy/action-android/emulator-run-cmd|hannesa2/action-android/emulator-run-cmd)@",
                nlow,
            )
            if has_gradle_anywhere_repo or gha_tied:
                if "gha gradle inputs/script" not in t_labels:
                    t_labels.append("gha gradle inputs/script")
                if "Gradle" not in t_groups:
                    t_groups.append("Gradle")

        trigger_labels = unique_preserve(trigger_labels + t_labels)
        trigger_groups = unique_preserve(trigger_groups + t_groups)

        d_labels, d_groups = collect_hits_with_groups(DEVICE_PATTERNS, nlow)
        # Guard: “other gha emulator” must have Android context or a trigger
        if ("other gha emulator" in d_labels) and (not ANDROID_CONTEXT_RE.search(nlow)) and (not t_labels):
            d_labels = [l for l in d_labels if l != "other gha emulator"]
            if not d_labels:
                d_groups = [g for g in d_groups if g != "Emulator"]

        device_labels = unique_preserve(device_labels + d_labels)
        device_groups = unique_preserve(device_groups + d_groups)

    has_test_trigger = bool(trigger_labels)

    # Weak hint suppression: require strong device OR a test trigger
    strong_seen = bool(set(device_labels) & STRONG_DEVICE_LABELS)
    if not (strong_seen or has_test_trigger):
        device_labels = [l for l in device_labels if l in STRONG_DEVICE_LABELS]
        if not device_labels:
            device_groups = []

    # BrowserStack upload-only guard
    repo_text = "\n".join(raw_blocks_for_guard)
    provider = detect_provider(repo_text)
    inline_decl = has_inline_env(repo_text)
    config_decl = has_config_env(repo_text)
    has_ftl_instr = bool(re.search(r"(?mi)\bgcloud\s+firebase\s+test\s+android\s+run[^\n]*\b(--test\b|--type\s+instrumentation\b)", repo_text))
    bs_test_hint = re.search(r"(?mi)\b(browserstack|bstack)\b[^\n]*\b(espresso|instrumentation|app-automate|automate|--device|--devices)\b", repo_text)
    if ("browserstack/bstack" in device_labels or provider == "browserstack"):
        if (not has_test_trigger) and (not inline_decl) and (not config_decl) and (not has_ftl_instr) and (not bs_test_hint):
            device_labels = [l for l in device_labels if l != "browserstack/bstack"]
            if "Third_Party_Lab" in device_groups and not any(l in {"gcloud firebase", "saucectl", "appcenter", "maestro cloud", "emulator.wtf action"} for l in device_labels):
                device_groups = [g for g in device_groups if g != "Third_Party_Lab"]

    # Map to final styles
    styles: Set[str] = set()

    if "Third_Party_Lab" in device_groups:
        styles.add("ThirdParty")

    if "Emulator" in device_groups:
        lbls = set(device_labels)
        if lbls & EMULATOR_COMMUNITY_LABELS:
            styles.add("Emu_Community")
        elif lbls & EMULATOR_CUSTOM_LABELS:
            styles.add("Emu_Custom")

    # --- GMD detection parity with shallow snapshot ---
    # Count GMD if EITHER:
    #  (A) GMD Gradle configuration is present, OR
    #  (B) CI shows managed-device AndroidTest triggers (execution evidence).
    def has_gmd_gradle_trigger(tlabs: List[str]) -> bool:
        L = {l.lower() for l in tlabs}
        if any("manageddevice androidtest" in l for l in L):
            return True
        if ("variant/device androidtest" in L) and not any(x in L for x in {"connected.*android.*", "connectedandroidtest", "connectedbenchmarkandroidtest", "spoon", "marathon"}):
            return True
        return False

    if features["gmd_config_present"] or has_gmd_gradle_trigger(trigger_labels):
        styles.add("GMD")

    meta = {
        "sources": {"yaml": [], "gradle": [], "scripts_xml": []},
        "features": {
            "yaml_loc": features["yaml_loc"],
            "gradle_loc": features["gradle_loc"],
            "runs_on": sorted(features["runs_on"]),
            "matrix_width_hint": features["matrix_width_hint"],
            "api_levels": sorted(int(x) for x in features["api_levels"]),
            "reliability_flags": sorted(features["reliability_flags"]),
            "trigger_labels": sorted(trigger_labels),
            "device_labels": sorted(device_labels),
            "provider": provider,
            "inline_env": bool(inline_decl),
            "config_env": bool(config_decl),
            "gradle_present_repo": bool(has_gradle_anywhere_repo),
            "gmd_config_present": bool(features["gmd_config_present"]),
            "gmd_identifiers": sorted(features["gmd_identifiers"]) if features["gmd_identifiers"] else [],
        },
    }
    return styles, meta

# ===========================
# Timeline building
# ===========================
def empty_result(repo: Path, cutoff_iso: str) -> Dict:
    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "cutoff_default_head": [],
        "cutoff_all_heads": [],
        "first_commit_date": None,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": [],
        "events": {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []},
        "snapshot_as_of_cutoff_default": [],
        "snapshot_as_of_cutoff_repo_wide": [],
        "off_default_extra_styles": [],
        "has_off_default_extra": 0,
        "empty_gaps": [],
        "qa_issue": "No environment detected at cutoff",
    }

def earliest_commit(repo: Path) -> Optional[str]:
    try:
        s = run_git(repo, ["rev-list", "--max-parents=0", "--all"]).stdout.strip()
        return s.splitlines()[0] if s else None
    except Exception:
        return None

def get_commit_date_iso(repo: Path, commit: str) -> Optional[str]:
    try:
        return run_git(repo, ["show", "-s", "--format=%cI", commit]).stdout.strip() or None
    except Exception:
        return None

def union_snapshot_styles_at_cutoff(repo: Path, heads: List[str]) -> List[str]:
    styles: Set[str] = set()
    for sha in heads:
        s, _m = scan_snapshot_for_styles(repo, sha)
        styles |= s
    return sorted(styles)

def build_timeline(repo: Path, cutoff_iso: str) -> Dict:
    # Heads at cutoff
    default_heads = cutoff_head_default(repo, cutoff_iso)
    all_heads     = cutoff_heads_all(repo, cutoff_iso)

    if not default_heads and not all_heads:
        return empty_result(repo, cutoff_iso)

    # Commits touching relevant files on default and repo-wide (for tagging & scope)
    commits_default = commits_touching_relevant(repo, default_heads) if default_heads else []
    commits_all     = commits_touching_relevant(repo, all_heads) if all_heads else commits_default

    # Date maps
    commit_dates: Dict[str, str] = {}
    for c in commits_all:
        d = get_commit_date_iso(repo, c)
        if d:
            commit_dates[c] = d
    first_commit_date = commit_dates.get(commits_all[0]) if commits_all else None

    # Build timeline (scope-controlled)
    scope_commits = commits_all if TIMELINE_SCOPE == "repo_wide" else commits_default
    scope_commits = scope_commits or commits_all  # fallback

    timeline: List[Dict] = []
    events: Dict[str, List[Dict]] = {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []}
    prev: Set[str] = set()

    empty_gaps: List[Dict] = []
    gap_open: Optional[Dict] = None

    # (Optional) historical baseline at repository root
    root = earliest_commit(repo)
    if root:
        base_styles, base_meta = scan_snapshot_for_styles(repo, root)
        if base_styles:
            baseline_date = get_commit_date_iso(repo, root)
            timeline.append({"date": baseline_date, "commit": root, "on_default": int(root in commits_default), "styles": sorted(base_styles), **base_meta})
            for s in sorted(base_styles):
                if s in events:
                    events[s].append({"event": "added", "date": baseline_date, "commit": root, "on_default": int(root in commits_default)})
            prev = set(base_styles)

    default_set = set(commits_default)

    for c in scope_commits:
        styles_now, meta_now = scan_snapshot_for_styles(repo, c)
        dt = commit_dates.get(c)
        on_default = int(c in default_set)

        # Skip commits that didn't detect any relevant style signals (unless capturing 'empty' gaps)
        if SUPPRESS_EMPTY_ROWS and not styles_now:
            if CAPTURE_EMPTY_GAPS and gap_open is None:
                gap_open = {"start_date": dt, "start_commit": c, "prev_state": "+".join(sorted(prev)) if prev else ""}
            continue

        # If we were in a gap and now have styles, close the gap (existing behavior)
        if CAPTURE_EMPTY_GAPS and gap_open is not None and styles_now:
            gap_open["end_date"] = dt
            gap_open["end_commit"] = c
            gap_open["next_state"] = "+".join(sorted(styles_now))
            try:
                d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)  # type: ignore[index]
                d2 = datetime.fromisoformat((dt or "").replace("Z", "+00:00")).replace(tzinfo=None)
                gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
            except Exception:
                gap_open["duration_days"] = None
            gap_open["censored"] = False
            empty_gaps.append(gap_open)
            gap_open = None

        if styles_now != prev:
            # === boundary change: keep existing behavior ===
            if EMIT_NONE_STATE and not styles_now:
                timeline.append({"date": dt, "commit": c, "on_default": on_default, "styles": [], **meta_now})
            elif styles_now:
                timeline.append({"date": dt, "commit": c, "on_default": on_default, "styles": sorted(styles_now), **meta_now})

            added = styles_now - prev
            removed = prev - styles_now
            for s in sorted(added):
                if s in events:
                    events[s].append({"event": "added", "date": dt, "commit": c, "on_default": on_default})
            for s in sorted(removed):
                if s in events:
                    events[s].append({"event": "removed", "date": dt, "commit": c, "on_default": on_default})
            prev = styles_now

        else:
            # === NEW: within-episode maintenance (style set unchanged) ===
            # We reached this commit because it touched relevant paths already (by construction).
            # Treat it as "maintenance" for all styles currently active.
            if styles_now:
                for s in sorted(styles_now):
                    if s in events:
                        events[s].append({
                            "event": "maintenance",
                            "date": dt,
                            "commit": c,
                            "on_default": on_default
                        })
            # No timeline row needed here; we only record the maintenance touch.

    # Cutoff snapshots (both lenses)
    snapshot_default   = union_snapshot_styles_at_cutoff(repo, default_heads) if default_heads else []
    snapshot_repo_wide = union_snapshot_styles_at_cutoff(repo, all_heads) if all_heads else snapshot_default

    if CAPTURE_EMPTY_GAPS and gap_open is not None:
        # close last gap at cutoff
        gap_open["end_date"] = cutoff_iso
        gap_open["end_commit"] = (default_heads or all_heads or [None])[0]
        gap_open["next_state"] = ""
        try:
            d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)  # type: ignore[index]
            d2 = datetime.fromisoformat(cutoff_iso.replace("Z", "+00:00")).replace(tzinfo=None)
            gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
        except Exception:
            gap_open["duration_days"] = None
        gap_open["censored"] = True
        empty_gaps.append(gap_open)
        gap_open = None

    off_default_extra = sorted(set(snapshot_repo_wide) - set(snapshot_default))
    qa_issue = None
    if not snapshot_default and not snapshot_repo_wide:
        qa_issue = "No environment detected at cutoff"

    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "cutoff_default_head": default_heads,
        "cutoff_all_heads": all_heads,
        "first_commit_date": first_commit_date,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": timeline,
        "events": events,
        "snapshot_as_of_cutoff_default": snapshot_default,
        "snapshot_as_of_cutoff_repo_wide": snapshot_repo_wide,
        "off_default_extra_styles": off_default_extra,
        "has_off_default_extra": int(bool(off_default_extra)),
        "empty_gaps": empty_gaps,
        **({"qa_issue": qa_issue} if qa_issue else {}),
    }

# ===========================
# Runner + index/summary
# ===========================
def output_path_for(repo: Path) -> Path:
    return OUTPUT_MINE / f"{repo.name}.emulator_timeline.json"

def list_repos_once(root: Path) -> List[Path]:
    rs = list_repos(root)
    rs.sort(key=lambda p: p.name.lower())
    return rs

def iso_min(dts: List[str]) -> Optional[str]:
    ds = [d for d in dts if d]
    return min(ds) if ds else None

def derive_summary_fields(rec: Dict) -> Dict:
    name = rec.get("repo_name")
    snap_def = rec.get("snapshot_as_of_cutoff_default", [])
    snap_all = rec.get("snapshot_as_of_cutoff_repo_wide", [])
    events = rec.get("events", {})
    first_events: List[Optional[str]] = []
    for k in ("Emu_Community", "Emu_Custom", "GMD", "ThirdParty"):
        for e in events.get(k, []):
            if e.get("event") == "added":
                first_events.append(e.get("date"))
    first_env_date = iso_min([d for d in first_events if d])
    transitions = 0
    for k in events:
        transitions += sum(1 for e in events[k] if e.get("event") in ("added", "removed"))
    gaps = rec.get("empty_gaps", [])
    gap_days = 0.0
    for g in gaps:
        try:
            gap_days += float(g.get("duration_days") or 0.0)
        except Exception:
            pass
    return {
        "repo_name": name,
        "has_env_at_cutoff_default": 1 if snap_def else 0,
        "has_env_at_cutoff_repo_wide": 1 if snap_all else 0,
        "cutoff_states_default": "+".join(snap_def),
        "cutoff_states_repo_wide": "+".join(snap_all),
        "off_default_extra": "+".join(rec.get("off_default_extra_styles", [])),
        "has_off_default_extra": int(bool(rec.get("off_default_extra_styles"))),
        "first_env_date": first_env_date or "",
        "transitions": transitions,
        "total_gap_days": round(gap_days, 2),
        "qa_issue": rec.get("qa_issue", ""),
    }

def run_miner(cutoff_iso: str = CUTOFF_ISO, max_repos: int = MAX_REPOS) -> None:
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

    repos = list_repos_once(INPUT_CLONES)
    if max_repos and max_repos > 0:
        repos = repos[:max_repos]

    if not repos:
        print(f"[info] No git repos found under: {INPUT_CLONES}")
        return

    print(f"[info] Work root:         {WORK_ROOT}")
    print(f"[info] Input repos:       {INPUT_CLONES}")
    print(f"[info] Output JSON dir:   {OUTPUT_MINE}")
    print(f"[info] Found repos:       {len(repos)}")
    print(f"[info] Cutoff (UTC):      {cutoff_iso}")
    print(f"[info] Timeline scope:    {TIMELINE_SCOPE}")
    print(f"[info] Options: suppress_empty_rows={SUPPRESS_EMPTY_ROWS}, capture_empty_gaps={CAPTURE_EMPTY_GAPS}, emit_none={EMIT_NONE_STATE}, blob_max_size={BLOB_MAX_SIZE}")

    written = skipped = errors = 0
    summaries: List[Dict] = []
    env_rows: List[Dict] = []

    

    def process(repo: Path) -> Tuple[str, Path, Optional[Dict], Optional[str]]:
        try:
            outp = output_path_for(repo)
            if RESUME_IF_EXISTS and outp.exists():
                return ("skipped", repo, None, None)
            data = build_timeline(repo, cutoff_iso)
            with outp.open("w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=2)
            return ("written", repo, data, None)
        except Exception as e:
            return ("error", repo, None, str(e))

    with PoolExecutor(max_workers=MAX_WORKERS) as ex:
        futs = {ex.submit(process, r): r for r in repos}
        total = len(futs)
        for i, fut in enumerate(as_completed(futs), 1):
            repo = futs[fut]
            rel = repo.relative_to(INPUT_CLONES) if repo != INPUT_CLONES else Path(repo.name)
            status, _repo, data, err = fut.result()
            if status == "written":
                print(f"[{i}/{total}] Wrote: {rel}")
                written += 1
                summaries.append(derive_summary_fields(data))  # type: ignore[arg-type]
                # NEW: build env/PR/issue rows from the freshly computed data
                env_rows.extend(_build_env_event_rows_for_repo(repo, data))  # type: ignore[arg-type]

            elif status == "skipped":
                print(f"[{i}/{total}] Skipped (exists): {rel}")
                skipped += 1
                try:
                    with output_path_for(repo).open("r", encoding="utf-8") as f:
                        data2 = json.load(f)
                    summaries.append(derive_summary_fields(data2))
                    # NEW: also build rows from existing JSON
                    env_rows.extend(_build_env_event_rows_for_repo(repo, data2))
                except Exception:
                    pass

            else:
                print(f"[i/{total}] [error] {rel}: {err}", file=sys.stderr)
                errors += 1


    # Write summary CSV + JSON index
    idx_json = OUTPUT_MINE / "index_summary.json"
    with idx_json.open("w", encoding="utf-8") as f:
        json.dump({"cutoff": cutoff_iso, "repos": summaries}, f, ensure_ascii=False, indent=2)

    idx_csv = OUTPUT_MINE / "index_summary.csv"
    with idx_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(
            f,
            fieldnames=[
                "repo_name",
                "has_env_at_cutoff_default",
                "has_env_at_cutoff_repo_wide",
                "cutoff_states_default",
                "cutoff_states_repo_wide",
                "off_default_extra",
                "has_off_default_extra",
                "first_env_date",
                "transitions",
                "total_gap_days",
                "qa_issue",
            ],
        )
        w.writeheader()
        for row in summaries:
            w.writerow(row)

    qa_csv = OUTPUT_MINE / "qa_issues.csv"
    with qa_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(f, fieldnames=["repo_name", "qa_issue"])
        w.writeheader()
        for row in summaries:
            if row.get("qa_issue"):
                w.writerow({"repo_name": row["repo_name"], "qa_issue": row["qa_issue"]})

    print(f"[done] JSON -> {OUTPUT_MINE}  (written={written}, skipped={skipped}, errors={errors})")
    print(f"[done] Summary: {idx_csv.name}, {idx_json.name}, QA: {qa_csv.name}")

        # NEW: write per-event env + PR + issues CSV
    env_csv = OUTPUT_MINE / "env_events_with_pr_issues.csv"
    if env_rows:
        fieldnames = [
            "full_name",
            "repo_folder",
            "env_style",
            "change_type",
            "change_date",
            "on_default",
            "commit",
            "commit_short",
            "commit_subject",
            "commit_body",
            "pr_number",
            "pr_state",
            "pr_title",
            "pr_body",
            "pr_created_at",
            "pr_merged_at",
            "pr_closed_at",
            "pr_user_login",
            "pr_labels",
            "pr_html_url",
            "issues_summary",
        ]
        with env_csv.open("w", encoding="utf-8", newline="") as f:
            w = csv.DictWriter(f, fieldnames=fieldnames)
            w.writeheader()
            for row in env_rows:
                w.writerow(row)
        print(f"[done] Env/PR/Issues CSV: {env_csv.name}")
    else:
        print("[info] No env events found to write to env_events_with_pr_issues.csv")


if __name__ == "__main__":
    _failfast_checks()
    print("[run] Starting miner…")
    run_miner(cutoff_iso=CUTOFF_ISO, max_repos=MAX_REPOS)
    print("[run] Finished.")
# Out:
# [run] Starting miner…
# [info] Work root:         C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4
# [info] Input repos:       C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0
# [info] Output JSON dir:   C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\mineV1.0
# [info] Found repos:       355
# [info] Cutoff (UTC):      2025-08-10 23:59:59 +0000
# [info] Timeline scope:    repo_wide
# [info] Options: suppress_empty_rows=True, capture_empty_gaps=True, emit_none=False, blob_max_size=2000000
# [1/355] Wrote: ajitsing__ExpenseManager
# [2/355] Wrote: AAkira__ExpandableLayout
# [3/355] Wrote: andremion__Villains-and-Heroes
# [4/355] Wrote: arkivanov__android-dev-challenge-compose-2
# [5/355] Wrote: andriydruk__swift-weather-app
# [6/355] Wrote: AndProx__AndProx
# [7/355] Wrote: 4eRTuk__audioview
# [8/355] Wrote: agoda-com__ninjato
# [9/355] Wrote: AdamMc331__AndroidStudyGuide
# [10/355] Wrote: alphacep__vosk-flutter
# [11/355] Wrote: alexbakker__webdav-provider
# [12/355] Wrote: a914-gowtham__compose-ratingbar
# [13/355] Wrote: anjlab__android-inapp-billing-v3
# [14/355] Wrote: bilibili__boxing
# [15/355] Wrote: am15h__tflite_flutter_helper
# [16/355] Wrote: AChep__AcDisplay
# [17/355] Wrote: amahi__android
# [18/355] Wrote: blazsolar__android-collapse-calendar-view
# [19/355] Wrote: airbnb__paris
# [20/355] Wrote: brarcher__video-transcoder
# [21/355] Wrote: alexstyl__contactstore
# [22/355] Wrote: CarlosMChica__easyrecycleradapters
# [23/355] Wrote: appmattus__layercache
# [24/355] Wrote: chenxiaolong__RSAF
# [25/355] Wrote: ActivityWatch__aw-android
# [26/355] Wrote: andreynovikov__trekarta
# [27/355] Wrote: Albert221__FastShopping
# [28/355] Wrote: aws__amazon-ivs-react-native-player
# [29/355] Wrote: amitshekhariitbhu__Fast-Android-Networking
# [30/355] Wrote: adorsys__secure-storage-android
# [31/355] Wrote: cuongpm__youtube-dl-android
# [32/355] Wrote: burnoo__cokoin
# [33/355] Wrote: AdevintaSpain__Barista
# [34/355] Wrote: a-mabe__OpenHIIT
# [35/355] Wrote: dbrodie__AdBuster
# [36/355] Wrote: charpeni__react-native-url-polyfill
# [37/355] Wrote: concretesolutions__canarinho
# [38/355] Wrote: cloudinary__cloudinary_android
# [39/355] Wrote: abdelaziz-mahdy__pytorch_lite
# [40/355] Wrote: cashapp__paraphrase
# [41/355] Wrote: beemdevelopment__Aegis
# [42/355] Wrote: douzifly__clear-todolist
# [43/355] Wrote: DesarrolloAntonio__Shiori-Android-Client
# [44/355] Wrote: doublesymmetry__KotlinAudio
# [45/355] Wrote: cliqz-oss__browser-android
# [46/355] Wrote: dgngulcan__droid-feed
# [47/355] Wrote: dlew__joda-time-android
# [48/355] Wrote: dmfs__opentasks
# [49/355] Wrote: bitfireAT__icsx5
# [50/355] Wrote: Criptext__Android-Email-Client
# [51/355] Wrote: anilbeesetti__nextplayer
# [52/355] Wrote: erkkah__naett
# [53/355] Wrote: FabianTerhorst__Floppy
# [54/355] Wrote: EvanRespaut__Equate
# [55/355] Wrote: Crazy-Marvin__MetadataRemover
# [56/355] Wrote: elftausend__custos
# [57/355] Wrote: fewlaps__flone-android
# [58/355] Wrote: CypherpunkArmory__UserLAnd
# [59/355] Wrote: FabianTerhorst__Iron
# [60/355] Wrote: Five-Prayers__five-prayers-android
# [61/355] Wrote: brandonp2412__FitBook
# [62/355] Wrote: droidconKE__droidconKeKotlin
# [63/355] Wrote: FliegendeWurst__TriliumDroid
# [64/355] Wrote: ErickSumargo__Dads
# [65/355] Wrote: flauschtrud__broccoli
# [66/355] Wrote: fossasia__loklak_wok_android
# [67/355] Wrote: GabrielBB__Android-CutOut
# [68/355] Wrote: evilcorpltd__aTox
# [69/355] Wrote: gdky005__AndroidBadge
# [70/355] Wrote: GerardPaligot__android-countdown
# [71/355] Wrote: freeotp__freeotp-android
# [72/355] Wrote: flet-dev__serious-python
# [73/355] Wrote: federicoiosue__Omni-Notes
# [74/355] Wrote: fornewid__naver-map-compose
# [75/355] Wrote: f-arslan__GptMap
# [76/355] Wrote: Faltenreich__Diaguard
# [77/355] Wrote: gotev__android-cookie-store
# [78/355] Wrote: gotev__android-speech
# [79/355] Wrote: ably__ably-flutter
# [80/355] Wrote: guolindev__android-dev-challenge-compose
# [81/355] Wrote: CatimaLoyalty__Android
# [82/355] Wrote: gemwalletcom__gem-android
# [83/355] Wrote: EventFahrplan__EventFahrplan
# [84/355] Wrote: fluttercommunity__flutter_workmanager
# [85/355] Wrote: commons-app__apps-android-commons
# [86/355] Wrote: hannesstruss__unearthed
# [87/355] Wrote: greenaddress__abcore
# [88/355] Wrote: hitherejoe__HackerNewsReader
# [89/355] Wrote: hitherejoe__MVVM_Hacker_News
# [90/355] Wrote: Hny0305Lin__NLChat
# [91/355] Wrote: grote__Transportr
# [92/355] Wrote: HYY-yu__TableRecyclerView
# [93/355] Wrote: google__jetpack-camera-app
# [94/355] Wrote: ICBNetwork__web3-Wallet
# [95/355] Wrote: ianthetechie__uniffi-starter
# [96/355] Wrote: haiyangwu__mediasoup-client-android
# [97/355] Wrote: connectbot__connectbot
# [98/355] Wrote: fossasia__phimpme-android
# [99/355] Wrote: guardianproject__proofmode-android
# [100/355] Wrote: H-PixelDroid__PixelDroid
# [101/355] Wrote: haroldadmin__MoonShot
# [102/355] Wrote: irgaly__kfswatch
# [103/355] Wrote: ivnsch__rust_android_ios
# [104/355] Wrote: hannesa2__panoramaGL
# [105/355] Wrote: hoc081098__ViewBindingDelegate
# [106/355] Wrote: ipfs-shipyard__gomobile-ipfs
# [107/355] Wrote: ice-blockchain__mobile-app
# [108/355] Wrote: izderadicka__audioserve-android
# [109/355] Wrote: glpi-project__android-inventory-agent
# [110/355] Wrote: jerryOkafor__TimeLineView
# [111/355] Wrote: javiersantos__PiracyChecker
# [112/355] Wrote: bitfireAT__davx5-ose
# [113/355] Wrote: jeziellago__Linkt
# [114/355] Wrote: inaturalist__iNaturalistAndroid
# [115/355] Wrote: DroidKaigi__conference-app-2020
# [116/355] Wrote: jimmod__ShareToComputer
# [117/355] Wrote: hitherejoe__minimise
# [118/355] Wrote: invertase__react-native-google-mobile-ads
# [119/355] Wrote: jianjunxiao__NiceVieoPlayer
# [120/355] Wrote: JimmyDaddy__react-native-image-marker
# [121/355] Wrote: JakeWharton__RxBinding
# [122/355] Wrote: kakajika__SwipeAwayDialog
# [123/355] Wrote: jungilhan__awesome-blogs-android
# [124/355] Wrote: karonl__InDoorSurfaceView
# [125/355] Wrote: kebernet__shortyz
# [126/355] Wrote: kost__NetworkMapper
# [127/355] Wrote: joreilly__StarWars
# [128/355] Wrote: AntennaPod__AntennaPod
# [129/355] Wrote: invertase__notifee
# [130/355] Wrote: krzdabrowski__android-starter-2022
# [131/355] Wrote: ksoichiro__AndroidFormEnhancer
# [132/355] Wrote: ksoichiro__Android-ObservableScrollView
# [133/355] Wrote: dart-lang__http
# [134/355] Wrote: DroidKaigi__conference-app-2022
# [135/355] Wrote: jerson__flutter-rsa
# [136/355] Wrote: ksoichiro__SimpleAlertDialog-for-Android
# [137/355] Wrote: jerson__flutter-openpgp
# [138/355] Wrote: jameshnsears__QuoteUnquote
# [139/355] Wrote: liangpengfei__LoadingPopPoint
# [140/355] Wrote: letelete__sleep-cycle-alarm
# [141/355] Wrote: liihuu__KLineChartAndroid
# [142/355] Wrote: linroid__Pexels
# [143/355] Wrote: livefront__bridge
# [144/355] Wrote: labexp__osmtracker-android
# [145/355] Wrote: lcdsmao__JetTheme
# [146/355] Wrote: lopspower__PokeCardCompose
# [147/355] Wrote: lolo-io__OneList
# [148/355] Wrote: MackHartley__RoundedProgressBar
# [149/355] Wrote: leandroBorgesFerreira__LoadingButtonAndroid
# [150/355] Wrote: MarcinMoskala__PreferenceHolder
# [151/355] Wrote: maksim-m__Popular-Movies-App
# [152/355] Wrote: mapbox__store-locator-android
# [153/355] Wrote: admob-plus__admob-plus
# [154/355] Wrote: KaustubhPatange__navigator
# [155/355] Wrote: maxistar__TextPad
# [156/355] Wrote: maxpower47__PinDroid
# [157/355] Wrote: MichaelEvans__Aftermath
# [158/355] Wrote: michelelacorte__AndroidAppShortcuts
# [159/355] Wrote: juancastillo0__wasm_run
# [160/355] Wrote: ligi__SurvivalManual
# [161/355] Wrote: miguelhincapie__CustomBottomSheetBehavior
# [162/355] Wrote: JackEblan__Geto
# [163/355] Wrote: maxkeppeler__sheets-compose-dialogs
# [164/355] Wrote: jaredsburrows__android-gif-search
# [165/355] Wrote: medic__cht-gateway
# [166/355] Wrote: joreilly__PeopleInSpace
# [167/355] Wrote: MostafaGazar__soas
# [168/355] Wrote: massivedisaster__ADAL
# [169/355] Wrote: firebase__FirebaseUI-Flutter
# [170/355] Wrote: mathisdt__trackworktime
# [171/355] Wrote: BlueWallet__BlueWallet
# [172/355] Wrote: natario1__GIFCompressor
# [173/355] Wrote: kickstarter__android-oss
# [174/355] Wrote: michaeltroger__pdfwallet-android
# [i/355] [error] MetaMask__metamask-mobile: [WinError 206] The filename or extension is too long
# [176/355] Wrote: n8ebel__GitHubActionsAutomationSandbox
# [177/355] Wrote: android__codelab-android-compose
# [178/355] Wrote: coil-kt__coil
# [179/355] Wrote: nhirokinet__bluelineconsole
# [180/355] Wrote: microservicer__flutter-pipelines
# [181/355] Wrote: inaturalist__iNaturalistReactNative
# [182/355] Wrote: okanaydin__Android-Compose-Challenge
# [183/355] Wrote: nanihadesuka__NovelDokusha
# [184/355] Wrote: nukc__LoadMoreWrapper
# [185/355] Wrote: nukc__StateView
# [186/355] Wrote: ligi__PassAndroid
# [187/355] Wrote: moezbhatti__qksms
# [188/355] Wrote: haqq-network__haqq-wallet
# [189/355] Wrote: isar__isar
# [190/355] Wrote: OlauncherCF__OlauncherCF
# [191/355] Wrote: OpnTec__bodyapps-android
# [192/355] Wrote: MikeOrtiz__TouchImageView
# [193/355] Wrote: openintents__shoppinglist
# [194/355] Wrote: nschnettler__Compose-Scrobbler
# [195/355] Wrote: mjaakko__NeoStumbler
# [196/355] Wrote: nkuppan__expensemanager
# [197/355] Wrote: OneBusAway__onebusaway-android
# [198/355] Wrote: openthread__ot-commissioner
# [199/355] Wrote: pauloaapereira__AndroidDevChallenge_Week4_JetWeatherfy
# [200/355] Wrote: Piasy__YaMvp
# [201/355] Wrote: mlcommons__mobile_app_open
# [202/355] Wrote: mshdabiola__NotePad
# [203/355] Wrote: NiciDieNase__chaosflix
# [204/355] Wrote: opendocument-app__OpenDocument.droid
# [205/355] Wrote: prisma__react-native-prisma
# [206/355] Wrote: ooni__probe-android
# [207/355] Wrote: passsy__spot
# [208/355] Wrote: posm__OpenMapKitAndroid
# [209/355] Wrote: oxygen-updater__oxygen-updater
# [210/355] Wrote: promeG__TinyPinyin
# [211/355] Wrote: PRosenb__AdbClipboard
# [212/355] Wrote: PureWriter__ToastCompat
# [213/355] Wrote: pilgr__Paper
# [214/355] Wrote: ragunathjawahar__android-saripaar
# [215/355] Wrote: kylecorry31__Trail-Sense
# [i/355] [error] rainbow-me__rainbow: [WinError 206] The filename or extension is too long
# [217/355] Wrote: Redgram__redgram-for-reddit
# [218/355] Wrote: natsuk4ze__gal
# [219/355] Wrote: RedMadRobot__PINkman
# [220/355] Wrote: orgzly-revived__orgzly-android-revived
# [221/355] Wrote: OpenTracksApp__OpenTracks
# [222/355] Wrote: riggaroo__adopt-me-compose
# [223/355] Wrote: rejasupotaro__Rebuild
# [224/355] Wrote: riggaroo__AndroidDatabaseUpgrades
# [225/355] Wrote: rafsanjani__datepickertimeline
# [226/355] Wrote: ronaldsmartin__Material-ViewPagerIndicator
# [227/355] Wrote: Nailik__rhasspy_mobile
# [228/355] Wrote: readrops__Readrops
# [229/355] Wrote: RoRoche__AndroidStarter
# [230/355] Wrote: NUmeroAndDev__MaterialGallery-android
# [231/355] Wrote: rtoshiro__FullscreenVideoView
# [232/355] Wrote: Bdaya-Dev__oidc
# [233/355] Wrote: renyuneyun__Easer
# [234/355] Wrote: salvadordeveloper__flutter-crypto-app
# [235/355] Wrote: sakusaku3939__DeepLAndroid
# [236/355] Wrote: ruffle-rs__ruffle-android
# [237/355] Wrote: rosuH__EasyWatermark
# [238/355] Wrote: requery__requery
# [i/355] [error] pytorch__executorch: [WinError 206] The filename or extension is too long
# [240/355] Wrote: SecUSo__privacy-friendly-notes
# [241/355] Wrote: SecUSo__privacy-friendly-todo-list
# [242/355] Wrote: SecUSo__privacy-friendly-pedometer
# [243/355] Wrote: Rajawali__Rajawali
# [244/355] Wrote: privacybydesign__irmamobile
# [245/355] Wrote: servo__surfman
# [246/355] Wrote: sangcomz__FishBun
# [247/355] Wrote: sellmair__kompass
# [248/355] Wrote: android__nowinandroid
# [249/355] Wrote: simonnorberg__dmach
# [250/355] Wrote: segler-alex__RadioDroid
# [251/355] Wrote: rozPierog__Cofi
# [252/355] Wrote: scribe-org__Scribe-Android
# [253/355] Wrote: RBusarow__Tangle
# [254/355] Wrote: seedvault-app__seedvault
# [255/355] Wrote: Spikeysanju__Wiggles
# [256/355] Wrote: ReactiveCircus__streamlined
# [257/355] Wrote: cgeo__cgeo
# [258/355] Wrote: splitwise__TokenAutoComplete
# [259/355] Wrote: square__curtains
# [260/355] Wrote: square__cycler
# [261/355] Wrote: sky-map-team__stardroid
# [262/355] Wrote: square__papa
# [263/355] Wrote: Samsung__escargot
# [264/355] Wrote: pachli__pachli-android
# [265/355] Wrote: owntracks__android
# [266/355] Wrote: sopt-makers__sopt-android
# [267/355] Wrote: Stuart-campbell__RushOrm
# [268/355] Wrote: persian-calendar__persian-calendar
# [269/355] Wrote: smartdevicelink__sdl_java_suite
# [270/355] Wrote: syrjs__core
# [271/355] Wrote: StefanIlchev__ElementumService
# [272/355] Wrote: talenguyen__PrettyBundle
# [273/355] Wrote: takahirom__PreLollipopTransition
# [274/355] Wrote: spacecowboy__NotePad
# [275/355] Wrote: getodk__collect
# [276/355] Wrote: SwissCovid__swisscovid-app-android
# [277/355] Wrote: tfcporciuncula__flow-preferences
# [278/355] Wrote: spacecowboy__Feeder
# [279/355] Wrote: slackhq__circuit
# [280/355] Wrote: tfcporciuncula__phonemoji
# [281/355] Wrote: TharunBalaji2004__android-ci-cd
# [282/355] Wrote: thiagokimo__Faker
# [283/355] Wrote: t895__DNSNet
# [284/355] Wrote: synonymdev__bitkit
# [285/355] Wrote: PatilShreyas__NotyKT
# [286/355] Wrote: thevindu-w__clip_share_client
# [287/355] Wrote: tonilopezmr__Game-of-Thrones
# [288/355] Wrote: ThibaultBee__srtdroid
# [289/355] Wrote: tripadvisor__android-clockseekbar
# [290/355] Wrote: TUBB__CalendarSelector
# [291/355] Wrote: Tommy-Geenexus__exif-eraser
# [292/355] Wrote: thunderbiscuit__padawan-wallet
# [293/355] Wrote: TomRoush__PdfBox-Android
# [294/355] Wrote: twilio__twilio-voice-react-native
# [295/355] Wrote: RocketChat__Rocket.Chat.ReactNative
# [296/355] Wrote: thyrlian__AwesomeValidation
# [297/355] Wrote: softartdev__NoteDelight
# [298/355] Wrote: ValentinFunk__BrainPhaser
# [299/355] Wrote: twireapp__Twire
# [300/355] Wrote: VictorAlbertos__BreadcrumbsView
# [301/355] Wrote: VictorAlbertos__SwipeCoordinator
# [302/355] Wrote: vitaviva__compose-weather
# [303/355] Wrote: vitaviva__CountdownTimer
# [304/355] Wrote: vgaidarji__ci-matters
# [305/355] Wrote: uber__simple-store
# [306/355] Wrote: voghDev__PdfViewPager
# [307/355] Wrote: ValterKasper__space-app
# [308/355] Wrote: simpledotorg__simple-android
# [309/355] Wrote: openhab__openhab-android
# [310/355] Wrote: wajahatkarim3__Imagine
# [311/355] Wrote: v2er-app__Android
# [312/355] Wrote: woxingxiao__FillBlankView
# [313/355] Wrote: xebia-functional__appsly-android-rest
# [314/355] Wrote: UriahShaulMandel__BaldPhone
# [315/355] Wrote: xurxodev__Movies-Kotlin-Kata
# [316/355] Wrote: XuDaojie__MultiStateView
# [317/355] Wrote: square__leakcanary
# [318/355] Wrote: vmiklos__plees-tracker
# [319/355] Wrote: yeungeek__monkey-android
# [320/355] Wrote: zeref278__flutter_boilerplate
# [321/355] Wrote: getsentry__sentry-react-native
# [322/355] Wrote: willowtreeapps__vocable-android
# [323/355] Wrote: TeamAmaze__AmazeFileManager
# [324/355] Wrote: zsoltk__GameOfLife
# [325/355] Wrote: y-polek__TransmissionRemote
# [326/355] Wrote: VREMSoftwareDevelopment__WiFiAnalyzer
# [327/355] Wrote: TwidereProject__TwidereX-Android
# [328/355] Wrote: TeamNewPipe__NewPipe
# [329/355] Wrote: XRPL-Labs__Xaman-App
# [330/355] Wrote: yuriykulikov__AlarmClock
# [331/355] Wrote: trynoice__android-app
# [332/355] Wrote: zimly__zimly-backup
# [333/355] Wrote: software-mansion__react-native-screens
# [334/355] Wrote: AndBible__and-bible
# [335/355] Wrote: WangJie0822__Cashbook
# [336/355] Wrote: zkmopro__mopro
# [337/355] Wrote: tasks__tasks
# [338/355] Wrote: yogeshpaliyal__KeyPass
# [339/355] Wrote: streetwriters__notesnook
# [340/355] Wrote: TechbeeAT__jtxBoard
# [341/355] Wrote: wikimedia__apps-android-wikipedia
# [342/355] Wrote: square__okhttp
# [343/355] Wrote: realm__realm-kotlin
# [344/355] Wrote: EnsembleUI__ensemble
# [345/355] Wrote: robolectric__robolectric
# [346/355] Wrote: nightscout__AndroidAPS
# [347/355] Wrote: SharezoneApp__sharezone-app
# [348/355] Wrote: zoff99__ToxAndroidRefImpl
# [349/355] Wrote: MiSikora__laboratory
# [350/355] Wrote: square__wire
# [351/355] Wrote: ankidroid__Anki-Android
# [352/355] Wrote: dart-lang__native
# [353/355] Wrote: sqldelight__sqldelight
# [354/355] Wrote: nextcloud__android
# [355/355] Wrote: LedgerHQ__ledger-live
# [done] JSON -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\mineV1.0  (written=352, skipped=0, errors=3)
# [done] Summary: index_summary.csv, index_summary.json, QA: qa_issues.csv
# [done] Env/PR/Issues CSV: env_events_with_pr_issues.csv
# [run] Finished.

# %% [markdown]
# ## Step 3_ Creating the Change
# Episodes defintion: Start to current timeline
# It create change episode && list of relevent Commits

# %%
# === Build dataset for Observation 3.1 (V1.0 aligned) ===
# ==========================

from __future__ import annotations
import json
from pathlib import Path
from datetime import datetime, timezone, timedelta
from typing import Dict, List, Optional, Tuple, Set
from collections import defaultdict, OrderedDict

import pandas as pd

# ---- Paths ----
WORK_ROOT   = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
OUTPUT_MINE = WORK_ROOT / "mineV1.0"

MAIN_CSV = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\1_Main_Spreadsheet\5.0_Total_Repo.csv")

OBS_OUTPUT = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations")
OBS_OUTPUT.mkdir(parents=True, exist_ok=True)

# ---- Settings ----
CUTOFF_ISO   = "2025-08-10 23:59:59 +0000"
PERSIST_DAYS = 14.0
CANONICAL_STYLES: Set[str] = {"Emu_Community", "Emu_Custom", "GMD", "ThirdParty"}

# ---- Helpers ----
def parse_iso(s: Optional[str]) -> Optional[datetime]:
    if not s:
        return None
    s = s.strip()
    if s.endswith("Z"):
        s = s[:-1] + "+00:00"
    # normalize +0000 -> +00:00
    if len(s) >= 5 and (s[-5] in ["+","-"]) and s[-3] != ":":
        s = s[:-2] + ":" + s[-2:]
    try:
        dt = datetime.fromisoformat(s)
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt.astimezone(timezone.utc)
    except Exception:
        return None

CUTOFF_DT = parse_iso(CUTOFF_ISO)
assert CUTOFF_DT is not None, f"Bad CUTOFF_ISO: {CUTOFF_ISO}"

def days_between(a: datetime, b: datetime) -> float:
    return (b - a).total_seconds() / 86400.0

def normalize_styles(style_list: List[str]) -> Set[str]:
    return {s for s in (style_list or []) if s in CANONICAL_STYLES}

def label_from_set(s: Set[str]) -> str:
    if "Emu_Community" in s and "Emu_Custom" in s:
        return "Both"
    if "Emu_Community" in s:
        return "Community"
    if "Emu_Custom" in s:
        return "Custom"
    if "GMD" in s:
        return "GMD"
    if "ThirdParty" in s:
        return "ThirdParty"
    return "None"

def read_repo_jsons(output_dir: Path) -> List[Path]:
    return sorted([p for p in output_dir.glob("*.emulator_timeline.json")])

def filter_timeline_to_default_branch(rec: Dict) -> List[Dict]:
    """
    Keep only timeline rows whose commit belongs to the default branch,
    based on the per-event `on_default` flag.
    """
    timeline_rows = rec.get("timeline") or []
    events_dict = rec.get("events") or {}

    # Collect all commits that are marked as on_default == 1
    default_commits: Set[str] = set()
    for style in CANONICAL_STYLES:
        for ev in events_dict.get(style, []):
            if ev.get("on_default", 0) == 1:
                sha = (ev.get("commit") or "").strip()
                if sha:
                    default_commits.add(sha)

    # If we somehow have no default commits, fall back to original timeline
    if not default_commits:
        return timeline_rows

    # Filter timeline rows to only those commits on default branch
    filtered = [
        row for row in timeline_rows
        if (row.get("commit") or "").strip() in default_commits
    ]
    return filtered

def build_episodes(timeline_rows: List[Dict], cutoff_dt: datetime) -> List[Dict]:
    """
    Build episodes as maximal contiguous intervals where the canonical style set
    (intersection with CANONICAL_STYLES) stays the same, capped at cutoff.
    A new episode starts ONLY when the canonical style set actually changes.
    """
    # Keep only rows that have at least one canonical style
    rows = []
    for r in (timeline_rows or []):
        dt = parse_iso(r.get("date"))
        if dt is None:
            continue
        styles_now = normalize_styles(list(r.get("styles") or []))
        if not styles_now:
            continue
        if dt > cutoff_dt:
            # anything after cutoff is irrelevant
            continue
        rows.append({"date": dt, "styles": styles_now})

    # Sort by time
    rows.sort(key=lambda r: r["date"])

    episodes: List[Dict] = []
    if not rows:
        return episodes

    # Initialise with the first canonical row
    cur_start = rows[0]["date"]
    cur_styles = rows[0]["styles"]

    for r in rows[1:]:
        dt = r["date"]
        styles_now = r["styles"]

        # If canonical style set is unchanged, just continue the current episode
        if styles_now == cur_styles:
            continue

        # Style set changed: close the current episode at this time
        end = min(dt, cutoff_dt)
        if end > cur_start:
            episodes.append({
                "start": cur_start,
                "end": end,
                "styles": cur_styles,
                "duration_days": max(0.0, days_between(cur_start, end)),
            })

        # Start new episode with the new style set
        cur_start = dt
        cur_styles = styles_now

    # Close the last episode up to the cutoff
    if cur_start < cutoff_dt:
        end = cutoff_dt
        episodes.append({
            "start": cur_start,
            "end": end,
            "styles": cur_styles,
            "duration_days": max(0.0, days_between(cur_start, end)),
        })

    return episodes

# ---- Per-style interval utilities ----
def merge_intervals(intervals: List[Tuple[datetime, datetime]]) -> List[Tuple[datetime, datetime]]:
    """Merge overlapping/contiguous [start,end] intervals."""
    if not intervals:
        return []
    intervals.sort(key=lambda ab: ab[0])
    merged: List[Tuple[datetime, datetime]] = []
    cur_s, cur_e = intervals[0]
    for a, b in intervals[1:]:
        if a <= cur_e:  # overlap or contiguous
            if b > cur_e: cur_e = b
        else:
            merged.append((cur_s, cur_e))
            cur_s, cur_e = a, b
    merged.append((cur_s, cur_e))
    return merged

def per_style_intervals(episodes: List[Dict]) -> Dict[str, List[Tuple[datetime, datetime]]]:
    """Intervals per style drawn from episode styles (episodes already capped at cutoff)."""
    m: Dict[str, List[Tuple[datetime, datetime]]] = {s: [] for s in CANONICAL_STYLES}
    for ep in episodes:
        for s in (ep["styles"] or []):
            if s in CANONICAL_STYLES:
                m[s].append((ep["start"], ep["end"]))
    # merge
    return {s: merge_intervals(v) for s, v in m.items() if v}

# ---- FIRST via union ≥14d ----
def first_union14d(episodes: List[Dict], min_days: float) -> Tuple[Optional[datetime], Optional[str]]:
    """
    Earliest moment any single style achieves ≥min_days of continuous coverage.
    Returns (first_date, style_name) or (None, None).
    """
    psi = per_style_intervals(episodes)
    best_date: Optional[datetime] = None
    best_style: Optional[str] = None

    # deterministic style tie-break order
    order = ["Emu_Community", "Emu_Custom", "GMD", "ThirdParty"]
    for style in order:
        if style not in psi:
            continue
        for a, b in psi[style]:
            if days_between(a, b) >= min_days:
                t = a + timedelta(days=min_days)
                if best_date is None or t < best_date or (t == best_date and order.index(style) < order.index(best_style)):  # type: ignore
                    best_date = t
                    best_style = style
                break  # earliest interval for this style is enough

    return best_date, best_style

# ---- TIMELINE formation set (union of styles that ever achieved ≥14d) ----
def timeline_union14d_styles(episodes: List[Dict], min_days: float) -> Set[str]:
    psi = per_style_intervals(episodes)
    kept: Set[str] = set()
    for s, ivs in psi.items():
        for a, b in ivs:
            if days_between(a, b) >= min_days:
                kept.add(s)
                break
    return kept

def _find_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    lowmap = {c.lower(): c for c in df.columns}
    for name in candidates:
        if name.lower() in lowmap:
            return lowmap[name.lower()]
    return None

# ---- Build OBS core from miner ----
records: List[Dict] = []

# NEW: per-event rows across all repos
episode_event_rows: List[Dict] = []

json_files = read_repo_jsons(OUTPUT_MINE)
if not json_files:
    raise FileNotFoundError(f"No miner JSON files found under: {OUTPUT_MINE}")

for jf in json_files:
    with jf.open("r", encoding="utf-8") as f:
        rec = json.load(f)

    repo = rec.get("repo_name") or jf.stem
    full_name = (repo or "").replace("__", ".")
    # Filter timeline to default-branch commits
    timeline = filter_timeline_to_default_branch(rec)

    episodes = build_episodes(timeline, CUTOFF_DT)

    # --- EPISODES: only those with duration ≥14 days are "persistent" episodes ---
    persistent_eps = [ep for ep in episodes if ep.get("duration_days", 0.0) >= PERSIST_DAYS]
    # assign stable indexes based on time
    persistent_eps.sort(key=lambda ep: ep["start"])
    for idx, ep in enumerate(persistent_eps, start=1):
        ep["episode_index"] = idx

    # Precompute episode boundary maps: (style, timestamp_utc) -> [episode_index,...]
    start_boundaries = defaultdict(list)
    end_boundaries = defaultdict(list)
    for ep in persistent_eps:
        start_key = ep["start"].astimezone(timezone.utc).isoformat()
        end_key   = ep["end"].astimezone(timezone.utc).isoformat()
        for s in ep["styles"]:
            if s in CANONICAL_STYLES:
                start_boundaries[(s, start_key)].append(ep["episode_index"])
                end_boundaries[(s, end_key)].append(ep["episode_index"])

    # --- Build per-event rows for THIS repo ---
    events_dict = rec.get("events") or {}
    for style in CANONICAL_STYLES:
        for ev in events_dict.get(style, []):
            ev_type = ev.get("event", "")
            raw_date = ev.get("date", "")
            dt = parse_iso(raw_date)
            if dt is None:
                continue
            dt_utc = dt.astimezone(timezone.utc)
            dt_key = dt_utc.isoformat()

            # map this event into (at most one) persistent episode for this style
            in_persist = 0
            ep_idx = None
            ep_start = ep_end = None
            ep_dur = None

            for ep in persistent_eps:
                # episode is active if style is in its styles and date in [start,end]
                if style in ep["styles"] and ep["start"] <= dt_utc <= ep["end"]:
                    in_persist = 1
                    ep_idx = ep.get("episode_index")
                    ep_start = ep["start"].astimezone(timezone.utc).isoformat()
                    ep_end = ep["end"].astimezone(timezone.utc).isoformat()
                    ep_dur = ep.get("duration_days")
                    break

            is_start_boundary = 1 if (style, dt_key) in start_boundaries else 0
            is_end_boundary   = 1 if (style, dt_key) in end_boundaries else 0

            episode_event_rows.append({
                "repo_name": repo,
                "full_name": full_name,
                "env_style": style,
                "event_type": ev_type,
                "event_date_raw": raw_date,
                "event_date_utc": dt_key,
                "commit": ev.get("commit", ""),
                "commit_sha": ev.get("commit", ""),      # explicit SHA for joining
                "on_default": ev.get("on_default", 0),

                "in_persistent_episode": in_persist,
                "episode_index": ep_idx if ep_idx is not None else "",
                "episode_start_utc": ep_start if ep_start is not None else "",
                "episode_end_utc": ep_end if ep_end is not None else "",
                "episode_duration_days": ep_dur if ep_dur is not None else "",

                "is_episode_start_boundary": is_start_boundary,
                "is_episode_end_boundary": is_end_boundary,
            })

    # --- Summary metrics per repo as before ---
    # Count episodes with ≥14d (for reference)
    num_episodes = len(persistent_eps)

    # FIRST via union ≥14d
    first_dt, first_style = first_union14d(episodes, PERSIST_DAYS)
    if first_dt and first_style:
        first_styleset_union14d = first_style
        first_label = label_from_set({first_style})
        first_year = first_dt.year
    else:
        first_styleset_union14d = ""
        first_label = "None"
        first_year = ""

    # TIMELINE formation set (filters out temporary <14d styles)
    timeline_set = timeline_union14d_styles(episodes, PERSIST_DAYS)
    timeline_styleset_union14d = "+".join(sorted(timeline_set)) if timeline_set else ""
    timeline_label_union14d = label_from_set(timeline_set)

    # CURRENT snapshot (repo-wide, no ≥14d)
    snap_def_raw  = rec.get("snapshot_as_of_cutoff_default") or []
    snap_all_raw  = rec.get("snapshot_as_of_cutoff_repo_wide") or []
    snap_def_norm_set  = normalize_styles(snap_def_raw)
    snap_all_norm_set  = normalize_styles(snap_all_raw)

    current_label_snapshot    = label_from_set(snap_all_norm_set)
    current_styleset_snapshot = "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else ""

    # Default-branch snapshot
    current_styleset_default_B = "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else ""

    # Optional diagnostic: short-and-active-at-cutoff flag (kept)
    recent_lt14d = 0
    if episodes:
        last_ep = episodes[-1]
        if last_ep["end"] >= CUTOFF_DT and last_ep["duration_days"] < PERSIST_DAYS:
            recent_lt14d = 1

    out = {
        "repo_name": repo,
        "full_name": full_name,
        "cutoff_date": CUTOFF_ISO,

        "num_episodes": num_episodes,

        # FIRST (union ≥14d)
        "first_date": first_dt.isoformat() if first_dt else "",
        "first_year": first_year,
        "first_label": first_label,
        "first_styleset": first_styleset_union14d,           # updated meaning
        "first_styleset_union14d": first_styleset_union14d,  # explicit column

        # TIMELINE formation set (ever ≥14d)
        "timeline_styleset_union14d": timeline_styleset_union14d,
        "timeline_label_union14d": timeline_label_union14d,

        # CURRENT (snapshot)
        "current_label_snapshot": current_label_snapshot,
        "current_styleset_snapshot": current_styleset_snapshot,
        "current_styleset_default_B": current_styleset_default_B,

        # Diagnostics
        "current_recent_lt14d": recent_lt14d,
        "snapshot_default_norm": "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else "",
        "snapshot_repo_wide_norm": "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else "",
        "qa_issue": rec.get("qa_issue", ""),
    }
    records.append(out)

# ==== Build repo-level summary DF (same as before) ====
df = pd.DataFrame.from_records(records).sort_values(["first_date", "repo_name"], na_position="last")

# ---- Merge MAIN: include 'execution_environment' as-is; exclude api_*; prefix the rest with main_ ----
if MAIN_CSV.exists():
    df_main = pd.read_csv(MAIN_CSV, dtype=str, encoding="utf-8", keep_default_na=False)

    col_full = _find_col(df_main, ["full_name", "Full_name", "repo_full_name"])
    col_exec = _find_col(df_main, ["execution_environment", "Execution_Environment"])

    if col_full:
        df["_key"] = df["full_name"].astype(str).str.lower().str.strip()
        df_main["_key"] = df_main[col_full].astype(str).str.lower().str.strip()

        # execution_environment as-is
        if col_exec:
            df_exec = df_main[["_key", col_exec]].copy()
            df_exec.rename(columns={col_exec: "execution_environment"}, inplace=True)
            df = df.merge(df_exec, on="_key", how="left")
        else:
            df["execution_environment"] = ""

        # other MAIN columns (exclude join col, exec col, any api_*)
        main_cols = []
        for c in df_main.columns:
            cl = c.lower()
            if c in {"_key", col_full}: continue
            if col_exec and c == col_exec: continue
            if cl.startswith("api_"): continue
            main_cols.append(c)
        if main_cols:
            df_other = df_main[["_key"] + main_cols].copy()
            df_other.rename(columns={c: f"main_{c}" for c in main_cols}, inplace=True)
            df = df.merge(df_other, on="_key", how="left")

        df.drop(columns=["_key"], inplace=True, errors="ignore")
    else:
        df["execution_environment"] = ""
else:
    df["execution_environment"] = ""

# ---- Column order: repo_name, full_name, execution_environment, then the rest ----
cols = list(df.columns)
for required in ["repo_name", "full_name", "execution_environment"]:
    if required not in cols:
        cols.insert(0, required)

# place full_name after repo_name
if "repo_name" in cols and "full_name" in cols:
    cols.remove("full_name")
    cols.insert(cols.index("repo_name") + 1, "full_name")

# place execution_environment after full_name
if "execution_environment" in cols:
    cols.remove("execution_environment")
    insert_at = cols.index("full_name") + 1 if "full_name" in cols else 1
    cols.insert(insert_at, "execution_environment")

df = df[cols]

# ---- FILTER: exclude repos where first_label == "None" ----
pre_filter_n = len(df)
df = df[df["first_label"] != "None"].copy()
post_filter_n = len(df)
dropped_n = pre_filter_n - post_filter_n
print(f"[info] Excluding repos with first_label == 'None': dropped {dropped_n} of {pre_filter_n}")

# ---- Save repo-level summary ----
out_csv = OBS_OUTPUT / "obs3_1_entry_vs_current.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"[ok] Wrote dataset (filtered): {out_csv}")

# ---- Save event-level / commit-level CSV for episode analysis ----
events_df = pd.DataFrame.from_records(episode_event_rows)

if not events_df.empty:
    # Filter to default-branch events only
    events_df = events_df[events_df["on_default"] == 1].copy()

    # Keep ONLY the commits that actually create the ≥14-day change episodes:
    #  - events inside a persistent episode
    #  - event_type is added/removed (no maintenance)
    #  - event is at start or end boundary of that persistent episode
    mask = (
        (events_df["in_persistent_episode"] == 1) &
        (events_df["event_type"].isin(["added", "removed"])) &
        (
            (events_df["is_episode_start_boundary"] == 1) |
            (events_df["is_episode_end_boundary"] == 1)
        )
    )
    events_df = events_df[mask].copy()

    # Nice ordering for the commit-level dataset
    sort_cols = [
        "repo_name",
        "episode_index",
        "event_date_utc",
        "env_style",
        "event_type",
    ]
    sort_cols = [c for c in sort_cols if c in events_df.columns]
    if sort_cols:
        events_df.sort_values(sort_cols, inplace=True)

# === RQ4 output: change-episode commits with SHAs (event-level) ===
rq4_out_csv = OBS_OUTPUT / "observation_RQ4.csv"
events_df.to_csv(rq4_out_csv, index=False, encoding="utf-8")
print(f"[ok] Wrote RQ4 change-episode dataset with commit SHAs: {rq4_out_csv}")

# === Build per-episode list with explicit start/end commits (episode-level) ===
if not events_df.empty:
    def join_unique(series, sep=" || "):
        vals = [str(x).strip() for x in series.dropna() if str(x).strip()]
        # preserve original order but remove duplicates
        vals = list(OrderedDict.fromkeys(vals))
        return sep.join(vals) if vals else ""

    # Base per-episode aggregation (NO boundary_commit_shas anymore)
    episodes_list_df = (
        events_df
        .groupby(["repo_name", "full_name", "episode_index"], dropna=False)
        .agg(
            episode_start_utc=("episode_start_utc", "first"),
            episode_end_utc=("episode_end_utc", "first"),
            episode_duration_days=("episode_duration_days", "first"),

            # which styles participate in this episode (from boundary events)
            env_styles=("env_style", join_unique),

            # optional: what kind of boundary events (added/removed) and when
            boundary_event_types=("event_type", join_unique),
            boundary_event_dates=("event_date_utc", join_unique),
        )
        .reset_index()
    )

    # --- single "start commit" per episode ---
    # earliest start-boundary event (intro of the episode)
    start_commit_df = (
        events_df[events_df["is_episode_start_boundary"] == 1]
        .assign(
            event_dt=lambda df: pd.to_datetime(
                df["event_date_utc"], utc=True, errors="coerce"
            )
        )
        .sort_values(["repo_name", "full_name", "episode_index", "event_dt"])
        .groupby(["repo_name", "full_name", "episode_index"])
        .head(1)[["repo_name", "full_name", "episode_index", "commit_sha"]]
        .rename(columns={"commit_sha": "episode_start_commit_sha"})
    )

    # single "end commit" per episode
    end_commit_df = (
        events_df[events_df["is_episode_end_boundary"] == 1]
        .assign(
            event_dt=lambda df: pd.to_datetime(
                df["event_date_utc"], utc=True, errors="coerce"
            )
        )
        .sort_values(["repo_name", "full_name", "episode_index", "event_dt"])
        .groupby(["repo_name", "full_name", "episode_index"])
        .tail(1)[["repo_name", "full_name", "episode_index", "commit_sha"]]
        .rename(columns={"commit_sha": "episode_end_commit_sha"})
    )

    # Merge start + end commits onto the per-episode table
    episodes_list_df = episodes_list_df.merge(
        start_commit_df,
        on=["repo_name", "full_name", "episode_index"],
        how="left"
    )
    episodes_list_df = episodes_list_df.merge(
        end_commit_df,
        on=["repo_name", "full_name", "episode_index"],
        how="left"
    )

    # Sort episodes nicely
    ep_sort_cols = ["repo_name", "episode_index", "episode_start_utc"]
    ep_sort_cols = [c for c in ep_sort_cols if c in episodes_list_df.columns]
    if ep_sort_cols:
        episodes_list_df.sort_values(ep_sort_cols, inplace=True)

else:
    # empty placeholder if there were no episodes
    episodes_list_df = pd.DataFrame(
        columns=[
            "repo_name", "full_name", "episode_index",
            "episode_start_utc", "episode_end_utc", "episode_duration_days",
            "env_styles", "boundary_event_types", "boundary_event_dates",
            "episode_start_commit_sha", "episode_end_commit_sha",
        ]
    )

episodes_out_csv = OBS_OUTPUT / "list_of_episodes.csv"
episodes_list_df.to_csv(episodes_out_csv, index=False, encoding="utf-8")
print(f"[ok] Wrote per-episode list with start/end commits: {episodes_out_csv}")

# Optional quick peek
try:
    show_cols = [
        "repo_name","full_name","execution_environment",
        "num_episodes",
        "first_year","first_label","first_date",
        "first_styleset","first_styleset_union14d",
        "timeline_styleset_union14d","timeline_label_union14d",
        "current_label_snapshot","current_styleset_snapshot",
        "current_styleset_default_B",
        "current_recent_lt14d",
        "snapshot_repo_wide_norm"
    ]
    show_cols += [c for c in df.columns if c.startswith("main_")][:3]
    print(df[show_cols].head(20).to_string(index=False))
except Exception:
    pass
# Out:
# [info] Excluding repos with first_label == 'None': dropped 12 of 352
# [ok] Wrote dataset (filtered): C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\obs3_1_entry_vs_current.csv
# [ok] Wrote RQ4 change-episode dataset with commit SHAs: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\observation_RQ4.csv
# [ok] Wrote per-episode list with start/end commits: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\list_of_episodes.csv
#                                 repo_name                                full_name execution_environment  num_episodes first_year first_label                first_date first_styleset first_styleset_union14d   timeline_styleset_union14d timeline_label_union14d current_label_snapshot    current_styleset_snapshot current_styleset_default_B  current_recent_lt14d      snapshot_repo_wide_norm
#                   ankidroid__Anki-Android                   ankidroid.Anki-Android                                   2       2013      Custom 2013-07-04T07:12:51+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom
#                              tasks__tasks                              tasks.tasks                                   4       2013      Custom 2013-10-30T23:48:56+00:00     Emu_Custom              Emu_Custom Emu_Community+Emu_Custom+GMD                    Both                   Both Emu_Community+Emu_Custom+GMD          Emu_Community+GMD                     0 Emu_Community+Emu_Custom+GMD
#     xebia-functional__appsly-android-rest     xebia-functional.appsly-android-rest                                   1       2014      Custom 2014-01-11T22:45:09+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                      spacecowboy__NotePad                      spacecowboy.NotePad                                   2       2014      Custom 2014-02-01T14:45:28+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community
#                        nextcloud__android                        nextcloud.android                                   2       2014      Custom 2014-02-04T16:16:57+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom
#                     rejasupotaro__Rebuild                     rejasupotaro.Rebuild                                   1       2014      Custom 2014-02-17T14:16:49+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#  ksoichiro__SimpleAlertDialog-for-Android  ksoichiro.SimpleAlertDialog-for-Android                                   1       2014      Custom 2014-03-22T14:35:30+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#            ksoichiro__AndroidFormEnhancer            ksoichiro.AndroidFormEnhancer                                   1       2014      Custom 2014-03-23T11:15:00+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                    AntennaPod__AntennaPod                    AntennaPod.AntennaPod                                   2       2014      Custom 2014-06-01T20:12:08+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community
#            OneBusAway__onebusaway-android            OneBusAway.onebusaway-android                                   2       2014      Custom 2014-06-10T17:14:25+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community
#                 openintents__shoppinglist                 openintents.shoppinglist                                   1       2014      Custom 2014-06-30T11:25:16+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                  OpnTec__bodyapps-android                  OpnTec.bodyapps-android                                   1       2014      Custom 2014-07-06T19:34:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
# blazsolar__android-collapse-calendar-view blazsolar.android-collapse-calendar-view                                   1       2014      Custom 2014-07-30T10:03:36+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                          AChep__AcDisplay                          AChep.AcDisplay                                   1       2014      Custom 2014-08-05T16:23:35+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#         tripadvisor__android-clockseekbar         tripadvisor.android-clockseekbar                                   1       2014      Custom 2014-08-18T20:21:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                         ligi__PassAndroid                         ligi.PassAndroid                                   1       2014      Custom 2014-08-26T19:45:07+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom              Community                Emu_Community              Emu_Community                     0                Emu_Community
#   ksoichiro__Android-ObservableScrollView   ksoichiro.Android-ObservableScrollView                                   1       2014      Custom 2014-11-22T15:16:43+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                       simonnorberg__dmach                       simonnorberg.dmach                                   2       2015      Custom 2015-01-01T19:43:14+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community
#                        MostafaGazar__soas                        MostafaGazar.soas                                   1       2015      Custom 2015-01-12T21:40:46+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom
#                 federicoiosue__Omni-Notes                 federicoiosue.Omni-Notes                                   2       2015      Custom 2015-03-03T00:13:10+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom

# %% [markdown]
# # Step 5: Final CSV:
#
# Final list of change commits with all the intention sources: Commits subjects and boddys, PRs and Issues

# %%
from __future__ import annotations

import json
from pathlib import Path
from typing import Dict, List, Tuple, Any

import pandas as pd


# -----------------------------
# Config
# -----------------------------
WORK_ROOT   = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
OBS_DIR     = WORK_ROOT / "Observations"
OBS_CSV     = OBS_DIR / "obs3_1_change_episodes_commits.csv"

META_ROOT   = WORK_ROOT / "metadataV1.0"    # PR / Issues JSONs

# 👉 env_events_with_pr_issues CSV (adjust filename if needed)
MINER_SUMMARY_CSV = WORK_ROOT / "mineV1.0/miner summary" / "env_events_with_pr_issues.csv"

OUT_CSV     = OBS_DIR / "All_Env_Change_Commit_PR_Iss.csv"


# -----------------------------
# Helpers
# -----------------------------

def _find_col(df: pd.DataFrame, candidates: List[str]) -> str | None:
    """
    Find a column in df matching any of the candidate names (case-insensitive).
    Returns the actual column name or None.
    """
    lowmap = {c.lower(): c for c in df.columns}
    for name in candidates:
        if name.lower() in lowmap:
            return lowmap[name.lower()]
    return None


def load_json(path: Path) -> Any:
    """Safely load JSON or return [] if file doesn't exist."""
    if not path.exists():
        return []
    with path.open("r", encoding="utf-8") as f:
        return json.load(f)


def build_commit_to_pr_issue_maps(
    prs: List[dict],
    issues: List[dict],
) -> Tuple[Dict[str, List[dict]], Dict[str, List[dict]]]:
    """
    Build:
      - commit_sha -> [PRs]
      - commit_sha -> [Issues]

    Prefers the `target_commits` field if present (as produced by the
    targeted metadata miner). Falls back to merge_commit_sha for PRs.
    """
    commit_to_prs: Dict[str, List[dict]] = {}

    for pr in prs:
        # Prefer explicit target_commits added by the metadata step
        targets = pr.get("target_commits") or []
        if isinstance(targets, str):
            targets = [targets]
        shas: List[str] = []

        if targets:
            shas = [s.strip() for s in targets if s]
        else:
            merge_sha = pr.get("merge_commit_sha")
            if merge_sha:
                shas = [merge_sha.strip()]

        for sha in shas:
            if not sha:
                continue
            commit_to_prs.setdefault(sha, []).append(pr)

    commit_to_issues: Dict[str, List[dict]] = {}

    # NOTE: this only works if issues JSON includes 'target_commits'.
    for iss in issues:
        targets = iss.get("target_commits") or []
        if isinstance(targets, str):
            targets = [targets]

        shas = [s.strip() for s in targets if s]
        for sha in shas:
            if not sha:
                continue
            commit_to_issues.setdefault(sha, []).append(iss)

    return commit_to_prs, commit_to_issues


def summarise_prs(prs_for_commit: List[dict]) -> Dict[str, str]:
    """
    Turn a list of PR dicts into flattened string fields matching the
    columns used in 3 - env_events_with_pr_issues.
    If multiple PRs map to the same commit, values are joined with " | ".
    """
    def join(vals):
        vs = [str(v) for v in vals if v not in (None, "")]
        return " | ".join(vs) if vs else ""

    pr_numbers = join([pr.get("number") for pr in prs_for_commit])
    pr_states  = join([pr.get("state") for pr in prs_for_commit])
    pr_titles  = join([pr.get("title") for pr in prs_for_commit])
    pr_bodies  = join([pr.get("body") for pr in prs_for_commit])
    pr_created = join([pr.get("created_at") for pr in prs_for_commit])
    pr_merged  = join([pr.get("merged_at") for pr in prs_for_commit])
    pr_closed  = join([pr.get("closed_at") for pr in prs_for_commit])

    pr_users   = join([
        (pr.get("user") or {}).get("login")
        for pr in prs_for_commit
    ])

    pr_labels  = join([
        ";".join([
            lab.get("name", "")
            for lab in (pr.get("labels") or [])
            if lab.get("name")
        ])
        for pr in prs_for_commit
    ])

    pr_urls    = join([pr.get("html_url") for pr in prs_for_commit])

    return {
        "pr_number": pr_numbers,
        "pr_state": pr_states,
        "pr_title": pr_titles,
        "pr_body": pr_bodies,
        "pr_created_at": pr_created,
        "pr_merged_at": pr_merged,
        "pr_closed_at": pr_closed,
        "pr_user_login": pr_users,
        "pr_labels": pr_labels,
        "pr_html_url": pr_urls,
    }


def summarise_issues(issues_for_commit: List[dict]) -> str:
    """
    Build a compact 'issues_summary' string, e.g.:
      "#123: Crash on emulator | #456: CI config update"
    """
    parts: List[str] = []
    for iss in issues_for_commit:
        num = iss.get("number")
        title = (iss.get("title") or "").strip()
        if num is not None:
            if title:
                parts.append(f"#{num}: {title}")
            else:
                parts.append(f"#{num}")
        elif title:
            parts.append(title)
    return " | ".join(parts)


def load_commit_messages_from_miner(path: Path) -> Dict[str, Tuple[str, str]]:
    """
    Load commit subject/body from the env_events_with_pr_issues CSV.

    Tries to detect columns:
      - commit SHA:   one of ["commit","commit_sha","sha","hash"]
      - subject:      one of ["commit_subject","subject","summary","title"]
      - body/message: one of ["commit_body","body","message","description"]
    """
    if not path.exists():
        print(f"⚠️ env_events_with_pr_issues CSV not found: {path}")
        return {}

    df = pd.read_csv(path, dtype=str, keep_default_na=False)

    commit_col = _find_col(df, ["commit", "commit_sha", "sha", "hash"])
    subj_col   = _find_col(df, ["commit_subject", "subject", "summary", "title"])
    body_col   = _find_col(df, ["commit_body", "body", "message", "description"])

    if not commit_col:
        print(f"⚠️ Could not find commit SHA column in env_events_with_pr_issues: {path}")
        return {}

    if not subj_col:
        print("⚠️ Could not find commit subject column; subjects will be empty.")
    if not body_col:
        print("⚠️ Could not find commit body/message column; bodies will be empty.")

    mapping: Dict[str, Tuple[str, str]] = {}

    for _, row in df.iterrows():
        sha = (row.get(commit_col) or "").strip()
        if not sha:
            continue
        subj = (row.get(subj_col) or "").strip() if subj_col else ""
        body = (row.get(body_col) or "").strip() if body_col else ""
        # first one wins; if duplicates exist, we ignore later rows
        if sha not in mapping:
            mapping[sha] = (subj, body)

    print(f"ℹ️ Loaded commit messages for {len(mapping)} commits from env_events_with_pr_issues.")
    return mapping


# -----------------------------
# Main
# -----------------------------

def main() -> None:
    assert OBS_CSV.exists(), f"Obs CSV not found: {OBS_CSV}"

    # 1) Load all env-change commits (your obs3 CSV)
    df_obs = pd.read_csv(OBS_CSV, dtype=str, keep_default_na=False)

    # 2) Load commit subjects/bodies from env_events_with_pr_issues
    commit_msg_map = load_commit_messages_from_miner(MINER_SUMMARY_CSV)

    # container for the new rows
    out_rows: List[Dict[str, str]] = []

    # 3) Process per repo for efficiency
    for repo_name, df_repo in df_obs.groupby("repo_name"):
        repo_name = str(repo_name)
        full_repo_name = str(df_repo["full_name"].iloc[0]) if "full_name" in df_repo.columns else ""

        # Load metadata JSON for this repo (if present)
        prs_path    = META_ROOT / f"{repo_name}_PRs.json"
        issues_path = META_ROOT / f"{repo_name}_Issues.json"

        prs    = load_json(prs_path)
        issues = load_json(issues_path)

        commit_to_prs, commit_to_issues = build_commit_to_pr_issue_maps(prs, issues)

        # Build output rows for this repo
        for _, row in df_repo.iterrows():
            sha = str(row.get("commit", "")).strip()

            # 👉 commit subject/body from env_events_with_pr_issues map
            subj, body = commit_msg_map.get(sha, ("", ""))

            prs_for_commit = commit_to_prs.get(sha, [])
            pr_fields = summarise_prs(prs_for_commit) if prs_for_commit else {
                "pr_number": "",
                "pr_state": "",
                "pr_title": "",
                "pr_body": "",
                "pr_created_at": "",
                "pr_merged_at": "",
                "pr_closed_at": "",
                "pr_user_login": "",
                "pr_labels": "",
                "pr_html_url": "",
            }

            issues_for_commit = commit_to_issues.get(sha, [])
            issues_summary = summarise_issues(issues_for_commit) if issues_for_commit else ""

            out_row = {
                # Core identity / change info (aligned with env_events_with_pr_issues)
                "full_name": full_repo_name or str(row.get("full_name", "")),
                "repo_folder": repo_name,
                "env_style": row.get("env_style", ""),
                "change_type": row.get("event_type", ""),
                "change_date": row.get("event_date_raw", "") or row.get("event_date_utc", ""),
                "on_default": row.get("on_default", ""),

                # Commit info
                "commit": sha,
                "commit_short": sha[:12] if sha else "",
                "commit_subject": subj,
                "commit_body": body,

                # PR info
                **pr_fields,

                # Issues summary
                "issues_summary": issues_summary,
            }

            out_rows.append(out_row)

    # 4) Build final DataFrame in a nice column order and save
    if out_rows:
        cols = [
            "full_name",
            "repo_folder",
            "env_style",
            "change_type",
            "change_date",
            "on_default",
            "commit",
            "commit_short",
            "commit_subject",
            "commit_body",
            "pr_number",
            "pr_state",
            "pr_title",
            "pr_body",
            "pr_created_at",
            "pr_merged_at",
            "pr_closed_at",
            "pr_user_login",
            "pr_labels",
            "pr_html_url",
            "issues_summary",
        ]
        df_out = pd.DataFrame(out_rows)
        # Ensure all expected columns exist
        for c in cols:
            if c not in df_out.columns:
                df_out[c] = ""
        df_out = df_out[cols]

        OUT_CSV.parent.mkdir(parents=True, exist_ok=True)
        df_out.to_csv(OUT_CSV, index=False, encoding="utf-8")
        print(f"[ok] Wrote: {OUT_CSV}  (rows={len(df_out)})")
    else:
        print("No rows produced – check input CSV and paths.")


if __name__ == "__main__":
    main()
# Out:
# ℹ️ Loaded commit messages for 56659 commits from env_events_with_pr_issues.
# [ok] Wrote: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_Env_Change_Commit_PR_Iss.csv  (rows=557)

# %%
from __future__ import annotations

import json
import re
from pathlib import Path
from typing import Dict, List, Tuple, Any

import pandas as pd


# -----------------------------
# Config
# -----------------------------
WORK_ROOT   = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4")
OBS_DIR     = WORK_ROOT / "Observations"
OBS_CSV     = OBS_DIR / "obs3_1_change_episodes_commits.csv"

META_ROOT   = WORK_ROOT / "metadataV1.0"    # PR / Issues JSONs

# Miner summary with commit_subject / commit_body
MINER_SUMMARY_DIR = WORK_ROOT / "mineV1.0" / "miner summary"
ENV_EVENTS_CSV    = MINER_SUMMARY_DIR / "env_events_with_pr_issues.csv"

OUT_CSV     = OBS_DIR / "All_Env_Change_Commit_PR_Iss.csv"

# Regex to detect issue references like "#123"
ISSUE_REF_RE = re.compile(r"#(\d+)")


# -----------------------------
# Helpers
# -----------------------------

def load_json(path: Path) -> Any:
    """Safely load JSON or return [] if file doesn't exist."""
    if not path.exists():
        return []
    with path.open("r", encoding="utf-8") as f:
        return json.load(f)


def extract_issue_numbers_from_pr(pr: dict) -> List[int]:
    """
    Extract referenced issue numbers from PR title/body/comments/reviews,
    using #123 pattern.
    """
    texts: List[str] = []

    for key in ("title", "body"):
        v = pr.get(key)
        if isinstance(v, str):
            texts.append(v)

    for c in pr.get("issue_comments", []):
        v = c.get("body")
        if isinstance(v, str):
            texts.append(v)

    for c in pr.get("review_comments", []):
        v = c.get("body")
        if isinstance(v, str):
            texts.append(v)

    for r in pr.get("reviews", []):
        v = r.get("body")
        if isinstance(v, str):
            texts.append(v)

    nums: List[int] = []
    for t in texts:
        for m in ISSUE_REF_RE.findall(t):
            try:
                nums.append(int(m))
            except ValueError:
                pass
    return nums


def build_commit_to_pr_and_issue_maps(
    prs: List[dict],
    issues: List[dict],
) -> Tuple[Dict[str, List[dict]], Dict[str, List[dict]]]:
    """
    Build:
      - commit_sha -> [PRs]
      - commit_sha -> [Issues]

    PRs:
      commit → PR uses:
        - pr['target_commits'] if present (from metadata step)
        - otherwise pr['merge_commit_sha'] as a fallback.

    Issues:
      For each commit:
        - look at its PRs
        - scan PR text/comments for #issue references
        - attach those issues (by number) from the Issues JSON.
    """
    # --- commit -> PRs ---
    commit_to_prs: Dict[str, List[dict]] = {}

    for pr in prs:
        targets = pr.get("target_commits") or []
        if isinstance(targets, str):
            targets = [targets]
        shas: List[str] = []

        if targets:
            shas = [s.strip() for s in targets if s]
        else:
            merge_sha = pr.get("merge_commit_sha")
            if merge_sha:
                shas = [merge_sha.strip()]

        for sha in shas:
            if not sha:
                continue
            commit_to_prs.setdefault(sha, []).append(pr)

    # --- issue_number -> issue dict ---
    issues_by_number: Dict[int, dict] = {}
    for iss in issues:
        num = iss.get("number")
        if isinstance(num, int):
            issues_by_number[num] = iss

    # --- commit -> Issues (computed via PR references) ---
    commit_to_issues: Dict[str, List[dict]] = {}

    for sha, pr_list in commit_to_prs.items():
        issue_nums_for_sha = set()  # avoid duplicates per commit
        for pr in pr_list:
            nums = extract_issue_numbers_from_pr(pr)
            for n in nums:
                issue_nums_for_sha.add(n)

        if not issue_nums_for_sha:
            continue

        issues_for_sha: List[dict] = []
        for n in sorted(issue_nums_for_sha):
            iss = issues_by_number.get(n)
            if iss is not None:
                issues_for_sha.append(iss)

        if issues_for_sha:
            commit_to_issues[sha] = issues_for_sha

    return commit_to_prs, commit_to_issues


def summarise_prs(prs_for_commit: List[dict]) -> Dict[str, str]:
    """
    Turn a list of PR dicts into flattened string fields.
    If multiple PRs map to the same commit, values are joined with " | ".
    """
    def join(vals):
        vs = [str(v) for v in vals if v not in (None, "")]
        return " | ".join(vs) if vs else ""

    pr_numbers = join([pr.get("number") for pr in prs_for_commit])
    pr_states  = join([pr.get("state") for pr in prs_for_commit])
    pr_titles  = join([pr.get("title") for pr in prs_for_commit])
    pr_bodies  = join([pr.get("body") for pr in prs_for_commit])
    pr_created = join([pr.get("created_at") for pr in prs_for_commit])
    pr_merged  = join([pr.get("merged_at") for pr in prs_for_commit])
    pr_closed  = join([pr.get("closed_at") for pr in prs_for_commit])

    pr_users   = join([
        (pr.get("user") or {}).get("login")
        for pr in prs_for_commit
    ])

    pr_labels  = join([
        ";".join([
            lab.get("name", "")
            for lab in (pr.get("labels") or [])
            if lab.get("name")
        ])
        for pr in prs_for_commit
    ])

    pr_urls    = join([pr.get("html_url") for pr in prs_for_commit])

    return {
        "pr_number": pr_numbers,
        "pr_state": pr_states,
        "pr_title": pr_titles,
        "pr_body": pr_bodies,
        "pr_created_at": pr_created,
        "pr_merged_at": pr_merged,
        "pr_closed_at": pr_closed,
        "pr_user_login": pr_users,
        "pr_labels": pr_labels,
        "pr_html_url": pr_urls,
    }


def summarise_issues(issues_for_commit: List[dict]) -> str:
    """
    Build a compact 'Issue_Summary' string, e.g.:
      "#123: Crash on emulator | #456: CI config update"
    """
    parts: List[str] = []
    for iss in issues_for_commit:
        num = iss.get("number")
        title = (iss.get("title") or "").strip()
        if num is not None:
            if title:
                parts.append(f"#{num}: {title}")
            else:
                parts.append(f"#{num}")
        elif title:
            parts.append(title)
    return " | ".join(parts)


# -----------------------------
# Main
# -----------------------------

def main() -> None:
    assert OBS_CSV.exists(), f"Obs CSV not found: {OBS_CSV}"
    assert ENV_EVENTS_CSV.exists(), f"env_events_with_pr_issues not found: {ENV_EVENTS_CSV}"

    # 1) Load obs3 commits (episode-boundary commits)
    df_obs = pd.read_csv(OBS_CSV, dtype=str, keep_default_na=False)

    # 2) Load miner env_events_with_pr_issues to get commit_subject & commit_body
    df_env = pd.read_csv(ENV_EVENTS_CSV, dtype=str, keep_default_na=False)

    # Build an index: (repo_folder, commit) -> (subject, body)
    commit_info_index: Dict[tuple, Tuple[str, str]] = {}
    for _, row in df_env.iterrows():
        repo_folder = (row.get("repo_folder") or "").strip()
        sha = (row.get("commit") or "").strip()
        subj = (row.get("commit_subject") or "").strip()
        body = (row.get("commit_body") or "").strip()
        if not repo_folder or not sha:
            continue
        key = (repo_folder, sha)
        if key not in commit_info_index and (subj or body):
            commit_info_index[key] = (subj, body)

    # container for the new rows
    out_rows: List[Dict[str, str]] = []

    # 3) Process per repo (repo_name in obs3 == repo_folder in env_events & JSON file prefix)
    for repo_name, df_repo in df_obs.groupby("repo_name"):
        repo_name = str(repo_name)
        full_repo_name = str(df_repo["full_name"].iloc[0]) if "full_name" in df_repo.columns else ""

        # Load metadata JSON for this repo (if present)
        prs_path    = META_ROOT / f"{repo_name}_PRs.json"
        issues_path = META_ROOT / f"{repo_name}_Issues.json"

        prs    = load_json(prs_path)
        issues = load_json(issues_path)

        commit_to_prs, commit_to_issues = build_commit_to_pr_and_issue_maps(prs, issues)

        # Build output rows for this repo
        for _, row in df_repo.iterrows():
            sha = str(row.get("commit", "")).strip()

            # Get commit_subject/body from miner CSV index
            subj, body = commit_info_index.get((repo_name, sha), ("", ""))

            prs_for_commit = commit_to_prs.get(sha, [])
            pr_fields = summarise_prs(prs_for_commit) if prs_for_commit else {
                "pr_number": "",
                "pr_state": "",
                "pr_title": "",
                "pr_body": "",
                "pr_created_at": "",
                "pr_merged_at": "",
                "pr_closed_at": "",
                "pr_user_login": "",
                "pr_labels": "",
                "pr_html_url": "",
            }

            issues_for_commit = commit_to_issues.get(sha, [])
            issue_summary = summarise_issues(issues_for_commit) if issues_for_commit else ""

            out_row = {
                # Core identity / change info
                "full_name": full_repo_name or str(row.get("full_name", "")),
                "repo_folder": repo_name,
                "env_style": row.get("env_style", ""),
                "change_type": row.get("event_type", ""),
                "change_date": row.get("event_date_raw", "") or row.get("event_date_utc", ""),
                "on_default": row.get("on_default", ""),

                # Commit info
                "commit": sha,
                "commit_short": sha[:12] if sha else "",
                "commit_subject": subj,
                "commit_body": body,

                # PR info
                **pr_fields,

                # Issues summary
                "Issue_Summary": issue_summary,
            }

            out_rows.append(out_row)

    # 4) Build final DataFrame in a stable column order
    if out_rows:
        cols = [
            "full_name",
            "repo_folder",
            "env_style",
            "change_type",
            "change_date",
            "on_default",
            "commit",
            "commit_short",
            "commit_subject",
            "commit_body",
            "pr_number",
            "pr_state",
            "pr_title",
            "pr_body",
            "pr_created_at",
            "pr_merged_at",
            "pr_closed_at",
            "pr_user_login",
            "pr_labels",
            "pr_html_url",
            "Issue_Summary",
        ]
        df_out = pd.DataFrame(out_rows)
        # Ensure all expected columns exist
        for c in cols:
            if c not in df_out.columns:
                df_out[c] = ""
        df_out = df_out[cols]

        OUT_CSV.parent.mkdir(parents=True, exist_ok=True)
        df_out.to_csv(OUT_CSV, index=False, encoding="utf-8")
        print(f"[ok] Wrote: {OUT_CSV}  (rows={len(df_out)})")
    else:
        print("No rows produced – check input CSV and paths.")


if __name__ == "__main__":
    main()
# Out:
# [ok] Wrote: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_Env_Change_Commit_PR_Iss.csv  (rows=557)

# %% [markdown]
# ## Step 5 - appending the commit and PR messages to the episode lists
#
# After having change episods list "list_of_episodes" and "All_Env_Change_Commit_PR_Iss_Final". we merge them together in this code

# %%
from pathlib import Path
import pandas as pd

# ---- Paths ----
OBS_DIR = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations")
EPISODES_CSV = OBS_DIR / "list_of_episodes.csv"

# Adjust this path if your commit file is elsewhere
COMMITS_CSV = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_Env_Change_Commit_PR_Iss.csv")

OUTPUT_CSV = OBS_DIR / "All_episodes_with_messages.csv"

# ---- Load data ----
episodes = pd.read_csv(EPISODES_CSV, dtype=str, keep_default_na=False)
commits  = pd.read_csv(COMMITS_CSV, dtype=str, keep_default_na=False)

# ---- Normalise commit SHA columns ----
# Episodes: start/end SHAs
for col in ["episode_start_commit_sha", "episode_end_commit_sha"]:
    if col in episodes.columns:
        episodes[col] = episodes[col].astype(str).str.strip().str.lower()

# Commits: commit SHA + repo name
if "commit" not in commits.columns:
    raise KeyError("Expected a 'commit' column in All_Env_Change_Commit_PR_Iss_Final.csv")

# Ensure full_name exists (adjust if your column name differs)
if "full_name" not in commits.columns:
    raise KeyError("Expected a 'full_name' column in All_Env_Change_Commit_PR_Iss_Final.csv")

commits["commit_sha"] = commits["commit"].astype(str).str.strip().str.lower()
commits["full_name"]  = commits["full_name"].astype(str).str.strip()

# ---- Select and deduplicate commit-level message fields ----
# Adjust these column names if your file uses slightly different ones
msg_cols = [
    "full_name",
    "commit_sha",
    "commit_subject",
    "commit_body",
    "pr_title",
    "pr_body",
    "Issue_Summary",
]

for c in msg_cols:
    if c not in commits.columns:
        raise KeyError(f"Expected column '{c}' in All_Env_Change_Commit_PR_Iss.csv")

commit_msgs = commits[msg_cols].copy()

# one row per (repo, commit) to avoid duplication on merge
commit_msgs = commit_msgs.drop_duplicates(subset=["full_name", "commit_sha"])

# Normalise full_name in episodes as well
episodes["full_name"] = episodes["full_name"].astype(str).str.strip()

# ---- Prepare start-commit message mapping ----
start_msgs = commit_msgs.rename(
    columns={
        "commit_sha": "episode_start_commit_sha",
        "commit_subject": "start_commit_subject",
        "commit_body": "start_commit_body",
        "pr_title": "start_pr_title",
        "pr_body": "start_pr_body",
        "Issue_Summary": "start_issue_summary",
    }
)

# ---- Prepare end-commit message mapping ----
end_msgs = commit_msgs.rename(
    columns={
        "commit_sha": "episode_end_commit_sha",
        "commit_subject": "end_commit_subject",
        "commit_body": "end_commit_body",
        "pr_title": "end_pr_title",
        "pr_body": "end_pr_body",
        "Issue_Summary": "end_issue_summary",
    }
)

# ---- Merge start messages onto episodes ----
episodes_with_msgs = episodes.merge(
    start_msgs[
        [
            "full_name",
            "episode_start_commit_sha",
            "start_commit_subject",
            "start_commit_body",
            "start_pr_title",
            "start_pr_body",
            "start_issue_summary",
        ]
    ],
    on=["full_name", "episode_start_commit_sha"],
    how="left",
)

# ---- Merge end messages onto episodes ----
episodes_with_msgs = episodes_with_msgs.merge(
    end_msgs[
        [
            "full_name",
            "episode_end_commit_sha",
            "end_commit_subject",
            "end_commit_body",
            "end_pr_title",
            "end_pr_body",
            "end_issue_summary",
        ]
    ],
    on=["full_name", "episode_end_commit_sha"],
    how="left",
)

# ---- Save final output ----
episodes_with_msgs.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")
print(f"[ok] Wrote: {OUTPUT_CSV}")
# Out:
# [ok] Wrote: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_episodes_with_messages.csv

# %% [markdown]
# ## Step 4: Intention labeling by keywords

# %%
import pandas as pd

# -----------------------------
# Config: paths & column names
# -----------------------------
INPUT_PATH = "C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_episodes_with_messages.csv"
OUTPUT_PATH = "C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_episodes_with_messages_with_intentions_keywords.csv"

# Columns used to build the "start" and "end" text blobs
START_COLS = [
    "start_commit_subject",
    "start_commit_body",
    "start_pr_title",
    "start_pr_body",
    "start_issue_summary",
]

END_COLS = [
    "end_commit_subject",
    "end_commit_body",
    "end_pr_title",
    "end_pr_body",
    "end_issue_summary",
]

END_COMMIT_COL = "episode_end_commit_sha"  # used to decide if end_intention should be null


# -----------------------------
# Keyword dictionaries
# -----------------------------
ci_keywords = [
    "ci", "github actions", "action", "actions", "workflow", "workflows",
    "travis", "circleci", "bitrise", "jenkins", "gitlab ci", "buildkite",
    "azure pipelines", "pipeline", "runner", "job", "jobs",
]

test_keywords = [
    "test", "tests", "testing", "unittest", "unit test", "unit tests",
    "androidtest", "connectedandroidtest", "instrumentation", "instrumentation test",
    "instrumentation tests", "ui test", "ui tests", "uitest", "espresso",
    "robolectric", "detox", "snapshot test", "screenshot test", "coverage",
    "jacoco", "lint test", "integration test", "integration tests",
    "e2e", "end-to-end", "end to end", "functional test", "acceptance test",
]

migrate_keywords = [
    "migrate", "migration", "move to", "moving to", "switch to", "switch from",
    "replace", "replaced", "rewrite", "rewrote", "port", "ported",
    "deprecate", "deprecated", "retire", "retired", "drop travis",
    "drop circleci", "drop bitrise", "new ci", "ci v2",
]

scope_keywords = [
    "e2e", "end-to-end", "end to end",
    "integration test", "integration tests",
    "instrumentation test", "instrumentation tests",
    "ui test", "ui tests", "uitest",
    "espresso", "detox", "firebase test lab", "ftl",
    "device farm", "device lab", "browserstack", "saucelabs", "sauce labs",
    "matrix", "multi-device", "multi device", "multiple devices",
    "gradle managed device", "managed device", "gmd", "benchmark",
    "screenshot test", "snapshot test", "golden test",
]

release_keywords = [
    "release", "releasing", "deploy", "deployment", "deploying",
    "publish", "publishing", "uploaded to", "upload to",
    "play store", "google play", "app store", "testflight",
    "beta", "production", "release pipeline", "release workflow",
    "version bump", "bump version", "bump to", "tag", "tagged",
    "artifact", "maven central", "jitpack", "fastlane",
    "signed apk", "bundle", "aab", "apk", "rollout", "roll out",
]

cleanup_keywords = [
    "clean up", "cleanup", "tidy", "tidied", "remove", "removed", "drop", "dropped",
    "delete", "deleted", "simplify", "simplified", "refactor", "refactored",
    "restructure", "restructured", "re-organize", "reorganize", "consolidate",
    "deduplicate", "dedup", "dedupe", "unused", "legacy", "obsolete",
    "dead code", "strip", "trim", "split workflow", "combine workflow",
    "rename workflow", "rename job", "cleanup ci", "clean ci",
]

env_keywords = [
    "emulator", "emulators", "emu", "device", "devices", "avd",
    "virtual device", "gmd", "managed device", "test matrix",
]

perf_keywords = [
    "flaky", "flakiness", "flake", "deflake", "unstable", "stability",
    "stable", "more stable", "less stable", "less flaky",
    "fixed flaky", "slow", "slowness", "slowdown", "faster",
    "speed up", "speedup", "performance", "perf", "timeout",
    "time-out", "time out", "hang", "hanging", "hangs",
    "crash", "crashes", "crashing", "intermittent", "intermittently",
    "non-deterministic", "non deterministic", "sporadic",
    "retry", "retries", "rerun", "re-run", "stuck", "stalls", "stalled",
]


# -----------------------------
# Detection helpers
# -----------------------------
def has_any(text: str, keywords) -> bool:
    """Return True if any keyword is a substring of text."""
    return any(kw in text for kw in keywords)


def detect_intentions_from_text(text: str):
    """
    Return a comma-separated string of intention labels
    for the given text, or None if nothing matches.
    """
    if not isinstance(text, str):
        return None
    t = text.lower().strip()
    if not t:
        return None

    labels = set()

    # 1. Introduce / strengthen CI-backed tests
    if has_any(t, ci_keywords) and has_any(t, test_keywords):
        labels.add("Introduce / strengthen CI-backed tests")

    # 2. Migrate or modernise CI infrastructure
    if has_any(t, migrate_keywords) and has_any(t, ci_keywords):
        labels.add("Migrate or modernise CI infrastructure")

    # 3. Expand test scope or capabilities
    if has_any(t, scope_keywords):
        labels.add("Expand test scope or capabilities")

    # 4. Automate or integrate release workflows
    if has_any(t, release_keywords):
        labels.add("Automate or integrate release workflows")

    # 5. Clean up or simplify CI / environment configuration
    if has_any(t, cleanup_keywords) and (has_any(t, ci_keywords) or has_any(t, env_keywords)):
        labels.add("Clean up or simplify CI / environment configuration")

    # 6. Address performance or stability issues
    if has_any(t, perf_keywords):
        labels.add("Address performance or stability issues")

    if not labels:
        return None

    # Sorted for determinism; comma-separated for multiple labels
    return ", ".join(sorted(labels))


def build_text(row, cols):
    """Concatenate non-empty text from the given columns for a row."""
    parts = []
    for c in cols:
        if c in row:
            val = row[c]
            if isinstance(val, str) and val.strip():
                parts.append(val.strip())
    return "\n".join(parts)


# -----------------------------
# Main processing
# -----------------------------
def main():
    df = pd.read_csv(INPUT_PATH)

    # start_intention: always computed from available start-* fields
    df["start_intention"] = df.apply(
        lambda r: detect_intentions_from_text(build_text(r, START_COLS)),
        axis=1,
    )

    # end_intention: only if there *is* an end commit; otherwise keep as None/NaN
    def compute_end_intention(row):
        if pd.isna(row.get(END_COMMIT_COL)):
            return None
        end_text = build_text(row, END_COLS)
        return detect_intentions_from_text(end_text)

    df["end_intention"] = df.apply(compute_end_intention, axis=1)

    # Save the updated file
    df.to_csv(OUTPUT_PATH, index=False)
    print(f"Saved updated file with intentions to: {OUTPUT_PATH}")


if __name__ == "__main__":
    main()
# Out:
# Saved updated file with intentions to: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ4\Observations\All_episodes_with_messages_with_intentions_keywords.csv
