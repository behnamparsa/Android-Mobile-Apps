# %%
import requests
import time
import pandas as pd
from dotenv import load_dotenv
import os


# === Load project list ===
df_projects = pd.read_csv("Project_List_Only.csv")  # adjust path if needed

# === GitHub token (paste yours here) ===

load_dotenv("All_Tokens.env")
token = os.getenv("GITHUB_TOKEN")
headers = {"Authorization": f"token {token.strip()}"}


# === Rate Limit Checker ===
def check_rate_limit():
    url = "https://api.github.com/rate_limit"
    response = requests.get(url, headers=headers)
    data = response.json()
    remaining = data['rate']['remaining']
    limit = data['rate']['limit']
    reset_time = data['rate']['reset']
    print(f"⏳ GitHub API: {remaining} / {limit} requests remaining.")
    return remaining

# === GitHub Search Function ===
def search_github_repo(project_name):
    query = f"{project_name} in:name"
    url = f"https://api.github.com/search/repositories?q={query}&sort=stars&order=desc&per_page=1"
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        if data.get("total_count", 0) > 0:
            return data["items"][0]["html_url"]
        else:
            return ""
    except Exception as e:
        print(f"❌ Error for {project_name}: {e}")
        return ""

# === Search Loop with Rate Limit Check ===
results = []
check_rate_limit()  # Show status before starting

for i, name in enumerate(df_projects['project'], 1):
    url = search_github_repo(name)
    results.append({'project': name, 'github_url': url})
    
    # Check every 50 requests
    if i % 50 == 0:
        remaining = check_rate_limit()
        if remaining < 10:
            print("⚠️ Near rate limit — pausing for 60 seconds...")
            time.sleep(60)

    time.sleep(1.2)  # Light delay between requests

# === Save Results ===
df_out = pd.DataFrame(results)
df_out.to_csv("Project_GitHub_URLs.csv", index=False)
print("✅ Saved: Project_GitHub_URLs.csv")
# Out:
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for afwall: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=afwall%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for age-gender_estimation_tf-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=age-gender_estimation_tf-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aggregator-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aggregator-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for agoradesk-app-foss: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=agoradesk-app-foss%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aimybox-android-assistant: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aimybox-android-assistant%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aio_myday_app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aio_myday_app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for airguard: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=airguard%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for akvo-flow-mobile: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=akvo-flow-mobile%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for akvo-rsr-up: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=akvo-rsr-up%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for al-azan: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=al-azan%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aladin-aos: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aladin-aos%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for alakazam: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=alakazam%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-anuto: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-anuto%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-app-cortesia-webview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-app-cortesia-webview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-app-eye-rest-blue-light-filter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-app-eye-rest-blue-light-filter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-app-get-device-id: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-app-get-device-id%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-appcachecleaner: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-appcachecleaner%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-arsenal: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-arsenal%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-base: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-base%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-base-project: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-base-project%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-beacon-mqtt: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-beacon-mqtt%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-beginner-projects: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-beginner-projects%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-boilerplate: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-boilerplate%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for android-luajit-launcher: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-luajit-launcher%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-metronome: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-metronome%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-minimal-todo: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-minimal-todo%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-navigation-with-compose: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-navigation-with-compose%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-nfc-timestamp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-nfc-timestamp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-notification-converter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-notification-converter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-object-detection: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-object-detection%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-ocr: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-ocr%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-odeon: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-odeon%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-oss: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-oss%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-otpview-pinview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-otpview-pinview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android-password-store: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android-password-store%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for android2048: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android2048%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android_dev_quick: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android_dev_quick%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for android_navigator: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=android_navigator%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidappshortcuts: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidappshortcuts%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidautotrack: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidautotrack%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidbible: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidbible%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidclient: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidclient%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidcustomviews: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidcustomviews%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androiddatawithoutrootapi33: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androiddatawithoutrootapi33%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androideastereggs: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androideastereggs%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for androidfacedetection: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=androidfacedetection%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for anitrend-v2: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=anitrend-v2%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for anki-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=anki-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for anlinux-adfree: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=anlinux-adfree%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ansvif_android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ansvif_android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ant-design-mobile-rn: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ant-design-mobile-rn%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antennamap: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antennamap%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antennapod: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antennapod%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antimalwareapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antimalwareapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antimine-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antimine-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antispam: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antispam%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for antox: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=antox%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for any: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=any%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for arcade-plaza: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=arcade-plaza%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for arcane-tracker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=arcane-tracker%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for arcgis-android-moremap: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=arcgis-android-moremap%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for archwiki-viewer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=archwiki-viewer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ard: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ard%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for arduino-usb-terminal: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=arduino-usb-terminal%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aria2app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aria2app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aria2c-android-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aria2c-android-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ark-navigator: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ark-navigator%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ark-rate: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ark-rate%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ark-shelf: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ark-shelf%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for armscomponent: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=armscomponent%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for awaken: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=awaken%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for awol: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=awol%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for axion-technologies-hnh: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=axion-technologies-hnh%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for aztube-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=aztube-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for baby-sleep-sounds: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=baby-sleep-sounds%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for babybook: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=babybook%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for babydots: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=babydots%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bacon: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bacon%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for badge-magic-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=badge-magic-android%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for badpixels: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=badpixels%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for balanduinoandroidapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=balanduinoandroidapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for birthdaycalendar: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=birthdaycalendar%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitcoin-balance-check: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitcoin-balance-check%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitcoin-wallet: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitcoin-wallet%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitcoinium: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitcoinium%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitcoinpools: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitcoinpools%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitmask_android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitmask_android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitnews: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitnews%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bitportal-client: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bitportal-client%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bixer-btc-app-: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bixer-btc-app-%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bjutloginapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bjutloginapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for bjutwifi: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=bjutwifi%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for blackhole: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=blackhole%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for boxbox: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=boxbox%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for braillebox: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=braillebox%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for brainjogging: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=brainjogging%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for brainteaser: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=brainteaser%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for brassexcerpts: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=brassexcerpts%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for brethap: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=brethap%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for briar: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=briar%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for brouter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=brouter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for browse: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=browse%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for btcmap-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=btcmap-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for btle-scanner-compat: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=btle-scanner-compat%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for canvasscript: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=canvasscript%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for capgo: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=capgo%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for capod: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=capod%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for car-server: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=car-server%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for carcinofit: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=carcinofit%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cardiac-zone-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cardiac-zone-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for care4ther-: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=care4ther-%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cartsbusboarding: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cartsbusboarding%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cat-adoption-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cat-adoption-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cataclysm-dda-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cataclysm-dda-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cattle: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cattle%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cattlebodyconditioning: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cattlebodyconditioning%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for cis-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cis-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for clarifai-android-starter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=clarifai-android-starter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for class-organizer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=class-organizer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for clean-sms-forwarding: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=clean-sms-forwarding%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cleaner: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cleaner%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cleantodo: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cleantodo%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for clear-todolist: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=clear-todolist%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for click: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=click%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for clicli-dark: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=clicli-dark%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for client: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=client%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for client-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=client-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for clipboard: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=clipboard%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for colorosnotifyicon: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=colorosnotifyicon%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for colorpicker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=colorpicker%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for colors_ai: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=colors_ai%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for colorwaver: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=colorwaver%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for comicsapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=comicsapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for commcare-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=commcare-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for comp0016_2020_21_team25: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=comp0016_2020_21_team25%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for comp0016_2020_21_team26: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=comp0016_2020_21_team26%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for companion-for-band: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=companion-for-band%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for compose-breakingbad: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=compose-breakingbad%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for compose-challenges: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=compose-challenges%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for compose-color-picker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=compose-color-picker%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for covid19-tracker-app-kenya: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=covid19-tracker-app-kenya%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for covid_tracker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=covid_tracker%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for covidcertificate-app-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=covidcertificate-app-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for covidnow: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=covidnow%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for covidtoday-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=covidtoday-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cpu-info: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cpu-info%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for cpymo: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=cpymo%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for crawl: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=crawl%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for crazie: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=crazie%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4982 / 5000 requests remaining.
# ❌ Error for crime_map: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=crime_map%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for crimsonota: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=crimsonota%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for criticalmaps-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=criticalmaps-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for darkmodewallpaper: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=darkmodewallpaper%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dart-jobs: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dart-jobs%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dash-wallet: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dash-wallet%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for databag: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=databag%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for datepickertimeline: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=datepickertimeline%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for datmusic-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=datmusic-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dawnn_client: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dawnn_client%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for days: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=days%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for daytomato: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=daytomato%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dazzling-android-kt: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dazzling-android-kt%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dcipher-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dcipher-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ddcc-validator: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ddcc-validator%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for devto-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=devto-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dexter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dexter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dfm: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dfm%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for diagonal-imageview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=diagonal-imageview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for diaguard: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=diaguard%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dial-dial: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dial-dial%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dialerloading: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dialerloading%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dialogmusicplayer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dialogmusicplayer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dialogplus: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dialogplus%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dialogue: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dialogue%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for diary: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=diary%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for diceoverflow: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=diceoverflow%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for dowel: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dowel%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for download-navi: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=download-navi%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for draftsman: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=draftsman%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for draggable-menu: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=draggable-menu%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for drawa-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=drawa-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dreamdroid: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dreamdroid%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for dribbbleclient: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=dribbbleclient%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for drinkable: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=drinkable%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for drinks: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=drinks%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for drip: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=drip%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for drive: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=drive%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for driver-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=driver-android%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for eat-poop-you-cat-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=eat-poop-you-cat-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ebeveynkontrollutwitter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ebeveynkontrollutwitter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ebookreader: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ebookreader%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for editor: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=editor%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for edmflare: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=edmflare%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for edokuri: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=edokuri%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for edtrack: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=edtrack%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for edujam: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=edujam%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for eh-redux: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=eh-redux%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ehviewer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ehviewer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ehviewer_cn_sxj: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ehviewer_cn_sxj%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for einkbro: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=einkbro%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for eta-android-2048: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=eta-android-2048%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for etar-calendar: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=etar-calendar%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for etopa: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=etopa%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for etsmobile-android2: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=etsmobile-android2%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for euphony-hub-collector: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=euphony-hub-collector%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for event-registration-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=event-registration-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for eventfahrplan: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=eventfahrplan%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for every_door: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=every_door%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for evmap: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=evmap%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for evrimnews: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=evrimnews%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for exif-thumbnail-adder: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=exif-thumbnail-adder%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for exodus-android-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=exodus-android-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fbp-go: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fbp-go%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for feather: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=feather%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fediverse: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fediverse%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for feed-watcher: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=feed-watcher%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for feedback-prime: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=feedback-prime%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for feudaltactics: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=feudaltactics%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ffupdater: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ffupdater%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for file: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=file%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for file-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=file-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for file-explorer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=file-explorer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for filepickerdialog-master: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=filepickerdialog-master%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fileshortcut: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fileshortcut%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fluidsynth-midi-service-j: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fluidsynth-midi-service-j%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutsapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutsapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-calculator: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-calculator%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-ci-deployment: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-ci-deployment%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-gif-search: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-gif-search%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-hackernews: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-hackernews%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-healthbook: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-healthbook%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-learn: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-learn%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-movie: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-movie%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-music-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-music-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for flutter-social: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=flutter-social%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for freezer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=freezer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for freezeyou: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=freezeyou%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for freifunkautoconnectapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=freifunkautoconnectapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fridgexlight: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fridgexlight%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for frinder-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=frinder-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for frisbee: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=frisbee%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fritter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fritter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for frogo-notification: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=frogo-notification%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for frost-for-facebook: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=frost-for-facebook%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fucksgiven: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fucksgiven%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fuckview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fuckview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for fuelup: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=fuelup%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for gift-card-guard: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gift-card-guard%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for giggity: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=giggity%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for git-point: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=git-point%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for git-touch: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=git-touch%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gitexplorer-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gitexplorer-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for githubvisualizer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=githubvisualizer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gitnotes: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gitnotes%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gitpositive: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gitpositive%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gitsurf: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gitsurf%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gjzs: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gjzs%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for glass-notes-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=glass-notes-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for glider: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=glider%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for groupno1-vehicular-traffic-abatement: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=groupno1-vehicular-traffic-abatement%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gsy_github_app_flutter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gsy_github_app_flutter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gsyricktext: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gsyricktext%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gsyvideoplayer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gsyvideoplayer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for guide7: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=guide7%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for guideapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=guideapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gurgle: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gurgle%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gymaths: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gymaths%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gymroutines: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gymroutines%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for gyrodraw: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=gyrodraw%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for habitbuilder: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=habitbuilder%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for habot: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=habot%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4979 / 5000 requests remaining.
# ❌ Error for hexviewer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hexviewer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hglauncher: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hglauncher%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hid-barcode-scanner: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hid-barcode-scanner%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hilt-sandbox: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hilt-sandbox%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hishoot2i: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hishoot2i%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hmi-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hmi-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for hnews: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=hnews%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for holokenmod: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=holokenmod%20in:name&sort=stars&order=desc&per_page=1
# ...
# ❌ Error for tblauncher: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tblauncher%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for team2: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=team2%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for technical-fest: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=technical-fest%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for telegram-sms: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=telegram-sms%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for templeapp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=templeapp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tensor: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tensor%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tensuu: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tensuu%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for terminal_flutter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=terminal_flutter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for termux-api: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=termux-api%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for termux-app: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=termux-app%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for termux-app-bluetooth: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=termux-app-bluetooth%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for timber: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timber%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timebomb: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timebomb%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timeclock: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timeclock%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timelineview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timelineview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timer-machine-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timer-machine-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timerinrecyclerview: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timerinrecyclerview%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for timetable: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=timetable%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tinc_gui: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tinc_gui%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tinfoil-facebook: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tinfoil-facebook%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tinylisp: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tinylisp%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tinyritro: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tinyritro%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tisk: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tisk%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for toxandroidrefimpl: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=toxandroidrefimpl%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tracex: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tracex%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for trackingwifi: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=trackingwifi%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for tracktor-composeui: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=tracktor-composeui%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for trackworktime: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=trackworktime%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for trading: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=trading%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for trail-sense: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=trail-sense%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for translate: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=translate%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for translateyou: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=translateyou%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for translator: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=translator%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for transmissionic: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=transmissionic%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for transportr: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=transportr%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for twittnuker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=twittnuker%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for txt: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=txt%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for typewriter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=typewriter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for uatranslit: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=uatranslit%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ubuntu-launcher: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ubuntu-launcher%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for udrive: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=udrive%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ueno: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ueno%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for uhabits: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=uhabits%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for uhooipicbook-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=uhooipicbook-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for uhuruphotos-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=uhuruphotos-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for uinspector: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=uinspector%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for ukurkecepatanstrippeds: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=ukurkecepatanstrippeds%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vanilla: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vanilla%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vergiss-nix: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vergiss-nix%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vgs-checkout-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vgs-checkout-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vibe: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vibe%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for video-transcoder: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=video-transcoder%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for videocrop: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=videocrop%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for videoeditor: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=videoeditor%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for view404: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=view404%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for viewmodeladapter: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=viewmodeladapter%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for viewtiful: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=viewtiful%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vimusic: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vimusic%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for vinylmusicplayer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=vinylmusicplayer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wasted: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wasted%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watchcat: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watchcat%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watchdone: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watchdone%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watchlist: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watchlist%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watchtower: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watchtower%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for water-me: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=water-me%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for waterfly-iii: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=waterfly-iii%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watermaniac: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watermaniac%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watermelonquotes: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watermelonquotes%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for watomatic: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=watomatic%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for waveswallet-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=waveswallet-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wawa-tabor: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wawa-tabor%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for whatsthere: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=whatsthere%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wheellog: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wheellog%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for white-noise-player: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=white-noise-player%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for whooby: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=whooby%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for whs: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=whs%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for whuhelper: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=whuhelper%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifi-automatic: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifi-automatic%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifi-radar: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifi-radar%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifianalyzer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifianalyzer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifiauto: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifiauto%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifiindoorpositioning: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifiindoorpositioning%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifikeyshare: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifikeyshare%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for wifisdcryptolocker: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=wifisdcryptolocker%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4997 / 5000 requests remaining.
# ❌ Error for xifan: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=xifan%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for xikolo-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=xikolo-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for xplayer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=xplayer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for xxpermissions: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=xxpermissions%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for xzil-wallet: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=xzil-wallet%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for yaaic: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=yaaic%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for yacguide: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=yacguide%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for yana: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=yana%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for yelpexplorer: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=yelpexplorer%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for yggdrasil-android: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=yggdrasil-android%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for you-coach-you: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=you-coach-you%20in:name&sort=stars&order=desc&per_page=1
# ❌ Error for you-have-mail: 403 Client Error: Forbidden for url: https://api.github.com/search/repositories?q=you-have-mail%20in:name&sort=stars&order=desc&per_page=1
# ⏳ GitHub API: 4995 / 5000 requests remaining.
# ✅ Saved: Project_GitHub_URLs.csv
