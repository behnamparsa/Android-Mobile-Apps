# %%
# %% [markdown]
# Tier-2 Scraper Notebook (sequential + resume, robust HTTP)
# - Start date pinned to 2024-01-01 (change SINCE or set None for full history)
# - Reads URL_List.csv and episodes_enriched_combined.csv from your path
# - Uses All_Tokens.env with GITHUB_TOKEN_1..N at C:\GitHub\Android-Mobile-Apps\All_Tokens.env
# - NEW: Stores SCRAPE_PROGRESS_INDEX (and optional SCRAPE_PAUSE) in All_Tokens.env for play/pause safety
# - Scrapes runs, jobs, and (if available) timing
# - Writes NDJSON per repo; optional mapping of episodes -> runs to Parquet

# %% Install dependencies (run once per environment)
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install",
    "httpx>=0.27.0", "pandas>=2.1.0", "pyarrow>=15.0.0", "nest_asyncio>=1.6.0"
])

# %% Configuration — set your paths and knobs here
from pathlib import Path

BASE = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
URL_CSV = BASE / "URL_List.csv"
EPISODES_CSV = BASE / "episodes_enriched_combined.csv"          # optional for mapping

# 👉 Tokens / progress file location:
TOKENS_ENV = Path(r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env")

OUTDIR = BASE / "ci_out"                                         # output folder
SINCE = "2024-01-01"                                             # ← start here; set None for no date limit

INCLUDE_JOBS = True
INCLUDE_TIMING = True
MAX_RUNS_PER_REPO = None                                         # None = no cap

MAP_EPISODES = True
WINDOW_DAYS = 14

# Progress / verbosity
VERBOSE = True
PROGRESS_EVERY_RUNS = 25
PROGRESS_EVERY_JOBS = 100

# Resume/pause env variable names
PROGRESS_ENV_KEY = "SCRAPE_PROGRESS_INDEX"
PAUSE_ENV_KEY = "SCRAPE_PAUSE"

print("Config OK")

# %% Utilities
import os, re, json, asyncio, random, io
from typing import List, Iterable, Dict, Any, Optional, Tuple
from datetime import datetime, timezone
import pandas as pd

def ensure_dir(path: str | os.PathLike) -> None:
    os.makedirs(path, exist_ok=True)

def dump_ndjson(path: str | os.PathLike, rows: Iterable[Dict[str, Any]]) -> None:
    ensure_dir(os.path.dirname(str(path)))
    with open(path, "a", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def read_env_tokens(env_path: str | os.PathLike, prefix: str = "GITHUB_TOKEN_") -> List[str]:
    tokens = []
    with open(env_path, "r", encoding="utf-8") as f:
        for raw in f:
            line = raw.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k = k.strip()
            v = v.strip().strip('"').strip("'")
            if k.upper().startswith(prefix) and v:
                tokens.append(v)
    if not tokens:
        raise RuntimeError(f"No tokens found in {env_path} with prefix {prefix}")
    return tokens

def parse_repo_from_text(s: str) -> Optional[str]:
    if not isinstance(s, str):
        return None
    s = s.strip()
    if re.match(r"^[A-Za-z0-9_.-]+/[A-Za-z0-9_.-]+$", s):
        return s
    m = re.search(r"github\.com/([A-Za-z0-9_.-]+/[A-Za-z0-9_.-]+)", s, re.I)
    if m:
        return m.group(1)
    return None

def extract_repos_from_csv(url_csv: str | os.PathLike) -> List[str]:
    df = pd.read_csv(url_csv)
    repos = set()
    for col in df.columns:
        for v in df[col].astype(str):
            r = parse_repo_from_text(v)
            if r:
                repos.add(r)
    repos = sorted(repos)
    if not repos:
        raise RuntimeError("No GitHub repos parsed from URL CSV (need owner/name or GH URLs).")
    return repos

# (Used by optional mapping step)
def _robust_parse_epoch_series(s: pd.Series) -> pd.Series:
    snum = pd.to_numeric(s, errors="coerce")
    if snum.notna().sum() == 0:
        return pd.Series([], dtype="datetime64[ns, UTC]")
    med = snum.dropna().abs().median()
    if med > 1e14:
        unit = "us"
    elif med > 1e11:
        unit = "ms"
    else:
        unit = "s"
    return pd.to_datetime(snum, unit=unit, errors="coerce", utc=True)

print("Utils ready")

# %% Env helpers for progress/pause (atomic updates)
def _read_env_var(env_path: str | os.PathLike, key: str) -> Optional[str]:
    key_re = re.compile(rf"^\s*{re.escape(key)}\s*=(.*)$", re.I)
    try:
        with open(env_path, "r", encoding="utf-8") as f:
            for raw in f:
                m = key_re.match(raw.strip())
                if m:
                    val = m.group(1).strip().strip('"').strip("'")
                    return val
    except FileNotFoundError:
        return None
    return None

def _write_env_var(env_path: str | os.PathLike, key: str, value: str) -> None:
    key_lower = key.lower()
    lines: List[str] = []
    found = False
    if os.path.exists(env_path):
        with open(env_path, "r", encoding="utf-8") as f:
            for raw in f:
                line = raw.rstrip("\n")
                if re.match(rf"^\s*{re.escape(key)}\s*=", line, re.I):
                    lines.append(f"{key}={value}")
                    found = True
                else:
                    lines.append(line)
    if not found:
        lines.append(f"{key}={value}")
    # atomic replace
    tmp = str(env_path) + ".tmp"
    with open(tmp, "w", encoding="utf-8", newline="\n") as f:
        f.write("\n".join(lines) + "\n")
    os.replace(tmp, env_path)

def get_progress_index(env_path: str | os.PathLike, key: str) -> int:
    v = _read_env_var(env_path, key)
    if v is None or not str(v).strip().isdigit():
        return 0
    try:
        idx = int(str(v).strip())
        return max(0, idx)
    except Exception:
        return 0

def set_progress_index(env_path: str | os.PathLike, key: str, value: int) -> None:
    _write_env_var(env_path, key, str(int(value)))

def is_pause_requested(env_path: str | os.PathLike, key: str) -> bool:
    v = _read_env_var(env_path, key)
    return str(v).strip() in {"1", "true", "True"} if v is not None else False

# %% GitHub API client (async, robust retries, HTTP/2)
import httpx

GITHUB_API = "https://api.github.com"

class GHClient:
    def __init__(self, token: str, rate_sleep: float = 0.2):
        self.token = token
        self.rate_sleep = rate_sleep
        self.headers = {
            "Authorization": f"Bearer {self.token}",
            "Accept": "application/vnd.github+json",
            "X-GitHub-Api-Version": "2022-11-28",
        }
        self.client = httpx.AsyncClient(
            headers=self.headers,
            http2=True,  # fewer EOF hiccups
            timeout=httpx.Timeout(connect=30, read=60, write=30),
            limits=httpx.Limits(max_connections=32, max_keepalive_connections=16, keepalive_expiry=30.0),
        )

    async def close(self):
        await self.client.aclose()

    async def _get(self, url, params=None, max_retries: int = 5) -> httpx.Response:
        RETRYABLE = (
            httpx.RemoteProtocolError,
            httpx.ConnectError, httpx.ReadError, httpx.WriteError,
            httpx.PoolTimeout, httpx.TimeoutException,
        )
        last_exc: Optional[BaseException] = None
        for attempt in range(max_retries):
            try:
                resp = await self.client.get(url, params=params)
                # Upstream transient errors → retry
                if resp.status_code in (502, 503, 504, 429):
                    raise httpx.HTTPStatusError("upstream transient", request=resp.request, response=resp)

                # Rate limit handling (403 classic OR secondary rate limit)
                if resp.status_code == 403 and (
                    resp.headers.get("X-RateLimit-Remaining") == "0"
                    or "rate limit" in (resp.text or "").lower()
                ):
                    reset = resp.headers.get("X-RateLimit-Reset")
                    wait_s = 10
                    if reset:
                        try:
                            now = int(datetime.now(timezone.utc).timestamp())
                            wait_s = max(1, int(reset) - now + 1)
                        except Exception:
                            pass
                    print(f"[rate-limit] sleeping {wait_s}s", flush=True)
                    await asyncio.sleep(wait_s)
                    continue

                resp.raise_for_status()
                await asyncio.sleep(self.rate_sleep)
                return resp

            except (httpx.HTTPStatusError,) as e:
                last_exc = e
                backoff = min(20.0, (2 ** attempt)) + random.random()
                print(f"[http-status] retry {attempt+1}/{max_retries} in {backoff:.1f}s: {url} ({e})", flush=True)
                await asyncio.sleep(backoff)

            except RETRYABLE as e:
                last_exc = e
                backoff = min(20.0, (2 ** attempt)) + random.random()
                print(f"[transport] {e.__class__.__name__} → retry {attempt+1}/{max_retries} in {backoff:.1f}s: {url}", flush=True)
                # Drop any bad sockets; recreate client
                try:
                    await self.client.aclose()
                except Exception:
                    pass
                self.client = httpx.AsyncClient(
                    headers=self.headers,
                    http2=True,
                    timeout=httpx.Timeout(connect=30, read=60, write=30),
                    limits=httpx.Limits(max_connections=32, max_keepalive_connections=16, keepalive_expiry=30.0),
                )
                await asyncio.sleep(backoff)

        raise last_exc if last_exc else httpx.RemoteProtocolError("Unrecoverable transport error")

    # Repo-level runs (no 'created' filter; we filter locally)
    async def list_workflow_runs(self, owner: str, repo: str, per_page=100):
        page = 1
        while True:
            params = {"per_page": per_page, "page": page}
            resp = await self._get(f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs", params=params)
            data = resp.json()
            runs = data.get("workflow_runs", [])
            if not runs:
                break
            for run in runs:
                yield run
            if len(runs) < per_page:
                break
            page += 1

    async def list_jobs_for_run(self, owner: str, repo: str, run_id: int):
        page = 1
        per_page = 100
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs/{run_id}/jobs",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            jobs = data.get("jobs", [])
            if not jobs:
                break
            for job in jobs:
                yield job
            if len(jobs) < per_page:
                break
            page += 1

    # Workflows & per-workflow runs (fallback)
    async def list_workflows(self, owner: str, repo: str):
        page = 1
        per_page = 100
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/workflows",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            wfs = data.get("workflows", [])
            if not wfs:
                break
            for wf in wfs:
                yield wf
            if len(wfs) < per_page:
                break
            page += 1

    async def list_workflow_runs_for_workflow(self, owner: str, repo: str, workflow_id: int, per_page=100):
        page = 1
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/workflows/{workflow_id}/runs",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            runs = data.get("workflow_runs", [])
            if not runs:
                break
            for run in runs:
                yield run
            if len(runs) < per_page:
                break
            page += 1

    async def get_run_timing(self, owner: str, repo: str, run_id: int):
        resp = await self._get(f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs/{run_id}/timing")
        return resp.json()

print("GitHub client ready")

# %% Scrape logic (per-repo, since filter, fallback) — with robust logging
async def scrape_repo(owner_repo: str,
                      client: GHClient,
                      outdir: str | os.PathLike,
                      since_iso: Optional[str],
                      include_jobs: bool,
                      include_timing: bool,
                      max_runs: Optional[int]) -> None:
    owner, repo = owner_repo.split("/", 1)
    base = Path(outdir) / owner_repo.replace("/", "_")
    runs_path = base / "runs.ndjson"
    jobs_path = base / "jobs.ndjson"
    timing_path = base / "timing.ndjson"
    ensure_dir(base)

    since_dt = pd.to_datetime(since_iso, utc=True) if since_iso else None
    run_count = 0
    job_count = 0
    timing_count = 0

    print(f"[{owner_repo}] ▶ start (since={since_iso or 'ALL'})", flush=True)

    async def _consume_runs(run_iter):
        nonlocal run_count, job_count, timing_count
        async for run in run_iter:
            # local since filter (runs are reverse-chronological)
            ca = run.get("run_started_at") or run.get("created_at")
            if since_dt is not None and ca:
                ca_dt = pd.to_datetime(ca, utc=True, errors="coerce")
                if pd.notna(ca_dt) and ca_dt < since_dt:
                    return "stopped_by_since"

            dump_ndjson(runs_path, [run])
            run_count += 1
            if VERBOSE and (run_count % PROGRESS_EVERY_RUNS == 0):
                print(f"[{owner_repo}] … runs fetched: {run_count}", flush=True)

            if include_jobs:
                try:
                    async for job in client.list_jobs_for_run(owner, repo, run["id"]):
                        dump_ndjson(jobs_path, [job])
                        job_count += 1
                        if VERBOSE and (job_count % PROGRESS_EVERY_JOBS == 0):
                            print(f"[{owner_repo}] … jobs fetched: {job_count}", flush=True)
                except httpx.HTTPError as e:
                    print(f"[{owner_repo}] jobs fetch failed for run {run['id']}: {e}; continuing", flush=True)

            if include_timing:
                try:
                    timing = await client.get_run_timing(owner, repo, run["id"])
                    dump_ndjson(timing_path, [dict(run_id=run["id"], **timing)])
                    timing_count += 1
                except httpx.HTTPError:
                    # timing endpoint not always enabled
                    pass

            if max_runs and run_count >= max_runs:
                return "stopped_by_cap"

        return "exhausted"

    try:
        status = await _consume_runs(client.list_workflow_runs(owner, repo))

        # Fallback: if repo-level returned nothing, try per-workflow listing
        if run_count == 0:
            async for wf in client.list_workflows(owner, repo):
                wf_id = wf.get("id")
                if not wf_id:
                    continue
                status = await _consume_runs(client.list_workflow_runs_for_workflow(owner, repo, wf_id))
                if max_runs and run_count >= max_runs:
                    break

    except Exception as e:
        with open(base / "errors.log", "a", encoding="utf-8") as f:
            f.write(f"{datetime.now().isoformat()} error: {e}\n")
        raise
    finally:
        print(f"[{owner_repo}] ✓ done | runs={run_count}, jobs={job_count}, timings={timing_count}", flush=True)

print("Scrape logic loaded")

# %% Sanity check tokens (masked) — optional
def _read_env_tokens(env_path, prefix="GITHUB_TOKEN_"):
    toks = []
    with open(env_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k = k.strip()
            v = v.strip().strip('"').strip("'")
            if k.upper().startswith(prefix) and v:
                toks.append(v)
    return toks

try:
    _toks = _read_env_tokens(TOKENS_ENV)
    print(f"Loaded {len(_toks)} token(s): " + ", ".join("****" + t[-4:] for t in _toks))
except Exception as e:
    print(f"Token check failed: {e}")

# %% Execute scraping (sequential + resume; Notebook-safe: top-level await)
import nest_asyncio, asyncio
nest_asyncio.apply()
if sys.platform.startswith("win"):
    try:
        asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
    except Exception:
        pass

since_iso = SINCE  # fixed start date; set to None to fetch all history

tokens = read_env_tokens(TOKENS_ENV)
repos = extract_repos_from_csv(URL_CSV)

TOTAL = len(repos)
print(f"Found {TOTAL} repos; {len(tokens)} token(s); since={since_iso or 'ALL'}")
ensure_dir(OUTDIR)

async def run_all_sequential(
    repos: List[str],
    tokens: List[str],
    outdir: str | os.PathLike,
    since_iso: Optional[str],
    include_jobs: bool,
    include_timing: bool,
    max_runs: Optional[int],
    progress_env_path: str | os.PathLike,
    progress_key: str,
    pause_key: str,
):
    # One client per token (rotated per repo)
    clients = [GHClient(t) for t in tokens]
    start_idx = get_progress_index(progress_env_path, progress_key)
    if start_idx >= len(repos):
        print(f"Progress index ({start_idx}) >= repo count ({len(repos)}). Nothing to do.")
        await asyncio.gather(*(c.close() for c in clients))
        return

    print(f"Resuming from {progress_key}={start_idx} ({start_idx+1}/{len(repos)})")

    try:
        for i in range(start_idx, len(repos)):
            # Optional pause check (allows external toggle without killing the process)
            if is_pause_requested(progress_env_path, pause_key):
                print(f"[pause] {pause_key}=1 detected. Stopping before repo index {i}.")
                break

            repo = repos[i]
            client = clients[i % len(clients)]
            print(f"[{i+1}/{len(repos)}] {repo} queued (token {(i % len(clients)) + 1}/{len(clients)})", flush=True)
            try:
                await scrape_repo(
                    owner_repo=repo,
                    client=client,
                    outdir=str(outdir),
                    since_iso=since_iso,
                    include_jobs=include_jobs,
                    include_timing=include_timing,
                    max_runs=max_runs
                )
            except Exception as e:
                # Don't advance index; write a top-level error marker and stop.
                with open(Path(outdir) / "top_level_errors.log", "a", encoding="utf-8") as f:
                    f.write(f"{datetime.now().isoformat()} repo={repo} idx={i} error={repr(e)}\n")
                print(f"[{repo}] ✖ fatal error, not advancing index. Fix and rerun to retry this repo.", flush=True)
                break

            # Repo finished successfully → advance index so it resumes at the next repo later
            set_progress_index(progress_env_path, progress_key, i + 1)
            print(f"[{repo}] ■ completed; updated {progress_key}={i+1}", flush=True)

        print("Sequential run finished.")

    finally:
        await asyncio.gather(*(c.close() for c in clients))

await run_all_sequential(
    repos=repos,
    tokens=tokens,
    outdir=str(OUTDIR),
    since_iso=since_iso,
    include_jobs=INCLUDE_JOBS,
    include_timing=INCLUDE_TIMING,
    max_runs=MAX_RUNS_PER_REPO,
    progress_env_path=str(TOKENS_ENV),
    progress_key=PROGRESS_ENV_KEY,
    pause_key=PAUSE_ENV_KEY,
)
print("Scrape finished (append-only; safe to rerun).")

# %% (Optional) Map CCE episodes → runs (Parquet)
if MAP_EPISODES and EPISODES_CSV.exists():
    def map_episodes_to_runs(episodes_csv: str | os.PathLike, outdir: str | os.PathLike, window_days: int = 14) -> pd.DataFrame:
        eps = pd.read_csv(episodes_csv)
        # detect repo column
        repo_col = None
        for k in ["repo", "repository", "full_name", "repo_full_name"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                repo_col = m[0]; break
        if not repo_col:
            raise ValueError("Could not detect a repo column in episodes CSV")

        ts_col = None
        for k in ["timestamp", "time", "created", "episode_time", "event_time", "date", "datetime"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                ts_col = m[0]; break
        if not ts_col:
            raise ValueError("Could not detect a timestamp column in episodes CSV")

        fam_col = None
        for k in ["family", "label", "cce_family"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                fam_col = m[0]; break

        eps[ts_col] = pd.to_datetime(eps[ts_col], errors="coerce", utc=True)
        if eps[ts_col].isna().mean() > 0.5:
            eps[ts_col] = _robust_parse_epoch_series(eps[ts_col])
        eps = eps.dropna(subset=[ts_col])

        mapped_frames = []
        for repo_name, grp in eps.groupby(repo_col):
            base = Path(outdir) / repo_name.replace("/", "_")
            runs_fn = base / "runs.ndjson"
            if not runs_fn.exists():
                continue
            runs = pd.read_json(runs_fn, lines=True)
            for c in ["created_at", "run_started_at", "updated_at"]:
                if c in runs.columns:
                    runs[c] = pd.to_datetime(runs[c], errors="coerce", utc=True)

            for _, e in grp.iterrows():
                ts = e[ts_col]
                lo = ts - pd.Timedelta(days=window_days)
                hi = ts + pd.Timedelta(days=window_days)
                time_col = "run_started_at" if "run_started_at" in runs.columns else "created_at"
                sel = runs[(runs[time_col] >= lo) & (runs[time_col] <= hi)].copy()
                sel["episode_ts"] = ts
                if fam_col and fam_col in e:
                    sel["episode_family"] = e[fam_col]
                mapped_frames.append(sel)

        return pd.concat(mapped_frames, ignore_index=True) if mapped_frames else pd.DataFrame()

    mapped = map_episodes_to_runs(EPISODES_CSV, OUTDIR, window_days=WINDOW_DAYS)
    if not mapped.empty:
        out_parquet = Path(OUTDIR) / "episodes_to_runs.parquet"
        mapped.to_parquet(out_parquet, index=False)
        print(f"Wrote {len(mapped):,} rows → {out_parquet}")
    else:
        print("No episode→run mappings created (check that runs.ndjson exist for the repos).")
else:
    print("Mapping skipped (set MAP_EPISODES=True to enable and ensure episodes CSV exists).")
# Out:
# Config OK
# Utils ready
# GitHub client ready
# Scrape logic loaded
# Loaded 6 token(s): ****GoAm, ****Ep4C, ****Cu3o, ****n3yv, ****n3yv, ****1Zvh
# Found 282 repos; 6 token(s); since=2024-01-01
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 510
#     507     finally:
#     508         await asyncio.gather(*(c.close() for c in clients))
# --> 510 await run_all_sequential(
#     511     repos=repos,
#     512     tokens=tokens,
#     513     outdir=str(OUTDIR),
#     514     since_iso=since_iso,
#     515     include_jobs=INCLUDE_JOBS,
#     516     include_timing=INCLUDE_TIMING,
#     517     max_runs=MAX_RUNS_PER_REPO,
#     518     progress_env_path=str(TOKENS_ENV),
#     519     progress_key=PROGRESS_ENV_KEY,
#     520     pause_key=PAUSE_ENV_KEY,
#     521 )
#     522 print("Scrape finished (append-only; safe to rerun).")
#     524 # %% (Optional) Map CCE episodes → runs (Parquet)
#
# Cell In[2], line 465, in run_all_sequential(repos, tokens, outdir, since_iso, include_jobs, include_timing, max_runs, progress_env_path, progress_key, pause_key)
#     452 async def run_all_sequential(
#     453     repos: List[str],
#     454     tokens: List[str],
#    (...)
#     463 ):
#     464     # One client per token (rotated per repo)
# --> 465     clients = [GHClient(t) for t in tokens]
#     466     start_idx = get_progress_index(progress_env_path, progress_key)
#     467     if start_idx >= len(repos):
#
# Cell In[2], line 465, in <listcomp>(.0)
#     452 async def run_all_sequential(
#     453     repos: List[str],
#     454     tokens: List[str],
#    (...)
#     463 ):
#     464     # One client per token (rotated per repo)
# --> 465     clients = [GHClient(t) for t in tokens]
#     466     start_idx = get_progress_index(progress_env_path, progress_key)
#     467     if start_idx >= len(repos):
#
# Cell In[2], line 187, in GHClient.__init__(self, token, rate_sleep)
#     178 self.rate_sleep = rate_sleep
#     179 self.headers = {
#     180     "Authorization": f"Bearer {self.token}",
#     181     "Accept": "application/vnd.github+json",
#     182     "X-GitHub-Api-Version": "2022-11-28",
#     183 }
#     184 self.client = httpx.AsyncClient(
#     185     headers=self.headers,
#     186     http2=True,  # fewer EOF hiccups
# --> 187     timeout=httpx.Timeout(connect=30, read=60, write=30),
#     188     limits=httpx.Limits(max_connections=32, max_keepalive_connections=16, keepalive_expiry=30.0),
#     189 )
#
# File c:\GitHub\.PCvenv\lib\site-packages\httpx\_config.py:123, in Timeout.__init__(self, timeout, connect, read, write, pool)
#     121 else:
#     122     if isinstance(timeout, UnsetType):
# --> 123         raise ValueError(
#     124             "httpx.Timeout must either include a default, or set all "
#     125             "four parameters explicitly."
#     126         )
#     127     self.connect = timeout if isinstance(connect, UnsetType) else connect
#     128     self.read = timeout if isinstance(read, UnsetType) else read
#
# ValueError: httpx.Timeout must either include a default, or set all four parameters explicitly.

# %%
# version 2 of the above code - Same date frame with some improvements
# %% [markdown]
# Tier-2 Scraper Notebook (GitHub Actions, multi-token, Windows-friendly)
# - Start date pinned to 2024-01-01 (change SINCE to extend or set None for full history)
# - Reads URL_List.csv and episodes_enriched_combined.csv from your path
# - Uses All_Tokens.env with GITHUB_TOKEN_1..N at C:\GitHub\Android-Mobile-Apps\All_Tokens.env
# - Scrapes runs, jobs, and (if available) timing
# - Writes NDJSON per repo; optional mapping of episodes -> runs to Parquet

# %% Install dependencies (run once per environment)
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install",
    "httpx>=0.27.0", "pandas>=2.1.0", "pyarrow>=15.0.0", "nest_asyncio>=1.6.0"
])

# %% Configuration — set your paths and knobs here
from pathlib import Path

BASE = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
URL_CSV = BASE / "URL_List.csv"
EPISODES_CSV = BASE / "episodes_enriched_combined.csv"          # optional for mapping

# 👉 Tokens file location:
TOKENS_ENV = Path(r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env")

OUTDIR = BASE / "ci_out"                                         # output folder
SINCE = "2024-01-01"                                             # ← start here; set None for no date limit

INCLUDE_JOBS = True
INCLUDE_TIMING = True
CONCURRENCY = 12
MAX_RUNS_PER_REPO = None

MAP_EPISODES = True
WINDOW_DAYS = 14

# Progress / verbosity
VERBOSE = True
PROGRESS_EVERY_RUNS = 25
PROGRESS_EVERY_JOBS = 100

print("Config OK")

# %% Utilities
import os, re, json, asyncio
from typing import List, Iterable, Dict, Any, Optional
from datetime import datetime, timezone
import pandas as pd

def ensure_dir(path: str | os.PathLike) -> None:
    os.makedirs(path, exist_ok=True)

def dump_ndjson(path: str | os.PathLike, rows: Iterable[Dict[str, Any]]) -> None:
    ensure_dir(os.path.dirname(str(path)))
    with open(path, "a", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def read_env_tokens(env_path: str | os.PathLike, prefix: str = "GITHUB_TOKEN_") -> List[str]:
    tokens = []
    with open(env_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k = k.strip()
            v = v.strip().strip('"').strip("'")
            if k.upper().startswith(prefix) and v:
                tokens.append(v)
    if not tokens:
        raise RuntimeError(f"No tokens found in {env_path} with prefix {prefix}")
    return tokens

def parse_repo_from_text(s: str) -> Optional[str]:
    if not isinstance(s, str):
        return None
    s = s.strip()
    if re.match(r"^[A-Za-z0-9_.-]+/[A-Za-z0-9_.-]+$", s):
        return s
    m = re.search(r"github\.com/([A-Za-z0-9_.-]+/[A-Za-z0-9_.-]+)", s, re.I)
    if m:
        return m.group(1)
    return None

def extract_repos_from_csv(url_csv: str | os.PathLike) -> List[str]:
    df = pd.read_csv(url_csv)
    repos = set()
    for col in df.columns:
        for v in df[col].astype(str):
            r = parse_repo_from_text(v)
            if r:
                repos.add(r)
    repos = sorted(repos)
    if not repos:
        raise RuntimeError("No GitHub repos parsed from URL CSV (need owner/name or GH URLs).")
    return repos

# (Used by optional mapping step)
def _robust_parse_epoch_series(s: pd.Series) -> pd.Series:
    snum = pd.to_numeric(s, errors="coerce")
    if snum.notna().sum() == 0:
        return pd.Series([], dtype="datetime64[ns, UTC]")
    med = snum.dropna().abs().median()
    if med > 1e14:
        unit = "us"
    elif med > 1e11:
        unit = "ms"
    else:
        unit = "s"
    return pd.to_datetime(snum, unit=unit, errors="coerce", utc=True)

print("Utils ready")

# %% GitHub API client (async, with basic rate-limit handling + workflow fallback)
import httpx

GITHUB_API = "https://api.github.com"

class GHClient:
    def __init__(self, token: str, rate_sleep: float = 0.3):
        self.token = token
        self.rate_sleep = rate_sleep
        self.headers = {
            "Authorization": f"Bearer {self.token}",
            "Accept": "application/vnd.github+json",
            "X-GitHub-Api-Version": "2022-11-28",
        }
        self.client = httpx.AsyncClient(headers=self.headers, timeout=60)

    async def close(self):
        await self.client.aclose()

    async def _get(self, url, params=None) -> httpx.Response:
        resp = await self.client.get(url, params=params)
        if resp.status_code == 403 and "rate limit" in resp.text.lower():
            reset = resp.headers.get("X-RateLimit-Reset")
            if reset:
                try:
                    reset_epoch = int(reset)
                    now = int(datetime.now(timezone.utc).timestamp())
                    wait_s = max(0, reset_epoch - now) + 1
                    print(f"[rate-limit] sleeping {wait_s}s", flush=True)
                    await asyncio.sleep(wait_s)
                    resp = await self.client.get(url, params=params)
                except Exception:
                    print("[rate-limit] backing off 10s", flush=True)
                    await asyncio.sleep(10)
                    resp = await self.client.get(url, params=params)
        resp.raise_for_status()
        await asyncio.sleep(self.rate_sleep)
        return resp

    # Repo-level runs (no 'created' filter; we filter locally)
    async def list_workflow_runs(self, owner: str, repo: str, per_page=100):
        page = 1
        while True:
            params = {"per_page": per_page, "page": page}
            resp = await self._get(f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs", params=params)
            data = resp.json()
            runs = data.get("workflow_runs", [])
            if not runs:
                break
            for run in runs:
                yield run
            if len(runs) < per_page:
                break
            page += 1

    async def list_jobs_for_run(self, owner: str, repo: str, run_id: int):
        page = 1
        per_page = 100
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs/{run_id}/jobs",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            jobs = data.get("jobs", [])
            if not jobs:
                break
            for job in jobs:
                yield job
            if len(jobs) < per_page:
                break
            page += 1

    # Workflows & per-workflow runs (fallback)
    async def list_workflows(self, owner: str, repo: str):
        page = 1
        per_page = 100
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/workflows",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            wfs = data.get("workflows", [])
            if not wfs:
                break
            for wf in wfs:
                yield wf
            if len(wfs) < per_page:
                break
            page += 1

    async def list_workflow_runs_for_workflow(self, owner: str, repo: str, workflow_id: int, per_page=100):
        page = 1
        while True:
            resp = await self._get(
                f"{GITHUB_API}/repos/{owner}/{repo}/actions/workflows/{workflow_id}/runs",
                params={"per_page": per_page, "page": page}
            )
            data = resp.json()
            runs = data.get("workflow_runs", [])
            if not runs:
                break
            for run in runs:
                yield run
            if len(runs) < per_page:
                break
            page += 1

    async def get_run_timing(self, owner: str, repo: str, run_id: int):
        resp = await self._get(f"{GITHUB_API}/repos/{owner}/{repo}/actions/runs/{run_id}/timing")
        return resp.json()

print("GitHub client ready")

# %% Scrape logic (per-repo and bulk runner) — with progress logs + local since filter + workflow fallback
from pathlib import Path

async def scrape_repo(owner_repo: str,
                      client: GHClient,
                      outdir: str | os.PathLike,
                      since_iso: Optional[str],
                      include_jobs: bool,
                      include_timing: bool,
                      max_runs: Optional[int]) -> None:
    owner, repo = owner_repo.split("/", 1)
    base = Path(outdir) / owner_repo.replace("/", "_")
    runs_path = base / "runs.ndjson"
    jobs_path = base / "jobs.ndjson"
    timing_path = base / "timing.ndjson"
    ensure_dir(base)

    since_dt = pd.to_datetime(since_iso, utc=True) if since_iso else None
    run_count = 0
    job_count = 0
    timing_count = 0

    print(f"[{owner_repo}] ▶ start (since={since_iso or 'ALL'})", flush=True)

    async def _consume_runs(run_iter):
        nonlocal run_count, job_count, timing_count
        async for run in run_iter:
            # local since filter (runs are reverse-chronological)
            ca = run.get("run_started_at") or run.get("created_at")
            if since_dt is not None and ca:
                ca_dt = pd.to_datetime(ca, utc=True, errors="coerce")
                if pd.notna(ca_dt) and ca_dt < since_dt:
                    return "stopped_by_since"

            dump_ndjson(runs_path, [run])
            run_count += 1
            if VERBOSE and (run_count % PROGRESS_EVERY_RUNS == 0):
                print(f"[{owner_repo}] … runs fetched: {run_count}", flush=True)

            if include_jobs:
                async for job in client.list_jobs_for_run(owner, repo, run["id"]):
                    dump_ndjson(jobs_path, [job])
                    job_count += 1
                    if VERBOSE and (job_count % PROGRESS_EVERY_JOBS == 0):
                        print(f"[{owner_repo}] … jobs fetched: {job_count}", flush=True)

            if include_timing:
                try:
                    timing = await client.get_run_timing(owner, repo, run["id"])
                    dump_ndjson(timing_path, [dict(run_id=run["id"], **timing)])
                    timing_count += 1
                except httpx.HTTPStatusError:
                    pass

            if max_runs and run_count >= max_runs:
                return "stopped_by_cap"

        return "exhausted"

    try:
        status = await _consume_runs(client.list_workflow_runs(owner, repo))

        # Fallback: if repo-level returned nothing, try per-workflow listing
        if run_count == 0:
            async for wf in client.list_workflows(owner, repo):
                wf_id = wf.get("id")
                if not wf_id:
                    continue
                status = await _consume_runs(client.list_workflow_runs_for_workflow(owner, repo, wf_id))
                if max_runs and run_count >= max_runs:
                    break

    except httpx.HTTPStatusError as e:
        with open(base / "errors.log", "a", encoding="utf-8") as f:
            f.write(f"{datetime.now().isoformat()} HTTP error: {e}\n")

    finally:
        print(f"[{owner_repo}] ✓ done | runs={run_count}, jobs={job_count}, timings={timing_count}", flush=True)


async def run_all(repos: list[str],
                  tokens: list[str],
                  outdir: str | os.PathLike,
                  since_iso: Optional[str],
                  include_jobs: bool,
                  include_timing: bool,
                  max_runs: Optional[int],
                  concurrency: int) -> None:
    clients = [GHClient(t) for t in tokens]  # one client per token
    sem = asyncio.Semaphore(concurrency)
    total = len(repos)
    done = 0
    lock = asyncio.Lock()

    async def worker(owner_repo: str, idx: int):
        client = clients[idx % len(clients)]
        async with sem:
            print(f"[{owner_repo}] queued (token {idx % len(clients) + 1}/{len(clients)})", flush=True)
            await scrape_repo(owner_repo, client, outdir, since_iso, include_jobs, include_timing, max_runs)
            async with lock:
                nonlocal done
                done += 1
                print(f"[{owner_repo}] ■ completed ({done}/{total})", flush=True)

    try:
        await asyncio.gather(*(worker(r, i) for i, r in enumerate(repos)))
    finally:
        await asyncio.gather(*(c.close() for c in clients))

print("Scrape logic loaded")

# %% Sanity check tokens (masked) — optional
def _read_env_tokens(env_path, prefix="GITHUB_TOKEN_"):
    toks = []
    with open(env_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k = k.strip()
            v = v.strip().strip('"').strip("'")
            if k.upper().startswith(prefix) and v:
                toks.append(v)
    return toks

try:
    _toks = _read_env_tokens(TOKENS_ENV)
    print(f"Loaded {len(_toks)} token(s): " + ", ".join("****" + t[-4:] for t in _toks))
except Exception as e:
    print(f"Token check failed: {e}")

# %% Execute scraping (Notebook-safe: top-level await, no asyncio.run)
import nest_asyncio, sys, asyncio
nest_asyncio.apply()
if sys.platform.startswith("win"):
    try:
        asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
    except Exception:
        pass

since_iso = SINCE  # fixed start date; set to None to fetch all history

tokens = read_env_tokens(TOKENS_ENV)
repos = extract_repos_from_csv(URL_CSV)

print(f"Found {len(repos)} repos; {len(tokens)} token(s); since={since_iso or 'ALL'}")
ensure_dir(OUTDIR)

await run_all(
    repos=repos,
    tokens=tokens,
    outdir=str(OUTDIR),
    since_iso=since_iso,
    include_jobs=INCLUDE_JOBS,
    include_timing=INCLUDE_TIMING,
    max_runs=MAX_RUNS_PER_REPO,
    concurrency=CONCURRENCY
)
print("Scrape finished (you can rerun; files are append-only).")

# %% (Optional) Map CCE episodes → runs (Parquet)
if MAP_EPISODES and EPISODES_CSV.exists():
    def map_episodes_to_runs(episodes_csv: str | os.PathLike, outdir: str | os.PathLike, window_days: int = 14) -> pd.DataFrame:
        eps = pd.read_csv(episodes_csv)
        # detect repo column
        repo_col = None
        for k in ["repo", "repository", "full_name", "repo_full_name"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                repo_col = m[0]; break
        if not repo_col:
            raise ValueError("Could not detect a repo column in episodes CSV")

        ts_col = None
        for k in ["timestamp", "time", "created", "episode_time", "event_time", "date", "datetime"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                ts_col = m[0]; break
        if not ts_col:
            raise ValueError("Could not detect a timestamp column in episodes CSV")

        fam_col = None
        for k in ["family", "label", "cce_family"]:
            m = [c for c in eps.columns if re.search(k, c, re.I)]
            if m:
                fam_col = m[0]; break

        eps[ts_col] = pd.to_datetime(eps[ts_col], errors="coerce", utc=True)
        if eps[ts_col].isna().mean() > 0.5:
            eps[ts_col] = _robust_parse_epoch_series(eps[ts_col])
        eps = eps.dropna(subset=[ts_col])

        mapped_frames = []
        for repo, grp in eps.groupby(repo_col):
            base = Path(outdir) / repo.replace("/", "_")
            runs_fn = base / "runs.ndjson"
            if not runs_fn.exists():
                continue
            runs = pd.read_json(runs_fn, lines=True)
            for c in ["created_at", "run_started_at", "updated_at"]:
                if c in runs.columns:
                    runs[c] = pd.to_datetime(runs[c], errors="coerce", utc=True)

            for _, e in grp.iterrows():
                ts = e[ts_col]
                lo = ts - pd.Timedelta(days=window_days)
                hi = ts + pd.Timedelta(days=window_days)
                time_col = "run_started_at" if "run_started_at" in runs.columns else "created_at"
                sel = runs[(runs[time_col] >= lo) & (runs[time_col] <= hi)].copy()
                sel["episode_ts"] = ts
                if fam_col and fam_col in e:
                    sel["episode_family"] = e[fam_col]
                mapped_frames.append(sel)

        return pd.concat(mapped_frames, ignore_index=True) if mapped_frames else pd.DataFrame()

    mapped = map_episodes_to_runs(EPISODES_CSV, OUTDIR, window_days=WINDOW_DAYS)
    if not mapped.empty:
        out_parquet = Path(OUTDIR) / "episodes_to_runs.parquet"
        mapped.to_parquet(out_parquet, index=False)
        print(f"Wrote {len(mapped):,} rows → {out_parquet}")
    else:
        print("No episode→run mappings created (check that runs.ndjson exist for the repos).")
else:
    print("Mapping skipped (set MAP_EPISODES=True to enable and ensure episodes CSV exists).")
# Out:
# Config OK
# Utils ready
# GitHub client ready
# Scrape logic loaded
# Loaded 6 token(s): ****GoAm, ****Ep4C, ****Cu3o, ****n3yv, ****n3yv, ****1Zvh
# Found 282 repos; 6 token(s); since=2024-01-01
# [4eRTuk/audioview] queued (token 1/6)
# [4eRTuk/audioview] ▶ start (since=2024-01-01)
# [AAkira/ExpandableLayout] queued (token 2/6)
# [AAkira/ExpandableLayout] ▶ start (since=2024-01-01)
# [AChep/AcDisplay] queued (token 3/6)
# [AChep/AcDisplay] ▶ start (since=2024-01-01)
# [ActivityWatch/aw-android] queued (token 4/6)
# [ActivityWatch/aw-android] ▶ start (since=2024-01-01)
# [AdevintaSpain/Barista] queued (token 5/6)
# [AdevintaSpain/Barista] ▶ start (since=2024-01-01)
# [Albert221/FastShopping] queued (token 6/6)
# [Albert221/FastShopping] ▶ start (since=2024-01-01)
# [AndBible/and-bible] queued (token 1/6)
# [AndBible/and-bible] ▶ start (since=2024-01-01)
# [AndProx/AndProx] queued (token 2/6)
# [AndProx/AndProx] ▶ start (since=2024-01-01)
# [AntennaPod/AntennaPod] queued (token 3/6)
# [AntennaPod/AntennaPod] ▶ start (since=2024-01-01)
# [Arian04/android-hid-client] queued (token 4/6)
# [Arian04/android-hid-client] ▶ start (since=2024-01-01)
# [Bdaya-Dev/oidc] queued (token 5/6)
# [Bdaya-Dev/oidc] ▶ start (since=2024-01-01)
# [BlueWallet/BlueWallet] queued (token 6/6)
# [BlueWallet/BlueWallet] ▶ start (since=2024-01-01)
# [AChep/AcDisplay] ✓ done | runs=0, jobs=0, timings=0
# [AChep/AcDisplay] ■ completed (1/282)
# [AAkira/ExpandableLayout] ✓ done | runs=0, jobs=0, timings=0
# [AAkira/ExpandableLayout] ■ completed (2/282)
# [CarlosMChica/easyrecycleradapters] queued (token 1/6)
# [CarlosMChica/easyrecycleradapters] ▶ start (since=2024-01-01)
# [CatimaLoyalty/Android] queued (token 2/6)
# [CatimaLoyalty/Android] ▶ start (since=2024-01-01)
# [4eRTuk/audioview] ✓ done | runs=0, jobs=0, timings=0
# [4eRTuk/audioview] ■ completed (3/282)
# [Crazy-Marvin/MetadataRemover] queued (token 3/6)
# [Crazy-Marvin/MetadataRemover] ▶ start (since=2024-01-01)
# [AndProx/AndProx] ✓ done | runs=0, jobs=0, timings=0
# [AndProx/AndProx] ■ completed (4/282)
# [DesarrolloAntonio/Shiori-Android-Client] queued (token 4/6)
# [DesarrolloAntonio/Shiori-Android-Client] ▶ start (since=2024-01-01)
# [Albert221/FastShopping] ✓ done | runs=1, jobs=2, timings=1
# [Albert221/FastShopping] ■ completed (5/282)
# [DroidKaigi/conference-app-2020] queued (token 5/6)
# [DroidKaigi/conference-app-2020] ▶ start (since=2024-01-01)
# [CarlosMChica/easyrecycleradapters] ✓ done | runs=0, jobs=0, timings=0
# [CarlosMChica/easyrecycleradapters] ■ completed (6/282)
# [EnsembleUI/ensemble] queued (token 6/6)
# [EnsembleUI/ensemble] ▶ start (since=2024-01-01)
# [AdevintaSpain/Barista] ✓ done | runs=0, jobs=0, timings=0
# [AdevintaSpain/Barista] ■ completed (7/282)
# [ErickSumargo/Dads] queued (token 1/6)
# [ErickSumargo/Dads] ▶ start (since=2024-01-01)
# [DroidKaigi/conference-app-2020] ✓ done | runs=0, jobs=0, timings=0
# [DroidKaigi/conference-app-2020] ■ completed (8/282)
# [EvanRespaut/Equate] queued (token 2/6)
# [EvanRespaut/Equate] ▶ start (since=2024-01-01)
# [ErickSumargo/Dads] ✓ done | runs=0, jobs=0, timings=0
# [ErickSumargo/Dads] ■ completed (9/282)
# [EventFahrplan/EventFahrplan] queued (token 3/6)
# [EventFahrplan/EventFahrplan] ▶ start (since=2024-01-01)
# [EvanRespaut/Equate] ✓ done | runs=0, jobs=0, timings=0
# [EvanRespaut/Equate] ■ completed (10/282)
# [FabianTerhorst/Iron] queued (token 4/6)
# [FabianTerhorst/Iron] ▶ start (since=2024-01-01)
# [FabianTerhorst/Iron] ✓ done | runs=0, jobs=0, timings=0
# [FabianTerhorst/Iron] ■ completed (11/282)
# [Faltenreich/Diaguard] queued (token 5/6)
# [Faltenreich/Diaguard] ▶ start (since=2024-01-01)
# [ActivityWatch/aw-android] … jobs fetched: 100
# [DesarrolloAntonio/Shiori-Android-Client] … runs fetched: 25
# [Arian04/android-hid-client] … runs fetched: 25
# [CatimaLoyalty/Android] … runs fetched: 25
# [AndBible/and-bible] … runs fetched: 25
# [Crazy-Marvin/MetadataRemover] … runs fetched: 25
# [Bdaya-Dev/oidc] … runs fetched: 25
# [AntennaPod/AntennaPod] … runs fetched: 25
# [ActivityWatch/aw-android] … runs fetched: 25
# [EnsembleUI/ensemble] … runs fetched: 25
# [EventFahrplan/EventFahrplan] … runs fetched: 25
# [Faltenreich/Diaguard] … runs fetched: 25
# [BlueWallet/BlueWallet] … runs fetched: 25
# [DesarrolloAntonio/Shiori-Android-Client] ✓ done | runs=32, jobs=93, timings=32
# [DesarrolloAntonio/Shiori-Android-Client] ■ completed (12/282)
# [Five-Prayers/five-prayers-android] queued (token 6/6)
# [Five-Prayers/five-prayers-android] ▶ start (since=2024-01-01)
# [Five-Prayers/five-prayers-android] ✓ done | runs=1, jobs=1, timings=1
# [Five-Prayers/five-prayers-android] ■ completed (13/282)
# [H-PixelDroid/PixelDroid] queued (token 1/6)
# [H-PixelDroid/PixelDroid] ▶ start (since=2024-01-01)
# [H-PixelDroid/PixelDroid] ✓ done | runs=0, jobs=0, timings=0
# [H-PixelDroid/PixelDroid] ■ completed (14/282)
# [Hny0305Lin/NLChat] queued (token 2/6)
# [Hny0305Lin/NLChat] ▶ start (since=2024-01-01)
# [EventFahrplan/EventFahrplan] … jobs fetched: 100
# [AntennaPod/AntennaPod] … jobs fetched: 100
# [Bdaya-Dev/oidc] … jobs fetched: 100
# [ActivityWatch/aw-android] … jobs fetched: 200
# [Arian04/android-hid-client] … jobs fetched: 100
# [Faltenreich/Diaguard] … jobs fetched: 100
