# %% [markdown]
# It creates:
#
#     - ReadmeFiles\owner@repo.md
#
#     - Manifests\owner@repo.csv (paths)
#
#     - Metadata\owner@repo.json
#
#     - Outputs\fetched_index.csv
#
# Then read them for removal keywords

# %%
# === stage1_fetch_data.py ===
import os
import requests
import pandas as pd
from base64 import b64decode
from dotenv import load_dotenv
from time import sleep

# === Load GitHub tokens ===
load_dotenv("All_Tokens.env")
tokens = [os.getenv(f"GITHUB_TOKEN_{i}") for i in range(1, 7)]
tokens = [t for t in tokens if t]
token_index = 0
if not tokens:
    raise ValueError("❌ No GitHub tokens found in All_Tokens.env")

def get_headers():
    global token_index
    token = tokens[token_index]
    token_index = (token_index + 1) % len(tokens)
    return {"Authorization": f"token {token}"}

# === Paths ===
base_dir = r"C:\Android Mobile App\Step1_URL_Search\Type_1_Searching_Pipeline_July 14"
input_path = os.path.join(base_dir, "step2_manifest_final_output.csv")
readme_dir = os.path.join(base_dir, "ReadmeFiles")
manifest_dir = os.path.join(base_dir, "ManifestPaths")
os.makedirs(readme_dir, exist_ok=True)
os.makedirs(manifest_dir, exist_ok=True)

# === Load Data ===
df = pd.read_csv(input_path)
repos = df["html_url"].dropna().apply(lambda x: '/'.join(x.strip('/').split('/')[-2:]))

# === Fetch loop ===
for i, repo in enumerate(repos, 1):
    print(f"🔍 [{i}/{len(repos)}] Fetching: {repo}")
    try:
        # Fetch README
        r_readme = requests.get(f"https://api.github.com/repos/{repo}/readme", headers=get_headers())
        if r_readme.status_code == 200:
            content = r_readme.json().get("content", "")
            readme_text = b64decode(content).decode('utf-8', errors='ignore')
        else:
            readme_text = ""
        with open(os.path.join(readme_dir, repo.replace("/", "@") + ".md"), "w", encoding="utf-8") as f:
            f.write(readme_text)

        # Fetch Manifest Paths
        r_manifest = requests.get(f"https://api.github.com/search/code?q=filename:AndroidManifest.xml+repo:{repo}", headers=get_headers())
        paths = [item["path"] for item in r_manifest.json().get("items", [])] if r_manifest.status_code == 200 else []
        with open(os.path.join(manifest_dir, repo.replace("/", "@") + ".txt"), "w", encoding="utf-8") as f:
            f.write("\n".join(paths))

    except Exception as e:
        print(f"❌ Error with {repo}: {e}")
        sleep(1)

print("\n✅ Fetch complete.")
# Out:
# 🔍 [1/75102] Fetching: dustin/java-memcached-client
# 🔍 [2/75102] Fetching: mth/yeti
# 🔍 [3/75102] Fetching: cyberfox/jbidwatcher
# 🔍 [4/75102] Fetching: mheath/adbcj
# 🔍 [5/75102] Fetching: jashkenas/ruby-processing
# 🔍 [6/75102] Fetching: davidB/scala-maven-plugin
# 🔍 [7/75102] Fetching: rictic/code_swarm
# 🔍 [8/75102] Fetching: rikrd/geomerative
# 🔍 [9/75102] Fetching: slagyr/limelight
# 🔍 [10/75102] Fetching: leachim6/hello-world
# 🔍 [11/75102] Fetching: brendanlim/mobile-fu
# 🔍 [12/75102] Fetching: clarkware/jdepend
# 🔍 [13/75102] Fetching: mhroth/jvsthost
# 🔍 [14/75102] Fetching: bmc/javautil
# 🔍 [15/75102] Fetching: darkk/redsocks
# 🔍 [16/75102] Fetching: sintaxi/phonegap
# 🔍 [17/75102] Fetching: rhomobile/rhodes
# 🔍 [18/75102] Fetching: rafaelp/css_browser_selector
# 🔍 [19/75102] Fetching: tcurdt/jdeb
# 🔍 [20/75102] Fetching: myabc/markdownj
# 🔍 [21/75102] Fetching: bwaldvogel/liblinear-java
# 🔍 [22/75102] Fetching: prevayler/prevayler
# 🔍 [23/75102] Fetching: bradfitz/android-garage-opener
# 🔍 [24/75102] Fetching: tcurdt/jdependency
# 🔍 [25/75102] Fetching: yanbe/qrcode
# 🔍 [26/75102] Fetching: Dawnthorn/nagare
# 🔍 [27/75102] Fetching: HamptonMakes/wikimedia-mobile
# 🔍 [28/75102] Fetching: jamplus/jamplus
# 🔍 [29/75102] Fetching: junit-team/junit4
# 🔍 [30/75102] Fetching: yui/yuicompressor
# 🔍 [31/75102] Fetching: mongodb/mongo-java-driver
# 🔍 [32/75102] Fetching: unclebob/fitnesse
# 🔍 [33/75102] Fetching: bpellin/keepassdroid
# 🔍 [34/75102] Fetching: kungfoo/geohash-java
# 🔍 [35/75102] Fetching: cwensel/cascading
# 🔍 [36/75102] Fetching: mikereedell/sunrisesunsetlib-java
# 🔍 [37/75102] Fetching: talios/clojure-maven-plugin
# 🔍 [38/75102] Fetching: gwenn/sqlite-dialect
# 🔍 [39/75102] Fetching: macournoyer/min
# 🔍 [40/75102] Fetching: collectd/jcollectd
# 🔍 [41/75102] Fetching: happygiraffe/jslint4java
# 🔍 [42/75102] Fetching: akkumar/jreversepro
# 🔍 [43/75102] Fetching: purcell/jargs
# 🔍 [44/75102] Fetching: unclebob/javaargs
# 🔍 [45/75102] Fetching: samuelclay/NewsBlur
# 🔍 [46/75102] Fetching: aburch/simutrans
# 🔍 [47/75102] Fetching: apache/zookeeper
# 🔍 [48/75102] Fetching: connectbot/connectbot
# 🔍 [49/75102] Fetching: nodebox/nodebox
# 🔍 [50/75102] Fetching: magro/memcached-session-manager
# 🔍 [51/75102] Fetching: caelum/vraptor
# 🔍 [52/75102] Fetching: alphazero/jredis
# 🔍 [53/75102] Fetching: tonyg/reversehttp
# 🔍 [54/75102] Fetching: maxcom/lorsource
# 🔍 [55/75102] Fetching: jdf/peasycam
# 🔍 [56/75102] Fetching: chrsan/css-selectors
# 🔍 [57/75102] Fetching: karlmdavis/ksoap2-android
# 🔍 [58/75102] Fetching: apache/jspwiki
# 🔍 [59/75102] Fetching: jmtd/wadc
# 🔍 [60/75102] Fetching: tackley/dbdeploy
# 🔍 [61/75102] Fetching: JakeWharton/SMSMorse
# 🔍 [62/75102] Fetching: JakeWharton/SMSBarrage
# 🔍 [63/75102] Fetching: kevwil/aspen
# 🔍 [64/75102] Fetching: apache/lucenenet
# 🔍 [65/75102] Fetching: mbrubeck/android-completion
# 🔍 [66/75102] Fetching: erkyrath/quixe
# 🔍 [67/75102] Fetching: semanticart/is_paranoid
# 🔍 [68/75102] Fetching: millenomi/diceshaker
# 🔍 [69/75102] Fetching: projectlombok/lombok
# 🔍 [70/75102] Fetching: apache/cassandra
# 🔍 [71/75102] Fetching: apache/camel
# 🔍 [72/75102] Fetching: apache/hive
# 🔍 [73/75102] Fetching: apache/maven
# 🔍 [74/75102] Fetching: apache/avro
# 🔍 [75/75102] Fetching: apache/tika
# 🔍 [76/75102] Fetching: apache/nutch
# 🔍 [77/75102] Fetching: apache/commons-lang
# 🔍 [78/75102] Fetching: Twitter4J/Twitter4J
# 🔍 [79/75102] Fetching: voldemort/voldemort
# 🔍 [80/75102] Fetching: apache/activemq
# 🔍 [81/75102] Fetching: apache/poi
# 🔍 [82/75102] Fetching: apache/httpcomponents-client
# 🔍 [83/75102] Fetching: hyphanet/fred
# 🔍 [84/75102] Fetching: simpligility/android-maven-plugin
# 🔍 [85/75102] Fetching: apache/commons-io
# 🔍 [86/75102] Fetching: apache/mina
# 🔍 [87/75102] Fetching: apache/wicket
# 🔍 [88/75102] Fetching: apache/commons-collections
# 🔍 [89/75102] Fetching: apache/pig
# 🔍 [90/75102] Fetching: caelum/caelum-stella
# 🔍 [91/75102] Fetching: gwhalin/Memcached-Java-Client
# 🔍 [92/75102] Fetching: jblas-project/jblas
# 🔍 [93/75102] Fetching: apache/commons-codec
# 🔍 [94/75102] Fetching: alexo/wro4j
# 🔍 [95/75102] Fetching: luontola/tdd-tetris-tutorial
# 🔍 [96/75102] Fetching: apache/commons-cli
# 🔍 [97/75102] Fetching: apache/httpcomponents-core
# 🔍 [98/75102] Fetching: apache/jackrabbit
# 🔍 [99/75102] Fetching: pocmo/Yaaic
# 🔍 [100/75102] Fetching: apache/cayenne
# 🔍 [101/75102] Fetching: apache/xmlgraphics-batik
# 🔍 [102/75102] Fetching: ushahidi/Ushahidi_Android
# 🔍 [103/75102] Fetching: apache/xmlgraphics-fop
# 🔍 [104/75102] Fetching: synchrony/smsn
# 🔍 [105/75102] Fetching: apache/directory-server
# 🔍 [106/75102] Fetching: apache/commons-logging
# 🔍 [107/75102] Fetching: apache/maven-enforcer
# 🔍 [108/75102] Fetching: apache/maven-archetype
# 🔍 [109/75102] Fetching: apache/openjpa
# 🔍 [110/75102] Fetching: apache/directory-studio
# 🔍 [111/75102] Fetching: apache/qpid
# 🔍 [112/75102] Fetching: apache/roller
# 🔍 [113/75102] Fetching: apache/maven-release
# 🔍 [114/75102] Fetching: agawish/Better-Arabic-Reshaper
# 🔍 [115/75102] Fetching: apache/maven-site
# 🔍 [116/75102] Fetching: vidageek/mirror
# 🔍 [117/75102] Fetching: hrehfeld/QuakeInjector
# 🔍 [118/75102] Fetching: apache/maven-scm
# 🔍 [119/75102] Fetching: akara/faban
# 🔍 [120/75102] Fetching: Ramblurr/Anki-Android
# 🔍 [121/75102] Fetching: apache/synapse
# 🔍 [122/75102] Fetching: larsgeorge/hbase-schema-manager
# 🔍 [123/75102] Fetching: constretto/constretto-core
# 🔍 [124/75102] Fetching: smilebase/org.eclipse.mylyn.github
# 🔍 [125/75102] Fetching: jabley/rate-limit
# 🔍 [126/75102] Fetching: apache/maven-plugin-tools
# 🔍 [127/75102] Fetching: textmate/java.tmbundle
# 🔍 [128/75102] Fetching: hyphanet/plugin-WebOfTrust
# 🔍 [129/75102] Fetching: sdsykes/fastimage
# 🔍 [130/75102] Fetching: Shougo/vimproc.vim
# 🔍 [131/75102] Fetching: jdbi/jdbi
# 🔍 [132/75102] Fetching: novoda/android-demos
# 🔍 [133/75102] Fetching: commonsguy/cw-advandroid
# 🔍 [134/75102] Fetching: sgroschupf/zkclient
# 🔍 [135/75102] Fetching: commonsguy/cwac-merge
# 🔍 [136/75102] Fetching: ccw-ide/ccw
# 🔍 [137/75102] Fetching: konklone/congress-android
# 🔍 [138/75102] Fetching: clafonta/Mockey
# 🔍 [139/75102] Fetching: fasterthanlime/jooc-legacy
# 🔍 [140/75102] Fetching: johannilsson/sthlmtraveling
# 🔍 [141/75102] Fetching: beberlei/netbeans-php-enhancements
# 🔍 [142/75102] Fetching: mbreese/couchdb4j
# 🔍 [143/75102] Fetching: apache/xmlbeans
# 🔍 [144/75102] Fetching: league/lzmajio
# 🔍 [145/75102] Fetching: tidev/titanium-sdk
# 🔍 [146/75102] Fetching: zeromq/libzmq
# 🔍 [147/75102] Fetching: wireghoul/graudit
# 🔍 [148/75102] Fetching: appcelerator-archive/sample-snapost
# 🔍 [149/75102] Fetching: filmaj/Beer-Me
# 🔍 [150/75102] Fetching: apache/shiro
# 🔍 [151/75102] Fetching: qos-ch/logback
# 🔍 [152/75102] Fetching: apache/pdfbox
# 🔍 [153/75102] Fetching: qos-ch/slf4j
# 🔍 [154/75102] Fetching: liferay/liferay-portal
# 🔍 [155/75102] Fetching: haraldk/TwelveMonkeys
# 🔍 [156/75102] Fetching: sirthias/parboiled
# 🔍 [157/75102] Fetching: fusesource/jansi
# 🔍 [158/75102] Fetching: aptana/studio3
# 🔍 [159/75102] Fetching: twilio/twilio-java
# 🔍 [160/75102] Fetching: yaxim-org/yaxim
# 🔍 [161/75102] Fetching: sitemesh/sitemesh3
# 🔍 [162/75102] Fetching: talklittle/reddit-is-fun
# 🔍 [163/75102] Fetching: resty-gwt/resty-gwt
# 🔍 [164/75102] Fetching: sanger-pathogens/Artemis
# 🔍 [165/75102] Fetching: aptana/Pydev
# 🔍 [166/75102] Fetching: webmetrics/browsermob-proxy
# 🔍 [167/75102] Fetching: maven-nar/nar-maven-plugin
# 🔍 [168/75102] Fetching: poidasmith/winrun4j
# 🔍 [169/75102] Fetching: jruby/joni
# 🔍 [170/75102] Fetching: martint/jmxutils
# 🔍 [171/75102] Fetching: ProjectCCNx/ccnx
# 🔍 [172/75102] Fetching: felis/USB_Host_Shield
# 🔍 [173/75102] Fetching: SableCC/sablecc
# 🔍 [174/75102] Fetching: JPMoresmau/eclipsefp
# 🔍 [175/75102] Fetching: sitemesh/sitemesh2
# 🔍 [176/75102] Fetching: djpowell/liverepl
# 🔍 [177/75102] Fetching: apache/aries
# 🔍 [178/75102] Fetching: poidasmith/xlloop
# 🔍 [179/75102] Fetching: yusuke/sign-in-with-twitter
# 🔍 [180/75102] Fetching: ericthorsen/enclojure
# 🔍 [181/75102] Fetching: brianm/config-magic
# 🔍 [182/75102] Fetching: konklone/campyre
# 🔍 [183/75102] Fetching: barryvan/CSSMin
# 🔍 [184/75102] Fetching: asual/lesscss-servlet
# 🔍 [185/75102] Fetching: davidw/hecl
# 🔍 [186/75102] Fetching: flyerhzm/contactlist
# 🔍 [187/75102] Fetching: XCSoar/XCSoar
# 🔍 [188/75102] Fetching: ohmyzsh/ohmyzsh
# 🔍 [189/75102] Fetching: gradle/gradle
# 🔍 [190/75102] Fetching: libffi/libffi
# 🔍 [191/75102] Fetching: cowboy/jquery-bbq
# 🔍 [192/75102] Fetching: billmccord/OpenCV-Android
# 🔍 [193/75102] Fetching: micahpearlman/MonkVG
# 🔍 [194/75102] Fetching: uavana/android
# 🔍 [195/75102] Fetching: fries/android-external-openssl
# 🔍 [196/75102] Fetching: tchaikov/scim-googlepinyin
# 🔍 [197/75102] Fetching: fries/android-external-openvpn
# 🔍 [198/75102] Fetching: oalders/http-browserdetect
# 🔍 [199/75102] Fetching: ligi/gobandroid
# 🔍 [200/75102] Fetching: jhy/jsoup
# 🔍 [201/75102] Fetching: RobotiumTech/robotium
# 🔍 [202/75102] Fetching: tinkerpop/gremlin
# 🔍 [203/75102] Fetching: notnoop/java-apns
# 🔍 [204/75102] Fetching: commonsguy/cw-android
# 🔍 [205/75102] Fetching: psiegman/epublib
# 🔍 [206/75102] Fetching: mttkay/droid-fu
# 🔍 [207/75102] Fetching: matburt/mobileorg-android
# 🔍 [208/75102] Fetching: trifork/erjang
# 🔍 [209/75102] Fetching: ddf/Minim
# 🔍 [210/75102] Fetching: ChainsDD/Superuser
# 🔍 [211/75102] Fetching: mttkay/signpost
# 🔍 [212/75102] Fetching: davidar/lljvm
# 🔍 [213/75102] Fetching: sgothel/jogl
# 🔍 [214/75102] Fetching: sf105/goos-code
# 🔍 [215/75102] Fetching: haseman/Android-AR-Kit
# 🔍 [216/75102] Fetching: jwood/standup-timer
# 🔍 [217/75102] Fetching: jezhumble/javasysmon
# 🔍 [218/75102] Fetching: orphan-oss/ognl
# 🔍 [219/75102] Fetching: miracle2k/android-autostarts
# 🔍 [220/75102] Fetching: erlang/erlide_eclipse
# 🔍 [221/75102] Fetching: huxi/sulky
# 🔍 [222/75102] Fetching: ricardobcl/Interval-Tree-Clocks
# 🔍 [223/75102] Fetching: nbronson/snaptree
# 🔍 [224/75102] Fetching: huxi/lilith
# 🔍 [225/75102] Fetching: sbt/junit-interface
# 🔍 [226/75102] Fetching: samtingleff/jchronic
# 🔍 [227/75102] Fetching: erikrozendaal/cqrs-lottery
# 🔍 [228/75102] Fetching: jruby/jruby-maven-plugins
# 🔍 [229/75102] Fetching: awsmithson/tcx2nikeplus
# 🔍 [230/75102] Fetching: subfuzion/droidex
# 🔍 [231/75102] Fetching: caelum/restfulie-java
# 🔍 [232/75102] Fetching: sgothel/gluegen
# 🔍 [233/75102] Fetching: dlindner/vorlesung-se2-dhbw
# 🔍 [234/75102] Fetching: colder/phantm
# 🔍 [235/75102] Fetching: tranchis/xsd2thrift
# 🔍 [236/75102] Fetching: sgothel/jogl-demos
# 🔍 [237/75102] Fetching: jdeolive/geodb
# 🔍 [238/75102] Fetching: riotfamily/riot
# 🔍 [239/75102] Fetching: vcl-xx/cue.language
# 🔍 [240/75102] Fetching: openframeworks/openFrameworks
# 🔍 [241/75102] Fetching: chrisboyle/sgtpuzzles
# 🔍 [242/75102] Fetching: simpligility/maven-android-sdk-deployer
# 🔍 [243/75102] Fetching: sympy/sympy_gamma
# 🔍 [244/75102] Fetching: pisi/Reel
# 🔍 [245/75102] Fetching: vogellacompany/codeexamples-java
# 🔍 [246/75102] Fetching: miracle2k/android2po
# 🔍 [247/75102] Fetching: mcr/Android-HelloWorldService
# 🔍 [248/75102] Fetching: danielgtaylor/arista
# 🔍 [249/75102] Fetching: talison/rack-mobile-detect
# 🔍 [250/75102] Fetching: quran/quran_android
# 🔍 [251/75102] Fetching: evanchooly/javabot
# 🔍 [252/75102] Fetching: elastic/elasticsearch
# 🔍 [253/75102] Fetching: antlr/antlr4
# 🔍 [254/75102] Fetching: TooTallNate/Java-WebSocket
# 🔍 [255/75102] Fetching: awaitility/awaitility
# 🔍 [256/75102] Fetching: jberkel/sms-backup-plus
# 🔍 [257/75102] Fetching: tinkerpop/blueprints
# 🔍 [258/75102] Fetching: antlr/stringtemplate4
# 🔍 [259/75102] Fetching: purplecabbage/phonegap-plugins
# 🔍 [260/75102] Fetching: jgilfelt/android-mapviewballoons
# 🔍 [261/75102] Fetching: quartzjer/TeleHash
# 🔍 [262/75102] Fetching: hector-client/hector
# 🔍 [263/75102] Fetching: rorist/android-network-discovery
# 🔍 [264/75102] Fetching: joestelmach/natty
# 🔍 [265/75102] Fetching: citrusframework/citrus
# 🔍 [266/75102] Fetching: tinkerpop/rexster
# 🔍 [267/75102] Fetching: telecapoland/jamendo-android
# 🔍 [268/75102] Fetching: ianopolous/JPC
# 🔍 [269/75102] Fetching: EddieRingle/hubroid
# 🔍 [270/75102] Fetching: jenkinsci/trilead-ssh2
# 🔍 [271/75102] Fetching: dwdyer/watchmaker
# 🔍 [272/75102] Fetching: ge0rg/MemorizingTrustManager
# 🔍 [273/75102] Fetching: fusesource/hawtjni
# 🔍 [274/75102] Fetching: olabini/ioke
# 🔍 [275/75102] Fetching: braintree/braintree_java
# 🔍 [276/75102] Fetching: tvrenamer/tvrenamer
# 🔍 [277/75102] Fetching: mttkay/calculon
# 🔍 [278/75102] Fetching: dtrott/maven-thrift-plugin
# 🔍 [279/75102] Fetching: branaway/Japid
# 🔍 [280/75102] Fetching: johanlkarlsson/microlog4android
# 🔍 [281/75102] Fetching: guillaumebort/play-gae
# 🔍 [282/75102] Fetching: antlr/antlrworks
# 🔍 [283/75102] Fetching: mhgrove/Empire
# 🔍 [284/75102] Fetching: thillerson/oreilly_android
# 🔍 [285/75102] Fetching: jenkinsci/winstone
# 🔍 [286/75102] Fetching: darius/expr
# 🔍 [287/75102] Fetching: felixb/websms
# 🔍 [288/75102] Fetching: raymyers/JHaml
# 🔍 [289/75102] Fetching: chirino/hawtdb
# 🔍 [290/75102] Fetching: jiangxin/freemind-mmx
# 🔍 [291/75102] Fetching: rfonseca/X-Trace
# 🔍 [292/75102] Fetching: npryce/goos-code-examples
# 🔍 [293/75102] Fetching: rzwitserloot/lombok.ast
# 🔍 [294/75102] Fetching: brione-zz/Brion-Learns-OAuth
# 🔍 [295/75102] Fetching: cyrilmottier/DrawablePresentation
# 🔍 [296/75102] Fetching: antlr/examples-v3
# 🔍 [297/75102] Fetching: jfager/jdiscript
# 🔍 [298/75102] Fetching: sudar/android-samples
# 🔍 [299/75102] Fetching: bherrmann7/Car-Cast
# 🔍 [300/75102] Fetching: rapidftr/RapidFTR---BlackBerry-Edition
# 🔍 [301/75102] Fetching: pepite/play--pdf
# 🔍 [302/75102] Fetching: kinabalu/mysticpaste
# 🔍 [303/75102] Fetching: coresmart/persistencejs
# 🔍 [304/75102] Fetching: cowboy/jquery-hashchange
# 🔍 [305/75102] Fetching: getfatday/keytool-importkeypair
# 🔍 [306/75102] Fetching: jackpal/Taipei-Torrent
# 🔍 [307/75102] Fetching: ronin-rb/ronin
# 🔍 [308/75102] Fetching: ge0rg/aprsdroid
# 🔍 [309/75102] Fetching: keesj/gomo
# 🔍 [310/75102] Fetching: vpelletier/python-libusb1
# 🔍 [311/75102] Fetching: camh/CHGridView
# 🔍 [312/75102] Fetching: glastonbridge/SuperCollider-Android
# 🔍 [313/75102] Fetching: colszowka/serious
# 🔍 [314/75102] Fetching: musk/SbtEclipsify
# 🔍 [315/75102] Fetching: bk138/Multicast-Client-Server-Example
# 🔍 [316/75102] Fetching: dylex/android_external_busybox
# 🔍 [317/75102] Fetching: CreativeCodingLab/stereo
# 🔍 [318/75102] Fetching: dropwizard/metrics
# 🔍 [319/75102] Fetching: brianfrankcooper/YCSB
# 🔍 [320/75102] Fetching: aws/aws-sdk-java
# 🔍 [321/75102] Fetching: eishay/jvm-serializers
# 🔍 [322/75102] Fetching: hierynomus/sshj
# 🔍 [323/75102] Fetching: flyingsaucerproject/flyingsaucer
# 🔍 [324/75102] Fetching: kilim/kilim
# 🔍 [325/75102] Fetching: hub4j/github-api
# 🔍 [326/75102] Fetching: twitter/elephant-bird
# 🔍 [327/75102] Fetching: bagilevi/android-pedometer
# 🔍 [328/75102] Fetching: cowtowncoder/java-uuid-generator
# 🔍 [329/75102] Fetching: jenkinsci/git-plugin
# 🔍 [330/75102] Fetching: zeromq/jzmq
# 🔍 [331/75102] Fetching: bndtools/bnd
# 🔍 [332/75102] Fetching: eleybourn/Book-Catalogue
# 🔍 [333/75102] Fetching: jasonsantos/luajava
# 🔍 [334/75102] Fetching: magro/kryo-serializers
# 🔍 [335/75102] Fetching: senseidb/zoie
# 🔍 [336/75102] Fetching: donpark/identicon
# 🔍 [337/75102] Fetching: leebyron/streamgraph
# 🔍 [338/75102] Fetching: tinkerpop/pipes
# 🔍 [339/75102] Fetching: basho/riak-java-client
# 🔍 [340/75102] Fetching: liato/android-bankdroid
# 🔍 [341/75102] Fetching: rawr/rawr
# 🔍 [342/75102] Fetching: pulse00/Symfony-2-Eclipse-Plugin
# 🔍 [343/75102] Fetching: szegedi/dynalink
# 🔍 [344/75102] Fetching: senseidb/bobo
# 🔍 [345/75102] Fetching: mcfunley/juds
# 🔍 [346/75102] Fetching: happyalu/Flite-TTS-Engine-for-Android
# 🔍 [347/75102] Fetching: sparks/themidibus
# 🔍 [348/75102] Fetching: fusesource/hawtdispatch
# 🔍 [349/75102] Fetching: unclebob/PPP
# 🔍 [350/75102] Fetching: seomoz/SEOmozAPISamples
# 🔍 [351/75102] Fetching: jingwei/krati
# 🔍 [352/75102] Fetching: johndeverall/opengraph-java
# 🔍 [353/75102] Fetching: pcgod/mumble-android
# 🔍 [354/75102] Fetching: kreed/vanilla
# 🔍 [355/75102] Fetching: helloworld1/AnyMemo
# 🔍 [356/75102] Fetching: krka/kahlua2
# 🔍 [357/75102] Fetching: smartrevolution/gnupg-for-java
# 🔍 [358/75102] Fetching: felixb/smsdroid
# 🔍 [359/75102] Fetching: vivin/GenericTree
# 🔍 [360/75102] Fetching: titanpad/titanpad
# 🔍 [361/75102] Fetching: mttkay/signpost-examples
# 🔍 [362/75102] Fetching: jboulon/Honu
# 🔍 [363/75102] Fetching: mark-watson/java_practical_semantic_web
# 🔍 [364/75102] Fetching: mchr3k/org.intrace
# 🔍 [365/75102] Fetching: Cascading/cascading-dbmigrate
# 🔍 [366/75102] Fetching: bengarney/PBLabsProfiler
# 🔍 [367/75102] Fetching: onesocialweb/osw-openfire-plugin
# 🔍 [368/75102] Fetching: leaflabs/maple-ide
# 🔍 [369/75102] Fetching: sansumbrella/Processing-ObliqueStrategies
# 🔍 [370/75102] Fetching: jbrisbin/vcloud
# 🔍 [371/75102] Fetching: fernandezpablo85/scribe
# 🔍 [372/75102] Fetching: novnc/noVNC
# 🔍 [373/75102] Fetching: vcr/vcr
# 🔍 [374/75102] Fetching: antirez/linenoise
# 🔍 [375/75102] Fetching: ajstarks/svgo
# 🔍 [376/75102] Fetching: c-ares/c-ares
# 🔍 [377/75102] Fetching: joseph/Monocle
# 🔍 [378/75102] Fetching: wycats/rack-offline
# 🔍 [379/75102] Fetching: cbschuld/Browser.php
# 🔍 [380/75102] Fetching: davidaurelio/TouchScroll
# 🔍 [381/75102] Fetching: winston/google_visualr
# 🔍 [382/75102] Fetching: jvoegele/gradle-android-plugin
# 🔍 [383/75102] Fetching: devpunks/snuggsi
# 🔍 [384/75102] Fetching: yangh/sevensquare
# 🔍 [385/75102] Fetching: marcogulino/AndroidUsbCamera
# 🔍 [386/75102] Fetching: technoweenie/jquery.doubletap
# 🔍 [387/75102] Fetching: astro/prittorrent
# 🔍 [388/75102] Fetching: realXtend/tundra
# 🔍 [389/75102] Fetching: formigarafa/robotito
# 🔍 [390/75102] Fetching: mini3d/mini3d
# 🔍 [391/75102] Fetching: max-mapper/PDXAPI
# 🔍 [392/75102] Fetching: facebook/facebook-android-sdk
# 🔍 [393/75102] Fetching: thewca/tnoodle
# 🔍 [394/75102] Fetching: dkandalov/pomodoro-tm
# 🔍 [395/75102] Fetching: redis/jedis
# 🔍 [396/75102] Fetching: clojure/clojure
# 🔍 [397/75102] Fetching: apache/jmeter
# 🔍 [398/75102] Fetching: Graylog2/graylog2-server
# 🔍 [399/75102] Fetching: Atmosphere/atmosphere
# 🔍 [400/75102] Fetching: cyrilmottier/GreenDroid
# 🔍 [401/75102] Fetching: testng-team/testng
# 🔍 [402/75102] Fetching: sirthias/pegdown
# 🔍 [403/75102] Fetching: todoroo/astrid
# 🔍 [404/75102] Fetching: tokudu/AndroidPushNotificationsDemo
# 🔍 [405/75102] Fetching: apache/mina-sshd
# 🔍 [406/75102] Fetching: cloudera/flume
# 🔍 [407/75102] Fetching: ZhouWeikuan/cocos2d
# 🔍 [408/75102] Fetching: abarisain/dmix
# 🔍 [409/75102] Fetching: cdk/cdk
# 🔍 [410/75102] Fetching: graphstream/gs-core
# 🔍 [411/75102] Fetching: JOSM/josm
# 🔍 [412/75102] Fetching: ruboto/ruboto-irb
# 🔍 [413/75102] Fetching: Cathedrow/Cryptosuite
# 🔍 [414/75102] Fetching: searls/jasmine-maven-plugin
# 🔍 [415/75102] Fetching: getrailo/railo
# 🔍 [416/75102] Fetching: jai-imageio/jai-imageio-core
# 🔍 [417/75102] Fetching: aled/jsi
# 🔍 [418/75102] Fetching: paul-hammant/paranamer
# 🔍 [419/75102] Fetching: krukow/clj-ds
# 🔍 [420/75102] Fetching: jenkinsci/gerrit-trigger-plugin
# 🔍 [421/75102] Fetching: testng-team/testng-eclipse
# 🔍 [422/75102] Fetching: sevntu-checkstyle/sevntu.checkstyle
# 🔍 [423/75102] Fetching: apollo-rsps/apollo
# 🔍 [424/75102] Fetching: luontola/idea-sbt-plugin
# 🔍 [425/75102] Fetching: scriptographer/scriptographer
# 🔍 [426/75102] Fetching: banshee/AndroidProguardScala
# 🔍 [427/75102] Fetching: tulskiy/musique
# 🔍 [428/75102] Fetching: esnyder/callrecorder
# 🔍 [429/75102] Fetching: jenkinsci/throttle-concurrent-builds-plugin
# 🔍 [430/75102] Fetching: suguru/cassandra-webconsole
# 🔍 [431/75102] Fetching: synhershko/HebMorph
# 🔍 [432/75102] Fetching: graphstream/gs-algo
# 🔍 [433/75102] Fetching: intervigilium/MicDroid
# 🔍 [434/75102] Fetching: apache/harmony
# 🔍 [435/75102] Fetching: tfnico/guava-examples
# 🔍 [436/75102] Fetching: AlgorithmsNYC/AlgorithmsNYC
# 🔍 [437/75102] Fetching: atduskgreg/GitHub-Stoplight
# 🔍 [438/75102] Fetching: zznate/hector-examples
# 🔍 [439/75102] Fetching: StrickenFromHistory/PocketMonstersOnline
# 🔍 [440/75102] Fetching: spullara/havrobase
# 🔍 [441/75102] Fetching: sanity/Athena
# 🔍 [442/75102] Fetching: npryce/maybe-java
# 🔍 [443/75102] Fetching: ImpalerWrG/Khazad
# 🔍 [444/75102] Fetching: alienrobotwizard/sounder
# 🔍 [445/75102] Fetching: demoscenepassivist/SocialCoding
# 🔍 [446/75102] Fetching: cbeams/distyles
# 🔍 [447/75102] Fetching: AndrewRosenberg/AuToBI
# 🔍 [448/75102] Fetching: northern-bites/nbites
# 🔍 [449/75102] Fetching: john-difool/cocos2d-android
# 🔍 [450/75102] Fetching: JoelPM/BidiThrift
# 🔍 [451/75102] Fetching: zpasal/hbase-gui-admin
# 🔍 [452/75102] Fetching: albb0920/LunaTerm
# 🔍 [453/75102] Fetching: kohsuke/jcifs
# 🔍 [454/75102] Fetching: jfinkels/tuxguitar
# 🔍 [455/75102] Fetching: 360/360-Engine-for-Android
# 🔍 [456/75102] Fetching: assimp/assimp
# 🔍 [457/75102] Fetching: reactiveui/ReactiveUI
# 🔍 [458/75102] Fetching: atsushieno/managed-midi
# 🔍 [459/75102] Fetching: marcuswestin/store.js
# 🔍 [460/75102] Fetching: libretro/RetroArch
# 🔍 [461/75102] Fetching: metafizzy/infinite-scroll
# 🔍 [462/75102] Fetching: senchalabs/jQTouch
# 🔍 [463/75102] Fetching: ruboto/ruboto
# 🔍 [464/75102] Fetching: django/djangoproject.com
# 🔍 [465/75102] Fetching: davebalmer/jo
# 🔍 [466/75102] Fetching: csnover/TraceKit
# 🔍 [467/75102] Fetching: 3rd-Eden/useragent
# 🔍 [468/75102] Fetching: havlenapetr/FFMpeg
# 🔍 [469/75102] Fetching: libts/tslib
# 🔍 [470/75102] Fetching: fabrik42/acts_as_api
# 🔍 [471/75102] Fetching: Lax/traffic-accounting-nginx-module
# 🔍 [472/75102] Fetching: jleclanche/python-bna
# 🔍 [473/75102] Fetching: comex/frash
# 🔍 [474/75102] Fetching: purplecabbage/GloveBox
# 🔍 [475/75102] Fetching: isieo/adbFS
# 🔍 [476/75102] Fetching: openvoice/openvoice
# 🔍 [477/75102] Fetching: krawaller/Golingo
# 🔍 [478/75102] Fetching: PathagarBooks/pathagar
# 🔍 [479/75102] Fetching: premasagar/sandie
# 🔍 [480/75102] Fetching: bustardcelly/as3flobile
# 🔍 [481/75102] Fetching: enjalot/EnjaParticles
# 🔍 [482/75102] Fetching: theflashbum/BitmapScroller
# 🔍 [483/75102] Fetching: nysenate/NYSenateMobileApp
# 🔍 [484/75102] Fetching: robolectric/robolectric
# 🔍 [485/75102] Fetching: OpenTSDB/opentsdb
# 🔍 [486/75102] Fetching: go-lang-plugin-org/go-lang-idea-plugin
# 🔍 [487/75102] Fetching: wildfly/wildfly
# 🔍 [488/75102] Fetching: cbeust/jcommander
# 🔍 [489/75102] Fetching: playframework/play1
# 🔍 [490/75102] Fetching: vrapper/vrapper
# 🔍 [491/75102] Fetching: mixpanel/mixpanel-android
# 🔍 [492/75102] Fetching: larsgeorge/hbase-book
# 🔍 [493/75102] Fetching: jolokia/jolokia
# 🔍 [494/75102] Fetching: apache/karaf
# 🔍 [495/75102] Fetching: OpenTSDB/asynchbase
# 🔍 [496/75102] Fetching: jeremyh/jBCrypt
# 🔍 [497/75102] Fetching: rtyley/agit
# 🔍 [498/75102] Fetching: nysenate/OpenLegislation
# 🔍 [499/75102] Fetching: nolanlawson/Catlog
# 🔍 [500/75102] Fetching: FlowingMedia/TimeFlow
# 🔍 [501/75102] Fetching: apache/maven-surefire
# 🔍 [502/75102] Fetching: smallrye/jandex
# 🔍 [503/75102] Fetching: weld/core
# 🔍 [504/75102] Fetching: jawi/ols
# 🔍 [505/75102] Fetching: CyanogenMod/android_packages_apps_Camera
# 🔍 [506/75102] Fetching: FasterXML/aalto-xml
# 🔍 [507/75102] Fetching: xnio/xnio
# 🔍 [508/75102] Fetching: jboss-modules/jboss-modules
# 🔍 [509/75102] Fetching: ning/compress
# 🔍 [510/75102] Fetching: cyclestreets/android
# 🔍 [511/75102] Fetching: openstreetmap/OSM-binary
# 🔍 [512/75102] Fetching: preon/preon
# 🔍 [513/75102] Fetching: nexes/Android-File-Manager
# 🔍 [514/75102] Fetching: ymasory/iText-4.2.0
# 🔍 [515/75102] Fetching: arquillian/arquillian-examples
# 🔍 [516/75102] Fetching: dennisjzh/GwtMobile
# 🔍 [517/75102] Fetching: IanWraith/DMRDecode
# 🔍 [518/75102] Fetching: munificent/jasic
# 🔍 [519/75102] Fetching: 19WAS85/coollection
# 🔍 [520/75102] Fetching: jsankey/android-junit-report
# 🔍 [521/75102] Fetching: BlackLabs/play-morphia
# 🔍 [522/75102] Fetching: shrinkwrap/shrinkwrap
# 🔍 [523/75102] Fetching: s7/scale7-pelops
# 🔍 [524/75102] Fetching: awhitford/lombok.maven
# 🔍 [525/75102] Fetching: CyanogenMod/android_packages_apps_Gallery3D
# 🔍 [526/75102] Fetching: kritzikratzi/edsdk4j
# 🔍 [527/75102] Fetching: OpenTSDB/async
# 🔍 [528/75102] Fetching: CyanogenMod/android_packages_inputmethods_LatinIME
# 🔍 [529/75102] Fetching: smartrics/RestFixture
# 🔍 [530/75102] Fetching: CyanogenMod/android_packages_apps_Torch
# 🔍 [531/75102] Fetching: pragkirk/poma
# 🔍 [532/75102] Fetching: CyanogenMod/android_packages_apps_Gallery
# 🔍 [533/75102] Fetching: CyanogenMod/android_packages_apps_DSPManager
# 🔍 [534/75102] Fetching: jexp/jpatterns
# 🔍 [535/75102] Fetching: dmx-systems/dmx-platform
# 🔍 [536/75102] Fetching: joelind/zxing-iphone
# 🔍 [537/75102] Fetching: dumbledore/AlbiteREADER
# 🔍 [538/75102] Fetching: MaskedRetriever/SuperSkein
# 🔍 [539/75102] Fetching: pilhuhn/ZwitscherA
# 🔍 [540/75102] Fetching: phstc/javapokertexasholdem
# 🔍 [541/75102] Fetching: shakalaca/UniversalAndroot
# 🔍 [542/75102] Fetching: sunnygleason/j4-minimal
# 🔍 [543/75102] Fetching: thobe/social-network-workshop
# 🔍 [544/75102] Fetching: CyanogenMod/android_packages_apps_Launcher2
# 🔍 [545/75102] Fetching: Medo42/Gmk-Splitter
# 🔍 [546/75102] Fetching: seph-lang/seph
# 🔍 [547/75102] Fetching: cakephp/cakephp-netbeans
# 🔍 [548/75102] Fetching: jdubois/Tudu-Lists
# 🔍 [549/75102] Fetching: faraday/wikiprep-esa
# 🔍 [550/75102] Fetching: MIT-Mobile/MIT-Mobile-for-Android
# 🔍 [551/75102] Fetching: jenkinsci/priority-sorter-plugin
# 🔍 [552/75102] Fetching: Mahoney/sysout-over-slf4j
# 🔍 [553/75102] Fetching: CleverCloud/Quercus
# 🔍 [554/75102] Fetching: jkff/ire
# 🔍 [555/75102] Fetching: gabu/AndroidSDK-RecipeBook
# 🔍 [556/75102] Fetching: kjk/volante-obsolete
# 🔍 [557/75102] Fetching: mono/mono
# 🔍 [558/75102] Fetching: RHVoice/RHVoice
# 🔍 [559/75102] Fetching: BYVoid/OpenCC
# 🔍 [560/75102] Fetching: mediaelement/mediaelement
# 🔍 [561/75102] Fetching: fnando/browser
# 🔍 [562/75102] Fetching: dotnet/android-samples
# 🔍 [563/75102] Fetching: maccman/juggernaut
# 🔍 [564/75102] Fetching: kevinlawler/kona
# 🔍 [565/75102] Fetching: tnantoka/edhita
# 🔍 [566/75102] Fetching: iamcal/php-emoji
# 🔍 [567/75102] Fetching: oNaiPs/droidVncServer
# 🔍 [568/75102] Fetching: kennethkufluk/js-mindmap
# 🔍 [569/75102] Fetching: CyanogenMod/android_bootable_recovery
# 🔍 [570/75102] Fetching: iDroid-Project/openiBoot
# 🔍 [571/75102] Fetching: yui/yeti
# 🔍 [572/75102] Fetching: jpmobile/jpmobile
# 🔍 [573/75102] Fetching: dex4er/fakechroot
# 🔍 [574/75102] Fetching: borfast/arrispwgen
# 🔍 [575/75102] Fetching: alanmcgovern/Mono.Nat
# 🔍 [576/75102] Fetching: unify/unify
# 🔍 [577/75102] Fetching: cpojer/mootools-mobile
# 🔍 [578/75102] Fetching: mleone/broadcast
# 🔍 [579/75102] Fetching: iRail/iRail
# 🔍 [580/75102] Fetching: browndeer/coprthr
# 🔍 [581/75102] Fetching: CyanogenMod/android_hardware_libhardware
# 🔍 [582/75102] Fetching: CyanogenMod/android_external_webkit
# 🔍 [583/75102] Fetching: szym/barnacle
# 🔍 [584/75102] Fetching: CyanogenMod/android_system_vold
# 🔍 [585/75102] Fetching: CyanogenMod/android_hardware_libhardware_legacy
# 🔍 [586/75102] Fetching: CyanogenMod/android_device_htc_bravo
# 🔍 [587/75102] Fetching: geeknam/Push-Contacts
# 🔍 [588/75102] Fetching: CyanogenMod/android_system_extras
# 🔍 [589/75102] Fetching: dankex/kgdb-android
# 🔍 [590/75102] Fetching: dkandalov/scratch
# 🔍 [591/75102] Fetching: Bombe/Sone
# 🔍 [592/75102] Fetching: arduino/Arduino
# 🔍 [593/75102] Fetching: plantuml/plantuml
# 🔍 [594/75102] Fetching: rest-assured/rest-assured
# 🔍 [595/75102] Fetching: rabbitmq/rabbitmq-tutorials
# 🔍 [596/75102] Fetching: hibernate/hibernate-orm
# 🔍 [597/75102] Fetching: scribejava/scribejava
# 🔍 [598/75102] Fetching: EngineHub/WorldEdit
# 🔍 [599/75102] Fetching: modelmapper/modelmapper
# 🔍 [600/75102] Fetching: geometer/FBReaderJ
# 🔍 [601/75102] Fetching: kiegroup/jbpm
# 🔍 [602/75102] Fetching: functionaljava/functionaljava
# 🔍 [603/75102] Fetching: dcm4che/dcm4che
# 🔍 [604/75102] Fetching: rabbitmq/rabbitmq-java-client
# 🔍 [605/75102] Fetching: infinispan/infinispan
# 🔍 [606/75102] Fetching: py4j/py4j
# 🔍 [607/75102] Fetching: hibernate/hibernate-validator
# 🔍 [608/75102] Fetching: mpatric/mp3agic
# 🔍 [609/75102] Fetching: jhalterman/expiringmap
# 🔍 [610/75102] Fetching: pholser/junit-quickcheck
# 🔍 [611/75102] Fetching: samskivert/jmustache
# 🔍 [612/75102] Fetching: jpos/jPOS
# 🔍 [613/75102] Fetching: jhalterman/typetools
# 🔍 [614/75102] Fetching: lemire/javaewah
# 🔍 [615/75102] Fetching: ahorn/android-rss
# 🔍 [616/75102] Fetching: hibernate/hibernate-search
# 🔍 [617/75102] Fetching: forcedotcom/dataloader
# 🔍 [618/75102] Fetching: jmeter-maven-plugin/jmeter-maven-plugin
# 🔍 [619/75102] Fetching: jhalterman/concurrentunit
# 🔍 [620/75102] Fetching: samsonw/OpenExplorer
# 🔍 [621/75102] Fetching: alexruiz/fest-assert-2.x
# 🔍 [622/75102] Fetching: subgraph/Vega
# 🔍 [623/75102] Fetching: GeoWebCache/geowebcache
# 🔍 [624/75102] Fetching: EngineHub/CraftBook
# 🔍 [625/75102] Fetching: michel-kraemer/bson4jackson
# 🔍 [626/75102] Fetching: xetorthio/johm
# 🔍 [627/75102] Fetching: errai/errai
# 🔍 [628/75102] Fetching: Animosity/CraftIRC
# 🔍 [629/75102] Fetching: FasterXML/java-classmate
# 🔍 [630/75102] Fetching: CloudStack-extras/CloudStack-archive
# 🔍 [631/75102] Fetching: cscotta/Octobot
# 🔍 [632/75102] Fetching: s4/core
# 🔍 [633/75102] Fetching: apache/commons-validator
# 🔍 [634/75102] Fetching: fakereplace/fakereplace
# 🔍 [635/75102] Fetching: CSEMike/OneSwarm
# 🔍 [636/75102] Fetching: rschildmeijer/deft
# 🔍 [637/75102] Fetching: yusuke/samurai
# 🔍 [638/75102] Fetching: andygibson/datafactory
# 🔍 [639/75102] Fetching: reverb/wordnik-oss
# 🔍 [640/75102] Fetching: dwdyer/uncommons-maths
# 🔍 [641/75102] Fetching: NXT/LEGO-MINDSTORMS-MINDdroid
# 🔍 [642/75102] Fetching: ops4j/org.ops4j.pax.web
# 🔍 [643/75102] Fetching: alexruiz/fest-reflect
# 🔍 [644/75102] Fetching: jakartaee/validation
# 🔍 [645/75102] Fetching: xetorthio/rmq
# 🔍 [646/75102] Fetching: jmock-developers/jmock-library
# 🔍 [647/75102] Fetching: craigwblake/redline
# 🔍 [648/75102] Fetching: brix-cms/brix-cms
# 🔍 [649/75102] Fetching: fuzziness/kabeja
# 🔍 [650/75102] Fetching: CyanogenMod/android_packages_apps_FileManager
# 🔍 [651/75102] Fetching: alexruiz/fest-swing-1.x
# 🔍 [652/75102] Fetching: licheng/zoj
# 🔍 [653/75102] Fetching: open2jamorg/open2jam
# 🔍 [654/75102] Fetching: CoreMedia/jangaroo-tools
# 🔍 [655/75102] Fetching: dashorst/dashboard
# 🔍 [656/75102] Fetching: abashev/vfs-s3
# 🔍 [657/75102] Fetching: fadmaa/grefine-rdf-extension
# 🔍 [658/75102] Fetching: rtreffer/AsmackService
# 🔍 [659/75102] Fetching: anjlab/sat3
# 🔍 [660/75102] Fetching: Skywriter-se/adbWireless
# 🔍 [661/75102] Fetching: c4t-dr34m/c-geo
# 🔍 [662/75102] Fetching: rjo1970/dumbster
# 🔍 [663/75102] Fetching: CyanogenMod/android_packages_apps_FM
# 🔍 [664/75102] Fetching: jamesshore/lets_play_tdd
# 🔍 [665/75102] Fetching: FreakDev/PhoneGap-Android-HTML5-WebSocket
# 🔍 [666/75102] Fetching: ning/maven-duplicate-finder-plugin
# 🔍 [667/75102] Fetching: stephenc/java-iso-tools
# 🔍 [668/75102] Fetching: ning/maven-dependency-versions-check-plugin
# 🔍 [669/75102] Fetching: Gornova/MarteEngine
# 🔍 [670/75102] Fetching: jukka/java-unrar
# 🔍 [671/75102] Fetching: bekkopen/NoCommons
# 🔍 [672/75102] Fetching: manzke/guice-automatic-injection
# 🔍 [673/75102] Fetching: chrislongo/download-hls
# 🔍 [674/75102] Fetching: mobilepearls/com.mobilepearls.sokoban
# 🔍 [675/75102] Fetching: rodnaph/sockso
# 🔍 [676/75102] Fetching: ccordenier/tapestry5-hotel-booking
# 🔍 [677/75102] Fetching: intervigilium/Lame4Android
# 🔍 [678/75102] Fetching: techatspree/androlog
# 🔍 [679/75102] Fetching: panterch/ch.panter.projectzero
# 🔍 [680/75102] Fetching: stazz/java-sql-generator
# 🔍 [681/75102] Fetching: t3hnar/CmdSupport
# 🔍 [682/75102] Fetching: square/retrofit
# 🔍 [683/75102] Fetching: kivy/kivy
# 🔍 [684/75102] Fetching: liballeg/allegro5
# 🔍 [685/75102] Fetching: opendocument-app/OpenDocument.droid
# 🔍 [686/75102] Fetching: mosra/toolchains
# 🔍 [687/75102] Fetching: gildas-lormeau/SingleFile
# 🔍 [688/75102] Fetching: madrobby/zepto
# 🔍 [689/75102] Fetching: libgit2/libgit2
# 🔍 [690/75102] Fetching: liuliu/ccv
# 🔍 [691/75102] Fetching: fpillet/NSLogger
# 🔍 [692/75102] Fetching: tapmodo/Jcrop
# 🔍 [693/75102] Fetching: piroor/treestyletab
# 🔍 [694/75102] Fetching: furf/jquery-ui-touch-punch
# 🔍 [695/75102] Fetching: tomahawk-player/tomahawk
# 🔍 [696/75102] Fetching: snes9xgit/snes9x
# 🔍 [697/75102] Fetching: strongswan/strongswan
# 🔍 [698/75102] Fetching: drawpile/Drawpile
# 🔍 [699/75102] Fetching: benvanik/WebGL-Inspector
# 🔍 [700/75102] Fetching: gregmuellegger/django-mobile
# 🔍 [701/75102] Fetching: hierynomus/license-gradle-plugin
# 🔍 [702/75102] Fetching: max-mapper/monocles
# 🔍 [703/75102] Fetching: MJPA/SimpleJSON
# 🔍 [704/75102] Fetching: tmzt/g2root-kmod
# 🔍 [705/75102] Fetching: sztupy/adbputty
# 🔍 [706/75102] Fetching: dpavlin/android-command-line
# 🔍 [707/75102] Fetching: senchalabs/android-tools
# 🔍 [708/75102] Fetching: shagr4th/droid48
# 🔍 [709/75102] Fetching: mattiasgeniar/MoZBX
# 🔍 [710/75102] Fetching: dionjwa/Hydrax
# 🔍 [711/75102] Fetching: aduros/hydra
# 🔍 [712/75102] Fetching: relevance/hooppps
# 🔍 [713/75102] Fetching: iamdaniele/Foundation
# 🔍 [714/75102] Fetching: Pretz/SNesoid
# 🔍 [715/75102] Fetching: conceptdev/RestaurantGuide
# 🔍 [716/75102] Fetching: spring-projects/spring-framework
# 🔍 [717/75102] Fetching: netty/netty
# 🔍 [718/75102] Fetching: jenkinsci/jenkins
# 🔍 [719/75102] Fetching: elastic/logstash
# 🔍 [720/75102] Fetching: SonarSource/sonarqube
# 🔍 [721/75102] Fetching: rstudio/rstudio
# 🔍 [722/75102] Fetching: stleary/JSON-java
# 🔍 [723/75102] Fetching: spockframework/spock
# 🔍 [724/75102] Fetching: spring-projects/spring-data-jpa
# 🔍 [725/75102] Fetching: spring-projects/spring-batch
# 🔍 [726/75102] Fetching: johannilsson/android-pulltorefresh
# 🔍 [727/75102] Fetching: Bukkit/Bukkit
# 🔍 [728/75102] Fetching: spring-projects/spring-retry
# 🔍 [729/75102] Fetching: p6spy/p6spy
# 🔍 [730/75102] Fetching: webbukkit/dynmap
# 🔍 [731/75102] Fetching: validator/validator
# 🔍 [732/75102] Fetching: ocpsoft/prettytime
# 🔍 [733/75102] Fetching: johannilsson/android-actionbar
# 🔍 [734/75102] Fetching: rkalla/imgscalr
# 🔍 [735/75102] Fetching: belaban/JGroups
# 🔍 [736/75102] Fetching: eclipse-color-theme/eclipse-color-theme
# 🔍 [737/75102] Fetching: EngineHub/WorldGuard
# 🔍 [738/75102] Fetching: spring-projects/spring-amqp
# 🔍 [739/75102] Fetching: spring-projects/spring-data-commons
# 🔍 [740/75102] Fetching: FasterXML/jackson-dataformat-xml
# 🔍 [741/75102] Fetching: infinitest/infinitest
# 🔍 [742/75102] Fetching: springtestdbunit/spring-test-dbunit
# 🔍 [743/75102] Fetching: asterisk-java/asterisk-java
# 🔍 [744/75102] Fetching: techatspree/android-archetypes
# 🔍 [745/75102] Fetching: dozingcat/Vector-Pinball
# 🔍 [746/75102] Fetching: smooks/smooks
# 🔍 [747/75102] Fetching: pmuellr/weinre
# 🔍 [748/75102] Fetching: jenkinsci/email-ext-plugin
# 🔍 [749/75102] Fetching: wicketstuff/core
# 🔍 [750/75102] Fetching: guardianproject/ObscuraCam
# 🔍 [751/75102] Fetching: FasterXML/jackson-datatype-hibernate
# 🔍 [752/75102] Fetching: jimwebber/neo4j-tutorial
# 🔍 [753/75102] Fetching: maxpower47/PinDroid
# 🔍 [754/75102] Fetching: jenkinsci/github-plugin
# 🔍 [755/75102] Fetching: shiffman/Most-Pixels-Ever-Processing
# 🔍 [756/75102] Fetching: jenkinsci/ec2-plugin
# 🔍 [757/75102] Fetching: forcedotcom/wsc
# 🔍 [758/75102] Fetching: dront78/PulseDroid
# 🔍 [759/75102] Fetching: alecgorge/jsonapi
# 🔍 [760/75102] Fetching: Whiley/WhileyCompiler
# 🔍 [761/75102] Fetching: markfguerra/GLWallpaperService
# 🔍 [762/75102] Fetching: twitter/joauth
# 🔍 [763/75102] Fetching: hallvard/plantuml
# 🔍 [764/75102] Fetching: GiorgioRegni/Binaural-Beats
# 🔍 [765/75102] Fetching: jenkinsci/android-emulator-plugin
# 🔍 [766/75102] Fetching: yocontra/JMD
# 🔍 [767/75102] Fetching: trystan/AsciiPanel
# 🔍 [768/75102] Fetching: gpu/JOCL
# 🔍 [769/75102] Fetching: jenkinsci/performance-plugin
# 🔍 [770/75102] Fetching: infochimps-labs/wonderdog
# 🔍 [771/75102] Fetching: jenkinsci/jira-plugin
# 🔍 [772/75102] Fetching: Hidendra/LWC
# 🔍 [773/75102] Fetching: stephenc/high-scale-lib
# 🔍 [774/75102] Fetching: jbehave/jbehave-tutorial
# 🔍 [775/75102] Fetching: ogrisel/pignlproc
# 🔍 [776/75102] Fetching: Bukkit/SamplePlugin
# 🔍 [777/75102] Fetching: raffaeleguidi/DirectMemory
# 🔍 [778/75102] Fetching: jenkinsci/tfs-plugin
# 🔍 [779/75102] Fetching: ogrodnek/csv-serde
# 🔍 [780/75102] Fetching: jenkinsci/swarm-plugin
# 🔍 [781/75102] Fetching: jenkinsci/role-strategy-plugin
# 🔍 [782/75102] Fetching: androrm/androrm
# 🔍 [783/75102] Fetching: jenkins-infra/update-center2
# 🔍 [784/75102] Fetching: jenkinsci/subversion-plugin
# 🔍 [785/75102] Fetching: tenaciousRas/android-plist-parser
# 🔍 [786/75102] Fetching: radargun/radargun
# 🔍 [787/75102] Fetching: dhanji/loop
# 🔍 [788/75102] Fetching: caelum/agiletickets
# 🔍 [789/75102] Fetching: jenkinsci/scm-sync-configuration-plugin
# 🔍 [790/75102] Fetching: yui/yuitest
# 🔍 [791/75102] Fetching: jenkinsci/selenium-plugin
# 🔍 [792/75102] Fetching: jenkinsci/gradle-plugin
# 🔍 [793/75102] Fetching: anthonyu/KeptCollections
# 🔍 [794/75102] Fetching: timrdf/csv2rdf4lod-automation
# 🔍 [795/75102] Fetching: jenkinsci/ssh-agents-plugin
# 🔍 [796/75102] Fetching: jenkinsci/artifactory-plugin
# 🔍 [797/75102] Fetching: kordamp/json-lib
# 🔍 [798/75102] Fetching: richmidwinter/google-api-translate-java
# 🔍 [799/75102] Fetching: Zapotek/raw2vmdk
# 🔍 [800/75102] Fetching: spring-projects/spring-data-gemfire
# 🔍 [801/75102] Fetching: mafrosis/Wake-On-Lan
# 🔍 [802/75102] Fetching: neurolabs/henplus
# 🔍 [803/75102] Fetching: adrian/upm-swing
# 🔍 [804/75102] Fetching: akaigoro/df4j
# 🔍 [805/75102] Fetching: chesterbr/minitruco-android
# 🔍 [806/75102] Fetching: jenkinsci/promoted-builds-plugin
# 🔍 [807/75102] Fetching: jenkinsci/chucknorris-plugin
# 🔍 [808/75102] Fetching: m2e-code-quality/m2e-code-quality
# 🔍 [809/75102] Fetching: sonalgoyal/hiho
# 🔍 [810/75102] Fetching: honcheng/ScrollableTabHost-for-Android
# 🔍 [811/75102] Fetching: ops4j/org.ops4j.pax.exam
# 🔍 [812/75102] Fetching: cretz/gwt-node
# 🔍 [813/75102] Fetching: jenkinsci/htmlpublisher-plugin
# 🔍 [814/75102] Fetching: Xevel/NXV11
# 🔍 [815/75102] Fetching: Qi4j/qi4j-sdk
# 🔍 [816/75102] Fetching: mandubian/siena
# 🔍 [817/75102] Fetching: jenkinsci/deploy-plugin
# 🔍 [818/75102] Fetching: bogeblad/infoglue
# 🔍 [819/75102] Fetching: metapirate/LimeWire-Pirate-Edition
# 🔍 [820/75102] Fetching: jenkinsci/xunit-plugin
# 🔍 [821/75102] Fetching: adrian/upm-android
# 🔍 [822/75102] Fetching: jenkinsci/parameterized-trigger-plugin
# 🔍 [823/75102] Fetching: jenkinsci/maven-hpi-plugin
# 🔍 [824/75102] Fetching: stephenfreund/RoadRunner
# 🔍 [825/75102] Fetching: jenkinsci/jclouds-plugin
# 🔍 [826/75102] Fetching: grahamedgecombe/lightstone
# 🔍 [827/75102] Fetching: AnderWeb/ADW.Theme-Template
# 🔍 [828/75102] Fetching: salaboy/emergency-service-drools-app
# 🔍 [829/75102] Fetching: jenkinsci/nodejs-plugin
# 🔍 [830/75102] Fetching: wernerd/Skein3Fish
# 🔍 [831/75102] Fetching: melix/asm-bytecode-intellij
# 🔍 [832/75102] Fetching: taoneill/war
# 🔍 [833/75102] Fetching: majidkh/MajBot
# 🔍 [834/75102] Fetching: jiro-aqua/Jota-Text-Editor-old
# 🔍 [835/75102] Fetching: kowshik/JPregel
# 🔍 [836/75102] Fetching: jenkinsci/msbuild-plugin
# 🔍 [837/75102] Fetching: jenkinsci/sbt-plugin
# 🔍 [838/75102] Fetching: jenkinsci/copyartifact-plugin
# 🔍 [839/75102] Fetching: jenkinsci/testng-plugin-plugin
# 🔍 [840/75102] Fetching: dennisjzh/GwtMobile-UI
# 🔍 [841/75102] Fetching: saileshmittal/phonegap-system-notification-plugin
# 🔍 [842/75102] Fetching: jenkinsci/plot-plugin
# 🔍 [843/75102] Fetching: steos/jnafilechooser
# 🔍 [844/75102] Fetching: MarkyVasconcelos/Towel
# 🔍 [845/75102] Fetching: dustismo/TrendrrBeanstalk
# 🔍 [846/75102] Fetching: Bukkit/ScrapBukkit
# 🔍 [847/75102] Fetching: validator/htmlparser
# 🔍 [848/75102] Fetching: dennisjzh/GwtMobile-PhoneGap
# 🔍 [849/75102] Fetching: mportuesisf/ScreenInfo
# 🔍 [850/75102] Fetching: tbuser/spinscan
# 🔍 [851/75102] Fetching: jenkinsci/mercurial-plugin
# 🔍 [852/75102] Fetching: ocpsoft/prettyfaces
# 🔍 [853/75102] Fetching: jenkinsci/log-parser-plugin
# 🔍 [854/75102] Fetching: jenkinsci/perforce-plugin
# 🔍 [855/75102] Fetching: jenkinsci/violations-plugin
# 🔍 [856/75102] Fetching: ybonnel/TransportsRennes
# 🔍 [857/75102] Fetching: jenkinsci/ssh-plugin
# 🔍 [858/75102] Fetching: ogrisel/paper2ebook
# 🔍 [859/75102] Fetching: jenkinsci/job-config-history-plugin
# 🔍 [860/75102] Fetching: jenkinsci/active-directory-plugin
# 🔍 [861/75102] Fetching: vanevery/Pro-Android-Media
# 🔍 [862/75102] Fetching: xbmc/xbmc
# 🔍 [863/75102] Fetching: cocos2d/cocos2d-x
# 🔍 [864/75102] Fetching: mosra/magnum
# 🔍 [865/75102] Fetching: Benjamin-Dobell/Heimdall
# 🔍 [866/75102] Fetching: andoma/movian
# 🔍 [867/75102] Fetching: aria2/aria2
# 🔍 [868/75102] Fetching: json-c/json-c
# 🔍 [869/75102] Fetching: adamfisk/LittleProxy
# 🔍 [870/75102] Fetching: moritz-wundke/Boost-for-Android
# 🔍 [871/75102] Fetching: brinley/jSignature
# 🔍 [872/75102] Fetching: louisremi/jquery.transition.js
# 🔍 [873/75102] Fetching: techatspree/jquery-toastmessage-plugin
# 🔍 [874/75102] Fetching: dotmaster/Touchable-jQuery-Plugin
# 🔍 [875/75102] Fetching: sirthias/BlueForest
# 🔍 [876/75102] Fetching: julianshen/ScreenCap
# 🔍 [877/75102] Fetching: julienr/libpng-android
# 🔍 [878/75102] Fetching: praeclarum/CrossGraphics
# 🔍 [879/75102] Fetching: theshock/atomjs
# 🔍 [880/75102] Fetching: randyjensen/handcrafted-wp-theme
# 🔍 [881/75102] Fetching: vranki/ExtPlane
# 🔍 [882/75102] Fetching: glennjones/microformat-shiv
# 🔍 [883/75102] Fetching: bowler-framework/Bowler
# 🔍 [884/75102] Fetching: vranki/ExtPlane-Panel
# 🔍 [885/75102] Fetching: davebalmer/turtlewax
# 🔍 [886/75102] Fetching: laukstein/ajax-seo
# 🔍 [887/75102] Fetching: swdunlop/WaspVM
# 🔍 [888/75102] Fetching: koush/sqlite-net
# 🔍 [889/75102] Fetching: urbanairship/python-library
# 🔍 [890/75102] Fetching: CyanogenMod/android_device_samsung_crespo
# 🔍 [891/75102] Fetching: julienr/libzip-android
# 🔍 [892/75102] Fetching: intervigilium/liblame
# 🔍 [893/75102] Fetching: coolya/android_kernel_samsung
# 🔍 [894/75102] Fetching: amro/c2dm
# 🔍 [895/75102] Fetching: CyanogenMod/android_hardware_qcom_media
# 🔍 [896/75102] Fetching: nelhage/reverse-android
# 🔍 [897/75102] Fetching: tmzt/androix-xserver
# 🔍 [898/75102] Fetching: thunderbird/thunderbird-android
# 🔍 [899/75102] Fetching: JetBrains/ideavim
# 🔍 [900/75102] Fetching: android-async-http/android-async-http
# 🔍 [901/75102] Fetching: json-path/JsonPath
# 🔍 [902/75102] Fetching: dropwizard/dropwizard
# 🔍 [903/75102] Fetching: AsyncHttpClient/async-http-client
# 🔍 [904/75102] Fetching: apache/incubator-kie-drools
# 🔍 [905/75102] Fetching: osmandapp/OsmAnd
# 🔍 [906/75102] Fetching: grantland/android-autofittextview
# 🔍 [907/75102] Fetching: MovingBlocks/Terasology
# 🔍 [908/75102] Fetching: apache/incubator-kie-optaplanner
# 🔍 [909/75102] Fetching: sqlcipher/android-database-sqlcipher
# 🔍 [910/75102] Fetching: plantuml/plantuml-server
# 🔍 [911/75102] Fetching: slapperwan/gh4a
# 🔍 [912/75102] Fetching: git-commit-id/git-commit-id-maven-plugin
# 🔍 [913/75102] Fetching: jnr/jnr-ffi
# 🔍 [914/75102] Fetching: loopj/android-smart-image-view
# 🔍 [915/75102] Fetching: ushahidi/SMSSync
# 🔍 [916/75102] Fetching: xwiki/xwiki-platform
# 🔍 [917/75102] Fetching: carrotsearch/hppc
# 🔍 [918/75102] Fetching: atilika/kuromoji
# 🔍 [919/75102] Fetching: codebutler/farebot
# 🔍 [920/75102] Fetching: tomighty/tomighty
# 🔍 [921/75102] Fetching: webbit/webbit
# 🔍 [922/75102] Fetching: structr/structr
# 🔍 [923/75102] Fetching: killme2008/xmemcached
# 🔍 [924/75102] Fetching: matyb/java-koans
# 🔍 [925/75102] Fetching: BaseXdb/basex
# 🔍 [926/75102] Fetching: attenzione/android-ColorPickerPreference
# 🔍 [927/75102] Fetching: jbellis/jamm
# 🔍 [928/75102] Fetching: gresrun/jesque
# 🔍 [929/75102] Fetching: spring-projects/spring-amqp-samples
# 🔍 [930/75102] Fetching: marhan/effective-java-examples
# 🔍 [931/75102] Fetching: lorensiuswlt/NewQuickAction
# 🔍 [932/75102] Fetching: nathanmarz/elephantdb
# 🔍 [933/75102] Fetching: halfhp/androidplot
# 🔍 [934/75102] Fetching: taweili/ardublock
# 🔍 [935/75102] Fetching: orphan-oss/launch4j-maven-plugin
# 🔍 [936/75102] Fetching: broo2s/brut.apktool
# 🔍 [937/75102] Fetching: peichhorn/lombok-pg
# 🔍 [938/75102] Fetching: anismiles/websocket-android-phonegap
# 🔍 [939/75102] Fetching: hibernate/hibernate-tools
# 🔍 [940/75102] Fetching: helun/Ektorp
# 🔍 [941/75102] Fetching: jzachr/goldenorb
# 🔍 [942/75102] Fetching: shiffman/Box2D-for-Processing
# 🔍 [943/75102] Fetching: jnr/jnr-unixsocket
# 🔍 [944/75102] Fetching: kiegroup/droolsjbpm-integration
# 🔍 [945/75102] Fetching: cschneider/Karaf-Tutorial
# 🔍 [946/75102] Fetching: sporst/SWFREtools
# 🔍 [947/75102] Fetching: SonarSource/sonarlint-eclipse
# 🔍 [948/75102] Fetching: thucydides-webtests/thucydides
# 🔍 [949/75102] Fetching: ning/jvm-compressor-benchmark
# 🔍 [950/75102] Fetching: ModeShape/modeshape
# 🔍 [951/75102] Fetching: mojo-executor/mojo-executor
# 🔍 [952/75102] Fetching: xebialabs/overthere
# 🔍 [953/75102] Fetching: locationtech/udig-platform
# 🔍 [954/75102] Fetching: jsvazic/GAHelloWorld
# 🔍 [955/75102] Fetching: t0xa/gelfj
# 🔍 [956/75102] Fetching: petedoyle/android-support-v4-googlemaps
# 🔍 [957/75102] Fetching: SonarSource/sonar-scanner-jenkins
# 🔍 [958/75102] Fetching: cloudsmith/geppetto
# 🔍 [959/75102] Fetching: BasLeijdekkers/MetricsReloaded
# 🔍 [960/75102] Fetching: ysamlan/horizontalpager
# 🔍 [961/75102] Fetching: GregBowyer/ManagedRuntimeInitiative
# 🔍 [962/75102] Fetching: operasoftware/operaprestodriver
# 🔍 [963/75102] Fetching: cpesch/RouteConverter
# 🔍 [964/75102] Fetching: luugiathuy/Remote-Bluetooth-Android
# 🔍 [965/75102] Fetching: sandsmark/QuasselDroid
# 🔍 [966/75102] Fetching: hudson/hudson-2.x
# 🔍 [967/75102] Fetching: jfrog/build-info
# 🔍 [968/75102] Fetching: EngineHub/CommandBook
# 🔍 [969/75102] Fetching: s4/s4
# 🔍 [970/75102] Fetching: ceylon/ceylon-compiler
# 🔍 [971/75102] Fetching: picocontainer/picocontainer
# 🔍 [972/75102] Fetching: tinkerpop/frames
# 🔍 [973/75102] Fetching: rjmarsan/Weka-for-Android
# 🔍 [974/75102] Fetching: zznate/cassandra-tutorial
# 🔍 [975/75102] Fetching: carrotsearch/smartsprites
# 🔍 [976/75102] Fetching: ctran/TinyRadius
# 🔍 [977/75102] Fetching: EngineHub/CommandHelper
# 🔍 [978/75102] Fetching: jenkinsci/publish-over-ssh-plugin
# 🔍 [979/75102] Fetching: mway-io/titanium-barcode
# 🔍 [980/75102] Fetching: xwiki-attic/xwiki-enterprise
# 🔍 [981/75102] Fetching: stepinto/android-sshd
# 🔍 [982/75102] Fetching: cederberg/mibble
# 🔍 [983/75102] Fetching: bio4j/bio4j
# 🔍 [984/75102] Fetching: GadgetFactory/OpenBench-Logic-Sniffer
# 🔍 [985/75102] Fetching: tbuktu/ntru
# 🔍 [986/75102] Fetching: kiegroup/droolsjbpm-knowledge
# 🔍 [987/75102] Fetching: jalkanen/speed4j
# 🔍 [988/75102] Fetching: twitwi/AndroidDnssdDemo
# 🔍 [989/75102] Fetching: Awful/Awful.apk
# 🔍 [990/75102] Fetching: lorensiuswlt/AndroidTwitter
# 🔍 [991/75102] Fetching: arquillian/arquillian-graphene
# 🔍 [992/75102] Fetching: Morlok8k/MinecraftLandGenerator
# 🔍 [993/75102] Fetching: sebhoerl/Twig-netbeans
# 🔍 [994/75102] Fetching: r5v9/persist
# 🔍 [995/75102] Fetching: irssiconnectbot/irssiconnectbot
# 🔍 [996/75102] Fetching: gemserk/artemis
# 🔍 [997/75102] Fetching: martinadamek/json-android-compare
# 🔍 [998/75102] Fetching: xwiki/xwiki-commons
# 🔍 [999/75102] Fetching: docusign/docusign-soap-sdk
# 🔍 [1000/75102] Fetching: jlewallen/jenkins-hipchat-plugin
# 🔍 [1001/75102] Fetching: rtyley/spongycastle-old
# 🔍 [1002/75102] Fetching: neo4j-attic/graphdb
# 🔍 [1003/75102] Fetching: arnaudroques/maven-plantuml-plugin
# 🔍 [1004/75102] Fetching: jsievers/tycho-demo
# 🔍 [1005/75102] Fetching: lemire/rollinghashjava
# 🔍 [1006/75102] Fetching: graniteds/graniteds
# 🔍 [1007/75102] Fetching: iConomy/Core
# 🔍 [1008/75102] Fetching: CyanogenMod/android_packages_apps_Calendar
# 🔍 [1009/75102] Fetching: nickfox/Update-Android-UI-from-a-Service
# 🔍 [1010/75102] Fetching: xwiki/xwiki-rendering
# 🔍 [1011/75102] Fetching: mogo29/Android-RTMP
# 🔍 [1012/75102] Fetching: luontola/jumi
# 🔍 [1013/75102] Fetching: krestenkrab/bitcask-java
# 🔍 [1014/75102] Fetching: yigiter/Demo6DoF
# 🔍 [1015/75102] Fetching: EmiteGWT/emite
# 🔍 [1016/75102] Fetching: apache/openwebbeans
# 🔍 [1017/75102] Fetching: dreamcat4/CmdMessenger2
# 🔍 [1018/75102] Fetching: miracle2k/android-platform_sdk
# 🔍 [1019/75102] Fetching: jnr/jnr-x86asm
# 🔍 [1020/75102] Fetching: guyboertje/jrjackson
# 🔍 [1021/75102] Fetching: akiraly/cage
# 🔍 [1022/75102] Fetching: salaboy/Drools_jBPM5-Training-Examples
# 🔍 [1023/75102] Fetching: jboss-switchyard/quickstarts
# 🔍 [1024/75102] Fetching: SimonKagstrom/despotify
# 🔍 [1025/75102] Fetching: grantland/android-verticalpager
# 🔍 [1026/75102] Fetching: luugiathuy/Java-Download-Manager
# 🔍 [1027/75102] Fetching: mifos/head
# 🔍 [1028/75102] Fetching: gimite/android-native-exe-demo
# 🔍 [1029/75102] Fetching: scribble/scribble-java
# 🔍 [1030/75102] Fetching: marcelo-mason/PreciousStones
# 🔍 [1031/75102] Fetching: loopj/airbrake-android
# 🔍 [1032/75102] Fetching: killme2008/hs4j
# 🔍 [1033/75102] Fetching: jexp/neo4j-clean-remote-db-addon
# 🔍 [1034/75102] Fetching: OpenMEAP/OpenMEAP
# 🔍 [1035/75102] Fetching: bekkopen/jetty-pkg
# 🔍 [1036/75102] Fetching: OlegKrikun/S2E
# 🔍 [1037/75102] Fetching: pstehlik/gelf4j
# 🔍 [1038/75102] Fetching: jhasse/jngl
# 🔍 [1039/75102] Fetching: ageneau/ecl-android
# 🔍 [1040/75102] Fetching: getlantern/lantern
# 🔍 [1041/75102] Fetching: OpenMathLib/OpenBLAS
# 🔍 [1042/75102] Fetching: red/red
# 🔍 [1043/75102] Fetching: ServiceStack/ServiceStack
# 🔍 [1044/75102] Fetching: ilius/pyglossary
# 🔍 [1045/75102] Fetching: Yaffle/EventSource
# ...
# 🔍 [74800/75102] Fetching: betingrich3/Mercedes
# 🔍 [74801/75102] Fetching: uyez/v2ray
# 🔍 [74802/75102] Fetching: holyshell/AppsForMac
# 🔍 [74803/75102] Fetching: hfdem/android_gki_kernel_5.15_common
# 🔍 [74804/75102] Fetching: styluslabs/Write
# 🔍 [74805/75102] Fetching: evergrace-co/react-native-audio-pro
# 🔍 [74806/75102] Fetching: mehedihjoy0/GPhotos-Unlimited
# 🔍 [74807/75102] Fetching: FinAegis/core-banking-prototype-laravel
# 🔍 [74808/75102] Fetching: Freddywhest/MemeFiBot-New
# 🔍 [74809/75102] Fetching: SeidSmatti/redditUntranslate
# 🔍 [74810/75102] Fetching: LatiteClient/Latite
# 🔍 [74811/75102] Fetching: dov/r36s-programming
# 🔍 [74812/75102] Fetching: APMMDEVS/RootManageModuleModel
# 🔍 [74813/75102] Fetching: HomoArk/Homogram
# 🔍 [74814/75102] Fetching: MoWei-2077/CPU-speed-controller
# 🔍 [74815/75102] Fetching: zhi888459/SSV2RayTrojanClashSSR
# 🔍 [74816/75102] Fetching: uber/RIBs-iOS
# 🔍 [74817/75102] Fetching: moonshine-ai/qc_npu_benchmark
# 🔍 [74818/75102] Fetching: mouredev/dia-de-la-programacion-web
# 🔍 [74819/75102] Fetching: vova7878-modules/PaySecurityBypass
# 🔍 [74820/75102] Fetching: YorkieDev/LMStudioWebUI
# 🔍 [74821/75102] Fetching: DeepSoftwareAnalytics/Awesome-Agent4SE
# 🔍 [74822/75102] Fetching: 5ec1cff/ZygiskNextModuleSample
# 🔍 [74823/75102] Fetching: freev2rayclash/freev2rayclash.github.io
# 🔍 [74824/75102] Fetching: SuperLlama88888/holoprint
# 🔍 [74825/75102] Fetching: BillyDM/Firewheel
# 🔍 [74826/75102] Fetching: vanhbakaa/Cexio-Tap-bot
# 🔍 [74827/75102] Fetching: celenityy/Phoenix
# 🔍 [74828/75102] Fetching: mathe00/obsidian-plugin-python-bridge
# 🔍 [74829/75102] Fetching: tun-rs/tun-rs
# 🔍 [74830/75102] Fetching: vanhbakaa/Seed-App-Mine-Seed-BOT-Telegram
# 🔍 [74831/75102] Fetching: friuns2/appforge
# 🔍 [74832/75102] Fetching: getsentry/sentry-godot
# 🔍 [74833/75102] Fetching: StephanArnas/CraftUI
# 🔍 [74834/75102] Fetching: Jman-Github/Awesome-ReVanced
# 🔍 [74835/75102] Fetching: dwongdev/sugoi-supernote
# 🔍 [74836/75102] Fetching: rix4uni/medium-writeups
# 🔍 [74837/75102] Fetching: SCA-OAU/LearnLink
# 🔍 [74838/75102] Fetching: ri-char/zygisk-dump-dex
# 🔍 [74839/75102] Fetching: CyberAlbSecOP/Awesome_Hacking_Apps_for_Android
# 🔍 [74840/75102] Fetching: OpenIPC/PixelPilot
# 🔍 [74841/75102] Fetching: ir-engine/ir-engine
# 🔍 [74842/75102] Fetching: YarmolenkoD/boinkers
# 🔍 [74843/75102] Fetching: princeton-computational-imaging/NeuLS
# 🔍 [74844/75102] Fetching: lingvanex-mt/models
# 🔍 [74845/75102] Fetching: LuanRT/googlevideo
# 🔍 [74846/75102] Fetching: vanhbakaa/Fabrika-Friends-Factory
# 🔍 [74847/75102] Fetching: shouryashashank/Trackster
# 🔍 [74848/75102] Fetching: androidoffsec/libdevbinder
# 🔍 [74849/75102] Fetching: timmitra/visionosresources
# 🔍 [74850/75102] Fetching: 1999AZZAR/use-waydroid-on-x11
# 🔍 [74851/75102] Fetching: CyberAlbSecOP/Awesome_Free_Online_SOC_And_Pentest_Tools
# 🔍 [74852/75102] Fetching: GravelFire/CatsGangBot
# 🔍 [74853/75102] Fetching: EvanBacon/expo-apple-colors
# 🔍 [74854/75102] Fetching: fredrikburmester/marlin-search
# 🔍 [74855/75102] Fetching: chemharuka/toGainMapHDR
# 🔍 [74856/75102] Fetching: rookidroid/hexapod
# 🔍 [74857/75102] Fetching: m13v/whatsapp2llm
# 🔍 [74858/75102] Fetching: HassanChowdhry/Canadian-Tech-Internships-2025
# 🔍 [74859/75102] Fetching: JMBQ/azurlane
# 🔍 [74860/75102] Fetching: zjkhahah/HivisionIDPhotos-cpp
# 🔍 [74861/75102] Fetching: ZeromaXHe/ZeromaX-s-Playground
# 🔍 [74862/75102] Fetching: AndroidGODev/Bad-Google-Play
# 🔍 [74863/75102] Fetching: empirical-run/appwright
# 🔍 [74864/75102] Fetching: Galaxies-dev/threads-clone-react-native
# 🔍 [74865/75102] Fetching: Victor2266/The-Fluid-Toy
# 🔍 [74866/75102] Fetching: shahriarsajeeb/Artifonia
# 🔍 [74867/75102] Fetching: JPeterMugaas/TaurusTLS
# 🔍 [74868/75102] Fetching: p120s/aviator-predictor-apk
# 🔍 [74869/75102] Fetching: muhammadrizwan87/sigtool
# 🔍 [74870/75102] Fetching: Poeschl-HomeAssistant-Addons/repository
# 🔍 [74871/75102] Fetching: XForYouX/Uzuy-Android-10
# 🔍 [74872/75102] Fetching: maoist2009/TlsFragment
# 🔍 [74873/75102] Fetching: atamshkai/Phantom-Process-Killer
# 🔍 [74874/75102] Fetching: MjeedBakr/Student-Success-Kit
# 🔍 [74875/75102] Fetching: IGuanggg/Some-Stars-Main
# 🔍 [74876/75102] Fetching: AshkanArabim/newsbridge
# 🔍 [74877/75102] Fetching: wgslfuzz/darthshader
# 🔍 [74878/75102] Fetching: silbinarywolf/zig-android-sdk
# 🔍 [74879/75102] Fetching: Willie169/Android-Non-Root
# 🔍 [74880/75102] Fetching: eric-pierce/freshapi
# 🔍 [74881/75102] Fetching: silvioviscuso/nova34
# 🔍 [74882/75102] Fetching: hopeforsenegal/com.moonlitstudios.immediatestyle
# 🔍 [74883/75102] Fetching: Faceplugin-ltd/Face-Recognition-SDK
# 🔍 [74884/75102] Fetching: heng30/slint-template
# 🔍 [74885/75102] Fetching: ToniDarodda/react-native-template
# 🔍 [74886/75102] Fetching: MollySophia/rwkv-mobile
# 🔍 [74887/75102] Fetching: punkpeye/awesome-mcp-servers
# 🔍 [74888/75102] Fetching: modelcontextprotocol/servers
# 🔍 [74889/75102] Fetching: blinkospace/blinko
# 🔍 [74890/75102] Fetching: wong2/awesome-mcp-servers
# 🔍 [74891/75102] Fetching: guoyue2010/lxmusic-
# 🔍 [74892/75102] Fetching: SheepChef/Abracadabra
# 🔍 [74893/75102] Fetching: likuai2010/auto-installer
# 🔍 [74894/75102] Fetching: bst04/CyberSources
# 🔍 [74895/75102] Fetching: amclubs/am-cf-tunnel
# 🔍 [74896/75102] Fetching: EinGuterWaran/awesome-opensource-boilerplates
# 🔍 [74897/75102] Fetching: mustbeperfect/definitive-opensource
# 🔍 [74898/75102] Fetching: 1q23lyc45/KitsuneMagisk
# 🔍 [74899/75102] Fetching: Tanq16/ExpenseOwl
# 🔍 [74900/75102] Fetching: Lizonghang/prima.cpp
# 🔍 [74901/75102] Fetching: jbikker/tinybvh
# 🔍 [74902/75102] Fetching: saulamsal/react-native-sheet-transitions
# 🔍 [74903/75102] Fetching: callstackincubator/cali
# 🔍 [74904/75102] Fetching: privastead/privastead
# 🔍 [74905/75102] Fetching: alangrainger/immich-public-proxy
# 🔍 [74906/75102] Fetching: software-mansion/react-native-executorch
# 🔍 [74907/75102] Fetching: EmptyLibra/Configure-Xray-with-VLESS-Reality-on-VPS-server
# 🔍 [74908/75102] Fetching: kilvn/iptv
# 🔍 [74909/75102] Fetching: XiaomingX/1000-chinese-independent-developer-plus
# 🔍 [74910/75102] Fetching: ArcSurge/Termius-Pro-zh_CN
# 🔍 [74911/75102] Fetching: leonboe1/GoogleFindMyTools
# 🔍 [74912/75102] Fetching: dongyubin/Baidu-VIP
# 🔍 [74913/75102] Fetching: luestr/ShuntRules
# 🔍 [74914/75102] Fetching: za515217965/OKBrowser
# 🔍 [74915/75102] Fetching: ChaosJulien/XiaoYuanKouSuan_Auto
# 🔍 [74916/75102] Fetching: howmp/reality
# 🔍 [74917/75102] Fetching: jaywcjlove/awesome-swift-macos-apps
# 🔍 [74918/75102] Fetching: allenai/molmo
# 🔍 [74919/75102] Fetching: DevLARLEY/WidevineProxy2
# 🔍 [74920/75102] Fetching: InputShare/InputShare
# 🔍 [74921/75102] Fetching: OSU-NLP-Group/GUI-Agents-Paper-List
# 🔍 [74922/75102] Fetching: ranpox/awesome-computer-use
# 🔍 [74923/75102] Fetching: connet-dev/connet
# 🔍 [74924/75102] Fetching: lscambo13/ElegantFin
# 🔍 [74925/75102] Fetching: stevendborrelli/bluesky-tech-starter-packs
# 🔍 [74926/75102] Fetching: djylb/nps
# 🔍 [74927/75102] Fetching: open-vela/docs
# 🔍 [74928/75102] Fetching: saulamsal/apple-music-sheet-ui
# 🔍 [74929/75102] Fetching: saulamsal/apple-news-ui
# 🔍 [74930/75102] Fetching: askui/vision-agent
# 🔍 [74931/75102] Fetching: xlang-ai/aguvis
# 🔍 [74932/75102] Fetching: xmexg/xyks
# 🔍 [74933/75102] Fetching: zanjie1999/meDisplay
# 🔍 [74934/75102] Fetching: winebox64/winlator
# 🔍 [74935/75102] Fetching: ProtocolScience/AstralGocq
# 🔍 [74936/75102] Fetching: liuzq2002/Adguard-Home-For-Magisk-Mod
# 🔍 [74937/75102] Fetching: Freedom-Guard/Freedom-Guard
# 🔍 [74938/75102] Fetching: secureworks/pytune
# 🔍 [74939/75102] Fetching: sinspired/cnNetTool
# 🔍 [74940/75102] Fetching: dedsec1121fk/DedSec
# 🔍 [74941/75102] Fetching: MakersFunDuck/humidity-temperature-sensor-TH05F
# 🔍 [74942/75102] Fetching: SohelIslamImran/expo-in-app-updates
# 🔍 [74943/75102] Fetching: ente0/hashCrack
# 🔍 [74944/75102] Fetching: Alan-Rock-GS/GpuScript
# 🔍 [74945/75102] Fetching: cnwikee/CheckTMDB
# 🔍 [74946/75102] Fetching: hsa00000/Urocissa
# 🔍 [74947/75102] Fetching: danmindru/rare-big-deal
# 🔍 [74948/75102] Fetching: ifokeev/awesome-copilots
# 🔍 [74949/75102] Fetching: Sgyling/Free-proxy-pool
# 🔍 [74950/75102] Fetching: Luboy23/foundry_advanced_turtorial
# 🔍 [74951/75102] Fetching: nianticlabs/mvsanywhere
# 🔍 [74952/75102] Fetching: NRTnarathip/SMAPILoader
# 🔍 [74953/75102] Fetching: LightQuanta/BiliResourceDownloader
# 🔍 [74954/75102] Fetching: RockinChaos/Shiru
# 🔍 [74955/75102] Fetching: shahriarsajeeb/Becodemy-Mobile-App
# 🔍 [74956/75102] Fetching: vyokky/LLM-Brained-GUI-Agents-Survey
# 🔍 [74957/75102] Fetching: andrew-levy/jetpack-compose-react-native
# 🔍 [74958/75102] Fetching: ugurkocde/IntuneBrew
# 🔍 [74959/75102] Fetching: travisvn/obsidian-edge-tts
# 🔍 [74960/75102] Fetching: zebangeth/ai-closet
# 🔍 [74961/75102] Fetching: takushun-wu/WenYuanFonts
# 🔍 [74962/75102] Fetching: dev-Ali2008/xanite
# 🔍 [74963/75102] Fetching: EasyDarwin/EasyPlayer.js
# 🔍 [74964/75102] Fetching: Pixel-Props/sensitive-props
# 🔍 [74965/75102] Fetching: AumGupta/KWGT-Widgets
# 🔍 [74966/75102] Fetching: navaismo/Ender-3V3-SE
# 🔍 [74967/75102] Fetching: zouyee/zig-learning
# 🔍 [74968/75102] Fetching: chinavpns/router-vpn
# 🔍 [74969/75102] Fetching: In3tinct/Androidmeda
# 🔍 [74970/75102] Fetching: AvenCores/goida-vpn-configs
# 🔍 [74971/75102] Fetching: liuk7071/ChonkyStation3
# 🔍 [74972/75102] Fetching: galaxy-s10/billd-desk-server
# 🔍 [74973/75102] Fetching: WildKernels/OnePlus_KernelSU_SUSFS
# 🔍 [74974/75102] Fetching: jfversluis/built-with-maui
# 🔍 [74975/75102] Fetching: osamaqarem/drag-select
# 🔍 [74976/75102] Fetching: xtfjt1988/learn-tech
# 🔍 [74977/75102] Fetching: meta-quest/webxr-first-steps-react
# 🔍 [74978/75102] Fetching: FFTAI/teleoperation
# 🔍 [74979/75102] Fetching: RustNSparks/sockudo
# 🔍 [74980/75102] Fetching: Katana-O/MobileGamePenetrationTestingFramework
# 🔍 [74981/75102] Fetching: Ivy-Apps/android-guidebook
# 🔍 [74982/75102] Fetching: ImMALWARE/zapret-magisk
# 🔍 [74983/75102] Fetching: animate-react-native/accordion
# 🔍 [74984/75102] Fetching: yshmarov/hotwire_native_rails
# 🔍 [74985/75102] Fetching: GoodyOG/Iceraven-OLED
# 🔍 [74986/75102] Fetching: Galaxies-dev/todoist-clone-react-native
# 🔍 [74987/75102] Fetching: List-KR/tinyShield
# 🔍 [74988/75102] Fetching: typeconf/typeconf
# 🔍 [74989/75102] Fetching: trend-ui/trendui-react-native
# 🔍 [74990/75102] Fetching: abshare3/abshare3.github.io
# 🔍 [74991/75102] Fetching: peditx/EZpasswall
# 🔍 [74992/75102] Fetching: chinavpns/chatgpt-plus
# 🔍 [74993/75102] Fetching: manio/aa-proxy-rs
# 🔍 [74994/75102] Fetching: donkuri/japanese-resources
# 🔍 [74995/75102] Fetching: drbarzaga/React-Toolkit
# 🔍 [74996/75102] Fetching: trakt/trakt-lite
# 🔍 [74997/75102] Fetching: xvnpw/ai-security-analyzer
# 🔍 [74998/75102] Fetching: nyeinkokoaung404/V2ray-Configs
# 🔍 [74999/75102] Fetching: erosman/firemonkey
# 🔍 [75000/75102] Fetching: hardenedlinux/userland-exec
# 🔍 [75001/75102] Fetching: nieheyong/logcat-in-devtools
# 🔍 [75002/75102] Fetching: erfanmola/TMA-Studio
# 🔍 [75003/75102] Fetching: dermv/marzbanify-template
# 🔍 [75004/75102] Fetching: MeoMunDep/Automatic-Ultimate-Create-Wallets-for-Airdrop
# 🔍 [75005/75102] Fetching: avoylenko/wwebjs-api
# 🔍 [75006/75102] Fetching: Raphael-Boichot/The-TinyGB-Printer
# 🔍 [75007/75102] Fetching: ericclemmons/awesome-starter-packs
# 🔍 [75008/75102] Fetching: MnlPhlp/tauri-plugin-blec
# 🔍 [75009/75102] Fetching: ikoyhn/clean-cast
# 🔍 [75010/75102] Fetching: kukuqi666/TVBoxOS-Mobile
# 🔍 [75011/75102] Fetching: Ericcsr/ARCap
# 🔍 [75012/75102] Fetching: xiaotujinbnb/QBDI_trace_demo
# 🔍 [75013/75102] Fetching: MLSZHU/LLMSafetyBenchmark
# 🔍 [75014/75102] Fetching: OpenMined/30DaysOfFLCode
# 🔍 [75015/75102] Fetching: vfdeclnc/panda-vpn-pro
# 🔍 [75016/75102] Fetching: DonBraulio/tuneo
# 🔍 [75017/75102] Fetching: RaffaDNDM/HacknDroid
# 🔍 [75018/75102] Fetching: AxellNetwork/NekoBot
# 🔍 [75019/75102] Fetching: nativeapptemplate/NativeAppTemplate-Free-iOS
# 🔍 [75020/75102] Fetching: VidraProject/Vidra-Project
# 🔍 [75021/75102] Fetching: Preloading/TwitterAPIBridge
# 🔍 [75022/75102] Fetching: morrownr/rtl8852bu-20240418
# 🔍 [75023/75102] Fetching: gmankab/waydroid
# 🔍 [75024/75102] Fetching: RuriOSS/asl
# 🔍 [75025/75102] Fetching: Magisk-Modules-Alt-Repo/Xtreme-Battery-Saver
# 🔍 [75026/75102] Fetching: westonganger/rails_local_analytics
# 🔍 [75027/75102] Fetching: greatfrontend/black-friday-cyber-monday-deals
# 🔍 [75028/75102] Fetching: StayRealHQ/Universal
# 🔍 [75029/75102] Fetching: vin3110/facecheck.id-results-extractor
# 🔍 [75030/75102] Fetching: Magisk-Modules-Alt-Repo/video-to-bootanimation
# 🔍 [75031/75102] Fetching: wyp010428/xiaoyuankousuan
# 🔍 [75032/75102] Fetching: Pilfer/heresy
# 🔍 [75033/75102] Fetching: utkabobr/SliceBeam
# 🔍 [75034/75102] Fetching: vanhbakaa/Blum
# 🔍 [75035/75102] Fetching: bohonghuang/org-srs
# 🔍 [75036/75102] Fetching: s1ntoneli/Awesome-Black-Friday-Cyber-Monday-for-Mac-Apps
# 🔍 [75037/75102] Fetching: eimg/spata
# 🔍 [75038/75102] Fetching: PhiZone/player
# 🔍 [75039/75102] Fetching: EvanBacon/expo-stock-widget-example
# 🔍 [75040/75102] Fetching: xiaou61/XiaoYuanKousuan
# 🔍 [75041/75102] Fetching: ViewTurbo/ViewTurbo
# 🔍 [75042/75102] Fetching: browserbase/sdk-python
# 🔍 [75043/75102] Fetching: UbiquitousLearning/PhoneLM
# 🔍 [75044/75102] Fetching: aw-junaid/Computer-Science
# 🔍 [75045/75102] Fetching: jeffc/hassmic
# 🔍 [75046/75102] Fetching: hokkar/vpntochina
# 🔍 [75047/75102] Fetching: shobhakartiwari/iOS_Junior_Level_Interview_Questions
# 🔍 [75048/75102] Fetching: Numbersf/MakeFontsGreatAgain
# 🔍 [75049/75102] Fetching: bitcoin-flashing-software/Flash-BTC-apk
# 🔍 [75050/75102] Fetching: HubertRyanOfficial/google-gemini-app-clone
# 🔍 [75051/75102] Fetching: hackcatml/frida-watchpoint-tutorial
# 🔍 [75052/75102] Fetching: HappyHackingSpace/awesome-hackathon
# 🔍 [75053/75102] Fetching: wendell0218/GVA-Survey
# 🔍 [75054/75102] Fetching: OnePlusOSS/android_kernel_oneplus_sm8750
# 🔍 [75055/75102] Fetching: PIPIKAI/android-ncnn-yolo11
# 🔍 [75056/75102] Fetching: vanhbakaa/Paws
# 🔍 [75057/75102] Fetching: maduwatas/Vin-HkE
# 🔍 [75058/75102] Fetching: 5mdld/anki-jlpt-decks
# 🔍 [75059/75102] Fetching: JetBrains/mcp-jetbrains
# 🔍 [75060/75102] Fetching: WildKernels/GKI_KernelSU_SUSFS
# 🔍 [75061/75102] Fetching: adrianhajdin/react_native-restate
# 🔍 [75062/75102] Fetching: futo-org/Grayjay.Desktop
# 🔍 [75063/75102] Fetching: BandarLabs/clickclickclick
# 🔍 [75064/75102] Fetching: ironfox-oss/IronFox
# 🔍 [75065/75102] Fetching: OS-Agent-Survey/OS-Agent-Survey
# 🔍 [75066/75102] Fetching: apappascs/mcp-servers-hub
# 🔍 [75067/75102] Fetching: pipecat-ai/gemini-webrtc-web-simple
# 🔍 [75068/75102] Fetching: LLeavesG/eBPFDexDumper
# 🔍 [75069/75102] Fetching: vincentnussbaum303/youtube-download
# 🔍 [75070/75102] Fetching: joinloops/loops-app
# 🔍 [75071/75102] Fetching: guohub8080/mtkit
# 🔍 [75072/75102] Fetching: OS-Copilot/OS-Genesis
# 🔍 [75073/75102] Fetching: avitsa/aviator-predictor
# 🔍 [75074/75102] Fetching: Ucekay/nitro-palette
# 🔍 [75075/75102] Fetching: a-chacon/chaski-app
# 🔍 [75076/75102] Fetching: betomoedano/groceries-shopping-list-app
# 🔍 [75077/75102] Fetching: MyShiLingStar/PCCE
# 🔍 [75078/75102] Fetching: timklge/awesome-karoo
# 🔍 [75079/75102] Fetching: xob0t/google_photos_mobile_client
# 🔍 [75080/75102] Fetching: yogeshpaliyal/awesome-mobile-system-design
# 🔍 [75081/75102] Fetching: joshuacant/ProjectTitle
# 🔍 [75082/75102] Fetching: MisterZtr/LineageOS_gsi
# 🔍 [75083/75102] Fetching: taisuii/rusda
# 🔍 [75084/75102] Fetching: 2468785842/krkr2
# 🔍 [75085/75102] Fetching: mendsalbert/medicine-reminder-app
# 🔍 [75086/75102] Fetching: PhoneLLM/Awesome-LLM-Powered-Phone-GUI-Agents
# 🔍 [75087/75102] Fetching: eindpunt/awesome-TRMNL
# 🔍 [75088/75102] Fetching: marcomq/tauri-plugin-python
# 🔍 [75089/75102] Fetching: drndos/openspoolman
# 🔍 [75090/75102] Fetching: TMLP-Team/keyboxGenerator
# 🔍 [75091/75102] Fetching: XiaomingX/awesome-docker
# 🔍 [75092/75102] Fetching: JSREI/awesome-protobuf-reverse-engineering
# 🔍 [75093/75102] Fetching: gucooing/BaPs
# 🔍 [75094/75102] Fetching: Touch-N-Stars/Touch-N-Stars
# 🔍 [75095/75102] Fetching: nginetechnologies/sceneri-common
# 🔍 [75096/75102] Fetching: ong19th/Torzu
# 🔍 [75097/75102] Fetching: letmeNo1/Cathin
# 🔍 [75098/75102] Fetching: galaxy-s10/billd-desk-admin
# 🔍 [75099/75102] Fetching: tjac/tsto_server
# 🔍 [75100/75102] Fetching: XiaomingX/1000-startup-idea-from-yc
# 🔍 [75101/75102] Fetching: aylhex/hegui_rom
# 🔍 [75102/75102] Fetching: suiyuanlixin/fas-rs-usage-clamping
#
# ✅ Fetch complete.

# %%
import os
import re
import pandas as pd

# === Base keywords for all checks ===
base_keywords = [
    'example', 'sample', 'demo', 'test', 'debug', 'presentation', 'module', 'components',
    'lib', 'library', 'sdk', 'utils', 'utility', 'plugin', 'widget', 'playground', 'framework',
    'architecture', 'skeleton', 'collection', 'starting point', 'protocol', 'benchmark', 'hackathon',
    'classroom', 'course', 'exercise', 'assignment', 'homework', 'assessment', 'interview', 'asset',
    'template', 'catalog', 'tutorial'
]

# === Keyword separation by target ===
manifest_keywords = base_keywords.copy()  # 'tool' not included here
non_manifest_keywords = base_keywords + ['tool']  # 'tool' added for repo name, description, README

preceded_by = ['this', 'is a', 'is an', 'our', 'my']
not_preceded_by = ['using', 'with']

def has_removal_context(text, k):
    if re.search(rf'(?<!\S){re.escape(k)}(?!\S)', text, re.IGNORECASE):
        if any(re.search(rf'(?<!\S){re.escape(w)}\s+(\S+\s+){{0,4}}{re.escape(k)}(?!\S)', text, re.IGNORECASE) for w in preceded_by):
            if not any(re.search(rf'{re.escape(n)}\s+(\S+\s+){{0,4}}{re.escape(k)}', text, re.IGNORECASE) for n in not_preceded_by):
                return True
    return False

# === Paths ===
base_dir = r"C:\Android Mobile App\Step1_URL_Search\Type_1_Searching_Pipeline_July 14"
input_path = os.path.join(base_dir, "step2_manifest_final_output.csv")
output_path = os.path.join(base_dir, "step3_removal_keyword_output.csv")
readme_dir = os.path.join(base_dir, "ReadmeFiles")
manifest_dir = os.path.join(base_dir, "ManifestPaths")

# === Load dataset ===
df = pd.read_csv(input_path)
for col in ["removal_keyword_flag", "removal_reason", "Valid_Repo_Step3"]:
    if col not in df.columns:
        df[col] = "none"

# === Analyze each repo ===
for idx, row in df.iterrows():
    if row["Valid_Repo_Step2"] != "yes" or row["Valid_Repo_Step3"] != "none":
        continue

    repo = '/'.join(row["html_url"].strip('/').split('/')[-2:])
    name = row["name"].lower() if pd.notna(row["name"]) else ""
    topics = str(row.get("topics", "")).lower()
    description = str(row.get("description", "")).lower()

    readme_path = os.path.join(readme_dir, repo.replace("/", "@") + ".md")
    manifest_path = os.path.join(manifest_dir, repo.replace("/", "@") + ".txt")
    readme = open(readme_path, encoding="utf-8").read() if os.path.exists(readme_path) else ""
    manifest_paths = open(manifest_path, encoding="utf-8").read().splitlines() if os.path.exists(manifest_path) else []

    reasons = []

    # === Manifest path match (without 'tool') — Pandas-style logic ===
    if any(
        any(k in path.lower() for k in manifest_keywords)
        for path in manifest_paths
    ):
        reasons.append("manifest_path")

    # === Repo name / topic match (with 'tool') ===
    if any(k in name for k in non_manifest_keywords) or any(k in topics for k in non_manifest_keywords):
        reasons.append("repo_name")

    # === Description contextual match ===
    if any(has_removal_context(description, k) for k in non_manifest_keywords):
        reasons.append("description")

    # === README contextual match ===
    if any(has_removal_context(readme, k) for k in non_manifest_keywords):
        reasons.append("readme")

    # === Save result ===
    flag = "yes" if reasons else "no"
    df.at[idx, "removal_keyword_flag"] = flag
    df.at[idx, "Valid_Repo_Step3"] = "no" if flag == "yes" else "yes"
    df.at[idx, "removal_reason"] = ", ".join(reasons) if reasons else "none"

# === Save results ===
df.to_csv(output_path, index=False)
print(f"✅ Analysis complete. Saved to: {output_path}")
# Out:
# ✅ Analysis complete. Saved to: C:\Android Mobile App\Step1_URL_Search\Type_1_Searching_Pipeline_July 14\step3_removal_keyword_output.csv
