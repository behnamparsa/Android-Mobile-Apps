# %% [markdown]
# - This code runs 5 independent base queries for seaching 3 languages and the keyword android once in the topic and once in the name, desc and readme
# - All 5 queries includes three common qualifier: stars:>50, fork:false and archived:false
# - Layer 1: Live Search - GitHub API
# - Layer 2: Local Filter - real-time Json (double Check the API detections)

# %%
import os
import re
import requests
import pandas as pd
import logging
from dotenv import load_dotenv
from datetime import datetime, timedelta
from time import sleep, time as now


# === LOGGING ===
logging.basicConfig(level=logging.INFO, format="[%(levelname)s] %(message)s")
logger = logging.getLogger(__name__)

# === CONFIG ===
output_dir = r"C:\Android Mobile App\Step1_URL_Search"
output_csv_all = os.path.join(output_dir, "github_android_search_results_all.csv")
output_csv_filtered = os.path.join(output_dir, "github_android_search_results_filtered.csv")

os.makedirs(output_dir, exist_ok=True)

# === AUTH ===
load_dotenv("All_Tokens.env")
tokens = [v for k, v in os.environ.items() if k.startswith("GITHUB_TOKEN_") and v]
if not tokens:
    raise ValueError("❌ No GitHub tokens found in All_Tokens.env")

token_index = 0
HEADERS = {
    "Authorization": f"token {tokens[token_index]}",
    "Accept": "application/vnd.github.mercy-preview+json",  # 🔥 includes topics
    "User-Agent": "android-repo-crawler/1.0"
}

# === DATE RANGE ===
start_date = datetime.strptime("2008-01-01", "%Y-%m-%d")
end_date = datetime.strptime("2024-12-31", "%Y-%m-%d")

# === WINDOW SETTINGS ===
initial_window_hours = 15 * 24  # 10 days
min_window_hours = 1
max_window_hours = 90 * 24
MAX_RESULTS_PER_QUERY = 1000
TARGET_FILL_RATIO = 0.25

# === BASE QUERIES ===
# Basis fully independent search for languages and keywords 
base_queries = [
    "stars:>50 language:Kotlin fork:false archived:false",
    "stars:>50 language:Java fork:false archived:false",
    "stars:>50 language:Dart fork:false archived:false",
    "stars:>50 topic:android fork:false archived:false",
    "stars:>50 android in:name,description,readme fork:false archived:false",
]


# === Filter ===
#rejected_items = []  # To store items returned by GitHub but filtered out

# def filter_item(item, expected_fork, expected_archived, expected_languages, expected_topic, expected_keyword): 
#     min_stars = 50
#     passed = True
#     rejection_reasons = []

#     language = (item.get('language') or '').lower()
#     topics = [t.lower() for t in item.get('topics', [])]
#     description = (item.get('description') or '').lower()
#     name = (item.get('name') or '').lower()
#     full_name = item.get("full_name", "")

#     if item.get('stargazers_count', 0) <= min_stars:
#         passed = False
#         rejection_reasons.append("Below minimum stars")
#     if item.get('fork', False) != expected_fork:
#         passed = False
#         rejection_reasons.append("Fork status mismatch")
#     if item.get('archived', False) != expected_archived:
#         passed = False
#         rejection_reasons.append("Archived status mismatch")

#     # ✅ Language check: now allows any in list + fallback to /languages
#     if expected_languages and language not in expected_languages:
#         try:
#             owner, repo = full_name.split("/")
#             lang_url = f"https://api.github.com/repos/{owner}/{repo}/languages"
#             lang_resp = requests.get(lang_url, headers=HEADERS, timeout=10)
#             if lang_resp.status_code == 200:
#                 langs = [k.lower() for k in lang_resp.json().keys()]
#                 if not any(lang in langs for lang in expected_languages):
#                     passed = False
#                     rejection_reasons.append(f"Language mismatch (expected one of: {', '.join(expected_languages)})")
#                 else:
#                     # Optional: set to first matching language
#                     for lang in expected_languages:
#                         if lang in langs:
#                             item["language"] = lang
#                             break
#             else:
#                 passed = False
#                 rejection_reasons.append("Language API fetch failed")
#         except Exception as e:
#             passed = False
#             rejection_reasons.append(f"Language fallback exception: {str(e)}")

#     if expected_topic and expected_topic not in topics:
#         passed = False
#         rejection_reasons.append("Missing topic: android")

#     if expected_keyword:
#         keyword = expected_keyword.lower()
#         if keyword not in name and keyword not in description:
#             try:
#                 owner, repo = full_name.split("/")
#                 readme_url = f"https://api.github.com/repos/{owner}/{repo}/readme"
#                 readme_headers = {
#                     "Authorization": f"token {tokens[token_index]}",
#                     "Accept": "application/vnd.github.v3.raw",
#                     "User-Agent": "android-repo-crawler/1.0"
#                 }
#                 r = requests.get(readme_url, headers=readme_headers, timeout=10)
#                 if r.status_code == 200:
#                     readme_text = r.text.lower()
#                     if not re.search(rf"\b{re.escape(keyword)}\b", readme_text, re.IGNORECASE):
#                         passed = False
#                         rejection_reasons.append(f"Keyword '{keyword}' not found in README (case-insensitive)")
#                 else:
#                     logger.warning(f"❌ README fetch failed ({r.status_code}) for {full_name}")
#                     passed = False
#             except Exception as e:
#                 passed = False
#                 rejection_reasons.append(f"README fetch exception: {str(e)}")

#     if not passed:
#         rejected_items.append({
#             "full_name": full_name,
#             "language": item.get("language"),
#             "description": item.get("description"),
#             "topics": item.get("topics"),
#             "stars": item.get("stargazers_count"),
#             "fork": item.get("fork"),
#             "archived": item.get("archived"),
#             "base_qualifier": item.get("base_qualifier", "N/A"),
#             "html_url": item.get("html_url"),
#             "rejection_reasons": "; ".join(rejection_reasons)
#         })

#     return passed



# === Token Rotate ===
def rotate_token():
    global token_index, HEADERS
    token_index = (token_index + 1) % len(tokens)
    HEADERS = {
        "Authorization": f"token {tokens[token_index]}",
        "Accept": "application/vnd.github.mercy-preview+json",
    }

    logger.warning(f"🔑 Rotated → Token #{token_index + 1} / {len(tokens)}")

# === Rate Limit ===
def check_rate_limit():
    r = requests.get("https://api.github.com/rate_limit", headers=HEADERS)
    if r.status_code != 200:
        logger.warning("⚠️  Could not check rate limit.")
        return
    data = r.json()
    remaining = data['resources']['search']['remaining']
    reset_epoch = data['resources']['search']['reset']
    reset_in = max(0, reset_epoch - now())
    logger.info(f"🔎 Remaining: {remaining} | Resets in {reset_in/60:.1f} min")
    if remaining < 5:
        if len(tokens) > 1:
            rotate_token()
            check_rate_limit()
        else:
            logger.warning(f"⏳ No extra tokens → sleeping {reset_in/60:.1f} min")
            sleep(reset_in + 5)

# === Count ===
def check_count(query):
    while True:
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 1})
        if r.status_code == 200:
            return r.json().get("total_count", 0)
        elif r.status_code == 403:
            rotate_token()
        else:
            logger.error(f"❌ Count error: {r.status_code} — {r.text}")
            return -1

# === Fetch ===
def fetch_items(query):
    all_items = []
    for page in range(1, 11):
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 100, "page": page})
        if r.status_code == 200:
            items = r.json().get("items", [])
            if not items:
                break
            all_items.extend(items)
            sleep(1)
        elif r.status_code == 403:
            rotate_token()
            return fetch_items(query)
        else:
            logger.error(f"❌ Fetch error: {r.status_code} — {r.text}")
            break
    return all_items

# === MAIN ===
final_results = []
for base_query_prefix in base_queries:
    current_start = start_date
    window_hours = initial_window_hours

    while current_start < end_date:
        current_end = min(current_start + timedelta(hours=window_hours), end_date)
        date_range = f"created:{current_start.isoformat()}..{current_end.isoformat()}"
        base_query = f"{base_query_prefix} {date_range}"

        total_count = check_count(base_query)
        logger.info(f"⏳ {base_query} → {total_count} repos")

        if total_count >= MAX_RESULTS_PER_QUERY and window_hours > min_window_hours:
            window_hours = max(window_hours // 2, min_window_hours)
            continue
        elif total_count < MAX_RESULTS_PER_QUERY * TARGET_FILL_RATIO and window_hours * 2 <= max_window_hours:
            window_hours = min(window_hours * 2, max_window_hours)

        items = fetch_items(base_query)
        expected_fork = 'fork:true' in base_query_prefix
        expected_archived = 'archived:true' in base_query_prefix
        expected_language = ''
        expected_topic = ''
        expected_keyword = ''

        if 'language:Kotlin' in base_query_prefix:
            expected_language = ['kotlin', 'java', 'dart']
        elif 'language:Java' in base_query_prefix:
            expected_language = ['kotlin', 'java', 'dart']
        elif 'language:Dart' in base_query_prefix:
            expected_language = ['kotlin', 'java', 'dart']
        elif 'topic:android' in base_query_prefix:
            expected_topic = 'android'
        elif 'android' in base_query_prefix:
            expected_keyword = 'android'


        count_passed = 0  # ✅ NEW counter for this window
        for item in items:
            # if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
            #     # === Check for valid clone_url ===
            #     clone_url = item.get("clone_url", "").strip()
            #     if not clone_url:
            #         logger.warning(f"⚠️ Skipped: missing or blank clone_url for {item.get('full_name')}")
            #         continue  # skip this one!
            item["base_qualifier"] = base_query_prefix
            #if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
            clean_item = {
                "name": item.get("name"),
                "full_name": item.get("full_name"),
                "language": item.get("language"),
                "stargazers_count": item.get("stargazers_count"),
                "forks": item.get("forks"),
                "topics": item.get("topics"),
                #"description": item.get("description"),
                "fork": item.get("fork"),
                "archived": item.get("archived"),
                "owner.login": item.get("owner", {}).get("login"),
                "html_url": item.get("html_url"),
                "clone_url": item.get("clone_url"),
                "visibility": item.get("visibility"),
                "size": item.get("size"),
                "open_issues_count": item.get("open_issues_count"),
                "base_qualifier": base_query_prefix,
                "search_qualifier": base_query,
                "repo_stars": item.get("stargazers_count", 0)
            }
            final_results.append(clean_item)
            count_passed += 1  # ✅ increment

        logger.info(f"✅ Window done: {count_passed} items")


        current_start = current_end + timedelta(seconds=1)


# ✅ === SAVE CLEAN CSV/XLSX ===

# Optional: create unique timestamp to prevent overwriting
ts = datetime.now().strftime("%Y%m%d_%H%M%S")

# 1️⃣ One final DataFrame: from CLEAN all_results
df_clean = pd.DataFrame(final_results)

# 2️⃣ Quick check: show a preview to be sure it's clean
print("📌 Columns:", list(df_clean.columns))
print(df_clean.head(5))

# 3️⃣ Choose output file names — timestamped for safety
output_csv = os.path.join(output_dir, f"search_results_{ts}.csv")
output_xlsx = os.path.join(output_dir, f"search_results_{ts}.xlsx")


# 4️⃣ Save to CSV and Excel
df_clean.to_csv(output_csv, index=False)
df_clean.to_excel(output_xlsx, index=False)

logger.info(f"✅ All done! Clean results saved to: {output_csv} and {output_xlsx}")

# 5️⃣ Optional: show final row count
print(f"✅ Final rows saved: {len(df_clean)}")
# Out:
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-01-01T00:00:00..2008-01-16T00:00:00 → 0 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-01-16T00:00:01..2008-02-15T00:00:01 → 0 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-02-15T00:00:02..2008-04-15T00:00:02 → 0 repos
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-04-15T00:00:03..2008-06-14T00:00:03 → 0 repos
# [INFO] 🔎 Remaining: 23 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 22 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-06-14T00:00:04..2008-08-13T00:00:04 → 0 repos
# [INFO] 🔎 Remaining: 21 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 20 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-08-13T00:00:05..2008-10-12T00:00:05 → 0 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-10-12T00:00:06..2008-12-11T00:00:06 → 0 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 16 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2008-12-11T00:00:07..2009-02-09T00:00:07 → 0 repos
# [INFO] 🔎 Remaining: 15 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-02-09T00:00:08..2009-04-10T00:00:08 → 0 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-04-10T00:00:09..2009-06-09T00:00:09 → 0 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-06-09T00:00:10..2009-08-08T00:00:10 → 0 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-08-08T00:00:11..2009-10-07T00:00:11 → 0 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 6 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-10-07T00:00:12..2009-12-06T00:00:12 → 0 repos
# [INFO] 🔎 Remaining: 5 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 4 | Resets in 0.9 min
# [WARNING] 🔑 Rotated → Token #2 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2009-12-06T00:00:13..2010-02-04T00:00:13 → 3 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-02-04T00:00:14..2010-04-05T00:00:14 → 0 repos
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-04-05T00:00:15..2010-06-04T00:00:15 → 3 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-06-04T00:00:16..2010-08-03T00:00:16 → 0 repos
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-08-03T00:00:17..2010-10-02T00:00:17 → 1 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-10-02T00:00:18..2010-12-01T00:00:18 → 1 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.8 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2010-12-01T00:00:19..2011-01-30T00:00:19 → 0 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.8 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-01-30T00:00:20..2011-03-31T00:00:20 → 2 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 10 | Resets in 0.8 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 9 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-03-31T00:00:21..2011-05-30T00:00:21 → 1 repos
# [INFO] 🔎 Remaining: 8 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 6 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-05-30T00:00:22..2011-07-29T00:00:22 → 1 repos
# [INFO] 🔎 Remaining: 5 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 4 | Resets in 0.7 min
# [WARNING] 🔑 Rotated → Token #3 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-07-29T00:00:23..2011-09-27T00:00:23 → 4 repos
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-09-27T00:00:24..2011-11-26T00:00:24 → 2 repos
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2011-11-26T00:00:25..2012-01-25T00:00:25 → 3 repos
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-01-25T00:00:26..2012-03-25T00:00:26 → 7 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ✅ Window done: 7 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-03-25T00:00:27..2012-05-24T00:00:27 → 5 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.8 min
# [INFO] ✅ Window done: 5 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-05-24T00:00:28..2012-07-23T00:00:28 → 4 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.8 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 11 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-07-23T00:00:29..2012-09-21T00:00:29 → 10 repos
# [INFO] 🔎 Remaining: 10 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.7 min
# [INFO] ✅ Window done: 10 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-09-21T00:00:30..2012-11-20T00:00:30 → 4 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 6 | Resets in 0.7 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 5 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2012-11-20T00:00:31..2013-01-19T00:00:31 → 7 repos
# [INFO] 🔎 Remaining: 4 | Resets in 0.7 min
# [WARNING] 🔑 Rotated → Token #4 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 7 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2013-01-19T00:00:32..2013-03-20T00:00:32 → 8 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ✅ Window done: 8 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:2013-03-20T00:00:33..2013-05-19T00:00:33 → 12 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ✅ Window done: 12 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false created:
items
# [INFO] 🔎 Remaining: 11 | Resets in 0.5 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2011-03-31T00:00:21..2011-05-30T00:00:21 → 132 repos
# [INFO] 🔎 Remaining: 10 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.4 min
# [INFO] ✅ Window done: 132 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.4 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2011-05-30T00:00:22..2011-07-29T00:00:22 → 162 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 4 | Resets in 0.3 min
# [WARNING] 🔑 Rotated → Token #1 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ✅ Window done: 162 items
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2011-07-29T00:00:23..2011-09-27T00:00:23 → 154 repos
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ✅ Window done: 154 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2011-09-27T00:00:24..2011-11-26T00:00:24 → 184 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] ✅ Window done: 184 items
# [INFO] 🔎 Remaining: 21 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2011-11-26T00:00:25..2012-01-25T00:00:25 → 186 repos
# [INFO] 🔎 Remaining: 20 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.6 min
# [INFO] ✅ Window done: 186 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.6 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-01-25T00:00:26..2012-03-25T00:00:26 → 223 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.4 min
# [INFO] ✅ Window done: 223 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.4 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-03-25T00:00:27..2012-05-24T00:00:27 → 244 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 10 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.2 min
# [INFO] ✅ Window done: 244 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.2 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-05-24T00:00:28..2012-07-23T00:00:28 → 238 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 4 | Resets in 0.0 min
# [WARNING] 🔑 Rotated → Token #2 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 238 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-07-23T00:00:29..2012-09-21T00:00:29 → 270 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] ✅ Window done: 270 items
# [INFO] 🔎 Remaining: 23 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-09-21T00:00:30..2012-11-20T00:00:30 → 279 repos
# [INFO] 🔎 Remaining: 22 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.6 min
# [INFO] ✅ Window done: 279 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2012-11-20T00:00:31..2013-01-19T00:00:31 → 270 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.4 min
# [INFO] ✅ Window done: 270 items
# [INFO] 🔎 Remaining: 13 | Resets in 0.3 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-01-19T00:00:32..2013-03-20T00:00:32 → 389 repos
# [INFO] 🔎 Remaining: 12 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 10 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.1 min
# [INFO] ✅ Window done: 389 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.1 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-03-20T00:00:33..2013-05-19T00:00:33 → 380 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] ✅ Window done: 380 items
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-05-19T00:00:34..2013-07-18T00:00:34 → 351 repos
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] ✅ Window done: 351 items
# [INFO] 🔎 Remaining: 20 | Resets in 0.6 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-07-18T00:00:35..2013-09-16T00:00:35 → 358 repos
# [INFO] 🔎 Remaining: 19 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] ✅ Window done: 358 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.3 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-09-16T00:00:36..2013-11-15T00:00:36 → 346 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 10 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.1 min
# [INFO] ✅ Window done: 346 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.1 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2013-11-15T00:00:37..2014-01-14T00:00:37 → 390 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 6 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] ✅ Window done: 390 items
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-01-14T00:00:38..2014-03-15T00:00:38 → 437 repos
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] ✅ Window done: 437 items
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-03-15T00:00:39..2014-05-14T00:00:39 → 517 repos
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.2 min
# [INFO] ✅ Window done: 517 items
# [INFO] 🔎 Remaining: 11 | Resets in 0.2 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-05-14T00:00:40..2014-07-13T00:00:40 → 433 repos
# [INFO] 🔎 Remaining: 10 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 9 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] ✅ Window done: 433 items
# [INFO] 🔎 Remaining: 26 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-07-13T00:00:41..2014-09-11T00:00:41 → 560 repos
# [INFO] 🔎 Remaining: 25 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.5 min
# [INFO] ✅ Window done: 556 items
# [INFO] 🔎 Remaining: 18 | Resets in 0.5 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-09-11T00:00:42..2014-11-10T00:00:42 → 543 repos
# [INFO] 🔎 Remaining: 17 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.1 min
# [INFO] ✅ Window done: 542 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.1 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2014-11-10T00:00:43..2015-01-09T00:00:43 → 571 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.7 min
# [INFO] ✅ Window done: 571 items
# [INFO] 🔎 Remaining: 24 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2015-01-09T00:00:44..2015-03-10T00:00:44 → 622 repos
# [INFO] 🔎 Remaining: 23 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 22 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 21 | Resets in 0.6 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.5 min
# [INFO] 🔎 Remaining: 19 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 18 | Resets in 0.4 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 16 | Resets in 0.3 min
# [INFO] ✅ Window done: 622 items
# [INFO] 🔎 Remaining: 15 | Resets in 0.2 min
# [INFO] ⏳ stars:>50 language:Java fork:false archived:false created:2015-03-10T00:00:45..2015-05-09T00:00:45 → 785 repos
# [INFO] 🔎 Remaining: 14 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 12 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.0 min
# ...
# [WARNING] ❌ README fetch failed (403) for 4TWIGGERS/realremote-front
# [WARNING] ❌ README fetch failed (403) for ajchellew/zwiftplay
# [WARNING] ❌ README fetch failed (403) for SamBouwer/any-docker
# [WARNING] ❌ README fetch failed (403) for QIDITECH/QIDISlicer
# [WARNING] ❌ README fetch failed (403) for th3cyb3rhub/100-hacking-tools
# [WARNING] ❌ README fetch failed (403) for bazelbuild/reclient
# [WARNING] ❌ README fetch failed (403) for cubicbyte/reddit-account-generator
# [WARNING] ❌ README fetch failed (403) for Harshita-Kohli/Namaste-React
# [WARNING] ❌ README fetch failed (403) for taichi-dev/soft2d-release
# [WARNING] ❌ README fetch failed (403) for WuXuBaiYang/jtech_anime
# [WARNING] ❌ README fetch failed (403) for sim0n00ps/OF-DRM
# [WARNING] ❌ README fetch failed (403) for bigbrodude6119/flipper-zero-evil-portal
# [WARNING] ❌ README fetch failed (403) for THUDM/CodeGeeX2
# [WARNING] ❌ README fetch failed (403) for RedpointGames/uet
# [WARNING] ❌ README fetch failed (403) for fluttercandies/flutter_tilt
# [WARNING] ❌ README fetch failed (403) for JLChnToZ/VVMW
# [WARNING] ❌ README fetch failed (403) for h-RAT/Willy_Firmware_V2_ESP32_Flipper_Zero_Alternative
# [WARNING] ❌ README fetch failed (403) for jzyong/ugk-server
# [WARNING] ❌ README fetch failed (403) for bradfitz/issue-tracker-behaviors
# [WARNING] ❌ README fetch failed (403) for CodingTrain/Creative-Coding-Processing-Full-Course
# [WARNING] ❌ README fetch failed (403) for SwayKh/dotfiles
# [WARNING] ❌ README fetch failed (403) for hufrea/byedpi
# [WARNING] ❌ README fetch failed (403) for melloware/react-logviewer
# [WARNING] ❌ README fetch failed (403) for liulilittle/openppp2
# [WARNING] ❌ README fetch failed (403) for autox-community/autox-super-kit
# [WARNING] ❌ README fetch failed (403) for kormax/apple-device-as-access-card
# [WARNING] ❌ README fetch failed (403) for NeonLightning/pwny
# [WARNING] ❌ README fetch failed (403) for gyrovorbis/libevmu
# [WARNING] ❌ README fetch failed (403) for cjyyx/ScreenFilter
# [WARNING] ❌ README fetch failed (403) for meistrari/cursive
# [WARNING] ❌ README fetch failed (403) for Cp0204/CasaOS-AppStore-Play
# [WARNING] ❌ README fetch failed (403) for seanghay/awesome-khmer-language
# [WARNING] ❌ README fetch failed (403) for gerwld/igplus-extension
# [WARNING] ❌ README fetch failed (403) for wasdwasd0105/PicoW-usb2bt-audio
# [WARNING] ❌ README fetch failed (403) for HuolalaTech/hll-wp-therouter-ios
# [WARNING] ❌ README fetch failed (403) for myelectronix/xtls-reality-docker
# [WARNING] ❌ README fetch failed (403) for ansari-project/ansari-backend
# [WARNING] ❌ README fetch failed (403) for Xposed-Modules-Repo/Hook.JiuWu.Xp
# [WARNING] ❌ README fetch failed (403) for GodotHub/gmui
# [WARNING] ❌ README fetch failed (403) for oldshensheep/v2ex_scrapy
# [WARNING] ❌ README fetch failed (403) for ProbiusOfficial/CTF-OS
# [WARNING] ❌ README fetch failed (403) for bizz84/fluttercon_23_resources
# [WARNING] ❌ README fetch failed (403) for IchildYu/load-elf
# [WARNING] ❌ README fetch failed (403) for vitoplantamura/OnnxStream
# [WARNING] ❌ README fetch failed (403) for WisdomSky/CasaOS-Coolstore
# [WARNING] ❌ README fetch failed (403) for 7h3h4ckv157/100-Days-of-Hacking
# [WARNING] ❌ README fetch failed (403) for KDE/krdp
# [WARNING] ❌ README fetch failed (403) for PIut02/ROG-Zephyrus-G14-GA401-Hackintosh
# [WARNING] ❌ README fetch failed (403) for huahuacatTX/greasyfork
# [WARNING] ❌ README fetch failed (403) for kevin2li/PDF-Guru
# [WARNING] ❌ README fetch failed (403) for MarvNC/StampNyaa
# [WARNING] ❌ README fetch failed (403) for akhilkammila/leetcode-screenshotter
# [WARNING] ❌ README fetch failed (403) for bookingcom/perfsuite-ios
# [WARNING] ❌ README fetch failed (403) for Satanarious/TranslucentFlyoutsConfig
# [WARNING] ❌ README fetch failed (403) for henrybear327/Proton-API-Bridge
# [WARNING] ❌ README fetch failed (403) for Cysharp/YetAnotherHttpHandler
# [WARNING] ❌ README fetch failed (403) for HSLix/LixAssistantLimbusCompany
# [WARNING] ❌ README fetch failed (403) for inanevin/LinaGX
# [WARNING] ❌ README fetch failed (403) for symisc/tiny-dream
# [WARNING] ❌ README fetch failed (403) for Slamsneider/SingleTom
# [WARNING] ❌ README fetch failed (403) for TravMurav/Qcom-Secure-Launch
# [WARNING] ❌ README fetch failed (403) for ReVanced-Extended-Community/Patches-Documentation
# [WARNING] ❌ README fetch failed (403) for lf-/clipper
# [WARNING] ❌ README fetch failed (403) for jdtsmith/indent-bars
# [WARNING] ❌ README fetch failed (403) for JairajJangle/react-native-tree-multi-select
# [WARNING] ❌ README fetch failed (403) for mlabonne/llm-course
# [WARNING] ❌ README fetch failed (403) for feiyangqingyun/qucsdk
# [WARNING] ❌ README fetch failed (403) for milkv-duo/duo-buildroot-sdk
# [WARNING] ❌ README fetch failed (403) for Pekaway/VAN_PI
# [WARNING] ❌ README fetch failed (403) for TheLogicMaster/Cranked
# [WARNING] ❌ README fetch failed (403) for ai919/Awesome-ChatGPT
# [WARNING] ❌ README fetch failed (403) for manyeyes/AliParaformerAsr
# [WARNING] ❌ README fetch failed (403) for kiliokuara/KuimiVM
# [WARNING] ❌ README fetch failed (403) for m3y54m/Embedded-Engineering-Roadmap
# [WARNING] ❌ README fetch failed (403) for Hakuuyosei/QQHistoryExport
# [WARNING] ❌ README fetch failed (403) for sagar-viradiya/auto-benchmark
# [WARNING] ❌ README fetch failed (403) for roleoroleo/onvif_simple_server
# [WARNING] ❌ README fetch failed (403) for Bert-JanP/SecScripts
# [WARNING] ❌ README fetch failed (403) for zhangyuang/node-ffi-rs
# [WARNING] ❌ README fetch failed (403) for GioF71/tidal-connect
# [WARNING] ❌ README fetch failed (403) for OrdinarySF/capacitor-websocket-client
# [WARNING] ❌ README fetch failed (403) for simulot/immich-go
# [WARNING] ❌ README fetch failed (403) for baichuan-inc/Baichuan-13B
# [WARNING] ❌ README fetch failed (403) for rikonaka/pistol-rs
# [WARNING] ❌ README fetch failed (403) for adrianlois/DFIR-Detection-Engineering
# [WARNING] ❌ README fetch failed (403) for IamAlch3mist/Awesome-Embedded-Systems-Vulnerability-Research
# [WARNING] ❌ README fetch failed (403) for NiREvil/vless
# [WARNING] ❌ README fetch failed (403) for sun9426/sun9426.github.io
# [WARNING] ❌ README fetch failed (403) for natecarlson/quectel-rgmii-configuration-notes
# [WARNING] ❌ README fetch failed (403) for HillZhang1999/llm-hallucination-survey
# [WARNING] ❌ README fetch failed (403) for thiswillbeyourgithub/wdoc
# [WARNING] ❌ README fetch failed (403) for Zhou-Zi7/Awesome-AI-Security-BIG4
# [WARNING] ❌ README fetch failed (403) for ghimiresunil/LLM-PowerHouse-A-Curated-Guide-for-Large-Language-Models-with-Custom-Training-and-Inferencing
# [WARNING] ❌ README fetch failed (403) for maltfield/awesome-lemmy-instances
# [WARNING] ❌ README fetch failed (403) for tolgaerok/nixos-kde
# [WARNING] ❌ README fetch failed (403) for GoGPTAI/ChatGPT-Prompt
# [WARNING] ❌ README fetch failed (403) for tonusoo/koduinternet-cpe
# [WARNING] ❌ README fetch failed (403) for maurobonfietti/remote-jobs
# [WARNING] ❌ README fetch failed (403) for AGI-Edgerunners/LLM-Agents-Papers
# [WARNING] ❌ README fetch failed (403) for Home-Assistant-Pro-Team/Gestione-Allarme-Home-Assistant-Alarm
# [WARNING] ❌ README fetch failed (403) for erlang-punch/awesome-erlang
# [WARNING] ❌ README fetch failed (403) for Ditectrev/AWS-Certified-Solutions-Architect-Associate-SAA-C03-Practice-Tests-Exams-Questions-Answers
# [WARNING] ❌ README fetch failed (403) for mmrobotlab/DailyRobot
# [INFO] ✅ Window done: 121 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2023-07-26T00:02:09..2023-09-24T00:02:09 → 395 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [WARNING] ❌ README fetch failed (403) for chen08209/FlClash
# [WARNING] ❌ README fetch failed (403) for joelkanyi/FocusBloom
# [WARNING] ❌ README fetch failed (403) for Nekogram/Nekogram
# [WARNING] ❌ README fetch failed (403) for UbiquitousLearning/mllm
# [WARNING] ❌ README fetch failed (403) for MohamedRejeb/Calf
# [WARNING] ❌ README fetch failed (403) for Trixarian/NetherSX2-patch
# [WARNING] ❌ README fetch failed (403) for romainguy/kotlin-explorer
# [WARNING] ❌ README fetch failed (403) for hackcatml/frida-ue4dump
# [WARNING] ❌ README fetch failed (403) for zkmopro/mopro
# [WARNING] ❌ README fetch failed (403) for llSourcell/Doctor-Dignity
# [WARNING] ❌ README fetch failed (403) for nyadla-sys/whisper.tflite
# [WARNING] ❌ README fetch failed (403) for JioTV-Go/jiotv_go
# [WARNING] ❌ README fetch failed (403) for zhbhun/idify
# [WARNING] ❌ README fetch failed (403) for Eclipse-Laboratories-Inc/eclipse-wallet
# [WARNING] ❌ README fetch failed (403) for dstark5/Openlib
# [WARNING] ❌ README fetch failed (403) for aelassas/movinin
# [WARNING] ❌ README fetch failed (403) for sdcb/OpenVINO.NET
# [WARNING] ❌ README fetch failed (403) for TheChance101/beep-beep
# [WARNING] ❌ README fetch failed (403) for KevinnZou/compose-webview-multiplatform
# [WARNING] ❌ README fetch failed (403) for ShokhrukhbekYuldoshev/Meloplay
# [WARNING] ❌ README fetch failed (403) for maitrungduc1410/react-native-video-trim
# [INFO] ✅ Window done: 360 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2023-09-24T00:02:10..2023-11-23T00:02:10 → 355 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] ✅ Window done: 347 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2023-11-23T00:02:11..2024-01-22T00:02:11 → 433 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.7 min
# [INFO] ✅ Window done: 414 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-01-22T00:02:12..2024-03-22T00:02:12 → 386 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] ✅ Window done: 379 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-03-22T00:02:13..2024-05-21T00:02:13 → 335 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] ✅ Window done: 322 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-05-21T00:02:14..2024-07-20T00:02:14 → 310 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.8 min
# [INFO] ✅ Window done: 300 items
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-07-20T00:02:15..2024-09-18T00:02:15 → 261 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 27 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 26 | Resets in 0.8 min
# [INFO] ✅ Window done: 256 items
# [INFO] 🔎 Remaining: 25 | Resets in 0.1 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-09-18T00:02:16..2024-11-17T00:02:16 → 239 repos
# [INFO] 🔎 Remaining: 24 | Resets in 0.1 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 0.9 min
# [INFO] ✅ Window done: 233 items
# [INFO] 🔎 Remaining: 27 | Resets in 0.3 min
# [INFO] ⏳ stars:>50 android in:name,description,readme fork:false archived:false created:2024-11-17T00:02:17..2024-12-31T00:00:00 → 156 repos
# [INFO] 🔎 Remaining: 26 | Resets in 0.3 min
# [INFO] 🔎 Remaining: 25 | Resets in 0.2 min
# [INFO] 🔎 Remaining: 24 | Resets in 0.2 min
# [INFO] ✅ Window done: 152 items
# 📌 Columns: ['name', 'full_name', 'language', 'stargazers_count', 'forks', 'topics', 'fork', 'archived', 'owner.login', 'html_url', 'clone_url', 'visibility', 'size', 'open_issues_count', 'base_qualifier', 'search_qualifier', 'repo_stars', 'match_type', 'match_reason']
#                    name                      full_name language  \
# 0         quran_android            quran/quran_android   Kotlin
# 1            gobandroid                ligi/gobandroid   Kotlin
# 2               javabot             evanchooly/javabot   Kotlin
# 3  facebook-android-sdk  facebook/facebook-android-sdk   Kotlin
# 4               tnoodle                 thewca/tnoodle   Kotlin
#
#    stargazers_count  forks                                             topics  \
# 0              2174    918                                   [android, quran]
# 1               237     66  [android, android-app, goban, kotlin, kotlin-a...
# 2                56     30                                                 []
# 3              6256   3668                                                 []
# 4               423    101                      [scrambles, speedcubing, wca]
#
#     fork  archived owner.login  \
# 0  False     False       quran
# 1  False     False        ligi
# 2  False     False  evanchooly
# 3  False     False    facebook
# 4  False     False      thewca
#
#                                            html_url  \
# 0            https://github.com/quran/quran_android
# 1                https://github.com/ligi/gobandroid
# 2             https://github.com/evanchooly/javabot
# 3  https://github.com/facebook/facebook-android-sdk
# 4                 https://github.com/thewca/tnoodle
#
#                                            clone_url visibility    size  \
# 0         https://github.com/quran/quran_android.git     public   16904
# 1             https://github.com/ligi/gobandroid.git     public   14650
# 2          https://github.com/evanchooly/javabot.git     public   68483
# 3  https://github.com/facebook/facebook-android-s...     public   33465
# 4              https://github.com/thewca/tnoodle.git     public  152817
#
#    open_issues_count                                     base_qualifier  \
# 0                354  stars:>50 language:Kotlin fork:false archived:...
# 1                 73  stars:>50 language:Kotlin fork:false archived:...
# 2                 44  stars:>50 language:Kotlin fork:false archived:...
# 3                142  stars:>50 language:Kotlin fork:false archived:...
# 4                 48  stars:>50 language:Kotlin fork:false archived:...
#
#                                     search_qualifier  repo_stars match_type  \
# 0  stars:>50 language:Kotlin fork:false archived:...        2174     Kotlin
# 1  stars:>50 language:Kotlin fork:false archived:...         237     Kotlin
# 2  stars:>50 language:Kotlin fork:false archived:...          56     Kotlin
# 3  stars:>50 language:Kotlin fork:false archived:...        6256     Kotlin
# 4  stars:>50 language:Kotlin fork:false archived:...         423     Kotlin
#
#   match_reason
# 0      unknown
# 1      unknown
# 2      unknown
# 3      unknown
# 4      unknown
# [INFO] ✅ All done! Clean results saved to: C:\Android Mobile App\Step1_URL_Search\search_results_20250626_132436.csv and C:\Android Mobile App\Step1_URL_Search\search_results_20250626_132436.xlsx
# [INFO] 🚫 Rejected repos saved to: C:\Android Mobile App\Step1_URL_Search\rejected_repos_20250626_132436.csv
# ✅ Final rows saved: 91650
