# %% [markdown]
# upgradeing the miner to pull the number of the changes to each style in dwelling period

# %% [markdown]
# # Step 1: Clone

# %%
from __future__ import annotations
import csv, os, re, subprocess, time, base64
from pathlib import Path
from typing import Optional, List, Dict, Tuple
from urllib.parse import urlparse

# -----------------------------
# Config (edit as needed)
# -----------------------------
WORK_ROOT       = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3")
URL_LIST_CSV    = WORK_ROOT / "URL_List_RQ3.csv"
CLONE_ROOT      = WORK_ROOT / "Clone"
MANIFEST_CSV    = WORK_ROOT / "clones_manifest_V1_retry.csv"

# Token file + keys (you said you already have these)
TOKENS_ENV_FILE = Path(r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env")
TOKEN_KEYS      = [f"GITHUB_TOKEN_{i}" for i in range(1, 7)]

# Optional: keep your PR refs option
FETCH_PR_REFS   = True

# Create dirs
WORK_ROOT.mkdir(parents=True, exist_ok=True)
CLONE_ROOT.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Helpers
# -----------------------------
DEFAULT_TIMEOUT = 1800  # 30 minutes for huge repos
GIT_ENV = {"GIT_TERMINAL_PROMPT": "0", "GIT_ASKPASS": ""}

def log(msg: str) -> None:
    ts = time.strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] {msg}")

def load_env_file(path: Path) -> None:
    """
    Loads KEY=VALUE lines from a .env-like file into os.environ (non-destructive).
    Supports lines like:
      GITHUB_TOKEN_1=...
      export GITHUB_TOKEN_2="..."
      # comments
    """
    if not path.exists():
        raise FileNotFoundError(f"Missing env file: {path}")
    for raw in path.read_text(encoding="utf-8", errors="ignore").splitlines():
        line = raw.strip()
        if not line or line.startswith("#"):
            continue
        if line.lower().startswith("export "):
            line = line[7:].strip()
        if "=" not in line:
            continue
        k, v = line.split("=", 1)
        k = k.strip()
        v = v.strip().strip('"').strip("'")
        if k and v and k not in os.environ:
            os.environ[k] = v

def repo_dir_name_from_url(url: str) -> str:
    u = url.strip()
    # SSH form: git@host:owner/repo(.git)
    m = re.match(r"^[^@]+@([^:]+):([^/]+)/(.+?)(?:\.git)?$", u)
    if m:
        owner, name = m.group(2), m.group(3)
        return f"{owner}__{name}"
    # https://host/owner/repo(.git)
    if "://" in u:
        base = u.split("://", 1)[1]
    else:
        base = u
    parts = [p for p in base.split("/") if p]
    if len(parts) >= 2:
        owner, name = parts[-2], parts[-1].removesuffix(".git")
        return f"{owner}__{name}"
    return base.replace("/", "__").removesuffix(".git")

def get_total_commits(repo_dir: Path) -> int:
    cp = sh(["git", "rev-list", "--all", "--count"], cwd=repo_dir, check=False)
    try:
        return int((cp.stdout or "0").strip() or "0")
    except Exception:
        return 0

def url_host_and_mode(url: str) -> Tuple[Optional[str], str]:
    """
    Returns (host, mode) where mode is:
      - "ssh" for git@host:owner/repo
      - "https" for https://host/...
      - "other" otherwise
    """
    u = url.strip()
    if re.match(r"^[^@]+@([^:]+):", u):
        host = u.split("@", 1)[1].split(":", 1)[0]
        return host, "ssh"
    if "://" in u:
        parsed = urlparse(u)
        host = (parsed.netloc or "").split("@")[-1].split(":")[0] or None
        return host, parsed.scheme.lower()
    return None, "other"

def git_auth_config_args(host: str, token: str) -> List[str]:
    """
    Injects an HTTP Authorization header for git HTTPS requests to the given host.
    Uses Basic auth with x-access-token:<TOKEN>.
    """
    basic = base64.b64encode(f"x-access-token:{token}".encode("utf-8")).decode("ascii")
    # -c http.https://HOST/.extraheader="Authorization: Basic ...."
    return ["-c", f"http.https://{host}/.extraheader=Authorization: Basic {basic}"]

def sh(
    cmd: List[str],
    cwd: Optional[Path] = None,
    check: bool = True,
    capture: bool = True,
    timeout: Optional[int] = DEFAULT_TIMEOUT,
    auth_url: Optional[str] = None,
    token: Optional[str] = None
) -> subprocess.CompletedProcess:
    env = os.environ.copy()
    env.update(GIT_ENV)

    if cmd and cmd[0] == "git" and token and auth_url:
        host, mode = url_host_and_mode(auth_url)
        # Only apply token injection for HTTPS-like URLs (tokens don't apply to SSH)
        if host and mode in ("https", "http"):
            cmd = ["git", *git_auth_config_args(host, token), *cmd[1:]]

    return subprocess.run(
        cmd, cwd=cwd, check=check,
        capture_output=capture, text=True,
        timeout=timeout, env=env
    )

class TokenRotator:
    def __init__(self, tokens: List[str]) -> None:
        self.tokens = tokens[:]
        self.i = 0

    def next(self) -> Tuple[int, str]:
        """
        Returns (slot, token) where slot is 1..N.
        """
        if not self.tokens:
            raise RuntimeError("No tokens available")
        idx = self.i % len(self.tokens)
        self.i += 1
        return (idx + 1, self.tokens[idx])

def is_retryable_auth_error(msg: str) -> bool:
    m = (msg or "").lower()
    # Covers common GitHub/HTTP auth & throttling patterns seen in git stderr
    needles = [
        "rate limit", "abuse detection", "too many requests", "http 429",
        "http 403", "403 forbidden", "http 401", "401 unauthorized",
        "authentication failed", "could not read username", "access denied",
        "fatal: unable to access", "remote: permission to"
    ]
    return any(n in m for n in needles)

def ensure_full_clone_no_submodules_no_lfs(
    url: str,
    dest_root: Path,
    fetch_pr_refs: bool,
    token: Optional[str] = None
) -> Path:
    """
    Ensures a non-shallow clone with full history of all branches & tags.
    NO submodules. NO LFS.
    Optionally fetches GitHub PR heads.
    """
    dest_root.mkdir(parents=True, exist_ok=True)
    d = dest_root / repo_dir_name_from_url(url)

    if not (d.exists() and (d / ".git").exists()):
        # Full clone (not shallow). Explicitly no submodules.
        sh(
            ["git", "clone", "--no-single-branch", "--no-recurse-submodules", "--tags", "--quiet", url, str(d)],
            capture=True,
            auth_url=url,
            token=token
        )
    else:
        # Ensure origin URL is correct
        sh(["git", "remote", "set-url", "origin", url], cwd=d, check=False, capture=True, auth_url=url, token=token)

    # Helpful on Windows for deep trees (best-effort)
    sh(["git", "config", "core.longpaths", "true"], cwd=d, check=False, capture=True, auth_url=url, token=token)

    # If shallow, unshallow
    cp = sh(["git", "rev-parse", "--is-shallow-repository"], cwd=d, check=False, capture=True, auth_url=url, token=token)
    if cp.returncode == 0 and (cp.stdout or "").strip() == "true":
        sh(["git", "fetch", "--unshallow", "--tags", "--quiet"], cwd=d, capture=True, auth_url=url, token=token)
    else:
        sh(["git", "fetch", "--tags", "--quiet"], cwd=d, check=False, capture=True, auth_url=url, token=token)

    # Fetch all branches under refs/heads/* and prune deleted ones
    sh(
        ["git", "fetch", "origin", "--prune", "--tags",
         "+refs/heads/*:refs/remotes/origin/*", "--quiet"],
        cwd=d, check=False, capture=True, auth_url=url, token=token
    )

    # Best-effort PR refs (GitHub); harmless if not present
    if fetch_pr_refs:
        sh(
            ["git", "fetch", "origin",
             "+refs/pull/*/head:refs/remotes/origin/pr/*", "--quiet"],
            cwd=d, check=False, capture=True, auth_url=url, token=token
        )

    return d

def clone_with_token_rotation(
    url: str,
    clone_root: Path,
    fetch_pr_refs: bool,
    rotator: Optional[TokenRotator],
    max_token_attempts: int = 6
) -> Tuple[Path, Dict[str, object]]:
    """
    Tries clone/fetch using rotating tokens (HTTPS only). For SSH URLs, runs once (no token).
    Returns (repo_path, meta)
    """
    host, mode = url_host_and_mode(url)
    meta: Dict[str, object] = {
        "auth_mode": None,
        "token_slot": None,
        "attempts": 0,
    }

    # SSH or non-https -> no token injection possible/needed
    if mode == "ssh":
        meta["auth_mode"] = "ssh"
        meta["attempts"] = 1
        d = ensure_full_clone_no_submodules_no_lfs(url, clone_root, fetch_pr_refs, token=None)
        return d, meta

    # HTTPS with token rotation if we have tokens
    if rotator and mode in ("https", "http") and host:
        meta["auth_mode"] = "https-token"
        last_err: Optional[Exception] = None

        # Try up to N tokens (or fewer if you configured fewer)
        tries = min(max_token_attempts, len(rotator.tokens))
        for _ in range(tries):
            slot, token = rotator.next()
            meta["attempts"] += 1
            meta["token_slot"] = slot

            try:
                d = ensure_full_clone_no_submodules_no_lfs(url, clone_root, fetch_pr_refs, token=token)
                return d, meta
            except subprocess.CalledProcessError as e:
                # Retry only if it looks like auth/rate/throttle; otherwise fail fast.
                err = (e.stderr or e.stdout or str(e))[:5000]
                last_err = e
                if is_retryable_auth_error(err):
                    log(f"Retryable auth/rate error for {url} using token slot {slot}; rotating token...")
                    continue
                raise

        # exhausted tokens
        if last_err:
            raise last_err
        raise RuntimeError("Clone failed after token rotation attempts")

    # HTTPS but no tokens loaded
    meta["auth_mode"] = "https-no-token"
    meta["attempts"] = 1
    d = ensure_full_clone_no_submodules_no_lfs(url, clone_root, fetch_pr_refs, token=None)
    return d, meta


# -----------------------------
# Main
# -----------------------------
assert URL_LIST_CSV.exists(), f"CSV not found: {URL_LIST_CSV}"

# Load tokens
rotator: Optional[TokenRotator] = None
try:
    load_env_file(TOKENS_ENV_FILE)
    tokens = [os.environ.get(k) for k in TOKEN_KEYS]
    tokens = [t for t in tokens if t and t.strip()]
    if tokens:
        rotator = TokenRotator(tokens)
        log(f"Loaded {len(tokens)} GitHub token(s) from {TOKENS_ENV_FILE.name} (slots: 1..{len(tokens)})")
    else:
        log(f"No tokens found in {TOKENS_ENV_FILE.name}; proceeding without tokens.")
except Exception as e:
    log(f"Token file not loaded ({e}); proceeding without tokens.")

rows, ok, fail = [], 0, 0
with URL_LIST_CSV.open(newline="", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        url = (row.get("repo_url") or "").strip()
        if not url:
            continue

        t0 = time.time()
        rec: Dict[str, object] = {
            "repo_url": url,
            "dir": None,
            "status": "unknown",
            "seconds": None,
            "total_commits": None,
            "error": "",

            # token/logging fields
            "auth_mode": None,
            "token_slot": None,
            "attempts": None,
        }

        try:
            d, meta = clone_with_token_rotation(
                url=url,
                clone_root=CLONE_ROOT,
                fetch_pr_refs=FETCH_PR_REFS,
                rotator=rotator,
                max_token_attempts=6
            )
            rec["dir"] = str(d)
            rec["total_commits"] = get_total_commits(d)
            rec["status"] = "ok"
            rec.update(meta)
            ok += 1

            log(f"[ok] {url} -> {rec['dir']}  commits={rec['total_commits']}  "
                f"auth={rec['auth_mode']} token_slot={rec['token_slot']} attempts={rec['attempts']}")

        except subprocess.CalledProcessError as e:
            rec["status"] = "error"
            rec["error"]  = (e.stderr or e.stdout or str(e)).strip()[:2000]
            fail += 1
            log(f"[error] {url}  auth={rec.get('auth_mode')} token_slot={rec.get('token_slot')} attempts={rec.get('attempts')}")

        except Exception as e:
            rec["status"] = "error"
            rec["error"]  = str(e)[:2000]
            fail += 1
            log(f"[error] {url}  ({e})")

        rec["seconds"] = round(time.time() - t0, 2)
        rows.append(rec)

# Write manifest
MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
fieldnames = [
    "repo_url","dir","status","seconds","total_commits","error",
    "auth_mode","token_slot","attempts"
]
with MANIFEST_CSV.open("w", newline="", encoding="utf-8") as f:
    w = csv.DictWriter(f, fieldnames=fieldnames)
    w.writeheader()
    w.writerows(rows)

log(f"Done. OK={ok}, FAIL={fail}. Manifest: {MANIFEST_CSV}")
# Out:
# [2025-12-14 22:05:26] Loaded 6 GitHub token(s) from All_Tokens.env (slots: 1..6)
# [2025-12-14 22:05:28] [ok] https://github.com/connectbot/connectbot -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\connectbot__connectbot  commits=4100  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:05:29] [ok] https://github.com/ge0rg/aprsdroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ge0rg__aprsdroid  commits=1211  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:06:07] [ok] https://github.com/robolectric/robolectric -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\robolectric__robolectric  commits=21638  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:06:36] [ok] https://github.com/opendocument-app/OpenDocument.droid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\opendocument-app__OpenDocument.droid  commits=6107  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:06:43] [ok] https://github.com/maxpower47/PinDroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\maxpower47__PinDroid  commits=1057  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:07:04] [ok] https://github.com/Rajawali/Rajawali -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Rajawali__Rajawali  commits=3065  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:13:32] [ok] https://github.com/cgeo/cgeo -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\cgeo__cgeo  commits=74434  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:13:42] [ok] https://github.com/OneBusAway/onebusaway-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\OneBusAway__onebusaway-android  commits=4381  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:13:49] [ok] https://github.com/MikeOrtiz/TouchImageView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\MikeOrtiz__TouchImageView  commits=1148  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:13:55] [ok] https://github.com/chennaione/sugar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\chennaione__sugar  commits=801  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:14:00] [ok] https://github.com/labexp/osmtracker-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\labexp__osmtracker-android  commits=1936  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:14:46] [ok] https://github.com/AndBible/and-bible -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AndBible__and-bible  commits=13124  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:14:50] [ok] https://github.com/maxistar/TextPad -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\maxistar__TextPad  commits=369  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:15:01] [ok] https://github.com/spacecowboy/NotePad -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\spacecowboy__NotePad  commits=3151  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:15:17] [ok] https://github.com/persian-calendar/persian-calendar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\persian-calendar__persian-calendar  commits=12993  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:15:39] [ok] https://github.com/inaturalist/iNaturalistAndroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\inaturalist__iNaturalistAndroid  commits=3592  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:16:43] [ok] https://github.com/yuriykulikov/AlarmClock -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\yuriykulikov__AlarmClock  commits=2740  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:18:07] [ok] https://github.com/AnySoftKeyboard/AnySoftKeyboard -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AnySoftKeyboard__AnySoftKeyboard  commits=12694  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:18:16] [ok] https://github.com/openintents/shoppinglist -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\openintents__shoppinglist  commits=553  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:19:02] [ok] https://github.com/square/okhttp -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\square__okhttp  commits=13838  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:20:09] [ok] https://github.com/AntennaPod/AntennaPod -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AntennaPod__AntennaPod  commits=14997  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:20:14] [ok] https://github.com/TimotheeJeannin/ProviGen -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\TimotheeJeannin__ProviGen  commits=358  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:20:16] [ok] https://github.com/kevinhinterlong/archwiki-viewer -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\kevinhinterlong__archwiki-viewer  commits=230  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:20:19] [ok] https://github.com/ragunathjawahar/android-saripaar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ragunathjawahar__android-saripaar  commits=345  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:25:36] [ok] https://github.com/fossasia/phimpme-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\fossasia__phimpme-android  commits=7821  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:25:38] [ok] https://github.com/xebia-functional/appsly-android-rest -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\xebia-functional__appsly-android-rest  commits=209  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:25:52] [ok] https://github.com/chaosbastler/opentraining -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\chaosbastler__opentraining  commits=531  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:25:53] [error] https://github.com/jakenjarvis/Android-OrmLiteContentProvider  auth=None token_slot=None attempts=None
# [2025-12-14 22:28:08] [ok] https://github.com/ankidroid/Anki-Android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ankidroid__Anki-Android  commits=48765  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:28:12] [ok] https://github.com/ligi/PassAndroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ligi__PassAndroid  commits=2328  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:28:17] [ok] https://github.com/segler-alex/RadioDroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\segler-alex__RadioDroid  commits=1764  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:28:19] [error] https://github.com/ksoichiro/AndroidFormEnhancer  auth=None token_slot=None attempts=None
# [2025-12-14 22:28:22] [ok] https://github.com/cloudinary/cloudinary_android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\cloudinary__cloudinary_android  commits=660  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:28:24] [ok] https://github.com/niteshpatel/ministocks -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\niteshpatel__ministocks  commits=401  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:28:48] [ok] https://github.com/dmfs/opentasks -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\dmfs__opentasks  commits=1538  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:28:57] [ok] https://github.com/jpaulynice/android-jigsaw-puzzle -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jpaulynice__android-jigsaw-puzzle  commits=514  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:30:59] [ok] https://github.com/leapcode/bitmask_android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\leapcode__bitmask_android  commits=3866  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:31:11] [ok] https://github.com/square/wire -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\square__wire  commits=7341  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:31:47] [ok] https://github.com/tasks/tasks -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\tasks__tasks  commits=15853  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:31:51] [ok] https://github.com/simonnorberg/dmach -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\simonnorberg__dmach  commits=225  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:32:02] [ok] https://github.com/DroidPHP/DroidPHP -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\DroidPHP__DroidPHP  commits=209  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:32:04] [ok] https://github.com/netmackan/ATimeTracker -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\netmackan__ATimeTracker  commits=249  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:34:04] [ok] https://github.com/wikimedia/apps-android-wikipedia -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\wikimedia__apps-android-wikipedia  commits=41923  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:34:06] [ok] https://github.com/splitwise/TokenAutoComplete -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\splitwise__TokenAutoComplete  commits=428  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:34:20] [ok] https://github.com/grote/Transportr -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\grote__Transportr  commits=1953  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:34:23] [ok] https://github.com/anjlab/android-inapp-billing-v3 -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\anjlab__android-inapp-billing-v3  commits=583  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:34:25] [ok] https://github.com/stephanenicolas/boundbox -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\stephanenicolas__boundbox  commits=248  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:36:23] [ok] https://github.com/simlar/simlar-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\simlar__simlar-android  commits=4725  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:37:04] [ok] https://github.com/moonlight-stream/moonlight-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\moonlight-stream__moonlight-android  commits=4125  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:37:09] [ok] https://github.com/JakeWharton/u2020 -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\JakeWharton__u2020  commits=563  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:37:28] [ok] https://github.com/federicoiosue/Omni-Notes -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\federicoiosue__Omni-Notes  commits=3789  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:37:34] [ok] https://github.com/rejasupotaro/Rebuild -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\rejasupotaro__Rebuild  commits=672  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:38:18] [ok] https://github.com/owntracks/android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\owntracks__android  commits=6521  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:38:21] [ok] https://github.com/dlew/joda-time-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\dlew__joda-time-android  commits=549  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:38:55] [ok] https://github.com/TomRoush/PdfBox-Android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\TomRoush__PdfBox-Android  commits=748  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:39:00] [ok] https://github.com/AChep/AcDisplay -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AChep__AcDisplay  commits=1156  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:39:02] [ok] https://github.com/andrewgiang/SpritzerTextView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\andrewgiang__SpritzerTextView  commits=116  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:39:06] [ok] https://github.com/mathisdt/trackworktime -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\mathisdt__trackworktime  commits=1097  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:39:09] [ok] https://github.com/ksoichiro/SimpleAlertDialog-for-Android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ksoichiro__SimpleAlertDialog-for-Android  commits=157  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:39:45] [ok] https://github.com/openhab/openhab-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\openhab__openhab-android  commits=14892  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:39:46] [ok] https://github.com/wuyexiong/transparent-over-animtabsview -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\wuyexiong__transparent-over-animtabsview  commits=10  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:39:57] [ok] https://github.com/amahi/android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\amahi__android  commits=1909  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:39:59] [ok] https://github.com/vashisthg/StartPointSeekBar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\vashisthg__StartPointSeekBar  commits=19  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:40:01] [ok] https://github.com/hotchemi/ProgressMenuItem -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\hotchemi__ProgressMenuItem  commits=42  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:40:05] [ok] https://github.com/EvanRespaut/Equate -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\EvanRespaut__Equate  commits=419  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:40:08] [ok] https://github.com/OpnTec/bodyapps-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\OpnTec__bodyapps-android  commits=160  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:40:10] [ok] https://github.com/blazsolar/android-collapse-calendar-view -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\blazsolar__android-collapse-calendar-view  commits=99  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:40:12] [ok] https://github.com/creativepsyco/secondary-dex-gradle -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\creativepsyco__secondary-dex-gradle  commits=38  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:40:41] [ok] https://github.com/spacecowboy/Feeder -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\spacecowboy__Feeder  commits=5240  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:41:08] [ok] https://github.com/TeamAmaze/AmazeFileManager -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\TeamAmaze__AmazeFileManager  commits=9071  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:41:24] [ok] https://github.com/f-droid/fdroidclient -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\f-droid__fdroidclient  commits=11028  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:41:26] [ok] https://github.com/quemb/QMBForm -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\quemb__QMBForm  commits=231  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:41:28] [ok] https://github.com/tripadvisor/android-clockseekbar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\tripadvisor__android-clockseekbar  commits=65  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:41:30] [ok] https://github.com/cgutman/USBIPServerForAndroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\cgutman__USBIPServerForAndroid  commits=43  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:41:52] [ok] https://github.com/iSoron/uhabits -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\iSoron__uhabits  commits=3659  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:41:57] [error] https://github.com/ksoichiro/Android-ObservableScrollView  auth=None token_slot=None attempts=None
# [2025-12-14 22:42:31] [ok] https://github.com/smartdevicelink/sdl_java_suite -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\smartdevicelink__sdl_java_suite  commits=8003  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:43:59] [ok] https://github.com/fossasia/badgemagic-app -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\fossasia__badgemagic-app  commits=2731  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:44:01] [ok] https://github.com/thyrlian/AwesomeValidation -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\thyrlian__AwesomeValidation  commits=482  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:44:04] [ok] https://github.com/MostafaGazar/soas -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\MostafaGazar__soas  commits=69  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:44:07] [ok] https://github.com/Stuart-campbell/RushOrm -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Stuart-campbell__RushOrm  commits=216  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:44:39] [ok] https://github.com/posm/OpenMapKitAndroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\posm__OpenMapKitAndroid  commits=619  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:44:41] [ok] https://github.com/CarlosMChica/easyrecycleradapters -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\CarlosMChica__easyrecycleradapters  commits=161  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:44:42] [ok] https://github.com/kost/NetworkMapper -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\kost__NetworkMapper  commits=71  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:44:51] [ok] https://github.com/dart-lang/http -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\dart-lang__http  commits=4433  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:45:02] [ok] https://github.com/Antox/Antox -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Antox__Antox  commits=4083  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:45:05] [ok] https://github.com/JakeWharton/RxBinding -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\JakeWharton__RxBinding  commits=1003  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:45:15] [ok] https://github.com/moezbhatti/qksms -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\moezbhatti__qksms  commits=2673  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:45:17] [ok] https://github.com/takahirom/PreLollipopTransition -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\takahirom__PreLollipopTransition  commits=169  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:45:35] [ok] https://github.com/SilenceIM/Silence -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\SilenceIM__Silence  commits=3167  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:46:22] [ok] https://github.com/ooni/probe-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ooni__probe-android  commits=4444  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:46:24] [ok] https://github.com/jjhesk/hkm-progress-button -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jjhesk__hkm-progress-button  commits=71  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:46:27] [ok] https://github.com/hitherejoe/HackerNewsReader -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\hitherejoe__HackerNewsReader  commits=78  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:46:29] [ok] https://github.com/zsoltk/GameOfLife -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\zsoltk__GameOfLife  commits=160  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:46:31] [ok] https://github.com/talenguyen/PrettyBundle -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\talenguyen__PrettyBundle  commits=76  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:46:40] [ok] https://github.com/fewlaps/flone-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\fewlaps__flone-android  commits=152  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:47:17] [ok] https://github.com/square/leakcanary -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\square__leakcanary  commits=3618  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:47:19] [ok] https://github.com/rtoshiro/FullscreenVideoView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\rtoshiro__FullscreenVideoView  commits=55  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:47:22] [ok] https://github.com/kebernet/shortyz -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\kebernet__shortyz  commits=174  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:47:24] [ok] https://github.com/Redgram/redgram-for-reddit -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Redgram__redgram-for-reddit  commits=328  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:47:28] [ok] https://github.com/servo/surfman -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\servo__surfman  commits=1286  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:47:49] [ok] https://github.com/metrodroid/metrodroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\metrodroid__metrodroid  commits=5457  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:47:51] [ok] https://github.com/pilgr/Paper -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\pilgr__Paper  commits=332  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:48:06] [ok] https://github.com/sky-map-team/stardroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\sky-map-team__stardroid  commits=1611  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:48:07] [ok] https://github.com/MichaelEvans/Aftermath -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\MichaelEvans__Aftermath  commits=40  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:48:09] [ok] https://github.com/thiagokimo/Faker -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\thiagokimo__Faker  commits=74  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:48:11] [ok] https://github.com/concretesolutions/canarinho -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\concretesolutions__canarinho  commits=186  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:48:16] [ok] https://github.com/Piwigo/Piwigo-Android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Piwigo__Piwigo-Android  commits=824  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:50:41] [ok] https://github.com/commons-app/apps-android-commons -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\commons-app__apps-android-commons  commits=17845  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:51:59] [ok] https://github.com/TeamNewPipe/NewPipe -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\TeamNewPipe__NewPipe  commits=15659  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:52:01] [ok] https://github.com/promeG/TinyPinyin -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\promeG__TinyPinyin  commits=36  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:52:15] [ok] https://github.com/AAkira/ExpandableLayout -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AAkira__ExpandableLayout  commits=193  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:52:17] [ok] https://github.com/hitherejoe/MVVM_Hacker_News -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\hitherejoe__MVVM_Hacker_News  commits=109  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:52:19] [ok] https://github.com/kakajika/SwipeAwayDialog -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\kakajika__SwipeAwayDialog  commits=32  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:53:18] [ok] https://github.com/getodk/collect -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\getodk__collect  commits=27515  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:53:34] [ok] https://github.com/hannesa2/panoramaGL -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\hannesa2__panoramaGL  commits=833  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:53:36] [ok] https://github.com/ajitsing/ExpenseManager -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ajitsing__ExpenseManager  commits=108  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:53:37] [ok] https://github.com/4eRTuk/audioview -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\4eRTuk__audioview  commits=107  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:54:42] [ok] https://github.com/realm/realm-js -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\realm__realm-js  commits=23286  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:56:19] [error] https://github.com/sqldelight/sqldelight  auth=None token_slot=None attempts=None
# [2025-12-14 22:56:31] [ok] https://github.com/sangcomz/FishBun -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\sangcomz__FishBun  commits=792  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:56:33] [ok] https://github.com/requery/requery -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\requery__requery  commits=970  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:56:36] [ok] https://github.com/artem-zinnatullin/qualitymatters -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\artem-zinnatullin__qualitymatters  commits=388  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:56:56] [ok] https://github.com/fossasia/loklak_wok_android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\fossasia__loklak_wok_android  commits=164  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:57:24] [ok] https://github.com/andreynovikov/trekarta -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\andreynovikov__trekarta  commits=1705  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:57:26] [ok] https://github.com/liangpengfei/LoadingPopPoint -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\liangpengfei__LoadingPopPoint  commits=25  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:57:31] [ok] https://github.com/douzifly/clear-todolist -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\douzifly__clear-todolist  commits=127  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:57:45] [ok] https://github.com/sitefinitysteve/nativescript-auth0 -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\sitefinitysteve__nativescript-auth0  commits=323  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:57:53] [ok] https://github.com/VREMSoftwareDevelopment/WiFiAnalyzer -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\VREMSoftwareDevelopment__WiFiAnalyzer  commits=2143  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:58:01] [ok] https://github.com/justjanne/QuasselDroid-ng -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\justjanne__QuasselDroid-ng  commits=1459  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:58:29] [ok] https://github.com/software-mansion/react-native-svg -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\software-mansion__react-native-svg  commits=5203  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:58:33] [ok] https://github.com/whilu/AndroidTagView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\whilu__AndroidTagView  commits=121  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:58:39] [ok] https://github.com/grandstaish/paperparcel -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\grandstaish__paperparcel  commits=801  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:58:41] [ok] https://github.com/XuDaojie/MultiStateView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\XuDaojie__MultiStateView  commits=85  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:58:47] [ok] https://github.com/TUBB/CalendarSelector -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\TUBB__CalendarSelector  commits=49  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:58:54] [ok] https://github.com/greenaddress/abcore -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\greenaddress__abcore  commits=435  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:58:55] [ok] https://github.com/woxingxiao/FillBlankView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\woxingxiao__FillBlankView  commits=52  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:58:57] [ok] https://github.com/FabianTerhorst/Iron -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\FabianTerhorst__Iron  commits=218  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:58:58] [ok] https://github.com/riggaroo/AndroidDatabaseUpgrades -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\riggaroo__AndroidDatabaseUpgrades  commits=16  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:59:11] [ok] https://github.com/caarmen/poet-assistant -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\caarmen__poet-assistant  commits=1246  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:59:14] [ok] https://github.com/amitshekhariitbhu/Fast-Android-Networking -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\amitshekhariitbhu__Fast-Android-Networking  commits=719  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:59:19] [ok] https://github.com/voghDev/PdfViewPager -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\voghDev__PdfViewPager  commits=281  auth=https-token token_slot=4 attempts=1
# [2025-12-14 22:59:23] [ok] https://github.com/renyuneyun/Easer -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\renyuneyun__Easer  commits=1631  auth=https-token token_slot=5 attempts=1
# [2025-12-14 22:59:26] [ok] https://github.com/nukc/StateView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\nukc__StateView  commits=86  auth=https-token token_slot=6 attempts=1
# [2025-12-14 22:59:30] [ok] https://github.com/yeungeek/monkey-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\yeungeek__monkey-android  commits=124  auth=https-token token_slot=1 attempts=1
# [2025-12-14 22:59:39] [ok] https://github.com/maksim-m/Popular-Movies-App -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\maksim-m__Popular-Movies-App  commits=157  auth=https-token token_slot=2 attempts=1
# [2025-12-14 22:59:44] [ok] https://github.com/RoRoche/AndroidStarter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\RoRoche__AndroidStarter  commits=93  auth=https-token token_slot=3 attempts=1
# [2025-12-14 22:59:50] [ok] https://github.com/ValentinFunk/BrainPhaser -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ValentinFunk__BrainPhaser  commits=411  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:00:00] [ok] https://github.com/elixsr/FwdPortForwardingApp -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\elixsr__FwdPortForwardingApp  commits=95  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:00:03] [ok] https://github.com/tonilopezmr/Game-of-Thrones -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\tonilopezmr__Game-of-Thrones  commits=230  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:00:04] [ok] https://github.com/osama-raddad/FireCrasher -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\osama-raddad__FireCrasher  commits=206  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:00:07] [ok] https://github.com/SecUSo/privacy-friendly-notes -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\SecUSo__privacy-friendly-notes  commits=673  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:00:23] [ok] https://github.com/SecUSo/privacy-friendly-todo-list -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\SecUSo__privacy-friendly-todo-list  commits=719  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:00:24] [ok] https://github.com/dbrodie/AdBuster -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\dbrodie__AdBuster  commits=101  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:03:55] [ok] https://github.com/nextcloud/android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\nextcloud__android  commits=60050  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:04:01] [ok] https://github.com/javiersantos/PiracyChecker -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\javiersantos__PiracyChecker  commits=300  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:04:03] [ok] https://github.com/karonl/InDoorSurfaceView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\karonl__InDoorSurfaceView  commits=67  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:04:07] [ok] https://github.com/miguelhincapie/CustomBottomSheetBehavior -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\miguelhincapie__CustomBottomSheetBehavior  commits=171  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:04:15] [ok] https://github.com/SecUSo/privacy-friendly-pedometer -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\SecUSo__privacy-friendly-pedometer  commits=522  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:04:16] [ok] https://github.com/NightlyNexus/ViewStatePagerAdapter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\NightlyNexus__ViewStatePagerAdapter  commits=47  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:04:19] [ok] https://github.com/y-polek/TransmissionRemote -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\y-polek__TransmissionRemote  commits=953  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:04:21] [ok] https://github.com/medic/cht-gateway -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\medic__cht-gateway  commits=822  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:04:33] [ok] https://github.com/cliqz-oss/browser-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\cliqz-oss__browser-android  commits=927  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:04:42] [ok] https://github.com/andremion/Villains-and-Heroes -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\andremion__Villains-and-Heroes  commits=129  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:08:08] [ok] https://github.com/streetcomplete/StreetComplete -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\streetcomplete__StreetComplete  commits=17930  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:08:13] [ok] https://github.com/leandroBorgesFerreira/LoadingButtonAndroid -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\leandroBorgesFerreira__LoadingButtonAndroid  commits=380  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:08:17] [ok] https://github.com/jaredsburrows/android-gif-search -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jaredsburrows__android-gif-search  commits=2706  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:53:01] [error] https://github.com/expo/expo  (Command '['git', '-c', 'http.https://github.com/.extraheader=Authorization: Basic eC1hY2Nlc3MtdG9rZW46Z2hwX09XdGJpUEtVRDFvbDJLcmdOOW11bzlFbFZmaVNsWjB3c0Vnaw==', 'clone', '--no-single-branch', '--no-recurse-submodules', '--tags', '--quiet', 'https://github.com/expo/expo', 'C:\\Android Mobile App\\Step3_Instr_Testing_Analysis\\Type_1\\Aug_10\\ICST2026\\3 - RQ3\\Clone\\expo__expo']' timed out after 1800 seconds)
# [2025-12-14 23:53:18] [ok] https://github.com/beemdevelopment/Aegis -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\beemdevelopment__Aegis  commits=1918  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:53:20] [ok] https://github.com/nukc/LoadMoreWrapper -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\nukc__LoadMoreWrapper  commits=73  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:54:27] [ok] https://github.com/topjohnwu/Magisk -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\topjohnwu__Magisk  commits=12216  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:54:32] [ok] https://github.com/ligi/SurvivalManual -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ligi__SurvivalManual  commits=806  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:54:34] [ok] https://github.com/gotev/android-speech -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\gotev__android-speech  commits=170  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:54:36] [ok] https://github.com/Piasy/YaMvp -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Piasy__YaMvp  commits=12  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:54:38] [ok] https://github.com/FabianTerhorst/Floppy -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\FabianTerhorst__Floppy  commits=77  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:54:39] [ok] https://github.com/pakoito/FunctionalAndroidReference -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\pakoito__FunctionalAndroidReference  commits=281  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:55:20] [ok] https://github.com/guardianproject/proofmode-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\guardianproject__proofmode-android  commits=946  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:55:28] [ok] https://github.com/vgaidarji/ci-matters -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\vgaidarji__ci-matters  commits=178  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:55:34] [ok] https://github.com/BennyKok/PxerStudio -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\BennyKok__PxerStudio  commits=186  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:55:37] [ok] https://github.com/freeotp/freeotp-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\freeotp__freeotp-android  commits=653  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:55:39] [ok] https://github.com/VictorAlbertos/BreadcrumbsView -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\VictorAlbertos__BreadcrumbsView  commits=12  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:55:41] [ok] https://github.com/ronaldsmartin/Material-ViewPagerIndicator -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ronaldsmartin__Material-ViewPagerIndicator  commits=130  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:55:43] [ok] https://github.com/patloew/RxLocation -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\patloew__RxLocation  commits=41  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:55:45] [ok] https://github.com/PureWriter/about-page -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\PureWriter__about-page  commits=159  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:55:46] [ok] https://github.com/VictorAlbertos/SwipeCoordinator -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\VictorAlbertos__SwipeCoordinator  commits=9  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:55:48] [ok] https://github.com/tmurakami/dexopener -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\tmurakami__dexopener  commits=535  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:56:31] [error] https://github.com/kickstarter/android-oss  auth=None token_slot=None attempts=None
# [2025-12-14 23:56:33] [ok] https://github.com/JoaquimLey/faboptions -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\JoaquimLey__faboptions  commits=113  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:56:36] [ok] https://github.com/michelelacorte/AndroidAppShortcuts -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\michelelacorte__AndroidAppShortcuts  commits=146  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:56:45] [ok] https://github.com/massivedisaster/ADAL -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\massivedisaster__ADAL  commits=598  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:58:09] [ok] https://github.com/getsentry/sentry-react-native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\getsentry__sentry-react-native  commits=13308  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:58:14] [ok] https://github.com/AdevintaSpain/Barista -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\AdevintaSpain__Barista  commits=1675  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:58:18] [ok] https://github.com/F4uzan/HgLauncher -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\F4uzan__HgLauncher  commits=1646  auth=https-token token_slot=1 attempts=1
# [2025-12-14 23:58:20] [ok] https://github.com/bilibili/boxing -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\bilibili__boxing  commits=139  auth=https-token token_slot=2 attempts=1
# [2025-12-14 23:58:25] [ok] https://github.com/jungilhan/awesome-blogs-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jungilhan__awesome-blogs-android  commits=292  auth=https-token token_slot=3 attempts=1
# [2025-12-14 23:58:27] [ok] https://github.com/MarcinMoskala/PreferenceHolder -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\MarcinMoskala__PreferenceHolder  commits=129  auth=https-token token_slot=4 attempts=1
# [2025-12-14 23:58:35] [ok] https://github.com/NiciDieNase/chaosflix -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\NiciDieNase__chaosflix  commits=1612  auth=https-token token_slot=5 attempts=1
# [2025-12-14 23:58:39] [ok] https://github.com/adorsys/secure-storage-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\adorsys__secure-storage-android  commits=325  auth=https-token token_slot=6 attempts=1
# [2025-12-14 23:58:58] [ok] https://github.com/JimmyDaddy/react-native-image-marker -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\JimmyDaddy__react-native-image-marker  commits=470  auth=https-token token_slot=1 attempts=1
# ...
# [2025-12-15 01:38:14] [ok] https://github.com/briar/briar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\briar__briar  commits=9223  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:38:27] [ok] https://github.com/Five-Prayers/five-prayers-android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Five-Prayers__five-prayers-android  commits=601  auth=https-token token_slot=6 attempts=1
# [2025-12-15 01:38:34] [ok] https://github.com/v2er-app/Android -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\v2er-app__Android  commits=1698  auth=https-token token_slot=1 attempts=1
# [2025-12-15 01:38:36] [ok] https://github.com/thevindu-w/clip_share_client -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\thevindu-w__clip_share_client  commits=330  auth=https-token token_slot=2 attempts=1
# [2025-12-15 01:38:38] [ok] https://github.com/VRatMIT/TheSingularity-Unity -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\VRatMIT__TheSingularity-Unity  commits=22  auth=https-token token_slot=3 attempts=1
# [2025-12-15 01:38:58] [ok] https://github.com/Hny0305Lin/NLChat -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Hny0305Lin__NLChat  commits=237  auth=https-token token_slot=4 attempts=1
# [2025-12-15 01:39:03] [ok] https://github.com/ably/ably-flutter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ably__ably-flutter  commits=4153  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:42:15] [ok] https://github.com/jerson/flutter-rsa -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jerson__flutter-rsa  commits=404  auth=https-token token_slot=6 attempts=1
# [2025-12-15 01:43:39] [ok] https://github.com/jerson/flutter-openpgp -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\jerson__flutter-openpgp  commits=416  auth=https-token token_slot=1 attempts=1
# [2025-12-15 01:43:56] [ok] https://github.com/isar/isar -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\isar__isar  commits=2304  auth=https-token token_slot=2 attempts=1
# [2025-12-15 01:44:24] [ok] https://github.com/am15h/tflite_flutter_helper -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\am15h__tflite_flutter_helper  commits=165  auth=https-token token_slot=3 attempts=1
# [2025-12-15 01:44:52] [ok] https://github.com/privacybydesign/irmamobile -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\privacybydesign__irmamobile  commits=5369  auth=https-token token_slot=4 attempts=1
# [2025-12-15 01:44:55] [ok] https://github.com/salvadordeveloper/flutter-crypto-app -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\salvadordeveloper__flutter-crypto-app  commits=31  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:47:07] [ok] https://github.com/linagora/tmail-flutter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\linagora__tmail-flutter  commits=21921  auth=https-token token_slot=6 attempts=1
# [2025-12-15 01:48:01] [ok] https://github.com/SharezoneApp/sharezone-app -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\SharezoneApp__sharezone-app  commits=8114  auth=https-token token_slot=1 attempts=1
# [2025-12-15 01:49:09] [ok] https://github.com/acterglobal/a3 -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\acterglobal__a3  commits=14331  auth=https-token token_slot=2 attempts=1
# [2025-12-15 01:49:26] [ok] https://github.com/alphacep/vosk-flutter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\alphacep__vosk-flutter  commits=111  auth=https-token token_slot=3 attempts=1
# [2025-12-15 01:49:48] [ok] https://github.com/abdelaziz-mahdy/pytorch_lite -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\abdelaziz-mahdy__pytorch_lite  commits=341  auth=https-token token_slot=4 attempts=1
# [2025-12-15 01:49:51] [ok] https://github.com/passsy/spot -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\passsy__spot  commits=1111  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:49:53] [ok] https://github.com/zeref278/flutter_boilerplate -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\zeref278__flutter_boilerplate  commits=63  auth=https-token token_slot=6 attempts=1
# [2025-12-15 01:50:26] [ok] https://github.com/dart-lang/native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\dart-lang__native  commits=6963  auth=https-token token_slot=1 attempts=1
# [2025-12-15 01:50:32] [ok] https://github.com/flet-dev/serious-python -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\flet-dev__serious-python  commits=690  auth=https-token token_slot=2 attempts=1
# [2025-12-15 01:50:47] [ok] https://github.com/natsuk4ze/gal -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\natsuk4ze__gal  commits=1460  auth=https-token token_slot=3 attempts=1
# [2025-12-15 01:50:52] [ok] https://github.com/a-mabe/OpenHIIT -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\a-mabe__OpenHIIT  commits=1034  auth=https-token token_slot=4 attempts=1
# [2025-12-15 01:50:58] [ok] https://github.com/firebase/FirebaseUI-Flutter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\firebase__FirebaseUI-Flutter  commits=1311  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:51:01] [ok] https://github.com/microservicer/flutter-pipelines -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\microservicer__flutter-pipelines  commits=385  auth=https-token token_slot=6 attempts=1
# [2025-12-15 01:51:04] [ok] https://github.com/Bdaya-Dev/oidc -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Bdaya-Dev__oidc  commits=850  auth=https-token token_slot=1 attempts=1
# [2025-12-15 01:51:28] [ok] https://github.com/brandonp2412/FitBook -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\brandonp2412__FitBook  commits=847  auth=https-token token_slot=2 attempts=1
# [2025-12-15 01:51:37] [ok] https://github.com/mixpanel/mixpanel-react-native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\mixpanel__mixpanel-react-native  commits=935  auth=https-token token_slot=3 attempts=1
# [2025-12-15 01:51:40] [ok] https://github.com/andriydruk/swift-weather-app -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\andriydruk__swift-weather-app  commits=70  auth=https-token token_slot=4 attempts=1
# [2025-12-15 01:51:50] [ok] https://github.com/PhoneVR-Developers/PhoneVR -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\PhoneVR-Developers__PhoneVR  commits=958  auth=https-token token_slot=5 attempts=1
# [2025-12-15 01:51:52] [ok] https://github.com/Yoonit-Labs/nativescript-yoonit-camera -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Yoonit-Labs__nativescript-yoonit-camera  commits=374  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:17:53] [error] https://github.com/organicmaps/organicmaps  auth=None token_slot=None attempts=None
# [2025-12-15 02:17:57] [ok] https://github.com/invertase/react-native-google-mobile-ads -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\invertase__react-native-google-mobile-ads  commits=2068  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:18:50] [error] https://github.com/jameshnsears/QuoteUnquote  auth=None token_slot=None attempts=None
# [2025-12-15 02:18:51] [ok] https://github.com/erkkah/naett -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\erkkah__naett  commits=170  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:18:54] [ok] https://github.com/mrrfv/open-android-backup -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\mrrfv__open-android-backup  commits=294  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:19:11] [ok] https://github.com/THEOplayer/react-native-theoplayer -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\THEOplayer__react-native-theoplayer  commits=4938  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:19:41] [error] https://github.com/haiyangwu/mediasoup-client-android  auth=None token_slot=None attempts=None
# [2025-12-15 02:19:52] [ok] https://github.com/ReactiveCircus/android-emulator-runner -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ReactiveCircus__android-emulator-runner  commits=678  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:19:55] [ok] https://github.com/openthread/ot-commissioner -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\openthread__ot-commissioner  commits=1482  auth=https-token token_slot=3 attempts=1
# [2025-12-15 02:20:11] [ok] https://github.com/XRPL-Labs/Xaman-App -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\XRPL-Labs__Xaman-App  commits=2986  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:20:12] [ok] https://github.com/xuyuanxiang/umi-react-native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\xuyuanxiang__umi-react-native  commits=389  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:20:34] [ok] https://github.com/synonymdev/bitkit -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\synonymdev__bitkit  commits=5956  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:21:45] [ok] https://github.com/streetwriters/notesnook -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\streetwriters__notesnook  commits=21144  auth=https-token token_slot=1 attempts=1
# [2025-12-15 02:21:51] [ok] https://github.com/twilio/twilio-voice-react-native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\twilio__twilio-voice-react-native  commits=1874  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:22:05] [ok] https://github.com/mlcommons/mobile_app_open -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\mlcommons__mobile_app_open  commits=4033  auth=https-token token_slot=3 attempts=1
# [2025-12-15 02:22:08] [ok] https://github.com/aws/amazon-ivs-react-native-player -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\aws__amazon-ivs-react-native-player  commits=650  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:22:30] [ok] https://github.com/Picovoice/cobra -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Picovoice__cobra  commits=1166  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:22:54] [error] https://github.com/inaturalist/iNaturalistReactNative  auth=None token_slot=None attempts=None
# [2025-12-15 02:29:59] [error] https://github.com/LedgerHQ/ledger-live  auth=None token_slot=None attempts=None
# [2025-12-15 02:30:06] [ok] https://github.com/fingerprintjs/fingerprintjs-pro-react-native -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\fingerprintjs__fingerprintjs-pro-react-native  commits=978  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:31:49] [ok] https://github.com/pytorch/executorch -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\pytorch__executorch  commits=69979  auth=https-token token_slot=3 attempts=1
# [2025-12-15 02:32:01] [ok] https://github.com/EnsembleUI/ensemble -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\EnsembleUI__ensemble  commits=8728  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:32:03] [ok] https://github.com/elftausend/custos -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\elftausend__custos  commits=1750  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:32:19] [ok] https://github.com/haqq-network/haqq-wallet -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\haqq-network__haqq-wallet  commits=9061  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:32:33] [ok] https://github.com/Picovoice/koala -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Picovoice__koala  commits=428  auth=https-token token_slot=1 attempts=1
# [2025-12-15 02:33:05] [ok] https://github.com/lovegaoshi/azusa-player-mobile -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\lovegaoshi__azusa-player-mobile  commits=5055  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:33:22] [ok] https://github.com/juancastillo0/wasm_run -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\juancastillo0__wasm_run  commits=550  auth=https-token token_slot=3 attempts=1
# [2025-12-15 02:33:46] [ok] https://github.com/ice-blockchain/mobile-app -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ice-blockchain__mobile-app  commits=1704  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:34:40] [ok] https://github.com/zkmopro/mopro -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\zkmopro__mopro  commits=2917  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:34:55] [ok] https://github.com/Picovoice/falcon -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Picovoice__falcon  commits=296  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:35:00] [ok] https://github.com/prisma/react-native-prisma -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\prisma__react-native-prisma  commits=427  auth=https-token token_slot=1 attempts=1
# [2025-12-15 02:35:02] [ok] https://github.com/ianthetechie/uniffi-starter -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ianthetechie__uniffi-starter  commits=104  auth=https-token token_slot=2 attempts=1
# [2025-12-15 02:36:45] [ok] https://github.com/Picovoice/picollm -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Picovoice__picollm  commits=569  auth=https-token token_slot=3 attempts=1
# [2025-12-15 02:36:58] [ok] https://github.com/ICBNetwork/web3-Wallet -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\ICBNetwork__web3-Wallet  commits=1  auth=https-token token_slot=4 attempts=1
# [2025-12-15 02:37:50] [ok] https://github.com/Jellify-Music/App -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\Jellify-Music__App  commits=5460  auth=https-token token_slot=5 attempts=1
# [2025-12-15 02:38:05] [ok] https://github.com/1q23lyc45/KitsuneMagisk -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone\1q23lyc45__KitsuneMagisk  commits=6974  auth=https-token token_slot=6 attempts=1
# [2025-12-15 02:38:05] Done. OK=459, FAIL=21. Manifest: C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\clones_manifest_V1.csv

# %% [markdown]
# ## Step 2: Mining
# add a baseline to read the repos from the begining not from the first change

# %%
from __future__ import annotations

import csv
import json
import os
import random
import re
import shutil
import subprocess
import sys
import time
from concurrent.futures import ThreadPoolExecutor as PoolExecutor, as_completed
from datetime import datetime
from functools import lru_cache
from pathlib import Path
from typing import Dict, Iterable, List, Optional, Set, Tuple

# ===========================
# Config (EDIT THESE PATHS)
# ===========================
WORK_ROOT    = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3")
INPUT_CLONES = WORK_ROOT / "Clone"     # <-- point to your upgraded clone folder
OUTPUT_MINE  = WORK_ROOT / "Mine"

# Study end date (UTC)
CUTOFF_ISO = "2025-08-10 23:59:59 +0000"

# IMPORTANT: Default branch ONLY (first-parent)
TIMELINE_SCOPE = "default_first_parent"  # fixed; do not change

# Performance / behavior toggles
MAX_REPOS = 0  # 0 = all
MAX_WORKERS = min(32, (os.cpu_count() or 8) * 2)
RESUME_IF_EXISTS = True
SUPPRESS_EMPTY_ROWS = True
CAPTURE_EMPTY_GAPS = True
EMIT_NONE_STATE = False

# Blob size guards
BLOB_MAX_SIZE = 2_000_000
HARD_MAX_SIZE = 5_000_000

# Workflow-expansion bounds (prevents explosion)
EXPAND_MAX_DEPTH = 3
EXPAND_MAX_FILES = 250
EXPAND_MAX_TEXT_CHARS = 5_000_000

# High-priority CI paths never skipped (even if large)
HIGH_PRIORITY_CI_PATHS = {
    ".github/workflows",
    ".gitlab-ci.yml",
    "azure-pipelines.yml",
    ".circleci/config.yml",
    ".bitrise.yml",
    ".travis.yml",
}

# CI entrypoints (cut-off procedure)
CI_ENTRYPOINTS_EXACT = {
    ".travis.yml",
    ".gitlab-ci.yml",
    "azure-pipelines.yml",
    "circle.yml",
    ".bitrise.yml",
    ".circleci/config.yml",
}
GHA_WORKFLOWS_DIR = ".github/workflows"

# ===========================
# Quick startup checks
# ===========================
def _failfast_checks() -> None:
    if shutil.which("git") is None:
        print("[fatal] Git not found in PATH. Install Git and/or add it to PATH.", file=sys.stderr)
        raise SystemExit(1)
    if not WORK_ROOT.exists():
        print(f"[fatal] WORK_ROOT does not exist: {WORK_ROOT}", file=sys.stderr)
        raise SystemExit(1)
    if not INPUT_CLONES.exists():
        print(f"[warn] INPUT_CLONES does not exist yet: {INPUT_CLONES}")
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

# ===========================
# File classifiers
# ===========================
YAML_EXTS = (".yml", ".yaml")
GRADLE_NAMES = {"build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts"}
GRADLE_EXTS = (".gradle", ".gradle.kts")

SCRIPT_EXTS = (".sh", ".bat", ".cmd", ".ps1", ".py", ".js", ".rb", ".pl")
CI_BUILD_SPECIAL = {"Jenkinsfile", ".travis.yml", "azure-pipelines.yml", ".gitlab-ci.yml", "circle.yml", ".bitrise.yml"}
XML_BUILD_FILES = {"pom.xml", "build.xml", "config.xml"}

def is_yaml(path: str) -> bool:
    return os.path.splitext(path)[1].lower() in YAML_EXTS or os.path.basename(path) in CI_BUILD_SPECIAL

def is_gradle(path: str) -> bool:
    name = os.path.basename(path)
    ext = os.path.splitext(path)[1].lower()
    return name in GRADLE_NAMES or ext in GRADLE_EXTS

def is_script(path: str) -> bool:
    ext = os.path.splitext(path)[1].lower()
    return ext in SCRIPT_EXTS or os.path.basename(path) in ("Jenkinsfile",)

def is_ci_xml_or_build_xml(path: str) -> bool:
    return os.path.basename(path).lower() in {n.lower() for n in XML_BUILD_FILES}

def is_relevant_file(path: str) -> bool:
    return is_yaml(path) or is_gradle(path) or is_script(path) or is_ci_xml_or_build_xml(path)

def is_high_priority_ci_path(path: str) -> bool:
    norm = path.replace("\\", "/")
    base = os.path.basename(norm)
    if base in HIGH_PRIORITY_CI_PATHS:
        return True
    for root in HIGH_PRIORITY_CI_PATHS:
        if norm.startswith(root.rstrip("/") + "/"):
            return True
    return False

# ===========================
# Regex helpers & normalizers
# ===========================
COMMENT_LINE_RE = re.compile(r"(?m)^\s*(#|//|REM\b|::).*?$")

def strip_comments(raw: str) -> str:
    return COMMENT_LINE_RE.sub("", raw or "")

# --- Gradle comment stripper (preserves http(s)://) ---
def strip_comments_gradle(text: str) -> str:
    if not text:
        return ""
    s = re.sub(r"/\*.*?\*/", "", text, flags=re.S)                 # /* ... */
    s = re.sub(r"(?<!:)//.*?$", "", s, flags=re.M)                  # // ...
    return s

def normalize_block_keys(text: str) -> str:
    # expose content of run/script/command keys and drop YAML dashes before likely shell lines
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(?!\||>|\|\-)\s*(.+)$", r"\2", text)
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(\||>|\|\-)\s*$", "", text)
    text = re.sub(
        r"(?m)^(\s*)-\s*(?=(?:\./|\.\\|bash|sh|pwsh|powershell|python(?:3)?|node|ruby|perl|gradle(?:w)?|adb|flutter|gcloud|saucectl|appcenter)\b)",
        r"\1",
        text,
    )
    return text

IGNORE_GHA_ACTIONS_RE = re.compile(
    r"(?mi)^\s*uses\s*:\s*(docker/(?:setup-qemu-action|setup-buildx-action|build-push-action|login-action)|actions/checkout|docker/setup-qemu-action|docker/setup-buildx-action)@.*$"
)

def strip_irrelevant_ci_lines(text: str) -> str:
    return IGNORE_GHA_ACTIONS_RE.sub("", text or "")

# --- Excluded Gradle task sanitizer (align with YAML scanner) ---
EXCLUDED_TASK_SEGMENT_RE = re.compile(
    r'(^|\s)(?:-x|--exclude-task)\s+(["\']?)[:\w\.-]*(?:androidtest|baselineprofile)[\w:\.-]*\2\b',
    re.IGNORECASE | re.MULTILINE,
)

def remove_excluded_gradle_tasks(text: str) -> str:
    return EXCLUDED_TASK_SEGMENT_RE.sub(lambda m: (m.group(1) or " "), text or "")

GHA_EXPR_RE = re.compile(r"\${{\s*[^}]+}}")

def pre_sanitize_for_triggers(text: str) -> str:
    # For detection matching: remove excluded tasks + GHA expressions
    t = remove_excluded_gradle_tasks(text or "")
    return GHA_EXPR_RE.sub("", t)

def unique_preserve(seq: Iterable[str]) -> List[str]:
    seen: Set[str] = set()
    out: List[str] = []
    for x in seq:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

def compile_any(patterns: List[str], flags: int = re.I | re.M) -> List[re.Pattern]:
    return [re.compile(p, flags) for p in patterns]

def any_match(patterns: Iterable, text: str) -> bool:
    for p in patterns:
        if isinstance(p, str):
            p = re.compile(p, re.I | re.M)
        if p.search(text):
            return True
    return False

# ===========================
# Detection patterns (core)
# ===========================
GRADLE_PREFIX = (
    r"^\s*"
    r"(?:\S+=\S+\s+)*"
    r"(?:sudo\s+)?"
    r"(?:(?:bash|sh)\s+-c[l]?\s+[\'\"]?)?"
    r"(?:[^#\n;]*?&&\s+)?"
    r"(?:cd\s+\S+\s+&&\s+)?"
    r"(?:\./|\.\\)?gradle(?:w)?(?:\.bat)?"
)
GRADLE_ANYWHERE = r"(?i)[^\n]*\bgradle(?:w)?(?:\.bat)?[^\n]*"
GRADLE_ANYWHERE_RE = re.compile(GRADLE_ANYWHERE)
GRADLE_BUILD_ACTION_RE = re.compile(r"(?mi)\buses\s*:\s*(gradle/gradle-build-action|gradle/actions/setup-gradle)@")
NON_TEST_PREFIX = r"(?:assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)"
SHELL_PREFIX = r"(?:\S+=\S+\s+)*(?:sudo\s+)?(?:(?:bash|sh|pwsh|powershell|python(?:3)?|node|ruby|perl)\s+-c\s+[\'\"]?)?(?:[^#\n;]*?&&\s+)?"

EMULATOR_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}(?:\s|^)(?:(?:\./|\.\\)?(?:emulator)(?:\.exe)?)\b[^\n]*-avd\s+\S+"
ADB_WAIT_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+wait[- ]?for[- ]?device\b"
ADB_SERIAL_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+-s\s+(?:emulator-\d+|localhost:\d+|127\.0\.0\.1:\d+)"

# NOTE: Real devices are out of scope for evolution. We keep patterns out of styles/events.
# If you truly want to “not detect” them at all, remove the Real_Device entry below.
REAL_DEVICE_LINE = rf"(?mi)^\s*adb\s+-s\s+(?!emulator-\d+\b)(?!localhost:\d+\b)(?!127\.0\.0\.1:\d+\b)\S+\b"

DEVICE_SOURCES = [
    # (Optional, out-of-scope for style evolution; kept only for strict Flutter gating parity)
    ("Real_Device", "adb -s <serial> (physical)", [REAL_DEVICE_LINE]),

    ("Emulator", "adb -s emulator-serial", [ADB_SERIAL_LINE]),
    ("Emulator", "adb wait-for-device", [ADB_WAIT_LINE]),
    ("Emulator", "emulator -avd/@", [EMULATOR_LINE]),
    ("Emulator", "android-wait-for-emulator", [r"(?mi)^\s*(?:\./)?android-wait-for-emulator\b"]),
    ("Emulator", "start-emulator.sh", [r"(?mi)^\s*start-emulator\.sh\b"]),
    ("Emulator", "android create avd", [r"\bandroid\b[^\n]*\bcreate\s+avd\b"]),
    ("Emulator", "circleci android orb", [
        r"(?mi)^\s*(?:-\s*)?android/(?:start-emulator-and-run-tests|create-avd|launch-emulator)\s*:",
        r"(?mi)^\s*system-image\s*:\s*system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*);(?:default|google_apis)[^\s]*"
    ]),
    ("Emulator", "reactivecircus runner", [r"(?mi)\buses\s*:\s*reactivecircus/android-emulator-runner@[\w\.\-]+"]),
    ("Emulator", "malinskiy runner", [r"(?mi)\buses\s*:\s*malinskiy/action-android/emulator-run-cmd@[\w\.\-]+"]),
    ("Emulator", "sys-img component", [
        r"(?m)^\s*-\s*sys-img-[^\s]*-android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b",
        r"(?m)^\s*-\s*sys-img-[^\s]*-google_apis-[^\s]*(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "avdmanager", [r"(?m)^\s*\S*avdmanager\b"]),
    ("Emulator", "sdkmanager system-images/emulator", [
        r'^\s*\S*sdkmanager\b[^\n"]*"system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)[^"\n]*"',
        r"^\s*\S*sdkmanager\b[^\n]*\bsystem-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "other gha emulator", [
        r"(?mi)^\s*uses\s*:\s*vgaidarji/android-github-actions-emulator@[\w\.\-]+",
        r"(?mi)^\s*uses\s*:\s*(?!reactivecircus/android-emulator-runner@)(?!malinskiy/action-android/emulator-run-cmd@)(?!emulator-wtf/run-tests@)[\w\.-]+/[\w\./-]*android[\w\./-]*(?:\bemulator\b|\bavd\b)[\w\./-]*@[\w\.\-]+"
    ]),
    ("Third_Party_Lab", "gcloud firebase", [r"(?mi)^[^\n]*\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "browserstack/bstack", [r"(?i)\b(browserstack|bstack)\b"]),
    ("Third_Party_Lab", "appcenter test", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "maestro cloud", [r"(?mi)^[^\n]*\bmaestro\s+cloud\b"]),
    ("Third_Party_Lab", "emulator.wtf action", [
        r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+",
        r"(?i)\bemulator\.wtf\b"
    ]),
]
DEVICE_PATTERNS = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in DEVICE_SOURCES]

TRIGGER_SOURCES_PRIMARY = [
    ("Gradle", "connectedAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedandroidtest\b[^\n\r]*"]),
    ("Gradle", "connected.*Android.*", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b(?![^\n\r]*\b(?:{NON_TEST_PREFIX})[\w-]*androidtest\b)[^\n\r]*"]),
    ("Gradle", "connectedCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedcheck\b[^\n\r]*"]),
    ("Gradle", "cAT shorthand", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*cAT\b[^\n\r]*"]),
    ("Gradle", "deviceCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b[^\n\r]*"]),
    ("Gradle", "managedDevice AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?!{NON_TEST_PREFIX})(?:manageddevice|device)[\w:-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "variant/device AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "Spoon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bmarathon(?:\w*androidtest)?\b"]),
    ("ADB", "am instrument", [r"(?mi)^[^\n]*\bam\s+instrument\b"]),
    ("Third_Party_Lab", "gcloud firebase (instr)", [r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run[^\n]*\b(--test\b|--type\s+instrumentation\b)"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "appcenter", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "emulator.wtf run", [r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+", r"(?i)\bemulator\.wtf\b"]),
    # BaselineProfile & benchmark tasks (kept as in your miner)
    ("Gradle", "generateBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*generate(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "collectBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*collect(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "connectedBenchmarkAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedbenchmarkandroidtest\b[^\n\r]*"]),
]
TRIGGER_PATTERNS_PRIMARY  = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_PRIMARY]

TRIGGER_SOURCES_ANYWHERE = [
    ("Gradle", "connected (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b"]),
    ("Gradle", "connectedAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedandroidtest\b"]),
    ("Gradle", "connectedCheck (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connectedcheck\b"]),
    ("Gradle", "managedDevice AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b"]),
    ("Gradle", "variant/device AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})[\w-]*androidtest\b"]),
    ("Gradle", "Spoon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bmarathon(?:\w*androidtest)?\b"]),
    ("Gradle", "generateBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bgenerate(?:\w*?)baselineprofile\b"]),
    ("Gradle", "collectBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bcollect(?:\w*?)baselineprofile\b"]),
    ("Gradle", "connectedBenchmarkAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedbenchmarkandroidtest\b"]),
]
TRIGGER_PATTERNS_ANYWHERE = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_ANYWHERE]

def collect_hits_with_groups(patterns, text: str):
    labels = []
    groups = []
    for grp, lbl, pats in patterns:
        if any_match(pats, text):
            labels.append(lbl)
            groups.append(grp)
    return unique_preserve(labels), unique_preserve(groups)

# --- GHA Gradle inputs (kept) ---
GHA_GRADLE_INPUTS = compile_any([
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connectedcheck\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:(?:[:\w-]+:)*) (?!assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)[\w-]*androidtest\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*cAT\b",
])

# --- NEW: GHA GMD inputs (align with YAML scanner) ---
GHA_GMD_INPUTS = compile_any([
    rf"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?!(?:[:\w-]+:)*(?:connected[a-z0-9:._-]*|{NON_TEST_PREFIX})[\w:-]*androidtest\b)(?:[:\w-]+:)*[\w:-]*androidtest\b"
])

# Provider patterns (unchanged)
PROVIDER_PATTERNS = [
    ("emulator-wtf", compile_any([r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@", r"(?i)\bemulator\.wtf\b"])),
    ("firebase-test-lab", compile_any([r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b", r"(?mi)\bflank\s+android\s+run\b"])),
    ("browserstack", compile_any([r"(?i)\bbrowserstack\b", r"(?i)\bbstack\b"])),
    ("sauce-labs", compile_any([r"(?mi)\bsaucectl(?:\s+run)?\b", r"(?mi)\bsauce\s+ctl\b"])),
    ("appcenter", compile_any([r"(?mi)\bappcenter\s+test\s+run\s+android\b"])),
    ("maestro-cloud", compile_any([r"(?mi)\bmaestro\s+cloud\b"])),
]

INLINE_DEVICE_HINTS = compile_any([
    r"(?mi)^\s*devices\s*:\s*\|",
    r"(?mi)\b--device\b",
    r"(?mi)\bmodel\s*=\s*[^,\s]+",
    r"(?mi)\bversion\s*=\s*\d+",
    r"(?mi)\blocale\s*=\s*[-\w]+",
    r"(?mi)\borientation\s*=\s*(portrait|landscape)",
    r"(?mi)^\s*with-orchestrator\s*:\s*true\b",
    r"(?mi)\b--use-orchestrator\b",
    r"(?mi)\bnum-flaky-test-attempts\s*:\s*\d+\b",
    r"(?mi)\b--num-flaky-test-attempts(?:=|\s+)\d+\b",
])

CONFIG_FILE_HINTS = compile_any([
    r"(?mi)\.ewtf\.ya?ml\b",
    r"(?mi)\b(flank\.ya?ml|flank\.android\.ya?ml)\b",
    r"(?mi)\b--config(?:=|\s+)\S+",
    r"(?mi)\b(browserstack\.ya?ml)\b",
    r"(?mi)\b(bs(?:config)?\.ya?ml)\b",
])

ANDROID_CONTEXT_RE = re.compile(
    r"(?i)\b(adb|avd|emulator|android\s+sdk|system-images;android-|androidtest|connected(?:check|androidtest)|gcloud\s+firebase\s+test\s+android\s+run)\b"
)

# ===========================
# NEW: STRICT Flutter gating (align with YAML scanner)
# ===========================
FLUTTER_IT_LINE = re.compile(r"(?mi)^\s*flutter\s+(?:test|drive)\b[^\n]*")
FLUTTER_IT_ANDROID_HINT = re.compile(r"(?i)(integration_test|--driver\b|/integration_test/)")
FLUTTER_DEVICE_FLAG_RE = re.compile(r"(?i)\s+-d\s+(?P<dev>\"[^\"]+\"|'[^']+'|\S+)")
FLUTTER_DEVICE_IS_ANDROID = re.compile(r"(?i)\b(android|emulator-\d+|sdk\s+gphone|android\s+sdk\s+built\s+for|pixel)\b")

ANDROID_RUNTIME_ENV_LABELS = {
    "emulator -avd/@",
    "adb wait-for-device",
    "adb -s emulator-serial",
    "android-wait-for-emulator",
    "start-emulator.sh",
    "reactivecircus runner",
    "malinskiy runner",
    "other gha emulator",
    "circleci android orb",
    # real device label (optional)
    "adb -s <serial> (physical)",
}
ANDROID_STRICT_3P_LABELS = {
    "gcloud firebase",
    "appcenter test",
    "emulator.wtf action",
}

def has_android_runtime_evidence(dev_labels: List[str], dev_groups: List[str]) -> bool:
    lbls = {str(l).strip().lower() for l in (dev_labels or []) if str(l).strip()}
    grps = {str(g).strip() for g in (dev_groups or []) if str(g).strip()}

    if "Real_Device" in grps:
        return True
    if lbls & {s.lower() for s in ANDROID_RUNTIME_ENV_LABELS}:
        return True
    if lbls & {s.lower() for s in ANDROID_STRICT_3P_LABELS}:
        return True
    return False

def flutter_androidish_in_block(block_text: str, dev_labels: List[str], dev_groups: List[str]) -> bool:
    """
    STRICT: Flutter integration tests count only if they explicitly target Android (-d android / emulator-* etc.)
    OR the same block has strong Android runtime evidence (emulator started/waited, emulator runners, etc.).
    """
    hits: List[str] = []
    for m in FLUTTER_IT_LINE.finditer(block_text or ""):
        line = m.group(0) or ""
        if FLUTTER_IT_ANDROID_HINT.search(line) or FLUTTER_DEVICE_IS_ANDROID.search(line):
            hits.append(line)

    if not hits:
        return False

    android_targeted = False
    for line in hits:
        d = FLUTTER_DEVICE_FLAG_RE.search(line)
        if d:
            plat = (d.group("dev") or "").strip('"\''"").lower()
            if (
                plat == "android"
                or plat.startswith("emulator-")
                or "sdk gphone" in plat
                or "android sdk built for" in plat
                or "pixel" in plat
            ):
                android_targeted = True
                break

    if android_targeted:
        return True

    return has_android_runtime_evidence(dev_labels, dev_groups)

# ===========================
# Environment label sets (your updated mapping: DIY->Custom, Malinskiy/Other/ReactiveCircus->Community)
# ===========================
EMULATOR_COMMUNITY_LABELS = {"reactivecircus runner", "malinskiy runner", "other gha emulator", "circleci android orb"}
EMULATOR_CUSTOM_LABELS = {
    "adb -s emulator-serial",
    "adb wait-for-device",
    "emulator -avd/@",
    "android-wait-for-emulator",
    "start-emulator.sh",
    "android create avd",
    "avdmanager",
    "sdkmanager system-images/emulator",
    "sys-img component",
}
THIRD_PARTY_STRONG_LABELS = {"gcloud firebase", "emulator.wtf run", "saucectl", "appcenter test", "browserstack/bstack", "maestro cloud"}
REAL_DEVICE_STRONG_LABELS = {"adb -s <serial> (physical)"}
STRONG_DEVICE_LABELS = EMULATOR_COMMUNITY_LABELS | EMULATOR_CUSTOM_LABELS | THIRD_PARTY_STRONG_LABELS | REAL_DEVICE_STRONG_LABELS

def detect_provider(text: str) -> str:
    for name, pats in PROVIDER_PATTERNS:
        if any_match(pats, text):
            return name
    return "other"

def has_inline_env(text: str) -> bool:
    return any_match(INLINE_DEVICE_HINTS, text)

def has_config_env(text: str) -> bool:
    return any_match(CONFIG_FILE_HINTS, text)

# ===========================
# Gradle GMD config detector
# ===========================
TESTOPTIONS_HEAD = re.compile(r"\btestOptions\s*\{", re.I)
MANAGED_HEAD     = re.compile(r"\bmanagedDevices\s*\{", re.I)
GMD_INNER_TOKENS_RX = re.compile(r"\b(managedDevices|managedVirtualDevice|devices|groups|deviceGroups)\b", re.I)

def _find_block_span_from_head(text: str, head_start: int) -> Optional[Tuple[int, int]]:
    i = text.find("{", head_start)
    if i == -1:
        return None
    depth = 0
    for j in range(i, len(text)):
        ch = text[j]
        if ch == "{":
            depth += 1
        elif ch == "}":
            depth -= 1
            if depth == 0:
                return (i, j)
    return None

def find_gmd_block(text_gradle_no_comments: str) -> bool:
    t = text_gradle_no_comments
    for m in MANAGED_HEAD.finditer(t):
        if _find_block_span_from_head(t, m.start()):
            return True
    for m in TESTOPTIONS_HEAD.finditer(t):
        ci = _find_block_span_from_head(t, m.start())
        if not ci:
            continue
        a, b = ci
        sub = t[a:b+1]
        if GMD_INNER_TOKENS_RX.search(sub):
            return True
    return False

# ===========================
# Git helpers
# ===========================
def run_git(repo: Path, args: List[str], text: bool = True, check: bool = True, retries: int = 2) -> subprocess.CompletedProcess:
    last_exc: Optional[BaseException] = None
    for attempt in range(retries + 1):
        try:
            return subprocess.run(
                ["git", "-C", str(repo)] + args,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=text,
                check=check,
                encoding="utf-8" if text else None,
                errors="replace" if text else None,
            )
        except subprocess.CalledProcessError as e:
            last_exc = e
            time.sleep(0.1 * (attempt + 1) + random.random() * 0.1)
        except Exception as e:
            last_exc = e
            time.sleep(0.05)
    if isinstance(last_exc, subprocess.CalledProcessError) and not check:
        return last_exc  # type: ignore[return-value]
    raise last_exc  # type: ignore[misc]

def list_repos(root: Path) -> List[Path]:
    out: List[Path] = []
    for p, dirs, _files in os.walk(root):
        pth = Path(p)
        if (pth / ".git").exists():
            out.append(pth)
            dirs[:] = []
    return out

def default_branch_ref(repo: Path) -> Optional[str]:
    try:
        ref = run_git(repo, ["symbolic-ref", "refs/remotes/origin/HEAD"], check=False).stdout.strip()
        if ref.startswith("refs/remotes/origin/"):
            return "origin/" + ref.split("refs/remotes/origin/")[1]
    except Exception:
        pass
    for cand in ("origin/main", "origin/master"):
        cp = run_git(repo, ["rev-parse", "--verify", cand], check=False)
        if cp.returncode == 0:
            return cand
    return None

def cutoff_head_default(repo: Path, cutoff_iso: str) -> Optional[str]:
    ref = default_branch_ref(repo)
    if not ref:
        return None
    cp = run_git(repo, ["rev-list", "-n1", "--first-parent", f"--before={cutoff_iso}", ref], check=False)
    sha = (cp.stdout or "").strip()
    return sha or None

def earliest_commit_first_parent(repo: Path, head: str) -> Optional[str]:
    cp = run_git(repo, ["rev-list", "--max-parents=0", "--first-parent", head], check=False)
    s = (cp.stdout or "").strip()
    return s.splitlines()[0] if s else None

def get_commit_date_iso(repo: Path, commit: str) -> Optional[str]:
    try:
        return run_git(repo, ["show", "-s", "--format=%cI", commit]).stdout.strip() or None
    except Exception:
        return None

def commits_touching_relevant_default(repo: Path, head: str) -> List[str]:
    pathspecs = [
        f":(glob){GHA_WORKFLOWS_DIR}/**/*.yml",
        f":(glob){GHA_WORKFLOWS_DIR}/**/*.yaml",
        ".travis.yml",
        ".gitlab-ci.yml",
        "azure-pipelines.yml",
        ".circleci/config.yml",
        ".bitrise.yml",
        "circle.yml",
        ":(glob)**/*.yml",
        ":(glob)**/*.yaml",
        "build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts",
        ":(glob)**/*.gradle", ":(glob)**/*.gradle.kts",
        "Jenkinsfile",
        ":(glob)**/*.sh", ":(glob)**/*.bat", ":(glob)**/*.cmd", ":(glob)**/*.ps1",
        ":(glob)**/*.py", ":(glob)**/*.js", ":(glob)**/*.rb", ":(glob)**/*.pl",
        ":(glob)**/pom.xml", ":(glob)**/build.xml", ":(glob)**/config.xml",
    ]
    s = run_git(repo, ["rev-list", "--reverse", "--first-parent", head, "--"] + pathspecs, check=False).stdout
    return [c for c in s.splitlines() if c.strip()]

def list_tree_entries(repo: Path, treeish: str) -> List[Tuple[str, str]]:
    raw = run_git(repo, ["ls-tree", "-r", "-z", treeish], check=False).stdout or ""
    out: List[Tuple[str, str]] = []
    for entry in raw.split("\x00"):
        if not entry or "\t" not in entry:
            continue
        meta, path = entry.split("\t", 1)
        parts = meta.split()
        if len(parts) < 3:
            continue
        sha = parts[2]
        out.append((sha, path.replace("\\", "/")))
    return out

def blob_size(repo: Path, sha: str) -> int:
    try:
        return int(run_git(repo, ["cat-file", "-s", sha], check=False).stdout.strip())
    except Exception:
        return 0

@lru_cache(maxsize=350_000)
def read_blob_cached(repo_path: str, sha: str) -> Optional[str]:
    repo = Path(repo_path)
    try:
        return run_git(repo, ["cat-file", "-p", sha], check=False).stdout
    except Exception:
        return None

# ===========================
# Workflow expansion (resolve referenced scripts/actions)
# ===========================
RX_USES = re.compile(r"(?mi)^\s*uses\s*:\s*([^\s#]+)\s*$")
RX_CD_PREFIX = re.compile(r"(?i)^\s*cd\s+([^\s;&|]+)\s*(?:&&|\;)\s*(.+)$")
RX_WORKDIR = re.compile(r"(?mi)^\s*working-directory\s*:\s*([^\n#]+)$")

RX_EXEC_REL = re.compile(r"""(?x)(?:^|[\s;&|()])((?:\./|\.\\)[^\s"'`<>]+)""")
RX_LANG_CALL = re.compile(r"""(?ix)(?:^|[\s;&|()])(bash|sh|pwsh|powershell|python3?|node|ruby|perl)\s+([^\s"'`<>]+)""")
RX_CONFIG_ARG = re.compile(r"""(?ix)\b--config(?:=|\s+)([^\s"'`<>]+)""")
RX_DYNAMIC_MARKERS = re.compile(r"(\${{\s*[^}]+}}|\$[A-Za-z_][A-Za-z0-9_]*|%[A-Za-z_][A-Za-z0-9_]*%)")

def _clean_ref_token(tok: str) -> str:
    t = tok.strip()
    t = t.strip('\'"')
    t = t.rstrip("),;")
    return t

def _is_probably_dynamic(path: str) -> bool:
    return bool(RX_DYNAMIC_MARKERS.search(path))

def _normalize_rel_path(p: str) -> str:
    p = p.replace("\\", "/")
    if p.startswith("./"):
        p = p[2:]
    p = str(Path(p).as_posix())
    if p.startswith("./"):
        p = p[2:]
    return p

def _join_posix(a: str, b: str) -> str:
    return str((Path(a) / b).as_posix()).replace("\\", "/")

def _candidate_paths_for_ref(ref: str, current_file: str) -> List[str]:
    r = _normalize_rel_path(ref)
    cur_dir = str(Path(current_file).parent.as_posix()).replace("\\", "/")
    cand = []
    if r:
        cand.append(r)
        if cur_dir and cur_dir != ".":
            cand.append(_join_posix(cur_dir, r))
    out = []
    seen = set()
    for x in cand:
        x = x.lstrip("/")
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

def _resolve_local_action_metadata(dir_path: str) -> List[str]:
    d = dir_path.rstrip("/").lstrip("/")
    return [f"{d}/action.yml", f"{d}/action.yaml"]

def extract_references_from_text(text: str, current_file: str) -> Tuple[Set[str], Set[str], int, List[str]]:
    """
    Returns:
      - local_action_dirs: directories referenced by uses: ./...
      - file_refs: file paths invoked (scripts/configs) relative-ish
      - unresolved_dynamic_count
      - unresolved_samples
    """
    local_action_dirs: Set[str] = set()
    file_refs: Set[str] = set()
    unresolved = 0
    unresolved_samples: List[str] = []

    if not text:
        return local_action_dirs, file_refs, unresolved, unresolved_samples

    t = strip_comments(text)
    t = normalize_block_keys(t)
    t = strip_irrelevant_ci_lines(t)

    # NEW: capture working-directory hints (align with YAML scanner)
    base_workdirs: List[str] = []
    for m in RX_WORKDIR.finditer(t):
        wd = _clean_ref_token(m.group(1) or "")
        if wd:
            wd_norm = _normalize_rel_path(wd).rstrip("/")
            if wd_norm and wd_norm not in base_workdirs:
                base_workdirs.append(wd_norm)

    # Keep expressions for unresolved counting; only remove excluded-task segments here.
    # (Do NOT strip ${{ }} here, otherwise dynamic refs won’t be counted.)
    t_for_refs = remove_excluded_gradle_tasks(t)

    # uses: lines
    for m in RX_USES.finditer(t_for_refs):
        u = (m.group(1) or "").strip()
        if not u:
            continue
        if u.startswith("./") or u.startswith(".\\"):
            u2 = _normalize_rel_path(u)
            local_action_dirs.add(u2.rstrip("/"))

    for line in t_for_refs.splitlines():
        line = line.strip()
        if not line:
            continue

        # working dir candidates = repo root + YAML working-directory + any "cd X && ..."
        work_dirs = [""] + base_workdirs

        cur = line
        for _ in range(2):
            mcd = RX_CD_PREFIX.match(cur)
            if not mcd:
                break
            wd = _clean_ref_token(mcd.group(1) or "")
            rest = mcd.group(2) or ""
            if wd:
                wd_norm = _normalize_rel_path(wd).rstrip("/")
                if wd_norm and wd_norm not in work_dirs:
                    work_dirs.append(wd_norm)
            cur = rest.strip()

        # ./relative_exec
        for mm in RX_EXEC_REL.finditer(cur):
            p = _clean_ref_token(mm.group(1) or "")
            if not p:
                continue
            if _is_probably_dynamic(p):
                unresolved += 1
                if len(unresolved_samples) < 10:
                    unresolved_samples.append(p)
                continue
            p2 = _normalize_rel_path(p)
            for wd in work_dirs:
                if wd:
                    file_refs.add(_join_posix(wd, p2))
                else:
                    file_refs.add(p2)

        # bash/python/node <path>
        for mm in RX_LANG_CALL.finditer(cur):
            p = _clean_ref_token(mm.group(2) or "")
            if not p:
                continue
            if p.startswith("http://") or p.startswith("https://"):
                continue
            if _is_probably_dynamic(p):
                unresolved += 1
                if len(unresolved_samples) < 10:
                    unresolved_samples.append(p)
                continue
            p2 = p.replace("\\", "/").lstrip("./")
            for wd in work_dirs:
                if wd:
                    file_refs.add(_join_posix(wd, p2))
                else:
                    file_refs.add(p2)

        # --config=FILE
        for mm in RX_CONFIG_ARG.finditer(cur):
            p = _clean_ref_token(mm.group(1) or "")
            if not p:
                continue
            if _is_probably_dynamic(p):
                unresolved += 1
                if len(unresolved_samples) < 10:
                    unresolved_samples.append(p)
                continue
            p2 = p.replace("\\", "/").lstrip("./")
            file_refs.add(p2)

    return local_action_dirs, file_refs, unresolved, unresolved_samples

# ===========================
# Snapshot scan (DEFAULT branch commit) with workflow expansion
# ===========================
def scan_treeish_for_styles_expanded(repo: Path, treeish: str) -> Tuple[Set[str], Dict]:
    entries = list_tree_entries(repo, treeish)
    path_to_sha: Dict[str, str] = {p: sha for (sha, p) in entries}

    def read_path(p: str) -> Optional[str]:
        sha = path_to_sha.get(p)
        if not sha:
            return None
        size = blob_size(repo, sha)
        if not is_high_priority_ci_path(p) and BLOB_MAX_SIZE and size > BLOB_MAX_SIZE:
            return None
        txt = read_blob_cached(str(repo), sha)
        if not txt or len(txt) > HARD_MAX_SIZE:
            return None
        return txt

    # ---------- Step 1: find CI entrypoints ----------
    entrypoints: List[str] = []

    for ep in CI_ENTRYPOINTS_EXACT:
        if ep in path_to_sha:
            entrypoints.append(ep)

    for p in path_to_sha.keys():
        if p.startswith(GHA_WORKFLOWS_DIR.rstrip("/") + "/") and p.lower().endswith((".yml", ".yaml")):
            entrypoints.append(p)

    entrypoints = sorted(set(entrypoints))

    # ---------- Step 2: always gather gradle files ----------
    gradle_files: List[str] = []
    for p in path_to_sha.keys():
        if is_gradle(p):
            gradle_files.append(p)
    gradle_files = sorted(set(gradle_files))

    # ---------- Step 3: workflow expansion ----------
    scanned_paths: Set[str] = set()
    scanned_text_blocks: List[Tuple[str, str]] = []

    unresolved_dynamic_refs_count = 0
    unresolved_dynamic_samples: List[str] = []

    q: List[Tuple[str, int]] = []
    for ep in entrypoints:
        q.append((ep, 0))

    cat = {
        "entrypoints": set(entrypoints),
        "local_actions": set(),
        "called_files": set(),
        "gradle": set(gradle_files),
    }

    def enqueue_path(p: str, depth: int, category: str) -> None:
        nonlocal q
        if len(scanned_paths) >= EXPAND_MAX_FILES:
            return
        p = p.replace("\\", "/").lstrip("/")
        if p in scanned_paths:
            return
        if p not in path_to_sha:
            return
        scanned_paths.add(p)
        cat.get(category, set()).add(p)
        q.append((p, depth))

    for gf in gradle_files:
        enqueue_path(gf, 0, "gradle")

    while q and len(scanned_text_blocks) < EXPAND_MAX_FILES:
        p, depth = q.pop(0)
        txt = read_path(p)
        if txt is None:
            continue

        # normalize
        norm = txt
        if is_gradle(p):
            norm = strip_comments_gradle(norm)
            norm = pre_sanitize_for_triggers(norm)
        else:
            norm = strip_comments(norm)
            norm = normalize_block_keys(norm)
            norm = strip_irrelevant_ci_lines(norm)
            norm = pre_sanitize_for_triggers(norm)

        scanned_text_blocks.append((p, norm))

        if depth < EXPAND_MAX_DEPTH:
            la_dirs, file_refs, unr_cnt, unr_samples = extract_references_from_text(txt, p)
            unresolved_dynamic_refs_count += unr_cnt
            for s in unr_samples:
                if len(unresolved_dynamic_samples) < 20 and s not in unresolved_dynamic_samples:
                    unresolved_dynamic_samples.append(s)

            for d in sorted(la_dirs):
                for cand_dir in _candidate_paths_for_ref(d, p):
                    for am in _resolve_local_action_metadata(cand_dir):
                        if am in path_to_sha:
                            cat["local_actions"].add(cand_dir)
                            enqueue_path(am, depth + 1, "called_files")

            for r in sorted(file_refs):
                for cand in _candidate_paths_for_ref(r, p):
                    if cand in path_to_sha:
                        enqueue_path(cand, depth + 1, "called_files")

        if sum(len(t) for _, t in scanned_text_blocks) > EXPAND_MAX_TEXT_CHARS:
            break

    # ---------- Step 4: compute features & styles ----------
    features = {
        "yaml_loc": 0,
        "gradle_loc": 0,
        "runs_on": set(),
        "matrix_width_hint": 0,
        "api_levels": set(),
        "reliability_flags": set(),
        "gmd_config_present": False,
        "gmd_identifiers": set(),
    }

    RX_RUNS_ON = re.compile(r"(?mi)^\s*runs-on\s*:\s*(.+)$")
    RX_LIST_ITEM = re.compile(r"(?mi)^\s*-\s")
    RX_API_LEVEL = re.compile(r"(?i)\bandroid[-_ ]?(\d{2})\b|system-images;android-(\d{2})\b")
    RX_RETRY = re.compile(r"(?i)\bretry\b|\bmax-attempts\b|\bflaky\b")
    RX_TIMEOUT = re.compile(r"(?i)\btimeout[- ]?minutes\b|\btimeout\b")
    RX_HEADLESS = re.compile(r"(?i)\bheadless\b|\b-no-window\b|\b-no-boot-anim\b")
    RX_WAIT_FOR_DEVICE = re.compile(r"(?i)\badb\s+wait[- ]?for[- ]?device\b")

    GMD_BLOCK_NAME_RX = re.compile(
        r'(\w+)\s*\(\s*(?:com\.android\.build\.api\.dsl\.)?ManagedVirtualDevice(?:\s*::\s*class)?\s*\)',
        re.I
    )

    has_gradle_anywhere_repo = False

    for path, norm in scanned_text_blocks:
        if is_yaml(path):
            features["yaml_loc"] += len(norm.splitlines())
            for m in RX_RUNS_ON.finditer(norm):
                features["runs_on"].add((m.group(1) or "").strip())
            features["matrix_width_hint"] = max(features["matrix_width_hint"], len(RX_LIST_ITEM.findall(norm)))

        if is_gradle(path):
            features["gradle_loc"] += len(norm.splitlines())
            if not features["gmd_config_present"] and find_gmd_block(norm):
                features["gmd_config_present"] = True
                for m in GMD_BLOCK_NAME_RX.finditer(norm):
                    ident = (m.group(1) or "").strip()
                    if ident:
                        features["gmd_identifiers"].add(ident)

        for m in RX_API_LEVEL.finditer(norm):
            for g in m.groups():
                if g and g.isdigit():
                    features["api_levels"].add(int(g))
        if RX_RETRY.search(norm):
            features["reliability_flags"].add("retry")
        if RX_TIMEOUT.search(norm):
            features["reliability_flags"].add("timeout")
        if RX_HEADLESS.search(norm):
            features["reliability_flags"].add("headless")
        if RX_WAIT_FOR_DEVICE.search(norm):
            features["reliability_flags"].add("wait_for_device")

        if GRADLE_ANYWHERE_RE.search(norm) or GRADLE_BUILD_ACTION_RE.search(norm):
            has_gradle_anywhere_repo = True

    trigger_labels: List[str] = []
    trigger_groups: List[str] = []
    device_labels: List[str] = []
    device_groups: List[str] = []

    # IMPORTANT: single-pass per block so Flutter gating can use same-block runtime evidence
    for _path, norm in scanned_text_blocks:
        low = (norm or "").lower()

        # device signals
        d_labels, d_groups = collect_hits_with_groups(DEVICE_PATTERNS, low)

        # trigger signals
        t_labels, t_groups = collect_hits_with_groups(TRIGGER_PATTERNS_PRIMARY, low)
        fb_labels, fb_groups = collect_hits_with_groups(TRIGGER_PATTERNS_ANYWHERE, low)
        if fb_labels:
            t_labels = unique_preserve(t_labels + fb_labels)
            t_groups = unique_preserve(t_groups + fb_groups)

        # GHA Gradle action inputs
        if any_match(GHA_GRADLE_INPUTS, norm):
            gha_tied = re.search(
                r"(?mi)^\s*uses\s*:\s*(reactivecircus/android-emulator-runner|malinskiy/action-android/emulator-run-cmd|hannesa2/action-android/emulator-run-cmd)@",
                norm,
            )
            if has_gradle_anywhere_repo or gha_tied:
                if "gha gradle inputs/script" not in t_labels:
                    t_labels.append("gha gradle inputs/script")
                if "Gradle" not in t_groups:
                    t_groups.append("Gradle")

        # NEW: GHA GMD inputs (align with YAML scanner)
        if any_match(GHA_GMD_INPUTS, norm):
            if "variant/device AndroidTest" not in t_labels:
                t_labels.append("variant/device AndroidTest")
            if "Gradle" not in t_groups:
                t_groups.append("Gradle")

        # NEW: STRICT Flutter gating (align with YAML scanner)
        if flutter_androidish_in_block(norm, d_labels, d_groups):
            if "flutter integration test" not in t_labels:
                t_labels.append("flutter integration test")
            if "Flutter" not in t_groups:
                t_groups.append("Flutter")

        # Filter weak "other gha emulator" when no Android context and no test triggers
        if ("other gha emulator" in d_labels) and (not ANDROID_CONTEXT_RE.search(low)) and (not t_labels):
            d_labels = [l for l in d_labels if l != "other gha emulator"]
            if not d_labels:
                d_groups = [g for g in d_groups if g != "Emulator"]

        trigger_labels = unique_preserve(trigger_labels + t_labels)
        trigger_groups = unique_preserve(trigger_groups + t_groups)
        device_labels = unique_preserve(device_labels + d_labels)
        device_groups = unique_preserve(device_groups + d_groups)

    has_test_trigger = bool(trigger_labels)

    strong_seen = bool(set(device_labels) & STRONG_DEVICE_LABELS)
    if not (strong_seen or has_test_trigger):
        device_labels = [l for l in device_labels if l in STRONG_DEVICE_LABELS]
        if not device_labels:
            device_groups = []

    # Provider/env declarations
    repo_text = "\n".join([t for _, t in scanned_text_blocks])
    provider = detect_provider(repo_text)
    inline_decl = has_inline_env(repo_text)
    config_decl = has_config_env(repo_text)

    # NOTE: Removed the BrowserStack “drop unless supported” guard to align with YAML scanner behavior.

    styles: Set[str] = set()

    if "Third_Party_Lab" in device_groups:
        styles.add("ThirdParty")

    if "Emulator" in device_groups:
        lbls = set(device_labels)
        # UPDATED: your requested mapping
        if lbls & EMULATOR_COMMUNITY_LABELS:
            styles.add("Emu_Community")
        if lbls & EMULATOR_CUSTOM_LABELS:
            styles.add("Emu_Custom")

    def has_gmd_gradle_trigger(tlabs: List[str]) -> bool:
        L = {l.lower() for l in tlabs}
        if any("manageddevice androidtest" in l for l in L):
            return True
        if ("variant/device androidtest" in L) and not any(x in L for x in {"connected.*android.*", "connectedandroidtest", "connectedbenchmarkandroidtest", "spoon", "marathon"}):
            return True
        return False

    if features["gmd_config_present"] or has_gmd_gradle_trigger(trigger_labels):
        styles.add("GMD")

    meta = {
        "procedure": {
            "timeline_scope": TIMELINE_SCOPE,
            "expanded_refs": True,
            "expand_max_depth": EXPAND_MAX_DEPTH,
            "expand_max_files": EXPAND_MAX_FILES,
        },
        "expansion": {
            "entrypoints_count": len(entrypoints),
            "gradle_files_count": len(gradle_files),
            "scanned_files_count": len(scanned_text_blocks),
            "called_files_count": len(cat["called_files"]),
            "local_action_dirs_count": len(cat["local_actions"]),
            "unresolved_dynamic_refs_count": int(unresolved_dynamic_refs_count),
            "unresolved_dynamic_samples": unresolved_dynamic_samples[:20],
            "scanned_paths_sample": sorted([p for p, _ in scanned_text_blocks])[:50],
        },
        "features": {
            "yaml_loc": features["yaml_loc"],
            "gradle_loc": features["gradle_loc"],
            "runs_on": sorted(features["runs_on"]),
            "matrix_width_hint": features["matrix_width_hint"],
            "api_levels": sorted(int(x) for x in features["api_levels"]),
            "reliability_flags": sorted(features["reliability_flags"]),
            "trigger_labels": sorted(trigger_labels),
            "device_labels": sorted(device_labels),
            "provider": provider,
            "inline_env": bool(inline_decl),
            "config_env": bool(config_decl),
            "gradle_present_repo": bool(has_gradle_anywhere_repo),
            "gmd_config_present": bool(features["gmd_config_present"]),
            "gmd_identifiers": sorted(features["gmd_identifiers"]) if features["gmd_identifiers"] else [],
        },
    }
    return styles, meta

# ===========================
# Timeline building (DEFAULT branch ONLY)
# ===========================
def empty_result(repo: Path, cutoff_iso: str) -> Dict:
    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "default_branch_ref": default_branch_ref(repo),
        "cutoff_default_head": None,
        "first_commit_date": None,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": [],
        "events": {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []},
        "snapshot_as_of_cutoff_default": [],
        "empty_gaps": [],
        "qa_issue": "No default-branch head at cutoff or no detectable environment at cutoff",
    }

def build_timeline(repo: Path, cutoff_iso: str) -> Dict:
    ref = default_branch_ref(repo)
    head = cutoff_head_default(repo, cutoff_iso)
    if not head:
        return empty_result(repo, cutoff_iso)

    commits = commits_touching_relevant_default(repo, head)

    commit_dates: Dict[str, str] = {}
    for c in commits:
        d = get_commit_date_iso(repo, c)
        if d:
            commit_dates[c] = d
    first_commit_date = commit_dates.get(commits[0]) if commits else None

    timeline: List[Dict] = []
    events: Dict[str, List[Dict]] = {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []}
    prev: Set[str] = set()

    empty_gaps: List[Dict] = []
    gap_open: Optional[Dict] = None

    root = earliest_commit_first_parent(repo, head)
    if root:
        base_styles, base_meta = scan_treeish_for_styles_expanded(repo, root)
        if base_styles:
            baseline_date = get_commit_date_iso(repo, root)
            timeline.append({"date": baseline_date, "commit": root, "styles": sorted(base_styles), **base_meta})
            for s in sorted(base_styles):
                if s in events:
                    events[s].append({"event": "added", "date": baseline_date, "commit": root})
            prev = set(base_styles)

    for c in commits:
        styles_now, meta_now = scan_treeish_for_styles_expanded(repo, c)
        dt = commit_dates.get(c)

        if SUPPRESS_EMPTY_ROWS and not styles_now:
            if CAPTURE_EMPTY_GAPS and gap_open is None:
                gap_open = {"start_date": dt, "start_commit": c, "prev_state": "+".join(sorted(prev)) if prev else ""}
            continue

        if CAPTURE_EMPTY_GAPS and gap_open is not None and styles_now:
            gap_open["end_date"] = dt
            gap_open["end_commit"] = c
            gap_open["next_state"] = "+".join(sorted(styles_now))
            try:
                d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)
                d2 = datetime.fromisoformat((dt or "").replace("Z", "+00:00")).replace(tzinfo=None)
                gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
            except Exception:
                gap_open["duration_days"] = None
            gap_open["censored"] = False
            empty_gaps.append(gap_open)
            gap_open = None

        if styles_now != prev:
            if EMIT_NONE_STATE and not styles_now:
                timeline.append({"date": dt, "commit": c, "styles": [], **meta_now})
            elif styles_now:
                timeline.append({"date": dt, "commit": c, "styles": sorted(styles_now), **meta_now})

            added = styles_now - prev
            removed = prev - styles_now
            for s in sorted(added):
                if s in events:
                    events[s].append({"event": "added", "date": dt, "commit": c})
            for s in sorted(removed):
                if s in events:
                    events[s].append({"event": "removed", "date": dt, "commit": c})
            prev = styles_now
        else:
            if styles_now:
                for s in sorted(styles_now):
                    if s in events:
                        events[s].append({"event": "maintenance", "date": dt, "commit": c})

    if CAPTURE_EMPTY_GAPS and gap_open is not None:
        gap_open["end_date"] = cutoff_iso
        gap_open["end_commit"] = head
        gap_open["next_state"] = ""
        try:
            d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)
            d2 = datetime.fromisoformat(cutoff_iso.replace("Z", "+00:00")).replace(tzinfo=None)
            gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
        except Exception:
            gap_open["duration_days"] = None
        gap_open["censored"] = True
        empty_gaps.append(gap_open)
        gap_open = None

    snap_styles, snap_meta = scan_treeish_for_styles_expanded(repo, head)
    snapshot_default = sorted(snap_styles)

    qa_issue = None
    if not snapshot_default:
        qa_issue = "No environment detected at cutoff (default branch) under expanded workflow procedure"

    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "default_branch_ref": ref,
        "cutoff_default_head": head,
        "first_commit_date": first_commit_date,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": timeline,
        "events": events,
        "snapshot_as_of_cutoff_default": snapshot_default,
        "snapshot_meta_at_cutoff_default": snap_meta,
        "empty_gaps": empty_gaps,
        **({"qa_issue": qa_issue} if qa_issue else {}),
    }

# ===========================
# Runner + index/summary
# ===========================
def output_path_for(repo: Path) -> Path:
    return OUTPUT_MINE / f"{repo.name}.emulator_timeline.default_refs.json"

def list_repos_once(root: Path) -> List[Path]:
    rs = list_repos(root)
    rs.sort(key=lambda p: p.name.lower())
    return rs

def iso_min(dts: List[str]) -> Optional[str]:
    ds = [d for d in dts if d]
    return min(ds) if ds else None

def derive_summary_fields(rec: Dict) -> Dict:
    name = rec.get("repo_name")
    snap_def = rec.get("snapshot_as_of_cutoff_default", [])
    events = rec.get("events", {})
    first_events: List[Optional[str]] = []
    for k in ("Emu_Community", "Emu_Custom", "GMD", "ThirdParty"):
        for e in events.get(k, []):
            if e.get("event") == "added":
                first_events.append(e.get("date"))
    first_env_date = iso_min([d for d in first_events if d])
    transitions = 0
    for k in events:
        transitions += sum(1 for e in events[k] if e.get("event") in ("added", "removed"))
    gaps = rec.get("empty_gaps", [])
    gap_days = 0.0
    for g in gaps:
        try:
            gap_days += float(g.get("duration_days") or 0.0)
        except Exception:
            pass

    cutoff_meta = rec.get("snapshot_meta_at_cutoff_default", {}) or {}
    exp = (cutoff_meta.get("expansion", {}) or {})

    return {
        "repo_name": name,
        "default_branch_ref": rec.get("default_branch_ref", ""),
        "has_env_at_cutoff_default": 1 if snap_def else 0,
        "cutoff_states_default": "+".join(snap_def),
        "first_env_date": first_env_date or "",
        "transitions": transitions,
        "total_gap_days": round(gap_days, 2),
        "cutoff_scanned_files": exp.get("scanned_files_count", ""),
        "cutoff_called_files": exp.get("called_files_count", ""),
        "cutoff_unresolved_dynamic_refs": exp.get("unresolved_dynamic_refs_count", ""),
        "qa_issue": rec.get("qa_issue", ""),
    }

def run_miner(cutoff_iso: str = CUTOFF_ISO, max_repos: int = MAX_REPOS) -> None:
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

    repos = list_repos_once(INPUT_CLONES)
    if max_repos and max_repos > 0:
        repos = repos[:max_repos]

    if not repos:
        print(f"[info] No git repos found under: {INPUT_CLONES}")
        return

    print(f"[info] Work root:         {WORK_ROOT}")
    print(f"[info] Input repos:       {INPUT_CLONES}")
    print(f"[info] Output JSON dir:   {OUTPUT_MINE}")
    print(f"[info] Found repos:       {len(repos)}")
    print(f"[info] Cutoff (UTC):      {cutoff_iso}")
    print(f"[info] Timeline scope:    {TIMELINE_SCOPE}")
    print(f"[info] Expansion bounds:  depth={EXPAND_MAX_DEPTH}, max_files={EXPAND_MAX_FILES}, max_text_chars={EXPAND_MAX_TEXT_CHARS}")
    print(f"[info] Options: suppress_empty_rows={SUPPRESS_EMPTY_ROWS}, capture_empty_gaps={CAPTURE_EMPTY_GAPS}, emit_none={EMIT_NONE_STATE}, blob_max_size={BLOB_MAX_SIZE}")

    written = skipped = errors = 0
    summaries: List[Dict] = []

    def process(repo: Path) -> Tuple[str, Path, Optional[Dict], Optional[str]]:
        try:
            outp = output_path_for(repo)
            if RESUME_IF_EXISTS and outp.exists():
                return ("skipped", repo, None, None)
            data = build_timeline(repo, cutoff_iso)
            with outp.open("w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=2)
            return ("written", repo, data, None)
        except Exception as e:
            return ("error", repo, None, str(e))

    with PoolExecutor(max_workers=MAX_WORKERS) as ex:
        futs = {ex.submit(process, r): r for r in repos}
        total = len(futs)
        for i, fut in enumerate(as_completed(futs), 1):
            repo = futs[fut]
            rel = repo.relative_to(INPUT_CLONES) if repo != INPUT_CLONES else Path(repo.name)
            status, _repo, data, err = fut.result()
            if status == "written":
                print(f"[{i}/{total}] Wrote: {rel}")
                written += 1
                summaries.append(derive_summary_fields(data))  # type: ignore[arg-type]
            elif status == "skipped":
                print(f"[{i}/{total}] Skipped (exists): {rel}")
                skipped += 1
                try:
                    with output_path_for(repo).open("r", encoding="utf-8") as f:
                        data2 = json.load(f)
                    summaries.append(derive_summary_fields(data2))
                except Exception:
                    pass
            else:
                print(f"[{i}/{total}] [error] {rel}: {err}", file=sys.stderr)
                errors += 1

    idx_json = OUTPUT_MINE / "index_summary.default_refs.json"
    with idx_json.open("w", encoding="utf-8") as f:
        json.dump({"cutoff": cutoff_iso, "repos": summaries}, f, ensure_ascii=False, indent=2)

    idx_csv = OUTPUT_MINE / "index_summary.default_refs.csv"
    with idx_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(
            f,
            fieldnames=[
                "repo_name",
                "default_branch_ref",
                "has_env_at_cutoff_default",
                "cutoff_states_default",
                "first_env_date",
                "transitions",
                "total_gap_days",
                "cutoff_scanned_files",
                "cutoff_called_files",
                "cutoff_unresolved_dynamic_refs",
                "qa_issue",
            ],
        )
        w.writeheader()
        for row in summaries:
            w.writerow(row)

    qa_csv = OUTPUT_MINE / "qa_issues.default_refs.csv"
    with qa_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(f, fieldnames=["repo_name", "qa_issue"])
        w.writeheader()
        for row in summaries:
            if row.get("qa_issue"):
                w.writerow({"repo_name": row["repo_name"], "qa_issue": row["qa_issue"]})

    print(f"[done] JSON -> {OUTPUT_MINE}  (written={written}, skipped={skipped}, errors={errors})")
    print(f"[done] Summary: {idx_csv.name}, {idx_json.name}, QA: {qa_csv.name}")

if __name__ == "__main__":
    _failfast_checks()
    print("[run] Starting miner (default branch + expanded refs)…")
    run_miner(cutoff_iso=CUTOFF_ISO, max_repos=MAX_REPOS)
    print("[run] Finished.")
# Out:
# [run] Starting miner (default branch + expanded refs)…
# [info] Work root:         C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3
# [info] Input repos:       C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Clone
# [info] Output JSON dir:   C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\ICST2026\3 - RQ3\Mine
# [info] Found repos:       480
# [info] Cutoff (UTC):      2025-08-10 23:59:59 +0000
# [info] Timeline scope:    default_first_parent
# [info] Expansion bounds:  depth=3, max_files=250, max_text_chars=5000000
# [info] Options: suppress_empty_rows=True, capture_empty_gaps=True, emit_none=False, blob_max_size=2000000
# [1/480] Wrote: AAkira__ExpandableLayout
# [2/480] Wrote: alphacep__vosk-flutter
# [3/480] Wrote: andrewgiang__SpritzerTextView
# [4/480] Wrote: andriydruk__swift-weather-app
# [5/480] Wrote: ajitsing__ExpenseManager
# [6/480] Wrote: am15h__tflite_flutter_helper
# [7/480] Wrote: AndProx__AndProx
# [8/480] Wrote: andremion__Villains-and-Heroes
# [9/480] Wrote: adorsys__secure-storage-android
# [10/480] Wrote: AdamMc331__AndroidStudyGuide
# [11/480] Wrote: 4eRTuk__audioview
# [12/480] Wrote: alexbakker__webdav-provider
# [13/480] Wrote: agoda-com__ninjato
# [14/480] Wrote: arkivanov__android-dev-challenge-compose-2
# [15/480] Wrote: a914-gowtham__compose-ratingbar
# [16/480] Wrote: abdelaziz-mahdy__pytorch_lite
# [17/480] Wrote: AChep__AcDisplay
# [18/480] Wrote: amahi__android
# [19/480] Wrote: anhnnt1__Android-UtilCode
# [20/480] Wrote: aws__amazon-ivs-react-native-player
# [21/480] Wrote: a-mabe__OpenHIIT
# [22/480] Wrote: Albert221__FastShopping
# [23/480] Wrote: ActivityWatch__aw-android
# [24/480] Wrote: Arian04__android-hid-client
# [25/480] Wrote: anjlab__android-inapp-billing-v3
# [26/480] Wrote: arildojr7__iris-mock
# [27/480] Wrote: Antox__Antox
# [28/480] Wrote: airbnb__paris
# [29/480] Wrote: BennyKok__PxerStudio
# [30/480] Wrote: blazsolar__android-collapse-calendar-view
# [31/480] Wrote: Blankj__ALog
# [32/480] Wrote: amitshekhariitbhu__Fast-Android-Networking
# [33/480] Wrote: bilibili__boxing
# [34/480] Wrote: alexstyl__contactstore
# [35/480] Wrote: cgutman__USBIPServerForAndroid
# [36/480] Wrote: brarcher__video-transcoder
# [37/480] Wrote: CarlosMChica__easyrecycleradapters
# [38/480] Wrote: chaosbastler__opentraining
# [39/480] Wrote: appmattus__layercache
# [40/480] Wrote: AdevintaSpain__Barista
# [41/480] Wrote: andreynovikov__trekarta
# [42/480] Wrote: chennaione__sugar
# [43/480] Wrote: chenxiaolong__RSAF
# [44/480] Wrote: artem-zinnatullin__qualitymatters
# [45/480] Wrote: burnoo__cokoin
# [46/480] Wrote: ably__ably-flutter
# [47/480] Wrote: creativepsyco__secondary-dex-gradle
# [48/480] Wrote: concretesolutions__canarinho
# [49/480] Wrote: brandonp2412__FitBook
# [50/480] Wrote: cloudinary__cloudinary_android
# [51/480] Wrote: cuongpm__youtube-dl-android
# [52/480] Wrote: cliqz-oss__browser-android
# [53/480] Wrote: dbrodie__AdBuster
# [54/480] Wrote: cashapp__paraphrase
# [55/480] Wrote: caarmen__poet-assistant
# [56/480] Wrote: charpeni__react-native-url-polyfill
# [57/480] Wrote: bitfireAT__icsx5
# [58/480] Wrote: beemdevelopment__Aegis
# [59/480] Wrote: deepmedia__Knee
# [60/480] Wrote: anilbeesetti__nextplayer
# [61/480] Wrote: dgngulcan__droid-feed
# [62/480] Wrote: DesarrolloAntonio__Shiori-Android-Client
# [63/480] Wrote: Crazy-Marvin__MetadataRemover
# [64/480] Wrote: CypherpunkArmory__UserLAnd
# [65/480] Wrote: douzifly__clear-todolist
# [66/480] Wrote: drakeet__Floo
# [67/480] Wrote: Criptext__Android-Email-Client
# [68/480] Wrote: dlew__joda-time-android
# [69/480] Wrote: DroidPHP__DroidPHP
# [70/480] Wrote: elixsr__FwdPortForwardingApp
# [71/480] Wrote: devgianlu__DNSHero
# [72/480] Wrote: devgianlu__Aria2Android
# [73/480] Wrote: doublesymmetry__KotlinAudio
# [74/480] Wrote: ericktijerou__jetpuppy
# [75/480] Wrote: elftausend__custos
# [76/480] Wrote: dmfs__opentasks
# [77/480] Wrote: bluefireteam__audioplayers
# [78/480] Wrote: erkkah__naett
# [79/480] Wrote: EvanRespaut__Equate
# [80/480] Wrote: AlphaWallet__alpha-wallet-android
# [81/480] Wrote: commons-app__apps-android-commons
# [82/480] Wrote: Bdaya-Dev__oidc
# [83/480] Wrote: FabianTerhorst__Floppy
# [84/480] Wrote: devgianlu__Aria2App
# [85/480] Wrote: faruktoptas__RetrofitRssConverterFactory
# [86/480] Wrote: devgianlu__PretendYoureXyzzyAndroid
# [87/480] Wrote: F4uzan__HgLauncher
# [88/480] Wrote: droidconKE__droidconKeKotlin
# [89/480] Wrote: fewlaps__flone-android
# [90/480] Wrote: fingerprintjs__fingerprintjs-pro-react-native
# [91/480] Wrote: ErickSumargo__Dads
# [92/480] Wrote: FabianTerhorst__Iron
# [93/480] Wrote: federicoiosue__Omni-Notes
# [94/480] Wrote: Five-Prayers__five-prayers-android
# [95/480] Wrote: flet-dev__serious-python
# [96/480] Wrote: Faltenreich__Diaguard
# [97/480] Wrote: CatimaLoyalty__Android
# [98/480] Wrote: DroidKaigi__conference-app-2020
# [99/480] Wrote: FliegendeWurst__TriliumDroid
# [100/480] Wrote: AndBible__and-bible
# [101/480] Wrote: fossasia__loklak_wok_android
# [102/480] Wrote: GabrielBB__Android-CutOut
# [103/480] Wrote: fluttercommunity__flutter_workmanager
# [104/480] Wrote: gdky005__AndroidBadge
# [105/480] Wrote: dart-lang__http
# [106/480] Wrote: GerardPaligot__android-countdown
# [107/480] Wrote: android__codelab-android-compose
# [108/480] Wrote: flauschtrud__broccoli
# [109/480] Wrote: freeotp__freeotp-android
# [110/480] Wrote: ge0rg__aprsdroid
# [111/480] Wrote: fornewid__naver-map-compose
# [112/480] Wrote: GetStream__ai-chat-android
# [113/480] Wrote: GetStream__gemini-android
# [114/480] Wrote: fornewid__material-motion-compose
# [115/480] Wrote: EventFahrplan__EventFahrplan
# [116/480] Wrote: admob-plus__admob-plus
# [117/480] Wrote: gotev__android-speech
# [118/480] Wrote: f-arslan__GptMap
# [119/480] Wrote: guolindev__android-dev-challenge-compose
# [120/480] Wrote: evilcorpltd__aTox
# [121/480] Wrote: gotev__android-cookie-store
# [122/480] Wrote: grandstaish__paperparcel
# [123/480] Wrote: haiyangwu__mediasoup-client-android
# [124/480] Wrote: AntennaPod__AntennaPod
# [125/480] Wrote: greenaddress__abcore
# [126/480] Wrote: harryjph__android-bluetooth-serial
# [127/480] Wrote: hitherejoe__HackerNewsReader
# [128/480] Wrote: hannesstruss__unearthed
# [129/480] Wrote: gemwalletcom__gem-android
# [130/480] Wrote: connectbot__connectbot
# [131/480] Wrote: hitherejoe__MVVM_Hacker_News
# [132/480] Wrote: google__jetpack-camera-app
# [133/480] Wrote: hotchemi__ProgressMenuItem
# [134/480] Wrote: EnsembleUI__ensemble
# [135/480] Wrote: HYY-yu__TableRecyclerView
# [136/480] Wrote: ICBNetwork__web3-Wallet
# [137/480] Wrote: ianthetechie__uniffi-starter
# [138/480] Wrote: Hny0305Lin__NLChat
# [139/480] Wrote: H-PixelDroid__PixelDroid
# [140/480] Wrote: ice-blockchain__mobile-app
# [141/480] Wrote: ImaginativeShohag__Why-Not-Compose
# [142/480] Wrote: android__nowinandroid
# [143/480] Wrote: 1q23lyc45__KitsuneMagisk
# [144/480] Wrote: guardianproject__proofmode-android
# [145/480] Wrote: firebase__FirebaseUI-Flutter
# [146/480] Wrote: ivnsch__rust_android_ios
# [147/480] Wrote: briar__briar
# [148/480] Wrote: irgaly__kfswatch
# [149/480] Wrote: jakenjarvis__Android-OrmLiteContentProvider
# [150/480] Wrote: grote__Transportr
# [151/480] Wrote: ipfs-shipyard__gomobile-ipfs
# [152/480] Wrote: coil-kt__coil
# [153/480] Wrote: izderadicka__audioserve-android
# [154/480] Wrote: hannesa2__panoramaGL
# [155/480] Wrote: acterglobal__a3
# [156/480] Wrote: haroldadmin__MoonShot
# [157/480] Wrote: jerryOkafor__TimeLineView
# [158/480] Wrote: javiersantos__PiracyChecker
# [159/480] Wrote: JakeWharton__u2020
# [160/480] Wrote: glpi-project__android-inventory-agent
# [161/480] Wrote: jeziellago__Linkt
# [162/480] Wrote: fossasia__phimpme-android
# [163/480] Wrote: jimmod__ShareToComputer
# [164/480] Wrote: inaturalist__iNaturalistAndroid
# [165/480] Wrote: hoc081098__ViewBindingDelegate
# [166/480] Wrote: JoaquimLey__faboptions
# [167/480] Wrote: jianjunxiao__NiceVieoPlayer
# [168/480] Wrote: jjhesk__hkm-progress-button
# [169/480] Wrote: 4accccc__vivo-Magisk-suu
# [170/480] Wrote: invertase__react-native-google-mobile-ads
# [171/480] Wrote: JimmyDaddy__react-native-image-marker
# [172/480] Wrote: jungilhan__awesome-blogs-android
# [173/480] Wrote: kakajika__SwipeAwayDialog
# [174/480] Wrote: Karn__notify
# [175/480] Wrote: jordond__kmpalette
# [176/480] Wrote: JakeWharton__RxBinding
# [177/480] Wrote: karonl__InDoorSurfaceView
# [178/480] Wrote: kevinhinterlong__archwiki-viewer
# [179/480] Wrote: jpaulynice__android-jigsaw-puzzle
# [180/480] Wrote: kebernet__shortyz
# [181/480] Wrote: Jellify-Music__App
# [182/480] Wrote: kost__NetworkMapper
# [183/480] Wrote: joreilly__StarWars
# [184/480] Wrote: juancastillo0__wasm_run
# [185/480] Wrote: ksoichiro__AndroidFormEnhancer
# [186/480] Wrote: fossasia__badgemagic-app
# [187/480] Wrote: jerson__flutter-openpgp
# [188/480] Wrote: ksoichiro__SimpleAlertDialog-for-Android
# [189/480] Wrote: kalaspuffar__secure-quick-reliable-login
# [190/480] Wrote: labexp__osmtracker-android
# [191/480] Wrote: ksoichiro__Android-ObservableScrollView
# [192/480] Wrote: krzdabrowski__android-starter-2022
# [193/480] Wrote: liangpengfei__LoadingPopPoint
# [194/480] Wrote: jameshnsears__QuoteUnquote
# [195/480] Wrote: jerson__flutter-rsa
# [196/480] Wrote: liihuu__KLineChartAndroid
# [197/480] Wrote: letelete__sleep-cycle-alarm
# [198/480] Wrote: f-droid__fdroidclient
# [199/480] Wrote: cgeo__cgeo
# [200/480] Wrote: invertase__notifee
# [201/480] Wrote: lcdsmao__JetTheme
# [202/480] Wrote: livefront__bridge
# [203/480] Wrote: lopspower__PokeCardCompose
# [204/480] Wrote: hitherejoe__minimise
# [205/480] Wrote: leandroBorgesFerreira__LoadingButtonAndroid
# [206/480] Wrote: Link184__KidAdapter
# [207/480] Wrote: lolo-io__OneList
# [208/480] Wrote: maoruibin__OneDrawable
# [209/480] Wrote: MackHartley__RoundedProgressBar
# [210/480] Wrote: isar__isar
# [211/480] Wrote: mapbox__store-locator-android
# [212/480] Wrote: maksim-m__Popular-Movies-App
# [213/480] Wrote: MarcinMoskala__PreferenceHolder
# [214/480] Wrote: maxistar__TextPad
# [215/480] Wrote: massivedisaster__ADAL
# [216/480] Wrote: LinX64__CoinCap
# [217/480] Wrote: maxpower47__PinDroid
# [218/480] Wrote: ligi__SurvivalManual
# [219/480] Wrote: Mercandj__android-dev-challenge-compose-4
# [220/480] Wrote: justjanne__QuasselDroid-ng
# [221/480] Wrote: KaustubhPatange__navigator
# [222/480] Wrote: medic__cht-gateway
# [223/480] Wrote: MichaelEvans__Aftermath
# [224/480] Wrote: iSoron__uhabits
# [225/480] Wrote: michelelacorte__AndroidAppShortcuts
# [226/480] Wrote: miguelhincapie__CustomBottomSheetBehavior
# [227/480] Wrote: mapbox__mapbox-events-android
# [228/480] Wrote: joreilly__PeopleInSpace
# [229/480] Wrote: maxkeppeler__sheets-compose-dialogs
# [230/480] Wrote: kickstarter__android-oss
# [231/480] Wrote: JackEblan__Geto
# [232/480] Wrote: mathisdt__trackworktime
# [233/480] Wrote: jaredsburrows__android-gif-search
# [234/480] Wrote: MostafaGazar__soas
# [235/480] Wrote: leapcode__bitmask_android
# [236/480] Wrote: mbakgun__midjourney-images-compose-multiplatform
# [237/480] Wrote: mixpanel__mixpanel-react-native
# [238/480] Wrote: metrodroid__metrodroid
# [239/480] Wrote: ligi__PassAndroid
# [240/480] Wrote: michaeltroger__pdfwallet-android
# [241/480] Wrote: n8ebel__GitHubActionsAutomationSandbox
# [242/480] Wrote: mlcommons__mobile_app_open
# [243/480] Wrote: Nailik__rhasspy_mobile
# [244/480] Wrote: netmackan__ATimeTracker
# [245/480] Wrote: natario1__GIFCompressor
# [246/480] Wrote: moonlight-stream__moonlight-android
# [247/480] Wrote: NightlyNexus__ViewStatePagerAdapter
# [248/480] Wrote: MikeOrtiz__TouchImageView
# [249/480] Wrote: microservicer__flutter-pipelines
# [250/480] Wrote: mrrfv__open-android-backup
# [251/480] Wrote: nhirokinet__bluelineconsole
# [252/480] Wrote: niteshpatel__ministocks
# [253/480] Wrote: mjaakko__NeoStumbler
# [254/480] Wrote: okanaydin__Android-Compose-Challenge
# [255/480] Wrote: nukc__LoadMoreWrapper
# [256/480] Wrote: LinkSheet__LinkSheet
# [257/480] Wrote: nanihadesuka__NovelDokusha
# [258/480] Wrote: nukc__StateView
# [259/480] Wrote: moezbhatti__qksms
# [260/480] Wrote: NiciDieNase__chaosflix
# [261/480] Wrote: mshdabiola__NotePad
# [262/480] Wrote: linagora__tmail-flutter
# [263/480] Wrote: msasikanth__twine
# [264/480] Wrote: natsuk4ze__gal
# [265/480] Wrote: OpnTec__bodyapps-android
# [266/480] Wrote: OlauncherCF__OlauncherCF
# [267/480] Wrote: openintents__shoppinglist
# [268/480] Wrote: FooIbar__EhViewer
# [269/480] Wrote: opendocument-app__OpenDocument.droid
# [270/480] Wrote: getodk__collect
# [271/480] Wrote: openthread__ot-commissioner
# [272/480] Wrote: nschnettler__Compose-Scrobbler
# [273/480] Wrote: osama-raddad__FireCrasher
# [274/480] Wrote: passsy__spot
# [275/480] Wrote: pakoito__FunctionalAndroidReference
# [276/480] Wrote: patloew__RxLocation
# [277/480] Wrote: pauloaapereira__AndroidDevChallenge_Week4_JetWeatherfy
# [278/480] Wrote: overpas__compose-treemap-chart
# [279/480] Wrote: luniehq__lunie
# [280/480] Wrote: Piasy__YaMvp
# [281/480] Wrote: oxygen-updater__oxygen-updater
# [282/480] Wrote: ooni__probe-android
# [283/480] Wrote: OneBusAway__onebusaway-android
# [284/480] Wrote: PhoneVR-Developers__PhoneVR
# [285/480] Wrote: kylecorry31__Trail-Sense
# [286/480] Wrote: getsentry__sentry-react-native
# [287/480] Wrote: dart-lang__native
# [288/480] Wrote: Picovoice__falcon
# [289/480] Wrote: haqq-network__haqq-wallet
# [290/480] Wrote: Prashant-123__XpenseTracker
# [291/480] Wrote: posm__OpenMapKitAndroid
# [292/480] Wrote: pilgr__Paper
# [293/480] Wrote: Picovoice__picollm
# [294/480] Wrote: prisma__react-native-prisma
# [295/480] Wrote: Piwigo__Piwigo-Android
# [296/480] Wrote: promeG__TinyPinyin
# [297/480] Wrote: PRosenb__AdbClipboard
# [298/480] Wrote: PureWriter__ToastCompat
# [299/480] Wrote: Picovoice__koala
# [300/480] Wrote: quemb__QMBForm
# [301/480] Wrote: orgzly-revived__orgzly-android-revived
# [302/480] Wrote: rafaeltoledo__social-app
# [303/480] Wrote: pedrovgs__Shot
# [304/480] Wrote: ragunathjawahar__android-saripaar
# [305/480] Wrote: PureWriter__about-page
# [306/480] Wrote: OpenTracksApp__OpenTracks
# [307/480] Wrote: NUmeroAndDev__MaterialGallery-android
# [308/480] Wrote: nightscout__AndroidAPS
# [309/480] Wrote: inaturalist__iNaturalistReactNative
# [310/480] Wrote: Picovoice__cobra
# [311/480] Wrote: Redgram__redgram-for-reddit
# [312/480] Wrote: react-native-community__jsc-android-buildscripts
# [313/480] Wrote: ReactiveCircus__android-emulator-runner
# [314/480] Wrote: RedMadRobot__PINkman
# [315/480] Wrote: privacybydesign__irmamobile
# [316/480] Wrote: riggaroo__adopt-me-compose
# [317/480] Wrote: rafsanjani__datepickertimeline
# [318/480] Wrote: riggaroo__AndroidDatabaseUpgrades
# [319/480] Wrote: rejasupotaro__Rebuild
# [320/480] Wrote: BlueWallet__BlueWallet
# [321/480] Wrote: ronaldsmartin__Material-ViewPagerIndicator
# [322/480] Wrote: Rajawali__Rajawali
# [323/480] Wrote: RoRoche__AndroidStarter
# [324/480] Wrote: rubygarage__shopapp-android
# [325/480] Wrote: rtoshiro__FullscreenVideoView
# [326/480] Wrote: readrops__Readrops
# [327/480] Wrote: renyuneyun__Easer
# [328/480] Wrote: rumax__react-native-PixelsCatcher
# [329/480] Wrote: salvadordeveloper__flutter-crypto-app
# [330/480] Wrote: ruffle-rs__ruffle-android
# [331/480] Wrote: lovegaoshi__azusa-player-mobile
# [332/480] Wrote: ryanw-mobile__OctoMeter
# [333/480] Wrote: sakusaku3939__DeepLAndroid
# [334/480] Wrote: requery__requery
# [335/480] Wrote: SecUSo__privacy-friendly-notes
# [336/480] Wrote: SecUSo__privacy-friendly-pedometer
# [337/480] Wrote: SecUSo__privacy-friendly-todo-list
# [338/480] Wrote: sangcomz__FishBun
# [339/480] Wrote: servo__surfman
# [340/480] Wrote: scribe-org__Scribe-Android
# [341/480] Wrote: sellmair__kompass
# [342/480] Wrote: rozPierog__Cofi
# [343/480] Wrote: Sharkaboi__MediaHub
# [344/480] Wrote: seedvault-app__seedvault
# [345/480] Wrote: massivemadness__Squircle-CE
# [346/480] Wrote: segler-alex__RadioDroid
# [347/480] Wrote: simonnorberg__dmach
# [348/480] Wrote: sitefinitysteve__nativescript-auth0
# [349/480] Wrote: skydoves__colorpicker-compose
# [350/480] Wrote: skydoves__firebase-android-ktx
# [351/480] Wrote: skydoves__snitcher
# [352/480] Wrote: PatilShreyas__NotyKT
# [353/480] Wrote: RBusarow__Tangle
# [354/480] Wrote: Samsung__escargot
# [355/480] Wrote: skydoves__chatgpt-android
# [356/480] Wrote: sky-map-team__stardroid
# [357/480] Wrote: SilenceIM__Silence
# [358/480] Wrote: owntracks__android
# [359/480] Wrote: smartdevicelink__sdl_java_suite
# [360/480] Wrote: Picovoice__cheetah
# [361/480] Wrote: Spikeysanju__Wiggles
# [362/480] Wrote: splitwise__TokenAutoComplete
# [363/480] Wrote: sqldelight__sqldelight
# [364/480] Wrote: simlar__simlar-android
# [365/480] Wrote: square__curtains
# [366/480] Wrote: realm__realm-kotlin
# [367/480] Wrote: square__cycler
# [368/480] Wrote: square__papa
# [369/480] Wrote: ReactiveCircus__streamlined
# [370/480] Wrote: pachli__pachli-android
# [371/480] Wrote: persian-calendar__persian-calendar
# [372/480] Wrote: stephanenicolas__boundbox
# [373/480] Wrote: sopt-makers__sopt-android
# [374/480] Wrote: spacecowboy__NotePad
# [375/480] Wrote: software-mansion__react-native-svg
# [376/480] Wrote: Stuart-campbell__RushOrm
# [377/480] Wrote: StefanIlchev__ElementumService
# [378/480] Wrote: solygambas__kotlin-projects
# [379/480] Wrote: softartdev__NoteDelight
# [380/480] Wrote: takahirom__PreLollipopTransition
# [381/480] Wrote: SwissCovid__swisscovid-app-android
# [382/480] Wrote: talenguyen__PrettyBundle
# [383/480] Wrote: takahirom__Rin
# [384/480] Wrote: syrjs__core
# [385/480] Wrote: spacecowboy__Feeder
# [386/480] Wrote: simpledotorg__simple-android
# [387/480] Wrote: TeamNewPipe__NewPlayer
# [388/480] Wrote: square__leakcanary
# [389/480] Wrote: tfcporciuncula__flow-preferences
# [390/480] Wrote: tfcporciuncula__phonemoji
# [391/480] Wrote: TeamAmaze__AmazeFileManager
# [392/480] Wrote: TharunBalaji2004__android-ci-cd
# [393/480] Wrote: thiagokimo__Faker
# [394/480] Wrote: t895__DNSNet
# [395/480] Wrote: synonymdev__bitkit
# [396/480] Wrote: THEOplayer__react-native-theoplayer
# [397/480] Wrote: thevindu-w__clip_share_client
# [398/480] Wrote: TimotheeJeannin__ProviGen
# [399/480] Wrote: software-mansion__react-native-screens
# [400/480] Wrote: TeamNewPipe__NewPipe
# [401/480] Wrote: slackhq__circuit
# [402/480] Wrote: ThibaultBee__srtdroid
# [403/480] Wrote: tripadvisor__android-clockseekbar
# [404/480] Wrote: tonilopezmr__Game-of-Thrones
# [405/480] Wrote: thunderbiscuit__padawan-wallet
# [406/480] Wrote: TUBB__CalendarSelector
# [407/480] Wrote: Tommy-Geenexus__exif-eraser
# [408/480] Wrote: SharezoneApp__sharezone-app
# [409/480] Wrote: TomRoush__PdfBox-Android
# [410/480] Wrote: twilio__twilio-voice-react-native
# [411/480] Wrote: thyrlian__AwesomeValidation
# [412/480] Wrote: ValentinFunk__BrainPhaser
# [413/480] Wrote: vashisthg__StartPointSeekBar
# [414/480] Wrote: uber__simple-store
# [415/480] Wrote: VictorAlbertos__BreadcrumbsView
# [416/480] Wrote: VictorAlbertos__SwipeCoordinator
# [417/480] Wrote: vitaviva__compose-weather
# [418/480] Wrote: vitaviva__CountdownTimer
# [419/480] Wrote: twireapp__Twire
# [420/480] Wrote: openhab__openhab-android
# [421/480] Wrote: VRatMIT__TheSingularity-Unity
# [422/480] Wrote: vgaidarji__ci-matters
# [423/480] Wrote: voghDev__PdfViewPager
# [424/480] Wrote: wajahatkarim3__Imagine
# [425/480] Wrote: whilu__AndroidTagView
# [426/480] Wrote: UriahShaulMandel__BaldPhone
# [427/480] Wrote: tmurakami__dexopener
# [428/480] Wrote: v2er-app__Android
# [429/480] Wrote: TwidereProject__TwidereX-Android
# [430/480] Wrote: wuyexiong__transparent-over-animtabsview
# [431/480] Wrote: woxingxiao__FillBlankView
# [432/480] Wrote: vmiklos__plees-tracker
# [433/480] Wrote: willowtreeapps__vocable-android
# [434/480] Wrote: WangJie0822__Cashbook
# [435/480] Wrote: xurxodev__Movies-Kotlin-Kata
# [436/480] Wrote: xebia-functional__appsly-android-rest
# [437/480] Wrote: XuDaojie__MultiStateView
# [438/480] Wrote: XRPL-Labs__Xaman-App
# [439/480] Wrote: yahch__aria2c-android-app
# [440/480] Wrote: y-polek__TransmissionRemote
# [441/480] Wrote: xxfast__Decompose-Router
# [442/480] Wrote: xuyuanxiang__umi-react-native
# [443/480] Wrote: Yoonit-Labs__nativescript-yoonit-camera
# [444/480] Wrote: yeungeek__monkey-android
# [445/480] Wrote: zeref278__flutter_boilerplate
# [446/480] Wrote: ZenitechSoftware__Krate
# [447/480] Wrote: VREMSoftwareDevelopment__WiFiAnalyzer
# [448/480] Wrote: trynoice__android-app
# [449/480] Wrote: XilinJia__Podcini
# [450/480] Wrote: zsoltk__GameOfLife
# [451/480] Wrote: RocketChat__Rocket.Chat.ReactNative
# [452/480] Wrote: zkmopro__mopro
# [453/480] Wrote: yuriykulikov__AlarmClock
# [454/480] Wrote: zimly__zimly-backup
# [455/480] Wrote: streetcomplete__StreetComplete
# [456/480] Wrote: tasks__tasks
# [457/480] Wrote: Picovoice__porcupine
# [458/480] Wrote: square__okhttp
# [459/480] Wrote: TechbeeAT__jtxBoard
# [460/480] Wrote: topjohnwu__Magisk
# [461/480] Wrote: open-ani__animeko
# [462/480] Wrote: wireapp__kalium
# [463/480] Wrote: rainbow-me__rainbow
# [464/480] Wrote: nextcloud__android
# [465/480] Wrote: yogeshpaliyal__KeyPass
# [466/480] Wrote: realm__realm-js
# [467/480] Wrote: wikimedia__apps-android-wikipedia
# [468/480] Wrote: robolectric__robolectric
# [469/480] Wrote: square__workflow-kotlin
# [470/480] Wrote: streetwriters__notesnook
# [471/480] Wrote: organicmaps__organicmaps
# [472/480] Wrote: ankidroid__Anki-Android
# [473/480] Wrote: zoff99__ToxAndroidRefImpl
# [474/480] Wrote: square__wire
# [475/480] Wrote: MiSikora__laboratory
# [476/480] Wrote: MetaMask__metamask-mobile
# [477/480] Wrote: AnySoftKeyboard__AnySoftKeyboard
# [478/480] Wrote: LedgerHQ__ledger-live
# [479/480] Wrote: pytorch__executorch
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Episodes defintion: Start to current timeline

# %%
# === Build dataset for Observation 3.1 (V9.3 aligned) ===
# CHANGES:
# - DROP current_*_strict columns (they were misleading for your use case)
# - "FIRST" now uses a per-style union rule:
#     The earliest style to achieve ≥14 days of continuous coverage (no projecting beyond cutoff).
#   -> Updates: first_date, first_year, first_label, first_styleset
#   -> Also writes: first_styleset_union14d (same value as first_styleset for clarity)
# - "TIMELINE FORMATION" styles:
#     timeline_styleset_union14d = all styles that EVER achieved ≥14 days at any time
#     (filters out temporary (<14d) add+remove changes; does not use post-cutoff time)
# - "CURRENT" stays snapshot-based (repo-wide inventory at cutoff, no ≥14d):
#     current_label_snapshot, current_styleset_snapshot
# - Default-branch snapshot kept as current_styleset_default_B
# - num_episodes counts episodes with duration ≥14 days (as before)

from __future__ import annotations
import json
from pathlib import Path
from datetime import datetime, timezone, timedelta
from typing import Dict, List, Optional, Tuple, Set
import pandas as pd

# ---- Paths ----
WORK_ROOT   = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
OUTPUT_MINE = WORK_ROOT / "mineV9.3"

MAIN_CSV = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\1_Main_Spreadsheet\5.0_Total_Repo.csv")

OBS_OUTPUT = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\RQ3\Observations")
OBS_OUTPUT.mkdir(parents=True, exist_ok=True)

# ---- Settings ----
CUTOFF_ISO   = "2025-08-10 23:59:59 +0000"
PERSIST_DAYS = 14.0
CANONICAL_STYLES: Set[str] = {"Emu_Community", "Emu_Custom", "GMD", "ThirdParty"}

# ---- Helpers ----
def parse_iso(s: Optional[str]) -> Optional[datetime]:
    if not s:
        return None
    s = s.strip()
    if s.endswith("Z"):
        s = s[:-1] + "+00:00"
    # normalize +0000 -> +00:00
    if len(s) >= 5 and (s[-5] in ["+","-"]) and s[-3] != ":":
        s = s[:-2] + ":" + s[-2:]
    try:
        dt = datetime.fromisoformat(s)
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt.astimezone(timezone.utc)
    except Exception:
        return None

CUTOFF_DT = parse_iso(CUTOFF_ISO)
assert CUTOFF_DT is not None, f"Bad CUTOFF_ISO: {CUTOFF_ISO}"

def days_between(a: datetime, b: datetime) -> float:
    return (b - a).total_seconds() / 86400.0

def normalize_styles(style_list: List[str]) -> Set[str]:
    return {s for s in (style_list or []) if s in CANONICAL_STYLES}

def label_from_set(s: Set[str]) -> str:
    if "Emu_Community" in s and "Emu_Custom" in s:
        return "Both"
    if "Emu_Community" in s:
        return "Community"
    if "Emu_Custom" in s:
        return "Custom"
    if "GMD" in s:
        return "GMD"
    if "ThirdParty" in s:
        return "ThirdParty"
    return "None"

def read_repo_jsons(output_dir: Path) -> List[Path]:
    return sorted([p for p in output_dir.glob("*.emulator_timeline.json")])

def build_episodes(timeline_rows: List[Dict], cutoff_dt: datetime) -> List[Dict]:
    """Build contiguous episodes from timeline rows with non-empty canonical styles, capped at cutoff."""
    rows = [r for r in (timeline_rows or []) if r.get("styles")]
    rows.sort(key=lambda r: parse_iso(r.get("date")) or datetime.min.replace(tzinfo=timezone.utc))

    episodes: List[Dict] = []
    for i, r in enumerate(rows):
        start = parse_iso(r.get("date"))
        if start is None:
            continue

        styles_now = normalize_styles(list(r.get("styles") or []))
        if not styles_now:
            continue

        # end at the date of the next canonical row, else at cutoff
        end: Optional[datetime] = None
        for j in range(i + 1, len(rows)):
            nxt = rows[j]
            nxt_styles = normalize_styles(list(nxt.get("styles") or []))
            if nxt_styles:
                end = parse_iso(nxt.get("date"))
                break
        if end is None:
            end = cutoff_dt
        if end <= start:
            continue

        episodes.append({
            "start": start,
            "end": min(end, cutoff_dt),
            "styles": styles_now,
            "duration_days": max(0.0, days_between(start, min(end, cutoff_dt))),
        })
    return episodes

# ---- Per-style interval utilities ----
def merge_intervals(intervals: List[Tuple[datetime, datetime]]) -> List[Tuple[datetime, datetime]]:
    """Merge overlapping/contiguous [start,end] intervals."""
    if not intervals:
        return []
    intervals.sort(key=lambda ab: ab[0])
    merged: List[Tuple[datetime, datetime]] = []
    cur_s, cur_e = intervals[0]
    for a, b in intervals[1:]:
        if a <= cur_e:  # overlap or contiguous
            if b > cur_e: cur_e = b
        else:
            merged.append((cur_s, cur_e))
            cur_s, cur_e = a, b
    merged.append((cur_s, cur_e))
    return merged

def per_style_intervals(episodes: List[Dict]) -> Dict[str, List[Tuple[datetime, datetime]]]:
    """Intervals per style drawn from episode styles (episodes already capped at cutoff)."""
    m: Dict[str, List[Tuple[datetime, datetime]]] = {s: [] for s in CANONICAL_STYLES}
    for ep in episodes:
        for s in (ep["styles"] or []):
            if s in CANONICAL_STYLES:
                m[s].append((ep["start"], ep["end"]))
    # merge
    return {s: merge_intervals(v) for s, v in m.items() if v}

# ---- FIRST via union ≥14d ----
def first_union14d(episodes: List[Dict], min_days: float) -> Tuple[Optional[datetime], Optional[str]]:
    """
    Earliest moment any single style achieves ≥min_days of continuous coverage.
    Returns (first_date, style_name) or (None, None).
    """
    psi = per_style_intervals(episodes)
    best_date: Optional[datetime] = None
    best_style: Optional[str] = None

    # deterministic style tie-break order
    order = ["Emu_Community", "Emu_Custom", "GMD", "ThirdParty"]
    for style in order:
        if style not in psi: 
            continue
        for a, b in psi[style]:
            if days_between(a, b) >= min_days:
                t = a + timedelta(days=min_days)
                if best_date is None or t < best_date or (t == best_date and order.index(style) < order.index(best_style)):  # type: ignore
                    best_date = t
                    best_style = style
                break  # earliest interval for this style is enough

    return best_date, best_style

# ---- TIMELINE formation set (union of styles that ever achieved ≥14d) ----
def timeline_union14d_styles(episodes: List[Dict], min_days: float) -> Set[str]:
    psi = per_style_intervals(episodes)
    kept: Set[str] = set()
    for s, ivs in psi.items():
        for a, b in ivs:
            if days_between(a, b) >= min_days:
                kept.add(s)
                break
    return kept

def _find_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    lowmap = {c.lower(): c for c in df.columns}
    for name in candidates:
        if name.lower() in lowmap:
            return lowmap[name.lower()]
    return None

# ---- Build OBS core from miner ----
records: List[Dict] = []

json_files = read_repo_jsons(OUTPUT_MINE)
if not json_files:
    raise FileNotFoundError(f"No miner JSON files found under: {OUTPUT_MINE}")

for jf in json_files:
    with jf.open("r", encoding="utf-8") as f:
        rec = json.load(f)

    repo = rec.get("repo_name") or jf.stem
    timeline = rec.get("timeline") or []

    episodes = build_episodes(timeline, CUTOFF_DT)

    # Count episodes with ≥14d (for reference)
    num_episodes = sum(1 for ep in episodes if ep.get("duration_days", 0.0) >= PERSIST_DAYS)

    # FIRST via union ≥14d
    first_dt, first_style = first_union14d(episodes, PERSIST_DAYS)
    if first_dt and first_style:
        first_styleset_union14d = first_style
        first_label = label_from_set({first_style})
        first_year = first_dt.year
    else:
        first_styleset_union14d = ""
        first_label = "None"
        first_year = ""

    # TIMELINE formation set (filters out temporary <14d styles)
    timeline_set = timeline_union14d_styles(episodes, PERSIST_DAYS)
    timeline_styleset_union14d = "+".join(sorted(timeline_set)) if timeline_set else ""
    timeline_label_union14d = label_from_set(timeline_set)

    # CURRENT snapshot (repo-wide, no ≥14d)
    snap_def_raw  = rec.get("snapshot_as_of_cutoff_default") or []
    snap_all_raw  = rec.get("snapshot_as_of_cutoff_repo_wide") or []
    snap_def_norm_set  = normalize_styles(snap_def_raw)
    snap_all_norm_set  = normalize_styles(snap_all_raw)

    current_label_snapshot    = label_from_set(snap_all_norm_set)
    current_styleset_snapshot = "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else ""

    # Default-branch snapshot
    current_styleset_default_B = "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else ""

    # Optional diagnostic: short-and-active-at-cutoff flag (kept)
    recent_lt14d = 0
    if episodes:
        last_ep = episodes[-1]
        if last_ep["end"] >= CUTOFF_DT and last_ep["duration_days"] < PERSIST_DAYS:
            recent_lt14d = 1

    full_name = (repo or "").replace("__", ".")

    out = {
        "repo_name": repo,
        "full_name": full_name,
        "cutoff_date": CUTOFF_ISO,

        "num_episodes": num_episodes,

        # FIRST (union ≥14d)
        "first_date": first_dt.isoformat() if first_dt else "",
        "first_year": first_year,
        "first_label": first_label,
        "first_styleset": first_styleset_union14d,           # updated meaning
        "first_styleset_union14d": first_styleset_union14d,  # explicit column

        # TIMELINE formation set (ever ≥14d)
        "timeline_styleset_union14d": timeline_styleset_union14d,
        "timeline_label_union14d": timeline_label_union14d,

        # CURRENT (snapshot)
        "current_label_snapshot": current_label_snapshot,
        "current_styleset_snapshot": current_styleset_snapshot,
        "current_styleset_default_B": current_styleset_default_B,

        # Diagnostics
        "current_recent_lt14d": recent_lt14d,
        "snapshot_default_norm": "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else "",
        "snapshot_repo_wide_norm": "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else "",
        "qa_issue": rec.get("qa_issue", ""),
    }
    records.append(out)

df = pd.DataFrame.from_records(records).sort_values(["first_date", "repo_name"], na_position="last")

# ---- Merge MAIN: include 'execution_environment' as-is; exclude api_*; prefix the rest with main_ ----
if MAIN_CSV.exists():
    df_main = pd.read_csv(MAIN_CSV, dtype=str, encoding="utf-8", keep_default_na=False)

    col_full = _find_col(df_main, ["full_name", "Full_name", "repo_full_name"])
    col_exec = _find_col(df_main, ["execution_environment", "Execution_Environment"])

    if col_full:
        df["_key"] = df["full_name"].astype(str).str.lower().str.strip()
        df_main["_key"] = df_main[col_full].astype(str).str.lower().str.strip()

        # execution_environment as-is
        if col_exec:
            df_exec = df_main[["_key", col_exec]].copy()
            df_exec.rename(columns={col_exec: "execution_environment"}, inplace=True)
            df = df.merge(df_exec, on="_key", how="left")
        else:
            df["execution_environment"] = ""

        # other MAIN columns (exclude join col, exec col, any api_*)
        main_cols = []
        for c in df_main.columns:
            cl = c.lower()
            if c in {"_key", col_full}: continue
            if col_exec and c == col_exec: continue
            if cl.startswith("api_"): continue
            main_cols.append(c)
        if main_cols:
            df_other = df_main[["_key"] + main_cols].copy()
            df_other.rename(columns={c: f"main_{c}" for c in main_cols}, inplace=True)
            df = df.merge(df_other, on="_key", how="left")

        df.drop(columns=["_key"], inplace=True, errors="ignore")
    else:
        df["execution_environment"] = ""
else:
    df["execution_environment"] = ""

# ---- Column order: repo_name, full_name, execution_environment, then the rest ----
cols = list(df.columns)
for required in ["repo_name", "full_name", "execution_environment"]:
    if required not in cols:
        cols.insert(0, required)

# place full_name after repo_name
if "repo_name" in cols and "full_name" in cols:
    cols.remove("full_name")
    cols.insert(cols.index("repo_name") + 1, "full_name")

# place execution_environment after full_name
if "execution_environment" in cols:
    cols.remove("execution_environment")
    insert_at = cols.index("full_name") + 1 if "full_name" in cols else 1
    cols.insert(insert_at, "execution_environment")

df = df[cols]

# ---- FILTER: exclude repos where first_label == "None" ----
pre_filter_n = len(df)
df = df[df["first_label"] != "None"].copy()
post_filter_n = len(df)
dropped_n = pre_filter_n - post_filter_n
print(f"[info] Excluding repos with first_label == 'None': dropped {dropped_n} of {pre_filter_n}")

# ---- Save ----
out_csv = OBS_OUTPUT / "obs3_1_entry_vs_current.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"[ok] Wrote dataset (filtered): {out_csv}")

# Optional quick peek
try:
    show_cols = [
        "repo_name","full_name","execution_environment",
        "num_episodes",
        "first_year","first_label","first_date",
        "first_styleset","first_styleset_union14d",
        "timeline_styleset_union14d","timeline_label_union14d",
        "current_label_snapshot","current_styleset_snapshot",
        "current_styleset_default_B",
        "current_recent_lt14d",
        "snapshot_repo_wide_norm"
    ]
    show_cols += [c for c in df.columns if c.startswith("main_")][:3]
    print(df[show_cols].head(20).to_string(index=False))
except Exception:
    pass
# Out:
# [info] Excluding repos with first_label == 'None': dropped 1 of 352
# [ok] Wrote dataset (filtered): C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\RQ3\Observations\obs3_1_entry_vs_current.csv
#                                 repo_name                                full_name                execution_environment  num_episodes first_year first_label                first_date first_styleset first_styleset_union14d   timeline_styleset_union14d timeline_label_union14d current_label_snapshot    current_styleset_snapshot current_styleset_default_B  current_recent_lt14d      snapshot_repo_wide_norm                                               main_html_url main_native_instru_test main_flutter_instru_test
#                   ankidroid__Anki-Android                   ankidroid.Anki-Android              Emulator_ReactiveCircus             2       2013      Custom 2013-07-04T07:12:51+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                   https://github.com/ankidroid/Anki-Android                      45                        0
#                              tasks__tasks                              tasks.tasks Emulator_ReactiveCircus,Emulator_GMD             4       2013      Custom 2013-10-30T23:48:56+00:00     Emu_Custom              Emu_Custom Emu_Community+Emu_Custom+GMD                    Both                   Both Emu_Community+Emu_Custom+GMD          Emu_Community+GMD                     0 Emu_Community+Emu_Custom+GMD                              https://github.com/tasks/tasks                      70                        0
#     xebia-functional__appsly-android-rest     xebia-functional.appsly-android-rest                         Emulator_DIY             1       2014      Custom 2014-01-11T22:45:09+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom     https://github.com/xebia-functional/appsly-android-rest                      11                        0
#                      spacecowboy__NotePad                      spacecowboy.NotePad              Emulator_ReactiveCircus             2       2014      Custom 2014-02-01T14:45:28+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                      https://github.com/spacecowboy/NotePad                      31                        0
#                        nextcloud__android                        nextcloud.android              Emulator_ReactiveCircus             4       2014      Custom 2014-02-04T16:16:57+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                        https://github.com/nextcloud/android                     132                        0
#                     rejasupotaro__Rebuild                     rejasupotaro.Rebuild                         Emulator_DIY             1       2014      Custom 2014-02-17T14:16:49+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                     https://github.com/rejasupotaro/Rebuild                       9                        0
#  ksoichiro__SimpleAlertDialog-for-Android  ksoichiro.SimpleAlertDialog-for-Android                         Emulator_DIY             1       2014      Custom 2014-03-22T14:35:30+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom  https://github.com/ksoichiro/SimpleAlertDialog-for-Android                       1                        0
#            ksoichiro__AndroidFormEnhancer            ksoichiro.AndroidFormEnhancer                         Emulator_DIY             1       2014      Custom 2014-03-23T11:15:00+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom            https://github.com/ksoichiro/AndroidFormEnhancer                       2                        0
#                    AntennaPod__AntennaPod                    AntennaPod.AntennaPod              Emulator_ReactiveCircus             2       2014      Custom 2014-06-01T20:12:08+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                    https://github.com/AntennaPod/AntennaPod                      23                        0
#            OneBusAway__onebusaway-android            OneBusAway.onebusaway-android              Emulator_ReactiveCircus             2       2014      Custom 2014-06-10T17:14:25+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community            https://github.com/OneBusAway/onebusaway-android                      51                        0
#                 openintents__shoppinglist                 openintents.shoppinglist                         Emulator_DIY             1       2014      Custom 2014-06-30T11:25:16+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                 https://github.com/openintents/shoppinglist                       3                        0
#                  OpnTec__bodyapps-android                  OpnTec.bodyapps-android                         Emulator_DIY             1       2014      Custom 2014-07-06T19:34:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                  https://github.com/OpnTec/bodyapps-android                       9                        0
# blazsolar__android-collapse-calendar-view blazsolar.android-collapse-calendar-view                         Emulator_DIY             1       2014      Custom 2014-07-30T10:03:36+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom https://github.com/blazsolar/android-collapse-calendar-view                       1                        0
#                          AChep__AcDisplay                          AChep.AcDisplay                         Emulator_DIY             1       2014      Custom 2014-08-05T16:23:35+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                          https://github.com/AChep/AcDisplay                       6                        0
#         tripadvisor__android-clockseekbar         tripadvisor.android-clockseekbar                         Emulator_DIY             1       2014      Custom 2014-08-18T20:21:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom         https://github.com/tripadvisor/android-clockseekbar                       2                        0
#                         ligi__PassAndroid                         ligi.PassAndroid              Emulator_ReactiveCircus             2       2014      Custom 2014-08-26T19:45:07+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                         https://github.com/ligi/PassAndroid                      27                        0
#   ksoichiro__Android-ObservableScrollView   ksoichiro.Android-ObservableScrollView                         Emulator_DIY             1       2014      Custom 2014-11-22T15:16:43+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom   https://github.com/ksoichiro/Android-ObservableScrollView                      46                        0
#                       simonnorberg__dmach                       simonnorberg.dmach              Emulator_ReactiveCircus             2       2015      Custom 2015-01-01T19:43:14+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                       https://github.com/simonnorberg/dmach                       2                        0
#                        MostafaGazar__soas                        MostafaGazar.soas                         Emulator_DIY             1       2015      Custom 2015-01-12T21:40:46+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                        https://github.com/MostafaGazar/soas                       5                        0
#                 federicoiosue__Omni-Notes                 federicoiosue.Omni-Notes              Emulator_ReactiveCircus             2       2015      Custom 2015-03-03T00:13:10+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                 https://github.com/federicoiosue/Omni-Notes                      41                        0
