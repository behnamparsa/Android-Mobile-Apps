# %%
import pandas as pd
import os
import subprocess
import shutil
import random
from pathlib import Path
from dotenv import load_dotenv, set_key
import requests
import stat
import time

# === CONFIGURATION ===
MAX_PROJECTS = 2482
RANDOM_SEED = 42
NUM_SAMPLES_TO_KEEP = 150
ENV_FILE = 'All_tokens.env'
SEPARATOR = "__"


# === LOAD .env ===
load_dotenv(ENV_FILE)
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')
headers = {'Authorization': f'token {GITHUB_TOKEN}'}

if not GITHUB_TOKEN:
    raise ValueError("❌ GitHub token not found in All_tokens.env")

START_NUMBER = int(os.getenv("START_NUMBER"))
SAMPLE_LIST_RAW = os.getenv("SAMPLE_LIST", "").strip()

# === PATHS ===
csv_path = Path(r"D:\Android_Mobile_App\AndroidProject_4th\Android_Repos_MultiRange.csv")
base_dir = Path(r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone")
clone_dir = base_dir / "Cloned repos"
cloned_sample_dir = base_dir / "Cloned_Sample"
yml_output_dir = base_dir / "Config Files"
commits_dir = base_dir / "Commits"
build_info_dir = base_dir / "BuildInfo"
metadata_path = base_dir / "8.2-Project_Metadata.csv"
config_location_csv = base_dir / "Config_Location.csv"
log_path = base_dir / "repo_processing.log"
failed_projects = []



# === ENSURE ALL FOLDERS EXIST ===
for path in [clone_dir, yml_output_dir, commits_dir, build_info_dir, cloned_sample_dir]:
    path.mkdir(parents=True, exist_ok=True)

# === LOAD AND CLEAN CSV ===
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip().str.lower()
df = df[df['clone_url'].notna()]
df['github_url'] = df['clone_url'].astype(str).str.strip()
df = df[df['clone_url'].str.startswith("https://")]
df[['clone_url']].to_csv(base_dir / 'Sorted_URL_List.csv', index_label='Index')

# === HANDLE SAMPLE_LIST ===
if SAMPLE_LIST_RAW:
    sample_indices_to_keep = set(map(int, SAMPLE_LIST_RAW.split(',')))
    print(f"🔁 Loaded SAMPLE_LIST from .env with {len(sample_indices_to_keep)} indices.")
else:
    random.seed(RANDOM_SEED)
    sample_indices_to_keep = set(random.sample(range(len(df)), min(NUM_SAMPLES_TO_KEEP, len(df))))
    sample_string = ",".join(map(str, sorted(sample_indices_to_keep)))
    set_key(ENV_FILE, 'SAMPLE_LIST', sample_string)
    print(f"🎲 Generated and saved new SAMPLE_LIST with {len(sample_indices_to_keep)} indices.")

# === LOAD EXISTING CONFIG LOCATIONS IF RESUMING ===
if config_location_csv.exists():
    config_locations_df = pd.read_csv(config_location_csv)
else:
    config_locations_df = pd.DataFrame(columns=["repo_name", "config_file_path", "file_type"])

#log_message for warnings and errors
def log_message(message):
    print(message)
    with open(log_path, "a", encoding="utf-8") as log_file:
        log_file.write(message + "\n")


def check_rate_limit():
    response = requests.get("https://api.github.com/rate_limit", headers=headers)
    if response.status_code == 200:
        remaining = response.json()['rate']['remaining']
        reset_time = response.json()['rate']['reset']
        if remaining < 50:
            wait_seconds = reset_time - int(time.time())
            if wait_seconds > 0:
                log_message(f"⏳ Rate limit low. Sleeping for {wait_seconds} seconds...")
                time.sleep(wait_seconds + 5)  # Add buffer
        return remaining
    else:
        log_message("⚠️ Could not check rate limit.")
        return None

#========= Commit Hist from GitHub API
def extract_commit_metadata_api(owner, repo, repo_name, max_commits=500):
    url = f"https://api.github.com/repos/{owner}/{repo}/commits"
    commits = []
    page = 1
    check_rate_limit()

    while len(commits) < max_commits:
        paged_url = f"{url}?per_page=100&page={page}"
        response = requests.get(paged_url, headers=headers)
        if response.status_code != 200:
            log_message(f"❌ Error fetching {owner}/{repo} commits: {response.status_code}")
            

            break

        data = response.json()
        if not data:
            break

        for commit in data:
            commit_data = commit.get("commit", {})
            author = commit_data.get("author", {})
            commits.append({
                "sha": commit.get("sha"),
                "author_name": author.get("name"),
                "author_email": author.get("email"),
                "date": author.get("date"),
                "message": commit_data.get("message"),
                "html_url": commit.get("html_url")
            })

            if len(commits) >= max_commits:
                break

        page += 1

    if commits:
        
        df_commits = pd.DataFrame(commits)
        filename = f"{owner}.{repo}.commits.csv"
        filename = f"{repo_name}{SEPARATOR}commits.csv"
        df_commits.to_csv(commits_dir/filename, index=False)
        print(f"✅ API commit data saved for {owner}/{repo}")
    else:
        log_message(f"⚠️ No commits found for {owner}/{repo} via API")
        failed_projects.append(repo_name)

        





# # === COMMIT METADATA EXTRACTION FUNCTION ===
# def extract_commit_metadata(repo_path, output_path):
#     try:
#         cmd_hashes = ["git", "-C", str(repo_path), "log", "--pretty=format:%H"]
#         result_hashes = subprocess.run(cmd_hashes, capture_output=True, text=True, check=True)
#         commit_hashes = result_hashes.stdout.strip().split("\n")

#         rows = []
#         for commit in commit_hashes:
#             cmd_metadata = ["git", "-C", str(repo_path), "show", "--quiet",
#                             f"--pretty=format:%H|%an|%ae|%ad|%s", "--date=iso", commit]
#             result_metadata = subprocess.run(cmd_metadata, capture_output=True, text=True, check=True)
#             parts = result_metadata.stdout.strip().split("|", maxsplit=4)
#             if len(parts) < 5:
#                 continue

#             cmd_files = ["git", "-C", str(repo_path), "show", "--name-only", "--pretty=format:", commit]
#             result_files = subprocess.run(cmd_files, capture_output=True, text=True, check=True)
#             changed_files = result_files.stdout.strip().split("\n")
#             changed_files = [f.strip() for f in changed_files if f.strip()]

#             count_androidTest = sum("androidTest" in f for f in changed_files)
#             count_github_workflows = sum(".github/workflows" in f for f in changed_files)
#             count_gradle = sum("build.gradle" in f for f in changed_files)

#             rows.append({
#                 "commit_hash": parts[0],
#                 "author_name": parts[1],
#                 "author_email": parts[2],
#                 "commit_date": parts[3],
#                 "commit_message": parts[4],
#                 "touches_androidTest": count_androidTest > 0,
#                 "count_androidTest": count_androidTest,
#                 "touches_github_workflows": count_github_workflows > 0,
#                 "count_github_workflows": count_github_workflows,
#                 "touches_gradle": count_gradle > 0,
#                 "count_gradle": count_gradle
#             })

#         if rows:
#             df = pd.DataFrame(rows)
#             output_path.mkdir(parents=True, exist_ok=True)
#             df.to_csv(output_path / "contributors_commits.csv", index=False)
#             print(f"✅ Saved commit metadata for {repo_path.name}")
#         else:
#             print(f"⚠️ No commit data for {repo_path.name}")

#     except subprocess.CalledProcessError as e:
#         print(f"❌ Failed to extract commit data for {repo_path.name}: {e}")

# === FUNCTION TO HANDLE READ-ONLY FILES ===
def force_remove_readonly(func, path, _):
    os.chmod(path, stat.S_IWRITE)
    func(path)

# === FUNCTION TO GET COUNT FROM GITHUB API ===
def get_count(api_url, headers):
    check_rate_limit()

    try:
        r = requests.get(api_url, headers=headers, params={"per_page": 1})
        if 'Link' in r.headers:
            return int(r.headers['Link'].split(',')[0].split('page=')[-1].split('>')[0])
        return len(r.json())
    except:
        return 0

# === PROCESS EACH REPO ===
for i in range(START_NUMBER - 1, len(df)):
    url = df.iloc[i]['github_url']
    parts = url.split('/')
    if len(parts) < 5:
        continue
    username, project = parts[-2], parts[-1].replace('.git', '')
    
    repo_index = str(i).zfill(4)
    repo_name = f"{repo_index}{SEPARATOR}{username}{SEPARATOR}{project}"

    repo_path = clone_dir / repo_name

    print(f"\n🔍 [{i+1}/{len(df)}] Processing {repo_name}...")

    try:
        #subprocess.run(['git', 'clone', url, str(repo_path)], check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        subprocess.run(['git', 'clone', '--depth', '1', '--single-branch', url, str(repo_path)],
               check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        print("✅ Clone complete")
    except Exception as e:
        #print(f"❌ Clone failed for {repo_name}: {e}")
        log_message(f"❌ Clone failed for {repo_name}: {e}")
        failed_projects.append(repo_name)

        continue

        # === Detect and checkout default branch from GitHub API ===
    try:
        base_api = f"https://api.github.com/repos/{username}/{project}"
        headers = {'Authorization': f'token {GITHUB_TOKEN}'}
        check_rate_limit()
        r_branch = requests.get(base_api, headers=headers, timeout=15)
        if r_branch.status_code == 200:
            default_branch = r_branch.json().get('default_branch', 'main')
            subprocess.run(["git", "-C", str(repo_path), "checkout", default_branch],
                        stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
            print(f"📌 Checked out default branch: {default_branch}")
        else:
            print(f"⚠️ Could not detect default branch for {repo_name}, using current HEAD")
    except Exception as e:
        log_message(f"⚠️ Failed to checkout default branch for {repo_name}: {e}")
        #failed_projects.append(repo_name)



        # === Commit metadata via GitHub API ===
    #metadata_dir = git_metadata_dir / repo_name
    extract_commit_metadata_api(username, project,repo_name)



    # === Check commit count ===
    #metadata_dir = git_metadata_dir / repo_name
    #==== this block tries to get Commit hist from Full Clone with does not work for now
    #try:
    #    result = subprocess.run(['git', '-C', str(repo_path), 'rev-list', '--count', 'HEAD'], capture_output=True, text=True, check=True)
    #    local_commit_count = int(result.stdout.strip())
    #except subprocess.CalledProcessError:
    #    local_commit_count = 0
    #    print(f"⚠️ Could not get commit count for {repo_name}")

    #if local_commit_count > 0:
    #    extract_commit_metadata(repo_path, metadata_dir)
    #else:
    #    print(f"⚠️ No commits to extract for {repo_name}")

    # === Scan and copy config/build files ===
    ci_keywords = ['ci', 'build', 'test', 'workflow', 'pipeline', 'instrumentation']
    config_files_found = []

    for root, _, files in os.walk(repo_path):
        for file in files:
            file_lower = file.lower()
            file_path = Path(root) / file
            rel_path = str(file_path.relative_to(repo_path)).replace("\\", "/")

            try:
                should_copy = False
                file_type = file_lower.split('.')[-1]

                  # === Determine CI Platform ===
                ci_platform = "Other"
                rel_path_lower = rel_path.lower()

                if ".github/workflows" in rel_path_lower:
                    ci_platform = "GitHub"
                elif "circleci" in rel_path_lower:
                    ci_platform = "CircleCI"
                elif "gitlab-ci" in rel_path_lower or "gitlab" in rel_path_lower:
                    ci_platform = "GitLab CI"
                elif "travis" in rel_path_lower:
                    ci_platform = "Travis CI"
                elif "bitrise" in rel_path_lower:
                    ci_platform = "Bitrise"


                # === Determine if file qualifies as config ===
                if file_lower.endswith(('.yml', '.yaml')):
                    should_copy = True

                elif file_lower.endswith(('build.gradle', 'build.gradle.kts')): #['test', 'instrumentation']
                    # Store ALL build files unconditionally
                    should_copy = True

                elif file_lower.endswith(('.json', '.sh')):
                    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read().lower()
                        if any(keyword in content for keyword in ci_keywords):
                            should_copy = True

                # === If it qualifies, copy to Config Files with custom name ===
                if should_copy:
                    # Build the flat filename
                    rel_parts = rel_path.replace("/", ".").replace("\\", ".")
                    flat_filename = f"{repo_name}{SEPARATOR}{ci_platform}{SEPARATOR}{file}"


                    # Save to build folder
                    if file_lower.endswith('build.gradle'):
                        destination_path = build_info_dir / flat_filename
                    else:
                        destination_path = yml_output_dir / flat_filename
                    shutil.copy2(file_path, destination_path)
                    
                    config_files_found.append({
                        "repo_name": repo_name,
                        "config_file_path": flat_filename,
                        "file_type": file_type
                    })
                    
            except Exception as e:
                log_message(f"⚠️ Could not process or copy {rel_path} in {repo_name}: {e}")
                #log_message(f"❌ Could not process or copy {repo_name}: {e}")



    if config_files_found:
        config_locations_df = pd.concat([config_locations_df, pd.DataFrame(config_files_found)], ignore_index=True)

    # === Fetch and save metadata + contributors ===
    try:
        headers = {'Authorization': f'token {GITHUB_TOKEN}'}
        base_api = f"https://api.github.com/repos/{username}/{project}"

        check_rate_limit()
        r = requests.get(base_api, headers=headers, timeout=30)
        data = r.json()

                # === Count commits and unique contributors from CSV ===
        commit_csv_path = commits_dir / f"{username}.{project}.commits.csv"
        if commit_csv_path.exists():
            try:
                df_commits = pd.read_csv(commit_csv_path)
                total_commits = len(df_commits)
                unique_contributors = df_commits['author_name'].nunique()
            except Exception as e:
                log_message(f"⚠️ Could not read commit CSV for {repo_name}: {e}")
                total_commits = None
                unique_contributors = None
        else:
            total_commits = None
            unique_contributors = None

        metadata_row = {
            'project_name': project,
            'repo_name': repo_name,
            'full_name': data.get('full_name'),
            'description': data.get('description'),
            'language': data.get('language'),
            'license': data.get('license', {}).get('name') if data.get('license') else None,
            'created_at': data.get('created_at'),
            'updated_at': data.get('updated_at'),
            'last_commit_date': data.get('pushed_at'),
            'stars': data.get('stargazers_count'),
            'forks': data.get('forks_count'),
            'watchers': data.get('watchers_count'),
            'open_issues': data.get('open_issues_count'),
            'contributors': get_count(f"{base_api}/contributors", headers),
            'pull_requests': get_count(f"{base_api}/pulls?state=all", headers),
            'commits_GitAPI': total_commits,
            'contributors_with_commit': unique_contributors,
            'size': data.get('size')
        }

        metadata_df = pd.DataFrame([metadata_row])
        if metadata_path.exists():
            metadata_df.to_csv(metadata_path, mode='a', header=False, index=False)
        else:
            metadata_df.to_csv(metadata_path, mode='w', header=True, index=False)
        print("📜 Metadata saved")

        # === Save contributor names ===
        contrib_url = f"{base_api}/contributors"
        check_rate_limit()

        r_contrib = requests.get(contrib_url, headers=headers, timeout=30)
        if r_contrib.status_code == 200:
            contributor_logins = [c['login'] for c in r_contrib.json()]
            contributors_text = "\n".join(contributor_logins)
            # === Save contributors as single file in Config Files ===
            
            contributors_filename = f"{repo_name}{SEPARATOR}contributors.txt"
            contributors_path = commits_dir / contributors_filename
            with open(contributors_path, "w", encoding="utf-8") as f:
                f.write(contributors_text)

            print(f"👥 Saved contributors to: {contributors_path.name}")

        else:
            log_message(f"⚠️ Failed to fetch contributors for {repo_name}: {r_contrib.status_code}")

    except Exception as e:
        log_message(f"⚠️ Metadata or contributors error for {repo_name}: {e}")
        failed_projects.append(repo_name)


    # === Move to Cloned_Sample or delete ===
    try:
        if i in sample_indices_to_keep:
            # If part of sample, move to Cloned_Sample
            dest_path = cloned_sample_dir / repo_path.name
            if dest_path.exists():
                shutil.rmtree(dest_path, onerror=force_remove_readonly)
            shutil.move(str(repo_path), str(dest_path))
            print(f"📆 Sample repo moved to: {dest_path}")
        else:
            # If NOT in sample, delete completely
            shutil.rmtree(repo_path, onerror=force_remove_readonly)
            print(f"🗑️ Repo deleted: {repo_name}")
    except Exception as e:
        log_message(f"❌ Error moving/deleting repo folder for {repo_name}: {e}")


    set_key(ENV_FILE, 'START_NUMBER', str(i + 2))
    config_locations_df.drop_duplicates().to_csv(config_location_csv, index=False)

if failed_projects:
    failed_df = pd.DataFrame(failed_projects, columns=["repo_name"])
    failed_df.to_csv(base_dir / "Failed_Projects.csv", index=False)
    print(f"\n⚠️ {len(failed_projects)} projects failed. Saved to Failed_Projects.csv.")


print(f"\n✅ Process complete. Sampled: {len(sample_indices_to_keep)} | Total Processed: {len(df) - (START_NUMBER - 1)}")
print("\n✅ All selected repositories have been processed.")
# Out:
# 🔁 Loaded SAMPLE_LIST from .env with 150 indices.
#
# 🔍 [1/2614] Processing 0000__JunkFood02__Seal...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for JunkFood02/Seal
# 📜 Metadata saved
# 👥 Saved contributors to: 0000__JunkFood02__Seal__contributors.txt
# 🗑️ Repo deleted: 0000__JunkFood02__Seal
#
# 🔍 [2/2614] Processing 0001__android__nowinandroid...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android/nowinandroid
# 📜 Metadata saved
# 👥 Saved contributors to: 0001__android__nowinandroid__contributors.txt
# 🗑️ Repo deleted: 0001__android__nowinandroid
#
# 🔍 [3/2614] Processing 0002__square__picasso...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for square/picasso
# 📜 Metadata saved
# 👥 Saved contributors to: 0002__square__picasso__contributors.txt
# 🗑️ Repo deleted: 0002__square__picasso
#
# 🔍 [4/2614] Processing 0003__google__flexbox-layout...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for google/flexbox-layout
# 📜 Metadata saved
# 👥 Saved contributors to: 0003__google__flexbox-layout__contributors.txt
# 🗑️ Repo deleted: 0003__google__flexbox-layout
#
# 🔍 [5/2614] Processing 0004__android__sunflower...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android/sunflower
# 📜 Metadata saved
# 👥 Saved contributors to: 0004__android__sunflower__contributors.txt
# 🗑️ Repo deleted: 0004__android__sunflower
#
# 🔍 [6/2614] Processing 0005__JetBrains__compose-multiplatform...
# ❌ Clone failed for 0005__JetBrains__compose-multiplatform: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/JetBrains/compose-multiplatform.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0005__JetBrains__compose-multiplatform']' returned non-zero exit status 128.
#
# 🔍 [7/2614] Processing 0006__nickbutcher__plaid...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for nickbutcher/plaid
# 📜 Metadata saved
# 👥 Saved contributors to: 0006__nickbutcher__plaid__contributors.txt
# 🗑️ Repo deleted: 0006__nickbutcher__plaid
#
# 🔍 [8/2614] Processing 0007__MatsuriDayo__NekoBoxForAndroid...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for MatsuriDayo/NekoBoxForAndroid
# 📜 Metadata saved
# 👥 Saved contributors to: 0007__MatsuriDayo__NekoBoxForAndroid__contributors.txt
# 🗑️ Repo deleted: 0007__MatsuriDayo__NekoBoxForAndroid
#
# 🔍 [9/2614] Processing 0008__mihonapp__mihon...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for mihonapp/mihon
# 📜 Metadata saved
# 👥 Saved contributors to: 0008__mihonapp__mihon__contributors.txt
# 🗑️ Repo deleted: 0008__mihonapp__mihon
#
# 🔍 [10/2614] Processing 0009__android__uamp...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android/uamp
# 📜 Metadata saved
# 👥 Saved contributors to: 0009__android__uamp__contributors.txt
# 🗑️ Repo deleted: 0009__android__uamp
#
# 🔍 [11/2614] Processing 0010__tiann__KernelSU...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for tiann/KernelSU
# 📜 Metadata saved
# 👥 Saved contributors to: 0010__tiann__KernelSU__contributors.txt
# 🗑️ Repo deleted: 0010__tiann__KernelSU
#
# 🔍 [12/2614] Processing 0011__thunderbird__thunderbird-android...
# ❌ Clone failed for 0011__thunderbird__thunderbird-android: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/thunderbird/thunderbird-android.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0011__thunderbird__thunderbird-android']' returned non-zero exit status 128.
#
# 🔍 [13/2614] Processing 0012__mikepenz__MaterialDrawer...
# ✅ Clone complete
# 📌 Checked out default branch: develop
# ✅ API commit data saved for mikepenz/MaterialDrawer
# 📜 Metadata saved
# 👥 Saved contributors to: 0012__mikepenz__MaterialDrawer__contributors.txt
# 🗑️ Repo deleted: 0012__mikepenz__MaterialDrawer
#
# 🔍 [14/2614] Processing 0013__YiiGuxing__TranslationPlugin...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for YiiGuxing/TranslationPlugin
# 📜 Metadata saved
# 👥 Saved contributors to: 0013__YiiGuxing__TranslationPlugin__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0013__YiiGuxing__TranslationPlugin
#
# 🔍 [15/2614] Processing 0014__coil-kt__coil...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for coil-kt/coil
# 📜 Metadata saved
# 👥 Saved contributors to: 0014__coil-kt__coil__contributors.txt
# 🗑️ Repo deleted: 0014__coil-kt__coil
#
# 🔍 [16/2614] Processing 0015__Shabinder__SpotiFlyer...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for Shabinder/SpotiFlyer
# 📜 Metadata saved
# 👥 Saved contributors to: 0015__Shabinder__SpotiFlyer__contributors.txt
# 🗑️ Repo deleted: 0015__Shabinder__SpotiFlyer
#
# 🔍 [17/2614] Processing 0016__JakeWharton__timber...
# ✅ Clone complete
# 📌 Checked out default branch: trunk
# ✅ API commit data saved for JakeWharton/timber
# 📜 Metadata saved
# 👥 Saved contributors to: 0016__JakeWharton__timber__contributors.txt
# 🗑️ Repo deleted: 0016__JakeWharton__timber
#
# 🔍 [18/2614] Processing 0017__AppIntro__AppIntro...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for AppIntro/AppIntro
# 📜 Metadata saved
# 👥 Saved contributors to: 0017__AppIntro__AppIntro__contributors.txt
# 🗑️ Repo deleted: 0017__AppIntro__AppIntro
#
# 🔍 [19/2614] Processing 0018__libre-tube__LibreTube...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for libre-tube/LibreTube
# 📜 Metadata saved
# 👥 Saved contributors to: 0018__libre-tube__LibreTube__contributors.txt
# 🗑️ Repo deleted: 0018__libre-tube__LibreTube
#
# 🔍 [20/2614] Processing 0019__ankidroid__Anki-Android...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for ankidroid/Anki-Android
# 📜 Metadata saved
# 👥 Saved contributors to: 0019__ankidroid__Anki-Android__contributors.txt
# 🗑️ Repo deleted: 0019__ankidroid__Anki-Android
#
# 🔍 [21/2614] Processing 0020__InsertKoinIO__koin...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for InsertKoinIO/koin
# 📜 Metadata saved
# 👥 Saved contributors to: 0020__InsertKoinIO__koin__contributors.txt
# 🗑️ Repo deleted: 0020__InsertKoinIO__koin
#
# 🔍 [22/2614] Processing 0021__vfsfitvnm__ViMusic...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for vfsfitvnm/ViMusic
# 📜 Metadata saved
# 👥 Saved contributors to: 0021__vfsfitvnm__ViMusic__contributors.txt
# 🗑️ Repo deleted: 0021__vfsfitvnm__ViMusic
#
# 🔍 [23/2614] Processing 0022__yairm210__Unciv...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for yairm210/Unciv
# 📜 Metadata saved
# 👥 Saved contributors to: 0022__yairm210__Unciv__contributors.txt
# 🗑️ Repo deleted: 0022__yairm210__Unciv
#
# 🔍 [24/2614] Processing 0023__firebase__quickstart-android...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for firebase/quickstart-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0023__firebase__quickstart-android__contributors.txt
# 🗑️ Repo deleted: 0023__firebase__quickstart-android
#
# 🔍 [25/2614] Processing 0024__square__okio...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for square/okio
# 📜 Metadata saved
# 👥 Saved contributors to: 0024__square__okio__contributors.txt
# 🗑️ Repo deleted: 0024__square__okio
#
# 🔍 [26/2614] Processing 0025__simplex-chat__simplex-chat...
# ✅ Clone complete
# 📌 Checked out default branch: stable
# ✅ API commit data saved for simplex-chat/simplex-chat
# 📜 Metadata saved
# 👥 Saved contributors to: 0025__simplex-chat__simplex-chat__contributors.txt
# 🗑️ Repo deleted: 0025__simplex-chat__simplex-chat
#
# 🔍 [27/2614] Processing 0026__iSoron__uhabits...
# ✅ Clone complete
# 📌 Checked out default branch: dev
# ✅ API commit data saved for iSoron/uhabits
# 📜 Metadata saved
# 👥 Saved contributors to: 0026__iSoron__uhabits__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0026__iSoron__uhabits
#
# 🔍 [28/2614] Processing 0027__skydoves__Pokedex...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for skydoves/Pokedex
# 📜 Metadata saved
# 👥 Saved contributors to: 0027__skydoves__Pokedex__contributors.txt
# 🗑️ Repo deleted: 0027__skydoves__Pokedex
#
# 🔍 [29/2614] Processing 0028__T8RIN__ImageToolbox...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for T8RIN/ImageToolbox
# 📜 Metadata saved
# 👥 Saved contributors to: 0028__T8RIN__ImageToolbox__contributors.txt
# 🗑️ Repo deleted: 0028__T8RIN__ImageToolbox
#
# 🔍 [30/2614] Processing 0029__mobile-dev-inc__Maestro...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for mobile-dev-inc/Maestro
# 📜 Metadata saved
# 👥 Saved contributors to: 0029__mobile-dev-inc__Maestro__contributors.txt
# 🗑️ Repo deleted: 0029__mobile-dev-inc__Maestro
#
# 🔍 [31/2614] Processing 0030__uber__RIBs...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for uber/RIBs
# 📜 Metadata saved
# 👥 Saved contributors to: 0030__uber__RIBs__contributors.txt
# 🗑️ Repo deleted: 0030__uber__RIBs
#
# 🔍 [32/2614] Processing 0031__facebook__litho...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for facebook/litho
# 📜 Metadata saved
# 👥 Saved contributors to: 0031__facebook__litho__contributors.txt
# 🗑️ Repo deleted: 0031__facebook__litho
#
# 🔍 [33/2614] Processing 0032__recloudstream__cloudstream...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for recloudstream/cloudstream
# 📜 Metadata saved
# 👥 Saved contributors to: 0032__recloudstream__cloudstream__contributors.txt
# 🗑️ Repo deleted: 0032__recloudstream__cloudstream
#
# 🔍 [34/2614] Processing 0033__skydoves__android-developer-roadmap...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for skydoves/android-developer-roadmap
# 📜 Metadata saved
# 👥 Saved contributors to: 0033__skydoves__android-developer-roadmap__contributors.txt
# 🗑️ Repo deleted: 0033__skydoves__android-developer-roadmap
#
# 🔍 [35/2614] Processing 0034__bitwarden__android...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for bitwarden/android
# 📜 Metadata saved
# 👥 Saved contributors to: 0034__bitwarden__android__contributors.txt
# 🗑️ Repo deleted: 0034__bitwarden__android
#
# 🔍 [36/2614] Processing 0035__open-ani__animeko...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for open-ani/animeko
# 📜 Metadata saved
# 👥 Saved contributors to: 0035__open-ani__animeko__contributors.txt
# 🗑️ Repo deleted: 0035__open-ani__animeko
#
# 🔍 [37/2614] Processing 0036__florisboard__florisboard...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for florisboard/florisboard
# 📜 Metadata saved
# 👥 Saved contributors to: 0036__florisboard__florisboard__contributors.txt
# 🗑️ Repo deleted: 0036__florisboard__florisboard
#
# 🔍 [38/2614] Processing 0037__zhanghai__MaterialFiles...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for zhanghai/MaterialFiles
# 📜 Metadata saved
# 👥 Saved contributors to: 0037__zhanghai__MaterialFiles__contributors.txt
# 🗑️ Repo deleted: 0037__zhanghai__MaterialFiles
#
# 🔍 [39/2614] Processing 0038__chrisbanes__tivi...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for chrisbanes/tivi
# 📜 Metadata saved
# 👥 Saved contributors to: 0038__chrisbanes__tivi__contributors.txt
# 🗑️ Repo deleted: 0038__chrisbanes__tivi
#
# 🔍 [40/2614] Processing 0039__igorwojda__android-showcase...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for igorwojda/android-showcase
# 📜 Metadata saved
# 👥 Saved contributors to: 0039__igorwojda__android-showcase__contributors.txt
# 🗑️ Repo deleted: 0039__igorwojda__android-showcase
#
# 🔍 [41/2614] Processing 0040__Gurupreet__ComposeCookBook...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Gurupreet/ComposeCookBook
# 📜 Metadata saved
# 👥 Saved contributors to: 0040__Gurupreet__ComposeCookBook__contributors.txt
# 🗑️ Repo deleted: 0040__Gurupreet__ComposeCookBook
#
# 🔍 [42/2614] Processing 0041__ACRA__acra...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for ACRA/acra
# 📜 Metadata saved
# 👥 Saved contributors to: 0041__ACRA__acra__contributors.txt
# 🗑️ Repo deleted: 0041__ACRA__acra
#
# 🔍 [43/2614] Processing 0042__facebook__facebook-android-sdk...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for facebook/facebook-android-sdk
# 📜 Metadata saved
# 👥 Saved contributors to: 0042__facebook__facebook-android-sdk__contributors.txt
# 🗑️ Repo deleted: 0042__facebook__facebook-android-sdk
#
# 🔍 [44/2614] Processing 0043__Ashinch__ReadYou...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for Ashinch/ReadYou
# 📜 Metadata saved
# 👥 Saved contributors to: 0043__Ashinch__ReadYou__contributors.txt
# 🗑️ Repo deleted: 0043__Ashinch__ReadYou
#
# 🔍 [45/2614] Processing 0044__aniyomiorg__aniyomi...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for aniyomiorg/aniyomi
# 📜 Metadata saved
# 👥 Saved contributors to: 0044__aniyomiorg__aniyomi__contributors.txt
# 🗑️ Repo deleted: 0044__aniyomiorg__aniyomi
#
# 🔍 [46/2614] Processing 0045__airbnb__mavericks...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for airbnb/mavericks
# 📜 Metadata saved
# 👥 Saved contributors to: 0045__airbnb__mavericks__contributors.txt
# 🗑️ Repo deleted: 0045__airbnb__mavericks
#
# 🔍 [47/2614] Processing 0046__bmax121__APatch...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for bmax121/APatch
# 📜 Metadata saved
# 👥 Saved contributors to: 0046__bmax121__APatch__contributors.txt
# 🗑️ Repo deleted: 0046__bmax121__APatch
#
# 🔍 [48/2614] Processing 0047__KotatsuApp__Kotatsu...
# ✅ Clone complete
# 📌 Checked out default branch: devel
# ✅ API commit data saved for KotatsuApp/Kotatsu
# 📜 Metadata saved
# 👥 Saved contributors to: 0047__KotatsuApp__Kotatsu__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0047__KotatsuApp__Kotatsu
#
# 🔍 [49/2614] Processing 0048__kickstarter__android-oss...
# ❌ Clone failed for 0048__kickstarter__android-oss: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/kickstarter/android-oss.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0048__kickstarter__android-oss']' returned non-zero exit status 128.
#
# 🔍 [50/2614] Processing 0049__SagerNet__SagerNet...
# ✅ Clone complete
# 📌 Checked out default branch: dev
# ✅ API commit data saved for SagerNet/SagerNet
# 📜 Metadata saved
# 👥 Saved contributors to: 0049__SagerNet__SagerNet__contributors.txt
# 🗑️ Repo deleted: 0049__SagerNet__SagerNet
#
# 🔍 [51/2614] Processing 0050__androidx__androidx...
# ❌ Clone failed for 0050__androidx__androidx: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/androidx/androidx.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0050__androidx__androidx']' returned non-zero exit status 128.
#
# 🔍 [52/2614] Processing 0051__deniscerri__ytdlnis...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for deniscerri/ytdlnis
# 📜 Metadata saved
# 👥 Saved contributors to: 0051__deniscerri__ytdlnis__contributors.txt
# 🗑️ Repo deleted: 0051__deniscerri__ytdlnis
#
# 🔍 [53/2614] Processing 0052__z-huang__InnerTune...
# ✅ Clone complete
# 📌 Checked out default branch: dev
# ✅ API commit data saved for z-huang/InnerTune
# 📜 Metadata saved
# 👥 Saved contributors to: 0052__z-huang__InnerTune__contributors.txt
# 🗑️ Repo deleted: 0052__z-huang__InnerTune
#
# 🔍 [54/2614] Processing 0053__LibChecker__LibChecker...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for LibChecker/LibChecker
# 📜 Metadata saved
# 👥 Saved contributors to: 0053__LibChecker__LibChecker__contributors.txt
# 🗑️ Repo deleted: 0053__LibChecker__LibChecker
#
# 🔍 [55/2614] Processing 0054__Kunzisoft__KeePassDX...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Kunzisoft/KeePassDX
# 📜 Metadata saved
# 👥 Saved contributors to: 0054__Kunzisoft__KeePassDX__contributors.txt
# 🗑️ Repo deleted: 0054__Kunzisoft__KeePassDX
#
# 🔍 [56/2614] Processing 0055__mikepenz__Android-Iconics...
# ❌ Clone failed for 0055__mikepenz__Android-Iconics: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/mikepenz/Android-Iconics.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0055__mikepenz__Android-Iconics']' returned non-zero exit status 128.
#
# 🔍 [57/2614] Processing 0056__android__camera-samples...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android/camera-samples
# 📜 Metadata saved
# 👥 Saved contributors to: 0056__android__camera-samples__contributors.txt
# 🗑️ Repo deleted: 0056__android__camera-samples
#
# 🔍 [58/2614] Processing 0057__kizitonwose__Calendar...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for kizitonwose/Calendar
# 📜 Metadata saved
# 👥 Saved contributors to: 0057__kizitonwose__Calendar__contributors.txt
# 🗑️ Repo deleted: 0057__kizitonwose__Calendar
#
# 🔍 [59/2614] Processing 0058__Droid-ify__client...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for Droid-ify/client
# 📜 Metadata saved
# 👥 Saved contributors to: 0058__Droid-ify__client__contributors.txt
# 🗑️ Repo deleted: 0058__Droid-ify__client
#
# 🔍 [60/2614] Processing 0059__XayahSuSuSu__Android-DataBackup...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for XayahSuSuSu/Android-DataBackup
# 📜 Metadata saved
# 👥 Saved contributors to: 0059__XayahSuSuSu__Android-DataBackup__contributors.txt
# 🗑️ Repo deleted: 0059__XayahSuSuSu__Android-DataBackup
#
# 🔍 [61/2614] Processing 0060__didi__booster...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for didi/booster
# 📜 Metadata saved
# 👥 Saved contributors to: 0060__didi__booster__contributors.txt
# 🗑️ Repo deleted: 0060__didi__booster
#
# 🔍 [62/2614] Processing 0061__muzei__muzei...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for muzei/muzei
# 📜 Metadata saved
# 👥 Saved contributors to: 0061__muzei__muzei__contributors.txt
# 🗑️ Repo deleted: 0061__muzei__muzei
#
# 🔍 [63/2614] Processing 0062__android10__Android-CleanArchitecture-Kotlin...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android10/Android-CleanArchitecture-Kotlin
# 📜 Metadata saved
# 👥 Saved contributors to: 0062__android10__Android-CleanArchitecture-Kotlin__contributors.txt
# 🗑️ Repo deleted: 0062__android10__Android-CleanArchitecture-Kotlin
#
# 🔍 [64/2614] Processing 0063__d4rken-org__sdmaid-se...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for d4rken-org/sdmaid-se
# 📜 Metadata saved
# 👥 Saved contributors to: 0063__d4rken-org__sdmaid-se__contributors.txt
# 🗑️ Repo deleted: 0063__d4rken-org__sdmaid-se
#
# 🔍 [65/2614] Processing 0064__kittinunf__fuel...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for kittinunf/fuel
# 📜 Metadata saved
# 👥 Saved contributors to: 0064__kittinunf__fuel__contributors.txt
# 🗑️ Repo deleted: 0064__kittinunf__fuel
#
# 🔍 [66/2614] Processing 0065__AlmasB__FXGL...
# ✅ Clone complete
# 📌 Checked out default branch: dev
# ✅ API commit data saved for AlmasB/FXGL
# 📜 Metadata saved
# 👥 Saved contributors to: 0065__AlmasB__FXGL__contributors.txt
# 🗑️ Repo deleted: 0065__AlmasB__FXGL
#
# 🔍 [67/2614] Processing 0066__ReVanced__revanced-patches-template...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for ReVanced/revanced-patches-template
# 📜 Metadata saved
# 👥 Saved contributors to: 0066__ReVanced__revanced-patches-template__contributors.txt
# 🗑️ Repo deleted: 0066__ReVanced__revanced-patches-template
#
# 🔍 [68/2614] Processing 0067__android__user-interface-samples...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for android/user-interface-samples
# 📜 Metadata saved
# 👥 Saved contributors to: 0067__android__user-interface-samples__contributors.txt
# 🗑️ Repo deleted: 0067__android__user-interface-samples
#
# 🔍 [69/2614] Processing 0068__izhangzhihao__intellij-rainbow-brackets...
# ✅ Clone complete
# 📌 Checked out default branch: 2022.3
# ✅ API commit data saved for izhangzhihao/intellij-rainbow-brackets
# 📜 Metadata saved
# 👥 Saved contributors to: 0068__izhangzhihao__intellij-rainbow-brackets__contributors.txt
# 🗑️ Repo deleted: 0068__izhangzhihao__intellij-rainbow-brackets
#
# 🔍 [70/2614] Processing 0069__RetroMusicPlayer__RetroMusicPlayer...
# ✅ Clone complete
# 📌 Checked out default branch: dev
# ✅ API commit data saved for RetroMusicPlayer/RetroMusicPlayer
# 📜 Metadata saved
# 👥 Saved contributors to: 0069__RetroMusicPlayer__RetroMusicPlayer__contributors.txt
# 🗑️ Repo deleted: 0069__RetroMusicPlayer__RetroMusicPlayer
#
# 🔍 [71/2614] Processing 0070__simondankelmann__Bluetooth-LE-Spam...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for simondankelmann/Bluetooth-LE-Spam
# 📜 Metadata saved
# 👥 Saved contributors to: 0070__simondankelmann__Bluetooth-LE-Spam__contributors.txt
# 🗑️ Repo deleted: 0070__simondankelmann__Bluetooth-LE-Spam
#
# 🔍 [72/2614] Processing 0071__Mygod__VPNHotspot...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Mygod/VPNHotspot
# 📜 Metadata saved
# 👥 Saved contributors to: 0071__Mygod__VPNHotspot__contributors.txt
# 🗑️ Repo deleted: 0071__Mygod__VPNHotspot
#
# 🔍 [73/2614] Processing 0072__square__wire...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for square/wire
# 📜 Metadata saved
# 👥 Saved contributors to: 0072__square__wire__contributors.txt
# 🗑️ Repo deleted: 0072__square__wire
#
# 🔍 [74/2614] Processing 0073__burhanrashid52__PhotoEditor...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for burhanrashid52/PhotoEditor
# 📜 Metadata saved
# 👥 Saved contributors to: 0073__burhanrashid52__PhotoEditor__contributors.txt
# 🗑️ Repo deleted: 0073__burhanrashid52__PhotoEditor
#
# 🔍 [75/2614] Processing 0074__tasks__tasks...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for tasks/tasks
# 📜 Metadata saved
# 👥 Saved contributors to: 0074__tasks__tasks__contributors.txt
# 🗑️ Repo deleted: 0074__tasks__tasks
#
# 🔍 [76/2614] Processing 0075__ChuckerTeam__chucker...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for ChuckerTeam/chucker
# 📜 Metadata saved
# 👥 Saved contributors to: 0075__ChuckerTeam__chucker__contributors.txt
# 🗑️ Repo deleted: 0075__ChuckerTeam__chucker
#
# 🔍 [77/2614] Processing 0076__streetcomplete__StreetComplete...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for streetcomplete/StreetComplete
# 📜 Metadata saved
# 👥 Saved contributors to: 0076__streetcomplete__StreetComplete__contributors.txt
# 🗑️ Repo deleted: 0076__streetcomplete__StreetComplete
#
# 🔍 [78/2614] Processing 0077__Triple-T__gradle-play-publisher...
# ❌ Clone failed for 0077__Triple-T__gradle-play-publisher: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/Triple-T/gradle-play-publisher.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0077__Triple-T__gradle-play-publisher']' returned non-zero exit status 128.
#
# 🔍 [79/2614] Processing 0078__duckduckgo__Android...
# ❌ Clone failed for 0078__duckduckgo__Android: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/duckduckgo/Android.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0078__duckduckgo__Android']' returned non-zero exit status 128.
#
# 🔍 [80/2614] Processing 0079__dovecoteescapee__ByeDPIAndroid...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for dovecoteescapee/ByeDPIAndroid
# 📜 Metadata saved
# 👥 Saved contributors to: 0079__dovecoteescapee__ByeDPIAndroid__contributors.txt
# 🗑️ Repo deleted: 0079__dovecoteescapee__ByeDPIAndroid
#
# 🔍 [81/2614] Processing 0080__Dr-TSNG__Hide-My-Applist...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Dr-TSNG/Hide-My-Applist
# 📜 Metadata saved
# 👥 Saved contributors to: 0080__Dr-TSNG__Hide-My-Applist__contributors.txt
# 🗑️ Repo deleted: 0080__Dr-TSNG__Hide-My-Applist
#
# 🔍 [82/2614] Processing 0081__VREMSoftwareDevelopment__WiFiAnalyzer...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for VREMSoftwareDevelopment/WiFiAnalyzer
# 📜 Metadata saved
# 👥 Saved contributors to: 0081__VREMSoftwareDevelopment__WiFiAnalyzer__contributors.txt
# 🗑️ Repo deleted: 0081__VREMSoftwareDevelopment__WiFiAnalyzer
#
# 🔍 [83/2614] Processing 0082__owncloud__android...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for owncloud/android
# 📜 Metadata saved
# 👥 Saved contributors to: 0082__owncloud__android__contributors.txt
# 🗑️ Repo deleted: 0082__owncloud__android
#
# 🔍 [84/2614] Processing 0083__mikepenz__AboutLibraries...
# ❌ Clone failed for 0083__mikepenz__AboutLibraries: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/mikepenz/AboutLibraries.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0083__mikepenz__AboutLibraries']' returned non-zero exit status 128.
#
# 🔍 [85/2614] Processing 0084__jing332__tts-server-android...
# ✅ Clone complete
# 📌 Checked out default branch: compose
# ✅ API commit data saved for jing332/tts-server-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0084__jing332__tts-server-android__contributors.txt
# 🗑️ Repo deleted: 0084__jing332__tts-server-android
#
# 🔍 [86/2614] Processing 0085__mikepenz__FastAdapter...
# ✅ Clone complete
# 📌 Checked out default branch: develop
# ✅ API commit data saved for mikepenz/FastAdapter
# 📜 Metadata saved
# 👥 Saved contributors to: 0085__mikepenz__FastAdapter__contributors.txt
# 🗑️ Repo deleted: 0085__mikepenz__FastAdapter
#
# 🔍 [87/2614] Processing 0086__apollographql__apollo-kotlin...
# ❌ Clone failed for 0086__apollographql__apollo-kotlin: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/apollographql/apollo-kotlin.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0086__apollographql__apollo-kotlin']' returned non-zero exit status 128.
#
# 🔍 [88/2614] Processing 0087__skydoves__Balloon...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for skydoves/Balloon
# 📜 Metadata saved
# 👥 Saved contributors to: 0087__skydoves__Balloon__contributors.txt
# 🗑️ Repo deleted: 0087__skydoves__Balloon
#
# 🔍 [89/2614] Processing 0088__skydoves__chatgpt-android...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for skydoves/chatgpt-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0088__skydoves__chatgpt-android__contributors.txt
# 🗑️ Repo deleted: 0088__skydoves__chatgpt-android
#
# 🔍 [90/2614] Processing 0089__aistra0528__Hail...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for aistra0528/Hail
# 📜 Metadata saved
# 👥 Saved contributors to: 0089__aistra0528__Hail__contributors.txt
# 🗑️ Repo deleted: 0089__aistra0528__Hail
#
# 🔍 [91/2614] Processing 0090__SimpleMobileTools__Simple-Gallery...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for SimpleMobileTools/Simple-Gallery
# 📜 Metadata saved
# 👥 Saved contributors to: 0090__SimpleMobileTools__Simple-Gallery__contributors.txt
# 🗑️ Repo deleted: 0090__SimpleMobileTools__Simple-Gallery
#
# 🔍 [92/2614] Processing 0091__fcitx5-android__fcitx5-android...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for fcitx5-android/fcitx5-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0091__fcitx5-android__fcitx5-android__contributors.txt
# 🗑️ Repo deleted: 0091__fcitx5-android__fcitx5-android
#
# 🔍 [93/2614] Processing 0092__KieronQuinn__TapTap...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for KieronQuinn/TapTap
# 📜 Metadata saved
# 👥 Saved contributors to: 0092__KieronQuinn__TapTap__contributors.txt
# 🗑️ Repo deleted: 0092__KieronQuinn__TapTap
#
# 🔍 [94/2614] Processing 0093__ReVanced__revanced-patches...
# ❌ Clone failed for 0093__ReVanced__revanced-patches: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/ReVanced/revanced-patches.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0093__ReVanced__revanced-patches']' returned non-zero exit status 128.
#
# 🔍 [95/2614] Processing 0094__guolindev__PermissionX...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for guolindev/PermissionX
# 📜 Metadata saved
# 👥 Saved contributors to: 0094__guolindev__PermissionX__contributors.txt
# 🗑️ Repo deleted: 0094__guolindev__PermissionX
#
# 🔍 [96/2614] Processing 0095__NeoApplications__Neo-Store...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for NeoApplications/Neo-Store
# 📜 Metadata saved
# 👥 Saved contributors to: 0095__NeoApplications__Neo-Store__contributors.txt
# 🗑️ Repo deleted: 0095__NeoApplications__Neo-Store
#
# 🔍 [97/2614] Processing 0096__SimpleMobileTools__Simple-Calendar...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for SimpleMobileTools/Simple-Calendar
# 📜 Metadata saved
# 👥 Saved contributors to: 0096__SimpleMobileTools__Simple-Calendar__contributors.txt
# 🗑️ Repo deleted: 0096__SimpleMobileTools__Simple-Calendar
#
# 🔍 [98/2614] Processing 0097__tommybuonomo__dotsindicator...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for tommybuonomo/dotsindicator
# 📜 Metadata saved
# 👥 Saved contributors to: 0097__tommybuonomo__dotsindicator__contributors.txt
# 🗑️ Repo deleted: 0097__tommybuonomo__dotsindicator
#
# 🔍 [99/2614] Processing 0098__fumiama__copymanga...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for fumiama/copymanga
# 📜 Metadata saved
# 👥 Saved contributors to: 0098__fumiama__copymanga__contributors.txt
# 🗑️ Repo deleted: 0098__fumiama__copymanga
#
# 🔍 [100/2614] Processing 0099__Foso__Jetpack-Compose-Playground...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Foso/Jetpack-Compose-Playground
# 📜 Metadata saved
# 👥 Saved contributors to: 0099__Foso__Jetpack-Compose-Playground__contributors.txt
# 🗑️ Repo deleted: 0099__Foso__Jetpack-Compose-Playground
#
# 🔍 [101/2614] Processing 0100__celzero__rethink-app...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for celzero/rethink-app
# 📜 Metadata saved
# 👥 Saved contributors to: 0100__celzero__rethink-app__contributors.txt
# 🗑️ Repo deleted: 0100__celzero__rethink-app
#
# 🔍 [102/2614] Processing 0101__PierfrancescoSoffritti__android-youtube-player...
# ❌ Clone failed for 0101__PierfrancescoSoffritti__android-youtube-player: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/PierfrancescoSoffritti/android-youtube-player.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0101__PierfrancescoSoffritti__android-youtube-player']' returned non-zero exit status 128.
#
# 🔍 [103/2614] Processing 0102__osfans__trime...
# ✅ Clone complete
# 📌 Checked out default branch: develop
# ✅ API commit data saved for osfans/trime
# 📜 Metadata saved
# 👥 Saved contributors to: 0102__osfans__trime__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0102__osfans__trime
#
# 🔍 [104/2614] Processing 0103__maxrave-dev__SimpMusic...
# ✅ Clone complete
# 📌 Checked out default branch: jetpack_compose
# ✅ API commit data saved for maxrave-dev/SimpMusic
# 📜 Metadata saved
# 👥 Saved contributors to: 0103__maxrave-dev__SimpMusic__contributors.txt
# 🗑️ Repo deleted: 0103__maxrave-dev__SimpMusic
#
# 🔍 [105/2614] Processing 0104__element-hq__element-android...
# ✅ Clone complete
# 📌 Checked out default branch: develop
# ✅ API commit data saved for element-hq/element-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0104__element-hq__element-android__contributors.txt
# 🗑️ Repo deleted: 0104__element-hq__element-android
#
# 🔍 [106/2614] Processing 0105__jellyfin__jellyfin-androidtv...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for jellyfin/jellyfin-androidtv
# 📜 Metadata saved
# 👥 Saved contributors to: 0105__jellyfin__jellyfin-androidtv__contributors.txt
# 🗑️ Repo deleted: 0105__jellyfin__jellyfin-androidtv
#
# 🔍 [107/2614] Processing 0106__SmartToolFactory__Jetpack-Compose-Tutorials...
# ❌ Clone failed for 0106__SmartToolFactory__Jetpack-Compose-Tutorials: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/SmartToolFactory/Jetpack-Compose-Tutorials.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0106__SmartToolFactory__Jetpack-Compose-Tutorials']' returned non-zero exit status 128.
#
# 🔍 [108/2614] Processing 0107__vinaygaba__Learn-Jetpack-Compose-By-Example...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for vinaygaba/Learn-Jetpack-Compose-By-Example
# 📜 Metadata saved
# 👥 Saved contributors to: 0107__vinaygaba__Learn-Jetpack-Compose-By-Example__contributors.txt
# 🗑️ Repo deleted: 0107__vinaygaba__Learn-Jetpack-Compose-By-Example
#
# 🔍 [109/2614] Processing 0108__easybangumiorg__EasyBangumi...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for easybangumiorg/EasyBangumi
# 📜 Metadata saved
# 👥 Saved contributors to: 0108__easybangumiorg__EasyBangumi__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0108__easybangumiorg__EasyBangumi
#
# 🔍 [110/2614] Processing 0109__hegaojian__JetpackMvvm...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for hegaojian/JetpackMvvm
# 📜 Metadata saved
# 👥 Saved contributors to: 0109__hegaojian__JetpackMvvm__contributors.txt
# 🗑️ Repo deleted: 0109__hegaojian__JetpackMvvm
#
# 🔍 [111/2614] Processing 0110__oblador__react-native-keychain...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for oblador/react-native-keychain
# 📜 Metadata saved
# 👥 Saved contributors to: 0110__oblador__react-native-keychain__contributors.txt
# 🗑️ Repo deleted: 0110__oblador__react-native-keychain
#
# 🔍 [112/2614] Processing 0111__raamcosta__compose-destinations...
# ❌ Clone failed for 0111__raamcosta__compose-destinations: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/raamcosta/compose-destinations.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0111__raamcosta__compose-destinations']' returned non-zero exit status 128.
#
# 🔍 [113/2614] Processing 0112__DanielMartinus__Konfetti...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for DanielMartinus/Konfetti
# 📜 Metadata saved
# 👥 Saved contributors to: 0112__DanielMartinus__Konfetti__contributors.txt
# 🗑️ Repo deleted: 0112__DanielMartinus__Konfetti
#
# 🔍 [114/2614] Processing 0113__rumboalla__apkupdater...
# ✅ Clone complete
# 📌 Checked out default branch: 3.x
# ✅ API commit data saved for rumboalla/apkupdater
# 📜 Metadata saved
# 👥 Saved contributors to: 0113__rumboalla__apkupdater__contributors.txt
# 🗑️ Repo deleted: 0113__rumboalla__apkupdater
#
# 🔍 [115/2614] Processing 0114__kosi-libs__Kodein...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for kosi-libs/Kodein
# 📜 Metadata saved
# 👥 Saved contributors to: 0114__kosi-libs__Kodein__contributors.txt
# 🗑️ Repo deleted: 0114__kosi-libs__Kodein
#
# 🔍 [116/2614] Processing 0115__JetBrains__kotlinconf-app...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for JetBrains/kotlinconf-app
# 📜 Metadata saved
# 👥 Saved contributors to: 0115__JetBrains__kotlinconf-app__contributors.txt
# 🗑️ Repo deleted: 0115__JetBrains__kotlinconf-app
#
# 🔍 [117/2614] Processing 0116__Swordfish90__Lemuroid...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for Swordfish90/Lemuroid
# 📜 Metadata saved
# 👥 Saved contributors to: 0116__Swordfish90__Lemuroid__contributors.txt
# 🗑️ Repo deleted: 0116__Swordfish90__Lemuroid
#
# 🔍 [118/2614] Processing 0117__jarnedemeulemeester__findroid...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for jarnedemeulemeester/findroid
# 📜 Metadata saved
# 👥 Saved contributors to: 0117__jarnedemeulemeester__findroid__contributors.txt
# 🗑️ Repo deleted: 0117__jarnedemeulemeester__findroid
#
# 🔍 [119/2614] Processing 0118__MM2-0__Kvaesitso...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for MM2-0/Kvaesitso
# 📜 Metadata saved
# 👥 Saved contributors to: 0118__MM2-0__Kvaesitso__contributors.txt
# 🗑️ Repo deleted: 0118__MM2-0__Kvaesitso
#
# 🔍 [120/2614] Processing 0119__wuseal__JsonToKotlinClass...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for wuseal/JsonToKotlinClass
# 📜 Metadata saved
# 👥 Saved contributors to: 0119__wuseal__JsonToKotlinClass__contributors.txt
# 🗑️ Repo deleted: 0119__wuseal__JsonToKotlinClass
#
# 🔍 [121/2614] Processing 0120__FooIbar__EhViewer...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for FooIbar/EhViewer
# 📜 Metadata saved
# 👥 Saved contributors to: 0120__FooIbar__EhViewer__contributors.txt
# 🗑️ Repo deleted: 0120__FooIbar__EhViewer
#
# 🔍 [122/2614] Processing 0121__videolan__vlc-android...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for videolan/vlc-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0121__videolan__vlc-android__contributors.txt
# 🗑️ Repo deleted: 0121__videolan__vlc-android
#
# 🔍 [123/2614] Processing 0122__joreilly__PeopleInSpace...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for joreilly/PeopleInSpace
# 📜 Metadata saved
# 👥 Saved contributors to: 0122__joreilly__PeopleInSpace__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0122__joreilly__PeopleInSpace
#
# 🔍 [124/2614] Processing 0123__EhViewer-NekoInverter__EhViewer...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for EhViewer-NekoInverter/EhViewer
# 📜 Metadata saved
# 👥 Saved contributors to: 0123__EhViewer-NekoInverter__EhViewer__contributors.txt
# 🗑️ Repo deleted: 0123__EhViewer-NekoInverter__EhViewer
#
# 🔍 [125/2614] Processing 0124__GuoXiCheng__SKIP...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for GuoXiCheng/SKIP
# 📜 Metadata saved
# 👥 Saved contributors to: 0124__GuoXiCheng__SKIP__contributors.txt
# 🗑️ Repo deleted: 0124__GuoXiCheng__SKIP
#
# 🔍 [126/2614] Processing 0125__wordpress-mobile__WordPress-Android...
# ❌ Clone failed for 0125__wordpress-mobile__WordPress-Android: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/wordpress-mobile/WordPress-Android.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0125__wordpress-mobile__WordPress-Android']' returned non-zero exit status 128.
#
# 🔍 [127/2614] Processing 0126__BiliRoamingX__BiliRoamingX...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for BiliRoamingX/BiliRoamingX
# 📜 Metadata saved
# 👥 Saved contributors to: 0126__BiliRoamingX__BiliRoamingX__contributors.txt
# 🗑️ Repo deleted: 0126__BiliRoamingX__BiliRoamingX
#
# 🔍 [128/2614] Processing 0127__Ivy-Apps__ivy-wallet...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for Ivy-Apps/ivy-wallet
# 📜 Metadata saved
# 👥 Saved contributors to: 0127__Ivy-Apps__ivy-wallet__contributors.txt
# 🗑️ Repo deleted: 0127__Ivy-Apps__ivy-wallet
#
# 🔍 [129/2614] Processing 0128__keiyoushi__extensions-source...
# ❌ Clone failed for 0128__keiyoushi__extensions-source: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/keiyoushi/extensions-source.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0128__keiyoushi__extensions-source']' returned non-zero exit status 128.
#
# 🔍 [130/2614] Processing 0129__adrielcafe__voyager...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for adrielcafe/voyager
# 📜 Metadata saved
# 👥 Saved contributors to: 0129__adrielcafe__voyager__contributors.txt
# 🗑️ Repo deleted: 0129__adrielcafe__voyager
#
# 🔍 [131/2614] Processing 0130__ismartcoding__plain-app...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for ismartcoding/plain-app
# 📜 Metadata saved
# 👥 Saved contributors to: 0130__ismartcoding__plain-app__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0130__ismartcoding__plain-app
#
# 🔍 [132/2614] Processing 0131__gotev__android-upload-service...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for gotev/android-upload-service
# 📜 Metadata saved
# 👥 Saved contributors to: 0131__gotev__android-upload-service__contributors.txt
# 📆 Sample repo moved to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Cloned_Sample\0131__gotev__android-upload-service
#
# 🔍 [133/2614] Processing 0132__ReVanced__revanced-patcher...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for ReVanced/revanced-patcher
# 📜 Metadata saved
# 👥 Saved contributors to: 0132__ReVanced__revanced-patcher__contributors.txt
# 🗑️ Repo deleted: 0132__ReVanced__revanced-patcher
#
# 🔍 [134/2614] Processing 0133__oshai__kotlin-logging...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for oshai/kotlin-logging
# 📜 Metadata saved
# 👥 Saved contributors to: 0133__oshai__kotlin-logging__contributors.txt
# 🗑️ Repo deleted: 0133__oshai__kotlin-logging
#
# 🔍 [135/2614] Processing 0134__LukasLechnerDev__Kotlin-Coroutines-and-Flow-UseCases-on-Android...
# ❌ Clone failed for 0134__LukasLechnerDev__Kotlin-Coroutines-and-Flow-UseCases-on-Android: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/LukasLechnerDev/Kotlin-Coroutines-and-Flow-UseCases-on-Android.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0134__LukasLechnerDev__Kotlin-Coroutines-and-Flow-UseCases-on-Android']' returned non-zero exit status 128.
#
# 🔍 [136/2614] Processing 0135__korlibs__korge...
# ✅ Clone complete
# 📌 Checked out default branch: main
# ✅ API commit data saved for korlibs/korge
# 📜 Metadata saved
# 👥 Saved contributors to: 0135__korlibs__korge__contributors.txt
# 🗑️ Repo deleted: 0135__korlibs__korge
#
# 🔍 [137/2614] Processing 0136__home-assistant__android...
# ❌ Clone failed for 0136__home-assistant__android: Command '['git', 'clone', '--depth', '1', '--single-branch', 'https://github.com/home-assistant/android.git', 'D:\\Android_Mobile_App\\AndroidProject_4th\\6.2-Shallow_Clone\\Cloned repos\\0136__home-assistant__android']' returned non-zero exit status 128.
#
# 🔍 [138/2614] Processing 0137__wangchenyan__ponymusic...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for wangchenyan/ponymusic
# 📜 Metadata saved
# 👥 Saved contributors to: 0137__wangchenyan__ponymusic__contributors.txt
# 🗑️ Repo deleted: 0137__wangchenyan__ponymusic
#
# 🔍 [139/2614] Processing 0138__YenalyLiew__Han1meViewer...
# ✅ Clone complete
# 📌 Checked out default branch: feat/new_download
# ✅ API commit data saved for YenalyLiew/Han1meViewer
# 📜 Metadata saved
# 👥 Saved contributors to: 0138__YenalyLiew__Han1meViewer__contributors.txt
# 🗑️ Repo deleted: 0138__YenalyLiew__Han1meViewer
#
# 🔍 [140/2614] Processing 0139__MikeOrtiz__TouchImageView...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for MikeOrtiz/TouchImageView
# 📜 Metadata saved
# 👥 Saved contributors to: 0139__MikeOrtiz__TouchImageView__contributors.txt
# 🗑️ Repo deleted: 0139__MikeOrtiz__TouchImageView
#
# 🔍 [141/2614] Processing 0140__liangjingkanji__BRV...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for liangjingkanji/BRV
# 📜 Metadata saved
# 👥 Saved contributors to: 0140__liangjingkanji__BRV__contributors.txt
# 🗑️ Repo deleted: 0140__liangjingkanji__BRV
#
# 🔍 [142/2614] Processing 0141__zcweng__SwitchButton...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for zcweng/SwitchButton
# 📜 Metadata saved
# 👥 Saved contributors to: 0141__zcweng__SwitchButton__contributors.txt
# 🗑️ Repo deleted: 0141__zcweng__SwitchButton
#
# 🔍 [143/2614] Processing 0142__orgzly__orgzly-android...
# ✅ Clone complete
# 📌 Checked out default branch: master
# ✅ API commit data saved for orgzly/orgzly-android
# 📜 Metadata saved
# 👥 Saved contributors to: 0142__orgzly__orgzly-android__contributors.txt
# 🗑️ Repo deleted: 0142__orgzly__orgzly-android
#
# 🔍 [144/2614] Processing 0143__KieronQuinn__Smartspacer...
