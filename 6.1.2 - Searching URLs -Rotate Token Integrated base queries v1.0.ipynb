# %% [markdown]
# - Search in GitHub REST API - integrated base queries for lanaguges and keyword "android"
# - double check with Real-time json

# %%
import os
import requests
import pandas as pd
import logging
from dotenv import load_dotenv
from datetime import datetime, timedelta
from time import sleep, time as now


# === LOGGING ===
logging.basicConfig(level=logging.INFO, format="[%(levelname)s] %(message)s")
logger = logging.getLogger(__name__)

# === CONFIG ===
output_dir = r"C:\Android Mobile App\Step1_URL_Search"
output_csv_all = os.path.join(output_dir, "github_android_search_results_all.csv")
output_csv_filtered = os.path.join(output_dir, "github_android_search_results_filtered.csv")

os.makedirs(output_dir, exist_ok=True)

# === AUTH ===
load_dotenv("All_Tokens.env")
tokens = [v for k, v in os.environ.items() if k.startswith("GITHUB_TOKEN_") and v]
if not tokens:
    raise ValueError("❌ No GitHub tokens found in All_Tokens.env")

token_index = 0
HEADERS = {
    "Authorization": f"token {tokens[token_index]}",
    "Accept": "application/vnd.github+json"
}

# === DATE RANGE ===
start_date = datetime.strptime("2008-01-01", "%Y-%m-%d")
end_date = datetime.strptime("2024-12-31", "%Y-%m-%d")

# === WINDOW SETTINGS ===
initial_window_hours = 15 * 24  # 10 days
min_window_hours = 1
max_window_hours = 90 * 24
MAX_RESULTS_PER_QUERY = 1000
TARGET_FILL_RATIO = 0.25

# === BASE QUERIES ===
# language and keyword must meet at the same time - more rubust structure than fully independent queries
# second laryer verification for the query items is upgraded for this combined query structure
base_queries = [
    "stars:>50 language:Kotlin fork:false archived:false topic:android",
    "stars:>50 language:Kotlin fork:false archived:false android in:name,description,readme",
    
    "stars:>50 language:Java fork:false archived:false topic:android",
    "stars:>50 language:Java fork:false archived:false android in:name,description,readme",
    
    "stars:>50 language:Dart fork:false archived:false topic:android",
    "stars:>50 language:Dart fork:false archived:false android in:name,description,readme",
    
]

# === Filter ===
def filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
    # Basic checks — same as before
    min_stars = 50
    if item.get('stargazers_count', 0) <= min_stars:
        return False
    if item.get('fork', False) != expected_fork:
        return False
    if item.get('archived', False) != expected_archived:
        return False

    # Lowercased comparisons
    language = (item.get('language') or '').lower()
    topics = [t.lower() for t in item.get('topics', [])]
    description = (item.get('description') or '').lower()
    name = (item.get('name') or '').lower()

    if expected_language:
        if language != expected_language:
            return False
    if expected_topic:
        if expected_topic not in topics:
            return False
    if expected_keyword:
        if expected_keyword not in description and expected_keyword not in name:
            return False

    return True


# === Token Rotate ===
def rotate_token():
    global token_index, HEADERS
    token_index = (token_index + 1) % len(tokens)
    HEADERS = {
        "Authorization": f"token {tokens[token_index]}",
        "Accept": "application/vnd.github+json"
    }
    logger.warning(f"🔑 Rotated → Token #{token_index + 1} / {len(tokens)}")

# === Rate Limit ===
def check_rate_limit():
    r = requests.get("https://api.github.com/rate_limit", headers=HEADERS)
    if r.status_code != 200:
        logger.warning("⚠️  Could not check rate limit.")
        return
    data = r.json()
    remaining = data['resources']['search']['remaining']
    reset_epoch = data['resources']['search']['reset']
    reset_in = max(0, reset_epoch - now())
    logger.info(f"🔎 Remaining: {remaining} | Resets in {reset_in/60:.1f} min")
    if remaining < 5:
        if len(tokens) > 1:
            rotate_token()
            check_rate_limit()
        else:
            logger.warning(f"⏳ No extra tokens → sleeping {reset_in/60:.1f} min")
            sleep(reset_in + 5)

# === Count ===
def check_count(query):
    while True:
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 1})
        if r.status_code == 200:
            return r.json().get("total_count", 0)
        elif r.status_code == 403:
            rotate_token()
        else:
            logger.error(f"❌ Count error: {r.status_code} — {r.text}")
            return -1

# === Fetch ===
def fetch_items(query):
    all_items = []
    for page in range(1, 11):
        check_rate_limit()
        r = requests.get("https://api.github.com/search/repositories",
                         headers=HEADERS, params={"q": query, "per_page": 100, "page": page})
        if r.status_code == 200:
            items = r.json().get("items", [])
            if not items:
                break
            all_items.extend(items)
            sleep(1)
        elif r.status_code == 403:
            rotate_token()
            return fetch_items(query)
        else:
            logger.error(f"❌ Fetch error: {r.status_code} — {r.text}")
            break
    return all_items

# === MAIN ===
final_results = []
for base_query_prefix in base_queries:
    current_start = start_date
    window_hours = initial_window_hours

    while current_start < end_date:
        current_end = min(current_start + timedelta(hours=window_hours), end_date)
        date_range = f"created:{current_start.isoformat()}..{current_end.isoformat()}"
        base_query = f"{base_query_prefix} {date_range}"

        total_count = check_count(base_query)
        logger.info(f"⏳ {base_query} → {total_count} repos")

        if total_count >= MAX_RESULTS_PER_QUERY and window_hours > min_window_hours:
            window_hours = max(window_hours // 2, min_window_hours)
            continue
        elif total_count < MAX_RESULTS_PER_QUERY * TARGET_FILL_RATIO and window_hours * 2 <= max_window_hours:
            window_hours = min(window_hours * 2, max_window_hours)

        items = fetch_items(base_query)
        expected_fork = 'fork:true' in base_query_prefix
        expected_archived = 'archived:true' in base_query_prefix
        expected_language = ''
        expected_topic = ''
        expected_keyword = ''

        if 'language:Kotlin' in base_query_prefix:
            expected_language = 'kotlin'
        if 'language:Java' in base_query_prefix:
            expected_language = 'java'
        if 'language:Dart' in base_query_prefix:
            expected_language = 'dart'

        if 'topic:android' in base_query_prefix:
            expected_topic = 'android'

        if 'android in:name,description,readme' in base_query_prefix:
            expected_keyword = 'android'



        count_passed = 0  # ✅ NEW counter for this window
        for item in items:
            # if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
            #     # === Check for valid clone_url ===
            #     clone_url = item.get("clone_url", "").strip()
            #     if not clone_url:
            #         logger.warning(f"⚠️ Skipped: missing or blank clone_url for {item.get('full_name')}")
            #         continue  # skip this one!
            
            if filter_item(item, expected_fork, expected_archived, expected_language, expected_topic, expected_keyword):
                clean_item = {
                    "name": item.get("name"),
                    "full_name": item.get("full_name"),
                    "language": item.get("language"),
                    "stargazers_count": item.get("stargazers_count"),
                    "forks": item.get("forks"),
                    "topics": item.get("topics"),
                    #"description": item.get("description"),
                    "fork": item.get("fork"),
                    "archived": item.get("archived"),
                    "owner.login": item.get("owner", {}).get("login"),
                    "html_url": item.get("html_url"),
                    "clone_url": item.get("clone_url"),
                    "visibility": item.get("visibility"),
                    "size": item.get("size"),
                    "open_issues_count": item.get("open_issues_count"),
                    "base_qualifier": base_query_prefix,
                    "search_qualifier": base_query,
                    "repo_stars": item.get("stargazers_count", 0),
                    "match_type": expected_language.capitalize() or expected_topic.capitalize() or expected_keyword.capitalize()
                }
                final_results.append(clean_item)
                count_passed += 1  # ✅ increment

        logger.info(f"✅ Window done: {count_passed} items")


        current_start = current_end + timedelta(seconds=1)


# ✅ === SAVE CLEAN CSV/XLSX ===


# Optional: create unique timestamp to prevent overwriting
ts = datetime.now().strftime("%Y%m%d_%H%M%S")

# 1️⃣ One final DataFrame: from CLEAN all_results
df_clean = pd.DataFrame(final_results)

# 2️⃣ Quick check: show a preview to be sure it's clean
print("📌 Columns:", list(df_clean.columns))
print(df_clean.head(5))

# 3️⃣ Choose output file names — timestamped for safety
output_csv = os.path.join(output_dir, f"search_results_{ts}.csv")
output_xlsx = os.path.join(output_dir, f"search_results_{ts}.xlsx")


# 4️⃣ Save to CSV and Excel
df_clean.to_csv(output_csv, index=False)
df_clean.to_excel(output_xlsx, index=False)

logger.info(f"✅ All done! Clean results saved to: {output_csv} and {output_xlsx}")

# 5️⃣ Optional: show final row count
print(f"✅ Final rows saved: {len(df_clean)}")
# Out:
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-01-01T00:00:00..2008-01-16T00:00:00 → 0 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-01-16T00:00:01..2008-02-15T00:00:01 → 0 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-02-15T00:00:02..2008-04-15T00:00:02 → 0 repos
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-04-15T00:00:03..2008-06-14T00:00:03 → 0 repos
# [INFO] 🔎 Remaining: 23 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 22 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-06-14T00:00:04..2008-08-13T00:00:04 → 0 repos
# [INFO] 🔎 Remaining: 21 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 20 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-08-13T00:00:05..2008-10-12T00:00:05 → 0 repos
# [INFO] 🔎 Remaining: 19 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 18 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-10-12T00:00:06..2008-12-11T00:00:06 → 0 repos
# [INFO] 🔎 Remaining: 17 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 16 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2008-12-11T00:00:07..2009-02-09T00:00:07 → 0 repos
# [INFO] 🔎 Remaining: 15 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-02-09T00:00:08..2009-04-10T00:00:08 → 0 repos
# [INFO] 🔎 Remaining: 13 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-04-10T00:00:09..2009-06-09T00:00:09 → 0 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-06-09T00:00:10..2009-08-08T00:00:10 → 0 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 8 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-08-08T00:00:11..2009-10-07T00:00:11 → 0 repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 6 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-10-07T00:00:12..2009-12-06T00:00:12 → 0 repos
# [INFO] 🔎 Remaining: 5 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 4 | Resets in 0.9 min
# [WARNING] 🔑 Rotated → Token #2 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2009-12-06T00:00:13..2010-02-04T00:00:13 → 2 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-02-04T00:00:14..2010-04-05T00:00:14 → 0 repos
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-04-05T00:00:15..2010-06-04T00:00:15 → 0 repos
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 23 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-06-04T00:00:16..2010-08-03T00:00:16 → 0 repos
# [INFO] 🔎 Remaining: 22 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 21 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-08-03T00:00:17..2010-10-02T00:00:17 → 0 repos
# [INFO] 🔎 Remaining: 20 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 19 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-10-02T00:00:18..2010-12-01T00:00:18 → 0 repos
# [INFO] 🔎 Remaining: 18 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 17 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2010-12-01T00:00:19..2011-01-30T00:00:19 → 0 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 15 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-01-30T00:00:20..2011-03-31T00:00:20 → 1 repos
# [INFO] 🔎 Remaining: 14 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 13 | Resets in 0.9 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 12 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-03-31T00:00:21..2011-05-30T00:00:21 → 0 repos
# [INFO] 🔎 Remaining: 11 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-05-30T00:00:22..2011-07-29T00:00:22 → 1 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.9 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-07-29T00:00:23..2011-09-27T00:00:23 → 2 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.8 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 4 | Resets in 0.8 min
# [WARNING] 🔑 Rotated → Token #3 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-09-27T00:00:24..2011-11-26T00:00:24 → 0 repos
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2011-11-26T00:00:25..2012-01-25T00:00:25 → 1 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2012-01-25T00:00:26..2012-03-25T00:00:26 → 2 repos
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 23 | Resets in 1.0 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2012-03-25T00:00:27..2012-05-24T00:00:27 → 2 repos
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2012-05-24T00:00:28..2012-07-23T00:00:28 → 0 repos
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] ✅ Window done: 0 items
# [INFO] 🔎 Remaining: 17 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:2012-07-23T00:00:29..2012-09-21T00:00:29 → 4 repos
# [INFO] 🔎 Remaining: 16 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 15 | Resets in 0.9 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 14 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Kotlin fork:false archived:false topic:android created:
repos
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 6 | Resets in 0.6 min
# [INFO] ✅ Window done: 5 items
# [INFO] 🔎 Remaining: 5 | Resets in 0.6 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2023-07-26T00:01:36..2023-09-24T00:01:36 → 22 repos
# [INFO] 🔎 Remaining: 4 | Resets in 0.6 min
# [WARNING] 🔑 Rotated → Token #1 / 4
# [INFO] 🔎 Remaining: 30 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 29 | Resets in 1.0 min
# [INFO] ✅ Window done: 2 items
# [INFO] 🔎 Remaining: 28 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2023-09-24T00:01:37..2023-11-23T00:01:37 → 24 repos
# [INFO] 🔎 Remaining: 27 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 26 | Resets in 1.0 min
# [INFO] ✅ Window done: 5 items
# [INFO] 🔎 Remaining: 25 | Resets in 1.0 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2023-11-23T00:01:38..2024-01-22T00:01:38 → 28 repos
# [INFO] 🔎 Remaining: 24 | Resets in 1.0 min
# [INFO] 🔎 Remaining: 23 | Resets in 0.9 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 22 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-01-22T00:01:39..2024-03-22T00:01:39 → 33 repos
# [INFO] 🔎 Remaining: 21 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 20 | Resets in 0.9 min
# [INFO] ✅ Window done: 7 items
# [INFO] 🔎 Remaining: 19 | Resets in 0.9 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-03-22T00:01:40..2024-05-21T00:01:40 → 15 repos
# [INFO] 🔎 Remaining: 18 | Resets in 0.9 min
# [INFO] 🔎 Remaining: 17 | Resets in 0.8 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 16 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-05-21T00:01:41..2024-07-20T00:01:41 → 12 repos
# [INFO] 🔎 Remaining: 15 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 14 | Resets in 0.8 min
# [INFO] ✅ Window done: 1 items
# [INFO] 🔎 Remaining: 13 | Resets in 0.8 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-07-20T00:01:42..2024-09-18T00:01:42 → 23 repos
# [INFO] 🔎 Remaining: 12 | Resets in 0.8 min
# [INFO] 🔎 Remaining: 11 | Resets in 0.7 min
# [INFO] ✅ Window done: 3 items
# [INFO] 🔎 Remaining: 10 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-09-18T00:01:43..2024-11-17T00:01:43 → 10 repos
# [INFO] 🔎 Remaining: 9 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 8 | Resets in 0.7 min
# [INFO] ✅ Window done: 4 items
# [INFO] 🔎 Remaining: 7 | Resets in 0.7 min
# [INFO] ⏳ stars:>50 language:Dart fork:false archived:false android in:name,description,readme created:2024-11-17T00:01:44..2024-12-31T00:00:00 → 12 repos
# [INFO] 🔎 Remaining: 6 | Resets in 0.7 min
# [INFO] 🔎 Remaining: 5 | Resets in 0.7 min
# [INFO] ✅ Window done: 1 items
# 📌 Columns: ['name', 'full_name', 'language', 'stargazers_count', 'forks', 'topics', 'fork', 'archived', 'owner.login', 'html_url', 'clone_url', 'visibility', 'size', 'open_issues_count', 'base_qualifier', 'search_qualifier', 'repo_stars', 'match_type']
#                   name                        full_name language  \
# 0        quran_android              quran/quran_android   Kotlin
# 1           gobandroid                  ligi/gobandroid   Kotlin
# 2  thunderbird-android  thunderbird/thunderbird-android   Kotlin
# 3          SeriesGuide         UweTrottmann/SeriesGuide   Kotlin
# 4      bugsnag-android          bugsnag/bugsnag-android   Kotlin
#
#    stargazers_count  forks                                             topics  \
# 0              2174    918                                   [android, quran]
# 1               237     66  [android, android-app, goban, kotlin, kotlin-a...
# 2             12110   2594           [android, communication, email, mozilla]
# 3              2030    403  [android, android-application, kotlin, movies,...
# 4              1217    207  [android, android-apps, bugs, bugsnag, crash, ...
#
#     fork  archived   owner.login  \
# 0  False     False         quran
# 1  False     False          ligi
# 2  False     False   thunderbird
# 3  False     False  UweTrottmann
# 4  False     False       bugsnag
#
#                                             html_url  \
# 0             https://github.com/quran/quran_android
# 1                 https://github.com/ligi/gobandroid
# 2  https://github.com/thunderbird/thunderbird-and...
# 3        https://github.com/UweTrottmann/SeriesGuide
# 4         https://github.com/bugsnag/bugsnag-android
#
#                                            clone_url visibility    size  \
# 0         https://github.com/quran/quran_android.git     public   16893
# 1             https://github.com/ligi/gobandroid.git     public   14650
# 2  https://github.com/thunderbird/thunderbird-and...     public  151639
# 3    https://github.com/UweTrottmann/SeriesGuide.git     public  146185
# 4     https://github.com/bugsnag/bugsnag-android.git     public   12669
#
#    open_issues_count                                     base_qualifier  \
# 0                357  stars:>50 language:Kotlin fork:false archived:...
# 1                 73  stars:>50 language:Kotlin fork:false archived:...
# 2                847  stars:>50 language:Kotlin fork:false archived:...
# 3                 57  stars:>50 language:Kotlin fork:false archived:...
# 4                 19  stars:>50 language:Kotlin fork:false archived:...
#
#                                     search_qualifier  repo_stars match_type
# 0  stars:>50 language:Kotlin fork:false archived:...        2174     Kotlin
# 1  stars:>50 language:Kotlin fork:false archived:...         237     Kotlin
# 2  stars:>50 language:Kotlin fork:false archived:...       12110     Kotlin
# 3  stars:>50 language:Kotlin fork:false archived:...        2030     Kotlin
# 4  stars:>50 language:Kotlin fork:false archived:...        1217     Kotlin
# [INFO] ✅ All done! Clean results saved to: C:\Android Mobile App\Step1_URL_Search\search_results_20250624_123004.csv and C:\Android Mobile App\Step1_URL_Search\search_results_20250624_123004.xlsx
# ✅ Final rows saved: 20041
