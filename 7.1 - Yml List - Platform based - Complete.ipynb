# %%
import os
import pandas as pd
import re
import yaml  # pip install pyyaml

# === CONFIG ===
PROJECTS_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files"
OUTPUT_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, "7.1-YML_List_4th_attempt_ShallowC.csv")

# === UNIVERSAL UNIT TEST KEYWORDS ===
UNIT_TEST_KEYWORDS = [
    'gradlew test', './gradlew test', 'testdebugunittest', 'testreleaseunittest',
    'test', 'run unit tests', 'run: test', 'npm test', 'yarn test'
]

# === CI-SPECIFIC INSTRUMENTATION RULES ===
def detect_instrumentation_by_platform(ci_platform, yaml_text, run_scripts, parsed):
    """
    Improved detection:
    - Wrappers & GMD: parsed 'uses'
    - Manual emulator: must have (sdkmanager or avdmanager) AND (emulator or avdmanager)
    - No more adb-only false positives.
    """
    run_text = "\n".join(run_scripts)
    found = set()
    matched = []

    # === Common emulator keywords ===
    has_sdk = any(kw in run_text for kw in ['sdkmanager'])
    has_avd = any(kw in run_text for kw in ['avdmanager'])
    has_emulator = any(kw in run_text for kw in ['emulator'])
    has_create_avd = any(kw in run_text for kw in ['android create avd'])

    if ci_platform == "GitHub":
        # 1️⃣ Wrappers & GMD
        for job in parsed.get('jobs', {}).values():
            for step in job.get('steps', []):
                if isinstance(step, dict) and 'uses' in step:
                    uses = step['uses'].lower()
                    if 'reactivecircus/android-emulator-runner' in uses:
                        found.add('GitHub_emulator_full')
                        matched.append('reactivecircus/android-emulator-runner')
                    if 'malinskiy/action-android/emulator-run-cmd' in uses:
                        found.add('GitHub_emulator_compact')
                        matched.append('malinskiy/action-android/emulator-run-cmd')
                    if any(gmd in uses for gmd in ['cleanmanageddevices', 'managedvirtualdevice', 'manageddevices']):
                        found.add('GitHub_GMD')
                        matched.append('GMD keywords (uses)')

        if any("cleanmanageddevices" in s or "manageddevices" in s for s in run_scripts):
            found.add('GitHub_GMD')
            matched.append('GMD keywords (Gradle run)')

        # ✅ Improved manual check:
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitHub_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "CircleCI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('CircleCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Bitrise":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Bitrise_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "GitLab CI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitLab CI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Travis CI":
        if (has_sdk or has_avd or has_create_avd) and (has_emulator or has_avd):
            found.add('TravisCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Other":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Other_emulator_manual')
            matched.append('manual emulator setup')

    # === Third-party Labs ===
    lab_run_text = run_text
    for job in parsed.get('jobs', {}).values():
        for step in job.get('steps', []):
            if isinstance(step, dict) and 'uses' in step:
                uses = step['uses'].lower()
                if 'firebase-test-lab-action' in uses:
                    found.add('Firebase_Compact')
                    matched.append('Firebase-Test-Lab-Action')
                if 'microsoft/appcenter-test-cli-action' in uses:
                    found.add('Appcenter')
                    matched.append('Appcenter Test CLI Action')
                if 'browserstack' in uses or 'browserstack/github-actions' in uses:
                    found.add('Browserstack')
                    matched.append('Browserstack action')
                if 'saucelabs/saucectl-run-action' in uses:
                    found.add('SauceLabs')
                    matched.append('Sauce Labs GitHub Action')

    if 'gcloud firebase test android run' in lab_run_text:
        found.add('Firebase_Full')
        matched.append('gcloud firebase test android run')

    if 'appcenter test run' in lab_run_text:
        found.add('Appcenter')
        matched.append('appcenter test run')

    if 'browserstack' in lab_run_text:
        found.add('Browserstack')
        matched.append('browserstack CLI call')

    if 'saucectl' in lab_run_text:
        found.add('SauceLabs')
        matched.append('saucectl CLI')

    return found, matched


def detect_ci_platform(file_path, yaml_text):
    text = yaml_text.lower()
    path = file_path.lower()
    filename = os.path.basename(path)

    if re.search(r'(^|[\\/])\.github([\\/]|$)', path) or 'github_actions' in filename:
        return "GitHub"
    if '.gitlab' in path or 'gitlab-ci' in filename:
        return "GitLab CI"
    if '.travis' in path or 'travis' in filename:
        return "Travis CI"
    if '.circleci' in path or 'circleci' in filename:
        return "CircleCI"
    if '.bitrise' in path or 'bitrise' in filename:
        return "Bitrise"

    if 'uses: actions/' in text:
        return "GitHub"
    if 'uses: docker://circleci/' in text or 'circleci/android:' in text:
        return "CircleCI"
    if 'travis' in text:
        return "Travis CI"
    if 'bitrise' in text:
        return "Bitrise"
    if 'gitlab-ci' in text:
        return "GitLab CI"

    return "Other"


def detect_unit_test(yaml_text):
    text = yaml_text.lower()
    for kw in UNIT_TEST_KEYWORDS:
        if kw in text:
            return True
    return False


def extract_run_scripts(parsed):
    def get_runs(node):
        runs = []
        if isinstance(node, dict):
            for k, v in node.items():
                if k == 'run' and isinstance(v, str):
                    runs.append(v.lower())
                else:
                    runs.extend(get_runs(v))
        elif isinstance(node, list):
            for item in node:
                runs.extend(get_runs(item))
        return runs

    scripts = get_runs(parsed)
    if isinstance(parsed, dict):
        for key in ['script', 'before_script', 'before_install', 'after_script']:
            val = parsed.get(key)
            if isinstance(val, list):
                scripts.extend([str(v).lower() for v in val])
            elif isinstance(val, str):
                scripts.append(val.lower())
    return scripts


# === PROCESS ALL ===
results = []

for root, _, files in os.walk(PROJECTS_DIR):
    for file in files:
        if file.endswith(('.yml', '.yaml')):
            file_path = os.path.join(root, file)
            filename = os.path.basename(file_path)

            # ✅ NEW: Extract full_name between first and third '__'
            parts = filename.split("__")
            if len(parts) >= 3:
                full_name = f"{parts[1]}__{parts[2]}"
            else:
                full_name = filename  # fallback

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    raw = f.read().replace('\t', ' ')
                    ci_platform = detect_ci_platform(file_path, raw)

                    parsed = yaml.safe_load(raw)
                    run_scripts = extract_run_scripts(parsed)

                    is_unit = detect_unit_test(raw)
                    instr_types, matched_keys = detect_instrumentation_by_platform(ci_platform, raw, run_scripts, parsed)

                    test_type_str = ', '.join(sorted(instr_types))
                    is_instr = bool(instr_types)

                    results.append({
                        'filename': filename,
                        'full_name': full_name,
                        'ci_platform': ci_platform,
                        'test_type': test_type_str,
                        'unit_test': is_unit,
                        'instrumentation_test': is_instr,
                        'matched_keywords': "; ".join(sorted(set(matched_keys)))
                    })

                    print(f"✅ {filename} | CI: {ci_platform} | Unit: {is_unit} | Instr: {is_instr} | Keys: {matched_keys}")

            except Exception as e:
                print(f"❌ ERROR: {file_path} => {e}")
                results.append({
                    'filename': filename,
                    'full_name': full_name,
                    'ci_platform': 'Error',
                    'test_type': '',
                    'unit_test': False,
                    'instrumentation_test': False,
                    'matched_keywords': ''
                })

# === EXPORT ===
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ DONE! CSV generated at: {OUTPUT_CSV}")
# Out:
# ✅ 0000__JunkFood02__Seal__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__close-stale-issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__Issue-Handler.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__sponsor.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__Other__bug_report.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__Other__config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__Other__feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__Other__FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__GitHub__Build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0001__android__nowinandroid__GitHub__NightlyBaselineProfiles.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0001__android__nowinandroid__GitHub__Release.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0001__android__nowinandroid__Other__bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__Other__docs_issue.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__Other__feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__Other__packaging.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0002__square__picasso__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0002__square__picasso__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__update_deps.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__Other__bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0004__android__sunflower__Other__feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0004__android__sunflower__Other__packaging.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0007__MatsuriDayo__NekoBoxForAndroid__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__update_website.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__Other__1_request_feature.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__Other__2_report_issue.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 
yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0024__square__okio__GitHub__release.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0024__square__okio__Other__mkdocs.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__cla.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__reproduce-schedule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__web.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__.eslintrc.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__action.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__bug.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__feature.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__fourmolu.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__Other__question.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0026__iSoron__uhabits__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0026__iSoron__uhabits__Other__config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0027__skydoves__Pokedex__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0027__skydoves__Pokedex__Other__.coderabbit.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0027__skydoves__Pokedex__Other__FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__GitHub__tb_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__Other__dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__close-inactive-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__lock-closed-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-cli.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test-e2e-prod.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test-e2e.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['manual emulator setup']
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__update-samples.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__warn_build_xctestrunner.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__001_assert_visible_by_id.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__002_assert_visible_by_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__002_launchApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__003_assert_visible_by_size.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__003_launchApp_withClearState.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__004_assert_no_visible_element_with_id.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__005_assert_no_visible_element_with_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__006_assert_no_visible_element_with_size.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__007_assert_visible_by_size_with_tolerance.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__008_config_unknownKeys.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 7, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__008_tap_on_element.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__009_skip_optional_elements.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__010_scroll.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__011_back_press.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__012_input_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__013_launch_app.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__014_tap_on_point.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__015_element_relative_position.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__016_multiline_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__017_launchApp_otherPackage.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__017_swipe.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__018_backPress_string.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__018_contains_child.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__019_dont_wait_for_visibility.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__019_scroll_string.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__020_config_name.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     name: Example Flow
#     ^
# but found another document
#   in "<unicode string>", line 3, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__020_parse_config.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__021_launch_app_with_clear_state.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__022_launch_app_that_is_not_installed.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.nonexistent
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__022_on_flow_start_complete.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__023_labels.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__024_string_non_string_commands.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__025_element_relative_position_shortcut.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__025_killApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__026_assert_not_visible.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__027_open_link.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__027_waitToSettleTimeoutMs.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__028_command_descriptions.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__028_env.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__029_long_press_on_element.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__030_long_press_on_point.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__031_traits.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__032_element_index.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__033_int_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__034_press_key.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__035_refresh_position_ignore_duplicates.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__036_erase_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__037_unicode_input.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__038_partial_id.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__039_hide_keyboard.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__040_escape_regex.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__041_take_screenshot.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__042_extended_wait.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__043_stop_app.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__044_clear_state.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__045_clear_keychain.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__046_run_flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.other.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__047_run_flow_nested.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.other.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__048_tapOn_clickable.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__049_run_flow_conditionally.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.other.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__051_set_location.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__052_text_random.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__053_repeat_times.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.other.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__054_enabled.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.other.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__055_compare_regex.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__056_ignore_error.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__057_runFlow_env.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__057_subflow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__057_subflow_override.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__058_inline_env.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__058_subflow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__059_directional_swipe_command.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__060_pass_env_to_env.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__060_subflow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__061_launchApp_withoutStopping.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__062_copy_paste_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__063_js_injection.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0029__mobile-dev-inc__Maestro__Other__064_js_files.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
# ...
# ✅ 2543__icerockdev__moko-errors__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2544__doublesymmetry__KotlinAudio__GitHub__validate.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2544__doublesymmetry__KotlinAudio__Other__action.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2544__doublesymmetry__KotlinAudio__Other__jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2545__matsumo0922__PixiView-KMP__GitHub__pull-request-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2545__matsumo0922__PixiView-KMP__GitHub__translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2545__matsumo0922__PixiView-KMP__Other__detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2546__kibotu__StreamingAndroidLogger__Other__FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2546__kibotu__StreamingAndroidLogger__Other__jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__GitHub__android_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2548__nuhkoca__libbra__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2548__nuhkoca__libbra__Other__default-detekt-config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2549__Lastaapps__menza__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2552__google-developer-training__basic-android-kotlin-compose-training-lemonade__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2555__ahaodev__heji__Other__.drone.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     kind: pipeline # build go server ...
#     ^
# but found another document
#   in "<unicode string>", line 37, column 1:
#     ---
#     ^
# ✅ 2555__ahaodev__heji__Other__config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2555__ahaodev__heji__Other__docker-compose.yml => 'NoneType' object has no attribute 'get'
# ✅ 2558__Web3Auth__web3auth-android-sdk__Other__jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2559__Kalbra__NoReel__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2559__Kalbra__NoReel__Other__FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2563__natura-cosmeticos__natds-android__Other__.typo-ci.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2563__natura-cosmeticos__natds-android__Other__release-drafter.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2564__ilyasipek__easy-mvi__Other__jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2565__sirekanian__outline__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2566__basaransuleyman__Compose-FeatureBase-Multi-Module-Clean-Hexagonal-Architecture-Android-Kotlin__GitHub__ComposeFeaturedBasedMultiModule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2568__tobiasschuerg__android-week-view__Other__jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__Other__.yarnrc.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__Other__action.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__Other__bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__Other__config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__Other__lefthook.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__data_model_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__dod_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__dod_wrapper_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__flow_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__rx_data_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__rx_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__scheduler_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__backup-publish-swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__backup-publish-web-npm.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__benchmarks-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__cherry-pick-pr-to-newer-release-cycle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__codestyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__generate-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__generate-dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-android-instrumented-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2571__wireapp__kalium__GitHub__gradle-android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-db-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-ios-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-jvm-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__jira-lint-and-link.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__label-pr.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__pr-author-assigner.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__quay.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__semantic-commit-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__stale-issues-and-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__action.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__Chart.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__codecov.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__configmaps.yaml => while parsing a flow node
# expected the node content, but found '-'
#   in "<unicode string>", line 1, column 3:
#     {{- if .Values.podMonitorIntegrati ...
#       ^
# ✅ 2571__wireapp__kalium__Other__dashboard.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__datasource.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__docker-compose.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__labeler.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__main.yml => 'list' object has no attribute 'get'
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__monkey-controller.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     apiVersion: v1
#     ^
# but found another document
#   in "<unicode string>", line 17, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__monkey-server.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     apiVersion: v1
#     ^
# but found another document
#   in "<unicode string>", line 18, column 1:
#     ---
#     ^
# ✅ 2571__wireapp__kalium__Other__plugin.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__podmonitor.yaml => while parsing a flow node
# expected the node content, but found '-'
#   in "<unicode string>", line 1, column 3:
#     {{- if .Values.podMonitorIntegrati ...
#       ^
# ✅ 2571__wireapp__kalium__Other__prometheus.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\2571__wireapp__kalium__Other__site.yml => 'list' object has no attribute 'get'
# ✅ 2571__wireapp__kalium__Other__stale.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__technolinator.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__Other__values.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2574__diareuse__gecko__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2574__diareuse__gecko__Other__dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅