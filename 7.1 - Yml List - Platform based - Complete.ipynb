# %%
import os
import pandas as pd
import re
import yaml  # pip install pyyaml

# === CONFIG ===
PROJECTS_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files"
OUTPUT_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, "7.1-YML_List_4th_attempt_ShallowC.csv")

# === UNIVERSAL UNIT TEST KEYWORDS ===
UNIT_TEST_KEYWORDS = [
    'gradlew test', './gradlew test', 'testdebugunittest', 'testreleaseunittest',
    'test', 'run unit tests', 'run: test', 'npm test', 'yarn test'
]

# === CI-SPECIFIC INSTRUMENTATION RULES ===
def detect_instrumentation_by_platform(ci_platform, yaml_text, run_scripts, parsed):
    """
    Improved detection:
    - Wrappers & GMD: parsed 'uses'
    - Manual emulator: must have (sdkmanager or avdmanager) AND (emulator or avdmanager)
    - No more adb-only false positives.
    """
    run_text = "\n".join(run_scripts)
    found = set()
    matched = []

    # === Common emulator keywords ===
    has_sdk = any(kw in run_text for kw in ['sdkmanager'])
    has_avd = any(kw in run_text for kw in ['avdmanager'])
    has_emulator = any(kw in run_text for kw in ['emulator'])
    has_create_avd = any(kw in run_text for kw in ['android create avd'])

    if ci_platform == "GitHub":
        # 1️⃣ Wrappers & GMD
        for job in parsed.get('jobs', {}).values():
            for step in job.get('steps', []):
                if isinstance(step, dict) and 'uses' in step:
                    uses = step['uses'].lower()
                    if 'reactivecircus/android-emulator-runner' in uses:
                        found.add('GitHub_emulator_full')
                        matched.append('reactivecircus/android-emulator-runner')
                    if 'malinskiy/action-android/emulator-run-cmd' in uses:
                        found.add('GitHub_emulator_compact')
                        matched.append('malinskiy/action-android/emulator-run-cmd')
                    if any(gmd in uses for gmd in ['cleanmanageddevices', 'managedvirtualdevice', 'manageddevices']):
                        found.add('GitHub_GMD')
                        matched.append('GMD keywords (uses)')

        if any("cleanmanageddevices" in s or "manageddevices" in s for s in run_scripts):
            found.add('GitHub_GMD')
            matched.append('GMD keywords (Gradle run)')

        # ✅ Improved manual check:
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitHub_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "CircleCI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('CircleCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Bitrise":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Bitrise_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "GitLab CI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitLab CI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Travis CI":
        if (has_sdk or has_avd or has_create_avd) and (has_emulator or has_avd):
            found.add('TravisCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Other":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Other_emulator_manual')
            matched.append('manual emulator setup')

    # === Third-party Labs ===
    lab_run_text = run_text
    for job in parsed.get('jobs', {}).values():
        for step in job.get('steps', []):
            if isinstance(step, dict) and 'uses' in step:
                uses = step['uses'].lower()
                if 'firebase-test-lab-action' in uses:
                    found.add('Firebase_Compact')
                    matched.append('Firebase-Test-Lab-Action')
                if 'microsoft/appcenter-test-cli-action' in uses:
                    found.add('Appcenter')
                    matched.append('Appcenter Test CLI Action')
                if 'browserstack' in uses or 'browserstack/github-actions' in uses:
                    found.add('Browserstack')
                    matched.append('Browserstack action')
                if 'saucelabs/saucectl-run-action' in uses:
                    found.add('SauceLabs')
                    matched.append('Sauce Labs GitHub Action')

    if 'gcloud firebase test android run' in lab_run_text:
        found.add('Firebase_Full')
        matched.append('gcloud firebase test android run')

    if 'appcenter test run' in lab_run_text:
        found.add('Appcenter')
        matched.append('appcenter test run')

    if 'browserstack' in lab_run_text:
        found.add('Browserstack')
        matched.append('browserstack CLI call')

    if 'saucectl' in lab_run_text:
        found.add('SauceLabs')
        matched.append('saucectl CLI')

    return found, matched


def detect_ci_platform(file_path, yaml_text):
    text = yaml_text.lower()
    path = file_path.lower()
    filename = os.path.basename(path)

    if re.search(r'(^|[\\/])\.github([\\/]|$)', path) or 'github_actions' in filename:
        return "GitHub"
    if '.gitlab' in path or 'gitlab-ci' in filename:
        return "GitLab CI"
    if '.travis' in path or 'travis' in filename:
        return "Travis CI"
    if '.circleci' in path or 'circleci' in filename:
        return "CircleCI"
    if '.bitrise' in path or 'bitrise' in filename:
        return "Bitrise"

    if 'uses: actions/' in text:
        return "GitHub"
    if 'uses: docker://circleci/' in text or 'circleci/android:' in text:
        return "CircleCI"
    if 'travis' in text:
        return "Travis CI"
    if 'bitrise' in text:
        return "Bitrise"
    if 'gitlab-ci' in text:
        return "GitLab CI"

    return "Other"


def detect_unit_test(yaml_text):
    text = yaml_text.lower()
    for kw in UNIT_TEST_KEYWORDS:
        if kw in text:
            return True
    return False


def extract_run_scripts(parsed):
    def get_runs(node):
        runs = []
        if isinstance(node, dict):
            for k, v in node.items():
                if k == 'run' and isinstance(v, str):
                    runs.append(v.lower())
                else:
                    runs.extend(get_runs(v))
        elif isinstance(node, list):
            for item in node:
                runs.extend(get_runs(item))
        return runs

    scripts = get_runs(parsed)
    if isinstance(parsed, dict):
        for key in ['script', 'before_script', 'before_install', 'after_script']:
            val = parsed.get(key)
            if isinstance(val, list):
                scripts.extend([str(v).lower() for v in val])
            elif isinstance(val, str):
                scripts.append(val.lower())
    return scripts


# === PROCESS ALL ===
results = []

for root, _, files in os.walk(PROJECTS_DIR):
    for file in files:
        if file.endswith(('.yml', '.yaml')):
            file_path = os.path.join(root, file)
            filename = os.path.basename(file_path)

            # ✅ NEW: Extract full_name between first and third '__'
            parts = filename.split("__")
            if len(parts) >= 3:
                full_name = f"{parts[1]}__{parts[2]}"
            else:
                full_name = filename  # fallback

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    raw = f.read().replace('\t', ' ')
                    ci_platform = detect_ci_platform(file_path, raw)

                    parsed = yaml.safe_load(raw)
                    run_scripts = extract_run_scripts(parsed)

                    is_unit = detect_unit_test(raw)
                    instr_types, matched_keys = detect_instrumentation_by_platform(ci_platform, raw, run_scripts, parsed)

                    test_type_str = ', '.join(sorted(instr_types))
                    is_instr = bool(instr_types)

                    results.append({
                        'filename': filename,
                        'full_name': full_name,
                        'ci_platform': ci_platform,
                        'test_type': test_type_str,
                        'unit_test': is_unit,
                        'instrumentation_test': is_instr,
                        'matched_keywords': "; ".join(sorted(set(matched_keys)))
                    })

                    print(f"✅ {filename} | CI: {ci_platform} | Unit: {is_unit} | Instr: {is_instr} | Keys: {matched_keys}")

            except Exception as e:
                print(f"❌ ERROR: {file_path} => {e}")
                results.append({
                    'filename': filename,
                    'full_name': full_name,
                    'ci_platform': 'Error',
                    'test_type': '',
                    'unit_test': False,
                    'instrumentation_test': False,
                    'matched_keywords': ''
                })

# === EXPORT ===
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ DONE! CSV generated at: {OUTPUT_CSV}")
# Out:
# ✅ 0000__JunkFood02__Seal__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__.github+++workflows+++android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__.github+++workflows+++close-stale-issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__.github+++workflows+++issue-handler.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__.github+++workflows+++sponsor.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__.github+++workflows+++build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0001__android__nowinandroid__.github+++workflows+++nightlybaselineprofiles.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0001__android__nowinandroid__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0002__square__picasso__.github+++workflows+++build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0002__square__picasso__.github+++workflows+++release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__.github+++workflows+++copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__.github+++workflows+++update_deps.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__.github+++workflows+++copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0007__MatsuriDayo__NekoBoxForAndroid__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__.github+++workflows+++build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__.github+++workflows+++build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__.github+++workflows+++update_website.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0009__android__uamp__.github+++workflows+++android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0009__android__uamp__.github+++workflows+++copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++add-device.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++avd-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-debug-kernel.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-a12.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-a13.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-a14.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-a15.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-arcvm.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-avd.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-kernel-wsa.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-lkm.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-manager.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++build-su.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++clippy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++deploy-website.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++gki-kernel.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++ksud.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++rustfmt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++shellcheck.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__.github+++workflows+++wsa-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++daily_builds.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++fluidscan.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++gradle-cache.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++markdown.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++needinfo-answered.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++needinfo-remove.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++needinfo-stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++pulls-merged.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++shippable_builds.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++uplift-merges.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++validate-gradle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__.github+++workflows+++validate-workflows.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0012__mikepenz__MaterialDrawer__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0012__mikepenz__MaterialDrawer__.github+++workflows+++gradle-dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__.github+++workflows+++issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__.github+++workflows+++snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0014__coil-kt__coil__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0015__Shabinder__SpotiFlyer__.github+++workflows+++build-and-publish-kjs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__.github+++workflows+++build-release-binaries.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__.github+++workflows+++maintenance.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__.github+++workflows+++tf-refresh.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0016__JakeWharton__timber__.github+++workflows+++build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0016__JakeWharton__timber__.github+++workflows+++release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0017__AppIntro__AppIntro__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0017__AppIntro__AppIntro__.github+++workflows+++pre-merge.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__.github+++workflows+++codeql-analysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__.github+++workflows+++run-on-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++assignees.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++compare_apk_size.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++conflict.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++label.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++milestone.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++opencollective_notices.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++sync_translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++tests_emulator.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++tests_unit.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__.github+++workflows+++update_js_libs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__.github+++workflows+++codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__.github+++workflows+++test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__.github+++workflows+++weekly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0021__vfsfitvnm__ViMusic__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++buildanddeploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++buildandtest.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++buildmultiplatform.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++conflicts.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++detektanalysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++detekt_config+++detekt-errors.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++detekt_config+++detekt-warnings.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++dockerpublish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++mkdocs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++stale-issues-and-prs.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__.github+++workflows+++uncivbot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0023__firebase__quickstart-android__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0024__square__okio__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0024__square__okio__.github+++workflows+++release.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__.github+++workflows+++cla.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__.github+++workflows+++reproduce-schedule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__.github+++workflows+++web.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0026__iSoron__uhabits__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0027__skydoves__Pokedex__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__.github+++workflows+++tb_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++close-inactive-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++ios-integration-tests.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++lock-closed-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++publish-cli.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++test-e2e-prod.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++test-e2e.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['manual emulator setup']
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++test.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++update-samples.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__.github+++workflows+++warn_build_xctestrunner.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0030__uber__RIBs__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__.github+++workflows+++docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__.github+++workflows+++tagit-weekly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++build_to_archive.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++generate_dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++issue_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++prerelease.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__.github+++workflows+++update_locales.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0033__skydoves__android-developer-roadmap__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++build-authenticator.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++cron-sync-google-priviledged-browsers.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++crowdin-pull.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++crowdin-push.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++github-release.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++publish-github-release.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++publish.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++release-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++scan-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++scan.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++test-device.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__.github+++workflows+++test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0035__open-ani__animeko__.github+++workflows+++build.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0035__open-ani__animeko__.github+++workflows+++release.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__.github+++workflows+++crowdin-upload.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__.github+++workflows+++validate-strings-no-translations.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0037__zhanghai__MaterialFiles__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__.github+++workflows+++baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0038__chrisbanes__tivi__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__.github+++workflows+++gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__.github+++workflows+++todo.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0039__igorwojda__android-showcase__.github+++workflows+++check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0040__Gurupreet__ComposeCookBook__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0040__Gurupreet__ComposeCookBook__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0040__Gurupreet__ComposeCookBook__.github+++workflows+++master-apk-create.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__.github+++workflows+++deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__.github+++workflows+++release-build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__.github+++workflows+++test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0041__ACRA__acra__.github+++workflows+++upload-javadoc.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__.travis.yml | CI: Travis CI | Unit: False | Instr: False | Keys: []
# ✅ 0042__facebook__facebook-android-sdk__.github+++workflows+++needs-attention.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0042__facebook__facebook-android-sdk__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__.github+++workflows+++build_commit.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__.github+++workflows+++build_pull_request.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__.github+++workflows+++testing.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0044__aniyomiorg__aniyomi__.github+++workflows+++build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0044__aniyomiorg__aniyomi__.github+++workflows+++build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__.github+++workflows+++automated_github_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__.github+++workflows+++build_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__.github+++workflows+++deploy_snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0046__bmax121__APatch__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0047__KotatsuApp__Kotatsu__.github+++workflows+++issue_moderator.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0048__kickstarter__android-oss__.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++debug_apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_brook.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_hysteria.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_mieru.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_naive.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_pingtunnel.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_relaybaton.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_trojan_go.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__.github+++workflows+++release_tuic.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0051__deniscerri__ytdlnis__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0051__deniscerri__ytdlnis__.github+++workflows+++tg-bot.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0052__z-huang__InnerTune__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0052__z-huang__InnerTune__.github+++workflows+++build_pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__.github+++workflows+++android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__.github+++workflows+++codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__.github+++workflows+++translation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0055__mikepenz__Android-Iconics__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0056__android__camera-samples__.github+++workflows+++android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0056__android__camera-samples__.github+++workflows+++copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0057__kizitonwose__Calendar__.github+++workflows+++check.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0057__kizitonwose__Calendar__.github+++workflows+++gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0057__kizitonwose__Calendar__.github+++workflows+++publish-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0058__Droid-ify__client__.github+++workflows+++build_debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0058__Droid-ify__client__.github+++workflows+++release_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__.github+++workflows+++bin.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__.github+++workflows+++build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__.github+++workflows+++lint.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__.github+++workflows+++release-please.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__.github+++workflows+++dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__.github+++workflows+++test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__.github+++workflows+++code-checks.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__.github+++workflows+++release-tag.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__.github+++workflows+++linter.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__.github+++workflows+++pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__.github+++workflows+++deploy_snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__.github+++workflows+++latest_jdk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__.github+++workflows+++maven.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__.github+++workflows+++build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__.github+++workflows+++open_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0067__android__user-interface-samples__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0067__android__user-interface-samples__.github+++workflows+++copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0068__izhangzhihao__intellij-rainbow-brackets__.github+++workflows+++anti-phishing.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0068__izhangzhihao__intellij-rainbow-brackets__.github+++workflows+++translator.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0069__RetroMusicPlayer__RetroMusicPlayer__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0069__RetroMusicPlayer__RetroMusicPlayer__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0070__simondankelmann__Bluetooth-LE-Spam__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0071__Mygod__VPNHotspot__.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0072__square__wire__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0072__square__wire__.github+++workflows+++gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0072__square__wire__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__.github+++workflows+++app_build_and_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0073__burhanrashid52__PhotoEditor__.github+++workflows+++app_playstore_publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__.github+++workflows+++publish_maven.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__.github+++workflows+++bundle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__.github+++workflows+++check.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0074__tasks__tasks__.github+++workflows+++dependency_diff.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__.github+++workflows+++deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__.github+++workflows+++close-and-release-repository.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__.github+++workflows+++pre-merge.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__.github+++workflows+++publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__.github+++workflows+++publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++android-test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++build-debug-apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++generate-quest-list.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__.github+++workflows+++unit-test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0077__Triple-T__gradle-play-publisher__.github+++workflows+++cid.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0077__Triple-T__gradle-play-publisher__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__.github+++workflows+++crowdin.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__.github+++workflows+++issue.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__.github+++workflows+++pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__.github+++workflows+++android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__.github+++workflows+++android_test_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__.github+++workflows+++codeql-analysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__.github+++workflows+++android-instrumented-data-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0082__owncloud__android__.github+++workflows+++android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__.github+++workflows+++calens.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0082__owncloud__android__.github+++workflows+++detekt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__.github+++workflows+++sbom.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__.github+++workflows+++gradle-dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__.github+++workflows+++static.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__.github+++workflows+++automerge.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__.github+++workflows+++debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__.github+++workflows+++test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0085__mikepenz__FastAdapter__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__.github+++workflows+++baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0087__skydoves__Balloon__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__.github+++workflows+++release-docs.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0088__skydoves__chatgpt-android__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0088__skydoves__chatgpt-android__.github+++workflows+++baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0089__aistra0528__Hail__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__.github+++workflows+++fdroid.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__.github+++workflows+++nix.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__.github+++workflows+++publish.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__.github+++workflows+++pull_request.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0099__Foso__Jetpack-Compose-Playground__.github+++workflows+++gh-pages.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++mobsf.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++sa.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++sym.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__.github+++workflows+++telegram-notify.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0102__osfans__trime__.github+++workflows+++commit-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0102__osfans__trime__.github+++workflows+++nightly-ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0102__osfans__trime__.github+++workflows+++pull-request-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0102__osfans__trime__.github+++workflows+++release-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0103__maxrave-dev__SimpMusic__.github+++workflows+++android-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0103__maxrave-dev__SimpMusic__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++danger.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++post-pr.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0104__element-hq__element-android__.github+++workflows+++quality.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++sync-from-external-sources.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0104__element-hq__element-android__.github+++workflows+++triage-labelled.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++triage-move-review-requests.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++triage-priority-bugs.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__.github+++workflows+++validate-lfs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++app-build.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++app-lint.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++app-publish.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++app-test.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++gradlew-validate.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++repo-merge-conflict.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__.github+++workflows+++repo-stale.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0107__vinaygaba__Learn-Jetpack-Compose-By-Example__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0108__easybangumiorg__EasyBangumi__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__.github+++workflows+++deploy.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__.github+++workflows+++docs.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__.github+++workflows+++e2e_tests.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0110__oblador__react-native-keychain__.github+++workflows+++lint_and_types.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0111__raamcosta__compose-destinations__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0111__raamcosta__compose-destinations__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0112__DanielMartinus__Konfetti__.github+++workflows+++ci-konfetti.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0113__rumboalla__apkupdater__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__.github+++workflows+++release.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__.github+++workflows+++snapshot.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__.github+++workflows+++test.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__.github+++workflows+++build-all.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__.github+++workflows+++junie.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__.github+++workflows+++web-deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0116__Swordfish90__Lemuroid__.github+++workflows+++checkstyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0116__Swordfish90__Lemuroid__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0117__jarnedemeulemeester__findroid__.github+++workflows+++build.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0117__jarnedemeulemeester__findroid__.github+++workflows+++publish.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__.github+++workflows+++build-nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__.github+++workflows+++deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__.github+++workflows+++trigger-fdroid-repo-rebuild.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0119__wuseal__JsonToKotlinClass__.github+++workflows+++deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0119__wuseal__JsonToKotlinClass__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__.github+++workflows+++lock-threads.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__.github+++workflows+++releases.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0121__videolan__vlc-android__buildsystem+++gitlab+++.gitlab-ci.yml | CI: GitLab CI | Unit: False | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0122__joreilly__PeopleInSpace__.github+++workflows+++ios.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__.github+++workflows+++wearos.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__.github+++workflows+++web.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0123__EhViewer-NekoInverter__EhViewer__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0123__EhViewer-NekoInverter__EhViewer__.github+++workflows+++releases.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0124__GuoXiCheng__SKIP__.github+++workflows+++deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__.github+++workflows+++automated-version-update-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__.github+++workflows+++run-danger.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__.github+++workflows+++submit-gradle-dependencies.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__.github+++workflows+++validate-issues.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__.github+++workflows+++pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__.github+++workflows+++update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__.github+++workflows+++apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__.github+++workflows+++automatic_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__.github+++workflows+++ci_actions_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__.github+++workflows+++compose_stability.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ...
# ✅ 2496__microsoft__VerifiableCredential-SDK-Android__azure-pipelines.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2498__captainepoch__husky__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__.github+++workflows+++build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__.github+++workflows+++open_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__.github+++workflows+++update_bundle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2500__Aditprayogo__GithubUsers__.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 2504__Link184__Lifecycle-Delegates__.travis.yml | CI: Travis CI | Unit: False | Instr: False | Keys: []
# ✅ 2511__its-me-debk007__kotlin-android-mvvm-template__.github+++workflows+++build_apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__.github+++workflows+++documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__.github+++workflows+++semgrep.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2515__mikekpl__pokedex__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__.github+++workflows+++cd.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__backend+++node_modules+++debug+++.travis.yml | CI: Travis CI | Unit: True | Instr: False | Keys: []
# ✅ 2518__rafsanjani__datepickertimeline__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 2518__rafsanjani__datepickertimeline__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__.github+++workflows+++create_jira.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__.github+++workflows+++release.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__.github+++workflows+++snapshot.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__.github+++workflows+++danger.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__.github+++workflows+++release_snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__.github+++workflows+++tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2527__lcdsmao__JetTheme__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2527__lcdsmao__JetTheme__.github+++workflows+++deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2527__lcdsmao__JetTheme__.github+++workflows+++refresh-versions.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2528__jing332__SherpaOnnxTtsEngineAndroid__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2528__jing332__SherpaOnnxTtsEngineAndroid__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2529__mars885__value-picker__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2529__mars885__value-picker__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2531__tunjid__Mutator__.github+++workflows+++tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__.github+++workflows+++pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__.github+++workflows+++publish_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__.github+++workflows+++publish_snapshot_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2538__x13a__Clipeus__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2538__x13a__Clipeus__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__.github+++workflows+++android_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__.github+++workflows+++create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__.github+++workflows+++local_unit_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__.github+++workflows+++spotless.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2540__shadmanadman__KSensor__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2543__icerockdev__moko-errors__.github+++workflows+++compilation-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2543__icerockdev__moko-errors__.github+++workflows+++publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2544__doublesymmetry__KotlinAudio__.github+++workflows+++validate.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2545__matsumo0922__PixiView-KMP__.github+++workflows+++pull-request-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2545__matsumo0922__PixiView-KMP__.github+++workflows+++translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__.github+++workflows+++android_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2548__nuhkoca__libbra__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2549__Lastaapps__menza__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2552__google-developer-training__basic-android-kotlin-compose-training-lemonade__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2559__Kalbra__NoReel__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2565__sirekanian__outline__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2566__basaransuleyman__Compose-FeatureBase-Multi-Module-Clean-Hexagonal-Architecture-Android-Kotlin__.github+++workflows+++composefeaturedbasedmultimodule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__.github+++workflows+++ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++data_model_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++dod_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++dod_wrapper_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++flow_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++rx_data_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++rx_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__.github+++workflows+++scheduler_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++backup-publish-swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++backup-publish-web-npm.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++benchmarks-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++cherry-pick-pr-to-newer-release-cycle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++codestyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++generate-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++generate-dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++gradle-android-instrumented-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2571__wireapp__kalium__.github+++workflows+++gradle-android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++gradle-db-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++gradle-ios-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++gradle-jvm-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++jira-lint-and-link.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++label-pr.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++pr-author-assigner.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++quay.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++semantic-commit-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__.github+++workflows+++stale-issues-and-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2574__diareuse__gecko__.github+++workflows+++main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2575__solygambas__kotlin-projects__11-blur-o-matic+++circle.yml | CI: Travis CI | Unit: True | Instr: False | Keys: []
# ✅ 2575__solygambas__kotlin-projects__25-to-do-notes+++.circleci+++config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 2577__sczerwinski__android-hilt__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2577__sczerwinski__android-hilt__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2578__MwaiBanda__WPRK-MultiPlatform__.github+++workflows+++swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2579__Carrieukie__android_mpesa_stk__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2584__Yorick-Ryu__CokoTools__.github+++workflows+++android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2585__Patch4Code__Logline__.github+++workflows+++build-apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2586__jakepurple13__Full-Multiplatform-Compose-Plugin__.github+++workflows+++custom_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2586__jakepurple13__Full-Multiplatform-Compose-Plugin__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++continuous-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++periodic-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++publication.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++publish-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__.github+++workflows+++stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2591__qq549631030__PriorityDialog__.github+++workflows+++android-unit-test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__.github+++workflows+++create-documentation-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__.github+++workflows+++create-release-from-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__.github+++workflows+++update-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2597__alejandro-rios__Boggle-Multiplatform__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2599__mtrewartha__positional__.github+++workflows+++tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2604__ishubhamsingh__Splashy__.github+++workflows+++check.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2605__Gegenbauer__CatSpy__.github+++workflows+++build_artifacts.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2605__Gegenbauer__CatSpy__.github+++workflows+++create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__.github+++workflows+++gradle-publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__.github+++workflows+++on-pull-request.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__.github+++workflows+++run-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2610__matu666__mytv-android__.github+++workflows+++release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2612__ChrisKruegerDev__trakt-kotlin__.github+++workflows+++build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2612__ChrisKruegerDev__trakt-kotlin__.github+++workflows+++release-update.yml | CI: Other | Unit: True | Instr: False | Keys: []
#
# ✅ DONE! CSV generated at: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output\7.1-YML_List_4th_attempt_ShallowC.csv
