# %%
import os
import pandas as pd
import re
import yaml  # pip install pyyaml

# === CONFIG ===
PROJECTS_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files"
OUTPUT_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, "7.1-YML_List_4th_attempt_ShallowC.csv")

# === UNIVERSAL UNIT TEST KEYWORDS ===
UNIT_TEST_KEYWORDS = [
    'gradlew test', './gradlew test', 'testdebugunittest', 'testreleaseunittest',
    'test', 'run unit tests', 'run: test', 'npm test', 'yarn test'
]

# === CI-SPECIFIC INSTRUMENTATION RULES ===
def detect_instrumentation_by_platform(ci_platform, yaml_text, run_scripts, parsed):
    """
    Improved detection:
    - Wrappers & GMD: parsed 'uses'
    - Manual emulator: must have (sdkmanager or avdmanager) AND (emulator or avdmanager)
    - No more adb-only false positives.
    """
    run_text = "\n".join(run_scripts)
    found = set()
    matched = []

    # === Common emulator keywords ===
    has_sdk = any(kw in run_text for kw in ['sdkmanager'])
    has_avd = any(kw in run_text for kw in ['avdmanager'])
    has_emulator = any(kw in run_text for kw in ['emulator'])
    has_create_avd = any(kw in run_text for kw in ['android create avd'])

    if ci_platform == "GitHub":
        # 1️⃣ Wrappers & GMD
        for job in parsed.get('jobs', {}).values():
            for step in job.get('steps', []):
                if isinstance(step, dict) and 'uses' in step:
                    uses = step['uses'].lower()
                    if 'reactivecircus/android-emulator-runner' in uses:
                        found.add('GitHub_emulator_full')
                        matched.append('reactivecircus/android-emulator-runner')
                    if 'malinskiy/action-android/emulator-run-cmd' in uses:
                        found.add('GitHub_emulator_compact')
                        matched.append('malinskiy/action-android/emulator-run-cmd')
                    if any(gmd in uses for gmd in ['cleanmanageddevices', 'managedvirtualdevice', 'manageddevices']):
                        found.add('GitHub_GMD')
                        matched.append('GMD keywords (uses)')

        if any("cleanmanageddevices" in s or "manageddevices" in s for s in run_scripts):
            found.add('GitHub_GMD')
            matched.append('GMD keywords (Gradle run)')

        # ✅ Improved manual check:
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitHub_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "CircleCI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('CircleCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Bitrise":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Bitrise_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "GitLab CI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitLab CI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Travis CI":
        if (has_sdk or has_avd or has_create_avd) and (has_emulator or has_avd):
            found.add('TravisCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Other":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Other_emulator_manual')
            matched.append('manual emulator setup')

    # === Third-party Labs ===
    lab_run_text = run_text
    for job in parsed.get('jobs', {}).values():
        for step in job.get('steps', []):
            if isinstance(step, dict) and 'uses' in step:
                uses = step['uses'].lower()
                if 'firebase-test-lab-action' in uses:
                    found.add('Firebase_Compact')
                    matched.append('Firebase-Test-Lab-Action')
                if 'microsoft/appcenter-test-cli-action' in uses:
                    found.add('Appcenter')
                    matched.append('Appcenter Test CLI Action')
                if 'browserstack' in uses or 'browserstack/github-actions' in uses:
                    found.add('Browserstack')
                    matched.append('Browserstack action')
                if 'saucelabs/saucectl-run-action' in uses:
                    found.add('SauceLabs')
                    matched.append('Sauce Labs GitHub Action')

    if 'gcloud firebase test android run' in lab_run_text:
        found.add('Firebase_Full')
        matched.append('gcloud firebase test android run')

    if 'appcenter test run' in lab_run_text:
        found.add('Appcenter')
        matched.append('appcenter test run')

    if 'browserstack' in lab_run_text:
        found.add('Browserstack')
        matched.append('browserstack CLI call')

    if 'saucectl' in lab_run_text:
        found.add('SauceLabs')
        matched.append('saucectl CLI')

    return found, matched


def detect_ci_platform(file_path, yaml_text):
    text = yaml_text.lower()
    path = file_path.lower()
    filename = os.path.basename(path)

    if re.search(r'(^|[\\/])\.github([\\/]|$)', path) or 'github_actions' in filename:
        return "GitHub"
    if '.gitlab' in path or 'gitlab-ci' in filename:
        return "GitLab CI"
    if '.travis' in path or 'travis' in filename:
        return "Travis CI"
    if '.circleci' in path or 'circleci' in filename:
        return "CircleCI"
    if '.bitrise' in path or 'bitrise' in filename:
        return "Bitrise"

    if 'uses: actions/' in text:
        return "GitHub"
    if 'uses: docker://circleci/' in text or 'circleci/android:' in text:
        return "CircleCI"
    if 'travis' in text:
        return "Travis CI"
    if 'bitrise' in text:
        return "Bitrise"
    if 'gitlab-ci' in text:
        return "GitLab CI"

    return "Other"


def detect_unit_test(yaml_text):
    text = yaml_text.lower()
    for kw in UNIT_TEST_KEYWORDS:
        if kw in text:
            return True
    return False


def extract_run_scripts(parsed):
    def get_runs(node):
        runs = []
        if isinstance(node, dict):
            for k, v in node.items():
                if k == 'run' and isinstance(v, str):
                    runs.append(v.lower())
                else:
                    runs.extend(get_runs(v))
        elif isinstance(node, list):
            for item in node:
                runs.extend(get_runs(item))
        return runs

    scripts = get_runs(parsed)
    if isinstance(parsed, dict):
        for key in ['script', 'before_script', 'before_install', 'after_script']:
            val = parsed.get(key)
            if isinstance(val, list):
                scripts.extend([str(v).lower() for v in val])
            elif isinstance(val, str):
                scripts.append(val.lower())
    return scripts


# === PROCESS ALL ===
results = []

for root, _, files in os.walk(PROJECTS_DIR):
    for file in files:
        if file.endswith(('.yml', '.yaml')):
            file_path = os.path.join(root, file)
            filename = os.path.basename(file_path)

            # ✅ NEW: Extract full_name between first and third '__'
            parts = filename.split("__")
            if len(parts) >= 3:
                full_name = f"{parts[1]}__{parts[2]}"
            else:
                full_name = filename  # fallback

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    raw = f.read().replace('\t', ' ')
                    ci_platform = detect_ci_platform(file_path, raw)

                    parsed = yaml.safe_load(raw)
                    run_scripts = extract_run_scripts(parsed)

                    is_unit = detect_unit_test(raw)
                    instr_types, matched_keys = detect_instrumentation_by_platform(ci_platform, raw, run_scripts, parsed)

                    test_type_str = ', '.join(sorted(instr_types))
                    is_instr = bool(instr_types)

                    results.append({
                        'filename': filename,
                        'full_name': full_name,
                        'ci_platform': ci_platform,
                        'test_type': test_type_str,
                        'unit_test': is_unit,
                        'instrumentation_test': is_instr,
                        'matched_keywords': "; ".join(sorted(set(matched_keys)))
                    })

                    print(f"✅ {filename} | CI: {ci_platform} | Unit: {is_unit} | Instr: {is_instr} | Keys: {matched_keys}")

            except Exception as e:
                print(f"❌ ERROR: {file_path} => {e}")
                results.append({
                    'filename': filename,
                    'full_name': full_name,
                    'ci_platform': 'Error',
                    'test_type': '',
                    'unit_test': False,
                    'instrumentation_test': False,
                    'matched_keywords': ''
                })

# === EXPORT ===
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ DONE! CSV generated at: {OUTPUT_CSV}")
# Out:
# ✅ 0000__JunkFood02__Seal__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__close-stale-issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__Issue-Handler.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0000__JunkFood02__Seal__GitHub__sponsor.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0001__android__nowinandroid__GitHub__Build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0001__android__nowinandroid__GitHub__NightlyBaselineProfiles.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0001__android__nowinandroid__GitHub__Release.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0002__square__picasso__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0002__square__picasso__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0003__google__flexbox-layout__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0004__android__sunflower__GitHub__update_deps.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0006__nickbutcher__plaid__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0007__MatsuriDayo__NekoBoxForAndroid__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0008__mihonapp__mihon__GitHub__update_website.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0009__android__uamp__GitHub__android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0009__android__uamp__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__add-device.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__avd-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-debug-kernel.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-a12.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-a13.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-a14.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-a15.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-arcvm.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-avd.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-kernel-wsa.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-lkm.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-manager.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__build-su.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__clippy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__deploy-website.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__gki-kernel.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__ksud.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__rustfmt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__shellcheck.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0010__tiann__KernelSU__GitHub__wsa-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__daily_builds.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__fluidscan.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__gradle-cache.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__markdown.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__needinfo-answered.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__needinfo-remove.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__needinfo-stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__pulls-merged.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__shippable_builds.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__uplift-merges.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__validate-gradle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0011__thunderbird__thunderbird-android__GitHub__validate-workflows.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0012__mikepenz__MaterialDrawer__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0012__mikepenz__MaterialDrawer__GitHub__gradle-dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__GitHub__issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0013__YiiGuxing__TranslationPlugin__GitHub__snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0014__coil-kt__coil__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0015__Shabinder__SpotiFlyer__GitHub__build-and-publish-kjs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__GitHub__build-release-binaries.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__GitHub__maintenance.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__GitHub__Release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0015__Shabinder__SpotiFlyer__GitHub__tf-refresh.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0016__JakeWharton__timber__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0016__JakeWharton__timber__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0017__AppIntro__AppIntro__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0017__AppIntro__AppIntro__GitHub__pre-merge.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__GitHub__codeql-analysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0018__libre-tube__LibreTube__GitHub__run-on-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__assignees.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__compare_apk_size.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__conflict.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__label.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__milestone.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__opencollective_notices.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__sync_translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__tests_emulator.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0019__ankidroid__Anki-Android__GitHub__tests_unit.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0019__ankidroid__Anki-Android__GitHub__update_js_libs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__GitHub__codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0020__InsertKoinIO__koin__GitHub__weekly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0021__vfsfitvnm__ViMusic__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__buildAndDeploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__buildAndTest.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__buildMultiplatform.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__conflicts.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__detekt-errors.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__detekt-warnings.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__detektAnalysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__dockerPublish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__mkdocs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__stale-issues-and-prs.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0022__yairm210__Unciv__GitHub__uncivbot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0023__firebase__quickstart-android__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0024__square__okio__GitHub__build.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0024__square__okio__GitHub__release.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__cla.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__reproduce-schedule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0025__simplex-chat__simplex-chat__GitHub__web.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0026__iSoron__uhabits__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0027__skydoves__Pokedex__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0028__T8RIN__ImageToolbox__GitHub__tb_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__close-inactive-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__ios-integration-tests.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__lock-closed-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-cli.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test-e2e-prod.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test-e2e.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['manual emulator setup']
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__test.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__update-samples.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0029__mobile-dev-inc__Maestro__GitHub__warn_build_xctestrunner.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0030__uber__RIBs__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__GitHub__docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0031__facebook__litho__GitHub__tagit-weekly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__build_to_archive.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__generate_dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__issue_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__prerelease.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0032__recloudstream__cloudstream__GitHub__update_locales.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0033__skydoves__android-developer-roadmap__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__build-authenticator.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__cron-sync-google-priviledged-browsers.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__crowdin-pull.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__crowdin-push.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__github-release.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__publish-github-release.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__publish.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__release-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__scan-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__scan.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__test-device.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0034__bitwarden__android__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0035__open-ani__animeko__GitHub__build.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0035__open-ani__animeko__GitHub__release.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__GitHub__crowdin-upload.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0036__florisboard__florisboard__GitHub__validate-strings-no-translations.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0037__zhanghai__MaterialFiles__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__GitHub__baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ 0038__chrisbanes__tivi__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__GitHub__gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0038__chrisbanes__tivi__GitHub__todo.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0039__igorwojda__android-showcase__GitHub__check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0040__Gurupreet__ComposeCookBook__GitHub__android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0040__Gurupreet__ComposeCookBook__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0040__Gurupreet__ComposeCookBook__GitHub__master-apk-create.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__GitHub__deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__GitHub__release-build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__GitHub__test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0041__ACRA__acra__GitHub__upload-javadoc.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0041__ACRA__acra__Travis CI__.travis.yml | CI: Travis CI | Unit: False | Instr: False | Keys: []
# ✅ 0042__facebook__facebook-android-sdk__GitHub__needs-attention.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0042__facebook__facebook-android-sdk__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__GitHub__build_commit.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__GitHub__build_pull_request.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0043__Ashinch__ReadYou__GitHub__testing.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0044__aniyomiorg__aniyomi__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0044__aniyomiorg__aniyomi__GitHub__build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__GitHub__automated_github_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__GitHub__build_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0045__airbnb__mavericks__GitHub__deploy_snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0046__bmax121__APatch__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0047__KotatsuApp__Kotatsu__GitHub__issue_moderator.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0048__kickstarter__android-oss__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__debug_apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_brook.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_hysteria.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_mieru.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_naive.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_pingtunnel.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_relaybaton.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_trojan_go.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0049__SagerNet__SagerNet__GitHub__release_tuic.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0051__deniscerri__ytdlnis__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0051__deniscerri__ytdlnis__GitHub__tg-bot.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0052__z-huang__InnerTune__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0052__z-huang__InnerTune__GitHub__build_pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__GitHub__android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__GitHub__codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0053__LibChecker__LibChecker__GitHub__translation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0055__mikepenz__Android-Iconics__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0056__android__camera-samples__GitHub__android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0056__android__camera-samples__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0057__kizitonwose__Calendar__GitHub__check.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0057__kizitonwose__Calendar__GitHub__gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0057__kizitonwose__Calendar__GitHub__publish-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0058__Droid-ify__client__GitHub__build_debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0058__Droid-ify__client__GitHub__release_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__GitHub__bin.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__GitHub__lint.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0059__XayahSuSuSu__Android-DataBackup__GitHub__release-please.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__GitHub__dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0060__didi__booster__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__GitHub__code-checks.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0063__d4rken-org__sdmaid-se__GitHub__release-tag.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__GitHub__linter.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__GitHub__pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0064__kittinunf__fuel__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__GitHub__deploy_SNAPSHOT.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__GitHub__latest_jdk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0065__AlmasB__FXGL__GitHub__maven.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__GitHub__open_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0066__ReVanced__revanced-patches-template__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0067__android__user-interface-samples__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0067__android__user-interface-samples__GitHub__copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0068__izhangzhihao__intellij-rainbow-brackets__GitHub__anti-phishing.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0068__izhangzhihao__intellij-rainbow-brackets__GitHub__translator.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0069__RetroMusicPlayer__RetroMusicPlayer__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0069__RetroMusicPlayer__RetroMusicPlayer__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0070__simondankelmann__Bluetooth-LE-Spam__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0071__Mygod__VPNHotspot__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 0072__square__wire__GitHub__build.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0072__square__wire__GitHub__gradle-wrapper.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0072__square__wire__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__GitHub__app_build_and_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0073__burhanrashid52__PhotoEditor__GitHub__app_playstore_publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__GitHub__publish_maven.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0073__burhanrashid52__PhotoEditor__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__GitHub__bundle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__GitHub__check.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0074__tasks__tasks__GitHub__dependency_diff.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0074__tasks__tasks__GitHub__deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__GitHub__close-and-release-repository.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__GitHub__pre-merge.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__GitHub__publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0075__ChuckerTeam__chucker__GitHub__publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__GitHub__android-test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0076__streetcomplete__StreetComplete__GitHub__build-debug-apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__GitHub__generate-quest-list.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__GitHub__lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0076__streetcomplete__StreetComplete__GitHub__unit-test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0077__Triple-T__gradle-play-publisher__GitHub__cid.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0077__Triple-T__gradle-play-publisher__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__GitHub__crowdin.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__GitHub__issue.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0080__Dr-TSNG__Hide-My-Applist__GitHub__pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__GitHub__android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__GitHub__android_test_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__GitHub__codeql-analysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__GitHub__android-instrumented-data-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0082__owncloud__android__GitHub__android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__GitHub__calens.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0082__owncloud__android__GitHub__detekt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0082__owncloud__android__GitHub__sbom.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__GitHub__gradle-dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0083__mikepenz__AboutLibraries__GitHub__static.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__GitHub__automerge.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__GitHub__debug.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0084__jing332__tts-server-android__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0085__mikepenz__FastAdapter__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__GitHub__baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0087__skydoves__Balloon__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0087__skydoves__Balloon__GitHub__release-docs.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0088__skydoves__chatgpt-android__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0088__skydoves__chatgpt-android__GitHub__baseline-profile.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0089__aistra0528__Hail__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__GitHub__fdroid.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__GitHub__nix.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__GitHub__publish.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0091__fcitx5-android__fcitx5-android__GitHub__pull_request.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0099__Foso__Jetpack-Compose-Playground__GitHub__gh-pages.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__mobsf.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__sa.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__sym.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0100__celzero__rethink-app__GitHub__telegram-notify.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0102__osfans__trime__GitHub__commit-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0102__osfans__trime__GitHub__nightly-ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0102__osfans__trime__GitHub__pull-request-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0102__osfans__trime__GitHub__release-ci.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0103__maxrave-dev__SimpMusic__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__danger.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__post-pr.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0104__element-hq__element-android__GitHub__quality.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__sync-from-external-sources.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0104__element-hq__element-android__GitHub__triage-labelled.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__triage-move-review-requests.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__triage-priority-bugs.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0104__element-hq__element-android__GitHub__validate-lfs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__app-build.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__app-lint.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__app-publish.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__app-test.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__gradlew-validate.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__repo-merge-conflict.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0105__jellyfin__jellyfin-androidtv__GitHub__repo-stale.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0107__vinaygaba__Learn-Jetpack-Compose-By-Example__GitHub__android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0108__easybangumiorg__EasyBangumi__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__GitHub__deploy.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__GitHub__docs.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0110__oblador__react-native-keychain__GitHub__e2e_tests.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0110__oblador__react-native-keychain__GitHub__lint_and_types.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0111__raamcosta__compose-destinations__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0111__raamcosta__compose-destinations__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0112__DanielMartinus__Konfetti__GitHub__ci-konfetti.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0113__rumboalla__apkupdater__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__GitHub__release.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__GitHub__snapshot.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0114__kosi-libs__Kodein__GitHub__test.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__GitHub__build-all.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__GitHub__junie.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0115__JetBrains__kotlinconf-app__GitHub__web-deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0116__Swordfish90__Lemuroid__GitHub__checkstyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0116__Swordfish90__Lemuroid__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0117__jarnedemeulemeester__findroid__GitHub__build.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0117__jarnedemeulemeester__findroid__GitHub__publish.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__GitHub__build-nightly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__GitHub__deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0118__MM2-0__Kvaesitso__GitHub__trigger-fdroid-repo-rebuild.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0119__wuseal__JsonToKotlinClass__GitHub__deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0119__wuseal__JsonToKotlinClass__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__GitHub__lock-threads.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0120__FooIbar__EhViewer__GitHub__releases.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)']
# ✅ 0121__videolan__vlc-android__Other__.gitlab-ci.yml | CI: GitLab CI | Unit: False | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__GitHub__android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0122__joreilly__PeopleInSpace__GitHub__ios.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__GitHub__wearos.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0122__joreilly__PeopleInSpace__GitHub__web.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0123__EhViewer-NekoInverter__EhViewer__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0123__EhViewer-NekoInverter__EhViewer__GitHub__releases.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0124__GuoXiCheng__SKIP__GitHub__deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__GitHub__automated-version-update-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__GitHub__run-danger.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__GitHub__submit-gradle-dependencies.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0125__wordpress-mobile__WordPress-Android__GitHub__validate-issues.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__GitHub__pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0126__BiliRoamingX__BiliRoamingX__GitHub__update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__automatic_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__ci_actions_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__compose_stability.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__detekt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__integration_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__internal_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__issue_assign.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__issue_created.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__paparazzi_screenshot_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__pr_description.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0127__Ivy-Apps__ivy-wallet__GitHub__upgrade-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0129__adrielcafe__voyager__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0129__adrielcafe__voyager__GitHub__docs-publish.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0129__adrielcafe__voyager__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0130__ismartcoding__plain-app__GitHub__generate-apk-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0130__ismartcoding__plain-app__GitHub__generate-playstore-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0130__ismartcoding__plain-app__GitHub__releases-to-discord.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0131__gotev__android-upload-service__GitHub__android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0132__ReVanced__revanced-patcher__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0132__ReVanced__revanced-patcher__GitHub__open_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0132__ReVanced__revanced-patcher__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0132__ReVanced__revanced-patcher__GitHub__update_documentation.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0133__oshai__kotlin-logging__GitHub__cd.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0133__oshai__kotlin-logging__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0133__oshai__kotlin-logging__GitHub__github-pages.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0133__oshai__kotlin-logging__GitHub__greetings.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Config Files\0133__oshai__kotlin-logging__Travis CI__.travis.yml => 'list' object has no attribute 'get'
# ✅ 0135__korlibs__korge__GitHub__DEPLOY.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0135__korlibs__korge__GitHub__TEST.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0138__YenalyLiew__Han1meViewer__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0138__YenalyLiew__Han1meViewer__GitHub__pr_check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0139__MikeOrtiz__TouchImageView__GitHub__Android-CI-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0139__MikeOrtiz__TouchImageView__GitHub__Android-CI.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0139__MikeOrtiz__TouchImageView__GitHub__update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0140__liangjingkanji__BRV__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0142__orgzly__orgzly-android__GitHub__android-build-master.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 0144__pedroSG94__RootEncoder__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0145__anilbeesetti__nextplayer__GitHub__android_build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 0145__anilbeesetti__nextplayer__GitHub__junie.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0145__anilbeesetti__nextplayer__GitHub__update_version_and_publish.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0146__OxygenCobalt__Auxio__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0149__Automattic__pocket-casts-android__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0149__Automattic__pocket-casts-android__GitHub__high-prio-issue-notify-slack.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 0149__Automattic__pocket-casts-android__GitHub__run-danger.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ 0149__Automattic__pocket-casts-android__GitHub__submit-gradle-dependencies.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0150__aaa1115910__bv__GitHub__alpha.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 0150__aaa1115910__bv__GitHub__alpha_build_manually_without_sign.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ...
# ✅ 2482__eggheadgames__android-in-app-payments__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 2483__allegro__json-logic-kmp__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2483__allegro__json-logic-kmp__GitHub__pr_review.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2483__allegro__json-logic-kmp__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2484__programadorthi__kotlin-routing__GitHub__development.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2484__programadorthi__kotlin-routing__GitHub__release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2485__jenly1314__AppTemplate__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2485__jenly1314__AppTemplate__GitHub__issues-stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2489__QuickBirdEng__NonEmptyCollections__GitHub__kotlin.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2490__tamimattafi__kabin__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2490__tamimattafi__kabin__GitHub__test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2492__CodandoTV__Netflix-Android__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2493__Alberto97__OUILookup__GitHub__build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2493__Alberto97__OUILookup__GitHub__update-oui.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2495__nphausg__android.embeddedserver__GitHub__deploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2495__nphausg__android.embeddedserver__GitHub__test&build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2496__microsoft__VerifiableCredential-SDK-Android__Azure Pipelines__azure-pipelines.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2498__captainepoch__husky__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__GitHub__build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__GitHub__open_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2499__indrastorms__Dropped-Patches__GitHub__update_bundle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2500__Aditprayogo__GithubUsers__CircleCI__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 2504__Link184__Lifecycle-Delegates__Travis CI__.travis.yml | CI: Travis CI | Unit: False | Instr: False | Keys: []
# ✅ 2511__its-me-debk007__kotlin-android-mvvm-template__GitHub__build_apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__GitHub__documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2514__jump-sdk__jetpack_compose_country_code_picker_emoji__GitHub__semgrep.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2515__mikekpl__pokedex__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__GitHub__cd.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2516__NielsMasdorp__Nederadio-Android__Other__.travis.yml | CI: Travis CI | Unit: True | Instr: False | Keys: []
# ✅ 2518__rafsanjani__datepickertimeline__GitHub__android.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ 2518__rafsanjani__datepickertimeline__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__GitHub__create_jira.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__GitHub__release.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2521__segmentio__analytics-kotlin__GitHub__snapshot.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__GitHub__danger.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2524__PostHog__posthog-android__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__GitHub__release_snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2525__braintree__popup-bridge-android__GitHub__tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2527__lcdsmao__JetTheme__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2527__lcdsmao__JetTheme__GitHub__deploy-docs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2527__lcdsmao__JetTheme__GitHub__refresh-versions.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2528__jing332__SherpaOnnxTtsEngineAndroid__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2528__jing332__SherpaOnnxTtsEngineAndroid__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2529__mars885__value-picker__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2529__mars885__value-picker__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2531__tunjid__Mutator__GitHub__tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__GitHub__pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__GitHub__publish_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2533__eygraber__sqldelight-androidx-driver__GitHub__publish_snapshot_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2538__x13a__Clipeus__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2538__x13a__Clipeus__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__GitHub__android_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__GitHub__create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__GitHub__local_unit_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2539__alirezaeiii__TMDb-Compose-Playground__GitHub__spotless.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2540__shadmanadman__KSensor__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2543__icerockdev__moko-errors__GitHub__compilation-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2543__icerockdev__moko-errors__GitHub__publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2544__doublesymmetry__KotlinAudio__GitHub__validate.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2545__matsumo0922__PixiView-KMP__GitHub__pull-request-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2545__matsumo0922__PixiView-KMP__GitHub__translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2547__dora4__DoraMusic__GitHub__android_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2548__nuhkoca__libbra__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2549__Lastaapps__menza__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2552__google-developer-training__basic-android-kotlin-compose-training-lemonade__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2559__Kalbra__NoReel__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2565__sirekanian__outline__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2566__basaransuleyman__Compose-FeatureBase-Multi-Module-Clean-Hexagonal-Architecture-Android-Kotlin__GitHub__ComposeFeaturedBasedMultiModule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2569__jagnesh__react-native-splash-view__GitHub__ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__data_model_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__dod_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__dod_wrapper_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__flow_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__rx_data_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__rx_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2570__revolut-mobile__RxData__GitHub__scheduler_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__backup-publish-swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__backup-publish-web-npm.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__benchmarks-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__cherry-pick-pr-to-newer-release-cycle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__codestyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__generate-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__generate-dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-android-instrumented-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ 2571__wireapp__kalium__GitHub__gradle-android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-db-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-ios-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__gradle-jvm-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__jira-lint-and-link.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__label-pr.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__pr-author-assigner.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__quay.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__semantic-commit-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2571__wireapp__kalium__GitHub__stale-issues-and-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2574__diareuse__gecko__GitHub__main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2575__solygambas__kotlin-projects__Other__circle.yml | CI: Travis CI | Unit: True | Instr: False | Keys: []
# ✅ 2575__solygambas__kotlin-projects__Other__config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ 2577__sczerwinski__android-hilt__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2577__sczerwinski__android-hilt__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2578__MwaiBanda__WPRK-MultiPlatform__GitHub__swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2579__Carrieukie__android_mpesa_stk__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2584__Yorick-Ryu__CokoTools__GitHub__android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2585__Patch4Code__Logline__GitHub__build-apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2586__jakepurple13__Full-Multiplatform-Compose-Plugin__GitHub__custom_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2586__jakepurple13__Full-Multiplatform-Compose-Plugin__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__continuous-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__periodic-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__publication.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__publish-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2587__bloomberg__selekt__GitHub__stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2591__qq549631030__PriorityDialog__GitHub__android-unit-test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__GitHub__create-documentation-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__GitHub__create-release-from-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2593__apivideo__api.video-android-live-stream__GitHub__update-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2597__alejandro-rios__Boggle-Multiplatform__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2599__mtrewartha__positional__GitHub__tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2604__ishubhamsingh__Splashy__GitHub__Check.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2605__Gegenbauer__CatSpy__GitHub__build_artifacts.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2605__Gegenbauer__CatSpy__GitHub__create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__GitHub__gradle-publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__GitHub__on-pull-request.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ 2606__tabilzad__inspektor__GitHub__run-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2610__matu666__mytv-android__GitHub__release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2612__ChrisKruegerDev__trakt-kotlin__GitHub__build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ 2612__ChrisKruegerDev__trakt-kotlin__GitHub__release-update.yml | CI: Other | Unit: True | Instr: False | Keys: []
#
# ✅ DONE! CSV generated at: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output\7.1-YML_List_4th_attempt_ShallowC.csv
