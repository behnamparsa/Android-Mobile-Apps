# %%
import os
import pandas as pd

# === CONFIGURATION ===
GRADLE_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\BuildInfo"
OUTPUT_CSV = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output\7.1-Gradle_List_4th_attempt_ShallowC.csv"

# === TEST DETECTION LOGIC ===
def detect_tests(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        content = f.read().lower()
        has_unit_test = any(keyword in content for keyword in ['junit', 'testimplementation'])
        has_instrumentation_test = any(keyword in content for keyword in ['androidtestimplementation', 'espresso', 'uiautomator'])
        return has_unit_test, has_instrumentation_test

# === ANALYZE FILES ===
rows = []
for filename in os.listdir(GRADLE_DIR):
    if filename.endswith('__build.gradle') or filename.endswith('__build.gradle.kts'):
        full_path = os.path.join(GRADLE_DIR, filename)
        try:
            parts = filename.split("__")

            # ✅ Extract full_name (between first and third '__')
            if len(parts) >= 3:
                full_name = f"{parts[1]}__{parts[2]}"
            else:
                full_name = filename  # fallback

            # ✅ Extract CI platform (between third and fourth '__')
            if len(parts) >= 4:
                ci_platform = parts[3]
            else:
                ci_platform = "Unknown"

            has_unit, has_instrument = detect_tests(full_path)

            print(f"✅ {filename} | Full Name: {full_name} | CI Platform: {ci_platform} | Unit: {has_unit} | Instr: {has_instrument}")

            rows.append({
                'full_name': full_name,
                'ci_platform_build': ci_platform,
                'gradle_file': filename,
                'has_local_unit_test': has_unit,
                'has_local_instrumentation_test': has_instrument
            })
        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")

# === SAVE TO CSV ===
df = pd.DataFrame(rows)
df.to_csv(OUTPUT_CSV, index=False)
print(f"✅ Saved results to: {OUTPUT_CSV}")
# Out:
# ✅ 0002__square__picasso__Other__build.gradle | Full Name: square__picasso | CI Platform: Other | Unit: False | Instr: False
# ✅ 0003__google__flexbox-layout__Other__build.gradle | Full Name: google__flexbox-layout | CI Platform: Other | Unit: True | Instr: True
# ✅ 0006__nickbutcher__plaid__Other__build.gradle | Full Name: nickbutcher__plaid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0009__android__uamp__Other__build.gradle | Full Name: android__uamp | CI Platform: Other | Unit: True | Instr: False
# ✅ 0016__JakeWharton__timber__Other__build.gradle | Full Name: JakeWharton__timber | CI Platform: Other | Unit: False | Instr: False
# ✅ 0019__ankidroid__Anki-Android__Other__build.gradle | Full Name: ankidroid__Anki-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0020__InsertKoinIO__koin__Other__build.gradle | Full Name: InsertKoinIO__koin | CI Platform: Other | Unit: True | Instr: False
# ✅ 0029__mobile-dev-inc__Maestro__Other__build.gradle | Full Name: mobile-dev-inc__Maestro | CI Platform: Other | Unit: False | Instr: False
# ✅ 0030__uber__RIBs__Other__build.gradle | Full Name: uber__RIBs | CI Platform: Other | Unit: True | Instr: False
# ✅ 0031__facebook__litho__Other__build.gradle | Full Name: facebook__litho | CI Platform: Other | Unit: True | Instr: False
# ✅ 0033__skydoves__android-developer-roadmap__Other__build.gradle | Full Name: skydoves__android-developer-roadmap | CI Platform: Other | Unit: False | Instr: False
# ✅ 0037__zhanghai__MaterialFiles__Other__build.gradle | Full Name: zhanghai__MaterialFiles | CI Platform: Other | Unit: False | Instr: False
# ✅ 0040__Gurupreet__ComposeCookBook__Other__build.gradle | Full Name: Gurupreet__ComposeCookBook | CI Platform: Other | Unit: True | Instr: True
# ✅ 0042__facebook__facebook-android-sdk__Other__build.gradle | Full Name: facebook__facebook-android-sdk | CI Platform: Other | Unit: True | Instr: False
# ✅ 0045__airbnb__mavericks__Other__build.gradle | Full Name: airbnb__mavericks | CI Platform: Other | Unit: True | Instr: False
# ✅ 0047__KotatsuApp__Kotatsu__Other__build.gradle | Full Name: KotatsuApp__Kotatsu | CI Platform: Other | Unit: True | Instr: True
# ✅ 0048__kickstarter__android-oss__Other__build.gradle | Full Name: kickstarter__android-oss | CI Platform: Other | Unit: True | Instr: True
# ✅ 0051__deniscerri__ytdlnis__Other__build.gradle | Full Name: deniscerri__ytdlnis | CI Platform: Other | Unit: True | Instr: True
# ✅ 0054__Kunzisoft__KeePassDX__Other__build.gradle | Full Name: Kunzisoft__KeePassDX | CI Platform: Other | Unit: False | Instr: False
# ✅ 0055__mikepenz__Android-Iconics__Other__build.gradle | Full Name: mikepenz__Android-Iconics | CI Platform: Other | Unit: False | Instr: False
# ✅ 0056__android__camera-samples__Other__build.gradle | Full Name: android__camera-samples | CI Platform: Other | Unit: False | Instr: False
# ✅ 0060__didi__booster__Other__build.gradle | Full Name: didi__booster | CI Platform: Other | Unit: True | Instr: False
# ✅ 0061__muzei__muzei__Other__build.gradle | Full Name: muzei__muzei | CI Platform: Other | Unit: False | Instr: False
# ✅ 0067__android__user-interface-samples__Other__build.gradle | Full Name: android__user-interface-samples | CI Platform: Other | Unit: True | Instr: True
# ✅ 0069__RetroMusicPlayer__RetroMusicPlayer__Other__build.gradle | Full Name: RetroMusicPlayer__RetroMusicPlayer | CI Platform: Other | Unit: False | Instr: False
# ✅ 0072__square__wire__Other__build.gradle | Full Name: square__wire | CI Platform: Other | Unit: False | Instr: False
# ✅ 0073__burhanrashid52__PhotoEditor__Other__build.gradle | Full Name: burhanrashid52__PhotoEditor | CI Platform: Other | Unit: True | Instr: True
# ✅ 0081__VREMSoftwareDevelopment__WiFiAnalyzer__Other__build.gradle | Full Name: VREMSoftwareDevelopment__WiFiAnalyzer | CI Platform: Other | Unit: True | Instr: True
# ✅ 0082__owncloud__android__Other__build.gradle | Full Name: owncloud__android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0084__jing332__tts-server-android__Other__build.gradle | Full Name: jing332__tts-server-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0085__mikepenz__FastAdapter__Other__build.gradle | Full Name: mikepenz__FastAdapter | CI Platform: Other | Unit: False | Instr: False
# ✅ 0092__KieronQuinn__TapTap__Other__build.gradle | Full Name: KieronQuinn__TapTap | CI Platform: Other | Unit: False | Instr: False
# ✅ 0098__fumiama__copymanga__Other__build.gradle | Full Name: fumiama__copymanga | CI Platform: Other | Unit: True | Instr: False
# ✅ 0100__celzero__rethink-app__Other__build.gradle | Full Name: celzero__rethink-app | CI Platform: Other | Unit: True | Instr: True
# ✅ 0104__element-hq__element-android__Other__build.gradle | Full Name: element-hq__element-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0107__vinaygaba__Learn-Jetpack-Compose-By-Example__Other__build.gradle | Full Name: vinaygaba__Learn-Jetpack-Compose-By-Example | CI Platform: Other | Unit: True | Instr: True
# ✅ 0109__hegaojian__JetpackMvvm__Other__build.gradle | Full Name: hegaojian__JetpackMvvm | CI Platform: Other | Unit: True | Instr: False
# ✅ 0110__oblador__react-native-keychain__Other__build.gradle | Full Name: oblador__react-native-keychain | CI Platform: Other | Unit: True | Instr: True
# ✅ 0119__wuseal__JsonToKotlinClass__Other__build.gradle | Full Name: wuseal__JsonToKotlinClass | CI Platform: Other | Unit: True | Instr: False
# ✅ 0121__videolan__vlc-android__Other__build.gradle | Full Name: videolan__vlc-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0125__wordpress-mobile__WordPress-Android__Other__build.gradle | Full Name: wordpress-mobile__WordPress-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0131__gotev__android-upload-service__Other__build.gradle | Full Name: gotev__android-upload-service | CI Platform: Other | Unit: True | Instr: True
# ✅ 0135__korlibs__korge__Other__build.gradle | Full Name: korlibs__korge | CI Platform: Other | Unit: False | Instr: False
# ✅ 0139__MikeOrtiz__TouchImageView__Other__build.gradle | Full Name: MikeOrtiz__TouchImageView | CI Platform: Other | Unit: False | Instr: False
# ✅ 0140__liangjingkanji__BRV__Other__build.gradle | Full Name: liangjingkanji__BRV | CI Platform: Other | Unit: True | Instr: True
# ✅ 0141__zcweng__SwitchButton__Other__build.gradle | Full Name: zcweng__SwitchButton | CI Platform: Other | Unit: True | Instr: True
# ✅ 0142__orgzly__orgzly-android__Other__build.gradle | Full Name: orgzly__orgzly-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0143__KieronQuinn__Smartspacer__Other__build.gradle | Full Name: KieronQuinn__Smartspacer | CI Platform: Other | Unit: True | Instr: False
# ✅ 0146__OxygenCobalt__Auxio__Other__build.gradle | Full Name: OxygenCobalt__Auxio | CI Platform: Other | Unit: True | Instr: True
# ✅ 0147__tanujnotes__Olauncher__Other__build.gradle | Full Name: tanujnotes__Olauncher | CI Platform: Other | Unit: True | Instr: False
# ✅ 0148__gallonyin__worktool__Other__build.gradle | Full Name: gallonyin__worktool | CI Platform: Other | Unit: False | Instr: False
# ✅ 0152__androiddevnotes__awesome-android-kotlin-apps__Other__build.gradle | Full Name: androiddevnotes__awesome-android-kotlin-apps | CI Platform: Other | Unit: True | Instr: False
# ✅ 0153__wikimedia__apps-android-wikipedia__Other__build.gradle | Full Name: wikimedia__apps-android-wikipedia | CI Platform: Other | Unit: True | Instr: True
# ✅ 0155__tuskyapp__Tusky__Other__build.gradle | Full Name: tuskyapp__Tusky | CI Platform: Other | Unit: True | Instr: False
# ✅ 0158__ahmedeltaher__MVVM-Kotlin-Android-Architecture__Other__build.gradle | Full Name: ahmedeltaher__MVVM-Kotlin-Android-Architecture | CI Platform: Other | Unit: True | Instr: True
# ✅ 0160__mpv-android__mpv-android__Other__build.gradle | Full Name: mpv-android__mpv-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0167__azhon__AppUpdate__Other__build.gradle | Full Name: azhon__AppUpdate | CI Platform: Other | Unit: True | Instr: True
# ✅ 0170__wdsqjq__FengYunWeather__Other__build.gradle | Full Name: wdsqjq__FengYunWeather | CI Platform: Other | Unit: False | Instr: False
# ✅ 0171__zagum__Android-SwitchIcon__Other__build.gradle | Full Name: zagum__Android-SwitchIcon | CI Platform: Other | Unit: False | Instr: False
# ✅ 0179__mollyim__mollyim-android__Other__build.gradle | Full Name: mollyim__mollyim-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0180__android__gradle-recipes__Other__build.gradle | Full Name: android__gradle-recipes | CI Platform: Other | Unit: False | Instr: False
# ✅ 0181__allenymt__PrivacySentry__Other__build.gradle | Full Name: allenymt__PrivacySentry | CI Platform: Other | Unit: False | Instr: False
# ✅ 0182__crazyqiang__AndroidStudy__Other__build.gradle | Full Name: crazyqiang__AndroidStudy | CI Platform: Other | Unit: False | Instr: False
# ✅ 0183__10miaomiao__bilimiao2__Other__build.gradle | Full Name: 10miaomiao__bilimiao2 | CI Platform: Other | Unit: True | Instr: True
# ✅ 0184__quran__quran_android__Other__build.gradle | Full Name: quran__quran_android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0185__brianwernick__ExoMedia__Other__build.gradle | Full Name: brianwernick__ExoMedia | CI Platform: Other | Unit: True | Instr: False
# ✅ 0189__mouredev__Weekly-Challenge-2022-Kotlin__Other__build.gradle | Full Name: mouredev__Weekly-Challenge-2022-Kotlin | CI Platform: Other | Unit: True | Instr: True
# ✅ 0190__KieronQuinn__AmbientMusicMod__Other__build.gradle | Full Name: KieronQuinn__AmbientMusicMod | CI Platform: Other | Unit: True | Instr: False
# ✅ 0193__saket__cascade__Other__build.gradle | Full Name: saket__cascade | CI Platform: Other | Unit: False | Instr: False
# ✅ 0194__VIPyinzhiwei__Eyepetizer__Other__build.gradle | Full Name: VIPyinzhiwei__Eyepetizer | CI Platform: Other | Unit: True | Instr: True
# ✅ 0197__stfalcon-studio__StfalconImageViewer__Other__build.gradle | Full Name: stfalcon-studio__StfalconImageViewer | CI Platform: Other | Unit: False | Instr: False
# ✅ 0198__tytydraco__LADB__Other__build.gradle | Full Name: tytydraco__LADB | CI Platform: Other | Unit: False | Instr: False
# ✅ 0199__faruktoptas__FancyShowCaseView__Other__build.gradle | Full Name: faruktoptas__FancyShowCaseView | CI Platform: Other | Unit: True | Instr: True
# ✅ 0200__barbeau__gpstest__Other__build.gradle | Full Name: barbeau__gpstest | CI Platform: Other | Unit: True | Instr: True
# ✅ 0201__liangjingkanji__Net__Other__build.gradle | Full Name: liangjingkanji__Net | CI Platform: Other | Unit: True | Instr: True
# ✅ 0207__cashapp__redwood__Other__build.gradle | Full Name: cashapp__redwood | CI Platform: Other | Unit: False | Instr: False
# ✅ 0208__OmGodse__Notally__Other__build.gradle | Full Name: OmGodse__Notally | CI Platform: Other | Unit: False | Instr: False
# ✅ 0210__HMBSbige__ShadowsocksR-Android__Other__build.gradle | Full Name: HMBSbige__ShadowsocksR-Android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0212__enricocid__Music-Player-GO__Other__build.gradle | Full Name: enricocid__Music-Player-GO | CI Platform: Other | Unit: False | Instr: False
# ✅ 0213__czy1121__update__Other__build.gradle | Full Name: czy1121__update | CI Platform: Other | Unit: False | Instr: False
# ✅ 0217__Foso__Ktorfit__Other__build.gradle | Full Name: Foso__Ktorfit | CI Platform: Other | Unit: False | Instr: False
# ✅ 0219__markusfisch__BinaryEye__Other__build.gradle | Full Name: markusfisch__BinaryEye | CI Platform: Other | Unit: True | Instr: False
# ✅ 0220__mozilla-mobile__firefox-android__Other__build.gradle | Full Name: mozilla-mobile__firefox-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0222__tonyofrancis__Fetch__Other__build.gradle | Full Name: tonyofrancis__Fetch | CI Platform: Other | Unit: True | Instr: True
# ✅ 0227__ArisGuimera__SimpleAndroidMVVM__Other__build.gradle | Full Name: ArisGuimera__SimpleAndroidMVVM | CI Platform: Other | Unit: True | Instr: True
# ✅ 0229__AdevintaSpain__Barista__Other__build.gradle | Full Name: AdevintaSpain__Barista | CI Platform: Other | Unit: False | Instr: False
# ✅ 0237__keymapperorg__KeyMapper__Other__build.gradle | Full Name: keymapperorg__KeyMapper | CI Platform: Other | Unit: True | Instr: True
# ✅ 0238__angcyo__DslTabLayout__Other__build.gradle | Full Name: angcyo__DslTabLayout | CI Platform: Other | Unit: False | Instr: False
# ✅ 0244__android__storage-samples__Other__build.gradle | Full Name: android__storage-samples | CI Platform: Other | Unit: False | Instr: False
# ✅ 0247__vanniktech__Emoji__Other__build.gradle | Full Name: vanniktech__Emoji | CI Platform: Other | Unit: False | Instr: False
# ✅ 0249__android__codelab-android-compose__Other__build.gradle | Full Name: android__codelab-android-compose | CI Platform: Other | Unit: False | Instr: False
# ✅ 0258__CarGuo__GSYGithubAppKotlin__Other__build.gradle | Full Name: CarGuo__GSYGithubAppKotlin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0259__Spikeysanju__MotionToast__Other__build.gradle | Full Name: Spikeysanju__MotionToast | CI Platform: Other | Unit: True | Instr: True
# ✅ 0260__plateaukao__einkbro__Other__build.gradle | Full Name: plateaukao__einkbro | CI Platform: Other | Unit: True | Instr: False
# ✅ 0267__getActivity__AndroidProject-Kotlin__Other__build.gradle | Full Name: getActivity__AndroidProject-Kotlin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0271__javakam__FileOperator__Other__build.gradle | Full Name: javakam__FileOperator | CI Platform: Other | Unit: True | Instr: False
# ✅ 0281__legendsayantan__ShizuTools__Other__build.gradle | Full Name: legendsayantan__ShizuTools | CI Platform: Other | Unit: True | Instr: True
# ✅ 0285__octoshrimpy__quik__Other__build.gradle | Full Name: octoshrimpy__quik | CI Platform: Other | Unit: True | Instr: True
# ✅ 0287__Hamza417__Inure__Other__build.gradle | Full Name: Hamza417__Inure | CI Platform: Other | Unit: False | Instr: False
# ✅ 0289__termux__termux-styling__Other__build.gradle | Full Name: termux__termux-styling | CI Platform: Other | Unit: False | Instr: False
# ✅ 0294__Petterpx__FloatingX__Other__build.gradle | Full Name: Petterpx__FloatingX | CI Platform: Other | Unit: False | Instr: False
# ✅ 0295__android__performance-samples__Other__build.gradle | Full Name: android__performance-samples | CI Platform: Other | Unit: False | Instr: False
# ✅ 0298__tailscale__tailscale-android__Other__build.gradle | Full Name: tailscale__tailscale-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0299__ihsanbal__LoggingInterceptor__Other__build.gradle | Full Name: ihsanbal__LoggingInterceptor | CI Platform: Other | Unit: False | Instr: False
# ✅ 0300__anastr__SpeedView__Other__build.gradle | Full Name: anastr__SpeedView | CI Platform: Other | Unit: False | Instr: False
# ✅ 0302__magnusja__libaums__Other__build.gradle | Full Name: magnusja__libaums | CI Platform: Other | Unit: False | Instr: False
# ✅ 0304__splitwise__TokenAutoComplete__Other__build.gradle | Full Name: splitwise__TokenAutoComplete | CI Platform: Other | Unit: True | Instr: False
# ✅ 0310__Pool-Of-Tears__Myne__Other__build.gradle | Full Name: Pool-Of-Tears__Myne | CI Platform: Other | Unit: True | Instr: True
# ✅ 0313__LagradOst__QuickNovel__Other__build.gradle | Full Name: LagradOst__QuickNovel | CI Platform: Other | Unit: True | Instr: True
# ✅ 0314__vitorpamplona__amethyst__Other__build.gradle | Full Name: vitorpamplona__amethyst | CI Platform: Other | Unit: True | Instr: True
# ✅ 0322__bugsnag__bugsnag-android__Other__build.gradle | Full Name: bugsnag__bugsnag-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0326__Myzel394__Alibi__Other__build.gradle | Full Name: Myzel394__Alibi | CI Platform: Other | Unit: True | Instr: True
# ✅ 0328__react-native-text-input-mask__react-native-text-input-mask__Other__build.gradle | Full Name: react-native-text-input-mask__react-native-text-input-mask | CI Platform: Other | Unit: False | Instr: False
# ✅ 0329__mozilla__rust-android-gradle__Other__build.gradle | Full Name: mozilla__rust-android-gradle | CI Platform: Other | Unit: True | Instr: True
# ✅ 0331__pedrovgs__Shot__Other__build.gradle | Full Name: pedrovgs__Shot | CI Platform: Other | Unit: True | Instr: True
# ✅ 0332__ImangazalievM__CircleMenu__Other__build.gradle | Full Name: ImangazalievM__CircleMenu | CI Platform: Other | Unit: False | Instr: False
# ✅ 0333__badoo__Reaktive__Other__build.gradle | Full Name: badoo__Reaktive | CI Platform: Other | Unit: False | Instr: False
# ✅ 0334__avluis__Hentoid__Other__build.gradle | Full Name: avluis__Hentoid | CI Platform: Other | Unit: True | Instr: False
# ✅ 0335__spotify__ruler__Other__build.gradle | Full Name: spotify__ruler | CI Platform: Other | Unit: False | Instr: False
# ✅ 0340__RyensX__MediaBox__Other__build.gradle | Full Name: RyensX__MediaBox | CI Platform: Other | Unit: True | Instr: True
# ✅ 0342__DUpdateSystem__UpgradeAll__Other__build.gradle | Full Name: DUpdateSystem__UpgradeAll | CI Platform: Other | Unit: True | Instr: True
# ✅ 0345__suming77__SumTea_Android__Other__build.gradle | Full Name: suming77__SumTea_Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0346__PatilShreyas__Capturable__Other__build.gradle | Full Name: PatilShreyas__Capturable | CI Platform: Other | Unit: True | Instr: True
# ✅ 0348__android__tv-samples__Other__build.gradle | Full Name: android__tv-samples | CI Platform: Other | Unit: True | Instr: False
# ✅ 0353__esafirm__android-image-picker__Other__build.gradle | Full Name: esafirm__android-image-picker | CI Platform: Other | Unit: True | Instr: True
# ✅ 0356__capntrips__KernelFlasher__Other__build.gradle | Full Name: capntrips__KernelFlasher | CI Platform: Other | Unit: False | Instr: False
# ✅ 0358__gotify__android__Other__build.gradle | Full Name: gotify__android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0364__AAChartModel__AAChartCore-Kotlin__Other__build.gradle | Full Name: AAChartModel__AAChartCore-Kotlin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0368__square__workflow-kotlin__Other__build.gradle | Full Name: square__workflow-kotlin | CI Platform: Other | Unit: True | Instr: False
# ✅ 0371__rosuH__AndroidFilePicker__Other__build.gradle | Full Name: rosuH__AndroidFilePicker | CI Platform: Other | Unit: True | Instr: True
# ✅ 0372__measure-sh__measure__Other__build.gradle | Full Name: measure-sh__measure | CI Platform: Other | Unit: True | Instr: False
# ✅ 0375__JunioJsv__mtk-easy-su__Other__build.gradle | Full Name: JunioJsv__mtk-easy-su | CI Platform: Other | Unit: False | Instr: False
# ✅ 0376__ligi__SurvivalManual__Other__build.gradle | Full Name: ligi__SurvivalManual | CI Platform: Other | Unit: True | Instr: True
# ✅ 0377__realm__realm-kotlin__Other__build.gradle | Full Name: realm__realm-kotlin | CI Platform: Other | Unit: True | Instr: True
# ✅ 0379__kiwix__kiwix-android__Other__build.gradle | Full Name: kiwix__kiwix-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0381__google-developer-training__advanced-android-testing__Other__build.gradle | Full Name: google-developer-training__advanced-android-testing | CI Platform: Other | Unit: True | Instr: True
# ✅ 0382__Chooloo__koler__Other__build.gradle | Full Name: Chooloo__koler | CI Platform: Other | Unit: True | Instr: True
# ✅ 0383__vhqtvn__VHEditor-Android__Other__build.gradle | Full Name: vhqtvn__VHEditor-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0385__horizontalsystems__unstoppable-wallet-android__Other__build.gradle | Full Name: horizontalsystems__unstoppable-wallet-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0386__tejado__android-usb-gadget__Other__build.gradle | Full Name: tejado__android-usb-gadget | CI Platform: Other | Unit: True | Instr: True
# ✅ 0387__stantanasi__streamflix__Other__build.gradle | Full Name: stantanasi__streamflix | CI Platform: Other | Unit: True | Instr: True
# ✅ 0391__aliyun__alicloud-android-demo__Other__build.gradle | Full Name: aliyun__alicloud-android-demo | CI Platform: Other | Unit: False | Instr: False
# ✅ 0393__Hamadakram__Sneaker__Other__build.gradle | Full Name: Hamadakram__Sneaker | CI Platform: Other | Unit: True | Instr: False
# ✅ 0395__Applandeo__Material-Calendar-View__Other__build.gradle | Full Name: Applandeo__Material-Calendar-View | CI Platform: Other | Unit: True | Instr: True
# ✅ 0400__SceneView__sceneview-android__Other__build.gradle | Full Name: SceneView__sceneview-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0401__trynoice__android-app__Other__build.gradle | Full Name: trynoice__android-app | CI Platform: Other | Unit: True | Instr: True
# ✅ 0402__android__security-samples__Other__build.gradle | Full Name: android__security-samples | CI Platform: Other | Unit: False | Instr: False
# ✅ 0403__mtotschnig__MyExpenses__Other__build.gradle | Full Name: mtotschnig__MyExpenses | CI Platform: Other | Unit: True | Instr: True
# ✅ 0404__infinum__android_dbinspector__Other__build.gradle | Full Name: infinum__android_dbinspector | CI Platform: Other | Unit: False | Instr: False
# ✅ 0407__ernestoyaquello__DragDropSwipeRecyclerview__Other__build.gradle | Full Name: ernestoyaquello__DragDropSwipeRecyclerview | CI Platform: Other | Unit: False | Instr: False
# ✅ 0413__fluttercommunity__flutter_downloader__Other__build.gradle | Full Name: fluttercommunity__flutter_downloader | CI Platform: Other | Unit: False | Instr: False
# ✅ 0423__cryptomator__android__Other__build.gradle | Full Name: cryptomator__android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0427__pawegio__KAndroid__Other__build.gradle | Full Name: pawegio__KAndroid | CI Platform: Other | Unit: True | Instr: True
# ✅ 0431__Kennyc1012__BottomSheetMenu__Other__build.gradle | Full Name: Kennyc1012__BottomSheetMenu | CI Platform: Other | Unit: False | Instr: False
# ✅ 0434__WaxMoon__MultiApp__Other__build.gradle | Full Name: WaxMoon__MultiApp | CI Platform: Other | Unit: False | Instr: False
# ✅ 0436__termux__termux-gui__Other__build.gradle | Full Name: termux__termux-gui | CI Platform: Other | Unit: True | Instr: False
# ✅ 0438__akshay2211__PixImagePicker__Other__build.gradle | Full Name: akshay2211__PixImagePicker | CI Platform: Other | Unit: True | Instr: True
# ✅ 0441__hushenghao__AndroidEasterEggs__Other__build.gradle | Full Name: hushenghao__AndroidEasterEggs | CI Platform: Other | Unit: False | Instr: False
# ✅ 0447__Xed-Editor__Xed-Editor__Other__build.gradle | Full Name: Xed-Editor__Xed-Editor | CI Platform: Other | Unit: True | Instr: True
# ✅ 0449__ligi__PassAndroid__Other__build.gradle | Full Name: ligi__PassAndroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0454__orgzly-revived__orgzly-android-revived__Other__build.gradle | Full Name: orgzly-revived__orgzly-android-revived | CI Platform: Other | Unit: True | Instr: False
# ✅ 0458__CofbroTeam__Doraemon__Other__build.gradle | Full Name: CofbroTeam__Doraemon | CI Platform: Other | Unit: True | Instr: True
# ✅ 0459__gujjwal00__avnc__Other__build.gradle | Full Name: gujjwal00__avnc | CI Platform: Other | Unit: True | Instr: True
# ✅ 0462__xbdcc__GrabRedEnvelope__Other__build.gradle | Full Name: xbdcc__GrabRedEnvelope | CI Platform: Other | Unit: True | Instr: True
# ✅ 0465__takahirom__roborazzi__Other__build.gradle | Full Name: takahirom__roborazzi | CI Platform: Other | Unit: True | Instr: True
# ✅ 0467__caydey__ffshare__Other__build.gradle | Full Name: caydey__ffshare | CI Platform: Other | Unit: True | Instr: True
# ✅ 0469__GoodieBag__Pinview__Other__build.gradle | Full Name: GoodieBag__Pinview | CI Platform: Other | Unit: True | Instr: True
# ✅ 0473__skydoves__ElasticViews__Other__build.gradle | Full Name: skydoves__ElasticViews | CI Platform: Other | Unit: False | Instr: False
# ✅ 0477__jahirfiquitiva__Blueprint__Other__build.gradle | Full Name: jahirfiquitiva__Blueprint | CI Platform: Other | Unit: False | Instr: False
# ✅ 0481__MackHartley__RoundedProgressBar__Other__build.gradle | Full Name: MackHartley__RoundedProgressBar | CI Platform: Other | Unit: True | Instr: True
# ✅ 0483__st235__ExpandableBottomBar__Other__build.gradle | Full Name: st235__ExpandableBottomBar | CI Platform: Other | Unit: True | Instr: False
# ✅ 0486__FSpaceCore__SpaceCore__Other__build.gradle | Full Name: FSpaceCore__SpaceCore | CI Platform: Other | Unit: True | Instr: False
# ✅ 0488__MoyuruAizawa__TimetableLayout__Other__build.gradle | Full Name: MoyuruAizawa__TimetableLayout | CI Platform: Other | Unit: True | Instr: True
# ✅ 0490__rt-bishop__Look4Sat__Other__build.gradle | Full Name: rt-bishop__Look4Sat | CI Platform: Other | Unit: True | Instr: False
# ✅ 0491__mudkipme__MoeMemosAndroid__Other__build.gradle | Full Name: mudkipme__MoeMemosAndroid | CI Platform: Other | Unit: True | Instr: True
# ✅ 0492__meshenger-app__meshenger-android__Other__build.gradle | Full Name: meshenger-app__meshenger-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0501__adrielcafe__lyricist__Other__build.gradle | Full Name: adrielcafe__lyricist | CI Platform: Other | Unit: False | Instr: False
# ✅ 0502__KieronQuinn__ClassicPowerMenu__Other__build.gradle | Full Name: KieronQuinn__ClassicPowerMenu | CI Platform: Other | Unit: False | Instr: False
# ✅ 0510__bernaferrari__ChangeDetection__Other__build.gradle | Full Name: bernaferrari__ChangeDetection | CI Platform: Other | Unit: False | Instr: False
# ✅ 0514__angcyo__DslAdapter__Other__build.gradle | Full Name: angcyo__DslAdapter | CI Platform: Other | Unit: True | Instr: True
# ✅ 0516__wordpress-mobile__AztecEditor-Android__Other__build.gradle | Full Name: wordpress-mobile__AztecEditor-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0520__imandolatkia__Android-Animated-Theme-Manager__Other__build.gradle | Full Name: imandolatkia__Android-Animated-Theme-Manager | CI Platform: Other | Unit: False | Instr: False
# ✅ 0521__traccar__traccar-client-android__Other__build.gradle | Full Name: traccar__traccar-client-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0522__jeziellago__compose-markdown__Other__build.gradle | Full Name: jeziellago__compose-markdown | CI Platform: Other | Unit: True | Instr: True
# ✅ 0526__janishar__android-kotlin-mvp-architecture__Other__build.gradle | Full Name: janishar__android-kotlin-mvp-architecture | CI Platform: Other | Unit: True | Instr: True
# ✅ 0530__SimformSolutionsPvtLtd__SSComposeCookBook__Other__build.gradle | Full Name: SimformSolutionsPvtLtd__SSComposeCookBook | CI Platform: Other | Unit: True | Instr: True
# ✅ 0532__FlyJingFish__AndroidAOP__Other__build.gradle | Full Name: FlyJingFish__AndroidAOP | CI Platform: Other | Unit: False | Instr: False
# ✅ 0533__SagerNet__sing-box-for-android__Other__build.gradle | Full Name: SagerNet__sing-box-for-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0536__Flank__flank__Other__build.gradle | Full Name: Flank__flank | CI Platform: Other | Unit: True | Instr: True
# ✅ 0537__Pool-Of-Tears__GreenStash__Other__build.gradle | Full Name: Pool-Of-Tears__GreenStash | CI Platform: Other | Unit: True | Instr: True
# ✅ 0541__LibreShift__red-moon__Other__build.gradle | Full Name: LibreShift__red-moon | CI Platform: Other | Unit: True | Instr: True
# ✅ 0542__wealthfront__magellan__Other__build.gradle | Full Name: wealthfront__magellan | CI Platform: Other | Unit: True | Instr: False
# ✅ 0543__anyproto__anytype-kotlin__Other__build.gradle | Full Name: anyproto__anytype-kotlin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0546__darshanparajuli__LogcatReader__Other__build.gradle | Full Name: darshanparajuli__LogcatReader | CI Platform: Other | Unit: True | Instr: True
# ✅ 0548__binwiederhier__ntfy-android__Other__build.gradle | Full Name: binwiederhier__ntfy-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0552__jaaksi__pickerview__Other__build.gradle | Full Name: jaaksi__pickerview | CI Platform: Other | Unit: False | Instr: False
# ✅ 0557__b-lam__Resplash__Other__build.gradle | Full Name: b-lam__Resplash | CI Platform: Other | Unit: True | Instr: True
# ✅ 0561__yhs0602__Android-Disassembler__Other__build.gradle | Full Name: yhs0602__Android-Disassembler | CI Platform: Other | Unit: False | Instr: False
# ✅ 0564__RikkaApps__WADB__Other__build.gradle | Full Name: RikkaApps__WADB | CI Platform: Other | Unit: False | Instr: False
# ✅ 0566__fornewid__material-motion-compose__Other__build.gradle | Full Name: fornewid__material-motion-compose | CI Platform: Other | Unit: False | Instr: False
# ✅ 0568__jahirfiquitiva__Frames__Other__build.gradle | Full Name: jahirfiquitiva__Frames | CI Platform: Other | Unit: False | Instr: False
# ✅ 0570__amitshekhariitbhu__MVVM-Architecture-Android__Other__build.gradle | Full Name: amitshekhariitbhu__MVVM-Architecture-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0571__mapbox__mapbox-navigation-android__Other__build.gradle | Full Name: mapbox__mapbox-navigation-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0572__ffgiraldez__reactive-mvvm-android__Other__build.gradle | Full Name: ffgiraldez__reactive-mvvm-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0573__mozilla-mobile__reference-browser__Other__build.gradle | Full Name: mozilla-mobile__reference-browser | CI Platform: Other | Unit: True | Instr: True
# ✅ 0574__gabriel-TheCode__AestheticDialogs__Other__build.gradle | Full Name: gabriel-TheCode__AestheticDialogs | CI Platform: Other | Unit: True | Instr: True
# ✅ 0577__vestrel00__contacts-android__Other__build.gradle | Full Name: vestrel00__contacts-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0581__microsoft__fluentui-android__Other__build.gradle | Full Name: microsoft__fluentui-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0582__WirelessAlien__ZipXtract__Other__build.gradle | Full Name: WirelessAlien__ZipXtract | CI Platform: Other | Unit: True | Instr: True
# ✅ 0583__openhab__openhab-android__Other__build.gradle | Full Name: openhab__openhab-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0588__ldlywt__FastJetpack__Other__build.gradle | Full Name: ldlywt__FastJetpack | CI Platform: Other | Unit: False | Instr: False
# ✅ 0589__walleth__walleth__Other__build.gradle | Full Name: walleth__walleth | CI Platform: Other | Unit: True | Instr: True
# ✅ 0590__OneSignal__OneSignal-Android-SDK__Other__build.gradle | Full Name: OneSignal__OneSignal-Android-SDK | CI Platform: Other | Unit: True | Instr: False
# ✅ 0592__romainguy__combo-breaker__Other__build.gradle | Full Name: romainguy__combo-breaker | CI Platform: Other | Unit: True | Instr: False
# ✅ 0594__nextcloud__talk-android__Other__build.gradle | Full Name: nextcloud__talk-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0599__myinnos__AlphabetIndex-Fast-Scroll-RecyclerView__Other__build.gradle | Full Name: myinnos__AlphabetIndex-Fast-Scroll-RecyclerView | CI Platform: Other | Unit: False | Instr: False
# ✅ 0608__PatilShreyas__permission-flow-android__Other__build.gradle | Full Name: PatilShreyas__permission-flow-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0609__mickstar__Zoo-For-Zotero__Other__build.gradle | Full Name: mickstar__Zoo-For-Zotero | CI Platform: Other | Unit: True | Instr: True
# ✅ 0611__BimmerGestalt__AAIdrive__Other__build.gradle | Full Name: BimmerGestalt__AAIdrive | CI Platform: Other | Unit: False | Instr: False
# ✅ 0614__DylanCaiCoding__Longan__Other__build.gradle | Full Name: DylanCaiCoding__Longan | CI Platform: Other | Unit: True | Instr: True
# ✅ 0617__lz233__Tarnhelm__Other__build.gradle | Full Name: lz233__Tarnhelm | CI Platform: Other | Unit: True | Instr: True
# ✅ 0618__sangcomz__StickyTimeLine__Other__build.gradle | Full Name: sangcomz__StickyTimeLine | CI Platform: Other | Unit: True | Instr: True
# ✅ 0619__furkanaskin__Weatherapp__Other__build.gradle | Full Name: furkanaskin__Weatherapp | CI Platform: Other | Unit: True | Instr: True
# ✅ 0621__canopas__compose-intro-showcase__Other__build.gradle | Full Name: canopas__compose-intro-showcase | CI Platform: Other | Unit: True | Instr: True
# ✅ 0622__metrodroid__metrodroid__Other__build.gradle | Full Name: metrodroid__metrodroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0626__VarunS2002__Xposed-Disable-FLAG_SECURE__Other__build.gradle | Full Name: VarunS2002__Xposed-Disable-FLAG_SECURE | CI Platform: Other | Unit: False | Instr: False
# ✅ 0632__YouROK__TorrServe__Other__build.gradle | Full Name: YouROK__TorrServe | CI Platform: Other | Unit: False | Instr: False
# ✅ 0633__prof18__RSS-Parser__Other__build.gradle | Full Name: prof18__RSS-Parser | CI Platform: Other | Unit: False | Instr: False
# ✅ 0634__AbedElazizShe__LightCompressor__Other__build.gradle | Full Name: AbedElazizShe__LightCompressor | CI Platform: Other | Unit: True | Instr: True
# ✅ 0635__joreilly__GalwayBus__Other__build.gradle | Full Name: joreilly__GalwayBus | CI Platform: Other | Unit: False | Instr: False
# ✅ 0638__android__codelab-android-workmanager__Other__build.gradle | Full Name: android__codelab-android-workmanager | CI Platform: Other | Unit: True | Instr: False
# ✅ 0639__kongpf8848__Animation__Other__build.gradle | Full Name: kongpf8848__Animation | CI Platform: Other | Unit: True | Instr: False
# ✅ 0641__mobiledevpro__Android-Kotlin-MVVM-Template__Other__build.gradle | Full Name: mobiledevpro__Android-Kotlin-MVVM-Template | CI Platform: Other | Unit: False | Instr: False
# ✅ 0642__woheller69__whoBIRD__Other__build.gradle | Full Name: woheller69__whoBIRD | CI Platform: Other | Unit: False | Instr: False
# ✅ 0645__Krosxx__Android-Auto-Api__Other__build.gradle | Full Name: Krosxx__Android-Auto-Api | CI Platform: Other | Unit: False | Instr: True
# ✅ 0647__saveourtool__diktat__Other__build.gradle | Full Name: saveourtool__diktat | CI Platform: Other | Unit: False | Instr: False
# ✅ 0648__abhinavsuthar__Android_Spy_App__Other__build.gradle | Full Name: abhinavsuthar__Android_Spy_App | CI Platform: Other | Unit: True | Instr: True
# ✅ 0651__commandiron__WheelPickerCompose__Other__build.gradle | Full Name: commandiron__WheelPickerCompose | CI Platform: Other | Unit: True | Instr: False
# ✅ 0652__soupslurpr__Transcribro__Other__build.gradle | Full Name: soupslurpr__Transcribro | CI Platform: Other | Unit: False | Instr: False
# ✅ 0655__microsoft__thrifty__Other__build.gradle | Full Name: microsoft__thrifty | CI Platform: Other | Unit: True | Instr: False
# ✅ 0659__Slion__Fulguris__Other__build.gradle | Full Name: Slion__Fulguris | CI Platform: Other | Unit: True | Instr: False
# ✅ 0662__TheTimeWalker__wallpanel-android__Other__build.gradle | Full Name: TheTimeWalker__wallpanel-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0666__uber__motif__Other__build.gradle | Full Name: uber__motif | CI Platform: Other | Unit: False | Instr: False
# ✅ 0667__ubergeek42__weechat-android__Other__build.gradle | Full Name: ubergeek42__weechat-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0670__SimformSolutionsPvtLtd__SSCustomBottomNavigation__Other__build.gradle | Full Name: SimformSolutionsPvtLtd__SSCustomBottomNavigation | CI Platform: Other | Unit: True | Instr: True
# ✅ 0672__aitsuki__SwipeMenuRecyclerView__Other__build.gradle | Full Name: aitsuki__SwipeMenuRecyclerView | CI Platform: Other | Unit: False | Instr: False
# ✅ 0674__pyamsoft__tetherfi__Other__build.gradle | Full Name: pyamsoft__tetherfi | CI Platform: Other | Unit: False | Instr: False
# ✅ 0679__msoultanidis__quillnote__Other__build.gradle | Full Name: msoultanidis__quillnote | CI Platform: Other | Unit: True | Instr: True
# ✅ 0681__ven-coder__Assists__Other__build.gradle | Full Name: ven-coder__Assists | CI Platform: Other | Unit: True | Instr: False
# ✅ 0684__MalitsPlus__ShizuruNotes__Other__build.gradle | Full Name: MalitsPlus__ShizuruNotes | CI Platform: Other | Unit: True | Instr: True
# ✅ 0685__massoudss__waveformSeekBar__Other__build.gradle | Full Name: massoudss__waveformSeekBar | CI Platform: Other | Unit: True | Instr: False
# ✅ 0686__solkin__appteka-android__Other__build.gradle | Full Name: solkin__appteka-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0687__fondesa__kpermissions__Other__build.gradle | Full Name: fondesa__kpermissions | CI Platform: Other | Unit: False | Instr: False
# ✅ 0694__ologe__canaree-music-player__Other__build.gradle | Full Name: ologe__canaree-music-player | CI Platform: Other | Unit: False | Instr: False
# ✅ 0695__fondesa__recycler-view-divider__Other__build.gradle | Full Name: fondesa__recycler-view-divider | CI Platform: Other | Unit: False | Instr: False
# ✅ 0696__SamAmco__track-and-graph__Other__build.gradle | Full Name: SamAmco__track-and-graph | CI Platform: Other | Unit: True | Instr: False
# ✅ 0698__OmneyaOsman__OnBoardingScreen__Other__build.gradle | Full Name: OmneyaOsman__OnBoardingScreen | CI Platform: Other | Unit: True | Instr: False
# ✅ 0699__amitshekhariitbhu__Learn-Kotlin-Flow__Other__build.gradle | Full Name: amitshekhariitbhu__Learn-Kotlin-Flow | CI Platform: Other | Unit: True | Instr: True
# ✅ 0700__khushpanchal__Ketch__Other__build.gradle | Full Name: khushpanchal__Ketch | CI Platform: Other | Unit: True | Instr: True
# ✅ 0701__Radiokot__photoprism-android-client__Other__build.gradle | Full Name: Radiokot__photoprism-android-client | CI Platform: Other | Unit: True | Instr: True
# ✅ 0707__capcom6__android-sms-gateway__Other__build.gradle | Full Name: capcom6__android-sms-gateway | CI Platform: Other | Unit: True | Instr: True
# ✅ 0708__android__codelab-android-paging__Other__build.gradle | Full Name: android__codelab-android-paging | CI Platform: Other | Unit: True | Instr: False
# ✅ 0713__pandulapeter__beagle__Other__build.gradle | Full Name: pandulapeter__beagle | CI Platform: Other | Unit: False | Instr: False
# ✅ 0714__Smooth-E__wireless-adb-switch__Other__build.gradle | Full Name: Smooth-E__wireless-adb-switch | CI Platform: Other | Unit: False | Instr: False
# ✅ 0716__wajahatkarim3__Flippable__Other__build.gradle | Full Name: wajahatkarim3__Flippable | CI Platform: Other | Unit: True | Instr: False
# ✅ 0718__Trendyol__medusa__Other__build.gradle | Full Name: Trendyol__medusa | CI Platform: Other | Unit: True | Instr: True
# ✅ 0725__hanjoongcho__aaf-easydiary__Other__build.gradle | Full Name: hanjoongcho__aaf-easydiary | CI Platform: Other | Unit: True | Instr: True
# ✅ 0727__jing332__AlistAndroid__Other__build.gradle | Full Name: jing332__AlistAndroid | CI Platform: Other | Unit: True | Instr: True
# ✅ 0728__mytv-android__mytv-android__Other__build.gradle | Full Name: mytv-android__mytv-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0730__FunkyMuse__Aurora__Other__build.gradle | Full Name: FunkyMuse__Aurora | CI Platform: Other | Unit: False | Instr: False
# ✅ 0731__premnirmal__StockTicker__Other__build.gradle | Full Name: premnirmal__StockTicker | CI Platform: Other | Unit: True | Instr: False
# ✅ 0733__Knight-ZXW__BlockCanaryX__Other__build.gradle | Full Name: Knight-ZXW__BlockCanaryX | CI Platform: Other | Unit: True | Instr: True
# ✅ 0735__ImaginativeShohag__Why-Not-Image-Carousel__Other__build.gradle | Full Name: ImaginativeShohag__Why-Not-Image-Carousel | CI Platform: Other | Unit: False | Instr: False
# ✅ 0737__reveny__Android-Native-Root-Detector__Other__build.gradle | Full Name: reveny__Android-Native-Root-Detector | CI Platform: Other | Unit: False | Instr: False
# ✅ 0744__MixinNetwork__android-app__Other__build.gradle | Full Name: MixinNetwork__android-app | CI Platform: Other | Unit: True | Instr: True
# ✅ 0746__mistamek__Android-drawable-preview-plugin__Other__build.gradle | Full Name: mistamek__Android-drawable-preview-plugin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0750__idanatz__OneAdapter__Other__build.gradle | Full Name: idanatz__OneAdapter | CI Platform: Other | Unit: False | Instr: False
# ✅ 0751__ekibun__Bangumi__Other__build.gradle | Full Name: ekibun__Bangumi | CI Platform: Other | Unit: True | Instr: True
# ✅ 0753__ElishaAz__Sayboard__Other__build.gradle | Full Name: ElishaAz__Sayboard | CI Platform: Other | Unit: True | Instr: True
# ✅ 0758__twiceyuan__WXAPK__Other__build.gradle | Full Name: twiceyuan__WXAPK | CI Platform: Other | Unit: True | Instr: False
# ✅ 0760__giejay__Immich-Android-TV__Other__build.gradle | Full Name: giejay__Immich-Android-TV | CI Platform: Other | Unit: True | Instr: False
# ✅ 0763__android__identity-samples__Other__build.gradle | Full Name: android__identity-samples | CI Platform: Other | Unit: True | Instr: True
# ✅ 0764__muneebwanee__Dash__Other__build.gradle | Full Name: muneebwanee__Dash | CI Platform: Other | Unit: True | Instr: False
# ✅ 0765__dropbox__dependency-guard__Other__build.gradle | Full Name: dropbox__dependency-guard | CI Platform: Other | Unit: False | Instr: False
# ✅ 0767__VKCOM__vk-android-sdk__Other__build.gradle | Full Name: VKCOM__vk-android-sdk | CI Platform: Other | Unit: False | Instr: False
# ✅ 0768__dekusms__DekuSMS-Android__Other__build.gradle | Full Name: dekusms__DekuSMS-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0769__MiniAiLive__FaceRecognition-LivenessDetection-SDK-Android__Other__build.gradle | Full Name: MiniAiLive__FaceRecognition-LivenessDetection-SDK-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0770__y20k__transistor__Other__build.gradle | Full Name: y20k__transistor | CI Platform: Other | Unit: False | Instr: False
# ✅ 0772__hegaojian__MvvmHelper__Other__build.gradle | Full Name: hegaojian__MvvmHelper | CI Platform: Other | Unit: True | Instr: False
# ✅ 0773__BlinkID__blinkid-android__Other__build.gradle | Full Name: BlinkID__blinkid-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0774__vanniktech__RxRiddles__Other__build.gradle | Full Name: vanniktech__RxRiddles | CI Platform: Other | Unit: True | Instr: False
# ✅ 0777__GetStream__webrtc-in-jetpack-compose__Other__build.gradle | Full Name: GetStream__webrtc-in-jetpack-compose | CI Platform: Other | Unit: True | Instr: False
# ✅ 0778__tmo1__sms-ie__Other__build.gradle | Full Name: tmo1__sms-ie | CI Platform: Other | Unit: True | Instr: True
# ✅ 0784__sensorsdata__sa-sdk-android-plugin2__Other__build.gradle | Full Name: sensorsdata__sa-sdk-android-plugin2 | CI Platform: Other | Unit: False | Instr: False
# ✅ 0786__amitshekhariitbhu__Learn-Kotlin-Coroutines__Other__build.gradle | Full Name: amitshekhariitbhu__Learn-Kotlin-Coroutines | CI Platform: Other | Unit: True | Instr: True
# ✅ 0789__tasy5kg__CuteGIF__Other__build.gradle | Full Name: tasy5kg__CuteGIF | CI Platform: Other | Unit: True | Instr: True
# ✅ 0790__kby-ai__FaceRecognition-Android__Other__build.gradle | Full Name: kby-ai__FaceRecognition-Android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0791__slavabarkov__tidy__Other__build.gradle | Full Name: slavabarkov__tidy | CI Platform: Other | Unit: True | Instr: True
# ✅ 0792__giandifra__arcore_flutter_plugin__Other__build.gradle | Full Name: giandifra__arcore_flutter_plugin | CI Platform: Other | Unit: True | Instr: True
# ✅ 0797__canopas__compose-animations-examples__Other__build.gradle | Full Name: canopas__compose-animations-examples | CI Platform: Other | Unit: True | Instr: True
# ✅ 0798__kittoku__Open-SSTP-Client__Other__build.gradle | Full Name: kittoku__Open-SSTP-Client | CI Platform: Other | Unit: True | Instr: True
# ✅ 0800__liujiayu5566__MockGps__Other__build.gradle | Full Name: liujiayu5566__MockGps | CI Platform: Other | Unit: True | Instr: False
# ✅ 0803__wisnukurniawan__Compose-ToDo__Other__build.gradle | Full Name: wisnukurniawan__Compose-ToDo | CI Platform: Other | Unit: True | Instr: True
# ✅ 0804__sakusaku3939__DeepLAndroid__Other__build.gradle | Full Name: sakusaku3939__DeepLAndroid | CI Platform: Other | Unit: True | Instr: True
# ✅ 0807__Peakmain__BasicLibrary__Other__build.gradle | Full Name: Peakmain__BasicLibrary | CI Platform: Other | Unit: True | Instr: False
# ✅ 0809__dotintent__flutter-nfc-reader__Other__build.gradle | Full Name: dotintent__flutter-nfc-reader | CI Platform: Other | Unit: True | Instr: True
# ✅ 0812__VladimirWrites__Lemniscate__Other__build.gradle | Full Name: VladimirWrites__Lemniscate | CI Platform: Other | Unit: False | Instr: False
# ✅ 0813__SonicCloudOrg__sonic-android-apk__Other__build.gradle | Full Name: SonicCloudOrg__sonic-android-apk | CI Platform: Other | Unit: True | Instr: True
# ✅ 0816__TakuSemba__CropMe__Other__build.gradle | Full Name: TakuSemba__CropMe | CI Platform: Other | Unit: True | Instr: False
# ✅ 0818__ibitcy__react-native-hole-view__Other__build.gradle | Full Name: ibitcy__react-native-hole-view | CI Platform: Other | Unit: False | Instr: False
# ✅ 0819__tasomaniac__OpenLinkWith__Other__build.gradle | Full Name: tasomaniac__OpenLinkWith | CI Platform: Other | Unit: True | Instr: False
# ✅ 0820__rive-app__rive-android__Other__build.gradle | Full Name: rive-app__rive-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0823__simple-login__Simple-Login-Android__Other__build.gradle | Full Name: simple-login__Simple-Login-Android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0824__data2viz__data2viz__Other__build.gradle | Full Name: data2viz__data2viz | CI Platform: Other | Unit: False | Instr: False
# ✅ 0825__technophilist__Musify__Other__build.gradle | Full Name: technophilist__Musify | CI Platform: Other | Unit: True | Instr: True
# ✅ 0828__SmartToolFactory__Compose-Cropper__Other__build.gradle | Full Name: SmartToolFactory__Compose-Cropper | CI Platform: Other | Unit: True | Instr: True
# ✅ 0830__greyovo__PicQuery__Other__build.gradle | Full Name: greyovo__PicQuery | CI Platform: Other | Unit: True | Instr: True
# ✅ 0831__callstack__react-native-image-editor__Other__build.gradle | Full Name: callstack__react-native-image-editor | CI Platform: Other | Unit: False | Instr: False
# ✅ 0834__acszo__Redomi__Other__build.gradle | Full Name: acszo__Redomi | CI Platform: Other | Unit: False | Instr: False
# ✅ 0835__braintree__braintree_android__Other__build.gradle | Full Name: braintree__braintree_android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0838__tachiyomiorg__extensions__Other__build.gradle | Full Name: tachiyomiorg__extensions | CI Platform: Other | Unit: False | Instr: False
# ✅ 0840__usefulness__easylauncher-gradle-plugin__Other__build.gradle | Full Name: usefulness__easylauncher-gradle-plugin | CI Platform: Other | Unit: True | Instr: True
# ✅ 0841__dropbox__focus__Other__build.gradle | Full Name: dropbox__focus | CI Platform: Other | Unit: False | Instr: False
# ✅ 0843__rozPierog__Cofi__Other__build.gradle | Full Name: rozPierog__Cofi | CI Platform: Other | Unit: True | Instr: True
# ✅ 0844__adrielcafe__bonsai__Other__build.gradle | Full Name: adrielcafe__bonsai | CI Platform: Other | Unit: False | Instr: False
# ✅ 0847__2307vivek__Seeker__Other__build.gradle | Full Name: 2307vivek__Seeker | CI Platform: Other | Unit: True | Instr: True
# ✅ 0850__TeamAmaze__AmazeFileUtilities__Other__build.gradle | Full Name: TeamAmaze__AmazeFileUtilities | CI Platform: Other | Unit: True | Instr: True
# ✅ 0851__AndraxDev__speak-gpt__Other__build.gradle | Full Name: AndraxDev__speak-gpt | CI Platform: Other | Unit: False | Instr: False
# ✅ 0854__poingstudios__godot-admob-android__Other__build.gradle | Full Name: poingstudios__godot-admob-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0855__Reedyuk__blue-falcon__Other__build.gradle | Full Name: Reedyuk__blue-falcon | CI Platform: Other | Unit: False | Instr: False
# ✅ 0856__alisonthemonster__Presently__Other__build.gradle | Full Name: alisonthemonster__Presently | CI Platform: Other | Unit: True | Instr: False
# ✅ 0863__Hamza417__Peristyle__Other__build.gradle | Full Name: Hamza417__Peristyle | CI Platform: Other | Unit: True | Instr: True
# ✅ 0865__zedlabs__WallPortal__Other__build.gradle | Full Name: zedlabs__WallPortal | CI Platform: Other | Unit: True | Instr: True
# ✅ 0867__google-pay__android-quickstart__Other__build.gradle | Full Name: google-pay__android-quickstart | CI Platform: Other | Unit: True | Instr: True
# ✅ 0869__trustdecision__trustdevice-android__Other__build.gradle | Full Name: trustdecision__trustdevice-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0873__eneim__kohii__Other__build.gradle | Full Name: eneim__kohii | CI Platform: Other | Unit: True | Instr: True
# ✅ 0876__x13a__Duress__Other__build.gradle | Full Name: x13a__Duress | CI Platform: Other | Unit: True | Instr: True
# ...
# ✅ 0165__skydoves__TransformationLayout__Other__build.gradle.kts | Full Name: skydoves__TransformationLayout | CI Platform: Other | Unit: False | Instr: False
# ✅ 0163__Mahmud0808__Iconify__Other__build.gradle.kts | Full Name: Mahmud0808__Iconify | CI Platform: Other | Unit: False | Instr: False
# ✅ 0162__nekomangaorg__Neko__Other__build.gradle.kts | Full Name: nekomangaorg__Neko | CI Platform: Other | Unit: False | Instr: False
# ✅ 0161__patrykandpatrick__vico__Other__build.gradle.kts | Full Name: patrykandpatrick__vico | CI Platform: Other | Unit: True | Instr: False
# ✅ 0159__Nain57__Smart-AutoClicker__Other__build.gradle.kts | Full Name: Nain57__Smart-AutoClicker | CI Platform: Other | Unit: False | Instr: False
# ✅ 0157__arkivanov__Decompose__Other__build.gradle.kts | Full Name: arkivanov__Decompose | CI Platform: Other | Unit: False | Instr: False
# ✅ 0156__LouisCAD__Splitties__Other__build.gradle.kts | Full Name: LouisCAD__Splitties | CI Platform: Other | Unit: False | Instr: False
# ✅ 0154__PaulWoitaschek__Voice__Other__build.gradle.kts | Full Name: PaulWoitaschek__Voice | CI Platform: Other | Unit: False | Instr: False
# ✅ 0153__wikimedia__apps-android-wikipedia__Other__build.gradle.kts | Full Name: wikimedia__apps-android-wikipedia | CI Platform: Other | Unit: False | Instr: False
# ✅ 0151__android-password-store__Android-Password-Store__Other__build.gradle.kts | Full Name: android-password-store__Android-Password-Store | CI Platform: Other | Unit: False | Instr: False
# ✅ 0150__aaa1115910__bv__Other__build.gradle.kts | Full Name: aaa1115910__bv | CI Platform: Other | Unit: True | Instr: False
# ✅ 0149__Automattic__pocket-casts-android__Other__build.gradle.kts | Full Name: Automattic__pocket-casts-android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0145__anilbeesetti__nextplayer__Other__build.gradle.kts | Full Name: anilbeesetti__nextplayer | CI Platform: Other | Unit: True | Instr: True
# ✅ 0144__pedroSG94__RootEncoder__Other__build.gradle.kts | Full Name: pedroSG94__RootEncoder | CI Platform: Other | Unit: True | Instr: False
# ✅ 0138__YenalyLiew__Han1meViewer__Other__build.gradle.kts | Full Name: YenalyLiew__Han1meViewer | CI Platform: Other | Unit: True | Instr: True
# ✅ 0137__wangchenyan__ponymusic__Other__build.gradle.kts | Full Name: wangchenyan__ponymusic | CI Platform: Other | Unit: False | Instr: False
# ✅ 0135__korlibs__korge__Other__build.gradle.kts | Full Name: korlibs__korge | CI Platform: Other | Unit: True | Instr: False
# ✅ 0133__oshai__kotlin-logging__Other__build.gradle.kts | Full Name: oshai__kotlin-logging | CI Platform: Other | Unit: True | Instr: False
# ✅ 0132__ReVanced__revanced-patcher__Other__build.gradle.kts | Full Name: ReVanced__revanced-patcher | CI Platform: Other | Unit: True | Instr: False
# ✅ 0130__ismartcoding__plain-app__Other__build.gradle.kts | Full Name: ismartcoding__plain-app | CI Platform: Other | Unit: False | Instr: False
# ✅ 0129__adrielcafe__voyager__Other__build.gradle.kts | Full Name: adrielcafe__voyager | CI Platform: Other | Unit: True | Instr: False
# ✅ 0127__Ivy-Apps__ivy-wallet__Other__build.gradle.kts | Full Name: Ivy-Apps__ivy-wallet | CI Platform: Other | Unit: False | Instr: False
# ✅ 0126__BiliRoamingX__BiliRoamingX__Other__build.gradle.kts | Full Name: BiliRoamingX__BiliRoamingX | CI Platform: Other | Unit: False | Instr: False
# ✅ 0124__GuoXiCheng__SKIP__Other__build.gradle.kts | Full Name: GuoXiCheng__SKIP | CI Platform: Other | Unit: True | Instr: True
# ✅ 0123__EhViewer-NekoInverter__EhViewer__Other__build.gradle.kts | Full Name: EhViewer-NekoInverter__EhViewer | CI Platform: Other | Unit: False | Instr: False
# ✅ 0122__joreilly__PeopleInSpace__Other__build.gradle.kts | Full Name: joreilly__PeopleInSpace | CI Platform: Other | Unit: True | Instr: True
# ✅ 0120__FooIbar__EhViewer__Other__build.gradle.kts | Full Name: FooIbar__EhViewer | CI Platform: Other | Unit: True | Instr: True
# ✅ 0119__wuseal__JsonToKotlinClass__Other__build.gradle.kts | Full Name: wuseal__JsonToKotlinClass | CI Platform: Other | Unit: True | Instr: False
# ✅ 0118__MM2-0__Kvaesitso__Other__build.gradle.kts | Full Name: MM2-0__Kvaesitso | CI Platform: Other | Unit: True | Instr: False
# ✅ 0117__jarnedemeulemeester__findroid__Other__build.gradle.kts | Full Name: jarnedemeulemeester__findroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0116__Swordfish90__Lemuroid__Other__build.gradle.kts | Full Name: Swordfish90__Lemuroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0115__JetBrains__kotlinconf-app__Other__build.gradle.kts | Full Name: JetBrains__kotlinconf-app | CI Platform: Other | Unit: False | Instr: False
# ✅ 0114__kosi-libs__Kodein__Other__build.gradle.kts | Full Name: kosi-libs__Kodein | CI Platform: Other | Unit: True | Instr: False
# ✅ 0113__rumboalla__apkupdater__Other__build.gradle.kts | Full Name: rumboalla__apkupdater | CI Platform: Other | Unit: True | Instr: True
# ✅ 0112__DanielMartinus__Konfetti__Other__build.gradle.kts | Full Name: DanielMartinus__Konfetti | CI Platform: Other | Unit: True | Instr: True
# ✅ 0111__raamcosta__compose-destinations__Other__build.gradle.kts | Full Name: raamcosta__compose-destinations | CI Platform: Other | Unit: True | Instr: False
# ✅ 0108__easybangumiorg__EasyBangumi__Other__build.gradle.kts | Full Name: easybangumiorg__EasyBangumi | CI Platform: Other | Unit: False | Instr: False
# ✅ 0106__SmartToolFactory__Jetpack-Compose-Tutorials__Other__build.gradle.kts | Full Name: SmartToolFactory__Jetpack-Compose-Tutorials | CI Platform: Other | Unit: True | Instr: True
# ✅ 0105__jellyfin__jellyfin-androidtv__Other__build.gradle.kts | Full Name: jellyfin__jellyfin-androidtv | CI Platform: Other | Unit: True | Instr: False
# ✅ 0103__maxrave-dev__SimpMusic__Other__build.gradle.kts | Full Name: maxrave-dev__SimpMusic | CI Platform: Other | Unit: True | Instr: True
# ✅ 0102__osfans__trime__Other__build.gradle.kts | Full Name: osfans__trime | CI Platform: Other | Unit: False | Instr: False
# ✅ 0099__Foso__Jetpack-Compose-Playground__Other__build.gradle.kts | Full Name: Foso__Jetpack-Compose-Playground | CI Platform: Other | Unit: True | Instr: True
# ✅ 0097__tommybuonomo__dotsindicator__Other__build.gradle.kts | Full Name: tommybuonomo__dotsindicator | CI Platform: Other | Unit: True | Instr: True
# ✅ 0096__SimpleMobileTools__Simple-Calendar__Other__build.gradle.kts | Full Name: SimpleMobileTools__Simple-Calendar | CI Platform: Other | Unit: False | Instr: False
# ✅ 0095__NeoApplications__Neo-Store__Other__build.gradle.kts | Full Name: NeoApplications__Neo-Store | CI Platform: Other | Unit: False | Instr: False
# ✅ 0094__guolindev__PermissionX__Other__build.gradle.kts | Full Name: guolindev__PermissionX | CI Platform: Other | Unit: False | Instr: False
# ✅ 0091__fcitx5-android__fcitx5-android__Other__build.gradle.kts | Full Name: fcitx5-android__fcitx5-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0090__SimpleMobileTools__Simple-Gallery__Other__build.gradle.kts | Full Name: SimpleMobileTools__Simple-Gallery | CI Platform: Other | Unit: False | Instr: False
# ✅ 0089__aistra0528__Hail__Other__build.gradle.kts | Full Name: aistra0528__Hail | CI Platform: Other | Unit: False | Instr: False
# ✅ 0088__skydoves__chatgpt-android__Other__build.gradle.kts | Full Name: skydoves__chatgpt-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0087__skydoves__Balloon__Other__build.gradle.kts | Full Name: skydoves__Balloon | CI Platform: Other | Unit: False | Instr: False
# ✅ 0084__jing332__tts-server-android__Other__build.gradle.kts | Full Name: jing332__tts-server-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0083__mikepenz__AboutLibraries__Other__build.gradle.kts | Full Name: mikepenz__AboutLibraries | CI Platform: Other | Unit: False | Instr: False
# ✅ 0082__owncloud__android__Other__build.gradle.kts | Full Name: owncloud__android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0080__Dr-TSNG__Hide-My-Applist__Other__build.gradle.kts | Full Name: Dr-TSNG__Hide-My-Applist | CI Platform: Other | Unit: False | Instr: False
# ✅ 0079__dovecoteescapee__ByeDPIAndroid__Other__build.gradle.kts | Full Name: dovecoteescapee__ByeDPIAndroid | CI Platform: Other | Unit: True | Instr: True
# ✅ 0077__Triple-T__gradle-play-publisher__Other__build.gradle.kts | Full Name: Triple-T__gradle-play-publisher | CI Platform: Other | Unit: False | Instr: False
# ✅ 0076__streetcomplete__StreetComplete__Other__build.gradle.kts | Full Name: streetcomplete__StreetComplete | CI Platform: Other | Unit: False | Instr: False
# ✅ 0075__ChuckerTeam__chucker__Other__build.gradle.kts | Full Name: ChuckerTeam__chucker | CI Platform: Other | Unit: True | Instr: True
# ✅ 0074__tasks__tasks__Other__build.gradle.kts | Full Name: tasks__tasks | CI Platform: Other | Unit: True | Instr: False
# ✅ 0072__square__wire__Other__build.gradle.kts | Full Name: square__wire | CI Platform: Other | Unit: False | Instr: False
# ✅ 0071__Mygod__VPNHotspot__Other__build.gradle.kts | Full Name: Mygod__VPNHotspot | CI Platform: Other | Unit: True | Instr: True
# ✅ 0070__simondankelmann__Bluetooth-LE-Spam__Other__build.gradle.kts | Full Name: simondankelmann__Bluetooth-LE-Spam | CI Platform: Other | Unit: True | Instr: False
# ✅ 0068__izhangzhihao__intellij-rainbow-brackets__Other__build.gradle.kts | Full Name: izhangzhihao__intellij-rainbow-brackets | CI Platform: Other | Unit: True | Instr: False
# ✅ 0066__ReVanced__revanced-patches-template__Other__build.gradle.kts | Full Name: ReVanced__revanced-patches-template | CI Platform: Other | Unit: False | Instr: False
# ✅ 0064__kittinunf__fuel__Other__build.gradle.kts | Full Name: kittinunf__fuel | CI Platform: Other | Unit: False | Instr: False
# ✅ 0063__d4rken-org__sdmaid-se__Other__build.gradle.kts | Full Name: d4rken-org__sdmaid-se | CI Platform: Other | Unit: False | Instr: False
# ✅ 0062__android10__Android-CleanArchitecture-Kotlin__Other__build.gradle.kts | Full Name: android10__Android-CleanArchitecture-Kotlin | CI Platform: Other | Unit: True | Instr: True
# ✅ 0059__XayahSuSuSu__Android-DataBackup__Other__build.gradle.kts | Full Name: XayahSuSuSu__Android-DataBackup | CI Platform: Other | Unit: True | Instr: True
# ✅ 0058__Droid-ify__client__Other__build.gradle.kts | Full Name: Droid-ify__client | CI Platform: Other | Unit: True | Instr: True
# ✅ 0057__kizitonwose__Calendar__Other__build.gradle.kts | Full Name: kizitonwose__Calendar | CI Platform: Other | Unit: False | Instr: False
# ✅ 0053__LibChecker__LibChecker__Other__build.gradle.kts | Full Name: LibChecker__LibChecker | CI Platform: Other | Unit: False | Instr: False
# ✅ 0052__z-huang__InnerTune__Other__build.gradle.kts | Full Name: z-huang__InnerTune | CI Platform: Other | Unit: False | Instr: False
# ✅ 0049__SagerNet__SagerNet__Other__build.gradle.kts | Full Name: SagerNet__SagerNet | CI Platform: Other | Unit: False | Instr: False
# ✅ 0046__bmax121__APatch__Other__build.gradle.kts | Full Name: bmax121__APatch | CI Platform: Other | Unit: False | Instr: False
# ✅ 0044__aniyomiorg__aniyomi__Other__build.gradle.kts | Full Name: aniyomiorg__aniyomi | CI Platform: Other | Unit: True | Instr: False
# ✅ 0043__Ashinch__ReadYou__Other__build.gradle.kts | Full Name: Ashinch__ReadYou | CI Platform: Other | Unit: True | Instr: True
# ✅ 0042__facebook__facebook-android-sdk__Other__build.gradle.kts | Full Name: facebook__facebook-android-sdk | CI Platform: Other | Unit: True | Instr: False
# ✅ 0041__ACRA__acra__Other__build.gradle.kts | Full Name: ACRA__acra | CI Platform: Other | Unit: False | Instr: False
# ✅ 0040__Gurupreet__ComposeCookBook__Other__build.gradle.kts | Full Name: Gurupreet__ComposeCookBook | CI Platform: Other | Unit: False | Instr: False
# ✅ 0039__igorwojda__android-showcase__Other__build.gradle.kts | Full Name: igorwojda__android-showcase | CI Platform: Other | Unit: True | Instr: False
# ✅ 0038__chrisbanes__tivi__Other__build.gradle.kts | Full Name: chrisbanes__tivi | CI Platform: Other | Unit: False | Instr: False
# ✅ 0036__florisboard__florisboard__Other__build.gradle.kts | Full Name: florisboard__florisboard | CI Platform: Other | Unit: True | Instr: True
# ✅ 0035__open-ani__animeko__Other__build.gradle.kts | Full Name: open-ani__animeko | CI Platform: Other | Unit: False | Instr: False
# ✅ 0034__bitwarden__android__Other__build.gradle.kts | Full Name: bitwarden__android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0032__recloudstream__cloudstream__Other__build.gradle.kts | Full Name: recloudstream__cloudstream | CI Platform: Other | Unit: False | Instr: False
# ✅ 0030__uber__RIBs__Other__build.gradle.kts | Full Name: uber__RIBs | CI Platform: Other | Unit: False | Instr: False
# ✅ 0029__mobile-dev-inc__Maestro__Other__build.gradle.kts | Full Name: mobile-dev-inc__Maestro | CI Platform: Other | Unit: True | Instr: False
# ✅ 0028__T8RIN__ImageToolbox__Other__build.gradle.kts | Full Name: T8RIN__ImageToolbox | CI Platform: Other | Unit: False | Instr: False
# ✅ 0027__skydoves__Pokedex__Other__build.gradle.kts | Full Name: skydoves__Pokedex | CI Platform: Other | Unit: True | Instr: False
# ✅ 0026__iSoron__uhabits__Other__build.gradle.kts | Full Name: iSoron__uhabits | CI Platform: Other | Unit: True | Instr: False
# ✅ 0025__simplex-chat__simplex-chat__Other__build.gradle.kts | Full Name: simplex-chat__simplex-chat | CI Platform: Other | Unit: False | Instr: False
# ✅ 0024__square__okio__Other__build.gradle.kts | Full Name: square__okio | CI Platform: Other | Unit: True | Instr: False
# ✅ 0023__firebase__quickstart-android__Other__build.gradle.kts | Full Name: firebase__quickstart-android | CI Platform: Other | Unit: True | Instr: True
# ✅ 0022__yairm210__Unciv__Other__build.gradle.kts | Full Name: yairm210__Unciv | CI Platform: Other | Unit: False | Instr: False
# ✅ 0021__vfsfitvnm__ViMusic__Other__build.gradle.kts | Full Name: vfsfitvnm__ViMusic | CI Platform: Other | Unit: True | Instr: False
# ✅ 0020__InsertKoinIO__koin__Other__build.gradle.kts | Full Name: InsertKoinIO__koin | CI Platform: Other | Unit: False | Instr: False
# ✅ 0019__ankidroid__Anki-Android__Other__build.gradle.kts | Full Name: ankidroid__Anki-Android | CI Platform: Other | Unit: True | Instr: False
# ✅ 0018__libre-tube__LibreTube__Other__build.gradle.kts | Full Name: libre-tube__LibreTube | CI Platform: Other | Unit: True | Instr: True
# ✅ 0017__AppIntro__AppIntro__Other__build.gradle.kts | Full Name: AppIntro__AppIntro | CI Platform: Other | Unit: False | Instr: False
# ✅ 0015__Shabinder__SpotiFlyer__Other__build.gradle.kts | Full Name: Shabinder__SpotiFlyer | CI Platform: Other | Unit: False | Instr: False
# ✅ 0014__coil-kt__coil__Other__build.gradle.kts | Full Name: coil-kt__coil | CI Platform: Other | Unit: False | Instr: False
# ✅ 0013__YiiGuxing__TranslationPlugin__Other__build.gradle.kts | Full Name: YiiGuxing__TranslationPlugin | CI Platform: Other | Unit: True | Instr: False
# ✅ 0012__mikepenz__MaterialDrawer__Other__build.gradle.kts | Full Name: mikepenz__MaterialDrawer | CI Platform: Other | Unit: False | Instr: False
# ✅ 0011__thunderbird__thunderbird-android__Other__build.gradle.kts | Full Name: thunderbird__thunderbird-android | CI Platform: Other | Unit: False | Instr: False
# ✅ 0010__tiann__KernelSU__Other__build.gradle.kts | Full Name: tiann__KernelSU | CI Platform: Other | Unit: False | Instr: False
# ✅ 0008__mihonapp__mihon__Other__build.gradle.kts | Full Name: mihonapp__mihon | CI Platform: Other | Unit: False | Instr: False
# ✅ 0007__MatsuriDayo__NekoBoxForAndroid__Other__build.gradle.kts | Full Name: MatsuriDayo__NekoBoxForAndroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0004__android__sunflower__Other__build.gradle.kts | Full Name: android__sunflower | CI Platform: Other | Unit: True | Instr: True
# ✅ 0001__android__nowinandroid__Other__build.gradle.kts | Full Name: android__nowinandroid | CI Platform: Other | Unit: False | Instr: False
# ✅ 0000__JunkFood02__Seal__Other__build.gradle.kts | Full Name: JunkFood02__Seal | CI Platform: Other | Unit: False | Instr: False
# ✅ Saved results to: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone\Analysis Output\7.1-Gradle_List_4th_attempt_ShallowC.csv
