# %%
# detect instrumentation tests in YAML CI files (GitHub Actions, GitLab CI, etc.)
# expands the detection logic to cover more instrumentation test keywords as V2.0
import os
import pandas as pd
import re
import yaml  # pip install pyyaml

# === CONFIG ===
PROJECTS_DIR = r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_31\YAML_Files"
OUTPUT_DIR = r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\July_31"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, "3.1_YML_List_ShallowC.csv")

# === UNIT TEST KEYWORDS ===
UNIT_TEST_KEYWORDS = [
    'gradlew test', './gradlew test','./gradlew jvmtest', 'testdebugunittest', 'testreleaseunittest','kotlintest','unittest',
    'run unit tests', 'run: test', 'npm test', 'yarn test', 'run: flutter test'
]

# === EXTRACT CI PLATFORM FROM FILENAME ===
def detect_ci_platform(file_path):
    filename = os.path.basename(file_path)
    if "__" in filename and "++" in filename:
        try:
            return filename.split("__")[1].split("++")[0]
        except Exception:
            return "Other"
    return "Other"

# === DETECT UNIT TEST ===
def detect_unit_test(yaml_text):
    text = yaml_text.lower()
    return any(kw in text for kw in UNIT_TEST_KEYWORDS)

# === EXTRACT ALL 'run' SCRIPTS FROM YAML ===
def extract_run_scripts(parsed):
    def get_runs(node):
        runs = []
        if isinstance(node, dict):
            for k, v in node.items():
                if k == 'run' and isinstance(v, str):
                    runs.append(v.lower())
                else:
                    runs.extend(get_runs(v))
        elif isinstance(node, list):
            for item in node:
                runs.extend(get_runs(item))
        return runs

    scripts = get_runs(parsed)
    if isinstance(parsed, dict):
        for key in ['script', 'before_script', 'before_install', 'after_script']:
            val = parsed.get(key)
            if isinstance(val, list):
                scripts.extend([str(v).lower() for v in val])
            elif isinstance(val, str):
                scripts.append(val.lower())
    return scripts

# === INSTRUMENTATION TEST DETECTION ===
def detect_instrumentation_by_platform(ci_platform, yaml_text, run_scripts, parsed):
    run_text = "\n".join(run_scripts)
    found = set()
    matched = []

    # === Emulator Setup Detection ===
    has_sdk = any(kw in run_text for kw in ['sdkmanager'])
    has_avd = any(kw in run_text for kw in ['avdmanager'])
    has_emulator = any(kw in run_text for kw in ['emulator'])
    has_create_avd = any(kw in run_text for kw in ['android create avd'])

    # === GitHub Actions-specific logic ===
    if ci_platform.lower() == "github_actions":
        for job in parsed.get('jobs', {}).values():
            for step in job.get('steps', []):
                if isinstance(step, dict) and 'uses' in step:
                    uses = step['uses'].lower()
                    if 'reactivecircus/android-emulator-runner' in uses:
                        found.add('GitHub_emulator_full')
                        matched.append('reactivecircus/android-emulator-runner')
                    if 'malinskiy/action-android/emulator-run-cmd' in uses:
                        found.add('GitHub_emulator_compact')
                        matched.append('malinskiy/action-android/emulator-run-cmd')
                    if any(gmd in uses for gmd in ['cleanmanageddevices', 'managedvirtualdevice', 'manageddevices']):
                        found.add('GitHub_GMD')
                        matched.append('GMD keywords (uses)')

        for s in run_scripts:
            if re.search(r'gradlew.*(managed)?device.*test', s):
                found.add('GitHub_GMD')
                matched.append('GMD test run')

        if (has_sdk or has_avd) and (has_emulator or has_avd):
            if any(re.search(r'(connected.*(test|check)|instrumentation|assemble.*androidtest|run.*instrument.*test|orchestrator|install.*debug)', s) for s in run_scripts):
                found.add('GitHub_emulator_manual')
                matched.append('manual emulator + test run')

    # === Non-GitHub CI: emulator + test detection ===
    elif (has_sdk or has_avd) and (has_emulator or has_avd):
        if any(re.search(r'(connected.*(test|check)|instrumentation|assemble.*androidtest|run.*instrument.*test|orchestrator|install.*debug)', s) for s in run_scripts):
            found.add(f"{ci_platform}_emulator_manual")
            matched.append('manual emulator + test run')

    # === Gradle / CLI test command keywords ===
        COMMON_INSTR_TEST_CMDS = [
    'connectedandroidtest',       # canonical instrumentation test
    'cat',                        # common shorthand alias
    'connectedcheck',             # often used to trigger connected tests
    'assembleandroidtest',        # builds APK for instr tests
    'assembledebugandroidtest',   # more specific variant
    'installdebug',               # install test APK on emulator
    'uninstallall',               # cleanup step for instrumentation
    'am instrument',              # CLI-based instrumentation run
    'connectedflavortest',        # used for flavor-specific connected tests
    'createinstrumentationtestcoveragereport',  # used in coverage pipelines
    'connecteddevicetest',        # alt naming
    'connectedtest',              # often a custom Gradle alias
    'runinstrumentationtests',    # Firebase or wrapper tasks
    'executescreenshottests',     # screenshot instrumentation tests (e.g., Facebook’s screenshot-test)
    'orchestrator'                # commonly used for instrumentation orchestration
]
    COMMON_INSTR_TEST_CMDS = [
        'connectedandroidtest', 'connectedcheck', 'cAT', 'installdebug',
        'uninstallall', 'am instrument', 'assembleandroidtest', 'assembledebugandroidtest',
        'connectedflavortest', 'createinstrumentationtestcoveragereport', 'connecteddevicetest',
        'connectedtest', 'runinstrumentationtests', 'executescreenshottests', 'orchestrator'
    ]
    for cmd in COMMON_INSTR_TEST_CMDS:
        if any(cmd in s.lower() for s in run_scripts):
            found.add('Gradle_Command')
            matched.append(cmd)

    # === Optional exact phrase matches ===
    COMMON_EXACT_CMD_PHRASES = [
        './gradlew connectedandroidtest',
        './gradlew connectedcheck',
        './gradlew assembledebugandroidtest',
        './gradlew installdebug',
        './gradlew createDebugCoverageReport',
        './gradlew runinstrumentationtests',
        'gcloud firebase test android run',
        'am instrument'
    ]
    for exact in COMMON_EXACT_CMD_PHRASES:
        if any(s.strip().lower() == exact for s in run_scripts):
            found.add('Exact_Command')
            matched.append(exact)

    # === Third-party runners ===
    for job in parsed.get('jobs', {}).values():
        for step in job.get('steps', []):
            if isinstance(step, dict) and 'uses' in step:
                uses = step['uses'].lower()
                if 'firebase-test-lab-action' in uses:
                    found.add('Firebase_Compact')
                    matched.append('Firebase-Test-Lab-Action')
                if 'microsoft/appcenter-test-cli-action' in uses:
                    found.add('Appcenter')
                    matched.append('Appcenter Test CLI Action')
                if 'browserstack' in uses:
                    found.add('Browserstack')
                    matched.append('Browserstack action')
                if 'saucelabs/saucectl-run-action' in uses:
                    found.add('SauceLabs')
                    matched.append('Sauce Labs GitHub Action')

    # === CLI-based instrumentation calls ===
    if re.search(r'gcloud.*firebase test android run', run_text):
        found.add('Firebase_Full')
        matched.append('gcloud/firebase CLI command')

    if re.search(r'appcenter test run', run_text):
        found.add('Appcenter')
        matched.append('appcenter CLI command')

    if 'browserstack' in run_text:
        found.add('Browserstack')
        matched.append('browserstack CLI call')

    if 'saucectl' in run_text:
        found.add('SauceLabs')
        matched.append('saucectl CLI')

    return found, matched


# === MAIN PROCESSING LOOP ===
results = []

for root, _, files in os.walk(PROJECTS_DIR):
    for file in files:
        if file.endswith(('.yml', '.yaml')):
            file_path = os.path.join(root, file)
            filename = os.path.basename(file_path)

            if "__" in filename:
                full_name = filename.split("__")[0]
            else:
                full_name = filename

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    raw = f.read().replace('\t', ' ')
                    ci_platform = detect_ci_platform(file_path)

                    parsed = yaml.safe_load(raw) or {}
                    run_scripts = extract_run_scripts(parsed)

                    is_unit = detect_unit_test(raw)
                    instr_types, matched_keys = detect_instrumentation_by_platform(
                        ci_platform, raw, run_scripts, parsed
                    )

                    results.append({
                        'filename': filename,
                        'full_name': full_name,
                        'ci_platform': ci_platform,
                        'test_type': ', '.join(sorted(instr_types)),
                        'unit_test': is_unit,
                        'instrumentation_test': bool(instr_types),
                        'matched_keywords': ', '.join(sorted(set(map(str.strip, matched_keys))))
                    })

                    print(f"✅ {filename} | CI: {ci_platform} | Unit: {is_unit} | Instr: {bool(instr_types)} | Keys: {matched_keys}")

            except Exception as e:
                print(f"❌ ERROR: {file_path} => {e}")
                results.append({
                    'filename': filename,
                    'full_name': full_name,
                    'ci_platform': 'Error',
                    'test_type': '',
                    'unit_test': False,
                    'instrumentation_test': False,
                    'matched_keywords': ''
                })

# === EXPORT RESULTS ===
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ DONE! CSV generated at: {OUTPUT_CSV}")
# Out:
# ✅ 0niel.university-app__GitHub_Actions++example.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++main.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++permission_client.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++persistent_storage.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++schedule_api_client.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++secure_storage.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++shorebird-release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0niel.university-app__GitHub_Actions++storage.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x4f53.Wristkey__GitHub_Actions++build-release-apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3-mono-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3-mono-ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3-mono-linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3-mono-macos.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3-mono-windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3a-mono-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3a-mono-ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3a-mono-linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3a-mono-macos.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0x7c13.Pal3.Unity__GitHub_Actions++build-pal3a-mono-windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0xf104a.NextcloudServices__GitHub_Actions++gradle.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 0xZhangKe.Fread__GitHub_Actions++build_apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 0xZhangKe.Fread__GitHub_Actions++check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-android__GitHub_Actions++roomkit-publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++firstinteraction.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++ktlint.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++stale.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++swiftlint.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 100mslive.100ms-flutter__GitHub_Actions++vale.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 10miaomiao.bili-down-out__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 10miaomiao.bilimiao2__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1250422131.BiliVideoTunes__GitHub_Actions++flutter.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 1596941391qq.pokerogue-android__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1596941391qq.pokerogue-android__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1gravity.Android-ContactPicker__GitHub_Actions++publish_google_play.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1gravity.Android-ContactPicker__GitHub_Actions++publish_maven.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1hbb.react-native-instagram-clone__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 1q23lyc45.KitsuneMagisk__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++android_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++ios_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++linux_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++macos_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++publish_release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 1runeberg.confichat__GitHub_Actions++windows_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2002Bishwajeet.no_signal__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2002Bishwajeet.no_signal__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 2003scape.rsc-c__AppVeyor++appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ✅ 2003scape.rsc-c__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 2468785842.krkr2__GitHub_Actions++build-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2468785842.krkr2__GitHub_Actions++build-linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2468785842.krkr2__GitHub_Actions++build-windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2468785842.krkr2__GitHub_Actions++code-format-check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2754LM.oj_helper__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++build-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++build-ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++codeql-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++deploy-cms.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++deploy-functions.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++deploy-revopush.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++deploy-web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++pull_requests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 29ki.29k__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 2BAB.Koncat__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 2BAB.Koncat__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2d-inc.developer_quest__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ 2dust.v2rayNG__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2dust.v2rayNG__GitHub_Actions++fastlane.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 2dxgujun.AndroidTagGroup__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 3003h.Eros-FE__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 360Conferences.chicago-roboto__Circle_CI++circle.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ 3zpnix.WriteOn__GitHub_Actions++debug_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 3zpnix.WriteOn__GitHub_Actions++nightly_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 3zpnix.WriteOn__GitHub_Actions++release_build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 452.USBHIDTerminal__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 4accccc.vivo-Magisk-suu__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 4eRTuk.audioview__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 4o3F.Ascent__GitHub_Actions++github-releases-to-discord.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 4Q-s-r-o.ota_update__GitHub_Actions++on_push.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 4Q-s-r-o.ota_update__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 4seer.openflutterecommerceapp__GitHub_Actions++dart.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 5ec1cff.KsuWebUIStandalone__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 5ec1cff.MyInjector__GitHub_Actions++build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 5GSD.AIMSICDL__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 5hmlA.JPagerSlidingTabStrip__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 6c65726f79.Transmissionic__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 6c65726f79.Transmissionic__GitHub_Actions++codeql-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 6c65726f79.Transmissionic__GitHub_Actions++no-response.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 6eero.NewPass__GitHub_Actions++debugcompile.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 6thsolution.ApexNLP__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 709924470.FanboxViewer__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 709924470.FanboxViewer__GitHub_Actions++apk.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ 781flyingdutchman.background_downloader__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 781flyingdutchman.background_downloader__GitHub_Actions++issue-metrics.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 781flyingdutchman.background_downloader__GitHub_Actions++stale.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 7heaven.SHSegmentControl__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 7heaven.SHSwitchView__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 8enet.AppOpsX__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 8tory.json2notification__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++bump-version.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++codecheck.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++codecov.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++codeql-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++dependabot-auto-merge.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++extract-version.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++manual_rc.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++matrix-discussion.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++matrix-issues.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++matrix-notify.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++matrix-release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++maxtrix-pr.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++merged-pull-request.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++pr-artifact-comment.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++pr-conventionalcommit.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++pr-test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++private-fdroid-repo.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++promote.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++publish.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++update-schemas.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 8VIM.8VIM__GitHub_Actions++wiki.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ 99Taxis.RxPlaces__Travis_CI++.travis.yml | CI: Travis_CI | Unit: True | Instr: False | Keys: []
# ✅ a-ghorbani.pocketpal-ai__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ a-ghorbani.pocketpal-ai__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a-mabe.OpenHIIT__GitHub_Actions++integration_tests.yaml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ a-mabe.OpenHIIT__GitHub_Actions++nightly_build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a-mabe.OpenHIIT__GitHub_Actions++pre_release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a-mabe.OpenHIIT__GitHub_Actions++pre_release_discussion.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a-mabe.OpenHIIT__GitHub_Actions++release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a-pavlov.jed2k__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ a-tarasyuk.create-rx-app__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ❌ ERROR: C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_31\YAML_Files\a1studmuffin.Cataclysm-DDA-Android__Travis_CI++.travis.yml => found duplicate anchor 'gcc48'; first occurrence
#   in "<unicode string>", line 51, column 15:
#           addons: &gcc48
#                   ^
# second occurrence
#   in "<unicode string>", line 59, column 15:
#           addons: &gcc48
#                   ^
# ✅ a7medev.react-native-prevent-screenshots__GitHub_Actions++npm-publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a914-gowtham.android-video-trimmer__GitHub_Actions++maven-publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ a914-gowtham.android-video-trimmer__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ a914-gowtham.compose-ratingbar__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: True | Keys: ['connectedandroidtest', './gradlew connectedandroidtest']
# ✅ aaa1115910.bv__GitHub_Actions++alpha.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aaa1115910.bv__GitHub_Actions++alpha_build_manually_without_sign.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aaa1115910.bv__GitHub_Actions++auto_close_issues.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aaa1115910.bv__GitHub_Actions++close_inactive_issues.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aaa1115910.bv__GitHub_Actions++features.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aaa1115910.bv__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aabhasr1.OtpView__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ AAkira.ExpandableLayout__Circle_CI++circle.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ aarcangeli.Serious-Sam-Android__AppVeyor++appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++batch_close_issues.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++bug_greetings.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++dart.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++extension-issue-handling.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++feature_greetings.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++handle_extension_issue.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++pr_greetings.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aayush2622.Dartotsu__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abarisain.dmix__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ abdallahmehiz.mpvKt__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdallahmehiz.mpvKt__GitHub_Actions++nightlies.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdallahmehiz.mpvKt__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++build_debug_variant.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++build_release_variant.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++codacy_security_scan.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++codeql_security_scan.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++publish_release_by_tag.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdalmoniem.Caffeinate__GitHub_Actions++publish_release_on_tag.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.flutter_meedu_videoplayer__GitHub_Actions++build_cross_platform.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.flutter_meedu_videoplayer__GitHub_Actions++build_demo.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.flutter_meedu_videoplayer__GitHub_Actions++dart_fix.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.flutter_meedu_videoplayer__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.pytorch_lite__GitHub_Actions++build_cross_platform.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abdelaziz-mahdy.pytorch_lite__GitHub_Actions++integration_tests.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ abdelaziz-mahdy.pytorch_lite__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abertschi.ad-free__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abertschi.water-me__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ abhi16180.photon__GitHub_Actions++nightly.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AbhinayMe.currency-edittext__Azure_Pipelines++azure-pipelines.yml | CI: Azure_Pipelines | Unit: False | Instr: False | Keys: []
# ✅ AbhinayMe.currency-edittext__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ ably.ably-flutter__GitHub_Actions++check.yaml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ ably.ably-flutter__GitHub_Actions++docs.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ably.ably-flutter__GitHub_Actions++features.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ably.ably-flutter__GitHub_Actions++flutter_example_app.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ably.ably-flutter__GitHub_Actions++flutter_integration.yaml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ ably.ably-flutter__GitHub_Actions++release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Abonaventure.ORB_SLAM3_AR-for-Android__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ✅ abrensch.brouter__GitHub_Actions++docker-publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abrensch.brouter__GitHub_Actions++gradle-publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abrensch.brouter__GitHub_Actions++gradle.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Abror96.CustomPhoneDialer__GitHub_Actions++gradle.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abualgait.MovieApp__GitHub_Actions++android-ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abuanwar072.EV-Car-Dashboard-Flutter__GitHub_Actions++web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abuanwar072.Responsive-Blog-Theme-using-Flutter__GitHub_Actions++web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ abuanwar072.Welcome-Login-Signup-Page-Flutter__GitHub_Actions++web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ accrescent.accrescent__GitHub_Actions++build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ accrescent.accrescent__GitHub_Actions++bump-timestamp.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AceDroidX.frp-Android__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acefalobi.android-stepper__GitHub_Actions++android_build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ AChep.15puzzle__GitHub_Actions++flutter.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AChep.AcDisplay__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: True | Keys: ['connectedcheck', './gradlew connectedcheck']
# ✅ AChep.HeadsUp__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ AChep.PocketMode__GitHub_Actions++crowdin.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AChep.PocketMode__GitHub_Actions++deploy.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AChep.PocketMode__GitHub_Actions++detect.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AChep.PocketMode__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ACINQ.phoenix__GitHub_Actions++testnet-build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aclassen.ComposeReorderable__GitHub_Actions++pull-request.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acmerobotics.road-runner__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acmerobotics.road-runner__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++build-app.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++build-changelog.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++build-docs.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-changelog.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-docs.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-flutter-integration-tests.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ acterglobal.a3__GitHub_Actions++check-flutter-unittest.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-native.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-rust-integration-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++check-styles.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++deploy-demo.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++deploy-docs.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++deploy-nightly.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++deploy-release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ acterglobal.a3__GitHub_Actions++update-translations.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ActivityWatch.aw-android__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ad-on-is.odin-tv__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adafruit.Bluefruit_LE_Connect_Android_V2__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++capacitor-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++deweb.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++electron-linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++electron-mac.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++electron-windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++github-pages.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++preview-teardown.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++preview.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adamant-im.adamant-im__GitHub_Actions++pwa-testnet.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdamGold.Dryvo-App__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: True | Instr: False | Keys: []
# ✅ AdamMc331.AndroidStudyGuide__GitHub_Actions++android_build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ AdamMc331.AndroidStudyGuide__GitHub_Actions++android_ui_tests.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ AdamMc331.AndroidStudyGuide__GitHub_Actions++danger_checks.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdAway.AdAway__GitHub_Actions++android-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdAway.AdAway__GitHub_Actions++android-ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ AdAway.AdAway__GitHub_Actions++android-locale-check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdAway.AdAway__GitHub_Actions++issues-checker.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeekshith.watomatic__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ adeekshith.watomatic__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.Classipod__GitHub_Actions++build-and-deploy.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.Classipod__GitHub_Actions++pr-checker.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.FlutterMarkdownEditor__GitHub_Actions++build-and-deploy.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.FlutterMarkdownEditor__GitHub_Actions++pr-checker.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.FontGallery__GitHub_Actions++build-and-deploy.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adeeteya.FontGallery__GitHub_Actions++pr-checker.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdevintaSpain.Barista__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ AdevintaSpain.Barista__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adibfara.WatchTower__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++android-play-store.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++android.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++macos.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++test.yaml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++web.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adil192.ricochlime__GitHub_Actions++windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Aditprayogo.GithubUsers__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ adityadroid.Messio__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ AdityaMulgundkar.flutter_opencv__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ admob-plus.admob-plus__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ AdNotFound.EhViewer__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AdNotFound.EhViewer__GitHub_Actions++releases.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adonespitogo.AdoBot__GitHub_Actions++android-build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adorsys.secure-storage-android__GitHub_Actions++pull_request.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ adorsys.secure-storage-android__GitHub_Actions++push.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adorsys.secure-storage-android__GitHub_Actions++tag.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ adrcotfas.goodtime__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ adrianblancode.Cheddar__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adrianblancode.Cheddar__GitHub_Actions++tests.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++assign_author_to_issue.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++assign_pull_requests_author.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++generate_daily_snapshot.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++lint_pr_title.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++promote_alpha_to_production_20.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++promote_internal_to_alpha.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++promote_production_100.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++publish_firebase_app_distribution.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adriangl.pict2cam__GitHub_Actions++validate_pr.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adrielcafe.satchel__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adrielcafe.voyager__GitHub_Actions++build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adrielcafe.voyager__GitHub_Actions++docs-publish.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ adrielcafe.voyager__GitHub_Actions++release.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adventech.sabbath-school-android__GitHub_Actions++labels.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adventech.sabbath-school-android__GitHub_Actions++on_publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adventech.sabbath-school-android__GitHub_Actions++on_push.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ Adventech.sabbath-school-android__GitHub_Actions++pull_request.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Adventech.sabbath-school-android__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ advplyr.audiobookshelf-app__GitHub_Actions++build-apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ advplyr.audiobookshelf-app__GitHub_Actions++close-issues-on-release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ advplyr.audiobookshelf-app__GitHub_Actions++close_blank_issues.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ advplyr.audiobookshelf-app__GitHub_Actions++deploy-apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ advplyr.audiobookshelf-app__GitHub_Actions++i18n-check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AEFeinstein.mtg-familiar__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Aefyr.SAI__GitHub_Actions++stale.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aelassas.wexflow__Azure_Pipelines++azure-pipelines.yml | CI: Azure_Pipelines | Unit: False | Instr: False | Keys: []
# ✅ aelassas.wexflow__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aelassas.wexflow__GitHub_Actions++ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aelassas.wexflow__GitHub_Actions++loc.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aerys.minko__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ✅ aerys.minko__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ AfigAliyev.Cinemax__GitHub_Actions++cinemax-ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ afoxer-com.rsbind__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ afoxer-com.rsbind__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ ag2s20150909.TTS__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ag2s20150909.TTS__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ agateau.pixelwheels__GitHub_Actions++changelog-check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ agateau.pixelwheels__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ agersant.polaris-android__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ agersant.polaris-android__GitHub_Actions++promote_beta_to_production.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ agersant.polaris-android__GitHub_Actions++release_to_beta.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ agoda-com.ninjato__Circle_CI++config.yml | CI: Circle_CI | Unit: True | Instr: False | Keys: []
# ✅ agoldis.react-native-mlkit-ocr__Circle_CI++config.yml | CI: Circle_CI | Unit: True | Instr: False | Keys: []
# ✅ AgoraDesk-LocalMonero.agoradesk-app-foss__GitHub_Actions++build_from_tags_ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AgoraIO-Usecase.agora-ent-scenarios__GitHub_Actions++gitee-sync.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ❌ ERROR: C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_31\YAML_Files\AgoraIO-Usecase.Chatroom__Azure_Pipelines++azure-pipelines.yml => 'list' object has no attribute 'values'
# ✅ AgoraIO.Basic-Video-Broadcasting__AppVeyor++appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ❌ ERROR: C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_31\YAML_Files\AgoraIO.Basic-Video-Broadcasting__Azure_Pipelines++azure-pipelines.yml => 'list' object has no attribute 'values'
# ✅ agrawalsuneet.LoadersPack-Android__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ Ahmadre.FlutterIconPicker__GitHub_Actions++dart.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AhmedAbdoElhawary.image_picker_plus__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AhmedLSayed9.deliverzler__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ aidanmcb1.Citra__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aidanmcb1.Citra__GitHub_Actions++format.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aidanmcb1.Citra__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aidanmcb1.Citra__GitHub_Actions++transifex.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ailabstw.social-distancing-android__GitHub_Actions++build.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ailiwean.NBZxing__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ ailiwean.NBZxing__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ aimardcr.APKKiller__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aimok04.kitshn__GitHub_Actions++nightly.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aimok04.kitshn__GitHub_Actions++web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aint.laverna-android__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ airbnb.AirMapView__GitHub_Actions++build_test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airbnb.AirMapView__GitHub_Actions++deploy_snapshot.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airbnb.mavericks__GitHub_Actions++automated_github_release.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ airbnb.mavericks__GitHub_Actions++build_test.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ airbnb.mavericks__GitHub_Actions++deploy_snapshot.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airbnb.paris__GitHub_Actions++build_test.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ airbnb.RxGroups__GitHub_Actions++build_test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airbnb.RxGroups__GitHub_Actions++deploy_snapshot.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airgap-it.airgap-vault__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airgap-it.airgap-vault__GitHub_Actions++netflify.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airgap-it.airgap-vault__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: True | Instr: False | Keys: []
# ✅ airgap-it.airgap-wallet__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ airgap-it.airgap-wallet__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ✅ aistra0528.Hail__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aivanovski.keepassvault__GitHub_Actions++pipeline.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aivanovski.keepassvault__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aiyakuaile.easy_tv_live__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aizuzi.FastAdapter__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++labeler.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++latest.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++new_release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++share.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ aj3423.SpamBlocker__GitHub_Actions++upgrade_directly____no_need_to_uninstall_the_previous_version.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ajay-dewari.FloatingActionButton-Menu__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ajitsing.ExpenseManager__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ ajitsing.Sherlock__Travis_CI++.travis.yml | CI: Travis_CI | Unit: True | Instr: False | Keys: []
# ✅ ajnas.WiFiPS__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ Akaflieg-Freiburg.enroute__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Akaflieg-Freiburg.enroute__GitHub_Actions++api.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Akaflieg-Freiburg.enroute__GitHub_Actions++ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Akaflieg-Freiburg.enroute__GitHub_Actions++linux.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Akaflieg-Freiburg.enroute__GitHub_Actions++macos.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akaMrNagar.Mindful__GitHub_Actions++build_and_deploy.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akaMrNagar.Mindful__GitHub_Actions++download_translations_from_crowdin.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akaMrNagar.Mindful__GitHub_Actions++upload_sources_to_crowdin.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akexorcist.RoundCornerProgressBar__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akexorcist.ruam-mij-android__GitHub_Actions++bump-version.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akexorcist.ruam-mij-android__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akexorcist.ruam-mij-android__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akexorcist.ruam-mij-android__GitHub_Actions++snapshot_test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akexorcist.ruam-mij-android__GitHub_Actions++update-gradle.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akexorcist.SnapTimePicker__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akhilesh0707.Rick-and-Morty__GitHub_Actions++android_build.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akiomik.seiun__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akiomik.seiun__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akitikkx.upnext__GitHub_Actions++pull_request.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ akoufa.CoolWeather__Circle_CI++config.yml | CI: Circle_CI | Unit: True | Instr: False | Keys: []
# ✅ akshaaatt.Google-IAP__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ akshay2211.Oblique__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ akshay2211.PixImagePicker__GitHub_Actions++android ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AkshayChordiya.News__GitHub_Actions++build-workflow.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ Akylas.oss-weather__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ alan-eu.react-native-fast-shadow__Circle_CI++config.yml | CI: Circle_CI | Unit: True | Instr: False | Keys: []
# ✅ alan-eu.react-native-fast-shadow__GitHub_Actions++publish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ AlanCheen.Flap__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ alanlgoncalves.pokedex__GitHub_Actions++ci-cd.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ alanlgoncalves.pokedex__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ alanlgoncalves.pokedex__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ alann-maulana.flutter_beacon__GitHub_Actions++coverage-report.yaml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ alann-maulana.flutter_beacon__GitHub_Actions++flutter.yaml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ alann-maulana.flutter_beacon__GitHub_Actions++pub-publish-test.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ alann-maulana.flutter_beacon__GitHub_Actions++pub-publish.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ alariej.quadrix__GitHub_Actions++main.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ alashow.datmusic-android__Bitrise++bitrise.yml | CI: Bitrise | Unit: False | Instr: False | Keys: []
# ✅ alashow.datmusic-android__GitHub_Actions++android-pr.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ alashow.datmusic-android__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ albbus-stack.t5.rs__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ albbus-stack.t5.rs__GitHub_Actions++build-api.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ albbus-stack.t5.rs__GitHub_Actions++build-web.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ...
# ✅ zeshuaro.appainter__GitHub_Actions++pull-request-target.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zeshuaro.appainter__GitHub_Actions++pull-request.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zeshuaro.appainter__GitHub_Actions++scheduled.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zetavg.Inventory__GitHub_Actions++build_app.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zetavg.Inventory__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ zetavg.Inventory__GitHub_Actions++lint.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zetavg.Inventory__GitHub_Actions++pr_greetings.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zetbaitsu.Compressor__Travis_CI++.travis.yml | CI: Travis_CI | Unit: True | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++build-android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++lint.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++prettier.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++telegram.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZeusLN.zeus__GitHub_Actions++tsc.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zfdang.Android-Touch-Helper__GitHub_Actions++build_apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zfdang.zSMTH-Android__GitHub_Actions++build_apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zfdang.zSMTH-Android__GitHub_Actions++publisher_to_play.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhanghai.AndroidFastScroll__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhanghai.BeeShell__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhanghai.MaterialFiles__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhanghai.TextSelectionWebSearch__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhanghai.Untracker__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhenghaoz.MaterialWeCenter__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zhihulite.Hydrogen__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhkrb.Iwara-android-client__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__AppVeyor++.appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++bit32-multi-arch-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++compat53-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++ios.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++macos.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__GitHub_Actions++windows.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zhongfq.cocos-lua__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zhouchaoyuan.excelPanel__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhouWeikuan.DouDiZhu__AppVeyor++.appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ✅ zhpanvip.LockView__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zhuinden.live-event__Circle_CI++circle.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++auto-merge.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++cargo-ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++cliff.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++flutter-ci.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++issue.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++label-pr.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZhuJHua.moodiary__GitHub_Actions++telegram-bot.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zilianliuxue.AndroidStudy__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++android-tests.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zimly.zimly-backup__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++play-store-listing.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++release-alpha.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++release-production.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++repo-aws-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++repo-garage-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++repo-linode-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++repo-minio-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zimly.zimly-backup__GitHub_Actions++repo-tencent-tests.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++codcoverage.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++release_dart.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++release_flutter.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++release_packages.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zino-hofmann.graphql-flutter__GitHub_Actions++test.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zjyzip.AdClose__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zkmopro.mopro__GitHub_Actions++build-and-test.yml | CI: GitHub_Actions | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zlgopen.awtk__AppVeyor++appveyor.yml | CI: AppVeyor | Unit: False | Instr: False | Keys: []
# ✅ zlgopen.awtk__GitHub_Actions++codeql.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zlgopen.awtk__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zly2006.zhihu-plus-plus__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zly2006.zhihu-plus-plus__GitHub_Actions++my-build-action.yml | CI: GitHub_Actions | Unit: True | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__Circle_CI++config.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++app_startup.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++bobtests_linux.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++change_log.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++codeql.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++compile.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_androidjdbc_jni.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_ffmpeg.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_iocipher_jni.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_libsodium.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_libvpx.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_opus.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_sorma2.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_sqlite_jdbc.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_toxcore_jni.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++dep_x264.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++maven_package.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++screenshot_tests.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++tests_export_import_linux.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitHub_Actions++tests_linux.yml | CI: GitHub_Actions | Unit: False | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ zoff99.ToxAndroidRefImpl__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ✅ Zomato.sushi-ui-android__GitHub_Actions++devchecker.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zomato.sushi-ui-android__GitHub_Actions++libversionbump.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zomato.sushi-ui-android__GitHub_Actions++packagepublish.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zonble.flutter_platform_alert__GitHub_Actions++ci.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zonble.flutter_platform_alert__GitHub_Actions++ci_spm.yaml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZorinOS.zorin-connect-android__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ✅ zotero.zotero-android__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zoxc.crusader__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zoxc.crusader__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zs9024.UnityRTC__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zsakvo.Clash-Fudge__GitHub_Actions++test-package.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zserge.log__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zsmb13.MaterialDrawerKt__GitLab++.gitlab-ci.yml | CI: GitLab | Unit: False | Instr: False | Keys: []
# ❌ ERROR: C:\Android Mobile App\Step2_Clone_Repo\Type_1\July_31\YAML_Files\zsmb13.MaterialDrawerKt__Travis_CI++.travis.yml => while parsing a block mapping
#   in "<unicode string>", line 15, column 2:
#      global:
#      ^
# expected <block end>, but found '-'
#   in "<unicode string>", line 17, column 2:
#      - EMULATOR_API=21
#      ^
# ✅ zsoltk.compose-router__GitHub_Actions++gradle.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zsoltk.GameOfLife__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zsoltk.overpasser__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zsqw123.QQ-Exp-Android__GitHub_Actions++debugci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.compose-pdf__GitHub_Actions++check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.compose-pdf__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.compose-pipette__GitHub_Actions++check.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.compose-pipette__GitHub_Actions++pages.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.compose-pipette__GitHub_Actions++release.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.Hyperion__GitHub_Actions++build.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.Hyperion__GitHub_Actions++pr.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zt64.Hyperion__GitHub_Actions++sync-crowdin.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ ZTFtrue.MonsterMusic__GitHub_Actions++android.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zugaldia.android-robocar__Circle_CI++circle.yml | CI: Circle_CI | Unit: False | Instr: False | Keys: []
# ✅ zulip.zulip-mobile__GitHub_Actions++ci.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zverik.every_door__GitHub_Actions++build-apk.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zverik.every_door__GitHub_Actions++fdroid.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ Zweihui.Aurora__Travis_CI++.travis.yml | CI: Travis_CI | Unit: False | Instr: False | Keys: []
# ✅ zxing.zxing__GitHub_Actions++codeql-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zxing.zxing__GitHub_Actions++test_java_17.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zxing.zxing__GitHub_Actions++test_java_21.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zxing.zxing__GitHub_Actions++test_java_8.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++canary.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++code-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++fastlane-changelogs-analysis.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++i18n-summary.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++nightly.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++stable.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
# ✅ zyrouge.symphony__GitHub_Actions++website.yml | CI: GitHub_Actions | Unit: False | Instr: False | Keys: []
#
# ✅ DONE! CSV generated at: C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\July_31\3.1_YML_List_ShallowC.csv
