# %%
## detecting the local yaml files
# change from V1 to V2: saves the action yamls in a subfolder "actions".

# %%
# -*- coding: utf-8 -*-
from __future__ import annotations

import csv
import os
import re
import shutil
import stat
import subprocess
import time
from dataclasses import dataclass, field
from pathlib import Path
from typing import Dict, Optional, Set
from urllib.parse import urlparse

import pandas as pd
import requests
from dotenv import load_dotenv

# ========= CONFIG & PATHS =========

# Your env file location (as you stated)
ENV_DIR = Path(r"C:\GitHub\Android-Mobile-Apps")
ENV_FILE_NAME = "All_Tokens.env"  # keep this exact filename

# Cutoff date (ISO 8601, UTC)
CUTOFF_ISO = "2025-08-10T23:59:59Z"

# Base RQ1 directory
BASE_RQ1 = Path(r"D:")

# URL list for all repos
URL_LIST_CSV = Path(r"D:\URL_List.csv")

# Local instrumentation detection results
LOCAL_INSTRU_DIR = BASE_RQ1 / "Local_Instru_Tests"
LOCAL_NON_WORKFLOW_CSV = LOCAL_INSTRU_DIR / "Repos_with_Local_GHA_Actions_NON_WORKFLOW.csv"

# TEMP git dirs per repo (no checkout)
CLONE_DIR = LOCAL_INSTRU_DIR / "Local_Cloned_Repos"

# === NEW: where we store extracted local action YAML files for parsing ===
# Layout: D:\All_Action_YMLs\<owner_repo_key>\<relative_path_inside_repo>
# Example: owner_repo_key = "owner.repo", relative_path = ".github/actions/my-action/action.yml"
# => D:\All_Action_YMLs\owner.repo\.github\actions\my-action\action.yml
OUTPUT_YML_DIR = Path(r"D:\All_Action_YMLs")

# Index CSV describing extracted local YAMLs (kept under Local_Instru_Tests)
LOCAL_INDEX_CSV = LOCAL_INSTRU_DIR / "Local_YML_Extraction_Index.csv"

# Whether to keep temp git dirs after extraction
KEEP_CLONES = False

# --- GitHub API behavior ---
REQUEST_TIMEOUT_SECONDS = 30

# If tokens are rate-limited, do you want to WAIT until reset?
# For your use-case, default False so we just fall back to HEAD and continue extraction.
WAIT_FOR_RATE_LIMIT_RESET = False

# Secondary limit backoff (short, bounded)
SECONDARY_BACKOFF_BASE_SECONDS = 10
SECONDARY_BACKOFF_MAX_SECONDS = 90
MAX_SECONDARY_RETRIES_PER_CALL = 3
MAX_TOTAL_API_ATTEMPTS_PER_CALL = 50

# Git on Windows
GIT_PREFIX = ["git", "-c", "core.longpaths=true"]


# ========= subprocess helpers =========

def run_text(cmd, cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    """Run a command and capture stdout+stderr as text, safely decoded."""
    return subprocess.run(
        cmd,
        cwd=str(cwd) if cwd else None,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        check=check,
    )

def run_bytes(cmd, cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    """Run a command and capture stdout+stderr as bytes."""
    return subprocess.run(
        cmd,
        cwd=str(cwd) if cwd else None,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=False,
        check=check,
    )

def force_remove_readonly(func, path, _):
    os.chmod(path, stat.S_IWRITE)
    func(path)

def sanitize_token(s: str) -> str:
    return re.sub(r"[^a-z0-9._+-]", "_", s.lower())

def split_stem_and_suffixes(name: str):
    p = Path(name)
    suffixes = "".join(p.suffixes)
    if suffixes:
        return name[:-len(suffixes)], suffixes
    return name, ""

def _counter_candidate(base_name: str, n: int) -> str:
    if n == 1:
        return base_name
    if "++" in base_name:
        head, tail = base_name.split("++", 1)
        tail_stem, tail_suf = split_stem_and_suffixes(tail)
        return f"{head}++{tail_stem}__{n}{tail_suf}"
    stem, suf = split_stem_and_suffixes(base_name)
    return f"{stem}__{n}{suf}"

def resolve_counter_name(bucket_dir: Path, base_name: str, in_memory_taken: Set[str]) -> str:
    n = 1
    while True:
        candidate = _counter_candidate(base_name, n)
        if candidate not in in_memory_taken and not (bucket_dir / candidate).exists():
            in_memory_taken.add(candidate)
            return candidate
        n += 1

def make_flat_filename(owner: str, project: str, ci_platform: str, file_name: str) -> str:
    owner_tok = sanitize_token(owner)
    project_tok = sanitize_token(project)
    ci_tok = sanitize_token(ci_platform or "other")
    file_lower = file_name.lower()
    return f"{owner_tok}.{project_tok}__{ci_tok}++{file_lower}"

def save_bytes(bucket_dir: Path, flat_filename: str, content: bytes, in_memory_taken: Set[str]) -> Path:
    bucket_dir.mkdir(parents=True, exist_ok=True)
    final_name = resolve_counter_name(bucket_dir, flat_filename, in_memory_taken)
    dest = bucket_dir / final_name
    dest.write_bytes(content)
    return dest


# ========= branch detection =========

def detect_default_branch(repo_url: str) -> str:
    try:
        out = run_text(GIT_PREFIX + ["ls-remote", "--symref", repo_url, "HEAD"]).stdout
        for line in out.splitlines():
            s = line.strip()
            if s.startswith("ref: ") and s.endswith("HEAD"):
                ref = s.split()[1]  # refs/heads/main
                if ref.startswith("refs/heads/"):
                    return ref.split("/", 2)[2]
    except Exception:
        pass

    for guess in ("main", "master"):
        try:
            run_text(GIT_PREFIX + ["ls-remote", repo_url, f"refs/heads/{guess}"], check=True)
            return guess
        except Exception:
            continue

    raise RuntimeError("Could not determine default branch via git ls-remote")


# ========= load tokens (notebook + script safe) =========

def find_env_file(env_dir: Path, env_filename: str) -> Path:
    """
    Try these locations (in order):
      1) ENV_DIR/env_filename (your stated location)
      2) cwd/env_filename
      3) BASE_RQ1/env_filename
      4) parents of cwd (up to 5 levels)
      5) script directory (if available)
    """
    candidates: list[Path] = []

    candidates.append(env_dir / env_filename)
    candidates.append(Path.cwd() / env_filename)
    candidates.append(BASE_RQ1 / env_filename)

    # walk up cwd a bit (helpful in notebooks)
    cur = Path.cwd()
    for _ in range(5):
        candidates.append(cur / env_filename)
        if cur.parent == cur:
            break
        cur = cur.parent

    # script dir (if running as a script)
    try:
        script_dir = Path(__file__).resolve().parent  # type: ignore[name-defined]
        candidates.append(script_dir / env_filename)
    except NameError:
        pass

    env_path = next((p for p in candidates if p.exists()), None)
    if env_path is None:
        raise FileNotFoundError(
            f"Could not find env file '{env_filename}'. Tried:\n" +
            "\n".join(f"  {p}" for p in candidates)
        )
    return env_path

def load_tokens(env_dir: Path, env_filename: str) -> list[str]:
    env_path = find_env_file(env_dir, env_filename)
    load_dotenv(dotenv_path=str(env_path), override=True)

    tokens: list[str] = []
    for i in range(1, 50):
        t = os.getenv(f"GITHUB_TOKEN_{i}")
        if t:
            tokens.append(t.strip())
    return tokens


TOKENS = load_tokens(ENV_DIR, ENV_FILE_NAME)


# ========= GitHub API: rotation + backoff =========

GITHUB_API_BASE_HEADERS = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28",
}

@dataclass
class TokenState:
    remaining: Optional[int] = None
    reset_epoch: Optional[int] = None
    disabled: bool = False

@dataclass
class TokenPool:
    tokens: list[str]
    idx: int = 0
    state: Dict[str, TokenState] = field(default_factory=dict)

    def __post_init__(self):
        for t in self.tokens:
            self.state.setdefault(t, TokenState())

    def _is_usable(self, token: str) -> bool:
        st = self.state[token]
        if st.disabled:
            return False
        now = int(time.time())
        if st.remaining == 0 and st.reset_epoch and st.reset_epoch > now:
            return False
        return True

    def next_token(self) -> Optional[str]:
        if not self.tokens:
            return None
        for _ in range(len(self.tokens)):
            token = self.tokens[self.idx % len(self.tokens)]
            self.idx += 1
            if self._is_usable(token):
                return token
        return None

    def mark_rate_info(self, token: str, remaining: Optional[int], reset_epoch: Optional[int]) -> None:
        st = self.state[token]
        if remaining is not None:
            st.remaining = remaining
        if reset_epoch is not None:
            st.reset_epoch = reset_epoch

    def disable(self, token: str) -> None:
        self.state[token].disabled = True

    def earliest_reset(self) -> Optional[int]:
        resets = [
            st.reset_epoch
            for st in self.state.values()
            if st.reset_epoch is not None and st.remaining == 0 and not st.disabled
        ]
        return min(resets) if resets else None


SESSION = requests.Session()
POOL = TokenPool(TOKENS)

def _parse_int_header(resp: requests.Response, name: str) -> Optional[int]:
    v = resp.headers.get(name)
    if v is None:
        return None
    try:
        return int(v)
    except Exception:
        return None

def github_get(url: str, params: dict) -> requests.Response:
    secondary_tries = 0
    attempts = 0

    while attempts < MAX_TOTAL_API_ATTEMPTS_PER_CALL:
        attempts += 1

        token = POOL.next_token()
        headers = dict(GITHUB_API_BASE_HEADERS)
        if token:
            headers["Authorization"] = f"Bearer {token}"

        resp = SESSION.get(url, headers=headers, params=params, timeout=REQUEST_TIMEOUT_SECONDS)

        # Parse message if possible
        msg = ""
        try:
            j = resp.json()
            if isinstance(j, dict):
                msg = str(j.get("message", "") or "")
        except Exception:
            pass

        remaining = _parse_int_header(resp, "X-RateLimit-Remaining")
        reset = _parse_int_header(resp, "X-RateLimit-Reset")
        retry_after = _parse_int_header(resp, "Retry-After")

        if token:
            POOL.mark_rate_info(token, remaining, reset)

        if resp.status_code == 200:
            return resp

        if resp.status_code == 401:
            if token:
                print("  GitHub API: 401 Unauthorized; disabling that token.")
                POOL.disable(token)
            return resp

        if resp.status_code in (403, 429):
            low_msg = msg.lower()

            # secondary rate limit
            if "secondary rate limit" in low_msg:
                if secondary_tries >= MAX_SECONDARY_RETRIES_PER_CALL:
                    return resp
                wait_s = retry_after if retry_after is not None else (SECONDARY_BACKOFF_BASE_SECONDS * (2 ** secondary_tries))
                wait_s = min(wait_s, SECONDARY_BACKOFF_MAX_SECONDS)
                secondary_tries += 1
                print(f"  GitHub API: secondary rate limit; sleeping {wait_s}s then retrying...")
                time.sleep(wait_s)
                continue

            # primary rate limit exhausted
            if remaining == 0:
                # try other token
                next_tok = POOL.next_token()
                if next_tok is not None:
                    continue

                # all tokens exhausted
                if not WAIT_FOR_RATE_LIMIT_RESET:
                    return resp

                earliest = POOL.earliest_reset()
                if earliest is None:
                    return resp
                now = int(time.time())
                sleep_s = max(1, earliest - now)
                print(f"  GitHub API: all tokens exhausted; sleeping {sleep_s}s until reset...")
                time.sleep(sleep_s)
                continue

            return resp

        return resp

    return resp

def get_cutoff_commit(owner: str, repo: str, branch: str, cutoff_iso: str) -> Optional[str]:
    url = f"https://api.github.com/repos/{owner}/{repo}/commits"
    params = {"sha": branch, "until": cutoff_iso, "per_page": 1}

    resp = github_get(url, params=params)
    if resp.status_code != 200:
        try:
            j = resp.json()
            msg = j.get("message", "") if isinstance(j, dict) else ""
        except Exception:
            msg = (resp.text or "")[:200]

        print(
            f"  GitHub API error for {owner}/{repo} commits: {resp.status_code} {msg} "
            f"(remaining={resp.headers.get('X-RateLimit-Remaining')}, reset={resp.headers.get('X-RateLimit-Reset')}, "
            f"retry_after={resp.headers.get('Retry-After')})"
        )
        return None

    data = resp.json()
    if not isinstance(data, list) or not data:
        return None
    return data[0].get("sha")


# ========= git read without checkout =========

def normalize_uses_path(uses_path: str) -> str:
    norm = uses_path.strip().strip('"').strip("'").replace("\\", "/")
    if norm.startswith("./"):
        norm = norm[2:]
    norm = norm.lstrip("/")
    norm = norm.rstrip("/")
    if norm in ("", "."):
        return ""  # repo root
    return norm

def git_path_exists(repo_dir: Path, commit_sha: str, rel_path: str) -> bool:
    if not rel_path:
        return False
    target = f"{commit_sha}:{rel_path}"
    proc = run_text(GIT_PREFIX + ["cat-file", "-e", target], cwd=repo_dir, check=False)
    return proc.returncode == 0

def git_show_file(repo_dir: Path, commit_sha: str, rel_path: str) -> Optional[bytes]:
    if not rel_path:
        return None
    target = f"{commit_sha}:{rel_path}"
    proc = run_bytes(GIT_PREFIX + ["show", target], cwd=repo_dir, check=False)
    if proc.returncode != 0:
        return None
    return proc.stdout

def resolve_action_yaml_path_at_commit(repo_dir: Path, commit_sha: str, uses_path: str) -> Optional[str]:
    norm = normalize_uses_path(uses_path)

    # direct YAML file
    if norm.lower().endswith((".yml", ".yaml")):
        return norm if git_path_exists(repo_dir, commit_sha, norm) else None

    # directory action.yml/action.yaml or root action.yml/action.yaml
    for fname in ("action.yml", "action.yaml"):
        candidate = f"{norm}/{fname}" if norm else fname
        if git_path_exists(repo_dir, commit_sha, candidate):
            return candidate

    return None

def prepare_git_dir(repo_git_dir: Path, github_url: str) -> None:
    if repo_git_dir.exists():
        shutil.rmtree(repo_git_dir, onerror=force_remove_readonly)
    repo_git_dir.mkdir(parents=True, exist_ok=True)
    run_text(GIT_PREFIX + ["init"], cwd=repo_git_dir)
    run_text(GIT_PREFIX + ["remote", "add", "origin", github_url], cwd=repo_git_dir)

def fetch_ref(repo_git_dir: Path, ref: str) -> str:
    run_text(GIT_PREFIX + ["fetch", "--depth", "1", "origin", ref], cwd=repo_git_dir)
    sha = run_text(GIT_PREFIX + ["rev-parse", "FETCH_HEAD"], cwd=repo_git_dir).stdout.strip()
    return sha


# ========= MAIN =========

def main():
    LOCAL_INSTRU_DIR.mkdir(parents=True, exist_ok=True)
    CLONE_DIR.mkdir(parents=True, exist_ok=True)
    OUTPUT_YML_DIR.mkdir(parents=True, exist_ok=True)

    print(f"Loaded {len(TOKENS)} GitHub token(s) from {ENV_DIR}\\{ENV_FILE_NAME}")
    if len(TOKENS) == 0:
        print("WARNING: Running unauthenticated -> you WILL hit API rate limits quickly.")

    # 1) Load URL list
    if not URL_LIST_CSV.exists():
        raise FileNotFoundError(f"URL list CSV not found: {URL_LIST_CSV}")

    url_df = pd.read_csv(URL_LIST_CSV)
    url_df.columns = url_df.columns.str.strip().str.lower()
    if "github_url" not in url_df.columns:
        raise ValueError("URL_List.csv must contain a 'github_url' column")

    owner_repo_to_info: Dict[str, Dict[str, str]] = {}
    for raw_url in url_df["github_url"].dropna().astype(str):
        raw_url = raw_url.strip()
        if not raw_url.startswith("http"):
            continue
        parsed = urlparse(raw_url)
        parts = parsed.path.strip("/").split("/")
        if len(parts) < 2:
            continue
        owner_raw, project_raw = parts[0], parts[1].replace(".git", "")
        key = f"{sanitize_token(owner_raw)}.{sanitize_token(project_raw)}"
        owner_repo_to_info[key] = {"github_url": raw_url, "owner": owner_raw, "project": project_raw}

    print(f"Built mapping for {len(owner_repo_to_info)} repos from URL_List.csv")

    # 2) Load NON_WORKFLOW local uses CSV
    if not LOCAL_NON_WORKFLOW_CSV.exists():
        raise FileNotFoundError(f"Local NON_WORKFLOW CSV not found: {LOCAL_NON_WORKFLOW_CSV}")

    local_df = pd.read_csv(LOCAL_NON_WORKFLOW_CSV)
    local_df.columns = local_df.columns.str.strip()

    if "owner_repo" not in local_df.columns or "uses_paths" not in local_df.columns:
        raise ValueError("Repos_with_Local_GHA_Actions_NON_WORKFLOW.csv must contain 'owner_repo' and 'uses_paths' columns")

    local_uses_by_repo: Dict[str, Set[str]] = {}
    for _, row in local_df.iterrows():
        owner_repo = str(row["owner_repo"]).strip()
        uses_field = str(row["uses_paths"]).strip()
        if not owner_repo or not uses_field or uses_field.lower() == "nan":
            continue
        for raw_part in uses_field.split(";"):
            up = raw_part.strip()
            if up:
                local_uses_by_repo.setdefault(owner_repo, set()).add(up)

    print(f"Found {len(local_uses_by_repo)} repos with NON-workflow local uses")

    # 3) Prepare index CSV
    index_fields = [
        "owner",
        "repo",
        "owner_repo_key",
        "github_url",
        "default_branch",
        "snapshot_commit",   # actual fetched SHA (cutoff or HEAD)
        "local_use_path",
        "relative_path",
        "filename",
        "flat_filename",     # now used to store relative_path (repo-relative)
        "saved_to",
    ]
    if not LOCAL_INDEX_CSV.exists():
        with LOCAL_INDEX_CSV.open("w", newline="", encoding="utf-8") as f:
            csv.DictWriter(f, fieldnames=index_fields).writeheader()

    # 4) Process repos
    for owner_repo_key, uses_set in sorted(local_uses_by_repo.items()):
        info = owner_repo_to_info.get(owner_repo_key)
        if not info:
            print(f"No URL found in URL_List.csv for key: {owner_repo_key} – skipping.")
            continue

        github_url = info["github_url"]
        owner = info["owner"]
        project = info["project"]

        print(f"\nProcessing repo {owner_repo_key} -> {github_url}")

        # default branch
        try:
            default_branch = detect_default_branch(github_url)
            print(f"  Default branch: {default_branch}")
        except Exception as e:
            print(f"  Failed to detect default branch: {e}")
            continue

        # cutoff commit via API; if none or API fails, fall back to HEAD branch
        cutoff_sha = get_cutoff_commit(owner, project, default_branch, CUTOFF_ISO)
        fetch_ref_name = cutoff_sha or default_branch

        if cutoff_sha:
            print(f"  Cutoff commit (API): {cutoff_sha}")
        else:
            print(f"  No cutoff commit (none before cutoff OR API failure). Falling back to HEAD of {default_branch}")

        # temp git dir
        repo_git_dir = CLONE_DIR / owner_repo_key.replace("/", "_")
        try:
            prepare_git_dir(repo_git_dir, github_url)
            snapshot_sha = fetch_ref(repo_git_dir, fetch_ref_name)
            print(f"  Fetched snapshot commit: {snapshot_sha}")
        except Exception as e:
            if isinstance(e, subprocess.CalledProcessError):
                print(f"  Failed to prepare/fetch repo:\n{e.stdout}")
            else:
                print(f"  Failed to prepare/fetch repo: {e}")
            continue

        # resolve & save each local use path
        for local_path in sorted(uses_set):
            print(f"    Resolving local use path: {local_path}")

            rel_file_path = resolve_action_yaml_path_at_commit(repo_git_dir, snapshot_sha, local_path)
            if not rel_file_path:
                print(f"    Could not resolve YAML for local path in snapshot: {local_path}")
                continue

            content = git_show_file(repo_git_dir, snapshot_sha, rel_file_path)
            if content is None:
                print(f"    Could not read file content via git show: {rel_file_path}")
                continue

            filename = Path(rel_file_path).name

            # === SAVE SCHEME (NEW) ===
            # Save under: D:\All_Action_YMLs\<owner_repo_key>\<relative_path_inside_repo>
            # Example: owner_repo_key = "owner.repo",
            #          rel_file_path = ".github/actions/my-action/action.yml"
            # => D:\All_Action_YMLs\owner.repo\.github\actions\my-action\action.yml
            dest_path = OUTPUT_YML_DIR / owner_repo_key / rel_file_path
            dest_path.parent.mkdir(parents=True, exist_ok=True)
            dest_path.write_bytes(content)

            with LOCAL_INDEX_CSV.open("a", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=index_fields)
                writer.writerow({
                    "owner": owner,
                    "repo": project,
                    "owner_repo_key": owner_repo_key,
                    "github_url": github_url,
                    "default_branch": default_branch,
                    "snapshot_commit": snapshot_sha,
                    "local_use_path": local_path,
                    "relative_path": rel_file_path,
                    "filename": filename,
                    "flat_filename": rel_file_path,   # repo-relative path
                    "saved_to": str(dest_path),
                })

            print(f"    Saved {rel_file_path} -> {dest_path}")

        if not KEEP_CLONES:
            try:
                shutil.rmtree(repo_git_dir, onerror=force_remove_readonly)
            except Exception as e:
                print(f"  Failed to delete temp git dir {repo_git_dir}: {e}")

    print("\nDone. Local action YAMLs stored in:")
    print(f"  {OUTPUT_YML_DIR}")
    print("Index CSV:")
    print(f"  {LOCAL_INDEX_CSV}")


if __name__ == "__main__":
    main()
# Out:
# 🔁 Scanning config folder: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ1\All_Config_Files
#
# === SCAN SUMMARY ===
# Total files visited:                                 78894
# Total YAML files:                                    12667
# Total '__github_actions++' YAML files (workflows):   9724
# Workflow files with NON-.github/workflows 'uses:':   499
#
# === Repos with NON-.github/workflows local actions ===
# Total repos: 160
#
# - 1q23lyc45.kitsunemagisk (workflow files: 1)
#     • 1q23lyc45.kitsunemagisk__github_actions++android.yml  →  ./.github/actions/setup
#
# - 4accccc.vivo-magisk-suu (workflow files: 1)
#     • 4accccc.vivo-magisk-suu__github_actions++build.yml  →  ./.github/actions/setup
#
# - alvr.katana (workflow files: 1)
#     • alvr.katana__github_actions++katana.yml  →  ./.github/actions/common-steps
#
# - anysoftkeyboard.anysoftkeyboard (workflow files: 4)
#     • anysoftkeyboard.anysoftkeyboard__github_actions++checks.yml  →  ./.github/actions/collect-reports;./.github/actions/deploy-request
#     • anysoftkeyboard.anysoftkeyboard__github_actions++deploy.yml  →  ./.github/actions/deploy
#     • anysoftkeyboard.anysoftkeyboard__github_actions++deployment_promote.yml  →  ./.github/actions/deploy-request
#     • anysoftkeyboard.anysoftkeyboard__github_actions++manual_deploy.yml  →  ./.github/actions/deploy-request
#
# - astubenbord.paperless-mobile (workflow files: 4)
#     • astubenbord.paperless-mobile__github_actions++build_app.yml  →  ./.github/actions/setup-android-signing-config
#     • astubenbord.paperless-mobile__github_actions++create-github-release.yml  →  ./.github/actions/setup-android-signing-config
#     • astubenbord.paperless-mobile__github_actions++create_release.yml  →  ./.github/actions/setup-android-signing-config
#     • astubenbord.paperless-mobile__github_actions++release-deploy-play-store.yml  →  ./.github/actions/setup-android-signing-config
#
# - atlj.react-native-background-remover (workflow files: 2)
#     • atlj.react-native-background-remover__github_actions++ci.yml  →  ./.github/actions/setup
#     • atlj.react-native-background-remover__github_actions++publish.yml  →  ./.github/actions/setup
#
# - atsign-foundation.noports (workflow files: 2)
#     • atsign-foundation.noports__github_actions++end2end_tests.yaml  →  ./.github/composite/setup_entrypoints
#     • atsign-foundation.noports__github_actions++unit_tests.yaml  →  ./.github/composite/verify_cli_tags
#
# - auth0.auth0-flutter (workflow files: 4)
#     • auth0.auth0-flutter__github_actions++main.yml  →  ./.github/actions/setup-android;./.github/actions/setup-darwin;./.github/actions/smoke-tests-darwin;./.github/actions/unit-tests-darwin
#     • auth0.auth0-flutter__github_actions++publish-af.yml  →  ./.github/actions/setup-publish
#     • auth0.auth0-flutter__github_actions++publish-afpi.yml  →  ./.github/actions/setup-publish
#     • auth0.auth0-flutter__github_actions++rl-scanner.yml  →  ./.github/actions/rl-scanner
#
# - aws.aws-iot-fleetwise-edge (workflow files: 1)
#     • aws.aws-iot-fleetwise-edge__github_actions++ci.yml  →  ./.github/template/docker-build;./.github/template/fwe-build
#
# - azesmway.react-native-unity (workflow files: 1)
#     • azesmway.react-native-unity__github_actions++ci.yml  →  ./.github/actions/setup
#
# - bdaya-dev.oidc (workflow files: 1)
#     • bdaya-dev.oidc__github_actions++tests.yaml  →  ./.github/actions/flutter_base;./.github/actions/integration_test_base
#
# - bimmergestalt.idriveconnectaddons (workflow files: 1)
#     • bimmergestalt.idriveconnectaddons__github_actions++build.yml  →  ./.github/actions/download-externals-action
#
# - bitwarden.android (workflow files: 1)
#     • bitwarden.android__github_actions++github-release.yml  →  ./.github/actions/log-inputs
#
# - braintree.android-card-form (workflow files: 1)
#     • braintree.android-card-form__github_actions++release.yml  →  ./.github/actions/decode_signing_key_action;./.github/actions/publish_module;./.github/actions/set_github_user
#
# - braintree.braintree-android-drop-in (workflow files: 2)
#     • braintree.braintree-android-drop-in__github_actions++release.yml  →  ./.github/actions/decode_signing_key_action;./.github/actions/publish_module;./.github/actions/set_github_user;./.github/actions/update_versions
#     • braintree.braintree-android-drop-in__github_actions++release_snapshot.yml  →  ./.github/actions/decode_signing_key_action;./.github/actions/publish_module
#
# - callstackincubator.ai (workflow files: 1)
#     • callstackincubator.ai__github_actions++ci.yml  →  ./.github/actions/setup
#
# - candlefinance.blur-view (workflow files: 1)
#     • candlefinance.blur-view__github_actions++ci.yml  →  ./.github/actions/setup
#
# - candlefinance.faster-image (workflow files: 1)
#     • candlefinance.faster-image__github_actions++ci.yml  →  ./.github/actions/setup
#
# - candlefinance.haptics (workflow files: 1)
#     • candlefinance.haptics__github_actions++ci.yml  →  ./.github/actions/setup
#
# - candlefinance.page-control (workflow files: 1)
#     • candlefinance.page-control__github_actions++ci.yml  →  ./.github/actions/setup
#
# - candlefinance.pow (workflow files: 1)
#     • candlefinance.pow__github_actions++ci.yml  →  ./.github/actions/setup
#
# - cgeo.cgeo (workflow files: 2)
#     • cgeo.cgeo__github_actions++tests.yml  →  ./.github/actions/cgeo-preferences;./.github/actions/check-websites
#     • cgeo.cgeo__github_actions++watchdog.yml  →  ./.github/actions/cgeo-preferences;./.github/actions/check-websites
#
# - chaquo.chaquopy (workflow files: 1)
#     • chaquo.chaquopy__github_actions++ci.yml  →  ./.github/actions/create-local-properties;./.github/actions/setup-python
#
# - chrisimx.scanbridge (workflow files: 2)
#     • chrisimx.scanbridge__github_actions++android.yml  →  ./.github/actions/build
#     • chrisimx.scanbridge__github_actions++create-release.yml  →  ./.github/actions/build
#
# - classicube.classicube (workflow files: 31)
#     • classicube.classicube__github_actions++build_3ds.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_android.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_dreamcast.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_freebsd.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_haiku.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_ios.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_linux.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_mac32.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_mac64.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_macclassic.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_msdos.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_n64.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_nds.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_netbsd.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_ps1.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_ps2.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_ps3.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_psp.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_rpi.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_saturn.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_switch.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_symbian.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_vita.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_webclient.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_wiigc.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_wiiu.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_win-arm.yml  →  ./.github/actions/notify_failure;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_windows.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_xbox.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++build_xbox360.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#     • classicube.classicube__github_actions++release.yml  →  ./.github/actions/notify_failure;./.github/actions/notify_success;./.github/actions/upload_build
#
# - coil-kt.coil (workflow files: 1)
#     • coil-kt.coil__github_actions++ci.yml  →  ./.github/actions/get-avd-info
#
# - d4rken-org.bluemusic (workflow files: 2)
#     • d4rken-org.bluemusic__github_actions++code-checks.yml  →  ./.github/actions/common-setup
#     • d4rken-org.bluemusic__github_actions++release-tag.yml  →  ./.github/actions/common-setup
#
# - d4rken-org.capod (workflow files: 2)
#     • d4rken-org.capod__github_actions++code-checks.yml  →  ./.github/actions/common-setup
#     • d4rken-org.capod__github_actions++release-tag.yml  →  ./.github/actions/common-setup
#
# - d4rken-org.octi (workflow files: 2)
#     • d4rken-org.octi__github_actions++code-checks.yml  →  ./.github/actions/common-setup
#     • d4rken-org.octi__github_actions++release-tag.yml  →  ./.github/actions/common-setup
#
# - d4rken-org.permission-pilot (workflow files: 2)
#     • d4rken-org.permission-pilot__github_actions++code-checks.yml  →  ./.github/actions/common-setup
#     • d4rken-org.permission-pilot__github_actions++release-tag.yml  →  ./.github/actions/common-setup
#
# - dart-lang.native (workflow files: 1)
#     • dart-lang.native__github_actions++jnigen.yaml  →  ./.github/actions/java-format-check
#
# - doko-demo-doa.react-native-shake (workflow files: 1)
#     • doko-demo-doa.react-native-shake__github_actions++ci.yml  →  ./.github/actions/setup
#
# - dotanuki-labs.norris (workflow files: 1)
#     • dotanuki-labs.norris__github_actions++main.yml  →  ./.github/actions/setup-android-build
#
# - dotnet.android (workflow files: 1)
#     • dotnet.android__github_actions++locker.yml  →  ./actions/locker
#
# - doublesymmetry.kotlinaudio (workflow files: 1)
#     • doublesymmetry.kotlinaudio__github_actions++validate.yml  →  ./.github/actions/get-avd-info
#
# - dr-blank.vaani (workflow files: 1)
#     • dr-blank.vaani__github_actions++flutter-ci.yaml  →  ./.github/actions/flutter-setup
#
# - drawpile.drawpile (workflow files: 1)
#     • drawpile.drawpile__github_actions++main.yml  →  ./.github/actions/build-deps;./.github/actions/post-sccache;./.github/actions/pre-sccache;./.github/actions/restore-linux
#
# - dreautall.waterfly-iii (workflow files: 2)
#     • dreautall.waterfly-iii__github_actions++commit.yml  →  ./.github/actions/setup_env
#     • dreautall.waterfly-iii__github_actions++release.yml  →  ./.github/actions/setup_env
#
# - droidkaigi.conference-app-2022 (workflow files: 3)
#     • droidkaigi.conference-app-2022__github_actions++dropstaging.yml  →  ./gh-actions/actions/destroy-distribution-by-name
#     • droidkaigi.conference-app-2022__github_actions++stagepullrequest.yml  →  ./gh-actions/actions/commit-deployment;./gh-actions/actions/create-deployment;./gh-actions/actions/find-files;./gh-actions/actions/get-artifact
#     • droidkaigi.conference-app-2022__github_actions++stagepush.yml  →  ./gh-actions/actions/find-files;./gh-actions/actions/get-artifact
#
# - emurgo.yoroi (workflow files: 1)
#     • emurgo.yoroi__github_actions++wallet-mobile-checks.yml  →  ./.github/actions/wallet-mobile
#
# - eranboudjnah.loaders (workflow files: 1)
#     • eranboudjnah.loaders__github_actions++gradle-checks.yml  →  ./.github/actions/cache-build-paths
#
# - expo.expo (workflow files: 31)
#     • expo.expo__github_actions++android-instrumentation-tests.yml  →  ./.github/actions/cleanup-linux-disk-space;./.github/actions/expo-caches;./.github/actions/use-android-emulator
#     • expo.expo__github_actions++android-unit-tests.yml  →  ./.github/actions/cleanup-linux-disk-space;./.github/actions/expo-caches
#     • expo.expo__github_actions++bare-diffs.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++check-issues-nightly.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++client-android-eas.yml  →  ./.github/actions/eas-build;./.github/actions/expo-caches;./.github/actions/expo-git-decrypt
#     • expo.expo__github_actions++client-ios-eas.yml  →  ./.github/actions/eas-build;./.github/actions/expo-caches;./.github/actions/expo-git-decrypt
#     • expo.expo__github_actions++code-review.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++commentator.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++create-expo-app.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++development-client-e2e.yml  →  ./.github/actions/expo-caches;./.github/actions/use-android-emulator
#     • expo.expo__github_actions++development-client-latest-e2e.yml  →  ./.github/actions/expo-caches;./.github/actions/use-android-emulator
#     • expo.expo__github_actions++development-client.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++docs-pr.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++docs.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++expotools.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++fingerprint.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++home.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++ios-static-frameworks.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++ios-unit-tests.yml  →  ./.github/actions/expo-caches;./.github/actions/expo-git-decrypt
#     • expo.expo__github_actions++issue-closed.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++issue-opened.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++issue-triage.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++native-component-list.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++pr-labeler.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++publish-canaries.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++sdk.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++test-suite-lint.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++test-suite-macos.yml  →  ./.github/actions/expo-caches
#     • expo.expo__github_actions++test-suite-nightly.yml  →  ./.github/actions/cleanup-linux-disk-space;./.github/actions/expo-caches;./.github/actions/use-android-emulator
#     • expo.expo__github_actions++test-suite.yml  →  ./.github/actions/cleanup-linux-disk-space;./.github/actions/expo-caches;./.github/actions/use-android-emulator
#     • expo.expo__github_actions++validate-npm-owners.yml  →  ./.github/actions/expo-caches
#
# - fabernovel.docker-android (workflow files: 1)
#     • fabernovel.docker-android__github_actions++ci_action.yml  →  ./
#
# - felangel.bloc (workflow files: 1)
#     • felangel.bloc__github_actions++main.yaml  →  ./.github/actions/angular_dart_package;./.github/actions/astro_site;./.github/actions/dart_compile;./.github/actions/dart_package;./.github/actions/flutter_package
#
# - firebase.firebaseui-flutter (workflow files: 1)
#     • firebase.firebaseui-flutter__github_actions++unit_tests.yml  →  ./.github/actions/changes
#
# - firefly-social.firefly (workflow files: 1)
#     • firefly-social.firefly__github_actions++pr.yml  →  ./.github/actions/setup-environment
#
# - firezone.firezone (workflow files: 9)
#     • firezone.firezone__github_actions++ci.yml  →  ./.github/actions/ghcr-docker-login
#     • firezone.firezone__github_actions++sentry.yml  →  ./.github/actions/create-sentry-release
#     • firezone.firezone__github_actions++_build_artifacts.yml  →  ./.github/actions/ghcr-docker-login;./.github/actions/setup-rust
#     • firezone.firezone__github_actions++_elixir.yml  →  ./.github/actions/setup-elixir;./.github/actions/setup-node;./.github/actions/setup-postgres
#     • firezone.firezone__github_actions++_integration_tests.yml  →  ./.github/actions/ghcr-docker-login
#     • firezone.firezone__github_actions++_kotlin.yml  →  ./.github/actions/setup-android
#     • firezone.firezone__github_actions++_rust.yml  →  ./.github/actions/setup-rust;./.github/actions/setup-tauri-v2
#     • firezone.firezone__github_actions++_swift.yml  →  ./.github/actions/setup-rust
#     • firezone.firezone__github_actions++_tauri.yml  →  ./.github/actions/setup-node;./.github/actions/setup-rust;./.github/actions/setup-tauri-v2
#
# - fluttercandies.extended_list (workflow files: 1)
#     • fluttercandies.extended_list__github_actions++checker.yml  →  ./
#
# - fluttercandies.waterfall_flow (workflow files: 1)
#     • fluttercandies.waterfall_flow__github_actions++checker.yml  →  ./
#
# - fm-sys.snapdrop-android (workflow files: 1)
#     • fm-sys.snapdrop-android__github_actions++translation-validation.yaml  →  ./translation-validation-bot/
#
# - fossasia.badgemagic-app (workflow files: 2)
#     • fossasia.badgemagic-app__github_actions++pull_request.yml  →  ./.github/actions/android;./.github/actions/common;./.github/actions/ios;./.github/actions/screenshot-android;./.github/actions/screenshot-ios
#     • fossasia.badgemagic-app__github_actions++push.yml  →  ./.github/actions/android;./.github/actions/common;./.github/actions/ios;./.github/actions/screenshot-android;./.github/actions/screenshot-ios
#
# - fossasia.pslab-android (workflow files: 2)
#     • fossasia.pslab-android__github_actions++pull-request.yml  →  ./.github/actions/android;./.github/actions/common;./.github/actions/ios
#     • fossasia.pslab-android__github_actions++push-event.yml  →  ./.github/actions/android;./.github/actions/common;./.github/actions/ios
#
# - friesi23.mhabit (workflow files: 4)
#     • friesi23.mhabit__github_actions++app-release.yml  →  ./.github/actions/setup_flutter;./.github/actions/setup_jdk
#     • friesi23.mhabit__github_actions++_analyze.yml  →  ./.github/actions/setup_flutter
#     • friesi23.mhabit__github_actions++_check.yml  →  ./.github/actions/setup_flutter
#     • friesi23.mhabit__github_actions++_test.yml  →  ./.github/actions/setup_flutter
#
# - fujidaiti.smooth_sheets (workflow files: 3)
#     • fujidaiti.smooth_sheets__github_actions++claude_code.yaml  →  ./.github/actions/setup_flutter
#     • fujidaiti.smooth_sheets__github_actions++health.yaml  →  ./.github/actions/setup_flutter
#     • fujidaiti.smooth_sheets__github_actions++publish.yaml  →  ./.github/actions/setup_flutter
#
# - gabber235.typewriter (workflow files: 5)
#     • gabber235.typewriter__github_actions++build-and-publish-release-jars.yml  →  ./.github/actions/build-engine
#     • gabber235.typewriter__github_actions++build-development-jars-and-publish.yml  →  ./.github/actions/build-engine
#     • gabber235.typewriter__github_actions++build-engine.yml  →  ./.github/actions/build-engine
#     • gabber235.typewriter__github_actions++build-extension.yml  →  ./.github/actions/build-extension
#     • gabber235.typewriter__github_actions++test-building.yml  →  ./.github/actions/build-engine
#
# - gabrielbmoro.moviedb-app (workflow files: 1)
#     • gabrielbmoro.moviedb-app__github_actions++popcorn.yml  →  ./.github/actions/java
#
# - getsentry.sentry-react-native (workflow files: 2)
#     • getsentry.sentry-react-native__github_actions++e2e-v2.yml  →  ./.github/actions/disk-cleanup
#     • getsentry.sentry-react-native__github_actions++native-tests.yml  →  ./.github/actions/disk-cleanup
#
# - githubsecuritylab.codeql-community-packs (workflow files: 2)
#     • githubsecuritylab.codeql-community-packs__github_actions++ci.yml  →  ./.github/actions/install-codeql
#     • githubsecuritylab.codeql-community-packs__github_actions++publish.yml  →  ./.github/actions/install-codeql
#
# - godotengine.godot (workflow files: 6)
#     • godotengine.godot__github_actions++android_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#     • godotengine.godot__github_actions++ios_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#     • godotengine.godot__github_actions++linux_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-converter-test;./.github/actions/godot-cpp-build;./.github/actions/godot-deps;./.github/actions/godot-project-test;./.github/actions/upload-artifact
#     • godotengine.godot__github_actions++macos_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#     • godotengine.godot__github_actions++web_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#     • godotengine.godot__github_actions++windows_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#
# - google.android-fhir (workflow files: 1)
#     • google.android-fhir__github_actions++build.yml  →  ./.github/actions/commonSetup
#
# - google.filament (workflow files: 9)
#     • google.filament__github_actions++android-continuous.yml  →  ./.github/actions/android-continuous;./.github/actions/linux-prereq
#     • google.filament__github_actions++ios-continuous.yml  →  ./.github/actions/mac-prereq
#     • google.filament__github_actions++linux-continuous.yml  →  ./.github/actions/linux-prereq
#     • google.filament__github_actions++mac-continuous.yml  →  ./.github/actions/mac-prereq
#     • google.filament__github_actions++postsubmit.yml  →  ./.github/actions/get-commit-msg;./.github/actions/linux-prereq
#     • google.filament__github_actions++presubmit.yml  →  ./.github/actions/get-commit-msg;./.github/actions/linux-prereq;./.github/actions/mac-prereq;./.github/actions/web-prereq
#     • google.filament__github_actions++release.yml  →  ./.github/actions/linux-prereq;./.github/actions/mac-prereq;./.github/actions/web-prereq
#     • google.filament__github_actions++verify-release-notes.yml  →  ./.github/actions/verify-release-notes
#     • google.filament__github_actions++web-continuous.yml  →  ./.github/actions/linux-prereq;./.github/actions/web-prereq
#
# - grab.grazel (workflow files: 1)
#     • grab.grazel__github_actions++ci.yml  →  ./.github/actions/bazel;./.github/actions/gradle
#
# - gromif.astracrypt (workflow files: 4)
#     • gromif.astracrypt__github_actions++pull_request.yml  →  ./.github/actions/setup-gradle-action;./.github/actions/setup-java-action
#     • gromif.astracrypt__github_actions++push.yml  →  ./.github/actions/setup-gradle-action;./.github/actions/setup-java-action;./.github/actions/setup-keystore;./.github/actions/upload-artifact
#     • gromif.astracrypt__github_actions++workflow-code-analysis.yml  →  ./.github/actions/setup-gradle-action;./.github/actions/setup-java-action
#     • gromif.astracrypt__github_actions++workflow-tests.yml  →  ./.github/actions/setup-gradle-action;./.github/actions/setup-java-action
#
# - grote.transportr (workflow files: 1)
#     • grote.transportr__github_actions++build.yml  →  ./.github/actions/get-avd-arch
#
# - hoanglam10499.react-native-drop-shadow (workflow files: 1)
#     • hoanglam10499.react-native-drop-shadow__github_actions++ci.yml  →  ./.github/actions/setup
#
# - holochain-apps.volla-messages (workflow files: 1)
#     • holochain-apps.volla-messages__github_actions++release-tauri-app.yaml  →  ./.github/actions/extend-space
#
# - huextrat.react-native-screenshot-aware (workflow files: 3)
#     • huextrat.react-native-screenshot-aware__github_actions++ci.yml  →  ./.github/actions/setup
#     • huextrat.react-native-screenshot-aware__github_actions++coverage.yml  →  ./.github/actions/setup
#     • huextrat.react-native-screenshot-aware__github_actions++release.yml  →  ./.github/actions/setup
#
# - insertkoinio.koin (workflow files: 5)
#     • insertkoinio.koin__github_actions++build.yml  →  ./.github/actions/prepare-env
#     • insertkoinio.koin__github_actions++codeql.yml  →  ./.github/actions/prepare-env
#     • insertkoinio.koin__github_actions++release.yml  →  ./.github/actions/prepare-env
#     • insertkoinio.koin__github_actions++test.yml  →  ./.github/actions/prepare-env
#     • insertkoinio.koin__github_actions++weekly.yml  →  ./.github/actions/prepare-env
#
# - invertase.jet (workflow files: 1)
#     • invertase.jet__github_actions++ci.yml  →  ./.github/actions/setup
#
# - iotivity.iotivity-lite (workflow files: 1)
#     • iotivity.iotivity-lite__github_actions++ghcr-cleanup.yml  →  ./.github/actions/cleanup-stale
#
# - irgaly.kfswatch (workflow files: 3)
#     • irgaly.kfswatch__github_actions++build-test.yml  →  ./.github/actions/gradle-cache
#     • irgaly.kfswatch__github_actions++deploy_mavencentral_release.yml  →  ./.github/actions/gradle-cache
#     • irgaly.kfswatch__github_actions++deploy_mavencentral_staging.yml  →  ./.github/actions/gradle-cache
#
# - isar.isar (workflow files: 3)
#     • isar.isar__github_actions++release.yaml  →  ./.github/actions/prepare-build
#     • isar.isar__github_actions++test.yaml  →  ./.github/actions/prepare-build
#     • isar.isar__github_actions++testlab.yaml  →  ./.github/actions/prepare-build
#
# - itscalebjones.spacelaunchnow-android (workflow files: 3)
#     • itscalebjones.spacelaunchnow-android__github_actions++android_build.yml  →  ./.github/actions/run-tests;./.github/actions/setup-env
#     • itscalebjones.spacelaunchnow-android__github_actions++android_pr.yml  →  ./.github/actions/run-tests;./.github/actions/setup-env
#     • itscalebjones.spacelaunchnow-android__github_actions++android_release.yml  →  ./.github/actions/run-tests;./.github/actions/setup-env
#
# - jameshnsears.quoteunquote (workflow files: 2)
#     • jameshnsears.quoteunquote__github_actions++coverage-androidtest.yml  →  ./.github/actions/get-avd-info
#     • jameshnsears.quoteunquote__github_actions++coverage-test.yml  →  ./.github/actions/get-avd-info
#
# - keidan.hexviewer (workflow files: 1)
#     • keidan.hexviewer__github_actions++build.yml  →  ./.github/actions/analyze-with-sonar;./.github/actions/setup-gradle
#
# - komodoplatform.komodo-wallet (workflow files: 8)
#     • komodoplatform.komodo-wallet__github_actions++desktop-builds.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/releases/setup-linux;./.github/actions/releases/setup-macos;./.github/actions/releases/setup-windows
#     • komodoplatform.komodo-wallet__github_actions++firebase-hosting-merge.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/validate-build
#     • komodoplatform.komodo-wallet__github_actions++firebase-hosting-pull-request.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/validate-build
#     • komodoplatform.komodo-wallet__github_actions++mobile-builds.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/releases/setup-android;./.github/actions/releases/setup-ios
#     • komodoplatform.komodo-wallet__github_actions++sdk-integration-preview.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/validate-build
#     • komodoplatform.komodo-wallet__github_actions++ui-tests-on-pr.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/validate-build
#     • komodoplatform.komodo-wallet__github_actions++unit-tests-on-pr.yml  →  ./.github/actions/code-coverage;./.github/actions/flutter-deps;./.github/actions/generate-assets;./.github/actions/validate-build
#     • komodoplatform.komodo-wallet__github_actions++validate-code-guidelines.yml  →  ./.github/actions/flutter-deps;./.github/actions/generate-assets
#
# - kts6056.droidknights-2024-github-actions (workflow files: 10)
#     • kts6056.droidknights-2024-github-actions__github_actions++create-hotfix-branch.yml  →  ./.github/actions/calculate-distribution-version;./.github/actions/create-pull-request-to-release;./.github/actions/update-app-version
#     • kts6056.droidknights-2024-github-actions__github_actions++create-release-branch.yaml  →  ./.github/actions/calculate-distribution-version;./.github/actions/create-pull-request-to-release;./.github/actions/update-app-version
#     • kts6056.droidknights-2024-github-actions__github_actions++create-release-note.yml  →  ./.github/actions/get-app-version
#     • kts6056.droidknights-2024-github-actions__github_actions++deploy-all-variants.yml  →  ./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++deploy-from-comment.yml  →  ./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++deploy-from-firebase-app-distribution.yml  →  ./.github/actions/firebase-app-distribution;./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++ktlint.yml  →  ./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++publish-to-play-console.yml  →  ./.github/actions/missing-translation-lint;./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++verify-on-build-test.yml  →  ./.github/actions/setup-development-environment
#     • kts6056.droidknights-2024-github-actions__github_actions++verify-on-unit-test.yml  →  ./.github/actions/setup-development-environment
#
# - lanedirt.aliasvault (workflow files: 3)
#     • lanedirt.aliasvault__github_actions++browser-extension-build.yml  →  ./.github/actions/build-browser-extension
#     • lanedirt.aliasvault__github_actions++mobile-app-build.yml  →  ./.github/actions/build-android-app;./.github/actions/build-ios-app
#     • lanedirt.aliasvault__github_actions++release.yml  →  ./.github/actions/build-android-app;./.github/actions/build-browser-extension
#
# - leboncoin.spark-android (workflow files: 8)
#     • leboncoin.spark-android__github_actions++chat-bot-commands.yml  →  ./.github/actions/dependencyguard-baseline;./.github/actions/paparazzi-golden-images;./.github/actions/spotless-apply
#     • leboncoin.spark-android__github_actions++ci.yml  →  ./.github/actions/archive-junit-reports;./.github/actions/archive-lint-reports;./.github/actions/archive-paparazzi-reports;./.github/actions/check-git-lfs;./.github/actions/diffuse-aar;./.github/actions/paparazzi-report;./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#     • leboncoin.spark-android__github_actions++dependabot-dependency-guard.yml  →  ./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#     • leboncoin.spark-android__github_actions++dokka.yml  →  ./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#     • leboncoin.spark-android__github_actions++firebase-app-distribution.yml  →  ./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#     • leboncoin.spark-android__github_actions++gradle-wrapper-updater.yml  →  ./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#     • leboncoin.spark-android__github_actions++paparazzi-golden-images.yml  →  ./.github/actions/paparazzi-golden-images
#     • leboncoin.spark-android__github_actions++publish.yml  →  ./.github/actions/setup-gradle;./.github/actions/setup-gradle-properties;./.github/actions/setup-java
#
# - ledgerhq.ledger-live (workflow files: 1)
#     • ledgerhq.ledger-live__github_actions++test-coin-tester.yml  →  ./tools/actions/composites/run-coin-tester;./tools/actions/composites/setup-coin-tester-env
#
# - lg0gs.react-native-tiktok (workflow files: 1)
#     • lg0gs.react-native-tiktok__github_actions++ci.yml  →  ./.github/actions/setup
#
# - lichess-org.lichobile (workflow files: 1)
#     • lichess-org.lichobile__github_actions++android.yml  →  ./.github/actions/build-lichobile-apk
#
# - linksheet.linksheet (workflow files: 2)
#     • linksheet.linksheet__github_actions++build-nightly-nopublish.yml  →  ./.github/actions/get-avd-info
#     • linksheet.linksheet__github_actions++build-nightly.yml  →  ./.github/actions/get-avd-info
#
# - lodev09.react-native-true-sheet (workflow files: 1)
#     • lodev09.react-native-true-sheet__github_actions++ci.yml  →  ./.github/actions/setup
#
# - lyswhut.lx-music-mobile (workflow files: 2)
#     • lyswhut.lx-music-mobile__github_actions++beta-pack.yml  →  ./.github/actions/setup;./.github/actions/upload-artifact
#     • lyswhut.lx-music-mobile__github_actions++release.yml  →  ./.github/actions/setup;./.github/actions/upload-artifact
#
# - maitrungduc1410.react-native-loader-kit (workflow files: 1)
#     • maitrungduc1410.react-native-loader-kit__github_actions++ci.yml  →  ./.github/actions/setup
#
# - maitrungduc1410.react-native-video-trim (workflow files: 1)
#     • maitrungduc1410.react-native-video-trim__github_actions++ci.yml  →  ./.github/actions/setup
#
# - maitrungduc1410.react-native-zalo-kit (workflow files: 1)
#     • maitrungduc1410.react-native-zalo-kit__github_actions++ci.yml  →  ./.github/actions/setup
#
# - mavlink.qgroundcontrol (workflow files: 8)
#     • mavlink.qgroundcontrol__github_actions++android-linux.yml  →  ./.github/actions/common;./.github/actions/qt-android;./.github/actions/upload
#     • mavlink.qgroundcontrol__github_actions++android-macos.yml  →  ./.github/actions/common;./.github/actions/qt-android
#     • mavlink.qgroundcontrol__github_actions++android-windows.yml  →  ./.github/actions/common;./.github/actions/qt-android
#     • mavlink.qgroundcontrol__github_actions++custom.yml  →  ./.github/actions/cache;./.github/actions/common
#     • mavlink.qgroundcontrol__github_actions++ios.yml  →  ./.github/actions/cache;./.github/actions/common
#     • mavlink.qgroundcontrol__github_actions++linux.yml  →  ./.github/actions/cache;./.github/actions/common;./.github/actions/upload
#     • mavlink.qgroundcontrol__github_actions++macos.yml  →  ./.github/actions/cache;./.github/actions/common;./.github/actions/upload
#     • mavlink.qgroundcontrol__github_actions++windows.yml  →  ./.github/actions/cache;./.github/actions/common;./.github/actions/upload
#
# - mayunyi.react-native-brayant-ad (workflow files: 1)
#     • mayunyi.react-native-brayant-ad__github_actions++ci.yml  →  ./.github/actions/setup
#
# - mbakgun.midjourney-images-compose-multiplatform (workflow files: 1)
#     • mbakgun.midjourney-images-compose-multiplatform__github_actions++main.yml  →  ./.github/actions/ios-action
#
# - mewssystems.mews-flutter (workflow files: 11)
#     • mewssystems.mews-flutter__github_actions++check.yml  →  ./.github/actions/setup
#     • mewssystems.mews-flutter__github_actions++dcm.yml  →  ./.github/actions/setup
#     • mewssystems.mews-flutter__github_actions++dependabot-follow-up.yml  →  ./.github/actions/setup
#     • mewssystems.mews-flutter__github_actions++deploy-widgetbook-azure.yml  →  ./.github/actions/setup
#     • mewssystems.mews-flutter__github_actions++deploy-widgetbook.yml  →  ./.github/actions/setup
#     • mewssystems.mews-flutter__github_actions++kiosk_mode-publish.yml  →  ./.github/actions/publish
#     • mewssystems.mews-flutter__github_actions++mews_pedantic-publish.yml  →  ./.github/actions/publish
#     • mewssystems.mews-flutter__github_actions++optimus-publish.yml  →  ./.github/actions/publish
#     • mewssystems.mews-flutter__github_actions++optimus_icons-publish.yml  →  ./.github/actions/publish
#     • mewssystems.mews-flutter__github_actions++remote_logger-publish.yml  →  ./.github/actions/publish
#     • mewssystems.mews-flutter__github_actions++tokens-pr.yml  →  ./.github/actions/setup
#
# - mises-id.mises-browser-core (workflow files: 1)
#     • mises-id.mises-browser-core__github_actions++main__6.yml  →  ./.github/actions/setup-geckodriver
#
# - missingcore.music (workflow files: 2)
#     • missingcore.music__github_actions++android-release.yml  →  ./.github/actions/setup
#     • missingcore.music__github_actions++privacy-build.yml  →  ./.github/actions/setup
#
# - mollyim.mollyim-android (workflow files: 1)
#     • mollyim.mollyim-android__github_actions++test.yml  →  ./.github/actions/disk-cleanup
#
# - mosc.glider (workflow files: 2)
#     • mosc.glider__github_actions++ci.yml  →  ./.github/actions/bootstrap
#     • mosc.glider__github_actions++release.yml  →  ./.github/actions/bootstrap
#
# - mybigday.llama.rn (workflow files: 1)
#     • mybigday.llama.rn__github_actions++ci.yml  →  ./.github/actions/setup
#
# - mym0404.react-native-naver-map (workflow files: 2)
#     • mym0404.react-native-naver-map__github_actions++ci.yml  →  ./.github/actions/setup
#     • mym0404.react-native-naver-map__github_actions++doc-publish.yml  →  ./.github/actions/setup
#
# - nmfisher.thermion (workflow files: 1)
#     • nmfisher.thermion__github_actions++dart.yml  →  ./.github/actions/setup-build-env
#
# - numandev1.react-native-keys (workflow files: 4)
#     • numandev1.react-native-keys__github_actions++build-android.yml  →  ./.github/actions/setup
#     • numandev1.react-native-keys__github_actions++build-ios.yml  →  ./.github/actions/setup
#     • numandev1.react-native-keys__github_actions++build-project.yml  →  ./.github/actions/setup
#     • numandev1.react-native-keys__github_actions++validate-js.yml  →  ./.github/actions/setup
#
# - omahili.react-native-reorderable-list (workflow files: 1)
#     • omahili.react-native-reorderable-list__github_actions++ci.yml  →  ./.github/actions/setup
#
# - onekeyhq.app-monorepo (workflow files: 10)
#     • onekeyhq.app-monorepo__github_actions++release-android-debug.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-android.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-desktop-mas.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-desktop-snap.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-desktop-winms.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-desktop.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-ext.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-ios-debug.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-ios.yml  →  ./.github/actions/shared-env
#     • onekeyhq.app-monorepo__github_actions++release-web.yml  →  ./.github/actions/shared-env
#
# - op-engineering.op-s2 (workflow files: 1)
#     • op-engineering.op-s2__github_actions++ci.yml  →  ./.github/actions/setup
#
# - opener-next.openstop (workflow files: 3)
#     • opener-next.openstop__github_actions++build_app.yml  →  ./.github/actions/environment_setup
#     • opener-next.openstop__github_actions++code_validation.yml  →  ./.github/actions/environment_setup
#     • opener-next.openstop__github_actions++tests.yml  →  ./app/.github/actions/environment_setup
#
# - openflutter.fluwx (workflow files: 1)
#     • openflutter.fluwx__github_actions++publish.yml  →  ./.github/actions/publish_flutter_package
#
# - oppzippy.openscq30 (workflow files: 2)
#     • oppzippy.openscq30__github_actions++build.yml  →  ./.github/actions/install-android-build-tools
#     • oppzippy.openscq30__github_actions++test.yml  →  ./.github/actions/install-android-build-tools
#
# - orchidtechnologies.orchid (workflow files: 1)
#     • orchidtechnologies.orchid__github_actions++main.yml  →  ./.github/actions/nerdctl;./.github/actions/submodule
#
# - owntracks.android (workflow files: 4)
#     • owntracks.android__github_actions++build-test-lint.yaml  →  ./.github/actions/gradle-task
#     • owntracks.android__github_actions++espresso.yaml  →  ./.github/actions/upload-artifact
#     • owntracks.android__github_actions++release.yaml  →  ./.github/actions/gradle-task
#     • owntracks.android__github_actions++trunk-build.yaml  →  ./.github/actions/gradle-task
#
# - pachli.pachli-android (workflow files: 4)
#     • pachli.pachli-android__github_actions++apk-on-comment.yml  →  ./.github/actions/setup-build-env
#     • pachli.pachli-android__github_actions++ci.yml  →  ./.github/actions/setup-build-env
#     • pachli.pachli-android__github_actions++upload-blue-release-google-play.yml  →  ./.github/actions/setup-build-env
#     • pachli.pachli-android__github_actions++upload-orange-release.yml  →  ./.github/actions/setup-build-env
#
# - pokeapi.pokekotlin (workflow files: 3)
#     • pokeapi.pokekotlin__github_actions++ci.yml  →  ./.github/actions/setup
#     • pokeapi.pokekotlin__github_actions++daily.yml  →  ./.github/actions/setup
#     • pokeapi.pokekotlin__github_actions++release.yml  →  ./.github/actions/setup
#
# - powersync-ja.powersync.dart (workflow files: 2)
#     • powersync-ja.powersync.dart__github_actions++check.yml  →  ./.github/actions/prepare
#     • powersync-ja.powersync.dart__github_actions++release.yml  →  ./.github/actions/prepare
#
# - prisma.react-native-prisma (workflow files: 3)
#     • prisma.react-native-prisma__github_actions++check-updates.yml  →  ./.github/actions/setup
#     • prisma.react-native-prisma__github_actions++test.yml  →  ./.github/actions/setup
#     • prisma.react-native-prisma__github_actions++update-and-publish.yml  →  ./.github/actions/setup
#
# - privacybydesign.irmamobile (workflow files: 2)
#     • privacybydesign.irmamobile__github_actions++delivery.yml  →  ./.github/actions/setup-build-environment
#     • privacybydesign.irmamobile__github_actions++status-checks.yml  →  ./.github/actions/setup-build-environment
#
# - processing.processing-sound (workflow files: 3)
#     • processing.processing-sound__github_actions++pr.yml  →  ./.github/actions/setup
#     • processing.processing-sound__github_actions++push.yml  →  ./.github/actions/setup
#     • processing.processing-sound__github_actions++tag.yml  →  ./.github/actions/setup
#
# - prof18.feed-flow (workflow files: 7)
#     • prof18.feed-flow__github_actions++android-release.yml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++code-checks.yaml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++ios-release.yml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++linux-release.yml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++macos-release.yml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++macos-testflight-release.yml  →  ./.github/actions/setup-gradle
#     • prof18.feed-flow__github_actions++windows-release.yml  →  ./.github/actions/setup-gradle
#
# - rafaeltonholo.svg-to-compose (workflow files: 3)
#     • rafaeltonholo.svg-to-compose__github_actions++pull_request.yml  →  ./.github/actions/cli-integrity-check;./.github/actions/setup;./.github/actions/setup-nodejs
#     • rafaeltonholo.svg-to-compose__github_actions++release.v2.yml  →  ./.github/actions/cli-integrity-check;./.github/actions/setup;./.github/actions/setup-nodejs
#     • rafaeltonholo.svg-to-compose__github_actions++release.yml  →  ./.github/actions/cli-integrity-check;./.github/actions/setup;./.github/actions/setup-nodejs
#
# - rainbow-me.rainbow (workflow files: 3)
#     • rainbow-me.rainbow__github_actions++android-e2e.yml  →  ./.github/actions/android-emulator/;./.github/actions/ssh/
#     • rainbow-me.rainbow__github_actions++macstadium-clear-cache-all-instances.yml  →  ./.github/actions/clear-cache
#     • rainbow-me.rainbow__github_actions++unit-test.yml  →  ./.github/actions/ssh/
#
# - react-native-community.jsc-android-buildscripts (workflow files: 1)
#     • react-native-community.jsc-android-buildscripts__github_actions++build_and_test.yml  →  ./.github/actions/cleanup-linux-disk-space
#
# - reactivecircus.android-emulator-runner (workflow files: 2)
#     • reactivecircus.android-emulator-runner__github_actions++main.yml  →  ./
#     • reactivecircus.android-emulator-runner__github_actions++manually.yml  →  ./
#
# - realm.realm-js (workflow files: 5)
#     • realm.realm-js__github_actions++package-unit-tests.yml  →  ./.github/actions/baas-test-server
#     • realm.realm-js__github_actions++pr-coverage.yml  →  ./.github/actions/baas-test-server
#     • realm.realm-js__github_actions++pr-realm-js.yml  →  ./.github/actions/baas-test-server
#     • realm.realm-js__github_actions++pr-realm-web.yml  →  ./.github/actions/baas-test-server
#     • realm.realm-js__github_actions++test-server.yml  →  ./.github/actions/baas-test-server
#
# - realm.realm-kotlin (workflow files: 1)
#     • realm.realm-kotlin__github_actions++pr.yml  →  ./.github/actions/run-android-device-farm-test
#
# - red.red (workflow files: 2)
#     • red.red__github_actions++linux.yml  →  ./CI/Linux-32;./CI/Linux-gtk
#     • red.red__github_actions++rpi.yml  →  ./CI/Linux-32
#
# - redot-engine.redot-engine (workflow files: 6)
#     • redot-engine.redot-engine__github_actions++android_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
#     • redot-engine.redot-engine__github_actions++ios_builds.yml  →  ./.github/actions/godot-build;./.github/actions/godot-cache-restore;./.github/actions/godot-cache-save;./.github/actions/godot-deps;./.github/actions/upload-artifact
# ...
#
# - sergeymild.react-native-jsi-cpr (workflow files: 1)
#     • sergeymild.react-native-jsi-cpr__github_actions++ci.yml  →  ./.github/actions/setup
#
# - servo.servo (workflow files: 15)
#     • servo.servo__github_actions++android.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++bencher.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++docs.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++lint.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++linux-wpt.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++linux.yml  →  ./.github/actions/runner-timeout;./.github/actions/setup-python
#     • servo.servo__github_actions++mac-wpt.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++mac.yml  →  ./.github/actions/runner-timeout;./.github/actions/setup-python
#     • servo.servo__github_actions++main.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++ohos.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++pull-request-wpt-export.yml  →  ./servo/.github/actions/setup-python
#     • servo.servo__github_actions++scheduled-wpt-import.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++try-label.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++try.yml  →  ./.github/actions/setup-python
#     • servo.servo__github_actions++windows.yml  →  ./.github/actions/runner-timeout;./.github/actions/setup-python
#
# - simpleble.simpleble (workflow files: 10)
#     • simpleble.simpleble__github_actions++ci_docs.yml  →  ./.github/actions/package-native
#     • simpleble.simpleble__github_actions++ci_linux_internals.yml  →  ./.github/actions/build-native;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_main.yml  →  ./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simpleble.yml  →  ./.github/actions/build-native;./.github/actions/package-native;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simplecble.yml  →  ./.github/actions/build-native;./.github/actions/package-native;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simpledroidble.yml  →  ./.github/actions/package-native;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simplejavable.yml  →  ./.github/actions/build-native;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simplepyble.yml  →  ./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_simplersble.yml  →  ./.github/actions/build-dbus-full;./.github/actions/setup-cmake;./.github/actions/setup-version
#     • simpleble.simpleble__github_actions++ci_smoketest.yml  →  ./.github/actions/build-dbus-full;./.github/actions/build-native;./.github/actions/setup-cmake;./.github/actions/setup-version
#
# - simplex-chat.simplex-chat (workflow files: 1)
#     • simplex-chat.simplex-chat__github_actions++build.yml  →  ./.github/actions/prepare-build;./.github/actions/prepare-release;./.github/actions/swap
#
# - software-mansion.react-native-screens (workflow files: 4)
#     • software-mansion.react-native-screens__github_actions++close-when-stale.yml  →  ./close-when-stale
#     • software-mansion.react-native-screens__github_actions++needs-more-info.yml  →  ./needs-more-info
#     • software-mansion.react-native-screens__github_actions++needs-repro.yml  →  ./needs-repro
#     • software-mansion.react-native-screens__github_actions++platforms.yml  →  ./platforms
#
# - software-mansion.react-native-svg (workflow files: 3)
#     • software-mansion.react-native-svg__github_actions++close-when-stale.yml  →  ./close-when-stale
#     • software-mansion.react-native-svg__github_actions++needs-more-info.yml  →  ./needs-more-info
#     • software-mansion.react-native-svg__github_actions++needs-repro.yml  →  ./needs-repro
#
# - solrudev.ackpine (workflow files: 2)
#     • solrudev.ackpine__github_actions++ci.yml  →  ./.github/actions/setup-gradle-environment-action
#     • solrudev.ackpine__github_actions++github-release.yml  →  ./.github/actions/setup-gradle-environment-action
#
# - sosog.react-native-dynamically-selected-picker (workflow files: 1)
#     • sosog.react-native-dynamically-selected-picker__github_actions++ci.yml  →  ./.github/actions/setup
#
# - square.workflow-kotlin (workflow files: 3)
#     • square.workflow-kotlin__github_actions++kotlin.yml  →  ./.github/actions/gradle-task;./.github/actions/gradle-task-with-commit;./.github/actions/gradle-tasks-with-emulator
#     • square.workflow-kotlin__github_actions++publish-release.yml  →  ./.github/actions/gradle-task
#     • square.workflow-kotlin__github_actions++publish-snapshot.yml  →  ./.github/actions/gradle-task
#
# - stallion-tech.react-native-stallion (workflow files: 2)
#     • stallion-tech.react-native-stallion__github_actions++ci-pre-release.yml  →  ./.github/actions/setup
#     • stallion-tech.react-native-stallion__github_actions++ci.yml  →  ./.github/actions/setup
#
# - standardnotes.app (workflow files: 3)
#     • standardnotes.app__github_actions++clipper.release.prod.yml  →  ./actions/release-notes
#     • standardnotes.app__github_actions++desktop.release.reuse.yml  →  ./actions/release-notes
#     • standardnotes.app__github_actions++mobile.release.prod.yml  →  ./actions/release-notes
#
# - streetwriters.notesnook (workflow files: 14)
#     • streetwriters.notesnook__github_actions++android.e2e.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++android.publish.internal.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++android.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++core.tests.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++desktop.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++desktop.tests.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++editor.tests.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++ios.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++monograph.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++theme-builder.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++vericrypt.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++web.benchmarks.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++web.publish.yml  →  ./.github/actions/setup-node-with-cache
#     • streetwriters.notesnook__github_actions++web.tests.yml  →  ./.github/actions/setup-node-with-cache
#
# - subsurface.subsurface (workflow files: 13)
#     • subsurface.subsurface__github_actions++android.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++coverity-scan.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++documentation-publish.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++fedora-copr-build.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++linux-debian-generic.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++linux-fedora-35-qt6.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++linux-snap.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++linux-ubuntu-20.04-qt5-appimage.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++linux-ubuntu-24.04-qt5-export-html.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++mac.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++post-releasenotes.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++ubuntu-launchpad-build.yml  →  ./.github/actions/manage-version
#     • subsurface.subsurface__github_actions++windows.yml  →  ./.github/actions/manage-version
#
# - supershadoe.delta (workflow files: 2)
#     • supershadoe.delta__github_actions++ci.yml  →  ./.github/actions/gradle-setup;./.github/actions/run-lints;./.github/actions/run-tests
#     • supershadoe.delta__github_actions++release.yml  →  ./.github/actions/build-apk
#
# - susatthi.github-search (workflow files: 1)
#     • susatthi.github-search__github_actions++flutter_ci.yaml  →  ./.github/actions/setup_flutter
#
# - suwu150.react-native-tree-select (workflow files: 1)
#     • suwu150.react-native-tree-select__github_actions++ci.yml  →  ./.github/actions/setup
#
# - swisscovid.swisscovid-app-android (workflow files: 4)
#     • swisscovid.swisscovid-app-android__github_actions++android.yml  →  ./.github/actions/gradle_docker
#     • swisscovid.swisscovid-app-android__github_actions++appcenter_abnahme.yml  →  ./.github/actions/gradle_docker
#     • swisscovid.swisscovid-app-android__github_actions++appcenter_dev.yml  →  ./.github/actions/gradle_docker
#     • swisscovid.swisscovid-app-android__github_actions++appcenter_prod.yml  →  ./.github/actions/gradle_docker
#
# - telosnex.fllama (workflow files: 9)
#     • telosnex.fllama__github_actions++build.yml  →  ./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++build__2.yml  →  ./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++build__3.yml  →  ./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++release.yml  →  ./.github/actions/get-tag-name;./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++release__2.yml  →  ./.github/actions/get-tag-name;./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++release__3.yml  →  ./.github/actions/get-tag-name;./.github/actions/windows-setup-cuda;./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++server.yml  →  ./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++server__2.yml  →  ./.github/actions/windows-setup-curl
#     • telosnex.fllama__github_actions++server__3.yml  →  ./.github/actions/windows-setup-curl
#
# - thewidlarzgroup.react-native-video (workflow files: 3)
#     • thewidlarzgroup.react-native-video__github_actions++build-android.yml  →  ./.github/actions/setup-node
#     • thewidlarzgroup.react-native-video__github_actions++build-ios.yml  →  ./.github/actions/setup-node
#     • thewidlarzgroup.react-native-video__github_actions++check-js.yml  →  ./.github/actions/setup-node
#
# - tloncorp.tlon-apps (workflow files: 5)
#     • tloncorp.tlon-apps__github_actions++build-and-glob.yml  →  ./.github/actions/glob
#     • tloncorp.tlon-apps__github_actions++deploy-canary.yml  →  ./.github/actions/glob
#     • tloncorp.tlon-apps__github_actions++deploy-ephemeral.yml  →  ./.github/actions/glob
#     • tloncorp.tlon-apps__github_actions++deploy.yml  →  ./.github/actions/glob
#     • tloncorp.tlon-apps__github_actions++glob-and-deploy-kernel.yml  →  ./.github/actions/glob
#
# - toeverything.octobase (workflow files: 4)
#     • toeverything.octobase__github_actions++benchmark.yml  →  ./.github/actions/setup-rust
#     • toeverything.octobase__github_actions++jwst-asan.yml  →  ./.github/actions/setup-rust
#     • toeverything.octobase__github_actions++jwst-memory-test.yml  →  ./.github/actions/setup-rust
#     • toeverything.octobase__github_actions++jwst.yml  →  ./.github/actions/setup-rust
#
# - topjohnwu.magisk (workflow files: 1)
#     • topjohnwu.magisk__github_actions++build.yml  →  ./.github/actions/setup
#
# - tr3v3r.react-native-esc-pos-printer (workflow files: 1)
#     • tr3v3r.react-native-esc-pos-printer__github_actions++ci.yml  →  ./.github/actions/setup
#
# - vonovak.react-native-simple-toast (workflow files: 1)
#     • vonovak.react-native-simple-toast__github_actions++ci.yml  →  ./.github/actions/setup
#
# - wger-project.flutter (workflow files: 6)
#     • wger-project.flutter__github_actions++build-android.yml  →  ./.github/actions/flutter-common
#     • wger-project.flutter__github_actions++build-apple.yml  →  ./.github/actions/flutter-common
#     • wger-project.flutter__github_actions++build-linux.yml  →  ./.github/actions/flutter-common
#     • wger-project.flutter__github_actions++build-windows.yml  →  ./.github/actions/flutter-common
#     • wger-project.flutter__github_actions++bump-version.yml  →  ./.github/actions/flutter-common
#     • wger-project.flutter__github_actions++ci.yml  →  ./.github/actions/flutter-common
#
# - wireapp.kalium (workflow files: 9)
#     • wireapp.kalium__github_actions++backup-publish-swift.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++backup-publish-web-npm.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++benchmarks-check.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++codestyle.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++generate-dokka.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++gradle-android-instrumented-tests.yml  →  ./.github/actions/get-avd-info;./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++gradle-android-unit-tests.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++gradle-ios-tests.yml  →  ./.github/actions/setup-java-gradle
#     • wireapp.kalium__github_actions++gradle-jvm-tests.yml  →  ./.github/actions/setup-java-gradle
#
# - wolfenrain.fluttium (workflow files: 1)
#     • wolfenrain.fluttium__github_actions++main.yaml  →  ./.github/actions/dart_package;./.github/actions/docs;./.github/actions/flutter_package;./.github/actions/pana
#
# - xrpl-labs.xaman-app (workflow files: 5)
#     • xrpl-labs.xaman-app__github_actions++android.yml  →  ./.github/actions/prepare-env
#     • xrpl-labs.xaman-app__github_actions++e2e.yml  →  ./.github/actions/prepare-env
#     • xrpl-labs.xaman-app__github_actions++ios.yml  →  ./.github/actions/prepare-env
#     • xrpl-labs.xaman-app__github_actions++unit.yml  →  ./.github/actions/prepare-env
#     • xrpl-labs.xaman-app__github_actions++validate.yml  →  ./.github/actions/prepare-env
#
# - xxfast.decompose-router (workflow files: 1)
#     • xxfast.decompose-router__github_actions++build.yml  →  ./.github/actions/get-avd-info
#
# - yogeshpaliyal.keypass (workflow files: 7)
#     • yogeshpaliyal.keypass__github_actions++generate-aab-release.yml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++generate-baseline-profile.yml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++generate-pro-aab-release.yml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++master-apk-create.yml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++pr-check.yaml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++reportsexports.yml  →  ./.github/actions/setup
#     • yogeshpaliyal.keypass__github_actions++uploadbuildontag.yaml  →  ./.github/actions/setup
#
# - yutasuzuki.react-native-record-screen (workflow files: 1)
#     • yutasuzuki.react-native-record-screen__github_actions++ci.yml  →  ./.github/actions/setup
#
# - zt64.hyperion (workflow files: 2)
#     • zt64.hyperion__github_actions++build.yml  →  ./.github/actions/setup-env
#     • zt64.hyperion__github_actions++pr.yml  →  ./.github/actions/setup-env
#
#
# 💾 Details written to: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ1\Local_Instru_Tests\Repos_with_Local_GHA_Actions_NON_WORKFLOW.csv

# %%
## Download the local yml files through a similar clone with the initial data extraction with the cut off date: Aug 10, 2025

# %%
# -*- coding: utf-8 -*-
from __future__ import annotations

import csv
import os
import re
import shutil
import stat
import subprocess
import time
from dataclasses import dataclass, field
from pathlib import Path
from typing import Dict, Optional, Set
from urllib.parse import urlparse

import pandas as pd
import requests
from dotenv import load_dotenv

# ========= CONFIG & PATHS =========

# Your env file location (as you stated)
ENV_DIR = Path(r"C:\GitHub\Android-Mobile-Apps")
ENV_FILE_NAME = "All_Tokens.env"  # keep this exact filename

# Cutoff date (ISO 8601, UTC)
CUTOFF_ISO = "2025-08-10T23:59:59Z"

# Base RQ1 directory
BASE_RQ1 = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ1")

# URL list for all repos
URL_LIST_CSV = BASE_RQ1 / "URL_List.csv"

# Local instrumentation detection results
LOCAL_INSTRU_DIR = BASE_RQ1 / "Local_Instru_Tests"
LOCAL_NON_WORKFLOW_CSV = LOCAL_INSTRU_DIR / "Repos_with_Local_GHA_Actions_NON_WORKFLOW.csv"

# TEMP git dirs per repo (no checkout)
CLONE_DIR = LOCAL_INSTRU_DIR / "Local_Cloned_Repos"

# Where we store extracted local YAML files
OUTPUT_YML_DIR = LOCAL_INSTRU_DIR / "All_Local_YMLs"

# Index CSV describing extracted local YAMLs
LOCAL_INDEX_CSV = LOCAL_INSTRU_DIR / "Local_YML_Extraction_Index.csv"

# Whether to keep temp git dirs after extraction
KEEP_CLONES = False

# --- GitHub API behavior ---
REQUEST_TIMEOUT_SECONDS = 30

# If tokens are rate-limited, do you want to WAIT until reset?
# For your use-case, default False so we just fall back to HEAD and continue extraction.
WAIT_FOR_RATE_LIMIT_RESET = False

# Secondary limit backoff (short, bounded)
SECONDARY_BACKOFF_BASE_SECONDS = 10
SECONDARY_BACKOFF_MAX_SECONDS = 90
MAX_SECONDARY_RETRIES_PER_CALL = 3
MAX_TOTAL_API_ATTEMPTS_PER_CALL = 50

# Git on Windows
GIT_PREFIX = ["git", "-c", "core.longpaths=true"]


# ========= subprocess helpers =========

def run_text(cmd, cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    """Run a command and capture stdout+stderr as text, safely decoded."""
    return subprocess.run(
        cmd,
        cwd=str(cwd) if cwd else None,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        check=check,
    )

def run_bytes(cmd, cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    """Run a command and capture stdout+stderr as bytes."""
    return subprocess.run(
        cmd,
        cwd=str(cwd) if cwd else None,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=False,
        check=check,
    )

def force_remove_readonly(func, path, _):
    os.chmod(path, stat.S_IWRITE)
    func(path)

def sanitize_token(s: str) -> str:
    return re.sub(r"[^a-z0-9._+-]", "_", s.lower())

def split_stem_and_suffixes(name: str):
    p = Path(name)
    suffixes = "".join(p.suffixes)
    if suffixes:
        return name[:-len(suffixes)], suffixes
    return name, ""

def _counter_candidate(base_name: str, n: int) -> str:
    if n == 1:
        return base_name
    if "++" in base_name:
        head, tail = base_name.split("++", 1)
        tail_stem, tail_suf = split_stem_and_suffixes(tail)
        return f"{head}++{tail_stem}__{n}{tail_suf}"
    stem, suf = split_stem_and_suffixes(base_name)
    return f"{stem}__{n}{suf}"

def resolve_counter_name(bucket_dir: Path, base_name: str, in_memory_taken: Set[str]) -> str:
    n = 1
    while True:
        candidate = _counter_candidate(base_name, n)
        if candidate not in in_memory_taken and not (bucket_dir / candidate).exists():
            in_memory_taken.add(candidate)
            return candidate
        n += 1

def make_flat_filename(owner: str, project: str, ci_platform: str, file_name: str) -> str:
    owner_tok = sanitize_token(owner)
    project_tok = sanitize_token(project)
    ci_tok = sanitize_token(ci_platform or "other")
    file_lower = file_name.lower()
    return f"{owner_tok}.{project_tok}__{ci_tok}++{file_lower}"

def save_bytes(bucket_dir: Path, flat_filename: str, content: bytes, in_memory_taken: Set[str]) -> Path:
    bucket_dir.mkdir(parents=True, exist_ok=True)
    final_name = resolve_counter_name(bucket_dir, flat_filename, in_memory_taken)
    dest = bucket_dir / final_name
    dest.write_bytes(content)
    return dest


# ========= branch detection =========

def detect_default_branch(repo_url: str) -> str:
    try:
        out = run_text(GIT_PREFIX + ["ls-remote", "--symref", repo_url, "HEAD"]).stdout
        for line in out.splitlines():
            s = line.strip()
            if s.startswith("ref: ") and s.endswith("HEAD"):
                ref = s.split()[1]  # refs/heads/main
                if ref.startswith("refs/heads/"):
                    return ref.split("/", 2)[2]
    except Exception:
        pass

    for guess in ("main", "master"):
        try:
            run_text(GIT_PREFIX + ["ls-remote", repo_url, f"refs/heads/{guess}"], check=True)
            return guess
        except Exception:
            continue

    raise RuntimeError("Could not determine default branch via git ls-remote")


# ========= load tokens (notebook + script safe) =========

def find_env_file(env_dir: Path, env_filename: str) -> Path:
    """
    Try these locations (in order):
      1) ENV_DIR/env_filename (your stated location)
      2) cwd/env_filename
      3) BASE_RQ1/env_filename
      4) parents of cwd (up to 5 levels)
      5) script directory (if available)
    """
    candidates: list[Path] = []

    candidates.append(env_dir / env_filename)
    candidates.append(Path.cwd() / env_filename)
    candidates.append(BASE_RQ1 / env_filename)

    # walk up cwd a bit (helpful in notebooks)
    cur = Path.cwd()
    for _ in range(5):
        candidates.append(cur / env_filename)
        if cur.parent == cur:
            break
        cur = cur.parent

    # script dir (if running as a script)
    try:
        script_dir = Path(__file__).resolve().parent  # type: ignore[name-defined]
        candidates.append(script_dir / env_filename)
    except NameError:
        pass

    env_path = next((p for p in candidates if p.exists()), None)
    if env_path is None:
        raise FileNotFoundError(
            f"Could not find env file '{env_filename}'. Tried:\n" +
            "\n".join(f"  {p}" for p in candidates)
        )
    return env_path

def load_tokens(env_dir: Path, env_filename: str) -> list[str]:
    env_path = find_env_file(env_dir, env_filename)
    load_dotenv(dotenv_path=str(env_path), override=True)

    tokens: list[str] = []
    for i in range(1, 50):
        t = os.getenv(f"GITHUB_TOKEN_{i}")
        if t:
            tokens.append(t.strip())
    return tokens


TOKENS = load_tokens(ENV_DIR, ENV_FILE_NAME)


# ========= GitHub API: rotation + backoff =========

GITHUB_API_BASE_HEADERS = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28",
}

@dataclass
class TokenState:
    remaining: Optional[int] = None
    reset_epoch: Optional[int] = None
    disabled: bool = False

@dataclass
class TokenPool:
    tokens: list[str]
    idx: int = 0
    state: Dict[str, TokenState] = field(default_factory=dict)

    def __post_init__(self):
        for t in self.tokens:
            self.state.setdefault(t, TokenState())

    def _is_usable(self, token: str) -> bool:
        st = self.state[token]
        if st.disabled:
            return False
        now = int(time.time())
        if st.remaining == 0 and st.reset_epoch and st.reset_epoch > now:
            return False
        return True

    def next_token(self) -> Optional[str]:
        if not self.tokens:
            return None
        for _ in range(len(self.tokens)):
            token = self.tokens[self.idx % len(self.tokens)]
            self.idx += 1
            if self._is_usable(token):
                return token
        return None

    def mark_rate_info(self, token: str, remaining: Optional[int], reset_epoch: Optional[int]) -> None:
        st = self.state[token]
        if remaining is not None:
            st.remaining = remaining
        if reset_epoch is not None:
            st.reset_epoch = reset_epoch

    def disable(self, token: str) -> None:
        self.state[token].disabled = True

    def earliest_reset(self) -> Optional[int]:
        resets = [
            st.reset_epoch
            for st in self.state.values()
            if st.reset_epoch is not None and st.remaining == 0 and not st.disabled
        ]
        return min(resets) if resets else None


SESSION = requests.Session()
POOL = TokenPool(TOKENS)

def _parse_int_header(resp: requests.Response, name: str) -> Optional[int]:
    v = resp.headers.get(name)
    if v is None:
        return None
    try:
        return int(v)
    except Exception:
        return None

def github_get(url: str, params: dict) -> requests.Response:
    secondary_tries = 0
    attempts = 0

    while attempts < MAX_TOTAL_API_ATTEMPTS_PER_CALL:
        attempts += 1

        token = POOL.next_token()
        headers = dict(GITHUB_API_BASE_HEADERS)
        if token:
            headers["Authorization"] = f"Bearer {token}"

        resp = SESSION.get(url, headers=headers, params=params, timeout=REQUEST_TIMEOUT_SECONDS)

        # Parse message if possible
        msg = ""
        try:
            j = resp.json()
            if isinstance(j, dict):
                msg = str(j.get("message", "") or "")
        except Exception:
            pass

        remaining = _parse_int_header(resp, "X-RateLimit-Remaining")
        reset = _parse_int_header(resp, "X-RateLimit-Reset")
        retry_after = _parse_int_header(resp, "Retry-After")

        if token:
            POOL.mark_rate_info(token, remaining, reset)

        if resp.status_code == 200:
            return resp

        if resp.status_code == 401:
            if token:
                print("  GitHub API: 401 Unauthorized; disabling that token.")
                POOL.disable(token)
            return resp

        if resp.status_code in (403, 429):
            low_msg = msg.lower()

            # secondary rate limit
            if "secondary rate limit" in low_msg:
                if secondary_tries >= MAX_SECONDARY_RETRIES_PER_CALL:
                    return resp
                wait_s = retry_after if retry_after is not None else (SECONDARY_BACKOFF_BASE_SECONDS * (2 ** secondary_tries))
                wait_s = min(wait_s, SECONDARY_BACKOFF_MAX_SECONDS)
                secondary_tries += 1
                print(f"  GitHub API: secondary rate limit; sleeping {wait_s}s then retrying...")
                time.sleep(wait_s)
                continue

            # primary rate limit exhausted
            if remaining == 0:
                # try other token
                next_tok = POOL.next_token()
                if next_tok is not None:
                    continue

                # all tokens exhausted
                if not WAIT_FOR_RATE_LIMIT_RESET:
                    return resp

                earliest = POOL.earliest_reset()
                if earliest is None:
                    return resp
                now = int(time.time())
                sleep_s = max(1, earliest - now)
                print(f"  GitHub API: all tokens exhausted; sleeping {sleep_s}s until reset...")
                time.sleep(sleep_s)
                continue

            return resp

        return resp

    return resp

def get_cutoff_commit(owner: str, repo: str, branch: str, cutoff_iso: str) -> Optional[str]:
    url = f"https://api.github.com/repos/{owner}/{repo}/commits"
    params = {"sha": branch, "until": cutoff_iso, "per_page": 1}

    resp = github_get(url, params=params)
    if resp.status_code != 200:
        try:
            j = resp.json()
            msg = j.get("message", "") if isinstance(j, dict) else ""
        except Exception:
            msg = (resp.text or "")[:200]

        print(
            f"  GitHub API error for {owner}/{repo} commits: {resp.status_code} {msg} "
            f"(remaining={resp.headers.get('X-RateLimit-Remaining')}, reset={resp.headers.get('X-RateLimit-Reset')}, "
            f"retry_after={resp.headers.get('Retry-After')})"
        )
        return None

    data = resp.json()
    if not isinstance(data, list) or not data:
        return None
    return data[0].get("sha")


# ========= git read without checkout =========

def normalize_uses_path(uses_path: str) -> str:
    norm = uses_path.strip().strip('"').strip("'").replace("\\", "/")
    if norm.startswith("./"):
        norm = norm[2:]
    norm = norm.lstrip("/")
    norm = norm.rstrip("/")
    if norm in ("", "."):
        return ""  # repo root
    return norm

def git_path_exists(repo_dir: Path, commit_sha: str, rel_path: str) -> bool:
    if not rel_path:
        return False
    target = f"{commit_sha}:{rel_path}"
    proc = run_text(GIT_PREFIX + ["cat-file", "-e", target], cwd=repo_dir, check=False)
    return proc.returncode == 0

def git_show_file(repo_dir: Path, commit_sha: str, rel_path: str) -> Optional[bytes]:
    if not rel_path:
        return None
    target = f"{commit_sha}:{rel_path}"
    proc = run_bytes(GIT_PREFIX + ["show", target], cwd=repo_dir, check=False)
    if proc.returncode != 0:
        return None
    return proc.stdout

def resolve_action_yaml_path_at_commit(repo_dir: Path, commit_sha: str, uses_path: str) -> Optional[str]:
    norm = normalize_uses_path(uses_path)

    # direct YAML file
    if norm.lower().endswith((".yml", ".yaml")):
        return norm if git_path_exists(repo_dir, commit_sha, norm) else None

    # directory action.yml/action.yaml or root action.yml/action.yaml
    for fname in ("action.yml", "action.yaml"):
        candidate = f"{norm}/{fname}" if norm else fname
        if git_path_exists(repo_dir, commit_sha, candidate):
            return candidate

    return None

def prepare_git_dir(repo_git_dir: Path, github_url: str) -> None:
    if repo_git_dir.exists():
        shutil.rmtree(repo_git_dir, onerror=force_remove_readonly)
    repo_git_dir.mkdir(parents=True, exist_ok=True)
    run_text(GIT_PREFIX + ["init"], cwd=repo_git_dir)
    run_text(GIT_PREFIX + ["remote", "add", "origin", github_url], cwd=repo_git_dir)

def fetch_ref(repo_git_dir: Path, ref: str) -> str:
    run_text(GIT_PREFIX + ["fetch", "--depth", "1", "origin", ref], cwd=repo_git_dir)
    sha = run_text(GIT_PREFIX + ["rev-parse", "FETCH_HEAD"], cwd=repo_git_dir).stdout.strip()
    return sha


# ========= MAIN =========

def main():
    LOCAL_INSTRU_DIR.mkdir(parents=True, exist_ok=True)
    CLONE_DIR.mkdir(parents=True, exist_ok=True)
    OUTPUT_YML_DIR.mkdir(parents=True, exist_ok=True)

    print(f"Loaded {len(TOKENS)} GitHub token(s) from {ENV_DIR}\\{ENV_FILE_NAME}")
    if len(TOKENS) == 0:
        print("WARNING: Running unauthenticated -> you WILL hit API rate limits quickly.")

    # 1) Load URL list
    if not URL_LIST_CSV.exists():
        raise FileNotFoundError(f"URL list CSV not found: {URL_LIST_CSV}")

    url_df = pd.read_csv(URL_LIST_CSV)
    url_df.columns = url_df.columns.str.strip().str.lower()
    if "github_url" not in url_df.columns:
        raise ValueError("URL_List.csv must contain a 'github_url' column")

    owner_repo_to_info: Dict[str, Dict[str, str]] = {}
    for raw_url in url_df["github_url"].dropna().astype(str):
        raw_url = raw_url.strip()
        if not raw_url.startswith("http"):
            continue
        parsed = urlparse(raw_url)
        parts = parsed.path.strip("/").split("/")
        if len(parts) < 2:
            continue
        owner_raw, project_raw = parts[0], parts[1].replace(".git", "")
        key = f"{sanitize_token(owner_raw)}.{sanitize_token(project_raw)}"
        owner_repo_to_info[key] = {"github_url": raw_url, "owner": owner_raw, "project": project_raw}

    print(f"Built mapping for {len(owner_repo_to_info)} repos from URL_List.csv")

    # 2) Load NON_WORKFLOW local uses CSV
    if not LOCAL_NON_WORKFLOW_CSV.exists():
        raise FileNotFoundError(f"Local NON_WORKFLOW CSV not found: {LOCAL_NON_WORKFLOW_CSV}")

    local_df = pd.read_csv(LOCAL_NON_WORKFLOW_CSV)
    local_df.columns = local_df.columns.str.strip()

    if "owner_repo" not in local_df.columns or "uses_paths" not in local_df.columns:
        raise ValueError("Repos_with_Local_GHA_Actions_NON_WORKFLOW.csv must contain 'owner_repo' and 'uses_paths' columns")

    local_uses_by_repo: Dict[str, Set[str]] = {}
    for _, row in local_df.iterrows():
        owner_repo = str(row["owner_repo"]).strip()
        uses_field = str(row["uses_paths"]).strip()
        if not owner_repo or not uses_field or uses_field.lower() == "nan":
            continue
        for raw_part in uses_field.split(";"):
            up = raw_part.strip()
            if up:
                local_uses_by_repo.setdefault(owner_repo, set()).add(up)

    print(f"Found {len(local_uses_by_repo)} repos with NON-workflow local uses")

    # 3) Prepare index CSV
    index_fields = [
        "owner",
        "repo",
        "owner_repo_key",
        "github_url",
        "default_branch",
        "snapshot_commit",   # actual fetched SHA (cutoff or HEAD)
        "local_use_path",
        "relative_path",
        "filename",
        "flat_filename",
        "saved_to",
    ]
    if not LOCAL_INDEX_CSV.exists():
        with LOCAL_INDEX_CSV.open("w", newline="", encoding="utf-8") as f:
            csv.DictWriter(f, fieldnames=index_fields).writeheader()

    used_flat_names: Set[str] = set()

    # 4) Process repos
    for owner_repo_key, uses_set in sorted(local_uses_by_repo.items()):
        info = owner_repo_to_info.get(owner_repo_key)
        if not info:
            print(f"No URL found in URL_List.csv for key: {owner_repo_key} – skipping.")
            continue

        github_url = info["github_url"]
        owner = info["owner"]
        project = info["project"]

        print(f"\nProcessing repo {owner_repo_key} -> {github_url}")

        # default branch
        try:
            default_branch = detect_default_branch(github_url)
            print(f"  Default branch: {default_branch}")
        except Exception as e:
            print(f"  Failed to detect default branch: {e}")
            continue

        # cutoff commit via API; if none or API fails, fall back to HEAD branch
        cutoff_sha = get_cutoff_commit(owner, project, default_branch, CUTOFF_ISO)
        fetch_ref_name = cutoff_sha or default_branch

        if cutoff_sha:
            print(f"  Cutoff commit (API): {cutoff_sha}")
        else:
            print(f"  No cutoff commit (none before cutoff OR API failure). Falling back to HEAD of {default_branch}")

        # temp git dir
        repo_git_dir = CLONE_DIR / owner_repo_key.replace("/", "_")
        try:
            prepare_git_dir(repo_git_dir, github_url)
            snapshot_sha = fetch_ref(repo_git_dir, fetch_ref_name)
            print(f"  Fetched snapshot commit: {snapshot_sha}")
        except Exception as e:
            if isinstance(e, subprocess.CalledProcessError):
                print(f"  Failed to prepare/fetch repo:\n{e.stdout}")
            else:
                print(f"  Failed to prepare/fetch repo: {e}")
            continue

        # resolve & save each local use path
        for local_path in sorted(uses_set):
            print(f"    Resolving local use path: {local_path}")

            rel_file_path = resolve_action_yaml_path_at_commit(repo_git_dir, snapshot_sha, local_path)
            if not rel_file_path:
                print(f"    Could not resolve YAML for local path in snapshot: {local_path}")
                continue

            content = git_show_file(repo_git_dir, snapshot_sha, rel_file_path)
            if content is None:
                print(f"    Could not read file content via git show: {rel_file_path}")
                continue

            filename = Path(rel_file_path).name
            flat_filename_base = make_flat_filename(owner, project, "github_actions", filename)
            dest_path = save_bytes(OUTPUT_YML_DIR, flat_filename_base, content, used_flat_names)

            with LOCAL_INDEX_CSV.open("a", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=index_fields)
                writer.writerow({
                    "owner": owner,
                    "repo": project,
                    "owner_repo_key": owner_repo_key,
                    "github_url": github_url,
                    "default_branch": default_branch,
                    "snapshot_commit": snapshot_sha,
                    "local_use_path": local_path,
                    "relative_path": rel_file_path,
                    "filename": filename,
                    "flat_filename": dest_path.name,
                    "saved_to": str(dest_path),
                })

            print(f"    Saved {rel_file_path} as {dest_path.name}")

        if not KEEP_CLONES:
            try:
                shutil.rmtree(repo_git_dir, onerror=force_remove_readonly)
            except Exception as e:
                print(f"  Failed to delete temp git dir {repo_git_dir}: {e}")

    print("\nDone. Local YAMLs stored in:")
    print(f"  {OUTPUT_YML_DIR}")
    print("Index CSV:")
    print(f"  {LOCAL_INDEX_CSV}")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 18
#      16 import pandas as pd
#      17 import requests
# ---> 18 from dotenv import load_dotenv
#      20 # ========= CONFIG & PATHS =========
#      21
#      22 # Your env file location (as you stated)
#      23 ENV_DIR = Path(r"C:\GitHub\Android-Mobile-Apps")
#
# ModuleNotFoundError: No module named 'dotenv'
