# %% [markdown]
# # Change from V2.0:
# ## Updated Secondary Label detection and allication in labeling stage

# %%
# %% [markdown]
# # RQ2 — Step 0: Clone repositories
# Reads a CSV with column `repo_url`, clones/fetches into CLONE_ROOT,
# and writes a manifest with basic metadata.

# %%
from __future__ import annotations
import csv, subprocess, sys, json, time
from pathlib import Path
from typing import Optional, List
from pathlib import Path

# -----------------------------
# Config (edit as needed)
# -----------------------------


# Use a raw string r"..." for Windows paths with spaces
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2")
URL_LIST_CSV = WORK_ROOT / "URL_List.csv"   # put your CSV here
CLONE_ROOT   = WORK_ROOT / "clones"         # repos will clone here
MANIFEST_CSV = WORK_ROOT / "clones_manifest.csv"

WORK_ROOT.mkdir(parents=True, exist_ok=True)
CLONE_ROOT.mkdir(parents=True, exist_ok=True)


# Create dirs
WORK_ROOT.mkdir(parents=True, exist_ok=True)
CLONE_ROOT.mkdir(parents=True, exist_ok=True)

# %%
def sh(cmd: List[str], cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    return subprocess.run(cmd, cwd=cwd, check=check, capture_output=True, text=True)

def repo_dir_name_from_url(url: str) -> str:
    # e.g. https://github.com/owner/name(.git) -> owner__name
    base = url.split("//")[-1]
    parts = base.split("/")
    if len(parts) >= 3:
        owner = parts[-2]
        name  = parts[-1].replace(".git", "")
        return f"{owner}__{name}"
    return base.replace("/", "__").replace(".git", "")

def ensure_cloned(url: str, dest_root: Path) -> Path:
    dest_root.mkdir(parents=True, exist_ok=True)
    d = dest_root / repo_dir_name_from_url(url)
    if d.exists() and (d / ".git").exists():
        # Refresh remote info (best-effort)
        try:
            sh(["git", "fetch", "--all", "--tags", "--prune"], cwd=d)
        except Exception:
            pass
        return d
    sh(["git", "clone", "--no-tags", "--filter=blob:none", "--recurse-submodules=no", url, str(d)])
    return d

def get_total_commits(repo_dir: Path) -> int:
    cp = sh(["git", "rev-list", "--all", "--count"], cwd=repo_dir)
    return int(cp.stdout.strip() or "0")

# %%
assert URL_LIST_CSV.exists(), f"CSV not found: {URL_LIST_CSV}"

rows, ok, fail = [], 0, 0
with URL_LIST_CSV.open(newline="", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        url = (row.get("repo_url") or "").strip()
        if not url:
            continue
        t0 = time.time()
        rec = {"repo_url": url, "dir": None, "status": "unknown", "seconds": None, "total_commits": None, "error": ""}
        try:
            d = ensure_cloned(url, CLONE_ROOT)
            rec["dir"] = str(d)
            rec["total_commits"] = get_total_commits(d)
            rec["status"] = "ok"
            ok += 1
        except subprocess.CalledProcessError as e:
            rec["status"] = "error"
            rec["error"]  = (e.stderr or e.stdout or str(e)).strip()[:2000]
            fail += 1
        rec["seconds"] = round(time.time() - t0, 2)
        rows.append(rec)
        print(f"[{rec['status']}] {url} -> {rec['dir']} ({rec['seconds']}s)")

# %%
# Write manifest
MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
with MANIFEST_CSV.open("w", newline="", encoding="utf-8") as f:
    w = csv.DictWriter(f, fieldnames=list(rows[0].keys()) if rows else ["repo_url","dir","status","seconds","total_commits","error"])
    w.writeheader()
    w.writerows(rows)

print(f"\nDone. OK={ok}, FAIL={fail}. Manifest: {MANIFEST_CSV}")
# Out:
# [ok] https://github.com/connectbot/connectbot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\connectbot__connectbot (1.64s)
# [ok] https://github.com/robolectric/robolectric -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\robolectric__robolectric (7.22s)
# [ok] https://github.com/opendocument-app/OpenDocument.droid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\opendocument-app__OpenDocument.droid (4.29s)
# [ok] https://github.com/maxpower47/PinDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\maxpower47__PinDroid (2.95s)
# [ok] https://github.com/Rajawali/Rajawali -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Rajawali__Rajawali (6.46s)
# [ok] https://github.com/cgeo/cgeo -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\cgeo__cgeo (24.03s)
# [ok] https://github.com/OneBusAway/onebusaway-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\OneBusAway__onebusaway-android (2.7s)
# [ok] https://github.com/MikeOrtiz/TouchImageView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\MikeOrtiz__TouchImageView (2.1s)
# [ok] https://github.com/labexp/osmtracker-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\labexp__osmtracker-android (1.95s)
# [ok] https://github.com/AndBible/and-bible -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AndBible__and-bible (9.13s)
# [ok] https://github.com/andstatus/andstatus -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\andstatus__andstatus (5.1s)
# [ok] https://github.com/spacecowboy/NotePad -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\spacecowboy__NotePad (2.44s)
# [ok] https://github.com/persian-calendar/persian-calendar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\persian-calendar__persian-calendar (3.4s)
# [ok] https://github.com/inaturalist/iNaturalistAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\inaturalist__iNaturalistAndroid (5.75s)
# [ok] https://github.com/yuriykulikov/AlarmClock -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\yuriykulikov__AlarmClock (1.79s)
# [ok] https://github.com/openintents/shoppinglist -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\openintents__shoppinglist (2.04s)
# [ok] https://github.com/square/okhttp -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__okhttp (4.04s)
# [ok] https://github.com/AntennaPod/AntennaPod -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AntennaPod__AntennaPod (5.46s)
# [ok] https://github.com/ragunathjawahar/android-saripaar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ragunathjawahar__android-saripaar (1.08s)
# [ok] https://github.com/fossasia/phimpme-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\fossasia__phimpme-android (4.15s)
# [ok] https://github.com/xebia-functional/appsly-android-rest -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\xebia-functional__appsly-android-rest (1.6s)
# [ok] https://github.com/ankidroid/Anki-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ankidroid__Anki-Android (15.94s)
# [ok] https://github.com/ligi/PassAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ligi__PassAndroid (1.63s)
# [ok] https://github.com/segler-alex/RadioDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\segler-alex__RadioDroid (1.86s)
# [ok] https://github.com/ksoichiro/AndroidFormEnhancer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ksoichiro__AndroidFormEnhancer (1.18s)
# [ok] https://github.com/cloudinary/cloudinary_android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\cloudinary__cloudinary_android (1.4s)
# [ok] https://github.com/dmfs/opentasks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dmfs__opentasks (10.23s)
# [ok] https://github.com/square/wire -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__wire (4.19s)
# [ok] https://github.com/tasks/tasks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\tasks__tasks (5.24s)
# [ok] https://github.com/simonnorberg/dmach -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\simonnorberg__dmach (1.15s)
# [ok] https://github.com/wikimedia/apps-android-wikipedia -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\wikimedia__apps-android-wikipedia (20.06s)
# [ok] https://github.com/splitwise/TokenAutoComplete -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\splitwise__TokenAutoComplete (1.04s)
# [ok] https://github.com/grote/Transportr -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\grote__Transportr (7.55s)
# [ok] https://github.com/anjlab/android-inapp-billing-v3 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\anjlab__android-inapp-billing-v3 (1.1s)
# [ok] https://github.com/JakeWharton/u2020 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\JakeWharton__u2020 (2.37s)
# [ok] https://github.com/federicoiosue/Omni-Notes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\federicoiosue__Omni-Notes (3.98s)
# [ok] https://github.com/rejasupotaro/Rebuild -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\rejasupotaro__Rebuild (2.0s)
# [ok] https://github.com/owntracks/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\owntracks__android (3.63s)
# [ok] https://github.com/dlew/joda-time-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dlew__joda-time-android (1.27s)
# [ok] https://github.com/TomRoush/PdfBox-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\TomRoush__PdfBox-Android (3.85s)
# [ok] https://github.com/AChep/AcDisplay -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AChep__AcDisplay (2.4s)
# [ok] https://github.com/mathisdt/trackworktime -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\mathisdt__trackworktime (1.63s)
# [ok] https://github.com/ksoichiro/SimpleAlertDialog-for-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ksoichiro__SimpleAlertDialog-for-Android (1.17s)
# [ok] https://github.com/openhab/openhab-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\openhab__openhab-android (3.03s)
# [ok] https://github.com/amahi/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\amahi__android (1.53s)
# [ok] https://github.com/EvanRespaut/Equate -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\EvanRespaut__Equate (1.15s)
# [ok] https://github.com/OpnTec/bodyapps-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\OpnTec__bodyapps-android (1.08s)
# [ok] https://github.com/TeamAmaze/AmazeFileManager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\TeamAmaze__AmazeFileManager (4.13s)
# [ok] https://github.com/f-droid/fdroidclient -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\f-droid__fdroidclient (5.24s)
# [ok] https://github.com/ksoichiro/Android-ObservableScrollView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ksoichiro__Android-ObservableScrollView (2.56s)
# [ok] https://github.com/smartdevicelink/sdl_java_suite -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\smartdevicelink__sdl_java_suite (3.35s)
# [ok] https://github.com/thyrlian/AwesomeValidation -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\thyrlian__AwesomeValidation (1.11s)
# [ok] https://github.com/Stuart-campbell/RushOrm -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Stuart-campbell__RushOrm (1.06s)
# [ok] https://github.com/posm/OpenMapKitAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\posm__OpenMapKitAndroid (1.4s)
# [ok] https://github.com/CarlosMChica/easyrecycleradapters -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\CarlosMChica__easyrecycleradapters (1.05s)
# [ok] https://github.com/dart-lang/http -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dart-lang__http (1.6s)
# [ok] https://github.com/JakeWharton/RxBinding -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\JakeWharton__RxBinding (1.21s)
# [ok] https://github.com/moezbhatti/qksms -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\moezbhatti__qksms (2.13s)
# [ok] https://github.com/takahirom/PreLollipopTransition -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\takahirom__PreLollipopTransition (1.01s)
# [ok] https://github.com/ooni/probe-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ooni__probe-android (3.21s)
# [ok] https://github.com/zsoltk/GameOfLife -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\zsoltk__GameOfLife (1.04s)
# [ok] https://github.com/fewlaps/flone-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\fewlaps__flone-android (2.1s)
# [ok] https://github.com/square/leakcanary -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__leakcanary (12.92s)
# [ok] https://github.com/SundeepK/CompactCalendarView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\SundeepK__CompactCalendarView (1.55s)
# [ok] https://github.com/kebernet/shortyz -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\kebernet__shortyz (2.0s)
# [ok] https://github.com/Redgram/redgram-for-reddit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Redgram__redgram-for-reddit (1.54s)
# [ok] https://github.com/servo/surfman -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\servo__surfman (1.23s)
# [ok] https://github.com/pilgr/Paper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\pilgr__Paper (1.0s)
# [ok] https://github.com/sky-map-team/stardroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sky-map-team__stardroid (2.94s)
# [ok] https://github.com/concretesolutions/canarinho -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\concretesolutions__canarinho (1.05s)
# [ok] https://github.com/Piwigo/Piwigo-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Piwigo__Piwigo-Android (1.75s)
# [ok] https://github.com/commons-app/apps-android-commons -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\commons-app__apps-android-commons (5.49s)
# [ok] https://github.com/TeamNewPipe/NewPipe -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\TeamNewPipe__NewPipe (6.79s)
# [ok] https://github.com/AAkira/ExpandableLayout -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AAkira__ExpandableLayout (1.87s)
# [ok] https://github.com/hannesa2/panoramaGL -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\hannesa2__panoramaGL (1.55s)
# [ok] https://github.com/4eRTuk/audioview -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\4eRTuk__audioview (0.98s)
# [ok] https://github.com/sqldelight/sqldelight -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sqldelight__sqldelight (5.47s)
# [ok] https://github.com/sangcomz/FishBun -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sangcomz__FishBun (4.57s)
# [ok] https://github.com/requery/requery -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\requery__requery (1.43s)
# [ok] https://github.com/fossasia/loklak_wok_android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\fossasia__loklak_wok_android (1.25s)
# [ok] https://github.com/andreynovikov/trekarta -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\andreynovikov__trekarta (5.47s)
# [ok] https://github.com/VREMSoftwareDevelopment/WiFiAnalyzer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\VREMSoftwareDevelopment__WiFiAnalyzer (2.15s)
# [ok] https://github.com/grandstaish/paperparcel -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\grandstaish__paperparcel (1.27s)
# [ok] https://github.com/vanniktech/OnActivityResult -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\vanniktech__OnActivityResult (0.98s)
# [ok] https://github.com/greenaddress/abcore -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\greenaddress__abcore (1.21s)
# [ok] https://github.com/FabianTerhorst/Iron -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\FabianTerhorst__Iron (1.07s)
# [ok] https://github.com/amitshekhariitbhu/Fast-Android-Networking -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\amitshekhariitbhu__Fast-Android-Networking (1.24s)
# [ok] https://github.com/voghDev/PdfViewPager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\voghDev__PdfViewPager (1.93s)
# [ok] https://github.com/renyuneyun/Easer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\renyuneyun__Easer (2.25s)
# [ok] https://github.com/yeungeek/monkey-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\yeungeek__monkey-android (2.41s)
# [ok] https://github.com/maksim-m/Popular-Movies-App -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\maksim-m__Popular-Movies-App (2.52s)
# [ok] https://github.com/ValentinFunk/BrainPhaser -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ValentinFunk__BrainPhaser (1.72s)
# [ok] https://github.com/tonilopezmr/Game-of-Thrones -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\tonilopezmr__Game-of-Thrones (2.55s)
# [ok] https://github.com/SecUSo/privacy-friendly-notes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\SecUSo__privacy-friendly-notes (1.37s)
# [ok] https://github.com/SecUSo/privacy-friendly-todo-list -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\SecUSo__privacy-friendly-todo-list (1.44s)
# [ok] https://github.com/dbrodie/AdBuster -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dbrodie__AdBuster (1.06s)
# [ok] https://github.com/nextcloud/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\nextcloud__android (11.31s)
# [ok] https://github.com/javiersantos/PiracyChecker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\javiersantos__PiracyChecker (1.8s)
# [ok] https://github.com/miguelhincapie/CustomBottomSheetBehavior -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\miguelhincapie__CustomBottomSheetBehavior (2.17s)
# [ok] https://github.com/SecUSo/privacy-friendly-pedometer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\SecUSo__privacy-friendly-pedometer (1.35s)
# [ok] https://github.com/medic/cht-gateway -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\medic__cht-gateway (1.13s)
# [ok] https://github.com/cliqz-oss/browser-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\cliqz-oss__browser-android (5.49s)
# [ok] https://github.com/andremion/Villains-and-Heroes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\andremion__Villains-and-Heroes (5.68s)
# [ok] https://github.com/leandroBorgesFerreira/LoadingButtonAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\leandroBorgesFerreira__LoadingButtonAndroid (1.07s)
# [ok] https://github.com/jaredsburrows/android-gif-search -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jaredsburrows__android-gif-search (1.29s)
# [ok] https://github.com/beemdevelopment/Aegis -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\beemdevelopment__Aegis (3.32s)
# [ok] https://github.com/ligi/SurvivalManual -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ligi__SurvivalManual (1.17s)
# [ok] https://github.com/gotev/android-speech -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\gotev__android-speech (0.98s)
# [ok] https://github.com/guardianproject/proofmode-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\guardianproject__proofmode-android (8.45s)
# [ok] https://github.com/freeotp/freeotp-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\freeotp__freeotp-android (1.27s)
# [ok] https://github.com/ronaldsmartin/Material-ViewPagerIndicator -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ronaldsmartin__Material-ViewPagerIndicator (1.02s)
# [ok] https://github.com/michelelacorte/AndroidAppShortcuts -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\michelelacorte__AndroidAppShortcuts (1.0s)
# [ok] https://github.com/massivedisaster/ADAL -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\massivedisaster__ADAL (3.42s)
# [ok] https://github.com/getsentry/sentry-react-native -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\getsentry__sentry-react-native (3.13s)
# [ok] https://github.com/AdevintaSpain/Barista -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AdevintaSpain__Barista (1.25s)
# [ok] https://github.com/bilibili/boxing -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\bilibili__boxing (1.26s)
# [ok] https://github.com/jungilhan/awesome-blogs-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jungilhan__awesome-blogs-android (1.86s)
# [ok] https://github.com/MarcinMoskala/PreferenceHolder -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\MarcinMoskala__PreferenceHolder (0.97s)
# [ok] https://github.com/NiciDieNase/chaosflix -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\NiciDieNase__chaosflix (2.87s)
# [ok] https://github.com/adorsys/secure-storage-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\adorsys__secure-storage-android (1.01s)
# [ok] https://github.com/JimmyDaddy/react-native-image-marker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\JimmyDaddy__react-native-image-marker (5.42s)
# [ok] https://github.com/zoff99/ToxAndroidRefImpl -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\zoff99__ToxAndroidRefImpl (10.98s)
# [ok] https://github.com/EventFahrplan/EventFahrplan -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\EventFahrplan__EventFahrplan (2.29s)
# [ok] https://github.com/jianjunxiao/NiceVieoPlayer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jianjunxiao__NiceVieoPlayer (1.28s)
# [ok] https://github.com/livefront/bridge -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\livefront__bridge (1.02s)
# [ok] https://github.com/invertase/notifee -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\invertase__notifee (2.67s)
# [ok] https://github.com/massivemadness/Squircle-CE -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\massivemadness__Squircle-CE (4.08s)
# [ok] https://github.com/syrjs/core -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\syrjs__core (2.11s)
# [ok] https://github.com/seedvault-app/seedvault -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\seedvault-app__seedvault (10.39s)
# [ok] https://github.com/kamgurgul/cpu-info -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\kamgurgul__cpu-info (1.74s)
# [ok] https://github.com/dgngulcan/droid-feed -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dgngulcan__droid-feed (2.93s)
# [ok] https://github.com/airbnb/paris -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\airbnb__paris (6.13s)
# [ok] https://github.com/sellmair/kompass -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sellmair__kompass (2.05s)
# [ok] https://github.com/Crazy-Marvin/MetadataRemover -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Crazy-Marvin__MetadataRemover (7.15s)
# [ok] https://github.com/brarcher/video-transcoder -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\brarcher__video-transcoder (8.36s)
# [ok] https://github.com/AndProx/AndProx -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\AndProx__AndProx (1.27s)
# [ok] https://github.com/BlueWallet/BlueWallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\BlueWallet__BlueWallet (4.91s)
# [ok] https://github.com/izderadicka/audioserve-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\izderadicka__audioserve-android (1.32s)
# [ok] https://github.com/kalaspuffar/secure-quick-reliable-login -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\kalaspuffar__secure-quick-reliable-login (3.0s)
# [ok] https://github.com/Picovoice/porcupine -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Picovoice__porcupine (14.05s)
# [ok] https://github.com/simpledotorg/simple-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\simpledotorg__simple-android (5.73s)
# [ok] https://github.com/nhirokinet/bluelineconsole -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\nhirokinet__bluelineconsole (4.53s)
# [ok] https://github.com/NUmeroAndDev/MaterialGallery-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\NUmeroAndDev__MaterialGallery-android (1.45s)
# [ok] https://github.com/letelete/sleep-cycle-alarm -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\letelete__sleep-cycle-alarm (2.18s)
# [ok] https://github.com/MetaMask/metamask-mobile -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\MetaMask__metamask-mobile (30.25s)
# [ok] https://github.com/admob-plus/admob-plus -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\admob-plus__admob-plus (4.39s)
# [ok] https://github.com/software-mansion/react-native-screens -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\software-mansion__react-native-screens (4.66s)
# [ok] https://github.com/Samsung/escargot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Samsung__escargot (2.45s)
# [ok] https://github.com/oxygen-updater/oxygen-updater -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\oxygen-updater__oxygen-updater (1.7s)
# [ok] https://github.com/uber/simple-store -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\uber__simple-store (1.08s)
# [ok] https://github.com/ActivityWatch/aw-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ActivityWatch__aw-android (1.15s)
# [ok] https://github.com/UriahShaulMandel/BaldPhone -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\UriahShaulMandel__BaldPhone (11.29s)
# [ok] https://github.com/Albert221/FastShopping -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Albert221__FastShopping (6.66s)
# [ok] https://github.com/readrops/Readrops -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\readrops__Readrops (2.22s)
# [ok] https://github.com/twireapp/Twire -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\twireapp__Twire (1.78s)
# [ok] https://github.com/rainbow-me/rainbow -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\rainbow-me__rainbow (19.1s)
# [ok] https://github.com/trynoice/android-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\trynoice__android-app (3.44s)
# [ok] https://github.com/evilcorpltd/aTox -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\evilcorpltd__aTox (1.66s)
# [ok] https://github.com/haroldadmin/MoonShot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\haroldadmin__MoonShot (1.35s)
# [ok] https://github.com/ipfs-shipyard/gomobile-ipfs -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ipfs-shipyard__gomobile-ipfs (1.4s)
# [ok] https://github.com/coil-kt/coil -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\coil-kt__coil (21.25s)
# [ok] https://github.com/DroidKaigi/conference-app-2020 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\DroidKaigi__conference-app-2020 (12.12s)
# [ok] https://github.com/OpenTracksApp/OpenTracks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\OpenTracksApp__OpenTracks (4.6s)
# [ok] https://github.com/natario1/GIFCompressor -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\natario1__GIFCompressor (1.18s)
# [ok] https://github.com/fluttercommunity/flutter_workmanager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\fluttercommunity__flutter_workmanager (1.79s)
# [ok] https://github.com/ThibaultBee/srtdroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ThibaultBee__srtdroid (1.23s)
# [ok] https://github.com/kylecorry31/Trail-Sense -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\kylecorry31__Trail-Sense (10.98s)
# [ok] https://github.com/tfcporciuncula/flow-preferences -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\tfcporciuncula__flow-preferences (0.99s)
# [ok] https://github.com/n8ebel/GitHubActionsAutomationSandbox -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\n8ebel__GitHubActionsAutomationSandbox (0.99s)
# [ok] https://github.com/joreilly/PeopleInSpace -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\joreilly__PeopleInSpace (1.37s)
# [ok] https://github.com/realm/realm-kotlin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\realm__realm-kotlin (3.28s)
# [ok] https://github.com/square/cycler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__cycler (1.0s)
# [ok] https://github.com/hitherejoe/minimise -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\hitherejoe__minimise (1.49s)
# [ok] https://github.com/vmiklos/plees-tracker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\vmiklos__plees-tracker (1.3s)
# [ok] https://github.com/ReactiveCircus/streamlined -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ReactiveCircus__streamlined (1.35s)
# [ok] https://github.com/H-PixelDroid/PixelDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\H-PixelDroid__PixelDroid (8.68s)
# [ok] https://github.com/Tommy-Geenexus/exif-eraser -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Tommy-Geenexus__exif-eraser (2.07s)
# [ok] https://github.com/MiSikora/laboratory -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\MiSikora__laboratory (1.44s)
# [ok] https://github.com/nschnettler/Compose-Scrobbler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\nschnettler__Compose-Scrobbler (1.71s)
# [ok] https://github.com/sakusaku3939/DeepLAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sakusaku3939__DeepLAndroid (1.21s)
# [ok] https://github.com/softartdev/NoteDelight -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\softartdev__NoteDelight (2.8s)
# [ok] https://github.com/hoc081098/ViewBindingDelegate -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\hoc081098__ViewBindingDelegate (1.35s)
# [ok] https://github.com/PatilShreyas/NotyKT -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\PatilShreyas__NotyKT (2.02s)
# [ok] https://github.com/android/codelab-android-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\android__codelab-android-compose (6.35s)
# [ok] https://github.com/TwidereProject/TwidereX-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\TwidereProject__TwidereX-Android (2.67s)
# [ok] https://github.com/nightscout/AndroidAPS -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\nightscout__AndroidAPS (25.71s)
# [ok] https://github.com/MackHartley/RoundedProgressBar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\MackHartley__RoundedProgressBar (2.2s)
# [ok] https://github.com/rozPierog/Cofi -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\rozPierog__Cofi (4.39s)
# [ok] https://github.com/ErickSumargo/Dads -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ErickSumargo__Dads (3.49s)
# [ok] https://github.com/alexbakker/webdav-provider -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\alexbakker__webdav-provider (1.14s)
# [ok] https://github.com/thunderbiscuit/padawan-wallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\thunderbiscuit__padawan-wallet (1.73s)
# [ok] https://github.com/lcdsmao/JetTheme -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\lcdsmao__JetTheme (1.05s)
# [ok] https://github.com/yogeshpaliyal/KeyPass -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\yogeshpaliyal__KeyPass (1.82s)
# [ok] https://github.com/square/curtains -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__curtains (1.45s)
# [ok] https://github.com/wajahatkarim3/Imagine -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\wajahatkarim3__Imagine (3.73s)
# [ok] https://github.com/a914-gowtham/compose-ratingbar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\a914-gowtham__compose-ratingbar (1.2s)
# [ok] https://github.com/joreilly/StarWars -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\joreilly__StarWars (1.12s)
# [ok] https://github.com/KaustubhPatange/navigator -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\KaustubhPatange__navigator (1.51s)
# [ok] https://github.com/WangJie0822/Cashbook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\WangJie0822__Cashbook (5.58s)
# [ok] https://github.com/RBusarow/Tangle -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\RBusarow__Tangle (1.68s)
# [ok] https://github.com/michaeltroger/pdfwallet-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\michaeltroger__pdfwallet-android (2.2s)
# [ok] https://github.com/ImaginativeShohag/Why-Not-Compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ImaginativeShohag__Why-Not-Compose (17.16s)
# [ok] https://github.com/nanihadesuka/NovelDokusha -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\nanihadesuka__NovelDokusha (1.65s)
# [ok] https://github.com/OlauncherCF/OlauncherCF -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\OlauncherCF__OlauncherCF (1.33s)
# [ok] https://github.com/doublesymmetry/KotlinAudio -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\doublesymmetry__KotlinAudio (3.18s)
# [ok] https://github.com/alexstyl/contactstore -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\alexstyl__contactstore (1.11s)
# [ok] https://github.com/square/papa -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\square__papa (1.09s)
# [ok] https://github.com/bitfireAT/icsx5 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\bitfireAT__icsx5 (1.28s)
# [ok] https://github.com/burnoo/cokoin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\burnoo__cokoin (0.97s)
# [ok] https://github.com/scribe-org/Scribe-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\scribe-org__Scribe-Android (14.12s)
# [ok] https://github.com/StefanIlchev/ElementumService -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\StefanIlchev__ElementumService (1.18s)
# [ok] https://github.com/rafsanjani/datepickertimeline -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\rafsanjani__datepickertimeline (1.16s)
# [ok] https://github.com/Arian04/android-hid-client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Arian04__android-hid-client (1.19s)
# [ok] https://github.com/Nailik/rhasspy_mobile -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Nailik__rhasspy_mobile (5.49s)
# [ok] https://github.com/android/nowinandroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\android__nowinandroid (5.76s)
# [ok] https://github.com/krzdabrowski/android-starter-2022 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\krzdabrowski__android-starter-2022 (1.15s)
# [ok] https://github.com/ruffle-rs/ruffle-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ruffle-rs__ruffle-android (1.12s)
# [ok] https://github.com/fornewid/naver-map-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\fornewid__naver-map-compose (1.2s)
# [ok] https://github.com/slackhq/circuit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\slackhq__circuit (4.0s)
# [ok] https://github.com/maxkeppeler/sheets-compose-dialogs -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\maxkeppeler__sheets-compose-dialogs (7.84s)
# [ok] https://github.com/sopt-makers/sopt-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\sopt-makers__sopt-android (6.43s)
# [ok] https://github.com/zimly/zimly-backup -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\zimly__zimly-backup (3.88s)
# [ok] https://github.com/TechbeeAT/jtxBoard -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\TechbeeAT__jtxBoard (4.82s)
# [ok] https://github.com/cashapp/paraphrase -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\cashapp__paraphrase (1.15s)
# [ok] https://github.com/DesarrolloAntonio/Shiori-Android-Client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\DesarrolloAntonio__Shiori-Android-Client (2.81s)
# [ok] https://github.com/mshdabiola/NotePad -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\mshdabiola__NotePad (2.72s)
# [ok] https://github.com/LinX64/CoinCap -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\LinX64__CoinCap (1.7s)
# [ok] https://github.com/anilbeesetti/nextplayer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\anilbeesetti__nextplayer (2.32s)
# [ok] https://github.com/LinkSheet/LinkSheet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\LinkSheet__LinkSheet (4.87s)
# [ok] https://github.com/chenxiaolong/RSAF -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\chenxiaolong__RSAF (1.17s)
# [ok] https://github.com/irgaly/kfswatch -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\irgaly__kfswatch (1.13s)
# [ok] https://github.com/droidconKE/droidconKeKotlin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\droidconKE__droidconKeKotlin (1.83s)
# [ok] https://github.com/orgzly-revived/orgzly-android-revived -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\orgzly-revived__orgzly-android-revived (3.51s)
# [ok] https://github.com/mjaakko/NeoStumbler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\mjaakko__NeoStumbler (2.58s)
# [ok] https://github.com/pachli/pachli-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\pachli__pachli-android (6.49s)
# [ok] https://github.com/JackEblan/Geto -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\JackEblan__Geto (2.45s)
# [ok] https://github.com/f-arslan/GptMap -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\f-arslan__GptMap (14.14s)
# [ok] https://github.com/t895/DNSNet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\t895__DNSNet (1.87s)
# [ok] https://github.com/gemwalletcom/gem-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\gemwalletcom__gem-android (2.22s)
# [ok] https://github.com/CatimaLoyalty/Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\CatimaLoyalty__Android (3.45s)
# [ok] https://github.com/flauschtrud/broccoli -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\flauschtrud__broccoli (3.95s)
# [ok] https://github.com/SwissCovid/swisscovid-app-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\SwissCovid__swisscovid-app-android (3.33s)
# [ok] https://github.com/Faltenreich/Diaguard -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Faltenreich__Diaguard (5.76s)
# [ok] https://github.com/briar/briar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\briar__briar (5.12s)
# [ok] https://github.com/Five-Prayers/five-prayers-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Five-Prayers__five-prayers-android (5.65s)
# [ok] https://github.com/v2er-app/Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\v2er-app__Android (1.51s)
# [ok] https://github.com/thevindu-w/clip_share_client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\thevindu-w__clip_share_client (1.1s)
# [ok] https://github.com/Hny0305Lin/NLChat -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Hny0305Lin__NLChat (17.04s)
# [ok] https://github.com/ably/ably-flutter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ably__ably-flutter (2.02s)
# [ok] https://github.com/jerson/flutter-rsa -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jerson__flutter-rsa (6.76s)
# [ok] https://github.com/jerson/flutter-openpgp -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jerson__flutter-openpgp (6.32s)
# [ok] https://github.com/am15h/tflite_flutter_helper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\am15h__tflite_flutter_helper (11.99s)
# [ok] https://github.com/abdelaziz-mahdy/pytorch_lite -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\abdelaziz-mahdy__pytorch_lite (17.5s)
# [ok] https://github.com/passsy/spot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\passsy__spot (1.46s)
# [ok] https://github.com/dart-lang/native -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\dart-lang__native (3.49s)
# [ok] https://github.com/flet-dev/serious-python -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\flet-dev__serious-python (1.29s)
# [ok] https://github.com/natsuk4ze/gal -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\natsuk4ze__gal (3.69s)
# [ok] https://github.com/a-mabe/OpenHIIT -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\a-mabe__OpenHIIT (1.47s)
# [ok] https://github.com/firebase/FirebaseUI-Flutter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\firebase__FirebaseUI-Flutter (3.0s)
# [ok] https://github.com/microservicer/flutter-pipelines -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\microservicer__flutter-pipelines (1.12s)
# [ok] https://github.com/Bdaya-Dev/oidc -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\Bdaya-Dev__oidc (1.31s)
# [ok] https://github.com/brandonp2412/FitBook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\brandonp2412__FitBook (3.64s)
# [ok] https://github.com/PhoneVR-Developers/PhoneVR -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\PhoneVR-Developers__PhoneVR (1.8s)
# [ok] https://github.com/invertase/react-native-google-mobile-ads -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\invertase__react-native-google-mobile-ads (1.33s)
# [ok] https://github.com/jameshnsears/QuoteUnquote -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\jameshnsears__QuoteUnquote (4.27s)
# [ok] https://github.com/erkkah/naett -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\erkkah__naett (0.9s)
# [ok] https://github.com/haiyangwu/mediasoup-client-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\haiyangwu__mediasoup-client-android (93.84s)
# [ok] https://github.com/openthread/ot-commissioner -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\openthread__ot-commissioner (1.3s)
# [ok] https://github.com/XRPL-Labs/Xaman-App -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\XRPL-Labs__Xaman-App (9.26s)
# [ok] https://github.com/synonymdev/bitkit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\synonymdev__bitkit (3.83s)
# [ok] https://github.com/streetwriters/notesnook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\streetwriters__notesnook (13.93s)
# [ok] https://github.com/aws/amazon-ivs-react-native-player -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\aws__amazon-ivs-react-native-player (1.22s)
# [ok] https://github.com/inaturalist/iNaturalistReactNative -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\inaturalist__iNaturalistReactNative (12.79s)
# [ok] https://github.com/LedgerHQ/ledger-live -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\LedgerHQ__ledger-live (42.31s)
# [ok] https://github.com/pytorch/executorch -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\pytorch__executorch (20.68s)
# [ok] https://github.com/EnsembleUI/ensemble -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\EnsembleUI__ensemble (6.61s)
# [ok] https://github.com/elftausend/custos -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\elftausend__custos (1.45s)
# [ok] https://github.com/haqq-network/haqq-wallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\haqq-network__haqq-wallet (4.57s)
# [ok] https://github.com/juancastillo0/wasm_run -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\juancastillo0__wasm_run (4.65s)
# [ok] https://github.com/ice-blockchain/mobile-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\ice-blockchain__mobile-app (2.27s)
# [ok] https://github.com/zkmopro/mopro -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\zkmopro__mopro (25.02s)
# [ok] https://github.com/prisma/react-native-prisma -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones\prisma__react-native-prisma (1.41s)
#
# Done. OK=282, FAIL=0. Manifest: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones_manifest.csv

# %%
# RQ2 — Step 1 (v5.1): Mine commit snapshots (normalized + helpers, stronger orchestrator, numeric boot wait)
# Outputs per-repo JSONL snapshots with:
#   features.detected_params[*]: { emulator_type in {"Generic","DIY","GMD"}, api_level, image_source, abi,
#                                  device_profile, device_identifier, start_mode, gpu_mode,
#                                  headless_flags{no_window,no_audio,no_boot_anim}, boot_wait (bool),
#                                  boot_wait_seconds (int|None), test_command, runner_args, context_anchor,
#                                  host_os, hypervisor }
#   features.medium_params: { image_flavor, orchestrator_enabled (bool), num_shards, locale, timezone,
#                             network_profile, gmd_device?, gmd_api_level?, gmd_system_image_source? }
#   features.toolchain_params: { agp_version, gradle_version, jdk_version, android_sdk_installed, android_sdk_licenses }
#   features.labels: { file_kind, ci_emulator_step_change, gradle_gmd_block_change, gmd_present }
#
# Notes:
# - Adds robust orchestrator detection surfaces.
# - Extracts numeric boot wait when obvious (sleep/timeout around boot).
# - No legacy fields / feature_scope.

from __future__ import annotations
import os, re, json, subprocess, datetime as dt
from pathlib import Path
from typing import List, Tuple, Optional, Dict, Any

try:
    from zoneinfo import ZoneInfo  # Python 3.9+
except Exception:
    ZoneInfo = None

WORK_ROOT      = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2")
CLONE_ROOT     = WORK_ROOT / "clones"
SNAPSHOT_DIR   = WORK_ROOT / "snapshots"
MAX_COMMITS_PER_REPO = 0  # 0 = no limit
SNAPSHOT_DIR.mkdir(parents=True, exist_ok=True)

CUTOFF_TZ_NAME = "America/Toronto"
_CUTOFF_DATE   = (2025, 8, 10, 23, 59, 59)
if ZoneInfo is not None:
    _tz = ZoneInfo(CUTOFF_TZ_NAME)
    _local_dt = dt.datetime(*_CUTOFF_DATE, tzinfo=_tz)
    CUTOFF_EPOCH = int(_local_dt.timestamp())
    CUTOFF_BEFORE_STR = _local_dt.strftime("%Y-%m-%d %H:%M:%S %z")
else:
    _utc_dt = dt.datetime(2025, 8, 11, 3, 59, 59, tzinfo=dt.timezone.utc)
    CUTOFF_EPOCH = int(_utc_dt.timestamp())
    CUTOFF_BEFORE_STR = "2025-08-10 23:59:59 -0400"

print(f"[cutoff] Using commit cutoff <= {CUTOFF_BEFORE_STR} (epoch={CUTOFF_EPOCH})")

def sh(cmd: List[str], cwd: Optional[Path] = None, check: bool = True) -> subprocess.CompletedProcess:
    env = os.environ.copy()
    env["GIT_PAGER"] = ""
    return subprocess.run(
        cmd, cwd=str(cwd) if cwd else None, check=check,
        stdout=subprocess.PIPE, stderr=subprocess.PIPE,
        text=True, encoding="utf-8", errors="replace", env=env,
    )

CI_VENDOR_PATTERNS = [
    re.compile(r'(?i)(?:^|/)\.travis\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)\.appveyor\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)appveyor\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)circle\.yml$'),
    re.compile(r'(?i)(?:^|/)\.circleci/config\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)azure-pipelines\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)\.github/workflows/.*\.(yml|yaml)$'),
    re.compile(r'(?i)(?:^|/)bitbucket-pipelines\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)\.gitlab-ci\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)Jenkinsfile(?:\.\w+)?$'),
    re.compile(r'(?i)(?:^|/)bitrise\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)bamboo\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)codeship-services\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)\.gocd\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)\.cirrus\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)wercker\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)semaphore\.ya?ml$'),
    re.compile(r'(?i)(?:^|/)codemagic\.ya?ml$'),
]
GENERIC_CI_DIRS = re.compile(r'(?i)(?:^|/)(?:ci|\.ci|\.jenkins)(?:/|$)')

def is_ci_file(p: str) -> bool:
    if not p: return False
    if any(rx.search(p) for rx in CI_VENDOR_PATTERNS): return True
    return bool(GENERIC_CI_DIRS.search(p))

GRADLE_FILES = [
    "build.gradle","build.gradle.kts","settings.gradle","settings.gradle.kts",
    "gradle.properties","gradle/wrapper/gradle-wrapper.properties",
]
SCRIPT_EXTS = {".sh",".bash",".zsh",".py",".bat",".cmd",".ps1",".psm1"}

def is_gradle_file(p: str) -> bool:
    lp = p.lower()
    return any(lp.endswith(x) for x in (f.lower() for f in GRADLE_FILES))

def is_script_file(p: str) -> bool:
    lp = p.lower()
    return any(lp.endswith(ext) for ext in SCRIPT_EXTS)

def touched_relevant(paths: List[str]) -> bool:
    for p in paths:
        if not p.strip(): continue
        if is_ci_file(p) or is_gradle_file(p) or is_script_file(p):
            return True
    return False

def list_relevant_commits(repo_dir: Path) -> List[Tuple[str,int,List[str]]]:
    cp = sh([
        "git", "-c", "i18n.logOutputEncoding=UTF-8", "-c", "core.quotepath=off",
        "log", "--all", "--before", CUTOFF_BEFORE_STR,
        "--name-only", "--pretty=%H%x09%ct"
    ], cwd=repo_dir)
    results: List[Tuple[str,int,List[str]]] = []
    sha: Optional[str] = None; ts: Optional[int] = None; changed: List[str] = []
    for line in cp.stdout.splitlines():
        if re.match(r"^[0-9a-f]{40}\t\d+$", line):
            if sha and ts and ts <= CUTOFF_EPOCH and touched_relevant(changed):
                results.append((sha, ts, changed))
            sha, ts_s = line.split("\t", 1); ts = int(ts_s); changed = []
        else:
            if line.strip(): changed.append(line.strip())
    if sha and ts and ts <= CUTOFF_EPOCH and touched_relevant(changed):
        results.append((sha, ts, changed))
    results.reverse()
    return results

def git_show(repo_dir: Path, sha: str, path: str) -> Optional[str]:
    try:
        cp = sh(["git", "show", f"{sha}:{path}"], cwd=repo_dir)
        return cp.stdout
    except subprocess.CalledProcessError:
        return None

def git_subject(repo_dir: Path, sha: str) -> str:
    try:
        cp = sh(["git","-c","i18n.logOutputEncoding=UTF-8","show","-s","--format=%s", sha],
                cwd=repo_dir, check=False)
        return (cp.stdout or "").strip()
    except Exception:
        return ""

RE_INT = re.compile(r"\d+")

# --- Invocation detectors (DIY/GMD/Generic)
DIY_RX = re.compile(
    r"(?:\bemulator(?:\.bat|\.exe)?\s-|"
    r"\bavdmanager\b|"
    r"\bsdkmanager\b|"
    r"\bcreate\s+avd\b|"
    r"\badb\s+(?:-s\s+\S+\s+)?wait-for-device\b|"
    r"\badb\s+shell\s+getprop\s+sys\.boot_completed\b|"
    r"\bqemu\b)",
    re.I,
)
GMD_GRADLE_RX = re.compile(r"(?:\bmanagedDevices\s*\{|testOptions\s*\{[^}]*devices)", re.I|re.S)
EMULATOR_RUNNER_USES_RX = re.compile(r"uses:\s*reactivecircus/android-emulator-runner@[\w\.\-]+", re.I)

# --- YAML step/run slicing (for DIY scanner & Generic 'uses')
STEP_START_RX = re.compile(r"""^(\s*)-\s+(?:name:\s*.*)?\s*$""", re.I | re.M)
RUN_KEY_RX    = re.compile(r"""^(\s*)(run|script)\s*:\s*(\|>|)?\s*$""", re.I | re.M)
LIST_ITEM_RX  = re.compile(r"""^\s*-\s+""")
NAME_KEY_RX   = re.compile(r"""^\s*name\s*:\s*(.+?)\s*$""", re.I)

def _yaml_step_spans(yaml_text: str) -> list[tuple[int,int]]:
    lines = yaml_text.splitlines()
    n = len(lines); spans=[]; i=0
    while i < n:
        m = STEP_START_RX.match(lines[i])
        if not m: i+=1; continue
        step_indent = len(m.group(1) or "")
        j = i+1
        while j < n:
            if STEP_START_RX.match(lines[j]): break
            cur_indent = len(lines[j]) - len(lines[j].lstrip(" "))
            if cur_indent < step_indent and lines[j].strip(): break
            j += 1
        spans.append((i+1, j))
        i = j
    return spans

def _slice_by_lines(text: str, ls: int, le: int) -> str:
    lines = text.splitlines()
    return "\n".join(lines[ls-1:le-1])

WITH_BLOCK_HEAD_RX = re.compile(r"^\s*with\s*:\s*$", re.I|re.M)
def _yaml_with_block_items(yaml_text: str, ls: int, le: int) -> dict:
    sub = _slice_by_lines(yaml_text, ls, le)
    m = WITH_BLOCK_HEAD_RX.search(sub)
    if not m: return {}
    sub_lines = sub.splitlines()
    with_idx = 0
    for idx, ln in enumerate(sub_lines):
        if WITH_BLOCK_HEAD_RX.match(ln): with_idx = idx; break
    out = {}
    with_indent = len(sub_lines[with_idx]) - len(sub_lines[with_idx].lstrip())
    for ln in sub_lines[with_idx+1:]:
        if not ln.strip(): continue
        indent = len(ln) - len(ln.lstrip())
        if indent <= with_indent: break
        if ":" in ln:
            k, v = ln.strip().split(":", 1)
            out[k.strip()] = v.strip().strip("\"'")
    return out

def _yaml_step_name(yaml_text: str, ls: int, le: int) -> Optional[str]:
    sub = _slice_by_lines(yaml_text, ls, le)
    for ln in sub.splitlines():
        m = NAME_KEY_RX.match(ln)
        if m: return m.group(1).strip()
    return None

# --- Orchestrator detection (strong)
ORCH_COORD_RX  = re.compile(r"androidx\.test:orchestrator(?::[^\s'\"\)]+)?", re.I)
ORCH_EXEC_RX   = re.compile(r"testOptions\s*\{[^}]*execution\s*['\"]ANDROIDX_TEST_ORCHESTRATOR['\"]", re.I|re.S)
ORCH_FLAG_RX   = re.compile(r"\buseOrchestrator\s*(?:=|\s)\s*true\b", re.I)
ORCH_PROP_RX   = re.compile(r"\bandroid(?:\.testInstrumentationRunnerArguments)?\.use(?:Test)?Orchestrator\s*=\s*true", re.I)
ORCH_YAML_RX   = re.compile(r"\b(useOrchestrator|orchestrator)\s*[:=]\s*true\b", re.I)

def orchestrator_enabled_in_text(text: str) -> bool:
    t = text or ""
    return any(rx.search(t) for rx in (ORCH_COORD_RX, ORCH_EXEC_RX, ORCH_FLAG_RX, ORCH_PROP_RX, ORCH_YAML_RX))

# --- Test command + runner args
GRADLE_CMD_LINE_RX = re.compile(r'(^|\n)\s*(?:\./)?gradlew(?:\.bat)?\s+([^\n]+)', re.I)
ADB_INSTR_RX       = re.compile(r'(^|\n)\s*adb\s+(?:-s\s+\S+\s+)?shell\s+am\s+instrument\b([^\n]+)', re.I)

def _find_test_command(text: str) -> Optional[str]:
    m = GRADLE_CMD_LINE_RX.search(text or "")
    if m:
        cmd = m.group(0).strip()
        if re.search(r'\bconnected(Android)?Test\b|\bconnectedCheck\b|\binstrumentation\b|\bandroidTest\b', cmd, re.I):
            return cmd
    m = ADB_INSTR_RX.search(text or "")
    if m:
        return ("adb shell am instrument" + m.group(2)).strip()
    return None

def _parse_runner_args_from_cmd(cmd: str) -> Optional[dict]:
    if not cmd: return None
    args = {}
    for key in ("package","class","annotation"):
        m = re.search(rf'-Pandroid\.testInstrumentationRunnerArguments\.{key}=([^\s"]+)', cmd)
        if m: args[key] = m.group(1)
    if "class" in args and "#" in args["class"]:
        klass, meth = args["class"].split("#", 1); args["class"]=klass; args["method"]=meth
    for key in ("class","package","annotation"):
        m = re.search(rf'\s-e\s+{key}\s+([^\s"]+)', cmd)
        if m: args[key] = m.group(1)
    if "class" in args and "#" in args["class"]:
        klass, meth = args["class"].split("#", 1); args["class"]=klass; args["method"]=meth
    return args or None

# --- Generic parser
def parse_generic_from_yaml(yaml_text: str) -> list[dict]:
    hits=[]
    for (ls, le) in _yaml_step_spans(yaml_text):
        step_txt = _slice_by_lines(yaml_text, ls, le)
        if not EMULATOR_RUNNER_USES_RX.search(step_txt): continue
        kv = _yaml_with_block_items(yaml_text, ls, le) or {}
        step_name = _yaml_step_name(yaml_text, ls, le)
        norm = {
            "emulator_type":"Generic",
            "api_level":None,"image_source":None,"abi":None,"device_profile":None,"device_identifier":None,
            "start_mode":None,"gpu_mode":None,
            "headless_flags":{"no_window":None,"no_audio":None,"no_boot_anim":None},
            "boot_wait": None, "boot_wait_seconds": None,
            "test_command":None,"runner_args":None,
            "context_anchor":f"step:{step_name}" if step_name else "step:<unknown>",
        }
        if "api-level" in kv and RE_INT.search(kv["api-level"]):
            norm["api_level"] = int(RE_INT.search(kv["api-level"]).group())
        if "target" in kv:  norm["image_source"]=kv["target"]
        if "arch" in kv:    norm["abi"]=kv["arch"]
        if "profile" in kv: norm["device_profile"]=kv["profile"]
        emu_opts = kv.get("emulator-options","")
        norm["headless_flags"]["no_window"]    = bool(re.search(r"-no-window\b", emu_opts))
        norm["headless_flags"]["no_audio"]     = bool(re.search(r"-no-audio\b", emu_opts))
        norm["headless_flags"]["no_boot_anim"] = bool(re.search(r"-no-boot-anim\b", emu_opts))
        hits.append(norm)
    return hits

# --- GMD (Gradle) parser
def _find_block_span_from_head(text: str, head_start: int) -> tuple[int,int] | None:
    i = text.find("{", head_start)
    if i == -1: return None
    depth = 0
    for j in range(i, len(text)):
        ch = text[j]
        if ch == "{": depth += 1
        elif ch == "}":
            depth -= 1
            if depth == 0: return (i, j)
    return None

def _char_span_to_line_span(text: str, ci: tuple[int,int]) -> tuple[int,int]:
    start_char, end_char = ci
    start_line = text[:start_char].count("\n") + 1
    end_line   = text[:end_char+1].count("\n") + 1
    return (start_line, end_line)

GMD_BLOCK_HEAD_RX = re.compile(r"(?:\bmanagedDevices\s*\{|testOptions\s*\{[^}]*devices)", re.I|re.S)
GMD_DEVICE_RX = re.compile(r'\bdevice\s*=\s*"([^"]+)"')
GMD_API_RX    = re.compile(r'\bapiLevel\s*=\s*(\d+)')
GMD_SRC_RX    = re.compile(r'\bsystemImageSource\s*=\s*"([^"]+)"')
GMD_BLOCK_NAME_RX = re.compile(r'(\w+)\s*\(\s*com\.android\.build\.api\.dsl\.ManagedVirtualDevice\s*\)', re.I)

def find_gmd_line_spans(gradle_text: str) -> list[tuple[int,int]]:
    spans=[]
    for m in GMD_BLOCK_HEAD_RX.finditer(gradle_text or ""):
        ci = _find_block_span_from_head(gradle_text, m.start())
        if ci: spans.append(_char_span_to_line_span(gradle_text, ci))
    return spans

def parse_gmd_from_gradle(gradle_text: str, span: tuple[int,int]) -> dict:
    lines = (gradle_text or "").splitlines()
    block_text = "\n".join(lines[span[0]-1:span[1]])
    norm = {
        "emulator_type":"GMD",
        "api_level":None,"image_source":None,"abi":None,
        "device_profile":None,"device_identifier":None,
        "start_mode":None,"gpu_mode":None,
        "headless_flags":{"no_window":None,"no_audio":None,"no_boot_anim":None},
        "boot_wait": None, "boot_wait_seconds": None,
        "gmd_device":None,"gmd_api_level":None,"gmd_system_image_source":None,
        "test_command":None,"runner_args":None,"context_anchor":None,
    }
    if (m := GMD_DEVICE_RX.search(block_text)):
        norm["device_profile"]=m.group(1); norm["gmd_device"]=m.group(1)
    if (m := GMD_API_RX.search(block_text)):
        norm["api_level"]=int(m.group(1)); norm["gmd_api_level"]=int(m.group(1))
    if (m := GMD_SRC_RX.search(block_text)):
        norm["image_source"]=m.group(1); norm["gmd_system_image_source"]=m.group(1)
    if (m := GMD_BLOCK_NAME_RX.search(block_text)):
        norm["device_identifier"]=m.group(1)
        norm["context_anchor"]=f"managedDevices.{norm['device_identifier']}"
    return norm

# --- DIY parser with numeric boot wait extraction
EMU_START_RX  = re.compile(r'(^|\n)\s*emulator(?:\.exe|\.bat)?\s+-avd\s+(\S+)(?P<rest>[^\n]*)', re.I)
AVD_CREATE_RX = re.compile(
    r'avdmanager\s+create\s+avd\b.*?-n\s+(\S+).*?-(?:k|--package)\s+"?system-images;android-(\d+);([^;]+);([A-Za-z0-9_]+)"?(?:.*?-(?:d|--device)\s+(\S+))?',
    re.I
)
SDKIMG_RX     = re.compile(r'system-images;android-(\d+);([^;]+);([A-Za-z0-9_]+)')
BOOT_WAIT_RX  = re.compile(r'adb\s+(?:-s\s+\S+\s+)?wait-for-device|adb\s+shell\s+getprop\s+sys\.boot_completed', re.I)
# crude numeric wait: sleep N | timeout /t N | (bash) timeout Ns cmd | GH composite 'timeout-minutes:'
SLEEP_SEC_RX  = re.compile(r'\bsleep\s+(\d+)\b', re.I)
TIMEOUT_SEC_RX= re.compile(r'\btimeout\s+(?:/t\s+)?(\d+)\b', re.I)
TIMEOUT_MIN_RX= re.compile(r'\btimeout-minutes\s*:\s*(\d+)\b', re.I)

def _extract_wait_seconds(text: str) -> Optional[int]:
    secs=[]
    for rx in (SLEEP_SEC_RX, TIMEOUT_SEC_RX):
        for m in rx.finditer(text or ""):
            try: secs.append(int(m.group(1)))
            except: pass
    for m in TIMEOUT_MIN_RX.finditer(text or ""):
        try: secs.append(int(m.group(1))*60)
        except: pass
    if secs: return max(secs)
    return None

def parse_diy_from_text(text: str) -> dict:
    t = text or ""
    norm = {
        "emulator_type":"DIY",
        "api_level":None,"image_source":None,"abi":None,
        "device_profile":None,"device_identifier":None,
        "start_mode":None,"gpu_mode":None,
        "headless_flags":{"no_window":None,"no_audio":None,"no_boot_anim":None},
        "boot_wait": None, "boot_wait_seconds": None,
        "test_command":None,"runner_args":None,"context_anchor":None,
    }
    anchor=None
    if (m := AVD_CREATE_RX.search(t)):
        norm["device_identifier"]=m.group(1)
        norm["api_level"]=int(m.group(2))
        norm["image_source"]=m.group(3)
        norm["abi"]=m.group(4)
        if m.group(5): norm["device_profile"]=m.group(5)
        anchor=f"avdmanager create:{norm['device_identifier']}"
    elif (m := SDKIMG_RX.search(t)):
        norm["api_level"]=int(m.group(1)); norm["image_source"]=m.group(2); norm["abi"]=m.group(3)
        anchor="sdkmanager system-image"

    if (m := EMU_START_RX.search(t)):
        rest = m.group("rest") or ""
        gm = re.search(r"-(?:-)?gpu\s+(\S+)", rest); norm["gpu_mode"]=gm.group(1) if gm else None
        norm["headless_flags"]["no_window"]    = bool(re.search(r"-no-window\b", rest))
        norm["headless_flags"]["no_audio"]     = bool(re.search(r"-no-audio\b", rest))
        norm["headless_flags"]["no_boot_anim"] = bool(re.search(r"-no-boot-anim\b", rest))
        norm["start_mode"] = "cold" if re.search(r"-no-snapshot\b", rest) else "snapshot"
        if not anchor:
            norm["device_identifier"] = norm["device_identifier"] or m.group(2)
            anchor = f"emulator -avd:{m.group(2)}"

    boot_wait = bool(BOOT_WAIT_RX.search(t))
    norm["boot_wait"] = boot_wait
    if boot_wait:
        norm["boot_wait_seconds"] = _extract_wait_seconds(t)
    norm["context_anchor"] = anchor or "diy:<unknown>"
    return norm

def infer_host_from_text(text: str) -> tuple[Optional[str], Optional[str]]:
    t = (text or "").lower()
    if "ubuntu" in t or "runs-on: ubuntu" in t or "linux" in t:  return "linux","kvm"
    if "macos" in t or "runs-on: macos" in t or "macos-latest" in t or "mac " in t: return "macos","hvf"
    return None, None

def file_kind_for_path(p: str) -> str:
    if is_gradle_file(p): return "gradle"
    if is_ci_file(p) and p.lower().endswith((".yml",".yaml")): return "ci_yaml"
    if is_script_file(p): return "script"
    return "other"

DIFF_HUNK_RX = re.compile(r"@@ -\d+(?:,\d+)? \+(\d+)(?:,(\d+))? @@")
def added_line_numbers_for_path(repo_dir: Path, sha: str, path: str) -> Optional[set[int]]:
    try:
        cp = sh(["git","-c","core.quotepath=off","diff","-U0", f"{sha}^", sha, "--", path],
                cwd=repo_dir, check=False)
    except Exception:
        return None
    if cp.returncode not in (0,1): return None
    added:set[int]=set(); new_line=None
    for line in cp.stdout.splitlines():
        m = DIFF_HUNK_RX.match(line)
        if m:
            start=int(m.group(1)); length=int(m.group(2) or "1"); new_line=start; continue
        if new_line is None: continue
        if line.startswith("+") and not line.startswith("+++"):
            added.add(new_line); new_line += 1
        elif line.startswith("-") and not line.startswith("---"):
            pass
        else:
            if not (line.startswith("---") or line.startswith("+++")):
                new_line += 1
    return added

def find_emulator_run_spans(yaml_text: str) -> list[tuple[int,int]]:
    lines = yaml_text.splitlines(); n=len(lines); spans=[]; i=0
    while i < n:
        mstep = STEP_START_RX.match(lines[i])
        if not mstep: i+=1; continue
        step_indent = len(mstep.group(1) or ""); j = i+1
        while j < n:
            if STEP_START_RX.match(lines[j]): break
            cur_indent = len(lines[j]) - len(lines[j].lstrip(" "))
            if cur_indent < step_indent and lines[j].strip(): break
            mrun = RUN_KEY_RX.match(lines[j])
            if mrun:
                block_indent = len(mrun.group(1) or ""); k = j+1; block_idx=[]
                while k < n:
                    ln = lines[k]
                    if not ln.strip(): block_idx.append(k); k+=1; continue
                    ind = len(ln) - len(ln.lstrip(" "))
                    if ind <= block_indent and not LIST_ITEM_RX.match(ln): break
                    block_idx.append(k); k+=1
                block_text = "\n".join(lines[x] for x in block_idx)
                if DIY_RX.search(block_text):
                    if block_idx: spans.append((min(block_idx)+1, max(block_idx)+1))
                j = k; continue
            j += 1
        i = j
    # merge adjacent
    merged: list[list[int]]=[]
    for s,e in sorted(spans):
        if not merged or s > merged[-1][1] + 1: merged.append([s,e])
        else: merged[-1][1] = max(merged[-1][1], e)
    return [(s,e) for s,e in merged]

def lines_overlap_spans(added: set[int] | None, spans: list[tuple[int,int]]) -> Optional[bool]:
    if added is None: return None
    if not spans: return False
    for a in added:
        for s,e in spans:
            if s <= a <= e: return True
    return False

def parse_medium_from_context(text: str) -> dict:
    t = text or ""
    out = {
        "image_flavor": None, "orchestrator_enabled": None, "num_shards": None,
        "locale": None, "timezone": None, "network_profile": None,
        "gmd_device": None, "gmd_api_level": None, "gmd_system_image_source": None,
    }
    if (m := re.search(r'\b(numShards|shards?)\s*[:=]\s*(\d+)', t, re.I)): out["num_shards"] = int(m.group(2))
    if (m := re.search(r'\blocale\s*[:=]\s*([A-Za-z]{2,3}[-_][A-Za-z]{2,3})', t)): out["locale"] = m.group(1)
    if (m := re.search(r'\b(timezone|TZ)\s*[:=]\s*([A-Za-z_/\-]+)', t)): out["timezone"] = m.group(2)
    if (m := re.search(r'\b(networkProfile|throttle(?:d|))\s*[:=]\s*([A-Za-z0-9_\-]+)', t, re.I)): out["network_profile"] = m.group(2)
    if re.search(r'\bplay\b', t, re.I): out["image_flavor"]="play"
    elif re.search(r'google-?apis', t, re.I): out["image_flavor"]="google_apis"
    elif re.search(r'google-?atd', t, re.I): out["image_flavor"]="google-atd"
    elif re.search(r'\baosp\b', t, re.I): out["image_flavor"]="aosp"
    # Orchestrator
    if orchestrator_enabled_in_text(t): out["orchestrator_enabled"]=True
    return out

def parse_toolchain_from_context(path: str, text: str) -> dict:
    t = text or ""; out = {
        "agp_version": None, "gradle_version": None, "jdk_version": None,
        "android_sdk_installed": None, "android_sdk_licenses": None,
    }
    if (m := re.search(r'com\.android\.tools\.build:gradle:([0-9][^\'"\s\)]+)', t)): out["agp_version"]=m.group(1)
    if "gradle/wrapper/gradle-wrapper.properties" in path.replace("\\","/"):
        if (m := re.search(r"distributionUrl=.*?/gradle-([0-9][\w\.\-]+)-", t)): out["gradle_version"]=m.group(1)
    if (m := re.search(r'(java-version|actions/setup-java).*(?:=|:)\s*([0-9][0-9]?)', t, re.I)): out["jdk_version"]=m.group(2)
    if re.search(r'\bsdkmanager\b', t): out["android_sdk_installed"]=True
    if re.search(r'sdkmanager\s+--licenses', t): out["android_sdk_licenses"]=True
    return out

def write_jsonl(path: Path, rows: List[dict]):
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as f:
        for r in rows: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def main():
    repos = [p for p in CLONE_ROOT.iterdir() if (p / ".git").exists()]
    repos.sort(key=lambda p: p.name.lower())
    print(f"Found {len(repos)} repos in {CLONE_ROOT}")

    ok=skip=err=0
    for repo in repos:
        try:
            rel_commits = list_relevant_commits(repo)
            if MAX_COMMITS_PER_REPO > 0: rel_commits = rel_commits[:MAX_COMMITS_PER_REPO]

            out_rows: List[dict] = []
            for sha, ts, changed_paths in rel_commits:
                rel_paths = [p for p in changed_paths if is_ci_file(p) or is_gradle_file(p) or is_script_file(p)]
                if not rel_paths: continue

                subj = git_subject(repo, sha)
                for pth in rel_paths:
                    txt = git_show(repo, sha, pth)
                    if txt is None: continue

                    # Detected params
                    detected: list[dict] = []
                    test_cmd = _find_test_command(txt)
                    runner_args = _parse_runner_args_from_cmd(test_cmd or "")

                    if pth.lower().endswith((".yml",".yaml")):
                        for g in parse_generic_from_yaml(txt):
                            g["test_command"]=test_cmd; g["runner_args"]=runner_args; detected.append(g)

                    if is_gradle_file(pth):
                        for sp in find_gmd_line_spans(txt):
                            gmd = parse_gmd_from_gradle(txt, sp)
                            gmd["test_command"]=test_cmd; gmd["runner_args"]=runner_args; detected.append(gmd)

                    if is_script_file(pth) or (pth.lower().endswith((".yml",".yaml")) and "run:" in (txt or "")):
                        if DIY_RX.search(txt or ""):
                            diy = parse_diy_from_text(txt or "")
                            diy["test_command"]=test_cmd; diy["runner_args"]=runner_args
                            if any(diy.get(k) for k in ("api_level","image_source","abi","device_identifier","gpu_mode","boot_wait","boot_wait_seconds")):
                                detected.append(diy)

                    feats: Dict[str,Any] = {}
                    if detected:
                        # attach host/hypervisor
                        host_os, hypervisor = infer_host_from_text(txt)
                        for dp in detected:
                            dp.setdefault("host_os", host_os)
                            dp.setdefault("hypervisor", hypervisor)
                        feats["detected_params"] = detected

                    # Medium & toolchain
                    med = parse_medium_from_context(txt or "")
                    tool = parse_toolchain_from_context(pth, txt or "")
                    if any(v is not None for v in med.values()):
                        feats["medium_params"] = {k:v for k,v in med.items() if v is not None}
                    if any(v is not None for v in tool.values()):
                        feats["toolchain_params"] = {k:v for k,v in tool.items() if v is not None}

                    # Labels
                    fk = file_kind_for_path(pth)
                    added_lines = added_line_numbers_for_path(repo, sha, pth)
                    ci_spans  = find_emulator_run_spans(txt) if fk == "ci_yaml" else None
                    gmd_spans = find_gmd_line_spans(txt)     if fk == "gradle"  else None
                    ci_emu_change     = lines_overlap_spans(added_lines, ci_spans or []) if fk == "ci_yaml" else None
                    gradle_gmd_change = lines_overlap_spans(added_lines, gmd_spans or []) if fk == "gradle" else None

                    labels = {
                        "file_kind": fk,
                        "ci_emulator_step_change": ci_emu_change,
                        "gradle_gmd_block_change": gradle_gmd_change,
                        # presence bit helps Step-2 repo/episode synthesis
                        "gmd_present": bool(gmd_spans) if fk == "gradle" else None,
                    }
                    feats["labels"] = labels

                    if not feats: continue
                    out_rows.append({
                        "repo": repo.name,
                        "sha": sha,
                        "timestamp": ts,
                        "subject": subj,
                        "path": pth,
                        "features": feats,
                    })

            if not out_rows:
                print(f"[skip] {repo.name}: no relevant snapshots"); skip += 1; continue
            dst = SNAPSHOT_DIR / f"{repo.name}.jsonl"
            write_jsonl(dst, out_rows)
            print(f"[ok] {repo.name}: {len(out_rows)} snapshots -> {dst}"); ok += 1

        except Exception as e:
            print(f"[err] {repo.name}: {e}"); err += 1

    print(f"\nDone. ok={ok}, skip={skip}, err={err}, out_dir={SNAPSHOT_DIR}")

if __name__ == "__main__":
    main()
# Out:
# [cutoff] Using commit cutoff <= 2025-08-10 23:59:59 -0400 (epoch=1754884799)
# Found 282 repos in C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\clones
# [ok] 4eRTuk__audioview: 78 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\4eRTuk__audioview.jsonl
# [ok] a-mabe__OpenHIIT: 171 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\a-mabe__OpenHIIT.jsonl
# [ok] a914-gowtham__compose-ratingbar: 159 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\a914-gowtham__compose-ratingbar.jsonl
# [ok] AAkira__ExpandableLayout: 56 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AAkira__ExpandableLayout.jsonl
# [ok] abdelaziz-mahdy__pytorch_lite: 131 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\abdelaziz-mahdy__pytorch_lite.jsonl
# [ok] ably__ably-flutter: 316 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ably__ably-flutter.jsonl
# [ok] AChep__AcDisplay: 150 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AChep__AcDisplay.jsonl
# [ok] ActivityWatch__aw-android: 191 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ActivityWatch__aw-android.jsonl
# [ok] AdevintaSpain__Barista: 243 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AdevintaSpain__Barista.jsonl
# [ok] admob-plus__admob-plus: 301 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\admob-plus__admob-plus.jsonl
# [ok] adorsys__secure-storage-android: 228 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\adorsys__secure-storage-android.jsonl
# [ok] airbnb__paris: 228 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\airbnb__paris.jsonl
# [ok] Albert221__FastShopping: 122 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Albert221__FastShopping.jsonl
# [ok] alexbakker__webdav-provider: 98 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\alexbakker__webdav-provider.jsonl
# [ok] alexstyl__contactstore: 63 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\alexstyl__contactstore.jsonl
# [ok] am15h__tflite_flutter_helper: 44 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\am15h__tflite_flutter_helper.jsonl
# [ok] amahi__android: 217 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\amahi__android.jsonl
# [ok] amitshekhariitbhu__Fast-Android-Networking: 182 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\amitshekhariitbhu__Fast-Android-Networking.jsonl
# [ok] AndBible__and-bible: 911 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AndBible__and-bible.jsonl
# [ok] AndProx__AndProx: 50 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AndProx__AndProx.jsonl
# [ok] andremion__Villains-and-Heroes: 54 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\andremion__Villains-and-Heroes.jsonl
# [ok] andreynovikov__trekarta: 242 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\andreynovikov__trekarta.jsonl
# [ok] android__codelab-android-compose: 3849 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\android__codelab-android-compose.jsonl
# [ok] android__nowinandroid: 1232 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\android__nowinandroid.jsonl
# [ok] andstatus__andstatus: 629 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\andstatus__andstatus.jsonl
# [ok] anilbeesetti__nextplayer: 325 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\anilbeesetti__nextplayer.jsonl
# [ok] anjlab__android-inapp-billing-v3: 150 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\anjlab__android-inapp-billing-v3.jsonl
# [ok] ankidroid__Anki-Android: 2441 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ankidroid__Anki-Android.jsonl
# [ok] AntennaPod__AntennaPod: 1120 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\AntennaPod__AntennaPod.jsonl
# [ok] Arian04__android-hid-client: 94 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Arian04__android-hid-client.jsonl
# [ok] aws__amazon-ivs-react-native-player: 166 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\aws__amazon-ivs-react-native-player.jsonl
# [ok] Bdaya-Dev__oidc: 348 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Bdaya-Dev__oidc.jsonl
# [ok] beemdevelopment__Aegis: 332 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\beemdevelopment__Aegis.jsonl
# [ok] bilibili__boxing: 73 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\bilibili__boxing.jsonl
# [ok] bitfireAT__icsx5: 374 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\bitfireAT__icsx5.jsonl
# [ok] BlueWallet__BlueWallet: 1120 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\BlueWallet__BlueWallet.jsonl
# [ok] brandonp2412__FitBook: 182 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\brandonp2412__FitBook.jsonl
# [ok] brarcher__video-transcoder: 77 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\brarcher__video-transcoder.jsonl
# [ok] briar__briar: 1134 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\briar__briar.jsonl
# [ok] burnoo__cokoin: 148 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\burnoo__cokoin.jsonl
# [ok] CarlosMChica__easyrecycleradapters: 76 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\CarlosMChica__easyrecycleradapters.jsonl
# [ok] cashapp__paraphrase: 318 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\cashapp__paraphrase.jsonl
# [ok] CatimaLoyalty__Android: 757 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\CatimaLoyalty__Android.jsonl
# [ok] cgeo__cgeo: 1408 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\cgeo__cgeo.jsonl
# [ok] chenxiaolong__RSAF: 81 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\chenxiaolong__RSAF.jsonl
# [ok] cliqz-oss__browser-android: 212 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\cliqz-oss__browser-android.jsonl
# [ok] cloudinary__cloudinary_android: 206 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\cloudinary__cloudinary_android.jsonl
# [ok] coil-kt__coil: 1910 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\coil-kt__coil.jsonl
# [ok] commons-app__apps-android-commons: 682 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\commons-app__apps-android-commons.jsonl
# [ok] concretesolutions__canarinho: 137 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\concretesolutions__canarinho.jsonl
# [ok] connectbot__connectbot: 761 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\connectbot__connectbot.jsonl
# [ok] Crazy-Marvin__MetadataRemover: 452 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Crazy-Marvin__MetadataRemover.jsonl
# [ok] dart-lang__http: 437 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dart-lang__http.jsonl
# [ok] dart-lang__native: 740 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dart-lang__native.jsonl
# [ok] dbrodie__AdBuster: 22 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dbrodie__AdBuster.jsonl
# [ok] DesarrolloAntonio__Shiori-Android-Client: 184 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\DesarrolloAntonio__Shiori-Android-Client.jsonl
# [ok] dgngulcan__droid-feed: 155 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dgngulcan__droid-feed.jsonl
# [ok] dlew__joda-time-android: 288 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dlew__joda-time-android.jsonl
# [ok] dmfs__opentasks: 154 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\dmfs__opentasks.jsonl
# [ok] doublesymmetry__KotlinAudio: 134 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\doublesymmetry__KotlinAudio.jsonl
# [ok] droidconKE__droidconKeKotlin: 302 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\droidconKE__droidconKeKotlin.jsonl
# [ok] DroidKaigi__conference-app-2020: 450 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\DroidKaigi__conference-app-2020.jsonl
# [ok] elftausend__custos: 71 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\elftausend__custos.jsonl
# [ok] EnsembleUI__ensemble: 520 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\EnsembleUI__ensemble.jsonl
# [ok] ErickSumargo__Dads: 203 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ErickSumargo__Dads.jsonl
# [ok] erkkah__naett: 42 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\erkkah__naett.jsonl
# [ok] EvanRespaut__Equate: 81 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\EvanRespaut__Equate.jsonl
# [ok] EventFahrplan__EventFahrplan: 599 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\EventFahrplan__EventFahrplan.jsonl
# [ok] evilcorpltd__aTox: 484 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\evilcorpltd__aTox.jsonl
# [ok] f-arslan__GptMap: 341 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\f-arslan__GptMap.jsonl
# [ok] f-droid__fdroidclient: 1237 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\f-droid__fdroidclient.jsonl
# [ok] FabianTerhorst__Iron: 130 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\FabianTerhorst__Iron.jsonl
# [ok] Faltenreich__Diaguard: 716 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Faltenreich__Diaguard.jsonl
# [ok] federicoiosue__Omni-Notes: 748 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\federicoiosue__Omni-Notes.jsonl
# [ok] fewlaps__flone-android: 38 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\fewlaps__flone-android.jsonl
# [ok] firebase__FirebaseUI-Flutter: 188 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\firebase__FirebaseUI-Flutter.jsonl
# [ok] Five-Prayers__five-prayers-android: 149 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Five-Prayers__five-prayers-android.jsonl
# [ok] flauschtrud__broccoli: 270 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\flauschtrud__broccoli.jsonl
# [ok] flet-dev__serious-python: 175 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\flet-dev__serious-python.jsonl
# [ok] fluttercommunity__flutter_workmanager: 210 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\fluttercommunity__flutter_workmanager.jsonl
# [ok] fornewid__naver-map-compose: 281 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\fornewid__naver-map-compose.jsonl
# [ok] fossasia__loklak_wok_android: 51 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\fossasia__loklak_wok_android.jsonl
# [ok] fossasia__phimpme-android: 441 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\fossasia__phimpme-android.jsonl
# [ok] freeotp__freeotp-android: 98 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\freeotp__freeotp-android.jsonl
# [ok] gemwalletcom__gem-android: 265 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\gemwalletcom__gem-android.jsonl
# [ok] getsentry__sentry-react-native: 1149 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\getsentry__sentry-react-native.jsonl
# [ok] gotev__android-speech: 86 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\gotev__android-speech.jsonl
# [ok] grandstaish__paperparcel: 236 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\grandstaish__paperparcel.jsonl
# [ok] greenaddress__abcore: 182 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\greenaddress__abcore.jsonl
# [ok] grote__Transportr: 389 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\grote__Transportr.jsonl
# [ok] guardianproject__proofmode-android: 396 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\guardianproject__proofmode-android.jsonl
# [ok] H-PixelDroid__PixelDroid: 423 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\H-PixelDroid__PixelDroid.jsonl
# [ok] haiyangwu__mediasoup-client-android: 760 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\haiyangwu__mediasoup-client-android.jsonl
# [ok] hannesa2__panoramaGL: 385 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\hannesa2__panoramaGL.jsonl
# [ok] haqq-network__haqq-wallet: 1013 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\haqq-network__haqq-wallet.jsonl
# [ok] haroldadmin__MoonShot: 365 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\haroldadmin__MoonShot.jsonl
# [ok] hitherejoe__minimise: 334 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\hitherejoe__minimise.jsonl
# [ok] Hny0305Lin__NLChat: 62 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Hny0305Lin__NLChat.jsonl
# [ok] hoc081098__ViewBindingDelegate: 266 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\hoc081098__ViewBindingDelegate.jsonl
# [ok] ice-blockchain__mobile-app: 77 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ice-blockchain__mobile-app.jsonl
# [ok] ImaginativeShohag__Why-Not-Compose: 334 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ImaginativeShohag__Why-Not-Compose.jsonl
# [ok] inaturalist__iNaturalistAndroid: 311 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\inaturalist__iNaturalistAndroid.jsonl
# [ok] inaturalist__iNaturalistReactNative: 597 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\inaturalist__iNaturalistReactNative.jsonl
# [ok] invertase__notifee: 405 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\invertase__notifee.jsonl
# [ok] invertase__react-native-google-mobile-ads: 242 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\invertase__react-native-google-mobile-ads.jsonl
# [ok] ipfs-shipyard__gomobile-ipfs: 170 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ipfs-shipyard__gomobile-ipfs.jsonl
# [ok] irgaly__kfswatch: 95 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\irgaly__kfswatch.jsonl
# [ok] izderadicka__audioserve-android: 108 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\izderadicka__audioserve-android.jsonl
# [ok] JackEblan__Geto: 749 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\JackEblan__Geto.jsonl
# [ok] JakeWharton__RxBinding: 409 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\JakeWharton__RxBinding.jsonl
# [ok] JakeWharton__u2020: 185 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\JakeWharton__u2020.jsonl
# [ok] jameshnsears__QuoteUnquote: 371 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jameshnsears__QuoteUnquote.jsonl
# [ok] jaredsburrows__android-gif-search: 839 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jaredsburrows__android-gif-search.jsonl
# [ok] javiersantos__PiracyChecker: 103 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\javiersantos__PiracyChecker.jsonl
# [ok] jerson__flutter-openpgp: 203 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jerson__flutter-openpgp.jsonl
# [ok] jerson__flutter-rsa: 234 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jerson__flutter-rsa.jsonl
# [ok] jianjunxiao__NiceVieoPlayer: 59 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jianjunxiao__NiceVieoPlayer.jsonl
# [ok] JimmyDaddy__react-native-image-marker: 133 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\JimmyDaddy__react-native-image-marker.jsonl
# [ok] joreilly__PeopleInSpace: 669 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\joreilly__PeopleInSpace.jsonl
# [ok] joreilly__StarWars: 218 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\joreilly__StarWars.jsonl
# [ok] juancastillo0__wasm_run: 189 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\juancastillo0__wasm_run.jsonl
# [ok] jungilhan__awesome-blogs-android: 101 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\jungilhan__awesome-blogs-android.jsonl
# [ok] kalaspuffar__secure-quick-reliable-login: 238 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\kalaspuffar__secure-quick-reliable-login.jsonl
# [ok] kamgurgul__cpu-info: 615 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\kamgurgul__cpu-info.jsonl
# [ok] KaustubhPatange__navigator: 329 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\KaustubhPatange__navigator.jsonl
# [ok] kebernet__shortyz: 63 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\kebernet__shortyz.jsonl
# [ok] krzdabrowski__android-starter-2022: 183 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\krzdabrowski__android-starter-2022.jsonl
# [ok] ksoichiro__Android-ObservableScrollView: 124 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ksoichiro__Android-ObservableScrollView.jsonl
# [ok] ksoichiro__AndroidFormEnhancer: 61 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ksoichiro__AndroidFormEnhancer.jsonl
# [ok] ksoichiro__SimpleAlertDialog-for-Android: 76 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ksoichiro__SimpleAlertDialog-for-Android.jsonl
# [ok] kylecorry31__Trail-Sense: 970 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\kylecorry31__Trail-Sense.jsonl
# [ok] labexp__osmtracker-android: 126 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\labexp__osmtracker-android.jsonl
# [ok] lcdsmao__JetTheme: 149 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\lcdsmao__JetTheme.jsonl
# [ok] leandroBorgesFerreira__LoadingButtonAndroid: 254 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\leandroBorgesFerreira__LoadingButtonAndroid.jsonl
# [ok] LedgerHQ__ledger-live: 4907 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\LedgerHQ__ledger-live.jsonl
# [ok] letelete__sleep-cycle-alarm: 84 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\letelete__sleep-cycle-alarm.jsonl
# [ok] ligi__PassAndroid: 934 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ligi__PassAndroid.jsonl
# [ok] ligi__SurvivalManual: 393 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ligi__SurvivalManual.jsonl
# [ok] LinkSheet__LinkSheet: 706 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\LinkSheet__LinkSheet.jsonl
# [ok] LinX64__CoinCap: 183 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\LinX64__CoinCap.jsonl
# [ok] livefront__bridge: 39 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\livefront__bridge.jsonl
# [ok] MackHartley__RoundedProgressBar: 28 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\MackHartley__RoundedProgressBar.jsonl
# [ok] maksim-m__Popular-Movies-App: 88 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\maksim-m__Popular-Movies-App.jsonl
# [ok] MarcinMoskala__PreferenceHolder: 62 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\MarcinMoskala__PreferenceHolder.jsonl
# [ok] massivedisaster__ADAL: 311 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\massivedisaster__ADAL.jsonl
# [ok] massivemadness__Squircle-CE: 1855 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\massivemadness__Squircle-CE.jsonl
# [ok] mathisdt__trackworktime: 371 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\mathisdt__trackworktime.jsonl
# [ok] maxkeppeler__sheets-compose-dialogs: 232 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\maxkeppeler__sheets-compose-dialogs.jsonl
# [ok] maxpower47__PinDroid: 94 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\maxpower47__PinDroid.jsonl
# [ok] medic__cht-gateway: 213 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\medic__cht-gateway.jsonl
# [ok] MetaMask__metamask-mobile: 7921 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\MetaMask__metamask-mobile.jsonl
# [ok] michaeltroger__pdfwallet-android: 327 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\michaeltroger__pdfwallet-android.jsonl
# [ok] michelelacorte__AndroidAppShortcuts: 45 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\michelelacorte__AndroidAppShortcuts.jsonl
# [ok] microservicer__flutter-pipelines: 290 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\microservicer__flutter-pipelines.jsonl
# [ok] miguelhincapie__CustomBottomSheetBehavior: 45 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\miguelhincapie__CustomBottomSheetBehavior.jsonl
# [ok] MikeOrtiz__TouchImageView: 447 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\MikeOrtiz__TouchImageView.jsonl
# [ok] MiSikora__laboratory: 1623 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\MiSikora__laboratory.jsonl
# [ok] mjaakko__NeoStumbler: 405 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\mjaakko__NeoStumbler.jsonl
# [ok] moezbhatti__qksms: 557 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\moezbhatti__qksms.jsonl
# [ok] mshdabiola__NotePad: 336 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\mshdabiola__NotePad.jsonl
# [ok] n8ebel__GitHubActionsAutomationSandbox: 135 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\n8ebel__GitHubActionsAutomationSandbox.jsonl
# [ok] Nailik__rhasspy_mobile: 1065 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Nailik__rhasspy_mobile.jsonl
# [ok] nanihadesuka__NovelDokusha: 314 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\nanihadesuka__NovelDokusha.jsonl
# [ok] natario1__GIFCompressor: 80 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\natario1__GIFCompressor.jsonl
# [ok] natsuk4ze__gal: 339 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\natsuk4ze__gal.jsonl
# [ok] nextcloud__android: 5272 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\nextcloud__android.jsonl
# [ok] nhirokinet__bluelineconsole: 151 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\nhirokinet__bluelineconsole.jsonl
# [ok] NiciDieNase__chaosflix: 664 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\NiciDieNase__chaosflix.jsonl
# [ok] nightscout__AndroidAPS: 3108 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\nightscout__AndroidAPS.jsonl
# [ok] nschnettler__Compose-Scrobbler: 537 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\nschnettler__Compose-Scrobbler.jsonl
# [ok] NUmeroAndDev__MaterialGallery-android: 631 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\NUmeroAndDev__MaterialGallery-android.jsonl
# [ok] OlauncherCF__OlauncherCF: 147 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\OlauncherCF__OlauncherCF.jsonl
# [ok] OneBusAway__onebusaway-android: 442 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\OneBusAway__onebusaway-android.jsonl
# [ok] ooni__probe-android: 607 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ooni__probe-android.jsonl
# [ok] opendocument-app__OpenDocument.droid: 424 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\opendocument-app__OpenDocument.droid.jsonl
# [ok] openhab__openhab-android: 1685 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\openhab__openhab-android.jsonl
# [ok] openintents__shoppinglist: 147 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\openintents__shoppinglist.jsonl
# [ok] openthread__ot-commissioner: 304 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\openthread__ot-commissioner.jsonl
# [ok] OpenTracksApp__OpenTracks: 2048 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\OpenTracksApp__OpenTracks.jsonl
# [ok] OpnTec__bodyapps-android: 19 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\OpnTec__bodyapps-android.jsonl
# [ok] orgzly-revived__orgzly-android-revived: 727 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\orgzly-revived__orgzly-android-revived.jsonl
# [ok] owntracks__android: 1190 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\owntracks__android.jsonl
# [ok] oxygen-updater__oxygen-updater: 389 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\oxygen-updater__oxygen-updater.jsonl
# [ok] pachli__pachli-android: 1070 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\pachli__pachli-android.jsonl
# [ok] passsy__spot: 25 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\passsy__spot.jsonl
# [ok] PatilShreyas__NotyKT: 493 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\PatilShreyas__NotyKT.jsonl
# [ok] persian-calendar__persian-calendar: 1482 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\persian-calendar__persian-calendar.jsonl
# [ok] PhoneVR-Developers__PhoneVR: 189 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\PhoneVR-Developers__PhoneVR.jsonl
# [ok] Picovoice__porcupine: 1248 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Picovoice__porcupine.jsonl
# [ok] pilgr__Paper: 112 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\pilgr__Paper.jsonl
# [ok] Piwigo__Piwigo-Android: 147 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Piwigo__Piwigo-Android.jsonl
# [ok] posm__OpenMapKitAndroid: 58 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\posm__OpenMapKitAndroid.jsonl
# [ok] prisma__react-native-prisma: 35 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\prisma__react-native-prisma.jsonl
# [ok] pytorch__executorch: 38522 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\pytorch__executorch.jsonl
# [ok] rafsanjani__datepickertimeline: 273 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\rafsanjani__datepickertimeline.jsonl
# [ok] ragunathjawahar__android-saripaar: 56 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ragunathjawahar__android-saripaar.jsonl
# [ok] rainbow-me__rainbow: 1374 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\rainbow-me__rainbow.jsonl
# [ok] Rajawali__Rajawali: 570 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Rajawali__Rajawali.jsonl
# [ok] RBusarow__Tangle: 527 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\RBusarow__Tangle.jsonl
# [ok] ReactiveCircus__streamlined: 620 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ReactiveCircus__streamlined.jsonl
# [ok] readrops__Readrops: 419 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\readrops__Readrops.jsonl
# [ok] realm__realm-kotlin: 1646 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\realm__realm-kotlin.jsonl
# [ok] Redgram__redgram-for-reddit: 72 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Redgram__redgram-for-reddit.jsonl
# [ok] rejasupotaro__Rebuild: 121 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\rejasupotaro__Rebuild.jsonl
# [ok] renyuneyun__Easer: 296 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\renyuneyun__Easer.jsonl
# [ok] requery__requery: 312 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\requery__requery.jsonl
# [ok] robolectric__robolectric: 3398 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\robolectric__robolectric.jsonl
# [ok] ronaldsmartin__Material-ViewPagerIndicator: 45 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ronaldsmartin__Material-ViewPagerIndicator.jsonl
# [ok] rozPierog__Cofi: 516 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\rozPierog__Cofi.jsonl
# [ok] ruffle-rs__ruffle-android: 156 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ruffle-rs__ruffle-android.jsonl
# [ok] sakusaku3939__DeepLAndroid: 112 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sakusaku3939__DeepLAndroid.jsonl
# [ok] Samsung__escargot: 567 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Samsung__escargot.jsonl
# [ok] sangcomz__FishBun: 335 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sangcomz__FishBun.jsonl
# [ok] scribe-org__Scribe-Android: 182 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\scribe-org__Scribe-Android.jsonl
# [ok] SecUSo__privacy-friendly-notes: 113 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\SecUSo__privacy-friendly-notes.jsonl
# [ok] SecUSo__privacy-friendly-pedometer: 99 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\SecUSo__privacy-friendly-pedometer.jsonl
# [ok] SecUSo__privacy-friendly-todo-list: 119 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\SecUSo__privacy-friendly-todo-list.jsonl
# [ok] seedvault-app__seedvault: 367 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\seedvault-app__seedvault.jsonl
# [ok] segler-alex__RadioDroid: 254 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\segler-alex__RadioDroid.jsonl
# [ok] sellmair__kompass: 183 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sellmair__kompass.jsonl
# [ok] servo__surfman: 81 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\servo__surfman.jsonl
# [ok] simonnorberg__dmach: 240 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\simonnorberg__dmach.jsonl
# [ok] simpledotorg__simple-android: 907 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\simpledotorg__simple-android.jsonl
# [ok] sky-map-team__stardroid: 501 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sky-map-team__stardroid.jsonl
# [ok] slackhq__circuit: 1065 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\slackhq__circuit.jsonl
# [ok] smartdevicelink__sdl_java_suite: 664 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\smartdevicelink__sdl_java_suite.jsonl
# [ok] softartdev__NoteDelight: 1044 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\softartdev__NoteDelight.jsonl
# [ok] software-mansion__react-native-screens: 1018 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\software-mansion__react-native-screens.jsonl
# [ok] sopt-makers__sopt-android: 469 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sopt-makers__sopt-android.jsonl
# [ok] spacecowboy__NotePad: 643 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\spacecowboy__NotePad.jsonl
# [ok] splitwise__TokenAutoComplete: 140 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\splitwise__TokenAutoComplete.jsonl
# [ok] sqldelight__sqldelight: 3752 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\sqldelight__sqldelight.jsonl
# [ok] square__curtains: 60 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__curtains.jsonl
# [ok] square__cycler: 66 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__cycler.jsonl
# [ok] square__leakcanary: 1101 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__leakcanary.jsonl
# [ok] square__okhttp: 1377 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__okhttp.jsonl
# [ok] square__papa: 155 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__papa.jsonl
# [ok] square__wire: 2510 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\square__wire.jsonl
# [ok] StefanIlchev__ElementumService: 407 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\StefanIlchev__ElementumService.jsonl
# [ok] streetwriters__notesnook: 912 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\streetwriters__notesnook.jsonl
# [ok] Stuart-campbell__RushOrm: 75 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Stuart-campbell__RushOrm.jsonl
# [ok] SundeepK__CompactCalendarView: 121 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\SundeepK__CompactCalendarView.jsonl
# [ok] SwissCovid__swisscovid-app-android: 235 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\SwissCovid__swisscovid-app-android.jsonl
# [ok] synonymdev__bitkit: 324 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\synonymdev__bitkit.jsonl
# [ok] syrjs__core: 49 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\syrjs__core.jsonl
# [ok] t895__DNSNet: 367 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\t895__DNSNet.jsonl
# [ok] takahirom__PreLollipopTransition: 73 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\takahirom__PreLollipopTransition.jsonl
# [ok] tasks__tasks: 1600 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\tasks__tasks.jsonl
# [ok] TeamAmaze__AmazeFileManager: 932 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\TeamAmaze__AmazeFileManager.jsonl
# [ok] TeamNewPipe__NewPipe: 982 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\TeamNewPipe__NewPipe.jsonl
# [ok] TechbeeAT__jtxBoard: 1643 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\TechbeeAT__jtxBoard.jsonl
# [ok] tfcporciuncula__flow-preferences: 87 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\tfcporciuncula__flow-preferences.jsonl
# [ok] thevindu-w__clip_share_client: 140 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\thevindu-w__clip_share_client.jsonl
# [ok] ThibaultBee__srtdroid: 204 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ThibaultBee__srtdroid.jsonl
# [ok] thunderbiscuit__padawan-wallet: 238 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\thunderbiscuit__padawan-wallet.jsonl
# [ok] thyrlian__AwesomeValidation: 288 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\thyrlian__AwesomeValidation.jsonl
# [ok] Tommy-Geenexus__exif-eraser: 170 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\Tommy-Geenexus__exif-eraser.jsonl
# [ok] TomRoush__PdfBox-Android: 286 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\TomRoush__PdfBox-Android.jsonl
# [ok] tonilopezmr__Game-of-Thrones: 94 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\tonilopezmr__Game-of-Thrones.jsonl
# [ok] trynoice__android-app: 662 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\trynoice__android-app.jsonl
# [ok] TwidereProject__TwidereX-Android: 549 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\TwidereProject__TwidereX-Android.jsonl
# [ok] twireapp__Twire: 230 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\twireapp__Twire.jsonl
# [ok] uber__simple-store: 159 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\uber__simple-store.jsonl
# [ok] UriahShaulMandel__BaldPhone: 283 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\UriahShaulMandel__BaldPhone.jsonl
# [ok] v2er-app__Android: 352 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\v2er-app__Android.jsonl
# [ok] ValentinFunk__BrainPhaser: 43 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\ValentinFunk__BrainPhaser.jsonl
# [ok] vanniktech__OnActivityResult: 132 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\vanniktech__OnActivityResult.jsonl
# [ok] vmiklos__plees-tracker: 340 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\vmiklos__plees-tracker.jsonl
# [ok] voghDev__PdfViewPager: 86 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\voghDev__PdfViewPager.jsonl
# [ok] VREMSoftwareDevelopment__WiFiAnalyzer: 603 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\VREMSoftwareDevelopment__WiFiAnalyzer.jsonl
# [ok] wajahatkarim3__Imagine: 93 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\wajahatkarim3__Imagine.jsonl
# [ok] WangJie0822__Cashbook: 532 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\WangJie0822__Cashbook.jsonl
# [ok] wikimedia__apps-android-wikipedia: 1646 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\wikimedia__apps-android-wikipedia.jsonl
# [ok] xebia-functional__appsly-android-rest: 56 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\xebia-functional__appsly-android-rest.jsonl
# [ok] XRPL-Labs__Xaman-App: 397 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\XRPL-Labs__Xaman-App.jsonl
# [ok] yeungeek__monkey-android: 95 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\yeungeek__monkey-android.jsonl
# [ok] yogeshpaliyal__KeyPass: 965 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\yogeshpaliyal__KeyPass.jsonl
# [ok] yuriykulikov__AlarmClock: 286 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\yuriykulikov__AlarmClock.jsonl
# [ok] zimly__zimly-backup: 310 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\zimly__zimly-backup.jsonl
# [ok] zkmopro__mopro: 250 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\zkmopro__mopro.jsonl
# [ok] zoff99__ToxAndroidRefImpl: 2137 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\zoff99__ToxAndroidRefImpl.jsonl
# [ok] zsoltk__GameOfLife: 65 snapshots -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots\zsoltk__GameOfLife.jsonl
#
# Done. ok=282, skip=0, err=0, out_dir=C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots

# %%
# RQ2 — Step 2, V5.1 (No baseline emission; style tracking + proper change types)
# - NO "begin" rows (we start emitting only when a real delta exists)
# - Proper change_type: added / removed / modified
# - Proper change_op: add / remove / value_edit / no_change
# - Reads Step-1 detected_params[*].emulator_type -> episode style Old/New/Change
# - Preserves original schema; adds AUX columns for Style/GMD/Orchestrator & coverage/runtime hints

from __future__ import annotations
import json, re
import datetime as _dt
from pathlib import Path
from typing import Dict, Any, List, Tuple, Optional

# -----------------------------
# Config
# -----------------------------
WORK_ROOT         = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2")
SNAPSHOT_DIR      = WORK_ROOT / "snapshots"
OUT_DIR           = WORK_ROOT / "cce_enriched_V5.1"
OUT_DIR.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Small helpers
# -----------------------------
VERSION_RE = re.compile(r"\d+(?:\.\d+)*")

def read_snapshots(folder: Path) -> Dict[str, List[dict]]:
    by_repo: Dict[str, List[dict]] = {}
    for p in folder.glob("*.jsonl"):
        with p.open(encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                d = json.loads(line)
                repo = d.get("repo")
                if not repo:
                    continue
                by_repo.setdefault(repo, []).append(d)
    # preserve per-path chronological order
    for repo, rows in by_repo.items():
        rows.sort(key=lambda r: (r.get("path",""), int(r.get("timestamp", 0)), r.get("sha","")))
    return by_repo

def stringify(x: Any) -> str:
    if isinstance(x, (dict, list, set, tuple)):
        try: return json.dumps(x, ensure_ascii=False, sort_keys=True)
        except: return str(x)
    return "" if x is None else str(x)

def _safe_json_loads(s: str):
    try: return json.loads(s) if s else None
    except: return None

def ensure_utc_epoch(ts_any) -> int:
    try: ts = int(float(ts_any))
    except: ts = 0
    return ts

def epoch_to_iso_utc(ts: int) -> str:
    return _dt.datetime.fromtimestamp(int(ts), tz=_dt.timezone.utc).isoformat().replace("+00:00", "Z")

def parse_version_tuple(s: str) -> Tuple[int, ...]:
    m = VERSION_RE.search(str(s) if s is not None else "")
    if not m: return tuple()
    parts = m.group(0).split(".")
    out: List[int] = []
    for p in parts:
        try: out.append(int(p))
        except: out.append(0)
    return tuple(out)

def max_version_tuple(strings: List[str]) -> Tuple[int, ...]:
    best: Tuple[int, ...] = tuple()
    for s in strings or []:
        vt = parse_version_tuple(str(s))
        if vt > best: best = vt
    return best

def _to_bool_or_none(x) -> Optional[bool]:
    if isinstance(x, bool): return x
    if isinstance(x, (int, float)): return bool(int(x))
    if isinstance(x, str):
        s = x.strip().lower()
        if s in {"true","1","yes"}: return True
        if s in {"false","0","no"}: return False
    return None

def _max_int_or_none(vals: List[str]) -> Optional[int]:
    best = None
    for v in vals or []:
        try:
            i = int(str(v).strip())
            best = i if best is None else max(best, i)
        except:
            continue
    return best

# -----------------------------
# Study-defined fields (What to diff)
# -----------------------------
COVERAGE_FIELDS = ["api_level","image_source","abi","device_profile","device_identifier"]
RUNTIME_FIELDS  = ["start_mode","gpu_mode","headless_flags","boot_wait"]
HOST_FIELDS     = ["host_os","hypervisor"]
MEDIUM_FIELDS   = ["image_flavor","orchestrator_enabled","num_shards","locale","timezone","network_profile"]
TOOLCHAIN_FIELDS = ["agp_version","jdk_version"]
ALL_FIELDS_ORDER = COVERAGE_FIELDS + RUNTIME_FIELDS + HOST_FIELDS + MEDIUM_FIELDS + TOOLCHAIN_FIELDS

# -----------------------------
# Primary label mapping (WHAT) → Category
# -----------------------------
CAT_COVERAGE = "Coverage"
CAT_RUNTIME  = "Runtime"
CAT_CONTEXT  = "Context"
CAT_INVOC    = "Invocation"   # retained for mapping completeness

FIELD_TO_PRIMARY = {
    # Coverage
    "api_level":          "api_bump",
    "image_source":       "system_image_change",
    "abi":                "abi_change",
    "device_profile":     "device_profile_change",
    "device_identifier":  "device_profile_change",

    # Runtime
    "start_mode":         "wait_strategy_change",
    "gpu_mode":           "timeout_tuning",
    "headless_flags":     "timeout_tuning",
    "boot_wait":          "wait_strategy_change",

    # Host / Context
    "host_os":            "runner_os_change",
    "hypervisor":         "runner_os_change",

    # Medium (context)
    "image_flavor":           "runner_os_change",
    "orchestrator_enabled":   "runner_os_change",
    "num_shards":             "runner_os_change",
    "locale":                 "runner_os_change",
    "timezone":               "runner_os_change",
    "network_profile":        "runner_os_change",

    # Toolchain
    "agp_version":        "agp_bump",
    "jdk_version":        "jdk_bump",
}

PRIMARY_TO_CATEGORY = {
    "api_bump":              CAT_COVERAGE,
    "system_image_change":   CAT_COVERAGE,
    "abi_change":            CAT_COVERAGE,
    "device_profile_change": CAT_COVERAGE,

    "wait_strategy_change":  CAT_RUNTIME,
    "timeout_tuning":        CAT_RUNTIME,

    "runner_os_change":      CAT_CONTEXT,

    "agp_bump":              CAT_CONTEXT,
    "jdk_bump":              CAT_CONTEXT,

    "other_change":          CAT_CONTEXT,
}

CATEGORY_NAME = {
    CAT_COVERAGE: "Coverage",
    CAT_RUNTIME:  "Runtime",
    CAT_CONTEXT:  "Context",
    CAT_INVOC:    "Invocation",
}

# -----------------------------
# Emulator style helpers (episode-level)
# -----------------------------
def _norm_style(s: Optional[str]) -> Optional[str]:
    if not s: return None
    t = str(s).strip().lower()
    if t in {"generic", "diy", "gmd"}:
        return t
    return None

def _style_from_dps(dps: list[dict]) -> Optional[str]:
    """Collapse per-dp emulator_type -> one snapshot style. If multiple different styles, return 'mixed'."""
    seen = { _norm_style(dp.get("emulator_type")) for dp in (dps or []) }
    seen.discard(None)
    if not seen: return None
    if len(seen) == 1: return next(iter(seen))
    return "mixed"

# -----------------------------
# Aggregate snapshot → set-of-values per field
# -----------------------------
def aggregate_snapshot(feats: dict) -> Dict[str, set]:
    agg: Dict[str, set] = {k: set() for k in ALL_FIELDS_ORDER}
    dps = (feats or {}).get("detected_params") or []

    for dp in dps:
        for f in COVERAGE_FIELDS + RUNTIME_FIELDS + HOST_FIELDS:
            v = dp.get(f)
            if v is None:
                continue
            if f == "headless_flags" and isinstance(v, dict):
                token = f"nw{int(bool(v.get('no_window')))}_na{int(bool(v.get('no_audio')))}_nba{int(bool(v.get('no_boot_anim')))}"
                agg["headless_flags"].add(token)
            else:
                agg[f].add(str(v) if not isinstance(v, (bool, int)) else str(v))

    # medium/toolchain
    med = (feats or {}).get("medium_params") or {}
    for f in MEDIUM_FIELDS:
        if med.get(f) is not None:
            vv = med.get(f)
            agg[f].add(str(vv) if not isinstance(vv, (bool,int)) else str(vv))

    tool = (feats or {}).get("toolchain_params") or {}
    for f in TOOLCHAIN_FIELDS:
        if tool.get(f) is not None:
            agg[f].add(str(tool.get(f)))

    return agg

def _labels(feats: dict) -> dict:
    return (feats or {}).get("labels", {}) or {}

def _gmd_present(feats: dict) -> Optional[bool]:
    """Prefer explicit Step-1 bit if available; else None."""
    lbl = _labels(feats)
    if "gmd_present" in lbl:
        return _to_bool_or_none(lbl.get("gmd_present"))
    return None

def _orch_present_boolset(agg_map: Dict[str,set]) -> Optional[bool]:
    """Collapse orchestrator_enabled set into a single boolean if unambiguous."""
    vals = list(agg_map.get("orchestrator_enabled", set()))
    norm = [_to_bool_or_none(v) for v in vals]
    norm = [v for v in norm if v is not None]
    if not norm:
        return None
    return norm[0] if len(set(norm)) == 1 else None

# -----------------------------
# Diff engine → per-field CCEs (with proper change_type)
# -----------------------------
def diff_features(old_feats: Dict[str, Any], new_feats: Dict[str, Any]) -> Tuple[List[Dict[str, Any]], dict]:
    """
    Return (list_of_field_deltas, episode_aux)
    episode_aux holds episode-level evidence: GMD/Orchestrator presence and Emulator Style Old/New
    """
    oldm = aggregate_snapshot(old_feats or {})
    newm = aggregate_snapshot(new_feats or {})

    out: List[Dict[str, Any]] = []

    def handle_field(field: str):
        a = oldm.get(field, set())
        b = newm.get(field, set())
        if a == b:
            return

        added   = sorted(b - a)
        removed = sorted(a - b)

        # Proper change_type
        if not a and b:
            change_type = "added"
        elif a and not b:
            change_type = "removed"
        else:
            change_type = "modified"

        row = {
            "field": field,
            "old_value": stringify(sorted(a)),
            "new_value": stringify(sorted(b)),
            "change_type": change_type,
        }
        if added:   row["added_items"] = stringify(added)
        if removed: row["removed_items"] = stringify(removed)

        # Magnitude for api_level
        if field == "api_level" and a and b:
            try:
                row["magnitude"] = max(int(x) for x in b) - max(int(x) for x in a)
            except:
                pass

        # Coverage net counts
        if field in COVERAGE_FIELDS:
            try:
                old_list = _safe_json_loads(row["old_value"]) or []
                new_list = _safe_json_loads(row["new_value"]) or []
                added_list = _safe_json_loads(row.get("added_items","")) or []
                removed_list = _safe_json_loads(row.get("removed_items","")) or []
                row["Coverage_Added_Count"] = len(added_list)
                row["Coverage_Removed_Count"] = len(removed_list)
                row["Coverage_Net"] = len(new_list) - len(old_list)
            except:
                row["Coverage_Added_Count"] = row["Coverage_Removed_Count"] = row["Coverage_Net"] = None

        # Runtime wait tuning
        if field == "boot_wait":
            try:
                old_list = _safe_json_loads(row["old_value"]) or []
                new_list = _safe_json_loads(row["new_value"]) or []
                old_max = _max_int_or_none(old_list)
                new_max = _max_int_or_none(new_list)
                if old_max is not None and new_max is not None:
                    delta = new_max - old_max
                    row["Runtime_Wait_Delta"] = delta
                    row["Runtime_Wait_Change"] = "increase" if delta > 0 else ("decrease" if delta < 0 else "")
                else:
                    row["Runtime_Wait_Delta"] = None
                    row["Runtime_Wait_Change"] = ""
            except:
                row["Runtime_Wait_Delta"] = None
                row["Runtime_Wait_Change"] = ""

        out.append(row)

    for f in ALL_FIELDS_ORDER:
        handle_field(f)

    # Episode-level AUX: GMD presence & Orchestrator enabled
    gmd_old = _gmd_present(old_feats)
    gmd_new = _gmd_present(new_feats)
    orch_old = _orch_present_boolset(oldm)
    orch_new = _orch_present_boolset(newm)

    # Episode-level emulator style from detections
    style_old = _style_from_dps((old_feats or {}).get("detected_params") or [])
    style_new = _style_from_dps((new_feats or {}).get("detected_params") or [])

    episode_aux = {
        "GMD_Present_Old": gmd_old,
        "GMD_Present_New": gmd_new,
        "Orchestrator_Enabled_Old": orch_old,
        "Orchestrator_Enabled_New": orch_new,
        "Emulator_Style_Old": style_old,   # 'generic' | 'diy' | 'gmd' | 'mixed' | None
        "Emulator_Style_New": style_new,
    }
    return out, episode_aux

# -----------------------------
# Delta → intents (meaningful knobs only)
# -----------------------------
DELTA_MEANINGFUL_FIELDS = set(COVERAGE_FIELDS) | {"agp_version","jdk_version"}

def derive_delta_intents(deltas: List[Dict[str, Any]]) -> List[str]:
    labs: set[str] = set()
    for d in deltas:
        field = d.get("field")
        if field not in DELTA_MEANINGFUL_FIELDS:
            continue
        added = _safe_json_loads(d.get("added_items") or "") or []
        removed = _safe_json_loads(d.get("removed_items") or "") or []

        if field in COVERAGE_FIELDS:
            old_list = _safe_json_loads(d.get("old_value") or "") or []
            new_list = _safe_json_loads(d.get("new_value") or "") or []
            if old_list and new_list:
                if added:   labs.add("expand_coverage")
                if removed: labs.add("reduce_coverage")

        if field in {"agp_version","jdk_version"}:
            old_list = _safe_json_loads(d.get("old_value") or "") or []
            new_list = _safe_json_loads(d.get("new_value") or "") or []
            old_max = max_version_tuple(old_list)
            new_max = max_version_tuple(new_list)
            if new_max > old_max:
                labs.add("version_change")

    return sorted(labs)

# -----------------------------
# Path detectors (generic + field-aware)
# -----------------------------
CI_VENDOR_PATTERNS = [
    (re.compile(r'(?i)(?:^|/)\.travis\.ya?ml$'),               'Travis_CI'),
    (re.compile(r'(?i)(?:^|/)\.appveyor\.ya?ml$'),             'AppVeyor'),
    (re.compile(r'(?i)(?:^|/)/?appveyor\.ya?ml$'),             'AppVeyor'),
    (re.compile(r'(?i)(?:^|/)/?circle\.yml$'),                 'Circle_CI'),
    (re.compile(r'(?i)(?:^|/)\.circleci/config\.ya?ml$'),      'Circle_CI'),
    (re.compile(r'(?i)(?:^|/)/?azure-pipelines\.ya?ml$'),      'Azure_Pipelines'),
    (re.compile(r'(?i)(?:^|/)\.github/workflows/.*\.(yml|yaml)$'), 'GitHub_Actions'),
    (re.compile(r'(?i)(?:^|/)/?bitbucket-pipelines\.ya?ml$'),  'Bitbucket'),
    (re.compile(r'(?i)(?:^|/)\.gitlab-ci\.ya?ml$'),            'GitLab'),
    (re.compile(r'(?i)(?:^|/)/?Jenkinsfile(?:\.ya?ml)?$'),     'Jenkins'),
    (re.compile(r'(?i)(?:^|/)/?bitrise\.ya?ml$'),              'Bitrise'),
    (re.compile(r'(?i)(?:^|/)/?bamboo\.ya?ml$'),               'Bamboo'),
    (re.compile(r'(?i)(?:^|/)/?codeship-services\.ya?ml$'),    'Codeship'),
    (re.compile(r'(?i)(?:^|/)\.gocd\.ya?ml$'),                 'GoCD'),
    (re.compile(r'(?i)(?:^|/)/?wercker\.ya?ml$'),              'Wercker'),
    (re.compile(r'(?i)(?:^|/)\.semaphore\.ya?ml$'),            'Semaphore'),
    (re.compile(r'(?i)(?:^|/)/?codemagic\.ya?ml$'),            'Nevercode'),
]
GENERIC_CI_DIRS   = re.compile(r'(?i)(?:^|/)(?:ci|\.ci)(?:/|$)')
_GRADLE_PATH_RX   = re.compile(r"(?i)(?:^|/)(?:build|settings)\.gradle(?:\.kts)?$|(?:^|/)gradle\.properties$|(?:^|/)gradle/wrapper/gradle-wrapper\.properties$")
_SCRIPT_PATH_RX   = re.compile(r"(?i)\.(?:sh|py|bat|ps1)$|(?:^|/)(?:scripts?|tools?)(?:/|$)")

def detect_intent_path_generic(path: str) -> List[str]:
    intents: List[str] = []
    p = path or ""
    if any(rx.search(p) for rx, _ in CI_VENDOR_PATTERNS) or GENERIC_CI_DIRS.search(p):
        intents.append("ci_env_workflow")
    if _GRADLE_PATH_RX.search(p):
        intents.append("version_change")
    if _SCRIPT_PATH_RX.search(p):
        intents.append("ci_env_workflow")
    return sorted(set(intents))

def detect_intent_path_field_aware(path: str, field: str) -> Tuple[List[str], Optional[str]]:
    p = path or ""; f = (field or "").lower()
    intents: List[str] = []; reasons: List[str] = []
    vendor = None
    for rx, name in CI_VENDOR_PATTERNS:
        if rx.search(p):
            vendor = name; break
    if vendor is None and GENERIC_CI_DIRS.search(p):
        vendor = "Generic_CI"

    is_gradle = bool(_GRADLE_PATH_RX.search(p))

    if vendor and f in set(COVERAGE_FIELDS):
        intents += ["coverage", "ci_env_workflow"]; reasons.append(f"ci vendor={vendor} + coverage field")
    if is_gradle and f in {"agp_version","jdk_version"}:
        intents.append("version_change"); reasons.append("gradle/build tool path")

    intents = sorted(set(intents))
    return intents, ("; ".join(reasons) if reasons else None)

# -----------------------------
# Subject intents (simple keywords)
# -----------------------------
def detect_subject_intents(subject: str) -> Tuple[List[str], Optional[str]]:
    s = (subject or "").lower()
    hits = set()
    if any(w in s for w in ["flake","flaky","retry","retries","timeout","timeouts","stabil","crash","fix"]):
        hits.add("flake_mitigation")
    if any(w in s for w in ["speed up","faster","reduce time","time to green","parallel","shard","concurr"]) and \
       any(c in s for c in [" ci","build","pipeline","workflow","runner","gha","github actions","gitlab","jenkins","circleci","azure pipelines","bitrise"]):
        hits.add("speed_up_ci")
    if any(w in s for w in ["gradle","agp","jdk","java","version","wrapper","target api"]):
        hits.add("version_change")
    if any(w in s for w in ["migrate","switch","replace","port","github actions","gha","gitlab","jenkins","circleci","azure pipelines","bitrise","workflow","pipeline"]):
        hits.add("ci_env_workflow")
    hits = sorted(hits)
    reason = hits[0] if hits else None
    return hits, reason

# -----------------------------
# 7-subintent + 4-headline mapping
# -----------------------------
RAW_TO_SUBINTENT = {
    "expand_coverage":"coverage", "reduce_coverage":"coverage", "coverage":"coverage",
    "flake_mitigation":"flake_mitigation", "speed_up_ci":"speed_up_ci",
    "version_change":"version_change",
    "ci_env_workflow":"ci_platform_infra",
}
SUB_TO_HEADLINE = {
    "coverage":"coverage",
    "flake_mitigation":"runtime",
    "speed_up_ci":"runtime",
    "version_change":"version_change",
    "ci_platform_infra":"ci_platform_infra",
}
SUB_PRIORITY = ["coverage","flake_mitigation","speed_up_ci","version_change","ci_platform_infra"]

def to_subbuckets(raws: List[str]) -> List[str]:
    out = []
    for r in raws or []:
        b = RAW_TO_SUBINTENT.get(r)
        if b and b not in out:
            out.append(b)
    return out

def pick_by_priority(cands: List[str]) -> str:
    for b in SUB_PRIORITY:
        if b in cands:
            return b
    return ""

# -----------------------------
# Style intent (optional): map style transitions to raw intents
# -----------------------------
def style_to_intent(style_old: Optional[str], style_new: Optional[str]) -> List[str]:
    out = []
    if not style_old or not style_new or style_old == style_new:
        return out
    if style_new == "gmd":
        out.append("adopt_gmd")
    elif style_new == "diy":
        out.append("adopt_diy")
    else:
        out.append("genericize_emulator")
    return out

# -----------------------------
# Change-op utils (robust)
# -----------------------------
def classify_change_op(old_value: str, new_value: str, change_type: str) -> str:
    ct = (change_type or "").lower()
    if ct == "added":   return "add"
    if ct == "removed": return "remove"

    # Fallback: infer from payloads if possible
    try:
        o = json.loads(old_value) if old_value else []
    except: o = []
    try:
        n = json.loads(new_value) if new_value else []
    except: n = []

    if (not o) and n:
        return "add"
    if o and (not n):
        return "remove"
    return "value_edit" if (old_value or "") != (new_value or "") else "no_change"

# -----------------------------
# Step-1 labels (no feature_scope; we only consume path-kind overlaps)
# -----------------------------
def _get_labels(feats: dict) -> dict:
    return (feats or {}).get("labels", {}) or {}

def compute_field_group(primary_category: str) -> str:
    if primary_category in {CAT_COVERAGE, CAT_RUNTIME}:
        return "emulator_related"
    return "context_only"

def spot_tag_for_filekind(file_kind: str) -> Optional[str]:
    if file_kind == "ci_yaml": return "yaml_unscoped"
    if file_kind == "gradle":  return "gradle_global"
    return None

# -----------------------------
# Main
# -----------------------------
if __name__ == "__main__":
    print(f"[info] snapshots dir: {SNAPSHOT_DIR}")
    print(f"[info] output dir   : {OUT_DIR}")

    by_repo = read_snapshots(SNAPSHOT_DIR)
    print(f"[info] Loaded snapshots for {len(by_repo)} repos")

    for repo, rows in by_repo.items():
        out_rows: List[dict] = []
        by_path: Dict[str, List[dict]] = {}
        for r in rows:
            by_path.setdefault(r.get("path",""), []).append(r)

        repeat_counter: Dict[Tuple[str,str], int] = {}

        for path, snaps in by_path.items():
            prev: Optional[dict] = None
            for cur in snaps:
                # --- NO BASELINE EMISSION ---
                if prev is None:
                    prev = cur
                    continue

                old_feats = prev.get("features", {}) or {}
                new_feats = cur.get("features", {}) or {}

                deltas, episode_aux = diff_features(old_feats, new_feats)
                if deltas:
                    # Episode delta intents
                    intent_delta_episode = derive_delta_intents(deltas)

                    subject_str = cur.get("subject","")
                    ts_epoch_utc = ensure_utc_epoch(cur.get("timestamp", 0))
                    ts_iso_utc   = epoch_to_iso_utc(ts_epoch_utc)

                    # Step-1 labels (path/file context only)
                    new_labels = _get_labels(new_feats)
                    file_kind = new_labels.get("file_kind", "")
                    ci_emu_change = new_labels.get("ci_emulator_step_change", None)
                    gmd_block_change = new_labels.get("gradle_gmd_block_change", None)

                    # Episode-level: style & GMD/Orchestrator direction
                    style_old = episode_aux.get("Emulator_Style_Old")
                    style_new = episode_aux.get("Emulator_Style_New")
                    style_change = f"{style_old.upper()}→{style_new.upper()}" if (style_old and style_new and style_old != style_new) else ""

                    gmd_old = episode_aux.get("GMD_Present_Old")
                    gmd_new = episode_aux.get("GMD_Present_New")
                    if gmd_old is True and gmd_new is False:
                        gmd_dir = "GMD→DIY"
                    elif gmd_old is False and gmd_new is True:
                        gmd_dir = "DIY→GMD"
                    else:
                        gmd_dir = ""

                    orch_old = episode_aux.get("Orchestrator_Enabled_Old")
                    orch_new = episode_aux.get("Orchestrator_Enabled_New")
                    if orch_old is True and orch_new is False:
                        orch_change = "disable"
                    elif orch_old is False and orch_new is True:
                        orch_change = "enable"
                    else:
                        orch_change = ""

                    # Intent helpers (for reason text only)
                    helper_tags = []
                    got_helpers = False
                    for dp in (new_feats.get("detected_params") or []):
                        if dp.get("context_anchor"): helper_tags.append(f"ctx={dp['context_anchor']}")
                        if dp.get("test_command"):   helper_tags.append("has_test_cmd")
                        if dp.get("runner_args"):    helper_tags.append("has_runner_args")
                        got_helpers = True
                        break
                    intent_helper_note = ";".join(helper_tags) if got_helpers else None

                    for d in deltas:
                        field = d["field"]
                        key = (path, field)
                        repeat_counter[key] = repeat_counter.get(key, 0) + 1
                        repeat_index = repeat_counter[key]
                        repeat_label = "first" if repeat_index == 1 else "repeat"

                        # WHAT + category
                        primary_label = FIELD_TO_PRIMARY.get(field, "other_change")
                        primary_category = CATEGORY_NAME.get(
                            PRIMARY_TO_CATEGORY.get(primary_label, CAT_CONTEXT),
                            PRIMARY_TO_CATEGORY.get(primary_label, CAT_CONTEXT)
                        )

                        # Per-source intents
                        intents_delta_list = derive_delta_intents([d]) if field in DELTA_MEANINGFUL_FIELDS else []
                        intents_path = detect_intent_path_generic(path)
                        intents_pfa_list, intent_pfa_reason = detect_intent_path_field_aware(path, field)
                        intents_subject, subj_reason = detect_subject_intents(subject_str)
                        style_intents = style_to_intent(style_old, style_new)

                        # Attach helper note to path reason (no schema change)
                        if intent_helper_note:
                            intent_pfa_reason = f"{intent_pfa_reason} | {intent_helper_note}" if intent_pfa_reason else intent_helper_note

                        # Arbitration
                        source_to_pool = [
                            ("Delta",   intents_delta_list,  "delta-derived"),
                            ("Style",   style_intents,       "emulator style transition"),
                            ("PathFA",  intents_pfa_list,    intent_pfa_reason or "path field-aware"),
                            ("Subject", intents_subject,     subj_reason or "subject regex"),
                            ("Path",    intents_path,        "path generic"),
                        ]
                        chosen_source = ""; chosen_raws: List[str] = []; chosen_reason = ""
                        for s, pool, why in source_to_pool:
                            if pool:
                                chosen_source, chosen_raws, chosen_reason = s, sorted(set(pool)), why
                                break

                        secondary_label = ",".join(chosen_raws) if chosen_raws else ""
                        sub_cands = to_subbuckets(chosen_raws)
                        driver = pick_by_priority(sub_cands) if sub_cands else ""
                        headline = SUB_TO_HEADLINE.get(driver, "") if driver else ""

                        change_op = classify_change_op(d.get("old_value",""), d.get("new_value",""), d.get("change_type","modified"))
                        field_group = compute_field_group(primary_category)
                        spot_tag = spot_tag_for_filekind(file_kind)
                        include_emu_study = (field_group == "emulator_related")

                        # --- Output row
                        row = {
                            # Metadata
                            "repo": repo,
                            "sha": cur.get("sha"),
                            "prev_sha": prev.get("sha"),
                            "timestamp_epoch_utc": ts_epoch_utc,
                            "timestamp_utc": ts_iso_utc,
                            "path": path,
                            "subject": subject_str,

                            # Primary (WHAT)
                            "Field": field,
                            "Primary_Label": primary_label,
                            "Primary_Label_Category": primary_category,

                            # Diff details
                            "old_value": d.get("old_value",""),
                            "new_value": d.get("new_value",""),
                            "change_type": d.get("change_type","modified"),
                            "change_op": change_op,
                            "magnitude": d.get("magnitude", None),
                            "added_items": d.get("added_items",""),
                            "removed_items": d.get("removed_items",""),
                            "repeat_index": repeat_index,
                            "repeat_label": repeat_label,

                            # Per-source intents
                            "intent_delta": ",".join(sorted(set(intents_delta_list))),
                            "intent_pfa": ",".join(sorted(set(intents_pfa_list))),
                            "intent_subject": ",".join(sorted(set(intents_subject))),
                            "intent_path": ",".join(sorted(set(intents_path))),
                            "intent_delta_episode": ",".join(sorted(set(intent_delta_episode))) if intent_delta_episode else "",

                            # Secondary (chosen raw intents)
                            "Secondary_Label": secondary_label,

                            # Why (sub-bucket/headline)
                            "Driver": driver,
                            "intent_headline": headline,
                            "Driver_Source": chosen_source or "",
                            "Driver_reason": chosen_reason or "",

                            # Aux (schema-compat + reasons)
                            "Aux_Tags": "",
                            "Intent_Path": "; ".join(intents_pfa_list) if intents_pfa_list else None,
                            "Intent_Path_Reason": intent_pfa_reason,
                            "Intent_Subject_Reason": subj_reason,

                            # Legacy compat
                            "Driver_Label_Selected": driver,

                            # Step-1 carryover
                            "File_Kind": file_kind,                          # ci_yaml|gradle|script|other
                            "CI_Emulator_Step_Change": ci_emu_change,        # True/False/None
                            "Gradle_GMD_Block_Change": gmd_block_change,     # True/False/None
                            "Context_Scope_Keys": "",                        # none in new miner
                            "Is_Emulator_Relevant_File": bool(ci_emu_change or gmd_block_change),

                            # Grouping
                            "Field_Group": field_group,                       # emulator_related|context_only
                            "Spot_Tag": spot_tag,
                            "Include_Emulator_Study": bool(include_emu_study),
                        }

                        # --- AUX: style & GMD/Orchestrator on every row
                        row["Emulator_Style_Old"] = style_old or ""
                        row["Emulator_Style_New"] = style_new or ""
                        row["Emulator_Style_Change"] = style_change

                        row["GMD_Present_Old"] = gmd_old
                        row["GMD_Present_New"] = gmd_new
                        row["GMD_Direction"]   = gmd_dir

                        row["Orchestrator_Enabled_Old"] = orch_old
                        row["Orchestrator_Enabled_New"] = orch_new
                        row["Orchestrator_Change"]      = orch_change

                        # (Per-delta extras if present): Coverage_Added_Count, Coverage_Removed_Count, Coverage_Net
                        # Runtime_Wait_Delta, Runtime_Wait_Change

                        out_rows.append(row)

                prev = cur  # advance window

        if not out_rows:
            print(f"[skip] {repo}: no field-level deltas found")
            continue

        dst = OUT_DIR / f"{repo}.jsonl"
        with dst.open("w", encoding="utf-8") as f:
            for r in out_rows:
                f.write(json.dumps(r, ensure_ascii=False) + "\n")
        print(f"[ok] {repo}: {len(out_rows)} enriched rows -> {dst}")

    print("Done.")
# Out:
# [info] snapshots dir: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\snapshots
# [info] output dir   : C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1
# [info] Loaded snapshots for 282 repos
# [ok] 4eRTuk__audioview: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\4eRTuk__audioview.jsonl
# [ok] a-mabe__OpenHIIT: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\a-mabe__OpenHIIT.jsonl
# [ok] a914-gowtham__compose-ratingbar: 16 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\a914-gowtham__compose-ratingbar.jsonl
# [ok] AAkira__ExpandableLayout: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AAkira__ExpandableLayout.jsonl
# [ok] abdelaziz-mahdy__pytorch_lite: 17 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\abdelaziz-mahdy__pytorch_lite.jsonl
# [ok] ably__ably-flutter: 45 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ably__ably-flutter.jsonl
# [ok] AChep__AcDisplay: 28 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AChep__AcDisplay.jsonl
# [ok] ActivityWatch__aw-android: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ActivityWatch__aw-android.jsonl
# [ok] AdevintaSpain__Barista: 46 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AdevintaSpain__Barista.jsonl
# [ok] admob-plus__admob-plus: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\admob-plus__admob-plus.jsonl
# [ok] adorsys__secure-storage-android: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\adorsys__secure-storage-android.jsonl
# [ok] airbnb__paris: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\airbnb__paris.jsonl
# [ok] Albert221__FastShopping: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Albert221__FastShopping.jsonl
# [ok] alexbakker__webdav-provider: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\alexbakker__webdav-provider.jsonl
# [ok] alexstyl__contactstore: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\alexstyl__contactstore.jsonl
# [ok] am15h__tflite_flutter_helper: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\am15h__tflite_flutter_helper.jsonl
# [ok] amahi__android: 20 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\amahi__android.jsonl
# [ok] amitshekhariitbhu__Fast-Android-Networking: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\amitshekhariitbhu__Fast-Android-Networking.jsonl
# [ok] AndBible__and-bible: 117 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AndBible__and-bible.jsonl
# [ok] AndProx__AndProx: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AndProx__AndProx.jsonl
# [ok] andremion__Villains-and-Heroes: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\andremion__Villains-and-Heroes.jsonl
# [ok] andreynovikov__trekarta: 54 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\andreynovikov__trekarta.jsonl
# [ok] android__codelab-android-compose: 519 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\android__codelab-android-compose.jsonl
# [ok] android__nowinandroid: 165 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\android__nowinandroid.jsonl
# [ok] andstatus__andstatus: 69 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\andstatus__andstatus.jsonl
# [ok] anilbeesetti__nextplayer: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\anilbeesetti__nextplayer.jsonl
# [ok] anjlab__android-inapp-billing-v3: 27 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\anjlab__android-inapp-billing-v3.jsonl
# [ok] ankidroid__Anki-Android: 101 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ankidroid__Anki-Android.jsonl
# [ok] AntennaPod__AntennaPod: 62 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\AntennaPod__AntennaPod.jsonl
# [skip] Arian04__android-hid-client: no field-level deltas found
# [ok] aws__amazon-ivs-react-native-player: 23 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\aws__amazon-ivs-react-native-player.jsonl
# [ok] Bdaya-Dev__oidc: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Bdaya-Dev__oidc.jsonl
# [ok] beemdevelopment__Aegis: 50 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\beemdevelopment__Aegis.jsonl
# [ok] bilibili__boxing: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\bilibili__boxing.jsonl
# [ok] bitfireAT__icsx5: 52 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\bitfireAT__icsx5.jsonl
# [ok] BlueWallet__BlueWallet: 48 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\BlueWallet__BlueWallet.jsonl
# [ok] brandonp2412__FitBook: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\brandonp2412__FitBook.jsonl
# [ok] brarcher__video-transcoder: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\brarcher__video-transcoder.jsonl
# [ok] briar__briar: 40 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\briar__briar.jsonl
# [ok] burnoo__cokoin: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\burnoo__cokoin.jsonl
# [ok] CarlosMChica__easyrecycleradapters: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\CarlosMChica__easyrecycleradapters.jsonl
# [ok] cashapp__paraphrase: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\cashapp__paraphrase.jsonl
# [ok] CatimaLoyalty__Android: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\CatimaLoyalty__Android.jsonl
# [ok] cgeo__cgeo: 81 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\cgeo__cgeo.jsonl
# [ok] chenxiaolong__RSAF: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\chenxiaolong__RSAF.jsonl
# [ok] cliqz-oss__browser-android: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\cliqz-oss__browser-android.jsonl
# [ok] cloudinary__cloudinary_android: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\cloudinary__cloudinary_android.jsonl
# [ok] coil-kt__coil: 44 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\coil-kt__coil.jsonl
# [ok] commons-app__apps-android-commons: 61 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\commons-app__apps-android-commons.jsonl
# [ok] concretesolutions__canarinho: 25 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\concretesolutions__canarinho.jsonl
# [ok] connectbot__connectbot: 40 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\connectbot__connectbot.jsonl
# [ok] Crazy-Marvin__MetadataRemover: 23 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Crazy-Marvin__MetadataRemover.jsonl
# [ok] dart-lang__http: 29 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dart-lang__http.jsonl
# [ok] dart-lang__native: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dart-lang__native.jsonl
# [ok] dbrodie__AdBuster: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dbrodie__AdBuster.jsonl
# [ok] DesarrolloAntonio__Shiori-Android-Client: 43 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\DesarrolloAntonio__Shiori-Android-Client.jsonl
# [ok] dgngulcan__droid-feed: 33 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dgngulcan__droid-feed.jsonl
# [ok] dlew__joda-time-android: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dlew__joda-time-android.jsonl
# [ok] dmfs__opentasks: 14 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\dmfs__opentasks.jsonl
# [ok] doublesymmetry__KotlinAudio: 27 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\doublesymmetry__KotlinAudio.jsonl
# [ok] droidconKE__droidconKeKotlin: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\droidconKE__droidconKeKotlin.jsonl
# [ok] DroidKaigi__conference-app-2020: 31 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\DroidKaigi__conference-app-2020.jsonl
# [skip] elftausend__custos: no field-level deltas found
# [ok] EnsembleUI__ensemble: 16 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\EnsembleUI__ensemble.jsonl
# [ok] ErickSumargo__Dads: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ErickSumargo__Dads.jsonl
# [ok] erkkah__naett: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\erkkah__naett.jsonl
# [ok] EvanRespaut__Equate: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\EvanRespaut__Equate.jsonl
# [ok] EventFahrplan__EventFahrplan: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\EventFahrplan__EventFahrplan.jsonl
# [ok] evilcorpltd__aTox: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\evilcorpltd__aTox.jsonl
# [ok] f-arslan__GptMap: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\f-arslan__GptMap.jsonl
# [ok] f-droid__fdroidclient: 39 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\f-droid__fdroidclient.jsonl
# [ok] FabianTerhorst__Iron: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\FabianTerhorst__Iron.jsonl
# [ok] Faltenreich__Diaguard: 77 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Faltenreich__Diaguard.jsonl
# [ok] federicoiosue__Omni-Notes: 84 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\federicoiosue__Omni-Notes.jsonl
# [ok] fewlaps__flone-android: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\fewlaps__flone-android.jsonl
# [ok] firebase__FirebaseUI-Flutter: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\firebase__FirebaseUI-Flutter.jsonl
# [ok] Five-Prayers__five-prayers-android: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Five-Prayers__five-prayers-android.jsonl
# [ok] flauschtrud__broccoli: 46 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\flauschtrud__broccoli.jsonl
# [ok] flet-dev__serious-python: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\flet-dev__serious-python.jsonl
# [ok] fluttercommunity__flutter_workmanager: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\fluttercommunity__flutter_workmanager.jsonl
# [ok] fornewid__naver-map-compose: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\fornewid__naver-map-compose.jsonl
# [ok] fossasia__loklak_wok_android: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\fossasia__loklak_wok_android.jsonl
# [ok] fossasia__phimpme-android: 30 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\fossasia__phimpme-android.jsonl
# [ok] freeotp__freeotp-android: 22 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\freeotp__freeotp-android.jsonl
# [ok] gemwalletcom__gem-android: 20 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\gemwalletcom__gem-android.jsonl
# [ok] getsentry__sentry-react-native: 42 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\getsentry__sentry-react-native.jsonl
# [ok] gotev__android-speech: 13 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\gotev__android-speech.jsonl
# [ok] grandstaish__paperparcel: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\grandstaish__paperparcel.jsonl
# [ok] greenaddress__abcore: 37 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\greenaddress__abcore.jsonl
# [ok] grote__Transportr: 55 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\grote__Transportr.jsonl
# [ok] guardianproject__proofmode-android: 30 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\guardianproject__proofmode-android.jsonl
# [ok] H-PixelDroid__PixelDroid: 53 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\H-PixelDroid__PixelDroid.jsonl
# [ok] haiyangwu__mediasoup-client-android: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\haiyangwu__mediasoup-client-android.jsonl
# [ok] hannesa2__panoramaGL: 55 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\hannesa2__panoramaGL.jsonl
# [ok] haqq-network__haqq-wallet: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\haqq-network__haqq-wallet.jsonl
# [ok] haroldadmin__MoonShot: 20 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\haroldadmin__MoonShot.jsonl
# [ok] hitherejoe__minimise: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\hitherejoe__minimise.jsonl
# [ok] Hny0305Lin__NLChat: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Hny0305Lin__NLChat.jsonl
# [ok] hoc081098__ViewBindingDelegate: 32 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\hoc081098__ViewBindingDelegate.jsonl
# [ok] ice-blockchain__mobile-app: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ice-blockchain__mobile-app.jsonl
# [ok] ImaginativeShohag__Why-Not-Compose: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ImaginativeShohag__Why-Not-Compose.jsonl
# [ok] inaturalist__iNaturalistAndroid: 16 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\inaturalist__iNaturalistAndroid.jsonl
# [ok] inaturalist__iNaturalistReactNative: 48 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\inaturalist__iNaturalistReactNative.jsonl
# [ok] invertase__notifee: 54 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\invertase__notifee.jsonl
# [ok] invertase__react-native-google-mobile-ads: 37 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\invertase__react-native-google-mobile-ads.jsonl
# [ok] ipfs-shipyard__gomobile-ipfs: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ipfs-shipyard__gomobile-ipfs.jsonl
# [ok] irgaly__kfswatch: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\irgaly__kfswatch.jsonl
# [ok] izderadicka__audioserve-android: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\izderadicka__audioserve-android.jsonl
# [ok] JackEblan__Geto: 17 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\JackEblan__Geto.jsonl
# [ok] JakeWharton__RxBinding: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\JakeWharton__RxBinding.jsonl
# [ok] JakeWharton__u2020: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\JakeWharton__u2020.jsonl
# [ok] jameshnsears__QuoteUnquote: 62 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jameshnsears__QuoteUnquote.jsonl
# [ok] jaredsburrows__android-gif-search: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jaredsburrows__android-gif-search.jsonl
# [ok] javiersantos__PiracyChecker: 11 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\javiersantos__PiracyChecker.jsonl
# [ok] jerson__flutter-openpgp: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jerson__flutter-openpgp.jsonl
# [ok] jerson__flutter-rsa: 13 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jerson__flutter-rsa.jsonl
# [ok] jianjunxiao__NiceVieoPlayer: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jianjunxiao__NiceVieoPlayer.jsonl
# [ok] JimmyDaddy__react-native-image-marker: 14 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\JimmyDaddy__react-native-image-marker.jsonl
# [ok] joreilly__PeopleInSpace: 87 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\joreilly__PeopleInSpace.jsonl
# [ok] joreilly__StarWars: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\joreilly__StarWars.jsonl
# [ok] juancastillo0__wasm_run: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\juancastillo0__wasm_run.jsonl
# [ok] jungilhan__awesome-blogs-android: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\jungilhan__awesome-blogs-android.jsonl
# [ok] kalaspuffar__secure-quick-reliable-login: 16 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\kalaspuffar__secure-quick-reliable-login.jsonl
# [ok] kamgurgul__cpu-info: 41 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\kamgurgul__cpu-info.jsonl
# [ok] KaustubhPatange__navigator: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\KaustubhPatange__navigator.jsonl
# [ok] kebernet__shortyz: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\kebernet__shortyz.jsonl
# [ok] krzdabrowski__android-starter-2022: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\krzdabrowski__android-starter-2022.jsonl
# [ok] ksoichiro__Android-ObservableScrollView: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ksoichiro__Android-ObservableScrollView.jsonl
# [ok] ksoichiro__AndroidFormEnhancer: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ksoichiro__AndroidFormEnhancer.jsonl
# [ok] ksoichiro__SimpleAlertDialog-for-Android: 13 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ksoichiro__SimpleAlertDialog-for-Android.jsonl
# [ok] kylecorry31__Trail-Sense: 56 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\kylecorry31__Trail-Sense.jsonl
# [ok] labexp__osmtracker-android: 31 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\labexp__osmtracker-android.jsonl
# [ok] lcdsmao__JetTheme: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\lcdsmao__JetTheme.jsonl
# [ok] leandroBorgesFerreira__LoadingButtonAndroid: 25 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\leandroBorgesFerreira__LoadingButtonAndroid.jsonl
# [ok] LedgerHQ__ledger-live: 202 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\LedgerHQ__ledger-live.jsonl
# [ok] letelete__sleep-cycle-alarm: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\letelete__sleep-cycle-alarm.jsonl
# [ok] ligi__PassAndroid: 79 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ligi__PassAndroid.jsonl
# [ok] ligi__SurvivalManual: 52 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ligi__SurvivalManual.jsonl
# [ok] LinkSheet__LinkSheet: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\LinkSheet__LinkSheet.jsonl
# [ok] LinX64__CoinCap: 26 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\LinX64__CoinCap.jsonl
# [ok] livefront__bridge: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\livefront__bridge.jsonl
# [ok] MackHartley__RoundedProgressBar: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\MackHartley__RoundedProgressBar.jsonl
# [ok] maksim-m__Popular-Movies-App: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\maksim-m__Popular-Movies-App.jsonl
# [ok] MarcinMoskala__PreferenceHolder: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\MarcinMoskala__PreferenceHolder.jsonl
# [ok] massivedisaster__ADAL: 14 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\massivedisaster__ADAL.jsonl
# [ok] massivemadness__Squircle-CE: 20 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\massivemadness__Squircle-CE.jsonl
# [ok] mathisdt__trackworktime: 63 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\mathisdt__trackworktime.jsonl
# [skip] maxkeppeler__sheets-compose-dialogs: no field-level deltas found
# [ok] maxpower47__PinDroid: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\maxpower47__PinDroid.jsonl
# [ok] medic__cht-gateway: 24 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\medic__cht-gateway.jsonl
# [ok] MetaMask__metamask-mobile: 147 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\MetaMask__metamask-mobile.jsonl
# [ok] michaeltroger__pdfwallet-android: 22 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\michaeltroger__pdfwallet-android.jsonl
# [ok] michelelacorte__AndroidAppShortcuts: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\michelelacorte__AndroidAppShortcuts.jsonl
# [ok] microservicer__flutter-pipelines: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\microservicer__flutter-pipelines.jsonl
# [ok] miguelhincapie__CustomBottomSheetBehavior: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\miguelhincapie__CustomBottomSheetBehavior.jsonl
# [ok] MikeOrtiz__TouchImageView: 75 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\MikeOrtiz__TouchImageView.jsonl
# [ok] MiSikora__laboratory: 22 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\MiSikora__laboratory.jsonl
# [ok] mjaakko__NeoStumbler: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\mjaakko__NeoStumbler.jsonl
# [ok] moezbhatti__qksms: 63 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\moezbhatti__qksms.jsonl
# [ok] mshdabiola__NotePad: 55 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\mshdabiola__NotePad.jsonl
# [ok] n8ebel__GitHubActionsAutomationSandbox: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\n8ebel__GitHubActionsAutomationSandbox.jsonl
# [ok] Nailik__rhasspy_mobile: 69 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Nailik__rhasspy_mobile.jsonl
# [ok] nanihadesuka__NovelDokusha: 33 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\nanihadesuka__NovelDokusha.jsonl
# [ok] natario1__GIFCompressor: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\natario1__GIFCompressor.jsonl
# [ok] natsuk4ze__gal: 121 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\natsuk4ze__gal.jsonl
# [ok] nextcloud__android: 209 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\nextcloud__android.jsonl
# [ok] nhirokinet__bluelineconsole: 17 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\nhirokinet__bluelineconsole.jsonl
# [ok] NiciDieNase__chaosflix: 33 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\NiciDieNase__chaosflix.jsonl
# [ok] nightscout__AndroidAPS: 136 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\nightscout__AndroidAPS.jsonl
# [ok] nschnettler__Compose-Scrobbler: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\nschnettler__Compose-Scrobbler.jsonl
# [ok] NUmeroAndDev__MaterialGallery-android: 87 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\NUmeroAndDev__MaterialGallery-android.jsonl
# [ok] OlauncherCF__OlauncherCF: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\OlauncherCF__OlauncherCF.jsonl
# [ok] OneBusAway__onebusaway-android: 54 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\OneBusAway__onebusaway-android.jsonl
# [ok] ooni__probe-android: 67 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ooni__probe-android.jsonl
# [ok] opendocument-app__OpenDocument.droid: 56 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\opendocument-app__OpenDocument.droid.jsonl
# [ok] openhab__openhab-android: 87 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\openhab__openhab-android.jsonl
# [ok] openintents__shoppinglist: 28 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\openintents__shoppinglist.jsonl
# [ok] openthread__ot-commissioner: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\openthread__ot-commissioner.jsonl
# [ok] OpenTracksApp__OpenTracks: 100 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\OpenTracksApp__OpenTracks.jsonl
# [ok] OpnTec__bodyapps-android: 2 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\OpnTec__bodyapps-android.jsonl
# [ok] orgzly-revived__orgzly-android-revived: 39 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\orgzly-revived__orgzly-android-revived.jsonl
# [ok] owntracks__android: 133 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\owntracks__android.jsonl
# [ok] oxygen-updater__oxygen-updater: 27 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\oxygen-updater__oxygen-updater.jsonl
# [ok] pachli__pachli-android: 49 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\pachli__pachli-android.jsonl
# [skip] passsy__spot: no field-level deltas found
# [ok] PatilShreyas__NotyKT: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\PatilShreyas__NotyKT.jsonl
# [ok] persian-calendar__persian-calendar: 127 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\persian-calendar__persian-calendar.jsonl
# [ok] PhoneVR-Developers__PhoneVR: 30 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\PhoneVR-Developers__PhoneVR.jsonl
# [ok] Picovoice__porcupine: 42 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Picovoice__porcupine.jsonl
# [ok] pilgr__Paper: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\pilgr__Paper.jsonl
# [ok] Piwigo__Piwigo-Android: 23 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Piwigo__Piwigo-Android.jsonl
# [ok] posm__OpenMapKitAndroid: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\posm__OpenMapKitAndroid.jsonl
# [skip] prisma__react-native-prisma: no field-level deltas found
# [ok] pytorch__executorch: 49 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\pytorch__executorch.jsonl
# [ok] rafsanjani__datepickertimeline: 11 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\rafsanjani__datepickertimeline.jsonl
# [ok] ragunathjawahar__android-saripaar: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ragunathjawahar__android-saripaar.jsonl
# [ok] rainbow-me__rainbow: 110 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\rainbow-me__rainbow.jsonl
# [ok] Rajawali__Rajawali: 52 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Rajawali__Rajawali.jsonl
# [ok] RBusarow__Tangle: 27 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\RBusarow__Tangle.jsonl
# [ok] ReactiveCircus__streamlined: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ReactiveCircus__streamlined.jsonl
# [ok] readrops__Readrops: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\readrops__Readrops.jsonl
# [ok] realm__realm-kotlin: 132 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\realm__realm-kotlin.jsonl
# [ok] Redgram__redgram-for-reddit: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Redgram__redgram-for-reddit.jsonl
# [ok] rejasupotaro__Rebuild: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\rejasupotaro__Rebuild.jsonl
# [ok] renyuneyun__Easer: 24 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\renyuneyun__Easer.jsonl
# [ok] requery__requery: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\requery__requery.jsonl
# [ok] robolectric__robolectric: 107 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\robolectric__robolectric.jsonl
# [ok] ronaldsmartin__Material-ViewPagerIndicator: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ronaldsmartin__Material-ViewPagerIndicator.jsonl
# [ok] rozPierog__Cofi: 50 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\rozPierog__Cofi.jsonl
# [ok] ruffle-rs__ruffle-android: 24 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ruffle-rs__ruffle-android.jsonl
# [ok] sakusaku3939__DeepLAndroid: 11 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sakusaku3939__DeepLAndroid.jsonl
# [ok] Samsung__escargot: 11 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Samsung__escargot.jsonl
# [ok] sangcomz__FishBun: 31 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sangcomz__FishBun.jsonl
# [ok] scribe-org__Scribe-Android: 24 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\scribe-org__Scribe-Android.jsonl
# [ok] SecUSo__privacy-friendly-notes: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\SecUSo__privacy-friendly-notes.jsonl
# [ok] SecUSo__privacy-friendly-pedometer: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\SecUSo__privacy-friendly-pedometer.jsonl
# [ok] SecUSo__privacy-friendly-todo-list: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\SecUSo__privacy-friendly-todo-list.jsonl
# [ok] seedvault-app__seedvault: 49 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\seedvault-app__seedvault.jsonl
# [ok] segler-alex__RadioDroid: 27 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\segler-alex__RadioDroid.jsonl
# [ok] sellmair__kompass: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sellmair__kompass.jsonl
# [ok] servo__surfman: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\servo__surfman.jsonl
# [ok] simonnorberg__dmach: 39 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\simonnorberg__dmach.jsonl
# [ok] simpledotorg__simple-android: 71 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\simpledotorg__simple-android.jsonl
# [ok] sky-map-team__stardroid: 70 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sky-map-team__stardroid.jsonl
# [ok] slackhq__circuit: 30 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\slackhq__circuit.jsonl
# [ok] smartdevicelink__sdl_java_suite: 68 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\smartdevicelink__sdl_java_suite.jsonl
# [ok] softartdev__NoteDelight: 102 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\softartdev__NoteDelight.jsonl
# [ok] software-mansion__react-native-screens: 112 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\software-mansion__react-native-screens.jsonl
# [ok] sopt-makers__sopt-android: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sopt-makers__sopt-android.jsonl
# [ok] spacecowboy__NotePad: 123 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\spacecowboy__NotePad.jsonl
# [ok] splitwise__TokenAutoComplete: 20 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\splitwise__TokenAutoComplete.jsonl
# [ok] sqldelight__sqldelight: 45 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\sqldelight__sqldelight.jsonl
# [ok] square__curtains: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__curtains.jsonl
# [ok] square__cycler: 17 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__cycler.jsonl
# [ok] square__leakcanary: 56 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__leakcanary.jsonl
# [ok] square__okhttp: 34 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__okhttp.jsonl
# [ok] square__papa: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__papa.jsonl
# [ok] square__wire: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\square__wire.jsonl
# [ok] StefanIlchev__ElementumService: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\StefanIlchev__ElementumService.jsonl
# [ok] streetwriters__notesnook: 47 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\streetwriters__notesnook.jsonl
# [ok] Stuart-campbell__RushOrm: 5 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Stuart-campbell__RushOrm.jsonl
# [ok] SundeepK__CompactCalendarView: 10 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\SundeepK__CompactCalendarView.jsonl
# [ok] SwissCovid__swisscovid-app-android: 13 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\SwissCovid__swisscovid-app-android.jsonl
# [ok] synonymdev__bitkit: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\synonymdev__bitkit.jsonl
# [ok] syrjs__core: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\syrjs__core.jsonl
# [ok] t895__DNSNet: 21 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\t895__DNSNet.jsonl
# [ok] takahirom__PreLollipopTransition: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\takahirom__PreLollipopTransition.jsonl
# [ok] tasks__tasks: 164 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\tasks__tasks.jsonl
# [ok] TeamAmaze__AmazeFileManager: 118 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\TeamAmaze__AmazeFileManager.jsonl
# [ok] TeamNewPipe__NewPipe: 76 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\TeamNewPipe__NewPipe.jsonl
# [ok] TechbeeAT__jtxBoard: 56 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\TechbeeAT__jtxBoard.jsonl
# [ok] tfcporciuncula__flow-preferences: 4 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\tfcporciuncula__flow-preferences.jsonl
# [ok] thevindu-w__clip_share_client: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\thevindu-w__clip_share_client.jsonl
# [ok] ThibaultBee__srtdroid: 19 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ThibaultBee__srtdroid.jsonl
# [ok] thunderbiscuit__padawan-wallet: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\thunderbiscuit__padawan-wallet.jsonl
# [ok] thyrlian__AwesomeValidation: 55 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\thyrlian__AwesomeValidation.jsonl
# [ok] Tommy-Geenexus__exif-eraser: 26 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\Tommy-Geenexus__exif-eraser.jsonl
# [ok] TomRoush__PdfBox-Android: 42 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\TomRoush__PdfBox-Android.jsonl
# [ok] tonilopezmr__Game-of-Thrones: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\tonilopezmr__Game-of-Thrones.jsonl
# [ok] trynoice__android-app: 40 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\trynoice__android-app.jsonl
# [ok] TwidereProject__TwidereX-Android: 43 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\TwidereProject__TwidereX-Android.jsonl
# [ok] twireapp__Twire: 42 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\twireapp__Twire.jsonl
# [ok] uber__simple-store: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\uber__simple-store.jsonl
# [ok] UriahShaulMandel__BaldPhone: 11 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\UriahShaulMandel__BaldPhone.jsonl
# [ok] v2er-app__Android: 40 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\v2er-app__Android.jsonl
# [ok] ValentinFunk__BrainPhaser: 1 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\ValentinFunk__BrainPhaser.jsonl
# [ok] vanniktech__OnActivityResult: 15 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\vanniktech__OnActivityResult.jsonl
# [ok] vmiklos__plees-tracker: 59 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\vmiklos__plees-tracker.jsonl
# [ok] voghDev__PdfViewPager: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\voghDev__PdfViewPager.jsonl
# [ok] VREMSoftwareDevelopment__WiFiAnalyzer: 112 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\VREMSoftwareDevelopment__WiFiAnalyzer.jsonl
# [ok] wajahatkarim3__Imagine: 12 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\wajahatkarim3__Imagine.jsonl
# [ok] WangJie0822__Cashbook: 28 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\WangJie0822__Cashbook.jsonl
# [ok] wikimedia__apps-android-wikipedia: 120 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\wikimedia__apps-android-wikipedia.jsonl
# [ok] xebia-functional__appsly-android-rest: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\xebia-functional__appsly-android-rest.jsonl
# [ok] XRPL-Labs__Xaman-App: 9 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\XRPL-Labs__Xaman-App.jsonl
# [ok] yeungeek__monkey-android: 7 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\yeungeek__monkey-android.jsonl
# [ok] yogeshpaliyal__KeyPass: 40 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\yogeshpaliyal__KeyPass.jsonl
# [ok] yuriykulikov__AlarmClock: 18 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\yuriykulikov__AlarmClock.jsonl
# [ok] zimly__zimly-backup: 6 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\zimly__zimly-backup.jsonl
# [ok] zkmopro__mopro: 8 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\zkmopro__mopro.jsonl
# [ok] zoff99__ToxAndroidRefImpl: 62 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\zoff99__ToxAndroidRefImpl.jsonl
# [ok] zsoltk__GameOfLife: 3 enriched rows -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\cce_enriched_V5.1\zsoltk__GameOfLife.jsonl
# Done.

# %%
# combine_v51.py
# RQ2 — Step 3 (Combine v5.1): Snapshots + Enriched Episodes
# - Aligned with Step-2 v5.1 (NO baseline "begin")
# - Column order: Metadata → Other → Primary → Secondary → Driver (+ AUX)
# - Cleans list-like cells to CSV-friendly strings
# - PRESERVES JSON diff payloads (old_value/new_value/added_items/removed_items) verbatim
# - NO Parquet output

from __future__ import annotations
import json, csv, ast, math
from pathlib import Path
from typing import List, Any

# -----------------------------
# Config (aligned with Step-2 v5.1)
# -----------------------------
WORK_ROOT         = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2")
SNAPSHOT_DIR      = WORK_ROOT / "snapshots"

# NOTE: Step-2 v5.1 currently writes to cce_enriched_V4.7 in your code.
# If you switch Step-2 to write to a new folder, update this constant.
CCE_ENRICHED_DIR  = WORK_ROOT / "cce_enriched_V5.1"

COMBINE_DIR       = WORK_ROOT / "combined_V5.1"
COMBINE_DIR.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Helpers
# -----------------------------
def read_all_jsonl(folder: Path) -> List[dict]:
    out: List[dict] = []
    if not folder.exists():
        return out
    for p in folder.glob("*.jsonl"):
        with p.open(encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    d = json.loads(line)
                    d["_source_file"] = p.name
                    out.append(d)
    return out

def to_json(x: Any) -> str:
    try:
        return json.dumps(x, ensure_ascii=False, sort_keys=True)
    except Exception:
        return "" if x is None else str(x)

def _is_na_like(x: Any) -> bool:
    if x is None:
        return True
    if isinstance(x, float):
        try:
            return math.isnan(x)
        except Exception:
            return False
    if isinstance(x, str):
        s = x.strip().lower()
        return s in {"", "null", "none", "nan", "na"}
    return False

def conservative_change_op(old_v: Any, new_v: Any) -> str:
    # Fallback only; Step-2 already emits 'change_op'
    o_empty = _is_na_like(old_v)
    n_empty = _is_na_like(new_v)
    if o_empty and n_empty:
        return "no_change"
    if o_empty and not n_empty:
        return "add"
    if not o_empty and n_empty:
        return "remove"
    return "value_edit" if (str(old_v) != str(new_v)) else "no_change"

def to_list_like(x: Any) -> list:
    if x is None:
        return []
    if isinstance(x, list):
        return x
    if isinstance(x, (set, tuple)):
        return list(x)
    if isinstance(x, str):
        s = x.strip()
        if not s:
            return []
        # JSON- or Python-like list
        if (s.startswith("[") and s.endswith("]")) or (s.startswith("(") and s.endswith(")")):
            try:
                v = json.loads(s)
                if isinstance(v, list):
                    return v
            except Exception:
                pass
            try:
                v = ast.literal_eval(s)
                if isinstance(v, (list, tuple, set)):
                    return list(v)
            except Exception:
                pass
        # Delimited
        if "," in s:
            return [t.strip() for t in s.split(",") if t.strip()]
        if ";" in s:
            return [t.strip() for t in s.split(";") if t.strip()]
        # Single token
        return [s]
    # Fallback
    return [x]

# Keep these exact JSON strings; don't normalize them to CSV tokens
KEEP_AS_JSON = {"old_value", "new_value", "added_items", "removed_items"}

def clean_cell_no_brackets(v: Any) -> str:
    """Default cleaner: lists→'a,b,c', dicts→JSON, strip brackets for stringified lists."""
    if v is None:
        return ""
    if isinstance(v, bool):
        return "True" if v else "False"
    if isinstance(v, dict):
        try:
            return json.dumps(v, ensure_ascii=False, sort_keys=True)
        except Exception:
            return str(v)
    if isinstance(v, (list, tuple, set)) or (isinstance(v, str) and v.strip()[:1] in "[(" and v.strip()[-1:] in "])"):
        items = [str(t).strip() for t in to_list_like(v) if str(t).strip()]
        items = sorted(set(items))
        return ",".join(items)
    s = str(v).strip()
    if (s.startswith("[") and s.endswith("]")) or (s.startswith("(") and s.endswith(")")):
        items = [str(t).strip() for t in to_list_like(s) if str(t).strip()]
        items = sorted(set(items))
        return ",".join(items)
    return str(v)

def clean_cell_preserve_json(key: str, v: Any) -> str:
    """Preserve JSON strings for diff payloads; otherwise use the normal cleaner."""
    if key in KEEP_AS_JSON and isinstance(v, str):
        return v.strip()
    return clean_cell_no_brackets(v)

# -----------------------------
# Load inputs
# -----------------------------
snapshots = read_all_jsonl(SNAPSHOT_DIR)
episodes  = read_all_jsonl(CCE_ENRICHED_DIR)
print(f"Loaded {len(snapshots)} snapshots; {len(episodes)} enriched episode rows.")

# -----------------------------
# Write CSV (snapshots)
# -----------------------------
snap_csv = COMBINE_DIR / "snapshots_combined.csv"
if snapshots:
    snaps_flat = []
    for r in snapshots:
        feats = r.get("features", {})
        rr = {**r, "features_json": to_json(feats)}
        rr.pop("features", None)
        snaps_flat.append(rr)

    keys = sorted(set().union(*[set(x.keys()) for x in snaps_flat]))
    with snap_csv.open("w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in snaps_flat:
            r_clean = {k: clean_cell_no_brackets(v) for k, v in r.items()}
            w.writerow(r_clean)
    print(f"[ok] {snap_csv}")
else:
    print("[warn] No snapshots found.")

# -----------------------------
# Write CSV (episodes enriched) — align to Step-2 v5.1 (no baseline)
# -----------------------------
cce_csv = COMBINE_DIR / "episodes_enriched_combined.csv"
if episodes:
    # Groups → Metadata / Other / Primary / Secondary / Driver (+ AUX)
    META_COLS = [
        "repo", "_source_file", "sha", "prev_sha",
        "timestamp_epoch_utc", "timestamp_utc",
        "path", "subject",
    ]

    # Diff/audit (keep JSON payloads)
    DIFF_COLS = [
        "old_value", "new_value", "change_type", "change_op", "magnitude",
        "added_items", "removed_items", "repeat_index", "repeat_label",
        # Per-delta extras (may be blank unless applicable)
        "Coverage_Added_Count", "Coverage_Removed_Count", "Coverage_Net",
        "Runtime_Wait_Delta", "Runtime_Wait_Change",
        "Aux_Tags",
        "intent_delta_episode",
    ]

    # Step-1 carryover (minimal)
    STEP1_CARRY_COLS = [
        "File_Kind",
        "CI_Emulator_Step_Change",
        "Gradle_GMD_Block_Change",
        "Context_Scope_Keys",
        "Is_Emulator_Relevant_File",
    ]

    # Grouping & flags
    GROUPING_AND_FLAGS = [
        "Spot_Tag",
        "Field_Group",
        "Include_Emulator_Study",
    ]

    # AUX fields actually emitted by Step-2 v5.1
    AUX_COLS = [
        # Emulator style (episode-level)
        "Emulator_Style_Old", "Emulator_Style_New", "Emulator_Style_Change",
        # GMD presence (+ direction)
        "GMD_Present_Old", "GMD_Present_New", "GMD_Direction",
        # Orchestrator presence (+ change)
        "Orchestrator_Enabled_Old", "Orchestrator_Enabled_New", "Orchestrator_Change",
    ]

    OTHER_COLS = DIFF_COLS + STEP1_CARRY_COLS + GROUPING_AND_FLAGS + AUX_COLS

    PRIMARY_COLS = [
        "Field",
        "Primary_Label",
        "Primary_Label_Category",
    ]

    SECONDARY_COLS = [
        "intent_delta", "intent_pfa", "intent_subject", "intent_path",
        "Secondary_Label",
        "Intent_Path", "Intent_Path_Reason", "Intent_Subject_Reason",
    ]

    DRIVER_COLS = [
        "Driver",
        "intent_headline",
        "Driver_Source",
        "Driver_reason",
        "Driver_Label_Selected",
    ]

    ORDERED_COLS = META_COLS + OTHER_COLS + PRIMARY_COLS + SECONDARY_COLS + DRIVER_COLS

    # Build rows (only fields from known schema; unknown keys ignored)
    rows_out: List[dict] = []
    for r in episodes:
        rr = {}
        for k in ORDERED_COLS:
            if k in r:
                rr[k] = r.get(k, "")
        # conservative fill for change_op if missing (fallback only)
        if not rr.get("change_op"):
            rr["change_op"] = conservative_change_op(r.get("old_value"), r.get("new_value"))
        # Clean cells (preserve JSON diff payloads)
        rr = {k: clean_cell_preserve_json(k, v) for k, v in rr.items()}
        rows_out.append(rr)

    # Header: include only columns that appear at least once, but force core metadata
    present_cols = [c for c in ORDERED_COLS if any((c in r and r[c] != "") for r in rows_out)]
    for c in META_COLS:
        if c not in present_cols:
            present_cols.insert(0 if c == "repo" else len(present_cols), c)

    with cce_csv.open("w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=present_cols)
        w.writeheader()
        for r in rows_out:
            w.writerow({k: r.get(k, "") for k in present_cols})

    print(f"[ok] {cce_csv}")
else:
    print("[warn] No enriched episodes found.")
# Out:
# Loaded 185593 snapshots; 9566 enriched episode rows.
# [ok] C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\combined_V5.1\snapshots_combined.csv
# [ok] C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ2\combined_V5.1\episodes_enriched_combined.csv
