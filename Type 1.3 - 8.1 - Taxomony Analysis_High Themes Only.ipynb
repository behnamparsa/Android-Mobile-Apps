# %%
"""
High/Medium/Low CI Theme Miner for Android Instrumentation (LOG FETCH + STRATUM GATING)
--------------------------------------------------------------------------------------
What this script does
- Reads your stratified sample (html_url + stratum) and strict weights from cohort_table.csv.
- Fetches GitHub Actions logs (token rotation, backoff) within a time window aligned to your snapshot.
- Scans logs for High/Medium/Low themes, but:
  * High themes always counted.
  * Medium/Low are only counted if the repo has instrumentation context based on STRATUM (Y/B/A).
    - De-noising for Med/Low: require >=2 matching lines OR hits in >=2 runs.
- Collects YAML hints (remote workflows + local configs) for audit context only (not gating).
- Outputs weighted counts, by-provider breakdown, examples, and an audit table.

Your key adjustments included:
1) Trust STRATUM (Y/B/A) for instrumentation context gating instead of YAML hints.
2) Expand log search period to 90 days BEFORE clone date (no drift after clone date).
3) Keep progress logs, early-stop, and token rotation.

Outputs (saved in OUT_DIR):
  - challenge_counts_weighted_high_only.csv
  - challenge_counts_by_provider_weighted_high_only.csv
  - challenge_examples_high_only.csv
  - challenge_run_audit_high_only.csv
"""

import os, re, io, zipfile, json, time, random
from pathlib import Path
import pandas as pd
import numpy as np
from datetime import datetime, time as dtime, timedelta, timezone

# ======================= CONFIG =======================
CONFIG_DIR        = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\All_Config_Files")
SAMPLED_CSV_DIR   = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\Stratified Sample")
SAMPLED_CSV_NAME  = None                   # If None → auto-pick CSV containing 'stratified' in name
COHORT_FILE_NAME  = "cohort_table.csv"     # STRICT: required, used for weights only
OUT_DIR           = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis")

# Tokens env file (both casings tried)
TOKENS_ENV_PATH   = Path(r"C:\GitHub\Android-Mobile-Apps\all_tokens.env")
if not TOKENS_ENV_PATH.exists():
    TOKENS_ENV_PATH = Path(r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env")

# Remote fetch controls
ENABLE_GITHUB_FETCH = True
MAX_RUNS_PER_REPO   = 60       # ↑ coverage
REQUEST_TIMEOUT     = 30
REQUESTS_MAX_RETRIES= 3
BACKOFF_BASE_SEC    = 2.0

# Early stop: stop scanning more runs for a repo once a hit is confirmed
EARLY_STOP_ON_HIT = True
EARLY_STOP_MODE   = "any"      # "any" (high/med/low) or "high-only"

# Time window around clone date (align logs to snapshot)
USE_CUTOFF          = True
CLONE_DATE_LOCAL    = "2025-08-10"   # your clone date
WINDOW_DAYS_BEFORE  = 90             # include logs up to 90 days BEFORE clone date
WINDOW_DAYS_AFTER   = 0              # keep 0 to avoid drift after snapshot
LOCAL_TZ            = "America/Toronto"

# Progress logging
VERBOSE = True
PROGRESS_EVERY = 1
SHOW_HIT_SNIPPET_COUNT = True

# ======================= THEMES =======================
THEMES = {
  # High (hard runtime failures, always counted)
  "EMULATOR_BOOT_TIMEOUT": ["device offline", "boot completed timeout", "emulator: ERROR", "emulator: Panic", "Adb connection refused"],
  "HW_ACCEL/KVM_MISSING": ["/dev/kvm permission denied", "KVM is required", "accel not installed", "HAXM is not installed", "Hypervisor.framework is required"],
  "MISSING_EMULATOR_BIN": ["emulator: not found", "No emulator installed"],
  "ADB_ISSUE": ["ADB server didn't ACK", "ADB server version mismatch", "error: device offline", "more than one device/emulator"],
  "X11/HEADLESS": ["xvfb-run: error", "Cannot open display", "DISPLAY not set"],
  "VENDOR_LAB_QUOTA": ["Quota exceeded", "Billing account not configured", "insufficient tokens for"],

  # Medium (config/setup + infra)
  "SDK_LICENSES": ["You have not accepted the license agreements", "licenses not accepted", "SDK licenses not accepted"],
  "IMAGE_NOT_FOUND": [r"Package .* was not found", r"failed to find target with hash string", r"system-images;android-\d+.*not found"],
  "JAVA/GRADLE/AGP_VERSION_DRIFT": ["Minimum supported Gradle is", "This version of the Android Gradle plugin requires", "Unsupported Java", "Kotlin version .* is not compatible"],
  "ANDROIDX_TEST_MISMATCH": ["Could not resolve androidx.test", "Duplicate class .* found in modules", "conflict with dependency 'androidx.test'"],
  "NETWORK_FLAKE": ["Connection reset by peer", "TLS handshake timeout", "temporary failure in name resolution", "network is unreachable"],
  "SECRETS_PERMS": ["Permission denied", "No such file or directory .*keystore", "secrets.* not set", "Missing .* environment variable"],
  "GENERIC_TIMEOUT/CANCEL": ["job timed out", "The operation was canceled", "timeout exceeded"],

  # Low (weak signals)
  "TEST_FLAKY_SIGNAL": [r"Flaky", r"retrying test", r"java\.lang\.AssertionError", r"org\.junit\.ComparisonFailure"],
}

HIGH_THEMES   = {"EMULATOR_BOOT_TIMEOUT","HW_ACCEL/KVM_MISSING","MISSING_EMULATOR_BIN","ADB_ISSUE","X11/HEADLESS","VENDOR_LAB_QUOTA"}
MEDIUM_THEMES = {"SDK_LICENSES","IMAGE_NOT_FOUND","JAVA/GRADLE/AGP_VERSION_DRIFT","ANDROIDX_TEST_MISMATCH","NETWORK_FLAKE","SECRETS_PERMS","GENERIC_TIMEOUT/CANCEL"}
LOW_THEMES    = {"TEST_FLAKY_SIGNAL"}

# Medium/Low de-noising + gating
INCLUDE_MEDIUM = True
INCLUDE_LOW    = True
MEDLOW_MIN_LINE_HITS     = 2   # >=2 matching lines ...
MEDLOW_MIN_RUNS_WITH_HIT = 2   # ... OR hits in >=2 runs
# GATING SOURCE: STRATUM ONLY (Y/B/A)
# YAML hints are collected for context but NOT used to gate Medium/Low.

# Simple YAML hints (for audit context only)
YAML_HINTS = [
    "reactivecircus/android-emulator-runner",
    "sdkmanager",
    "avdmanager",
    "emulator -avd",
    "gcloud firebase test android run",
    "adb", "androidTest", "connectedAndroidTest"
]
TEXT_EXTS = {".yml",".yaml",".log",".txt",".json",".xml",".gradle",".kts",".properties",".sh",".bat",".cfg",".conf",".ini",".md"}

# ======================= HELPERS =======================
def ts(): return datetime.now().strftime("%Y-%m-%d %H:%M:%S")
def banner(msg):   print(f"[{ts()}] ===== {msg} =====", flush=True) if VERBOSE else None
def note(msg):     print(f"[{ts()}] {msg}", flush=True)
def warn(msg):     print(f"[{ts()}] [WARN] {msg}", flush=True)
def info(msg):     print(f"[{ts()}] [INFO] {msg}", flush=True)

def load_tokens_from_env_file(path: Path) -> list:
    tokens = {}
    if path and path.exists():
        for raw in path.read_text(encoding="utf-8", errors="ignore").splitlines():
            line = raw.strip()
            if not line or line.startswith(("#",";")) or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k, v = k.strip(), v.strip().strip('"').strip("'")
            if k.upper().startswith("GITHUB_TOKEN_"):
                try: idx = int(k.split("_")[-1])
                except Exception: idx = 999
                tokens[idx] = v
    return [tokens[i] for i in sorted(tokens.keys()) if tokens[i]]

class TokenRotator:
    def __init__(self, tokens: list[str]): self.tokens, self.i = (tokens or []), 0
    def current(self): return (self.tokens[self.i] if self.tokens else None)
    def rotate(self): 
        if self.tokens: self.i = (self.i + 1) % len(self.tokens)
    def headers(self, allow_auth=True):
        base = {"Accept":"application/vnd.github+json","User-Agent":"challenge-miner/high-med-low/1.0"}
        tok = self.current()
        if allow_auth and tok: base["Authorization"] = f"Bearer {tok}"
        return base

def gh_get(url, rot: TokenRotator, allow_auth=True, timeout=REQUEST_TIMEOUT):
    import requests
    tries = 0
    while True:
        tries += 1
        resp = requests.get(url, headers=rot.headers(allow_auth=allow_auth), timeout=timeout)
        diag = {"status": resp.status_code, "rate_remaining": resp.headers.get("X-RateLimit-Remaining"),
                "rate_reset": resp.headers.get("X-RateLimit-Reset"), "message": None}
        try:
            j = resp.json()
            if isinstance(j, dict) and "message" in j: diag["message"] = j["message"]
        except Exception: pass
        resp._diag = diag

        if resp.status_code in (200,201,204): return resp
        if resp.status_code in (403,429):
            warn(f"Rate/403 on {url}. Rotating token. Diag={diag}")
            rot.rotate()
            if tries >= REQUESTS_MAX_RETRIES * max(1, len(rot.tokens)): return resp
            sleep_s = BACKOFF_BASE_SEC * (2 ** (tries-1)) + random.random()
            time.sleep(min(sleep_s, 30)); continue
        if resp.status_code == 401 and allow_auth:
            return gh_get(url, rot, allow_auth=False, timeout=timeout)
        return resp

def owner_repo_from_url(url: str):
    try:
        u = (url or "").strip().strip("/")
        if "github.com/" in u:
            tail = u.split("github.com/", 1)[1].strip("/")
            parts = tail.split("/")
            if len(parts) >= 2: return parts[0].lower(), parts[1].lower()
    except Exception: pass
    return None, None

def full_name_from_html_url(url: str) -> str | None:
    o, r = owner_repo_from_url(url); return f"{o}/{r}" if (o and r) else None

def full_name_from_saved_filename(path: Path) -> str | None:
    base = path.name
    m = re.match(r"^([A-Za-z0-9_.-]+)\.([A-Za-z0-9_.-]+)__", base)
    if m:
        owner, repo = m.group(1), m.group(2)
        return f"{owner.replace(' ','').lower()}/{repo.replace(' ','').lower()}"
    return None

# ---- time window helpers ----
try:
    from zoneinfo import ZoneInfo
except Exception:
    ZoneInfo = None

def parse_gh_ts(ts: str):
    if not ts: return None
    try: return datetime.strptime(ts, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)
    except Exception: return None

def window_utc_from_local(center_date_str: str, days_before: int, days_after: int, tz_name: str):
    try:
        center = datetime.strptime(center_date_str, "%Y-%m-%d").date()
    except Exception:
        return (None, None, True)
    start_date = center - timedelta(days=days_before)
    end_date   = center + timedelta(days=days_after)
    if ZoneInfo is None:
        # fallback: compare by DATE only
        return (start_date, end_date, True)
    tz = ZoneInfo(tz_name)
    start_local = datetime.combine(start_date, dtime(0,0,0)).replace(tzinfo=tz)
    end_local   = datetime.combine(end_date,   dtime(23,59,59)).replace(tzinfo=tz)
    return (start_local.astimezone(timezone.utc), end_local.astimezone(timezone.utc), False)

# ======================= REMOTE FETCH =======================
def list_workflow_runs(rot: TokenRotator, owner: str, repo: str, page: int, per_page: int = 100):
    return gh_get(f"https://api.github.com/repos/{owner}/{repo}/actions/runs?per_page={per_page}&page={page}",
                  rot, allow_auth=True)

def fetch_log_text_for_run(rot: TokenRotator, logs_url: str):
    resp = gh_get(logs_url, rot, allow_auth=True)
    if resp.status_code != 200: return None, resp._diag
    try:
        zf = zipfile.ZipFile(io.BytesIO(resp.content))
    except zipfile.BadZipFile:
        return None, resp._diag
    texts = []
    for name in zf.namelist():
        try:
            with zf.open(name) as f:
                texts.append(f.read().decode("utf-8", errors="ignore"))
        except Exception:
            continue
    return "\n".join(texts), None

def fetch_workflow_yamls(rot: TokenRotator, owner: str, repo: str):
    """Context only (not gating)."""
    yamls, err = [], None
    r = gh_get(f"https://api.github.com/repos/{owner}/{repo}/contents/.github/workflows", rot, allow_auth=True)
    if r.status_code == 200:
        for item in r.json():
            if item.get("type") == "file" and item.get("name", "").lower().endswith((".yml",".yaml")):
                raw_url = item.get("download_url")
                if not raw_url: continue
                fr = gh_get(raw_url, rot, allow_auth=True)
                if fr.status_code == 200: yamls.append(fr.text)
    else:
        err = r._diag
    return "\n".join(yamls), err

# ======================= SCANNING =======================
PAT_MAP = {k: [re.compile(p, re.I) for p in v] for k, v in THEMES.items()}

def scan_text_for_themes(text: str):
    """
    Returns:
      - found: list of themes that matched at least one line
      - hits:  list of (theme, line) for each matching line (truncated to 500 chars)
    """
    found, hits = set(), []
    if not text: return [], []
    for theme, regs in PAT_MAP.items():
        for line in text.splitlines():
            for rx in regs:
                if rx.search(line):
                    found.add(theme)
                    hits.append((theme, line[:500]))
                    break
            if theme in found:
                # continue scanning other themes; we still collect per-line hits for Med/Low de-noising
                continue
    return list(found), hits

def scan_yaml_hints(text: str):
    L = (text or "").lower()
    return [h for h in YAML_HINTS if h.lower() in L]

# ---------- STRATUM-BASED GATING ----------
STRATUM_RX = re.compile(r"^Y([01])_B([01])_A([01])$")

def parse_stratum_bits(s: str) -> tuple[int,int,int]:
    if not isinstance(s, str):
        return (0,0,0)
    m = STRATUM_RX.match(s.strip())
    if not m:
        return (0,0,0)
    return (int(m.group(1)), int(m.group(2)), int(m.group(3)))

def has_instru_context_from_stratum(stratum: str, at_pred: int | None = None) -> bool:
    y, b, a = parse_stratum_bits(stratum)
    if (y == 1) or (b == 1) or (a == 1):
        return True
    return bool(int(at_pred or 0) == 1)

# ========== Med/Low de-noising rule ==========
def _theme_counts_as_hit(theme: str, theme_line_hits: dict, theme_run_ids: dict, high: bool=False) -> bool:
    """
    High themes: any single hit counts.
    Medium/Low: require >= MEDLOW_MIN_LINE_HITS (line-level matches) OR
                >= MEDLOW_MIN_RUNS_WITH_HIT (distinct runs with a match).
    """
    if theme not in theme_line_hits and theme not in theme_run_ids:
        return False
    if (high or theme in HIGH_THEMES):
        return (theme_line_hits.get(theme, 0) >= 1)
    # Med/Low rule:
    line_hits = theme_line_hits.get(theme, 0)
    run_hits  = len(theme_run_ids.get(theme, set()))
    return (line_hits >= MEDLOW_MIN_LINE_HITS) or (run_hits >= MEDLOW_MIN_RUNS_WITH_HIT)

# ======================= DATA LOADING =======================
def auto_pick_stratified_csv(folder: Path) -> Path:
    cands = sorted([p for p in folder.glob("*.csv") if "stratified" in p.name.lower()])
    if not cands:
        cands = sorted(folder.glob("*.csv"))
    if not cands:
        raise FileNotFoundError(f"No CSV found in {folder}")
    return cands[0]

def load_sample_and_weights(folder: Path, sample_name: str | None, cohort_name: str) -> pd.DataFrame:
    # Sample
    samp_path = (folder / sample_name) if sample_name else auto_pick_stratified_csv(folder)
    sample = pd.read_csv(samp_path)

    if "html_url" not in sample.columns:
        for alt in ["url","repo_url","html_urls","html"]:
            if alt in sample.columns:
                sample = sample.rename(columns={alt:"html_url"}); break
    if "stratum" not in sample.columns:
        for alt in ["Stratum","strata","group"]:
            if alt in sample.columns:
                sample = sample.rename(columns={alt:"stratum"}); break
    if "html_url" not in sample.columns or "stratum" not in sample.columns:
        raise ValueError("Sample CSV must include 'html_url' and 'stratum' columns.")

    sample["full_name"] = sample["html_url"].apply(full_name_from_html_url)

    # Keep AT_pred if present; else 0
    if "AT_pred" not in sample.columns:
        sample["AT_pred"] = 0

    # Cohort (strict)
    cohort_path = folder / cohort_name
    if cohort_name.lower() != "cohort_table.csv":
        raise ValueError("COHORT_FILE_NAME must be 'cohort_table.csv'.")
    if not cohort_path.exists():
        raise FileNotFoundError(f"Required cohort table not found: {cohort_path}")

    cohort = pd.read_csv(cohort_path)
    if "stratum" not in cohort.columns:
        for alt in ["Stratum","strata","group"]:
            if alt in cohort.columns:
                cohort = cohort.rename(columns={alt:"stratum"}); break
    if "stratum" not in cohort.columns:
        raise ValueError("cohort_table.csv must include a 'stratum' column.")

    # Determine weights: prefer 'weight'; else N/n_sample; else 1.0
    weight_col = None
    for c in cohort.columns:
        if c.strip().lower() in {"weight","w","wt"}:
            weight_col = c; break
    if weight_col is None:
        lc_map = {c.lower(): c for c in cohort.columns}
        pop_col  = next((lc_map[k] for k in ["n","n_total","n_population","population","pop","n_pop","total","size"] if k in lc_map), None)
        samp_col = next((lc_map[k] for k in ["n_sample","sample","sample_n","n_samp","sample_size"] if k in lc_map), None)
        if pop_col is not None and samp_col is not None:
            cohort["__weight__"] = (
                pd.to_numeric(cohort[pop_col], errors="coerce") /
                pd.to_numeric(cohort[samp_col], errors="coerce").replace({0: np.nan})
            )
            weight_col = "__weight__"

    if weight_col:
        tmp = cohort[["stratum", weight_col]].copy().rename(columns={weight_col:"weight"})
        wmap = dict(zip(tmp["stratum"], tmp["weight"]))
    else:
        warn("cohort_table.csv has no 'weight' and cannot infer from N/n_sample; using flat weights = 1.0")
        wmap = {}

    sample["weight"] = sample["stratum"].map(lambda s: float(wmap.get(s, 1.0)))
    return sample

def index_local_configs_by_repo(root: Path) -> dict[str, list[Path]]:
    mapping: dict[str, list[Path]] = {}
    if not root.exists(): return mapping
    for p in root.rglob("*"):
        if not p.is_file(): continue
        if p.suffix.lower() not in TEXT_EXTS:
            if p.stat().st_size > 0 and p.suffix == "": pass
            else: continue
        full = full_name_from_saved_filename(p) or full_name_from_saved_filename(p.parent)
        if not full: continue
        mapping.setdefault(full, []).append(p)
    return mapping

# ======================= MAIN =======================
def main():
    start_t = time.time()
    OUT_DIR.mkdir(parents=True, exist_ok=True)

    banner("SETUP")
    tokens = load_tokens_from_env_file(TOKENS_ENV_PATH)
    rot = TokenRotator(tokens)
    if tokens: info(f"Loaded {len(tokens)} GitHub token(s) for rotation from {TOKENS_ENV_PATH}")
    else:      warn("No tokens found; unauthenticated fetch will work only for public repos and low rate limits.")

    # time window
    start_arg = end_arg = None
    date_only = False
    if USE_CUTOFF:
        start_arg, end_arg, date_only = window_utc_from_local(CLONE_DATE_LOCAL, WINDOW_DAYS_BEFORE, WINDOW_DAYS_AFTER, LOCAL_TZ)
        if start_arg is None and end_arg is None:
            warn(f"Invalid cutoff '{CLONE_DATE_LOCAL}', proceeding without a cutoff.")
        else:
            if date_only:
                info(f"Applying DATE window: [{start_arg} .. {end_arg}] (no tz support available)")
            else:
                info(f"Applying UTC window: [{start_arg.isoformat()} .. {end_arg.isoformat()}] "
                     f"(local {LOCAL_TZ}, before={WINDOW_DAYS_BEFORE}, after={WINDOW_DAYS_AFTER})")

    banner("LOAD SAMPLE + WEIGHTS")
    sample_df = load_sample_and_weights(SAMPLED_CSV_DIR, SAMPLED_CSV_NAME, COHORT_FILE_NAME)
    sample_df = sample_df[~sample_df["full_name"].isna()].copy()
    repo_list = sorted(sample_df["full_name"].str.lower().unique().tolist())
    info(f"Repos in stratified sample: {len(repo_list)}")

    banner("INDEX LOCAL CONFIGS FOR YAML HINTS")
    repo_to_files = index_local_configs_by_repo(CONFIG_DIR)
    info(f"Repos with any local files detected: {len(repo_to_files)}")

    banner("FETCH & SCAN")
    rows, examples, audit = [], [], []
    total_runs_fetched = 0
    repos_with_hits = 0

    for idx, full in enumerate(repo_list, start=1):
        tic = time.time()
        provider = "github_actions"
        sub = sample_df[sample_df["full_name"].str.lower() == full]
        stratum = sub["stratum"].iloc[0] if not sub.empty else "Y0_B0_A0"
        weight  = float(sub["weight"].mean()) if not sub.empty else 1.0
        at_pred = int(sub["AT_pred"].max()) if ("AT_pred" in sub.columns and not sub["AT_pred"].isna().all()) else 0
        owner, repo = full.split("/", 1)

        # YAML hints (context only)
        yaml_text, wf_err = ("", None)
        if ENABLE_GITHUB_FETCH:
            yaml_text, wf_err = fetch_workflow_yamls(rot, owner, repo)
        local_files = repo_to_files.get(full, [])
        for fp in local_files:
            try:
                with open(fp, "r", encoding="utf-8", errors="ignore") as f:
                    yaml_text += "\n" + f.read()
            except Exception:
                pass
        yaml_hints = scan_yaml_hints(yaml_text) if yaml_text else []

        # STRATUM-based instrumentation context
        instru_ctx = has_instru_context_from_stratum(stratum, at_pred)

        # Eligible themes for counting
        eligible_themes = set(HIGH_THEMES)
        if INCLUDE_MEDIUM and instru_ctx:
            eligible_themes |= MEDIUM_THEMES
        if INCLUDE_LOW and instru_ctx:
            eligible_themes |= LOW_THEMES

        # Accumulators for de-noising (lines + runs)
        theme_line_hits: dict[str, int] = {}
        theme_run_ids:  dict[str, set]  = {}
        kept_examples = []  # (theme, run_id, line)

        # Iterate runs with pagination
        runs_err = None
        page, got = 1, 0
        while got < MAX_RUNS_PER_REPO:
            runs_resp = list_workflow_runs(rot, owner, repo, page=page, per_page=min(100, MAX_RUNS_PER_REPO))
            if runs_resp.status_code != 200:
                runs_err = runs_resp._diag; break
            wr = runs_resp.json().get("workflow_runs", [])
            if not wr: break

            for run in wr:
                if got >= MAX_RUNS_PER_REPO: break

                # date window filter
                created = parse_gh_ts(run.get("created_at"))
                if (start_arg is not None) or (end_arg is not None):
                    if date_only:
                        d = created.date() if created else None
                        if start_arg is not None and d is not None and d < start_arg: 
                            continue
                        if end_arg is not None and d is not None and d > end_arg: 
                            continue
                    else:
                        if start_arg is not None and created and created < start_arg: 
                            continue
                        if end_arg is not None and created and created > end_arg: 
                            continue

                # fetch logs for this run
                txt, diag = fetch_log_text_for_run(rot, run.get("logs_url"))
                if diag is not None:
                    runs_err = diag
                    continue
                got += 1
                total_runs_fetched += 1

                # scan
                fthemes, fhits = scan_text_for_themes(txt)

                # Per-theme accumulation (lines + run ids) only for eligible themes
                # Count line hits per theme (across all lines in this run)
                per_theme_line_count = {}
                for th, line in fhits:
                    if th in eligible_themes:
                        per_theme_line_count[th] = per_theme_line_count.get(th, 0) + 1

                for th, line_count in per_theme_line_count.items():
                    theme_line_hits[th] = theme_line_hits.get(th, 0) + line_count
                    theme_run_ids.setdefault(th, set()).add(run["id"])

                # Keep up to 3 example snippets across eligible themes
                if fhits and len(kept_examples) < 3:
                    for th, line in fhits:
                        if th in eligible_themes:
                            kept_examples.append((th, run["id"], line))
                            if len(kept_examples) >= 3: break

                # Early stop logic
                if EARLY_STOP_ON_HIT:
                    if EARLY_STOP_MODE == "any":
                        if any(_theme_counts_as_hit(th, theme_line_hits, theme_run_ids) for th in eligible_themes):
                            break
                    elif EARLY_STOP_MODE == "high-only":
                        if any(th in HIGH_THEMES and _theme_counts_as_hit(th, theme_line_hits, theme_run_ids, high=True)
                               for th in eligible_themes):
                            break

            # early stop outer check
            if EARLY_STOP_ON_HIT:
                if EARLY_STOP_MODE == "any":
                    if any(_theme_counts_as_hit(th, theme_line_hits, theme_run_ids) for th in eligible_themes):
                        break
                elif EARLY_STOP_MODE == "high-only":
                    if any(th in HIGH_THEMES and _theme_counts_as_hit(th, theme_line_hits, theme_run_ids, high=True)
                           for th in eligible_themes):
                        break

            page += 1

        # Final counted themes after de-noising
        seen_themes = set()
        for th in eligible_themes:
            if _theme_counts_as_hit(th, theme_line_hits, theme_run_ids):
                seen_themes.add(th)

        if seen_themes: repos_with_hits += 1

        # examples (only for themes that ultimately counted)
        for th, run_id, snip in kept_examples:
            if th in seen_themes:
                examples.append({
                    "full_name": full, "provider": provider, "stratum": stratum,
                    "theme": th, "run_id": run_id, "snippet": (snip or "").strip()[:500]
                })

        # row & audit
        rows.append({
            "full_name": full,
            "provider": provider,
            "stratum": stratum,
            "weight": weight,
            "themes": ";".join(sorted(seen_themes)) if seen_themes else "",
            "yaml_hints": ";".join(sorted(set(yaml_hints))) if yaml_hints else "",
            "log_runs_scanned": got,
            "yaml_bytes": len(yaml_text),
            "runs_err": json.dumps(runs_err) if runs_err else "",
            "wf_err": json.dumps(wf_err) if wf_err else "",
        })

        audit.append({
            "full_name": full,
            "log_runs_scanned": got,
            "yaml_bytes": len(yaml_text),
            "yaml_hints": ";".join(sorted(set(yaml_hints))) if yaml_hints else "",
            "themes_high_only": ";".join(sorted([t for t in seen_themes if t in HIGH_THEMES])) if seen_themes else "",
            "rate_remaining": (runs_err or {}).get("rate_remaining") if runs_err else None,
        })

        # progress line
        if idx % PROGRESS_EVERY == 0:
            dur = time.time() - tic
            err_flag = " ERR" if (rows[-1]["runs_err"] or rows[-1]["wf_err"]) else ""
            snip_ct = len([1 for th, _, _ in kept_examples if th in seen_themes]) if SHOW_HIT_SNIPPET_COUNT else 0
            note(f"[{idx}/{len(repo_list)}]{err_flag} {full} | runs={rows[-1]['log_runs_scanned']} | themes={len(seen_themes)}"
                 + (f" | examples={snip_ct}" if SHOW_HIT_SNIPPET_COUNT else "")
                 + f" | hints={len(yaml_hints)} | {dur:.1f}s")

    # Build outputs
    df = pd.DataFrame(rows)

    # Explode themes
    df_exp = df.copy()
    df_exp["themes"] = df_exp["themes"].fillna("")
    df_exp = df_exp[df_exp["themes"] != ""]
    if not df_exp.empty:
        df_exp = df_exp.assign(theme=df_exp["themes"].str.split(";")).explode("theme")
    else:
        df_exp = pd.DataFrame(columns=["full_name","provider","stratum","weight","theme"])

    # Weighted counts
    if not df_exp.empty:
        grp = df_exp.groupby("theme").agg(
            weighted_count=("weight", lambda s: float(np.nansum(s))),
            repos=("full_name","nunique"),
        ).reset_index()
        total_w = float(np.nansum(df["weight"].values))
        grp["share"] = np.where(total_w>0, grp["weighted_count"]/total_w, np.nan)
        grp = grp.sort_values(["weighted_count","repos"], ascending=[False, False])
    else:
        grp = pd.DataFrame(columns=["theme","weighted_count","repos","share"])

    # By provider
    if not df_exp.empty:
        byprov = df_exp.groupby(["provider","theme"]).agg(
            weighted_count=("weight", lambda s: float(np.nansum(s))),
            repos=("full_name","nunique"),
        ).reset_index()
        totals = byprov.groupby("provider")["weighted_count"].sum().rename("total_w")
        byprov = byprov.merge(totals, on="provider", how="left")
        byprov["share_in_provider"] = np.where(byprov["total_w"]>0, byprov["weighted_count"]/byprov["total_w"], np.nan)
        byprov = byprov.drop(columns=["total_w"]).sort_values(["provider","weighted_count"], ascending=[True, False])
    else:
        byprov = pd.DataFrame(columns=["provider","theme","weighted_count","repos","share_in_provider"])

    OUT_DIR.mkdir(parents=True, exist_ok=True)
    grp.to_csv(OUT_DIR/"challenge_counts_weighted_high_only.csv", index=False, encoding="utf-8-sig")
    byprov.to_csv(OUT_DIR/"challenge_counts_by_provider_weighted_high_only.csv", index=False, encoding="utf-8-sig")
    pd.DataFrame(examples).to_csv(OUT_DIR/"challenge_examples_high_only.csv", index=False, encoding="utf-8-sig")
    pd.DataFrame(audit).to_csv(OUT_DIR/"challenge_run_audit_high_only.csv", index=False, encoding="utf-8-sig")

    banner("DONE")
    info(f"Saved -> {OUT_DIR/'challenge_counts_weighted_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_counts_by_provider_weighted_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_examples_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_run_audit_high_only.csv'}")
    elapsed = time.time() - start_t
    note(f"SUMMARY: repos={len(repo_list)} | total_runs_fetched={total_runs_fetched} | repos_with_any_hits={sum(df['themes'].astype(bool))} | elapsed={elapsed:.1f}s")

if __name__ == "__main__":
    main()
# Out:
# [2025-08-22 20:22:36] ===== SETUP =====
# [2025-08-22 20:22:36] [INFO] Loaded 6 GitHub token(s) for rotation from C:\GitHub\Android-Mobile-Apps\all_tokens.env
# [2025-08-22 20:22:36] [INFO] Applying UTC window: [2025-05-12T04:00:00+00:00 .. 2025-08-11T03:59:59+00:00] (local America/Toronto, before=90, after=0)
# [2025-08-22 20:22:36] ===== LOAD SAMPLE + WEIGHTS =====
# [2025-08-22 20:22:36] [INFO] Repos in stratified sample: 255
# [2025-08-22 20:22:36] ===== INDEX LOCAL CONFIGS FOR YAML HINTS =====
# [2025-08-22 20:22:38] [INFO] Repos with any local files detected: 4519
# [2025-08-22 20:22:38] ===== FETCH & SCAN =====
# [2025-08-22 20:22:39] [1/255] ERR 2d-inc/developer_quest | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:22:39] [2/255] ERR aabhasr1/otpview | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 20:22:39] [3/255] ERR aarcangeli/serious-sam-android | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-22 20:23:09] [4/255] accrescent/accrescent | runs=60 | themes=0 | examples=0 | hints=0 | 29.7s
# [2025-08-22 20:23:30] [5/255] ERR adeekshith/watomatic | runs=40 | themes=0 | examples=0 | hints=1 | 20.8s
# [2025-08-22 20:23:30] [6/255] ERR agoda-com/ninjato | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:23:31] [7/255] aimardcr/apkkiller | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-22 20:23:32] [8/255] alexbatalov/fallout1-ce | runs=0 | themes=0 | examples=0 | hints=0 | 1.1s
# [2025-08-22 20:23:32] [9/255] ERR ali322/cnodern | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 20:23:40] [10/255] ERR allgood/opennotescanner | runs=0 | themes=0 | examples=0 | hints=1 | 8.1s
# [2025-08-22 20:23:42] [11/255] ERR alpha0010/react-native-pdf-viewer | runs=0 | themes=0 | examples=0 | hints=0 | 1.4s
# [2025-08-22 20:23:46] [12/255] amrdeveloper/linkhub | runs=8 | themes=0 | examples=0 | hints=1 | 4.4s
# [2025-08-22 20:23:47] [13/255] amrdeveloper/treeview | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:23:47] [14/255] ERR androidstarters/generator-android-mvp-starter | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:23:48] [15/255] ERR antoniy/gidder | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:23:48] [16/255] ERR appsci/sleeptimepicker | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:23:52] [17/255] arian04/android-hid-client | runs=1 | themes=2 | examples=2 | hints=2 | 4.0s
# [2025-08-22 20:24:07] [18/255] art-chen/miui-extra-yukiapi | runs=0 | themes=0 | examples=0 | hints=0 | 14.5s
# [2025-08-22 20:24:07] [19/255] ERR ashish-bansal/onetapvideodownload | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:24:08] [20/255] astubenbord/paperless-mobile | runs=0 | themes=0 | examples=0 | hints=1 | 1.2s
# [2025-08-22 20:25:07] [21/255] atsign-foundation/noports | runs=60 | themes=0 | examples=0 | hints=0 | 58.3s
# [2025-08-22 20:25:08] [22/255] avinashkranjan/friday | runs=0 | themes=0 | examples=0 | hints=0 | 1.7s
# [2025-08-22 20:25:09] [23/255] avishayil/react-native-restart | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-22 20:25:14] [24/255] awxkee/avif-coder | runs=7 | themes=0 | examples=0 | hints=1 | 4.4s
# [2025-08-22 20:25:14] [25/255] ERR ayaremin/panter-dialog | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:26:26] [26/255] azahar-emu/azahar | runs=60 | themes=0 | examples=0 | hints=1 | 72.1s
# [2025-08-22 20:26:27] [27/255] benceszasz/xdripcarelinkfollower | runs=0 | themes=0 | examples=0 | hints=4 | 0.5s
# [2025-08-22 20:26:27] [28/255] ERR benjamindean/flutter_vibration | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:26:32] [29/255] billthefarmer/gurgle | runs=8 | themes=0 | examples=0 | hints=0 | 4.7s
# [2025-08-22 20:26:32] [30/255] billthefarmer/scope | runs=0 | themes=0 | examples=0 | hints=0 | 0.7s
# [2025-08-22 20:26:38] [31/255] bitcoinppl/cove | runs=5 | themes=1 | examples=2 | hints=2 | 5.6s
# [2025-08-22 20:26:39] [32/255] blokadaorg/five-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 20:27:12] [33/255] breezy-weather/breezy-weather | runs=60 | themes=0 | examples=0 | hints=0 | 33.4s
# [2025-08-22 20:27:13] [34/255] bubelov/news | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:27:13] [35/255] ERR callstack/react-native-material-palette | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:27:14] [36/255] candlefinance/pow | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:27:20] [37/255] cbl-dart/cbl-dart | runs=2 | themes=1 | examples=2 | hints=3 | 6.0s
# [2025-08-22 20:27:20] [38/255] ERR ch4t4r/nebulo | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:27:20] [39/255] ERR chensiliang/rotatephotoview | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 20:27:32] [40/255] chenxiaolong/msd | runs=15 | themes=0 | examples=0 | hints=1 | 11.2s
# [2025-08-22 20:27:39] [41/255] ERR chrynan/serialization-parcelable | runs=11 | themes=0 | examples=0 | hints=1 | 7.7s
# [2025-08-22 20:27:40] [42/255] chunlee-thong/flutter_event_app | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:27:43] [43/255] ERR cloudinary/cloudinary_android | runs=2 | themes=1 | examples=2 | hints=5 | 3.5s
# [2025-08-22 20:29:07] [44/255] cocos/cocos-engine | runs=60 | themes=0 | examples=0 | hints=0 | 83.4s
# [2025-08-22 20:29:07] [45/255] ERR corphish/nightlight | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:29:08] [46/255] covidshield/mobile | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:29:38] [47/255] ERR crazy-marvin/metadataremover | runs=44 | themes=0 | examples=0 | hints=3 | 29.9s
# [2025-08-22 20:30:31] [48/255] d4rken-org/octi | runs=54 | themes=0 | examples=0 | hints=1 | 53.3s
# [2025-08-22 20:30:31] [49/255] dailystudio/devbricksx-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-22 20:30:32] [50/255] ERR danielmartinus/konfetti | runs=0 | themes=0 | examples=0 | hints=1 | 1.0s
# [2025-08-22 20:30:41] [51/255] datl4g/mimasu-extension | runs=10 | themes=0 | examples=0 | hints=0 | 8.7s
# [2025-08-22 20:31:16] [52/255] ERR defold/extender | runs=46 | themes=0 | examples=0 | hints=1 | 35.1s
# [2025-08-22 20:31:23] [53/255] ERR dev-aniketj/weatherapp-android | runs=11 | themes=0 | examples=0 | hints=1 | 6.5s
# [2025-08-22 20:31:25] [54/255] devtodollars/mvp-boilerplate | runs=0 | themes=0 | examples=0 | hints=0 | 2.0s
# [2025-08-22 20:31:26] [55/255] dlew/joda-time-android | runs=0 | themes=0 | examples=0 | hints=2 | 1.8s
# [2025-08-22 20:31:27] [56/255] ERR drbeef/lambda1vr | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 20:31:59] [57/255] droidworksstudio/easylauncher | runs=60 | themes=0 | examples=0 | hints=1 | 31.7s
# [2025-08-22 20:31:59] [58/255] ERR eddyverbruggen/nativescript-fingerprint-auth | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:32:00] [59/255] ERR eemp/netcastsoss | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:32:00] [60/255] ERR einsitang/sudoku-flutter | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:32:43] [61/255] ERR emanuele-f/pcapdroid | runs=57 | themes=0 | examples=0 | hints=0 | 42.9s
# [2025-08-22 20:32:43] [62/255] ERR epam/coroutinescache | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:32:44] [63/255] ERR escamoteur/inkinorx | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 20:32:44] [64/255] ERR f2prateek/rx-receivers | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:32:47] [65/255] f4uzan/hglauncher | runs=5 | themes=0 | examples=0 | hints=3 | 3.0s
# [2025-08-22 20:32:50] [66/255] faltenreich/diaguard | runs=1 | themes=1 | examples=3 | hints=2 | 3.3s
# [2025-08-22 20:32:51] [67/255] ERR fatangare/logcatviewer | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:33:05] [68/255] fate-grand-automata/fga | runs=22 | themes=1 | examples=2 | hints=1 | 14.1s
# [2025-08-22 20:33:05] [69/255] feelfreelinux/wykopmobilnyhybrid | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 20:33:07] [70/255] flutterkaigi/conference-app-2023 | runs=0 | themes=0 | examples=0 | hints=0 | 1.9s
# [2025-08-22 20:33:56] [71/255] fossasia/badgemagic-app | runs=60 | themes=0 | examples=0 | hints=0 | 48.4s
# [2025-08-22 20:33:56] [72/255] ERR fossasia/loklak_wok_android | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-22 20:33:57] [73/255] ERR futo-org/voice-input | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 20:34:17] [74/255] futuresdr/futuresdr | runs=7 | themes=0 | examples=0 | hints=1 | 20.5s
# [2025-08-22 20:34:17] [75/255] ERR gabrn/react-native-persistent-job | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:34:18] [76/255] ERR gaugesapp/gauges-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:34:18] [77/255] gerardpaligot/android-countdown | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-22 20:34:19] [78/255] getactivity/androidproject-kotlin | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:34:34] [79/255] ERR getstream/gemini-android | runs=0 | themes=0 | examples=0 | hints=0 | 14.9s
# [2025-08-22 20:34:35] [80/255] git-touch/highlight.dart | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-22 20:35:07] [81/255] grapheneos/pdfviewer | runs=60 | themes=0 | examples=0 | hints=0 | 31.8s
# [2025-08-22 20:35:07] [82/255] ERR gregallensworth/mobilemapstarter | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:35:08] [83/255] gs-ts/trackmypath | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-22 20:35:11] [84/255] guoxicheng/skip | runs=0 | themes=0 | examples=0 | hints=1 | 3.3s
# [2025-08-22 20:35:11] [85/255] ERR habibi07/imgeffects | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 20:35:12] [86/255] ERR hamidness/restring | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:35:28] [87/255] hamza417/inure | runs=28 | themes=0 | examples=0 | hints=2 | 16.9s
# [2025-08-22 20:35:30] [88/255] ERR hariagus/groceriesapp-compose | runs=0 | themes=0 | examples=0 | hints=1 | 1.0s
# [2025-08-22 20:35:30] [89/255] haroldadmin/moonshot | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-22 20:35:32] [90/255] hash-studios/prism | runs=1 | themes=0 | examples=0 | hints=0 | 1.7s
# [2025-08-22 20:36:09] [91/255] hieuwu/android-groceries-store | runs=60 | themes=0 | examples=0 | hints=1 | 37.3s
# [2025-08-22 20:36:09] [92/255] ERR hitherejoe/bourbon | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:36:10] [93/255] ERR hotchemi/progressmenuitem | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:36:10] [94/255] ERR hummatli/androidappupdater | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:36:49] [95/255] hushenghao/androideastereggs | runs=60 | themes=0 | examples=0 | hints=1 | 38.4s
# [2025-08-22 20:36:49] [96/255] ERR icasdri/mather | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:36:50] [97/255] ichenhe/wear-gallery | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-22 20:36:53] [98/255] icylian/mdpings | runs=2 | themes=1 | examples=2 | hints=1 | 3.2s
# [2025-08-22 20:36:54] [99/255] interrupt/delverengine | runs=0 | themes=0 | examples=0 | hints=1 | 1.2s
# [2025-08-22 20:39:57] [100/255] ERR interstellar-app/interstellar | runs=60 | themes=0 | examples=0 | hints=0 | 182.9s
# [2025-08-22 20:40:27] [101/255] ipfs-shipyard/gomobile-ipfs | runs=60 | themes=0 | examples=0 | hints=6 | 30.2s
# [2025-08-22 20:40:56] [102/255] ippclub/dora-ssr | runs=60 | themes=0 | examples=0 | hints=1 | 29.0s
# [2025-08-22 20:40:58] [103/255] itscalebjones/spacelaunchnow-android | runs=0 | themes=0 | examples=0 | hints=1 | 2.1s
# [2025-08-22 20:40:59] [104/255] ERR iyegoroff/react-native-collapsible-header-views | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:40:59] [105/255] ERR jakewharton/hugo | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 20:40:59] [106/255] ERR jakubkinst/android-viewmodelbinding | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:41:29] [107/255] jamsch/expo-speech-recognition | runs=60 | themes=0 | examples=0 | hints=1 | 29.5s
# [2025-08-22 20:42:56] [108/255] ERR jarnedemeulemeester/findroid | runs=47 | themes=0 | examples=0 | hints=0 | 86.7s
# [2025-08-22 20:42:56] [109/255] javierpe/artgallery | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:42:57] [110/255] ERR jdamcd/material-sudoku | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 20:43:39] [111/255] jellyfin/jellyfin-androidtv | runs=60 | themes=0 | examples=0 | hints=0 | 42.3s
# [2025-08-22 20:44:08] [112/255] jenly1314/imageviewer | runs=60 | themes=0 | examples=0 | hints=2 | 29.2s
# [2025-08-22 20:44:09] [113/255] jerichoi224/nothing-gallery | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-22 20:44:13] [114/255] jiotv-go/jiotv_go_app | runs=6 | themes=0 | examples=0 | hints=1 | 4.2s
# [2025-08-22 20:44:52] [115/255] joelittlejohn/jsonschema2pojo | runs=60 | themes=0 | examples=0 | hints=0 | 38.5s
# [2025-08-22 20:44:52] [116/255] ERR johnjohndoe/typedpreferences | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:44:53] [117/255] ERR jonasoreland/runnerup | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:44:54] [118/255] kasukusakura/mirai-login-solver-sakura | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:44:54] [119/255] kaustubhpatange/gear-vpn | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-22 20:44:55] [120/255] kiarc/sobriety | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:44:56] [121/255] klarna-incubator/platform-colors | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-22 20:44:58] [122/255] ERR kvnp/youtune | runs=0 | themes=0 | examples=0 | hints=0 | 2.0s
# [2025-08-22 20:45:00] [123/255] ERR kyujin-cho/pixel-volte-patch | runs=0 | themes=0 | examples=0 | hints=1 | 1.8s
# [2025-08-22 20:45:01] [124/255] lawnchairlauncher/lawnfeed | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-22 20:45:45] [125/255] leboncoin/spark-android | runs=60 | themes=0 | examples=0 | hints=1 | 44.7s
# [2025-08-22 20:45:46] [126/255] leetomlee123/book | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-22 20:45:52] [127/255] lhns/restic-android | runs=0 | themes=0 | examples=0 | hints=2 | 6.1s
# [2025-08-22 20:45:52] [128/255] ERR lianyagang/flutter_swiper_null_safety | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 20:45:53] [129/255] ERR liaohuqiu/android-cube-app | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-22 20:46:25] [130/255] libpd/pd-for-android | runs=60 | themes=0 | examples=0 | hints=0 | 32.3s
# [2025-08-22 20:46:29] [131/255] ligi/gobandroid | runs=5 | themes=0 | examples=0 | hints=1 | 3.7s
# [2025-08-22 20:46:30] [132/255] lizongying/my-tv-1 | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-22 20:47:02] [133/255] ERR lorenzovngl/foodexpirationdates | runs=60 | themes=0 | examples=0 | hints=1 | 32.5s
# [2025-08-22 20:47:05] [134/255] lxpio/omnigram | runs=0 | themes=0 | examples=0 | hints=0 | 2.5s
# [2025-08-22 20:47:05] [135/255] ERR lynxitdigital/geoencoding | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:47:17] [136/255] ERR mahmud0808/colorblendr | runs=14 | themes=0 | examples=0 | hints=1 | 12.1s
# [2025-08-22 20:47:36] [137/255] ERR maikub/flutter_appauth | runs=17 | themes=0 | examples=0 | hints=0 | 19.2s
# [2025-08-22 20:47:38] [138/255] marshalx/tgcalls | runs=0 | themes=0 | examples=0 | hints=1 | 2.0s
# [2025-08-22 20:48:27] [139/255] mechakotik/tails-adventure | runs=60 | themes=0 | examples=0 | hints=0 | 49.2s
# [2025-08-22 20:48:28] [140/255] medic/cht-gateway | runs=0 | themes=0 | examples=0 | hints=4 | 0.8s
# [2025-08-22 20:48:29] [141/255] ERR mholtkamp/octave | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:48:30] [142/255] mi-g-alex/telegram-monet | runs=1 | themes=0 | examples=0 | hints=0 | 1.5s
# [2025-08-22 20:48:31] [143/255] ERR microg/nominatimgeocoderbackend | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:48:31] [144/255] mikepenz/android-iconics | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-22 20:48:37] [145/255] minikin/popover | runs=0 | themes=0 | examples=0 | hints=0 | 6.0s
# [2025-08-22 20:48:38] [146/255] mishkun/puerh | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 20:49:10] [147/255] ERR mlcommons/mobile_app_open | runs=34 | themes=1 | examples=2 | hints=3 | 32.4s
# [2025-08-22 20:49:12] [148/255] mneuroth/sciteqt | runs=0 | themes=0 | examples=0 | hints=0 | 1.3s
# [2025-08-22 20:49:58] [149/255] mym0404/react-native-naver-map | runs=60 | themes=0 | examples=0 | hints=0 | 46.2s
# [2025-08-22 20:49:58] [150/255] ERR mysteriumnetwork/mysterium-vpn-mobile | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 20:49:59] [151/255] ERR nanbox/parallaxrecyclerview | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 20:49:59] [152/255] ERR nbsp-team/materialfilepicker | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:52:20] [153/255] nextcloud/android | runs=6 | themes=1 | examples=3 | hints=4 | 140.7s
# [2025-08-22 20:52:21] [154/255] niuhuan/jasmine | runs=0 | themes=0 | examples=0 | hints=0 | 1.1s
# [2025-08-22 20:52:24] [155/255] nocrypt/migu | runs=0 | themes=0 | examples=0 | hints=1 | 3.4s
# [2025-08-22 20:52:25] [156/255] nordicsemiconductor/android-nrf-blinky | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-22 20:52:28] [157/255] nspire-emus/firebird | runs=0 | themes=0 | examples=0 | hints=0 | 3.0s
# [2025-08-22 20:52:30] [158/255] oatmealdome/dolphin-ios | runs=0 | themes=0 | examples=0 | hints=1 | 1.7s
# [2025-08-22 20:52:31] [159/255] oleur/mistral-ai-kmp | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 20:52:34] [160/255] omnioneid/did-ca-aos | runs=3 | themes=1 | examples=2 | hints=1 | 3.6s
# [2025-08-22 20:52:36] [161/255] onlyoffice/documents-app-android | runs=2 | themes=0 | examples=0 | hints=1 | 2.0s
# [2025-08-22 20:52:37] [162/255] onseok/peekaboo | runs=0 | themes=0 | examples=0 | hints=1 | 1.0s
# [2025-08-22 20:53:09] [163/255] opentracksapp/osmdashboard | runs=60 | themes=0 | examples=0 | hints=1 | 31.7s
# [2025-08-22 20:53:13] [164/255] osfans/trime | runs=2 | themes=1 | examples=2 | hints=1 | 3.7s
# [2025-08-22 20:53:50] [165/255] osmandapp/osmand | runs=60 | themes=0 | examples=0 | hints=2 | 37.6s
# [2025-08-22 20:53:59] [166/255] owntracks/android | runs=6 | themes=1 | examples=2 | hints=3 | 9.0s
# [2025-08-22 20:54:00] [167/255] parabox-app/parabox | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 20:54:00] [168/255] passwdapp/passwd | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 20:54:03] [169/255] ERR patch4code/logline | runs=0 | themes=0 | examples=0 | hints=1 | 2.1s
# [2025-08-22 20:54:04] [170/255] ERR paypal/selion | runs=0 | themes=0 | examples=0 | hints=0 | 1.5s
# [2025-08-22 20:54:09] [171/255] pilot51/voicenotify | runs=4 | themes=0 | examples=0 | hints=0 | 4.7s
# [2025-08-22 20:54:10] [172/255] pipelka/robotv | runs=0 | themes=0 | examples=0 | hints=2 | 0.8s
# [2025-08-22 20:54:23] [173/255] promops/flutter_pretty_qr | runs=22 | themes=0 | examples=0 | hints=0 | 13.8s
# [2025-08-22 20:54:24] [174/255] ERR punchthrough/ble-starter-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 20:55:15] [175/255] ERR qdsfdhvh/compose-imageloader | runs=24 | themes=0 | examples=0 | hints=1 | 50.9s
# [2025-08-22 20:55:49] [176/255] quantumphysique/trale | runs=60 | themes=0 | examples=0 | hints=0 | 33.9s
# [2025-08-22 20:55:52] [177/255] raamcosta/compose-destinations | runs=0 | themes=0 | examples=0 | hints=0 | 2.9s
# [2025-08-22 21:05:41] [178/255] ERR redot-engine/redot-engine | runs=60 | themes=0 | examples=0 | hints=0 | 589.7s
# [2025-08-22 21:05:42] [179/255] ERR redsolution/xabber-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:05:42] [180/255] ERR reinterpretcat/utymap | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:05:43] [181/255] ERR richardradics/rxandroidbootstrap | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:05:43] [182/255] rock3r/uplift | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-22 21:05:44] [183/255] ERR rockyqu/logg | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:05:50] [184/255] ERR rodrigmatrix/weather-you | runs=9 | themes=0 | examples=0 | hints=1 | 6.2s
# [2025-08-22 21:05:50] [185/255] ERR rohanoid5/muzesto | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 21:05:51] [186/255] rookietree/damaihelper | runs=0 | themes=0 | examples=0 | hints=0 | 0.7s
# [2025-08-22 21:05:54] [187/255] runningcode/fladle | runs=1 | themes=1 | examples=3 | hints=1 | 3.1s
# [2025-08-22 21:05:55] [188/255] ruskakimov/mooltik | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-22 21:05:56] [189/255] sail-tunnel/sail | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-22 21:06:26] [190/255] samolego/canta | runs=60 | themes=0 | examples=0 | hints=1 | 30.4s
# [2025-08-22 21:06:26] [191/255] ERR seatgeek/android-placesautocompletetextview | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:06:27] [192/255] ERR semperchen/novelapp | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:06:32] [193/255] servo/surfman | runs=1 | themes=1 | examples=3 | hints=2 | 5.1s
# [2025-08-22 21:06:33] [194/255] shadow60539/club_penguin_game | runs=0 | themes=0 | examples=0 | hints=0 | 0.7s
# [2025-08-22 21:06:33] [195/255] ERR shadyboukhary/axion-technologies-hnh | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:06:34] [196/255] shashank02051997/anywheregpt-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-22 21:07:07] [197/255] simformsolutionspvtltd/flutter_showcaseview | runs=60 | themes=0 | examples=0 | hints=1 | 32.9s
# [2025-08-22 21:07:07] [198/255] ERR sivenwu/waveview | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-22 21:07:12] [199/255] ERR skydoves/sealedx | runs=0 | themes=0 | examples=0 | hints=0 | 5.0s
# [2025-08-22 21:07:13] [200/255] smartpack/smartpack-kernel-manager | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-22 21:07:15] [201/255] snapchat/camera-kit-react-native | runs=0 | themes=0 | examples=0 | hints=0 | 2.0s
# [2025-08-22 21:07:46] [202/255] solsynth/solian | runs=21 | themes=0 | examples=0 | hints=0 | 31.9s
# [2025-08-22 21:07:47] [203/255] ERR sparker0i/weather | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 21:07:59] [204/255] square/okhttp | runs=3 | themes=1 | examples=3 | hints=3 | 12.5s
# [2025-08-22 21:08:36] [205/255] streetcomplete/streetcomplete | runs=60 | themes=0 | examples=0 | hints=3 | 36.4s
# [2025-08-22 21:09:44] [206/255] ERR sunarya-thito/shadcn_flutter | runs=31 | themes=0 | examples=0 | hints=0 | 68.4s
# [2025-08-22 21:09:45] [207/255] ERR sunilpaulmathew/translator | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-22 21:09:46] [208/255] ERR sunnyapp/flutter_contact | runs=1 | themes=0 | examples=0 | hints=0 | 1.2s
# [2025-08-22 21:10:34] [209/255] supabase-community/supabase-kt | runs=60 | themes=0 | examples=0 | hints=0 | 47.4s
# [2025-08-22 21:10:35] [210/255] syncfusionexamples/scheduling-events-flutter-calendar | runs=0 | themes=0 | examples=0 | hints=0 | 1.2s
# [2025-08-22 21:10:36] [211/255] ERR tachibanagenerallaboratories/download-navi | runs=0 | themes=0 | examples=0 | hints=2 | 1.8s
# [2025-08-22 21:10:51] [212/255] tahaak67/showcaselayoutcompose | runs=24 | themes=0 | examples=0 | hints=1 | 15.0s
# [2025-08-22 21:10:52] [213/255] tainzhi/videoplayer | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 21:10:56] [214/255] takahirom/rin | runs=0 | themes=0 | examples=0 | hints=2 | 3.7s
# [2025-08-22 21:11:30] [215/255] talaodao/altme | runs=60 | themes=0 | examples=0 | hints=0 | 34.3s
# [2025-08-22 21:11:50] [216/255] ERR talsec/free-rasp-flutter | runs=23 | themes=0 | examples=0 | hints=0 | 20.4s
# [2025-08-22 21:11:57] [217/255] teambtcmap/btcmap-android | runs=5 | themes=0 | examples=0 | hints=0 | 6.6s
# [2025-08-22 21:11:58] [218/255] tensorflow/flutter-tflite | runs=0 | themes=0 | examples=0 | hints=0 | 1.3s
# [2025-08-22 21:12:00] [219/255] tharunbirla/fetchit | runs=0 | themes=0 | examples=0 | hints=1 | 1.5s
# [2025-08-22 21:12:00] [220/255] thekaailashsharma/shortsclone | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-22 21:12:01] [221/255] ERR thinkive/webapp | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:12:01] [222/255] ERR thothbot/parallax | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:12:55] [223/255] thu-info-community/thu-info-app | runs=60 | themes=0 | examples=0 | hints=0 | 54.1s
# [2025-08-22 21:12:56] [224/255] ERR todou/nestrefresh | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-22 21:12:56] [225/255] ERR tonnyl/mango | runs=0 | themes=0 | examples=0 | hints=2 | 0.5s
# [2025-08-22 21:12:57] [226/255] ERR trikita/talalarmo | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:12:57] [227/255] ERR trojan295/android-webauthn-token | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-22 21:26:41] [228/255] tunjid/heron | runs=53 | themes=0 | examples=0 | hints=0 | 823.8s
# [2025-08-22 21:26:44] [229/255] twireapp/twire | runs=1 | themes=1 | examples=3 | hints=3 | 2.9s
# [2025-08-22 21:26:52] [230/255] ERR tylerbwong/stack | runs=11 | themes=0 | examples=0 | hints=2 | 8.5s
# [2025-08-22 21:26:53] [231/255] ERR uiters/store-pattern | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 21:26:53] [232/255] ERR vpaliy/android-music-app | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:26:54] [233/255] ERR weidongjian/androidwheelview | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:26:54] [234/255] wenet-e2e/wetts | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 21:26:55] [235/255] ERR whataa/nodrawable | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:26:55] [236/255] widgetbakery/pixel_snap | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-22 21:26:56] [237/255] ERR wiinputmethod/ve | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:43:27] [238/255] ERR wikimedia/apps-android-wikipedia | runs=0 | themes=0 | examples=0 | hints=2 | 990.9s
# [2025-08-22 21:43:27] [239/255] ERR wseemann/ffmpegmediaplayer | runs=0 | themes=0 | examples=0 | hints=3 | 0.7s
# [2025-08-22 21:43:28] [240/255] ERR wshunli/arcgis-android-tianditu | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-22 21:43:35] [241/255] ERR wstxda/google-shortcuts-launcher | runs=7 | themes=0 | examples=0 | hints=0 | 7.6s
# [2025-08-22 21:43:36] [242/255] ERR wujingchao/multicardmenu | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-22 21:43:36] [243/255] ERR xcodebuild/recyclerviewswipedismiss | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-22 21:43:37] [244/255] ERR xgfe/react-native-ui-xg | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-22 21:44:11] [245/255] ERR xiaojieonly/ehviewer_cn_sxj | runs=52 | themes=0 | examples=0 | hints=0 | 34.5s
# [2025-08-22 21:44:12] [246/255] ERR xudaojie/multistateview | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-22 21:44:14] [247/255] ERR xxfast/nytimes-kmp | runs=0 | themes=0 | examples=0 | hints=0 | 2.1s
# [2025-08-22 21:44:15] [248/255] yaoxieyoulei/mytv-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-22 21:44:29] [249/255] yarosmallorca/dji-mapper | runs=17 | themes=0 | examples=0 | hints=0 | 14.7s
# [2025-08-22 21:44:31] [250/255] ERR yukuku/androidbible | runs=0 | themes=0 | examples=0 | hints=1 | 1.6s
# [2025-08-22 21:45:08] [251/255] ERR yuriykulikov/alarmclock | runs=60 | themes=0 | examples=0 | hints=5 | 37.5s
# [2025-08-22 21:45:09] [252/255] ERR yuyakaido/cardstackview | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-22 21:45:16] [253/255] zakgof/korender | runs=10 | themes=0 | examples=0 | hints=0 | 7.1s
# [2025-08-22 21:45:36] [254/255] zeshuaro/appainter | runs=17 | themes=1 | examples=2 | hints=0 | 19.9s
# [2025-08-22 21:46:44] [255/255] ERR zonble/flutter_platform_alert | runs=51 | themes=0 | examples=0 | hints=0 | 68.0s
# [2025-08-22 21:46:44] ===== DONE =====
# [2025-08-22 21:46:44] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_counts_weighted_high_only.csv
# [2025-08-22 21:46:44] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_counts_by_provider_weighted_high_only.csv
# [2025-08-22 21:46:44] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_examples_high_only.csv
# [2025-08-22 21:46:44] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_run_audit_high_only.csv
# [2025-08-22 21:46:44] SUMMARY: repos=255 | total_runs_fetched=2898 | repos_with_any_hits=17 | elapsed=5048.3s
