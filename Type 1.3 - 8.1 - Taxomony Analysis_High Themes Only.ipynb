# %%
"""
High/Medium/Low CI Theme Miner for Android Instrumentation (LOG FETCH + STRATUM GATING)
--------------------------------------------------------------------------------------
What this script does
- Reads your stratified sample (html_url + stratum) and strict weights from cohort_table.csv.
- Fetches GitHub Actions logs (token rotation, backoff) within a time window aligned to your snapshot.
- Scans logs for High/Medium/Low themes, but:
  * High themes always counted.
  * Medium/Low are only counted if the repo has instrumentation context based on STRATUM (Y/B/A).
    - De-noising for Med/Low: require >=2 matching lines OR hits in >=2 runs.
- Collects YAML hints (remote workflows + local configs) for audit context only (not gating).
- Outputs weighted counts, by-provider breakdown, examples, and an audit table.

Your key adjustments included:
1) Trust STRATUM (Y/B/A) for instrumentation context gating instead of YAML hints.
2) Expand log search period to 90 days BEFORE clone date (no drift after clone date).
3) Keep progress logs, early-stop, and token rotation.

Outputs (saved in OUT_DIR):
  - challenge_counts_weighted_high_only.csv
  - challenge_counts_by_provider_weighted_high_only.csv
  - challenge_examples_high_only.csv
  - challenge_run_audit_high_only.csv
"""

import os, re, io, zipfile, json, time, random
from pathlib import Path
import pandas as pd
import numpy as np
from datetime import datetime, time as dtime, timedelta, timezone

# ======================= CONFIG =======================
CONFIG_DIR        = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\All_Config_Files")
SAMPLED_CSV_DIR   = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\Stratified Sample")
SAMPLED_CSV_NAME  = "stratified_sample_moe10.csv"   # <<— use this exact file
COHORT_FILE_NAME  = "cohort_table.csv"
OUT_DIR           = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis")


# Tokens env file (both casings tried)
TOKENS_ENV_PATH   = Path(r"C:\GitHub\Android-Mobile-Apps\all_tokens.env")
if not TOKENS_ENV_PATH.exists():
    TOKENS_ENV_PATH = Path(r"C:\GitHub\Android-Mobile-Apps\All_Tokens.env")

# Remote fetch controls
ENABLE_GITHUB_FETCH = True
MAX_RUNS_PER_REPO   = 60       # ↑ coverage
REQUEST_TIMEOUT     = 30
REQUESTS_MAX_RETRIES= 3
BACKOFF_BASE_SEC    = 2.0

# Early stop: stop scanning more runs for a repo once a hit is confirmed
EARLY_STOP_ON_HIT = True
EARLY_STOP_MODE   = "any"      # "any" (high/med/low) or "high-only"

# Time window around clone date (align logs to snapshot)
USE_CUTOFF          = True
CLONE_DATE_LOCAL    = "2025-08-10"   # your clone date
WINDOW_DAYS_BEFORE  = 90             # include logs up to 90 days BEFORE clone date
WINDOW_DAYS_AFTER   = 0              # keep 0 to avoid drift after snapshot
LOCAL_TZ            = "America/Toronto"

# Progress logging
VERBOSE = True
PROGRESS_EVERY = 1
SHOW_HIT_SNIPPET_COUNT = True

# ======================= THEMES =======================
THEMES = {
  # High (hard runtime failures, always counted)
  "EMULATOR_BOOT_TIMEOUT": ["device offline", "boot completed timeout", "emulator: ERROR", "emulator: Panic", "Adb connection refused"],
  "HW_ACCEL/KVM_MISSING": ["/dev/kvm permission denied", "KVM is required", "accel not installed", "HAXM is not installed", "Hypervisor.framework is required"],
  "MISSING_EMULATOR_BIN": ["emulator: not found", "No emulator installed"],
  "ADB_ISSUE": ["ADB server didn't ACK", "ADB server version mismatch", "error: device offline", "more than one device/emulator"],
  "X11/HEADLESS": ["xvfb-run: error", "Cannot open display", "DISPLAY not set"],
  "VENDOR_LAB_QUOTA": ["Quota exceeded", "Billing account not configured", "insufficient tokens for"],

  # Medium (config/setup + infra)
  "SDK_LICENSES": ["You have not accepted the license agreements", "licenses not accepted", "SDK licenses not accepted"],
  "IMAGE_NOT_FOUND": [r"Package .* was not found", r"failed to find target with hash string", r"system-images;android-\d+.*not found"],
  "JAVA/GRADLE/AGP_VERSION_DRIFT": ["Minimum supported Gradle is", "This version of the Android Gradle plugin requires", "Unsupported Java", "Kotlin version .* is not compatible"],
  "ANDROIDX_TEST_MISMATCH": ["Could not resolve androidx.test", "Duplicate class .* found in modules", "conflict with dependency 'androidx.test'"],
  "NETWORK_FLAKE": ["Connection reset by peer", "TLS handshake timeout", "temporary failure in name resolution", "network is unreachable"],
  "SECRETS_PERMS": ["Permission denied", "No such file or directory .*keystore", "secrets.* not set", "Missing .* environment variable"],
  "GENERIC_TIMEOUT/CANCEL": ["job timed out", "The operation was canceled", "timeout exceeded"],

  # Low (weak signals)
  "TEST_FLAKY_SIGNAL": [r"Flaky", r"retrying test", r"java\.lang\.AssertionError", r"org\.junit\.ComparisonFailure"],
}

HIGH_THEMES   = {"EMULATOR_BOOT_TIMEOUT","HW_ACCEL/KVM_MISSING","MISSING_EMULATOR_BIN","ADB_ISSUE","X11/HEADLESS","VENDOR_LAB_QUOTA"}
MEDIUM_THEMES = {"SDK_LICENSES","IMAGE_NOT_FOUND","JAVA/GRADLE/AGP_VERSION_DRIFT","ANDROIDX_TEST_MISMATCH","NETWORK_FLAKE","SECRETS_PERMS","GENERIC_TIMEOUT/CANCEL"}
LOW_THEMES    = {"TEST_FLAKY_SIGNAL"}

# Medium/Low de-noising + gating
INCLUDE_MEDIUM = True
INCLUDE_LOW    = True
MEDLOW_MIN_LINE_HITS     = 2   # >=2 matching lines ...
MEDLOW_MIN_RUNS_WITH_HIT = 2   # ... OR hits in >=2 runs
# GATING SOURCE: STRATUM ONLY (Y/B/A)
# YAML hints are collected for context but NOT used to gate Medium/Low.

# Simple YAML hints (for audit context only)
YAML_HINTS = [
    "reactivecircus/android-emulator-runner",
    "sdkmanager",
    "avdmanager",
    "emulator -avd",
    "gcloud firebase test android run",
    "adb", "androidTest", "connectedAndroidTest"
]
TEXT_EXTS = {".yml",".yaml",".log",".txt",".json",".xml",".gradle",".kts",".properties",".sh",".bat",".cfg",".conf",".ini",".md"}

# ======================= HELPERS =======================
def ts(): return datetime.now().strftime("%Y-%m-%d %H:%M:%S")
def banner(msg):   print(f"[{ts()}] ===== {msg} =====", flush=True) if VERBOSE else None
def note(msg):     print(f"[{ts()}] {msg}", flush=True)
def warn(msg):     print(f"[{ts()}] [WARN] {msg}", flush=True)
def info(msg):     print(f"[{ts()}] [INFO] {msg}", flush=True)

def load_tokens_from_env_file(path: Path) -> list:
    tokens = {}
    if path and path.exists():
        for raw in path.read_text(encoding="utf-8", errors="ignore").splitlines():
            line = raw.strip()
            if not line or line.startswith(("#",";")) or "=" not in line:
                continue
            k, v = line.split("=", 1)
            k, v = k.strip(), v.strip().strip('"').strip("'")
            if k.upper().startswith("GITHUB_TOKEN_"):
                try: idx = int(k.split("_")[-1])
                except Exception: idx = 999
                tokens[idx] = v
    return [tokens[i] for i in sorted(tokens.keys()) if tokens[i]]

class TokenRotator:
    def __init__(self, tokens: list[str]): self.tokens, self.i = (tokens or []), 0
    def current(self): return (self.tokens[self.i] if self.tokens else None)
    def rotate(self): 
        if self.tokens: self.i = (self.i + 1) % len(self.tokens)
    def headers(self, allow_auth=True):
        base = {"Accept":"application/vnd.github+json","User-Agent":"challenge-miner/high-med-low/1.0"}
        tok = self.current()
        if allow_auth and tok: base["Authorization"] = f"Bearer {tok}"
        return base

def gh_get(url, rot: TokenRotator, allow_auth=True, timeout=REQUEST_TIMEOUT):
    import requests
    tries = 0
    while True:
        tries += 1
        resp = requests.get(url, headers=rot.headers(allow_auth=allow_auth), timeout=timeout)
        diag = {"status": resp.status_code, "rate_remaining": resp.headers.get("X-RateLimit-Remaining"),
                "rate_reset": resp.headers.get("X-RateLimit-Reset"), "message": None}
        try:
            j = resp.json()
            if isinstance(j, dict) and "message" in j: diag["message"] = j["message"]
        except Exception: pass
        resp._diag = diag

        if resp.status_code in (200,201,204): return resp
        if resp.status_code in (403,429):
            warn(f"Rate/403 on {url}. Rotating token. Diag={diag}")
            rot.rotate()
            if tries >= REQUESTS_MAX_RETRIES * max(1, len(rot.tokens)): return resp
            sleep_s = BACKOFF_BASE_SEC * (2 ** (tries-1)) + random.random()
            time.sleep(min(sleep_s, 30)); continue
        if resp.status_code == 401 and allow_auth:
            return gh_get(url, rot, allow_auth=False, timeout=timeout)
        return resp

def owner_repo_from_url(url: str):
    try:
        u = (url or "").strip().strip("/")
        if "github.com/" in u:
            tail = u.split("github.com/", 1)[1].strip("/")
            parts = tail.split("/")
            if len(parts) >= 2: return parts[0].lower(), parts[1].lower()
    except Exception: pass
    return None, None

def full_name_from_html_url(url: str) -> str | None:
    o, r = owner_repo_from_url(url); return f"{o}/{r}" if (o and r) else None

def full_name_from_saved_filename(path: Path) -> str | None:
    base = path.name
    m = re.match(r"^([A-Za-z0-9_.-]+)\.([A-Za-z0-9_.-]+)__", base)
    if m:
        owner, repo = m.group(1), m.group(2)
        return f"{owner.replace(' ','').lower()}/{repo.replace(' ','').lower()}"
    return None

# ---- time window helpers ----
try:
    from zoneinfo import ZoneInfo
except Exception:
    ZoneInfo = None

def parse_gh_ts(ts: str):
    if not ts: return None
    try: return datetime.strptime(ts, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)
    except Exception: return None

def window_utc_from_local(center_date_str: str, days_before: int, days_after: int, tz_name: str):
    try:
        center = datetime.strptime(center_date_str, "%Y-%m-%d").date()
    except Exception:
        return (None, None, True)
    start_date = center - timedelta(days=days_before)
    end_date   = center + timedelta(days=days_after)
    if ZoneInfo is None:
        # fallback: compare by DATE only
        return (start_date, end_date, True)
    tz = ZoneInfo(tz_name)
    start_local = datetime.combine(start_date, dtime(0,0,0)).replace(tzinfo=tz)
    end_local   = datetime.combine(end_date,   dtime(23,59,59)).replace(tzinfo=tz)
    return (start_local.astimezone(timezone.utc), end_local.astimezone(timezone.utc), False)

# ======================= REMOTE FETCH =======================
def list_workflow_runs(rot: TokenRotator, owner: str, repo: str, page: int, per_page: int = 100):
    return gh_get(f"https://api.github.com/repos/{owner}/{repo}/actions/runs?per_page={per_page}&page={page}",
                  rot, allow_auth=True)

def fetch_log_text_for_run(rot: TokenRotator, logs_url: str):
    resp = gh_get(logs_url, rot, allow_auth=True)
    if resp.status_code != 200: return None, resp._diag
    try:
        zf = zipfile.ZipFile(io.BytesIO(resp.content))
    except zipfile.BadZipFile:
        return None, resp._diag
    texts = []
    for name in zf.namelist():
        try:
            with zf.open(name) as f:
                texts.append(f.read().decode("utf-8", errors="ignore"))
        except Exception:
            continue
    return "\n".join(texts), None

def fetch_workflow_yamls(rot: TokenRotator, owner: str, repo: str):
    """Context only (not gating)."""
    yamls, err = [], None
    r = gh_get(f"https://api.github.com/repos/{owner}/{repo}/contents/.github/workflows", rot, allow_auth=True)
    if r.status_code == 200:
        for item in r.json():
            if item.get("type") == "file" and item.get("name", "").lower().endswith((".yml",".yaml")):
                raw_url = item.get("download_url")
                if not raw_url: continue
                fr = gh_get(raw_url, rot, allow_auth=True)
                if fr.status_code == 200: yamls.append(fr.text)
    else:
        err = r._diag
    return "\n".join(yamls), err

# ======================= SCANNING =======================
PAT_MAP = {k: [re.compile(p, re.I) for p in v] for k, v in THEMES.items()}

def scan_text_for_themes(text: str):
    """
    Returns:
      - found: list of themes that matched at least one line
      - hits:  list of (theme, line) for each matching line (truncated to 500 chars)
    """
    found, hits = set(), []
    if not text: return [], []
    for theme, regs in PAT_MAP.items():
        for line in text.splitlines():
            for rx in regs:
                if rx.search(line):
                    found.add(theme)
                    hits.append((theme, line[:500]))
                    break
            if theme in found:
                # continue scanning other themes; we still collect per-line hits for Med/Low de-noising
                continue
    return list(found), hits

def scan_yaml_hints(text: str):
    L = (text or "").lower()
    return [h for h in YAML_HINTS if h.lower() in L]

# ---------- STRATUM-BASED GATING ----------
STRATUM_RX = re.compile(r"^Y([01])_B([01])_A([01])$")

def parse_stratum_bits(s: str) -> tuple[int,int,int]:
    if not isinstance(s, str):
        return (0,0,0)
    m = STRATUM_RX.match(s.strip())
    if not m:
        return (0,0,0)
    return (int(m.group(1)), int(m.group(2)), int(m.group(3)))

def has_instru_context_from_stratum(stratum: str, at_pred: int | None = None) -> bool:
    y, b, a = parse_stratum_bits(stratum)
    if (y == 1) or (b == 1) or (a == 1):
        return True
    return bool(int(at_pred or 0) == 1)

# ========== Med/Low de-noising rule ==========
def _theme_counts_as_hit(theme: str, theme_line_hits: dict, theme_run_ids: dict, high: bool=False) -> bool:
    """
    High themes: any single hit counts.
    Medium/Low: require >= MEDLOW_MIN_LINE_HITS (line-level matches) OR
                >= MEDLOW_MIN_RUNS_WITH_HIT (distinct runs with a match).
    """
    if theme not in theme_line_hits and theme not in theme_run_ids:
        return False
    if (high or theme in HIGH_THEMES):
        return (theme_line_hits.get(theme, 0) >= 1)
    # Med/Low rule:
    line_hits = theme_line_hits.get(theme, 0)
    run_hits  = len(theme_run_ids.get(theme, set()))
    return (line_hits >= MEDLOW_MIN_LINE_HITS) or (run_hits >= MEDLOW_MIN_RUNS_WITH_HIT)

# ======================= DATA LOADING =======================
def auto_pick_stratified_csv(folder: Path) -> Path:
    cands = sorted([p for p in folder.glob("*.csv") if "stratified" in p.name.lower()])
    if not cands:
        cands = sorted(folder.glob("*.csv"))
    if not cands:
        raise FileNotFoundError(f"No CSV found in {folder}")
    return cands[0]

def load_sample_and_weights(folder: Path, sample_name: str | None, cohort_name: str) -> pd.DataFrame:
    # Sample
    samp_path = (folder / sample_name) if sample_name else auto_pick_stratified_csv(folder)
    sample = pd.read_csv(samp_path)

    if "html_url" not in sample.columns:
        for alt in ["url","repo_url","html_urls","html"]:
            if alt in sample.columns:
                sample = sample.rename(columns={alt:"html_url"}); break
    if "stratum" not in sample.columns:
        for alt in ["Stratum","strata","group"]:
            if alt in sample.columns:
                sample = sample.rename(columns={alt:"stratum"}); break
    if "html_url" not in sample.columns or "stratum" not in sample.columns:
        raise ValueError("Sample CSV must include 'html_url' and 'stratum' columns.")

    sample["full_name"] = sample["html_url"].apply(full_name_from_html_url)

    # Keep AT_pred if present; else 0
    if "AT_pred" not in sample.columns:
        sample["AT_pred"] = 0

    # Cohort (strict)
    cohort_path = folder / cohort_name
    if cohort_name.lower() != "cohort_table.csv":
        raise ValueError("COHORT_FILE_NAME must be 'cohort_table.csv'.")
    if not cohort_path.exists():
        raise FileNotFoundError(f"Required cohort table not found: {cohort_path}")

    cohort = pd.read_csv(cohort_path)
    if "stratum" not in cohort.columns:
        for alt in ["Stratum","strata","group"]:
            if alt in cohort.columns:
                cohort = cohort.rename(columns={alt:"stratum"}); break
    if "stratum" not in cohort.columns:
        raise ValueError("cohort_table.csv must include a 'stratum' column.")

    # Determine weights: prefer 'weight'; else N/n_sample; else 1.0
    weight_col = None
    for c in cohort.columns:
        if c.strip().lower() in {"weight","w","wt"}:
            weight_col = c; break
    if weight_col is None:
        lc_map = {c.lower(): c for c in cohort.columns}
        pop_col  = next((lc_map[k] for k in ["n","n_total","n_population","population","pop","n_pop","total","size"] if k in lc_map), None)
        samp_col = next((lc_map[k] for k in ["n_sample","sample","sample_n","n_samp","sample_size"] if k in lc_map), None)
        if pop_col is not None and samp_col is not None:
            cohort["__weight__"] = (
                pd.to_numeric(cohort[pop_col], errors="coerce") /
                pd.to_numeric(cohort[samp_col], errors="coerce").replace({0: np.nan})
            )
            weight_col = "__weight__"

    if weight_col:
        tmp = cohort[["stratum", weight_col]].copy().rename(columns={weight_col:"weight"})
        wmap = dict(zip(tmp["stratum"], tmp["weight"]))
    else:
        warn("cohort_table.csv has no 'weight' and cannot infer from N/n_sample; using flat weights = 1.0")
        wmap = {}

    sample["weight"] = sample["stratum"].map(lambda s: float(wmap.get(s, 1.0)))
    return sample

def index_local_configs_by_repo(root: Path) -> dict[str, list[Path]]:
    mapping: dict[str, list[Path]] = {}
    if not root.exists(): return mapping
    for p in root.rglob("*"):
        if not p.is_file(): continue
        if p.suffix.lower() not in TEXT_EXTS:
            if p.stat().st_size > 0 and p.suffix == "": pass
            else: continue
        full = full_name_from_saved_filename(p) or full_name_from_saved_filename(p.parent)
        if not full: continue
        mapping.setdefault(full, []).append(p)
    return mapping

# ======================= MAIN =======================
def main():
    start_t = time.time()
    OUT_DIR.mkdir(parents=True, exist_ok=True)

    banner("SETUP")
    tokens = load_tokens_from_env_file(TOKENS_ENV_PATH)
    rot = TokenRotator(tokens)
    if tokens: info(f"Loaded {len(tokens)} GitHub token(s) for rotation from {TOKENS_ENV_PATH}")
    else:      warn("No tokens found; unauthenticated fetch will work only for public repos and low rate limits.")

    # time window
    start_arg = end_arg = None
    date_only = False
    if USE_CUTOFF:
        start_arg, end_arg, date_only = window_utc_from_local(CLONE_DATE_LOCAL, WINDOW_DAYS_BEFORE, WINDOW_DAYS_AFTER, LOCAL_TZ)
        if start_arg is None and end_arg is None:
            warn(f"Invalid cutoff '{CLONE_DATE_LOCAL}', proceeding without a cutoff.")
        else:
            if date_only:
                info(f"Applying DATE window: [{start_arg} .. {end_arg}] (no tz support available)")
            else:
                info(f"Applying UTC window: [{start_arg.isoformat()} .. {end_arg.isoformat()}] "
                     f"(local {LOCAL_TZ}, before={WINDOW_DAYS_BEFORE}, after={WINDOW_DAYS_AFTER})")

    banner("LOAD SAMPLE + WEIGHTS")
    sample_df = load_sample_and_weights(SAMPLED_CSV_DIR, SAMPLED_CSV_NAME, COHORT_FILE_NAME)
    sample_df = sample_df[~sample_df["full_name"].isna()].copy()
    repo_list = sorted(sample_df["full_name"].str.lower().unique().tolist())
    info(f"Repos in stratified sample: {len(repo_list)}")

    banner("INDEX LOCAL CONFIGS FOR YAML HINTS")
    repo_to_files = index_local_configs_by_repo(CONFIG_DIR)
    info(f"Repos with any local files detected: {len(repo_to_files)}")

    banner("FETCH & SCAN")
    rows, examples, audit = [], [], []
    total_runs_fetched = 0
    repos_with_hits = 0

    for idx, full in enumerate(repo_list, start=1):
        tic = time.time()
        provider = "github_actions"
        sub = sample_df[sample_df["full_name"].str.lower() == full]
        stratum = sub["stratum"].iloc[0] if not sub.empty else "Y0_B0_A0"
        weight  = float(sub["weight"].mean()) if not sub.empty else 1.0
        at_pred = int(sub["AT_pred"].max()) if ("AT_pred" in sub.columns and not sub["AT_pred"].isna().all()) else 0
        owner, repo = full.split("/", 1)

        # YAML hints (context only)
        yaml_text, wf_err = ("", None)
        if ENABLE_GITHUB_FETCH:
            yaml_text, wf_err = fetch_workflow_yamls(rot, owner, repo)
        local_files = repo_to_files.get(full, [])
        for fp in local_files:
            try:
                with open(fp, "r", encoding="utf-8", errors="ignore") as f:
                    yaml_text += "\n" + f.read()
            except Exception:
                pass
        yaml_hints = scan_yaml_hints(yaml_text) if yaml_text else []

        # STRATUM-based instrumentation context
        instru_ctx = has_instru_context_from_stratum(stratum, at_pred)

        # Eligible themes for counting
        eligible_themes = set(HIGH_THEMES)
        if INCLUDE_MEDIUM and instru_ctx:
            eligible_themes |= MEDIUM_THEMES
        if INCLUDE_LOW and instru_ctx:
            eligible_themes |= LOW_THEMES

        # Accumulators for de-noising (lines + runs)
        theme_line_hits: dict[str, int] = {}
        theme_run_ids:  dict[str, set]  = {}
        kept_examples = []  # (theme, run_id, line)

        # Iterate runs with pagination
        runs_err = None
        page, got = 1, 0
        while got < MAX_RUNS_PER_REPO:
            runs_resp = list_workflow_runs(rot, owner, repo, page=page, per_page=min(100, MAX_RUNS_PER_REPO))
            if runs_resp.status_code != 200:
                runs_err = runs_resp._diag; break
            wr = runs_resp.json().get("workflow_runs", [])
            if not wr: break

            for run in wr:
                if got >= MAX_RUNS_PER_REPO: break

                # date window filter
                created = parse_gh_ts(run.get("created_at"))
                if (start_arg is not None) or (end_arg is not None):
                    if date_only:
                        d = created.date() if created else None
                        if start_arg is not None and d is not None and d < start_arg: 
                            continue
                        if end_arg is not None and d is not None and d > end_arg: 
                            continue
                    else:
                        if start_arg is not None and created and created < start_arg: 
                            continue
                        if end_arg is not None and created and created > end_arg: 
                            continue

                # fetch logs for this run
                txt, diag = fetch_log_text_for_run(rot, run.get("logs_url"))
                if diag is not None:
                    runs_err = diag
                    continue
                got += 1
                total_runs_fetched += 1

                # scan
                fthemes, fhits = scan_text_for_themes(txt)

                # Per-theme accumulation (lines + run ids) only for eligible themes
                # Count line hits per theme (across all lines in this run)
                per_theme_line_count = {}
                for th, line in fhits:
                    if th in eligible_themes:
                        per_theme_line_count[th] = per_theme_line_count.get(th, 0) + 1

                for th, line_count in per_theme_line_count.items():
                    theme_line_hits[th] = theme_line_hits.get(th, 0) + line_count
                    theme_run_ids.setdefault(th, set()).add(run["id"])

                # Keep up to 3 example snippets across eligible themes
                if fhits and len(kept_examples) < 3:
                    for th, line in fhits:
                        if th in eligible_themes:
                            kept_examples.append((th, run["id"], line))
                            if len(kept_examples) >= 3: break

                # Early stop logic
                if EARLY_STOP_ON_HIT:
                    if EARLY_STOP_MODE == "any":
                        if any(_theme_counts_as_hit(th, theme_line_hits, theme_run_ids) for th in eligible_themes):
                            break
                    elif EARLY_STOP_MODE == "high-only":
                        if any(th in HIGH_THEMES and _theme_counts_as_hit(th, theme_line_hits, theme_run_ids, high=True)
                               for th in eligible_themes):
                            break

            # early stop outer check
            if EARLY_STOP_ON_HIT:
                if EARLY_STOP_MODE == "any":
                    if any(_theme_counts_as_hit(th, theme_line_hits, theme_run_ids) for th in eligible_themes):
                        break
                elif EARLY_STOP_MODE == "high-only":
                    if any(th in HIGH_THEMES and _theme_counts_as_hit(th, theme_line_hits, theme_run_ids, high=True)
                           for th in eligible_themes):
                        break

            page += 1

        # Final counted themes after de-noising
        seen_themes = set()
        for th in eligible_themes:
            if _theme_counts_as_hit(th, theme_line_hits, theme_run_ids):
                seen_themes.add(th)

        if seen_themes: repos_with_hits += 1

        # examples (only for themes that ultimately counted)
        for th, run_id, snip in kept_examples:
            if th in seen_themes:
                examples.append({
                    "full_name": full, "provider": provider, "stratum": stratum,
                    "theme": th, "run_id": run_id, "snippet": (snip or "").strip()[:500]
                })

        # row & audit
        rows.append({
            "full_name": full,
            "provider": provider,
            "stratum": stratum,
            "weight": weight,
            "themes": ";".join(sorted(seen_themes)) if seen_themes else "",
            "yaml_hints": ";".join(sorted(set(yaml_hints))) if yaml_hints else "",
            "log_runs_scanned": got,
            "yaml_bytes": len(yaml_text),
            "runs_err": json.dumps(runs_err) if runs_err else "",
            "wf_err": json.dumps(wf_err) if wf_err else "",
        })

        audit.append({
            "full_name": full,
            "log_runs_scanned": got,
            "yaml_bytes": len(yaml_text),
            "yaml_hints": ";".join(sorted(set(yaml_hints))) if yaml_hints else "",
            "themes_high_only": ";".join(sorted([t for t in seen_themes if t in HIGH_THEMES])) if seen_themes else "",
            "rate_remaining": (runs_err or {}).get("rate_remaining") if runs_err else None,
        })

        # progress line
        if idx % PROGRESS_EVERY == 0:
            dur = time.time() - tic
            err_flag = " ERR" if (rows[-1]["runs_err"] or rows[-1]["wf_err"]) else ""
            snip_ct = len([1 for th, _, _ in kept_examples if th in seen_themes]) if SHOW_HIT_SNIPPET_COUNT else 0
            note(f"[{idx}/{len(repo_list)}]{err_flag} {full} | runs={rows[-1]['log_runs_scanned']} | themes={len(seen_themes)}"
                 + (f" | examples={snip_ct}" if SHOW_HIT_SNIPPET_COUNT else "")
                 + f" | hints={len(yaml_hints)} | {dur:.1f}s")

    # Build outputs
    df = pd.DataFrame(rows)

    # Explode themes
    df_exp = df.copy()
    df_exp["themes"] = df_exp["themes"].fillna("")
    df_exp = df_exp[df_exp["themes"] != ""]
    if not df_exp.empty:
        df_exp = df_exp.assign(theme=df_exp["themes"].str.split(";")).explode("theme")
    else:
        df_exp = pd.DataFrame(columns=["full_name","provider","stratum","weight","theme"])

    # Weighted counts
    if not df_exp.empty:
        grp = df_exp.groupby("theme").agg(
            weighted_count=("weight", lambda s: float(np.nansum(s))),
            repos=("full_name","nunique"),
        ).reset_index()
        total_w = float(np.nansum(df["weight"].values))
        grp["share"] = np.where(total_w>0, grp["weighted_count"]/total_w, np.nan)
        grp = grp.sort_values(["weighted_count","repos"], ascending=[False, False])
    else:
        grp = pd.DataFrame(columns=["theme","weighted_count","repos","share"])

    # By provider
    if not df_exp.empty:
        byprov = df_exp.groupby(["provider","theme"]).agg(
            weighted_count=("weight", lambda s: float(np.nansum(s))),
            repos=("full_name","nunique"),
        ).reset_index()
        totals = byprov.groupby("provider")["weighted_count"].sum().rename("total_w")
        byprov = byprov.merge(totals, on="provider", how="left")
        byprov["share_in_provider"] = np.where(byprov["total_w"]>0, byprov["weighted_count"]/byprov["total_w"], np.nan)
        byprov = byprov.drop(columns=["total_w"]).sort_values(["provider","weighted_count"], ascending=[True, False])
    else:
        byprov = pd.DataFrame(columns=["provider","theme","weighted_count","repos","share_in_provider"])

    OUT_DIR.mkdir(parents=True, exist_ok=True)
    grp.to_csv(OUT_DIR/"challenge_counts_weighted_high_only.csv", index=False, encoding="utf-8-sig")
    byprov.to_csv(OUT_DIR/"challenge_counts_by_provider_weighted_high_only.csv", index=False, encoding="utf-8-sig")
    pd.DataFrame(examples).to_csv(OUT_DIR/"challenge_examples_high_only.csv", index=False, encoding="utf-8-sig")
    pd.DataFrame(audit).to_csv(OUT_DIR/"challenge_run_audit_high_only.csv", index=False, encoding="utf-8-sig")

    banner("DONE")
    info(f"Saved -> {OUT_DIR/'challenge_counts_weighted_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_counts_by_provider_weighted_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_examples_high_only.csv'}")
    info(f"Saved -> {OUT_DIR/'challenge_run_audit_high_only.csv'}")
    elapsed = time.time() - start_t
    note(f"SUMMARY: repos={len(repo_list)} | total_runs_fetched={total_runs_fetched} | repos_with_any_hits={sum(df['themes'].astype(bool))} | elapsed={elapsed:.1f}s")

if __name__ == "__main__":
    main()
# Out:
# [2025-08-23 17:45:15] ===== SETUP =====
# [2025-08-23 17:45:15] [INFO] Loaded 6 GitHub token(s) for rotation from C:\GitHub\Android-Mobile-Apps\all_tokens.env
# [2025-08-23 17:45:15] [INFO] Applying UTC window: [2025-05-12T04:00:00+00:00 .. 2025-08-11T03:59:59+00:00] (local America/Toronto, before=90, after=0)
# [2025-08-23 17:45:15] ===== LOAD SAMPLE + WEIGHTS =====
# [2025-08-23 17:45:15] [INFO] Repos in stratified sample: 383
# [2025-08-23 17:45:15] ===== INDEX LOCAL CONFIGS FOR YAML HINTS =====
# [2025-08-23 17:45:18] [INFO] Repos with any local files detected: 4519
# [2025-08-23 17:45:18] ===== FETCH & SCAN =====
# [2025-08-23 17:45:19] [1/383] 5hmla/jpagerslidingtabstrip | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-23 17:45:19] [2/383] ERR 7heaven/shswitchview | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 17:45:22] [3/383] a-mabe/openhiit | runs=1 | themes=1 | examples=2 | hints=2 | 2.8s
# [2025-08-23 17:45:23] [4/383] a914-gowtham/android-video-trimmer | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 17:45:26] [5/383] abdelaziz-mahdy/pytorch_lite | runs=0 | themes=0 | examples=0 | hints=1 | 3.7s
# [2025-08-23 17:46:08] [6/383] ably/ably-flutter | runs=60 | themes=0 | examples=0 | hints=2 | 41.6s
# [2025-08-23 17:46:09] [7/383] abualgait/movieapp | runs=0 | themes=0 | examples=0 | hints=1 | 0.9s
# [2025-08-23 17:46:16] [8/383] ERR acinq/phoenix | runs=7 | themes=0 | examples=0 | hints=1 | 7.8s
# [2025-08-23 17:46:17] [9/383] adammc331/androidstudyguide | runs=0 | themes=0 | examples=0 | hints=3 | 0.8s
# [2025-08-23 17:46:18] [10/383] admob-plus/admob-plus | runs=0 | themes=0 | examples=0 | hints=2 | 1.1s
# [2025-08-23 17:46:19] [11/383] ERR adrcotfas/goodtime | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-23 17:46:19] [12/383] ERR agrawalsuneet/loaderspack-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 17:46:22] [13/383] ahmadre/fluttericonpicker | runs=0 | themes=0 | examples=0 | hints=1 | 3.2s
# [2025-08-23 17:46:23] [14/383] ERR ailiwean/nbzxing | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 17:46:24] [15/383] airbnb/rxgroups | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 17:46:31] [16/383] ERR aivanovski/keepassvault | runs=3 | themes=0 | examples=0 | hints=1 | 7.6s
# [2025-08-23 17:46:32] [17/383] ajitsing/expensemanager | runs=0 | themes=0 | examples=0 | hints=2 | 0.5s
# [2025-08-23 17:46:32] [18/383] ERR alidili/recyclerviewhelper | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 17:46:44] [19/383] ERR almoullim/background_location | runs=0 | themes=0 | examples=0 | hints=1 | 11.6s
# [2025-08-23 17:46:45] [20/383] alphacep/vosk-flutter | runs=0 | themes=0 | examples=0 | hints=1 | 1.3s
# [2025-08-23 17:46:46] [21/383] amahi/android | runs=0 | themes=0 | examples=0 | hints=4 | 0.8s
# [2025-08-23 17:46:46] [22/383] ERR amitshekhariitbhu/fast-android-networking | runs=0 | themes=0 | examples=0 | hints=4 | 0.8s
# [2025-08-23 17:47:24] [23/383] amplitude/amplitude-flutter | runs=60 | themes=0 | examples=0 | hints=0 | 37.4s
# [2025-08-23 17:47:25] [24/383] amrdeveloper/easyadapter | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 17:47:26] [25/383] androidpoet/dropdown | runs=0 | themes=0 | examples=0 | hints=1 | 1.7s
# [2025-08-23 17:47:30] [26/383] anilbeesetti/nextplayer | runs=1 | themes=1 | examples=1 | hints=2 | 3.7s
# [2025-08-23 17:48:02] [27/383] ERR anthonycr/lightning-browser | runs=8 | themes=0 | examples=0 | hints=1 | 31.7s
# [2025-08-23 17:48:02] [28/383] ERR antox/antox | runs=0 | themes=0 | examples=0 | hints=3 | 0.5s
# [2025-08-23 17:48:06] [29/383] ERR araafroyall/cleaner-royall | runs=0 | themes=0 | examples=0 | hints=1 | 3.5s
# [2025-08-23 17:48:52] [30/383] ardriveapp/ardrive-web | runs=60 | themes=0 | examples=0 | hints=0 | 45.9s
# [2025-08-23 17:48:54] [31/383] arildojr7/iris-mock | runs=0 | themes=0 | examples=0 | hints=2 | 2.8s
# [2025-08-23 17:48:55] [32/383] arnnis/sup | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 17:48:56] [33/383] ERR artem-zinnatullin/android-wail-app | runs=0 | themes=0 | examples=0 | hints=4 | 0.5s
# [2025-08-23 17:48:56] [34/383] ERR artem-zinnatullin/qualitymatters | runs=0 | themes=0 | examples=0 | hints=5 | 0.5s
# [2025-08-23 17:49:04] [35/383] ERR artsmvch/frolomuse | runs=4 | themes=0 | examples=0 | hints=1 | 7.2s
# [2025-08-23 17:50:08] [36/383] auth0/auth0-flutter | runs=60 | themes=0 | examples=0 | hints=3 | 64.8s
# [2025-08-23 17:50:09] [37/383] ERR avjinder/minimal-todo | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 17:50:16] [38/383] axel358/smartdock | runs=9 | themes=0 | examples=0 | hints=0 | 7.3s
# [2025-08-23 17:50:16] [39/383] ERR baoyongzhang/treasure | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 17:50:17] [40/383] berdosi/heartbeat | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 17:50:17] [41/383] ERR bilibili/ijkplayer | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-23 17:50:52] [42/383] bithack/principia | runs=25 | themes=0 | examples=0 | hints=0 | 34.5s
# [2025-08-23 17:50:53] [43/383] bkhezry/weather | runs=0 | themes=0 | examples=0 | hints=1 | 1.0s
# [2025-08-23 17:50:54] [44/383] brainiumllc/cargo-mobile | runs=0 | themes=0 | examples=0 | hints=0 | 0.7s
# [2025-08-23 17:50:57] [45/383] brandonp2412/fitbook | runs=1 | themes=1 | examples=2 | hints=3 | 3.7s
# [2025-08-23 17:50:58] [46/383] brarcher/budget-watch | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-23 17:50:59] [47/383] ERR brarcher/video-transcoder | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-23 17:51:01] [48/383] ERR breens-mbaka/jetpack-compose-tables | runs=0 | themes=0 | examples=0 | hints=1 | 2.0s
# [2025-08-23 17:51:18] [49/383] bugsnag/bugsnag-android | runs=4 | themes=1 | examples=3 | hints=2 | 17.5s
# [2025-08-23 17:51:20] [50/383] byteszero/app_installer | runs=0 | themes=0 | examples=0 | hints=0 | 1.5s
# [2025-08-23 17:51:20] [51/383] calsign/apde | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 17:51:45] [52/383] ERR canopas/cloud-gallery | runs=0 | themes=0 | examples=0 | hints=0 | 25.2s
# [2025-08-23 17:51:46] [53/383] ERR carguo/gsyricktext | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 17:51:46] [54/383] ERR catappult/appcoins-wallet-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 17:51:48] [55/383] cbeuw/cloak-android | runs=2 | themes=1 | examples=2 | hints=1 | 1.9s
# [2025-08-23 17:51:52] [56/383] cbeyls/fosdem-companion-android | runs=4 | themes=0 | examples=0 | hints=0 | 4.2s
# [2025-08-23 17:51:53] [57/383] ERR cellularprivacy/android-imsi-catcher-detector | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 17:51:53] [58/383] ERR chaosbastler/opentraining | runs=0 | themes=0 | examples=0 | hints=3 | 0.5s
# [2025-08-23 17:52:07] [59/383] chenxiaolong/bcr | runs=16 | themes=0 | examples=0 | hints=0 | 13.9s
# [2025-08-23 17:52:13] [60/383] ERR cliuff/boundo | runs=6 | themes=0 | examples=0 | hints=0 | 6.3s
# [2025-08-23 17:52:14] [61/383] codehasan/current-activity | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 17:52:15] [62/383] coding-blocks/cbonlineapp | runs=0 | themes=0 | examples=0 | hints=3 | 0.7s
# [2025-08-23 17:52:15] [63/383] ERR coding/coding-android | runs=0 | themes=0 | examples=0 | hints=2 | 0.3s
# [2025-08-23 17:52:16] [64/383] ERR coffeepartner/capt | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 17:52:16] [65/383] ERR commit451/elasticdragdismisslayout | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 17:52:16] [66/383] ERR commit451/reptar | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 17:52:21] [67/383] coracle-social/coracle | runs=5 | themes=1 | examples=2 | hints=1 | 4.7s
# [2025-08-23 17:52:21] [68/383] ERR criptext/android-email-client | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 17:52:22] [69/383] cryptoguardoss/cryptoguard | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-23 17:52:22] [70/383] ERR cycloneaxe/phphub-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-23 17:52:31] [71/383] dagmawibabi/scholarxiv | runs=3 | themes=0 | examples=0 | hints=0 | 9.1s
# [2025-08-23 17:52:32] [72/383] ERR dalerank/caesaria-game | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 17:52:53] [73/383] dart-lang/http | runs=15 | themes=1 | examples=2 | hints=1 | 21.5s
# [2025-08-23 17:53:57] [74/383] dart-lang/native | runs=60 | themes=0 | examples=0 | hints=1 | 63.5s
# [2025-08-23 17:54:00] [75/383] deandreamatias/tv-randshow | runs=0 | themes=0 | examples=0 | hints=0 | 3.4s
# [2025-08-23 17:54:35] [76/383] deltazefiro/amarok-hider | runs=60 | themes=0 | examples=0 | hints=0 | 35.0s
# [2025-08-23 17:54:39] [77/383] devgianlu/aria2android | runs=4 | themes=0 | examples=0 | hints=0 | 3.4s
# [2025-08-23 17:54:46] [78/383] devgianlu/aria2app | runs=7 | themes=0 | examples=0 | hints=1 | 7.1s
# [2025-08-23 17:54:49] [79/383] dlutton/flutter_tts | runs=2 | themes=0 | examples=0 | hints=1 | 2.7s
# [2025-08-23 17:54:49] [80/383] dokar3/amlv | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 17:54:49] [81/383] ERR douban/rexxar-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 17:54:50] [82/383] ERR doyle-flutter/flutterplatformall | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 17:54:50] [83/383] ERR drakeet/floo | runs=0 | themes=0 | examples=0 | hints=4 | 0.5s
# [2025-08-23 17:57:51] [84/383] drawpile/drawpile | runs=60 | themes=0 | examples=0 | hints=1 | 180.7s
# [2025-08-23 17:57:52] [85/383] droidkaigi/conference-app-2020 | runs=0 | themes=0 | examples=0 | hints=2 | 1.0s
# [2025-08-23 17:57:53] [86/383] droidknights/droidknights2020_app | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:00:33] [87/383] ERR droidworksstudio/easylauncher | runs=57 | themes=0 | examples=0 | hints=1 | 160.2s
# [2025-08-23 18:00:33] [88/383] ERR dsappteam/anchors | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:00:34] [89/383] ERR emileb/opengames | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:00:38] [90/383] envoyproxy/envoy-mobile | runs=0 | themes=0 | examples=0 | hints=3 | 3.7s
# [2025-08-23 18:00:39] [91/383] ericksumargo/dads | runs=0 | themes=0 | examples=0 | hints=2 | 1.0s
# [2025-08-23 18:00:39] [92/383] ericktijerou/jetpuppy | runs=0 | themes=0 | examples=0 | hints=2 | 0.5s
# [2025-08-23 18:00:43] [93/383] etchdroid/etchdroid | runs=1 | themes=3 | examples=3 | hints=2 | 3.8s
# [2025-08-23 18:00:43] [94/383] ERR evilinsultgenerator/android-app-java | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:00:45] [95/383] evilpan/jni_helper | runs=0 | themes=0 | examples=0 | hints=1 | 1.5s
# [2025-08-23 18:01:17] [96/383] f-23/react-native-passkey | runs=60 | themes=0 | examples=0 | hints=0 | 32.1s
# [2025-08-23 18:01:21] [97/383] f4uzan/hglauncher | runs=5 | themes=0 | examples=0 | hints=3 | 3.9s
# [2025-08-23 18:01:24] [98/383] faltenreich/diaguard | runs=1 | themes=1 | examples=3 | hints=2 | 2.7s
# [2025-08-23 18:01:30] [99/383] fankes/colorosnotifyicon | runs=9 | themes=0 | examples=0 | hints=1 | 6.3s
# [2025-08-23 18:01:31] [100/383] ERR feeeei/circleseekbar | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:01:32] [101/383] feelfreelinux/octo4a | runs=0 | themes=0 | examples=0 | hints=1 | 1.2s
# [2025-08-23 18:01:32] [102/383] ERR fengzhizi715/saf | runs=0 | themes=0 | examples=0 | hints=2 | 0.3s
# [2025-08-23 18:01:41] [103/383] ferraridamiano/converternow | runs=14 | themes=1 | examples=2 | hints=0 | 9.0s
# [2025-08-23 18:01:41] [104/383] ERR fg607/relaxfinger | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 18:03:43] [105/383] ERR fingerprintjs/fingerprintjs-pro-react-native | runs=38 | themes=1 | examples=2 | hints=2 | 121.6s
# [2025-08-23 18:03:44] [106/383] five-prayers/five-prayers-android | runs=1 | themes=0 | examples=0 | hints=3 | 1.4s
# [2025-08-23 18:04:09] [107/383] fleeksoft/ksoup | runs=5 | themes=1 | examples=3 | hints=0 | 24.8s
# [2025-08-23 18:04:10] [108/383] ERR flet-dev/serious-python | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:04:24] [109/383] ERR fliegendewurst/triliumdroid | runs=20 | themes=1 | examples=2 | hints=1 | 14.3s
# [2025-08-23 18:04:26] [110/383] flutterkaigi/conference-app-2023 | runs=0 | themes=0 | examples=0 | hints=0 | 1.8s
# [2025-08-23 18:04:26] [111/383] ERR flyingradish/leamonax | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:04:27] [112/383] formatools/forma | runs=0 | themes=0 | examples=0 | hints=1 | 1.0s
# [2025-08-23 18:04:28] [113/383] fornewid/material-motion-compose | runs=0 | themes=0 | examples=0 | hints=2 | 1.3s
# [2025-08-23 18:04:29] [114/383] ERR fossasia/phimpme-android | runs=0 | themes=0 | examples=0 | hints=5 | 0.4s
# [2025-08-23 18:05:08] [115/383] fossifyorg/gallery | runs=60 | themes=0 | examples=0 | hints=0 | 38.9s
# [2025-08-23 18:05:10] [116/383] freeotp/freeotp-android | runs=1 | themes=1 | examples=3 | hints=3 | 2.6s
# [2025-08-23 18:05:11] [117/383] gerardpaligot/android-countdown | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-23 18:05:15] [118/383] getactivity/easywindow | runs=6 | themes=0 | examples=0 | hints=0 | 4.1s
# [2025-08-23 18:05:16] [119/383] getactivity/titlebar | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-23 18:05:17] [120/383] getlantern/lantern | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-23 18:05:33] [121/383] ERR getstream/twitch-clone-compose | runs=3 | themes=0 | examples=0 | hints=1 | 16.1s
# [2025-08-23 18:05:35] [122/383] giuliopime/zenbreak | runs=0 | themes=0 | examples=0 | hints=0 | 1.5s
# [2025-08-23 18:06:13] [123/383] go-vikunja/app | runs=60 | themes=0 | examples=0 | hints=1 | 38.4s
# [2025-08-23 18:06:18] [124/383] google-developer-training/android-basics-kotlin-sql-basics-app | runs=2 | themes=1 | examples=2 | hints=1 | 4.9s
# [2025-08-23 18:08:47] [125/383] ERR google/android-fhir | runs=40 | themes=0 | examples=0 | hints=2 | 148.8s
# [2025-08-23 18:09:41] [126/383] googlechromelabs/bubblewrap | runs=60 | themes=0 | examples=0 | hints=1 | 54.3s
# [2025-08-23 18:09:42] [127/383] gotev/android-cookie-store | runs=0 | themes=0 | examples=0 | hints=2 | 0.7s
# [2025-08-23 18:09:42] [128/383] ERR greenaddress/abcore | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:10:26] [129/383] gromif/astracrypt | runs=49 | themes=1 | examples=2 | hints=1 | 44.2s
# [2025-08-23 18:10:27] [130/383] ERR guardianproject/camerav | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:10:27] [131/383] ERR guiguegon/sineview | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:10:28] [132/383] guilhe/seekbarrangedview | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-23 18:10:30] [133/383] gzu-liyujiang/android_cn_oaid | runs=0 | themes=0 | examples=0 | hints=1 | 1.5s
# [2025-08-23 18:10:30] [134/383] ERR haiyangwu/mediasoup-client-android | runs=0 | themes=0 | examples=0 | hints=5 | 0.5s
# [2025-08-23 18:10:42] [135/383] ERR halilozercan/compose-richtext | runs=17 | themes=0 | examples=0 | hints=1 | 12.1s
# [2025-08-23 18:10:43] [136/383] ERR hluhovskyi/camerabutton | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:10:48] [137/383] horizontalsystems/ethereum-kit-android | runs=6 | themes=0 | examples=0 | hints=1 | 4.9s
# [2025-08-23 18:10:49] [138/383] ERR hprose/hprose-java | runs=1 | themes=0 | examples=0 | hints=0 | 1.4s
# [2025-08-23 18:11:30] [139/383] hulaspark/hula | runs=60 | themes=0 | examples=0 | hints=1 | 41.1s
# [2025-08-23 18:11:31] [140/383] ERR hypeapps/episodie | runs=0 | themes=0 | examples=0 | hints=2 | 0.7s
# [2025-08-23 18:12:06] [141/383] i2p/i2p.android.base | runs=60 | themes=0 | examples=0 | hints=0 | 34.8s
# [2025-08-23 18:12:06] [142/383] ERR icbnetwork/web3-wallet | runs=0 | themes=0 | examples=0 | hints=3 | 0.6s
# [2025-08-23 18:12:08] [143/383] ice-blockchain/mobile-app | runs=0 | themes=0 | examples=0 | hints=2 | 1.2s
# [2025-08-23 18:12:08] [144/383] igniti0n/flutter_algorithms_visualization | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:12:09] [145/383] ERR ihsanbal/wiv | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:12:21] [146/383] ishan09811/pine | runs=1 | themes=0 | examples=0 | hints=1 | 12.6s
# [2025-08-23 18:12:54] [147/383] itsvic-dev/parcel | runs=60 | themes=0 | examples=0 | hints=1 | 32.6s
# [2025-08-23 18:12:55] [148/383] ivnsch/rust_android_ios | runs=0 | themes=0 | examples=0 | hints=3 | 0.8s
# [2025-08-23 18:13:13] [149/383] izakirsheikh/audiofy | runs=19 | themes=0 | examples=0 | hints=0 | 18.1s
# [2025-08-23 18:13:13] [150/383] ERR jakenjarvis/android-ormlitecontentprovider | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:13:14] [151/383] ERR jakubkinst/android-statefullayout | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:13:14] [152/383] ERR jamling/af-pay | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:13:15] [153/383] ERR jariz/materialup | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:13:15] [154/383] ERR javiersantos/piracychecker | runs=0 | themes=0 | examples=0 | hints=4 | 0.3s
# [2025-08-23 18:13:16] [155/383] ERR jd-alexander/likebutton | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:13:21] [156/383] jeffsieu/stops-flutter | runs=8 | themes=0 | examples=0 | hints=1 | 5.3s
# [2025-08-23 18:14:02] [157/383] jellify-music/app | runs=47 | themes=1 | examples=1 | hints=1 | 41.3s
# [2025-08-23 18:14:03] [158/383] ERR jerryokafor/timelineview | runs=0 | themes=0 | examples=0 | hints=5 | 0.3s
# [2025-08-23 18:14:10] [159/383] jerson/flutter-openpgp | runs=6 | themes=1 | examples=3 | hints=1 | 7.2s
# [2025-08-23 18:14:16] [160/383] jerson/flutter-rsa | runs=4 | themes=1 | examples=3 | hints=1 | 5.6s
# [2025-08-23 18:14:16] [161/383] ERR jessyancoding/androidautosize | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:14:17] [162/383] jeziellago/linkt | runs=0 | themes=0 | examples=0 | hints=2 | 0.8s
# [2025-08-23 18:14:17] [163/383] ERR jianjunxiao/nicevieoplayer | runs=0 | themes=0 | examples=0 | hints=3 | 0.5s
# [2025-08-23 18:14:18] [164/383] ERR joaquimley/faboptions | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:14:20] [165/383] ERR jonathanklee/sapio | runs=1 | themes=0 | examples=0 | hints=1 | 2.7s
# [2025-08-23 18:14:26] [166/383] jordond/kmpalette | runs=1 | themes=1 | examples=3 | hints=1 | 5.7s
# [2025-08-23 18:15:09] [167/383] ERR joreilly/climatetracekmp | runs=60 | themes=1 | examples=2 | hints=0 | 42.9s
# [2025-08-23 18:15:13] [168/383] joreilly/starwars | runs=2 | themes=1 | examples=3 | hints=3 | 4.4s
# [2025-08-23 18:15:14] [169/383] jraska/falcon | runs=0 | themes=0 | examples=0 | hints=2 | 0.7s
# [2025-08-23 18:16:06] [170/383] ERR jrpie/launcher | runs=46 | themes=0 | examples=0 | hints=1 | 51.8s
# [2025-08-23 18:16:06] [171/383] ERR jshvarts/daggerandroidmvvm | runs=0 | themes=0 | examples=0 | hints=0 | 0.7s
# [2025-08-23 18:16:13] [172/383] juancastillo0/wasm_run | runs=2 | themes=1 | examples=3 | hints=2 | 6.3s
# [2025-08-23 18:16:20] [173/383] jump-sdk/jetpack_compose_country_code_picker_emoji | runs=0 | themes=0 | examples=0 | hints=0 | 6.7s
# [2025-08-23 18:16:20] [174/383] ERR justzak/dilatingdotsprogressbar | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:16:20] [175/383] ERR kagayamakaede/shadowsocksrdroid | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:16:21] [176/383] ERR kailuo99/toutiao | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:16:22] [177/383] kaisar945/xposed-godmode | runs=0 | themes=0 | examples=0 | hints=1 | 0.9s
# [2025-08-23 18:16:22] [178/383] ERR kevinhinterlong/archwiki-viewer | runs=0 | themes=0 | examples=0 | hints=4 | 0.5s
# [2025-08-23 18:16:23] [179/383] keystonehq/keystone-cold-app | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:16:23] [180/383] ERR kikoso/swipeable-cards | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 18:16:24] [181/383] ERR kitt-ai/snowboy | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:16:24] [182/383] ERR kominkyu/teaspoon | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 18:16:25] [183/383] ERR kost/networkmapper | runs=0 | themes=0 | examples=0 | hints=2 | 0.5s
# [2025-08-23 18:16:35] [184/383] ERR lagradost/quicknovel | runs=13 | themes=0 | examples=0 | hints=1 | 10.5s
# [2025-08-23 18:16:36] [185/383] lambiengcode/analog-clock | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 18:16:41] [186/383] lanlinju/animius | runs=2 | themes=1 | examples=2 | hints=1 | 4.5s
# [2025-08-23 18:16:44] [187/383] larryaasen/upgrader | runs=1 | themes=2 | examples=3 | hints=0 | 3.2s
# [2025-08-23 18:17:30] [188/383] ERR lawnchairlauncher/lawnchair | runs=60 | themes=0 | examples=0 | hints=1 | 46.2s
# [2025-08-23 18:17:30] [189/383] ERR leapcode/bitmask_android | runs=0 | themes=0 | examples=0 | hints=6 | 0.4s
# [2025-08-23 18:18:09] [190/383] leo-lox/camelus | runs=60 | themes=0 | examples=0 | hints=0 | 38.1s
# [2025-08-23 18:18:09] [191/383] ERR letelete/sleep-cycle-alarm | runs=0 | themes=0 | examples=0 | hints=3 | 0.6s
# [2025-08-23 18:18:10] [192/383] linagora/twake-mobile | runs=0 | themes=0 | examples=0 | hints=0 | 1.0s
# [2025-08-23 18:18:11] [193/383] ERR lincanbin/android-carbon-forum | runs=0 | themes=0 | examples=0 | hints=4 | 0.5s
# [2025-08-23 18:18:26] [194/383] linwooddev/butterfly | runs=2 | themes=2 | examples=3 | hints=0 | 15.4s
# [2025-08-23 18:21:50] [195/383] linx64/coincap | runs=0 | themes=0 | examples=0 | hints=1 | 204.1s
# [2025-08-23 18:21:51] [196/383] llazyl/tvbox | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:21:51] [197/383] lopspower/pokecardcompose | runs=0 | themes=0 | examples=0 | hints=2 | 0.7s
# [2025-08-23 18:21:53] [198/383] lordi/tickmate | runs=0 | themes=0 | examples=0 | hints=0 | 1.6s
# [2025-08-23 18:22:03] [199/383] love2d/love-android | runs=2 | themes=0 | examples=0 | hints=0 | 10.1s
# [2025-08-23 18:22:05] [200/383] lucasnlm/antimine-android | runs=1 | themes=0 | examples=0 | hints=1 | 1.7s
# [2025-08-23 18:22:08] [201/383] lxpio/omnigram | runs=0 | themes=0 | examples=0 | hints=0 | 2.6s
# [2025-08-23 18:22:53] [202/383] lyskouski/app-finance | runs=32 | themes=0 | examples=0 | hints=0 | 45.6s
# [2025-08-23 18:23:26] [203/383] mackhartley/roundedprogressbar | runs=60 | themes=0 | examples=0 | hints=2 | 33.0s
# [2025-08-23 18:23:26] [204/383] ERR malmstein/yahnac | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:23:27] [205/383] marcellogalhardo/retained | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 18:23:28] [206/383] ERR marcinmoskala/preferenceholder | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-23 18:23:33] [207/383] master-lzh/pipixiv | runs=3 | themes=1 | examples=2 | hints=1 | 5.1s
# [2025-08-23 18:23:34] [208/383] mastodon/mastodon-android | runs=0 | themes=0 | examples=0 | hints=1 | 1.3s
# [2025-08-23 18:24:40] [209/383] ERR mbakgun/midjourney-images-compose-multiplatform | runs=41 | themes=0 | examples=0 | hints=3 | 65.8s
# [2025-08-23 18:24:48] [210/383] ERR mcodex/react-native-sensitive-info | runs=13 | themes=0 | examples=0 | hints=0 | 8.5s
# [2025-08-23 18:25:03] [211/383] mediathekview/zapp | runs=24 | themes=0 | examples=0 | hints=2 | 14.7s
# [2025-08-23 18:25:19] [212/383] ERR michaeltroger/pdfwallet-android | runs=8 | themes=0 | examples=0 | hints=2 | 16.3s
# [2025-08-23 18:25:24] [213/383] microservicer/flutter-pipelines | runs=0 | themes=0 | examples=0 | hints=3 | 4.3s
# [2025-08-23 18:25:24] [214/383] ERR mightyfrog/centering-recycler-view | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:25:25] [215/383] mjaun/android-anuto | runs=0 | themes=0 | examples=0 | hints=2 | 1.1s
# [2025-08-23 18:26:09] [216/383] ERR mlc-ai/mlc-llm | runs=60 | themes=0 | examples=0 | hints=1 | 43.7s
# [2025-08-23 18:26:10] [217/383] ERR mnayef95/android-weekly | runs=0 | themes=0 | examples=0 | hints=2 | 0.5s
# [2025-08-23 18:26:15] [218/383] mobiledevpro/closetalk.app | runs=3 | themes=1 | examples=2 | hints=2 | 6.0s
# [2025-08-23 18:26:16] [219/383] ERR mostafaaryan/transitional-imageview | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 18:26:22] [220/383] msasikanth/twine | runs=1 | themes=1 | examples=1 | hints=3 | 5.7s
# [2025-08-23 18:26:39] [221/383] mshdabiola/notepad | runs=20 | themes=1 | examples=2 | hints=3 | 17.4s
# [2025-08-23 18:27:32] [222/383] mym0404/react-native-naver-map | runs=60 | themes=0 | examples=0 | hints=0 | 52.5s
# [2025-08-23 18:27:32] [223/383] ERR nanbox/nestedcalendar | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 18:27:32] [224/383] ERR neyoufan/brotli-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:27:33] [225/383] ERR nitroshare/nitroshare-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:27:35] [226/383] ERR niuhuan/daisy | runs=0 | themes=0 | examples=0 | hints=0 | 2.7s
# [2025-08-23 18:30:04] [227/383] nodejs-mobile/nodejs-mobile | runs=0 | themes=0 | examples=0 | hints=2 | 148.2s
# [2025-08-23 18:30:04] [228/383] ERR nontravis/pushdown-anim-click | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:30:04] [229/383] ERR norbert515/flutter_villains | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:30:05] [230/383] oaid/tenginekit | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 18:30:06] [231/383] oleksandrbalan/textflow | runs=0 | themes=0 | examples=0 | hints=0 | 1.3s
# [2025-08-23 18:30:13] [232/383] ERR omnilaboratory/obandroid | runs=3 | themes=0 | examples=0 | hints=1 | 6.2s
# [2025-08-23 18:30:14] [233/383] onseok/peekaboo | runs=0 | themes=0 | examples=0 | hints=1 | 1.1s
# [2025-08-23 18:30:27] [234/383] open-ani/animeko | runs=1 | themes=1 | examples=3 | hints=4 | 13.2s
# [2025-08-23 18:30:31] [235/383] openflutter/fluwx | runs=3 | themes=1 | examples=2 | hints=0 | 4.1s
# [2025-08-23 18:30:31] [236/383] ERR opntec/bodyapps-android | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:31:25] [237/383] organicmaps/organicmaps | runs=32 | themes=1 | examples=2 | hints=3 | 53.3s
# [2025-08-23 18:31:25] [238/383] orgzly/orgzly-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:31:29] [239/383] osociety/vernet | runs=1 | themes=1 | examples=2 | hints=0 | 3.4s
# [2025-08-23 18:32:23] [240/383] ERR overpas/compose-treemap-chart | runs=59 | themes=0 | examples=0 | hints=2 | 54.6s
# [2025-08-23 18:32:33] [241/383] owntracks/android | runs=6 | themes=1 | examples=2 | hints=3 | 9.2s
# [2025-08-23 18:33:12] [242/383] ERR oxyroid/m3uandroid | runs=41 | themes=0 | examples=0 | hints=1 | 39.9s
# [2025-08-23 18:33:27] [243/383] pachli/pachli-android | runs=1 | themes=2 | examples=3 | hints=3 | 14.3s
# [2025-08-23 18:33:27] [244/383] ERR papyon-apps/rn-notify | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:35:12] [245/383] ERR patilshreyas/notykt | runs=0 | themes=0 | examples=0 | hints=2 | 105.0s
# [2025-08-23 18:35:13] [246/383] ERR patloew/countries | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:35:13] [247/383] pedrovgs/shot | runs=0 | themes=0 | examples=0 | hints=4 | 0.6s
# [2025-08-23 18:36:10] [248/383] philippc/keepass2android | runs=17 | themes=1 | examples=2 | hints=1 | 57.2s
# [2025-08-23 18:36:20] [249/383] phizone/player | runs=3 | themes=1 | examples=2 | hints=1 | 9.7s
# [2025-08-23 18:36:49] [250/383] phonevr-developers/phonevr | runs=60 | themes=0 | examples=0 | hints=6 | 28.5s
# [2025-08-23 18:36:49] [251/383] ERR piasy/yamvp | runs=0 | themes=0 | examples=0 | hints=3 | 0.3s
# [2025-08-23 18:36:55] [252/383] plugfox/octopus | runs=7 | themes=0 | examples=0 | hints=0 | 5.8s
# [2025-08-23 18:36:55] [253/383] ERR pockethub/pockethub | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:37:33] [254/383] powersync-ja/powersync.dart | runs=42 | themes=1 | examples=2 | hints=0 | 38.1s
# [2025-08-23 18:37:36] [255/383] pr0gramm-com/pr0gramm-app | runs=2 | themes=1 | examples=2 | hints=1 | 2.9s
# [2025-08-23 18:39:09] [256/383] prisma/react-native-prisma | runs=60 | themes=0 | examples=0 | hints=2 | 92.3s
# [2025-08-23 18:40:18] [257/383] prof18/rss-parser | runs=60 | themes=0 | examples=0 | hints=0 | 69.7s
# [2025-08-23 18:40:19] [258/383] ERR promeg/xlog | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:40:19] [259/383] ERR punchthrough/ble-starter-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:40:19] [260/383] ERR purewriter/about-page | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:40:20] [261/383] ERR pwittchen/prefser | runs=0 | themes=0 | examples=0 | hints=2 | 0.3s
# [2025-08-23 18:40:20] [262/383] ERR pwittchen/rxbattery | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:40:20] [263/383] ERR pygmalion69/gauge | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:40:21] [264/383] ERR qqq3/good-weather | runs=0 | themes=0 | examples=0 | hints=0 | 0.3s
# [2025-08-23 18:40:21] [265/383] ERR ragnraok/rxcamera | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:44:25] [266/383] raphw/byte-buddy | runs=60 | themes=0 | examples=0 | hints=1 | 243.9s
# [2025-08-23 18:44:26] [267/383] react-native-community/jsc-android-buildscripts | runs=0 | themes=0 | examples=0 | hints=3 | 1.1s
# [2025-08-23 18:44:48] [268/383] realm/realm-js | runs=8 | themes=1 | examples=3 | hints=4 | 21.3s
# [2025-08-23 18:45:27] [269/383] realm/realm-kotlin | runs=60 | themes=0 | examples=0 | hints=5 | 39.1s
# [2025-08-23 18:45:27] [270/383] redmadrobot/pinkman | runs=0 | themes=0 | examples=0 | hints=2 | 0.6s
# [2025-08-23 18:45:28] [271/383] ERR requery/requery | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-23 18:45:50] [272/383] rescala-lang/rescala | runs=2 | themes=0 | examples=0 | hints=0 | 22.8s
# [2025-08-23 18:46:27] [273/383] ERR retromusicplayer/retromusicplayer | runs=44 | themes=0 | examples=0 | hints=0 | 37.0s
# [2025-08-23 18:46:28] [274/383] robert-luoqing/flutter_list_view | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-23 18:46:29] [275/383] ERR rohanoid5/muzesto | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:46:29] [276/383] ERR rome753/activitytaskview | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:46:30] [277/383] ERR roroche/androidstarter | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:47:00] [278/383] rosemoe/sora-editor | runs=60 | themes=0 | examples=0 | hints=1 | 30.8s
# [2025-08-23 18:47:20] [279/383] rozpierog/cofi | runs=31 | themes=0 | examples=0 | hints=4 | 19.4s
# [2025-08-23 18:47:20] [280/383] ERR rsenapps/commandr-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:47:20] [281/383] ERR rubygarage/shopapp-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:47:23] [282/383] runningcode/fladle | runs=1 | themes=1 | examples=3 | hints=1 | 2.8s
# [2025-08-23 18:47:26] [283/383] rxreader/tencent_kit | runs=3 | themes=1 | examples=2 | hints=0 | 3.1s
# [2025-08-23 18:47:54] [284/383] ryanheise/just_audio | runs=60 | themes=0 | examples=0 | hints=1 | 27.5s
# [2025-08-23 18:47:55] [285/383] salvadordeveloper/flutter-crypto-app | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-23 18:47:55] [286/383] ERR sarthakpranesh/cosmos | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:47:56] [287/383] segler-alex/radiodroid | runs=0 | themes=0 | examples=0 | hints=4 | 0.7s
# [2025-08-23 18:47:57] [288/383] ERR shadowsocks/shadowsocks-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-23 18:47:58] [289/383] shadowsocksr-live/ssrdroid | runs=0 | themes=0 | examples=0 | hints=2 | 1.5s
# [2025-08-23 18:47:59] [290/383] shensven/crazy-thursday | runs=0 | themes=0 | examples=0 | hints=0 | 0.9s
# [2025-08-23 18:48:34] [291/383] shivasurya/code-pathfinder | runs=60 | themes=0 | examples=0 | hints=0 | 35.3s
# [2025-08-23 18:48:35] [292/383] ERR shiyinghan/uvcandroid | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:48:35] [293/383] shunmukesh/spoofsms | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:48:36] [294/383] ERR silenceim/silence | runs=0 | themes=0 | examples=0 | hints=5 | 0.4s
# [2025-08-23 18:48:36] [295/383] ERR simoncherrygz/face-landmark-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:48:37] [296/383] simonmarquis/android-app-linking | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 18:48:38] [297/383] sirekanian/outline | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:48:38] [298/383] ERR sitefinitysteve/nativescript-auth0 | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:48:42] [299/383] sky-map-team/stardroid | runs=0 | themes=0 | examples=0 | hints=6 | 4.2s
# [2025-08-23 18:48:57] [300/383] skydoves/chatgpt-android | runs=18 | themes=1 | examples=3 | hints=0 | 14.4s
# [2025-08-23 18:49:11] [301/383] skydoves/colorpicker-compose | runs=0 | themes=0 | examples=0 | hints=1 | 14.1s
# [2025-08-23 18:49:12] [302/383] skydoves/snitcher | runs=0 | themes=0 | examples=0 | hints=1 | 1.4s
# [2025-08-23 18:49:13] [303/383] ERR sockeqwe/parcelableplease | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:49:18] [304/383] softartdev/notedelight | runs=1 | themes=1 | examples=3 | hints=3 | 5.1s
# [2025-08-23 18:49:24] [305/383] soil-kt/soil | runs=4 | themes=1 | examples=3 | hints=0 | 6.0s
# [2025-08-23 18:49:32] [306/383] ERR sphereon-opensource/mobile-wallet | runs=13 | themes=0 | examples=0 | hints=0 | 8.3s
# [2025-08-23 18:52:02] [307/383] ERR sspanak/tt9 | runs=30 | themes=0 | examples=0 | hints=0 | 150.2s
# [2025-08-23 18:52:03] [308/383] ERR stuart-campbell/rushorm | runs=0 | themes=0 | examples=0 | hints=4 | 0.3s
# [2025-08-23 18:52:04] [309/383] ERR sunnyapp/flutter_contact | runs=1 | themes=0 | examples=0 | hints=0 | 1.1s
# [2025-08-23 18:52:04] [310/383] ERR sunzxyong/tiny | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:52:05] [311/383] swiftdo/flutter_best_practice | runs=0 | themes=0 | examples=0 | hints=0 | 0.8s
# [2025-08-23 18:52:05] [312/383] swiftywang/toastbar | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:52:06] [313/383] ERR sz3/cfc | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-23 18:52:09] [314/383] takahirom/rin | runs=0 | themes=0 | examples=0 | hints=2 | 3.3s
# [2025-08-23 18:52:09] [315/383] ERR tangoagency/material-intro-screen | runs=0 | themes=0 | examples=0 | hints=1 | 0.3s
# [2025-08-23 18:52:10] [316/383] ERR taulabs/taulabs | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:52:10] [317/383] team-aliens/dms-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.5s
# [2025-08-23 18:52:14] [318/383] teamnewpipe/newplayer | runs=2 | themes=1 | examples=2 | hints=2 | 4.0s
# [2025-08-23 18:52:36] [319/383] techbeeat/jtxboard | runs=31 | themes=1 | examples=1 | hints=4 | 21.5s
# [2025-08-23 18:52:36] [320/383] telegram-sms/telegram-sms | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:52:37] [321/383] ERR tencent/matrix | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:52:37] [322/383] thealphamerc/flutter_pokedex | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:52:38] [323/383] thecodemonks/notzz-app | runs=0 | themes=0 | examples=0 | hints=1 | 0.6s
# [2025-08-23 18:52:39] [324/383] thecodemonks/nytimes-app | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 18:52:39] [325/383] ERR thegalfins/gnss_compare | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:52:45] [326/383] theoplayer/react-native-theoplayer | runs=6 | themes=1 | examples=3 | hints=2 | 6.0s
# [2025-08-23 18:52:46] [327/383] ERR thiagokimo/faker | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:52:46] [328/383] thyrlian/awesomevalidation | runs=0 | themes=0 | examples=0 | hints=7 | 0.6s
# [2025-08-23 18:52:47] [329/383] tiamo/flutter-concentric-transition | runs=0 | themes=0 | examples=0 | hints=0 | 0.6s
# [2025-08-23 18:53:06] [330/383] ERR tienisto/rhttp | runs=17 | themes=0 | examples=0 | hints=0 | 19.4s
# [2025-08-23 18:53:07] [331/383] ERR timotheejeannin/provigen | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:53:25] [332/383] ERR tmaegel/ntodotxt | runs=26 | themes=0 | examples=0 | hints=0 | 18.1s
# [2025-08-23 18:53:25] [333/383] ERR tomaszpolanski/flutter-animations | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:53:49] [334/383] tommy-geenexus/exif-eraser | runs=27 | themes=0 | examples=0 | hints=4 | 24.0s
# [2025-08-23 18:53:57] [335/383] ERR trackmyindoorworkout/trackmyindoorworkout | runs=2 | themes=0 | examples=0 | hints=0 | 7.4s
# [2025-08-23 18:53:57] [336/383] ERR travijuu/numberpicker | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:53:58] [337/383] trynoice/android-app | runs=0 | themes=0 | examples=0 | hints=3 | 1.0s
# [2025-08-23 18:53:58] [338/383] ERR tubb/calendarselector | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:53:59] [339/383] ERR twidereproject/twidere-android | runs=0 | themes=0 | examples=0 | hints=2 | 0.3s
# [2025-08-23 18:54:00] [340/383] twidereproject/twiderex-android | runs=0 | themes=0 | examples=0 | hints=4 | 1.3s
# [2025-08-23 18:54:00] [341/383] ERR txusballesteros/sliding-deck | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:54:01] [342/383] ERR tzutalin/android-object-detection | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 18:54:01] [343/383] ERR vanniktech/onactivityresult | runs=0 | themes=0 | examples=0 | hints=5 | 0.4s
# [2025-08-23 18:54:02] [344/383] ERR vasern/vasern | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:54:02] [345/383] ERR vashisthg/startpointseekbar | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:54:03] [346/383] vauvenal5/yaga | runs=0 | themes=0 | examples=0 | hints=1 | 0.9s
# [2025-08-23 18:54:36] [347/383] verygoodopensource/mockingjay | runs=60 | themes=0 | examples=0 | hints=0 | 33.6s
# [2025-08-23 18:54:38] [348/383] vhqtvn/vheditor-android | runs=0 | themes=0 | examples=0 | hints=1 | 1.2s
# [2025-08-23 18:54:38] [349/383] vitorhugods/avatarview | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 18:54:39] [350/383] ERR vpaliy/android-login | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 18:54:39] [351/383] ERR vratmit/thesingularity-unity | runs=0 | themes=0 | examples=0 | hints=3 | 0.4s
# [2025-08-23 18:54:49] [352/383] ERR wangwei1237/camerahook | runs=11 | themes=0 | examples=0 | hints=1 | 10.0s
# [2025-08-23 18:54:50] [353/383] ERR wavesplatform/waveswallet-android | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 18:54:53] [354/383] weixiansen574/hybridfilexfer | runs=5 | themes=0 | examples=0 | hints=2 | 3.5s
# [2025-08-23 18:54:53] [355/383] ERR whilu/androidtagview | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 18:55:09] [356/383] ERR why168/loopviewpagerlayout | runs=19 | themes=0 | examples=0 | hints=1 | 15.8s
# [2025-08-23 19:03:26] [WARN] Rate/403 on https://api.github.com/repos/wikimedia/apps-android-wikipedia/actions/runs/15451985038/logs. Rotating token. Diag={'status': 403, 'rate_remaining': '0', 'rate_reset': '1755991064', 'message': 'API rate limit exceeded for user ID 66279475. If you reach out to GitHub Support for help, please include the request ID CE53:38E4EC:1B7A07C:64AED3C:68AA48BE and timestamp 2025-08-23 23:03:26 UTC.'}
# [2025-08-23 19:10:49] [357/383] ERR wikimedia/apps-android-wikipedia | runs=0 | themes=0 | examples=0 | hints=2 | 940.0s
# [2025-08-23 19:10:50] [358/383] ERR wojta/no-server-webrtc-android | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 19:10:50] [359/383] ERR woxingxiao/fillblankview | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 19:11:06] [360/383] wuan/bo-android | runs=10 | themes=1 | examples=2 | hints=1 | 16.1s
# [2025-08-23 19:11:08] [361/383] wuba/fair | runs=0 | themes=0 | examples=0 | hints=0 | 2.0s
# [2025-08-23 19:11:08] [362/383] ERR xausky/unitymodmanager | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 19:11:21] [363/383] xiaoyaocz/dart_simple_live | runs=13 | themes=0 | examples=0 | hints=0 | 12.1s
# [2025-08-23 19:11:50] [364/383] xilinjia/podcini | runs=60 | themes=0 | examples=0 | hints=2 | 29.1s
# [2025-08-23 19:11:50] [365/383] ERR xingrz/cnode-android | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 19:11:50] [366/383] ERR xudaojie/multistateview | runs=0 | themes=0 | examples=0 | hints=4 | 0.4s
# [2025-08-23 19:11:51] [367/383] xuyuanxiang/umi-react-native | runs=0 | themes=0 | examples=0 | hints=3 | 0.9s
# [2025-08-23 19:11:53] [368/383] ERR xxfast/decompose-router | runs=0 | themes=0 | examples=0 | hints=2 | 1.8s
# [2025-08-23 19:11:54] [369/383] y-polek/transmissionremote | runs=0 | themes=0 | examples=0 | hints=1 | 1.1s
# [2025-08-23 19:11:55] [370/383] yanndroid/dualwallpaper | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 19:11:55] [371/383] ERR yeungeek/monkey-android | runs=0 | themes=0 | examples=0 | hints=2 | 0.4s
# [2025-08-23 19:11:56] [372/383] yggdrasil-network/yggdrasil-android | runs=0 | themes=0 | examples=0 | hints=1 | 1.3s
# [2025-08-23 19:11:57] [373/383] ERR yongjhih/android-proguards | runs=0 | themes=0 | examples=0 | hints=0 | 0.5s
# [2025-08-23 19:11:57] [374/383] ERR yoonit-labs/nativescript-yoonit-camera | runs=0 | themes=0 | examples=0 | hints=1 | 0.4s
# [2025-08-23 19:12:29] [375/383] ERR you-apps/translateyou | runs=49 | themes=0 | examples=0 | hints=1 | 31.5s
# [2025-08-23 19:12:41] [376/383] yurisizuku/onscripteryuri | runs=10 | themes=1 | examples=3 | hints=1 | 12.1s
# [2025-08-23 19:12:41] [377/383] ERR yydcdut/slideanddraglistview | runs=0 | themes=0 | examples=0 | hints=0 | 0.4s
# [2025-08-23 19:12:42] [378/383] zenitechsoftware/krate | runs=0 | themes=0 | examples=0 | hints=1 | 0.8s
# [2025-08-23 19:13:01] [379/383] zeshuaro/appainter | runs=17 | themes=1 | examples=2 | hints=0 | 19.1s
# [2025-08-23 19:13:18] [380/383] zhanghai/untracker | runs=33 | themes=0 | examples=0 | hints=0 | 16.7s
# [2025-08-23 19:13:53] [381/383] ERR zino-hofmann/graphql-flutter | runs=32 | themes=0 | examples=0 | hints=1 | 34.9s
# [2025-08-23 19:13:53] [382/383] zsoltk/compose-router | runs=0 | themes=0 | examples=0 | hints=1 | 0.7s
# [2025-08-23 19:13:57] [383/383] zt64/hyperion | runs=2 | themes=1 | examples=2 | hints=0 | 3.6s
# [2025-08-23 19:13:57] ===== DONE =====
# [2025-08-23 19:13:57] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_counts_weighted_high_only.csv
# [2025-08-23 19:13:57] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_counts_by_provider_weighted_high_only.csv
# [2025-08-23 19:13:57] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_examples_high_only.csv
# [2025-08-23 19:13:57] [INFO] Saved -> C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\CI_Taxomony_Analysis\challenge_run_audit_high_only.csv
# [2025-08-23 19:13:57] SUMMARY: repos=383 | total_runs_fetched=3192 | repos_with_any_hits=53 | elapsed=5321.9s
