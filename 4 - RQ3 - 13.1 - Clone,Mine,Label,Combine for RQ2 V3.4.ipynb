# %% [markdown]
# upgradeing the miner to pull the number of the changes to each style in dwelling period

# %% [markdown]
# # Step 1: Clone

# %%
from __future__ import annotations
import csv, os, re, subprocess, time
from pathlib import Path
from typing import Optional, List

# -----------------------------
# Config (edit as needed)
# -----------------------------
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
URL_LIST_CSV = WORK_ROOT / "URL_List.csv"
CLONE_ROOT   = WORK_ROOT / "clonesV9.0"
MANIFEST_CSV = WORK_ROOT / "clones_manifestV9.0.csv"

WITH_SUBMODULES = False     # set True if you want submodules initialized/updated
WITH_LFS        = False     # set True if you need Git LFS objects
FETCH_PR_REFS   = True      # set False to skip GitHub PR heads

# Create dirs
WORK_ROOT.mkdir(parents=True, exist_ok=True)
CLONE_ROOT.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Helpers
# -----------------------------
DEFAULT_TIMEOUT = 1800  # 30 minutes for huge repos
GIT_ENV = {"GIT_TERMINAL_PROMPT": "0", "GIT_ASKPASS": ""}

def sh(cmd: List[str], cwd: Optional[Path] = None, check: bool = True,
       capture: bool = True, timeout: Optional[int] = DEFAULT_TIMEOUT) -> subprocess.CompletedProcess:
    env = os.environ.copy()
    env.update(GIT_ENV)
    return subprocess.run(cmd, cwd=cwd, check=check,
                          capture_output=capture, text=True,
                          timeout=timeout, env=env)

def sh_ok(cmd: List[str], cwd: Optional[Path] = None, timeout: Optional[int] = DEFAULT_TIMEOUT) -> str:
    cp = sh(cmd, cwd=cwd, check=True, capture=True, timeout=timeout)
    return cp.stdout

def repo_dir_name_from_url(url: str) -> str:
    u = url.strip()
    # SSH form: git@host:owner/repo(.git)
    m = re.match(r"^[^@]+@([^:]+):([^/]+)/(.+?)(?:\.git)?$", u)
    if m:
        owner, name = m.group(2), m.group(3)
        return f"{owner}__{name}"
    # https://host/owner/repo(.git)
    if "://" in u:
        base = u.split("://", 1)[1]
    else:
        base = u
    parts = [p for p in base.split("/") if p]
    if len(parts) >= 2:
        owner, name = parts[-2], parts[-1].removesuffix(".git")
        return f"{owner}__{name}"
    return base.replace("/", "__").removesuffix(".git")

def ensure_full_clone(url: str, dest_root: Path,
                      with_submodules: bool = False,
                      with_lfs: bool = False,
                      fetch_pr_refs: bool = True) -> Path:
    """
    Ensures a non-shallow clone with full history of all branches & tags.
    Optionally fetches GitHub PR heads to refs/remotes/origin/pr/*,
    initializes submodules, and fetches LFS objects.
    """
    dest_root.mkdir(parents=True, exist_ok=True)
    d = dest_root / repo_dir_name_from_url(url)

    if not (d.exists() and (d / ".git").exists()):
        # no-recurse-submodules avoids submodule cost unless requested later
        sh(["git", "clone", "--no-recurse-submodules", "--tags", url, str(d)],
           capture=False)
    else:
        # If repo exists, ensure origin URL is correct
        sh(["git", "remote", "set-url", "origin", url], cwd=d, check=False)

    # If shallow, unshallow
    cp = sh(["git", "rev-parse", "--is-shallow-repository"], cwd=d, check=False)
    if cp.returncode == 0 and cp.stdout.strip() == "true":
        sh(["git", "fetch", "--unshallow", "--tags"], cwd=d, capture=False)
    else:
        # Make sure we have tags even if already full
        sh(["git", "fetch", "--tags"], cwd=d, check=False, capture=False)

    # Fetch all branches under refs/heads/* and prune deleted ones
    sh(["git", "fetch", "origin", "--prune", "--tags",
        "+refs/heads/*:refs/remotes/origin/*", "--quiet"], cwd=d, check=False, capture=False)

    # Best-effort PR refs (GitHub); harmless if not present
    if fetch_pr_refs:
        sh(["git", "fetch", "origin",
            "+refs/pull/*/head:refs/remotes/origin/pr/*", "--quiet"], cwd=d, check=False, capture=False)

    # Optional: submodules
    if with_submodules:
        sh(["git", "submodule", "update", "--init", "--recursive"], cwd=d, capture=False)

    # Optional: LFS
    if with_lfs:
        # If git-lfs isn't installed, these will fail harmlessly due to check=False
        sh(["git", "lfs", "install"], cwd=d, check=False, capture=False)
        sh(["git", "lfs", "fetch", "--all"], cwd=d, check=False, capture=False)
        sh(["git", "lfs", "checkout"], cwd=d, check=False, capture=False)

    return d

def get_total_commits(repo_dir: Path) -> int:
    # Count across all refs reachable in the repository
    cp = sh(["git", "rev-list", "--all", "--count"], cwd=repo_dir, check=False)
    try:
        return int((cp.stdout or "0").strip() or "0")
    except Exception:
        return 0

# -----------------------------
# Main: FULL CLONE ONLY
# -----------------------------
assert URL_LIST_CSV.exists(), f"CSV not found: {URL_LIST_CSV}"

rows, ok, fail = [], 0, 0
with URL_LIST_CSV.open(newline="", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        url = (row.get("repo_url") or "").strip()
        if not url:
            continue
        t0 = time.time()
        rec = {
            "repo_url": url,
            "dir": None,
            "status": "unknown",
            "seconds": None,
            "total_commits": None,
            "error": ""
        }
        try:
            d = ensure_full_clone(url, CLONE_ROOT,
                                  with_submodules=WITH_SUBMODULES,
                                  with_lfs=WITH_LFS,
                                  fetch_pr_refs=FETCH_PR_REFS)
            rec["dir"] = str(d)
            rec["total_commits"] = get_total_commits(d)
            rec["status"] = "ok"
            ok += 1
        except subprocess.CalledProcessError as e:
            rec["status"] = "error"
            rec["error"]  = (e.stderr or e.stdout or str(e)).strip()[:2000]
            fail += 1
        except Exception as e:
            rec["status"] = "error"
            rec["error"]  = str(e)[:2000]
            fail += 1

        rec["seconds"] = round(time.time() - t0, 2)
        rows.append(rec)
        print(f"[{rec['status']}] {url} -> {rec['dir']} ({rec['seconds']}s)  commits={rec['total_commits']}")

# Write manifest
MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
fieldnames = ["repo_url","dir","status","seconds","total_commits","error"]
with MANIFEST_CSV.open("w", newline="", encoding="utf-8") as f:
    w = csv.DictWriter(f, fieldnames=fieldnames)
    w.writeheader()
    w.writerows(rows)

print(f"\nDone. OK={ok}, FAIL={fail}. Manifest: {MANIFEST_CSV}")
# Out:
# [ok] https://github.com/connectbot/connectbot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\connectbot__connectbot (6.63s)  commits=3640
# [ok] https://github.com/robolectric/robolectric -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\robolectric__robolectric (27.72s)  commits=21440
# [ok] https://github.com/opendocument-app/OpenDocument.droid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\opendocument-app__OpenDocument.droid (12.64s)  commits=6083
# [ok] https://github.com/maxpower47/PinDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\maxpower47__PinDroid (5.26s)  commits=1057
# [ok] https://github.com/Rajawali/Rajawali -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Rajawali__Rajawali (17.48s)  commits=3065
# [ok] https://github.com/cgeo/cgeo -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\cgeo__cgeo (120.39s)  commits=73654
# [ok] https://github.com/OneBusAway/onebusaway-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\OneBusAway__onebusaway-android (7.44s)  commits=4378
# [ok] https://github.com/MikeOrtiz/TouchImageView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MikeOrtiz__TouchImageView (5.58s)  commits=1137
# [ok] https://github.com/labexp/osmtracker-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\labexp__osmtracker-android (4.48s)  commits=1864
# [ok] https://github.com/AndBible/and-bible -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AndBible__and-bible (31.7s)  commits=12954
# [ok] https://github.com/maxistar/TextPad -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\maxistar__TextPad (3.18s)  commits=362
# [ok] https://github.com/spacecowboy/NotePad -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\spacecowboy__NotePad (8.01s)  commits=3150
# [ok] https://github.com/persian-calendar/persian-calendar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\persian-calendar__persian-calendar (12.21s)  commits=12325
# [ok] https://github.com/inaturalist/iNaturalistAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\inaturalist__iNaturalistAndroid (18.8s)  commits=3589
# [ok] https://github.com/yuriykulikov/AlarmClock -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\yuriykulikov__AlarmClock (47.29s)  commits=2730
# [ok] https://github.com/openintents/shoppinglist -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\openintents__shoppinglist (4.68s)  commits=553
# [ok] https://github.com/square/okhttp -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__okhttp (29.1s)  commits=13665
# [ok] https://github.com/AntennaPod/AntennaPod -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AntennaPod__AntennaPod (47.49s)  commits=14716
# [ok] https://github.com/ragunathjawahar/android-saripaar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ragunathjawahar__android-saripaar (2.0s)  commits=345
# [ok] https://github.com/fossasia/phimpme-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\fossasia__phimpme-android (151.63s)  commits=7821
# [ok] https://github.com/xebia-functional/appsly-android-rest -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\xebia-functional__appsly-android-rest (2.1s)  commits=209
# [ok] https://github.com/ankidroid/Anki-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ankidroid__Anki-Android (89.67s)  commits=47674
# [ok] https://github.com/ligi/PassAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ligi__PassAndroid (3.66s)  commits=2328
# [ok] https://github.com/segler-alex/RadioDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\segler-alex__RadioDroid (3.55s)  commits=1764
# [ok] https://github.com/ksoichiro/AndroidFormEnhancer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ksoichiro__AndroidFormEnhancer (1.59s)  commits=149
# [ok] https://github.com/cloudinary/cloudinary_android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\cloudinary__cloudinary_android (2.22s)  commits=660
# [ok] https://github.com/dmfs/opentasks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dmfs__opentasks (12.46s)  commits=1538
# [ok] https://github.com/square/wire -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__wire (10.35s)  commits=7286
# [ok] https://github.com/tasks/tasks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\tasks__tasks (28.54s)  commits=15738
# [ok] https://github.com/simonnorberg/dmach -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\simonnorberg__dmach (2.52s)  commits=225
# [ok] https://github.com/wikimedia/apps-android-wikipedia -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\wikimedia__apps-android-wikipedia (93.63s)  commits=40991
# [ok] https://github.com/splitwise/TokenAutoComplete -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\splitwise__TokenAutoComplete (1.75s)  commits=428
# [ok] https://github.com/grote/Transportr -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\grote__Transportr (10.78s)  commits=1910
# [ok] https://github.com/anjlab/android-inapp-billing-v3 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\anjlab__android-inapp-billing-v3 (1.89s)  commits=583
# [ok] https://github.com/federicoiosue/Omni-Notes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\federicoiosue__Omni-Notes (14.21s)  commits=3789
# [ok] https://github.com/rejasupotaro/Rebuild -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rejasupotaro__Rebuild (4.68s)  commits=672
# [ok] https://github.com/owntracks/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\owntracks__android (26.19s)  commits=6427
# [ok] https://github.com/dlew/joda-time-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dlew__joda-time-android (2.68s)  commits=548
# [ok] https://github.com/TomRoush/PdfBox-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TomRoush__PdfBox-Android (15.08s)  commits=748
# [ok] https://github.com/AChep/AcDisplay -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AChep__AcDisplay (4.85s)  commits=1156
# [ok] https://github.com/mathisdt/trackworktime -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\mathisdt__trackworktime (3.03s)  commits=1082
# [ok] https://github.com/ksoichiro/SimpleAlertDialog-for-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ksoichiro__SimpleAlertDialog-for-Android (1.79s)  commits=157
# [ok] https://github.com/openhab/openhab-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\openhab__openhab-android (26.71s)  commits=14860
# [ok] https://github.com/amahi/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\amahi__android (5.95s)  commits=1909
# [ok] https://github.com/EvanRespaut/Equate -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\EvanRespaut__Equate (1.98s)  commits=419
# [ok] https://github.com/OpnTec/bodyapps-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\OpnTec__bodyapps-android (2.02s)  commits=160
# [ok] https://github.com/blazsolar/android-collapse-calendar-view -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\blazsolar__android-collapse-calendar-view (1.66s)  commits=99
# [ok] https://github.com/spacecowboy/Feeder -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\spacecowboy__Feeder (26.86s)  commits=5114
# [ok] https://github.com/TeamAmaze/AmazeFileManager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TeamAmaze__AmazeFileManager (21.34s)  commits=9036
# [ok] https://github.com/tripadvisor/android-clockseekbar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\tripadvisor__android-clockseekbar (2.01s)  commits=65
# [ok] https://github.com/ksoichiro/Android-ObservableScrollView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ksoichiro__Android-ObservableScrollView (3.82s)  commits=430
# [ok] https://github.com/smartdevicelink/sdl_java_suite -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\smartdevicelink__sdl_java_suite (25.61s)  commits=7977
# [ok] https://github.com/thyrlian/AwesomeValidation -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\thyrlian__AwesomeValidation (1.77s)  commits=482
# [ok] https://github.com/MostafaGazar/soas -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MostafaGazar__soas (2.23s)  commits=69
# [ok] https://github.com/Stuart-campbell/RushOrm -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Stuart-campbell__RushOrm (1.65s)  commits=216
# [ok] https://github.com/posm/OpenMapKitAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\posm__OpenMapKitAndroid (23.35s)  commits=619
# [ok] https://github.com/CarlosMChica/easyrecycleradapters -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\CarlosMChica__easyrecycleradapters (1.5s)  commits=161
# [ok] https://github.com/kost/NetworkMapper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\kost__NetworkMapper (1.2s)  commits=71
# [ok] https://github.com/dart-lang/http -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dart-lang__http (6.27s)  commits=4345
# [ok] https://github.com/JakeWharton/RxBinding -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\JakeWharton__RxBinding (2.38s)  commits=1003
# [ok] https://github.com/moezbhatti/qksms -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\moezbhatti__qksms (8.18s)  commits=2673
# [ok] https://github.com/takahirom/PreLollipopTransition -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\takahirom__PreLollipopTransition (1.43s)  commits=169
# [ok] https://github.com/ooni/probe-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ooni__probe-android (32.41s)  commits=4444
# [ok] https://github.com/hitherejoe/HackerNewsReader -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hitherejoe__HackerNewsReader (1.95s)  commits=78
# [ok] https://github.com/zsoltk/GameOfLife -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\zsoltk__GameOfLife (2.28s)  commits=160
# [ok] https://github.com/talenguyen/PrettyBundle -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\talenguyen__PrettyBundle (1.32s)  commits=76
# [ok] https://github.com/fewlaps/flone-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\fewlaps__flone-android (5.88s)  commits=152
# [ok] https://github.com/square/leakcanary -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__leakcanary (30.16s)  commits=3615
# [ok] https://github.com/rtoshiro/FullscreenVideoView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rtoshiro__FullscreenVideoView (1.35s)  commits=55
# [ok] https://github.com/kebernet/shortyz -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\kebernet__shortyz (2.78s)  commits=174
# [ok] https://github.com/Redgram/redgram-for-reddit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Redgram__redgram-for-reddit (2.11s)  commits=328
# [ok] https://github.com/servo/surfman -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\servo__surfman (2.63s)  commits=1265
# [ok] https://github.com/pilgr/Paper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\pilgr__Paper (1.59s)  commits=332
# [ok] https://github.com/sky-map-team/stardroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sky-map-team__stardroid (7.25s)  commits=1611
# [ok] https://github.com/MichaelEvans/Aftermath -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MichaelEvans__Aftermath (1.69s)  commits=40
# [ok] https://github.com/thiagokimo/Faker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\thiagokimo__Faker (1.5s)  commits=74
# [ok] https://github.com/concretesolutions/canarinho -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\concretesolutions__canarinho (1.49s)  commits=186
# [ok] https://github.com/commons-app/apps-android-commons -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\commons-app__apps-android-commons (96.23s)  commits=17582
# [ok] https://github.com/TeamNewPipe/NewPipe -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TeamNewPipe__NewPipe (32.64s)  commits=15485
# [ok] https://github.com/promeG/TinyPinyin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\promeG__TinyPinyin (1.47s)  commits=36
# [ok] https://github.com/AAkira/ExpandableLayout -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AAkira__ExpandableLayout (4.96s)  commits=193
# [ok] https://github.com/hitherejoe/MVVM_Hacker_News -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hitherejoe__MVVM_Hacker_News (2.33s)  commits=109
# [ok] https://github.com/kakajika/SwipeAwayDialog -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\kakajika__SwipeAwayDialog (1.74s)  commits=32
# [ok] https://github.com/getodk/collect -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\getodk__collect (33.82s)  commits=27217
# [ok] https://github.com/hannesa2/panoramaGL -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hannesa2__panoramaGL (5.98s)  commits=825
# [ok] https://github.com/ajitsing/ExpenseManager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ajitsing__ExpenseManager (1.41s)  commits=108
# [ok] https://github.com/4eRTuk/audioview -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\4eRTuk__audioview (1.53s)  commits=107
# [ok] https://github.com/sqldelight/sqldelight -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sqldelight__sqldelight (58.38s)  commits=10120
# [ok] https://github.com/sangcomz/FishBun -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sangcomz__FishBun (10.84s)  commits=784
# [ok] https://github.com/requery/requery -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\requery__requery (2.35s)  commits=970
# [ok] https://github.com/fossasia/loklak_wok_android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\fossasia__loklak_wok_android (16.25s)  commits=164
# [ok] https://github.com/andreynovikov/trekarta -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\andreynovikov__trekarta (20.98s)  commits=1705
# [ok] https://github.com/liangpengfei/LoadingPopPoint -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\liangpengfei__LoadingPopPoint (1.43s)  commits=25
# [ok] https://github.com/douzifly/clear-todolist -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\douzifly__clear-todolist (4.19s)  commits=127
# [ok] https://github.com/VREMSoftwareDevelopment/WiFiAnalyzer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\VREMSoftwareDevelopment__WiFiAnalyzer (6.68s)  commits=2123
# [ok] https://github.com/XuDaojie/MultiStateView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\XuDaojie__MultiStateView (1.23s)  commits=85
# [ok] https://github.com/TUBB/CalendarSelector -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TUBB__CalendarSelector (5.36s)  commits=49
# [ok] https://github.com/greenaddress/abcore -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\greenaddress__abcore (3.91s)  commits=435
# [ok] https://github.com/woxingxiao/FillBlankView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\woxingxiao__FillBlankView (1.21s)  commits=52
# [ok] https://github.com/FabianTerhorst/Iron -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\FabianTerhorst__Iron (1.32s)  commits=218
# [ok] https://github.com/riggaroo/AndroidDatabaseUpgrades -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\riggaroo__AndroidDatabaseUpgrades (1.15s)  commits=16
# [ok] https://github.com/amitshekhariitbhu/Fast-Android-Networking -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\amitshekhariitbhu__Fast-Android-Networking (2.05s)  commits=714
# [ok] https://github.com/voghDev/PdfViewPager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\voghDev__PdfViewPager (4.08s)  commits=281
# [ok] https://github.com/renyuneyun/Easer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\renyuneyun__Easer (3.26s)  commits=1631
# [ok] https://github.com/nukc/StateView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nukc__StateView (1.84s)  commits=86
# [ok] https://github.com/yeungeek/monkey-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\yeungeek__monkey-android (3.46s)  commits=124
# [ok] https://github.com/maksim-m/Popular-Movies-App -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\maksim-m__Popular-Movies-App (6.18s)  commits=157
# [ok] https://github.com/RoRoche/AndroidStarter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\RoRoche__AndroidStarter (3.93s)  commits=93
# [ok] https://github.com/ValentinFunk/BrainPhaser -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ValentinFunk__BrainPhaser (3.6s)  commits=411
# [ok] https://github.com/tonilopezmr/Game-of-Thrones -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\tonilopezmr__Game-of-Thrones (2.87s)  commits=230
# [ok] https://github.com/SecUSo/privacy-friendly-notes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\SecUSo__privacy-friendly-notes (2.03s)  commits=646
# [ok] https://github.com/SecUSo/privacy-friendly-todo-list -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\SecUSo__privacy-friendly-todo-list (11.52s)  commits=697
# [ok] https://github.com/dbrodie/AdBuster -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dbrodie__AdBuster (1.35s)  commits=101
# [ok] https://github.com/nextcloud/android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nextcloud__android (170.83s)  commits=59054
# [ok] https://github.com/javiersantos/PiracyChecker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\javiersantos__PiracyChecker (3.0s)  commits=300
# [ok] https://github.com/karonl/InDoorSurfaceView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\karonl__InDoorSurfaceView (2.0s)  commits=67
# [ok] https://github.com/miguelhincapie/CustomBottomSheetBehavior -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\miguelhincapie__CustomBottomSheetBehavior (2.88s)  commits=171
# [ok] https://github.com/SecUSo/privacy-friendly-pedometer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\SecUSo__privacy-friendly-pedometer (4.82s)  commits=515
# [ok] https://github.com/y-polek/TransmissionRemote -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\y-polek__TransmissionRemote (3.08s)  commits=953
# [ok] https://github.com/medic/cht-gateway -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\medic__cht-gateway (1.84s)  commits=822
# [ok] https://github.com/cliqz-oss/browser-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\cliqz-oss__browser-android (9.79s)  commits=927
# [ok] https://github.com/andremion/Villains-and-Heroes -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\andremion__Villains-and-Heroes (8.05s)  commits=129
# [ok] https://github.com/leandroBorgesFerreira/LoadingButtonAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\leandroBorgesFerreira__LoadingButtonAndroid (4.94s)  commits=380
# [ok] https://github.com/jaredsburrows/android-gif-search -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jaredsburrows__android-gif-search (3.39s)  commits=2613
# [ok] https://github.com/beemdevelopment/Aegis -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\beemdevelopment__Aegis (7.3s)  commits=1914
# [ok] https://github.com/nukc/LoadMoreWrapper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nukc__LoadMoreWrapper (1.45s)  commits=73
# [ok] https://github.com/ligi/SurvivalManual -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ligi__SurvivalManual (3.05s)  commits=805
# [ok] https://github.com/gotev/android-speech -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\gotev__android-speech (1.51s)  commits=170
# [ok] https://github.com/Piasy/YaMvp -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Piasy__YaMvp (1.28s)  commits=12
# [ok] https://github.com/FabianTerhorst/Floppy -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\FabianTerhorst__Floppy (1.27s)  commits=77
# [ok] https://github.com/guardianproject/proofmode-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\guardianproject__proofmode-android (14.43s)  commits=925
# [ok] https://github.com/vgaidarji/ci-matters -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\vgaidarji__ci-matters (3.64s)  commits=178
# [ok] https://github.com/freeotp/freeotp-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\freeotp__freeotp-android (2.17s)  commits=615
# [ok] https://github.com/VictorAlbertos/BreadcrumbsView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\VictorAlbertos__BreadcrumbsView (1.41s)  commits=12
# [ok] https://github.com/ronaldsmartin/Material-ViewPagerIndicator -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ronaldsmartin__Material-ViewPagerIndicator (1.48s)  commits=130
# [ok] https://github.com/VictorAlbertos/SwipeCoordinator -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\VictorAlbertos__SwipeCoordinator (1.33s)  commits=9
# [ok] https://github.com/kickstarter/android-oss -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\kickstarter__android-oss (24.5s)  commits=18514
# [ok] https://github.com/michelelacorte/AndroidAppShortcuts -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\michelelacorte__AndroidAppShortcuts (1.76s)  commits=146
# [ok] https://github.com/massivedisaster/ADAL -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\massivedisaster__ADAL (4.53s)  commits=598
# [ok] https://github.com/getsentry/sentry-react-native -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\getsentry__sentry-react-native (26.32s)  commits=12777
# [ok] https://github.com/AdevintaSpain/Barista -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AdevintaSpain__Barista (2.79s)  commits=1675
# [ok] https://github.com/bilibili/boxing -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\bilibili__boxing (1.72s)  commits=139
# [ok] https://github.com/jungilhan/awesome-blogs-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jungilhan__awesome-blogs-android (2.77s)  commits=292
# [ok] https://github.com/MarcinMoskala/PreferenceHolder -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MarcinMoskala__PreferenceHolder (1.44s)  commits=129
# [ok] https://github.com/NiciDieNase/chaosflix -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\NiciDieNase__chaosflix (4.14s)  commits=1612
# [ok] https://github.com/adorsys/secure-storage-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\adorsys__secure-storage-android (2.41s)  commits=325
# [ok] https://github.com/JimmyDaddy/react-native-image-marker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\JimmyDaddy__react-native-image-marker (10.95s)  commits=436
# [ok] https://github.com/xurxodev/Movies-Kotlin-Kata -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\xurxodev__Movies-Kotlin-Kata (1.39s)  commits=60
# [ok] https://github.com/HYY-yu/TableRecyclerView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\HYY-yu__TableRecyclerView (2.89s)  commits=44
# [ok] https://github.com/zoff99/ToxAndroidRefImpl -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\zoff99__ToxAndroidRefImpl (37.19s)  commits=6062
# [ok] https://github.com/gdky005/AndroidBadge -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\gdky005__AndroidBadge (3.75s)  commits=25
# [ok] https://github.com/EventFahrplan/EventFahrplan -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\EventFahrplan__EventFahrplan (6.3s)  commits=4344
# [ok] https://github.com/jianjunxiao/NiceVieoPlayer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jianjunxiao__NiceVieoPlayer (4.33s)  commits=120
# [ok] https://github.com/livefront/bridge -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\livefront__bridge (1.48s)  commits=175
# [ok] https://github.com/glpi-project/android-inventory-agent -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\glpi-project__android-inventory-agent (6.63s)  commits=3424
# [ok] https://github.com/invertase/notifee -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\invertase__notifee (9.48s)  commits=2258
# [ok] https://github.com/mapbox/store-locator-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\mapbox__store-locator-android (4.07s)  commits=204
# [ok] https://github.com/syrjs/core -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\syrjs__core (3.44s)  commits=1085
# [ok] https://github.com/seedvault-app/seedvault -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\seedvault-app__seedvault (62.41s)  commits=2324
# [ok] https://github.com/jerryOkafor/TimeLineView -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jerryOkafor__TimeLineView (1.62s)  commits=33
# [ok] https://github.com/dgngulcan/droid-feed -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dgngulcan__droid-feed (3.72s)  commits=506
# [ok] https://github.com/appmattus/layercache -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\appmattus__layercache (2.04s)  commits=247
# [ok] https://github.com/airbnb/paris -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\airbnb__paris (6.78s)  commits=650
# [ok] https://github.com/sellmair/kompass -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sellmair__kompass (7.31s)  commits=297
# [ok] https://github.com/Crazy-Marvin/MetadataRemover -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Crazy-Marvin__MetadataRemover (14.31s)  commits=730
# [ok] https://github.com/PureWriter/ToastCompat -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\PureWriter__ToastCompat (1.53s)  commits=39
# [ok] https://github.com/brarcher/video-transcoder -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\brarcher__video-transcoder (8.99s)  commits=405
# [ok] https://github.com/AndProx/AndProx -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AndProx__AndProx (1.73s)  commits=191
# [ok] https://github.com/BlueWallet/BlueWallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\BlueWallet__BlueWallet (127.0s)  commits=22286
# [ok] https://github.com/Criptext/Android-Email-Client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Criptext__Android-Email-Client (6.07s)  commits=1356
# [ok] https://github.com/PRosenb/AdbClipboard -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\PRosenb__AdbClipboard (1.39s)  commits=92
# [ok] https://github.com/izderadicka/audioserve-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\izderadicka__audioserve-android (1.67s)  commits=253
# [ok] https://github.com/CypherpunkArmory/UserLAnd -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\CypherpunkArmory__UserLAnd (5.95s)  commits=2457
# [ok] https://github.com/simpledotorg/simple-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\simpledotorg__simple-android (24.14s)  commits=37033
# [ok] https://github.com/nhirokinet/bluelineconsole -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nhirokinet__bluelineconsole (3.23s)  commits=722
# [ok] https://github.com/NUmeroAndDev/MaterialGallery-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\NUmeroAndDev__MaterialGallery-android (2.75s)  commits=1795
# [ok] https://github.com/letelete/sleep-cycle-alarm -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\letelete__sleep-cycle-alarm (10.33s)  commits=513
# [ok] https://github.com/MetaMask/metamask-mobile -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MetaMask__metamask-mobile (489.45s)  commits=117462
# [ok] https://github.com/admob-plus/admob-plus -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\admob-plus__admob-plus (7.49s)  commits=2765
# [ok] https://github.com/software-mansion/react-native-screens -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\software-mansion__react-native-screens (25.54s)  commits=14237
# [ok] https://github.com/Samsung/escargot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Samsung__escargot (39.2s)  commits=4136
# [ok] https://github.com/oxygen-updater/oxygen-updater -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\oxygen-updater__oxygen-updater (5.2s)  commits=1351
# [ok] https://github.com/uber/simple-store -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\uber__simple-store (1.87s)  commits=264
# [ok] https://github.com/cuongpm/youtube-dl-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\cuongpm__youtube-dl-android (1.8s)  commits=81
# [ok] https://github.com/ActivityWatch/aw-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ActivityWatch__aw-android (1.73s)  commits=370
# [ok] https://github.com/liihuu/KLineChartAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\liihuu__KLineChartAndroid (3.88s)  commits=121
# [ok] https://github.com/UriahShaulMandel/BaldPhone -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\UriahShaulMandel__BaldPhone (32.31s)  commits=1911
# [ok] https://github.com/GabrielBB/Android-CutOut -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\GabrielBB__Android-CutOut (2.3s)  commits=38
# [ok] https://github.com/Albert221/FastShopping -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Albert221__FastShopping (14.81s)  commits=631
# [ok] https://github.com/readrops/Readrops -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\readrops__Readrops (4.26s)  commits=1619
# [ok] https://github.com/hannesstruss/unearthed -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hannesstruss__unearthed (1.42s)  commits=77
# [ok] https://github.com/twireapp/Twire -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\twireapp__Twire (8.54s)  commits=1016
# [ok] https://github.com/rainbow-me/rainbow -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rainbow-me__rainbow (96.02s)  commits=44766
# [ok] https://github.com/trynoice/android-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\trynoice__android-app (37.1s)  commits=4140
# [ok] https://github.com/evilcorpltd/aTox -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\evilcorpltd__aTox (3.31s)  commits=1568
# [ok] https://github.com/haroldadmin/MoonShot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\haroldadmin__MoonShot (1.82s)  commits=400
# [ok] https://github.com/jimmod/ShareToComputer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jimmod__ShareToComputer (1.82s)  commits=170
# [ok] https://github.com/willowtreeapps/vocable-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\willowtreeapps__vocable-android (2.47s)  commits=1632
# [ok] https://github.com/agoda-com/ninjato -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\agoda-com__ninjato (1.55s)  commits=189
# [ok] https://github.com/ipfs-shipyard/gomobile-ipfs -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ipfs-shipyard__gomobile-ipfs (2.91s)  commits=514
# [ok] https://github.com/coil-kt/coil -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\coil-kt__coil (27.59s)  commits=9195
# [ok] https://github.com/DroidKaigi/conference-app-2020 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\DroidKaigi__conference-app-2020 (13.47s)  commits=2218
# [ok] https://github.com/lolo-io/OneList -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\lolo-io__OneList (3.23s)  commits=248
# [ok] https://github.com/OpenTracksApp/OpenTracks -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\OpenTracksApp__OpenTracks (20.43s)  commits=8390
# [ok] https://github.com/natario1/GIFCompressor -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\natario1__GIFCompressor (1.87s)  commits=196
# [ok] https://github.com/fluttercommunity/flutter_workmanager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\fluttercommunity__flutter_workmanager (13.35s)  commits=910
# [ok] https://github.com/ivnsch/rust_android_ios -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ivnsch__rust_android_ios (2.0s)  commits=63
# [ok] https://github.com/ThibaultBee/srtdroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ThibaultBee__srtdroid (2.28s)  commits=388
# [ok] https://github.com/kylecorry31/Trail-Sense -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\kylecorry31__Trail-Sense (43.78s)  commits=10603
# [ok] https://github.com/tfcporciuncula/flow-preferences -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\tfcporciuncula__flow-preferences (1.62s)  commits=153
# [ok] https://github.com/n8ebel/GitHubActionsAutomationSandbox -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\n8ebel__GitHubActionsAutomationSandbox (1.59s)  commits=144
# [ok] https://github.com/joreilly/PeopleInSpace -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\joreilly__PeopleInSpace (15.22s)  commits=1224
# [ok] https://github.com/realm/realm-kotlin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\realm__realm-kotlin (12.88s)  commits=8677
# [ok] https://github.com/square/cycler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__cycler (1.54s)  commits=128
# [ok] https://github.com/hitherejoe/minimise -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hitherejoe__minimise (2.29s)  commits=344
# [ok] https://github.com/vmiklos/plees-tracker -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\vmiklos__plees-tracker (7.4s)  commits=1185
# [ok] https://github.com/gotev/android-cookie-store -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\gotev__android-cookie-store (1.45s)  commits=122
# [ok] https://github.com/ReactiveCircus/streamlined -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ReactiveCircus__streamlined (2.04s)  commits=767
# [ok] https://github.com/ValterKasper/space-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ValterKasper__space-app (2.23s)  commits=192
# [ok] https://github.com/H-PixelDroid/PixelDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\H-PixelDroid__PixelDroid (22.98s)  commits=2870
# [ok] https://github.com/Tommy-Geenexus/exif-eraser -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Tommy-Geenexus__exif-eraser (3.64s)  commits=338
# [ok] https://github.com/RedMadRobot/PINkman -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\RedMadRobot__PINkman (1.59s)  commits=105
# [ok] https://github.com/MiSikora/laboratory -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MiSikora__laboratory (2.62s)  commits=1390
# [ok] https://github.com/nschnettler/Compose-Scrobbler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nschnettler__Compose-Scrobbler (3.61s)  commits=863
# [ok] https://github.com/rosuH/EasyWatermark -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rosuH__EasyWatermark (8.9s)  commits=847
# [ok] https://github.com/sakusaku3939/DeepLAndroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sakusaku3939__DeepLAndroid (2.0s)  commits=429
# [ok] https://github.com/softartdev/NoteDelight -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\softartdev__NoteDelight (7.06s)  commits=1619
# [ok] https://github.com/AdamMc331/AndroidStudyGuide -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\AdamMc331__AndroidStudyGuide (1.58s)  commits=326
# [ok] https://github.com/hoc081098/ViewBindingDelegate -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\hoc081098__ViewBindingDelegate (2.47s)  commits=532
# [ok] https://github.com/tfcporciuncula/phonemoji -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\tfcporciuncula__phonemoji (1.46s)  commits=58
# [ok] https://github.com/PatilShreyas/NotyKT -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\PatilShreyas__NotyKT (3.91s)  commits=2178
# [ok] https://github.com/android/codelab-android-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\android__codelab-android-compose (32.47s)  commits=1739
# [ok] https://github.com/TwidereProject/TwidereX-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TwidereProject__TwidereX-Android (4.26s)  commits=2755
# [ok] https://github.com/nightscout/AndroidAPS -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nightscout__AndroidAPS (58.15s)  commits=51656
# [ok] https://github.com/MackHartley/RoundedProgressBar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\MackHartley__RoundedProgressBar (4.5s)  commits=216
# [ok] https://github.com/rozPierog/Cofi -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rozPierog__Cofi (8.36s)  commits=1784
# [ok] https://github.com/ErickSumargo/Dads -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ErickSumargo__Dads (4.36s)  commits=283
# [ok] https://github.com/alexbakker/webdav-provider -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\alexbakker__webdav-provider (1.77s)  commits=133
# [ok] https://github.com/thunderbiscuit/padawan-wallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\thunderbiscuit__padawan-wallet (3.36s)  commits=1370
# [ok] https://github.com/lcdsmao/JetTheme -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\lcdsmao__JetTheme (1.59s)  commits=176
# [ok] https://github.com/yogeshpaliyal/KeyPass -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\yogeshpaliyal__KeyPass (13.22s)  commits=3642
# [ok] https://github.com/square/curtains -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__curtains (1.89s)  commits=135
# [ok] https://github.com/Spikeysanju/Wiggles -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Spikeysanju__Wiggles (7.47s)  commits=33
# [ok] https://github.com/wajahatkarim3/Imagine -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\wajahatkarim3__Imagine (4.39s)  commits=274
# [ok] https://github.com/jeziellago/Linkt -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jeziellago__Linkt (1.22s)  commits=6
# [ok] https://github.com/riggaroo/adopt-me-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\riggaroo__adopt-me-compose (5.98s)  commits=47
# [ok] https://github.com/guolindev/android-dev-challenge-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\guolindev__android-dev-challenge-compose (4.66s)  commits=16
# [ok] https://github.com/GerardPaligot/android-countdown -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\GerardPaligot__android-countdown (2.51s)  commits=6
# [ok] https://github.com/okanaydin/Android-Compose-Challenge -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\okanaydin__Android-Compose-Challenge (2.0s)  commits=5
# [ok] https://github.com/a914-gowtham/compose-ratingbar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\a914-gowtham__compose-ratingbar (1.92s)  commits=220
# [ok] https://github.com/joreilly/StarWars -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\joreilly__StarWars (3.15s)  commits=398
# [ok] https://github.com/pauloaapereira/AndroidDevChallenge_Week4_JetWeatherfy -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\pauloaapereira__AndroidDevChallenge_Week4_JetWeatherfy (2.82s)  commits=62
# [ok] https://github.com/vitaviva/compose-weather -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\vitaviva__compose-weather (10.24s)  commits=32
# [ok] https://github.com/KaustubhPatange/navigator -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\KaustubhPatange__navigator (2.21s)  commits=226
# [ok] https://github.com/arkivanov/android-dev-challenge-compose-2 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\arkivanov__android-dev-challenge-compose-2 (8.9s)  commits=4
# [ok] https://github.com/vitaviva/CountdownTimer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\vitaviva__CountdownTimer (6.79s)  commits=11
# [ok] https://github.com/WangJie0822/Cashbook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\WangJie0822__Cashbook (7.09s)  commits=1396
# [ok] https://github.com/RBusarow/Tangle -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\RBusarow__Tangle (3.7s)  commits=1636
# [ok] https://github.com/michaeltroger/pdfwallet-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\michaeltroger__pdfwallet-android (15.96s)  commits=2182
# [ok] https://github.com/nanihadesuka/NovelDokusha -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nanihadesuka__NovelDokusha (3.77s)  commits=917
# [ok] https://github.com/OlauncherCF/OlauncherCF -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\OlauncherCF__OlauncherCF (21.02s)  commits=1631
# [ok] https://github.com/doublesymmetry/KotlinAudio -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\doublesymmetry__KotlinAudio (4.32s)  commits=533
# [ok] https://github.com/bitfireAT/davx5-ose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\bitfireAT__davx5-ose (13.95s)  commits=7180
# [ok] https://github.com/alexstyl/contactstore -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\alexstyl__contactstore (1.82s)  commits=340
# [ok] https://github.com/square/papa -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\square__papa (1.62s)  commits=331
# [ok] https://github.com/bitfireAT/icsx5 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\bitfireAT__icsx5 (2.73s)  commits=2138
# [ok] https://github.com/burnoo/cokoin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\burnoo__cokoin (1.42s)  commits=133
# [ok] https://github.com/scribe-org/Scribe-Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\scribe-org__Scribe-Android (25.75s)  commits=1595
# [ok] https://github.com/StefanIlchev/ElementumService -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\StefanIlchev__ElementumService (16.94s)  commits=366
# [ok] https://github.com/rafsanjani/datepickertimeline -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\rafsanjani__datepickertimeline (1.61s)  commits=424
# [ok] https://github.com/Nailik/rhasspy_mobile -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Nailik__rhasspy_mobile (10.73s)  commits=2612
# [ok] https://github.com/android/nowinandroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\android__nowinandroid (18.42s)  commits=7895
# [ok] https://github.com/krzdabrowski/android-starter-2022 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\krzdabrowski__android-starter-2022 (1.65s)  commits=328
# [ok] https://github.com/ruffle-rs/ruffle-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ruffle-rs__ruffle-android (8.09s)  commits=1310
# [ok] https://github.com/fornewid/naver-map-compose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\fornewid__naver-map-compose (3.57s)  commits=459
# [ok] https://github.com/DroidKaigi/conference-app-2022 -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\DroidKaigi__conference-app-2022 (4.7s)  commits=2450
# [ok] https://github.com/slackhq/circuit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\slackhq__circuit (10.45s)  commits=7278
# [ok] https://github.com/maxkeppeler/sheets-compose-dialogs -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\maxkeppeler__sheets-compose-dialogs (56.79s)  commits=298
# [ok] https://github.com/nkuppan/expensemanager -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\nkuppan__expensemanager (4.01s)  commits=386
# [ok] https://github.com/lopspower/PokeCardCompose -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\lopspower__PokeCardCompose (20.17s)  commits=26
# [ok] https://github.com/sopt-makers/sopt-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\sopt-makers__sopt-android (12.72s)  commits=4779
# [ok] https://github.com/zimly/zimly-backup -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\zimly__zimly-backup (4.3s)  commits=889
# [ok] https://github.com/TechbeeAT/jtxBoard -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TechbeeAT__jtxBoard (11.41s)  commits=7886
# [ok] https://github.com/cashapp/paraphrase -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\cashapp__paraphrase (2.37s)  commits=1228
# [ok] https://github.com/google/jetpack-camera-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\google__jetpack-camera-app (5.0s)  commits=2751
# [ok] https://github.com/DesarrolloAntonio/Shiori-Android-Client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\DesarrolloAntonio__Shiori-Android-Client (3.94s)  commits=204
# [ok] https://github.com/mshdabiola/NotePad -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\mshdabiola__NotePad (4.75s)  commits=1645
# [ok] https://github.com/anilbeesetti/nextplayer -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\anilbeesetti__nextplayer (15.71s)  commits=3389
# [ok] https://github.com/chenxiaolong/RSAF -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\chenxiaolong__RSAF (2.19s)  commits=363
# [ok] https://github.com/irgaly/kfswatch -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\irgaly__kfswatch (2.09s)  commits=451
# [ok] https://github.com/droidconKE/droidconKeKotlin -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\droidconKE__droidconKeKotlin (3.47s)  commits=1468
# [ok] https://github.com/TharunBalaji2004/android-ci-cd -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\TharunBalaji2004__android-ci-cd (1.85s)  commits=82
# [ok] https://github.com/orgzly-revived/orgzly-android-revived -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\orgzly-revived__orgzly-android-revived (10.48s)  commits=3575
# [ok] https://github.com/mjaakko/NeoStumbler -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\mjaakko__NeoStumbler (5.2s)  commits=2143
# [ok] https://github.com/pachli/pachli-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\pachli__pachli-android (21.98s)  commits=12984
# [ok] https://github.com/JackEblan/Geto -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\JackEblan__Geto (14.82s)  commits=1132
# [ok] https://github.com/f-arslan/GptMap -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\f-arslan__GptMap (14.93s)  commits=356
# [ok] https://github.com/FliegendeWurst/TriliumDroid -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\FliegendeWurst__TriliumDroid (3.01s)  commits=407
# [ok] https://github.com/t895/DNSNet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\t895__DNSNet (3.49s)  commits=1154
# [ok] https://github.com/linroid/Pexels -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\linroid__Pexels (3.04s)  commits=52
# [ok] https://github.com/gemwalletcom/gem-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\gemwalletcom__gem-android (5.18s)  commits=1406
# [ok] https://github.com/CatimaLoyalty/Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\CatimaLoyalty__Android (11.1s)  commits=8464
# [ok] https://github.com/flauschtrud/broccoli -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\flauschtrud__broccoli (9.69s)  commits=1414
# [ok] https://github.com/SwissCovid/swisscovid-app-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\SwissCovid__swisscovid-app-android (7.78s)  commits=1331
# [ok] https://github.com/Faltenreich/Diaguard -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Faltenreich__Diaguard (12.65s)  commits=5948
# [ok] https://github.com/Five-Prayers/five-prayers-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Five-Prayers__five-prayers-android (11.31s)  commits=601
# [ok] https://github.com/v2er-app/Android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\v2er-app__Android (4.64s)  commits=1646
# [ok] https://github.com/thevindu-w/clip_share_client -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\thevindu-w__clip_share_client (1.61s)  commits=313
# [ok] https://github.com/Hny0305Lin/NLChat -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Hny0305Lin__NLChat (18.86s)  commits=237
# [ok] https://github.com/ably/ably-flutter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ably__ably-flutter (3.74s)  commits=4136
# [ok] https://github.com/jerson/flutter-rsa -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jerson__flutter-rsa (187.82s)  commits=403
# [ok] https://github.com/jerson/flutter-openpgp -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jerson__flutter-openpgp (80.72s)  commits=415
# [ok] https://github.com/isar/isar -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\isar__isar (15.37s)  commits=2304
# [ok] https://github.com/am15h/tflite_flutter_helper -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\am15h__tflite_flutter_helper (26.23s)  commits=165
# [ok] https://github.com/privacybydesign/irmamobile -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\privacybydesign__irmamobile (5.82s)  commits=5157
# [ok] https://github.com/salvadordeveloper/flutter-crypto-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\salvadordeveloper__flutter-crypto-app (1.88s)  commits=31
# [ok] https://github.com/SharezoneApp/sharezone-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\SharezoneApp__sharezone-app (121.3s)  commits=8050
# [ok] https://github.com/alphacep/vosk-flutter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\alphacep__vosk-flutter (20.75s)  commits=109
# [ok] https://github.com/abdelaziz-mahdy/pytorch_lite -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\abdelaziz-mahdy__pytorch_lite (23.79s)  commits=341
# [ok] https://github.com/passsy/spot -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\passsy__spot (2.93s)  commits=1105
# [ok] https://github.com/zeref278/flutter_boilerplate -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\zeref278__flutter_boilerplate (1.52s)  commits=57
# [ok] https://github.com/dart-lang/native -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\dart-lang__native (31.2s)  commits=6634
# [ok] https://github.com/flet-dev/serious-python -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\flet-dev__serious-python (7.42s)  commits=587
# [ok] https://github.com/natsuk4ze/gal -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\natsuk4ze__gal (14.08s)  commits=1459
# [ok] https://github.com/a-mabe/OpenHIIT -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\a-mabe__OpenHIIT (3.02s)  commits=957
# [ok] https://github.com/firebase/FirebaseUI-Flutter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\firebase__FirebaseUI-Flutter (5.45s)  commits=1274
# [ok] https://github.com/microservicer/flutter-pipelines -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\microservicer__flutter-pipelines (2.42s)  commits=385
# [ok] https://github.com/Bdaya-Dev/oidc -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\Bdaya-Dev__oidc (2.37s)  commits=847
# [ok] https://github.com/brandonp2412/FitBook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\brandonp2412__FitBook (31.08s)  commits=833
# [ok] https://github.com/andriydruk/swift-weather-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\andriydruk__swift-weather-app (1.59s)  commits=70
# [ok] https://github.com/invertase/react-native-google-mobile-ads -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\invertase__react-native-google-mobile-ads (3.53s)  commits=1388
# [ok] https://github.com/jameshnsears/QuoteUnquote -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\jameshnsears__QuoteUnquote (45.18s)  commits=639
# [ok] https://github.com/erkkah/naett -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\erkkah__naett (1.71s)  commits=170
# [ok] https://github.com/haiyangwu/mediasoup-client-android -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\haiyangwu__mediasoup-client-android (111.04s)  commits=132
# [ok] https://github.com/openthread/ot-commissioner -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\openthread__ot-commissioner (2.92s)  commits=1391
# [ok] https://github.com/XRPL-Labs/Xaman-App -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\XRPL-Labs__Xaman-App (15.02s)  commits=2986
# [ok] https://github.com/synonymdev/bitkit -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\synonymdev__bitkit (21.31s)  commits=5937
# [ok] https://github.com/streetwriters/notesnook -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\streetwriters__notesnook (126.85s)  commits=20720
# [ok] https://github.com/twilio/twilio-voice-react-native -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\twilio__twilio-voice-react-native (3.67s)  commits=1813
# [ok] https://github.com/mlcommons/mobile_app_open -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\mlcommons__mobile_app_open (11.58s)  commits=3885
# [ok] https://github.com/aws/amazon-ivs-react-native-player -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\aws__amazon-ivs-react-native-player (2.85s)  commits=619
# [ok] https://github.com/inaturalist/iNaturalistReactNative -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\inaturalist__iNaturalistReactNative (41.45s)  commits=12516
# [ok] https://github.com/LedgerHQ/ledger-live -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\LedgerHQ__ledger-live (587.78s)  commits=111408
# [ok] https://github.com/pytorch/executorch -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\pytorch__executorch (97.66s)  commits=56409
# [ok] https://github.com/EnsembleUI/ensemble -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\EnsembleUI__ensemble (11.23s)  commits=8642
# [ok] https://github.com/elftausend/custos -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\elftausend__custos (4.1s)  commits=1750
# [ok] https://github.com/haqq-network/haqq-wallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\haqq-network__haqq-wallet (14.38s)  commits=9057
# [ok] https://github.com/juancastillo0/wasm_run -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\juancastillo0__wasm_run (23.48s)  commits=550
# [ok] https://github.com/ice-blockchain/mobile-app -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ice-blockchain__mobile-app (22.83s)  commits=1704
# [ok] https://github.com/zkmopro/mopro -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\zkmopro__mopro (50.75s)  commits=2850
# [ok] https://github.com/prisma/react-native-prisma -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\prisma__react-native-prisma (3.92s)  commits=424
# [ok] https://github.com/ianthetechie/uniffi-starter -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ianthetechie__uniffi-starter (1.54s)  commits=80
# [ok] https://github.com/ICBNetwork/web3-Wallet -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0\ICBNetwork__web3-Wallet (8.82s)  commits=1
#
# Done. OK=353, FAIL=0. Manifest: C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clones_manifestV9.0.csv

# %% [markdown]
# ## Step 2: Mining
# add a baseline to read the repos from the begining not from the first change

# %%
from __future__ import annotations

import csv
import json
import os
import random
import re
import shutil
import subprocess
import sys
import time
from concurrent.futures import ThreadPoolExecutor as PoolExecutor, as_completed
from datetime import datetime
from functools import lru_cache
from pathlib import Path
from typing import Dict, Iterable, List, Optional, Set, Tuple

# ===========================
# Config (EDIT THESE PATHS)
# ===========================
WORK_ROOT    = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
INPUT_CLONES = WORK_ROOT / "clonesV9.0"
OUTPUT_MINE  = WORK_ROOT / "mineV9.4"

# Study end date (UTC)
CUTOFF_ISO = "2025-08-10 23:59:59 +0000"

# Timeline scope for evolution analysis:
#   "repo_wide" -> walk all origin/* heads (recommended for RQ3)
#   "default"   -> only default branch history
TIMELINE_SCOPE = "repo_wide"

# Performance / behavior toggles
MAX_REPOS = 0  # 0 = all
MAX_WORKERS = min(32, (os.cpu_count() or 8) * 2)
RESUME_IF_EXISTS = True
SUPPRESS_EMPTY_ROWS = True
CAPTURE_EMPTY_GAPS = True
EMIT_NONE_STATE = False

# Blob size guards
BLOB_MAX_SIZE = 2_000_000
HARD_MAX_SIZE = 5_000_000

# High-priority CI paths never skipped (even if large)
HIGH_PRIORITY_CI_PATHS = {
    ".github/workflows",
    ".gitlab-ci.yml",
    "azure-pipelines.yml",
    ".circleci/config.yml",
    ".bitrise.yml",
    ".travis.yml",
}

# ===========================
# Quick startup checks
# ===========================
def _failfast_checks() -> None:
    if shutil.which("git") is None:
        print("[fatal] Git not found in PATH. Install Git and/or add it to PATH.", file=sys.stderr)
        raise SystemExit(1)
    if not WORK_ROOT.exists():
        print(f"[fatal] WORK_ROOT does not exist: {WORK_ROOT}", file=sys.stderr)
        raise SystemExit(1)
    if not INPUT_CLONES.exists():
        print(f"[warn] INPUT_CLONES does not exist yet: {INPUT_CLONES}")
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

# ===========================
# File classifiers
# ===========================
YAML_EXTS = (".yml", ".yaml")
GRADLE_NAMES = {"build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts"}
GRADLE_EXTS = (".gradle", ".gradle.kts")
SCRIPT_EXTS = (".sh", ".bat", ".cmd", ".ps1")
CI_BUILD_SPECIAL = {"Jenkinsfile", ".travis.yml", "azure-pipelines.yml", ".gitlab-ci.yml", "circle.yml"}
XML_BUILD_FILES = {"pom.xml", "build.xml", "config.xml"}

def is_yaml(path: str) -> bool:
    return os.path.splitext(path)[1].lower() in YAML_EXTS or os.path.basename(path) in CI_BUILD_SPECIAL

def is_gradle(path: str) -> bool:
    name = os.path.basename(path)
    ext = os.path.splitext(path)[1].lower()
    return name in GRADLE_NAMES or ext in GRADLE_EXTS

def is_script(path: str) -> bool:
    ext = os.path.splitext(path)[1].lower()
    return ext in SCRIPT_EXTS or os.path.basename(path) in ("Jenkinsfile",)

def is_ci_xml_or_build_xml(path: str) -> bool:
    return os.path.basename(path).lower() in {n.lower() for n in XML_BUILD_FILES}

def is_relevant_file(path: str) -> bool:
    return is_yaml(path) or is_gradle(path) or is_script(path) or is_ci_xml_or_build_xml(path)

def is_high_priority_ci_path(path: str) -> bool:
    norm = path.replace("\\", "/")
    base = os.path.basename(norm)
    if base in HIGH_PRIORITY_CI_PATHS:
        return True
    for root in HIGH_PRIORITY_CI_PATHS:
        if norm.startswith(root.rstrip("/") + "/"):
            return True
    return False

# ===========================
# Regex helpers & normalizers
# ===========================
COMMENT_LINE_RE = re.compile(r"(?m)^\s*(#|//|REM\b|::).*?$")

def strip_comments(raw: str) -> str:
    return COMMENT_LINE_RE.sub("", raw or "")

# --- Gradle comment stripper (preserves http(s)://) ---
def strip_comments_gradle(text: str) -> str:
    if not text:
        return ""
    s = re.sub(r"/\*.*?\*/", "", text, flags=re.S)                 # /* ... */
    s = re.sub(r"(?<!:)//.*?$", "", s, flags=re.M)                  # // ...
    return s

def normalize_block_keys(text: str) -> str:
    # expose content of run/script/command keys and drop YAML dashes before likely shell lines
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(?!\||>|\|\-)\s*(.+)$", r"\2", text)
    text = re.sub(r"(?mi)^\s*(script|run|command)\s*:\s*(\||>|\|\-)\s*$", "", text)
    text = re.sub(
        r"(?m)^(\s*)-\s*(?=(?:\./|\.\\|bash|sh|pwsh|powershell|gradle(?:w)?|adb|flutter|gcloud|saucectl|appcenter)\b)",
        r"\1",
        text,
    )
    return text

IGNORE_GHA_ACTIONS_RE = re.compile(
    r"(?mi)^\s*uses\s*:\s*(docker/(?:setup-qemu-action|setup-buildx-action|build-push-action|login-action)|actions/checkout|docker/setup-qemu-action|docker/setup-buildx-action)@.*$"
)

def strip_irrelevant_ci_lines(text: str) -> str:
    return IGNORE_GHA_ACTIONS_RE.sub("", text or "")

GHA_EXPR_RE = re.compile(r"\${{\s*[^}]+}}")

def pre_sanitize(text: str) -> str:
    return GHA_EXPR_RE.sub("", text or "")

# Gradle command shapes (for CI scripts/YAML)
GRADLE_PREFIX = (
    r"^\s*"
    r"(?:\S+=\S+\s+)*"
    r"(?:sudo\s+)?"
    r"(?:(?:bash|sh)\s+-c[l]?\s+[\'\"]?)?"
    r"(?:[^#\n;]*?&&\s+)?"
    r"(?:cd\s+\S+\s+&&\s+)?"
    r"(?:\./|\.\\)?gradle(?:w)?(?:\.bat)?"
)
GRADLE_ANYWHERE = r"(?i)[^\n]*\bgradle(?:w)?(?:\.bat)?[^\n]*"
GRADLE_ANYWHERE_RE = re.compile(GRADLE_ANYWHERE)
GRADLE_BUILD_ACTION_RE = re.compile(r"(?mi)\buses\s*:\s*(gradle/gradle-build-action|gradle/actions/setup-gradle)@")
NON_TEST_PREFIX = r"(?:assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)"
SHELL_PREFIX = r"(?:\S+=\S+\s+)*(?:sudo\s+)?(?:(?:bash|sh|pwsh|powershell)\s+-c\s+[\'\"]?)?(?:[^#\n;]*?&&\s+)?"

# Device / env patterns (CI side)
EMULATOR_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}(?:\s|^)(?:(?:\./|\.\\)?(?:emulator)(?:\.exe)?)\b[^\n]*-avd\s+\S+"
ADB_WAIT_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+wait[- ]?for[- ]?device\b"
ADB_SERIAL_LINE = rf"(?mi)^[^\n]*{SHELL_PREFIX}adb\s+-s\s+(?:emulator-\d+|localhost:\d+|127\.0\.0\.1:\d+)"
REAL_DEVICE_LINE = rf"(?mi)^\s*adb\s+-s\s+(?!emulator-\d+\b)(?!localhost:\d+\b)(?!127\.0\.0\.1:\d+\b)\S+\b"

def compile_any(patterns: List[str], flags: int = re.I | re.M) -> List[re.Pattern]:
    return [re.compile(p, flags) for p in patterns]

def any_match(patterns: Iterable, text: str) -> bool:
    for p in patterns:
        if isinstance(p, str):
            p = re.compile(p, re.I | re.M)
        if p.search(text):
            return True
    return False

def unique_preserve(seq: Iterable[str]) -> List[str]:
    seen: Set[str] = set()
    out: List[str] = []
    for x in seq:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

# -------- DEVICE SOURCES --------
DEVICE_SOURCES = [
    ("Real_Device", "adb -s <serial> (physical)", [REAL_DEVICE_LINE]),
    ("Emulator", "adb -s emulator-serial", [ADB_SERIAL_LINE]),
    ("Emulator", "adb wait-for-device", [ADB_WAIT_LINE]),
    ("Emulator", "emulator -avd/@", [EMULATOR_LINE]),
    ("Emulator", "android-wait-for-emulator", [r"(?mi)^\s*(?:\./)?android-wait-for-emulator\b"]),
    ("Emulator", "start-emulator.sh", [r"(?mi)^\s*start-emulator\.sh\b"]),
    ("Emulator", "android create avd", [r"\bandroid\b[^\n]*\bcreate\s+avd\b"]),
    # ("Emulator", "circleci android orb", [
    #     r"(?mi)^\s*(?:-\s*)?android/start-emulator-and-run-tests\s*:",
    #     r"(?mi)^\s*system-image\s*:\s*system-images;android-\d+;google_apis;"
    # ]),
    ("Emulator", "circleci android orb", [
    r"(?mi)^\s*(?:-\s*)?android/(?:start-emulator-and-run-tests|create-avd|launch-emulator)\s*:",
    r"(?mi)^\s*system-image\s*:\s*system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*);(?:default|google_apis)[^\s]*"
    ]),
    ("Emulator", "reactivecircus runner", [r"(?mi)\buses\s*:\s*reactivecircus/android-emulator-runner@[\w\.\-]+"]),
    ("Emulator", "malinskiy runner", [r"(?mi)\buses\s*:\s*malinskiy/action-android/emulator-run-cmd@[\w\.\-]+"]),
    ("Emulator", "sys-img component", [
        r"(?m)^\s*-\s*sys-img-[^\s]*-android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b",
        r"(?m)^\s*-\s*sys-img-[^\s]*-google_apis-[^\s]*(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "avdmanager", [r"(?m)^\s*\S*avdmanager\b"]),
    ("Emulator", "sdkmanager system-images/emulator", [
        r'^\s*\S*sdkmanager\b[^\n"]*"system-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)[^"\n]*"',
        r"^\s*\S*sdkmanager\b[^\n]*\bsystem-images;android-(?:\d+|\$[A-Z_][A-Z0-9_]*)\b"
    ]),
    ("Emulator", "other gha emulator", [
        r"(?mi)^\s*uses\s*:\s*vgaidarji/android-github-actions-emulator@[\w\.\-]+",
        r"(?mi)^\s*uses\s*:\s*(?!reactivecircus/android-emulator-runner@)(?!malinskiy/action-android/emulator-run-cmd@)(?!emulator-wtf/run-tests@)[\w\.-]+/[\w\./-]*android[\w\./-]*(?:\bemulator\b|\bavd\b)[\w\./-]*@[\w\.\-]+"
    ]),
    ("Third_Party_Lab", "gcloud firebase", [r"(?mi)^[^\n]*\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "browserstack/bstack", [r"(?i)\b(browserstack|bstack)\b"]),
    ("Third_Party_Lab", "appcenter test", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "maestro cloud", [r"(?mi)^[^\n]*\bmaestro\s+cloud\b"]),
    ("Third_Party_Lab", "emulator.wtf action", [
        r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+",
        r"(?i)\bemulator\.wtf\b"
    ]),
]
DEVICE_PATTERNS = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in DEVICE_SOURCES]

# -------- Triggers (CI/YAML side) --------
TRIGGER_SOURCES_PRIMARY = [
    ("Gradle", "connectedAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedandroidtest\b[^\n\r]*"]),
    ("Gradle", "connected.*Android.*", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b(?![^\n\r]*\b(?:{NON_TEST_PREFIX})[\w-]*androidtest\b)[^\n\r]*"]),
    ("Gradle", "connectedCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedcheck\b[^\n\r]*"]),
    ("Gradle", "cAT shorthand", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*cAT\b[^\n\r]*"]),
    ("Gradle", "deviceCheck", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b[^\n\r]*"]),
    ("Gradle", "managedDevice AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?!{NON_TEST_PREFIX})(?:manageddevice|device)[\w:-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "variant/device AndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b[^\n\r]*"]),
    ("Gradle", "Spoon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\bmarathon(?:\w*androidtest)?\b"]),
    ("ADB", "am instrument", [r"(?mi)^[^\n]*\bam\s+instrument\b"]),
    ("Third_Party_Lab", "gcloud firebase (instr)", [r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run[^\n]*\b(--test\b|--type\s+instrumentation\b)"]),
    ("Third_Party_Lab", "flank", [r"(?mi)^[^\n]*\bflank\s+android\s+run\b"]),
    ("Third_Party_Lab", "saucectl", [r"(?mi)^[^\n]*\bsaucectl(?:\s+run)?\b"]),
    ("Third_Party_Lab", "appcenter", [r"(?mi)^[^\n]*\bappcenter\s+test\s+run\s+android\b"]),
    ("Third_Party_Lab", "emulator.wtf run", [r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@[\w\.\-]+", r"(?i)\bemulator\.wtf\b"]),
]
TRIGGER_SOURCES_PRIMARY += [
    ("Gradle", "generateBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*generate(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "collectBaselineProfile", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*collect(?:\w*?)baselineprofile\b[^\n\r]*"]),
    ("Gradle", "connectedBenchmarkAndroidTest", [rf"(?mi){GRADLE_PREFIX}[^\n\r]*\b(?:[:\w-]+:)*connectedbenchmarkandroidtest\b[^\n\r]*"]),
]

TRIGGER_SOURCES_ANYWHERE = [
    ("Gradle", "connected (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b"]),
    ("Gradle", "connectedAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedandroidtest\b"]),
    ("Gradle", "connectedCheck (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:[:\w-]+:)*connectedcheck\b"]),
    ("Gradle", "managedDevice AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})(?!connected)(?!spoon)(?!marathon)[A-Za-z0-9][\w-]*androidtest\b"]),
    ("Gradle", "variant/device AndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\b(?:(?:[:\w-]+:)*) (?!{NON_TEST_PREFIX})[\w-]*androidtest\b"]),
    ("Gradle", "Spoon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bspoon(?:\w*androidtest)?\b"]),
    ("Gradle", "Marathon (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bmarathon(?:\w*androidtest)?\b"]),
]
TRIGGER_SOURCES_ANYWHERE += [
    ("Gradle", "generateBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bgenerate(?:\w*?)baselineprofile\b"]),
    ("Gradle", "collectBaselineProfile (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bcollect(?:\w*?)baselineprofile\b"]),
    ("Gradle", "connectedBenchmarkAndroidTest (anywhere)", [rf"(?mi){GRADLE_ANYWHERE}\bconnectedbenchmarkandroidtest\b"]),
]

TRIGGER_PATTERNS_PRIMARY  = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_PRIMARY]
TRIGGER_PATTERNS_ANYWHERE = [(grp, lbl, compile_any(pats)) for (grp, lbl, pats) in TRIGGER_SOURCES_ANYWHERE]

def collect_hits_with_groups(patterns, text: str):
    labels = []
    groups = []
    for grp, lbl, pats in patterns:
        if any_match(pats, text):
            labels.append(lbl)
            groups.append(grp)
    return unique_preserve(labels), unique_preserve(groups)

# GHA gradle inputs guard
GHA_GRADLE_INPUTS = compile_any([
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connected[a-z0-9:_-]*android[a-z0-9:_-]*test\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*connectedcheck\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*(?:devicecheck|alldevicechecks)\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:(?:[:\w-]+:)*) (?!assemble|bundle|package|compile|merge|process|generate|install|uninstall|jacoco|lint|publish|sign|upload)[\w-]*androidtest\b",
    r"(?mi)^\s*(arguments|tasks|script|cmd)\s*:\s*[^$`\n]*\b(?:[:\w-]+:)*cAT\b",
])

PROVIDER_PATTERNS = [
    ("emulator-wtf", compile_any([r"(?mi)^\s*uses\s*:\s*emulator-wtf/run-tests@", r"(?i)\bemulator\.wtf\b"])),
    ("firebase-test-lab", compile_any([r"(?mi)\bgcloud(?:\s+beta)?\s+firebase\s+test\s+android\s+run\b", r"(?mi)\bflank\s+android\s+run\b"])),
    ("browserstack", compile_any([r"(?i)\bbrowserstack\b", r"(?i)\bbstack\b"])),
    ("sauce-labs", compile_any([r"(?mi)\bsaucectl(?:\s+run)?\b", r"(?mi)\bsauce\s+ctl\b"])),
    ("appcenter", compile_any([r"(?mi)\bappcenter\s+test\s+run\s+android\b"])),
    ("maestro-cloud", compile_any([r"(?mi)\bmaestro\s+cloud\b"])),
]

INLINE_DEVICE_HINTS = compile_any([
    r"(?mi)^\s*devices\s*:\s*\|",
    r"(?mi)\b--device\b",
    r"(?mi)\bmodel\s*=\s*[^,\s]+",
    r"(?mi)\bversion\s*=\s*\d+",
    r"(?mi)\blocale\s*=\s*[-\w]+",
    r"(?mi)\borientation\s*=\s*(portrait|landscape)",
    r"(?mi)^\s*with-orchestrator\s*:\s*true\b",
    r"(?mi)\b--use-orchestrator\b",
    r"(?mi)\bnum-flaky-test-attempts\s*:\s*\d+\b",
    r"(?mi)\b--num-flaky-test-attempts(?:=|\s+)\d+\b",
])

CONFIG_FILE_HINTS = compile_any([
    r"(?mi)\.ewtf\.ya?ml\b",
    r"(?mi)\b(flank\.ya?ml|flank\.android\.ya?ml)\b",
    r"(?mi)\b--config(?:=|\s+)\S+",
    r"(?mi)\b(browserstack\.ya?ml)\b",
    r"(?mi)\b(bs(?:config)?\.ya?ml)\b",
])

ANDROID_CONTEXT_RE = re.compile(
    r"(?i)\b(adb|avd|emulator|android\s+sdk|system-images;android-|androidtest|connected(?:check|androidtest)|gcloud\s+firebase\s+test\s+android\s+run)\b"
)

EMULATOR_COMMUNITY_LABELS = {"reactivecircus runner", "malinskiy runner", "other gha emulator", "circleci android orb"}
EMULATOR_CUSTOM_LABELS = {
    "adb -s emulator-serial",
    "adb wait-for-device",
    "emulator -avd/@",
    "android-wait-for-emulator",
    "start-emulator.sh",
    "android create avd",
    "avdmanager",
    "sdkmanager system-images/emulator",
    "sys-img component",
}
THIRD_PARTY_STRONG_LABELS = {"gcloud firebase", "emulator.wtf run", "saucectl", "appcenter", "browserstack/bstack", "maestro cloud"}
REAL_DEVICE_STRONG_LABELS = {"adb -s <serial> (physical)"}
STRONG_DEVICE_LABELS = EMULATOR_COMMUNITY_LABELS | EMULATOR_CUSTOM_LABELS | THIRD_PARTY_STRONG_LABELS | REAL_DEVICE_STRONG_LABELS

def detect_provider(text: str) -> str:
    for name, pats in PROVIDER_PATTERNS:
        if any_match(pats, text):
            return name
    return "other"

def has_inline_env(text: str) -> bool:
    return any_match(INLINE_DEVICE_HINTS, text)

def has_config_env(text: str) -> bool:
    return any_match(CONFIG_FILE_HINTS, text)

# ===========================
# Gradle GMD config detector (aligned with V6.0)
# ===========================
TESTOPTIONS_HEAD = re.compile(r"\btestOptions\s*\{", re.I)
MANAGED_HEAD     = re.compile(r"\bmanagedDevices\s*\{", re.I)
GMD_INNER_TOKENS_RX = re.compile(r"\b(managedDevices|managedVirtualDevice|devices|groups|deviceGroups)\b", re.I)

def _find_block_span_from_head(text: str, head_start: int) -> Optional[Tuple[int, int]]:
    i = text.find("{", head_start)
    if i == -1:
        return None
    depth = 0
    for j in range(i, len(text)):
        ch = text[j]
        if ch == "{":
            depth += 1
        elif ch == "}":
            depth -= 1
            if depth == 0:
                return (i, j)
    return None

def find_gmd_block(text_gradle_no_comments: str) -> bool:
    """Return True if we see testOptions{ managedDevices{ … } } or a direct managedDevices{ … } block."""
    t = text_gradle_no_comments
    # Direct managedDevices { ... }
    for m in MANAGED_HEAD.finditer(t):
        if _find_block_span_from_head(t, m.start()):
            return True
    # testOptions { ... } containing GMD tokens
    for m in TESTOPTIONS_HEAD.finditer(t):
        ci = _find_block_span_from_head(t, m.start())
        if not ci:
            continue
        a, b = ci
        sub = t[a:b+1]
        if GMD_INNER_TOKENS_RX.search(sub):
            return True
    return False

# ===========================
# Git helpers
# ===========================
def run_git(repo: Path, args: List[str], text: bool = True, check: bool = True, retries: int = 2) -> subprocess.CompletedProcess:
    last_exc: Optional[BaseException] = None
    for attempt in range(retries + 1):
        try:
            return subprocess.run(
                ["git", "-C", str(repo)] + args,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=text,
                check=check,
                encoding="utf-8" if text else None,
                errors="replace" if text else None,
            )
        except subprocess.CalledProcessError as e:
            last_exc = e
            time.sleep(0.1 * (attempt + 1) + random.random() * 0.1)
        except Exception as e:
            last_exc = e
            time.sleep(0.05)
    if isinstance(last_exc, subprocess.CalledProcessError) and not check:
        return last_exc  # type: ignore[return-value]
    raise last_exc  # type: ignore[misc]

def list_repos(root: Path) -> List[Path]:
    out: List[Path] = []
    for p, dirs, _files in os.walk(root):
        pth = Path(p)
        if (pth / ".git").exists():
            out.append(pth)
            dirs[:] = []
    return out

def default_branch_ref(repo: Path) -> Optional[str]:
    try:
        ref = run_git(repo, ["symbolic-ref", "refs/remotes/origin/HEAD"]).stdout.strip()
        if ref.startswith("refs/remotes/"):
            parts = ref.split("/")
            return "/".join(parts[2:])
    except Exception:
        pass
    for cand in ("origin/main", "origin/master"):
        cp = run_git(repo, ["rev-parse", "--verify", cand], check=False)
        if cp.returncode == 0:
            return cand
    return None

def cutoff_head_default(repo: Path, cutoff_iso: str) -> List[str]:
    ref = default_branch_ref(repo)
    if not ref:
        return []
    cp = run_git(repo, ["rev-list", "-n1", "--first-parent", f"--before={cutoff_iso}", ref], check=False)
    sha = (cp.stdout or "").strip()
    return [sha] if sha else []

def cutoff_heads_all(repo: Path, cutoff_iso: str) -> List[str]:
    refs_raw = run_git(repo, ["for-each-ref", "--format=%(refname:short)", "refs/remotes/origin"]).stdout
    refs = [r for r in refs_raw.splitlines() if r and r != "origin/HEAD" and not r.startswith("origin/pr/")]
    shas: List[str] = []
    for r in refs:
        cp = run_git(repo, ["rev-list", "-n1", "--first-parent", f"--before={cutoff_iso}", r], check=False)
        sha = (cp.stdout or "").strip()
        if sha:
            shas.append(sha)
    if not shas:
        cp = run_git(repo, ["rev-list", "-n1", "--before", cutoff_iso, "--all"], check=False)
        sha = (cp.stdout or "").strip()
        if sha:
            shas.append(sha)
    return shas

def _pathspecs_yaml() -> List[str]:
    return [":(glob)**/*.yml", ":(glob)**/*.yaml", ".travis.yml", "azure-pipelines.yml", ".gitlab-ci.yml", "circle.yml", ".bitrise.yml"]

def _pathspecs_gradle() -> List[str]:
    return ["build.gradle", "build.gradle.kts", "settings.gradle", "settings.gradle.kts", ":(glob)**/*.gradle", ":(glob)**/*.gradle.kts"]

def _pathspecs_scripts_and_xml() -> List[str]:
    return ["Jenkinsfile", ":(glob)**/*.sh", ":(glob)**/*.bat", ":(glob)**/*.cmd", ":(glob)**/*.ps1", ":(glob)**/pom.xml", ":(glob)**/build.xml", ":(glob)**/config.xml"]

def commits_touching_relevant(repo: Path, heads: List[str]) -> List[str]:
    pathspecs = _pathspecs_yaml() + _pathspecs_gradle() + _pathspecs_scripts_and_xml()
    if not heads:
        return []
    s = run_git(repo, ["rev-list", "--reverse"] + heads + ["--"] + pathspecs).stdout
    return [c for c in s.splitlines() if c.strip()]

def list_tree_entries(repo: Path, treeish: str) -> List[Tuple[str, str]]:
    try:
        raw = run_git(repo, ["ls-tree", "-r", "-z", treeish]).stdout
    except Exception:
        raw = ""
    out: List[Tuple[str, str]] = []
    for entry in raw.split("\x00"):
        if not entry or "\t" not in entry:
            continue
        meta, path = entry.split("\t", 1)
        parts = meta.split()
        if len(parts) < 3:
            continue
        sha = parts[2]
        out.append((sha, path))
    return out

def blob_size(repo: Path, sha: str) -> int:
    try:
        return int(run_git(repo, ["cat-file", "-s", sha]).stdout.strip())
    except Exception:
        return 0

@lru_cache(maxsize=250_000)
def read_blob_cached(repo_path: str, sha: str) -> Optional[str]:
    repo = Path(repo_path)
    try:
        return run_git(repo, ["cat-file", "-p", sha]).stdout
    except Exception:
        return None

# ===========================
# Detection at snapshot level
# ===========================
def scan_snapshot_for_styles(repo: Path, treeish: str) -> Tuple[Set[str], Dict]:
    entries = list_tree_entries(repo, treeish)

    # Aggregate features
    features = {
        "yaml_loc": 0,
        "gradle_loc": 0,
        "runs_on": set(),
        "matrix_width_hint": 0,
        "api_levels": set(),
        "reliability_flags": set(),
        "gmd_config_present": False,
        "gmd_identifiers": set(),  # optional, we only store names when we parse them from block heads
    }
    all_text_blocks: List[Tuple[str, str]] = []
    raw_blocks_for_guard: List[str] = []
    has_gradle_anywhere_repo = False

    RX_RUNS_ON = re.compile(r"(?mi)^\s*runs-on\s*:\s*(.+)$")
    RX_LIST_ITEM = re.compile(r"(?mi)^\s*-\s")
    RX_API_LEVEL = re.compile(r"(?i)\bandroid[-_ ]?(\d{2})\b|system-images;android-(\d{2})\b")
    RX_RETRY = re.compile(r"(?i)\bretry\b|\bmax-attempts\b|\bflaky\b")
    RX_TIMEOUT = re.compile(r"(?i)\btimeout[- ]?minutes\b|\btimeout\b")
    RX_HEADLESS = re.compile(r"(?i)\bheadless\b|\b-no-window\b|\b-no-boot-anim\b")
    RX_WAIT_FOR_DEVICE = re.compile(r"(?i)\badb\s+wait[- ]?for[- ]?device\b")

    # Optional identifier capture in GMD blocks (names before "(ManagedVirtualDevice)")
    GMD_BLOCK_NAME_RX = re.compile(
        r'(\w+)\s*\(\s*(?:com\.android\.build\.api\.dsl\.)?ManagedVirtualDevice(?:\s*::\s*class)?\s*\)',
        re.I
    )

    for sha, path in entries:
        if not is_relevant_file(path):
            continue
        size = blob_size(repo, sha)
        if not is_high_priority_ci_path(path) and BLOB_MAX_SIZE and size > BLOB_MAX_SIZE:
            continue
        text = read_blob_cached(str(repo), sha)
        if not text or len(text) > HARD_MAX_SIZE:
            continue

        lines = text.splitlines()
        norm = text  # default

        if is_yaml(path):
            features["yaml_loc"] += len(lines)
            for m in RX_RUNS_ON.finditer(text):
                features["runs_on"].add(m.group(1).strip())
            features["matrix_width_hint"] = max(features["matrix_width_hint"], len(RX_LIST_ITEM.findall(text)))
            # sanitize
            norm = strip_comments(norm)
            norm = normalize_block_keys(norm)
            norm = strip_irrelevant_ci_lines(norm)
            norm = pre_sanitize(norm)

        elif is_script(path) or is_ci_xml_or_build_xml(path):
            norm = strip_comments(norm)
            norm = normalize_block_keys(norm)
            norm = strip_irrelevant_ci_lines(norm)
            norm = pre_sanitize(norm)

        elif is_gradle(path):
            features["gradle_loc"] += len(lines)
            # For Gradle, use Gradle-aware comment stripping then look for GMD config blocks
            gradle_clean = strip_comments_gradle(text)
            # Detect managedDevices presence (aligned with your V6.0)
            if not features["gmd_config_present"] and find_gmd_block(gradle_clean):
                features["gmd_config_present"] = True
                # best-effort: capture identifiers (optional, for diagnostics only)
                for m in GMD_BLOCK_NAME_RX.finditer(gradle_clean):
                    ident = (m.group(1) or "").strip()
                    if ident:
                        features["gmd_identifiers"].add(ident)
            # Keep norm as lowercased “clean” text for any incidental signals
            norm = gradle_clean

        # Common feature mining from the (possibly sanitized) text
        for m in RX_API_LEVEL.finditer(text):
            for g in m.groups():
                if g and g.isdigit():
                    features["api_levels"].add(int(g))
        if RX_RETRY.search(text):
            features["reliability_flags"].add("retry")
        if RX_TIMEOUT.search(text):
            features["reliability_flags"].add("timeout")
        if RX_HEADLESS.search(text):
            features["reliability_flags"].add("headless")
        if RX_WAIT_FOR_DEVICE.search(text):
            features["reliability_flags"].add("wait_for_device")

        all_text_blocks.append((path, norm))
        raw_blocks_for_guard.append(norm)

        if GRADLE_ANYWHERE_RE.search(norm) or GRADLE_BUILD_ACTION_RE.search(norm):
            has_gradle_anywhere_repo = True

    # Collect triggers & devices repo-wide (mostly from YAML/scripts)
    trigger_labels: List[str] = []
    trigger_groups: List[str] = []
    device_labels: List[str] = []
    device_groups: List[str] = []

    for _path, norm in all_text_blocks:
        nlow = norm.lower()

        t_labels, t_groups = collect_hits_with_groups(TRIGGER_PATTERNS_PRIMARY, nlow)
        fb_labels, fb_groups = collect_hits_with_groups(TRIGGER_PATTERNS_ANYWHERE, nlow)
        if fb_labels:
            t_labels = unique_preserve(t_labels + fb_labels)
            t_groups = unique_preserve(t_groups + fb_groups)

        # GHA gradle input guard
        if any_match(GHA_GRADLE_INPUTS, nlow):
            gha_tied = re.search(
                r"(?mi)^\s*uses\s*:\s*(reactivecircus/android-emulator-runner|malinskiy/action-android/emulator-run-cmd|hannesa2/action-android/emulator-run-cmd)@",
                nlow,
            )
            if has_gradle_anywhere_repo or gha_tied:
                if "gha gradle inputs/script" not in t_labels:
                    t_labels.append("gha gradle inputs/script")
                if "Gradle" not in t_groups:
                    t_groups.append("Gradle")

        trigger_labels = unique_preserve(trigger_labels + t_labels)
        trigger_groups = unique_preserve(trigger_groups + t_groups)

        d_labels, d_groups = collect_hits_with_groups(DEVICE_PATTERNS, nlow)
        # Guard: “other gha emulator” must have Android context or a trigger
        if ("other gha emulator" in d_labels) and (not ANDROID_CONTEXT_RE.search(nlow)) and (not t_labels):
            d_labels = [l for l in d_labels if l != "other gha emulator"]
            if not d_labels:
                d_groups = [g for g in d_groups if g != "Emulator"]

        device_labels = unique_preserve(device_labels + d_labels)
        device_groups = unique_preserve(device_groups + d_groups)

    has_test_trigger = bool(trigger_labels)

    # Weak hint suppression: require strong device OR a test trigger
    strong_seen = bool(set(device_labels) & STRONG_DEVICE_LABELS)
    if not (strong_seen or has_test_trigger):
        device_labels = [l for l in device_labels if l in STRONG_DEVICE_LABELS]
        if not device_labels:
            device_groups = []

    # BrowserStack upload-only guard
    repo_text = "\n".join(raw_blocks_for_guard)
    provider = detect_provider(repo_text)
    inline_decl = has_inline_env(repo_text)
    config_decl = has_config_env(repo_text)
    has_ftl_instr = bool(re.search(r"(?mi)\bgcloud\s+firebase\s+test\s+android\s+run[^\n]*\b(--test\b|--type\s+instrumentation\b)", repo_text))
    bs_test_hint = re.search(r"(?mi)\b(browserstack|bstack)\b[^\n]*\b(espresso|instrumentation|app-automate|automate|--device|--devices)\b", repo_text)
    if ("browserstack/bstack" in device_labels or provider == "browserstack"):
        if (not has_test_trigger) and (not inline_decl) and (not config_decl) and (not has_ftl_instr) and (not bs_test_hint):
            device_labels = [l for l in device_labels if l != "browserstack/bstack"]
            if "Third_Party_Lab" in device_groups and not any(l in {"gcloud firebase", "saucectl", "appcenter", "maestro cloud", "emulator.wtf action"} for l in device_labels):
                device_groups = [g for g in device_groups if g != "Third_Party_Lab"]

    # Map to final styles
    styles: Set[str] = set()

    if "Third_Party_Lab" in device_groups:
        styles.add("ThirdParty")

    if "Emulator" in device_groups:
        lbls = set(device_labels)
        if lbls & EMULATOR_COMMUNITY_LABELS:
            styles.add("Emu_Community")
        elif lbls & EMULATOR_CUSTOM_LABELS:
            styles.add("Emu_Custom")

    # --- GMD detection parity with shallow snapshot ---
    # Count GMD if EITHER:
    #  (A) GMD Gradle configuration is present, OR
    #  (B) CI shows managed-device AndroidTest triggers (execution evidence).
    def has_gmd_gradle_trigger(tlabs: List[str]) -> bool:
        L = {l.lower() for l in tlabs}
        if any("manageddevice androidtest" in l for l in L):
            return True
        if ("variant/device androidtest" in L) and not any(x in L for x in {"connected.*android.*", "connectedandroidtest", "connectedbenchmarkandroidtest", "spoon", "marathon"}):
            return True
        return False

    if features["gmd_config_present"] or has_gmd_gradle_trigger(trigger_labels):
        styles.add("GMD")

    meta = {
        "sources": {"yaml": [], "gradle": [], "scripts_xml": []},
        "features": {
            "yaml_loc": features["yaml_loc"],
            "gradle_loc": features["gradle_loc"],
            "runs_on": sorted(features["runs_on"]),
            "matrix_width_hint": features["matrix_width_hint"],
            "api_levels": sorted(int(x) for x in features["api_levels"]),
            "reliability_flags": sorted(features["reliability_flags"]),
            "trigger_labels": sorted(trigger_labels),
            "device_labels": sorted(device_labels),
            "provider": provider,
            "inline_env": bool(inline_decl),
            "config_env": bool(config_decl),
            "gradle_present_repo": bool(has_gradle_anywhere_repo),
            "gmd_config_present": bool(features["gmd_config_present"]),
            "gmd_identifiers": sorted(features["gmd_identifiers"]) if features["gmd_identifiers"] else [],
        },
    }
    return styles, meta

# ===========================
# Timeline building
# ===========================
def empty_result(repo: Path, cutoff_iso: str) -> Dict:
    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "cutoff_default_head": [],
        "cutoff_all_heads": [],
        "first_commit_date": None,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": [],
        "events": {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []},
        "snapshot_as_of_cutoff_default": [],
        "snapshot_as_of_cutoff_repo_wide": [],
        "off_default_extra_styles": [],
        "has_off_default_extra": 0,
        "empty_gaps": [],
        "qa_issue": "No environment detected at cutoff",
    }

def earliest_commit(repo: Path) -> Optional[str]:
    try:
        s = run_git(repo, ["rev-list", "--max-parents=0", "--all"]).stdout.strip()
        return s.splitlines()[0] if s else None
    except Exception:
        return None

def get_commit_date_iso(repo: Path, commit: str) -> Optional[str]:
    try:
        return run_git(repo, ["show", "-s", "--format=%cI", commit]).stdout.strip() or None
    except Exception:
        return None

def union_snapshot_styles_at_cutoff(repo: Path, heads: List[str]) -> List[str]:
    styles: Set[str] = set()
    for sha in heads:
        s, _m = scan_snapshot_for_styles(repo, sha)
        styles |= s
    return sorted(styles)

def build_timeline(repo: Path, cutoff_iso: str) -> Dict:
    # Heads at cutoff
    default_heads = cutoff_head_default(repo, cutoff_iso)
    all_heads     = cutoff_heads_all(repo, cutoff_iso)

    if not default_heads and not all_heads:
        return empty_result(repo, cutoff_iso)

    # Commits touching relevant files on default and repo-wide (for tagging & scope)
    commits_default = commits_touching_relevant(repo, default_heads) if default_heads else []
    commits_all     = commits_touching_relevant(repo, all_heads) if all_heads else commits_default

    # Date maps
    commit_dates: Dict[str, str] = {}
    for c in commits_all:
        d = get_commit_date_iso(repo, c)
        if d:
            commit_dates[c] = d
    first_commit_date = commit_dates.get(commits_all[0]) if commits_all else None

    # Build timeline (scope-controlled)
    scope_commits = commits_all if TIMELINE_SCOPE == "repo_wide" else commits_default
    scope_commits = scope_commits or commits_all  # fallback

    timeline: List[Dict] = []
    events: Dict[str, List[Dict]] = {"Emu_Community": [], "Emu_Custom": [], "GMD": [], "ThirdParty": []}
    prev: Set[str] = set()

    empty_gaps: List[Dict] = []
    gap_open: Optional[Dict] = None

    # (Optional) historical baseline at repository root
    root = earliest_commit(repo)
    if root:
        base_styles, base_meta = scan_snapshot_for_styles(repo, root)
        if base_styles:
            baseline_date = get_commit_date_iso(repo, root)
            timeline.append({"date": baseline_date, "commit": root, "on_default": int(root in commits_default), "styles": sorted(base_styles), **base_meta})
            for s in sorted(base_styles):
                if s in events:
                    events[s].append({"event": "added", "date": baseline_date, "commit": root, "on_default": int(root in commits_default)})
            prev = set(base_styles)

    default_set = set(commits_default)

    for c in scope_commits:
        styles_now, meta_now = scan_snapshot_for_styles(repo, c)
        dt = commit_dates.get(c)
        on_default = int(c in default_set)

        # Skip commits that didn't detect any relevant style signals (unless capturing 'empty' gaps)
        if SUPPRESS_EMPTY_ROWS and not styles_now:
            if CAPTURE_EMPTY_GAPS and gap_open is None:
                gap_open = {"start_date": dt, "start_commit": c, "prev_state": "+".join(sorted(prev)) if prev else ""}
            continue

        # If we were in a gap and now have styles, close the gap (existing behavior)
        if CAPTURE_EMPTY_GAPS and gap_open is not None and styles_now:
            gap_open["end_date"] = dt
            gap_open["end_commit"] = c
            gap_open["next_state"] = "+".join(sorted(styles_now))
            try:
                d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)  # type: ignore[index]
                d2 = datetime.fromisoformat((dt or "").replace("Z", "+00:00")).replace(tzinfo=None)
                gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
            except Exception:
                gap_open["duration_days"] = None
            gap_open["censored"] = False
            empty_gaps.append(gap_open)
            gap_open = None

        if styles_now != prev:
            # === boundary change: keep existing behavior ===
            if EMIT_NONE_STATE and not styles_now:
                timeline.append({"date": dt, "commit": c, "on_default": on_default, "styles": [], **meta_now})
            elif styles_now:
                timeline.append({"date": dt, "commit": c, "on_default": on_default, "styles": sorted(styles_now), **meta_now})

            added = styles_now - prev
            removed = prev - styles_now
            for s in sorted(added):
                if s in events:
                    events[s].append({"event": "added", "date": dt, "commit": c, "on_default": on_default})
            for s in sorted(removed):
                if s in events:
                    events[s].append({"event": "removed", "date": dt, "commit": c, "on_default": on_default})
            prev = styles_now

        else:
            # === NEW: within-episode maintenance (style set unchanged) ===
            # We reached this commit because it touched relevant paths already (by construction).
            # Treat it as "maintenance" for all styles currently active.
            if styles_now:
                for s in sorted(styles_now):
                    if s in events:
                        events[s].append({
                            "event": "maintenance",
                            "date": dt,
                            "commit": c,
                            "on_default": on_default
                        })
            # No timeline row needed here; we only record the maintenance touch.

    # Cutoff snapshots (both lenses)
    snapshot_default   = union_snapshot_styles_at_cutoff(repo, default_heads) if default_heads else []
    snapshot_repo_wide = union_snapshot_styles_at_cutoff(repo, all_heads) if all_heads else snapshot_default

    if CAPTURE_EMPTY_GAPS and gap_open is not None:
        # close last gap at cutoff
        gap_open["end_date"] = cutoff_iso
        gap_open["end_commit"] = (default_heads or all_heads or [None])[0]
        gap_open["next_state"] = ""
        try:
            d1 = datetime.fromisoformat((gap_open["start_date"] or "").replace("Z", "+00:00")).replace(tzinfo=None)  # type: ignore[index]
            d2 = datetime.fromisoformat(cutoff_iso.replace("Z", "+00:00")).replace(tzinfo=None)
            gap_open["duration_days"] = round(max(0.0, (d2 - d1).total_seconds() / 86400.0), 2)
        except Exception:
            gap_open["duration_days"] = None
        gap_open["censored"] = True
        empty_gaps.append(gap_open)
        gap_open = None

    off_default_extra = sorted(set(snapshot_repo_wide) - set(snapshot_default))
    qa_issue = None
    if not snapshot_default and not snapshot_repo_wide:
        qa_issue = "No environment detected at cutoff"

    return {
        "repo_name": repo.name,
        "repo_path": str(repo),
        "cutoff_date": cutoff_iso,
        "cutoff_default_head": default_heads,
        "cutoff_all_heads": all_heads,
        "first_commit_date": first_commit_date,
        "timeline_scope": TIMELINE_SCOPE,
        "timeline": timeline,
        "events": events,
        "snapshot_as_of_cutoff_default": snapshot_default,
        "snapshot_as_of_cutoff_repo_wide": snapshot_repo_wide,
        "off_default_extra_styles": off_default_extra,
        "has_off_default_extra": int(bool(off_default_extra)),
        "empty_gaps": empty_gaps,
        **({"qa_issue": qa_issue} if qa_issue else {}),
    }

# ===========================
# Runner + index/summary
# ===========================
def output_path_for(repo: Path) -> Path:
    return OUTPUT_MINE / f"{repo.name}.emulator_timeline.json"

def list_repos_once(root: Path) -> List[Path]:
    rs = list_repos(root)
    rs.sort(key=lambda p: p.name.lower())
    return rs

def iso_min(dts: List[str]) -> Optional[str]:
    ds = [d for d in dts if d]
    return min(ds) if ds else None

def derive_summary_fields(rec: Dict) -> Dict:
    name = rec.get("repo_name")
    snap_def = rec.get("snapshot_as_of_cutoff_default", [])
    snap_all = rec.get("snapshot_as_of_cutoff_repo_wide", [])
    events = rec.get("events", {})
    first_events: List[Optional[str]] = []
    for k in ("Emu_Community", "Emu_Custom", "GMD", "ThirdParty"):
        for e in events.get(k, []):
            if e.get("event") == "added":
                first_events.append(e.get("date"))
    first_env_date = iso_min([d for d in first_events if d])
    transitions = 0
    for k in events:
        transitions += sum(1 for e in events[k] if e.get("event") in ("added", "removed"))
    gaps = rec.get("empty_gaps", [])
    gap_days = 0.0
    for g in gaps:
        try:
            gap_days += float(g.get("duration_days") or 0.0)
        except Exception:
            pass
    return {
        "repo_name": name,
        "has_env_at_cutoff_default": 1 if snap_def else 0,
        "has_env_at_cutoff_repo_wide": 1 if snap_all else 0,
        "cutoff_states_default": "+".join(snap_def),
        "cutoff_states_repo_wide": "+".join(snap_all),
        "off_default_extra": "+".join(rec.get("off_default_extra_styles", [])),
        "has_off_default_extra": int(bool(rec.get("off_default_extra_styles"))),
        "first_env_date": first_env_date or "",
        "transitions": transitions,
        "total_gap_days": round(gap_days, 2),
        "qa_issue": rec.get("qa_issue", ""),
    }

def run_miner(cutoff_iso: str = CUTOFF_ISO, max_repos: int = MAX_REPOS) -> None:
    OUTPUT_MINE.mkdir(parents=True, exist_ok=True)

    repos = list_repos_once(INPUT_CLONES)
    if max_repos and max_repos > 0:
        repos = repos[:max_repos]

    if not repos:
        print(f"[info] No git repos found under: {INPUT_CLONES}")
        return

    print(f"[info] Work root:         {WORK_ROOT}")
    print(f"[info] Input repos:       {INPUT_CLONES}")
    print(f"[info] Output JSON dir:   {OUTPUT_MINE}")
    print(f"[info] Found repos:       {len(repos)}")
    print(f"[info] Cutoff (UTC):      {cutoff_iso}")
    print(f"[info] Timeline scope:    {TIMELINE_SCOPE}")
    print(f"[info] Options: suppress_empty_rows={SUPPRESS_EMPTY_ROWS}, capture_empty_gaps={CAPTURE_EMPTY_GAPS}, emit_none={EMIT_NONE_STATE}, blob_max_size={BLOB_MAX_SIZE}")

    written = skipped = errors = 0
    summaries: List[Dict] = []

    def process(repo: Path) -> Tuple[str, Path, Optional[Dict], Optional[str]]:
        try:
            outp = output_path_for(repo)
            if RESUME_IF_EXISTS and outp.exists():
                return ("skipped", repo, None, None)
            data = build_timeline(repo, cutoff_iso)
            with outp.open("w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=2)
            return ("written", repo, data, None)
        except Exception as e:
            return ("error", repo, None, str(e))

    with PoolExecutor(max_workers=MAX_WORKERS) as ex:
        futs = {ex.submit(process, r): r for r in repos}
        total = len(futs)
        for i, fut in enumerate(as_completed(futs), 1):
            repo = futs[fut]
            rel = repo.relative_to(INPUT_CLONES) if repo != INPUT_CLONES else Path(repo.name)
            status, _repo, data, err = fut.result()
            if status == "written":
                print(f"[{i}/{total}] Wrote: {rel}")
                written += 1
                summaries.append(derive_summary_fields(data))  # type: ignore[arg-type]
            elif status == "skipped":
                print(f"[{i}/{total}] Skipped (exists): {rel}")
                skipped += 1
                try:
                    with output_path_for(repo).open("r", encoding="utf-8") as f:
                        data2 = json.load(f)
                    summaries.append(derive_summary_fields(data2))
                except Exception:
                    pass
            else:
                print(f"[{i}/{total}] [error] {rel}: {err}", file=sys.stderr)
                errors += 1

    # Write summary CSV + JSON index
    idx_json = OUTPUT_MINE / "index_summary.json"
    with idx_json.open("w", encoding="utf-8") as f:
        json.dump({"cutoff": cutoff_iso, "repos": summaries}, f, ensure_ascii=False, indent=2)

    idx_csv = OUTPUT_MINE / "index_summary.csv"
    with idx_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(
            f,
            fieldnames=[
                "repo_name",
                "has_env_at_cutoff_default",
                "has_env_at_cutoff_repo_wide",
                "cutoff_states_default",
                "cutoff_states_repo_wide",
                "off_default_extra",
                "has_off_default_extra",
                "first_env_date",
                "transitions",
                "total_gap_days",
                "qa_issue",
            ],
        )
        w.writeheader()
        for row in summaries:
            w.writerow(row)

    qa_csv = OUTPUT_MINE / "qa_issues.csv"
    with qa_csv.open("w", encoding="utf-8", newline="") as f:
        w = csv.DictWriter(f, fieldnames=["repo_name", "qa_issue"])
        w.writeheader()
        for row in summaries:
            if row.get("qa_issue"):
                w.writerow({"repo_name": row["repo_name"], "qa_issue": row["qa_issue"]})

    print(f"[done] JSON -> {OUTPUT_MINE}  (written={written}, skipped={skipped}, errors={errors})")
    print(f"[done] Summary: {idx_csv.name}, {idx_json.name}, QA: {qa_csv.name}")

if __name__ == "__main__":
    _failfast_checks()
    print("[run] Starting miner…")
    run_miner(cutoff_iso=CUTOFF_ISO, max_repos=MAX_REPOS)
    print("[run] Finished.")
# Out:
# [run] Starting miner…
# [info] Work root:         C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3
# [info] Input repos:       C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\clonesV9.0
# [info] Output JSON dir:   C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\mineV9.4
# [info] Found repos:       355
# [info] Cutoff (UTC):      2025-08-10 23:59:59 +0000
# [info] Timeline scope:    repo_wide
# [info] Options: suppress_empty_rows=True, capture_empty_gaps=True, emit_none=False, blob_max_size=2000000
# [1/355] Wrote: ajitsing__ExpenseManager
# [2/355] Wrote: AAkira__ExpandableLayout
# [3/355] Wrote: andremion__Villains-and-Heroes
# [4/355] Wrote: arkivanov__android-dev-challenge-compose-2
# [5/355] Wrote: andriydruk__swift-weather-app
# [6/355] Wrote: AndProx__AndProx
# [7/355] Wrote: 4eRTuk__audioview
# [8/355] Wrote: agoda-com__ninjato
# [9/355] Wrote: AdamMc331__AndroidStudyGuide
# [10/355] Wrote: alphacep__vosk-flutter
# [11/355] Wrote: alexbakker__webdav-provider
# [12/355] Wrote: a914-gowtham__compose-ratingbar
# [13/355] Wrote: bilibili__boxing
# [14/355] Wrote: anjlab__android-inapp-billing-v3
# [15/355] Wrote: am15h__tflite_flutter_helper
# [16/355] Wrote: AChep__AcDisplay
# [17/355] Wrote: blazsolar__android-collapse-calendar-view
# [18/355] Wrote: airbnb__paris
# [19/355] Wrote: amahi__android
# [20/355] Wrote: brarcher__video-transcoder
# [21/355] Wrote: alexstyl__contactstore
# [22/355] Wrote: CarlosMChica__easyrecycleradapters
# [23/355] Wrote: appmattus__layercache
# [24/355] Wrote: chenxiaolong__RSAF
# [25/355] Wrote: ActivityWatch__aw-android
# [26/355] Wrote: andreynovikov__trekarta
# [27/355] Wrote: Albert221__FastShopping
# [28/355] Wrote: adorsys__secure-storage-android
# [29/355] Wrote: aws__amazon-ivs-react-native-player
# [30/355] Wrote: amitshekhariitbhu__Fast-Android-Networking
# [31/355] Wrote: burnoo__cokoin
# [32/355] Wrote: cuongpm__youtube-dl-android
# [33/355] Wrote: a-mabe__OpenHIIT
# [34/355] Wrote: AdevintaSpain__Barista
# [35/355] Wrote: dbrodie__AdBuster
# [36/355] Wrote: concretesolutions__canarinho
# [37/355] Wrote: charpeni__react-native-url-polyfill
# [38/355] Wrote: cloudinary__cloudinary_android
# [39/355] Wrote: abdelaziz-mahdy__pytorch_lite
# [40/355] Wrote: cashapp__paraphrase
# [41/355] Wrote: beemdevelopment__Aegis
# [42/355] Wrote: douzifly__clear-todolist
# [43/355] Wrote: dgngulcan__droid-feed
# [44/355] Wrote: DesarrolloAntonio__Shiori-Android-Client
# [45/355] Wrote: bitfireAT__icsx5
# [46/355] Wrote: cliqz-oss__browser-android
# [47/355] Wrote: dlew__joda-time-android
# [48/355] Wrote: doublesymmetry__KotlinAudio
# [49/355] Wrote: dmfs__opentasks
# [50/355] Wrote: erkkah__naett
# [51/355] Wrote: Criptext__Android-Email-Client
# [52/355] Wrote: anilbeesetti__nextplayer
# [53/355] Wrote: EvanRespaut__Equate
# [54/355] Wrote: FabianTerhorst__Floppy
# [55/355] Wrote: elftausend__custos
# [56/355] Wrote: Crazy-Marvin__MetadataRemover
# [57/355] Wrote: fewlaps__flone-android
# [58/355] Wrote: FabianTerhorst__Iron
# [59/355] Wrote: CypherpunkArmory__UserLAnd
# [60/355] Wrote: brandonp2412__FitBook
# [61/355] Wrote: Five-Prayers__five-prayers-android
# [62/355] Wrote: droidconKE__droidconKeKotlin
# [63/355] Wrote: FliegendeWurst__TriliumDroid
# [64/355] Wrote: ErickSumargo__Dads
# [65/355] Wrote: fossasia__loklak_wok_android
# [66/355] Wrote: freeotp__freeotp-android
# [67/355] Wrote: flauschtrud__broccoli
# [68/355] Wrote: gdky005__AndroidBadge
# [69/355] Wrote: GabrielBB__Android-CutOut
# [70/355] Wrote: evilcorpltd__aTox
# [71/355] Wrote: GerardPaligot__android-countdown
# [72/355] Wrote: federicoiosue__Omni-Notes
# [73/355] Wrote: flet-dev__serious-python
# [74/355] Wrote: fornewid__naver-map-compose
# [75/355] Wrote: f-arslan__GptMap
# [76/355] Wrote: Faltenreich__Diaguard
# [77/355] Wrote: gotev__android-cookie-store
# [78/355] Wrote: gotev__android-speech
# [79/355] Wrote: ably__ably-flutter
# [80/355] Wrote: guolindev__android-dev-challenge-compose
# [81/355] Wrote: fluttercommunity__flutter_workmanager
# [82/355] Wrote: CatimaLoyalty__Android
# [83/355] Wrote: gemwalletcom__gem-android
# [84/355] Wrote: greenaddress__abcore
# [85/355] Wrote: commons-app__apps-android-commons
# [86/355] Wrote: hannesstruss__unearthed
# [87/355] Wrote: EventFahrplan__EventFahrplan
# [88/355] Wrote: hitherejoe__HackerNewsReader
# [89/355] Wrote: hitherejoe__MVVM_Hacker_News
# [90/355] Wrote: Hny0305Lin__NLChat
# [91/355] Wrote: grote__Transportr
# [92/355] Wrote: HYY-yu__TableRecyclerView
# [93/355] Wrote: google__jetpack-camera-app
# [94/355] Wrote: haiyangwu__mediasoup-client-android
# [95/355] Wrote: ianthetechie__uniffi-starter
# [96/355] Wrote: fossasia__phimpme-android
# [97/355] Wrote: ICBNetwork__web3-Wallet
# [98/355] Wrote: connectbot__connectbot
# [99/355] Wrote: guardianproject__proofmode-android
# [100/355] Wrote: H-PixelDroid__PixelDroid
# [101/355] Wrote: haroldadmin__MoonShot
# [102/355] Wrote: irgaly__kfswatch
# [103/355] Wrote: hannesa2__panoramaGL
# [104/355] Wrote: ivnsch__rust_android_ios
# [105/355] Wrote: ipfs-shipyard__gomobile-ipfs
# [106/355] Wrote: ice-blockchain__mobile-app
# [107/355] Wrote: izderadicka__audioserve-android
# [108/355] Wrote: hoc081098__ViewBindingDelegate
# [109/355] Wrote: javiersantos__PiracyChecker
# [110/355] Wrote: glpi-project__android-inventory-agent
# [111/355] Wrote: bitfireAT__davx5-ose
# [112/355] Wrote: jerryOkafor__TimeLineView
# [113/355] Wrote: inaturalist__iNaturalistAndroid
# [114/355] Wrote: invertase__react-native-google-mobile-ads
# [115/355] Wrote: jeziellago__Linkt
# [116/355] Wrote: jimmod__ShareToComputer
# [117/355] Wrote: DroidKaigi__conference-app-2020
# [118/355] Wrote: jianjunxiao__NiceVieoPlayer
# [119/355] Wrote: hitherejoe__minimise
# [120/355] Wrote: JakeWharton__RxBinding
# [121/355] Wrote: JimmyDaddy__react-native-image-marker
# [122/355] Wrote: kakajika__SwipeAwayDialog
# [123/355] Wrote: karonl__InDoorSurfaceView
# [124/355] Wrote: jungilhan__awesome-blogs-android
# [125/355] Wrote: kebernet__shortyz
# [126/355] Wrote: kost__NetworkMapper
# [127/355] Wrote: joreilly__StarWars
# [128/355] Wrote: invertase__notifee
# [129/355] Wrote: krzdabrowski__android-starter-2022
# [130/355] Wrote: AntennaPod__AntennaPod
# [131/355] Wrote: DroidKaigi__conference-app-2022
# [132/355] Wrote: ksoichiro__Android-ObservableScrollView
# [133/355] Wrote: ksoichiro__AndroidFormEnhancer
# [134/355] Wrote: jameshnsears__QuoteUnquote
# [135/355] Wrote: ksoichiro__SimpleAlertDialog-for-Android
# [136/355] Wrote: jerson__flutter-openpgp
# [137/355] Wrote: jerson__flutter-rsa
# [138/355] Wrote: liangpengfei__LoadingPopPoint
# [139/355] Wrote: letelete__sleep-cycle-alarm
# [140/355] Wrote: liihuu__KLineChartAndroid
# [141/355] Wrote: labexp__osmtracker-android
# [142/355] Wrote: lcdsmao__JetTheme
# [143/355] Wrote: linroid__Pexels
# [144/355] Wrote: livefront__bridge
# [145/355] Wrote: lopspower__PokeCardCompose
# [146/355] Wrote: dart-lang__http
# [147/355] Wrote: MackHartley__RoundedProgressBar
# [148/355] Wrote: lolo-io__OneList
# [149/355] Wrote: leandroBorgesFerreira__LoadingButtonAndroid
# [150/355] Wrote: KaustubhPatange__navigator
# [151/355] Wrote: MarcinMoskala__PreferenceHolder
# [152/355] Wrote: maksim-m__Popular-Movies-App
# [153/355] Wrote: mapbox__store-locator-android
# [154/355] Wrote: JackEblan__Geto
# [155/355] Wrote: maxistar__TextPad
# [156/355] Wrote: admob-plus__admob-plus
# [157/355] Wrote: maxpower47__PinDroid
# [158/355] Wrote: juancastillo0__wasm_run
# [159/355] Wrote: MichaelEvans__Aftermath
# [160/355] Wrote: jaredsburrows__android-gif-search
# [161/355] Wrote: miguelhincapie__CustomBottomSheetBehavior
# [162/355] Wrote: michelelacorte__AndroidAppShortcuts
# [163/355] Wrote: ligi__SurvivalManual
# [164/355] Wrote: maxkeppeler__sheets-compose-dialogs
# [165/355] Wrote: medic__cht-gateway
# [166/355] Wrote: MostafaGazar__soas
# [167/355] Wrote: joreilly__PeopleInSpace
# [168/355] Wrote: massivedisaster__ADAL
# [169/355] Wrote: firebase__FirebaseUI-Flutter
# [170/355] Wrote: mathisdt__trackworktime
# [171/355] Wrote: kickstarter__android-oss
# [172/355] Wrote: natario1__GIFCompressor
# [173/355] Wrote: michaeltroger__pdfwallet-android
# [174/355] [error] MetaMask__metamask-mobile: [WinError 206] The filename or extension is too long
# [175/355] Wrote: coil-kt__coil
# [176/355] Wrote: n8ebel__GitHubActionsAutomationSandbox
# [177/355] Wrote: android__codelab-android-compose
# [178/355] Wrote: BlueWallet__BlueWallet
# [179/355] Wrote: microservicer__flutter-pipelines
# [180/355] Wrote: nhirokinet__bluelineconsole
# [181/355] Wrote: nanihadesuka__NovelDokusha
# [182/355] Wrote: okanaydin__Android-Compose-Challenge
# [183/355] Wrote: nukc__LoadMoreWrapper
# [184/355] Wrote: ligi__PassAndroid
# [185/355] Wrote: inaturalist__iNaturalistReactNative
# [186/355] Wrote: nukc__StateView
# [187/355] Wrote: haqq-network__haqq-wallet
# [188/355] Wrote: moezbhatti__qksms
# [189/355] Wrote: MikeOrtiz__TouchImageView
# [190/355] Wrote: OlauncherCF__OlauncherCF
# [191/355] Wrote: isar__isar
# [192/355] Wrote: OpnTec__bodyapps-android
# [193/355] Wrote: openintents__shoppinglist
# [194/355] Wrote: openthread__ot-commissioner
# [195/355] Wrote: nschnettler__Compose-Scrobbler
# [196/355] Wrote: mjaakko__NeoStumbler
# [197/355] Wrote: nkuppan__expensemanager
# [198/355] Wrote: pauloaapereira__AndroidDevChallenge_Week4_JetWeatherfy
# [199/355] Wrote: OneBusAway__onebusaway-android
# [200/355] Wrote: mlcommons__mobile_app_open
# [201/355] Wrote: NiciDieNase__chaosflix
# [202/355] Wrote: Piasy__YaMvp
# [203/355] Wrote: oxygen-updater__oxygen-updater
# [204/355] Wrote: passsy__spot
# [205/355] Wrote: opendocument-app__OpenDocument.droid
# [206/355] Wrote: promeG__TinyPinyin
# [207/355] Wrote: PRosenb__AdbClipboard
# [208/355] Wrote: posm__OpenMapKitAndroid
# [209/355] Wrote: prisma__react-native-prisma
# [210/355] Wrote: PureWriter__ToastCompat
# [211/355] Wrote: mshdabiola__NotePad
# [212/355] Wrote: pilgr__Paper
# [213/355] Wrote: ragunathjawahar__android-saripaar
# [214/355] Wrote: ooni__probe-android
# [215/355] Wrote: kylecorry31__Trail-Sense
# [216/355] [error] rainbow-me__rainbow: [WinError 206] The filename or extension is too long
# [217/355] Wrote: Redgram__redgram-for-reddit
# [218/355] Wrote: RedMadRobot__PINkman
# [219/355] Wrote: orgzly-revived__orgzly-android-revived
# [220/355] Wrote: OpenTracksApp__OpenTracks
# [221/355] Wrote: rafsanjani__datepickertimeline
# [222/355] Wrote: rejasupotaro__Rebuild
# [223/355] Wrote: riggaroo__AndroidDatabaseUpgrades
# [224/355] Wrote: riggaroo__adopt-me-compose
# [225/355] Wrote: natsuk4ze__gal
# [226/355] Wrote: Bdaya-Dev__oidc
# [227/355] Wrote: ronaldsmartin__Material-ViewPagerIndicator
# [228/355] Wrote: Nailik__rhasspy_mobile
# [229/355] Wrote: readrops__Readrops
# [230/355] Wrote: rtoshiro__FullscreenVideoView
# [231/355] Wrote: RoRoche__AndroidStarter
# [232/355] Wrote: NUmeroAndDev__MaterialGallery-android
# [233/355] Wrote: sakusaku3939__DeepLAndroid
# [234/355] Wrote: salvadordeveloper__flutter-crypto-app
# [235/355] Wrote: renyuneyun__Easer
# [236/355] [error] pytorch__executorch: [WinError 206] The filename or extension is too long
# [237/355] Wrote: ruffle-rs__ruffle-android
# [238/355] Wrote: rosuH__EasyWatermark
# [239/355] Wrote: requery__requery
# [240/355] Wrote: android__nowinandroid
# [241/355] Wrote: SecUSo__privacy-friendly-pedometer
# [242/355] Wrote: SecUSo__privacy-friendly-notes
# [243/355] Wrote: SecUSo__privacy-friendly-todo-list
# [244/355] Wrote: privacybydesign__irmamobile
# [245/355] Wrote: servo__surfman
# [246/355] Wrote: Rajawali__Rajawali
# [247/355] Wrote: simonnorberg__dmach
# [248/355] Wrote: sellmair__kompass
# [249/355] Wrote: sangcomz__FishBun
# [250/355] Wrote: segler-alex__RadioDroid
# [251/355] Wrote: rozPierog__Cofi
# [252/355] Wrote: scribe-org__Scribe-Android
# [253/355] Wrote: seedvault-app__seedvault
# [254/355] Wrote: ReactiveCircus__streamlined
# [255/355] Wrote: RBusarow__Tangle
# [256/355] Wrote: Spikeysanju__Wiggles
# [257/355] Wrote: splitwise__TokenAutoComplete
# [258/355] Wrote: square__curtains
# [259/355] Wrote: square__cycler
# [260/355] Wrote: cgeo__cgeo
# [261/355] Wrote: sky-map-team__stardroid
# [262/355] Wrote: square__papa
# [263/355] Wrote: Samsung__escargot
# [264/355] Wrote: pachli__pachli-android
# [265/355] Wrote: owntracks__android
# [266/355] Wrote: sopt-makers__sopt-android
# [267/355] Wrote: Stuart-campbell__RushOrm
# [268/355] Wrote: persian-calendar__persian-calendar
# [269/355] Wrote: smartdevicelink__sdl_java_suite
# [270/355] Wrote: syrjs__core
# [271/355] Wrote: spacecowboy__NotePad
# [272/355] Wrote: takahirom__PreLollipopTransition
# [273/355] Wrote: talenguyen__PrettyBundle
# [274/355] Wrote: StefanIlchev__ElementumService
# [275/355] Wrote: SwissCovid__swisscovid-app-android
# [276/355] Wrote: spacecowboy__Feeder
# [277/355] Wrote: getodk__collect
# [278/355] Wrote: tfcporciuncula__flow-preferences
# [279/355] Wrote: tfcporciuncula__phonemoji
# [280/355] Wrote: slackhq__circuit
# [281/355] Wrote: TharunBalaji2004__android-ci-cd
# [282/355] Wrote: thiagokimo__Faker
# [283/355] Wrote: t895__DNSNet
# [284/355] Wrote: synonymdev__bitkit
# [285/355] Wrote: thevindu-w__clip_share_client
# [286/355] Wrote: ThibaultBee__srtdroid
# [287/355] Wrote: PatilShreyas__NotyKT
# [288/355] Wrote: tripadvisor__android-clockseekbar
# [289/355] Wrote: tonilopezmr__Game-of-Thrones
# [290/355] Wrote: Tommy-Geenexus__exif-eraser
# [291/355] Wrote: thunderbiscuit__padawan-wallet
# [292/355] Wrote: TUBB__CalendarSelector
# [293/355] Wrote: twilio__twilio-voice-react-native
# [294/355] Wrote: TomRoush__PdfBox-Android
# [295/355] Wrote: thyrlian__AwesomeValidation
# [296/355] Wrote: softartdev__NoteDelight
# [297/355] Wrote: twireapp__Twire
# [298/355] Wrote: openhab__openhab-android
# [299/355] Wrote: ValentinFunk__BrainPhaser
# [300/355] Wrote: RocketChat__Rocket.Chat.ReactNative
# [301/355] Wrote: VictorAlbertos__SwipeCoordinator
# [302/355] Wrote: VictorAlbertos__BreadcrumbsView
# [303/355] Wrote: simpledotorg__simple-android
# [304/355] Wrote: vitaviva__CountdownTimer
# [305/355] Wrote: vitaviva__compose-weather
# [306/355] Wrote: uber__simple-store
# [307/355] Wrote: vgaidarji__ci-matters
# [308/355] Wrote: voghDev__PdfViewPager
# [309/355] Wrote: getsentry__sentry-react-native
# [310/355] Wrote: ValterKasper__space-app
# [311/355] Wrote: wajahatkarim3__Imagine
# [312/355] Wrote: woxingxiao__FillBlankView
# [313/355] Wrote: xebia-functional__appsly-android-rest
# [314/355] Wrote: XuDaojie__MultiStateView
# [315/355] Wrote: xurxodev__Movies-Kotlin-Kata
# [316/355] Wrote: vmiklos__plees-tracker
# [317/355] Wrote: v2er-app__Android
# [318/355] Wrote: UriahShaulMandel__BaldPhone
# [319/355] Wrote: yeungeek__monkey-android
# [320/355] Wrote: zeref278__flutter_boilerplate
# [321/355] Wrote: willowtreeapps__vocable-android
# [322/355] Wrote: TeamAmaze__AmazeFileManager
# [323/355] Wrote: y-polek__TransmissionRemote
# [324/355] Wrote: square__leakcanary
# [325/355] Wrote: zsoltk__GameOfLife
# [326/355] Wrote: VREMSoftwareDevelopment__WiFiAnalyzer
# [327/355] Wrote: XRPL-Labs__Xaman-App
# [328/355] Wrote: TeamNewPipe__NewPipe
# [329/355] Wrote: WangJie0822__Cashbook
# [330/355] Wrote: TwidereProject__TwidereX-Android
# [331/355] Wrote: yuriykulikov__AlarmClock
# [332/355] Wrote: zimly__zimly-backup
# [333/355] Wrote: zkmopro__mopro
# [334/355] Wrote: software-mansion__react-native-screens
# [335/355] Wrote: trynoice__android-app
# [336/355] Wrote: tasks__tasks
# [337/355] Wrote: AndBible__and-bible
# [338/355] Wrote: streetwriters__notesnook
# [339/355] Wrote: yogeshpaliyal__KeyPass
# [340/355] Wrote: TechbeeAT__jtxBoard
# [341/355] Wrote: wikimedia__apps-android-wikipedia
# [342/355] Wrote: square__okhttp
# [343/355] Wrote: realm__realm-kotlin
# [344/355] Wrote: EnsembleUI__ensemble
# [345/355] Wrote: nightscout__AndroidAPS
# [346/355] Wrote: robolectric__robolectric
# [347/355] Wrote: zoff99__ToxAndroidRefImpl
# [348/355] Wrote: MiSikora__laboratory
# [349/355] Wrote: SharezoneApp__sharezone-app
# [350/355] Wrote: square__wire
# [351/355] Wrote: ankidroid__Anki-Android
# [352/355] Wrote: dart-lang__native
# [353/355] Wrote: sqldelight__sqldelight
# [354/355] Wrote: nextcloud__android
# [355/355] Wrote: LedgerHQ__ledger-live
# [done] JSON -> C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3\mineV9.4  (written=352, skipped=0, errors=3)
# [done] Summary: index_summary.csv, index_summary.json, QA: qa_issues.csv
# [run] Finished.

# %% [markdown]
# ## Episodes defintion: Start to current timeline

# %%
# === Build dataset for Observation 3.1 (V9.3 aligned) ===
# CHANGES:
# - DROP current_*_strict columns (they were misleading for your use case)
# - "FIRST" now uses a per-style union rule:
#     The earliest style to achieve ≥14 days of continuous coverage (no projecting beyond cutoff).
#   -> Updates: first_date, first_year, first_label, first_styleset
#   -> Also writes: first_styleset_union14d (same value as first_styleset for clarity)
# - "TIMELINE FORMATION" styles:
#     timeline_styleset_union14d = all styles that EVER achieved ≥14 days at any time
#     (filters out temporary (<14d) add+remove changes; does not use post-cutoff time)
# - "CURRENT" stays snapshot-based (repo-wide inventory at cutoff, no ≥14d):
#     current_label_snapshot, current_styleset_snapshot
# - Default-branch snapshot kept as current_styleset_default_B
# - num_episodes counts episodes with duration ≥14 days (as before)

from __future__ import annotations
import json
from pathlib import Path
from datetime import datetime, timezone, timedelta
from typing import Dict, List, Optional, Tuple, Set
import pandas as pd

# ---- Paths ----
WORK_ROOT   = Path(r"C:\Android Mobile App\Step2_Clone_Repo\Type_1\Aug_10\RQ3")
OUTPUT_MINE = WORK_ROOT / "mineV9.3"

MAIN_CSV = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\1_Main_Spreadsheet\5.0_Total_Repo.csv")

OBS_OUTPUT = Path(r"C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\RQ3\Observations")
OBS_OUTPUT.mkdir(parents=True, exist_ok=True)

# ---- Settings ----
CUTOFF_ISO   = "2025-08-10 23:59:59 +0000"
PERSIST_DAYS = 14.0
CANONICAL_STYLES: Set[str] = {"Emu_Community", "Emu_Custom", "GMD", "ThirdParty"}

# ---- Helpers ----
def parse_iso(s: Optional[str]) -> Optional[datetime]:
    if not s:
        return None
    s = s.strip()
    if s.endswith("Z"):
        s = s[:-1] + "+00:00"
    # normalize +0000 -> +00:00
    if len(s) >= 5 and (s[-5] in ["+","-"]) and s[-3] != ":":
        s = s[:-2] + ":" + s[-2:]
    try:
        dt = datetime.fromisoformat(s)
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt.astimezone(timezone.utc)
    except Exception:
        return None

CUTOFF_DT = parse_iso(CUTOFF_ISO)
assert CUTOFF_DT is not None, f"Bad CUTOFF_ISO: {CUTOFF_ISO}"

def days_between(a: datetime, b: datetime) -> float:
    return (b - a).total_seconds() / 86400.0

def normalize_styles(style_list: List[str]) -> Set[str]:
    return {s for s in (style_list or []) if s in CANONICAL_STYLES}

def label_from_set(s: Set[str]) -> str:
    if "Emu_Community" in s and "Emu_Custom" in s:
        return "Both"
    if "Emu_Community" in s:
        return "Community"
    if "Emu_Custom" in s:
        return "Custom"
    if "GMD" in s:
        return "GMD"
    if "ThirdParty" in s:
        return "ThirdParty"
    return "None"

def read_repo_jsons(output_dir: Path) -> List[Path]:
    return sorted([p for p in output_dir.glob("*.emulator_timeline.json")])

def build_episodes(timeline_rows: List[Dict], cutoff_dt: datetime) -> List[Dict]:
    """Build contiguous episodes from timeline rows with non-empty canonical styles, capped at cutoff."""
    rows = [r for r in (timeline_rows or []) if r.get("styles")]
    rows.sort(key=lambda r: parse_iso(r.get("date")) or datetime.min.replace(tzinfo=timezone.utc))

    episodes: List[Dict] = []
    for i, r in enumerate(rows):
        start = parse_iso(r.get("date"))
        if start is None:
            continue

        styles_now = normalize_styles(list(r.get("styles") or []))
        if not styles_now:
            continue

        # end at the date of the next canonical row, else at cutoff
        end: Optional[datetime] = None
        for j in range(i + 1, len(rows)):
            nxt = rows[j]
            nxt_styles = normalize_styles(list(nxt.get("styles") or []))
            if nxt_styles:
                end = parse_iso(nxt.get("date"))
                break
        if end is None:
            end = cutoff_dt
        if end <= start:
            continue

        episodes.append({
            "start": start,
            "end": min(end, cutoff_dt),
            "styles": styles_now,
            "duration_days": max(0.0, days_between(start, min(end, cutoff_dt))),
        })
    return episodes

# ---- Per-style interval utilities ----
def merge_intervals(intervals: List[Tuple[datetime, datetime]]) -> List[Tuple[datetime, datetime]]:
    """Merge overlapping/contiguous [start,end] intervals."""
    if not intervals:
        return []
    intervals.sort(key=lambda ab: ab[0])
    merged: List[Tuple[datetime, datetime]] = []
    cur_s, cur_e = intervals[0]
    for a, b in intervals[1:]:
        if a <= cur_e:  # overlap or contiguous
            if b > cur_e: cur_e = b
        else:
            merged.append((cur_s, cur_e))
            cur_s, cur_e = a, b
    merged.append((cur_s, cur_e))
    return merged

def per_style_intervals(episodes: List[Dict]) -> Dict[str, List[Tuple[datetime, datetime]]]:
    """Intervals per style drawn from episode styles (episodes already capped at cutoff)."""
    m: Dict[str, List[Tuple[datetime, datetime]]] = {s: [] for s in CANONICAL_STYLES}
    for ep in episodes:
        for s in (ep["styles"] or []):
            if s in CANONICAL_STYLES:
                m[s].append((ep["start"], ep["end"]))
    # merge
    return {s: merge_intervals(v) for s, v in m.items() if v}

# ---- FIRST via union ≥14d ----
def first_union14d(episodes: List[Dict], min_days: float) -> Tuple[Optional[datetime], Optional[str]]:
    """
    Earliest moment any single style achieves ≥min_days of continuous coverage.
    Returns (first_date, style_name) or (None, None).
    """
    psi = per_style_intervals(episodes)
    best_date: Optional[datetime] = None
    best_style: Optional[str] = None

    # deterministic style tie-break order
    order = ["Emu_Community", "Emu_Custom", "GMD", "ThirdParty"]
    for style in order:
        if style not in psi: 
            continue
        for a, b in psi[style]:
            if days_between(a, b) >= min_days:
                t = a + timedelta(days=min_days)
                if best_date is None or t < best_date or (t == best_date and order.index(style) < order.index(best_style)):  # type: ignore
                    best_date = t
                    best_style = style
                break  # earliest interval for this style is enough

    return best_date, best_style

# ---- TIMELINE formation set (union of styles that ever achieved ≥14d) ----
def timeline_union14d_styles(episodes: List[Dict], min_days: float) -> Set[str]:
    psi = per_style_intervals(episodes)
    kept: Set[str] = set()
    for s, ivs in psi.items():
        for a, b in ivs:
            if days_between(a, b) >= min_days:
                kept.add(s)
                break
    return kept

def _find_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    lowmap = {c.lower(): c for c in df.columns}
    for name in candidates:
        if name.lower() in lowmap:
            return lowmap[name.lower()]
    return None

# ---- Build OBS core from miner ----
records: List[Dict] = []

json_files = read_repo_jsons(OUTPUT_MINE)
if not json_files:
    raise FileNotFoundError(f"No miner JSON files found under: {OUTPUT_MINE}")

for jf in json_files:
    with jf.open("r", encoding="utf-8") as f:
        rec = json.load(f)

    repo = rec.get("repo_name") or jf.stem
    timeline = rec.get("timeline") or []

    episodes = build_episodes(timeline, CUTOFF_DT)

    # Count episodes with ≥14d (for reference)
    num_episodes = sum(1 for ep in episodes if ep.get("duration_days", 0.0) >= PERSIST_DAYS)

    # FIRST via union ≥14d
    first_dt, first_style = first_union14d(episodes, PERSIST_DAYS)
    if first_dt and first_style:
        first_styleset_union14d = first_style
        first_label = label_from_set({first_style})
        first_year = first_dt.year
    else:
        first_styleset_union14d = ""
        first_label = "None"
        first_year = ""

    # TIMELINE formation set (filters out temporary <14d styles)
    timeline_set = timeline_union14d_styles(episodes, PERSIST_DAYS)
    timeline_styleset_union14d = "+".join(sorted(timeline_set)) if timeline_set else ""
    timeline_label_union14d = label_from_set(timeline_set)

    # CURRENT snapshot (repo-wide, no ≥14d)
    snap_def_raw  = rec.get("snapshot_as_of_cutoff_default") or []
    snap_all_raw  = rec.get("snapshot_as_of_cutoff_repo_wide") or []
    snap_def_norm_set  = normalize_styles(snap_def_raw)
    snap_all_norm_set  = normalize_styles(snap_all_raw)

    current_label_snapshot    = label_from_set(snap_all_norm_set)
    current_styleset_snapshot = "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else ""

    # Default-branch snapshot
    current_styleset_default_B = "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else ""

    # Optional diagnostic: short-and-active-at-cutoff flag (kept)
    recent_lt14d = 0
    if episodes:
        last_ep = episodes[-1]
        if last_ep["end"] >= CUTOFF_DT and last_ep["duration_days"] < PERSIST_DAYS:
            recent_lt14d = 1

    full_name = (repo or "").replace("__", ".")

    out = {
        "repo_name": repo,
        "full_name": full_name,
        "cutoff_date": CUTOFF_ISO,

        "num_episodes": num_episodes,

        # FIRST (union ≥14d)
        "first_date": first_dt.isoformat() if first_dt else "",
        "first_year": first_year,
        "first_label": first_label,
        "first_styleset": first_styleset_union14d,           # updated meaning
        "first_styleset_union14d": first_styleset_union14d,  # explicit column

        # TIMELINE formation set (ever ≥14d)
        "timeline_styleset_union14d": timeline_styleset_union14d,
        "timeline_label_union14d": timeline_label_union14d,

        # CURRENT (snapshot)
        "current_label_snapshot": current_label_snapshot,
        "current_styleset_snapshot": current_styleset_snapshot,
        "current_styleset_default_B": current_styleset_default_B,

        # Diagnostics
        "current_recent_lt14d": recent_lt14d,
        "snapshot_default_norm": "+".join(sorted(snap_def_norm_set)) if snap_def_norm_set else "",
        "snapshot_repo_wide_norm": "+".join(sorted(snap_all_norm_set)) if snap_all_norm_set else "",
        "qa_issue": rec.get("qa_issue", ""),
    }
    records.append(out)

df = pd.DataFrame.from_records(records).sort_values(["first_date", "repo_name"], na_position="last")

# ---- Merge MAIN: include 'execution_environment' as-is; exclude api_*; prefix the rest with main_ ----
if MAIN_CSV.exists():
    df_main = pd.read_csv(MAIN_CSV, dtype=str, encoding="utf-8", keep_default_na=False)

    col_full = _find_col(df_main, ["full_name", "Full_name", "repo_full_name"])
    col_exec = _find_col(df_main, ["execution_environment", "Execution_Environment"])

    if col_full:
        df["_key"] = df["full_name"].astype(str).str.lower().str.strip()
        df_main["_key"] = df_main[col_full].astype(str).str.lower().str.strip()

        # execution_environment as-is
        if col_exec:
            df_exec = df_main[["_key", col_exec]].copy()
            df_exec.rename(columns={col_exec: "execution_environment"}, inplace=True)
            df = df.merge(df_exec, on="_key", how="left")
        else:
            df["execution_environment"] = ""

        # other MAIN columns (exclude join col, exec col, any api_*)
        main_cols = []
        for c in df_main.columns:
            cl = c.lower()
            if c in {"_key", col_full}: continue
            if col_exec and c == col_exec: continue
            if cl.startswith("api_"): continue
            main_cols.append(c)
        if main_cols:
            df_other = df_main[["_key"] + main_cols].copy()
            df_other.rename(columns={c: f"main_{c}" for c in main_cols}, inplace=True)
            df = df.merge(df_other, on="_key", how="left")

        df.drop(columns=["_key"], inplace=True, errors="ignore")
    else:
        df["execution_environment"] = ""
else:
    df["execution_environment"] = ""

# ---- Column order: repo_name, full_name, execution_environment, then the rest ----
cols = list(df.columns)
for required in ["repo_name", "full_name", "execution_environment"]:
    if required not in cols:
        cols.insert(0, required)

# place full_name after repo_name
if "repo_name" in cols and "full_name" in cols:
    cols.remove("full_name")
    cols.insert(cols.index("repo_name") + 1, "full_name")

# place execution_environment after full_name
if "execution_environment" in cols:
    cols.remove("execution_environment")
    insert_at = cols.index("full_name") + 1 if "full_name" in cols else 1
    cols.insert(insert_at, "execution_environment")

df = df[cols]

# ---- FILTER: exclude repos where first_label == "None" ----
pre_filter_n = len(df)
df = df[df["first_label"] != "None"].copy()
post_filter_n = len(df)
dropped_n = pre_filter_n - post_filter_n
print(f"[info] Excluding repos with first_label == 'None': dropped {dropped_n} of {pre_filter_n}")

# ---- Save ----
out_csv = OBS_OUTPUT / "obs3_1_entry_vs_current.csv"
df.to_csv(out_csv, index=False, encoding="utf-8")
print(f"[ok] Wrote dataset (filtered): {out_csv}")

# Optional quick peek
try:
    show_cols = [
        "repo_name","full_name","execution_environment",
        "num_episodes",
        "first_year","first_label","first_date",
        "first_styleset","first_styleset_union14d",
        "timeline_styleset_union14d","timeline_label_union14d",
        "current_label_snapshot","current_styleset_snapshot",
        "current_styleset_default_B",
        "current_recent_lt14d",
        "snapshot_repo_wide_norm"
    ]
    show_cols += [c for c in df.columns if c.startswith("main_")][:3]
    print(df[show_cols].head(20).to_string(index=False))
except Exception:
    pass
# Out:
# [info] Excluding repos with first_label == 'None': dropped 1 of 352
# [ok] Wrote dataset (filtered): C:\Android Mobile App\Step3_Instr_Testing_Analysis\Type_1\Aug_10\RQ3\Observations\obs3_1_entry_vs_current.csv
#                                 repo_name                                full_name                execution_environment  num_episodes first_year first_label                first_date first_styleset first_styleset_union14d   timeline_styleset_union14d timeline_label_union14d current_label_snapshot    current_styleset_snapshot current_styleset_default_B  current_recent_lt14d      snapshot_repo_wide_norm                                               main_html_url main_native_instru_test main_flutter_instru_test
#                   ankidroid__Anki-Android                   ankidroid.Anki-Android              Emulator_ReactiveCircus             2       2013      Custom 2013-07-04T07:12:51+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                   https://github.com/ankidroid/Anki-Android                      45                        0
#                              tasks__tasks                              tasks.tasks Emulator_ReactiveCircus,Emulator_GMD             4       2013      Custom 2013-10-30T23:48:56+00:00     Emu_Custom              Emu_Custom Emu_Community+Emu_Custom+GMD                    Both                   Both Emu_Community+Emu_Custom+GMD          Emu_Community+GMD                     0 Emu_Community+Emu_Custom+GMD                              https://github.com/tasks/tasks                      70                        0
#     xebia-functional__appsly-android-rest     xebia-functional.appsly-android-rest                         Emulator_DIY             1       2014      Custom 2014-01-11T22:45:09+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom     https://github.com/xebia-functional/appsly-android-rest                      11                        0
#                      spacecowboy__NotePad                      spacecowboy.NotePad              Emulator_ReactiveCircus             2       2014      Custom 2014-02-01T14:45:28+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                      https://github.com/spacecowboy/NotePad                      31                        0
#                        nextcloud__android                        nextcloud.android              Emulator_ReactiveCircus             4       2014      Custom 2014-02-04T16:16:57+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                        https://github.com/nextcloud/android                     132                        0
#                     rejasupotaro__Rebuild                     rejasupotaro.Rebuild                         Emulator_DIY             1       2014      Custom 2014-02-17T14:16:49+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                     https://github.com/rejasupotaro/Rebuild                       9                        0
#  ksoichiro__SimpleAlertDialog-for-Android  ksoichiro.SimpleAlertDialog-for-Android                         Emulator_DIY             1       2014      Custom 2014-03-22T14:35:30+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom  https://github.com/ksoichiro/SimpleAlertDialog-for-Android                       1                        0
#            ksoichiro__AndroidFormEnhancer            ksoichiro.AndroidFormEnhancer                         Emulator_DIY             1       2014      Custom 2014-03-23T11:15:00+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom            https://github.com/ksoichiro/AndroidFormEnhancer                       2                        0
#                    AntennaPod__AntennaPod                    AntennaPod.AntennaPod              Emulator_ReactiveCircus             2       2014      Custom 2014-06-01T20:12:08+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                    https://github.com/AntennaPod/AntennaPod                      23                        0
#            OneBusAway__onebusaway-android            OneBusAway.onebusaway-android              Emulator_ReactiveCircus             2       2014      Custom 2014-06-10T17:14:25+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community            https://github.com/OneBusAway/onebusaway-android                      51                        0
#                 openintents__shoppinglist                 openintents.shoppinglist                         Emulator_DIY             1       2014      Custom 2014-06-30T11:25:16+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                 https://github.com/openintents/shoppinglist                       3                        0
#                  OpnTec__bodyapps-android                  OpnTec.bodyapps-android                         Emulator_DIY             1       2014      Custom 2014-07-06T19:34:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                  https://github.com/OpnTec/bodyapps-android                       9                        0
# blazsolar__android-collapse-calendar-view blazsolar.android-collapse-calendar-view                         Emulator_DIY             1       2014      Custom 2014-07-30T10:03:36+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom https://github.com/blazsolar/android-collapse-calendar-view                       1                        0
#                          AChep__AcDisplay                          AChep.AcDisplay                         Emulator_DIY             1       2014      Custom 2014-08-05T16:23:35+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                          https://github.com/AChep/AcDisplay                       6                        0
#         tripadvisor__android-clockseekbar         tripadvisor.android-clockseekbar                         Emulator_DIY             1       2014      Custom 2014-08-18T20:21:23+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom         https://github.com/tripadvisor/android-clockseekbar                       2                        0
#                         ligi__PassAndroid                         ligi.PassAndroid              Emulator_ReactiveCircus             2       2014      Custom 2014-08-26T19:45:07+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                         https://github.com/ligi/PassAndroid                      27                        0
#   ksoichiro__Android-ObservableScrollView   ksoichiro.Android-ObservableScrollView                         Emulator_DIY             1       2014      Custom 2014-11-22T15:16:43+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom   https://github.com/ksoichiro/Android-ObservableScrollView                      46                        0
#                       simonnorberg__dmach                       simonnorberg.dmach              Emulator_ReactiveCircus             2       2015      Custom 2015-01-01T19:43:14+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both              Community                Emu_Community              Emu_Community                     0                Emu_Community                       https://github.com/simonnorberg/dmach                       2                        0
#                        MostafaGazar__soas                        MostafaGazar.soas                         Emulator_DIY             1       2015      Custom 2015-01-12T21:40:46+00:00     Emu_Custom              Emu_Custom                   Emu_Custom                  Custom                 Custom                   Emu_Custom                 Emu_Custom                     0                   Emu_Custom                        https://github.com/MostafaGazar/soas                       5                        0
#                 federicoiosue__Omni-Notes                 federicoiosue.Omni-Notes              Emulator_ReactiveCircus             2       2015      Custom 2015-03-03T00:13:10+00:00     Emu_Custom              Emu_Custom     Emu_Community+Emu_Custom                    Both                   Both     Emu_Community+Emu_Custom              Emu_Community                     0     Emu_Community+Emu_Custom                 https://github.com/federicoiosue/Omni-Notes                      41                        0
