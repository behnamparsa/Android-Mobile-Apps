# %%
import os
import pandas as pd
import re
import yaml  # pip install pyyaml

# === CONFIG ===
PROJECTS_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files"
OUTPUT_DIR = r"D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Analysis Output"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, "7.1-YML_List_1st_attempt_ShallowC.csv")

# === UNIVERSAL UNIT TEST KEYWORDS ===
UNIT_TEST_KEYWORDS = [
    'gradlew test', './gradlew test', 'testdebugunittest', 'testreleaseunittest',
    'test', 'run unit tests', 'run: test', 'npm test', 'yarn test'
]

# === CI-SPECIFIC INSTRUMENTATION RULES ===
def detect_instrumentation_by_platform(ci_platform, yaml_text, run_scripts, parsed):
    """
    Improved detection:
    - Wrappers & GMD: parsed 'uses'
    - Manual emulator: must have (sdkmanager or avdmanager) AND (emulator or avdmanager)
    - No more adb-only false positives.
    """

    run_text = "\n".join(run_scripts)
    found = set()
    matched = []

    # === Common emulator keywords ===
    has_sdk = any(kw in run_text for kw in ['sdkmanager'])
    has_avd = any(kw in run_text for kw in ['avdmanager'])
    has_emulator = any(kw in run_text for kw in ['emulator'])
    has_create_avd = any(kw in run_text for kw in ['android create avd'])

    if ci_platform == "GitHub":
        # 1️⃣ Wrappers & GMD
        for job in parsed.get('jobs', {}).values():
            for step in job.get('steps', []):
                if isinstance(step, dict) and 'uses' in step:
                    uses = step['uses'].lower()
                    if 'reactivecircus/android-emulator-runner' in uses:
                        found.add('GitHub_emulator_full')
                        matched.append('reactivecircus/android-emulator-runner')
                    if 'malinskiy/action-android/emulator-run-cmd' in uses:
                        found.add('GitHub_emulator_compact')
                        matched.append('malinskiy/action-android/emulator-run-cmd')
                    if any(gmd in uses for gmd in ['cleanmanageddevices', 'managedvirtualdevice', 'manageddevices']):
                        found.add('GitHub_GMD')
                        matched.append('GMD keywords (uses)')

        if any("cleanmanageddevices" in s or "manageddevices" in s for s in run_scripts):
            found.add('GitHub_GMD')
            matched.append('GMD keywords (Gradle run)')

        # ✅ Improved manual check:
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitHub_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "CircleCI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('CircleCI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Bitrise":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Bitrise_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "GitLab CI":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('GitLab CI_emulator_manual')
            matched.append('manual emulator setup')

    elif ci_platform == "Travis CI":
        if (has_sdk or has_avd or has_create_avd) and (has_emulator or has_avd):
            found.add('TravisCI_emulator_manual')
            matched.append('manual emulator setup')



    elif ci_platform == "Other":
        if (has_sdk or has_avd) and (has_emulator or has_avd):
            found.add('Other_emulator_manual')
            matched.append('manual emulator setup')

    # === Third-party Labs ===
    lab_run_text = run_text
    for job in parsed.get('jobs', {}).values():
        for step in job.get('steps', []):
            if isinstance(step, dict) and 'uses' in step:
                uses = step['uses'].lower()
                if 'firebase-test-lab-action' in uses:
                    found.add('Firebase_Compact')
                    matched.append('Firebase-Test-Lab-Action')
                if 'microsoft/appcenter-test-cli-action' in uses:
                    found.add('Appcenter')
                    matched.append('Appcenter Test CLI Action')
                if 'browserstack' in uses or 'browserstack/github-actions' in uses:
                    found.add('Browserstack')
                    matched.append('Browserstack action')
                if 'saucelabs/saucectl-run-action' in uses:
                    found.add('SauceLabs')
                    matched.append('Sauce Labs GitHub Action')

    if 'gcloud firebase test android run' in lab_run_text:
        found.add('Firebase_Full')
        matched.append('gcloud firebase test android run')

    if 'appcenter test run' in lab_run_text:
        found.add('Appcenter')
        matched.append('appcenter test run')

    if 'browserstack' in lab_run_text:
        found.add('Browserstack')
        matched.append('browserstack CLI call')

    if 'saucectl' in lab_run_text:
        found.add('SauceLabs')
        matched.append('saucectl CLI')

    return found, matched


def detect_ci_platform(file_path, yaml_text):
    text = yaml_text.lower()
    path = file_path.lower()
    filename = os.path.basename(path)

    if re.search(r'(^|[\\/])\.github([\\/]|$)', path) or 'github_actions' in filename:
        return "GitHub"
    if '.gitlab' in path or 'gitlab-ci' in filename:
        return "GitLab CI"
    if '.travis' in path or 'travis' in filename:
        return "Travis CI"
    if '.circleci' in path or 'circleci' in filename:
        return "CircleCI"
    if '.bitrise' in path or 'bitrise' in filename:
        return "Bitrise"

    if 'uses: actions/' in text:
        return "GitHub"
    if 'uses: docker://circleci/' in text or 'circleci/android:' in text:
        return "CircleCI"
    if 'travis' in text:
        return "Travis CI"
    if 'bitrise' in text:
        return "Bitrise"
    if 'gitlab-ci' in text:
        return "GitLab CI"

    return "Other"


def detect_unit_test(yaml_text):
    text = yaml_text.lower()
    for kw in UNIT_TEST_KEYWORDS:
        if kw in text:
            return True
    return False


def extract_run_scripts(parsed):
    def get_runs(node):
        runs = []
        if isinstance(node, dict):
            for k, v in node.items():
                if k == 'run' and isinstance(v, str):
                    runs.append(v.lower())
                else:
                    runs.extend(get_runs(v))
        elif isinstance(node, list):
            for item in node:
                runs.extend(get_runs(item))
        return runs

    scripts = get_runs(parsed)
    if isinstance(parsed, dict):
        for key in ['script', 'before_script', 'before_install', 'after_script']:
            val = parsed.get(key)
            if isinstance(val, list):
                scripts.extend([str(v).lower() for v in val])
            elif isinstance(val, str):
                scripts.append(val.lower())
    return scripts


# === PROCESS ALL ===
results = []

for root, _, files in os.walk(PROJECTS_DIR):
    for file in files:
        if file.endswith(('.yml', '.yaml')):
            file_path = os.path.join(root, file)
            filename = os.path.basename(file_path)
            parts = filename.split(".")
            username = parts[0].lower() if len(parts) > 1 else 'unknown'
            project_name = parts[1].lower() if len(parts) > 2 else parts[0].lower()

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    raw = f.read().replace('\t', ' ')
                    ci_platform = detect_ci_platform(file_path, raw)

                    parsed = yaml.safe_load(raw)
                    run_scripts = extract_run_scripts(parsed)

                    is_unit = detect_unit_test(raw)
                    instr_types, matched_keys = detect_instrumentation_by_platform(ci_platform, raw, run_scripts, parsed)

                    test_type_str = ', '.join(sorted(instr_types))
                    is_instr = bool(instr_types)

                    results.append({
                        'filename': filename,
                        'username': username,
                        'project': project_name,
                        'full_name': f"{username}.{project_name}",
                        'ci_platform': ci_platform,
                        'test_type': test_type_str,
                        'unit_test': is_unit,
                        'instrumentation_test': is_instr,
                        'matched_keywords': "; ".join(sorted(set(matched_keys)))
                    })

                    print(f"✅ {filename} | CI: {ci_platform} | Unit: {is_unit} | Instr: {is_instr} | Keys: {matched_keys}")

            except Exception as e:
                print(f"❌ ERROR: {file_path} => {e}")
                results.append({
                    'filename': filename,
                    'username': username,
                    'project': project_name,
                    'full_name': f"{username}.{project_name}",
                    'ci_platform': 'Error',
                    'test_type': '',
                    'unit_test': False,
                    'instrumentation_test': False,
                    'matched_keywords': ''
                })

# === EXPORT ===
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ DONE! CSV generated at: {OUTPUT_CSV}")
# Out:
# ✅ JunkFood02.Seal.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ JunkFood02.Seal.Other.bug_report.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ JunkFood02.Seal.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ JunkFood02.Seal.Other.feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ JunkFood02.Seal.GitHub.Issue-Handler.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JunkFood02.Seal.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JunkFood02.Seal.GitHub.android_ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JunkFood02.Seal.GitHub.close-stale-issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JunkFood02.Seal.GitHub.sponsor.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.nowinandroid.Other.bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.nowinandroid.Other.docs_issue.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.nowinandroid.Other.feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.nowinandroid.GitHub.Build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ android.nowinandroid.GitHub.NightlyBaselineProfiles.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ android.nowinandroid.GitHub.Release.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['GMD keywords (Gradle run)', 'manual emulator setup']
# ✅ android.nowinandroid.Other.packaging.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ square.picasso.GitHub.build.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ square.picasso.GitHub.release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ google.flexbox-layout.CircleCI.config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ google.flexbox-layout.GitHub.gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.sunflower.Other.bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.sunflower.Other.feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.sunflower.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.sunflower.GitHub.copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.sunflower.GitHub.update_deps.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.sunflower.Other.packaging.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ nickbutcher.plaid.CircleCI.config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ nickbutcher.plaid.GitHub.copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ nickbutcher.plaid.GitHub.gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ MatsuriDayo.NekoBoxForAndroid.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mihonapp.mihon.Other.1_request_feature.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mihonapp.mihon.Other.2_report_issue.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mihonapp.mihon.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ mihonapp.mihon.GitHub.build_pull_request.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mihonapp.mihon.GitHub.build_push.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mihonapp.mihon.GitHub.update_website.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.uamp.GitHub.android.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ android.uamp.GitHub.copy-branch.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ android.uamp.Other.packaging.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.add_device.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.Other.custom.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.add-device.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.avd-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-debug-kernel.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-a12.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-a13.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-a14.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-a15.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-arcvm.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-avd.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-kernel-wsa.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-lkm.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-manager.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.build-su.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.clippy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.deploy-website.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.gki-kernel.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.ksud.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.rustfmt.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.shellcheck.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tiann.KernelSU.GitHub.wsa-kernel.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ mikepenz.MaterialDrawer.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ mikepenz.MaterialDrawer.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ mikepenz.MaterialDrawer.GitHub.ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mikepenz.MaterialDrawer.GitHub.gradle-dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.dependabot.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.bug_report_zh.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.feature_request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.Other.feature_request_zh.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.GitHub.issues.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ YiiGuxing.TranslationPlugin.GitHub.snapshot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ coil-kt.coil.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ coil-kt.coil.Other.mkdocs.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ coil-kt.coil.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ coil-kt.coil.Other.action.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ coil-kt.coil.GitHub.ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ Shabinder.SpotiFlyer.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.GitHub.Release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.GitHub.build-and-publish-kjs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.GitHub.build-release-binaries.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.GitHub.maintenance.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Shabinder.SpotiFlyer.GitHub.tf-refresh.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JakeWharton.timber.Other.dependabot.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ JakeWharton.timber.GitHub.build.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ JakeWharton.timber.GitHub.release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.GitHub.gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.GitHub.pre-merge.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ AppIntro.AppIntro.Other.detekt-config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.Other.feature-request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.Other.report_bug.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.GitHub.ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.GitHub.codeql-analysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ libre-tube.LibreTube.GitHub.run-on-release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other..codecov.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other.jitpack.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other.bug_report_form.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.assignees.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.compare_apk_size.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.conflict.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.label.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.milestone.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.opencollective_notices.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.sync_translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.tests_emulator.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner', 'reactivecircus/android-emulator-runner']
# ✅ ankidroid.Anki-Android.GitHub.tests_unit.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.update-gradle-wrapper.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.GitHub.update_js_libs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ankidroid.Anki-Android.Other..yarnrc.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.Other.stale.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.Other.action.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.GitHub.codeql.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.GitHub.test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ InsertKoinIO.koin.GitHub.weekly.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ vfsfitvnm.ViMusic.Other.bug_report.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ vfsfitvnm.ViMusic.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ vfsfitvnm.ViMusic.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.docker-compose.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.mkdocs.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.bug-report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.Other.feature-request.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.buildAndDeploy.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.buildAndTest.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.buildMultiplatform.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.conflicts.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.detektAnalysis.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.dockerPublish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.mkdocs.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.stale-issues-and-prs.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.uncivbot.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.detekt-errors.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ yairm210.Unciv.GitHub.detekt-warnings.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ firebase.quickstart-android.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ firebase.quickstart-android.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ firebase.quickstart-android.Other.packaging.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ firebase.quickstart-android.Other.dataconnect.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ firebase.quickstart-android.Other.connector.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ square.okio.Other.mkdocs.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ square.okio.GitHub.build.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ square.okio.GitHub.release.yaml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.fourmolu.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.bug.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.feature.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.question.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other.action.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.GitHub.cla.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.GitHub.reproduce-schedule.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.GitHub.web.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ simplex-chat.simplex-chat.Other..eslintrc.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ iSoron.uhabits.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ iSoron.uhabits.GitHub.main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ skydoves.Pokedex.Other..coderabbit.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ skydoves.Pokedex.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ skydoves.Pokedex.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ T8RIN.ImageToolbox.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ T8RIN.ImageToolbox.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ T8RIN.ImageToolbox.GitHub.tb_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.Other.detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.Other.bug_report.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.Other.feature_request.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.close-inactive-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.lock-closed-issues.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.publish-cli.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.publish-release.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.publish-snapshot.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.test-e2e-prod.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.test-e2e.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['manual emulator setup']
# ✅ mobile-dev-inc.Maestro.GitHub.test.yaml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ mobile-dev-inc.Maestro.GitHub.update-samples.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mobile-dev-inc.Maestro.GitHub.warn_build_xctestrunner.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.ai_complex.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.ai_simple.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.commands_optional_tournee.yaml => expected a single document in the stream
#   in "<unicode string>", line 2, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.commands_tour.yaml => expected a single document in the stream
#   in "<unicode string>", line 2, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 9, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_fast.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_launchApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.nonexistent
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_launchApp_nonDefault.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_not_found.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_visible.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail_visible_extended.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fill_form.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.long_input_text.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.relatives.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.scrollUntilVisible_timeout.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.swipe.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.assertNotVisible.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.assertTrue.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.assertVisible.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.back.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.copyTextFrom.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.eraseText.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.evalScript.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.extendedWaitUntil.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.hideKeyboard.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.inputRandomEmail.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.inputRandomNumber.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.inputRandomPersonName.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.inputRandomText.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.inputText.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.killApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.launchApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.pasteText.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.pressKey.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.repeat.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.retry.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.runFlow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.runScript.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.example
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.environment-variables.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.notused
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.bookmarks.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.google.samples.apps.n ...
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.fail.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.google.samples.apps.n ...
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.android-advanced-flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.android-flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.ios-advanced-flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikimedia.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.ios-flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikimedia.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.launch-clearstate-android.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.launch-clearstate-ios.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikimedia.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.onboarding-android.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.onboarding-ios.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikimedia.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.run-test.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 5, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.login.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.signup.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.copy-paste.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.feed.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.main.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.saved.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.search.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add-language.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.remove-language.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: org.wikipedia
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.assert_multiple_locations.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: "com.google.android.apps. ...
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.assert_travel_command.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: "com.google.android.apps. ...
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.002_launchApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.003_launchApp_withClearState.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.008_config_unknownKeys.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 7, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.017_launchApp_otherPackage.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.018_backPress_string.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.019_scroll_string.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.020_config_name.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     name: Example Flow
#     ^
# but found another document
#   in "<unicode string>", line 3, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.022_on_flow_start_complete.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 6, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.023_labels.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.024_string_non_string_commands.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.025_killApp.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.027_waitToSettleTimeoutMs.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.028_command_descriptions.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_media_gif.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_media_jpeg.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_media_jpg.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_media_mp4.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_media_png.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.add_multiple_media.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.apple.mobileslideshow
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.flow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 2, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.flowA.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.flowB.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     appId: com.example.app
#     ^
# but found another document
#   in "<unicode string>", line 4, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\mobile-dev-inc.Maestro.Other.subflow.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
# ...
# ✅ eygraber.sqldelight-androidx-driver.GitHub.pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ eygraber.sqldelight-androidx-driver.GitHub.publish_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ eygraber.sqldelight-androidx-driver.GitHub.publish_snapshot_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ roozbehzarei.SuperWebView.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ x13a.Clipeus.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ x13a.Clipeus.GitHub.gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ alirezaeiii.TMDb-Compose-Playground.Other.release-drafter.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ alirezaeiii.TMDb-Compose-Playground.GitHub.android_test.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ alirezaeiii.TMDb-Compose-Playground.GitHub.create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ alirezaeiii.TMDb-Compose-Playground.GitHub.local_unit_test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ alirezaeiii.TMDb-Compose-Playground.GitHub.spotless.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ shadmanadman.KSensor.GitHub.publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ icerockdev.moko-errors.GitHub.compilation-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ icerockdev.moko-errors.GitHub.publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ doublesymmetry.KotlinAudio.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ doublesymmetry.KotlinAudio.Other.action.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ doublesymmetry.KotlinAudio.GitHub.validate.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ matsumo0922.PixiView-KMP.GitHub.pull-request-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ matsumo0922.PixiView-KMP.GitHub.translations.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ matsumo0922.PixiView-KMP.Other.detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ kibotu.StreamingAndroidLogger.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ kibotu.StreamingAndroidLogger.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ dora4.DoraMusic.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ dora4.DoraMusic.GitHub.android_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ nuhkoca.libbra.Other.default-detekt-config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ nuhkoca.libbra.GitHub.ci.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ Lastaapps.menza.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ google-developer-training.basic-android-kotlin-compose-training-lemonade.GitHub.main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\ahaodev.heji.Other..drone.yml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     kind: pipeline # build go server ...
#     ^
# but found another document
#   in "<unicode string>", line 37, column 1:
#     ---
#     ^
# ✅ ahaodev.heji.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\ahaodev.heji.Other.docker-compose.yml => 'NoneType' object has no attribute 'get'
# ✅ Web3Auth.web3auth-android-sdk.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ Kalbra.NoReel.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ Kalbra.NoReel.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ilyasipek.easy-mvi.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ sirekanian.outline.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tobiasschuerg.android-week-view.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.Other..yarnrc.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.Other.lefthook.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.Other.bug_report.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.Other.action.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ jagnesh.react-native-splash-view.GitHub.ci.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.data_model_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.dod_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.dod_wrapper_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.flow_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.rx_data_build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.rx_extensions_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ revolut-mobile.RxData.GitHub.scheduler_publish_maven_action.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.codecov.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.labeler.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.stale.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.technolinator.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.action.yml | CI: GitHub | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.backup-publish-swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.backup-publish-web-npm.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.benchmarks-check.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.cherry-pick-pr-to-newer-release-cycle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.codestyle.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.generate-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.generate-dokka.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.gradle-android-instrumented-tests.yml | CI: GitHub | Unit: True | Instr: True | Keys: ['reactivecircus/android-emulator-runner']
# ✅ wireapp.kalium.GitHub.gradle-android-unit-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.gradle-db-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.gradle-ios-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.gradle-jvm-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.jira-lint-and-link.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.label-pr.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.pr-author-assigner.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.quay.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.semantic-commit-lint.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.GitHub.stale-issues-and-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.docker-compose.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.dashboard.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.datasource.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.plugin.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.prometheus.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.Chart.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ wireapp.kalium.Other.values.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.configmaps.yaml => while parsing a flow node
# expected the node content, but found '-'
#   in "<unicode string>", line 1, column 3:
#     {{- if .Values.podMonitorIntegrati ...
#       ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.monkey-controller.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     apiVersion: v1
#     ^
# but found another document
#   in "<unicode string>", line 17, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.monkey-server.yaml => expected a single document in the stream
#   in "<unicode string>", line 1, column 1:
#     apiVersion: v1
#     ^
# but found another document
#   in "<unicode string>", line 18, column 1:
#     ---
#     ^
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.podmonitor.yaml => while parsing a flow node
# expected the node content, but found '-'
#   in "<unicode string>", line 1, column 3:
#     {{- if .Values.podMonitorIntegrati ...
#       ^
# ✅ wireapp.kalium.Other.config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.site.yml => 'list' object has no attribute 'get'
# ❌ ERROR: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Config Files\wireapp.kalium.Other.main.yml => 'list' object has no attribute 'get'
# ✅ diareuse.gecko.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ diareuse.gecko.GitHub.main.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ solygambas.kotlin-projects.Other.circle.yml | CI: Travis CI | Unit: True | Instr: False | Keys: []
# ✅ solygambas.kotlin-projects.CircleCI.config.yml | CI: CircleCI | Unit: True | Instr: False | Keys: []
# ✅ sczerwinski.android-hilt.Other.dependabot.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ sczerwinski.android-hilt.Other.config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ sczerwinski.android-hilt.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ sczerwinski.android-hilt.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ sczerwinski.android-hilt.Other.detekt.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ MwaiBanda.WPRK-MultiPlatform.GitHub.swift.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Carrieukie.android_mpesa_stk.Other.jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ Carrieukie.android_mpesa_stk.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Yorick-Ryu.CokoTools.GitHub.android.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Patch4Code.Logline.GitHub.build-apk.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ jakepurple13.Full-Multiplatform-Compose-Plugin.GitHub.custom_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ jakepurple13.Full-Multiplatform-Compose-Plugin.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.Other.mkdocs.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ bloomberg.selekt.Other.qodana.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.continuous-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.dependency-submission.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.gradle-wrapper-validation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.periodic-integration.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.publication.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.publish-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.scorecard.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.GitHub.stale.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ bloomberg.selekt.Other.config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ qq549631030.PriorityDialog.GitHub.android-unit-test.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ apivideo.api.video-android-live-stream.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ apivideo.api.video-android-live-stream.GitHub.create-documentation-pr.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ apivideo.api.video-android-live-stream.GitHub.create-release-from-changelog.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ apivideo.api.video-android-live-stream.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ apivideo.api.video-android-live-stream.GitHub.update-documentation.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mvojtkovszky.BillingHelper.Other..jitpack.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ android.midi-samples.Other.packaging.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ alejandro-rios.Boggle-Multiplatform.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ mtrewartha.positional.Other.codecov.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ mtrewartha.positional.Other.detekt.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ mtrewartha.positional.GitHub.tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ IslamKhSh.Xdimen.Other._config.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ IslamKhSh.Xdimen.Other.detekt-config.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ halilozel1903.AdMobApp.Other.FUNDING.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ ishubhamsingh.Splashy.GitHub.Check.yaml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Gegenbauer.CatSpy.GitHub.build_artifacts.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ Gegenbauer.CatSpy.GitHub.create_release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tabilzad.inspektor.GitHub.gradle-publish.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tabilzad.inspektor.GitHub.on-pull-request.yml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ tabilzad.inspektor.GitHub.run-tests.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ tabilzad.inspektor.Other.detekt.yaml | CI: Other | Unit: True | Instr: False | Keys: []
# ✅ FredHappyface.Android.FHCode.Other..pre-commit-config.yaml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ matu666.mytv-android.GitHub.release.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ChrisKruegerDev.trakt-kotlin.Other.release-drafter.yml | CI: Other | Unit: False | Instr: False | Keys: []
# ✅ ChrisKruegerDev.trakt-kotlin.GitHub.build.yml | CI: GitHub | Unit: True | Instr: False | Keys: []
# ✅ ChrisKruegerDev.trakt-kotlin.GitHub.release-update.yml | CI: Other | Unit: True | Instr: False | Keys: []
#
# ✅ DONE! CSV generated at: D:\Android_Mobile_App\AndroidProject_4th\6.2-Shallow_Clone_Complete\Analysis Output\7.1-YML_List_1st_attempt_ShallowC.csv
